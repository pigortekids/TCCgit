# %%
pip install keras --upgrade
# Out:
# Requirement already up-to-date: keras in d:\anaconda\lib\site-packages (2.3.0)
# Requirement already satisfied, skipping upgrade: pyyaml in d:\anaconda\lib\site-packages (from keras) (5.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in d:\anaconda\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: h5py in d:\anaconda\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in d:\anaconda\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in d:\anaconda\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in d:\anaconda\lib\site-packages (from keras) (1.16.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in d:\anaconda\lib\site-packages (from keras) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
#import TCCgit.korea.DQNModel_v4 as dqn
import matplotlib.pyplot as plt
import random

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
caminho_arquivo = ('./consolidado.csv')

# %%
##################### INICIALIZAO DE VARIAVEIS ################################################
index_arquivo = ['preco']#, 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 10000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
n_saidas = 3 #nmero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0
posicao_max = 100 #define variavel para normalizar a posicao

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1.0 #valor de epsilon
epsilon_min = 0.0001 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]
pmax = np.amax( inputs.loc[:, inputs.columns[0]] ) #define valor minimo do preo
pmin = np.amin( inputs.loc[:, inputs.columns[0]] ) #define valor maximo do preo

for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imax = np.amax( inputs.loc[:, inputs.columns[i]] ) #pega valor maximo
    imin = np.amin( inputs.loc[:, inputs.columns[i]] ) #pega valor minimo
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imin ) / ( imax - imin ) #normaliza prs

dt = arquivo['dt'].values #cria coluna apenas dos dias
steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
for i in range( 0, len(dt) ):
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
dias = len(steps)
dias = 50
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K            #importa backend para clear_session()

##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria()
        self.gamma = 0.95    # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 0.0001
        self.model = self.cria_modelo()
        self.model.summary()

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        return model

    def limpa_memoria(self):
        self.state = np.empty((0,))
        self.next_state = np.empty((0,))
        
    def toma_acao(self, valores_ant, teste):
        if not teste and np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora        
        act_values = self.model.predict(estado, batch_size=1) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action

    def treina_modelo(self, acao, reward, valores_ant, valores_dps, batch_size=1):
        prox_estado = np.array([np.append(self.next_state, valores_dps)]) #cria proximo estado
        target = (reward + self.gamma * np.amax(self.model.predict(prox_estado, batch_size=batch_size)[0])) #pega valor que quer chegar
        
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora
        target_f = self.model.predict(estado, batch_size=batch_size) #pega valor que chegou
        target_f[0][acao] = target #define o valor que deseja chegar
        
        self.model.fit(estado, target_f, epochs=1, verbose=0, batch_size=batch_size) #treina modelo
        
    def tira_ultimo_state(self):
        if self.state.shape[0] > self.janela * self.n_variaveis:
            self.state = self.state[self.n_variaveis:] #tira os ultimos preos
        if self.next_state.shape[0] > self.janela * self.n_variaveis:
            self.next_state = self.next_state[self.n_variaveis:] #tira os ultimos preos
        
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
        
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 216)               3024
# _________________________________________________________________
# dense_2 (Dense)              (None, 216)               46872
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 651
# =================================================================
# Total params: 50,547
# Trainable params: 50,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #ao atual, custo, valor da posio
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    
    if valor != 0:
        valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valor posicionado atual

    dp = ( preco * ( pmax - pmin ) + pmin ) - valor_cheio #variao do preo atual e do preo de compra/venda
    posicao = ncont_anterior * dp * 10 - custo * abs(acao) #posicao = lucro - custo (INSTANTNEO)

    #calculos sobre o valor    
    if ( ncont_anterior == 0 and acao != 0 ): #primeiro valor
        valor = preco
    elif ( ncont == 0 ):
        valor = 0
    #caso nao se encaixe nessas condies: valor = valor (nada muda)

    return ncont, valor, posicao, ncont_anterior

def obter_acao(ncont, valores_ant):
    decisao = modelo.toma_acao(valores_ant, False) #calcula a saida da rede neural

    if decisao == 0: #comprar
        if ncont == 0: #s compra se no tem nada ainda
            return 1
    elif decisao == 1: #vender
        if ncont == 1: #s vende se tiver alguma coisa
            return -1
    return 0 #neutro

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = 0 #cria variavel para preo medio
    reward = 0 #cria variavel para recompensa
    posicao = 0 #cria variavel de posio 
    modelo.limpa_memoria() #limpa o vetor de memoria

    dia_para_rodar = dias_para_rodar[dia] #pega um dia random para rodar
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.state = np.append( modelo.state, ultimos_precos ) #adiciona na variavel de estado
        
        modelo.tira_ultimo_state()
        valores_ant = [ncont, valor, posicao / posicao_max] #grava os valores de antes

        if modelo.state.shape[0] == janela * n_variaveis: #se ja tem memoria suficiente
            acao = obter_acao( ncont, valores_ant ) #obtem ao
            ncont, valor, posicao, ncont_anterior = atuacao(precos['preco'][step], ncont, acao, custo, valor)
            if ( ncont_anterior != ncont ): #reward acumulado recebe reward instantaneo somente se houver lucro/prejuizo real   
                reward += posicao #soma reward
            
        prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
        modelo.next_state = np.append(modelo.next_state, prox_precos) #adiciona variavel na variavel de proximo estado
        modelo.tira_ultimo_state()
        valores_dps = [ncont, valor, posicao / posicao_max] #grava os valores de depois
        
        if modelo.state.shape[0] == janela * n_variaveis: #se ja tem memoria suficiente
            modelo.treina_modelo(acao, posicao / posicao_max, valores_ant, valores_dps) #roda o modelo
            
    reward += posicao - custo * abs(ncont) #soma reward - DAY-TRADE (obs: custo nao havia sido considerado no reward pq acao era 0)
    if reward > melhor_reward:
        melhor_reward = reward
    return reward #retorna o valor do reward

def rodar_dias(precos, custo):   
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    #random.shuffle(dias_para_rodar) #randomiza vetor de dias
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        #rewards.append(reward) #guarda o valor do reward
        #print(len(rewards))
        #plotx.append(np.max(plotx) + 1) #guarda o valor do dia
        #print("dia {0} de {1}: R$ {2:0.2f}".format(dia, dias, reward)) #mostra o resultado do dia
    return sum_rewards

# %%
########################### MAIN ###############################################################
if __name__ == "__main__":
    sum_rewards_total = 0
    sr=[]
    modelo.epsilon = 0.05
    try:
        #if carregar_pesos:
         #   modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            #print("epoca {0}\n".format(epoca)) #mostra que epoca vai rodar
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f}".format(epoca, sum_rewards))
            epoca_parou += 1
    finally:
        modelo.salva_pesos('./pesos.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
        print("Somatoria dos rewards: {0:0.2f}".format(sum_rewards_total))
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, epoca+1), sr, range(0, epoca+1), np.zeros(epoca+1)) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0922 11:53:46.216886  9632 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0922 11:53:46.384895  9632 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W0922 11:53:46.407896  9632 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = 213.47
# resultado da epoca 1 = 1055.93
# resultado da epoca 2 = 203.12
# resultado da epoca 3 = 207.89
# resultado da epoca 4 = 998.72
# resultado da epoca 5 = 439.55
# resultado da epoca 6 = 367.89
# resultado da epoca 7 = 184.18
# resultado da epoca 8 = 454.11
# resultado da epoca 9 = 278.65
# resultado da epoca 10 = -321.12
# resultado da epoca 11 = 275.24
# resultado da epoca 12 = -517.87
# resultado da epoca 13 = 1316.76
# resultado da epoca 14 = 0.17
# resultado da epoca 15 = 655.01
# resultado da epoca 16 = 146.97
# resultado da epoca 17 = 576.67
# resultado da epoca 18 = 847.82
# resultado da epoca 19 = 255.68
# resultado da epoca 20 = 628.58
# resultado da epoca 21 = -25.38
# resultado da epoca 22 = 411.60
# resultado da epoca 23 = 187.66
# resultado da epoca 24 = 237.29
# resultado da epoca 25 = 687.43
# resultado da epoca 26 = 517.13
# resultado da epoca 27 = -34.60
# resultado da epoca 28 = -156.81
# resultado da epoca 29 = 237.59
# resultado da epoca 30 = 1336.07
# resultado da epoca 31 = 927.29
# resultado da epoca 32 = -394.23
# resultado da epoca 33 = 473.95
# resultado da epoca 34 = 672.59
# resultado da epoca 35 = 376.83
# resultado da epoca 36 = -402.18
# resultado da epoca 37 = 150.47
# resultado da epoca 38 = 501.53
# resultado da epoca 39 = -626.65
# resultado da epoca 40 = -218.10
# resultado da epoca 41 = -126.51
# resultado da epoca 42 = 731.37
# resultado da epoca 43 = 825.24
# resultado da epoca 44 = 334.48
# resultado da epoca 45 = 327.59
# resultado da epoca 46 = 372.06
# resultado da epoca 47 = 817.29
# resultado da epoca 48 = 607.66
# resultado da epoca 49 = 949.87
# resultado da epoca 50 = 188.72
# resultado da epoca 51 = 370.40
# resultado da epoca 52 = 43.12
# resultado da epoca 53 = 253.35
# resultado da epoca 54 = -328.93
# resultado da epoca 55 = -432.18
# resultado da epoca 56 = 523.19
# resultado da epoca 57 = 495.54
# resultado da epoca 58 = 523.35
# resultado da epoca 59 = 580.01
# resultado da epoca 60 = -489.00
# resultado da epoca 61 = 590.61
# resultado da epoca 62 = 142.59
# resultado da epoca 63 = 745.77
# resultado da epoca 64 = 285.84
# resultado da epoca 65 = 282.82
# resultado da epoca 66 = 458.65
# resultado da epoca 67 = 557.29
# resultado da epoca 68 = 378.42
# resultado da epoca 69 = 461.30
# resultado da epoca 70 = 657.89
# resultado da epoca 71 = 1172.96
# resultado da epoca 72 = 388.12
# resultado da epoca 73 = 444.57
# resultado da epoca 74 = -236.58
# resultado da epoca 75 = 62.89
# resultado da epoca 76 = -102.18
# resultado da epoca 77 = 412.89
# resultado da epoca 78 = 117.89
# resultado da epoca 79 = 526.46
# resultado da epoca 80 = 609.71
# resultado da epoca 81 = 18.72
# resultado da epoca 82 = 1136.00
# resultado da epoca 83 = 472.96
# resultado da epoca 84 = 968.95
# resultado da epoca 85 = 554.48
# resultado da epoca 86 = 116.83
# resultado da epoca 87 = 1271.37
# resultado da epoca 88 = 156.67
# resultado da epoca 89 = -376.28
# resultado da epoca 90 = 836.07
# resultado da epoca 91 = -342.48
# resultado da epoca 92 = 901.67
# resultado da epoca 93 = 782.43
# resultado da epoca 94 = 259.34
# resultado da epoca 95 = 450.54
# resultado da epoca 96 = 90.54
# resultado da epoca 97 = 338.12
# resultado da epoca 98 = 113.42
# resultado da epoca 99 = 804.78
# resultado da epoca 100 = 749.48
# resultado da epoca 101 = 836.37
# resultado da epoca 102 = -531.05
# resultado da epoca 103 = 286.37
# resultado da epoca 104 = 727.36
# resultado da epoca 105 = 1012.29
# resultado da epoca 106 = 116.67
# resultado da epoca 107 = 509.48
# resultado da epoca 108 = 555.77
# resultado da epoca 109 = 56.07
# resultado da epoca 110 = 517.96
# resultado da epoca 111 = 829.48
# resultado da epoca 112 = 818.95
# resultado da epoca 113 = 348.12
# resultado da epoca 114 = 217.13
# resultado da epoca 115 = -152.71
# resultado da epoca 116 = 264.11
# resultado da epoca 117 = 655.91
# resultado da epoca 118 = 235.70
# resultado da epoca 119 = 559.78
# resultado da epoca 120 = 816.23
# resultado da epoca 121 = 62.36
# resultado da epoca 122 = 694.64
# resultado da epoca 123 = 391.23
# resultado da epoca 124 = 345.01
# resultado da epoca 125 = 718.19
# resultado da epoca 126 = 387.96
# resultado da epoca 127 = 72.73
# resultado da epoca 128 = 915.47
# resultado da epoca 129 = -614.99
# resultado da epoca 130 = 294.02
# resultado da epoca 131 = 233.72
# resultado da epoca 132 = 298.58
# resultado da epoca 133 = 1314.25
# resultado da epoca 134 = 496.07
# resultado da epoca 135 = 687.13
# resultado da epoca 136 = 424.48
# resultado da epoca 137 = 565.54
# resultado da epoca 138 = -257.64
# resultado da epoca 139 = -236.05
# resultado da epoca 140 = 514.71
# resultado da epoca 141 = 458.95
# resultado da epoca 142 = -92.11
# resultado da epoca 143 = 882.89
# resultado da epoca 144 = 264.62
# resultado da epoca 145 = -563.70
# resultado da epoca 146 = 433.42
# resultado da epoca 147 = -62.48
# resultado da epoca 148 = -10.52
# resultado da epoca 149 = 425.70
# resultado da epoca 150 = 162.29
# resultado da epoca 151 = -158.10
# resultado da epoca 152 = 232.66
# resultado da epoca 153 = 565.01
# resultado da epoca 154 = 1181.76
# resultado da epoca 155 = 336.07
# resultado da epoca 156 = 471.30
# resultado da epoca 157 = 53.81
# resultado da epoca 158 = 401.14
# resultado da epoca 159 = 121.83
# resultado da epoca 160 = 335.31
# resultado da epoca 161 = 501.44
# resultado da epoca 162 = 406.76
# resultado da epoca 163 = 590.84
# resultado da epoca 164 = 368.58
# resultado da epoca 165 = -112.41
# resultado da epoca 166 = 298.65
# resultado da epoca 167 = 91.67
# resultado da epoca 168 = 375.61
# resultado da epoca 169 = 700.31
# resultado da epoca 170 = 815.31
# resultado da epoca 171 = 17.96
# resultado da epoca 172 = -86.88
# resultado da epoca 173 = 770.54
# resultado da epoca 174 = 942.73
# resultado da epoca 175 = 382.52
# resultado da epoca 176 = 476.60
# resultado da epoca 177 = -219.76
# resultado da epoca 178 = -25.98
# resultado da epoca 179 = 325.24
# resultado da epoca 180 = 717.13
# resultado da epoca 181 = 157.06
# resultado da epoca 182 = -10.59
# resultado da epoca 183 = 814.41
# resultado da epoca 184 = 322.36
# resultado da epoca 185 = 741.90
# resultado da epoca 186 = 1032.29
# resultado da epoca 187 = 636.67
# resultado da epoca 188 = 570.01
# resultado da epoca 189 = 646.07
# resultado da epoca 190 = 1434.71
# resultado da epoca 191 = 168.05
# resultado da epoca 192 = 453.56
# resultado da epoca 193 = -77.71
# resultado da epoca 194 = 172.43
# resultado da epoca 195 = 113.49
# resultado da epoca 196 = -755.29
# resultado da epoca 197 = 287.36
# resultado da epoca 198 = 1267.20
# resultado da epoca 199 = 971.99
# resultado da epoca 200 = 242.66
# resultado da epoca 201 = 631.76
# resultado da epoca 202 = -1040.52
# resultado da epoca 203 = 546.46
# resultado da epoca 204 = 937.06
# resultado da epoca 205 = 789.55
# resultado da epoca 206 = -444.46
# resultado da epoca 207 = 251.37
# resultado da epoca 208 = 404.34
# resultado da epoca 209 = 586.83
# resultado da epoca 210 = -159.16
# resultado da epoca 211 = -8.33
# resultado da epoca 212 = 327.43
# resultado da epoca 213 = -675.29
# resultado da epoca 214 = 1494.25
# resultado da epoca 215 = 387.36
# resultado da epoca 216 = 385.17
# resultado da epoca 217 = -17.41
# resultado da epoca 218 = 1500.91
# resultado da epoca 219 = 467.52
# resultado da epoca 220 = 323.88
# resultado da epoca 221 = 366.60
# resultado da epoca 222 = -95.22
# resultado da epoca 223 = 236.90
# resultado da epoca 224 = 747.73
# resultado da epoca 225 = 524.18
# resultado da epoca 226 = 102.66
# resultado da epoca 227 = 114.78
# resultado da epoca 228 = 262.36
# resultado da epoca 229 = 418.72
# resultado da epoca 230 = -264.76
# resultado da epoca 231 = 147.06
# resultado da epoca 232 = 150.31
# resultado da epoca 233 = -86.05
# resultado da epoca 234 = -211.65
# resultado da epoca 235 = 556.83
# resultado da epoca 236 = 355.54
# resultado da epoca 237 = 19.18
# resultado da epoca 238 = -93.63
# resultado da epoca 239 = 471.53
# resultado da epoca 240 = 162.36
# resultado da epoca 241 = 62.06
# resultado da epoca 242 = 676.67
# resultado da epoca 243 = -48.93
# resultado da epoca 244 = 239.94
# resultado da epoca 245 = 77.06
# resultado da epoca 246 = 439.25
# resultado da epoca 247 = -279.53
# resultado da epoca 248 = -105.29
# resultado da epoca 249 = 364.02
# resultado da epoca 250 = 774.18
# resultado da epoca 251 = 370.24
# resultado da epoca 252 = 156.83
# resultado da epoca 253 = -431.65
# resultado da epoca 254 = 141.00
# resultado da epoca 255 = 262.43
# resultado da epoca 256 = 316.90
# resultado da epoca 257 = -217.41
# resultado da epoca 258 = 7.89
# resultado da epoca 259 = -122.48
# resultado da epoca 260 = -108.17
# resultado da epoca 261 = 660.77
# resultado da epoca 262 = 1.60
# resultado da epoca 263 = -87.50
# resultado da epoca 264 = 646.23
# resultado da epoca 265 = 411.07
# resultado da epoca 266 = 794.11
# resultado da epoca 267 = 659.41
# resultado da epoca 268 = 540.84
# resultado da epoca 269 = 570.84
# resultado da epoca 270 = 528.88
# resultado da epoca 271 = 208.12
# resultado da epoca 272 = -155.29
# resultado da epoca 273 = -359.83
# resultado da epoca 274 = 456.90
# resultado da epoca 275 = 405.17
# resultado da epoca 276 = 564.48
# resultado da epoca 277 = -67.04
# resultado da epoca 278 = 466.07
# resultado da epoca 279 = 97.36
# resultado da epoca 280 = 1355.70
# resultado da epoca 281 = 521.53
# resultado da epoca 282 = 121.00
# resultado da epoca 283 = 13.95
# resultado da epoca 284 = 282.13
# resultado da epoca 285 = 274.64
# resultado da epoca 286 = 805.84
# resultado da epoca 287 = -14.53
# resultado da epoca 288 = 82.52
# resultado da epoca 289 = 110.77
# resultado da epoca 290 = 444.18
# resultado da epoca 291 = 27.59
# resultado da epoca 292 = -143.47
# resultado da epoca 293 = 297.43
# resultado da epoca 294 = 326.60
# resultado da epoca 295 = 523.35
# resultado da epoca 296 = 187.89
# resultado da epoca 297 = 492.82
# resultado da epoca 298 = 49.64
# resultado da epoca 299 = -378.70
# resultado da epoca 300 = -336.51
# resultado da epoca 301 = -154.30
# resultado da epoca 302 = 103.49
# resultado da epoca 303 = 675.08
# resultado da epoca 304 = 710.54
# resultado da epoca 305 = 321.76
# resultado da epoca 306 = 113.65
# resultado da epoca 307 = 518.19
# resultado da epoca 308 = -365.75
# resultado da epoca 309 = 138.58
# resultado da epoca 310 = 168.72
# resultado da epoca 311 = 764.78
# resultado da epoca 312 = 416.44
# resultado da epoca 313 = 113.42
# resultado da epoca 314 = 144.02
# resultado da epoca 315 = 330.24
# resultado da epoca 316 = 612.66
# resultado da epoca 317 = -331.58
# resultado da epoca 318 = 171.14
# resultado da epoca 319 = 586.53
# resultado da epoca 320 = -94.69
# resultado da epoca 321 = 1022.06
# resultado da epoca 322 = 440.01
# resultado da epoca 323 = 172.36
# resultado da epoca 324 = 249.25
# resultado da epoca 325 = 410.77
# resultado da epoca 326 = 249.41
# resultado da epoca 327 = -436.05
# resultado da epoca 328 = 247.29
# resultado da epoca 329 = 451.60
# resultado da epoca 330 = 150.31
# resultado da epoca 331 = 458.19
# resultado da epoca 332 = 163.86
# resultado da epoca 333 = -540.13
# resultado da epoca 334 = 871.90
# resultado da epoca 335 = 25.91
# resultado da epoca 336 = 183.49
# resultado da epoca 337 = 413.65
# resultado da epoca 338 = 45.01
# resultado da epoca 339 = 37.06
# resultado da epoca 340 = 192.13
# resultado da epoca 341 = 491.37
# resultado da epoca 342 = 219.55
# resultado da epoca 343 = 817.82
# resultado da epoca 344 = 817.36
# resultado da epoca 345 = -340.29
# resultado da epoca 346 = 1319.25
# resultado da epoca 347 = 467.73
# resultado da epoca 348 = 290.77
# resultado da epoca 349 = 326.07
# resultado da epoca 350 = 338.12
# resultado da epoca 351 = 485.01
# resultado da epoca 352 = 365.47
# resultado da epoca 353 = -74.99
# resultado da epoca 354 = 512.36
# resultado da epoca 355 = 434.78
# resultado da epoca 356 = 652.59
# resultado da epoca 357 = 376.21
# resultado da epoca 358 = 567.66
# resultado da epoca 359 = -87.41
# resultado da epoca 360 = -158.24
# resultado da epoca 361 = -194.99
# resultado da epoca 362 = -429.69
# resultado da epoca 363 = 678.88
# resultado da epoca 364 = 550.40
# resultado da epoca 365 = -481.12
# resultado da epoca 366 = 1100.61
# resultado da epoca 367 = 42.73
# resultado da epoca 368 = 658.19
# resultado da epoca 369 = 14.18
# resultado da epoca 370 = 1284.71
# resultado da epoca 371 = -254.00
# resultado da epoca 372 = 505.84
# resultado da epoca 373 = 626.21
# resultado da epoca 374 = 357.36
# resultado da epoca 375 = 410.54
# resultado da epoca 376 = 499.48
# resultado da epoca 377 = 195.91
# resultado da epoca 378 = 83.81
# resultado da epoca 379 = 37.52
# resultado da epoca 380 = 308.79
# resultado da epoca 381 = -46.12
# resultado da epoca 382 = -44.69
# resultado da epoca 383 = 374.85
# resultado da epoca 384 = -126.28
# resultado da epoca 385 = 281.90
# resultado da epoca 386 = -105.36
# resultado da epoca 387 = 277.66
# resultado da epoca 388 = 390.54
# resultado da epoca 389 = 306.90
# resultado da epoca 390 = 422.36
# resultado da epoca 391 = 373.26
# resultado da epoca 392 = 310.77
# resultado da epoca 393 = 63.05
# resultado da epoca 394 = -196.65
# resultado da epoca 395 = 712.36
# resultado da epoca 396 = -16.35
# resultado da epoca 397 = 776.90
# resultado da epoca 398 = -169.76
# resultado da epoca 399 = 358.49
# resultado da epoca 400 = 277.66
# resultado da epoca 401 = -85.98
# resultado da epoca 402 = 114.94
# resultado da epoca 403 = 91.00
# resultado da epoca 404 = 197.89
# resultado da epoca 405 = 853.19
# resultado da epoca 406 = 176.00
# resultado da epoca 407 = -555.52
# resultado da epoca 408 = 489.78
# resultado da epoca 409 = 307.89
# resultado da epoca 410 = 264.78
# resultado da epoca 411 = 74.25
# resultado da epoca 412 = -980.59
# resultado da epoca 413 = 126.23
# resultado da epoca 414 = -151.58
# resultado da epoca 415 = 1031.90
# resultado da epoca 416 = 404.25
# resultado da epoca 417 = 206.90
# resultado da epoca 418 = -267.94
# resultado da epoca 419 = 826.00
# resultado da epoca 420 = 436.83
# resultado da epoca 421 = 492.96
# resultado da epoca 422 = 508.79
# resultado da epoca 423 = 160.24
# resultado da epoca 424 = 681.76
# resultado da epoca 425 = 230.70
# resultado da epoca 426 = 335.84
# resultado da epoca 427 = 239.11
# resultado da epoca 428 = 54.85
# resultado da epoca 429 = 486.53
# resultado da epoca 430 = 604.02
# resultado da epoca 431 = 96.76
# resultado da epoca 432 = 621.30
# resultado da epoca 433 = -278.70
# resultado da epoca 434 = -80.29
# resultado da epoca 435 = -534.39
# resultado da epoca 436 = 236.60
# resultado da epoca 437 = 554.55
# resultado da epoca 438 = -251.51
# resultado da epoca 439 = 127.89
# resultado da epoca 440 = -344.83
# resultado da epoca 441 = 254.48
# resultado da epoca 442 = 621.53
# resultado da epoca 443 = 98.12
# resultado da epoca 444 = 493.95
# resultado da epoca 445 = 537.66
# resultado da epoca 446 = 575.61
# resultado da epoca 447 = -594.92
# resultado da epoca 448 = 252.06
# resultado da epoca 449 = 15.93
# resultado da epoca 450 = -404.23
# resultado da epoca 451 = 266.92
# resultado da epoca 452 = 392.36
# resultado da epoca 453 = 193.88
# resultado da epoca 454 = 541.83
# resultado da epoca 455 = 531.21
# resultado da epoca 456 = -400.06
# resultado da epoca 457 = -99.69
# resultado da epoca 458 = 86.07
# resultado da epoca 459 = 1479.18
# resultado da epoca 460 = 556.83
# resultado da epoca 461 = 99.41
# resultado da epoca 462 = 395.54
# resultado da epoca 463 = -145.29
# resultado da epoca 464 = 239.02
# resultado da epoca 465 = 488.88
# resultado da epoca 466 = 300.31
# resultado da epoca 467 = 128.05
# resultado da epoca 468 = 611.60
# resultado da epoca 469 = -219.46
# resultado da epoca 470 = 181.30
# resultado da epoca 471 = 773.95
# resultado da epoca 472 = 51.30
# resultado da epoca 473 = 175.84
# resultado da epoca 474 = -341.65
# resultado da epoca 475 = 1232.06
# resultado da epoca 476 = 288.05
# resultado da epoca 477 = 436.83
# resultado da epoca 478 = 401.30
# resultado da epoca 479 = -229.00
# resultado da epoca 480 = 421.76
# resultado da epoca 481 = 689.18
# resultado da epoca 482 = 598.12
# resultado da epoca 483 = 319.48
# resultado da epoca 484 = 726.60
# resultado da epoca 485 = 665.47
# resultado da epoca 486 = 350.61
# resultado da epoca 487 = 337.75
# resultado da epoca 488 = 197.96
# resultado da epoca 489 = 722.43
# resultado da epoca 490 = -383.10
# resultado da epoca 491 = -278.47
# resultado da epoca 492 = 97.96
# resultado da epoca 493 = 311.07
# resultado da epoca 494 = 389.94
# resultado da epoca 495 = -88.84
# resultado da epoca 496 = 53.95
# resultado da epoca 497 = 268.12
# resultado da epoca 498 = 366.37
# resultado da epoca 499 = 397.20
# resultado da epoca 500 = -170.22
# resultado da epoca 501 = 479.94
# resultado da epoca 502 = 381.90
# resultado da epoca 503 = 344.78
# resultado da epoca 504 = 1598.12
# resultado da epoca 505 = 226.60
# resultado da epoca 506 = 194.41
# resultado da epoca 507 = 57.06
# resultado da epoca 508 = -294.07
# resultado da epoca 509 = 276.30
# resultado da epoca 510 = 545.84
# resultado da epoca 511 = 232.59
# resultado da epoca 512 = -199.53
# resultado da epoca 513 = 368.65
# resultado da epoca 514 = -119.23
# resultado da epoca 515 = 587.06
# resultado da epoca 516 = 668.42
# resultado da epoca 517 = -42.11
# resultado da epoca 518 = 272.96
# resultado da epoca 519 = 1132.13
# resultado da epoca 520 = 778.95
# resultado da epoca 521 = 773.95
# resultado da epoca 522 = 269.78
# resultado da epoca 523 = -539.46
# resultado da epoca 524 = 819.04
# resultado da epoca 525 = -309.69
# resultado da epoca 526 = 481.60
# resultado da epoca 527 = 809.78
# resultado da epoca 528 = 301.60
# resultado da epoca 529 = 287.06
# resultado da epoca 530 = 378.58
# resultado da epoca 531 = 1100.77
# resultado da epoca 532 = 576.76
# resultado da epoca 533 = 935.77
# resultado da epoca 534 = 811.30
# resultado da epoca 535 = 663.19
# resultado da epoca 536 = 716.53
# resultado da epoca 537 = 254.25
# resultado da epoca 538 = 64.55
# resultado da epoca 539 = 44.71
# resultado da epoca 540 = 607.66
# resultado da epoca 541 = -28.54
# resultado da epoca 542 = 763.35
# resultado da epoca 543 = 46.53
# resultado da epoca 544 = -42.04
# resultado da epoca 545 = 52.06
# resultado da epoca 546 = 573.19
# resultado da epoca 547 = 351.46
# resultado da epoca 548 = 74.78
# resultado da epoca 549 = 472.59
# resultado da epoca 550 = 875.91
# resultado da epoca 551 = 907.20
# resultado da epoca 552 = -378.40
# resultado da epoca 553 = 614.41
# resultado da epoca 554 = 440.31
# resultado da epoca 555 = 240.24
# resultado da epoca 556 = 776.60
# resultado da epoca 557 = 481.07
# resultado da epoca 558 = 550.24
# resultado da epoca 559 = 753.72
# resultado da epoca 560 = 525.47
# resultado da epoca 561 = 373.49
# resultado da epoca 562 = -104.16
# resultado da epoca 563 = 229.78
# resultado da epoca 564 = 228.19
# resultado da epoca 565 = 633.42
# resultado da epoca 566 = 42.59
# resultado da epoca 567 = 354.41
# resultado da epoca 568 = 1106.76
# resultado da epoca 569 = 17.59
# resultado da epoca 570 = 502.13
# resultado da epoca 571 = 681.00
# resultado da epoca 572 = -138.24
# resultado da epoca 573 = 256.60
# resultado da epoca 574 = -151.95
# resultado da epoca 575 = 41.60
# resultado da epoca 576 = 109.94
# resultado da epoca 577 = 668.35
# resultado da epoca 578 = 637.59
# resultado da epoca 579 = 447.06
# resultado da epoca 580 = 633.49
# resultado da epoca 581 = -161.65
# resultado da epoca 582 = -509.99
# resultado da epoca 583 = 579.78
# resultado da epoca 584 = 785.54
# resultado da epoca 585 = 406.00
# resultado da epoca 586 = 16.23
# resultado da epoca 587 = 498.72
# resultado da epoca 588 = 479.18
# resultado da epoca 589 = 564.11
# resultado da epoca 590 = 145.91
# resultado da epoca 591 = -63.47
# resultado da epoca 592 = 711.30
# resultado da epoca 593 = 867.06
# resultado da epoca 594 = -171.65
# resultado da epoca 595 = 622.89
# resultado da epoca 596 = 362.59
# resultado da epoca 597 = 290.77
# resultado da epoca 598 = 589.48
# resultado da epoca 599 = 61.07
# resultado da epoca 600 = 745.77
# resultado da epoca 601 = 115.47
# resultado da epoca 602 = 391.37
# resultado da epoca 603 = 570.54
# resultado da epoca 604 = 387.06
# resultado da epoca 605 = 41.60
# resultado da epoca 606 = 763.58
# resultado da epoca 607 = 319.25
# resultado da epoca 608 = 792.36
# resultado da epoca 609 = -35.06
# resultado da epoca 610 = 254.71
# resultado da epoca 611 = 690.54
# resultado da epoca 612 = 841.90
# resultado da epoca 613 = 675.31
# resultado da epoca 614 = -7.04
# resultado da epoca 615 = 621.60
# resultado da epoca 616 = 567.52
# resultado da epoca 617 = 615.24
# resultado da epoca 618 = 1098.26
# resultado da epoca 619 = 315.47
# resultado da epoca 620 = -146.12
# resultado da epoca 621 = 239.25
# resultado da epoca 622 = 92.75
# resultado da epoca 623 = 384.34
# resultado da epoca 624 = 357.82
# resultado da epoca 625 = 1140.01
# resultado da epoca 626 = 803.65
# resultado da epoca 627 = -43.70
# resultado da epoca 628 = 471.07
# resultado da epoca 629 = -293.47
# resultado da epoca 630 = 82.50
# resultado da epoca 631 = 179.94
# resultado da epoca 632 = 448.65
# resultado da epoca 633 = 172.82
# resultado da epoca 634 = 538.58
# resultado da epoca 635 = -95.22
# resultado da epoca 636 = 626.37
# resultado da epoca 637 = 416.53
# resultado da epoca 638 = 45.47
# resultado da epoca 639 = 643.58
# resultado da epoca 640 = 218.19
# resultado da epoca 641 = 15.17
# resultado da epoca 642 = 266.00
# resultado da epoca 643 = 473.95
# resultado da epoca 644 = 891.60
# resultado da epoca 645 = 785.40
# resultado da epoca 646 = 356.37
# resultado da epoca 647 = 228.72
# resultado da epoca 648 = -32.04
# resultado da epoca 649 = 26.00
# resultado da epoca 650 = -292.57
# resultado da epoca 651 = 522.59
# resultado da epoca 652 = 709.11
# resultado da epoca 653 = -69.53
# resultado da epoca 654 = 381.53
# resultado da epoca 655 = -185.29
# resultado da epoca 656 = 600.54
# resultado da epoca 657 = 1171.23
# resultado da epoca 658 = 803.12
# resultado da epoca 659 = -27.94
# resultado da epoca 660 = 546.37
# resultado da epoca 661 = 340.84
# resultado da epoca 662 = -121.28
# resultado da epoca 663 = 811.60
# resultado da epoca 664 = 612.13
# resultado da epoca 665 = 362.66
# resultado da epoca 666 = -242.94
# resultado da epoca 667 = 274.78
# resultado da epoca 668 = 600.08
# resultado da epoca 669 = 105.31
# resultado da epoca 670 = 465.24
# resultado da epoca 671 = 946.97
# resultado da epoca 672 = 187.29
# resultado da epoca 673 = 590.54
# resultado da epoca 674 = 271.14
# resultado da epoca 675 = 779.78
# resultado da epoca 676 = 329.18
# resultado da epoca 677 = 215.31
# resultado da epoca 678 = 461.30
# resultado da epoca 679 = 177.06
# resultado da epoca 680 = 826.23
# resultado da epoca 681 = 286.53
# resultado da epoca 682 = 549.41
# resultado da epoca 683 = 943.65
# resultado da epoca 684 = 809.48
# resultado da epoca 685 = 372.59
# resultado da epoca 686 = 485.38
# resultado da epoca 687 = 774.41
# resultado da epoca 688 = 888.12
# resultado da epoca 689 = 598.49
# resultado da epoca 690 = 1121.14
# resultado da epoca 691 = -176.58
# resultado da epoca 692 = 928.12
# resultado da epoca 693 = 114.48
# resultado da epoca 694 = 1034.48
# resultado da epoca 695 = -49.46
# resultado da epoca 696 = 360.24
# resultado da epoca 697 = 638.49
# resultado da epoca 698 = 565.38
# resultado da epoca 699 = 184.94
# resultado da epoca 700 = 1526.37
# resultado da epoca 701 = 164.78
# resultado da epoca 702 = 43.95
# resultado da epoca 703 = 341.23
# resultado da epoca 704 = 6.16
# resultado da epoca 705 = 401.76
# resultado da epoca 706 = -373.77
# resultado da epoca 707 = 329.02
# resultado da epoca 708 = 139.25
# resultado da epoca 709 = 738.79
# resultado da epoca 710 = 607.06
# resultado da epoca 711 = 700.01
# resultado da epoca 712 = 444.02
# resultado da epoca 713 = 310.31
# resultado da epoca 714 = -342.48
# resultado da epoca 715 = -252.87
# resultado da epoca 716 = 691.37
# resultado da epoca 717 = 182.52
# resultado da epoca 718 = 272.59
# resultado da epoca 719 = 175.77
# resultado da epoca 720 = 179.71
# resultado da epoca 721 = 302.36
# resultado da epoca 722 = 38.26
# resultado da epoca 723 = 692.06
# resultado da epoca 724 = 572.06
# resultado da epoca 725 = -13.10
# resultado da epoca 726 = 278.26
# resultado da epoca 727 = 297.06
# resultado da epoca 728 = 458.95
# resultado da epoca 729 = -206.58
# resultado da epoca 730 = -47.94
# resultado da epoca 731 = -478.77
# resultado da epoca 732 = 123.65
# resultado da epoca 733 = 756.07
# resultado da epoca 734 = 312.89
# resultado da epoca 735 = 636.00
# resultado da epoca 736 = 577.89
# resultado da epoca 737 = 1034.48
# resultado da epoca 738 = 306.14
# resultado da epoca 739 = 383.19
# resultado da epoca 740 = 150.40
# resultado da epoca 741 = 68.42
# resultado da epoca 742 = -81.65
# resultado da epoca 743 = -329.60
# resultado da epoca 744 = 511.67
# resultado da epoca 745 = -193.17
# resultado da epoca 746 = 408.72
# resultado da epoca 747 = 981.74
# resultado da epoca 748 = 24.18
# resultado da epoca 749 = 530.47
# resultado da epoca 750 = 250.31
# resultado da epoca 751 = 156.60
# resultado da epoca 752 = 839.71
# resultado da epoca 753 = 196.60
# resultado da epoca 754 = 409.11
# resultado da epoca 755 = 978.95
# resultado da epoca 756 = 873.19
# resultado da epoca 757 = -434.39
# resultado da epoca 758 = -162.18
# resultado da epoca 759 = 1140.54
# resultado da epoca 760 = 349.71
# resultado da epoca 761 = 431.60
# resultado da epoca 762 = 442.82
# resultado da epoca 763 = 392.06
# resultado da epoca 764 = 518.49
# resultado da epoca 765 = 315.08
# resultado da epoca 766 = 418.72
# resultado da epoca 767 = 531.07
# resultado da epoca 768 = -254.76
# resultado da epoca 769 = 167.66
# resultado da epoca 770 = -342.94
# resultado da epoca 771 = 235.77
# resultado da epoca 772 = 613.19
# resultado da epoca 773 = 289.94
# resultado da epoca 774 = 582.82
# resultado da epoca 775 = -200.22
# resultado da epoca 776 = 481.00
# resultado da epoca 777 = 679.41
# resultado da epoca 778 = 104.48
# resultado da epoca 779 = -312.64
# resultado da epoca 780 = 912.29
# resultado da epoca 781 = 274.02
# resultado da epoca 782 = -340.45
# resultado da epoca 783 = 695.31
# resultado da epoca 784 = -468.24
# resultado da epoca 785 = 649.41
# resultado da epoca 786 = 1038.65
# resultado da epoca 787 = 225.08
# resultado da epoca 788 = -135.52
# resultado da epoca 789 = -48.40
# resultado da epoca 790 = 131.53
# resultado da epoca 791 = -656.88
# resultado da epoca 792 = -311.65
# resultado da epoca 793 = 487.66
# resultado da epoca 794 = 104.25
# resultado da epoca 795 = 619.71
# resultado da epoca 796 = 54.18
# resultado da epoca 797 = 539.41
# resultado da epoca 798 = 209.02
# resultado da epoca 799 = 730.01
# resultado da epoca 800 = 238.19
# resultado da epoca 801 = 704.71
# resultado da epoca 802 = 240.77
# resultado da epoca 803 = -531.81
# resultado da epoca 804 = 250.54
# resultado da epoca 805 = -110.89
# resultado da epoca 806 = -86.35
# resultado da epoca 807 = 511.60
# resultado da epoca 808 = 256.90
# resultado da epoca 809 = 249.55
# resultado da epoca 810 = -55.75
# resultado da epoca 811 = 391.07
# resultado da epoca 812 = 189.48
# resultado da epoca 813 = -24.00
# resultado da epoca 814 = 644.94
# resultado da epoca 815 = -417.87
# resultado da epoca 816 = 665.77
# resultado da epoca 817 = -405.06
# resultado da epoca 818 = 118.72
# resultado da epoca 819 = 525.77
# resultado da epoca 820 = 882.96
# resultado da epoca 821 = 358.42
# resultado da epoca 822 = 362.29
# resultado da epoca 823 = 531.83
# resultado da epoca 824 = 381.37
# resultado da epoca 825 = 995.24
# resultado da epoca 826 = 92.36
# resultado da epoca 827 = 966.60
# resultado da epoca 828 = 585.77
# resultado da epoca 829 = 23.95
# resultado da epoca 830 = 1600.01
# resultado da epoca 831 = 566.76
# resultado da epoca 832 = -16.35
# resultado da epoca 833 = 142.89
# resultado da epoca 834 = 928.42
# resultado da epoca 835 = 295.31
# resultado da epoca 836 = 400.31
# resultado da epoca 837 = 241.53
# resultado da epoca 838 = 70.93
# resultado da epoca 839 = 1061.30
# resultado da epoca 840 = 322.20
# resultado da epoca 841 = 312.66
# resultado da epoca 842 = 790.31
# resultado da epoca 843 = -181.88
# resultado da epoca 844 = 493.12
# resultado da epoca 845 = -170.59
# resultado da epoca 846 = 735.47
# resultado da epoca 847 = 580.84
# resultado da epoca 848 = 102.89
# resultado da epoca 849 = -421.05
# resultado da epoca 850 = 260.01
# resultado da epoca 851 = 464.78
# resultado da epoca 852 = 1038.12
# resultado da epoca 853 = 716.37
# resultado da epoca 854 = 258.72
# resultado da epoca 855 = 241.76
# resultado da epoca 856 = -555.06
# resultado da epoca 857 = 288.95
# resultado da epoca 858 = 962.59
# resultado da epoca 859 = -373.70
# resultado da epoca 860 = 540.01
# resultado da epoca 861 = 331.90
# resultado da epoca 862 = 913.42
# resultado da epoca 863 = 578.03
# resultado da epoca 864 = 703.95
# resultado da epoca 865 = 65.01
# resultado da epoca 866 = 399.25
# resultado da epoca 867 = -404.62
# resultado da epoca 868 = -81.05
# resultado da epoca 869 = 244.18
# resultado da epoca 870 = 418.19
# resultado da epoca 871 = 841.60
# resultado da epoca 872 = 662.59
# resultado da epoca 873 = 508.12
# resultado da epoca 874 = 253.65
# resultado da epoca 875 = 578.19
# resultado da epoca 876 = 411.00
# resultado da epoca 877 = 370.01
# resultado da epoca 878 = 80.01
# resultado da epoca 879 = 755.38
# resultado da epoca 880 = 816.07
# resultado da epoca 881 = -6.35
# resultado da epoca 882 = -389.16
# resultado da epoca 883 = 671.37
# resultado da epoca 884 = 697.06
# resultado da epoca 885 = -133.47
# resultado da epoca 886 = 544.18
# resultado da epoca 887 = 245.54
# resultado da epoca 888 = 444.11
# resultado da epoca 889 = -91.05
# resultado da epoca 890 = 250.93
# resultado da epoca 891 = -32.94
# resultado da epoca 892 = 281.67
# resultado da epoca 893 = 491.99
# resultado da epoca 894 = 661.07
# resultado da epoca 895 = 472.36
# resultado da epoca 896 = 646.30
# resultado da epoca 897 = 611.14
# resultado da epoca 898 = 306.39
# resultado da epoca 899 = 500.31
# resultado da epoca 900 = -127.64
# resultado da epoca 901 = -351.72
# resultado da epoca 902 = 996.00
# resultado da epoca 903 = 733.72
# resultado da epoca 904 = -438.70
# resultado da epoca 905 = -542.32
# resultado da epoca 906 = -70.59
# resultado da epoca 907 = 352.13
# resultado da epoca 908 = 733.28
# resultado da epoca 909 = 34.78
# resultado da epoca 910 = 483.72
# resultado da epoca 911 = 322.82
# resultado da epoca 912 = 26.14
# resultado da epoca 913 = 358.65
# resultado da epoca 914 = 285.01
# resultado da epoca 915 = 422.66
# resultado da epoca 916 = 515.31
# resultado da epoca 917 = 516.30
# resultado da epoca 918 = -208.84
# resultado da epoca 919 = 539.85
# resultado da epoca 920 = 181.53
# resultado da epoca 921 = 277.13
# resultado da epoca 922 = 232.66
# resultado da epoca 923 = 1101.60
# resultado da epoca 924 = 949.71
# resultado da epoca 925 = -431.95
# resultado da epoca 926 = 42.96
# resultado da epoca 927 = 362.13
# resultado da epoca 928 = 115.17
# resultado da epoca 929 = 561.37
# resultado da epoca 930 = 161.53
# resultado da epoca 931 = -556.28
# resultado da epoca 932 = -145.45
# resultado da epoca 933 = 597.36
# resultado da epoca 934 = -350.13
# resultado da epoca 935 = 888.12
# resultado da epoca 936 = -155.82
# resultado da epoca 937 = 252.66
# resultado da epoca 938 = 598.35
# resultado da epoca 939 = 278.72
# resultado da epoca 940 = 168.72
# resultado da epoca 941 = -223.70
# resultado da epoca 942 = -87.34
# resultado da epoca 943 = 645.84
# resultado da epoca 944 = 1087.06
# resultado da epoca 945 = -151.65
# resultado da epoca 946 = 365.24
# resultado da epoca 947 = 574.94
# resultado da epoca 948 = 535.61
# resultado da epoca 949 = -438.17
# resultado da epoca 950 = -174.16
# resultado da epoca 951 = 943.95
# resultado da epoca 952 = -13.40
# resultado da epoca 953 = -174.46
# resultado da epoca 954 = 118.95
# resultado da epoca 955 = 634.25
# resultado da epoca 956 = 528.95
# resultado da epoca 957 = 171.60
# resultado da epoca 958 = 284.25
# resultado da epoca 959 = 899.34
# resultado da epoca 960 = 262.36
# resultado da epoca 961 = 274.64
# resultado da epoca 962 = 569.41
# resultado da epoca 963 = 492.43
# resultado da epoca 964 = 938.03
# resultado da epoca 965 = 144.25
# resultado da epoca 966 = 297.13
# resultado da epoca 967 = -61.42
# resultado da epoca 968 = 1079.25
# resultado da epoca 969 = 1082.75
# resultado da epoca 970 = 628.95
# resultado da epoca 971 = 360.38
# resultado da epoca 972 = 518.72
# resultado da epoca 973 = 227.66
# resultado da epoca 974 = 416.00
# resultado da epoca 975 = 440.54
# resultado da epoca 976 = 51.76
# resultado da epoca 977 = -233.93
# resultado da epoca 978 = -112.87
# resultado da epoca 979 = 683.42
# resultado da epoca 980 = -33.17
# resultado da epoca 981 = 200.24
# resultado da epoca 982 = 304.48
# resultado da epoca 983 = -421.81
# resultado da epoca 984 = 307.06
# resultado da epoca 985 = 381.46
# resultado da epoca 986 = 814.18
# resultado da epoca 987 = -266.21
# resultado da epoca 988 = -75.06
# resultado da epoca 989 = 293.42
# resultado da epoca 990 = 329.18
# resultado da epoca 991 = 627.89
# resultado da epoca 992 = -136.05
# resultado da epoca 993 = 516.14
# resultado da epoca 994 = 428.19
# resultado da epoca 995 = -221.35
# resultado da epoca 996 = 614.18
# resultado da epoca 997 = 239.85
# resultado da epoca 998 = 240.54
# resultado da epoca 999 = -69.00
# resultado da epoca 1000 = 714.32
# resultado da epoca 1001 = 730.77
# resultado da epoca 1002 = 72.52
# resultado da epoca 1003 = -71.58
# resultado da epoca 1004 = 184.48
# resultado da epoca 1005 = -193.24
# resultado da epoca 1006 = 143.95
# resultado da epoca 1007 = 764.94
# resultado da epoca 1008 = 803.42
# resultado da epoca 1009 = 114.25
# resultado da epoca 1010 = 1119.78
# resultado da epoca 1011 = 1145.01
# resultado da epoca 1012 = -407.48
# resultado da epoca 1013 = -59.39
# resultado da epoca 1014 = 464.11
# resultado da epoca 1015 = -203.40
# resultado da epoca 1016 = 350.47
# resultado da epoca 1017 = -350.52
# resultado da epoca 1018 = -369.23
# resultado da epoca 1019 = 398.26
# resultado da epoca 1020 = 734.09
# resultado da epoca 1021 = 853.12
# resultado da epoca 1022 = 72.36
# resultado da epoca 1023 = 704.18
# resultado da epoca 1024 = 494.02
# resultado da epoca 1025 = 435.54
# resultado da epoca 1026 = 520.31
# resultado da epoca 1027 = 138.72
# resultado da epoca 1028 = -151.79
# resultado da epoca 1029 = 1124.48
# resultado da epoca 1030 = 170.54
# resultado da epoca 1031 = 118.72
# resultado da epoca 1032 = -142.87
# resultado da epoca 1033 = 926.00
# resultado da epoca 1034 = 285.77
# resultado da epoca 1035 = 112.96
# resultado da epoca 1036 = 541.60
# resultado da epoca 1037 = -237.04
# resultado da epoca 1038 = -88.93
# resultado da epoca 1039 = 436.90
# resultado da epoca 1040 = 311.99
# resultado da epoca 1041 = 846.30
# resultado da epoca 1042 = 675.01
# resultado da epoca 1043 = 244.41
# resultado da epoca 1044 = 680.01
# resultado da epoca 1045 = 212.89
# resultado da epoca 1046 = -24.46
# resultado da epoca 1047 = 338.19
# resultado da epoca 1048 = -64.69
# resultado da epoca 1049 = 113.49
# resultado da epoca 1050 = 417.06
# resultado da epoca 1051 = -330.59
# resultado da epoca 1052 = -87.94
# resultado da epoca 1053 = 234.94
# resultado da epoca 1054 = 569.87
# resultado da epoca 1055 = 636.90
# resultado da epoca 1056 = 403.95
# resultado da epoca 1057 = 613.86
# resultado da epoca 1058 = 525.01
# resultado da epoca 1059 = 80.31
# resultado da epoca 1060 = 6.07
# resultado da epoca 1061 = 277.59
# resultado da epoca 1062 = -44.76
# resultado da epoca 1063 = 21.23
# resultado da epoca 1064 = -186.35
# resultado da epoca 1065 = 282.59
# resultado da epoca 1066 = 362.29
# resultado da epoca 1067 = 93.72
# resultado da epoca 1068 = 526.90
# resultado da epoca 1069 = 278.12
# resultado da epoca 1070 = 612.73
# resultado da epoca 1071 = 768.19
# resultado da epoca 1072 = 808.58
# resultado da epoca 1073 = -647.41
# resultado da epoca 1074 = 261.07
# resultado da epoca 1075 = 457.29
# resultado da epoca 1076 = -163.77
# resultado da epoca 1077 = 680.24
# resultado da epoca 1078 = 561.23
# resultado da epoca 1079 = -23.17
# resultado da epoca 1080 = 496.37
# resultado da epoca 1081 = 412.06
# resultado da epoca 1082 = 455.61
# resultado da epoca 1083 = 74.25
# resultado da epoca 1084 = -401.12
# resultado da epoca 1085 = 590.54
# resultado da epoca 1086 = -1.12
# resultado da epoca 1087 = 488.35
# resultado da epoca 1088 = -138.86
# resultado da epoca 1089 = 384.78
# resultado da epoca 1090 = 190.38
# resultado da epoca 1091 = -545.29
# resultado da epoca 1092 = -81.51
# resultado da epoca 1093 = 242.89
# resultado da epoca 1094 = 4.41
# resultado da epoca 1095 = 898.95
# resultado da epoca 1096 = 207.06
# resultado da epoca 1097 = 50.01
# resultado da epoca 1098 = 553.65
# resultado da epoca 1099 = -246.88
# resultado da epoca 1100 = 408.88
# resultado da epoca 1101 = 531.30
# resultado da epoca 1102 = -295.59
# resultado da epoca 1103 = 1364.57
# resultado da epoca 1104 = 150.47
# resultado da epoca 1105 = 122.22
# resultado da epoca 1106 = -33.17
# resultado da epoca 1107 = 788.95
# resultado da epoca 1108 = 172.43
# resultado da epoca 1109 = 286.23
# resultado da epoca 1110 = 154.94
# resultado da epoca 1111 = 742.52
# resultado da epoca 1112 = 1294.55
# resultado da epoca 1113 = 44.78
# resultado da epoca 1114 = 590.77
# resultado da epoca 1115 = 917.13
# resultado da epoca 1116 = -441.51
# resultado da epoca 1117 = -47.80
# resultado da epoca 1118 = -13.86
# resultado da epoca 1119 = 435.31
# resultado da epoca 1120 = 167.59
# resultado da epoca 1121 = 385.47
# resultado da epoca 1122 = 310.61
# resultado da epoca 1123 = -55.29
# resultado da epoca 1124 = -280.06
# resultado da epoca 1125 = 252.59
# resultado da epoca 1126 = -82.64
# resultado da epoca 1127 = 837.66
# resultado da epoca 1128 = 724.18
# resultado da epoca 1129 = 174.25
# resultado da epoca 1130 = 1061.60
# resultado da epoca 1131 = 641.30
# resultado da epoca 1132 = 216.76
# resultado da epoca 1133 = 1378.95
# resultado da epoca 1134 = 508.42
# resultado da epoca 1135 = 216.07
# resultado da epoca 1136 = 73.19
# resultado da epoca 1137 = 170.01
# resultado da epoca 1138 = -306.05
# resultado da epoca 1139 = 641.53
# resultado da epoca 1140 = 266.83
# resultado da epoca 1141 = 513.95
# resultado da epoca 1142 = -130.59
# resultado da epoca 1143 = 617.82
# resultado da epoca 1144 = 613.58
# resultado da epoca 1145 = 65.40
# resultado da epoca 1146 = 63.72
# resultado da epoca 1147 = 4.32
# resultado da epoca 1148 = 936.30
# resultado da epoca 1149 = 280.54
# resultado da epoca 1150 = 462.43
# resultado da epoca 1151 = 82.43
# resultado da epoca 1152 = 197.43
# resultado da epoca 1153 = 915.24
# resultado da epoca 1154 = 735.93
# resultado da epoca 1155 = 504.94
# resultado da epoca 1156 = 562.06
# resultado da epoca 1157 = 215.54
# resultado da epoca 1158 = 1516.83
# resultado da epoca 1159 = 212.06
# resultado da epoca 1160 = 749.78
# resultado da epoca 1161 = 287.06
# resultado da epoca 1162 = 495.54
# resultado da epoca 1163 = 179.48
# resultado da epoca 1164 = 417.43
# resultado da epoca 1165 = 447.06
# resultado da epoca 1166 = 380.70
# resultado da epoca 1167 = 439.87
# resultado da epoca 1168 = 918.72
# resultado da epoca 1169 = -93.40
# resultado da epoca 1170 = 127.06
# resultado da epoca 1171 = 378.95
# resultado da epoca 1172 = 604.25
# resultado da epoca 1173 = 1352.82
# resultado da epoca 1174 = 242.13
# resultado da epoca 1175 = 914.78
# resultado da epoca 1176 = -23.47
# resultado da epoca 1177 = -754.53
# resultado da epoca 1178 = 199.18
# resultado da epoca 1179 = 438.88
# resultado da epoca 1180 = 15.70
# resultado da epoca 1181 = 316.37
# resultado da epoca 1182 = -215.82
# resultado da epoca 1183 = -122.34
# resultado da epoca 1184 = -240.82
# resultado da epoca 1185 = 955.54
# resultado da epoca 1186 = -675.52
# resultado da epoca 1187 = 416.14
# resultado da epoca 1188 = 296.30
# resultado da epoca 1189 = -113.47
# resultado da epoca 1190 = 549.32
# resultado da epoca 1191 = 341.76
# resultado da epoca 1192 = 124.25
# resultado da epoca 1193 = 658.72
# resultado da epoca 1194 = -308.17
# resultado da epoca 1195 = 1052.82
# resultado da epoca 1196 = -429.92
# resultado da epoca 1197 = 922.06
# resultado da epoca 1198 = 314.02
# resultado da epoca 1199 = 703.42
# resultado da epoca 1200 = 1032.36
# resultado da epoca 1201 = 57.36
# resultado da epoca 1202 = 694.11
# resultado da epoca 1203 = -667.18
# resultado da epoca 1204 = 653.12
# resultado da epoca 1205 = 789.78
# resultado da epoca 1206 = 265.24
# resultado da epoca 1207 = 131.76
# resultado da epoca 1208 = 37.66
# resultado da epoca 1209 = 353.65
# resultado da epoca 1210 = 215.47
# resultado da epoca 1211 = -99.83
# resultado da epoca 1212 = 538.65
# resultado da epoca 1213 = 277.20
# resultado da epoca 1214 = 569.18
# resultado da epoca 1215 = -39.14
# resultado da epoca 1216 = -23.77
# resultado da epoca 1217 = 871.60
# resultado da epoca 1218 = -434.07
# resultado da epoca 1219 = 362.89
# resultado da epoca 1220 = -345.13
# resultado da epoca 1221 = 89.25
# resultado da epoca 1222 = 247.13
# resultado da epoca 1223 = 301.07
# resultado da epoca 1224 = -334.00
# resultado da epoca 1225 = -431.12
# resultado da epoca 1226 = 114.94
# resultado da epoca 1227 = 293.12
# resultado da epoca 1228 = 197.82
# resultado da epoca 1229 = 143.26
# resultado da epoca 1230 = 300.08
# resultado da epoca 1231 = 2.06
# resultado da epoca 1232 = 626.53
# resultado da epoca 1233 = -146.81
# resultado da epoca 1234 = 569.64
# resultado da epoca 1235 = 134.25
# resultado da epoca 1236 = 117.20
# resultado da epoca 1237 = 493.88
# resultado da epoca 1238 = -257.34
# resultado da epoca 1239 = 168.88
# resultado da epoca 1240 = 323.95
# resultado da epoca 1241 = 129.25
# resultado da epoca 1242 = 749.85
# resultado da epoca 1243 = 763.72
# resultado da epoca 1244 = 165.77
# resultado da epoca 1245 = 123.72
# resultado da epoca 1246 = 140.17
# resultado da epoca 1247 = 911.07
# resultado da epoca 1248 = 582.66
# resultado da epoca 1249 = 807.52
# resultado da epoca 1250 = 415.24
# resultado da epoca 1251 = -112.18
# resultado da epoca 1252 = 1043.42
# resultado da epoca 1253 = 527.36
# resultado da epoca 1254 = -63.47
# resultado da epoca 1255 = -232.94
# resultado da epoca 1256 = 252.82
# resultado da epoca 1257 = 72.59
# resultado da epoca 1258 = 369.18
# resultado da epoca 1259 = 366.46
# resultado da epoca 1260 = 329.78
# resultado da epoca 1261 = 330.01
# resultado da epoca 1262 = 556.14
# resultado da epoca 1263 = -297.41
# resultado da epoca 1264 = 432.13
# resultado da epoca 1265 = 723.65
# resultado da epoca 1266 = 518.72
# resultado da epoca 1267 = -181.58
# resultado da epoca 1268 = -181.97
# resultado da epoca 1269 = 83.42
# resultado da epoca 1270 = 600.08
# resultado da epoca 1271 = -39.83
# resultado da epoca 1272 = 149.41
# resultado da epoca 1273 = 155.47
# resultado da epoca 1274 = -79.69
# resultado da epoca 1275 = 1024.02
# resultado da epoca 1276 = 997.66
# resultado da epoca 1277 = 166.00
# resultado da epoca 1278 = -229.69
# resultado da epoca 1279 = 91.07
# resultado da epoca 1280 = 210.24
# resultado da epoca 1281 = 724.02
# resultado da epoca 1282 = 374.94
# resultado da epoca 1283 = 426.97
# resultado da epoca 1284 = 264.71
# resultado da epoca 1285 = 858.88
# resultado da epoca 1286 = 676.76
# resultado da epoca 1287 = 574.41
# resultado da epoca 1288 = -72.80
# resultado da epoca 1289 = 567.36
# resultado da epoca 1290 = 589.41
# resultado da epoca 1291 = 663.65
# resultado da epoca 1292 = 775.24
# resultado da epoca 1293 = 719.71
# resultado da epoca 1294 = 643.65
# resultado da epoca 1295 = 386.83
# resultado da epoca 1296 = 38.58
# resultado da epoca 1297 = 923.58
# resultado da epoca 1298 = -184.00
# resultado da epoca 1299 = 55.47
# resultado da epoca 1300 = 578.12
# resultado da epoca 1301 = 459.48
# resultado da epoca 1302 = -482.78
# resultado da epoca 1303 = 115.61
# resultado da epoca 1304 = 9.64
# resultado da epoca 1305 = 172.06
# resultado da epoca 1306 = 254.41
# resultado da epoca 1307 = 559.78
# resultado da epoca 1308 = 308.35
# resultado da epoca 1309 = 385.91
# resultado da epoca 1310 = -320.59
# resultado da epoca 1311 = 302.13
# resultado da epoca 1312 = 1207.43
# resultado da epoca 1313 = 782.22
# resultado da epoca 1314 = 1092.73
# resultado da epoca 1315 = 803.72
# resultado da epoca 1316 = 286.67
# resultado da epoca 1317 = 479.78
# resultado da epoca 1318 = 260.84
# resultado da epoca 1319 = 884.25
# resultado da epoca 1320 = 591.76
# resultado da epoca 1321 = 73.88
# resultado da epoca 1322 = 578.72
# resultado da epoca 1323 = -289.16
# resultado da epoca 1324 = -51.65
# resultado da epoca 1325 = 914.55
# resultado da epoca 1326 = -218.70
# resultado da epoca 1327 = 242.68
# resultado da epoca 1328 = 81.60
# resultado da epoca 1329 = -89.46
# resultado da epoca 1330 = 281.00
# resultado da epoca 1331 = 657.36
# resultado da epoca 1332 = 606.07
# resultado da epoca 1333 = -194.69
# resultado da epoca 1334 = 453.19
# resultado da epoca 1335 = 635.84
# resultado da epoca 1336 = 694.62
# resultado da epoca 1337 = 275.17
# resultado da epoca 1338 = 438.88
# resultado da epoca 1339 = 1021.60
# resultado da epoca 1340 = 347.06
# resultado da epoca 1341 = 897.13
# resultado da epoca 1342 = -387.94
# resultado da epoca 1343 = 586.07
# resultado da epoca 1344 = 576.83
# resultado da epoca 1345 = 442.20
# resultado da epoca 1346 = 251.37
# resultado da epoca 1347 = 350.24
# resultado da epoca 1348 = 679.55
# resultado da epoca 1349 = 145.70
# resultado da epoca 1350 = -402.87
# resultado da epoca 1351 = 505.47
# resultado da epoca 1352 = 166.76
# resultado da epoca 1353 = -99.30
# resultado da epoca 1354 = 224.73
# resultado da epoca 1355 = 439.71
# resultado da epoca 1356 = -251.88
# resultado da epoca 1357 = 196.90
# resultado da epoca 1358 = 881.37
# resultado da epoca 1359 = 1115.31
# resultado da epoca 1360 = 360.61
# resultado da epoca 1361 = 369.41
# resultado da epoca 1362 = 568.88
# resultado da epoca 1363 = -38.47
# resultado da epoca 1364 = 718.72
# resultado da epoca 1365 = 9.25
# resultado da epoca 1366 = 95.31
# resultado da epoca 1367 = -144.99
# resultado da epoca 1368 = 180.01
# resultado da epoca 1369 = 996.46
# resultado da epoca 1370 = 474.11
# resultado da epoca 1371 = 1449.25
# resultado da epoca 1372 = -234.23
# resultado da epoca 1373 = 472.36
# resultado da epoca 1374 = -4.62
# resultado da epoca 1375 = 83.95
# resultado da epoca 1376 = 151.07
# resultado da epoca 1377 = 332.06
# resultado da epoca 1378 = 121.60
# resultado da epoca 1379 = 791.76
# resultado da epoca 1380 = 82.73
# resultado da epoca 1381 = 317.36
# resultado da epoca 1382 = 1003.42
# resultado da epoca 1383 = 137.52
# resultado da epoca 1384 = 1280.47
# resultado da epoca 1385 = 406.90
# resultado da epoca 1386 = 211.00
# resultado da epoca 1387 = 451.23
# resultado da epoca 1388 = 440.70
# resultado da epoca 1389 = 291.07
# resultado da epoca 1390 = -144.30
# resultado da epoca 1391 = 690.10
# resultado da epoca 1392 = 94.34
# resultado da epoca 1393 = 129.55
# resultado da epoca 1394 = 536.30
# resultado da epoca 1395 = 10.84
# resultado da epoca 1396 = -189.99
# resultado da epoca 1397 = -77.87
# resultado da epoca 1398 = 711.07
# resultado da epoca 1399 = 222.20
# resultado da epoca 1400 = 563.42
# resultado da epoca 1401 = 274.78
# resultado da epoca 1402 = 737.06
# resultado da epoca 1403 = 624.94
# resultado da epoca 1404 = 448.42
# resultado da epoca 1405 = 152.66
# resultado da epoca 1406 = 609.94
# resultado da epoca 1407 = -27.64
# resultado da epoca 1408 = 646.23
# resultado da epoca 1409 = -383.17
# resultado da epoca 1410 = 297.29
# resultado da epoca 1411 = -242.48
# resultado da epoca 1412 = 182.20
# resultado da epoca 1413 = -65.22
# resultado da epoca 1414 = 277.89
# resultado da epoca 1415 = 573.88
# resultado da epoca 1416 = 927.96
# resultado da epoca 1417 = 49.25
# resultado da epoca 1418 = 447.43
# resultado da epoca 1419 = 262.66
# resultado da epoca 1420 = 1111.46
# resultado da epoca 1421 = -57.94
# resultado da epoca 1422 = -158.93
# resultado da epoca 1423 = 494.71
# resultado da epoca 1424 = 282.96
# resultado da epoca 1425 = 195.01
# resultado da epoca 1426 = 186.53
# resultado da epoca 1427 = 641.83
# resultado da epoca 1428 = -145.98
# resultado da epoca 1429 = 76.60
# resultado da epoca 1430 = 819.18
# resultado da epoca 1431 = 421.53
# resultado da epoca 1432 = 785.01
# resultado da epoca 1433 = 711.30
# resultado da epoca 1434 = 470.54
# resultado da epoca 1435 = 607.89
# resultado da epoca 1436 = 284.25
# resultado da epoca 1437 = 124.09
# resultado da epoca 1438 = 711.92
# resultado da epoca 1439 = 262.66
# resultado da epoca 1440 = 4.64
# resultado da epoca 1441 = -119.53
# resultado da epoca 1442 = 203.95
# resultado da epoca 1443 = -369.92
# resultado da epoca 1444 = -194.92
# resultado da epoca 1445 = -632.71
# resultado da epoca 1446 = 330.54
# resultado da epoca 1447 = -107.48
# resultado da epoca 1448 = 30.84
# resultado da epoca 1449 = -810.13
# resultado da epoca 1450 = -736.88
# resultado da epoca 1451 = 213.51
# resultado da epoca 1452 = -139.16
# resultado da epoca 1453 = 379.71
# resultado da epoca 1454 = -44.46
# resultado da epoca 1455 = 532.59
# resultado da epoca 1456 = 826.76
# resultado da epoca 1457 = 296.76
# resultado da epoca 1458 = 196.53
# resultado da epoca 1459 = 463.72
# ...
# resultado da epoca 9520 = 76.00
# resultado da epoca 9521 = 61.14
# resultado da epoca 9522 = -431.28
# resultado da epoca 9523 = -222.11
# resultado da epoca 9524 = 839.48
# resultado da epoca 9525 = 378.65
# resultado da epoca 9526 = -157.11
# resultado da epoca 9527 = -267.34
# resultado da epoca 9528 = 476.83
# resultado da epoca 9529 = -84.99
# resultado da epoca 9530 = 336.76
# resultado da epoca 9531 = -167.71
# resultado da epoca 9532 = -330.22
# resultado da epoca 9533 = 89.25
# resultado da epoca 9534 = 68.65
# resultado da epoca 9535 = 214.48
# resultado da epoca 9536 = 303.79
# resultado da epoca 9537 = 513.65
# resultado da epoca 9538 = -138.10
# resultado da epoca 9539 = -203.63
# resultado da epoca 9540 = 202.20
# resultado da epoca 9541 = -187.41
# resultado da epoca 9542 = 146.53
# resultado da epoca 9543 = -189.69
# resultado da epoca 9544 = -249.46
# resultado da epoca 9545 = 239.02
# resultado da epoca 9546 = 64.71
# resultado da epoca 9547 = 1084.48
# resultado da epoca 9548 = 665.54
# resultado da epoca 9549 = -1.05
# resultado da epoca 9550 = -71.88
# resultado da epoca 9551 = 104.18
# resultado da epoca 9552 = -126.05
# resultado da epoca 9553 = 103.72
# resultado da epoca 9554 = 106.90
# resultado da epoca 9555 = 418.12
# resultado da epoca 9556 = -272.04
# resultado da epoca 9557 = -330.52
# resultado da epoca 9558 = 315.24
# resultado da epoca 9559 = 940.24
# resultado da epoca 9560 = -251.05
# resultado da epoca 9561 = -166.21
# resultado da epoca 9562 = 220.01
# resultado da epoca 9563 = -274.76
# resultado da epoca 9564 = 342.66
# resultado da epoca 9565 = 194.32
# resultado da epoca 9566 = 274.18
# resultado da epoca 9567 = 716.00
# resultado da epoca 9568 = 643.19
# resultado da epoca 9569 = -580.38
# resultado da epoca 9570 = 224.85
# resultado da epoca 9571 = 210.24
# resultado da epoca 9572 = 380.61
# resultado da epoca 9573 = 444.71
# resultado da epoca 9574 = 337.59
# resultado da epoca 9575 = 462.43
# resultado da epoca 9576 = 158.65
# resultado da epoca 9577 = 467.06
# resultado da epoca 9578 = -157.27
# resultado da epoca 9579 = 391.16
# resultado da epoca 9580 = -306.35
# resultado da epoca 9581 = 988.12
# resultado da epoca 9582 = 117.89
# resultado da epoca 9583 = -502.11
# resultado da epoca 9584 = -180.59
# resultado da epoca 9585 = -388.40
# resultado da epoca 9586 = 78.79
# resultado da epoca 9587 = -82.94
# resultado da epoca 9588 = 189.25
# resultado da epoca 9589 = 273.49
# resultado da epoca 9590 = 232.89
# resultado da epoca 9591 = 180.84
# resultado da epoca 9592 = 40.61
# resultado da epoca 9593 = 299.09
# resultado da epoca 9594 = 275.08
# resultado da epoca 9595 = 520.77
# resultado da epoca 9596 = 480.38
# resultado da epoca 9597 = 577.73
# resultado da epoca 9598 = 62.50
# resultado da epoca 9599 = -563.10
# resultado da epoca 9600 = 139.32
# resultado da epoca 9601 = 736.81
# resultado da epoca 9602 = 980.31
# resultado da epoca 9603 = -64.00
# resultado da epoca 9604 = -96.65
# resultado da epoca 9605 = 114.71
# resultado da epoca 9606 = 109.64
# resultado da epoca 9607 = -561.35
# resultado da epoca 9608 = -140.15
# resultado da epoca 9609 = 257.13
# resultado da epoca 9610 = 219.41
# resultado da epoca 9611 = -173.40
# resultado da epoca 9612 = 108.26
# resultado da epoca 9613 = -188.70
# resultado da epoca 9614 = 202.73
# resultado da epoca 9615 = 172.73
# resultado da epoca 9616 = 740.17
# resultado da epoca 9617 = -185.45
# resultado da epoca 9618 = 124.71
# resultado da epoca 9619 = 43.19
# resultado da epoca 9620 = 426.00
# resultado da epoca 9621 = -521.51
# resultado da epoca 9622 = -12.64
# resultado da epoca 9623 = -520.52
# resultado da epoca 9624 = 479.11
# resultado da epoca 9625 = 600.24
# resultado da epoca 9626 = 130.77
# resultado da epoca 9627 = 765.91
# resultado da epoca 9628 = 456.44
# resultado da epoca 9629 = -205.15
# resultado da epoca 9630 = 313.49
# resultado da epoca 9631 = 183.72
# resultado da epoca 9632 = 517.27
# resultado da epoca 9633 = 518.19
# resultado da epoca 9634 = 163.49
# resultado da epoca 9635 = -326.05
# resultado da epoca 9636 = 193.26
# resultado da epoca 9637 = 213.95
# resultado da epoca 9638 = 244.71
# resultado da epoca 9639 = 140.31
# resultado da epoca 9640 = 150.77
# resultado da epoca 9641 = 582.43
# resultado da epoca 9642 = 791.37
# resultado da epoca 9643 = -32.87
# resultado da epoca 9644 = 430.31
# resultado da epoca 9645 = 333.49
# resultado da epoca 9646 = 390.01
# resultado da epoca 9647 = -58.93
# resultado da epoca 9648 = 343.19
# resultado da epoca 9649 = -178.93
# resultado da epoca 9650 = -422.80
# resultado da epoca 9651 = 456.30
# resultado da epoca 9652 = 413.42
# resultado da epoca 9653 = 84.18
# resultado da epoca 9654 = -479.69
# resultado da epoca 9655 = -336.12
# resultado da epoca 9656 = -172.34
# resultado da epoca 9657 = 413.49
# resultado da epoca 9658 = 416.07
# resultado da epoca 9659 = 344.25
# resultado da epoca 9660 = 603.12
# resultado da epoca 9661 = -52.87
# resultado da epoca 9662 = -17.94
# resultado da epoca 9663 = 267.06
# resultado da epoca 9664 = 120.01
# resultado da epoca 9665 = 139.55
# resultado da epoca 9666 = 752.36
# resultado da epoca 9667 = 81.23
# resultado da epoca 9668 = 42.89
# resultado da epoca 9669 = 266.37
# resultado da epoca 9670 = 27.13
# resultado da epoca 9671 = -77.34
# resultado da epoca 9672 = 238.79
# resultado da epoca 9673 = 750.70
# resultado da epoca 9674 = 127.89
# resultado da epoca 9675 = -348.10
# resultado da epoca 9676 = -36.05
# resultado da epoca 9677 = -181.81
# resultado da epoca 9678 = 491.44
# resultado da epoca 9679 = -202.41
# resultado da epoca 9680 = 243.88
# resultado da epoca 9681 = 242.89
# resultado da epoca 9682 = 456.23
# resultado da epoca 9683 = -214.69
# resultado da epoca 9684 = 106.30
# resultado da epoca 9685 = -331.21
# resultado da epoca 9686 = 87.43
# resultado da epoca 9687 = -746.28
# resultado da epoca 9688 = 308.42
# resultado da epoca 9689 = -455.22
# resultado da epoca 9690 = 449.71
# resultado da epoca 9691 = 901.00
# resultado da epoca 9692 = -48.40
# resultado da epoca 9693 = -42.11
# resultado da epoca 9694 = 254.48
# resultado da epoca 9695 = 356.30
# resultado da epoca 9696 = -52.34
# resultado da epoca 9697 = -161.81
# resultado da epoca 9698 = -370.75
# resultado da epoca 9699 = -774.23
# resultado da epoca 9700 = -152.41
# resultado da epoca 9701 = 853.12
# resultado da epoca 9702 = 418.12
# resultado da epoca 9703 = -333.77
# resultado da epoca 9704 = -303.10
# resultado da epoca 9705 = 380.31
# resultado da epoca 9706 = 127.36
# resultado da epoca 9707 = 107.66
# resultado da epoca 9708 = 40.08
# resultado da epoca 9709 = 599.87
# resultado da epoca 9710 = 161.07
# resultado da epoca 9711 = -289.00
# resultado da epoca 9712 = -49.62
# resultado da epoca 9713 = -21.28
# resultado da epoca 9714 = 197.96
# resultado da epoca 9715 = -93.63
# resultado da epoca 9716 = 299.18
# resultado da epoca 9717 = -504.00
# resultado da epoca 9718 = 532.96
# resultado da epoca 9719 = 432.73
# resultado da epoca 9720 = 320.47
# resultado da epoca 9721 = -132.11
# resultado da epoca 9722 = -81.72
# resultado da epoca 9723 = 168.79
# resultado da epoca 9724 = 599.25
# resultado da epoca 9725 = -443.10
# resultado da epoca 9726 = 482.43
# resultado da epoca 9727 = 752.13
# resultado da epoca 9728 = -16.42
# resultado da epoca 9729 = 17.13
# resultado da epoca 9730 = 1119.48
# resultado da epoca 9731 = -26.05
# resultado da epoca 9732 = 409.78
# resultado da epoca 9733 = -73.70
# resultado da epoca 9734 = 667.43
# resultado da epoca 9735 = 577.06
# resultado da epoca 9736 = -121.88
# resultado da epoca 9737 = 398.88
# resultado da epoca 9738 = -577.94
# resultado da epoca 9739 = 908.35
# resultado da epoca 9740 = 30.84
# resultado da epoca 9741 = 366.16
# resultado da epoca 9742 = 444.32
# resultado da epoca 9743 = 36.37
# resultado da epoca 9744 = 71.07
# resultado da epoca 9745 = -468.93
# resultado da epoca 9746 = 805.31
# resultado da epoca 9747 = -370.82
# resultado da epoca 9748 = 838.95
# resultado da epoca 9749 = 486.53
# resultado da epoca 9750 = 321.76
# resultado da epoca 9751 = -311.28
# resultado da epoca 9752 = -190.36
# resultado da epoca 9753 = 354.41
# resultado da epoca 9754 = 320.01
# resultado da epoca 9755 = 235.24
# resultado da epoca 9756 = 360.93
# resultado da epoca 9757 = 486.14
# resultado da epoca 9758 = 986.37
# resultado da epoca 9759 = -128.93
# resultado da epoca 9760 = -204.76
# resultado da epoca 9761 = 497.89
# resultado da epoca 9762 = 400.84
# resultado da epoca 9763 = 140.01
# resultado da epoca 9764 = 59.87
# resultado da epoca 9765 = 275.08
# resultado da epoca 9766 = -158.01
# resultado da epoca 9767 = 279.48
# resultado da epoca 9768 = 520.84
# resultado da epoca 9769 = -70.75
# resultado da epoca 9770 = -122.57
# resultado da epoca 9771 = -385.68
# resultado da epoca 9772 = 54.25
# resultado da epoca 9773 = -15.06
# resultado da epoca 9774 = 137.36
# resultado da epoca 9775 = -253.40
# resultado da epoca 9776 = 79.25
# resultado da epoca 9777 = 852.43
# resultado da epoca 9778 = -228.70
# resultado da epoca 9779 = -328.01
# resultado da epoca 9780 = 551.90
# resultado da epoca 9781 = 27.13
# resultado da epoca 9782 = -549.99
# resultado da epoca 9783 = 912.13
# resultado da epoca 9784 = 977.36
# resultado da epoca 9785 = 465.84
# resultado da epoca 9786 = 481.76
# resultado da epoca 9787 = -417.80
# resultado da epoca 9788 = -40.75
# resultado da epoca 9789 = 260.54
# resultado da epoca 9790 = -246.12
# resultado da epoca 9791 = 77.82
# resultado da epoca 9792 = -7.18
# resultado da epoca 9793 = 488.35
# resultado da epoca 9794 = 312.36
# resultado da epoca 9795 = -173.40
# resultado da epoca 9796 = 607.66
# resultado da epoca 9797 = 98.72
# resultado da epoca 9798 = 210.01
# resultado da epoca 9799 = 769.85
# resultado da epoca 9800 = 558.42
# resultado da epoca 9801 = 524.25
# resultado da epoca 9802 = 223.88
# resultado da epoca 9803 = 868.49
# resultado da epoca 9804 = -13.70
# resultado da epoca 9805 = -73.10
# resultado da epoca 9806 = 387.59
# resultado da epoca 9807 = 413.88
# resultado da epoca 9808 = 201.60
# resultado da epoca 9809 = 229.32
# resultado da epoca 9810 = -453.40
# resultado da epoca 9811 = -175.06
# resultado da epoca 9812 = -136.88
# resultado da epoca 9813 = 586.44
# resultado da epoca 9814 = 371.07
# resultado da epoca 9815 = -429.23
# resultado da epoca 9816 = -319.16
# resultado da epoca 9817 = 735.01
# resultado da epoca 9818 = 225.91
# resultado da epoca 9819 = 195.31
# resultado da epoca 9820 = 82.89
# resultado da epoca 9821 = 475.54
# resultado da epoca 9822 = 379.64
# resultado da epoca 9823 = 651.83
# resultado da epoca 9824 = -397.41
# resultado da epoca 9825 = 23.95
# resultado da epoca 9826 = -446.58
# resultado da epoca 9827 = 549.94
# resultado da epoca 9828 = -0.22
# resultado da epoca 9829 = 1392.43
# resultado da epoca 9830 = 443.65
# resultado da epoca 9831 = 663.72
# resultado da epoca 9832 = -318.93
# resultado da epoca 9833 = -199.00
# resultado da epoca 9834 = 597.59
# resultado da epoca 9835 = -419.99
# resultado da epoca 9836 = 550.84
# resultado da epoca 9837 = -61.42
# resultado da epoca 9838 = -109.16
# resultado da epoca 9839 = 391.53
# resultado da epoca 9840 = 982.43
# resultado da epoca 9841 = 28.72
# resultado da epoca 9842 = 652.36
# resultado da epoca 9843 = 692.20
# resultado da epoca 9844 = 958.35
# resultado da epoca 9845 = -165.29
# resultado da epoca 9846 = -358.77
# resultado da epoca 9847 = 465.31
# resultado da epoca 9848 = 500.54
# resultado da epoca 9849 = 12.13
# resultado da epoca 9850 = -266.88
# resultado da epoca 9851 = 230.77
# resultado da epoca 9852 = 499.48
# resultado da epoca 9853 = 1424.25
# resultado da epoca 9854 = -358.86
# resultado da epoca 9855 = 446.37
# resultado da epoca 9856 = 394.64
# resultado da epoca 9857 = 684.78
# resultado da epoca 9858 = -171.35
# resultado da epoca 9859 = 115.84
# resultado da epoca 9860 = -17.27
# resultado da epoca 9861 = 763.72
# resultado da epoca 9862 = 624.71
# resultado da epoca 9863 = 38.26
# resultado da epoca 9864 = 455.08
# resultado da epoca 9865 = 356.37
# resultado da epoca 9866 = 144.48
# resultado da epoca 9867 = 633.58
# resultado da epoca 9868 = 717.96
# resultado da epoca 9869 = 447.06
# resultado da epoca 9870 = -92.11
# resultado da epoca 9871 = 100.93
# resultado da epoca 9872 = 763.65
# resultado da epoca 9873 = 247.96
# resultado da epoca 9874 = 482.82
# resultado da epoca 9875 = 152.36
# resultado da epoca 9876 = -18.93
# resultado da epoca 9877 = 342.13
# resultado da epoca 9878 = -511.51
# resultado da epoca 9879 = 91.37
# resultado da epoca 9880 = 552.59
# resultado da epoca 9881 = -97.11
# resultado da epoca 9882 = 418.35
# resultado da epoca 9883 = 222.13
# resultado da epoca 9884 = 826.67
# resultado da epoca 9885 = 749.85
# resultado da epoca 9886 = 420.77
# resultado da epoca 9887 = -245.98
# resultado da epoca 9888 = -594.46
# resultado da epoca 9889 = 479.78
# resultado da epoca 9890 = -160.22
# resultado da epoca 9891 = -186.05
# resultado da epoca 9892 = -26.65
# resultado da epoca 9893 = 112.59
# resultado da epoca 9894 = 276.60
# resultado da epoca 9895 = 541.83
# resultado da epoca 9896 = 69.71
# resultado da epoca 9897 = -278.40
# resultado da epoca 9898 = 1114.48
# resultado da epoca 9899 = -545.29
# resultado da epoca 9900 = 497.89
# resultado da epoca 9901 = 268.79
# resultado da epoca 9902 = 331.14
# resultado da epoca 9903 = 49.55
# resultado da epoca 9904 = 922.66
# resultado da epoca 9905 = -297.41
# resultado da epoca 9906 = 19.85
# resultado da epoca 9907 = -244.62
# resultado da epoca 9908 = -493.47
# resultado da epoca 9909 = 377.36
# resultado da epoca 9910 = -50.45
# resultado da epoca 9911 = 674.71
# resultado da epoca 9912 = 274.62
# resultado da epoca 9913 = -205.22
# resultado da epoca 9914 = 223.12
# resultado da epoca 9915 = 48.49
# resultado da epoca 9916 = 43.65
# resultado da epoca 9917 = 317.20
# resultado da epoca 9918 = 122.80
# resultado da epoca 9919 = 999.41
# resultado da epoca 9920 = 216.07
# resultado da epoca 9921 = -456.58
# resultado da epoca 9922 = -4.69
# resultado da epoca 9923 = 70.47
# resultado da epoca 9924 = 2.59
# resultado da epoca 9925 = 225.47
# resultado da epoca 9926 = 269.71
# resultado da epoca 9927 = 35.91
# resultado da epoca 9928 = 611.60
# resultado da epoca 9929 = 253.19
# resultado da epoca 9930 = -336.97
# resultado da epoca 9931 = 684.32
# resultado da epoca 9932 = 458.26
# resultado da epoca 9933 = 185.08
# resultado da epoca 9934 = -48.86
# resultado da epoca 9935 = -36.58
# resultado da epoca 9936 = 537.43
# resultado da epoca 9937 = -163.93
# resultado da epoca 9938 = 384.64
# resultado da epoca 9939 = 1.60
# resultado da epoca 9940 = -166.58
# resultado da epoca 9941 = 152.43
# resultado da epoca 9942 = 640.24
# resultado da epoca 9943 = 771.67
# resultado da epoca 9944 = 228.19
# resultado da epoca 9945 = -438.33
# resultado da epoca 9946 = 504.64
# resultado da epoca 9947 = 161.53
# resultado da epoca 9948 = -127.94
# resultado da epoca 9949 = 242.66
# resultado da epoca 9950 = 400.98
# resultado da epoca 9951 = -84.23
# resultado da epoca 9952 = -79.46
# resultado da epoca 9953 = 43.95
# resultado da epoca 9954 = 612.43
# resultado da epoca 9955 = -54.69
# resultado da epoca 9956 = -89.00
# resultado da epoca 9957 = 462.36
# resultado da epoca 9958 = 444.78
# resultado da epoca 9959 = 137.29
# resultado da epoca 9960 = 781.90
# resultado da epoca 9961 = 213.26
# resultado da epoca 9962 = 287.13
# resultado da epoca 9963 = 645.77
# resultado da epoca 9964 = 606.90
# resultado da epoca 9965 = 570.84
# resultado da epoca 9966 = 128.49
# resultado da epoca 9967 = 164.71
# resultado da epoca 9968 = 711.30
# resultado da epoca 9969 = 585.01
# resultado da epoca 9970 = 396.76
# resultado da epoca 9971 = -373.10
# resultado da epoca 9972 = 399.55
# resultado da epoca 9973 = 236.37
# resultado da epoca 9974 = -371.12
# resultado da epoca 9975 = 426.83
# resultado da epoca 9976 = 1154.11
# resultado da epoca 9977 = 1.37
# resultado da epoca 9978 = 666.00
# resultado da epoca 9979 = -203.17
# resultado da epoca 9980 = 525.77
# resultado da epoca 9981 = 306.30
# resultado da epoca 9982 = 450.31
# resultado da epoca 9983 = 648.19
# resultado da epoca 9984 = -188.47
# resultado da epoca 9985 = 484.94
# resultado da epoca 9986 = 164.48
# resultado da epoca 9987 = 444.11
# resultado da epoca 9988 = 1033.19
# resultado da epoca 9989 = 286.60
# resultado da epoca 9990 = -49.46
# resultado da epoca 9991 = 118.12
# resultado da epoca 9992 = 436.53
# resultado da epoca 9993 = 712.36
# resultado da epoca 9994 = 1161.60
# resultado da epoca 9995 = 227.43
# resultado da epoca 9996 = 395.24
# resultado da epoca 9997 = -320.98
# resultado da epoca 9998 = 181.21
# resultado da epoca 9999 = 448.65
# Somatoria dos rewards: 2518824.13
# Melhor resultado diario: 1488.41

# %%
modelo.salva_pesos('./pesos.h5')
