# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma']#, 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 500 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 250

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
inputs_nao_norm = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1
print(inputs)
#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
       
    inputs.loc[:, inputs.columns[i]] = inputs.loc[:, inputs.columns[i]] - imean 

valor0 = np.amin(inputs['preco']) - 500
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         preco    hr_int  preco_pon  qnt_soma
# 0      3907.5  32700000    3907.50       1.0
# 1      3900.0  33000000    3901.26   20309.0
# 2      3898.0  33300000    3901.42   17614.0
# 3      3898.0  33600000    3895.37   14283.0
# 4      3899.5  33900000    3897.78    6638.0
# 5      3906.0  34200000    3902.52   13485.0
# 6      3908.0  34500000    3907.20   12677.0
# 7      3913.0  34800000    3910.72   17927.0
# 8      3906.0  35100000    3909.27   18032.0
# 9      3902.0  35400000    3904.82   17600.0
# 10     3900.5  35700000    3900.53    9326.0
# 11     3894.0  36000000    3896.53   18013.0
# 12     3897.5  36300000    3897.41   14159.0
# 13     3900.0  36600000    3897.87    5793.0
# 14     3906.0  36900000    3902.17   15901.0
# 15     3907.5  37200000    3905.68   12928.0
# 16     3908.0  37500000    3908.40    7904.0
# 17     3911.0  37800000    3909.38    7750.0
# 18     3911.0  38100000    3912.43   10917.0
# 19     3908.5  38400000    3910.42    8978.0
# 20     3916.5  38700000    3913.49   12775.0
# 21     3914.0  39000000    3915.66    7874.0
# 22     3912.0  39300000    3913.06    6877.0
# 23     3910.5  39600000    3910.59    6747.0
# 24     3917.5  39900000    3914.81   12360.0
# 25     3914.0  40200000    3915.96    8289.0
# 26     3918.5  40500000    3916.91    6028.0
# 27     3918.0  40800000    3917.95    4025.0
# 28     3918.5  41100000    3917.52    4618.0
# 29     3917.5  41400000    3917.21    2747.0
# ...       ...       ...        ...       ...
# 30074  4076.5  55500000    4076.10    9242.0
# 30075  4076.5  55800000    4076.64    4228.0
# 30076  4076.0  56100000    4075.85    3009.0
# 30077  4078.5  56400000    4077.82    9162.0
# 30078  4078.0  56700000    4078.75    5166.0
# 30079  4080.0  57000000    4078.75    4928.0
# 30080  4083.0  57300000    4081.52    9979.0
# 30081  4078.0  57600000    4080.32   17157.0
# 30082  4077.5  57900000    4078.53    5130.0
# 30083  4077.5  58200000    4077.40    3576.0
# 30084  4075.0  58500000    4075.73    7682.0
# 30085  4077.0  58800000    4076.49    3760.0
# 30086  4075.5  59100000    4076.04    2943.0
# 30087  4080.5  59400000    4078.23    7689.0
# 30088  4079.5  59700000    4080.42    9414.0
# 30089  4081.5  60000000    4079.69    8811.0
# 30090  4082.5  60300000    4081.89    8741.0
# 30091  4083.5  60600000    4083.25    6228.0
# 30092  4084.0  60900000    4083.63    3415.0
# 30093  4085.5  61200000    4084.95    5914.0
# 30094  4081.0  61500000    4083.09    7944.0
# 30095  4079.5  61800000    4080.75    5461.0
# 30096  4078.0  62100000    4079.08    4891.0
# 30097  4079.0  62400000    4078.74    2705.0
# 30098  4077.5  62700000    4078.02    2231.0
# 30099  4074.0  63000000    4074.69    9221.0
# 30100  4071.5  63300000    4071.88    5389.0
# 30101  4071.0  63600000    4070.23    5930.0
# 30102  4069.0  63900000    4071.37    5387.0
# 30103  4068.5  64200000    4069.33    4407.0
#
# [30104 rows x 4 columns]
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 6
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.98     # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(512, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(196, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)        
        model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(64, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(32, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        
        #model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(x*3, activation='relu')) #camada escondida
        #model.add(Dense(x*2, activation='relu')) #camada escondida
        #model.add(Dense(x, activation='relu')) #camada escondida
        #model.add(Dense(64, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size) if dias>5 else self.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3584
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 196)               50372
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               25216
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 11)                363
# =================================================================
# Total params: 286,991
# Trainable params: 286,991
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(preco, ncont, acao, valor, custo=0):   

    if acao == 0: #zerado
        if ncont>0:  #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        elif ncont<0: #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        else:         
            reward = 0
        valor = valor0
    elif acao>0:  #comprado
        if ncont>0:
            if acao>ncont: #aumento da posicao
                reward = -custo*(acao-ncont)
                valor = (valor*ncont+(acao-ncont)*preco)/(acao)  #calculo preco medio
            elif acao<ncont:  #diminuicao da posicao
                reward = (ncont-acao)*(preco-valor) -custo*(ncont-acao)
                valor = valor #preco medio se mantem
            else:
                reward = 0
        elif ncont<0:   #trocando a mao
            reward = abs(ncont)*(valor-preco) -custo*(acao+abs(ncont))
            valor = preco
        else:          #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
    else:       #vendido
        if ncont>0:#trocando a mao
            reward = ncont*(preco-valor) -custo*(ncont+abs(acao))
            valor = preco
        elif ncont<0:
            if abs(acao)<abs(ncont): #diminuicao da posicao
                reward = (abs(ncont)-abs(acao))*(valor-preco) -custo*(abs(ncont)-abs(acao))
                valor = valor #preco medio se mantem
            elif abs(acao)>abs(ncont): #aumento da posicao
                reward = -custo*(abs(acao)-abs(ncont))
                valor = (valor*abs(ncont)+(abs(acao)-abs(ncont))*preco)/(abs(acao))  #calculo preco medio
            else: #preco medio se mantem
                reward = 0
        else:  #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
                
    #reward = ncont*acao*preco
    ncont = acao
    posicao = ncont*(preco-valor) -custo*abs(ncont) if ncont!=0 else 0.
    return ncont, reward, valor, posicao

def obter_acao():
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = valor0 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    indice = 0
    lucro = 0.
    posicao = 0. #cria variavel de posicao 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont, indice, precos['preco'][step], valor, precos['preco_pon'][step], precos['qnt_soma'][step]], (1,modelo.state_size))
        
        acao = obter_acao()
        ncont, reward, valor, posicao = teste(precos['preco'][step], ncont, acao, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor*pstd+pmean if valor!=-100 else 0
        #p=precos['preco'][step]+pmean
        #print("acao={0}; ncont={1}; reward={2} valor={3} preco={4}".format(acao, ncont, reward, valor, precos['preco'][step]))   

        if step == (steps[dia+1] - 1): #se ultimo step do dia
            done = True     
        
        modelo.next_state = np.reshape([ncont, indice+1, precos['preco'][step+1], valor, precos['preco_pon'][step+1], precos['qnt_soma'][step+1]], (1,modelo.state_size))
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        indice += 1
        
    #fim do dia
    lucro +=posicao
    
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo, dia_inicial, n_dias):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( dia_inicial, dia_inicial+n_dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        
        minibatch = modelo.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    melhor_reward = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo, 0, dias) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1117 11:42:05.677755  6616 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1117 11:42:24.247817  6616 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1117 11:42:24.286820  6616 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -1065.50 Epsilon = 1.000
# resultado da epoca 1 = 20.00 Epsilon = 0.998
# resultado da epoca 2 = 1730.00 Epsilon = 0.996
# resultado da epoca 3 = -518.50 Epsilon = 0.994
# resultado da epoca 4 = 2243.50 Epsilon = 0.992
# resultado da epoca 5 = 756.50 Epsilon = 0.990
# resultado da epoca 6 = 1323.50 Epsilon = 0.988
# resultado da epoca 7 = -2888.50 Epsilon = 0.986
# resultado da epoca 8 = -4989.50 Epsilon = 0.984
# resultado da epoca 9 = -1700.00 Epsilon = 0.982
# resultado da epoca 10 = 2267.50 Epsilon = 0.980
# resultado da epoca 11 = -1459.00 Epsilon = 0.978
# resultado da epoca 12 = -204.50 Epsilon = 0.976
# resultado da epoca 13 = -370.50 Epsilon = 0.974
# resultado da epoca 14 = 739.50 Epsilon = 0.972
# resultado da epoca 15 = 61.00 Epsilon = 0.970
# resultado da epoca 16 = 244.50 Epsilon = 0.968
# resultado da epoca 17 = -124.50 Epsilon = 0.966
# resultado da epoca 18 = 419.50 Epsilon = 0.964
# resultado da epoca 19 = -1707.50 Epsilon = 0.962
# resultado da epoca 20 = 2108.50 Epsilon = 0.960
# resultado da epoca 21 = -279.00 Epsilon = 0.958
# resultado da epoca 22 = 2563.00 Epsilon = 0.956
# resultado da epoca 23 = 3148.50 Epsilon = 0.954
# resultado da epoca 24 = -1107.50 Epsilon = 0.952
# resultado da epoca 25 = -277.00 Epsilon = 0.951
# resultado da epoca 26 = 1221.50 Epsilon = 0.949
# resultado da epoca 27 = -1785.00 Epsilon = 0.947
# resultado da epoca 28 = 312.50 Epsilon = 0.945
# resultado da epoca 29 = -386.00 Epsilon = 0.943
# resultado da epoca 30 = -1217.50 Epsilon = 0.941
# resultado da epoca 31 = -2150.00 Epsilon = 0.939
# resultado da epoca 32 = -1324.00 Epsilon = 0.937
# resultado da epoca 33 = 1148.50 Epsilon = 0.935
# resultado da epoca 34 = -3411.50 Epsilon = 0.933
# resultado da epoca 35 = -978.50 Epsilon = 0.931
# resultado da epoca 36 = -385.00 Epsilon = 0.929
# resultado da epoca 37 = 1256.00 Epsilon = 0.927
# resultado da epoca 38 = -1366.50 Epsilon = 0.925
# resultado da epoca 39 = 1727.00 Epsilon = 0.923
# resultado da epoca 40 = 311.00 Epsilon = 0.921
# resultado da epoca 41 = -1323.50 Epsilon = 0.919
# resultado da epoca 42 = -377.00 Epsilon = 0.917
# resultado da epoca 43 = -1401.50 Epsilon = 0.915
# resultado da epoca 44 = 96.00 Epsilon = 0.913
# resultado da epoca 45 = 1342.00 Epsilon = 0.911
# resultado da epoca 46 = 983.50 Epsilon = 0.909
# resultado da epoca 47 = 197.00 Epsilon = 0.907
# resultado da epoca 48 = -752.00 Epsilon = 0.905
# resultado da epoca 49 = -2603.00 Epsilon = 0.903
# resultado da epoca 50 = -227.50 Epsilon = 0.901
# resultado da epoca 51 = -1979.50 Epsilon = 0.899
# resultado da epoca 52 = -152.50 Epsilon = 0.897
# resultado da epoca 53 = 1888.00 Epsilon = 0.895
# resultado da epoca 54 = 792.50 Epsilon = 0.893
# resultado da epoca 55 = -723.00 Epsilon = 0.891
# resultado da epoca 56 = 525.00 Epsilon = 0.889
# resultado da epoca 57 = 70.00 Epsilon = 0.887
# resultado da epoca 58 = -644.50 Epsilon = 0.885
# resultado da epoca 59 = -1027.00 Epsilon = 0.883
# resultado da epoca 60 = -793.00 Epsilon = 0.881
# resultado da epoca 61 = 968.00 Epsilon = 0.879
# resultado da epoca 62 = 1755.50 Epsilon = 0.877
# resultado da epoca 63 = -2145.50 Epsilon = 0.875
# resultado da epoca 64 = 1445.00 Epsilon = 0.873
# resultado da epoca 65 = -1071.00 Epsilon = 0.871
# resultado da epoca 66 = -908.50 Epsilon = 0.869
# resultado da epoca 67 = 1222.00 Epsilon = 0.867
# resultado da epoca 68 = 1152.00 Epsilon = 0.865
# resultado da epoca 69 = -1990.50 Epsilon = 0.863
# resultado da epoca 70 = 1525.50 Epsilon = 0.861
# resultado da epoca 71 = 1595.50 Epsilon = 0.859
# resultado da epoca 72 = -1059.50 Epsilon = 0.857
# resultado da epoca 73 = 1648.50 Epsilon = 0.855
# resultado da epoca 74 = -1494.50 Epsilon = 0.853
# resultado da epoca 75 = 1870.00 Epsilon = 0.852
# resultado da epoca 76 = 258.50 Epsilon = 0.850
# resultado da epoca 77 = -334.50 Epsilon = 0.848
# resultado da epoca 78 = -1307.00 Epsilon = 0.846
# resultado da epoca 79 = 2093.50 Epsilon = 0.844
# resultado da epoca 80 = -2095.50 Epsilon = 0.842
# resultado da epoca 81 = -3679.50 Epsilon = 0.840
# resultado da epoca 82 = 1042.00 Epsilon = 0.838
# resultado da epoca 83 = -1021.00 Epsilon = 0.836
# resultado da epoca 84 = -1477.00 Epsilon = 0.834
# resultado da epoca 85 = 649.00 Epsilon = 0.832
# resultado da epoca 86 = 1446.00 Epsilon = 0.830
# resultado da epoca 87 = 2419.00 Epsilon = 0.828
# resultado da epoca 88 = 3633.00 Epsilon = 0.826
# resultado da epoca 89 = -597.00 Epsilon = 0.824
# resultado da epoca 90 = 1726.00 Epsilon = 0.822
# resultado da epoca 91 = -1015.50 Epsilon = 0.820
# resultado da epoca 92 = 1212.50 Epsilon = 0.818
# resultado da epoca 93 = 1420.00 Epsilon = 0.816
# resultado da epoca 94 = -96.50 Epsilon = 0.814
# resultado da epoca 95 = -2194.00 Epsilon = 0.812
# resultado da epoca 96 = 626.50 Epsilon = 0.810
# resultado da epoca 97 = 620.00 Epsilon = 0.808
# resultado da epoca 98 = -1333.00 Epsilon = 0.806
# resultado da epoca 99 = -1858.50 Epsilon = 0.804
# resultado da epoca 100 = 1960.00 Epsilon = 0.802
# resultado da epoca 101 = -1343.50 Epsilon = 0.800
# resultado da epoca 102 = 1823.50 Epsilon = 0.798
# resultado da epoca 103 = 150.00 Epsilon = 0.796
# resultado da epoca 104 = -690.50 Epsilon = 0.794
# resultado da epoca 105 = 2284.50 Epsilon = 0.792
# resultado da epoca 106 = 1116.50 Epsilon = 0.790
# resultado da epoca 107 = -1017.00 Epsilon = 0.788
# resultado da epoca 108 = -2493.50 Epsilon = 0.786
# resultado da epoca 109 = -697.50 Epsilon = 0.784
# resultado da epoca 110 = 1908.00 Epsilon = 0.782
# resultado da epoca 111 = -633.50 Epsilon = 0.780
# resultado da epoca 112 = 354.00 Epsilon = 0.778
# resultado da epoca 113 = -2730.00 Epsilon = 0.776
# resultado da epoca 114 = 454.00 Epsilon = 0.774
# resultado da epoca 115 = -1800.50 Epsilon = 0.772
# resultado da epoca 116 = -1767.00 Epsilon = 0.770
# resultado da epoca 117 = -1652.50 Epsilon = 0.768
# resultado da epoca 118 = 2066.50 Epsilon = 0.766
# resultado da epoca 119 = 648.00 Epsilon = 0.764
# resultado da epoca 120 = 1381.00 Epsilon = 0.762
# resultado da epoca 121 = 398.50 Epsilon = 0.760
# resultado da epoca 122 = 45.50 Epsilon = 0.758
# resultado da epoca 123 = -704.00 Epsilon = 0.756
# resultado da epoca 124 = 290.00 Epsilon = 0.754
# resultado da epoca 125 = -623.00 Epsilon = 0.753
# resultado da epoca 126 = 65.50 Epsilon = 0.751
# resultado da epoca 127 = -2934.50 Epsilon = 0.749
# resultado da epoca 128 = 1379.50 Epsilon = 0.747
# resultado da epoca 129 = 1563.50 Epsilon = 0.745
# resultado da epoca 130 = -2721.50 Epsilon = 0.743
# resultado da epoca 131 = -100.00 Epsilon = 0.741
# resultado da epoca 132 = 1977.00 Epsilon = 0.739
# resultado da epoca 133 = 1292.00 Epsilon = 0.737
# resultado da epoca 134 = 1131.50 Epsilon = 0.735
# resultado da epoca 135 = -3090.00 Epsilon = 0.733
# resultado da epoca 136 = 1194.50 Epsilon = 0.731
# resultado da epoca 137 = 315.00 Epsilon = 0.729
# resultado da epoca 138 = 859.00 Epsilon = 0.727
# resultado da epoca 139 = -1650.00 Epsilon = 0.725
# resultado da epoca 140 = 1628.50 Epsilon = 0.723
# resultado da epoca 141 = 926.00 Epsilon = 0.721
# resultado da epoca 142 = 37.50 Epsilon = 0.719
# resultado da epoca 143 = 1819.50 Epsilon = 0.717
# resultado da epoca 144 = -2264.50 Epsilon = 0.715
# resultado da epoca 145 = -3477.50 Epsilon = 0.713
# resultado da epoca 146 = -990.50 Epsilon = 0.711
# resultado da epoca 147 = -1636.00 Epsilon = 0.709
# resultado da epoca 148 = 1211.50 Epsilon = 0.707
# resultado da epoca 149 = 3155.50 Epsilon = 0.705
# resultado da epoca 150 = 798.50 Epsilon = 0.703
# resultado da epoca 151 = 2385.50 Epsilon = 0.701
# resultado da epoca 152 = 185.50 Epsilon = 0.699
# resultado da epoca 153 = -1164.50 Epsilon = 0.697
# resultado da epoca 154 = 2310.00 Epsilon = 0.695
# resultado da epoca 155 = 642.00 Epsilon = 0.693
# resultado da epoca 156 = -363.50 Epsilon = 0.691
# resultado da epoca 157 = 1084.00 Epsilon = 0.689
# resultado da epoca 158 = 922.50 Epsilon = 0.687
# resultado da epoca 159 = 4117.50 Epsilon = 0.685
# resultado da epoca 160 = 767.00 Epsilon = 0.683
# resultado da epoca 161 = -183.50 Epsilon = 0.681
# resultado da epoca 162 = 1671.00 Epsilon = 0.679
# resultado da epoca 163 = -2778.00 Epsilon = 0.677
# resultado da epoca 164 = -970.00 Epsilon = 0.675
# resultado da epoca 165 = 1249.50 Epsilon = 0.673
# resultado da epoca 166 = 758.00 Epsilon = 0.671
# resultado da epoca 167 = -1424.00 Epsilon = 0.669
# resultado da epoca 168 = 537.50 Epsilon = 0.667
# resultado da epoca 169 = 1541.00 Epsilon = 0.665
# resultado da epoca 170 = 1788.50 Epsilon = 0.663
# resultado da epoca 171 = 158.50 Epsilon = 0.661
# resultado da epoca 172 = 106.00 Epsilon = 0.659
# resultado da epoca 173 = -1212.00 Epsilon = 0.657
# resultado da epoca 174 = -343.50 Epsilon = 0.655
# resultado da epoca 175 = -2941.50 Epsilon = 0.654
# resultado da epoca 176 = 1503.50 Epsilon = 0.652
# resultado da epoca 177 = 141.50 Epsilon = 0.650
# resultado da epoca 178 = -81.00 Epsilon = 0.648
# resultado da epoca 179 = -201.00 Epsilon = 0.646
# resultado da epoca 180 = -1409.00 Epsilon = 0.644
# resultado da epoca 181 = -245.00 Epsilon = 0.642
# resultado da epoca 182 = -1609.50 Epsilon = 0.640
# resultado da epoca 183 = -925.00 Epsilon = 0.638
# resultado da epoca 184 = -1893.00 Epsilon = 0.636
# resultado da epoca 185 = 959.50 Epsilon = 0.634
# resultado da epoca 186 = -1374.00 Epsilon = 0.632
# resultado da epoca 187 = -880.50 Epsilon = 0.630
# resultado da epoca 188 = 1024.50 Epsilon = 0.628
# resultado da epoca 189 = 1489.50 Epsilon = 0.626
# resultado da epoca 190 = -638.50 Epsilon = 0.624
# resultado da epoca 191 = 176.50 Epsilon = 0.622
# resultado da epoca 192 = 364.50 Epsilon = 0.620
# resultado da epoca 193 = 314.00 Epsilon = 0.618
# resultado da epoca 194 = -2715.50 Epsilon = 0.616
# resultado da epoca 195 = 3738.00 Epsilon = 0.614
# resultado da epoca 196 = -308.00 Epsilon = 0.612
# resultado da epoca 197 = 2057.00 Epsilon = 0.610
# resultado da epoca 198 = 1248.50 Epsilon = 0.608
# resultado da epoca 199 = -2733.00 Epsilon = 0.606
# resultado da epoca 200 = -1587.50 Epsilon = 0.604
# resultado da epoca 201 = 561.50 Epsilon = 0.602
# resultado da epoca 202 = 2846.50 Epsilon = 0.600
# resultado da epoca 203 = 2965.00 Epsilon = 0.598
# resultado da epoca 204 = -3574.00 Epsilon = 0.596
# resultado da epoca 205 = -2483.00 Epsilon = 0.594
# resultado da epoca 206 = 869.50 Epsilon = 0.592
# resultado da epoca 207 = 2667.50 Epsilon = 0.590
# resultado da epoca 208 = 1355.50 Epsilon = 0.588
# resultado da epoca 209 = 2392.50 Epsilon = 0.586
# resultado da epoca 210 = -753.00 Epsilon = 0.584
# resultado da epoca 211 = 551.00 Epsilon = 0.582
# resultado da epoca 212 = 3296.50 Epsilon = 0.580
# resultado da epoca 213 = -1444.50 Epsilon = 0.578
# resultado da epoca 214 = 2466.50 Epsilon = 0.576
# resultado da epoca 215 = -1577.50 Epsilon = 0.574
# resultado da epoca 216 = 1030.50 Epsilon = 0.572
# resultado da epoca 217 = -928.00 Epsilon = 0.570
# resultado da epoca 218 = 2559.00 Epsilon = 0.568
# resultado da epoca 219 = 1100.00 Epsilon = 0.566
# resultado da epoca 220 = -1816.50 Epsilon = 0.564
# resultado da epoca 221 = -2584.00 Epsilon = 0.562
# resultado da epoca 222 = 361.00 Epsilon = 0.560
# resultado da epoca 223 = 24.50 Epsilon = 0.558
# resultado da epoca 224 = 3954.50 Epsilon = 0.556
# resultado da epoca 225 = 2972.50 Epsilon = 0.555
# resultado da epoca 226 = 1973.50 Epsilon = 0.553
# resultado da epoca 227 = -216.00 Epsilon = 0.551
# resultado da epoca 228 = 713.50 Epsilon = 0.549
# resultado da epoca 229 = -109.50 Epsilon = 0.547
# resultado da epoca 230 = 1160.00 Epsilon = 0.545
# resultado da epoca 231 = 150.50 Epsilon = 0.543
# resultado da epoca 232 = 2674.50 Epsilon = 0.541
# resultado da epoca 233 = 3925.00 Epsilon = 0.539
# resultado da epoca 234 = -200.50 Epsilon = 0.537
# resultado da epoca 235 = 2292.00 Epsilon = 0.535
# resultado da epoca 236 = 1193.00 Epsilon = 0.533
# resultado da epoca 237 = -1354.50 Epsilon = 0.531
# resultado da epoca 238 = -687.00 Epsilon = 0.529
# resultado da epoca 239 = 617.50 Epsilon = 0.527
# resultado da epoca 240 = 232.50 Epsilon = 0.525
# resultado da epoca 241 = 3112.50 Epsilon = 0.523
# resultado da epoca 242 = -2203.00 Epsilon = 0.521
# resultado da epoca 243 = -678.00 Epsilon = 0.519
# resultado da epoca 244 = 70.50 Epsilon = 0.517
# resultado da epoca 245 = -2645.50 Epsilon = 0.515
# resultado da epoca 246 = 710.50 Epsilon = 0.513
# resultado da epoca 247 = 1577.50 Epsilon = 0.511
# resultado da epoca 248 = 501.50 Epsilon = 0.509
# resultado da epoca 249 = 3106.00 Epsilon = 0.507
# resultado da epoca 250 = 1039.50 Epsilon = 0.505
# resultado da epoca 251 = -599.50 Epsilon = 0.503
# resultado da epoca 252 = -61.00 Epsilon = 0.501
# resultado da epoca 253 = 312.50 Epsilon = 0.499
# resultado da epoca 254 = -5.50 Epsilon = 0.497
# resultado da epoca 255 = 271.50 Epsilon = 0.495
# resultado da epoca 256 = 2067.00 Epsilon = 0.493
# resultado da epoca 257 = 1192.50 Epsilon = 0.491
# resultado da epoca 258 = 1630.50 Epsilon = 0.489
# resultado da epoca 259 = 4271.00 Epsilon = 0.487
# resultado da epoca 260 = 335.50 Epsilon = 0.485
# resultado da epoca 261 = -134.00 Epsilon = 0.483
# resultado da epoca 262 = -143.50 Epsilon = 0.481
# resultado da epoca 263 = 1842.00 Epsilon = 0.479
# resultado da epoca 264 = -406.50 Epsilon = 0.477
# resultado da epoca 265 = 2279.00 Epsilon = 0.475
# resultado da epoca 266 = -869.50 Epsilon = 0.473
# resultado da epoca 267 = 1457.50 Epsilon = 0.471
# resultado da epoca 268 = 1432.00 Epsilon = 0.469
# resultado da epoca 269 = 2449.50 Epsilon = 0.467
# resultado da epoca 270 = 1205.00 Epsilon = 0.465
# resultado da epoca 271 = 2367.00 Epsilon = 0.463
# resultado da epoca 272 = 1205.00 Epsilon = 0.461
# resultado da epoca 273 = 957.00 Epsilon = 0.459
# resultado da epoca 274 = -26.50 Epsilon = 0.457
# resultado da epoca 275 = 465.50 Epsilon = 0.456
# resultado da epoca 276 = 2568.00 Epsilon = 0.454
# resultado da epoca 277 = -905.50 Epsilon = 0.452
# resultado da epoca 278 = 3612.50 Epsilon = 0.450
# resultado da epoca 279 = 998.50 Epsilon = 0.448
# resultado da epoca 280 = 101.00 Epsilon = 0.446
# resultado da epoca 281 = 421.00 Epsilon = 0.444
# resultado da epoca 282 = 745.50 Epsilon = 0.442
# resultado da epoca 283 = 1641.50 Epsilon = 0.440
# resultado da epoca 284 = 1213.50 Epsilon = 0.438
# resultado da epoca 285 = 2254.00 Epsilon = 0.436
# resultado da epoca 286 = 546.50 Epsilon = 0.434
# resultado da epoca 287 = -172.50 Epsilon = 0.432
# resultado da epoca 288 = 1224.50 Epsilon = 0.430
# resultado da epoca 289 = 4278.00 Epsilon = 0.428
# resultado da epoca 290 = 4971.00 Epsilon = 0.426
# resultado da epoca 291 = 2150.00 Epsilon = 0.424
# resultado da epoca 292 = 2599.00 Epsilon = 0.422
# resultado da epoca 293 = 3083.00 Epsilon = 0.420
# resultado da epoca 294 = -698.50 Epsilon = 0.418
# resultado da epoca 295 = -1988.00 Epsilon = 0.416
# resultado da epoca 296 = 237.00 Epsilon = 0.414
# resultado da epoca 297 = -1755.00 Epsilon = 0.412
# resultado da epoca 298 = 1019.50 Epsilon = 0.410
# resultado da epoca 299 = 1271.50 Epsilon = 0.408
# resultado da epoca 300 = 882.50 Epsilon = 0.406
# resultado da epoca 301 = -566.00 Epsilon = 0.404
# resultado da epoca 302 = -945.00 Epsilon = 0.402
# resultado da epoca 303 = 2360.50 Epsilon = 0.400
# resultado da epoca 304 = -212.50 Epsilon = 0.398
# resultado da epoca 305 = 803.50 Epsilon = 0.396
# resultado da epoca 306 = -1110.50 Epsilon = 0.394
# resultado da epoca 307 = 2570.00 Epsilon = 0.392
# resultado da epoca 308 = 3101.50 Epsilon = 0.390
# resultado da epoca 309 = 2500.50 Epsilon = 0.388
# resultado da epoca 310 = 1022.50 Epsilon = 0.386
# resultado da epoca 311 = -749.00 Epsilon = 0.384
# resultado da epoca 312 = 1499.00 Epsilon = 0.382
# resultado da epoca 313 = 5113.50 Epsilon = 0.380
# resultado da epoca 314 = 866.00 Epsilon = 0.378
# resultado da epoca 315 = 2416.00 Epsilon = 0.376
# resultado da epoca 316 = -1036.00 Epsilon = 0.374
# resultado da epoca 317 = -977.00 Epsilon = 0.372
# resultado da epoca 318 = 366.00 Epsilon = 0.370
# resultado da epoca 319 = 1988.50 Epsilon = 0.368
# resultado da epoca 320 = -960.00 Epsilon = 0.366
# resultado da epoca 321 = 436.00 Epsilon = 0.364
# resultado da epoca 322 = 525.50 Epsilon = 0.362
# resultado da epoca 323 = 1544.50 Epsilon = 0.360
# resultado da epoca 324 = 1840.50 Epsilon = 0.358
# resultado da epoca 325 = -978.00 Epsilon = 0.357
# resultado da epoca 326 = 1992.50 Epsilon = 0.355
# resultado da epoca 327 = 790.50 Epsilon = 0.353
# resultado da epoca 328 = -1077.50 Epsilon = 0.351
# resultado da epoca 329 = 2231.00 Epsilon = 0.349
# resultado da epoca 330 = 1803.50 Epsilon = 0.347
# resultado da epoca 331 = 555.00 Epsilon = 0.345
# resultado da epoca 332 = -1543.50 Epsilon = 0.343
# resultado da epoca 333 = -211.00 Epsilon = 0.341
# resultado da epoca 334 = 3076.50 Epsilon = 0.339
# resultado da epoca 335 = -83.50 Epsilon = 0.337
# resultado da epoca 336 = -3351.00 Epsilon = 0.335
# resultado da epoca 337 = 4208.00 Epsilon = 0.333
# resultado da epoca 338 = -1823.00 Epsilon = 0.331
# resultado da epoca 339 = 159.50 Epsilon = 0.329
# resultado da epoca 340 = -2149.00 Epsilon = 0.327
# resultado da epoca 341 = -825.50 Epsilon = 0.325
# resultado da epoca 342 = 848.00 Epsilon = 0.323
# resultado da epoca 343 = 226.00 Epsilon = 0.321
# resultado da epoca 344 = -2084.00 Epsilon = 0.319
# resultado da epoca 345 = 2093.50 Epsilon = 0.317
# resultado da epoca 346 = -3338.50 Epsilon = 0.315
# resultado da epoca 347 = 862.00 Epsilon = 0.313
# resultado da epoca 348 = 2674.00 Epsilon = 0.311
# resultado da epoca 349 = -835.50 Epsilon = 0.309
# resultado da epoca 350 = -71.00 Epsilon = 0.307
# resultado da epoca 351 = 148.50 Epsilon = 0.305
# resultado da epoca 352 = 245.50 Epsilon = 0.303
# resultado da epoca 353 = -1450.50 Epsilon = 0.301
# resultado da epoca 354 = 2611.50 Epsilon = 0.299
# resultado da epoca 355 = -3002.00 Epsilon = 0.297
# resultado da epoca 356 = 2734.50 Epsilon = 0.295
# resultado da epoca 357 = -60.50 Epsilon = 0.293
# resultado da epoca 358 = 894.50 Epsilon = 0.291
# resultado da epoca 359 = -4912.50 Epsilon = 0.289
# resultado da epoca 360 = 1618.00 Epsilon = 0.287
# resultado da epoca 361 = -354.00 Epsilon = 0.285
# resultado da epoca 362 = -1310.00 Epsilon = 0.283
# resultado da epoca 363 = 247.00 Epsilon = 0.281
# resultado da epoca 364 = 1010.50 Epsilon = 0.279
# resultado da epoca 365 = 614.00 Epsilon = 0.277
# resultado da epoca 366 = -3560.50 Epsilon = 0.275
# resultado da epoca 367 = -1591.50 Epsilon = 0.273
# resultado da epoca 368 = 569.00 Epsilon = 0.271
# resultado da epoca 369 = -1025.00 Epsilon = 0.269
# resultado da epoca 370 = 2383.00 Epsilon = 0.267
# resultado da epoca 371 = 2931.00 Epsilon = 0.265
# resultado da epoca 372 = 732.50 Epsilon = 0.263
# resultado da epoca 373 = 2637.00 Epsilon = 0.261
# resultado da epoca 374 = -1934.50 Epsilon = 0.259
# resultado da epoca 375 = -3375.50 Epsilon = 0.258
# resultado da epoca 376 = 181.50 Epsilon = 0.256
# resultado da epoca 377 = -1191.50 Epsilon = 0.254
# resultado da epoca 378 = -1609.00 Epsilon = 0.252
# resultado da epoca 379 = -704.00 Epsilon = 0.250
# resultado da epoca 380 = -652.00 Epsilon = 0.248
# resultado da epoca 381 = -2008.50 Epsilon = 0.246
# resultado da epoca 382 = -1291.50 Epsilon = 0.244
# resultado da epoca 383 = -1901.00 Epsilon = 0.242
# resultado da epoca 384 = -3030.00 Epsilon = 0.240
# resultado da epoca 385 = -633.00 Epsilon = 0.238
# resultado da epoca 386 = -2018.50 Epsilon = 0.236
# resultado da epoca 387 = -1471.50 Epsilon = 0.234
# resultado da epoca 388 = 1025.50 Epsilon = 0.232
# resultado da epoca 389 = -2903.00 Epsilon = 0.230
# resultado da epoca 390 = -1072.50 Epsilon = 0.228
# resultado da epoca 391 = 1010.00 Epsilon = 0.226
# resultado da epoca 392 = -1709.00 Epsilon = 0.224
# resultado da epoca 393 = -1974.50 Epsilon = 0.222
# resultado da epoca 394 = 1094.50 Epsilon = 0.220
# resultado da epoca 395 = 1634.50 Epsilon = 0.218
# resultado da epoca 396 = -2659.00 Epsilon = 0.216
# resultado da epoca 397 = -186.00 Epsilon = 0.214
# resultado da epoca 398 = 404.50 Epsilon = 0.212
# resultado da epoca 399 = -1318.00 Epsilon = 0.210
# resultado da epoca 400 = -154.50 Epsilon = 0.208
# resultado da epoca 401 = -2590.50 Epsilon = 0.206
# resultado da epoca 402 = -2065.50 Epsilon = 0.204
# resultado da epoca 403 = 633.00 Epsilon = 0.202
# resultado da epoca 404 = -5130.00 Epsilon = 0.200
# resultado da epoca 405 = -2872.00 Epsilon = 0.198
# resultado da epoca 406 = 62.50 Epsilon = 0.196
# resultado da epoca 407 = -2098.00 Epsilon = 0.194
# resultado da epoca 408 = -953.50 Epsilon = 0.192
# resultado da epoca 409 = 1147.50 Epsilon = 0.190
# resultado da epoca 410 = 878.50 Epsilon = 0.188
# resultado da epoca 411 = -3266.50 Epsilon = 0.186
# resultado da epoca 412 = 783.00 Epsilon = 0.184
# resultado da epoca 413 = -1169.00 Epsilon = 0.182
# resultado da epoca 414 = -604.00 Epsilon = 0.180
# resultado da epoca 415 = -3032.00 Epsilon = 0.178
# resultado da epoca 416 = -749.00 Epsilon = 0.176
# resultado da epoca 417 = -969.50 Epsilon = 0.174
# resultado da epoca 418 = -2941.50 Epsilon = 0.172
# resultado da epoca 419 = 796.00 Epsilon = 0.170
# resultado da epoca 420 = -1512.50 Epsilon = 0.168
# resultado da epoca 421 = -1536.50 Epsilon = 0.166
# resultado da epoca 422 = -1657.00 Epsilon = 0.164
# resultado da epoca 423 = -229.50 Epsilon = 0.162
# resultado da epoca 424 = -306.00 Epsilon = 0.160
# resultado da epoca 425 = -332.50 Epsilon = 0.159
# resultado da epoca 426 = 263.50 Epsilon = 0.157
# resultado da epoca 427 = -5031.50 Epsilon = 0.155
# resultado da epoca 428 = -1508.00 Epsilon = 0.153
# resultado da epoca 429 = 492.00 Epsilon = 0.151
# resultado da epoca 430 = -238.00 Epsilon = 0.149
# resultado da epoca 431 = -3398.50 Epsilon = 0.147
# resultado da epoca 432 = -69.50 Epsilon = 0.145
# resultado da epoca 433 = -383.50 Epsilon = 0.143
# resultado da epoca 434 = -3085.00 Epsilon = 0.141
# resultado da epoca 435 = -2827.50 Epsilon = 0.139
# resultado da epoca 436 = -366.00 Epsilon = 0.137
# resultado da epoca 437 = -2095.50 Epsilon = 0.135
# resultado da epoca 438 = -2459.00 Epsilon = 0.133
# resultado da epoca 439 = -4452.00 Epsilon = 0.131
# resultado da epoca 440 = -1779.00 Epsilon = 0.129
# resultado da epoca 441 = -2337.50 Epsilon = 0.127
# resultado da epoca 442 = -892.50 Epsilon = 0.125
# resultado da epoca 443 = -2561.50 Epsilon = 0.123
# resultado da epoca 444 = -484.00 Epsilon = 0.121
# resultado da epoca 445 = 860.50 Epsilon = 0.119
# resultado da epoca 446 = 503.00 Epsilon = 0.117
# resultado da epoca 447 = -1819.50 Epsilon = 0.115
# resultado da epoca 448 = -1518.00 Epsilon = 0.113
# resultado da epoca 449 = -208.50 Epsilon = 0.111
# resultado da epoca 450 = -1212.00 Epsilon = 0.109
# resultado da epoca 451 = -245.00 Epsilon = 0.107
# resultado da epoca 452 = 1171.00 Epsilon = 0.105
# resultado da epoca 453 = -461.00 Epsilon = 0.103
# resultado da epoca 454 = -792.50 Epsilon = 0.101
# resultado da epoca 455 = 499.50 Epsilon = 0.099
# resultado da epoca 456 = -1342.50 Epsilon = 0.097
# resultado da epoca 457 = -1238.00 Epsilon = 0.095
# resultado da epoca 458 = -448.00 Epsilon = 0.093
# resultado da epoca 459 = -881.50 Epsilon = 0.091
# resultado da epoca 460 = -2549.00 Epsilon = 0.089
# resultado da epoca 461 = 405.00 Epsilon = 0.087
# resultado da epoca 462 = -1401.50 Epsilon = 0.085
# resultado da epoca 463 = 532.00 Epsilon = 0.083
# resultado da epoca 464 = 2683.00 Epsilon = 0.081
# resultado da epoca 465 = 718.50 Epsilon = 0.079
# resultado da epoca 466 = 818.00 Epsilon = 0.077
# resultado da epoca 467 = 1087.50 Epsilon = 0.075
# resultado da epoca 468 = 1214.50 Epsilon = 0.073
# resultado da epoca 469 = -460.50 Epsilon = 0.071
# resultado da epoca 470 = 198.00 Epsilon = 0.069
# resultado da epoca 471 = -508.50 Epsilon = 0.067
# resultado da epoca 472 = -447.50 Epsilon = 0.065
# resultado da epoca 473 = -62.50 Epsilon = 0.063
# resultado da epoca 474 = 37.00 Epsilon = 0.061
# resultado da epoca 475 = -1266.00 Epsilon = 0.060
# resultado da epoca 476 = 232.50 Epsilon = 0.058
# resultado da epoca 477 = -720.00 Epsilon = 0.056
# resultado da epoca 478 = 578.50 Epsilon = 0.054
# resultado da epoca 479 = -1548.50 Epsilon = 0.052
# resultado da epoca 480 = -657.50 Epsilon = 0.050
# resultado da epoca 481 = -312.50 Epsilon = 0.048
# resultado da epoca 482 = 1237.00 Epsilon = 0.046
# resultado da epoca 483 = 1387.00 Epsilon = 0.044
# resultado da epoca 484 = 558.00 Epsilon = 0.042
# resultado da epoca 485 = 1566.50 Epsilon = 0.040
# resultado da epoca 486 = -188.00 Epsilon = 0.038
# resultado da epoca 487 = -1084.50 Epsilon = 0.036
# resultado da epoca 488 = -1141.00 Epsilon = 0.034
# resultado da epoca 489 = 1575.50 Epsilon = 0.032
# resultado da epoca 490 = 1402.00 Epsilon = 0.030
# resultado da epoca 491 = -397.50 Epsilon = 0.028
# resultado da epoca 492 = 994.50 Epsilon = 0.026
# resultado da epoca 493 = 778.00 Epsilon = 0.024
# resultado da epoca 494 = 2382.00 Epsilon = 0.022
# resultado da epoca 495 = 3181.50 Epsilon = 0.020
# resultado da epoca 496 = 3449.00 Epsilon = 0.018
# resultado da epoca 497 = 3267.00 Epsilon = 0.016
# resultado da epoca 498 = 2959.50 Epsilon = 0.014
# resultado da epoca 499 = 2147.50 Epsilon = 0.012
# Melhor resultado diario: 802.50

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo, 0, dias))
# Out:
# 3344.5

# %%
modelo.epsilon = 0
rodar_dias(inputs, custo, dias, 10)
# Out:
# -1096.5

# %%
plt.plot(range(0,len(inputs)), inputs['preco'])

# %%
plt.plot(range(0,len(inputs_nao_norm)), inputs_nao_norm['preco'])

# %%
np.amin(inputs['preco'])
# Out:
# -275.7738953247049

# %%
pmean
# Out:
# 3859.773895324705

# %%
(4200-pmean)/pstd
# Out:
# 2.784507614194732

# %%
np.std(inputs_nao_norm['preco'])
# Out:
# 130.87810760032863
