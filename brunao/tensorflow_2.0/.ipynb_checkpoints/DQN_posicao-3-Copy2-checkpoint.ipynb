# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco']#, 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
n_saidas = 3 #nmero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0
lim_cont = 10
posicao_max = 100*lim_cont #define variavel para normalizar a posicao

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]
pmax = np.amax( inputs.loc[:, inputs.columns[0]] ) #define valor minimo do preo
pmin = np.amin( inputs.loc[:, inputs.columns[0]] ) #define valor maximo do preo

for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imax = np.amax( inputs.loc[:, inputs.columns[i]] ) #pega valor maximo
    imin = np.amin( inputs.loc[:, inputs.columns[i]] ) #pega valor minimo
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imin ) / ( imax - imin ) #normaliza prs

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = 105
#hr = hr/step_max
#inputs['hr_int'] = hr


dias = len(steps)
dias = 220
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K            #importa backend para clear_session()

##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-7
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(192, activation='relu')) #camada escondida
        model.add(Dense(128, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        
        return model

    def limpa_memoria(self):
        self.state = np.empty((0,))
        self.next_state = np.empty((0,))
        self.memory = []
        
    def toma_acao(self, valores_ant, teste):
        if not teste and np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora        
        act_values = self.model.predict(estado, batch_size=1) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=step_max):
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in self.memory:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado, batch_size=batch_size)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado, batch_size=batch_size) #pega valor que chegou
            target_f[0][acao] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0, batch_size=batch_size) #treina modelo
        
    def tira_ultimo_state(self):
        if self.state.shape[0] > self.janela * self.n_variaveis:
            self.state = self.state[self.n_variaveis:] #tira os ultimos preos
        if self.next_state.shape[0] > self.janela * self.n_variaveis:
            self.next_state = self.next_state[self.n_variaveis:] #tira os ultimos preos
    
    def remember(self, acao, reward, valores_ant, valores_dps, done):
        prox_estado = np.array([np.append(self.next_state, valores_dps)]) #cria proximo estado
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora
        self.memory.append((acao, reward, estado, prox_estado, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               3584
# _________________________________________________________________
# dense_2 (Dense)              (None, 192)               49344
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 78,019
# Trainable params: 78,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    r = 0.
        
    if acao != 0:
        if (acao*ncont_anterior) < 0:    #realizacao (lucro ou prejuizo)
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
            preco_cheio = ( preco * ( pmax - pmin ) + pmin )
            r = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
        else:
            r = -custo*abs(acao)                                       #reward = -custo*acao se houve operacao
        
        if valor!=0: 
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
        if abs(ncont) > 0:
            valor = (ncont_anterior*valor + acao*preco)/ncont     
        else:
            valor = 0
            
    if valor!=0: valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valor posicionado atual
            
    dp = ( preco * ( pmax - pmin ) + pmin ) - valor_cheio #variacao do preco atual e do preco de compra/venda
    posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (INSTANTNEO)
    
    return ncont, valor, posicao, ncont_anterior, r

def obter_acao(ncont, valores_ant):
    decisao = modelo.toma_acao(valores_ant, False) #calcula a saida da rede neural
    
    if decisao == 0: #comprar
        if ncont < lim_cont: #s compra se no tem nada ainda
            return 1
    elif decisao == 1: #vender
        if ncont > -lim_cont: #só vende se tiver alguma coisa
            return -1
    return 0 #neutro

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = 0 #cria variavel para preo medio
    reward = 0 #cria variavel para recompensa
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria() #limpa o vetor de memoria
    done = False
    modelo.state = np.zeros(n_variaveis*janela)
    modelo.next_state = np.zeros(n_variaveis*janela)
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.state = np.append( modelo.state, ultimos_precos ) #adiciona na variavel de estado
        
        modelo.tira_ultimo_state()
        valores_ant = [ncont / lim_cont, valor, posicao/posicao_max] #grava os valores de antes - estado

        acao = obter_acao( ncont, valores_ant ) #obtem acao
        ncont, valor, posicao, ncont_anterior, r = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        reward += r
        #print (hr[step]*step_max, acao)
        #print("acao: {0} reward: {1} step: {2}".format(acao, reward, hr[step]*step_max))
            
        prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
        modelo.next_state = np.append(modelo.next_state, prox_precos) #adiciona variavel na variavel de proximo estado
        modelo.tira_ultimo_state()
        valores_dps = [ncont / lim_cont, valor, posicao/posicao_max] #grava os valores de depois
        
        if step == (steps[dia] - 1):
            done = True
        else:
            modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    
    reward += posicao #soma reward - DAY-TRADE (obs: custo nao havia sido considerado no reward pq acao era 0)
    
    modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    
    modelo.treina_modelo() #roda o modelo com toda a memoria do dia
           
    if reward > melhor_reward:
        melhor_reward = reward
    return reward #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        #print("dia {0} de {1}: R$ {2:0.2f}".format(dia, dias, reward)) #mostra o resultado do dia
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    #modelo.epsilon = 0.1
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            #s=time.time()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f}".format(epoca, sum_rewards))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0
            #e=time.time()
            #print(e-s)
            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
        print("Somatoria dos rewards: {0:0.2f}".format(sum_rewards_total))
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1022 11:17:27.049630  9644 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1022 11:17:27.342647  9644 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1022 11:17:27.366648  9644 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = 2430.57
# 110
# 109
# resultado da epoca 1 = -45174.54
# 107
# 112
# resultado da epoca 2 = -146476.61
# 89
# 130
# resultado da epoca 3 = -91692.09
# 108
# 111
# resultado da epoca 4 = -87206.26
# 107
# 112
# resultado da epoca 5 = 105433.13
# 114
# 105
# resultado da epoca 6 = 20055.50
# 115
# 104
# resultado da epoca 7 = -43458.93
# 110
# 109
# resultado da epoca 8 = -64419.80
# 120
# 99
# resultado da epoca 9 = 24813.88
# 109
# 110
# resultado da epoca 10 = -145921.63
# 94
# 125
# resultado da epoca 11 = 56932.10
# 106
# 113
# resultado da epoca 12 = -18712.45
# 104
# 115
# resultado da epoca 13 = 15428.73
# 111
# 108
# resultado da epoca 14 = -16442.30
# 105
# 114
# resultado da epoca 15 = -63504.10
# 105
# 114
# resultado da epoca 16 = -12254.17
# 118
# 101
# resultado da epoca 17 = -71928.34
# 90
# 129
# resultado da epoca 18 = 46435.10
# 118
# 101
# resultado da epoca 19 = -22513.65
# 106
# 113
# resultado da epoca 20 = -25286.44
# 115
# 104
# resultado da epoca 21 = -3390.94
# 110
# 109
# resultado da epoca 22 = 53419.94
# 112
# 107
# resultado da epoca 23 = 19078.30
# 102
# 117
# resultado da epoca 24 = 42229.69
# 113
# 106
# resultado da epoca 25 = 75954.76
# 116
# 103
# resultado da epoca 26 = -86551.44
# 105
# 114
# resultado da epoca 27 = 44700.71
# 109
# 110
# resultado da epoca 28 = -35756.55
# 109
# 110
# resultado da epoca 29 = 69197.27
# 115
# 104
# resultado da epoca 30 = -76976.78
# 102
# 117
# resultado da epoca 31 = -41915.50
# 110
# 109
# resultado da epoca 32 = -136633.17
# 113
# 106
# resultado da epoca 33 = 146539.10
# 117
# 102
# resultado da epoca 34 = 22744.78
# 115
# 104
# resultado da epoca 35 = -48380.12
# 103
# 116
# resultado da epoca 36 = -51489.23
# 108
# 111
# resultado da epoca 37 = 2848.14
# 106
# 113
# resultado da epoca 38 = 170374.69
# 123
# 96
# resultado da epoca 39 = 5020.27
# 107
# 112
# resultado da epoca 40 = 66202.92
# 110
# 109
# resultado da epoca 41 = -127963.71
# 97
# 122
# resultado da epoca 42 = 24773.33
# 108
# 111
# resultado da epoca 43 = -117032.47
# 101
# 118
# resultado da epoca 44 = -39941.59
# 103
# 116
# resultado da epoca 45 = -109944.46
# 108
# 111
# resultado da epoca 46 = -43842.52
# 112
# 107
# resultado da epoca 47 = 97299.80
# 112
# 107
# resultado da epoca 48 = 1061.12
# 108
# 111
# resultado da epoca 49 = 47674.93
# 116
# 103
# resultado da epoca 50 = -51410.13
# 103
# 116
# resultado da epoca 51 = -92361.22
# 100
# 119
# resultado da epoca 52 = -14800.62
# 99
# 120
# resultado da epoca 53 = -99282.02
# 105
# 114
# resultado da epoca 54 = -96717.98
# 95
# 124
# resultado da epoca 55 = -151199.53
# 96
# 123
# resultado da epoca 56 = -84839.91
# 110
# 109
# resultado da epoca 57 = 20576.06
# 117
# 102
# resultado da epoca 58 = -73377.06
# 100
# 119
# resultado da epoca 59 = -229857.96
# 93
# 126
# resultado da epoca 60 = 153416.07
# 122
# 97
# resultado da epoca 61 = -44787.71
# 104
# 115
# resultado da epoca 62 = -46325.45
# 107
# 112
# resultado da epoca 63 = -38980.51
# 110
# 109
# resultado da epoca 64 = 20869.53
# 105
# 114
# resultado da epoca 65 = 85194.26
# 113
# 106
# resultado da epoca 66 = -76065.62
# 106
# 113
# resultado da epoca 67 = -129384.59
# 95
# 124
# resultado da epoca 68 = -34132.57
# 106
# 113
# resultado da epoca 69 = 17484.50
# 108
# 111
# resultado da epoca 70 = -68845.94
# 107
# 112
# resultado da epoca 71 = -118267.54
# 104
# 115
# resultado da epoca 72 = -38434.19
# 113
# 106
# resultado da epoca 73 = -9402.66
# 115
# 104
# resultado da epoca 74 = 50169.57
# 108
# 111
# resultado da epoca 75 = -17461.46
# 120
# 99
# resultado da epoca 76 = -72892.78
# 115
# 104
# resultado da epoca 77 = 23079.20
# 115
# 104
# resultado da epoca 78 = -1078.47
# 118
# 101
# resultado da epoca 79 = -32481.44
# 114
# 105
# resultado da epoca 80 = -79718.86
# 102
# 117
# resultado da epoca 81 = 12216.20
# 107
# 112
# resultado da epoca 82 = 92497.15
# 116
# 103
# resultado da epoca 83 = -50701.92
# 102
# 117
# resultado da epoca 84 = 186079.96
# 129
# 90
# resultado da epoca 85 = -25042.65
# 114
# 105
# resultado da epoca 86 = -122058.68
# 110
# 109
# resultado da epoca 87 = -40490.14
# 102
# 117
# resultado da epoca 88 = -35927.11
# 106
# 113
# resultado da epoca 89 = -121711.11
# 101
# 118
# resultado da epoca 90 = -137491.64
# 103
# 116
# resultado da epoca 91 = -689.95
# 118
# 101
# resultado da epoca 92 = -102544.12
# 112
# 107
# resultado da epoca 93 = -51251.15
# 99
# 120
# resultado da epoca 94 = -66398.01
# 101
# 118
# resultado da epoca 95 = -101413.82
# 103
# 116
# resultado da epoca 96 = 39542.40
# 110
# 109
# resultado da epoca 97 = 24902.69
# 119
# 100
# resultado da epoca 98 = -83351.08
# 112
# 107
# resultado da epoca 99 = -9570.27
# 115
# 104
# resultado da epoca 100 = 69085.83
# 108
# 111
# resultado da epoca 101 = -11920.88
# 104
# 115
# resultado da epoca 102 = 54540.04
# 122
# 97
# resultado da epoca 103 = -74669.34
# 111
# 108
# resultado da epoca 104 = -97660.54
# 103
# 116
# resultado da epoca 105 = -95483.81
# 105
# 114
# resultado da epoca 106 = 16529.58
# 110
# 109
# resultado da epoca 107 = 111581.44
# 118
# 101
# resultado da epoca 108 = -33164.19
# 102
# 117
# resultado da epoca 109 = 113689.25
# 113
# 106
# resultado da epoca 110 = 59978.89
# 111
# 108
# resultado da epoca 111 = 92890.83
# 112
# 107
# resultado da epoca 112 = -138244.17
# 109
# 110
# resultado da epoca 113 = -64555.91
# 110
# 109
# resultado da epoca 114 = 40893.08
# 106
# 113
# resultado da epoca 115 = -31078.70
# 110
# 109
# resultado da epoca 116 = 28406.38
# 114
# 105
# resultado da epoca 117 = -24690.35
# 101
# 118
# resultado da epoca 118 = -144891.61
# 92
# 127
# resultado da epoca 119 = 51350.92
# 110
# 109
# resultado da epoca 120 = 107736.19
# 108
# 111
# resultado da epoca 121 = 45571.44
# 114
# 105
# resultado da epoca 122 = -75198.76
# 115
# 104
# resultado da epoca 123 = 21314.14
# 114
# 105
# resultado da epoca 124 = 14633.76
# 111
# 108
# resultado da epoca 125 = 17536.55
# 112
# 107
# resultado da epoca 126 = 75441.93
# 107
# 112
# resultado da epoca 127 = 8399.69
# 110
# 109
# resultado da epoca 128 = -63232.64
# 107
# 112
# resultado da epoca 129 = -18044.58
# 105
# 114
# resultado da epoca 130 = 44793.67
# 114
# 105
# resultado da epoca 131 = 38827.39
# 113
# 106
# resultado da epoca 132 = -149136.07
# 92
# 127
# resultado da epoca 133 = 38035.71
# 108
# 111
# resultado da epoca 134 = -66939.27
# 100
# 119
# resultado da epoca 135 = 118627.43
# 123
# 96
# resultado da epoca 136 = -29507.14
# 104
# 115
# resultado da epoca 137 = -32508.20
# 105
# 114
# resultado da epoca 138 = -53551.42
# 113
# 106
# resultado da epoca 139 = -90700.77
# 97
# 122
# resultado da epoca 140 = -24276.86
# 112
# 107
# resultado da epoca 141 = 135236.88
# 120
# 99
# resultado da epoca 142 = 66710.81
# 111
# 108
# resultado da epoca 143 = 6359.88
# 112
# 107
# resultado da epoca 144 = -28069.40
# 109
# 110
# resultado da epoca 145 = -63984.94
# 104
# 115
# resultado da epoca 146 = -42108.19
# 114
# 105
# resultado da epoca 147 = -21023.04
# 102
# 117
# resultado da epoca 148 = 94759.35
# 110
# 109
# resultado da epoca 149 = 55695.76
# 112
# 107
# resultado da epoca 150 = -150049.20
# 105
# 114
# resultado da epoca 151 = -30788.90
# 109
# 110
# resultado da epoca 152 = -2609.94
# 106
# 113
# resultado da epoca 153 = -100122.97
# 108
# 111
# resultado da epoca 154 = 22133.91
# 107
# 112
# resultado da epoca 155 = -46173.39
# 112
# 107
# resultado da epoca 156 = -33204.68
# 111
# 108
# resultado da epoca 157 = -105596.08
# 103
# 116
# resultado da epoca 158 = 4400.92
# 117
# 102
# resultado da epoca 159 = 65653.66
# 104
# 115
# resultado da epoca 160 = 168.65
# 115
# 104
# resultado da epoca 161 = -1246.99
# 109
# 110
# resultado da epoca 162 = -118392.15
# 102
# 117
# resultado da epoca 163 = -25612.65
# 104
# 115
# resultado da epoca 164 = -72487.99
# 113
# 106
# resultado da epoca 165 = 100605.20
# 116
# 103
# resultado da epoca 166 = -11368.84
# 105
# 114
# resultado da epoca 167 = -32266.12
# 116
# 103
# resultado da epoca 168 = -22662.02
# 108
# 111
# resultado da epoca 169 = -5657.55
# 109
# 110
# resultado da epoca 170 = -76932.90
# 108
# 111
# resultado da epoca 171 = -68632.19
# 102
# 117
# resultado da epoca 172 = -9874.73
# 113
# 106
# resultado da epoca 173 = -44947.05
# 111
# 108
# resultado da epoca 174 = -90014.25
# 101
# 118
# resultado da epoca 175 = -8042.95
# 110
# 109
# resultado da epoca 176 = -53609.84
# 101
# 118
# resultado da epoca 177 = 9276.54
# 112
# 107
# resultado da epoca 178 = -34915.93
# 104
# 115
# resultado da epoca 179 = -65514.65
# 101
# 118
# resultado da epoca 180 = -99590.23
# 103
# 116
# resultado da epoca 181 = -7583.27
# 110
# 109
# resultado da epoca 182 = -18117.98
# 100
# 119
# resultado da epoca 183 = -35139.27
# 113
# 106
# resultado da epoca 184 = 57685.15
# 115
# 104
# resultado da epoca 185 = -13271.56
# 107
# 112
# resultado da epoca 186 = 72589.24
# 111
# 108
# resultado da epoca 187 = 12918.94
# 113
# 106
# resultado da epoca 188 = -22796.47
# 106
# 113
# resultado da epoca 189 = -108116.51
# 99
# 120
# resultado da epoca 190 = -117005.34
# 102
# 117
# resultado da epoca 191 = -19169.16
# 100
# 119
# resultado da epoca 192 = -60146.49
# 110
# 109
# resultado da epoca 193 = 67330.84
# 108
# 111
# resultado da epoca 194 = -50346.34
# 103
# 116
# resultado da epoca 195 = -86402.66
# 105
# 114
# resultado da epoca 196 = -56366.00
# 106
# 113
# resultado da epoca 197 = 52802.62
# 117
# 102
# resultado da epoca 198 = 31358.85
# 113
# 106
# resultado da epoca 199 = 162325.55
# 127
# 92
# resultado da epoca 200 = -60814.28
# 107
# 112
# resultado da epoca 201 = -30592.66
# 110
# 109
# resultado da epoca 202 = -4615.65
# 101
# 118
# resultado da epoca 203 = 25726.37
# 112
# 107
# resultado da epoca 204 = -44260.97
# 104
# 115
# resultado da epoca 205 = -14352.59
# 108
# 111
# resultado da epoca 206 = 6282.00
# 100
# 119
# resultado da epoca 207 = 54072.92
# 112
# 107
# resultado da epoca 208 = 63901.31
# 116
# 103
# resultado da epoca 209 = 54912.84
# 108
# 111
# resultado da epoca 210 = -29813.08
# 108
# 111
# resultado da epoca 211 = 61279.33
# 108
# 111
# resultado da epoca 212 = 123548.40
# 120
# 99
# resultado da epoca 213 = -104201.01
# 105
# 114
# resultado da epoca 214 = -9340.56
# 106
# 113
# resultado da epoca 215 = -35051.63
# 103
# 116
# resultado da epoca 216 = -47938.84
# 106
# 113
# resultado da epoca 217 = 31250.60
# 108
# 111
# resultado da epoca 218 = -14632.45
# 106
# 113
# resultado da epoca 219 = 22641.12
# 105
# 114
# resultado da epoca 220 = -10656.81
# 107
# 112
# resultado da epoca 221 = -1130.88
# 111
# 108
# resultado da epoca 222 = -43790.77
# 103
# 116
# resultado da epoca 223 = -50593.84
# 105
# 114
# resultado da epoca 224 = -53128.47
# 114
# 105
# resultado da epoca 225 = -88555.19
# 104
# 115
# resultado da epoca 226 = -53418.36
# 111
# 108
# resultado da epoca 227 = -52001.99
# 105
# 114
# resultado da epoca 228 = 58807.77
# 111
# 108
# resultado da epoca 229 = 78417.65
# 116
# 103
# resultado da epoca 230 = 41870.89
# 114
# 105
# resultado da epoca 231 = 11953.07
# 108
# 111
# resultado da epoca 232 = 53166.63
# 105
# 114
# resultado da epoca 233 = -169714.90
# 106
# 113
# resultado da epoca 234 = -53236.73
# 104
# 115
# resultado da epoca 235 = -68817.06
# 104
# 115
# resultado da epoca 236 = 45248.98
# 112
# 107
# resultado da epoca 237 = -49419.06
# 103
# 116
# resultado da epoca 238 = 2372.84
# 107
# 112
# resultado da epoca 239 = -80470.39
# 111
# 108
# resultado da epoca 240 = 75414.63
# 108
# 111
# resultado da epoca 241 = 6380.46
# 107
# 112
# resultado da epoca 242 = -116190.49
# 112
# 107
# resultado da epoca 243 = 8903.29
# 111
# 108
# resultado da epoca 244 = -29420.09
# 111
# 108
# resultado da epoca 245 = 62073.69
# 117
# 102
# resultado da epoca 246 = -24922.86
# 106
# 113
# resultado da epoca 247 = -22273.66
# 105
# 114
# resultado da epoca 248 = 38775.03
# 110
# 109
# resultado da epoca 249 = -17235.84
# 104
# 115
# resultado da epoca 250 = 11906.72
# 117
# 102
# resultado da epoca 251 = 40933.29
# 110
# 109
# resultado da epoca 252 = -44196.27
# 118
# 101
# resultado da epoca 253 = -9033.67
# 112
# 107
# resultado da epoca 254 = 3035.10
# 116
# 103
# resultado da epoca 255 = 34436.27
# 108
# 111
# resultado da epoca 256 = 33554.76
# 109
# 110
# resultado da epoca 257 = -80009.73
# 106
# 113
# resultado da epoca 258 = 18548.65
# 118
# 101
# resultado da epoca 259 = 32485.11
# 114
# 105
# resultado da epoca 260 = 39953.46
# 110
# 109
# resultado da epoca 261 = 78904.05
# 121
# 98
# resultado da epoca 262 = -18048.70
# 116
# 103
# resultado da epoca 263 = -44436.45
# 107
# 112
# resultado da epoca 264 = 53599.42
# 108
# 111
# resultado da epoca 265 = 53140.04
# 106
# 113
# resultado da epoca 266 = 32305.25
# 111
# 108
# resultado da epoca 267 = -48495.74
# 101
# 118
# resultado da epoca 268 = 28468.87
# 110
# 109
# resultado da epoca 269 = 23752.31
# 104
# 115
# resultado da epoca 270 = -47368.89
# 108
# 111
# resultado da epoca 271 = 23565.23
# 116
# 103
# resultado da epoca 272 = -30998.16
# 114
# 105
# resultado da epoca 273 = 10027.48
# 110
# 109
# resultado da epoca 274 = -68923.73
# 110
# 109
# resultado da epoca 275 = -12404.34
# 109
# 110
# resultado da epoca 276 = -34930.75
# 110
# 109
# resultado da epoca 277 = -76967.12
# 105
# 114
# resultado da epoca 278 = 126650.81
# 116
# 103
# resultado da epoca 279 = -18801.99
# 105
# 114
# resultado da epoca 280 = 36311.96
# 114
# 105
# resultado da epoca 281 = 5419.08
# 108
# 111
# resultado da epoca 282 = -16428.31
# 108
# 111
# resultado da epoca 283 = 11577.50
# 113
# 106
# resultado da epoca 284 = -12429.61
# 108
# 111
# resultado da epoca 285 = -34066.69
# 112
# 107
# resultado da epoca 286 = -20949.90
# 112
# 107
# resultado da epoca 287 = -29010.75
# 109
# 110
# resultado da epoca 288 = -17362.36
# 110
# 109
# resultado da epoca 289 = 50625.50
# 111
# 108
# resultado da epoca 290 = 28740.62
# 115
# 104
# resultado da epoca 291 = -15993.65
# 106
# 113
# resultado da epoca 292 = -59587.60
# 101
# 118
# resultado da epoca 293 = -31692.90
# 112
# 107
# resultado da epoca 294 = -32696.80
# 109
# 110
# resultado da epoca 295 = -62609.87
# 102
# 117
# resultado da epoca 296 = -7980.96
# 112
# 107
# resultado da epoca 297 = -39812.06
# 109
# 110
# resultado da epoca 298 = 10317.48
# 115
# 104
# resultado da epoca 299 = -9812.75
# 114
# 105
# resultado da epoca 300 = -11840.80
# 119
# 100
# resultado da epoca 301 = 10651.19
# 114
# 105
# resultado da epoca 302 = 25022.21
# 110
# 109
# resultado da epoca 303 = -72780.74
# 111
# 108
# resultado da epoca 304 = -60122.71
# 109
# 110
# resultado da epoca 305 = -35201.27
# 114
# 105
# resultado da epoca 306 = -34757.09
# 108
# 111
# resultado da epoca 307 = -3546.58
# 107
# 112
# resultado da epoca 308 = 35689.57
# 114
# 105
# resultado da epoca 309 = 6366.28
# 115
# 104
# resultado da epoca 310 = 45619.71
# 112
# 107
# resultado da epoca 311 = -6565.35
# 110
# 109
# resultado da epoca 312 = -6211.45
# 112
# 107
# resultado da epoca 313 = -119607.13
# 108
# 111
# resultado da epoca 314 = 35355.35
# 112
# 107
# resultado da epoca 315 = -16012.67
# 107
# 112
# resultado da epoca 316 = -12495.51
# 110
# 109
# resultado da epoca 317 = -18046.53
# 99
# 120
# resultado da epoca 318 = 20200.22
# 105
# 114
# resultado da epoca 319 = -39653.79
# 108
# 111
# resultado da epoca 320 = -48036.81
# 107
# 112
# resultado da epoca 321 = 47817.14
# 114
# 105
# resultado da epoca 322 = -46145.73
# 112
# 107
# resultado da epoca 323 = -39094.83
# 105
# 114
# resultado da epoca 324 = -16626.70
# 104
# 115
# resultado da epoca 325 = -22374.29
# 109
# 110
# resultado da epoca 326 = -9593.64
# 109
# 110
# resultado da epoca 327 = -32564.49
# 111
# 108
# resultado da epoca 328 = -40778.46
# 112
# 107
# resultado da epoca 329 = 14497.71
# 117
# 102
# resultado da epoca 330 = 55067.80
# 112
# 107
# resultado da epoca 331 = 24369.01
# 115
# 104
# resultado da epoca 332 = -33551.14
# 109
# 110
# resultado da epoca 333 = -58265.21
# 112
# 107
# resultado da epoca 334 = 17564.00
# 115
# 104
# resultado da epoca 335 = -25308.22
# 108
# 111
# resultado da epoca 336 = -1412.44
# 112
# 107
# resultado da epoca 337 = 50594.60
# 116
# 103
# resultado da epoca 338 = -34331.36
# 113
# 106
# resultado da epoca 339 = -46551.87
# 110
# 109
# resultado da epoca 340 = 13406.07
# 114
# 105
# resultado da epoca 341 = 17407.24
# 112
# 107
# resultado da epoca 342 = -59109.88
# 107
# 112
# resultado da epoca 343 = -8982.03
# 116
# 103
# resultado da epoca 344 = -12158.02
# 109
# 110
# resultado da epoca 345 = 6207.67
# 109
# 110
# resultado da epoca 346 = -43960.77
# 109
# 110
# resultado da epoca 347 = 37876.65
# 114
# 105
# resultado da epoca 348 = -8265.01
# 112
# 107
# resultado da epoca 349 = -97.57
# 105
# 114
# resultado da epoca 350 = -4992.78
# 118
# 101
# resultado da epoca 351 = -5938.13
# 113
# 106
# resultado da epoca 352 = -6674.15
# 109
# 110
# resultado da epoca 353 = -4252.87
# 118
# 101
# resultado da epoca 354 = -10786.30
# 108
# 111
# resultado da epoca 355 = -32979.70
# 104
# 115
# resultado da epoca 356 = -44563.45
# 104
# 115
# resultado da epoca 357 = -15601.26
# 107
# 112
# resultado da epoca 358 = -20256.23
# 112
# 107
# resultado da epoca 359 = -27766.15
# 114
# 105
# resultado da epoca 360 = -26089.17
# 108
# 111
# resultado da epoca 361 = 19831.70
# 107
# 112
# resultado da epoca 362 = -24485.87
# 114
# 105
# resultado da epoca 363 = -19555.65
# 107
# 112
# resultado da epoca 364 = -840.56
# 110
# 109
# resultado da epoca 365 = -48846.56
# 113
# 106
# resultado da epoca 366 = -48135.86
# 112
# 107
# resultado da epoca 367 = -33960.11
# 112
# 107
# resultado da epoca 368 = -32670.30
# 108
# 111
# resultado da epoca 369 = 3313.02
# 112
# 107
# resultado da epoca 370 = 23168.53
# 108
# 111
# resultado da epoca 371 = -48884.39
# 113
# 106
# resultado da epoca 372 = -5335.14
# 115
# 104
# resultado da epoca 373 = -3306.49
# 114
# 105
# resultado da epoca 374 = 40148.92
# 112
# 107
# resultado da epoca 375 = -15865.46
# 114
# 105
# resultado da epoca 376 = -54730.59
# 109
# 110
# resultado da epoca 377 = -16839.35
# 110
# 109
# resultado da epoca 378 = 127.93
# 105
# 114
# resultado da epoca 379 = 7579.45
# 110
# 109
# resultado da epoca 380 = 27889.39
# 111
# 108
# resultado da epoca 381 = -43032.58
# 109
# 110
# resultado da epoca 382 = 18975.90
# 117
# 102
# resultado da epoca 383 = -21112.23
# 108
# 111
# resultado da epoca 384 = 35923.44
# 109
# 110
# resultado da epoca 385 = -3050.50
# 111
# 108
# resultado da epoca 386 = 19537.19
# 110
# 109
# resultado da epoca 387 = -62841.90
# 108
# 111
# resultado da epoca 388 = 7238.25
# 110
# 109
# resultado da epoca 389 = 21321.19
# 106
# 113
# resultado da epoca 390 = -8691.70
# 110
# 109
# resultado da epoca 391 = 9890.27
# 115
# 104
# resultado da epoca 392 = 2122.29
# 113
# 106
# resultado da epoca 393 = 17886.18
# 108
# 111
# resultado da epoca 394 = 25886.08
# 116
# 103
# resultado da epoca 395 = -47806.87
# 112
# 107
# resultado da epoca 396 = -64567.32
# 112
# 107
# resultado da epoca 397 = 33598.14
# 113
# 106
# resultado da epoca 398 = 13135.69
# 109
# 110
# resultado da epoca 399 = -17611.56
# 110
# 109
# resultado da epoca 400 = 22329.21
# 112
# 107
# resultado da epoca 401 = -631.04
# 108
# 111
# resultado da epoca 402 = 50705.31
# 111
# 108
# resultado da epoca 403 = 13935.98
# 109
# 110
# resultado da epoca 404 = -33365.43
# 111
# 108
# resultado da epoca 405 = -28624.17
# 115
# 104
# resultado da epoca 406 = -4557.70
# 114
# 105
# resultado da epoca 407 = 4934.68
# 113
# 106
# resultado da epoca 408 = -11918.11
# 111
# 108
# resultado da epoca 409 = 7486.78
# 113
# 106
# resultado da epoca 410 = -9679.74
# 113
# 106
# resultado da epoca 411 = 32674.78
# 115
# 104
# resultado da epoca 412 = 13871.09
# 116
# 103
# resultado da epoca 413 = 7280.12
# 115
# 104
# resultado da epoca 414 = -45725.80
# 113
# 106
# resultado da epoca 415 = 10199.14
# 113
# 106
# resultado da epoca 416 = 5144.81
# 110
# 109
# resultado da epoca 417 = 34745.68
# 115
# 104
# resultado da epoca 418 = 52188.17
# 112
# 107
# resultado da epoca 419 = -46868.90
# 109
# 110
# resultado da epoca 420 = -17793.10
# 115
# 104
# resultado da epoca 421 = 30530.02
# 113
# 106
# resultado da epoca 422 = -4109.77
# 114
# 105
# resultado da epoca 423 = 30237.20
# 113
# 106
# resultado da epoca 424 = 5202.83
# 113
# 106
# resultado da epoca 425 = 153.60
# 111
# 108
# resultado da epoca 426 = -63117.30
# 116
# 103
# resultado da epoca 427 = 30183.64
# 107
# 112
# resultado da epoca 428 = -23164.20
# 110
# 109
# resultado da epoca 429 = -20637.00
# 118
# 101
# resultado da epoca 430 = 32550.85
# 115
# 104
# resultado da epoca 431 = -43458.28
# 110
# 109
# resultado da epoca 432 = -26680.90
# 111
# 108
# resultado da epoca 433 = -8823.84
# 111
# 108
# resultado da epoca 434 = 7604.11
# 115
# 104
# resultado da epoca 435 = 19598.18
# 113
# 106
# resultado da epoca 436 = -24090.52
# 114
# 105
# resultado da epoca 437 = 12240.47
# 111
# 108
# resultado da epoca 438 = 1212.77
# 112
# 107
# resultado da epoca 439 = 28084.20
# 111
# 108
# resultado da epoca 440 = -25945.36
# 109
# 110
# resultado da epoca 441 = -17646.85
# 107
# 112
# resultado da epoca 442 = -21507.22
# 109
# 110
# resultado da epoca 443 = -19506.95
# 115
# 104
# resultado da epoca 444 = -2719.98
# 116
# 103
# resultado da epoca 445 = -56188.87
# 112
# 107
# resultado da epoca 446 = -14636.50
# 111
# 108
# resultado da epoca 447 = 23622.82
# 110
# 109
# resultado da epoca 448 = 13757.24
# 108
# 111
# resultado da epoca 449 = -43937.42
# 114
# 105
# resultado da epoca 450 = 12490.04
# 112
# 107
# resultado da epoca 451 = 6949.90
# 114
# 105
# resultado da epoca 452 = -14084.96
# 115
# 104
# resultado da epoca 453 = 31372.33
# 115
# 104
# resultado da epoca 454 = -44146.60
# 110
# 109
# resultado da epoca 455 = -14974.60
# 109
# 110
# resultado da epoca 456 = -61188.99
# 112
# 107
# resultado da epoca 457 = -7391.71
# 112
# 107
# resultado da epoca 458 = 142.01
# 112
# 107
# resultado da epoca 459 = 1207.96
# 111
# 108
# resultado da epoca 460 = -18510.34
# 108
# 111
# resultado da epoca 461 = -13983.68
# 108
# 111
# resultado da epoca 462 = 41573.19
# 112
# 107
# resultado da epoca 463 = 2932.79
# 112
# 107
# resultado da epoca 464 = 1622.04
# 114
# 105
# resultado da epoca 465 = 7886.21
# 113
# 106
# resultado da epoca 466 = 47364.61
# 114
# 105
# resultado da epoca 467 = -9271.42
# 114
# 105
# resultado da epoca 468 = -71332.81
# 111
# 108
# resultado da epoca 469 = -34816.28
# 115
# 104
# resultado da epoca 470 = -25929.85
# 112
# 107
# resultado da epoca 471 = -144510.48
# 108
# 111
# resultado da epoca 472 = -104843.87
# 111
# 108
# resultado da epoca 473 = -90064.19
# 112
# 107
# resultado da epoca 474 = -35559.57
# 111
# 108
# resultado da epoca 475 = -116304.38
# 106
# 113
# resultado da epoca 476 = -142961.79
# 105
# 114
# resultado da epoca 477 = -91647.56
# 109
# 110
# resultado da epoca 478 = -69206.04
# 112
# 107
# resultado da epoca 479 = -146010.76
# 109
# 110
# resultado da epoca 480 = -130562.57
# 112
# 107
# resultado da epoca 481 = -120005.25
# 111
# 108
# resultado da epoca 482 = -174331.61
# 113
# 106
# resultado da epoca 483 = -141306.53
# 112
# 107
# resultado da epoca 484 = -119476.39
# 110
# 109
# resultado da epoca 485 = -89962.31
# 115
# 104
# resultado da epoca 486 = -76562.87
# 113
# 106
# resultado da epoca 487 = -138729.70
# 110
# 109
# resultado da epoca 488 = -164437.89
# 109
# 110
# resultado da epoca 489 = -121683.84
# 113
# 106
# resultado da epoca 490 = -107412.89
# 111
# 108
# resultado da epoca 491 = -120754.70
# 113
# 106
# resultado da epoca 492 = -162544.11
# 109
# 110
# resultado da epoca 493 = -151018.70
# 114
# 105
# resultado da epoca 494 = -168507.59
# 115
# 104
# resultado da epoca 495 = -81646.93
# 111
# 108
# resultado da epoca 496 = -153152.36
# 112
# 107
# resultado da epoca 497 = -128006.72
# 111
# 108
# resultado da epoca 498 = -121402.46
# 110
# 109
# resultado da epoca 499 = -140604.66
# 113
# 106
# resultado da epoca 500 = -142203.13
# 116
# 103
# resultado da epoca 501 = -190517.35
# 102
# 117
# resultado da epoca 502 = -207084.85
# 115
# 104
# resultado da epoca 503 = -160424.56
# 118
# 101
# resultado da epoca 504 = -159898.44
# 111
# 108
# resultado da epoca 505 = -108868.48
# 113
# 106
# resultado da epoca 506 = -128894.72
# 110
# 109
# resultado da epoca 507 = -127759.95
# 109
# 110
# resultado da epoca 508 = -94350.57
# 111
# 108
# resultado da epoca 509 = -114938.02
# 113
# 106
# resultado da epoca 510 = -141355.68
# 110
# 109
# resultado da epoca 511 = -147695.01
# 109
# 110
# resultado da epoca 512 = -184618.23
# 113
# 106
# resultado da epoca 513 = -134549.68
# 113
# 106
# resultado da epoca 514 = -199625.96
# 113
# 106
# resultado da epoca 515 = -184414.56
# 110
# 109
# resultado da epoca 516 = -161754.54
# 109
# 110
# resultado da epoca 517 = -170160.56
# 114
# 105
# resultado da epoca 518 = -99947.73
# 108
# 111
# resultado da epoca 519 = -91963.98
# 114
# 105
# resultado da epoca 520 = -146462.94
# 110
# 109
# resultado da epoca 521 = -133145.68
# 113
# 106
# resultado da epoca 522 = -145645.54
# 114
# 105
# resultado da epoca 523 = -131161.72
# 116
# 103
# resultado da epoca 524 = -136629.48
# 113
# 106
# resultado da epoca 525 = -118517.28
# 112
# 107
# resultado da epoca 526 = -107661.26
# 114
# 105
# resultado da epoca 527 = -180979.91
# 114
# 105
# resultado da epoca 528 = -205557.07
# 108
# 111
# resultado da epoca 529 = -251092.14
# 111
# 108
# resultado da epoca 530 = -205189.11
# 111
# 108
# resultado da epoca 531 = -141107.59
# 112
# 107
# resultado da epoca 532 = -211606.04
# 112
# 107
# resultado da epoca 533 = -224704.12
# 114
# 105
# resultado da epoca 534 = -226295.42
# 111
# 108
# resultado da epoca 535 = -176750.30
# 112
# 107
# resultado da epoca 536 = -179432.56
# 114
# 105
# resultado da epoca 537 = -174137.00
# 119
# 100
# resultado da epoca 538 = -145407.46
# 114
# 105
# resultado da epoca 539 = -147291.28
# 111
# 108
# resultado da epoca 540 = -157935.59
# 107
# 112
# resultado da epoca 541 = -127716.31
# 112
# 107
# resultado da epoca 542 = -110287.56
# 114
# 105
# resultado da epoca 543 = -140762.39
# 113
# 106
# resultado da epoca 544 = -165325.63
# 110
# 109
# resultado da epoca 545 = -177802.72
# 116
# 103
# resultado da epoca 546 = -147386.41
# 111
# 108
# resultado da epoca 547 = -178622.19
# 110
# 109
# resultado da epoca 548 = -181932.90
# 114
# 105
# resultado da epoca 549 = -187105.56
# 112
# 107
# resultado da epoca 550 = -167746.27
# 112
# 107
# resultado da epoca 551 = -195445.10
# 109
# 110
# resultado da epoca 552 = -150572.15
# 112
# 107
# resultado da epoca 553 = -123767.52
# 111
# 108
# resultado da epoca 554 = -264448.67
# 110
# 109
# resultado da epoca 555 = -199580.01
# 109
# 110
# resultado da epoca 556 = -189724.33
# 111
# 108
# resultado da epoca 557 = -128451.54
# 109
# 110
# resultado da epoca 558 = -187675.82
# 113
# 106
# resultado da epoca 559 = -143846.44
# 112
# 107
# resultado da epoca 560 = -147630.07
# 112
# 107
# resultado da epoca 561 = -116868.70
# 115
# 104
# resultado da epoca 562 = -155356.40
# 114
# 105
# resultado da epoca 563 = -188793.55
# 112
# 107
# resultado da epoca 564 = -133385.39
# 112
# 107
# resultado da epoca 565 = -140590.98
# 112
# 107
# resultado da epoca 566 = -171301.97
# 110
# 109
# resultado da epoca 567 = -162100.08
# 114
# 105
# resultado da epoca 568 = -194240.97
# 112
# 107
# resultado da epoca 569 = -187111.03
# 112
# 107
# resultado da epoca 570 = -200614.33
# 109
# 110
# resultado da epoca 571 = -207473.44
# 116
# 103
# resultado da epoca 572 = -244997.13
# 111
# 108
# resultado da epoca 573 = -202362.00
# 111
# 108
# resultado da epoca 574 = -125529.87
# 110
# 109
# resultado da epoca 575 = -191341.13
# 109
# 110
# resultado da epoca 576 = -226625.58
# 111
# 108
# resultado da epoca 577 = -189091.43
# 117
# 102
# resultado da epoca 578 = -207974.50
# 110
# 109
# resultado da epoca 579 = -163436.97
# 112
# 107
# resultado da epoca 580 = -196590.27
# 109
# 110
# resultado da epoca 581 = -162168.42
# 108
# 111
# resultado da epoca 582 = -198000.59
# 109
# 110
# resultado da epoca 583 = -183097.68
# 115
# 104
# resultado da epoca 584 = -181245.56
# 113
# 106
# resultado da epoca 585 = -153850.32
# 111
# 108
# resultado da epoca 586 = -215038.39
# 118
# 101
# resultado da epoca 587 = -169854.94
# 118
# 101
# resultado da epoca 588 = -142243.93
# 112
# 107
# resultado da epoca 589 = -183979.42
# 113
# 106
# resultado da epoca 590 = -152899.06
# 116
# 103
# resultado da epoca 591 = -236077.42
# 109
# 110
# resultado da epoca 592 = -227628.34
# 112
# 107
# resultado da epoca 593 = -214237.06
# 113
# 106
# resultado da epoca 594 = -226700.68
# 110
# 109
# resultado da epoca 595 = -212459.01
# 111
# 108
# resultado da epoca 596 = -178621.16
# 115
# 104
# resultado da epoca 597 = -222174.50
# 115
# 104
# resultado da epoca 598 = -196035.77
# 117
# 102
# resultado da epoca 599 = -187394.17
# 114
# 105
# resultado da epoca 600 = -156478.71
# 114
# 105
# resultado da epoca 601 = -169721.67
# 112
# 107
# resultado da epoca 602 = -136238.60
# 114
# 105
# resultado da epoca 603 = -179705.52
# 114
# 105
# resultado da epoca 604 = -205742.42
# 116
# 103
# resultado da epoca 605 = -155140.71
# 116
# 103
# resultado da epoca 606 = -170331.03
# 114
# 105
# resultado da epoca 607 = -134212.42
# 116
# 103
# resultado da epoca 608 = -138463.59
# 110
# 109
# resultado da epoca 609 = -190016.57
# 114
# 105
# resultado da epoca 610 = -162890.08
# 117
# 102
# resultado da epoca 611 = -192514.85
# 114
# 105
# resultado da epoca 612 = -210572.16
# 108
# 111
# resultado da epoca 613 = -129178.21
# 112
# 107
# resultado da epoca 614 = -198069.51
# 107
# 112
# resultado da epoca 615 = -162484.01
# 111
# 108
# resultado da epoca 616 = -174264.56
# 114
# 105
# resultado da epoca 617 = -191476.77
# 110
# 109
# resultado da epoca 618 = -178144.70
# 115
# 104
# resultado da epoca 619 = -199265.31
# 114
# 105
# resultado da epoca 620 = -176819.49
# 110
# 109
# resultado da epoca 621 = -145533.68
# 113
# 106
# resultado da epoca 622 = -154662.87
# 114
# 105
# resultado da epoca 623 = -226932.38
# 108
# 111
# resultado da epoca 624 = -262955.25
# 115
# 104
# resultado da epoca 625 = -222448.17
# 116
# 103
# resultado da epoca 626 = -228028.52
# 112
# 107
# resultado da epoca 627 = -240804.93
# 110
# 109
# resultado da epoca 628 = -217380.31
# 109
# 110
# resultado da epoca 629 = -205684.58
# 110
# 109
# resultado da epoca 630 = -177419.85
# 112
# 107
# resultado da epoca 631 = -209679.26
# 113
# 106
# resultado da epoca 632 = -198787.21
# 113
# 106
# resultado da epoca 633 = -196070.93
# 112
# 107
# resultado da epoca 634 = -230321.58
# 110
# 109
# resultado da epoca 635 = -202490.00
# 110
# 109
# resultado da epoca 636 = -213485.47
# 114
# 105
# resultado da epoca 637 = -229073.04
# 110
# 109
# resultado da epoca 638 = -218169.01
# 110
# 109
# resultado da epoca 639 = -216012.21
# 110
# 109
# resultado da epoca 640 = -217756.52
# 112
# 107
# resultado da epoca 641 = -225635.58
# 113
# 106
# resultado da epoca 642 = -208733.44
# 110
# 109
# resultado da epoca 643 = -194894.13
# 114
# 105
# resultado da epoca 644 = -192583.72
# 107
# 112
# resultado da epoca 645 = -178209.15
# 108
# 111
# resultado da epoca 646 = -229498.85
# 111
# 108
# resultado da epoca 647 = -250842.65
# 114
# 105
# resultado da epoca 648 = -250146.96
# 108
# 111
# resultado da epoca 649 = -238121.75
# 112
# 107
# resultado da epoca 650 = -193331.44
# 113
# 106
# resultado da epoca 651 = -245823.71
# 110
# 109
# resultado da epoca 652 = -280722.98
# 109
# 110
# resultado da epoca 653 = -284798.44
# 107
# 112
# resultado da epoca 654 = -308818.12
# 112
# 107
# resultado da epoca 655 = -282418.64
# 114
# 105
# resultado da epoca 656 = -240510.41
# 106
# 113
# resultado da epoca 657 = -264025.31
# 111
# 108
# resultado da epoca 658 = -276671.43
# 114
# 105
# resultado da epoca 659 = -218305.54
# 111
# 108
# resultado da epoca 660 = -217789.10
# 109
# 110
# resultado da epoca 661 = -212292.49
# 114
# 105
# resultado da epoca 662 = -262561.25
# 113
# 106
# resultado da epoca 663 = -244358.14
# 111
# 108
# resultado da epoca 664 = -228112.85
# 114
# 105
# resultado da epoca 665 = -224019.26
# 113
# 106
# resultado da epoca 666 = -318813.40
# 109
# 110
# resultado da epoca 667 = -275996.56
# 106
# 113
# resultado da epoca 668 = -314712.88
# 112
# 107
# resultado da epoca 669 = -244924.20
# 115
# 104
# resultado da epoca 670 = -276748.56
# 113
# 106
# resultado da epoca 671 = -313833.29
# 110
# 109
# resultado da epoca 672 = -307920.61
# 109
# 110
# resultado da epoca 673 = -222420.58
# 110
# 109
# resultado da epoca 674 = -249898.20
# 111
# 108
# resultado da epoca 675 = -251928.19
# 111
# 108
# resultado da epoca 676 = -272987.05
# 110
# 109
# resultado da epoca 677 = -287784.57
# 112
# 107
# resultado da epoca 678 = -220933.38
# 110
# 109
# resultado da epoca 679 = -245704.86
# 112
# 107
# resultado da epoca 680 = -209598.87
# 111
# 108
# resultado da epoca 681 = -285126.62
# 109
# 110
# resultado da epoca 682 = -288335.48
# 113
# 106
# resultado da epoca 683 = -277794.21
# 112
# 107
# resultado da epoca 684 = -293421.23
# 112
# 107
# resultado da epoca 685 = -269124.36
# 108
# 111
# resultado da epoca 686 = -239923.02
# 109
# 110
# resultado da epoca 687 = -261112.64
# 108
# 111
# resultado da epoca 688 = -248999.71
# 113
# 106
# resultado da epoca 689 = -260473.91
# 115
# 104
# resultado da epoca 690 = -298649.30
# 112
# 107
# resultado da epoca 691 = -217563.65
# 113
# 106
# resultado da epoca 692 = -250376.26
# 113
# 106
# resultado da epoca 693 = -266622.97
# 112
# 107
# resultado da epoca 694 = -268982.05
# 116
# 103
# resultado da epoca 695 = -282240.68
# 113
# 106
# resultado da epoca 696 = -284295.49
# 110
# 109
# resultado da epoca 697 = -216127.70
# 110
# 109
# resultado da epoca 698 = -196768.96
# 112
# 107
# resultado da epoca 699 = -240503.20
# 112
# 107
# resultado da epoca 700 = -269139.95
# 111
# 108
# resultado da epoca 701 = -197826.29
# 114
# 105
# resultado da epoca 702 = -242103.04
# 112
# 107
# resultado da epoca 703 = -223721.35
# 113
# 106
# resultado da epoca 704 = -198851.42
# 111
# 108
# resultado da epoca 705 = -215174.10
# 111
# 108
# resultado da epoca 706 = -270215.94
# 117
# 102
# resultado da epoca 707 = -181209.00
# 114
# 105
# resultado da epoca 708 = -246249.23
# 110
# 109
# resultado da epoca 709 = -212617.86
# 110
# 109
# resultado da epoca 710 = -229387.75
# 112
# 107
# resultado da epoca 711 = -278341.04
# 110
# 109
# resultado da epoca 712 = -265022.77
# 112
# 107
# resultado da epoca 713 = -287257.92
# 107
# 112
# resultado da epoca 714 = -293641.35
# 110
# 109
# resultado da epoca 715 = -323439.48
# 116
# 103
# resultado da epoca 716 = -289842.53
# 111
# 108
# resultado da epoca 717 = -256862.28
# 111
# 108
# resultado da epoca 718 = -283102.79
# 117
# 102
# resultado da epoca 719 = -299718.43
# 111
# 108
# resultado da epoca 720 = -208902.95
# 111
# 108
# resultado da epoca 721 = -203640.29
# 112
# 107
# resultado da epoca 722 = -209255.92
# 112
# 107
# resultado da epoca 723 = -239662.88
# 110
# 109
# resultado da epoca 724 = -250568.45
# 112
# 107
# resultado da epoca 725 = -268607.36
# 109
# 110
# resultado da epoca 726 = -226872.19
# 115
# 104
# resultado da epoca 727 = -245187.41
# 114
# 105
# resultado da epoca 728 = -204239.85
# 108
# 111
# resultado da epoca 729 = -275850.96
# 107
# 112
# resultado da epoca 730 = -254332.95
# 112
# 107
# resultado da epoca 731 = -260956.41
# 111
# 108
# resultado da epoca 732 = -243300.89
# 116
# 103
# resultado da epoca 733 = -222923.32
# 114
# 105
# resultado da epoca 734 = -267010.74
# 112
# 107
# resultado da epoca 735 = -208216.30
# 115
# 104
# resultado da epoca 736 = -286562.54
# 109
# 110
# resultado da epoca 737 = -220984.90
# 112
# 107
# resultado da epoca 738 = -281153.42
# 108
# 111
# resultado da epoca 739 = -298685.63
# 109
# 110
# resultado da epoca 740 = -320749.45
# 112
# 107
# resultado da epoca 741 = -264524.06
# 114
# 105
# resultado da epoca 742 = -247889.60
# 114
# 105
# resultado da epoca 743 = -257665.60
# 115
# 104
# resultado da epoca 744 = -304188.27
# 113
# 106
# resultado da epoca 745 = -297696.91
# 113
# 106
# resultado da epoca 746 = -321255.90
# 109
# 110
# resultado da epoca 747 = -283371.17
# 113
# 106
# resultado da epoca 748 = -290104.06
# 113
# 106
# resultado da epoca 749 = -289270.30
# 111
# 108
# resultado da epoca 750 = -245163.94
# 110
# 109
# resultado da epoca 751 = -303159.80
# 114
# 105
# resultado da epoca 752 = -283534.28
# 114
# 105
# resultado da epoca 753 = -281060.92
# 113
# 106
# resultado da epoca 754 = -262775.95
# 111
# 108
# resultado da epoca 755 = -313016.06
# 117
# 102
# resultado da epoca 756 = -305752.64
# 110
# 109
# resultado da epoca 757 = -291287.95
# 112
# 107
# resultado da epoca 758 = -255009.33
# 112
# 107
# resultado da epoca 759 = -290261.72
# 115
# 104
# resultado da epoca 760 = -231986.35
# 116
# 103
# resultado da epoca 761 = -329935.90
# 113
# 106
# resultado da epoca 762 = -264903.52
# 115
# 104
# resultado da epoca 763 = -254888.68
# 113
# 106
# resultado da epoca 764 = -247116.37
# 111
# 108
# resultado da epoca 765 = -262434.97
# 113
# 106
# resultado da epoca 766 = -256960.71
# 111
# 108
# resultado da epoca 767 = -238679.60
# 110
# 109
# resultado da epoca 768 = -258442.66
# 115
# 104
# resultado da epoca 769 = -255925.46
# 111
# 108
# resultado da epoca 770 = -249871.08
# 113
# 106
# resultado da epoca 771 = -189161.23
# 115
# 104
# resultado da epoca 772 = -208988.91
# 114
# 105
# resultado da epoca 773 = -222893.85
# 111
# 108
# resultado da epoca 774 = -218691.36
# 108
# 111
# resultado da epoca 775 = -184619.08
# 112
# 107
# resultado da epoca 776 = -214085.53
# 109
# 110
# resultado da epoca 777 = -167388.64
# 111
# 108
# resultado da epoca 778 = -280342.31
# 111
# 108
# resultado da epoca 779 = -261867.25
# 115
# 104
# resultado da epoca 780 = -227785.74
# 111
# 108
# resultado da epoca 781 = -262821.57
# 111
# 108
# resultado da epoca 782 = -202141.07
# 113
# 106
# resultado da epoca 783 = -275718.26
# 111
# 108
# resultado da epoca 784 = -240817.04
# 115
# 104
# resultado da epoca 785 = -198656.83
# 110
# 109
# resultado da epoca 786 = -280674.80
# 114
# 105
# resultado da epoca 787 = -221921.01
# 114
# 105
# resultado da epoca 788 = -240577.49
# 112
# 107
# resultado da epoca 789 = -230364.90
# 116
# 103
# resultado da epoca 790 = -213609.29
# 109
# 110
# resultado da epoca 791 = -230453.33
# 114
# 105
# resultado da epoca 792 = -231679.81
# 110
# 109
# resultado da epoca 793 = -236222.42
# 111
# 108
# resultado da epoca 794 = -180060.38
# 111
# 108
# resultado da epoca 795 = -253874.87
# 113
# 106
# resultado da epoca 796 = -222137.91
# 111
# 108
# resultado da epoca 797 = -266875.24
# 113
# 106
# resultado da epoca 798 = -252398.44
# 111
# 108
# resultado da epoca 799 = -265952.17
# 111
# 108
# resultado da epoca 800 = -334867.25
# 108
# 111
# resultado da epoca 801 = -237897.07
# 108
# 111
# resultado da epoca 802 = -260876.98
# 112
# 107
# resultado da epoca 803 = -238786.77
# 110
# 109
# resultado da epoca 804 = -248628.87
# 110
# 109
# resultado da epoca 805 = -265520.19
# 114
# 105
# resultado da epoca 806 = -226972.07
# 111
# 108
# resultado da epoca 807 = -303043.69
# 107
# 112
# resultado da epoca 808 = -321975.91
# 112
# 107
# resultado da epoca 809 = -298847.19
# 112
# 107
# resultado da epoca 810 = -260316.46
# 114
# 105
# resultado da epoca 811 = -354103.82
# 112
# 107
# resultado da epoca 812 = -305842.38
# 110
# 109
# resultado da epoca 813 = -331687.24
# 114
# 105
# resultado da epoca 814 = -318274.73
# 112
# 107
# resultado da epoca 815 = -300884.40
# 114
# 105
# resultado da epoca 816 = -374120.00
# 113
# 106
# resultado da epoca 817 = -360608.90
# 109
# 110
# resultado da epoca 818 = -348685.12
# 110
# 109
# resultado da epoca 819 = -320133.52
# 111
# 108
# resultado da epoca 820 = -362921.01
# 109
# 110
# resultado da epoca 821 = -345873.70
# 110
# 109
# resultado da epoca 822 = -244777.63
# 110
# 109
# resultado da epoca 823 = -339185.55
# 115
# 104
# resultado da epoca 824 = -371400.57
# 109
# 110
# resultado da epoca 825 = -387310.49
# 112
# 107
# resultado da epoca 826 = -419464.93
# 112
# 107
# resultado da epoca 827 = -360808.47
# 114
# 105
# resultado da epoca 828 = -394210.26
# 111
# 108
# resultado da epoca 829 = -291005.22
# 109
# 110
# resultado da epoca 830 = -295552.15
# 113
# 106
# resultado da epoca 831 = -254046.97
# 112
# 107
# resultado da epoca 832 = -256590.88
# 110
# 109
# resultado da epoca 833 = -241178.35
# 111
# 108
# resultado da epoca 834 = -255484.73
# 112
# 107
# resultado da epoca 835 = -207368.80
# 108
# 111
# resultado da epoca 836 = -249917.22
# 109
# 110
# resultado da epoca 837 = -242012.67
# 111
# 108
# resultado da epoca 838 = -218854.92
# 110
# 109
# resultado da epoca 839 = -167925.55
# 110
# 109
# resultado da epoca 840 = -187932.42
# 112
# 107
# resultado da epoca 841 = -201403.31
# 110
# 109
# resultado da epoca 842 = -225690.74
# 111
# 108
# resultado da epoca 843 = -242100.98
# 112
# 107
# resultado da epoca 844 = -218134.46
# 110
# 109
# resultado da epoca 845 = -202230.90
# 111
# 108
# resultado da epoca 846 = -215767.08
# 114
# 105
# resultado da epoca 847 = -163567.76
# 110
# 109
# resultado da epoca 848 = -209516.50
# 106
# 113
# resultado da epoca 849 = -183902.16
# 112
# 107
# resultado da epoca 850 = -211839.94
# 110
# 109
# resultado da epoca 851 = -213873.24
# 112
# 107
# resultado da epoca 852 = -215352.12
# 109
# 110
# resultado da epoca 853 = -207641.07
# 112
# 107
# resultado da epoca 854 = -197835.49
# 109
# 110
# resultado da epoca 855 = -191154.94
# 105
# 114
# resultado da epoca 856 = -165331.66
# 109
# 110
# resultado da epoca 857 = -209148.60
# 110
# 109
# resultado da epoca 858 = -179438.44
# 114
# 105
# resultado da epoca 859 = -185229.08
# 112
# 107
# resultado da epoca 860 = -211196.18
# 105
# 114
# resultado da epoca 861 = -219442.14
# 107
# 112
# resultado da epoca 862 = -219537.48
# 111
# 108
# resultado da epoca 863 = -201692.51
# 108
# 111
# resultado da epoca 864 = -204911.67
# 110
# 109
# resultado da epoca 865 = -207656.99
# 113
# 106
# resultado da epoca 866 = -184208.06
# 112
# 107
# resultado da epoca 867 = -216664.08
# 112
# 107
# resultado da epoca 868 = -162159.37
# 106
# 113
# resultado da epoca 869 = -188886.07
# 110
# 109
# resultado da epoca 870 = -200547.62
# 109
# 110
# resultado da epoca 871 = -240400.60
# 108
# 111
# resultado da epoca 872 = -185901.01
# 106
# 113
# resultado da epoca 873 = -200488.75
# 108
# 111
# resultado da epoca 874 = -204055.50
# 112
# 107
# resultado da epoca 875 = -190549.75
# 109
# 110
# resultado da epoca 876 = -178897.29
# 110
# 109
# resultado da epoca 877 = -218764.46
# 107
# 112
# resultado da epoca 878 = -170729.00
# 105
# 114
# resultado da epoca 879 = -214816.61
# 110
# 109
# resultado da epoca 880 = -196894.47
# 111
# 108
# resultado da epoca 881 = -207079.60
# 109
# 110
# resultado da epoca 882 = -212705.25
# 110
# 109
# resultado da epoca 883 = -199184.46
# 109
# 110
# resultado da epoca 884 = -203719.61
# 108
# 111
# resultado da epoca 885 = -227096.97
# 107
# 112
# resultado da epoca 886 = -209033.86
# 103
# 116
# resultado da epoca 887 = -184571.64
# 110
# 109
# resultado da epoca 888 = -217847.31
# 112
# 107
# resultado da epoca 889 = -216570.13
# 104
# 115
# resultado da epoca 890 = -204698.54
# 105
# 114
# resultado da epoca 891 = -221673.32
# 105
# 114
# resultado da epoca 892 = -204243.17
# 107
# 112
# resultado da epoca 893 = -235374.67
# 110
# 109
# resultado da epoca 894 = -199570.12
# 108
# 111
# resultado da epoca 895 = -217636.80
# 111
# 108
# resultado da epoca 896 = -211033.66
# 105
# 114
# resultado da epoca 897 = -205758.35
# 104
# 115
# resultado da epoca 898 = -218664.39
# 112
# 107
# resultado da epoca 899 = -216746.15
# 109
# 110
# resultado da epoca 900 = -235897.52
# 107
# 112
# resultado da epoca 901 = -220164.54
# 107
# 112
# resultado da epoca 902 = -196836.87
# 107
# 112
# resultado da epoca 903 = -221157.71
# 108
# 111
# resultado da epoca 904 = -219087.96
# 110
# 109
# resultado da epoca 905 = -211221.04
# 110
# 109
# resultado da epoca 906 = -208225.16
# 107
# 112
# resultado da epoca 907 = -239048.84
# 108
# 111
# resultado da epoca 908 = -234162.85
# 111
# 108
# resultado da epoca 909 = -211544.35
# 105
# 114
# resultado da epoca 910 = -216808.04
# 107
# 112
# resultado da epoca 911 = -219692.47
# 106
# 113
# resultado da epoca 912 = -204914.82
# 107
# 112
# resultado da epoca 913 = -194369.39
# 108
# 111
# resultado da epoca 914 = -234998.60
# 106
# 113
# resultado da epoca 915 = -214380.65
# 110
# 109
# resultado da epoca 916 = -203690.72
# 109
# 110
# resultado da epoca 917 = -231548.02
# 108
# 111
# resultado da epoca 918 = -212729.29
# 105
# 114
# resultado da epoca 919 = -215098.73
# 108
# 111
# resultado da epoca 920 = -219431.68
# 112
# 107
# resultado da epoca 921 = -231797.95
# 105
# 114
# resultado da epoca 922 = -224942.68
# 108
# 111
# resultado da epoca 923 = -207650.60
# 105
# 114
# resultado da epoca 924 = -244137.50
# 105
# 114
# resultado da epoca 925 = -204073.04
# 108
# 111
# resultado da epoca 926 = -226006.74
# 102
# 117
# resultado da epoca 927 = -234189.84
# 107
# 112
# resultado da epoca 928 = -227182.06
# 105
# 114
# resultado da epoca 929 = -217961.82
# 108
# 111
# resultado da epoca 930 = -230132.94
# 108
# 111
# resultado da epoca 931 = -263577.22
# 104
# 115
# resultado da epoca 932 = -238364.22
# 108
# 111
# resultado da epoca 933 = -225237.95
# 106
# 113
# resultado da epoca 934 = -245814.94
# 110
# 109
# resultado da epoca 935 = -237491.11
# 107
# 112
# resultado da epoca 936 = -246511.03
# 102
# 117
# resultado da epoca 937 = -220481.19
# 109
# 110
# resultado da epoca 938 = -249256.77
# 107
# 112
# resultado da epoca 939 = -249108.74
# 107
# 112
# resultado da epoca 940 = -257801.30
# 108
# 111
# resultado da epoca 941 = -263322.10
# 106
# 113
# resultado da epoca 942 = -238729.61
# 109
# 110
# resultado da epoca 943 = -248822.20
# 109
# 110
# resultado da epoca 944 = -242051.77
# 105
# 114
# resultado da epoca 945 = -242429.12
# 104
# 115
# resultado da epoca 946 = -264033.32
# 108
# 111
# resultado da epoca 947 = -253203.04
# 107
# 112
# resultado da epoca 948 = -275498.33
# 108
# 111
# resultado da epoca 949 = -235638.84
# 109
# 110
# resultado da epoca 950 = -252688.71
# 110
# 109
# resultado da epoca 951 = -247548.82
# 109
# 110
# resultado da epoca 952 = -261469.68
# 109
# 110
# resultado da epoca 953 = -247449.40
# 108
# 111
# resultado da epoca 954 = -244996.41
# 108
# 111
# resultado da epoca 955 = -253080.24
# 107
# 112
# resultado da epoca 956 = -241762.89
# 108
# 111
# resultado da epoca 957 = -256227.58
# 105
# 114
# resultado da epoca 958 = -257908.87
# 107
# 112
# resultado da epoca 959 = -260604.55
# 107
# 112
# resultado da epoca 960 = -263032.39
# 103
# 116
# resultado da epoca 961 = -255301.61
# 107
# 112
# resultado da epoca 962 = -249676.00
# 104
# 115
# resultado da epoca 963 = -260989.83
# 105
# 114
# resultado da epoca 964 = -268499.48
# 105
# 114
# resultado da epoca 965 = -247989.30
# 104
# 115
# resultado da epoca 966 = -243769.64
# 103
# 116
# resultado da epoca 967 = -249856.77
# 107
# 112
# resultado da epoca 968 = -251825.49
# 107
# 112
# resultado da epoca 969 = -238948.62
# 109
# 110
# resultado da epoca 970 = -274721.25
# 102
# 117
# resultado da epoca 971 = -257974.15
# 103
# 116
# resultado da epoca 972 = -241550.48
# 108
# 111
# resultado da epoca 973 = -279222.24
# 105
# 114
# resultado da epoca 974 = -267538.42
# 106
# 113
# resultado da epoca 975 = -272057.46
# 106
# 113
# resultado da epoca 976 = -280556.08
# 107
# 112
# resultado da epoca 977 = -263372.23
# 104
# 115
# resultado da epoca 978 = -264190.58
# 102
# 117
# resultado da epoca 979 = -269105.75
# 106
# 113
# resultado da epoca 980 = -276543.45
# 104
# 115
# resultado da epoca 981 = -278889.72
# 106
# 113
# resultado da epoca 982 = -288472.53
# 109
# 110
# resultado da epoca 983 = -266900.40
# 105
# 114
# resultado da epoca 984 = -283839.01
# 106
# 113
# resultado da epoca 985 = -290213.23
# 106
# 113
# resultado da epoca 986 = -286255.68
# 103
# 116
# resultado da epoca 987 = -287014.35
# 103
# 116
# resultado da epoca 988 = -281460.02
# 103
# 116
# resultado da epoca 989 = -282824.54
# 106
# 113
# resultado da epoca 990 = -287938.13
# 104
# 115
# resultado da epoca 991 = -286990.30
# 105
# 114
# resultado da epoca 992 = -307078.02
# 104
# 115
# resultado da epoca 993 = -289387.06
# 102
# 117
# resultado da epoca 994 = -296416.45
# 103
# 116
# resultado da epoca 995 = -292584.24
# 103
# 116
# resultado da epoca 996 = -302994.10
# 101
# 118
# resultado da epoca 997 = -311517.36
# 101
# 118
# resultado da epoca 998 = -310389.79
# 101
# 118
# resultado da epoca 999 = -310457.40
# 100
# 119
# 0
# 0
# Somatoria dos rewards: -123429666.67
# Melhor resultado diario: 40054.45
