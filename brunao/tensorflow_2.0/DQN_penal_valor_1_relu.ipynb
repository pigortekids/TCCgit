# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco']#, 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
n_saidas = 3 #nmero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0
lim_cont = 10
posicao_max = 100*lim_cont #define variavel para normalizar a posicao

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]
pmax = np.amax( inputs.loc[:, inputs.columns[0]] ) #define valor minimo do preo
pmin = np.amin( inputs.loc[:, inputs.columns[0]] ) #define valor maximo do preo

for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imax = np.amax( inputs.loc[:, inputs.columns[i]] ) #pega valor maximo
    imin = np.amin( inputs.loc[:, inputs.columns[i]] ) #pega valor minimo
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imin ) / ( imax - imin ) #normaliza prs

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = 105
#hr = hr/step_max
#inputs['hr_int'] = hr


dias = len(steps)
dias = 220
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K            #importa backend para clear_session()

##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria()
        self.gamma = 0.96       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-6
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(192, activation='relu')) #camada escondida
        model.add(Dense(128, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        
        return model

    def limpa_memoria(self):
        self.state = np.empty((0,))
        self.next_state = np.empty((0,))
        self.memory = []
        
    def toma_acao(self, valores_ant, teste):
        if not teste and np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora        
        act_values = self.model.predict(estado, batch_size=1) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=step_max):
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in self.memory:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado, batch_size=batch_size)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado, batch_size=batch_size) #pega valor que chegou
            target_f[0][acao] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0, batch_size=batch_size) #treina modelo
        
    def tira_ultimo_state(self):
        if self.state.shape[0] > self.janela * self.n_variaveis:
            self.state = self.state[self.n_variaveis:] #tira os ultimos preos
        if self.next_state.shape[0] > self.janela * self.n_variaveis:
            self.next_state = self.next_state[self.n_variaveis:] #tira os ultimos preos
    
    def remember(self, acao, reward, valores_ant, valores_dps, done):
        prox_estado = np.array([np.append(self.next_state, valores_dps)]) #cria proximo estado
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora
        self.memory.append((acao, reward, estado, prox_estado, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               3584
# _________________________________________________________________
# dense_2 (Dense)              (None, 192)               49344
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 78,019
# Trainable params: 78,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    posicao = 0.
    r = 0.
        
    if acao != 0:
        if (acao*ncont_anterior) < 0:    #realizacao (lucro ou prejuizo)
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
            preco_cheio = ( preco * ( pmax - pmin ) + pmin )
            r = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
        else:
            r = -custo*abs(acao)                                       #reward = -custo*acao se houve operacao
        
        if valor!=-1: 
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
            
        if abs(ncont) > 0:
            valor = (ncont_anterior*valor + acao*preco)/ncont     
        else:
            valor = -1
            
    if valor!=-1: 
        valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valor posicionado atual
        dp = ( preco * ( pmax - pmin ) + pmin ) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (INSTANTNEO)
    
    return ncont, valor, posicao, ncont_anterior, r

def obter_acao(ncont, valores_ant):
    decisao = modelo.toma_acao(valores_ant, False) #calcula a saida da rede neural
    penal = 0
    
    if decisao == 0: #comprar
        if ncont < lim_cont: #s compra se no tem nada ainda
            return 1, penal
        else:
            penal = -20
    elif decisao == 1: #vender
        if ncont > -lim_cont: #só vende se tiver alguma coisa
            return -1, penal
        else:
            penal = -20
    return 0, penal #neutro

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor =  -1 #cria variavel para preo medio
    reward = 0 #cria variavel para recompensa
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria() #limpa o vetor de memoria
    done = False
    modelo.state = np.zeros(n_variaveis*janela)
    modelo.next_state = np.zeros(n_variaveis*janela)
    penal = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.state = np.append( modelo.state, ultimos_precos ) #adiciona na variavel de estado
        
        modelo.tira_ultimo_state()
        valores_ant = [ncont / lim_cont, valor, posicao/posicao_max] #grava os valores de antes - estado

        acao, penal = obter_acao( ncont, valores_ant ) #obtem acao
        ncont, valor, posicao, ncont_anterior, r = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        reward += (r + penal)
        #if penal !=0:
         #   print(r, penal, reward)
        #if valor==-1: 
        #print(valor)
        #print (hr[step]*step_max, acao)
        #if ncont!=0: valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
        #else: valor_cheio = valor
        #preco_cheio = ( precos['preco'][step] * ( pmax - pmin ) + pmin )
        #print("ncont: {0} reward: {1} posicao: {2} valor: {3} preco: {4} ".format(ncont, reward, posicao, valor_cheio, preco_cheio))

        prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
        modelo.next_state = np.append(modelo.next_state, prox_precos) #adiciona variavel na variavel de proximo estado
        modelo.tira_ultimo_state()
        valores_dps = [ncont / lim_cont, valor, posicao/posicao_max] #grava os valores de depois
        
        if step == (steps[dia] - 1):
            done = True
        else:
            modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    
    reward += posicao #soma reward - DAY-TRADE (obs: custo nao havia sido considerado no reward pq acao era 0)
    
    modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    #print(reward)
    modelo.treina_modelo() #roda o modelo com toda a memoria do dia
    
    if reward > melhor_reward:
        melhor_reward = reward
    return reward #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        #print("dia {0} de {1}: R$ {2:0.2f}".format(dia, dias, reward)) #mostra o resultado do dia
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    #modelo.epsilon = 0.1
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            #s=time.time()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f}".format(epoca, sum_rewards))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0
            #e=time.time()
            #print(e-s)
            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
        print("Somatoria dos rewards: {0:0.2f}".format(sum_rewards_total))
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# resultado da epoca 0 = 33396.77
# 112
# 107
# resultado da epoca 1 = -65362.48
# 117
# 102
# resultado da epoca 2 = -19478.50
# 103
# 116
# resultado da epoca 3 = -70623.86
# 105
# 114
# resultado da epoca 4 = -110886.08
# 103
# 116
# resultado da epoca 5 = 36137.16
# 114
# 105
# resultado da epoca 6 = 9514.17
# 113
# 106
# resultado da epoca 7 = 17609.72
# 109
# 110
# resultado da epoca 8 = 134292.84
# 121
# 98
# resultado da epoca 9 = -176389.02
# 93
# 126
# resultado da epoca 10 = 16543.35
# 118
# 101
# resultado da epoca 11 = 87171.52
# 111
# 108
# resultado da epoca 12 = -102888.13
# 100
# 119
# resultado da epoca 13 = -15187.96
# 112
# 107
# resultado da epoca 14 = 29366.88
# 110
# 109
# resultado da epoca 15 = -84502.07
# 101
# 118
# resultado da epoca 16 = -95560.28
# 102
# 117
# resultado da epoca 17 = 19317.98
# 117
# 102
# resultado da epoca 18 = -44077.99
# 106
# 113
# resultado da epoca 19 = 5860.77
# 118
# 101
# resultado da epoca 20 = 3409.47
# 114
# 105
# resultado da epoca 21 = -88674.95
# 104
# 115
# resultado da epoca 22 = -30702.72
# 107
# 112
# resultado da epoca 23 = 33720.95
# 101
# 118
# resultado da epoca 24 = 115644.60
# 107
# 112
# resultado da epoca 25 = 13708.64
# 112
# 107
# resultado da epoca 26 = 8564.90
# 106
# 113
# resultado da epoca 27 = -183920.45
# 104
# 115
# resultado da epoca 28 = 29979.13
# 113
# 106
# resultado da epoca 29 = 93619.47
# 121
# 98
# resultado da epoca 30 = 26204.92
# 110
# 109
# resultado da epoca 31 = 79323.32
# 105
# 114
# resultado da epoca 32 = -74767.13
# 105
# 114
# resultado da epoca 33 = 20531.68
# 111
# 108
# resultado da epoca 34 = -127452.99
# 105
# 114
# resultado da epoca 35 = 8321.46
# 107
# 112
# resultado da epoca 36 = -74345.85
# 109
# 110
# resultado da epoca 37 = -66514.06
# 98
# 121
# resultado da epoca 38 = 15372.71
# 112
# 107
# resultado da epoca 39 = 43825.97
# 103
# 116
# resultado da epoca 40 = -77397.38
# 111
# 108
# resultado da epoca 41 = -29794.26
# 95
# 124
# resultado da epoca 42 = 123.17
# 105
# 114
# resultado da epoca 43 = 75865.91
# 114
# 105
# resultado da epoca 44 = 53290.90
# 115
# 104
# resultado da epoca 45 = 47017.71
# 111
# 108
# resultado da epoca 46 = 97801.35
# 116
# 103
# resultado da epoca 47 = 38460.83
# 111
# 108
# resultado da epoca 48 = -81144.15
# 101
# 118
# resultado da epoca 49 = -234040.23
# 92
# 127
# resultado da epoca 50 = -6406.72
# 108
# 111
# resultado da epoca 51 = 119245.60
# 118
# 101
# resultado da epoca 52 = -83641.15
# 110
# 109
# resultado da epoca 53 = -133561.41
# 99
# 120
# resultado da epoca 54 = 56470.86
# 103
# 116
# resultado da epoca 55 = -24229.90
# 109
# 110
# resultado da epoca 56 = 32796.54
# 116
# 103
# resultado da epoca 57 = 58097.57
# 114
# 105
# resultado da epoca 58 = -53285.92
# 102
# 117
# resultado da epoca 59 = -44201.89
# 104
# 115
# resultado da epoca 60 = 59320.65
# 118
# 101
# resultado da epoca 61 = -49449.77
# 100
# 119
# resultado da epoca 62 = -5031.28
# 109
# 110
# resultado da epoca 63 = 26210.55
# 106
# 113
# resultado da epoca 64 = -39908.85
# 107
# 112
# resultado da epoca 65 = -51569.82
# 111
# 108
# resultado da epoca 66 = 13274.47
# 111
# 108
# resultado da epoca 67 = -93148.84
# 100
# 119
# resultado da epoca 68 = 54847.55
# 108
# 111
# resultado da epoca 69 = -69333.42
# 98
# 121
# resultado da epoca 70 = -61766.70
# 101
# 118
# resultado da epoca 71 = -1332.11
# 103
# 116
# resultado da epoca 72 = -96181.67
# 109
# 110
# resultado da epoca 73 = 152972.59
# 120
# 99
# resultado da epoca 74 = -64522.97
# 97
# 122
# resultado da epoca 75 = -30072.09
# 109
# 110
# resultado da epoca 76 = 796.80
# 105
# 114
# resultado da epoca 77 = -12451.11
# 104
# 115
# resultado da epoca 78 = -44533.08
# 108
# 111
# resultado da epoca 79 = -30074.39
# 111
# 108
# resultado da epoca 80 = -99967.77
# 108
# 111
# resultado da epoca 81 = 88241.08
# 105
# 114
# resultado da epoca 82 = -56256.74
# 97
# 122
# resultado da epoca 83 = 80720.53
# 104
# 115
# resultado da epoca 84 = -11091.33
# 99
# 120
# resultado da epoca 85 = -11889.49
# 100
# 119
# resultado da epoca 86 = 32264.86
# 111
# 108
# resultado da epoca 87 = 95593.59
# 108
# 111
# resultado da epoca 88 = 6994.11
# 110
# 109
# resultado da epoca 89 = -24408.71
# 111
# 108
# resultado da epoca 90 = -44257.32
# 110
# 109
# resultado da epoca 91 = 4648.89
# 108
# 111
# resultado da epoca 92 = -39728.78
# 93
# 126
# resultado da epoca 93 = -78060.93
# 105
# 114
# resultado da epoca 94 = -46978.75
# 102
# 117
# resultado da epoca 95 = -17696.40
# 109
# 110
# resultado da epoca 96 = -10430.90
# 119
# 100
# resultado da epoca 97 = -32685.45
# 110
# 109
# resultado da epoca 98 = -149703.60
# 97
# 122
# resultado da epoca 99 = -40539.46
# 99
# 120
# resultado da epoca 100 = -57189.57
# 114
# 105
# resultado da epoca 101 = 33755.98
# 125
# 94
# resultado da epoca 102 = -79812.53
# 91
# 128
# resultado da epoca 103 = -69387.41
# 89
# 130
# resultado da epoca 104 = -120951.37
# 101
# 118
# resultado da epoca 105 = 40004.02
# 107
# 112
# resultado da epoca 106 = 127506.48
# 111
# 108
# resultado da epoca 107 = 31928.94
# 111
# 108
# resultado da epoca 108 = -54229.33
# 98
# 121
# resultado da epoca 109 = -63276.72
# 102
# 117
# resultado da epoca 110 = -30835.76
# 113
# 106
# resultado da epoca 111 = -113852.93
# 101
# 118
# resultado da epoca 112 = 944.52
# 107
# 112
# resultado da epoca 113 = -115824.52
# 97
# 122
# resultado da epoca 114 = -20776.66
# 110
# 109
# resultado da epoca 115 = -22887.24
# 106
# 113
# resultado da epoca 116 = -19066.62
# 109
# 110
# resultado da epoca 117 = 9933.62
# 109
# 110
# resultado da epoca 118 = 113521.21
# 121
# 98
# resultado da epoca 119 = -49274.07
# 105
# 114
# resultado da epoca 120 = -117714.25
# 109
# 110
# resultado da epoca 121 = -1158.17
# 108
# 111
# resultado da epoca 122 = 55152.67
# 112
# 107
# resultado da epoca 123 = -102656.88
# 100
# 119
# resultado da epoca 124 = 63000.14
# 106
# 113
# resultado da epoca 125 = 5242.43
# 108
# 111
# resultado da epoca 126 = 1387.73
# 107
# 112
# resultado da epoca 127 = -71320.10
# 94
# 125
# resultado da epoca 128 = -67714.52
# 111
# 108
# resultado da epoca 129 = 73374.32
# 115
# 104
# resultado da epoca 130 = 6373.04
# 109
# 110
# resultado da epoca 131 = 75183.23
# 120
# 99
# resultado da epoca 132 = -47526.92
# 104
# 115
# resultado da epoca 133 = 57600.85
# 110
# 109
# resultado da epoca 134 = 63853.02
# 116
# 103
# resultado da epoca 135 = 127443.45
# 119
# 100
# resultado da epoca 136 = -98474.46
# 101
# 118
# resultado da epoca 137 = -16588.26
# 110
# 109
# resultado da epoca 138 = 67502.77
# 117
# 102
# resultado da epoca 139 = 49297.73
# 110
# 109
# resultado da epoca 140 = -17507.41
# 103
# 116
# resultado da epoca 141 = -47899.53
# 110
# 109
# resultado da epoca 142 = -42920.12
# 95
# 124
# resultado da epoca 143 = -14314.71
# 106
# 113
# resultado da epoca 144 = -30541.76
# 105
# 114
# resultado da epoca 145 = 109201.95
# 104
# 115
# resultado da epoca 146 = 98599.12
# 119
# 100
# resultado da epoca 147 = -4298.29
# 106
# 113
# resultado da epoca 148 = -14984.78
# 95
# 124
# resultado da epoca 149 = 3420.47
# 107
# 112
# resultado da epoca 150 = -60824.26
# 104
# 115
# resultado da epoca 151 = -77957.60
# 103
# 116
# resultado da epoca 152 = 20698.10
# 121
# 98
# resultado da epoca 153 = -51256.45
# 103
# 116
# resultado da epoca 154 = -80997.53
# 99
# 120
# resultado da epoca 155 = 8779.39
# 113
# 106
# resultado da epoca 156 = -56920.12
# 108
# 111
# resultado da epoca 157 = -1415.13
# 111
# 108
# resultado da epoca 158 = 66973.75
# 112
# 107
# resultado da epoca 159 = 34733.46
# 115
# 104
# resultado da epoca 160 = -26001.95
# 107
# 112
# resultado da epoca 161 = -82934.71
# 103
# 116
# resultado da epoca 162 = -92514.25
# 102
# 117
# resultado da epoca 163 = -5242.02
# 103
# 116
# resultado da epoca 164 = -86222.20
# 101
# 118
# resultado da epoca 165 = -77406.69
# 94
# 125
# resultado da epoca 166 = -12475.88
# 113
# 106
# resultado da epoca 167 = 124867.75
# 124
# 95
# resultado da epoca 168 = -72776.49
# 102
# 117
# resultado da epoca 169 = -55657.77
# 101
# 118
# resultado da epoca 170 = -43470.88
# 105
# 114
# resultado da epoca 171 = -25171.79
# 98
# 121
# resultado da epoca 172 = -46037.38
# 105
# 114
# resultado da epoca 173 = 2552.26
# 107
# 112
# resultado da epoca 174 = 25146.13
# 118
# 101
# resultado da epoca 175 = 14305.79
# 102
# 117
# resultado da epoca 176 = 52711.96
# 111
# 108
# resultado da epoca 177 = 36884.32
# 109
# 110
# resultado da epoca 178 = 24247.23
# 111
# 108
# resultado da epoca 179 = 154700.16
# 112
# 107
# resultado da epoca 180 = -21998.92
# 103
# 116
# resultado da epoca 181 = -77120.20
# 113
# 106
# resultado da epoca 182 = -108253.44
# 97
# 122
# resultado da epoca 183 = -70885.59
# 100
# 119
# resultado da epoca 184 = 4844.44
# 104
# 115
# resultado da epoca 185 = -16656.25
# 90
# 129
# resultado da epoca 186 = -78710.51
# 111
# 108
# resultado da epoca 187 = 74310.22
# 112
# 107
# resultado da epoca 188 = -14403.25
# 111
# 108
# resultado da epoca 189 = -59374.74
# 99
# 120
# resultado da epoca 190 = 46416.50
# 110
# 109
# resultado da epoca 191 = -74294.90
# 109
# 110
# resultado da epoca 192 = -32132.62
# 110
# 109
# resultado da epoca 193 = 18605.12
# 115
# 104
# resultado da epoca 194 = 127028.03
# 114
# 105
# resultado da epoca 195 = -58854.85
# 105
# 114
# resultado da epoca 196 = -59138.76
# 112
# 107
# resultado da epoca 197 = -27383.18
# 111
# 108
# resultado da epoca 198 = -15528.73
# 101
# 118
# resultado da epoca 199 = 49035.79
# 116
# 103
# resultado da epoca 200 = 24548.07
# 103
# 116
# resultado da epoca 201 = -28881.11
# 104
# 115
# resultado da epoca 202 = -96105.13
# 100
# 119
# resultado da epoca 203 = -59534.03
# 94
# 125
# resultado da epoca 204 = -29765.28
# 111
# 108
# resultado da epoca 205 = 105620.65
# 118
# 101
# resultado da epoca 206 = -88434.82
# 99
# 120
# resultado da epoca 207 = -11163.73
# 110
# 109
# resultado da epoca 208 = 106092.42
# 104
# 115
# resultado da epoca 209 = -45352.68
# 108
# 111
# resultado da epoca 210 = 265.93
# 110
# 109
# resultado da epoca 211 = -5105.55
# 108
# 111
# resultado da epoca 212 = 1332.60
# 101
# 118
# resultado da epoca 213 = 58593.26
# 111
# 108
# resultado da epoca 214 = 83954.60
# 124
# 95
# resultado da epoca 215 = -2655.39
# 108
# 111
# resultado da epoca 216 = -10306.07
# 99
# 120
# resultado da epoca 217 = -53368.67
# 104
# 115
# resultado da epoca 218 = 103.21
# 99
# 120
# resultado da epoca 219 = 38245.21
# 117
# 102
# resultado da epoca 220 = -67726.28
# 105
# 114
# resultado da epoca 221 = 93775.33
# 109
# 110
# resultado da epoca 222 = -112818.76
# 100
# 119
# resultado da epoca 223 = -42698.66
# 105
# 114
# resultado da epoca 224 = -8638.29
# 113
# 106
# resultado da epoca 225 = 48730.05
# 106
# 113
# resultado da epoca 226 = 26837.01
# 109
# 110
# resultado da epoca 227 = -48669.15
# 113
# 106
# resultado da epoca 228 = 68648.88
# 125
# 94
# resultado da epoca 229 = -32710.81
# 99
# 120
# resultado da epoca 230 = -88932.09
# 102
# 117
# resultado da epoca 231 = -68655.15
# 103
# 116
# resultado da epoca 232 = -30681.36
# 113
# 106
# resultado da epoca 233 = 76511.78
# 116
# 103
# resultado da epoca 234 = 33759.75
# 116
# 103
# resultado da epoca 235 = 38579.95
# 107
# 112
# resultado da epoca 236 = -19414.65
# 100
# 119
# resultado da epoca 237 = 19251.38
# 112
# 107
# resultado da epoca 238 = -51583.58
# 110
# 109
# resultado da epoca 239 = -15118.01
# 107
# 112
# resultado da epoca 240 = -17064.59
# 102
# 117
# resultado da epoca 241 = -115899.89
# 95
# 124
# resultado da epoca 242 = -39811.35
# 101
# 118
# resultado da epoca 243 = -10780.54
# 109
# 110
# resultado da epoca 244 = -850.00
# 118
# 101
# resultado da epoca 245 = -98245.33
# 104
# 115
# resultado da epoca 246 = 32721.95
# 118
# 101
# resultado da epoca 247 = -94058.75
# 98
# 121
# resultado da epoca 248 = -79344.26
# 97
# 122
# resultado da epoca 249 = 19935.31
# 103
# 116
# resultado da epoca 250 = 32026.13
# 107
# 112
# resultado da epoca 251 = -34414.89
# 105
# 114
# resultado da epoca 252 = -40994.65
# 108
# 111
# resultado da epoca 253 = -3074.97
# 107
# 112
# resultado da epoca 254 = 43245.43
# 106
# 113
# resultado da epoca 255 = -28330.98
# 108
# 111
# resultado da epoca 256 = -29972.99
# 111
# 108
# resultado da epoca 257 = 20160.33
# 113
# 106
# resultado da epoca 258 = -76427.42
# 105
# 114
# resultado da epoca 259 = -62084.67
# 99
# 120
# resultado da epoca 260 = -43326.06
# 100
# 119
# resultado da epoca 261 = -63317.02
# 100
# 119
# resultado da epoca 262 = -80589.72
# 99
# 120
# resultado da epoca 263 = 51176.00
# 112
# 107
# resultado da epoca 264 = 57707.57
# 111
# 108
# resultado da epoca 265 = -3422.77
# 110
# 109
# resultado da epoca 266 = 38017.02
# 113
# 106
# resultado da epoca 267 = -23743.56
# 111
# 108
# resultado da epoca 268 = -82637.38
# 100
# 119
# resultado da epoca 269 = -110366.83
# 93
# 126
# resultado da epoca 270 = 51087.50
# 115
# 104
# resultado da epoca 271 = 31783.78
# 119
# 100
# resultado da epoca 272 = -140280.55
# 99
# 120
# resultado da epoca 273 = -13862.32
# 102
# 117
# resultado da epoca 274 = 34866.56
# 107
# 112
# resultado da epoca 275 = 22307.33
# 106
# 113
# resultado da epoca 276 = 783.43
# 107
# 112
# resultado da epoca 277 = 12186.85
# 113
# 106
# resultado da epoca 278 = 8508.55
# 114
# 105
# resultado da epoca 279 = 35881.03
# 117
# 102
# resultado da epoca 280 = -46620.44
# 105
# 114
# resultado da epoca 281 = -84607.27
# 91
# 128
# resultado da epoca 282 = -35322.27
# 103
# 116
# resultado da epoca 283 = -1596.90
# 103
# 116
# resultado da epoca 284 = -101001.49
# 93
# 126
# resultado da epoca 285 = -96128.50
# 94
# 125
# resultado da epoca 286 = -120755.97
# 102
# 117
# resultado da epoca 287 = -26547.95
# 106
# 113
# resultado da epoca 288 = -19918.43
# 104
# 115
# resultado da epoca 289 = -19404.84
# 117
# 102
# resultado da epoca 290 = -31091.81
# 110
# 109
# resultado da epoca 291 = -54192.37
# 109
# 110
# resultado da epoca 292 = -10296.09
# 107
# 112
# resultado da epoca 293 = 36224.71
# 110
# 109
# resultado da epoca 294 = 13710.71
# 108
# 111
# resultado da epoca 295 = 74907.03
# 106
# 113
# resultado da epoca 296 = -6120.16
# 105
# 114
# resultado da epoca 297 = -65984.48
# 98
# 121
# resultado da epoca 298 = 56259.75
# 108
# 111
# resultado da epoca 299 = 15836.59
# 111
# 108
# resultado da epoca 300 = -1111.47
# 108
# 111
# resultado da epoca 301 = -42420.24
# 94
# 125
# resultado da epoca 302 = 65741.96
# 109
# 110
# resultado da epoca 303 = 64256.73
# 120
# 99
# resultado da epoca 304 = -43342.03
# 106
# 113
# resultado da epoca 305 = 4966.61
# 112
# 107
# resultado da epoca 306 = 117180.65
# 127
# 92
# resultado da epoca 307 = -64788.79
# 98
# 121
# resultado da epoca 308 = -40196.68
# 110
# 109
# resultado da epoca 309 = -44833.49
# 104
# 115
# resultado da epoca 310 = -52947.80
# 98
# 121
# resultado da epoca 311 = 192042.31
# 123
# 96
# resultado da epoca 312 = 22088.67
# 102
# 117
# resultado da epoca 313 = -12656.67
# 112
# 107
# resultado da epoca 314 = -75090.69
# 111
# 108
# resultado da epoca 315 = -41976.36
# 114
# 105
# resultado da epoca 316 = -55340.19
# 108
# 111
# resultado da epoca 317 = -12965.34
# 102
# 117
# resultado da epoca 318 = -22567.70
# 104
# 115
# resultado da epoca 319 = -10000.95
# 112
# 107
# resultado da epoca 320 = 14775.26
# 106
# 113
# resultado da epoca 321 = -24771.64
# 105
# 114
# resultado da epoca 322 = 50104.27
# 118
# 101
# resultado da epoca 323 = -51958.13
# 98
# 121
# resultado da epoca 324 = 36876.84
# 114
# 105
# resultado da epoca 325 = 13253.88
# 108
# 111
# resultado da epoca 326 = 38479.50
# 114
# 105
# resultado da epoca 327 = 19551.12
# 110
# 109
# resultado da epoca 328 = 40659.81
# 110
# 109
# resultado da epoca 329 = -107044.14
# 85
# 134
# resultado da epoca 330 = 117163.98
# 118
# 101
# resultado da epoca 331 = 21616.02
# 107
# 112
# resultado da epoca 332 = -88018.82
# 99
# 120
# resultado da epoca 333 = 40373.69
# 107
# 112
# resultado da epoca 334 = -15111.00
# 99
# 120
# resultado da epoca 335 = 43255.53
# 108
# 111
# resultado da epoca 336 = 56621.62
# 119
# 100
# resultado da epoca 337 = 42762.22
# 113
# 106
# resultado da epoca 338 = -43115.48
# 107
# 112
# resultado da epoca 339 = 99295.86
# 115
# 104
# resultado da epoca 340 = -76022.33
# 99
# 120
# resultado da epoca 341 = -47684.52
# 107
# 112
# resultado da epoca 342 = 49884.75
# 103
# 116
# resultado da epoca 343 = 103184.23
# 121
# 98
# resultado da epoca 344 = 16642.40
# 111
# 108
# resultado da epoca 345 = 32849.95
# 115
# 104
# resultado da epoca 346 = -20041.69
# 105
# 114
# resultado da epoca 347 = -22591.70
# 111
# 108
# resultado da epoca 348 = -29459.61
# 107
# 112
# resultado da epoca 349 = 145563.61
# 110
# 109
# resultado da epoca 350 = 77223.55
# 115
# 104
# resultado da epoca 351 = 25590.46
# 113
# 106
# resultado da epoca 352 = 69020.30
# 114
# 105
# resultado da epoca 353 = 40275.87
# 105
# 114
# resultado da epoca 354 = 11960.49
# 114
# 105
# resultado da epoca 355 = 28084.77
# 116
# 103
# resultado da epoca 356 = 20121.74
# 111
# 108
# resultado da epoca 357 = 47217.57
# 108
# 111
# resultado da epoca 358 = -57514.49
# 105
# 114
# resultado da epoca 359 = -13340.71
# 99
# 120
# resultado da epoca 360 = 50319.60
# 104
# 115
# resultado da epoca 361 = -19609.66
# 103
# 116
# resultado da epoca 362 = 25336.20
# 107
# 112
# resultado da epoca 363 = -4075.60
# 110
# 109
# resultado da epoca 364 = -26975.81
# 101
# 118
# resultado da epoca 365 = -4850.49
# 102
# 117
# resultado da epoca 366 = -25239.42
# 108
# 111
# resultado da epoca 367 = 11662.52
# 98
# 121
# resultado da epoca 368 = -32364.67
# 98
# 121
# resultado da epoca 369 = 47580.46
# 118
# 101
# resultado da epoca 370 = -102439.57
# 93
# 126
# resultado da epoca 371 = -70679.27
# 92
# 127
# resultado da epoca 372 = 1023.28
# 99
# 120
# resultado da epoca 373 = -9400.69
# 104
# 115
# resultado da epoca 374 = -27537.91
# 99
# 120
# resultado da epoca 375 = -59923.47
# 98
# 121
# resultado da epoca 376 = -11505.91
# 110
# 109
# resultado da epoca 377 = -26704.91
# 103
# 116
# resultado da epoca 378 = -40245.78
# 100
# 119
# resultado da epoca 379 = 814.20
# 101
# 118
# resultado da epoca 380 = 64178.76
# 117
# 102
# resultado da epoca 381 = -35826.96
# 96
# 123
# resultado da epoca 382 = 14811.44
# 112
# 107
# resultado da epoca 383 = 12282.17
# 96
# 123
# resultado da epoca 384 = -20386.47
# 103
# 116
# resultado da epoca 385 = -33838.05
# 101
# 118
# resultado da epoca 386 = -43261.95
# 105
# 114
# resultado da epoca 387 = 82120.78
# 116
# 103
# resultado da epoca 388 = -24473.27
# 106
# 113
# resultado da epoca 389 = -27206.64
# 105
# 114
# resultado da epoca 390 = -1773.35
# 105
# 114
# resultado da epoca 391 = -16139.20
# 100
# 119
# resultado da epoca 392 = 20052.68
# 105
# 114
# resultado da epoca 393 = -67794.81
# 98
# 121
# resultado da epoca 394 = 85125.56
# 116
# 103
# resultado da epoca 395 = 1450.28
# 106
# 113
# resultado da epoca 396 = 30260.25
# 107
# 112
# resultado da epoca 397 = -29648.16
# 109
# 110
# resultado da epoca 398 = 65419.92
# 115
# 104
# resultado da epoca 399 = 29586.35
# 104
# 115
# resultado da epoca 400 = -1272.81
# 100
# 119
# resultado da epoca 401 = 68739.23
# 112
# 107
# resultado da epoca 402 = 90.83
# 114
# 105
# resultado da epoca 403 = -24788.43
# 116
# 103
# resultado da epoca 404 = 10989.68
# 106
# 113
# resultado da epoca 405 = 23042.35
# 113
# 106
# resultado da epoca 406 = -46095.42
# 102
# 117
# resultado da epoca 407 = 82683.93
# 116
# 103
# resultado da epoca 408 = 58011.42
# 105
# 114
# resultado da epoca 409 = 46493.34
# 108
# 111
# resultado da epoca 410 = 33020.66
# 106
# 113
# resultado da epoca 411 = 13789.66
# 96
# 123
# resultado da epoca 412 = -22427.31
# 102
# 117
# resultado da epoca 413 = -58325.18
# 103
# 116
# resultado da epoca 414 = -38550.68
# 110
# 109
# resultado da epoca 415 = -87194.24
# 99
# 120
# resultado da epoca 416 = 13042.54
# 106
# 113
# resultado da epoca 417 = 26530.08
# 113
# 106
# resultado da epoca 418 = -7858.88
# 99
# 120
# resultado da epoca 419 = 63433.72
# 106
# 113
# resultado da epoca 420 = 69477.56
# 105
# 114
# resultado da epoca 421 = 7038.10
# 94
# 125
# resultado da epoca 422 = 11610.22
# 99
# 120
# resultado da epoca 423 = -9047.45
# 108
# 111
# resultado da epoca 424 = 3614.94
# 109
# 110
# resultado da epoca 425 = -2853.33
# 101
# 118
# resultado da epoca 426 = 72540.84
# 105
# 114
# resultado da epoca 427 = -12943.10
# 106
# 113
# resultado da epoca 428 = -36437.79
# 102
# 117
# resultado da epoca 429 = -13883.37
# 102
# 117
# resultado da epoca 430 = -14899.29
# 102
# 117
# resultado da epoca 431 = 13398.47
# 105
# 114
# resultado da epoca 432 = -3003.63
# 95
# 124
# resultado da epoca 433 = -26658.39
# 97
# 122
# resultado da epoca 434 = -105295.21
# 101
# 118
# resultado da epoca 435 = -1370.49
# 96
# 123
# resultado da epoca 436 = -25862.11
# 105
# 114
# resultado da epoca 437 = -2480.58
# 111
# 108
# resultado da epoca 438 = -56246.94
# 99
# 120
# resultado da epoca 439 = -66236.86
# 101
# 118
# resultado da epoca 440 = 83746.58
# 103
# 116
# resultado da epoca 441 = -9511.98
# 94
# 125
# resultado da epoca 442 = -5567.98
# 112
# 107
# resultado da epoca 443 = 9256.53
# 105
# 114
# resultado da epoca 444 = -20416.69
# 110
# 109
# resultado da epoca 445 = -47498.18
# 97
# 122
# resultado da epoca 446 = -43389.63
# 99
# 120
# resultado da epoca 447 = -17518.85
# 112
# 107
# resultado da epoca 448 = 32268.13
# 109
# 110
# resultado da epoca 449 = -60344.52
# 98
# 121
# resultado da epoca 450 = -68026.82
# 96
# 123
# resultado da epoca 451 = -105239.78
# 92
# 127
# resultado da epoca 452 = 46726.77
# 104
# 115
# resultado da epoca 453 = -12429.62
# 96
# 123
# resultado da epoca 454 = -44481.64
# 104
# 115
# resultado da epoca 455 = -2854.53
# 103
# 116
# resultado da epoca 456 = -82165.14
# 99
# 120
# resultado da epoca 457 = -32954.17
# 95
# 124
# resultado da epoca 458 = -59455.37
# 101
# 118
# resultado da epoca 459 = -104177.71
# 91
# 128
# resultado da epoca 460 = 78533.59
# 111
# 108
# resultado da epoca 461 = -62690.06
# 84
# 135
# resultado da epoca 462 = -25040.50
# 99
# 120
# resultado da epoca 463 = 14354.76
# 108
# 111
# resultado da epoca 464 = 8539.02
# 107
# 112
# resultado da epoca 465 = 70489.98
# 116
# 103
# resultado da epoca 466 = 80179.33
# 105
# 114
# resultado da epoca 467 = -9789.75
# 101
# 118
# resultado da epoca 468 = -500.36
# 103
# 116
# resultado da epoca 469 = -104530.91
# 94
# 125
# resultado da epoca 470 = -85895.47
# 97
# 122
# resultado da epoca 471 = -71223.39
# 99
# 120
# resultado da epoca 472 = -12979.04
# 100
# 119
# resultado da epoca 473 = 100701.00
# 104
# 115
# resultado da epoca 474 = 13869.76
# 91
# 128
# resultado da epoca 475 = 46587.61
# 111
# 108
# resultado da epoca 476 = -7928.52
# 96
# 123
# resultado da epoca 477 = -50494.93
# 108
# 111
# resultado da epoca 478 = -70034.73
# 97
# 122
# resultado da epoca 479 = 59726.72
# 111
# 108
# resultado da epoca 480 = -30091.02
# 98
# 121
# resultado da epoca 481 = 41023.71
# 116
# 103
# resultado da epoca 482 = -59106.38
# 104
# 115
# resultado da epoca 483 = 2937.32
# 85
# 134
# resultado da epoca 484 = -50594.23
# 99
# 120
# resultado da epoca 485 = -73018.08
# 112
# 107
# resultado da epoca 486 = 22268.62
# 112
# 107
# resultado da epoca 487 = -5811.39
# 97
# 122
# resultado da epoca 488 = -25080.49
# 113
# 106
# resultado da epoca 489 = -62125.70
# 102
# 117
# resultado da epoca 490 = -114737.35
# 100
# 119
# resultado da epoca 491 = -59691.93
# 101
# 118
# resultado da epoca 492 = -40583.89
# 88
# 131
# resultado da epoca 493 = -56635.30
# 100
# 119
# resultado da epoca 494 = 5280.69
# 89
# 130
# resultado da epoca 495 = 62614.95
# 103
# 116
# resultado da epoca 496 = -3047.16
# 111
# 108
# resultado da epoca 497 = 9292.87
# 98
# 121
# resultado da epoca 498 = 84053.76
# 108
# 111
# resultado da epoca 499 = 48871.57
# 104
# 115
# resultado da epoca 500 = 1157.28
# 90
# 129
# resultado da epoca 501 = 62000.48
# 105
# 114
# resultado da epoca 502 = -66574.46
# 92
# 127
# resultado da epoca 503 = 54148.81
# 98
# 121
# resultado da epoca 504 = 22625.25
# 106
# 113
# resultado da epoca 505 = -55757.54
# 91
# 128
# resultado da epoca 506 = 45625.08
# 107
# 112
# resultado da epoca 507 = -1744.38
# 105
# 114
# resultado da epoca 508 = 30273.03
# 101
# 118
# resultado da epoca 509 = -52036.58
# 98
# 121
# resultado da epoca 510 = 85185.51
# 115
# 104
# resultado da epoca 511 = -50917.83
# 90
# 129
# resultado da epoca 512 = 80153.76
# 116
# 103
# resultado da epoca 513 = 46193.32
# 103
# 116
# resultado da epoca 514 = -18589.48
# 94
# 125
# resultado da epoca 515 = -27960.51
# 107
# 112
# resultado da epoca 516 = -35855.06
# 106
# 113
# resultado da epoca 517 = -37910.47
# 88
# 131
# resultado da epoca 518 = 803.15
# 103
# 116
# resultado da epoca 519 = -66644.32
# 89
# 130
# resultado da epoca 520 = -16107.47
# 114
# 105
# resultado da epoca 521 = -47409.54
# 102
# 117
# resultado da epoca 522 = 38131.56
# 103
# 116
# resultado da epoca 523 = -91665.02
# 85
# 134
# resultado da epoca 524 = -10641.43
# 97
# 122
# resultado da epoca 525 = -4937.16
# 100
# 119
# resultado da epoca 526 = 32654.92
# 107
# 112
# resultado da epoca 527 = -113307.53
# 89
# 130
# resultado da epoca 528 = -9001.11
# 108
# 111
# resultado da epoca 529 = -32298.52
# 108
# 111
# resultado da epoca 530 = 1492.73
# 111
# 108
# resultado da epoca 531 = 25644.64
# 103
# 116
# resultado da epoca 532 = 600.67
# 102
# 117
# resultado da epoca 533 = 75962.50
# 99
# 120
# resultado da epoca 534 = -55873.34
# 81
# 138
# resultado da epoca 535 = 72245.02
# 107
# 112
# resultado da epoca 536 = 27942.48
# 107
# 112
# resultado da epoca 537 = 25939.84
# 111
# 108
# resultado da epoca 538 = -39212.93
# 95
# 124
# resultado da epoca 539 = 7242.43
# 96
# 123
# resultado da epoca 540 = 22454.10
# 91
# 128
# resultado da epoca 541 = -29064.90
# 104
# 115
# resultado da epoca 542 = -23289.81
# 92
# 127
# resultado da epoca 543 = 75062.53
# 109
# 110
# resultado da epoca 544 = 13478.29
# 89
# 130
# resultado da epoca 545 = 72921.17
# 109
# 110
# resultado da epoca 546 = 11466.64
# 97
# 122
# resultado da epoca 547 = -3731.71
# 99
# 120
# resultado da epoca 548 = 59296.02
# 95
# 124
# resultado da epoca 549 = -32519.32
# 93
# 126
# resultado da epoca 550 = -14725.26
# 97
# 122
# resultado da epoca 551 = 110981.77
# 108
# 111
# resultado da epoca 552 = 33787.62
# 101
# 118
# resultado da epoca 553 = 22687.35
# 101
# 118
# resultado da epoca 554 = 13629.41
# 98
# 121
# resultado da epoca 555 = 101192.41
# 106
# 113
# resultado da epoca 556 = 9115.65
# 96
# 123
# resultado da epoca 557 = 119631.86
# 118
# 101
# resultado da epoca 558 = 102530.93
# 107
# 112
# resultado da epoca 559 = 50680.61
# 97
# 122
# resultado da epoca 560 = -18971.95
# 112
# 107
# resultado da epoca 561 = 3408.22
# 91
# 128
# resultado da epoca 562 = 93405.28
# 103
# 116
# resultado da epoca 563 = 82397.25
# 116
# 103
# resultado da epoca 564 = -26361.98
# 86
# 133
# resultado da epoca 565 = 34069.35
# 88
# 131
# resultado da epoca 566 = 50650.18
# 106
# 113
# resultado da epoca 567 = -31519.35
# 91
# 128
# resultado da epoca 568 = 24654.13
# 91
# 128
# resultado da epoca 569 = 8726.77
# 93
# 126
# resultado da epoca 570 = -38644.27
# 77
# 142
# resultado da epoca 571 = 15375.81
# 93
# 126
# resultado da epoca 572 = 70379.92
# 97
# 122
# resultado da epoca 573 = 105329.72
# 103
# 116
# resultado da epoca 574 = 3283.37
# 80
# 139
# resultado da epoca 575 = 77066.07
# 105
# 114
# resultado da epoca 576 = 165752.62
# 111
# 108
# resultado da epoca 577 = 111348.52
# 97
# 122
# resultado da epoca 578 = 134647.35
# 107
# 112
# resultado da epoca 579 = 92110.21
# 103
# 116
# resultado da epoca 580 = 88177.05
# 99
# 120
# resultado da epoca 581 = 96021.29
# 91
# 128
# resultado da epoca 582 = 132474.91
# 109
# 110
# resultado da epoca 583 = 56819.22
# 87
# 132
# resultado da epoca 584 = 103432.44
# 89
# 130
# resultado da epoca 585 = 63495.85
# 87
# 132
# resultado da epoca 586 = -49546.53
# 82
# 137
# resultado da epoca 587 = -31985.93
# 87
# 132
# resultado da epoca 588 = -95186.22
# 79
# 140
# resultado da epoca 589 = 10789.78
# 91
# 128
# resultado da epoca 590 = -113379.87
# 83
# 136
# resultado da epoca 591 = -135843.27
# 84
# 135
# resultado da epoca 592 = -87739.63
# 86
# 133
# resultado da epoca 593 = -70223.34
# 91
# 128
# resultado da epoca 594 = -80176.02
# 91
# 128
# resultado da epoca 595 = -108067.71
# 82
# 137
# resultado da epoca 596 = -117216.45
# 93
# 126
# resultado da epoca 597 = -68080.19
# 85
# 134
# resultado da epoca 598 = -66534.55
# 87
# 132
# resultado da epoca 599 = -13651.34
# 97
# 122
# resultado da epoca 600 = 14573.50
# 96
# 123
# resultado da epoca 601 = -19128.98
# 98
# 121
# resultado da epoca 602 = 5268.73
# 96
# 123
# resultado da epoca 603 = -2006.68
# 92
# 127
# resultado da epoca 604 = -60907.08
# 84
# 135
# resultado da epoca 605 = -123044.99
# 82
# 137
# resultado da epoca 606 = -48124.39
# 99
# 120
# resultado da epoca 607 = -62728.23
# 89
# 130
# resultado da epoca 608 = -82879.01
# 91
# 128
# resultado da epoca 609 = 90165.45
# 99
# 120
# resultado da epoca 610 = 40145.70
# 93
# 126
# resultado da epoca 611 = -9645.44
# 73
# 146
# resultado da epoca 612 = 49232.53
# 105
# 114
# resultado da epoca 613 = -9255.27
# 89
# 130
# resultado da epoca 614 = -141355.78
# 85
# 134
# resultado da epoca 615 = 54048.46
# 104
# 115
# resultado da epoca 616 = -3206.56
# 96
# 123
# resultado da epoca 617 = -13081.78
# 82
# 137
# resultado da epoca 618 = -119211.49
# 90
# 129
# resultado da epoca 619 = -77860.19
# 91
# 128
# resultado da epoca 620 = -49526.68
# 87
# 132
# resultado da epoca 621 = 22793.00
# 92
# 127
# resultado da epoca 622 = -13648.75
# 90
# 129
# resultado da epoca 623 = -27772.98
# 86
# 133
# resultado da epoca 624 = -44000.33
# 100
# 119
# resultado da epoca 625 = 69297.64
# 101
# 118
# resultado da epoca 626 = 72783.56
# 96
# 123
# resultado da epoca 627 = 111936.89
# 92
# 127
# resultado da epoca 628 = -6592.01
# 88
# 131
# resultado da epoca 629 = -3969.97
# 87
# 132
# resultado da epoca 630 = 98713.99
# 84
# 135
# resultado da epoca 631 = -41786.40
# 88
# 131
# resultado da epoca 632 = -11294.05
# 87
# 132
# resultado da epoca 633 = 8401.90
# 91
# 128
# resultado da epoca 634 = 7556.99
# 90
# 129
# resultado da epoca 635 = -50377.34
# 88
# 131
# resultado da epoca 636 = -56251.89
# 88
# 131
# resultado da epoca 637 = -34690.49
# 86
# 133
# resultado da epoca 638 = 30320.44
# 100
# 119
# resultado da epoca 639 = -74333.17
# 85
# 134
# resultado da epoca 640 = -113557.68
# 86
# 133
# resultado da epoca 641 = -97268.12
# 89
# 130
# resultado da epoca 642 = -77935.37
# 96
# 123
# resultado da epoca 643 = -65424.13
# 93
# 126
# resultado da epoca 644 = -86272.74
# 90
# 129
# resultado da epoca 645 = -35172.26
# 95
# 124
# resultado da epoca 646 = -95382.78
# 89
# 130
# resultado da epoca 647 = -129657.59
# 84
# 135
# resultado da epoca 648 = -84815.76
# 90
# 129
# resultado da epoca 649 = -29612.81
# 94
# 125
# resultado da epoca 650 = -73806.90
# 87
# 132
# resultado da epoca 651 = -24056.29
# 100
# 119
# resultado da epoca 652 = -20453.12
# 107
# 112
# resultado da epoca 653 = -9316.62
# 105
# 114
# resultado da epoca 654 = -69424.02
# 93
# 126
# resultado da epoca 655 = -19997.63
# 99
# 120
# resultado da epoca 656 = -41806.54
# 97
# 122
# resultado da epoca 657 = -41326.61
# 102
# 117
# resultado da epoca 658 = 41938.86
# 100
# 119
# resultado da epoca 659 = -84392.12
# 82
# 137
# resultado da epoca 660 = -8449.51
# 98
# 121
# resultado da epoca 661 = -19351.44
# 106
# 113
# resultado da epoca 662 = -60043.65
# 98
# 121
# resultado da epoca 663 = 8668.48
# 101
# 118
# resultado da epoca 664 = 11260.28
# 93
# 126
# resultado da epoca 665 = -64177.44
# 101
# 118
# resultado da epoca 666 = -61826.68
# 96
# 123
# resultado da epoca 667 = -65930.08
# 91
# 128
# resultado da epoca 668 = 49677.15
# 97
# 122
# resultado da epoca 669 = -70487.83
# 96
# 123
# resultado da epoca 670 = -64886.29
# 94
# 125
# resultado da epoca 671 = -23968.80
# 98
# 121
# resultado da epoca 672 = -16833.75
# 89
# 130
# resultado da epoca 673 = -45612.44
# 102
# 117
# resultado da epoca 674 = -14855.79
# 96
# 123
# resultado da epoca 675 = -46938.81
# 103
# 116
# resultado da epoca 676 = -45422.71
# 92
# 127
# resultado da epoca 677 = -93202.36
# 89
# 130
# resultado da epoca 678 = -100930.88
# 89
# 130
# resultado da epoca 679 = -21373.11
# 100
# 119
# resultado da epoca 680 = -72719.03
# 95
# 124
# resultado da epoca 681 = -69856.36
# 92
# 127
# resultado da epoca 682 = -111074.38
# 74
# 145
# resultado da epoca 683 = -43908.30
# 90
# 129
# resultado da epoca 684 = -30026.69
# 97
# 122
# resultado da epoca 685 = -44209.53
# 96
# 123
# resultado da epoca 686 = -39599.04
# 99
# 120
# resultado da epoca 687 = -48414.47
# 93
# 126
# resultado da epoca 688 = 13889.41
# 100
# 119
# resultado da epoca 689 = 42142.37
# 108
# 111
# resultado da epoca 690 = 4901.91
# 95
# 124
# resultado da epoca 691 = 45308.38
# 95
# 124
# resultado da epoca 692 = 82548.85
# 98
# 121
# resultado da epoca 693 = 25508.51
# 84
# 135
# resultado da epoca 694 = 30121.49
# 103
# 116
# resultado da epoca 695 = 10995.40
# 98
# 121
# resultado da epoca 696 = 45954.91
# 105
# 114
# resultado da epoca 697 = 44002.55
# 82
# 137
# resultado da epoca 698 = 63022.99
# 108
# 111
# resultado da epoca 699 = 92036.79
# 111
# 108
# resultado da epoca 700 = -30359.60
# 99
# 120
# resultado da epoca 701 = 69061.11
# 113
# 106
# resultado da epoca 702 = 66257.14
# 94
# 125
# resultado da epoca 703 = 64681.22
# 99
# 120
# resultado da epoca 704 = 31755.15
# 100
# 119
# resultado da epoca 705 = 45312.31
# 108
# 111
# resultado da epoca 706 = 58740.10
# 107
# 112
# resultado da epoca 707 = 69683.23
# 104
# 115
# resultado da epoca 708 = 119184.98
# 139
# 80
# resultado da epoca 709 = 169103.21
# 125
# 94
# resultado da epoca 710 = 97258.97
# 117
# 102
# resultado da epoca 711 = 169989.13
# 128
# 91
# resultado da epoca 712 = 151450.91
# 121
# 98
# resultado da epoca 713 = 117387.49
# 122
# 97
# resultado da epoca 714 = 143072.33
# 126
# 93
# resultado da epoca 715 = 102487.59
# 126
# 93
# resultado da epoca 716 = 127125.70
# 130
# 89
# resultado da epoca 717 = 103884.54
# 111
# 108
# resultado da epoca 718 = 155209.29
# 118
# 101
# resultado da epoca 719 = 172607.16
# 127
# 92
# resultado da epoca 720 = 160660.89
# 132
# 87
# resultado da epoca 721 = 154503.05
# 128
# 91
# resultado da epoca 722 = 159696.95
# 121
# 98
# resultado da epoca 723 = 164338.20
# 119
# 100
# resultado da epoca 724 = 180639.07
# 115
# 104
# resultado da epoca 725 = 121970.30
# 115
# 104
# resultado da epoca 726 = 222862.50
# 120
# 99
# resultado da epoca 727 = 237564.68
# 121
# 98
# resultado da epoca 728 = 247557.81
# 123
# 96
# resultado da epoca 729 = 245177.93
# 117
# 102
# resultado da epoca 730 = 246632.36
# 114
# 105
# resultado da epoca 731 = 198017.82
# 113
# 106
# resultado da epoca 732 = 243402.64
# 119
# 100
# resultado da epoca 733 = 240879.17
# 121
# 98
# resultado da epoca 734 = 216629.53
# 103
# 116
# resultado da epoca 735 = 231964.31
# 116
# 103
# resultado da epoca 736 = 217916.44
# 117
# 102
# resultado da epoca 737 = 301751.55
# 117
# 102
# resultado da epoca 738 = 200128.05
# 112
# 107
# resultado da epoca 739 = 262864.72
# 117
# 102
# resultado da epoca 740 = 194642.15
# 114
# 105
# resultado da epoca 741 = 255988.06
# 121
# 98
# resultado da epoca 742 = 215258.19
# 113
# 106
# resultado da epoca 743 = 278453.97
# 121
# 98
# resultado da epoca 744 = 232565.58
# 120
# 99
# resultado da epoca 745 = 236339.65
# 126
# 93
# resultado da epoca 746 = 284853.15
# 125
# 94
# resultado da epoca 747 = 242105.15
# 119
# 100
# resultado da epoca 748 = 274561.66
# 128
# 91
# resultado da epoca 749 = 239706.63
# 120
# 99
# resultado da epoca 750 = 240120.08
# 119
# 100
# resultado da epoca 751 = 295648.67
# 127
# 92
# resultado da epoca 752 = 246601.68
# 118
# 101
# resultado da epoca 753 = 226746.76
# 112
# 107
# resultado da epoca 754 = 239989.65
# 123
# 96
# resultado da epoca 755 = 217304.99
# 112
# 107
# resultado da epoca 756 = 283366.46
# 121
# 98
# resultado da epoca 757 = 246004.28
# 117
# 102
# resultado da epoca 758 = 304114.17
# 130
# 89
# resultado da epoca 759 = 207575.30
# 127
# 92
# resultado da epoca 760 = 227449.64
# 117
# 102
# resultado da epoca 761 = 268790.25
# 122
# 97
# resultado da epoca 762 = 216971.95
# 118
# 101
# resultado da epoca 763 = 245031.62
# 118
# 101
# resultado da epoca 764 = 290713.37
# 115
# 104
# resultado da epoca 765 = 265160.69
# 113
# 106
# resultado da epoca 766 = 258689.85
# 117
# 102
# resultado da epoca 767 = 270306.66
# 121
# 98
# resultado da epoca 768 = 300212.71
# 123
# 96
# resultado da epoca 769 = 255691.98
# 115
# 104
# resultado da epoca 770 = 232220.32
# 117
# 102
# resultado da epoca 771 = 241573.74
# 123
# 96
# resultado da epoca 772 = 289844.73
# 116
# 103
# resultado da epoca 773 = 325473.71
# 120
# 99
# resultado da epoca 774 = 247524.15
# 118
# 101
# resultado da epoca 775 = 256501.57
# 126
# 93
# resultado da epoca 776 = 300952.13
# 123
# 96
# resultado da epoca 777 = 312341.85
# 127
# 92
# resultado da epoca 778 = 276557.75
# 121
# 98
# resultado da epoca 779 = 294397.68
# 116
# 103
# resultado da epoca 780 = 255158.49
# 120
# 99
# resultado da epoca 781 = 214757.65
# 118
# 101
# resultado da epoca 782 = 281835.45
# 116
# 103
# resultado da epoca 783 = 289721.79
# 120
# 99
# resultado da epoca 784 = 297271.90
# 127
# 92
# resultado da epoca 785 = 278980.87
# 114
# 105
# resultado da epoca 786 = 292969.17
# 123
# 96
# resultado da epoca 787 = 268244.93
# 126
# 93
# resultado da epoca 788 = 312659.82
# 125
# 94
# resultado da epoca 789 = 262894.45
# 121
# 98
# resultado da epoca 790 = 287161.71
# 125
# 94
# resultado da epoca 791 = 317465.04
# 124
# 95
# resultado da epoca 792 = 272399.09
# 118
# 101
# resultado da epoca 793 = 263888.26
# 128
# 91
# resultado da epoca 794 = 262071.24
# 127
# 92
# resultado da epoca 795 = 285759.98
# 127
# 92
# resultado da epoca 796 = 288667.64
# 120
# 99
# resultado da epoca 797 = 286792.52
# 125
# 94
# resultado da epoca 798 = 267180.52
# 127
# 92
# resultado da epoca 799 = 304761.20
# 122
# 97
# resultado da epoca 800 = 287381.36
# 131
# 88
# resultado da epoca 801 = 277948.16
# 124
# 95
# resultado da epoca 802 = 277478.82
# 126
# 93
# resultado da epoca 803 = 303688.88
# 120
# 99
# resultado da epoca 804 = 268286.93
# 129
# 90
# resultado da epoca 805 = 288868.20
# 128
# 91
# resultado da epoca 806 = 263633.30
# 124
# 95
# resultado da epoca 807 = 317081.65
# 133
# 86
# resultado da epoca 808 = 234803.34
# 121
# 98
# resultado da epoca 809 = 81956.53
# 110
# 109
# resultado da epoca 810 = 39725.79
# 119
# 100
# resultado da epoca 811 = 219755.11
# 135
# 84
# resultado da epoca 812 = 52124.53
# 118
# 101
# resultado da epoca 813 = 66974.16
# 119
# 100
# resultado da epoca 814 = 93897.61
# 123
# 96
# resultado da epoca 815 = -75559.31
# 82
# 137
# resultado da epoca 816 = -11052.20
# 95
# 124
# resultado da epoca 817 = 234520.09
# 124
# 95
# resultado da epoca 818 = 65606.93
# 121
# 98
# resultado da epoca 819 = -31759.64
# 91
# 128
# resultado da epoca 820 = 75643.63
# 118
# 101
# resultado da epoca 821 = 108831.03
# 128
# 91
# resultado da epoca 822 = 76130.49
# 123
# 96
# resultado da epoca 823 = -43315.24
# 87
# 132
# resultado da epoca 824 = 40384.61
# 108
# 111
# resultado da epoca 825 = 171666.57
# 138
# 81
# resultado da epoca 826 = 198952.67
# 134
# 85
# resultado da epoca 827 = 56635.16
# 119
# 100
# resultado da epoca 828 = -13491.80
# 111
# 108
# resultado da epoca 829 = 135227.33
# 138
# 81
# resultado da epoca 830 = 60517.69
# 125
# 94
# resultado da epoca 831 = 96699.80
# 129
# 90
# resultado da epoca 832 = 200446.44
# 139
# 80
# resultado da epoca 833 = 126052.06
# 132
# 87
# resultado da epoca 834 = 68489.78
# 126
# 93
# resultado da epoca 835 = 16961.45
# 117
# 102
# resultado da epoca 836 = 260571.71
# 129
# 90
# resultado da epoca 837 = 36608.36
# 125
# 94
# resultado da epoca 838 = 84026.33
# 128
# 91
# resultado da epoca 839 = -48743.51
# 96
# 123
# resultado da epoca 840 = 88952.86
# 128
# 91
# resultado da epoca 841 = 110875.07
# 129
# 90
# resultado da epoca 842 = 227631.61
# 131
# 88
# resultado da epoca 843 = 160773.62
# 142
# 77
# resultado da epoca 844 = 43415.95
# 120
# 99
# resultado da epoca 845 = 32910.43
# 115
# 104
# resultado da epoca 846 = 242279.67
# 128
# 91
# resultado da epoca 847 = 302990.73
# 129
# 90
# resultado da epoca 848 = 178738.56
# 132
# 87
# resultado da epoca 849 = -16147.91
# 116
# 103
# resultado da epoca 850 = 117331.54
# 136
# 83
# resultado da epoca 851 = 70094.50
# 120
# 99
# resultado da epoca 852 = 80265.94
# 131
# 88
# resultado da epoca 853 = 209270.23
# 128
# 91
# resultado da epoca 854 = 330882.27
# 128
# 91
# resultado da epoca 855 = 291733.08
# 132
# 87
# resultado da epoca 856 = 332571.17
# 131
# 88
# resultado da epoca 857 = 321370.33
# 138
# 81
# resultado da epoca 858 = 199163.96
# 145
# 74
# resultado da epoca 859 = 54815.59
# 131
# 88
# resultado da epoca 860 = -15570.83
# 104
# 115
# resultado da epoca 861 = 16495.85
# 116
# 103
# resultado da epoca 862 = 106634.06
# 126
# 93
# resultado da epoca 863 = -38175.09
# 101
# 118
# resultado da epoca 864 = 248108.38
# 135
# 84
# resultado da epoca 865 = 24405.11
# 106
# 113
# resultado da epoca 866 = 93820.42
# 124
# 95
# resultado da epoca 867 = -56388.47
# 95
# 124
# resultado da epoca 868 = -55415.85
# 105
# 114
# resultado da epoca 869 = 84109.01
# 112
# 107
# resultado da epoca 870 = 39350.08
# 111
# 108
# resultado da epoca 871 = 200857.07
# 135
# 84
# resultado da epoca 872 = 243.23
# 105
# 114
# resultado da epoca 873 = 87341.50
# 126
# 93
# resultado da epoca 874 = 103833.22
# 121
# 98
# resultado da epoca 875 = 31841.91
# 104
# 115
# resultado da epoca 876 = 21886.55
# 117
# 102
# resultado da epoca 877 = -14286.95
# 105
# 114
# resultado da epoca 878 = 282588.47
# 128
# 91
# resultado da epoca 879 = 21297.77
# 114
# 105
# resultado da epoca 880 = -74479.77
# 89
# 130
# resultado da epoca 881 = 3264.21
# 117
# 102
# resultado da epoca 882 = -35705.03
# 105
# 114
# resultado da epoca 883 = 31407.44
# 114
# 105
# resultado da epoca 884 = -17435.54
# 106
# 113
# resultado da epoca 885 = 138633.67
# 124
# 95
# resultado da epoca 886 = 5890.04
# 125
# 94
# resultado da epoca 887 = 223598.98
# 131
# 88
# resultado da epoca 888 = 303566.88
# 132
# 87
# resultado da epoca 889 = 74219.32
# 119
# 100
# resultado da epoca 890 = -78892.05
# 96
# 123
# resultado da epoca 891 = 93128.13
# 117
# 102
# resultado da epoca 892 = 265175.19
# 132
# 87
# resultado da epoca 893 = 301391.37
# 132
# 87
# resultado da epoca 894 = 103751.05
# 124
# 95
# resultado da epoca 895 = 361551.34
# 132
# 87
# resultado da epoca 896 = 316637.40
# 132
# 87
# resultado da epoca 897 = 211636.06
# 133
# 86
# resultado da epoca 898 = 118561.76
# 129
# 90
# resultado da epoca 899 = 164986.23
# 141
# 78
# resultado da epoca 900 = 274772.05
# 123
# 96
# resultado da epoca 901 = 35268.17
# 117
# 102
# resultado da epoca 902 = 3267.04
# 106
# 113
# resultado da epoca 903 = 20082.36
# 122
# 97
# resultado da epoca 904 = -72598.55
# 105
# 114
# resultado da epoca 905 = 194678.70
# 130
# 89
# resultado da epoca 906 = 261775.73
# 128
# 91
# resultado da epoca 907 = 169153.17
# 137
# 82
# resultado da epoca 908 = 131759.44
# 123
# 96
# resultado da epoca 909 = 335828.78
# 133
# 86
# resultado da epoca 910 = -45857.52
# 102
# 117
# resultado da epoca 911 = 214981.98
# 117
# 102
# resultado da epoca 912 = 71820.19
# 119
# 100
# resultado da epoca 913 = 219161.60
# 123
# 96
# resultado da epoca 914 = 335375.59
# 129
# 90
# resultado da epoca 915 = 35834.76
# 114
# 105
# resultado da epoca 916 = -6761.37
# 112
# 107
# resultado da epoca 917 = 144035.14
# 134
# 85
# resultado da epoca 918 = -102554.89
# 91
# 128
# resultado da epoca 919 = 172136.18
# 117
# 102
# resultado da epoca 920 = 137786.50
# 127
# 92
# resultado da epoca 921 = -46747.44
# 104
# 115
# resultado da epoca 922 = 130656.28
# 117
# 102
# resultado da epoca 923 = 330191.26
# 132
# 87
# resultado da epoca 924 = -11210.44
# 110
# 109
# resultado da epoca 925 = 238360.45
# 128
# 91
# resultado da epoca 926 = -84699.74
# 87
# 132
# resultado da epoca 927 = -43369.21
# 99
# 120
# resultado da epoca 928 = 209838.77
# 131
# 88
# resultado da epoca 929 = 77943.90
# 115
# 104
# resultado da epoca 930 = -61276.77
# 103
# 116
# resultado da epoca 931 = 341112.15
# 126
# 93
# resultado da epoca 932 = 223463.61
# 128
# 91
# resultado da epoca 933 = 237073.57
# 140
# 79
# resultado da epoca 934 = -40078.97
# 104
# 115
# resultado da epoca 935 = 133424.79
# 132
# 87
# resultado da epoca 936 = -69616.64
# 100
# 119
# resultado da epoca 937 = -146771.92
# 89
# 130
# resultado da epoca 938 = 45064.41
# 125
# 94
# resultado da epoca 939 = 304839.99
# 134
# 85
# resultado da epoca 940 = 18604.01
# 118
# 101
# resultado da epoca 941 = -47518.29
# 111
# 108
# resultado da epoca 942 = 350926.84
# 135
# 84
# resultado da epoca 943 = 15055.98
# 104
# 115
# resultado da epoca 944 = -16336.85
# 110
# 109
# resultado da epoca 945 = 106999.18
# 132
# 87
# resultado da epoca 946 = 216401.93
# 132
# 87
# resultado da epoca 947 = -39326.05
# 116
# 103
# resultado da epoca 948 = 91669.57
# 119
# 100
# resultado da epoca 949 = -28987.39
# 107
# 112
# resultado da epoca 950 = -15351.87
# 103
# 116
# resultado da epoca 951 = 258807.04
# 128
# 91
# resultado da epoca 952 = 392609.74
# 131
# 88
# resultado da epoca 953 = 335008.80
# 135
# 84
# resultado da epoca 954 = -138218.59
# 91
# 128
# resultado da epoca 955 = -24393.23
# 104
# 115
# resultado da epoca 956 = -4380.90
# 110
# 109
# resultado da epoca 957 = 53731.09
# 129
# 90
# resultado da epoca 958 = 97873.77
# 117
# 102
# resultado da epoca 959 = -37135.56
# 109
# 110
# resultado da epoca 960 = 342007.16
# 130
# 89
# resultado da epoca 961 = -48217.71
# 106
# 113
# resultado da epoca 962 = -61192.77
# 108
# 111
# resultado da epoca 963 = 161541.54
# 121
# 98
# resultado da epoca 964 = -30277.55
# 114
# 105
# resultado da epoca 965 = -86320.60
# 97
# 122
# resultado da epoca 966 = -146034.05
# 94
# 125
# resultado da epoca 967 = 38528.51
# 126
# 93
# resultado da epoca 968 = 180697.40
# 138
# 81
# resultado da epoca 969 = 59575.61
# 120
# 99
# resultado da epoca 970 = 41722.97
# 116
# 103
# resultado da epoca 971 = 42076.61
# 116
# 103
# resultado da epoca 972 = 17529.14
# 118
# 101
# resultado da epoca 973 = 165017.03
# 131
# 88
# resultado da epoca 974 = 399633.18
# 131
# 88
# resultado da epoca 975 = 371928.73
# 130
# 89
# resultado da epoca 976 = 340640.51
# 135
# 84
# resultado da epoca 977 = 171352.23
# 139
# 80
# resultado da epoca 978 = 68688.36
# 133
# 86
# resultado da epoca 979 = -74981.59
# 89
# 130
# resultado da epoca 980 = -72211.19
# 95
# 124
# resultado da epoca 981 = -100096.28
# 92
# 127
# resultado da epoca 982 = 215195.88
# 126
# 93
# resultado da epoca 983 = 37761.93
# 116
# 103
# resultado da epoca 984 = -24770.92
# 105
# 114
# resultado da epoca 985 = 69286.52
# 111
# 108
# resultado da epoca 986 = 54580.02
# 127
# 92
# resultado da epoca 987 = -95462.78
# 102
# 117
# resultado da epoca 988 = 44772.11
# 116
# 103
# resultado da epoca 989 = -50481.86
# 107
# 112
# resultado da epoca 990 = 106058.80
# 130
# 89
# resultado da epoca 991 = -56018.54
# 116
# 103
# resultado da epoca 992 = -11508.97
# 120
# 99
# resultado da epoca 993 = -48411.98
# 111
# 108
# resultado da epoca 994 = 130435.11
# 123
# 96
# resultado da epoca 995 = -54286.19
# 103
# 116
# resultado da epoca 996 = -41771.72
# 105
# 114
# resultado da epoca 997 = -86801.49
# 99
# 120
# resultado da epoca 998 = 141954.71
# 136
# 83
# resultado da epoca 999 = -17434.47
# 110
# 109
# 0
# 0
# Somatoria dos rewards: 36384170.09
# Melhor resultado diario: 48129.72
