# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
n_saidas = 3 #nmero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0
lim_cont = 10
posicao_max = 100*lim_cont #define variavel para normalizar a posicao

versao_arquivo = 1

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]
pmax = np.amax( inputs.loc[:, inputs.columns[0]] ) #define valor minimo do preo
pmin = np.amin( inputs.loc[:, inputs.columns[0]] ) #define valor maximo do preo

for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imax = np.amax( inputs.loc[:, inputs.columns[i]] ) #pega valor maximo
    imin = np.amin( inputs.loc[:, inputs.columns[i]] ) #pega valor minimo
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imin ) / ( imax - imin ) #normaliza prs

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
hr = hr/step_max
inputs['hr_int'] = hr


dias = len(steps)
dias = 220

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K            #importa backend para clear_session()

##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria()
        self.gamma = 0.99       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-6
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(192, activation='relu')) #camada escondida
        model.add(Dense(128, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        
        return model

    def limpa_memoria(self):
        self.state = np.empty((0,))
        self.next_state = np.empty((0,))
        self.memory = []
        
    def toma_acao(self, valores_ant, teste):
        if not teste and np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora        
        act_values = self.model.predict(estado, batch_size=1) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=step_max):
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in self.memory:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado, batch_size=batch_size)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado, batch_size=batch_size) #pega valor que chegou
            target_f[0][acao] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0, batch_size=batch_size) #treina modelo
        
    def tira_ultimo_state(self):
        if self.state.shape[0] > self.janela * self.n_variaveis:
            self.state = self.state[self.n_variaveis:] #tira os ultimos preos
        if self.next_state.shape[0] > self.janela * self.n_variaveis:
            self.next_state = self.next_state[self.n_variaveis:] #tira os ultimos preos
    
    def remember(self, acao, reward, valores_ant, valores_dps, done):
        prox_estado = np.array([np.append(self.next_state, valores_dps)]) #cria proximo estado
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora
        self.memory.append((acao, reward, estado, prox_estado, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               21504
# _________________________________________________________________
# dense_2 (Dense)              (None, 192)               49344
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 95,939
# Trainable params: 95,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    r = 0.
        
    if acao != 0:
        if (acao*ncont_anterior) < 0:    #realizacao (lucro ou prejuizo)
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
            preco_cheio = ( preco * ( pmax - pmin ) + pmin )
            r = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
        else:
            r = -custo*abs(acao)                                       #reward = -custo*acao se houve operacao
        
        if valor!=0: 
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
        if abs(ncont) > 0:
            valor = (ncont_anterior*valor + acao*preco)/ncont     
        else:
            valor = 0
            
    if valor!=0: valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valor posicionado atual
            
    dp = ( preco * ( pmax - pmin ) + pmin ) - valor_cheio #variacao do preco atual e do preco de compra/venda
    posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (INSTANTNEO)
    
    return ncont, valor, posicao, ncont_anterior, r

def obter_acao(ncont, valores_ant):
    decisao = modelo.toma_acao(valores_ant, False) #calcula a saida da rede neural
    
    if decisao == 0: #comprar
        if ncont < lim_cont: #s compra se no tem nada ainda
            return 1
    elif decisao == 1: #vender
        if ncont > -lim_cont: #só vende se tiver alguma coisa
            return -1
    return 0 #neutro

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = 0 #cria variavel para preo medio
    reward = 0 #cria variavel para recompensa
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria() #limpa o vetor de memoria
    done = False
    modelo.state = np.zeros(n_variaveis*janela)
    modelo.next_state = np.zeros(n_variaveis*janela)
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.state = np.append( modelo.state, ultimos_precos ) #adiciona na variavel de estado
        
        modelo.tira_ultimo_state()
        valores_ant = [ncont / lim_cont, valor, posicao/posicao_max] #grava os valores de antes - estado

        acao = obter_acao( ncont, valores_ant ) #obtem acao
        ncont, valor, posicao, ncont_anterior, r = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        reward += r
        #print (hr[step]*step_max, acao)
        #print("acao: {0} reward: {1} step: {2}".format(acao, reward, hr[step]*step_max))
            
        prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
        modelo.next_state = np.append(modelo.next_state, prox_precos) #adiciona variavel na variavel de proximo estado
        modelo.tira_ultimo_state()
        valores_dps = [ncont / lim_cont, valor, posicao/posicao_max] #grava os valores de depois
        
        if step == (steps[dia] - 1):
            done = True
        else:
            modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    
    reward += posicao #soma reward - DAY-TRADE (obs: custo nao havia sido considerado no reward pq acao era 0)
    
    modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    
    modelo.treina_modelo() #roda o modelo com toda a memoria do dia
           
    if reward > melhor_reward:
        melhor_reward = reward
    return reward #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        #print("dia {0} de {1}: R$ {2:0.2f}".format(dia, dias, reward)) #mostra o resultado do dia
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    #modelo.epsilon = 0.1
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            #s=time.time()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f}".format(epoca, sum_rewards))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_4.h5')
            dias_pos = 0
            dias_neg = 0
            #e=time.time()
            #print(e-s)
            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_4.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
        print("Somatoria dos rewards: {0:0.2f}".format(sum_rewards_total))
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1021 19:48:45.009512 10364 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1021 19:48:45.368532 10364 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1021 19:48:45.391534 10364 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -81769.27
# 109
# 110
# resultado da epoca 1 = -33266.38
# 108
# 111
# resultado da epoca 2 = -13027.79
# 116
# 103
# resultado da epoca 3 = -35081.21
# 101
# 118
# resultado da epoca 4 = -13422.78
# 113
# 106
# resultado da epoca 5 = -16521.26
# 105
# 114
# resultado da epoca 6 = -13798.58
# 105
# 114
# resultado da epoca 7 = -67620.61
# 100
# 119
# resultado da epoca 8 = -8044.54
# 108
# 111
# resultado da epoca 9 = -52254.56
# 97
# 122
# resultado da epoca 10 = -94796.18
# 96
# 123
# resultado da epoca 11 = -22775.78
# 98
# 121
# resultado da epoca 12 = 147614.63
# 119
# 100
# resultado da epoca 13 = -62563.23
# 104
# 115
# resultado da epoca 14 = 3661.40
# 110
# 109
# resultado da epoca 15 = 15462.05
# 112
# 107
# resultado da epoca 16 = -101179.43
# 104
# 115
# resultado da epoca 17 = -66660.04
# 110
# 109
# resultado da epoca 18 = -78198.19
# 101
# 118
# resultado da epoca 19 = -37681.52
# 108
# 111
# resultado da epoca 20 = 97350.90
# 119
# 100
# resultado da epoca 21 = -53013.90
# 99
# 120
# resultado da epoca 22 = 74255.88
# 109
# 110
# resultado da epoca 23 = 77812.48
# 111
# 108
# resultado da epoca 24 = -116665.42
# 107
# 112
# resultado da epoca 25 = 43012.02
# 111
# 108
# resultado da epoca 26 = 11972.05
# 117
# 102
# resultado da epoca 27 = -11417.66
# 103
# 116
# resultado da epoca 28 = 47989.57
# 110
# 109
# resultado da epoca 29 = 78240.83
# 126
# 93
# resultado da epoca 30 = -199334.46
# 98
# 121
# resultado da epoca 31 = 99734.83
# 115
# 104
# resultado da epoca 32 = 21304.57
# 111
# 108
# resultado da epoca 33 = 58287.39
# 105
# 114
# resultado da epoca 34 = 86424.78
# 116
# 103
# resultado da epoca 35 = 124246.88
# 121
# 98
# resultado da epoca 36 = 19196.75
# 109
# 110
# resultado da epoca 37 = -77081.66
# 103
# 116
# resultado da epoca 38 = -81857.42
# 115
# 104
# resultado da epoca 39 = -18871.34
# 112
# 107
# resultado da epoca 40 = 34365.33
# 107
# 112
# resultado da epoca 41 = -109647.08
# 100
# 119
# resultado da epoca 42 = -80231.10
# 100
# 119
# resultado da epoca 43 = -50220.27
# 101
# 118
# resultado da epoca 44 = 62445.55
# 112
# 107
# resultado da epoca 45 = -36100.22
# 109
# 110
# resultado da epoca 46 = -89724.49
# 107
# 112
# resultado da epoca 47 = -27121.36
# 111
# 108
# resultado da epoca 48 = -42068.08
# 109
# 110
# resultado da epoca 49 = 142.98
# 116
# 103
# resultado da epoca 50 = -59048.38
# 108
# 111
# resultado da epoca 51 = 81913.30
# 111
# 108
# resultado da epoca 52 = -37797.95
# 109
# 110
# resultado da epoca 53 = -21895.58
# 109
# 110
# resultado da epoca 54 = 75172.98
# 115
# 104
# resultado da epoca 55 = 7216.48
# 115
# 104
# resultado da epoca 56 = -49582.60
# 108
# 111
# resultado da epoca 57 = 109729.84
# 125
# 94
# resultado da epoca 58 = 30802.47
# 109
# 110
# resultado da epoca 59 = -174750.84
# 101
# 118
# resultado da epoca 60 = -156013.08
# 101
# 118
# resultado da epoca 61 = -60851.80
# 106
# 113
# resultado da epoca 62 = -120876.94
# 103
# 116
# resultado da epoca 63 = -148962.50
# 107
# 112
# resultado da epoca 64 = -20373.94
# 106
# 113
# resultado da epoca 65 = -9729.65
# 114
# 105
# resultado da epoca 66 = -16287.98
# 107
# 112
# resultado da epoca 67 = 64471.31
# 113
# 106
# resultado da epoca 68 = -20094.28
# 109
# 110
# resultado da epoca 69 = -2520.75
# 112
# 107
# resultado da epoca 70 = -157739.37
# 110
# 109
# resultado da epoca 71 = -30963.03
# 102
# 117
# resultado da epoca 72 = 45818.18
# 115
# 104
# resultado da epoca 73 = -103483.31
# 104
# 115
# resultado da epoca 74 = -5189.40
# 108
# 111
# resultado da epoca 75 = -35320.41
# 108
# 111
# resultado da epoca 76 = -44786.92
# 111
# 108
# resultado da epoca 77 = 66861.44
# 121
# 98
# resultado da epoca 78 = -41683.59
# 109
# 110
# resultado da epoca 79 = -54576.40
# 103
# 116
# resultado da epoca 80 = -99009.78
# 104
# 115
# resultado da epoca 81 = -36572.95
# 116
# 103
# resultado da epoca 82 = -71960.05
# 107
# 112
# resultado da epoca 83 = -44249.56
# 110
# 109
# resultado da epoca 84 = -46980.55
# 110
# 109
# resultado da epoca 85 = -118433.50
# 108
# 111
# resultado da epoca 86 = -115824.82
# 111
# 108
# resultado da epoca 87 = -85311.17
# 95
# 124
# resultado da epoca 88 = -50061.40
# 106
# 113
# resultado da epoca 89 = 16785.71
# 106
# 113
# resultado da epoca 90 = -21178.79
# 113
# 106
# resultado da epoca 91 = -98449.61
# 105
# 114
# resultado da epoca 92 = 23573.64
# 105
# 114
# resultado da epoca 93 = -124693.36
# 109
# 110
# resultado da epoca 94 = -155049.31
# 95
# 124
# resultado da epoca 95 = -54917.72
# 104
# 115
# resultado da epoca 96 = -14323.11
# 107
# 112
# resultado da epoca 97 = -79801.20
# 108
# 111
# resultado da epoca 98 = -107225.09
# 112
# 107
# resultado da epoca 99 = 44724.71
# 121
# 98
# resultado da epoca 100 = -155768.46
# 102
# 117
# resultado da epoca 101 = -57307.30
# 110
# 109
# resultado da epoca 102 = -121335.54
# 109
# 110
# resultado da epoca 103 = -215911.76
# 106
# 113
# resultado da epoca 104 = 35469.69
# 110
# 109
# resultado da epoca 105 = -197379.14
# 107
# 112
# resultado da epoca 106 = -143796.82
# 106
# 113
# resultado da epoca 107 = 89843.90
# 126
# 93
# resultado da epoca 108 = -11.54
# 120
# 99
# resultado da epoca 109 = -109145.58
# 115
# 104
# resultado da epoca 110 = -115101.78
# 108
# 111
# resultado da epoca 111 = -9570.33
# 115
# 104
# resultado da epoca 112 = -126866.57
# 112
# 107
# resultado da epoca 113 = -200719.85
# 99
# 120
# resultado da epoca 114 = -136612.20
# 104
# 115
# resultado da epoca 115 = -51041.99
# 111
# 108
# resultado da epoca 116 = -133829.96
# 102
# 117
# resultado da epoca 117 = -106562.45
# 103
# 116
# resultado da epoca 118 = 26923.71
# 125
# 94
# resultado da epoca 119 = -106075.51
# 104
# 115
# resultado da epoca 120 = -63652.29
# 102
# 117
# resultado da epoca 121 = -156085.23
# 99
# 120
# resultado da epoca 122 = -104325.47
# 107
# 112
# resultado da epoca 123 = -159263.71
# 103
# 116
# resultado da epoca 124 = -103487.03
# 106
# 113
# resultado da epoca 125 = -83247.93
# 106
# 113
# resultado da epoca 126 = -126740.36
# 103
# 116
# resultado da epoca 127 = -115449.49
# 114
# 105
# resultado da epoca 128 = -165676.70
# 105
# 114
# resultado da epoca 129 = -74829.06
# 114
# 105
# resultado da epoca 130 = -134471.33
# 105
# 114
# resultado da epoca 131 = -77553.05
# 108
# 111
# resultado da epoca 132 = -106515.39
# 103
# 116
# resultado da epoca 133 = -128366.36
# 107
# 112
# resultado da epoca 134 = -182286.20
# 94
# 125
# resultado da epoca 135 = -88234.09
# 115
# 104
# resultado da epoca 136 = -198472.18
# 105
# 114
# resultado da epoca 137 = -113154.03
# 102
# 117
# resultado da epoca 138 = -227540.22
# 103
# 116
# resultado da epoca 139 = -192271.12
# 100
# 119
# resultado da epoca 140 = -190106.68
# 105
# 114
# resultado da epoca 141 = -199841.48
# 100
# 119
# resultado da epoca 142 = -35781.93
# 110
# 109
# resultado da epoca 143 = -152250.04
# 109
# 110
# resultado da epoca 144 = -256921.60
# 97
# 122
# resultado da epoca 145 = -157408.14
# 107
# 112
# resultado da epoca 146 = -166944.87
# 109
# 110
# resultado da epoca 147 = -55902.83
# 109
# 110
# resultado da epoca 148 = -132029.87
# 112
# 107
# resultado da epoca 149 = -268140.68
# 96
# 123
# resultado da epoca 150 = -231374.08
# 98
# 121
# resultado da epoca 151 = -232510.65
# 102
# 117
# resultado da epoca 152 = -134472.54
# 113
# 106
# resultado da epoca 153 = -152498.19
# 114
# 105
# resultado da epoca 154 = -108343.16
# 111
# 108
# resultado da epoca 155 = -149988.02
# 107
# 112
# resultado da epoca 156 = -71793.19
# 118
# 101
# resultado da epoca 157 = -115706.21
# 99
# 120
# resultado da epoca 158 = -172514.47
# 108
# 111
# resultado da epoca 159 = -74467.47
# 112
# 107
# resultado da epoca 160 = -247060.50
# 98
# 121
# resultado da epoca 161 = -94474.58
# 110
# 109
# resultado da epoca 162 = -266020.48
# 106
# 113
# resultado da epoca 163 = -170702.52
# 98
# 121
# resultado da epoca 164 = -229873.42
# 103
# 116
# resultado da epoca 165 = -149143.22
# 105
# 114
# resultado da epoca 166 = -278282.88
# 94
# 125
# resultado da epoca 167 = -81870.09
# 106
# 113
# resultado da epoca 168 = -213083.54
# 94
# 125
# resultado da epoca 169 = -146343.10
# 100
# 119
# resultado da epoca 170 = -195671.83
# 94
# 125
# resultado da epoca 171 = -218926.97
# 97
# 122
# resultado da epoca 172 = -189390.57
# 103
# 116
# resultado da epoca 173 = -203669.85
# 103
# 116
# resultado da epoca 174 = -167820.63
# 106
# 113
# resultado da epoca 175 = -198343.88
# 92
# 127
# resultado da epoca 176 = -86510.72
# 105
# 114
# resultado da epoca 177 = -180547.62
# 93
# 126
# resultado da epoca 178 = -106695.42
# 102
# 117
# resultado da epoca 179 = -99022.10
# 99
# 120
# resultado da epoca 180 = -190641.24
# 97
# 122
# resultado da epoca 181 = -199472.36
# 96
# 123
# resultado da epoca 182 = -142198.01
# 110
# 109
# resultado da epoca 183 = -106629.80
# 102
# 117
# resultado da epoca 184 = -231329.51
# 93
# 126
# resultado da epoca 185 = -202165.44
# 100
# 119
# resultado da epoca 186 = -350416.72
# 92
# 127
# resultado da epoca 187 = -220281.98
# 104
# 115
# resultado da epoca 188 = -121112.59
# 111
# 108
# resultado da epoca 189 = -203927.74
# 106
# 113
# resultado da epoca 190 = -131683.01
# 101
# 118
# resultado da epoca 191 = -185769.46
# 109
# 110
# resultado da epoca 192 = -216832.44
# 97
# 122
# resultado da epoca 193 = -158960.09
# 109
# 110
# resultado da epoca 194 = -113335.18
# 102
# 117
# resultado da epoca 195 = -182449.25
# 106
# 113
# resultado da epoca 196 = -252624.84
# 99
# 120
# resultado da epoca 197 = -260762.40
# 104
# 115
# resultado da epoca 198 = -253988.83
# 93
# 126
# resultado da epoca 199 = -192457.18
# 100
# 119
# resultado da epoca 200 = -206510.07
# 100
# 119
# resultado da epoca 201 = -296886.89
# 102
# 117
# resultado da epoca 202 = -143072.05
# 104
# 115
# resultado da epoca 203 = -322183.29
# 94
# 125
# resultado da epoca 204 = -126624.16
# 101
# 118
# resultado da epoca 205 = -261064.85
# 106
# 113
# resultado da epoca 206 = -227143.36
# 102
# 117
# resultado da epoca 207 = -134631.69
# 104
# 115
# resultado da epoca 208 = -217004.00
# 101
# 118
# resultado da epoca 209 = -234686.42
# 108
# 111
# resultado da epoca 210 = -244886.67
# 102
# 117
# resultado da epoca 211 = -201139.84
# 104
# 115
# resultado da epoca 212 = -83392.09
# 115
# 104
# resultado da epoca 213 = -231461.12
# 111
# 108
# resultado da epoca 214 = -191094.49
# 103
# 116
# resultado da epoca 215 = -221681.36
# 106
# 113
# resultado da epoca 216 = -270432.60
# 104
# 115
# resultado da epoca 217 = -186667.33
# 107
# 112
# resultado da epoca 218 = -293591.96
# 99
# 120
# resultado da epoca 219 = -253397.73
# 100
# 119
# resultado da epoca 220 = -215480.82
# 108
# 111
# resultado da epoca 221 = -238120.32
# 97
# 122
# resultado da epoca 222 = -303300.10
# 109
# 110
# resultado da epoca 223 = -249127.64
# 101
# 118
# resultado da epoca 224 = -324460.26
# 106
# 113
# resultado da epoca 225 = -203845.64
# 97
# 122
# resultado da epoca 226 = -222477.20
# 107
# 112
# resultado da epoca 227 = -189504.06
# 103
# 116
# resultado da epoca 228 = -144059.68
# 113
# 106
# resultado da epoca 229 = -171862.12
# 107
# 112
# resultado da epoca 230 = -223022.51
# 103
# 116
# resultado da epoca 231 = -222677.13
# 105
# 114
# resultado da epoca 232 = -270792.58
# 103
# 116
# resultado da epoca 233 = -221717.22
# 108
# 111
# resultado da epoca 234 = -332084.14
# 103
# 116
# resultado da epoca 235 = -186565.58
# 109
# 110
# resultado da epoca 236 = -252295.02
# 101
# 118
# resultado da epoca 237 = -299811.92
# 108
# 111
# resultado da epoca 238 = -228763.68
# 105
# 114
# resultado da epoca 239 = -245654.03
# 104
# 115
# resultado da epoca 240 = -198319.67
# 109
# 110
# resultado da epoca 241 = -192518.19
# 104
# 115
# resultado da epoca 242 = -232620.86
# 108
# 111
# resultado da epoca 243 = -196238.15
# 108
# 111
# resultado da epoca 244 = -194239.32
# 104
# 115
# resultado da epoca 245 = -246564.18
# 105
# 114
# resultado da epoca 246 = -190399.12
# 111
# 108
# resultado da epoca 247 = -211280.49
# 104
# 115
# resultado da epoca 248 = -221679.45
# 106
# 113
# resultado da epoca 249 = -264780.97
# 106
# 113
# resultado da epoca 250 = -149705.42
# 107
# 112
# resultado da epoca 251 = -148610.18
# 106
# 113
# resultado da epoca 252 = -130415.91
# 114
# 105
# resultado da epoca 253 = -255460.99
# 106
# 113
# resultado da epoca 254 = -96382.46
# 111
# 108
# resultado da epoca 255 = -276903.12
# 108
# 111
# resultado da epoca 256 = -258331.85
# 105
# 114
# resultado da epoca 257 = -160207.11
# 110
# 109
# resultado da epoca 258 = -220134.58
# 109
# 110
# resultado da epoca 259 = -216409.76
# 105
# 114
# resultado da epoca 260 = -192106.02
# 107
# 112
# resultado da epoca 261 = -149760.14
# 110
# 109
# resultado da epoca 262 = -191142.14
# 117
# 102
# resultado da epoca 263 = -185034.27
# 112
# 107
# resultado da epoca 264 = -141799.45
# 116
# 103
# resultado da epoca 265 = -127299.99
# 111
# 108
# resultado da epoca 266 = -126268.86
# 109
# 110
# resultado da epoca 267 = -214670.64
# 106
# 113
# resultado da epoca 268 = -133541.65
# 113
# 106
# resultado da epoca 269 = -138087.41
# 114
# 105
# resultado da epoca 270 = -229714.74
# 108
# 111
# resultado da epoca 271 = -172437.03
# 112
# 107
# resultado da epoca 272 = -178039.93
# 108
# 111
# resultado da epoca 273 = -148335.36
# 107
# 112
# resultado da epoca 274 = -157963.86
# 110
# 109
# resultado da epoca 275 = -130564.07
# 102
# 117
# resultado da epoca 276 = -202381.42
# 110
# 109
# resultado da epoca 277 = -256602.09
# 104
# 115
# resultado da epoca 278 = -69710.55
# 113
# 106
# resultado da epoca 279 = -146566.03
# 110
# 109
# resultado da epoca 280 = -243689.72
# 106
# 113
# resultado da epoca 281 = -221194.28
# 110
# 109
# resultado da epoca 282 = -330870.85
# 107
# 112
# resultado da epoca 283 = -233851.78
# 111
# 108
# resultado da epoca 284 = -158863.81
# 102
# 117
# resultado da epoca 285 = -241749.27
# 108
# 111
# resultado da epoca 286 = -213153.90
# 105
# 114
# resultado da epoca 287 = -162465.68
# 106
# 113
# resultado da epoca 288 = -216852.19
# 112
# 107
# resultado da epoca 289 = -202029.20
# 110
# 109
# resultado da epoca 290 = -148845.13
# 113
# 106
# resultado da epoca 291 = -118616.85
# 106
# 113
# resultado da epoca 292 = -152871.25
# 111
# 108
# resultado da epoca 293 = -181292.32
# 111
# 108
# resultado da epoca 294 = -241339.85
# 105
# 114
# resultado da epoca 295 = -210396.84
# 104
# 115
# resultado da epoca 296 = -205066.38
# 112
# 107
# resultado da epoca 297 = -234913.06
# 113
# 106
# resultado da epoca 298 = -183610.90
# 108
# 111
# resultado da epoca 299 = -177353.88
# 104
# 115
# resultado da epoca 300 = -254557.63
# 107
# 112
# resultado da epoca 301 = -200956.08
# 109
# 110
# resultado da epoca 302 = -244662.61
# 109
# 110
# resultado da epoca 303 = -148351.94
# 112
# 107
# resultado da epoca 304 = -173569.70
# 113
# 106
# resultado da epoca 305 = -138974.59
# 112
# 107
# resultado da epoca 306 = -213252.81
# 109
# 110
# resultado da epoca 307 = -172011.90
# 107
# 112
# resultado da epoca 308 = -139926.98
# 115
# 104
# resultado da epoca 309 = -254020.63
# 106
# 113
# resultado da epoca 310 = -245843.03
# 104
# 115
# resultado da epoca 311 = -145060.67
# 110
# 109
# resultado da epoca 312 = -208898.69
# 115
# 104
# resultado da epoca 313 = -183382.14
# 111
# 108
# resultado da epoca 314 = -155301.35
# 107
# 112
# resultado da epoca 315 = -272614.61
# 110
# 109
# resultado da epoca 316 = -189782.64
# 110
# 109
# resultado da epoca 317 = -163127.23
# 108
# 111
# resultado da epoca 318 = -118899.98
# 109
# 110
# resultado da epoca 319 = -122975.81
# 112
# 107
# resultado da epoca 320 = -175569.46
# 113
# 106
# resultado da epoca 321 = -176061.21
# 110
# 109
# resultado da epoca 322 = -116340.48
# 113
# 106
# resultado da epoca 323 = -152882.34
# 111
# 108
# resultado da epoca 324 = -216338.84
# 107
# 112
# resultado da epoca 325 = -158352.87
# 114
# 105
# resultado da epoca 326 = -130023.78
# 115
# 104
# resultado da epoca 327 = -201966.83
# 111
# 108
# resultado da epoca 328 = -99831.85
# 112
# 107
# resultado da epoca 329 = -183687.00
# 111
# 108
# resultado da epoca 330 = -162137.29
# 114
# 105
# resultado da epoca 331 = -204747.64
# 104
# 115
# resultado da epoca 332 = -207427.63
# 108
# 111
# resultado da epoca 333 = -232656.30
# 110
# 109
# resultado da epoca 334 = -216985.57
# 110
# 109
# resultado da epoca 335 = -183862.13
# 110
# 109
# resultado da epoca 336 = -234800.75
# 121
# 98
# resultado da epoca 337 = -202729.05
# 111
# 108
# resultado da epoca 338 = -252230.17
# 109
# 110
# resultado da epoca 339 = -164611.98
# 114
# 105
# resultado da epoca 340 = -178898.53
# 110
# 109
# resultado da epoca 341 = -203182.35
# 109
# 110
# resultado da epoca 342 = -216784.89
# 111
# 108
# resultado da epoca 343 = -172479.96
# 105
# 114
# resultado da epoca 344 = -168125.92
# 110
# 109
# resultado da epoca 345 = -255890.86
# 109
# 110
# resultado da epoca 346 = -283632.32
# 114
# 105
# resultado da epoca 347 = -147263.46
# 112
# 107
# resultado da epoca 348 = -233064.73
# 106
# 113
# resultado da epoca 349 = -134402.27
# 110
# 109
# resultado da epoca 350 = -129812.97
# 114
# 105
# resultado da epoca 351 = -156982.38
# 109
# 110
# resultado da epoca 352 = -218982.22
# 111
# 108
# resultado da epoca 353 = -213449.01
# 111
# 108
# resultado da epoca 354 = -268303.84
# 114
# 105
# resultado da epoca 355 = -148148.41
# 113
# 106
# resultado da epoca 356 = -263472.33
# 118
# 101
# resultado da epoca 357 = -286580.95
# 112
# 107
# resultado da epoca 358 = -217840.47
# 110
# 109
# resultado da epoca 359 = -247964.24
# 103
# 116
# resultado da epoca 360 = -196257.20
# 107
# 112
# resultado da epoca 361 = -235040.58
# 110
# 109
# resultado da epoca 362 = -220964.31
# 105
# 114
# resultado da epoca 363 = -142110.31
# 104
# 115
# resultado da epoca 364 = -205856.00
# 107
# 112
# resultado da epoca 365 = -185867.30
# 112
# 107
# resultado da epoca 366 = -184997.64
# 109
# 110
# resultado da epoca 367 = -230283.94
# 105
# 114
# resultado da epoca 368 = -207001.84
# 109
# 110
# resultado da epoca 369 = -196773.15
# 113
# 106
# resultado da epoca 370 = -258220.18
# 104
# 115
# resultado da epoca 371 = -251203.36
# 110
# 109
# resultado da epoca 372 = -154426.50
# 112
# 107
# resultado da epoca 373 = -239541.17
# 112
# 107
# resultado da epoca 374 = -202123.77
# 111
# 108
# resultado da epoca 375 = -187134.66
# 113
# 106
# resultado da epoca 376 = -162167.19
# 110
# 109
# resultado da epoca 377 = -263009.92
# 114
# 105
# resultado da epoca 378 = -221730.00
# 115
# 104
# resultado da epoca 379 = -174967.51
# 114
# 105
# resultado da epoca 380 = -150888.56
# 113
# 106
# resultado da epoca 381 = -171378.69
# 116
# 103
# resultado da epoca 382 = -114022.58
# 117
# 102
# resultado da epoca 383 = -215066.01
# 116
# 103
# resultado da epoca 384 = -131292.99
# 111
# 108
# resultado da epoca 385 = -196185.39
# 113
# 106
# resultado da epoca 386 = -195428.85
# 115
# 104
# resultado da epoca 387 = -239511.98
# 110
# 109
# resultado da epoca 388 = -188805.08
# 112
# 107
# resultado da epoca 389 = -192650.61
# 104
# 115
# resultado da epoca 390 = -282254.02
# 101
# 118
# resultado da epoca 391 = -188083.11
# 111
# 108
# resultado da epoca 392 = -140588.36
# 111
# 108
# resultado da epoca 393 = -211040.58
# 111
# 108
# resultado da epoca 394 = -148403.90
# 117
# 102
# resultado da epoca 395 = -203818.51
# 110
# 109
# resultado da epoca 396 = -195855.26
# 109
# 110
# resultado da epoca 397 = -173202.01
# 110
# 109
# resultado da epoca 398 = -191128.05
# 111
# 108
# resultado da epoca 399 = -192835.23
# 104
# 115
# resultado da epoca 400 = -201791.47
# 113
# 106
# resultado da epoca 401 = -160436.65
# 115
# 104
# resultado da epoca 402 = -204505.69
# 109
# 110
# resultado da epoca 403 = -215435.15
# 115
# 104
# resultado da epoca 404 = -190415.43
# 111
# 108
# resultado da epoca 405 = -260269.41
# 108
# 111
# resultado da epoca 406 = -144929.58
# 112
# 107
# resultado da epoca 407 = -200476.03
# 110
# 109
# resultado da epoca 408 = -180658.38
# 110
# 109
# resultado da epoca 409 = -224414.10
# 108
# 111
# resultado da epoca 410 = -148019.93
# 109
# 110
# resultado da epoca 411 = -178139.41
# 111
# 108
# resultado da epoca 412 = -197081.37
# 112
# 107
# resultado da epoca 413 = -213295.69
# 110
# 109
# resultado da epoca 414 = -178617.02
# 108
# 111
# resultado da epoca 415 = -222548.94
# 111
# 108
# resultado da epoca 416 = -163986.21
# 114
# 105
# resultado da epoca 417 = -161901.61
# 111
# 108
# resultado da epoca 418 = -192020.51
# 113
# 106
# resultado da epoca 419 = -174279.56
# 121
# 98
# resultado da epoca 420 = -210509.32
# 113
# 106
# resultado da epoca 421 = -243056.83
# 110
# 109
# resultado da epoca 422 = -160253.93
# 106
# 113
# resultado da epoca 423 = -190388.87
# 108
# 111
# resultado da epoca 424 = -220095.06
# 112
# 107
# resultado da epoca 425 = -179645.88
# 111
# 108
# resultado da epoca 426 = -226244.46
# 111
# 108
# resultado da epoca 427 = -155777.61
# 112
# 107
# resultado da epoca 428 = -181820.71
# 109
# 110
# resultado da epoca 429 = -213867.43
# 114
# 105
# resultado da epoca 430 = -107177.78
# 119
# 100
# resultado da epoca 431 = -159375.09
# 112
# 107
# resultado da epoca 432 = -123309.06
# 116
# 103
# resultado da epoca 433 = -165945.45
# 108
# 111
# resultado da epoca 434 = -259891.91
# 110
# 109
# resultado da epoca 435 = -209341.32
# 115
# 104
# resultado da epoca 436 = -160923.05
# 111
# 108
# resultado da epoca 437 = -243037.79
# 111
# 108
# resultado da epoca 438 = -206898.84
# 109
# 110
# resultado da epoca 439 = -217759.19
# 109
# 110
# resultado da epoca 440 = -239661.52
# 118
# 101
# resultado da epoca 441 = -185635.54
# 112
# 107
# resultado da epoca 442 = -193912.98
# 109
# 110
# resultado da epoca 443 = -258790.64
# 113
# 106
# resultado da epoca 444 = -193632.76
# 105
# 114
# resultado da epoca 445 = -204194.22
# 114
# 105
# resultado da epoca 446 = -219558.86
# 114
# 105
# resultado da epoca 447 = -259268.01
# 112
# 107
# resultado da epoca 448 = -138284.95
# 114
# 105
# resultado da epoca 449 = -206944.43
# 105
# 114
# resultado da epoca 450 = -207353.79
# 110
# 109
# resultado da epoca 451 = -216079.84
# 110
# 109
# resultado da epoca 452 = -246580.22
# 112
# 107
# resultado da epoca 453 = -202470.99
# 110
# 109
# resultado da epoca 454 = -227109.75
# 115
# 104
# resultado da epoca 455 = -188328.29
# 116
# 103
# resultado da epoca 456 = -230613.05
# 110
# 109
# resultado da epoca 457 = -226507.45
# 110
# 109
# resultado da epoca 458 = -215980.73
# 116
# 103
# resultado da epoca 459 = -223993.36
# 104
# 115
# resultado da epoca 460 = -246134.30
# 109
# 110
# resultado da epoca 461 = -212497.73
# 111
# 108
# resultado da epoca 462 = -164650.41
# 116
# 103
# resultado da epoca 463 = -192349.40
# 109
# 110
# resultado da epoca 464 = -210984.24
# 109
# 110
# resultado da epoca 465 = -235558.67
# 111
# 108
# resultado da epoca 466 = -274954.81
# 113
# 106
# resultado da epoca 467 = -189280.47
# 103
# 116
# resultado da epoca 468 = -238255.01
# 107
# 112
# resultado da epoca 469 = -241240.56
# 113
# 106
# resultado da epoca 470 = -271422.19
# 109
# 110
# resultado da epoca 471 = -216428.56
# 115
# 104
# resultado da epoca 472 = -202720.53
# 113
# 106
# resultado da epoca 473 = -233769.31
# 113
# 106
# resultado da epoca 474 = -306176.15
# 112
# 107
# resultado da epoca 475 = -201687.85
# 110
# 109
# resultado da epoca 476 = -292365.96
# 112
# 107
# resultado da epoca 477 = -248494.57
# 114
# 105
# resultado da epoca 478 = -250482.15
# 117
# 102
# resultado da epoca 479 = -227458.79
# 112
# 107
# resultado da epoca 480 = -278047.20
# 109
# 110
# resultado da epoca 481 = -253695.42
# 115
# 104
# resultado da epoca 482 = -244430.79
# 111
# 108
# resultado da epoca 483 = -261363.93
# 110
# 109
# resultado da epoca 484 = -235447.73
# 113
# 106
# resultado da epoca 485 = -251633.63
# 113
# 106
# resultado da epoca 486 = -201979.76
# 111
# 108
# resultado da epoca 487 = -299852.91
# 109
# 110
# resultado da epoca 488 = -237742.69
# 112
# 107
# resultado da epoca 489 = -273705.72
# 107
# 112
# resultado da epoca 490 = -241103.70
# 113
# 106
# resultado da epoca 491 = -216441.40
# 111
# 108
# resultado da epoca 492 = -306650.60
# 110
# 109
# resultado da epoca 493 = -285083.31
# 112
# 107
# resultado da epoca 494 = -243598.41
# 111
# 108
# resultado da epoca 495 = -297325.81
# 110
# 109
# resultado da epoca 496 = -176392.20
# 111
# 108
# resultado da epoca 497 = -270107.70
# 110
# 109
# resultado da epoca 498 = -288393.61
# 112
# 107
# resultado da epoca 499 = -331084.60
# 105
# 114
# resultado da epoca 500 = -281762.08
# 113
# 106
# resultado da epoca 501 = -286723.73
# 114
# 105
# resultado da epoca 502 = -227216.11
# 110
# 109
# resultado da epoca 503 = -306879.09
# 110
# 109
# resultado da epoca 504 = -229704.64
# 112
# 107
# resultado da epoca 505 = -278680.44
# 108
# 111
# resultado da epoca 506 = -250624.87
# 112
# 107
# resultado da epoca 507 = -323226.80
# 108
# 111
# resultado da epoca 508 = -238820.85
# 111
# 108
# resultado da epoca 509 = -269248.25
# 102
# 117
# resultado da epoca 510 = -286773.90
# 112
# 107
# resultado da epoca 511 = -268163.31
# 113
# 106
# resultado da epoca 512 = -230803.85
# 113
# 106
# resultado da epoca 513 = -261453.15
# 107
# 112
# resultado da epoca 514 = -236437.79
# 115
# 104
# resultado da epoca 515 = -253881.13
# 108
# 111
# resultado da epoca 516 = -271556.27
# 111
# 108
# resultado da epoca 517 = -240505.12
# 112
# 107
# resultado da epoca 518 = -226324.15
# 113
# 106
# resultado da epoca 519 = -243980.21
# 115
# 104
# resultado da epoca 520 = -210064.85
# 115
# 104
# resultado da epoca 521 = -222220.45
# 110
# 109
# resultado da epoca 522 = -237480.17
# 108
# 111
# resultado da epoca 523 = -269541.93
# 108
# 111
# resultado da epoca 524 = -205724.33
# 115
# 104
# resultado da epoca 525 = -218297.80
# 116
# 103
# resultado da epoca 526 = -207956.94
# 118
# 101
# resultado da epoca 527 = -198933.97
# 116
# 103
# resultado da epoca 528 = -204261.67
# 111
# 108
# resultado da epoca 529 = -202898.91
# 111
# 108
# resultado da epoca 530 = -198198.65
# 108
# 111
# resultado da epoca 531 = -208933.47
# 114
# 105
# resultado da epoca 532 = -233761.44
# 111
# 108
# resultado da epoca 533 = -209547.34
# 113
# 106
# resultado da epoca 534 = -269825.94
# 109
# 110
# resultado da epoca 535 = -236917.41
# 113
# 106
# resultado da epoca 536 = -206888.76
# 113
# 106
# resultado da epoca 537 = -183884.41
# 112
# 107
# resultado da epoca 538 = -234781.15
# 112
# 107
# resultado da epoca 539 = -212920.73
# 110
# 109
# resultado da epoca 540 = -213032.69
# 115
# 104
# resultado da epoca 541 = -230762.86
# 109
# 110
# resultado da epoca 542 = -266827.88
# 111
# 108
# resultado da epoca 543 = -209172.76
# 116
# 103
# resultado da epoca 544 = -252781.48
# 117
# 102
# resultado da epoca 545 = -234142.21
# 111
# 108
# resultado da epoca 546 = -212348.49
# 104
# 115
# resultado da epoca 547 = -285845.12
# 111
# 108
# resultado da epoca 548 = -302662.41
# 112
# 107
# resultado da epoca 549 = -272705.84
# 113
# 106
# resultado da epoca 550 = -253081.45
# 115
# 104
# resultado da epoca 551 = -280707.87
# 112
# 107
# resultado da epoca 552 = -281068.62
# 111
# 108
# resultado da epoca 553 = -258672.48
# 112
# 107
# resultado da epoca 554 = -209742.39
# 110
# 109
# resultado da epoca 555 = -205308.69
# 114
# 105
# resultado da epoca 556 = -238692.10
# 112
# 107
# resultado da epoca 557 = -231463.43
# 107
# 112
# resultado da epoca 558 = -249793.15
# 111
# 108
# resultado da epoca 559 = -201288.90
# 109
# 110
# resultado da epoca 560 = -235913.69
# 115
# 104
# resultado da epoca 561 = -199071.72
# 113
# 106
# resultado da epoca 562 = -270688.84
# 112
# 107
# resultado da epoca 563 = -259069.93
# 113
# 106
# resultado da epoca 564 = -266306.40
# 111
# 108
# resultado da epoca 565 = -223569.35
# 111
# 108
# resultado da epoca 566 = -221568.73
# 112
# 107
# resultado da epoca 567 = -294870.44
# 109
# 110
# resultado da epoca 568 = -252367.69
# 119
# 100
# resultado da epoca 569 = -248968.07
# 114
# 105
# resultado da epoca 570 = -266674.88
# 114
# 105
# resultado da epoca 571 = -248627.18
# 112
# 107
# resultado da epoca 572 = -271915.83
# 117
# 102
# resultado da epoca 573 = -249637.47
# 112
# 107
# resultado da epoca 574 = -264450.16
# 113
# 106
# resultado da epoca 575 = -253155.39
# 113
# 106
# resultado da epoca 576 = -262709.07
# 113
# 106
# resultado da epoca 577 = -235836.10
# 110
# 109
# resultado da epoca 578 = -298886.55
# 107
# 112
# resultado da epoca 579 = -246752.24
# 111
# 108
# resultado da epoca 580 = -266272.02
# 112
# 107
# resultado da epoca 581 = -279108.43
# 110
# 109
# resultado da epoca 582 = -251655.04
# 109
# 110
# resultado da epoca 583 = -234170.86
# 115
# 104
# resultado da epoca 584 = -302861.09
# 116
# 103
# resultado da epoca 585 = -258915.82
# 112
# 107
# resultado da epoca 586 = -247995.97
# 109
# 110
# resultado da epoca 587 = -214280.61
# 112
# 107
# resultado da epoca 588 = -261395.55
# 115
# 104
# resultado da epoca 589 = -291233.92
# 114
# 105
# resultado da epoca 590 = -262606.30
# 113
# 106
# resultado da epoca 591 = -227359.57
# 111
# 108
# resultado da epoca 592 = -239505.28
# 115
# 104
# resultado da epoca 593 = -272412.48
# 110
# 109
# resultado da epoca 594 = -271902.87
# 110
# 109
# resultado da epoca 595 = -284175.04
# 111
# 108
# resultado da epoca 596 = -252939.09
# 112
# 107
# resultado da epoca 597 = -251444.66
# 114
# 105
# resultado da epoca 598 = -285399.69
# 113
# 106
# resultado da epoca 599 = -322262.22
# 111
# 108
# resultado da epoca 600 = -331403.49
# 111
# 108
# resultado da epoca 601 = -306618.55
# 110
# 109
# resultado da epoca 602 = -309018.91
# 110
# 109
# resultado da epoca 603 = -290745.00
# 107
# 112
# resultado da epoca 604 = -302280.63
# 108
# 111
# resultado da epoca 605 = -290638.79
# 115
# 104
# resultado da epoca 606 = -293381.07
# 112
# 107
# resultado da epoca 607 = -300429.09
# 113
# 106
# resultado da epoca 608 = -290673.30
# 107
# 112
# resultado da epoca 609 = -281763.23
# 110
# 109
# resultado da epoca 610 = -350982.29
# 106
# 113
# resultado da epoca 611 = -302191.34
# 108
# 111
# resultado da epoca 612 = -313777.38
# 112
# 107
# resultado da epoca 613 = -317377.69
# 113
# 106
# resultado da epoca 614 = -274303.74
# 112
# 107
# resultado da epoca 615 = -293058.23
# 103
# 116
# resultado da epoca 616 = -325307.45
# 112
# 107
# resultado da epoca 617 = -298992.20
# 113
# 106
# resultado da epoca 618 = -310941.60
# 108
# 111
# resultado da epoca 619 = -386303.58
# 107
# 112
# resultado da epoca 620 = -367411.45
# 105
# 114
# resultado da epoca 621 = -316173.98
# 111
# 108
# resultado da epoca 622 = -349435.78
# 105
# 114
# resultado da epoca 623 = -329829.74
# 111
# 108
# resultado da epoca 624 = -355083.82
# 111
# 108
# 2
# 1
# Somatoria dos rewards: -112183526.58
# Melhor resultado diario: 41878.09
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6be5298d0275> in <module>
#      13         for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
#      14             #s=time.time()
# ---> 15             sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
#      16             sum_rewards_total += sum_rewards
#      17             sr.append(sum_rewards)
#
# <ipython-input-5-9acff2f7e595> in rodar_dias(precos, custo)
#      97     sum_rewards = 0 #cria variavel de somatoria de recompensas
#      98     for dia in range( 1, dias ): #loop de dias
# ---> 99         reward = rodar_1dia(precos, custo, dia)
#     100         sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
#     101         #print("dia {0} de {1}: R$ {2:0.2f}".format(dia, dias, reward)) #mostra o resultado do dia
#
# <ipython-input-5-9acff2f7e595> in rodar_1dia(precos, custo, dia)
#      83     modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
#      84
# ---> 85     modelo.treina_modelo() #roda o modelo com toda a memoria do dia
#      86
#      87     if reward > melhor_reward:
#
# <ipython-input-4-c575c789e950> in treina_modelo(self, batch_size)
#      65             target = reward
#      66             if not done:
# ---> 67                 target = (reward + self.gamma * np.amax(self.model.predict(prox_estado, batch_size=batch_size)[0])) #pega valor que quer chegar
#      68
#      69             target_f = self.model.predict(estado, batch_size=batch_size) #pega valor que chegou
#
# D:\anaconda\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# D:\anaconda\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# D:\anaconda\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# D:\anaconda\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
print(modelo.memory)

# %%
np.argmax(hr)

# %%
print(hr[0:106])

# %%
print(inputs['hr_int'])

# %%
print(hr[0:106])

# %%
print(modelo.state)

# %%
print(modelo.state.shape)

# %%
modelo.state_size

# %%
print(.shape)
