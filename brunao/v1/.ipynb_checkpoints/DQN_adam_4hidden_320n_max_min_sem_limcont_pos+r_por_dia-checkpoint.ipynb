# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
n_entradas = n_variaveis * janela + 2 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
n_saidas = 3 #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0
lim_cont = 10
posicao_max = 100*lim_cont #define variavel para normalizar a posicao

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]
    
pmed = np.( inputs.loc[:, inputs.columns[0]] ) #define valor minimo do preco
pstd = np.amin( inputs.loc[:, inputs.columns[0]] ) #define valor maximo do preco

for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1
hr = hr/step_max
inputs['hr_int'] = hr


dias = len(steps)
dias = 220
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import backend as K            #importa backend para clear_session()

##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria()
        self.gamma = 0.99       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-5
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(192, activation='relu')) #camada escondida
        model.add(Dense(128, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        
        return model

    def limpa_memoria(self):
        self.state = np.empty((0,))
        self.next_state = np.empty((0,))
        self.memory = []
        
    def toma_acao(self, valores_ant, teste):
        if not teste and np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora        
        act_values = self.model.predict(estado, batch_size=1) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=batch):
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in self.memory:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado, batch_size=batch_size)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado, batch_size=batch_size) #pega valor que chegou
            target_f[0][acao+1] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0, batch_size=batch_size) #treina modelo
        
    def tira_ultimo_state(self):
        if self.state.shape[0] > self.janela * self.n_variaveis:
            self.state = self.state[self.n_variaveis:] #tira os ultimos preos
        if self.next_state.shape[0] > self.janela * self.n_variaveis:
            self.next_state = self.next_state[self.n_variaveis:] #tira os ultimos preos
    
    def remember(self, acao, reward, valores_ant, valores_dps, done):
        prox_estado = np.array([np.append(self.next_state, valores_dps)]) #cria proximo estado
        estado = np.array([np.append(self.state, valores_ant)]) #cria valor de agora
        self.memory.append((acao, reward, estado, prox_estado, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7360
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 192)               49344
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 163,971
# Trainable params: 163,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    r = 0.
        
    if acao != 0:
        if (acao*ncont_anterior) < 0:    #realizacao (lucro ou prejuizo)
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
            preco_cheio = ( preco * ( pmax - pmin ) + pmin )
            r = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
        else:
            r = -custo*abs(acao)                                       #reward = -custo*acao se houve operacao
        
        if valor!=0: 
            valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valores nao normalizados
        if abs(ncont) > 0:
            valor = (ncont_anterior*valor + acao*preco)/ncont     
        else:
            valor = 0
            
    if valor!=0: valor_cheio = ( valor * ( pmax - pmin ) + pmin )  #valor posicionado atual
            
    dp = ( preco * ( pmax - pmin ) + pmin ) - valor_cheio #variacao do preco atual e do preco de compra/venda
    posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (INSTANTNEO)
    
    return ncont, valor, posicao, ncont_anterior, r

def obter_acao(ncont, valores_ant):
    decisao = modelo.toma_acao(valores_ant, False) #calcula a saida da rede neural
    
    if decisao == 2: #comprar
        return 1
    elif decisao == 0: #vender
        return -1
    return 0 #neutro

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = 0 #cria variavel para preo medio
    reward = 0 #cria variavel para recompensa
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria() #limpa o vetor de memoria
    done = False
    modelo.state = np.zeros(n_variaveis*janela)
    modelo.next_state = np.zeros(n_variaveis*janela)
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.state = np.append( modelo.state, ultimos_precos ) #adiciona na variavel de estado
        
        modelo.tira_ultimo_state()
        valores_ant = [ncont / batch, valor] #grava os valores de antes - estado
        
        acao = obter_acao( ncont, valores_ant ) #obtem acao
        ncont, valor, posicao, ncont_anterior, r = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        reward += r
        #print (hr[step]*step_max, acao)
        #print("acao: {0} reward: {1} step: {2}".format(acao, reward, hr[step]*step_max))
            
        prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
        modelo.next_state = np.append(modelo.next_state, prox_precos) #adiciona variavel na variavel de proximo estado
        modelo.tira_ultimo_state()
        valores_dps = [ncont / batch, valor] #grava os valores de depois
        
        if step == (steps[dia] - 1):
            done = True
        else:
            modelo.remember(acao, reward+posicao, valores_ant, valores_dps, done)  #salva step na memoria
            
    reward += posicao #soma reward - DAY-TRADE (obs: custo nao havia sido considerado no reward pq acao era 0)
    
    modelo.remember(acao, reward, valores_ant, valores_dps, done)  #salva step na memoria
    
    modelo.treina_modelo() #roda o modelo com toda a memoria do dia
           
    if reward > melhor_reward:
        melhor_reward = reward
    return reward #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        #print("dia {0} de {1}: R$ {2:0.2f}".format(dia, dias, reward)) #mostra o resultado do dia
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    #modelo.epsilon = 0.1
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            #s=time.time()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f}".format(epoca, sum_rewards))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0
            #e=time.time()
            #print(e-s)
            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
        print("Somatoria dos rewards: {0:0.2f}".format(sum_rewards_total))
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1031 00:32:36.194364 10152 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1031 00:32:36.500381 10152 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1031 00:32:36.526383 10152 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = 34357.39
# 115
# 104
# resultado da epoca 1 = -4216.70
# 105
# 114
# resultado da epoca 2 = 98022.93
# 116
# 103
# resultado da epoca 3 = -80902.04
# 94
# 125
# resultado da epoca 4 = 17836.25
# 104
# 115
# resultado da epoca 5 = 66848.87
# 113
# 106
# resultado da epoca 6 = 16243.60
# 100
# 119
# resultado da epoca 7 = -4819.01
# 109
# 110
# resultado da epoca 8 = -28384.38
# 110
# 109
# resultado da epoca 9 = -29037.82
# 103
# 116
# resultado da epoca 10 = -41926.88
# 102
# 117
# resultado da epoca 11 = 96867.32
# 107
# 112
# resultado da epoca 12 = -64489.76
# 105
# 114
# resultado da epoca 13 = 77672.46
# 114
# 105
# resultado da epoca 14 = 5657.59
# 109
# 110
# resultado da epoca 15 = -92591.64
# 102
# 117
# resultado da epoca 16 = -49239.57
# 102
# 117
# resultado da epoca 17 = 58620.58
# 113
# 106
# resultado da epoca 18 = -5655.86
# 97
# 122
# resultado da epoca 19 = 24439.39
# 115
# 104
# resultado da epoca 20 = -40796.47
# 107
# 112
# resultado da epoca 21 = -128843.08
# 103
# 116
# resultado da epoca 22 = -13655.92
# 110
# 109
# resultado da epoca 23 = 119769.65
# 124
# 95
# resultado da epoca 24 = -71133.80
# 106
# 113
# resultado da epoca 25 = -123605.27
# 96
# 123
# resultado da epoca 26 = -107473.33
# 104
# 115
# resultado da epoca 27 = -5786.84
# 107
# 112
# resultado da epoca 28 = -55599.31
# 117
# 102
# resultado da epoca 29 = -131906.43
# 97
# 122
# resultado da epoca 30 = -107877.44
# 113
# 106
# resultado da epoca 31 = -43709.34
# 111
# 108
# resultado da epoca 32 = 103786.84
# 106
# 113
# resultado da epoca 33 = -69244.98
# 115
# 104
# resultado da epoca 34 = -84253.59
# 97
# 122
# resultado da epoca 35 = -93296.60
# 105
# 114
# resultado da epoca 36 = -78251.74
# 112
# 107
# resultado da epoca 37 = 16553.35
# 109
# 110
# resultado da epoca 38 = -13411.29
# 102
# 117
# resultado da epoca 39 = 34251.12
# 104
# 115
# resultado da epoca 40 = -55503.97
# 109
# 110
# resultado da epoca 41 = 31875.04
# 124
# 95
# resultado da epoca 42 = -94066.85
# 111
# 108
# resultado da epoca 43 = -95419.05
# 96
# 123
# resultado da epoca 44 = -91155.00
# 106
# 113
# resultado da epoca 45 = -29294.50
# 106
# 113
# resultado da epoca 46 = -57749.21
# 101
# 118
# resultado da epoca 47 = -22261.43
# 109
# 110
# resultado da epoca 48 = -72525.40
# 110
# 109
# resultado da epoca 49 = -90970.48
# 96
# 123
# resultado da epoca 50 = -45935.29
# 103
# 116
# resultado da epoca 51 = 106093.90
# 110
# 109
# resultado da epoca 52 = -11008.30
# 103
# 116
# resultado da epoca 53 = 6265.08
# 104
# 115
# resultado da epoca 54 = -63835.92
# 107
# 112
# resultado da epoca 55 = -25729.54
# 111
# 108
# resultado da epoca 56 = -83273.13
# 108
# 111
# resultado da epoca 57 = -79988.79
# 112
# 107
# resultado da epoca 58 = -69852.50
# 115
# 104
# resultado da epoca 59 = 84889.53
# 111
# 108
# resultado da epoca 60 = -30751.70
# 108
# 111
# resultado da epoca 61 = -34936.46
# 99
# 120
# resultado da epoca 62 = 57475.34
# 120
# 99
# resultado da epoca 63 = -56075.81
# 102
# 117
# resultado da epoca 64 = 49642.14
# 110
# 109
# resultado da epoca 65 = 54126.88
# 101
# 118
# resultado da epoca 66 = 19979.79
# 111
# 108
# resultado da epoca 67 = 159137.02
# 114
# 105
# resultado da epoca 68 = 4847.77
# 104
# 115
# resultado da epoca 69 = -2907.13
# 98
# 121
# resultado da epoca 70 = 27860.60
# 109
# 110
# resultado da epoca 71 = -37033.09
# 103
# 116
# resultado da epoca 72 = -58667.38
# 106
# 113
# resultado da epoca 73 = 8617.14
# 109
# 110
# resultado da epoca 74 = -709.95
# 109
# 110
# resultado da epoca 75 = 21134.60
# 107
# 112
# resultado da epoca 76 = 8323.09
# 107
# 112
# resultado da epoca 77 = 70462.36
# 106
# 113
# resultado da epoca 78 = -42156.35
# 107
# 112
# resultado da epoca 79 = 20936.07
# 104
# 115
# resultado da epoca 80 = 38919.73
# 104
# 115
# resultado da epoca 81 = -94801.27
# 103
# 116
# resultado da epoca 82 = 164619.57
# 121
# 98
# resultado da epoca 83 = -23122.51
# 109
# 110
# resultado da epoca 84 = 24213.95
# 110
# 109
# resultado da epoca 85 = -103214.53
# 101
# 118
# resultado da epoca 86 = -24008.68
# 105
# 114
# resultado da epoca 87 = 16642.85
# 113
# 106
# resultado da epoca 88 = -76960.59
# 102
# 117
# resultado da epoca 89 = -24184.24
# 105
# 114
# resultado da epoca 90 = 1773.78
# 115
# 104
# resultado da epoca 91 = -72548.84
# 96
# 123
# resultado da epoca 92 = -13972.47
# 105
# 114
# resultado da epoca 93 = -74063.58
# 102
# 117
# resultado da epoca 94 = 7456.21
# 111
# 108
# resultado da epoca 95 = -97803.81
# 107
# 112
# resultado da epoca 96 = -2752.84
# 113
# 106
# resultado da epoca 97 = -91357.61
# 106
# 113
# resultado da epoca 98 = 6863.65
# 110
# 109
# resultado da epoca 99 = 41120.91
# 111
# 108
# resultado da epoca 100 = -2059.43
# 112
# 107
# resultado da epoca 101 = -194445.11
# 95
# 124
# resultado da epoca 102 = -91561.22
# 95
# 124
# resultado da epoca 103 = -56296.42
# 103
# 116
# resultado da epoca 104 = 73955.48
# 112
# 107
# resultado da epoca 105 = 74067.57
# 96
# 123
# resultado da epoca 106 = -66201.61
# 103
# 116
# resultado da epoca 107 = -61799.70
# 109
# 110
# resultado da epoca 108 = 52802.51
# 118
# 101
# resultado da epoca 109 = -106950.40
# 101
# 118
# resultado da epoca 110 = 142.12
# 112
# 107
# resultado da epoca 111 = -31018.24
# 105
# 114
# resultado da epoca 112 = 33004.76
# 108
# 111
# resultado da epoca 113 = -99286.78
# 105
# 114
# resultado da epoca 114 = -1417.89
# 111
# 108
# resultado da epoca 115 = 49422.30
# 113
# 106
# resultado da epoca 116 = 4689.22
# 106
# 113
# resultado da epoca 117 = -95413.31
# 106
# 113
# resultado da epoca 118 = -58687.58
# 101
# 118
# resultado da epoca 119 = 61141.21
# 115
# 104
# resultado da epoca 120 = -185118.32
# 98
# 121
# resultado da epoca 121 = -75347.94
# 103
# 116
# resultado da epoca 122 = 55790.97
# 108
# 111
# resultado da epoca 123 = -2145.98
# 110
# 109
# resultado da epoca 124 = -31531.11
# 110
# 109
# resultado da epoca 125 = -110496.40
# 104
# 115
# resultado da epoca 126 = -128339.75
# 100
# 119
# resultado da epoca 127 = -23931.68
# 111
# 108
# resultado da epoca 128 = -57689.19
# 107
# 112
# resultado da epoca 129 = -129698.66
# 103
# 116
# resultado da epoca 130 = -104995.55
# 106
# 113
# resultado da epoca 131 = -42366.52
# 107
# 112
# resultado da epoca 132 = -202193.44
# 99
# 120
# resultado da epoca 133 = 25572.45
# 113
# 106
# resultado da epoca 134 = -119689.41
# 100
# 119
# resultado da epoca 135 = -177111.38
# 99
# 120
# resultado da epoca 136 = -16175.93
# 108
# 111
# resultado da epoca 137 = -174916.07
# 93
# 126
# resultado da epoca 138 = -81605.21
# 103
# 116
# resultado da epoca 139 = -56742.78
# 107
# 112
# resultado da epoca 140 = 60670.71
# 111
# 108
# resultado da epoca 141 = 59064.15
# 106
# 113
# resultado da epoca 142 = 41761.48
# 107
# 112
# resultado da epoca 143 = -82918.20
# 107
# 112
# resultado da epoca 144 = -74659.81
# 108
# 111
# resultado da epoca 145 = -70201.55
# 105
# 114
# resultado da epoca 146 = -27352.25
# 105
# 114
# resultado da epoca 147 = -116081.24
# 103
# 116
# resultado da epoca 148 = 39919.62
# 116
# 103
# resultado da epoca 149 = 22028.36
# 112
# 107
# resultado da epoca 150 = -18059.37
# 100
# 119
# resultado da epoca 151 = 7634.61
# 107
# 112
# resultado da epoca 152 = 10000.66
# 117
# 102
# resultado da epoca 153 = 60925.39
# 115
# 104
# resultado da epoca 154 = 15979.37
# 125
# 94
# resultado da epoca 155 = -12458.22
# 113
# 106
# resultado da epoca 156 = -9524.28
# 107
# 112
# resultado da epoca 157 = 35630.01
# 110
# 109
# resultado da epoca 158 = -36593.29
# 101
# 118
# resultado da epoca 159 = -9121.07
# 100
# 119
# resultado da epoca 160 = 39124.26
# 110
# 109
# resultado da epoca 161 = -37661.60
# 102
# 117
# resultado da epoca 162 = 3952.78
# 116
# 103
# resultado da epoca 163 = -79871.95
# 109
# 110
# resultado da epoca 164 = 22945.03
# 113
# 106
# resultado da epoca 165 = 47184.27
# 105
# 114
# resultado da epoca 166 = 50633.44
# 112
# 107
# resultado da epoca 167 = -19953.85
# 111
# 108
# resultado da epoca 168 = 2213.20
# 114
# 105
# resultado da epoca 169 = -88617.85
# 105
# 114
# resultado da epoca 170 = -46738.87
# 105
# 114
# resultado da epoca 171 = 51763.75
# 113
# 106
# resultado da epoca 172 = 21790.21
# 109
# 110
# resultado da epoca 173 = -83159.97
# 106
# 113
# resultado da epoca 174 = -52846.11
# 105
# 114
# resultado da epoca 175 = 73735.14
# 111
# 108
# resultado da epoca 176 = 114595.44
# 109
# 110
# resultado da epoca 177 = -32074.69
# 102
# 117
# resultado da epoca 178 = -20008.64
# 111
# 108
# resultado da epoca 179 = 1914.65
# 116
# 103
# resultado da epoca 180 = -35443.72
# 101
# 118
# resultado da epoca 181 = 54418.52
# 111
# 108
# resultado da epoca 182 = 36345.24
# 114
# 105
# resultado da epoca 183 = -7167.75
# 106
# 113
# resultado da epoca 184 = 107146.01
# 113
# 106
# resultado da epoca 185 = 5219.95
# 112
# 107
# resultado da epoca 186 = 44661.45
# 113
# 106
# resultado da epoca 187 = -36961.80
# 109
# 110
# resultado da epoca 188 = -10915.00
# 115
# 104
# resultado da epoca 189 = -16111.03
# 106
# 113
# resultado da epoca 190 = -27034.39
# 102
# 117
# resultado da epoca 191 = -29613.80
# 106
# 113
# resultado da epoca 192 = -87417.24
# 97
# 122
# resultado da epoca 193 = -84902.69
# 113
# 106
# resultado da epoca 194 = 6519.14
# 108
# 111
# resultado da epoca 195 = -48288.16
# 109
# 110
# resultado da epoca 196 = -68404.37
# 107
# 112
# resultado da epoca 197 = 116318.87
# 110
# 109
# resultado da epoca 198 = -102478.71
# 98
# 121
# resultado da epoca 199 = -34501.12
# 111
# 108
# resultado da epoca 200 = -17277.87
# 112
# 107
# resultado da epoca 201 = -35021.67
# 105
# 114
# resultado da epoca 202 = -71586.69
# 110
# 109
# resultado da epoca 203 = -3406.48
# 107
# 112
# resultado da epoca 204 = -4226.82
# 116
# 103
# resultado da epoca 205 = -87886.24
# 105
# 114
# resultado da epoca 206 = 46394.80
# 110
# 109
# resultado da epoca 207 = 78277.64
# 113
# 106
# resultado da epoca 208 = 83955.03
# 108
# 111
# resultado da epoca 209 = 111725.27
# 115
# 104
# resultado da epoca 210 = -72428.64
# 104
# 115
# resultado da epoca 211 = -84375.28
# 107
# 112
# resultado da epoca 212 = 114592.61
# 117
# 102
# resultado da epoca 213 = -50371.13
# 102
# 117
# resultado da epoca 214 = 32524.59
# 105
# 114
# resultado da epoca 215 = 99882.44
# 100
# 119
# resultado da epoca 216 = 6592.69
# 109
# 110
# resultado da epoca 217 = -30903.22
# 109
# 110
# resultado da epoca 218 = 42786.20
# 111
# 108
# resultado da epoca 219 = 59575.89
# 119
# 100
# resultado da epoca 220 = 91365.52
# 110
# 109
# resultado da epoca 221 = -48242.93
# 113
# 106
# resultado da epoca 222 = -22649.39
# 116
# 103
# resultado da epoca 223 = 40467.91
# 115
# 104
# resultado da epoca 224 = 46978.49
# 112
# 107
# resultado da epoca 225 = 42691.72
# 109
# 110
# resultado da epoca 226 = 66171.11
# 115
# 104
# resultado da epoca 227 = 1451.64
# 104
# 115
# resultado da epoca 228 = 20774.03
# 104
# 115
# resultado da epoca 229 = 15069.28
# 105
# 114
# resultado da epoca 230 = -63865.44
# 108
# 111
# resultado da epoca 231 = 39647.50
# 117
# 102
# resultado da epoca 232 = -64618.35
# 101
# 118
# resultado da epoca 233 = 88587.11
# 111
# 108
# resultado da epoca 234 = 22920.95
# 109
# 110
# resultado da epoca 235 = -20226.33
# 109
# 110
# resultado da epoca 236 = -32130.57
# 106
# 113
# resultado da epoca 237 = 7021.87
# 105
# 114
# resultado da epoca 238 = -7784.06
# 105
# 114
# resultado da epoca 239 = 14269.18
# 103
# 116
# resultado da epoca 240 = 1181.55
# 106
# 113
# resultado da epoca 241 = 28403.55
# 111
# 108
# resultado da epoca 242 = -30065.14
# 106
# 113
# resultado da epoca 243 = -4812.55
# 109
# 110
# resultado da epoca 244 = -26014.27
# 110
# 109
# resultado da epoca 245 = 27794.64
# 112
# 107
# resultado da epoca 246 = -6134.82
# 111
# 108
# resultado da epoca 247 = -18985.38
# 112
# 107
# resultado da epoca 248 = -83094.54
# 106
# 113
# resultado da epoca 249 = 40118.06
# 110
# 109
# resultado da epoca 250 = 24469.56
# 113
# 106
# resultado da epoca 251 = 18540.80
# 110
# 109
# resultado da epoca 252 = 39939.97
# 113
# 106
# resultado da epoca 253 = 66727.09
# 110
# 109
# resultado da epoca 254 = -53503.35
# 104
# 115
# resultado da epoca 255 = 84082.83
# 112
# 107
# resultado da epoca 256 = 74849.88
# 107
# 112
# resultado da epoca 257 = 17962.48
# 108
# 111
# resultado da epoca 258 = 82462.40
# 113
# 106
# resultado da epoca 259 = 25474.75
# 107
# 112
# resultado da epoca 260 = 58730.86
# 107
# 112
# resultado da epoca 261 = -14646.66
# 107
# 112
# resultado da epoca 262 = 23244.17
# 108
# 111
# resultado da epoca 263 = 31972.17
# 111
# 108
# resultado da epoca 264 = -11573.11
# 114
# 105
# resultado da epoca 265 = -15722.76
# 108
# 111
# resultado da epoca 266 = -58021.14
# 106
# 113
# resultado da epoca 267 = 14027.03
# 108
# 111
# resultado da epoca 268 = -6131.42
# 108
# 111
# resultado da epoca 269 = 10049.37
# 109
# 110
# resultado da epoca 270 = 69440.64
# 109
# 110
# resultado da epoca 271 = 37639.89
# 115
# 104
# resultado da epoca 272 = 44849.54
# 107
# 112
# resultado da epoca 273 = -58412.07
# 107
# 112
# resultado da epoca 274 = 183186.66
# 120
# 99
# resultado da epoca 275 = 95270.40
# 107
# 112
# resultado da epoca 276 = -27772.87
# 105
# 114
# resultado da epoca 277 = -43645.21
# 114
# 105
# resultado da epoca 278 = -63232.52
# 108
# 111
# resultado da epoca 279 = 24327.43
# 115
# 104
# resultado da epoca 280 = -25101.47
# 106
# 113
# resultado da epoca 281 = 64349.08
# 108
# 111
# resultado da epoca 282 = -136424.85
# 107
# 112
# resultado da epoca 283 = 39070.36
# 113
# 106
# resultado da epoca 284 = -109652.88
# 102
# 117
# resultado da epoca 285 = -10962.58
# 104
# 115
# resultado da epoca 286 = 23895.76
# 107
# 112
# resultado da epoca 287 = 7617.48
# 109
# 110
# resultado da epoca 288 = -13245.06
# 103
# 116
# resultado da epoca 289 = 2625.80
# 108
# 111
# resultado da epoca 290 = -48729.58
# 111
# 108
# resultado da epoca 291 = -91813.29
# 101
# 118
# resultado da epoca 292 = -17603.68
# 104
# 115
# resultado da epoca 293 = -25473.79
# 108
# 111
# resultado da epoca 294 = -158222.65
# 112
# 107
# resultado da epoca 295 = -61352.98
# 106
# 113
# resultado da epoca 296 = -121772.93
# 111
# 108
# resultado da epoca 297 = 95222.66
# 110
# 109
# resultado da epoca 298 = 47467.62
# 109
# 110
# resultado da epoca 299 = -8108.03
# 104
# 115
# resultado da epoca 300 = 49638.37
# 110
# 109
# resultado da epoca 301 = -4806.37
# 103
# 116
# resultado da epoca 302 = -66239.10
# 102
# 117
# resultado da epoca 303 = 92845.12
# 116
# 103
# resultado da epoca 304 = 41439.66
# 111
# 108
# resultado da epoca 305 = -61023.33
# 105
# 114
# resultado da epoca 306 = -67813.09
# 101
# 118
# resultado da epoca 307 = -20828.51
# 101
# 118
# resultado da epoca 308 = -69319.39
# 111
# 108
# resultado da epoca 309 = -24444.95
# 111
# 108
# resultado da epoca 310 = -60560.38
# 110
# 109
# resultado da epoca 311 = -72179.67
# 110
# 109
# resultado da epoca 312 = -23034.81
# 110
# 109
# resultado da epoca 313 = -51782.68
# 112
# 107
# resultado da epoca 314 = -5136.49
# 107
# 112
# resultado da epoca 315 = 48336.00
# 114
# 105
# resultado da epoca 316 = -225285.38
# 111
# 108
# resultado da epoca 317 = 36698.46
# 109
# 110
# resultado da epoca 318 = -82454.08
# 112
# 107
# resultado da epoca 319 = 3229.79
# 109
# 110
# resultado da epoca 320 = -23966.59
# 112
# 107
# resultado da epoca 321 = -102794.09
# 105
# 114
# resultado da epoca 322 = 75136.90
# 114
# 105
# resultado da epoca 323 = -168431.86
# 97
# 122
# resultado da epoca 324 = 111305.25
# 118
# 101
# resultado da epoca 325 = -4056.48
# 106
# 113
# resultado da epoca 326 = 19794.08
# 107
# 112
# resultado da epoca 327 = -2284.61
# 104
# 115
# resultado da epoca 328 = 121082.29
# 113
# 106
# resultado da epoca 329 = -15087.42
# 107
# 112
# resultado da epoca 330 = -52583.77
# 103
# 116
# resultado da epoca 331 = 21502.77
# 108
# 111
# resultado da epoca 332 = 30991.13
# 115
# 104
# resultado da epoca 333 = 103975.62
# 112
# 107
# resultado da epoca 334 = -22552.25
# 108
# 111
# resultado da epoca 335 = 52766.05
# 106
# 113
# resultado da epoca 336 = 12766.71
# 108
# 111
# resultado da epoca 337 = -17593.80
# 107
# 112
# resultado da epoca 338 = 44627.50
# 105
# 114
# resultado da epoca 339 = 57508.87
# 109
# 110
# resultado da epoca 340 = 66790.21
# 111
# 108
# resultado da epoca 341 = 23539.54
# 102
# 117
# resultado da epoca 342 = 59081.16
# 112
# 107
# resultado da epoca 343 = -17740.55
# 113
# 106
# resultado da epoca 344 = -19896.90
# 105
# 114
# resultado da epoca 345 = 43834.43
# 110
# 109
# resultado da epoca 346 = 59238.19
# 106
# 113
# resultado da epoca 347 = 22101.62
# 108
# 111
# resultado da epoca 348 = -8110.67
# 111
# 108
# resultado da epoca 349 = 59939.51
# 117
# 102
# resultado da epoca 350 = 121191.53
# 114
# 105
# resultado da epoca 351 = 4580.71
# 108
# 111
# resultado da epoca 352 = 23364.15
# 109
# 110
# resultado da epoca 353 = 36802.07
# 109
# 110
# resultado da epoca 354 = 36435.35
# 110
# 109
# resultado da epoca 355 = 80953.00
# 113
# 106
# resultado da epoca 356 = 57171.66
# 113
# 106
# resultado da epoca 357 = -9284.44
# 112
# 107
# resultado da epoca 358 = -25481.07
# 109
# 110
# resultado da epoca 359 = 42294.28
# 114
# 105
# resultado da epoca 360 = 1758.69
# 110
# 109
# resultado da epoca 361 = 1564.12
# 111
# 108
# resultado da epoca 362 = -49650.25
# 100
# 119
# resultado da epoca 363 = 45266.17
# 106
# 113
# resultado da epoca 364 = 1861.10
# 108
# 111
# resultado da epoca 365 = 11690.40
# 107
# 112
# resultado da epoca 366 = 34654.82
# 115
# 104
# resultado da epoca 367 = -12789.38
# 114
# 105
# resultado da epoca 368 = -3879.93
# 106
# 113
# resultado da epoca 369 = 8211.81
# 104
# 115
# resultado da epoca 370 = -25616.52
# 109
# 110
# resultado da epoca 371 = -38380.33
# 97
# 122
# resultado da epoca 372 = 10418.69
# 105
# 114
# resultado da epoca 373 = 51631.76
# 103
# 116
# resultado da epoca 374 = -2473.77
# 105
# 114
# resultado da epoca 375 = -68807.87
# 106
# 113
# resultado da epoca 376 = -42856.34
# 102
# 117
# resultado da epoca 377 = -20361.97
# 103
# 116
# resultado da epoca 378 = 38373.02
# 105
# 114
# resultado da epoca 379 = -47651.12
# 112
# 107
# resultado da epoca 380 = -130933.40
# 109
# 110
# resultado da epoca 381 = -2284.65
# 105
# 114
# resultado da epoca 382 = -72775.37
# 95
# 124
# resultado da epoca 383 = 86107.86
# 112
# 107
# resultado da epoca 384 = 83579.93
# 105
# 114
# resultado da epoca 385 = 86128.18
# 108
# 111
# resultado da epoca 386 = 168588.08
# 111
# 108
# resultado da epoca 387 = 49155.59
# 104
# 115
# resultado da epoca 388 = 148120.54
# 102
# 117
# resultado da epoca 389 = 292626.17
# 111
# 108
# resultado da epoca 390 = 236058.82
# 122
# 97
# resultado da epoca 391 = 138792.24
# 115
# 104
# resultado da epoca 392 = 24773.95
# 110
# 109
# resultado da epoca 393 = -20199.10
# 107
# 112
# resultado da epoca 394 = 11421.45
# 102
# 117
# resultado da epoca 395 = -10120.60
# 108
# 111
# resultado da epoca 396 = -21634.19
# 111
# 108
# resultado da epoca 397 = -100357.25
# 111
# 108
# resultado da epoca 398 = -15132.20
# 105
# 114
# resultado da epoca 399 = 193567.34
# 107
# 112
# resultado da epoca 400 = -20911.28
# 97
# 122
# resultado da epoca 401 = -7213.97
# 108
# 111
# resultado da epoca 402 = 20520.16
# 102
# 117
# resultado da epoca 403 = 10385.46
# 106
# 113
# resultado da epoca 404 = -39519.67
# 112
# 107
# resultado da epoca 405 = 29015.14
# 106
# 113
# resultado da epoca 406 = 7684.55
# 106
# 113
# resultado da epoca 407 = 57624.58
# 109
# 110
# resultado da epoca 408 = 74369.53
# 112
# 107
# resultado da epoca 409 = 60955.53
# 111
# 108
# resultado da epoca 410 = 19963.08
# 107
# 112
# resultado da epoca 411 = -42411.59
# 105
# 114
# resultado da epoca 412 = -11841.90
# 107
# 112
# resultado da epoca 413 = 32792.79
# 109
# 110
# resultado da epoca 414 = -28784.00
# 100
# 119
# resultado da epoca 415 = 64199.01
# 105
# 114
# resultado da epoca 416 = -15966.52
# 110
# 109
# resultado da epoca 417 = -70916.02
# 106
# 113
# resultado da epoca 418 = -16940.03
# 113
# 106
# resultado da epoca 419 = -93980.93
# 108
# 111
# resultado da epoca 420 = -26634.74
# 113
# 106
# resultado da epoca 421 = 1603.87
# 110
# 109
# resultado da epoca 422 = -50554.76
# 107
# 112
# resultado da epoca 423 = 18312.15
# 106
# 113
# resultado da epoca 424 = 158465.74
# 112
# 107
# resultado da epoca 425 = 251598.14
# 121
# 98
# resultado da epoca 426 = 12413.70
# 107
# 112
# resultado da epoca 427 = 4239.29
# 110
# 109
# resultado da epoca 428 = 24301.94
# 114
# 105
# resultado da epoca 429 = -7523.27
# 107
# 112
# resultado da epoca 430 = -75882.39
# 110
# 109
# resultado da epoca 431 = 2883.37
# 110
# 109
# resultado da epoca 432 = -61967.99
# 113
# 106
# resultado da epoca 433 = -62623.51
# 113
# 106
# resultado da epoca 434 = 14302.94
# 112
# 107
# resultado da epoca 435 = -50228.21
# 107
# 112
# resultado da epoca 436 = -25974.26
# 107
# 112
# resultado da epoca 437 = -50595.30
# 107
# 112
# resultado da epoca 438 = -37946.05
# 105
# 114
# resultado da epoca 439 = -26520.03
# 107
# 112
# resultado da epoca 440 = -39032.42
# 106
# 113
# resultado da epoca 441 = -28651.65
# 105
# 114
# resultado da epoca 442 = 22266.62
# 110
# 109
# resultado da epoca 443 = -25159.64
# 108
# 111
# resultado da epoca 444 = -33159.86
# 109
# 110
# resultado da epoca 445 = -70189.17
# 105
# 114
# resultado da epoca 446 = 96936.39
# 122
# 97
# resultado da epoca 447 = 86412.79
# 107
# 112
# resultado da epoca 448 = 53971.67
# 109
# 110
# resultado da epoca 449 = 89372.14
# 111
# 108
# resultado da epoca 450 = 39976.39
# 109
# 110
# resultado da epoca 451 = -63433.70
# 103
# 116
# resultado da epoca 452 = 57536.81
# 110
# 109
# resultado da epoca 453 = -23726.13
# 106
# 113
# resultado da epoca 454 = 79849.09
# 112
# 107
# resultado da epoca 455 = -3285.73
# 106
# 113
# resultado da epoca 456 = -33649.97
# 105
# 114
# resultado da epoca 457 = 55808.11
# 107
# 112
# resultado da epoca 458 = 9986.57
# 109
# 110
# resultado da epoca 459 = -20055.24
# 107
# 112
# resultado da epoca 460 = -1749.57
# 110
# 109
# resultado da epoca 461 = 11093.98
# 104
# 115
# resultado da epoca 462 = 27216.91
# 115
# 104
# resultado da epoca 463 = 27427.14
# 111
# 108
# resultado da epoca 464 = -6510.87
# 110
# 109
# resultado da epoca 465 = -28082.86
# 106
# 113
# resultado da epoca 466 = -12806.93
# 109
# 110
# resultado da epoca 467 = 53391.67
# 108
# 111
# resultado da epoca 468 = 33883.16
# 109
# 110
# resultado da epoca 469 = 40380.40
# 110
# 109
# resultado da epoca 470 = 23310.54
# 109
# 110
# resultado da epoca 471 = -21309.10
# 109
# 110
# resultado da epoca 472 = -18661.83
# 107
# 112
# resultado da epoca 473 = -18721.92
# 108
# 111
# resultado da epoca 474 = 14404.71
# 107
# 112
# resultado da epoca 475 = -22397.23
# 108
# 111
# resultado da epoca 476 = 32289.21
# 104
# 115
# resultado da epoca 477 = -39530.36
# 107
# 112
# resultado da epoca 478 = 37989.72
# 111
# 108
# resultado da epoca 479 = -7657.92
# 105
# 114
# resultado da epoca 480 = -35145.55
# 110
# 109
# resultado da epoca 481 = -28448.73
# 109
# 110
# resultado da epoca 482 = 1786.97
# 111
# 108
# resultado da epoca 483 = 41376.30
# 108
# 111
# resultado da epoca 484 = -16603.60
# 106
# 113
# resultado da epoca 485 = 23144.00
# 109
# 110
# resultado da epoca 486 = 40418.33
# 108
# 111
# resultado da epoca 487 = 20322.91
# 107
# 112
# resultado da epoca 488 = -4551.79
# 106
# 113
# resultado da epoca 489 = 16501.51
# 110
# 109
# resultado da epoca 490 = 15254.97
# 110
# 109
# resultado da epoca 491 = -35608.06
# 109
# 110
# resultado da epoca 492 = 59988.41
# 110
# 109
# resultado da epoca 493 = 5190.87
# 107
# 112
# resultado da epoca 494 = 47172.99
# 109
# 110
# resultado da epoca 495 = 32072.62
# 111
# 108
# resultado da epoca 496 = 47121.61
# 109
# 110
# resultado da epoca 497 = 49394.34
# 109
# 110
# resultado da epoca 498 = -39342.55
# 105
# 114
# resultado da epoca 499 = -11421.18
# 109
# 110
# resultado da epoca 500 = 49246.62
# 114
# 105
# resultado da epoca 501 = 19554.42
# 108
# 111
# resultado da epoca 502 = 26928.64
# 107
# 112
# resultado da epoca 503 = -5614.37
# 108
# 111
# resultado da epoca 504 = 28788.44
# 107
# 112
# resultado da epoca 505 = -277.65
# 107
# 112
# resultado da epoca 506 = -30690.99
# 111
# 108
# resultado da epoca 507 = 35150.26
# 109
# 110
# resultado da epoca 508 = 5339.97
# 108
# 111
# resultado da epoca 509 = -13075.53
# 112
# 107
# resultado da epoca 510 = 4001.92
# 103
# 116
# resultado da epoca 511 = 4613.93
# 109
# 110
# resultado da epoca 512 = -52612.21
# 106
# 113
# resultado da epoca 513 = -35387.80
# 107
# 112
# resultado da epoca 514 = -34381.57
# 108
# 111
# resultado da epoca 515 = -30332.58
# 105
# 114
# resultado da epoca 516 = 9058.82
# 109
# 110
# resultado da epoca 517 = -60597.35
# 105
# 114
# resultado da epoca 518 = 5775.37
# 106
# 113
# resultado da epoca 519 = -12430.21
# 108
# 111
# resultado da epoca 520 = -13322.37
# 109
# 110
# resultado da epoca 521 = 17893.39
# 108
# 111
# resultado da epoca 522 = -14863.13
# 106
# 113
# resultado da epoca 523 = 8059.16
# 107
# 112
# resultado da epoca 524 = 36262.13
# 108
# 111
# resultado da epoca 525 = 10281.84
# 108
# 111
# resultado da epoca 526 = -3991.26
# 109
# 110
# resultado da epoca 527 = 4272.11
# 112
# 107
# resultado da epoca 528 = 12488.91
# 107
# 112
# resultado da epoca 529 = 3972.74
# 107
# 112
# resultado da epoca 530 = -10177.37
# 111
# 108
# resultado da epoca 531 = 56150.29
# 109
# 110
# resultado da epoca 532 = 513.24
# 108
# 111
# resultado da epoca 533 = -23371.71
# 109
# 110
# resultado da epoca 534 = -48877.54
# 106
# 113
# resultado da epoca 535 = -40382.63
# 109
# 110
# resultado da epoca 536 = -25912.26
# 106
# 113
# resultado da epoca 537 = 38190.02
# 110
# 109
# resultado da epoca 538 = -5669.94
# 107
# 112
# resultado da epoca 539 = -15459.65
# 109
# 110
# resultado da epoca 540 = 69145.20
# 108
# 111
# resultado da epoca 541 = 21367.93
# 107
# 112
# resultado da epoca 542 = -416.46
# 109
# 110
# resultado da epoca 543 = -9189.95
# 108
# 111
# resultado da epoca 544 = 65531.24
# 105
# 114
# resultado da epoca 545 = 33643.62
# 107
# 112
# resultado da epoca 546 = 42820.79
# 109
# 110
# resultado da epoca 547 = -60583.06
# 107
# 112
# resultado da epoca 548 = -20531.85
# 109
# 110
# resultado da epoca 549 = 34332.66
# 109
# 110
# resultado da epoca 550 = -15678.75
# 107
# 112
# resultado da epoca 551 = 97.49
# 108
# 111
# resultado da epoca 552 = 3090.99
# 108
# 111
# resultado da epoca 553 = -10572.89
# 106
# 113
# resultado da epoca 554 = 33245.42
# 108
# 111
# resultado da epoca 555 = 22664.64
# 109
# 110
# resultado da epoca 556 = -19243.57
# 104
# 115
# resultado da epoca 557 = 29347.71
# 108
# 111
# resultado da epoca 558 = -14921.29
# 106
# 113
# resultado da epoca 559 = 29445.14
# 110
# 109
# resultado da epoca 560 = 7176.13
# 110
# 109
# resultado da epoca 561 = 2631.98
# 110
# 109
# resultado da epoca 562 = 13771.37
# 106
# 113
# resultado da epoca 563 = -18522.50
# 108
# 111
# resultado da epoca 564 = -12056.62
# 104
# 115
# resultado da epoca 565 = -19435.64
# 107
# 112
# resultado da epoca 566 = 22081.48
# 106
# 113
# resultado da epoca 567 = -28147.62
# 105
# 114
# resultado da epoca 568 = 3601.84
# 108
# 111
# resultado da epoca 569 = -20867.41
# 105
# 114
# resultado da epoca 570 = -23057.03
# 109
# 110
# resultado da epoca 571 = -284.18
# 106
# 113
# resultado da epoca 572 = -4604.03
# 105
# 114
# resultado da epoca 573 = 40919.27
# 112
# 107
# resultado da epoca 574 = 16462.60
# 107
# 112
# resultado da epoca 575 = 14276.17
# 108
# 111
# resultado da epoca 576 = 5635.75
# 107
# 112
# resultado da epoca 577 = 31179.40
# 112
# 107
# resultado da epoca 578 = -2036.01
# 107
# 112
# resultado da epoca 579 = -29318.79
# 105
# 114
# resultado da epoca 580 = -23675.09
# 107
# 112
# resultado da epoca 581 = 13139.91
# 104
# 115
# resultado da epoca 582 = -8736.33
# 110
# 109
# resultado da epoca 583 = -23292.62
# 107
# 112
# resultado da epoca 584 = 31861.39
# 107
# 112
# resultado da epoca 585 = -63989.57
# 107
# 112
# resultado da epoca 586 = -16853.44
# 109
# 110
# resultado da epoca 587 = -30453.16
# 106
# 113
# resultado da epoca 588 = -5020.49
# 106
# 113
# resultado da epoca 589 = -743.47
# 106
# 113
# resultado da epoca 590 = 20374.51
# 108
# 111
# resultado da epoca 591 = 2336.65
# 110
# 109
# resultado da epoca 592 = -28716.11
# 105
# 114
# resultado da epoca 593 = -56436.48
# 105
# 114
# resultado da epoca 594 = 7818.27
# 108
# 111
# resultado da epoca 595 = -8513.31
# 107
# 112
# resultado da epoca 596 = 30020.35
# 109
# 110
# resultado da epoca 597 = 9275.23
# 109
# 110
# resultado da epoca 598 = -35733.29
# 109
# 110
# resultado da epoca 599 = -18978.04
# 107
# 112
# resultado da epoca 600 = -61412.72
# 106
# 113
# resultado da epoca 601 = -28726.54
# 106
# 113
# resultado da epoca 602 = -19887.87
# 106
# 113
# resultado da epoca 603 = -29287.23
# 105
# 114
# resultado da epoca 604 = -38965.42
# 107
# 112
# resultado da epoca 605 = -4289.74
# 108
# 111
# resultado da epoca 606 = -28240.08
# 104
# 115
# resultado da epoca 607 = 12256.35
# 105
# 114
# resultado da epoca 608 = 59364.58
# 107
# 112
# resultado da epoca 609 = 19946.43
# 107
# 112
# resultado da epoca 610 = -9378.47
# 110
# 109
# resultado da epoca 611 = 10040.73
# 105
# 114
# resultado da epoca 612 = -24934.98
# 107
# 112
# resultado da epoca 613 = -28463.70
# 106
# 113
# resultado da epoca 614 = -10196.25
# 110
# 109
# resultado da epoca 615 = -12467.29
# 108
# 111
# resultado da epoca 616 = 10556.78
# 107
# 112
# resultado da epoca 617 = -68273.29
# 106
# 113
# resultado da epoca 618 = -2246.65
# 108
# 111
# resultado da epoca 619 = -24263.77
# 109
# 110
# resultado da epoca 620 = -47556.41
# 108
# 111
# resultado da epoca 621 = -43657.37
# 107
# 112
# resultado da epoca 622 = 20417.10
# 105
# 114
# resultado da epoca 623 = -18563.53
# 103
# 116
# resultado da epoca 624 = -47529.03
# 105
# 114
# resultado da epoca 625 = 18072.81
# 107
# 112
# resultado da epoca 626 = -23907.97
# 109
# 110
# resultado da epoca 627 = -39382.45
# 106
# 113
# resultado da epoca 628 = -28548.97
# 108
# 111
# resultado da epoca 629 = -7700.03
# 107
# 112
# resultado da epoca 630 = 14631.67
# 104
# 115
# resultado da epoca 631 = -2430.94
# 111
# 108
# resultado da epoca 632 = 56411.17
# 107
# 112
# resultado da epoca 633 = -46135.39
# 106
# 113
# resultado da epoca 634 = -15289.97
# 107
# 112
# resultado da epoca 635 = -53188.21
# 104
# 115
# resultado da epoca 636 = -26207.78
# 106
# 113
# resultado da epoca 637 = -17181.67
# 109
# 110
# resultado da epoca 638 = -4408.18
# 108
# 111
# resultado da epoca 639 = -19725.15
# 103
# 116
# resultado da epoca 640 = -22529.96
# 108
# 111
# resultado da epoca 641 = 20812.87
# 107
# 112
# resultado da epoca 642 = -21549.13
# 106
# 113
# resultado da epoca 643 = -45817.29
# 106
# 113
# resultado da epoca 644 = -3762.01
# 105
# 114
# resultado da epoca 645 = 11398.18
# 104
# 115
# resultado da epoca 646 = -5450.13
# 108
# 111
# resultado da epoca 647 = 3881.59
# 110
# 109
# resultado da epoca 648 = -39257.08
# 108
# 111
# resultado da epoca 649 = -8827.57
# 108
# 111
# resultado da epoca 650 = -21959.32
# 103
# 116
# resultado da epoca 651 = -21537.20
# 106
# 113
# resultado da epoca 652 = 4288.37
# 109
# 110
# resultado da epoca 653 = 21163.85
# 110
# 109
# resultado da epoca 654 = -9813.55
# 108
# 111
# resultado da epoca 655 = -50077.93
# 106
# 113
# resultado da epoca 656 = -40035.42
# 106
# 113
# resultado da epoca 657 = -39061.82
# 111
# 108
# resultado da epoca 658 = 20720.65
# 108
# 111
# resultado da epoca 659 = 17507.29
# 106
# 113
# resultado da epoca 660 = 26048.26
# 109
# 110
# resultado da epoca 661 = -7195.06
# 105
# 114
# resultado da epoca 662 = -21386.98
# 103
# 116
# resultado da epoca 663 = -940.40
# 107
# 112
# resultado da epoca 664 = -8489.72
# 103
# 116
# resultado da epoca 665 = -43545.59
# 104
# 115
# resultado da epoca 666 = -27286.51
# 108
# 111
# resultado da epoca 667 = -2459.10
# 105
# 114
# resultado da epoca 668 = 24679.44
# 106
# 113
# resultado da epoca 669 = -7873.96
# 107
# 112
# resultado da epoca 670 = -38236.20
# 105
# 114
# resultado da epoca 671 = -8891.96
# 106
# 113
# resultado da epoca 672 = 24126.61
# 106
# 113
# resultado da epoca 673 = 19560.38
# 107
# 112
# resultado da epoca 674 = -6915.02
# 106
# 113
# resultado da epoca 675 = -55597.35
# 105
# 114
# resultado da epoca 676 = -13913.01
# 107
# 112
# resultado da epoca 677 = -1487.40
# 106
# 113
# resultado da epoca 678 = 15003.60
# 109
# 110
# resultado da epoca 679 = 2448.39
# 107
# 112
# resultado da epoca 680 = -9734.93
# 106
# 113
# resultado da epoca 681 = 5731.69
# 103
# 116
# resultado da epoca 682 = -744.59
# 108
# 111
# resultado da epoca 683 = -16927.72
# 106
# 113
# resultado da epoca 684 = -23307.23
# 107
# 112
# resultado da epoca 685 = 7369.59
# 107
# 112
# resultado da epoca 686 = -4840.74
# 108
# 111
# resultado da epoca 687 = -496.97
# 104
# 115
# resultado da epoca 688 = 3748.76
# 107
# 112
# resultado da epoca 689 = -15408.77
# 106
# 113
# resultado da epoca 690 = -53115.82
# 107
# 112
# resultado da epoca 691 = -66050.04
# 106
# 113
# resultado da epoca 692 = -31509.87
# 106
# 113
# resultado da epoca 693 = 12586.01
# 104
# 115
# resultado da epoca 694 = -43611.92
# 105
# 114
# resultado da epoca 695 = -22455.39
# 107
# 112
# resultado da epoca 696 = 14716.80
# 109
# 110
# resultado da epoca 697 = -37083.14
# 105
# 114
# resultado da epoca 698 = -36329.12
# 106
# 113
# resultado da epoca 699 = -20401.36
# 104
# 115
# resultado da epoca 700 = -8095.82
# 104
# 115
# resultado da epoca 701 = -37141.26
# 108
# 111
# resultado da epoca 702 = 7551.37
# 104
# 115
# resultado da epoca 703 = -39594.95
# 106
# 113
# resultado da epoca 704 = -43973.71
# 107
# 112
# resultado da epoca 705 = -8287.80
# 109
# 110
# resultado da epoca 706 = -35805.60
# 106
# 113
# resultado da epoca 707 = -32036.92
# 104
# 115
# resultado da epoca 708 = -47330.40
# 104
# 115
# resultado da epoca 709 = 3204.73
# 106
# 113
# resultado da epoca 710 = -17481.74
# 106
# 113
# resultado da epoca 711 = -20478.17
# 108
# 111
# resultado da epoca 712 = 26204.70
# 105
# 114
# resultado da epoca 713 = -9069.29
# 104
# 115
# resultado da epoca 714 = 18464.70
# 108
# 111
# resultado da epoca 715 = -37763.07
# 105
# 114
# resultado da epoca 716 = -29955.50
# 107
# 112
# resultado da epoca 717 = 8707.49
# 104
# 115
# resultado da epoca 718 = 14621.10
# 109
# 110
# resultado da epoca 719 = -6207.45
# 106
# 113
# resultado da epoca 720 = 25498.81
# 104
# 115
# resultado da epoca 721 = 4492.81
# 105
# 114
# resultado da epoca 722 = -29108.61
# 105
# 114
# resultado da epoca 723 = -29677.46
# 107
# 112
# resultado da epoca 724 = -5713.91
# 107
# 112
# resultado da epoca 725 = -24509.05
# 106
# 113
# resultado da epoca 726 = -4092.79
# 105
# 114
# resultado da epoca 727 = -14808.47
# 106
# 113
# resultado da epoca 728 = -29917.67
# 105
# 114
# resultado da epoca 729 = -37448.80
# 105
# 114
# resultado da epoca 730 = -51625.47
# 107
# 112
# resultado da epoca 731 = 6803.09
# 104
# 115
# resultado da epoca 732 = -34458.67
# 106
# 113
# resultado da epoca 733 = -5642.06
# 108
# 111
# resultado da epoca 734 = 3201.04
# 104
# 115
# resultado da epoca 735 = 15379.13
# 106
# 113
# resultado da epoca 736 = 930.65
# 106
# 113
# resultado da epoca 737 = 3982.47
# 105
# 114
# resultado da epoca 738 = -34314.61
# 107
# 112
# resultado da epoca 739 = -51592.41
# 104
# 115
# resultado da epoca 740 = -44520.43
# 104
# 115
# resultado da epoca 741 = -5609.18
# 108
# 111
# resultado da epoca 742 = -7752.31
# 105
# 114
# resultado da epoca 743 = -18731.91
# 104
# 115
# resultado da epoca 744 = -1839.91
# 106
# 113
# resultado da epoca 745 = -39135.30
# 104
# 115
# resultado da epoca 746 = -33288.66
# 103
# 116
# resultado da epoca 747 = 11930.46
# 104
# 115
# resultado da epoca 748 = -24407.19
# 103
# 116
# resultado da epoca 749 = -53075.41
# 105
# 114
# resultado da epoca 750 = -45412.38
# 103
# 116
# resultado da epoca 751 = -11838.69
# 106
# 113
# resultado da epoca 752 = -18657.06
# 104
# 115
# resultado da epoca 753 = -28073.27
# 103
# 116
# resultado da epoca 754 = -5498.96
# 107
# 112
# resultado da epoca 755 = -3830.90
# 103
# 116
# resultado da epoca 756 = -27272.55
# 106
# 113
# resultado da epoca 757 = -53493.84
# 104
# 115
# resultado da epoca 758 = -11568.87
# 107
# 112
# resultado da epoca 759 = -35436.99
# 107
# 112
# resultado da epoca 760 = -51995.47
# 101
# 118
# resultado da epoca 761 = -15055.97
# 105
# 114
# resultado da epoca 762 = -44609.62
# 102
# 117
# resultado da epoca 763 = 1884.75
# 103
# 116
# resultado da epoca 764 = -15191.64
# 103
# 116
# resultado da epoca 765 = -26484.72
# 102
# 117
# resultado da epoca 766 = -15037.41
# 104
# 115
# resultado da epoca 767 = -21760.39
# 104
# 115
# resultado da epoca 768 = -24339.03
# 106
# 113
# resultado da epoca 769 = -35604.15
# 106
# 113
# resultado da epoca 770 = -2526.05
# 110
# 109
# resultado da epoca 771 = -33779.77
# 103
# 116
# resultado da epoca 772 = -22391.26
# 106
# 113
# resultado da epoca 773 = -22642.10
# 102
# 117
# resultado da epoca 774 = -37689.10
# 106
# 113
# resultado da epoca 775 = -32766.95
# 103
# 116
# resultado da epoca 776 = -27271.37
# 102
# 117
# resultado da epoca 777 = -20052.53
# 103
# 116
# resultado da epoca 778 = -18603.60
# 107
# 112
# resultado da epoca 779 = -3300.53
# 104
# 115
# resultado da epoca 780 = -23427.49
# 103
# 116
# resultado da epoca 781 = -93433.93
# 104
# 115
# resultado da epoca 782 = -36174.52
# 103
# 116
# resultado da epoca 783 = -49091.52
# 103
# 116
# resultado da epoca 784 = -34690.52
# 103
# 116
# resultado da epoca 785 = 1914.47
# 105
# 114
# resultado da epoca 786 = -54010.01
# 103
# 116
# resultado da epoca 787 = -34283.22
# 104
# 115
# resultado da epoca 788 = -41443.17
# 102
# 117
# resultado da epoca 789 = -7052.19
# 100
# 119
# resultado da epoca 790 = -37577.02
# 102
# 117
# resultado da epoca 791 = -26563.79
# 102
# 117
# resultado da epoca 792 = -40766.85
# 101
# 118
# resultado da epoca 793 = -51274.08
# 105
# 114
# resultado da epoca 794 = -19202.19
# 104
# 115
# resultado da epoca 795 = -14937.00
# 103
# 116
# resultado da epoca 796 = -44979.40
# 105
# 114
# resultado da epoca 797 = -36340.86
# 101
# 118
# resultado da epoca 798 = -22957.00
# 101
# 118
# resultado da epoca 799 = -31269.37
# 101
# 118
# resultado da epoca 800 = -22586.50
# 103
# 116
# resultado da epoca 801 = -44332.14
# 105
# 114
# resultado da epoca 802 = -53995.65
# 101
# 118
# resultado da epoca 803 = -45565.30
# 103
# 116
# resultado da epoca 804 = -46347.59
# 103
# 116
# resultado da epoca 805 = -5276.09
# 105
# 114
# resultado da epoca 806 = -54122.41
# 102
# 117
# resultado da epoca 807 = -24611.57
# 104
# 115
# resultado da epoca 808 = -46520.00
# 101
# 118
# resultado da epoca 809 = -5231.52
# 103
# 116
# resultado da epoca 810 = -23010.34
# 102
# 117
# resultado da epoca 811 = -2229.69
# 106
# 113
# resultado da epoca 812 = -22127.92
# 104
# 115
# resultado da epoca 813 = -19559.09
# 104
# 115
# resultado da epoca 814 = -32094.19
# 104
# 115
# resultado da epoca 815 = -1401.86
# 105
# 114
# resultado da epoca 816 = -26162.89
# 101
# 118
# resultado da epoca 817 = -248.97
# 104
# 115
# resultado da epoca 818 = -26787.18
# 102
# 117
# resultado da epoca 819 = -25123.27
# 103
# 116
# resultado da epoca 820 = -50690.28
# 101
# 118
# resultado da epoca 821 = -21345.15
# 102
# 117
# resultado da epoca 822 = -12512.77
# 103
# 116
# resultado da epoca 823 = -46411.62
# 101
# 118
# resultado da epoca 824 = -15238.47
# 103
# 116
# resultado da epoca 825 = -28575.55
# 104
# 115
# resultado da epoca 826 = -25183.99
# 103
# 116
# resultado da epoca 827 = -35418.86
# 106
# 113
# resultado da epoca 828 = -16019.89
# 104
# 115
# resultado da epoca 829 = -24443.41
# 104
# 115
# resultado da epoca 830 = -16648.01
# 104
# 115
# resultado da epoca 831 = -41765.49
# 99
# 120
# resultado da epoca 832 = -31785.14
# 103
# 116
# resultado da epoca 833 = -40883.91
# 103
# 116
# resultado da epoca 834 = -5352.04
# 104
# 115
# resultado da epoca 835 = -23637.77
# 104
# 115
# resultado da epoca 836 = -50958.55
# 101
# 118
# resultado da epoca 837 = -40115.96
# 102
# 117
# resultado da epoca 838 = -22781.30
# 102
# 117
# resultado da epoca 839 = -3925.69
# 103
# 116
# resultado da epoca 840 = -16231.32
# 104
# 115
# resultado da epoca 841 = -12910.80
# 102
# 117
# resultado da epoca 842 = -32916.28
# 102
# 117
# resultado da epoca 843 = -711.54
# 103
# 116
# resultado da epoca 844 = -19767.78
# 103
# 116
# resultado da epoca 845 = -11251.80
# 102
# 117
# resultado da epoca 846 = -16861.28
# 104
# 115
# resultado da epoca 847 = -20656.95
# 105
# 114
# resultado da epoca 848 = -42996.18
# 100
# 119
# resultado da epoca 849 = -27858.50
# 102
# 117
# resultado da epoca 850 = -48714.97
# 103
# 116
# resultado da epoca 851 = -27831.77
# 103
# 116
# resultado da epoca 852 = -40337.59
# 102
# 117
# resultado da epoca 853 = -3610.24
# 103
# 116
# resultado da epoca 854 = -31329.49
# 102
# 117
# resultado da epoca 855 = -21092.18
# 102
# 117
# resultado da epoca 856 = -38655.45
# 102
# 117
# resultado da epoca 857 = -30082.45
# 103
# 116
# resultado da epoca 858 = -38025.61
# 102
# 117
# resultado da epoca 859 = -23452.79
# 104
# 115
# resultado da epoca 860 = -52741.93
# 102
# 117
# resultado da epoca 861 = -25643.48
# 101
# 118
# resultado da epoca 862 = -38967.53
# 101
# 118
# resultado da epoca 863 = -38461.98
# 101
# 118
# resultado da epoca 864 = -26661.22
# 104
# 115
# resultado da epoca 865 = -8537.69
# 103
# 116
# resultado da epoca 866 = -29863.23
# 103
# 116
# resultado da epoca 867 = -3852.34
# 104
# 115
# resultado da epoca 868 = -30269.18
# 104
# 115
# resultado da epoca 869 = -33756.53
# 103
# 116
# resultado da epoca 870 = -45377.10
# 100
# 119
# resultado da epoca 871 = -38293.07
# 102
# 117
# resultado da epoca 872 = -23317.41
# 102
# 117
# resultado da epoca 873 = -52554.80
# 104
# 115
# resultado da epoca 874 = -12948.86
# 100
# 119
# resultado da epoca 875 = -50269.91
# 101
# 118
# resultado da epoca 876 = -21798.30
# 104
# 115
# resultado da epoca 877 = -28834.98
# 102
# 117
# resultado da epoca 878 = -15132.42
# 101
# 118
# resultado da epoca 879 = -34129.78
# 100
# 119
# resultado da epoca 880 = -35456.91
# 103
# 116
# resultado da epoca 881 = -6014.02
# 100
# 119
# resultado da epoca 882 = -60415.35
# 102
# 117
# resultado da epoca 883 = -28388.57
# 101
# 118
# resultado da epoca 884 = -18058.22
# 102
# 117
# resultado da epoca 885 = -17360.35
# 101
# 118
# resultado da epoca 886 = -58223.56
# 101
# 118
# resultado da epoca 887 = -6190.02
# 101
# 118
# resultado da epoca 888 = -23509.77
# 101
# 118
# resultado da epoca 889 = -32412.39
# 102
# 117
# resultado da epoca 890 = -12802.17
# 101
# 118
# resultado da epoca 891 = -28694.34
# 100
# 119
# resultado da epoca 892 = -19685.81
# 101
# 118
# resultado da epoca 893 = -27580.13
# 102
# 117
# resultado da epoca 894 = -28118.21
# 102
# 117
# resultado da epoca 895 = -33074.84
# 102
# 117
# resultado da epoca 896 = -35645.08
# 103
# 116
# resultado da epoca 897 = -43483.63
# 103
# 116
# resultado da epoca 898 = -28341.80
# 101
# 118
# resultado da epoca 899 = -10927.25
# 100
# 119
# resultado da epoca 900 = -32225.62
# 101
# 118
# resultado da epoca 901 = -24588.00
# 101
# 118
# resultado da epoca 902 = -41566.89
# 101
# 118
# resultado da epoca 903 = -39852.14
# 102
# 117
# resultado da epoca 904 = -2771.79
# 103
# 116
# resultado da epoca 905 = -40146.06
# 102
# 117
# resultado da epoca 906 = -34969.55
# 102
# 117
# resultado da epoca 907 = -15492.61
# 101
# 118
# resultado da epoca 908 = -3665.02
# 103
# 116
# resultado da epoca 909 = -42565.75
# 101
# 118
# resultado da epoca 910 = -22055.80
# 101
# 118
# resultado da epoca 911 = -5444.45
# 103
# 116
# resultado da epoca 912 = -17824.46
# 101
# 118
# resultado da epoca 913 = 2494.43
# 103
# 116
# resultado da epoca 914 = -7472.12
# 101
# 118
# resultado da epoca 915 = -40802.19
# 100
# 119
# resultado da epoca 916 = 11326.78
# 102
# 117
# resultado da epoca 917 = -15737.47
# 101
# 118
# resultado da epoca 918 = -8388.26
# 102
# 117
# resultado da epoca 919 = -25633.63
# 102
# 117
# resultado da epoca 920 = -10090.71
# 101
# 118
# resultado da epoca 921 = -13850.45
# 101
# 118
# resultado da epoca 922 = -34612.92
# 101
# 118
# resultado da epoca 923 = -42668.00
# 101
# 118
# resultado da epoca 924 = -33491.74
# 99
# 120
# resultado da epoca 925 = -10463.86
# 103
# 116
# resultado da epoca 926 = -10067.72
# 99
# 120
# resultado da epoca 927 = -33615.19
# 102
# 117
# resultado da epoca 928 = -28405.95
# 100
# 119
# resultado da epoca 929 = -18476.09
# 100
# 119
# resultado da epoca 930 = -16538.68
# 102
# 117
# resultado da epoca 931 = -31445.65
# 101
# 118
# resultado da epoca 932 = -13609.88
# 102
# 117
# resultado da epoca 933 = -26055.62
# 102
# 117
# resultado da epoca 934 = -23462.02
# 99
# 120
# resultado da epoca 935 = -25464.97
# 100
# 119
# resultado da epoca 936 = -37543.39
# 100
# 119
# resultado da epoca 937 = -6376.05
# 101
# 118
# resultado da epoca 938 = -62768.45
# 99
# 120
# resultado da epoca 939 = -28398.12
# 101
# 118
# resultado da epoca 940 = -31535.54
# 100
# 119
# resultado da epoca 941 = -1128.78
# 100
# 119
# resultado da epoca 942 = -18625.61
# 102
# 117
# resultado da epoca 943 = -18911.95
# 102
# 117
# resultado da epoca 944 = -34682.20
# 101
# 118
# resultado da epoca 945 = -25407.31
# 102
# 117
# resultado da epoca 946 = -24195.51
# 101
# 118
# resultado da epoca 947 = -839.35
# 102
# 117
# resultado da epoca 948 = -11851.28
# 100
# 119
# resultado da epoca 949 = -36191.44
# 101
# 118
# resultado da epoca 950 = -12050.06
# 100
# 119
# resultado da epoca 951 = -2713.64
# 102
# 117
# resultado da epoca 952 = -19863.33
# 102
# 117
# resultado da epoca 953 = -34203.20
# 102
# 117
# resultado da epoca 954 = -19757.34
# 101
# 118
# resultado da epoca 955 = -18674.03
# 103
# 116
# resultado da epoca 956 = -32642.37
# 100
# 119
# resultado da epoca 957 = -33629.93
# 99
# 120
# resultado da epoca 958 = -5553.07
# 102
# 117
# resultado da epoca 959 = -23253.67
# 101
# 118
# resultado da epoca 960 = -12252.16
# 101
# 118
# resultado da epoca 961 = -19982.79
# 102
# 117
# resultado da epoca 962 = -30349.48
# 101
# 118
# resultado da epoca 963 = -21254.24
# 101
# 118
# resultado da epoca 964 = -18177.43
# 102
# 117
# resultado da epoca 965 = -23044.06
# 100
# 119
# resultado da epoca 966 = -30871.07
# 99
# 120
# resultado da epoca 967 = -34234.90
# 101
# 118
# resultado da epoca 968 = -24744.13
# 101
# 118
# resultado da epoca 969 = -25525.42
# 101
# 118
# resultado da epoca 970 = -29505.25
# 100
# 119
# resultado da epoca 971 = -14645.77
# 101
# 118
# resultado da epoca 972 = -35675.29
# 99
# 120
# resultado da epoca 973 = -28553.43
# 100
# 119
# resultado da epoca 974 = -19201.78
# 101
# 118
# resultado da epoca 975 = -17226.38
# 100
# 119
# resultado da epoca 976 = -32930.42
# 101
# 118
# resultado da epoca 977 = -43200.24
# 100
# 119
# resultado da epoca 978 = -21701.93
# 100
# 119
# resultado da epoca 979 = -6970.45
# 100
# 119
# resultado da epoca 980 = -14248.09
# 101
# 118
# resultado da epoca 981 = -21514.46
# 100
# 119
# resultado da epoca 982 = -37307.30
# 101
# 118
# resultado da epoca 983 = -30932.38
# 102
# 117
# resultado da epoca 984 = -18323.41
# 101
# 118
# resultado da epoca 985 = -28923.78
# 101
# 118
# resultado da epoca 986 = -37831.59
# 101
# 118
# resultado da epoca 987 = -17894.00
# 101
# 118
# resultado da epoca 988 = -13553.90
# 102
# 117
# resultado da epoca 989 = -23684.48
# 101
# 118
# resultado da epoca 990 = -15776.77
# 101
# 118
# resultado da epoca 991 = -17250.22
# 102
# 117
# resultado da epoca 992 = -17151.64
# 101
# 118
# resultado da epoca 993 = -29088.98
# 100
# 119
# resultado da epoca 994 = -31309.33
# 101
# 118
# resultado da epoca 995 = -31965.52
# 101
# 118
# resultado da epoca 996 = -20591.97
# 103
# 116
# resultado da epoca 997 = -17065.71
# 101
# 118
# resultado da epoca 998 = -18732.52
# 101
# 118
# resultado da epoca 999 = -8394.13
# 102
# 117
# 0
# 0
# Somatoria dos rewards: -10303672.79
# Melhor resultado diario: 86948.32
