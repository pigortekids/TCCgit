# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 4*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        #model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(modelo.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado) #pega valor que chegou
            target_f[0][acao+2*lim_cont] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7680
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 226,837
# Trainable params: 226,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    reward = 0.
    posicao = 0.
    dp = 0.

    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    
    acao = decisao - 2*lim_cont
    
    if abs(ncont+acao) <= lim_cont:
        return acao, 0 
    else:
        return 0, -20

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    penal = 0
    decisao = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l])
        modelo.state = np.reshape(np.concatenate((modelo.janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        
        acao, penal = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        reward += penal    #penalidade se quiser ficar posicionado mais que o permitido
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l])
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]) 
            
        modelo.next_state = np.reshape(np.concatenate((modelo.prox_janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        modelo.remember(acao, reward, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+50): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1105 05:30:36.677229  4220 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -26270.50 Epsilon = 1.000
# 104
# 115
# resultado da epoca 1 = -4606.74 Epsilon = 0.999
# 116
# 103
# resultado da epoca 2 = -5202.80 Epsilon = 0.998
# 103
# 116
# resultado da epoca 3 = -25889.10 Epsilon = 0.997
# 91
# 128
# resultado da epoca 4 = -23442.38 Epsilon = 0.996
# 101
# 118
# resultado da epoca 5 = -4778.88 Epsilon = 0.995
# 106
# 113
# resultado da epoca 6 = -48602.01 Epsilon = 0.994
# 90
# 129
# resultado da epoca 7 = -38045.76 Epsilon = 0.993
# 89
# 130
# resultado da epoca 8 = -32128.24 Epsilon = 0.992
# 101
# 118
# resultado da epoca 9 = -17048.02 Epsilon = 0.991
# 104
# 115
# resultado da epoca 10 = -8652.73 Epsilon = 0.990
# 102
# 117
# resultado da epoca 11 = -47842.21 Epsilon = 0.989
# 85
# 134
# resultado da epoca 12 = -26830.04 Epsilon = 0.988
# 101
# 118
# resultado da epoca 13 = -9824.71 Epsilon = 0.987
# 100
# 119
# resultado da epoca 14 = -34622.96 Epsilon = 0.986
# 92
# 127
# resultado da epoca 15 = -36585.19 Epsilon = 0.985
# 93
# 126
# resultado da epoca 16 = -18436.92 Epsilon = 0.984
# 105
# 114
# resultado da epoca 17 = -25119.31 Epsilon = 0.983
# 98
# 121
# resultado da epoca 18 = -45232.67 Epsilon = 0.982
# 88
# 131
# resultado da epoca 19 = -24741.04 Epsilon = 0.981
# 101
# 118
# resultado da epoca 20 = -35588.33 Epsilon = 0.980
# 95
# 124
# resultado da epoca 21 = -45068.24 Epsilon = 0.979
# 90
# 129
# resultado da epoca 22 = -1924.71 Epsilon = 0.978
# 108
# 111
# resultado da epoca 23 = -17734.80 Epsilon = 0.977
# 108
# 111
# resultado da epoca 24 = -20385.80 Epsilon = 0.976
# 104
# 115
# resultado da epoca 25 = -50122.56 Epsilon = 0.975
# 90
# 129
# resultado da epoca 26 = -25435.65 Epsilon = 0.974
# 105
# 114
# resultado da epoca 27 = -19868.18 Epsilon = 0.973
# 101
# 118
# resultado da epoca 28 = -20561.33 Epsilon = 0.972
# 100
# 119
# resultado da epoca 29 = -33404.37 Epsilon = 0.971
# 95
# 124
# resultado da epoca 30 = -36726.57 Epsilon = 0.970
# 88
# 131
# resultado da epoca 31 = -22709.23 Epsilon = 0.969
# 106
# 113
# resultado da epoca 32 = -29686.68 Epsilon = 0.968
# 100
# 119
# resultado da epoca 33 = 9049.60 Epsilon = 0.967
# 112
# 107
# resultado da epoca 34 = -21646.83 Epsilon = 0.966
# 92
# 127
# resultado da epoca 35 = -20025.08 Epsilon = 0.965
# 98
# 121
# resultado da epoca 36 = -16217.01 Epsilon = 0.964
# 103
# 116
# resultado da epoca 37 = -22553.09 Epsilon = 0.963
# 98
# 121
# resultado da epoca 38 = -28416.03 Epsilon = 0.962
# 99
# 120
# resultado da epoca 39 = -41274.77 Epsilon = 0.961
# 92
# 127
# resultado da epoca 40 = -37103.19 Epsilon = 0.960
# 84
# 135
# resultado da epoca 41 = -14905.60 Epsilon = 0.959
# 101
# 118
# resultado da epoca 42 = -50411.09 Epsilon = 0.958
# 88
# 131
# resultado da epoca 43 = 2137.86 Epsilon = 0.957
# 110
# 109
# resultado da epoca 44 = -28344.68 Epsilon = 0.956
# 96
# 123
# resultado da epoca 45 = -21199.19 Epsilon = 0.955
# 98
# 121
# resultado da epoca 46 = -27774.96 Epsilon = 0.954
# 95
# 124
# resultado da epoca 47 = -35165.07 Epsilon = 0.953
# 93
# 126
# resultado da epoca 48 = -43840.85 Epsilon = 0.952
# 94
# 125
# resultado da epoca 49 = -1191.17 Epsilon = 0.951
# 104
# 115
# resultado da epoca 50 = -13989.75 Epsilon = 0.950
# 99
# 120
# resultado da epoca 51 = -29376.71 Epsilon = 0.950
# 98
# 121
# resultado da epoca 52 = -3742.94 Epsilon = 0.949
# 113
# 106
# resultado da epoca 53 = -5008.42 Epsilon = 0.948
# 99
# 120
# resultado da epoca 54 = -2790.04 Epsilon = 0.947
# 114
# 105
# resultado da epoca 55 = -17928.75 Epsilon = 0.946
# 102
# 117
# resultado da epoca 56 = -15802.25 Epsilon = 0.945
# 93
# 126
# resultado da epoca 57 = -2041.15 Epsilon = 0.944
# 115
# 104
# resultado da epoca 58 = -18872.75 Epsilon = 0.943
# 98
# 121
# resultado da epoca 59 = 7127.15 Epsilon = 0.942
# 114
# 105
# resultado da epoca 60 = 14816.13 Epsilon = 0.941
# 116
# 103
# resultado da epoca 61 = -663.32 Epsilon = 0.940
# 106
# 113
# resultado da epoca 62 = -37115.92 Epsilon = 0.939
# 95
# 124
# resultado da epoca 63 = -2978.98 Epsilon = 0.938
# 115
# 104
# resultado da epoca 64 = -17006.00 Epsilon = 0.937
# 104
# 115
# resultado da epoca 65 = -20463.44 Epsilon = 0.936
# 101
# 118
# resultado da epoca 66 = -29363.64 Epsilon = 0.935
# 99
# 120
# resultado da epoca 67 = 1369.84 Epsilon = 0.934
# 107
# 112
# resultado da epoca 68 = -31499.74 Epsilon = 0.933
# 93
# 126
# resultado da epoca 69 = -26149.99 Epsilon = 0.932
# 98
# 121
# resultado da epoca 70 = -38006.45 Epsilon = 0.931
# 92
# 127
# resultado da epoca 71 = -49560.38 Epsilon = 0.930
# 90
# 129
# resultado da epoca 72 = -23761.83 Epsilon = 0.929
# 108
# 111
# resultado da epoca 73 = -29074.04 Epsilon = 0.928
# 102
# 117
# resultado da epoca 74 = -46514.24 Epsilon = 0.927
# 87
# 132
# resultado da epoca 75 = -17892.16 Epsilon = 0.926
# 105
# 114
# resultado da epoca 76 = -3636.32 Epsilon = 0.925
# 107
# 112
# resultado da epoca 77 = -23344.74 Epsilon = 0.924
# 102
# 117
# resultado da epoca 78 = -22156.91 Epsilon = 0.923
# 97
# 122
# resultado da epoca 79 = -40250.60 Epsilon = 0.922
# 84
# 135
# resultado da epoca 80 = -32847.44 Epsilon = 0.921
# 105
# 114
# resultado da epoca 81 = -11621.23 Epsilon = 0.920
# 102
# 117
# resultado da epoca 82 = -13926.30 Epsilon = 0.919
# 107
# 112
# resultado da epoca 83 = -11593.93 Epsilon = 0.918
# 105
# 114
# resultado da epoca 84 = -16584.83 Epsilon = 0.917
# 104
# 115
# resultado da epoca 85 = -45576.09 Epsilon = 0.916
# 94
# 125
# resultado da epoca 86 = -63781.19 Epsilon = 0.915
# 85
# 134
# resultado da epoca 87 = -616.11 Epsilon = 0.914
# 104
# 115
# resultado da epoca 88 = -17960.51 Epsilon = 0.913
# 100
# 119
# resultado da epoca 89 = -44851.12 Epsilon = 0.912
# 90
# 129
# resultado da epoca 90 = 15358.45 Epsilon = 0.911
# 116
# 103
# resultado da epoca 91 = -38694.53 Epsilon = 0.910
# 96
# 123
# resultado da epoca 92 = -28480.97 Epsilon = 0.909
# 105
# 114
# resultado da epoca 93 = -33422.64 Epsilon = 0.908
# 101
# 118
# resultado da epoca 94 = -35910.15 Epsilon = 0.907
# 97
# 122
# resultado da epoca 95 = -34014.46 Epsilon = 0.906
# 95
# 124
# resultado da epoca 96 = -43004.28 Epsilon = 0.905
# 103
# 116
# resultado da epoca 97 = -8189.23 Epsilon = 0.904
# 104
# 115
# resultado da epoca 98 = -17761.36 Epsilon = 0.903
# 102
# 117
# resultado da epoca 99 = -29664.36 Epsilon = 0.902
# 96
# 123
# resultado da epoca 100 = -5384.76 Epsilon = 0.901
# 105
# 114
# resultado da epoca 101 = -16649.33 Epsilon = 0.900
# 104
# 115
# resultado da epoca 102 = 2714.86 Epsilon = 0.899
# 113
# 106
# resultado da epoca 103 = -30965.74 Epsilon = 0.898
# 99
# 120
# resultado da epoca 104 = -14602.50 Epsilon = 0.897
# 95
# 124
# resultado da epoca 105 = -20252.98 Epsilon = 0.896
# 100
# 119
# resultado da epoca 106 = -4110.32 Epsilon = 0.895
# 112
# 107
# resultado da epoca 107 = -30639.33 Epsilon = 0.894
# 96
# 123
# resultado da epoca 108 = -28878.71 Epsilon = 0.893
# 104
# 115
# resultado da epoca 109 = -24680.18 Epsilon = 0.892
# 91
# 128
# resultado da epoca 110 = -24577.26 Epsilon = 0.891
# 106
# 113
# resultado da epoca 111 = -11497.02 Epsilon = 0.890
# 109
# 110
# resultado da epoca 112 = -13417.75 Epsilon = 0.889
# 100
# 119
# resultado da epoca 113 = -37252.87 Epsilon = 0.888
# 96
# 123
# resultado da epoca 114 = -37303.53 Epsilon = 0.887
# 91
# 128
# resultado da epoca 115 = -40005.02 Epsilon = 0.886
# 94
# 125
# resultado da epoca 116 = -18486.27 Epsilon = 0.885
# 104
# 115
# resultado da epoca 117 = -22532.35 Epsilon = 0.884
# 95
# 124
# resultado da epoca 118 = -32300.80 Epsilon = 0.883
# 95
# 124
# resultado da epoca 119 = -46482.00 Epsilon = 0.882
# 88
# 131
# resultado da epoca 120 = -38194.41 Epsilon = 0.881
# 101
# 118
# resultado da epoca 121 = -21596.26 Epsilon = 0.880
# 94
# 125
# resultado da epoca 122 = -32695.26 Epsilon = 0.879
# 101
# 118
# resultado da epoca 123 = -19421.03 Epsilon = 0.878
# 96
# 123
# resultado da epoca 124 = -23993.13 Epsilon = 0.877
# 96
# 123
# resultado da epoca 125 = -17435.97 Epsilon = 0.876
# 103
# 116
# resultado da epoca 126 = -28832.74 Epsilon = 0.875
# 105
# 114
# resultado da epoca 127 = -15919.62 Epsilon = 0.874
# 102
# 117
# resultado da epoca 128 = -50594.97 Epsilon = 0.873
# 80
# 139
# resultado da epoca 129 = -11998.28 Epsilon = 0.872
# 111
# 108
# resultado da epoca 130 = -3477.17 Epsilon = 0.871
# 105
# 114
# resultado da epoca 131 = -38828.71 Epsilon = 0.870
# 86
# 133
# resultado da epoca 132 = -2135.17 Epsilon = 0.869
# 101
# 118
# resultado da epoca 133 = -48294.50 Epsilon = 0.868
# 85
# 134
# resultado da epoca 134 = -6822.33 Epsilon = 0.867
# 100
# 119
# resultado da epoca 135 = -57439.95 Epsilon = 0.866
# 84
# 135
# resultado da epoca 136 = -46541.69 Epsilon = 0.865
# 93
# 126
# resultado da epoca 137 = -15015.60 Epsilon = 0.864
# 102
# 117
# resultado da epoca 138 = -31616.93 Epsilon = 0.863
# 95
# 124
# resultado da epoca 139 = -8566.98 Epsilon = 0.862
# 100
# 119
# resultado da epoca 140 = -30304.04 Epsilon = 0.861
# 97
# 122
# resultado da epoca 141 = -43942.20 Epsilon = 0.860
# 93
# 126
# resultado da epoca 142 = -49273.88 Epsilon = 0.859
# 92
# 127
# resultado da epoca 143 = -24656.33 Epsilon = 0.858
# 106
# 113
# resultado da epoca 144 = -37971.19 Epsilon = 0.857
# 89
# 130
# resultado da epoca 145 = -15203.26 Epsilon = 0.856
# 102
# 117
# resultado da epoca 146 = -15846.94 Epsilon = 0.855
# 106
# 113
# resultado da epoca 147 = -31491.93 Epsilon = 0.854
# 96
# 123
# resultado da epoca 148 = -9600.61 Epsilon = 0.853
# 107
# 112
# resultado da epoca 149 = -26541.69 Epsilon = 0.852
# 96
# 123
# resultado da epoca 150 = -58897.93 Epsilon = 0.851
# 91
# 128
# resultado da epoca 151 = -30105.75 Epsilon = 0.851
# 101
# 118
# resultado da epoca 152 = -26706.73 Epsilon = 0.850
# 105
# 114
# resultado da epoca 153 = -9406.25 Epsilon = 0.849
# 97
# 122
# resultado da epoca 154 = -26267.61 Epsilon = 0.848
# 104
# 115
# resultado da epoca 155 = -21998.87 Epsilon = 0.847
# 103
# 116
# resultado da epoca 156 = -27267.37 Epsilon = 0.846
# 95
# 124
# resultado da epoca 157 = -61926.56 Epsilon = 0.845
# 84
# 135
# resultado da epoca 158 = -24490.98 Epsilon = 0.844
# 97
# 122
# resultado da epoca 159 = -56458.72 Epsilon = 0.843
# 92
# 127
# resultado da epoca 160 = -24156.34 Epsilon = 0.842
# 99
# 120
# resultado da epoca 161 = -52910.38 Epsilon = 0.841
# 87
# 132
# resultado da epoca 162 = -5577.99 Epsilon = 0.840
# 113
# 106
# resultado da epoca 163 = -40747.12 Epsilon = 0.839
# 89
# 130
# resultado da epoca 164 = -73941.66 Epsilon = 0.838
# 82
# 137
# resultado da epoca 165 = -9397.92 Epsilon = 0.837
# 107
# 112
# resultado da epoca 166 = -33872.77 Epsilon = 0.836
# 98
# 121
# resultado da epoca 167 = -14944.02 Epsilon = 0.835
# 99
# 120
# resultado da epoca 168 = -40320.41 Epsilon = 0.834
# 89
# 130
# resultado da epoca 169 = -40637.63 Epsilon = 0.833
# 101
# 118
# resultado da epoca 170 = -29479.61 Epsilon = 0.832
# 94
# 125
# resultado da epoca 171 = -41443.36 Epsilon = 0.831
# 99
# 120
# resultado da epoca 172 = -64842.57 Epsilon = 0.830
# 93
# 126
# resultado da epoca 173 = -45831.05 Epsilon = 0.829
# 96
# 123
# resultado da epoca 174 = -37396.58 Epsilon = 0.828
# 94
# 125
# resultado da epoca 175 = -28921.74 Epsilon = 0.827
# 96
# 123
# resultado da epoca 176 = -41230.58 Epsilon = 0.826
# 95
# 124
# resultado da epoca 177 = -25511.73 Epsilon = 0.825
# 96
# 123
# resultado da epoca 178 = -12391.79 Epsilon = 0.824
# 100
# 119
# resultado da epoca 179 = -35925.62 Epsilon = 0.823
# 90
# 129
# resultado da epoca 180 = -57212.08 Epsilon = 0.822
# 84
# 135
# resultado da epoca 181 = -38926.63 Epsilon = 0.821
# 96
# 123
# resultado da epoca 182 = -33811.51 Epsilon = 0.820
# 94
# 125
# resultado da epoca 183 = -20453.79 Epsilon = 0.819
# 101
# 118
# resultado da epoca 184 = -14419.70 Epsilon = 0.818
# 105
# 114
# resultado da epoca 185 = -39832.98 Epsilon = 0.817
# 96
# 123
# resultado da epoca 186 = -31282.90 Epsilon = 0.816
# 97
# 122
# resultado da epoca 187 = -55616.14 Epsilon = 0.815
# 85
# 134
# resultado da epoca 188 = -35538.68 Epsilon = 0.814
# 98
# 121
# resultado da epoca 189 = -11904.50 Epsilon = 0.813
# 109
# 110
# resultado da epoca 190 = -44929.39 Epsilon = 0.812
# 92
# 127
# resultado da epoca 191 = -29130.30 Epsilon = 0.811
# 92
# 127
# resultado da epoca 192 = -21090.15 Epsilon = 0.810
# 95
# 124
# resultado da epoca 193 = -48334.91 Epsilon = 0.809
# 82
# 137
# resultado da epoca 194 = -40311.05 Epsilon = 0.808
# 100
# 119
# resultado da epoca 195 = -46406.43 Epsilon = 0.807
# 92
# 127
# resultado da epoca 196 = -53222.97 Epsilon = 0.806
# 96
# 123
# resultado da epoca 197 = -10139.07 Epsilon = 0.805
# 104
# 115
# resultado da epoca 198 = -25634.82 Epsilon = 0.804
# 99
# 120
# resultado da epoca 199 = -12189.35 Epsilon = 0.803
# 104
# 115
# resultado da epoca 200 = -30084.80 Epsilon = 0.802
# 91
# 128
# resultado da epoca 201 = -45400.85 Epsilon = 0.801
# 90
# 129
# resultado da epoca 202 = -30819.69 Epsilon = 0.800
# 95
# 124
# resultado da epoca 203 = -18541.26 Epsilon = 0.799
# 102
# 117
# resultado da epoca 204 = -63799.22 Epsilon = 0.798
# 90
# 129
# resultado da epoca 205 = -35551.95 Epsilon = 0.797
# 99
# 120
# resultado da epoca 206 = -39118.09 Epsilon = 0.796
# 88
# 131
# resultado da epoca 207 = -33929.99 Epsilon = 0.795
# 98
# 121
# resultado da epoca 208 = -24866.19 Epsilon = 0.794
# 87
# 132
# resultado da epoca 209 = -30809.88 Epsilon = 0.793
# 94
# 125
# resultado da epoca 210 = -35128.23 Epsilon = 0.792
# 89
# 130
# resultado da epoca 211 = -31618.25 Epsilon = 0.791
# 91
# 128
# resultado da epoca 212 = -12311.07 Epsilon = 0.790
# 103
# 116
# resultado da epoca 213 = -43326.24 Epsilon = 0.789
# 84
# 135
# resultado da epoca 214 = -25051.80 Epsilon = 0.788
# 103
# 116
# resultado da epoca 215 = -32237.62 Epsilon = 0.787
# 90
# 129
# resultado da epoca 216 = -9121.08 Epsilon = 0.786
# 110
# 109
# resultado da epoca 217 = -40430.95 Epsilon = 0.785
# 97
# 122
# resultado da epoca 218 = -41463.62 Epsilon = 0.784
# 94
# 125
# resultado da epoca 219 = -21422.63 Epsilon = 0.783
# 100
# 119
# resultado da epoca 220 = -32631.43 Epsilon = 0.782
# 94
# 125
# resultado da epoca 221 = -44250.05 Epsilon = 0.781
# 86
# 133
# resultado da epoca 222 = -48179.88 Epsilon = 0.780
# 96
# 123
# resultado da epoca 223 = -43080.42 Epsilon = 0.779
# 95
# 124
# resultado da epoca 224 = -31134.85 Epsilon = 0.778
# 91
# 128
# resultado da epoca 225 = -23416.22 Epsilon = 0.777
# 109
# 110
# resultado da epoca 226 = -36574.98 Epsilon = 0.776
# 100
# 119
# resultado da epoca 227 = -38476.22 Epsilon = 0.775
# 93
# 126
# resultado da epoca 228 = -21829.96 Epsilon = 0.774
# 101
# 118
# resultado da epoca 229 = -23877.65 Epsilon = 0.773
# 108
# 111
# resultado da epoca 230 = -42961.47 Epsilon = 0.772
# 93
# 126
# resultado da epoca 231 = -30574.43 Epsilon = 0.771
# 106
# 113
# resultado da epoca 232 = -7158.16 Epsilon = 0.770
# 109
# 110
# resultado da epoca 233 = -15509.12 Epsilon = 0.769
# 99
# 120
# resultado da epoca 234 = -50864.50 Epsilon = 0.768
# 91
# 128
# resultado da epoca 235 = -44099.35 Epsilon = 0.767
# 90
# 129
# resultado da epoca 236 = -26993.49 Epsilon = 0.766
# 101
# 118
# resultado da epoca 237 = -20014.68 Epsilon = 0.765
# 103
# 116
# resultado da epoca 238 = -35028.79 Epsilon = 0.764
# 86
# 133
# resultado da epoca 239 = -33052.00 Epsilon = 0.763
# 95
# 124
# resultado da epoca 240 = -16225.68 Epsilon = 0.762
# 96
# 123
# resultado da epoca 241 = -4810.03 Epsilon = 0.761
# 102
# 117
# resultado da epoca 242 = -42460.44 Epsilon = 0.760
# 96
# 123
# resultado da epoca 243 = -23198.93 Epsilon = 0.759
# 97
# 122
# resultado da epoca 244 = -6797.06 Epsilon = 0.758
# 99
# 120
# resultado da epoca 245 = -31657.05 Epsilon = 0.757
# 100
# 119
# resultado da epoca 246 = -46426.17 Epsilon = 0.756
# 97
# 122
# resultado da epoca 247 = -22173.72 Epsilon = 0.755
# 101
# 118
# resultado da epoca 248 = -53197.09 Epsilon = 0.754
# 84
# 135
# resultado da epoca 249 = -15865.58 Epsilon = 0.753
# 107
# 112
# resultado da epoca 250 = -8835.20 Epsilon = 0.752
# 102
# 117
# resultado da epoca 251 = -2987.44 Epsilon = 0.752
# 102
# 117
# resultado da epoca 252 = -18285.43 Epsilon = 0.751
# 95
# 124
# resultado da epoca 253 = -30756.14 Epsilon = 0.750
# 99
# 120
# resultado da epoca 254 = -21994.74 Epsilon = 0.749
# 100
# 119
# resultado da epoca 255 = -14968.34 Epsilon = 0.748
# 101
# 118
# resultado da epoca 256 = -39485.66 Epsilon = 0.747
# 92
# 127
# resultado da epoca 257 = -46681.08 Epsilon = 0.746
# 96
# 123
# resultado da epoca 258 = -26824.36 Epsilon = 0.745
# 100
# 119
# resultado da epoca 259 = -30876.86 Epsilon = 0.744
# 95
# 124
# resultado da epoca 260 = -39650.64 Epsilon = 0.743
# 96
# 123
# resultado da epoca 261 = -32843.70 Epsilon = 0.742
# 100
# 119
# resultado da epoca 262 = -21310.08 Epsilon = 0.741
# 102
# 117
# resultado da epoca 263 = -35773.66 Epsilon = 0.740
# 101
# 118
# resultado da epoca 264 = -32840.40 Epsilon = 0.739
# 93
# 126
# resultado da epoca 265 = -28986.95 Epsilon = 0.738
# 99
# 120
# resultado da epoca 266 = -29308.53 Epsilon = 0.737
# 96
# 123
# resultado da epoca 267 = -4333.39 Epsilon = 0.736
# 112
# 107
# resultado da epoca 268 = -22742.18 Epsilon = 0.735
# 109
# 110
# resultado da epoca 269 = -16811.27 Epsilon = 0.734
# 102
# 117
# resultado da epoca 270 = -9937.90 Epsilon = 0.733
# 100
# 119
# resultado da epoca 271 = -23486.54 Epsilon = 0.732
# 105
# 114
# resultado da epoca 272 = -39196.58 Epsilon = 0.731
# 98
# 121
# resultado da epoca 273 = -43335.01 Epsilon = 0.730
# 88
# 131
# resultado da epoca 274 = -39139.94 Epsilon = 0.729
# 90
# 129
# resultado da epoca 275 = -16873.08 Epsilon = 0.728
# 113
# 106
# resultado da epoca 276 = -24097.82 Epsilon = 0.727
# 94
# 125
# resultado da epoca 277 = -37489.13 Epsilon = 0.726
# 86
# 133
# resultado da epoca 278 = -52372.99 Epsilon = 0.725
# 77
# 142
# resultado da epoca 279 = -33313.06 Epsilon = 0.724
# 93
# 126
# resultado da epoca 280 = -20955.56 Epsilon = 0.723
# 100
# 119
# resultado da epoca 281 = -26552.92 Epsilon = 0.722
# 99
# 120
# resultado da epoca 282 = -8637.74 Epsilon = 0.721
# 97
# 122
# resultado da epoca 283 = -27825.23 Epsilon = 0.720
# 102
# 117
# resultado da epoca 284 = -27756.43 Epsilon = 0.719
# 100
# 119
# resultado da epoca 285 = -42527.74 Epsilon = 0.718
# 97
# 122
# resultado da epoca 286 = -6654.06 Epsilon = 0.717
# 103
# 116
# resultado da epoca 287 = -16300.23 Epsilon = 0.716
# 107
# 112
# resultado da epoca 288 = -7227.58 Epsilon = 0.715
# 107
# 112
# resultado da epoca 289 = -14131.29 Epsilon = 0.714
# 102
# 117
# resultado da epoca 290 = -8632.50 Epsilon = 0.713
# 104
# 115
# resultado da epoca 291 = -23622.95 Epsilon = 0.712
# 102
# 117
# resultado da epoca 292 = -13034.96 Epsilon = 0.711
# 104
# 115
# resultado da epoca 293 = -33905.53 Epsilon = 0.710
# 95
# 124
# resultado da epoca 294 = -27550.18 Epsilon = 0.709
# 95
# 124
# resultado da epoca 295 = -29850.50 Epsilon = 0.708
# 94
# 125
# resultado da epoca 296 = -49787.75 Epsilon = 0.707
# 87
# 132
# resultado da epoca 297 = -13028.23 Epsilon = 0.706
# 105
# 114
# resultado da epoca 298 = -37163.49 Epsilon = 0.705
# 91
# 128
# resultado da epoca 299 = -19841.49 Epsilon = 0.704
# 102
# 117
# resultado da epoca 300 = -53049.51 Epsilon = 0.703
# 84
# 135
# resultado da epoca 301 = -32740.48 Epsilon = 0.702
# 95
# 124
# resultado da epoca 302 = -26329.88 Epsilon = 0.701
# 98
# 121
# resultado da epoca 303 = -20084.69 Epsilon = 0.700
# 107
# 112
# resultado da epoca 304 = -35351.10 Epsilon = 0.699
# 90
# 129
# resultado da epoca 305 = -17477.86 Epsilon = 0.698
# 102
# 117
# resultado da epoca 306 = -37524.63 Epsilon = 0.697
# 100
# 119
# resultado da epoca 307 = -27120.74 Epsilon = 0.696
# 98
# 121
# resultado da epoca 308 = -26674.51 Epsilon = 0.695
# 90
# 129
# resultado da epoca 309 = -42042.06 Epsilon = 0.694
# 97
# 122
# resultado da epoca 310 = -13776.28 Epsilon = 0.693
# 107
# 112
# resultado da epoca 311 = -22591.62 Epsilon = 0.692
# 98
# 121
# resultado da epoca 312 = -10588.11 Epsilon = 0.691
# 104
# 115
# resultado da epoca 313 = -24098.18 Epsilon = 0.690
# 101
# 118
# resultado da epoca 314 = 811.97 Epsilon = 0.689
# 101
# 118
# resultado da epoca 315 = 8927.19 Epsilon = 0.688
# 106
# 113
# resultado da epoca 316 = -2128.41 Epsilon = 0.687
# 97
# 122
# resultado da epoca 317 = -28520.02 Epsilon = 0.686
# 99
# 120
# resultado da epoca 318 = -39299.23 Epsilon = 0.685
# 91
# 128
# resultado da epoca 319 = -17814.97 Epsilon = 0.684
# 102
# 117
# resultado da epoca 320 = -18614.27 Epsilon = 0.683
# 103
# 116
# resultado da epoca 321 = -27756.42 Epsilon = 0.682
# 97
# 122
# resultado da epoca 322 = -18725.58 Epsilon = 0.681
# 89
# 130
# resultado da epoca 323 = -1408.18 Epsilon = 0.680
# 107
# 112
# resultado da epoca 324 = -46562.46 Epsilon = 0.679
# 94
# 125
# resultado da epoca 325 = -37551.32 Epsilon = 0.678
# 96
# 123
# resultado da epoca 326 = -5988.09 Epsilon = 0.677
# 93
# 126
# resultado da epoca 327 = -14605.89 Epsilon = 0.676
# 108
# 111
# resultado da epoca 328 = -17031.62 Epsilon = 0.675
# 104
# 115
# resultado da epoca 329 = -29201.34 Epsilon = 0.674
# 100
# 119
# resultado da epoca 330 = -45585.83 Epsilon = 0.673
# 94
# 125
# resultado da epoca 331 = -39950.40 Epsilon = 0.672
# 86
# 133
# resultado da epoca 332 = -33264.26 Epsilon = 0.671
# 94
# 125
# resultado da epoca 333 = 4455.57 Epsilon = 0.670
# 106
# 113
# resultado da epoca 334 = -41874.02 Epsilon = 0.669
# 90
# 129
# resultado da epoca 335 = 8041.47 Epsilon = 0.668
# 103
# 116
# resultado da epoca 336 = -10148.00 Epsilon = 0.667
# 105
# 114
# resultado da epoca 337 = 16798.33 Epsilon = 0.666
# 116
# 103
# resultado da epoca 338 = -32537.25 Epsilon = 0.665
# 101
# 118
# resultado da epoca 339 = -32796.35 Epsilon = 0.664
# 100
# 119
# resultado da epoca 340 = -14608.70 Epsilon = 0.663
# 100
# 119
# resultado da epoca 341 = -17066.14 Epsilon = 0.662
# 93
# 126
# resultado da epoca 342 = -21929.92 Epsilon = 0.661
# 94
# 125
# resultado da epoca 343 = 14251.82 Epsilon = 0.660
# 119
# 100
# resultado da epoca 344 = -10812.16 Epsilon = 0.659
# 93
# 126
# resultado da epoca 345 = -25963.22 Epsilon = 0.658
# 109
# 110
# resultado da epoca 346 = -24472.98 Epsilon = 0.657
# 95
# 124
# resultado da epoca 347 = 22208.78 Epsilon = 0.656
# 112
# 107
# resultado da epoca 348 = -11114.41 Epsilon = 0.655
# 99
# 120
# resultado da epoca 349 = -11613.94 Epsilon = 0.654
# 105
# 114
# resultado da epoca 350 = -11881.63 Epsilon = 0.653
# 106
# 113
# resultado da epoca 351 = -18299.73 Epsilon = 0.653
# 102
# 117
# resultado da epoca 352 = -6479.49 Epsilon = 0.652
# 100
# 119
# resultado da epoca 353 = -7182.17 Epsilon = 0.651
# 106
# 113
# resultado da epoca 354 = -21685.39 Epsilon = 0.650
# 104
# 115
# resultado da epoca 355 = -14110.49 Epsilon = 0.649
# 101
# 118
# resultado da epoca 356 = -15290.20 Epsilon = 0.648
# 101
# 118
# resultado da epoca 357 = -8610.23 Epsilon = 0.647
# 102
# 117
# resultado da epoca 358 = -50565.24 Epsilon = 0.646
# 89
# 130
# resultado da epoca 359 = -18221.12 Epsilon = 0.645
# 99
# 120
# resultado da epoca 360 = 6642.00 Epsilon = 0.644
# 111
# 108
# resultado da epoca 361 = -12426.58 Epsilon = 0.643
# 101
# 118
# resultado da epoca 362 = 2989.02 Epsilon = 0.642
# 106
# 113
# resultado da epoca 363 = -32047.40 Epsilon = 0.641
# 95
# 124
# resultado da epoca 364 = -19665.38 Epsilon = 0.640
# 103
# 116
# resultado da epoca 365 = -47583.92 Epsilon = 0.639
# 90
# 129
# resultado da epoca 366 = -39333.74 Epsilon = 0.638
# 83
# 136
# resultado da epoca 367 = -41481.77 Epsilon = 0.637
# 97
# 122
# resultado da epoca 368 = -26833.93 Epsilon = 0.636
# 91
# 128
# resultado da epoca 369 = -21731.04 Epsilon = 0.635
# 98
# 121
# resultado da epoca 370 = -52405.00 Epsilon = 0.634
# 82
# 137
# resultado da epoca 371 = -18214.31 Epsilon = 0.633
# 102
# 117
# resultado da epoca 372 = -27177.15 Epsilon = 0.632
# 104
# 115
# resultado da epoca 373 = -31977.40 Epsilon = 0.631
# 101
# 118
# resultado da epoca 374 = -50059.85 Epsilon = 0.630
# 89
# 130
# resultado da epoca 375 = -18861.52 Epsilon = 0.629
# 107
# 112
# resultado da epoca 376 = -47255.50 Epsilon = 0.628
# 90
# 129
# resultado da epoca 377 = -30249.75 Epsilon = 0.627
# 99
# 120
# resultado da epoca 378 = -23240.00 Epsilon = 0.626
# 105
# 114
# resultado da epoca 379 = -3005.23 Epsilon = 0.625
# 110
# 109
# resultado da epoca 380 = -29509.40 Epsilon = 0.624
# 98
# 121
# resultado da epoca 381 = 2784.69 Epsilon = 0.623
# 112
# 107
# resultado da epoca 382 = -45670.30 Epsilon = 0.622
# 91
# 128
# resultado da epoca 383 = -23068.66 Epsilon = 0.621
# 103
# 116
# resultado da epoca 384 = -22301.99 Epsilon = 0.620
# 99
# 120
# resultado da epoca 385 = -21062.42 Epsilon = 0.619
# 101
# 118
# resultado da epoca 386 = -3709.23 Epsilon = 0.618
# 109
# 110
# resultado da epoca 387 = -32173.24 Epsilon = 0.617
# 97
# 122
# resultado da epoca 388 = -40560.42 Epsilon = 0.616
# 91
# 128
# resultado da epoca 389 = -27427.26 Epsilon = 0.615
# 97
# 122
# resultado da epoca 390 = -1944.95 Epsilon = 0.614
# 107
# 112
# resultado da epoca 391 = -16161.66 Epsilon = 0.613
# 104
# 115
# resultado da epoca 392 = -39556.42 Epsilon = 0.612
# 89
# 130
# resultado da epoca 393 = -31478.94 Epsilon = 0.611
# 96
# 123
# resultado da epoca 394 = -20432.15 Epsilon = 0.610
# 108
# 111
# resultado da epoca 395 = -30122.68 Epsilon = 0.609
# 97
# 122
# resultado da epoca 396 = -35264.73 Epsilon = 0.608
# 87
# 132
# resultado da epoca 397 = -18807.83 Epsilon = 0.607
# 105
# 114
# resultado da epoca 398 = -22555.79 Epsilon = 0.606
# 111
# 108
# resultado da epoca 399 = -3039.80 Epsilon = 0.605
# 108
# 111
# resultado da epoca 400 = -40280.33 Epsilon = 0.604
# 93
# 126
# resultado da epoca 401 = -28238.91 Epsilon = 0.603
# 104
# 115
# resultado da epoca 402 = -13865.84 Epsilon = 0.602
# 106
# 113
# resultado da epoca 403 = -41529.29 Epsilon = 0.601
# 100
# 119
# resultado da epoca 404 = -32476.46 Epsilon = 0.600
# 103
# 116
# resultado da epoca 405 = -38856.31 Epsilon = 0.599
# 96
# 123
# resultado da epoca 406 = -13385.72 Epsilon = 0.598
# 107
# 112
# resultado da epoca 407 = -24898.36 Epsilon = 0.597
# 100
# 119
# resultado da epoca 408 = -6614.57 Epsilon = 0.596
# 107
# 112
# resultado da epoca 409 = 9615.09 Epsilon = 0.595
# 112
# 107
# resultado da epoca 410 = -7626.87 Epsilon = 0.594
# 114
# 105
# resultado da epoca 411 = -12163.69 Epsilon = 0.593
# 103
# 116
# resultado da epoca 412 = -33616.81 Epsilon = 0.592
# 103
# 116
# resultado da epoca 413 = -23609.35 Epsilon = 0.591
# 104
# 115
# resultado da epoca 414 = 3864.86 Epsilon = 0.590
# 110
# 109
# resultado da epoca 415 = -15925.35 Epsilon = 0.589
# 98
# 121
# resultado da epoca 416 = -25290.24 Epsilon = 0.588
# 98
# 121
# resultado da epoca 417 = -30531.91 Epsilon = 0.587
# 93
# 126
# resultado da epoca 418 = -34263.26 Epsilon = 0.586
# 91
# 128
# resultado da epoca 419 = 24773.29 Epsilon = 0.585
# 115
# 104
# resultado da epoca 420 = -27703.55 Epsilon = 0.584
# 104
# 115
# resultado da epoca 421 = -21672.50 Epsilon = 0.583
# 105
# 114
# resultado da epoca 422 = -10908.59 Epsilon = 0.582
# 106
# 113
# resultado da epoca 423 = -54736.60 Epsilon = 0.581
# 89
# 130
# resultado da epoca 424 = -22690.21 Epsilon = 0.580
# 96
# 123
# resultado da epoca 425 = -29864.86 Epsilon = 0.579
# 101
# 118
# resultado da epoca 426 = -38333.03 Epsilon = 0.578
# 89
# 130
# resultado da epoca 427 = -4351.22 Epsilon = 0.577
# 114
# 105
# resultado da epoca 428 = -38495.49 Epsilon = 0.576
# 96
# 123
# resultado da epoca 429 = -40374.00 Epsilon = 0.575
# 94
# 125
# resultado da epoca 430 = -1853.92 Epsilon = 0.574
# 109
# 110
# resultado da epoca 431 = -17058.83 Epsilon = 0.573
# 101
# 118
# resultado da epoca 432 = -31013.18 Epsilon = 0.572
# 95
# 124
# resultado da epoca 433 = -3109.31 Epsilon = 0.571
# 113
# 106
# resultado da epoca 434 = -4803.25 Epsilon = 0.570
# 95
# 124
# resultado da epoca 435 = 8636.19 Epsilon = 0.569
# 106
# 113
# resultado da epoca 436 = -45181.72 Epsilon = 0.568
# 86
# 133
# resultado da epoca 437 = -9047.67 Epsilon = 0.567
# 105
# 114
# resultado da epoca 438 = 307.77 Epsilon = 0.566
# 120
# 99
# resultado da epoca 439 = 2518.53 Epsilon = 0.565
# 110
# 109
# resultado da epoca 440 = -26355.75 Epsilon = 0.564
# 94
# 125
# resultado da epoca 441 = -9709.31 Epsilon = 0.563
# 114
# 105
# resultado da epoca 442 = -48097.36 Epsilon = 0.562
# 93
# 126
# resultado da epoca 443 = -52044.80 Epsilon = 0.561
# 90
# 129
# resultado da epoca 444 = -20149.20 Epsilon = 0.560
# 101
# 118
# resultado da epoca 445 = -35449.20 Epsilon = 0.559
# 103
# 116
# resultado da epoca 446 = -18060.88 Epsilon = 0.558
# 98
# 121
# resultado da epoca 447 = -19633.85 Epsilon = 0.557
# 106
# 113
# resultado da epoca 448 = -7850.86 Epsilon = 0.556
# 106
# 113
# resultado da epoca 449 = -12100.42 Epsilon = 0.555
# 102
# 117
# resultado da epoca 450 = -40917.05 Epsilon = 0.554
# 90
# 129
# resultado da epoca 451 = 4157.10 Epsilon = 0.554
# 106
# 113
# resultado da epoca 452 = -17159.08 Epsilon = 0.553
# 97
# 122
# resultado da epoca 453 = -3357.44 Epsilon = 0.552
# 109
# 110
# resultado da epoca 454 = 2937.22 Epsilon = 0.551
# 110
# 109
# resultado da epoca 455 = -18312.15 Epsilon = 0.550
# 102
# 117
# resultado da epoca 456 = -33078.43 Epsilon = 0.549
# 100
# 119
# resultado da epoca 457 = 7727.10 Epsilon = 0.548
# 105
# 114
# resultado da epoca 458 = -20503.00 Epsilon = 0.547
# 105
# 114
# resultado da epoca 459 = -33453.19 Epsilon = 0.546
# 93
# 126
# resultado da epoca 460 = -44566.12 Epsilon = 0.545
# 95
# 124
# resultado da epoca 461 = 7866.81 Epsilon = 0.544
# 108
# 111
# resultado da epoca 462 = -15026.23 Epsilon = 0.543
# 99
# 120
# resultado da epoca 463 = -49683.36 Epsilon = 0.542
# 91
# 128
# resultado da epoca 464 = -1110.97 Epsilon = 0.541
# 109
# 110
# resultado da epoca 465 = -20387.31 Epsilon = 0.540
# 100
# 119
# resultado da epoca 466 = -8716.25 Epsilon = 0.539
# 107
# 112
# resultado da epoca 467 = -9843.28 Epsilon = 0.538
# 105
# 114
# resultado da epoca 468 = -19464.35 Epsilon = 0.537
# 109
# 110
# resultado da epoca 469 = -27665.61 Epsilon = 0.536
# 101
# 118
# resultado da epoca 470 = -18905.88 Epsilon = 0.535
# 100
# 119
# resultado da epoca 471 = 1684.75 Epsilon = 0.534
# 110
# 109
# resultado da epoca 472 = -13078.46 Epsilon = 0.533
# 108
# 111
# resultado da epoca 473 = -19019.90 Epsilon = 0.532
# 96
# 123
# resultado da epoca 474 = 11733.76 Epsilon = 0.531
# 120
# 99
# resultado da epoca 475 = -16705.43 Epsilon = 0.530
# 99
# 120
# resultado da epoca 476 = -17843.44 Epsilon = 0.529
# 104
# 115
# resultado da epoca 477 = -2762.42 Epsilon = 0.528
# 103
# 116
# resultado da epoca 478 = -12310.59 Epsilon = 0.527
# 110
# 109
# resultado da epoca 479 = -11257.16 Epsilon = 0.526
# 97
# 122
# resultado da epoca 480 = -18205.25 Epsilon = 0.525
# 103
# 116
# resultado da epoca 481 = 2406.40 Epsilon = 0.524
# 113
# 106
# resultado da epoca 482 = -20847.37 Epsilon = 0.523
# 102
# 117
# resultado da epoca 483 = -23972.16 Epsilon = 0.522
# 101
# 118
# resultado da epoca 484 = -6631.54 Epsilon = 0.521
# 114
# 105
# resultado da epoca 485 = -19013.34 Epsilon = 0.520
# 107
# 112
# resultado da epoca 486 = -10119.74 Epsilon = 0.519
# 106
# 113
# resultado da epoca 487 = 10054.33 Epsilon = 0.518
# 113
# 106
# resultado da epoca 488 = -3393.68 Epsilon = 0.517
# 107
# 112
# resultado da epoca 489 = 27964.64 Epsilon = 0.516
# 120
# 99
# resultado da epoca 490 = 9108.08 Epsilon = 0.515
# 115
# 104
# resultado da epoca 491 = -32829.30 Epsilon = 0.514
# 102
# 117
# resultado da epoca 492 = 25688.84 Epsilon = 0.513
# 125
# 94
# resultado da epoca 493 = -12964.39 Epsilon = 0.512
# 106
# 113
# resultado da epoca 494 = -23020.48 Epsilon = 0.511
# 98
# 121
# resultado da epoca 495 = -506.14 Epsilon = 0.510
# 112
# 107
# resultado da epoca 496 = -7670.16 Epsilon = 0.509
# 110
# 109
# resultado da epoca 497 = -729.86 Epsilon = 0.508
# 110
# 109
# resultado da epoca 498 = 365.34 Epsilon = 0.507
# 114
# 105
# resultado da epoca 499 = -476.42 Epsilon = 0.506
# 108
# 111
# resultado da epoca 500 = -3929.34 Epsilon = 0.505
# 105
# 114
# resultado da epoca 501 = -36057.28 Epsilon = 0.504
# 103
# 116
# resultado da epoca 502 = -17697.47 Epsilon = 0.503
# 110
# 109
# resultado da epoca 503 = -38802.28 Epsilon = 0.502
# 87
# 132
# resultado da epoca 504 = -8189.10 Epsilon = 0.501
# 101
# 118
# resultado da epoca 505 = 7529.97 Epsilon = 0.500
# 116
# 103
# resultado da epoca 506 = -21767.42 Epsilon = 0.499
# 108
# 111
# resultado da epoca 507 = -15561.13 Epsilon = 0.498
# 98
# 121
# resultado da epoca 508 = -26924.06 Epsilon = 0.497
# 106
# 113
# resultado da epoca 509 = -25704.78 Epsilon = 0.496
# 98
# 121
# resultado da epoca 510 = 8199.90 Epsilon = 0.495
# 113
# 106
# resultado da epoca 511 = -15818.09 Epsilon = 0.494
# 105
# 114
# resultado da epoca 512 = -16751.53 Epsilon = 0.493
# 99
# 120
# resultado da epoca 513 = -38344.74 Epsilon = 0.492
# 90
# 129
# resultado da epoca 514 = -27415.83 Epsilon = 0.491
# 92
# 127
# resultado da epoca 515 = -45836.85 Epsilon = 0.490
# 85
# 134
# resultado da epoca 516 = -30684.07 Epsilon = 0.489
# 109
# 110
# resultado da epoca 517 = -28581.22 Epsilon = 0.488
# 86
# 133
# resultado da epoca 518 = -31791.06 Epsilon = 0.487
# 101
# 118
# resultado da epoca 519 = -24791.65 Epsilon = 0.486
# 102
# 117
# resultado da epoca 520 = -22122.15 Epsilon = 0.485
# 97
# 122
# resultado da epoca 521 = -13130.08 Epsilon = 0.484
# 109
# 110
# resultado da epoca 522 = -27941.29 Epsilon = 0.483
# 99
# 120
# resultado da epoca 523 = -21915.63 Epsilon = 0.482
# 103
# 116
# resultado da epoca 524 = -37442.23 Epsilon = 0.481
# 100
# 119
# resultado da epoca 525 = -47303.54 Epsilon = 0.480
# 88
# 131
# resultado da epoca 526 = -10205.08 Epsilon = 0.479
# 99
# 120
# resultado da epoca 527 = -24587.66 Epsilon = 0.478
# 99
# 120
# resultado da epoca 528 = -26899.30 Epsilon = 0.477
# 101
# 118
# resultado da epoca 529 = -20277.63 Epsilon = 0.476
# 101
# 118
# resultado da epoca 530 = -48276.25 Epsilon = 0.475
# 93
# 126
# resultado da epoca 531 = -29510.60 Epsilon = 0.474
# 99
# 120
# resultado da epoca 532 = -17363.21 Epsilon = 0.473
# 102
# 117
# resultado da epoca 533 = -12828.34 Epsilon = 0.472
# 111
# 108
# resultado da epoca 534 = -39883.38 Epsilon = 0.471
# 96
# 123
# resultado da epoca 535 = -6229.80 Epsilon = 0.470
# 117
# 102
# resultado da epoca 536 = -21044.32 Epsilon = 0.469
# 101
# 118
# resultado da epoca 537 = -8526.35 Epsilon = 0.468
# 99
# 120
# resultado da epoca 538 = -51649.49 Epsilon = 0.467
# 92
# 127
# resultado da epoca 539 = 3991.45 Epsilon = 0.466
# 106
# 113
# resultado da epoca 540 = -18622.11 Epsilon = 0.465
# 100
# 119
# resultado da epoca 541 = 12349.44 Epsilon = 0.464
# 118
# 101
# resultado da epoca 542 = -25745.20 Epsilon = 0.463
# 95
# 124
# resultado da epoca 543 = -2630.32 Epsilon = 0.462
# 104
# 115
# resultado da epoca 544 = 1070.32 Epsilon = 0.461
# 108
# 111
# resultado da epoca 545 = -15707.37 Epsilon = 0.460
# 104
# 115
# resultado da epoca 546 = -852.82 Epsilon = 0.459
# 111
# 108
# resultado da epoca 547 = -18107.35 Epsilon = 0.458
# 109
# 110
# resultado da epoca 548 = -36202.63 Epsilon = 0.457
# 106
# 113
# resultado da epoca 549 = -7249.29 Epsilon = 0.456
# 111
# 108
# resultado da epoca 550 = -33749.46 Epsilon = 0.455
# 100
# 119
# resultado da epoca 551 = -16134.63 Epsilon = 0.455
# 100
# 119
# resultado da epoca 552 = -28568.25 Epsilon = 0.454
# 95
# 124
# resultado da epoca 553 = 17076.81 Epsilon = 0.453
# 120
# 99
# resultado da epoca 554 = -18336.53 Epsilon = 0.452
# 103
# 116
# resultado da epoca 555 = -23769.76 Epsilon = 0.451
# 110
# 109
# resultado da epoca 556 = -6585.05 Epsilon = 0.450
# 108
# 111
# resultado da epoca 557 = -28814.82 Epsilon = 0.449
# 104
# 115
# resultado da epoca 558 = -987.60 Epsilon = 0.448
# 107
# 112
# resultado da epoca 559 = -18832.24 Epsilon = 0.447
# 110
# 109
# resultado da epoca 560 = -16481.95 Epsilon = 0.446
# 103
# 116
# resultado da epoca 561 = -27705.84 Epsilon = 0.445
# 108
# 111
# resultado da epoca 562 = -22259.18 Epsilon = 0.444
# 96
# 123
# resultado da epoca 563 = -28042.49 Epsilon = 0.443
# 101
# 118
# resultado da epoca 564 = -29594.68 Epsilon = 0.442
# 103
# 116
# resultado da epoca 565 = -4625.24 Epsilon = 0.441
# 109
# 110
# resultado da epoca 566 = -25616.47 Epsilon = 0.440
# 100
# 119
# resultado da epoca 567 = -19305.21 Epsilon = 0.439
# 92
# 127
# resultado da epoca 568 = -27913.43 Epsilon = 0.438
# 96
# 123
# resultado da epoca 569 = -39834.28 Epsilon = 0.437
# 90
# 129
# resultado da epoca 570 = -19790.98 Epsilon = 0.436
# 103
# 116
# resultado da epoca 571 = -1502.91 Epsilon = 0.435
# 107
# 112
# resultado da epoca 572 = -33393.47 Epsilon = 0.434
# 102
# 117
# resultado da epoca 573 = -9642.07 Epsilon = 0.433
# 108
# 111
# resultado da epoca 574 = -44077.66 Epsilon = 0.432
# 92
# 127
# resultado da epoca 575 = -10632.96 Epsilon = 0.431
# 98
# 121
# resultado da epoca 576 = -19338.66 Epsilon = 0.430
# 103
# 116
# resultado da epoca 577 = 6440.94 Epsilon = 0.429
# 111
# 108
# resultado da epoca 578 = -31636.25 Epsilon = 0.428
# 96
# 123
# resultado da epoca 579 = -10988.75 Epsilon = 0.427
# 108
# 111
# resultado da epoca 580 = -41336.37 Epsilon = 0.426
# 99
# 120
# resultado da epoca 581 = -30240.41 Epsilon = 0.425
# 97
# 122
# resultado da epoca 582 = 13357.64 Epsilon = 0.424
# 112
# 107
# resultado da epoca 583 = -17655.98 Epsilon = 0.423
# 97
# 122
# resultado da epoca 584 = -7355.57 Epsilon = 0.422
# 104
# 115
# resultado da epoca 585 = -25448.33 Epsilon = 0.421
# 98
# 121
# resultado da epoca 586 = -16640.62 Epsilon = 0.420
# 100
# 119
# resultado da epoca 587 = -18452.96 Epsilon = 0.419
# 93
# 126
# resultado da epoca 588 = -18885.17 Epsilon = 0.418
# 109
# 110
# resultado da epoca 589 = -21547.78 Epsilon = 0.417
# 102
# 117
# resultado da epoca 590 = 11077.82 Epsilon = 0.416
# 109
# 110
# resultado da epoca 591 = -12060.00 Epsilon = 0.415
# 94
# 125
# resultado da epoca 592 = -15366.05 Epsilon = 0.414
# 108
# 111
# resultado da epoca 593 = -1112.30 Epsilon = 0.413
# 108
# 111
# resultado da epoca 594 = 6320.04 Epsilon = 0.412
# 109
# 110
# resultado da epoca 595 = -21257.89 Epsilon = 0.411
# 96
# 123
# resultado da epoca 596 = -8700.53 Epsilon = 0.410
# 104
# 115
# resultado da epoca 597 = 16091.55 Epsilon = 0.409
# 115
# 104
# resultado da epoca 598 = -12190.32 Epsilon = 0.408
# 104
# 115
# resultado da epoca 599 = -9504.19 Epsilon = 0.407
# 105
# 114
# resultado da epoca 600 = -27746.95 Epsilon = 0.406
# 104
# 115
# resultado da epoca 601 = -22442.39 Epsilon = 0.405
# 107
# 112
# resultado da epoca 602 = -23274.37 Epsilon = 0.404
# 97
# 122
# resultado da epoca 603 = -4489.52 Epsilon = 0.403
# 106
# 113
# resultado da epoca 604 = 11897.91 Epsilon = 0.402
# 115
# 104
# resultado da epoca 605 = -926.24 Epsilon = 0.401
# 97
# 122
# resultado da epoca 606 = -19190.48 Epsilon = 0.400
# 100
# 119
# resultado da epoca 607 = -26708.86 Epsilon = 0.399
# 98
# 121
# resultado da epoca 608 = -6436.01 Epsilon = 0.398
# 111
# 108
# resultado da epoca 609 = -21641.54 Epsilon = 0.397
# 103
# 116
# resultado da epoca 610 = -13243.91 Epsilon = 0.396
# 98
# 121
# resultado da epoca 611 = -25693.01 Epsilon = 0.395
# 98
# 121
# resultado da epoca 612 = -4928.54 Epsilon = 0.394
# 108
# 111
# resultado da epoca 613 = 14009.71 Epsilon = 0.393
# 107
# 112
# resultado da epoca 614 = -39201.54 Epsilon = 0.392
# 96
# 123
# resultado da epoca 615 = -23730.91 Epsilon = 0.391
# 97
# 122
# resultado da epoca 616 = -28777.87 Epsilon = 0.390
# 96
# 123
# resultado da epoca 617 = -17234.23 Epsilon = 0.389
# 106
# 113
# resultado da epoca 618 = -26989.46 Epsilon = 0.388
# 104
# 115
# resultado da epoca 619 = -6129.90 Epsilon = 0.387
# 98
# 121
# resultado da epoca 620 = -26099.82 Epsilon = 0.386
# 96
# 123
# resultado da epoca 621 = -15771.31 Epsilon = 0.385
# 99
# 120
# resultado da epoca 622 = -28230.63 Epsilon = 0.384
# 99
# 120
# resultado da epoca 623 = 132.58 Epsilon = 0.383
# 110
# 109
# resultado da epoca 624 = 12531.17 Epsilon = 0.382
# 118
# 101
# resultado da epoca 625 = 11729.28 Epsilon = 0.381
# 109
# 110
# resultado da epoca 626 = 11724.90 Epsilon = 0.380
# 116
# 103
# resultado da epoca 627 = -35394.73 Epsilon = 0.379
# 94
# 125
# resultado da epoca 628 = -10655.28 Epsilon = 0.378
# 107
# 112
# resultado da epoca 629 = 7677.71 Epsilon = 0.377
# 103
# 116
# resultado da epoca 630 = -19060.62 Epsilon = 0.376
# 97
# 122
# resultado da epoca 631 = -16840.66 Epsilon = 0.375
# 98
# 121
# resultado da epoca 632 = 27102.46 Epsilon = 0.374
# 123
# 96
# resultado da epoca 633 = 2009.99 Epsilon = 0.373
# 112
# 107
# resultado da epoca 634 = -29311.13 Epsilon = 0.372
# 99
# 120
# resultado da epoca 635 = 15803.53 Epsilon = 0.371
# 121
# 98
# resultado da epoca 636 = 25113.37 Epsilon = 0.370
# 119
# 100
# resultado da epoca 637 = -3706.58 Epsilon = 0.369
# 112
# 107
# resultado da epoca 638 = -15448.62 Epsilon = 0.368
# 97
# 122
# resultado da epoca 639 = 5367.17 Epsilon = 0.367
# 112
# 107
# resultado da epoca 640 = -10016.29 Epsilon = 0.366
# 101
# 118
# resultado da epoca 641 = -24421.06 Epsilon = 0.365
# 102
# 117
# resultado da epoca 642 = 2011.52 Epsilon = 0.364
# 105
# 114
# resultado da epoca 643 = -9509.52 Epsilon = 0.363
# 99
# 120
# resultado da epoca 644 = 6667.18 Epsilon = 0.362
# 116
# 103
# resultado da epoca 645 = -933.75 Epsilon = 0.361
# 114
# 105
# resultado da epoca 646 = -3043.39 Epsilon = 0.360
# 106
# 113
# resultado da epoca 647 = 11663.65 Epsilon = 0.359
# 107
# 112
# resultado da epoca 648 = 35573.28 Epsilon = 0.358
# 120
# 99
# resultado da epoca 649 = 17536.47 Epsilon = 0.357
# 117
# 102
# resultado da epoca 650 = 23244.59 Epsilon = 0.356
# 120
# 99
# resultado da epoca 651 = -1468.65 Epsilon = 0.356
# 108
# 111
# resultado da epoca 652 = 11413.83 Epsilon = 0.355
# 104
# 115
# resultado da epoca 653 = 24412.54 Epsilon = 0.354
# 118
# 101
# resultado da epoca 654 = 9716.40 Epsilon = 0.353
# 110
# 109
# resultado da epoca 655 = 24818.86 Epsilon = 0.352
# 118
# 101
# resultado da epoca 656 = 15966.31 Epsilon = 0.351
# 112
# 107
# resultado da epoca 657 = -8349.30 Epsilon = 0.350
# 100
# 119
# resultado da epoca 658 = -14080.53 Epsilon = 0.349
# 107
# 112
# resultado da epoca 659 = -8672.23 Epsilon = 0.348
# 113
# 106
# resultado da epoca 660 = -23934.94 Epsilon = 0.347
# 112
# 107
# resultado da epoca 661 = -20829.57 Epsilon = 0.346
# 105
# 114
# resultado da epoca 662 = -4368.94 Epsilon = 0.345
# 104
# 115
# resultado da epoca 663 = -34280.88 Epsilon = 0.344
# 100
# 119
# resultado da epoca 664 = -46057.23 Epsilon = 0.343
# 89
# 130
# resultado da epoca 665 = -37935.99 Epsilon = 0.342
# 96
# 123
# resultado da epoca 666 = -3982.24 Epsilon = 0.341
# 113
# 106
# resultado da epoca 667 = -32018.93 Epsilon = 0.340
# 97
# 122
# resultado da epoca 668 = -26926.75 Epsilon = 0.339
# 101
# 118
# resultado da epoca 669 = -28130.89 Epsilon = 0.338
# 98
# 121
# resultado da epoca 670 = -43288.65 Epsilon = 0.337
# 97
# 122
# resultado da epoca 671 = -39267.98 Epsilon = 0.336
# 95
# 124
# resultado da epoca 672 = -26263.34 Epsilon = 0.335
# 96
# 123
# resultado da epoca 673 = -20505.30 Epsilon = 0.334
# 100
# 119
# resultado da epoca 674 = -12002.90 Epsilon = 0.333
# 101
# 118
# resultado da epoca 675 = -3730.46 Epsilon = 0.332
# 107
# 112
# resultado da epoca 676 = -26269.05 Epsilon = 0.331
# 99
# 120
# resultado da epoca 677 = -13538.79 Epsilon = 0.330
# 104
# 115
# resultado da epoca 678 = -20870.69 Epsilon = 0.329
# 96
# 123
# resultado da epoca 679 = -22077.46 Epsilon = 0.328
# 99
# 120
# resultado da epoca 680 = -28859.36 Epsilon = 0.327
# 110
# 109
# resultado da epoca 681 = -16948.85 Epsilon = 0.326
# 105
# 114
# resultado da epoca 682 = -35204.65 Epsilon = 0.325
# 91
# 128
# resultado da epoca 683 = -15153.10 Epsilon = 0.324
# 106
# 113
# resultado da epoca 684 = -34188.59 Epsilon = 0.323
# 95
# 124
# resultado da epoca 685 = -26555.65 Epsilon = 0.322
# 105
# 114
# resultado da epoca 686 = -5233.33 Epsilon = 0.321
# 113
# 106
# resultado da epoca 687 = -17329.71 Epsilon = 0.320
# 104
# 115
# resultado da epoca 688 = -20235.57 Epsilon = 0.319
# 104
# 115
# resultado da epoca 689 = -13312.30 Epsilon = 0.318
# 101
# 118
# resultado da epoca 690 = -36949.07 Epsilon = 0.317
# 93
# 126
# resultado da epoca 691 = -12435.57 Epsilon = 0.316
# 103
# 116
# resultado da epoca 692 = -13338.61 Epsilon = 0.315
# 106
# 113
# resultado da epoca 693 = 154.52 Epsilon = 0.314
# 106
# 113
# resultado da epoca 694 = -25670.22 Epsilon = 0.313
# 94
# 125
# resultado da epoca 695 = -13538.85 Epsilon = 0.312
# 101
# 118
# resultado da epoca 696 = -22365.12 Epsilon = 0.311
# 110
# 109
# resultado da epoca 697 = -21781.54 Epsilon = 0.310
# 102
# 117
# resultado da epoca 698 = 2866.43 Epsilon = 0.309
# 113
# 106
# resultado da epoca 699 = -749.78 Epsilon = 0.308
# 113
# 106
# resultado da epoca 700 = -23119.28 Epsilon = 0.307
# 105
# 114
# resultado da epoca 701 = -29014.41 Epsilon = 0.306
# 96
# 123
# resultado da epoca 702 = -20185.60 Epsilon = 0.305
# 96
# 123
# resultado da epoca 703 = -43963.46 Epsilon = 0.304
# 88
# 131
# resultado da epoca 704 = -7824.82 Epsilon = 0.303
# 99
# 120
# resultado da epoca 705 = -11798.46 Epsilon = 0.302
# 107
# 112
# resultado da epoca 706 = -37682.29 Epsilon = 0.301
# 101
# 118
# resultado da epoca 707 = -35210.53 Epsilon = 0.300
# 87
# 132
# resultado da epoca 708 = -14100.68 Epsilon = 0.299
# 99
# 120
# resultado da epoca 709 = 1613.10 Epsilon = 0.298
# 110
# 109
# resultado da epoca 710 = -10515.03 Epsilon = 0.297
# 105
# 114
# resultado da epoca 711 = -15928.24 Epsilon = 0.296
# 100
# 119
# resultado da epoca 712 = -13635.86 Epsilon = 0.295
# 101
# 118
# resultado da epoca 713 = 12616.49 Epsilon = 0.294
# 109
# 110
# resultado da epoca 714 = 3258.67 Epsilon = 0.293
# 107
# 112
# resultado da epoca 715 = -20868.34 Epsilon = 0.292
# 105
# 114
# resultado da epoca 716 = -18488.76 Epsilon = 0.291
# 105
# 114
# resultado da epoca 717 = 7590.27 Epsilon = 0.290
# 116
# 103
# resultado da epoca 718 = -478.56 Epsilon = 0.289
# 110
# 109
# resultado da epoca 719 = -876.33 Epsilon = 0.288
# 110
# 109
# resultado da epoca 720 = 281.54 Epsilon = 0.287
# 110
# 109
# resultado da epoca 721 = -3896.00 Epsilon = 0.286
# 114
# 105
# resultado da epoca 722 = 6121.64 Epsilon = 0.285
# 111
# 108
# resultado da epoca 723 = 253.82 Epsilon = 0.284
# 106
# 113
# resultado da epoca 724 = -22635.91 Epsilon = 0.283
# 98
# 121
# resultado da epoca 725 = -21453.37 Epsilon = 0.282
# 106
# 113
# resultado da epoca 726 = -13529.55 Epsilon = 0.281
# 103
# 116
# resultado da epoca 727 = -20509.82 Epsilon = 0.280
# 104
# 115
# resultado da epoca 728 = -12921.52 Epsilon = 0.279
# 113
# 106
# resultado da epoca 729 = -18922.05 Epsilon = 0.278
# 102
# 117
# resultado da epoca 730 = -10653.27 Epsilon = 0.277
# 106
# 113
# resultado da epoca 731 = -8116.68 Epsilon = 0.276
# 105
# 114
# resultado da epoca 732 = -35417.31 Epsilon = 0.275
# 89
# 130
# resultado da epoca 733 = -4344.65 Epsilon = 0.274
# 109
# 110
# resultado da epoca 734 = -20802.65 Epsilon = 0.273
# 99
# 120
# resultado da epoca 735 = -8396.09 Epsilon = 0.272
# 108
# 111
# resultado da epoca 736 = -23749.10 Epsilon = 0.271
# 102
# 117
# resultado da epoca 737 = -382.52 Epsilon = 0.270
# 116
# 103
# resultado da epoca 738 = 17955.06 Epsilon = 0.269
# 117
# 102
# resultado da epoca 739 = 745.47 Epsilon = 0.268
# 108
# 111
# resultado da epoca 740 = -4460.26 Epsilon = 0.267
# 111
# 108
# resultado da epoca 741 = 2485.14 Epsilon = 0.266
# 105
# 114
# resultado da epoca 742 = -15910.40 Epsilon = 0.265
# 104
# 115
# resultado da epoca 743 = -1911.59 Epsilon = 0.264
# 107
# 112
# resultado da epoca 744 = -16311.11 Epsilon = 0.263
# 102
# 117
# resultado da epoca 745 = -3809.71 Epsilon = 0.262
# 104
# 115
# resultado da epoca 746 = -21747.99 Epsilon = 0.261
# 101
# 118
# resultado da epoca 747 = -3366.96 Epsilon = 0.260
# 109
# 110
# resultado da epoca 748 = 4956.92 Epsilon = 0.259
# 111
# 108
# resultado da epoca 749 = 21145.46 Epsilon = 0.258
# 113
# 106
# resultado da epoca 750 = -28054.86 Epsilon = 0.257
# 109
# 110
# resultado da epoca 751 = -33331.19 Epsilon = 0.257
# 94
# 125
# resultado da epoca 752 = -10143.64 Epsilon = 0.256
# 110
# 109
# resultado da epoca 753 = 129.24 Epsilon = 0.255
# 111
# 108
# resultado da epoca 754 = -534.08 Epsilon = 0.254
# 108
# 111
# resultado da epoca 755 = -536.20 Epsilon = 0.253
# 105
# 114
# resultado da epoca 756 = 3791.62 Epsilon = 0.252
# 104
# 115
# resultado da epoca 757 = 9140.95 Epsilon = 0.251
# 106
# 113
# resultado da epoca 758 = -7757.11 Epsilon = 0.250
# 108
# 111
# resultado da epoca 759 = -2949.13 Epsilon = 0.249
# 105
# 114
# resultado da epoca 760 = 8795.16 Epsilon = 0.248
# 116
# 103
# resultado da epoca 761 = -8851.73 Epsilon = 0.247
# 101
# 118
# resultado da epoca 762 = -2514.26 Epsilon = 0.246
# 104
# 115
# resultado da epoca 763 = -3046.86 Epsilon = 0.245
# 107
# 112
# resultado da epoca 764 = 7130.51 Epsilon = 0.244
# 114
# 105
# resultado da epoca 765 = 14175.07 Epsilon = 0.243
# 112
# 107
# resultado da epoca 766 = 5812.08 Epsilon = 0.242
# 110
# 109
# resultado da epoca 767 = 2076.04 Epsilon = 0.241
# 109
# 110
# resultado da epoca 768 = -9561.60 Epsilon = 0.240
# 98
# 121
# resultado da epoca 769 = -3875.95 Epsilon = 0.239
# 110
# 109
# resultado da epoca 770 = -23700.39 Epsilon = 0.238
# 97
# 122
# resultado da epoca 771 = -16339.52 Epsilon = 0.237
# 103
# 116
# resultado da epoca 772 = 5466.91 Epsilon = 0.236
# 104
# 115
# resultado da epoca 773 = 13605.72 Epsilon = 0.235
# 118
# 101
# resultado da epoca 774 = 10413.87 Epsilon = 0.234
# 110
# 109
# resultado da epoca 775 = 11962.34 Epsilon = 0.233
# 120
# 99
# resultado da epoca 776 = -19258.74 Epsilon = 0.232
# 107
# 112
# resultado da epoca 777 = -3568.87 Epsilon = 0.231
# 106
# 113
# resultado da epoca 778 = 6647.01 Epsilon = 0.230
# 111
# 108
# resultado da epoca 779 = 1107.09 Epsilon = 0.229
# 108
# 111
# resultado da epoca 780 = -6689.45 Epsilon = 0.228
# 113
# 106
# resultado da epoca 781 = 17525.34 Epsilon = 0.227
# 113
# 106
# resultado da epoca 782 = -5443.61 Epsilon = 0.226
# 107
# 112
# resultado da epoca 783 = 3998.39 Epsilon = 0.225
# 105
# 114
# resultado da epoca 784 = 8635.62 Epsilon = 0.224
# 117
# 102
# resultado da epoca 785 = 27323.25 Epsilon = 0.223
# 120
# 99
# resultado da epoca 786 = 23175.48 Epsilon = 0.222
# 117
# 102
# resultado da epoca 787 = 14335.45 Epsilon = 0.221
# 115
# 104
# resultado da epoca 788 = -6448.28 Epsilon = 0.220
# 107
# 112
# resultado da epoca 789 = 16463.15 Epsilon = 0.219
# 115
# 104
# resultado da epoca 790 = 7609.02 Epsilon = 0.218
# 110
# 109
# resultado da epoca 791 = -4175.41 Epsilon = 0.217
# 112
# 107
# resultado da epoca 792 = -8770.98 Epsilon = 0.216
# 107
# 112
# resultado da epoca 793 = 15759.97 Epsilon = 0.215
# 113
# 106
# resultado da epoca 794 = 18330.67 Epsilon = 0.214
# 116
# 103
# resultado da epoca 795 = -1925.42 Epsilon = 0.213
# 107
# 112
# resultado da epoca 796 = -4806.78 Epsilon = 0.212
# 108
# 111
# resultado da epoca 797 = 2533.88 Epsilon = 0.211
# 110
# 109
# resultado da epoca 798 = -8039.37 Epsilon = 0.210
# 109
# 110
# resultado da epoca 799 = -16601.48 Epsilon = 0.209
# 106
# 113
# resultado da epoca 800 = -22233.13 Epsilon = 0.208
# 104
# 115
# resultado da epoca 801 = -7554.18 Epsilon = 0.207
# 102
# 117
# resultado da epoca 802 = -5618.33 Epsilon = 0.206
# 117
# 102
# resultado da epoca 803 = 9111.43 Epsilon = 0.205
# 116
# 103
# resultado da epoca 804 = 10909.65 Epsilon = 0.204
# 113
# 106
# resultado da epoca 805 = -3621.96 Epsilon = 0.203
# 106
# 113
# resultado da epoca 806 = -14686.74 Epsilon = 0.202
# 98
# 121
# resultado da epoca 807 = -7177.65 Epsilon = 0.201
# 111
# 108
# resultado da epoca 808 = 15485.25 Epsilon = 0.200
# 106
# 113
# resultado da epoca 809 = 7019.82 Epsilon = 0.199
# 114
# 105
# resultado da epoca 810 = 41963.75 Epsilon = 0.198
# 127
# 92
# resultado da epoca 811 = 15163.16 Epsilon = 0.197
# 116
# 103
# resultado da epoca 812 = 27396.59 Epsilon = 0.196
# 120
# 99
# resultado da epoca 813 = -1282.24 Epsilon = 0.195
# 113
# 106
# resultado da epoca 814 = 9448.04 Epsilon = 0.194
# 111
# 108
# resultado da epoca 815 = -6446.67 Epsilon = 0.193
# 97
# 122
# resultado da epoca 816 = 16719.17 Epsilon = 0.192
# 126
# 93
# resultado da epoca 817 = -3191.08 Epsilon = 0.191
# 110
# 109
# resultado da epoca 818 = -4140.26 Epsilon = 0.190
# 100
# 119
# resultado da epoca 819 = -12737.02 Epsilon = 0.189
# 107
# 112
# resultado da epoca 820 = -17650.29 Epsilon = 0.188
# 98
# 121
# resultado da epoca 821 = -3348.06 Epsilon = 0.187
# 99
# 120
# resultado da epoca 822 = -9116.91 Epsilon = 0.186
# 102
# 117
# resultado da epoca 823 = 5319.92 Epsilon = 0.185
# 104
# 115
# resultado da epoca 824 = -17707.99 Epsilon = 0.184
# 90
# 129
# resultado da epoca 825 = -10946.55 Epsilon = 0.183
# 101
# 118
# resultado da epoca 826 = 2919.44 Epsilon = 0.182
# 104
# 115
# resultado da epoca 827 = -21654.55 Epsilon = 0.181
# 108
# 111
# resultado da epoca 828 = -20627.22 Epsilon = 0.180
# 101
# 118
# resultado da epoca 829 = 2177.97 Epsilon = 0.179
# 106
# 113
# resultado da epoca 830 = -13702.14 Epsilon = 0.178
# 100
# 119
# resultado da epoca 831 = 1021.29 Epsilon = 0.177
# 103
# 116
# resultado da epoca 832 = -9924.99 Epsilon = 0.176
# 108
# 111
# resultado da epoca 833 = 4534.85 Epsilon = 0.175
# 107
# 112
# resultado da epoca 834 = -1830.19 Epsilon = 0.174
# 102
# 117
# resultado da epoca 835 = 23082.86 Epsilon = 0.173
# 115
# 104
# resultado da epoca 836 = -1682.26 Epsilon = 0.172
# 102
# 117
# resultado da epoca 837 = 4874.77 Epsilon = 0.171
# 109
# 110
# resultado da epoca 838 = 173.38 Epsilon = 0.170
# 112
# 107
# resultado da epoca 839 = 2673.59 Epsilon = 0.169
# 111
# 108
# resultado da epoca 840 = -4130.64 Epsilon = 0.168
# 104
# 115
# resultado da epoca 841 = 208.57 Epsilon = 0.167
# 106
# 113
# resultado da epoca 842 = -7531.21 Epsilon = 0.166
# 98
# 121
# resultado da epoca 843 = 4505.71 Epsilon = 0.165
# 115
# 104
# resultado da epoca 844 = 13367.20 Epsilon = 0.164
# 111
# 108
# resultado da epoca 845 = 16834.71 Epsilon = 0.163
# 105
# 114
# resultado da epoca 846 = 1750.34 Epsilon = 0.162
# 113
# 106
# resultado da epoca 847 = 33831.33 Epsilon = 0.161
# 130
# 89
# resultado da epoca 848 = -1796.63 Epsilon = 0.160
# 117
# 102
# resultado da epoca 849 = 17594.44 Epsilon = 0.159
# 116
# 103
# resultado da epoca 850 = 27526.43 Epsilon = 0.158
# 118
# 101
# resultado da epoca 851 = 4581.50 Epsilon = 0.158
# 119
# 100
# resultado da epoca 852 = 12432.30 Epsilon = 0.157
# 124
# 95
# resultado da epoca 853 = -1179.20 Epsilon = 0.156
# 100
# 119
# resultado da epoca 854 = 20096.88 Epsilon = 0.155
# 118
# 101
# resultado da epoca 855 = 7674.36 Epsilon = 0.154
# 113
# 106
# resultado da epoca 856 = 18330.07 Epsilon = 0.153
# 116
# 103
# resultado da epoca 857 = -13396.14 Epsilon = 0.152
# 98
# 121
# resultado da epoca 858 = 19586.58 Epsilon = 0.151
# 112
# 107
# resultado da epoca 859 = 17324.88 Epsilon = 0.150
# 118
# 101
# resultado da epoca 860 = 18993.53 Epsilon = 0.149
# 125
# 94
# resultado da epoca 861 = -2724.87 Epsilon = 0.148
# 113
# 106
# resultado da epoca 862 = 42020.50 Epsilon = 0.147
# 134
# 85
# resultado da epoca 863 = 32646.86 Epsilon = 0.146
# 127
# 92
# resultado da epoca 864 = 27865.06 Epsilon = 0.145
# 122
# 97
# resultado da epoca 865 = 24126.49 Epsilon = 0.144
# 122
# 97
# resultado da epoca 866 = 29803.11 Epsilon = 0.143
# 121
# 98
# resultado da epoca 867 = 11572.86 Epsilon = 0.142
# 117
# 102
# resultado da epoca 868 = 33998.74 Epsilon = 0.141
# 125
# 94
# resultado da epoca 869 = 18871.51 Epsilon = 0.140
# 113
# 106
# resultado da epoca 870 = 27830.61 Epsilon = 0.139
# 119
# 100
# resultado da epoca 871 = 25325.91 Epsilon = 0.138
# 113
# 106
# resultado da epoca 872 = 14329.34 Epsilon = 0.137
# 114
# 105
# resultado da epoca 873 = 16642.24 Epsilon = 0.136
# 114
# 105
# resultado da epoca 874 = 16130.82 Epsilon = 0.135
# 112
# 107
# resultado da epoca 875 = 23341.88 Epsilon = 0.134
# 116
# 103
# resultado da epoca 876 = 6167.48 Epsilon = 0.133
# 117
# 102
# resultado da epoca 877 = 27970.84 Epsilon = 0.132
# 121
# 98
# resultado da epoca 878 = 27759.16 Epsilon = 0.131
# 122
# 97
# resultado da epoca 879 = 12559.84 Epsilon = 0.130
# 123
# 96
# resultado da epoca 880 = 23804.40 Epsilon = 0.129
# 122
# 97
# resultado da epoca 881 = 42381.02 Epsilon = 0.128
# 125
# 94
# resultado da epoca 882 = 37167.22 Epsilon = 0.127
# 118
# 101
# resultado da epoca 883 = 31809.35 Epsilon = 0.126
# 121
# 98
# resultado da epoca 884 = 21826.97 Epsilon = 0.125
# 121
# 98
# resultado da epoca 885 = 42642.82 Epsilon = 0.124
# 125
# 94
# resultado da epoca 886 = 15638.31 Epsilon = 0.123
# 121
# 98
# resultado da epoca 887 = 28059.33 Epsilon = 0.122
# 124
# 95
# resultado da epoca 888 = 28081.98 Epsilon = 0.121
# 122
# 97
# resultado da epoca 889 = 17970.70 Epsilon = 0.120
# 111
# 108
# resultado da epoca 890 = 22685.72 Epsilon = 0.119
# 118
# 101
# resultado da epoca 891 = 32485.74 Epsilon = 0.118
# 120
# 99
# resultado da epoca 892 = 38231.90 Epsilon = 0.117
# 115
# 104
# resultado da epoca 893 = 32679.16 Epsilon = 0.116
# 121
# 98
# resultado da epoca 894 = 29531.18 Epsilon = 0.115
# 119
# 100
# resultado da epoca 895 = 25678.55 Epsilon = 0.114
# 113
# 106
# resultado da epoca 896 = 21902.47 Epsilon = 0.113
# 115
# 104
# resultado da epoca 897 = 32724.51 Epsilon = 0.112
# 121
# 98
# resultado da epoca 898 = 10038.71 Epsilon = 0.111
# 117
# 102
# resultado da epoca 899 = 23296.51 Epsilon = 0.110
# 128
# 90
# resultado da epoca 900 = 17725.65 Epsilon = 0.109
# 124
# 94
# resultado da epoca 901 = 9400.38 Epsilon = 0.108
# 116
# 103
# resultado da epoca 902 = 5689.47 Epsilon = 0.107
# 110
# 107
# resultado da epoca 903 = 32739.29 Epsilon = 0.106
# 119
# 100
# resultado da epoca 904 = 24999.08 Epsilon = 0.105
# 129
# 90
# resultado da epoca 905 = 11319.72 Epsilon = 0.104
# 120
# 99
# resultado da epoca 906 = 9644.95 Epsilon = 0.103
# 113
# 105
# resultado da epoca 907 = 32276.40 Epsilon = 0.102
# 117
# 100
# resultado da epoca 908 = 8299.55 Epsilon = 0.101
# 108
# 108
# resultado da epoca 909 = 30994.18 Epsilon = 0.100
# 129
# 89
# resultado da epoca 910 = 21403.05 Epsilon = 0.099
# 124
# 94
# resultado da epoca 911 = 24682.86 Epsilon = 0.098
# 123
# 96
# resultado da epoca 912 = -2851.18 Epsilon = 0.097
# 109
# 108
# resultado da epoca 913 = 18617.69 Epsilon = 0.096
# 116
# 103
# resultado da epoca 914 = 19183.58 Epsilon = 0.095
# 126
# 92
# resultado da epoca 915 = 16432.39 Epsilon = 0.094
# 121
# 98
# resultado da epoca 916 = 7793.09 Epsilon = 0.093
# 114
# 104
# resultado da epoca 917 = 1484.75 Epsilon = 0.092
# 121
# 98
# resultado da epoca 918 = -4543.14 Epsilon = 0.091
# 121
# 96
# resultado da epoca 919 = 2141.47 Epsilon = 0.090
# 113
# 104
# resultado da epoca 920 = 453.62 Epsilon = 0.089
# 109
# 107
# resultado da epoca 921 = 127.74 Epsilon = 0.088
# 117
# 100
# resultado da epoca 922 = 20263.99 Epsilon = 0.087
# 127
# 91
# resultado da epoca 923 = 12387.15 Epsilon = 0.086
# 121
# 98
# resultado da epoca 924 = 4190.05 Epsilon = 0.085
# 113
# 106
# resultado da epoca 925 = 3204.13 Epsilon = 0.084
# 117
# 100
# resultado da epoca 926 = -4610.91 Epsilon = 0.083
# 106
# 110
# resultado da epoca 927 = 20998.31 Epsilon = 0.082
# 126
# 91
# resultado da epoca 928 = 9219.49 Epsilon = 0.081
# 120
# 97
# resultado da epoca 929 = 6965.91 Epsilon = 0.080
# 123
# 92
# resultado da epoca 930 = -2317.18 Epsilon = 0.079
# 113
# 103
# resultado da epoca 931 = 17497.21 Epsilon = 0.078
# 121
# 97
# resultado da epoca 932 = 22929.12 Epsilon = 0.077
# 123
# 95
# resultado da epoca 933 = 14252.70 Epsilon = 0.076
# 128
# 90
# resultado da epoca 934 = 19706.64 Epsilon = 0.075
# 123
# 92
# resultado da epoca 935 = 14661.18 Epsilon = 0.074
# 126
# 90
# resultado da epoca 936 = 20823.92 Epsilon = 0.073
# 126
# 89
# resultado da epoca 937 = 27514.46 Epsilon = 0.072
# 125
# 92
# resultado da epoca 938 = 21467.82 Epsilon = 0.071
# 123
# 89
# resultado da epoca 939 = 36341.07 Epsilon = 0.070
# 133
# 84
# resultado da epoca 940 = 31104.34 Epsilon = 0.069
# 135
# 77
# resultado da epoca 941 = 24634.98 Epsilon = 0.068
# 121
# 91
# resultado da epoca 942 = 31338.47 Epsilon = 0.067
# 130
# 86
# resultado da epoca 943 = 25320.44 Epsilon = 0.066
# 129
# 78
# resultado da epoca 944 = 40819.15 Epsilon = 0.065
# 136
# 76
# resultado da epoca 945 = 33766.30 Epsilon = 0.064
# 136
# 76
# resultado da epoca 946 = 36133.99 Epsilon = 0.063
# 137
# 73
# resultado da epoca 947 = 40857.34 Epsilon = 0.062
# 137
# 78
# resultado da epoca 948 = 43291.28 Epsilon = 0.061
# 133
# 79
# resultado da epoca 949 = 20840.51 Epsilon = 0.060
# 126
# 85
# resultado da epoca 950 = 44778.54 Epsilon = 0.059
# 138
# 75
# resultado da epoca 951 = 38351.22 Epsilon = 0.059
# 133
# 79
# resultado da epoca 952 = 35259.73 Epsilon = 0.058
# 122
# 92
# resultado da epoca 953 = 17354.52 Epsilon = 0.057
# 114
# 97
# resultado da epoca 954 = 37510.28 Epsilon = 0.056
# 130
# 83
# resultado da epoca 955 = 34452.04 Epsilon = 0.055
# 130
# 85
# resultado da epoca 956 = 38175.57 Epsilon = 0.054
# 128
# 82
# resultado da epoca 957 = 47764.01 Epsilon = 0.053
# 120
# 90
# resultado da epoca 958 = 46145.18 Epsilon = 0.052
# 104
# 103
# resultado da epoca 959 = 59299.89 Epsilon = 0.051
# 121
# 94
# resultado da epoca 960 = 50175.02 Epsilon = 0.050
# 121
# 93
# resultado da epoca 961 = 45034.44 Epsilon = 0.049
# 131
# 86
# resultado da epoca 962 = 45117.69 Epsilon = 0.048
# 129
# 83
# resultado da epoca 963 = 41188.46 Epsilon = 0.047
# 123
# 94
# resultado da epoca 964 = 46630.83 Epsilon = 0.046
# 119
# 87
# resultado da epoca 965 = 29430.04 Epsilon = 0.045
# 100
# 103
# resultado da epoca 966 = 48911.40 Epsilon = 0.044
# 101
# 103
# resultado da epoca 967 = 39479.14 Epsilon = 0.043
# 101
# 96
# resultado da epoca 968 = 33317.56 Epsilon = 0.042
# 107
# 98
# resultado da epoca 969 = 52021.48 Epsilon = 0.041
# 115
# 80
# resultado da epoca 970 = 27440.38 Epsilon = 0.040
# 94
# 101
# resultado da epoca 971 = 28951.12 Epsilon = 0.039
# 103
# 92
# resultado da epoca 972 = 5171.73 Epsilon = 0.038
# 101
# 96
# resultado da epoca 973 = 41630.85 Epsilon = 0.037
# 105
# 94
# resultado da epoca 974 = 27594.90 Epsilon = 0.036
# 102
# 92
# resultado da epoca 975 = 32987.99 Epsilon = 0.035
# 105
# 91
# resultado da epoca 976 = 42845.67 Epsilon = 0.034
# 103
# 89
# resultado da epoca 977 = 23855.66 Epsilon = 0.033
# 113
# 83
# resultado da epoca 978 = 16636.99 Epsilon = 0.032
# 97
# 86
# resultado da epoca 979 = 26040.52 Epsilon = 0.031
# 112
# 74
# resultado da epoca 980 = 24683.28 Epsilon = 0.030
# 113
# 72
# resultado da epoca 981 = 20521.45 Epsilon = 0.029
# 105
# 85
# resultado da epoca 982 = 16459.43 Epsilon = 0.028
# 105
# 85
# resultado da epoca 983 = 27982.36 Epsilon = 0.027
# 118
# 68
# resultado da epoca 984 = 20136.20 Epsilon = 0.026
# 117
# 64
# resultado da epoca 985 = 31714.73 Epsilon = 0.025
# 109
# 58
# resultado da epoca 986 = 48023.54 Epsilon = 0.024
# 106
# 57
# resultado da epoca 987 = 37326.83 Epsilon = 0.023
# 113
# 59
# resultado da epoca 988 = 34553.46 Epsilon = 0.022
# 114
# 49
# resultado da epoca 989 = 40922.00 Epsilon = 0.021
# 108
# 68
# resultado da epoca 990 = 47680.32 Epsilon = 0.020
# 120
# 49
# resultado da epoca 991 = 42398.76 Epsilon = 0.019
# 108
# 60
# resultado da epoca 992 = 41385.15 Epsilon = 0.018
# 105
# 57
# resultado da epoca 993 = 45160.39 Epsilon = 0.017
# 110
# 51
# resultado da epoca 994 = 48402.16 Epsilon = 0.016
# 119
# 33
# resultado da epoca 995 = 34016.50 Epsilon = 0.015
# 96
# 52
# resultado da epoca 996 = 26025.57 Epsilon = 0.014
# 89
# 53
# resultado da epoca 997 = 33388.80 Epsilon = 0.013
# 85
# 42
# resultado da epoca 998 = 43587.61 Epsilon = 0.012
# 98
# 45
# resultado da epoca 999 = 30873.20 Epsilon = 0.011
# 91
# 42
# resultado da epoca 1000 = 31698.77 Epsilon = 0.010
# 80
# 38
# resultado da epoca 1001 = 44966.44 Epsilon = 0.010
# 92
# 35
# resultado da epoca 1002 = 33044.05 Epsilon = 0.010
# 83
# 42
# resultado da epoca 1003 = 39843.50 Epsilon = 0.010
# 100
# 42
# resultado da epoca 1004 = 43568.83 Epsilon = 0.010
# 109
# 30
# resultado da epoca 1005 = 51047.49 Epsilon = 0.010
# 121
# 33
# resultado da epoca 1006 = 39327.38 Epsilon = 0.010
# 106
# 61
# resultado da epoca 1007 = 44728.17 Epsilon = 0.010
# 112
# 61
# resultado da epoca 1008 = 50532.76 Epsilon = 0.010
# 113
# 99
# resultado da epoca 1009 = 42807.06 Epsilon = 0.010
# 109
# 66
# resultado da epoca 1010 = 35816.78 Epsilon = 0.010
# 104
# 36
# resultado da epoca 1011 = 35018.63 Epsilon = 0.010
# 97
# 94
# resultado da epoca 1012 = 82231.19 Epsilon = 0.010
# 164
# 55
# resultado da epoca 1013 = 50257.24 Epsilon = 0.010
# 120
# 97
# resultado da epoca 1014 = 53150.02 Epsilon = 0.010
# 112
# 107
# resultado da epoca 1015 = 3745.33 Epsilon = 0.010
# 32
# 52
# resultado da epoca 1016 = 12301.94 Epsilon = 0.010
# 38
# 47
# resultado da epoca 1017 = 7284.63 Epsilon = 0.010
# 57
# 42
# resultado da epoca 1018 = 4435.18 Epsilon = 0.010
# 42
# 50
# resultado da epoca 1019 = 8330.92 Epsilon = 0.010
# 33
# 52
# resultado da epoca 1020 = 6231.03 Epsilon = 0.010
# 37
# 49
# resultado da epoca 1021 = -1203.19 Epsilon = 0.010
# 43
# 67
# resultado da epoca 1022 = 4283.87 Epsilon = 0.010
# 50
# 56
# resultado da epoca 1023 = 153.88 Epsilon = 0.010
# 44
# 60
# resultado da epoca 1024 = 1515.30 Epsilon = 0.010
# 48
# 71
# resultado da epoca 1025 = 3223.11 Epsilon = 0.010
# 50
# 61
# resultado da epoca 1026 = 8727.85 Epsilon = 0.010
# 61
# 51
# resultado da epoca 1027 = 7798.33 Epsilon = 0.010
# 59
# 47
# resultado da epoca 1028 = 8407.28 Epsilon = 0.010
# 61
# 66
# resultado da epoca 1029 = 5173.61 Epsilon = 0.010
# 54
# 60
# resultado da epoca 1030 = 8355.63 Epsilon = 0.010
# 66
# 70
# resultado da epoca 1031 = -1005.51 Epsilon = 0.010
# 53
# 66
# resultado da epoca 1032 = 6616.61 Epsilon = 0.010
# 57
# 63
# resultado da epoca 1033 = 5944.66 Epsilon = 0.010
# 67
# 64
# resultado da epoca 1034 = 6626.27 Epsilon = 0.010
# 64
# 55
# resultado da epoca 1035 = 8652.75 Epsilon = 0.010
# 73
# 60
# resultado da epoca 1036 = 4380.10 Epsilon = 0.010
# 62
# 63
# resultado da epoca 1037 = 4724.80 Epsilon = 0.010
# 66
# 64
# resultado da epoca 1038 = -492.10 Epsilon = 0.010
# 65
# 64
# resultado da epoca 1039 = 9469.06 Epsilon = 0.010
# 63
# 68
# resultado da epoca 1040 = 4586.28 Epsilon = 0.010
# 68
# 65
# resultado da epoca 1041 = 7687.24 Epsilon = 0.010
# 65
# 59
# resultado da epoca 1042 = 13520.09 Epsilon = 0.010
# 63
# 55
# resultado da epoca 1043 = 21388.53 Epsilon = 0.010
# 76
# 64
# resultado da epoca 1044 = 8148.21 Epsilon = 0.010
# 71
# 75
# resultado da epoca 1045 = 8618.93 Epsilon = 0.010
# 66
# 64
# resultado da epoca 1046 = 16100.90 Epsilon = 0.010
# 68
# 56
# resultado da epoca 1047 = 8163.81 Epsilon = 0.010
# 68
# 67
# resultado da epoca 1048 = 11813.78 Epsilon = 0.010
# 72
# 64
# resultado da epoca 1049 = 15390.22 Epsilon = 0.010
# 62
# 69
# 0
# 0
# Melhor resultado diario: 7473.52
