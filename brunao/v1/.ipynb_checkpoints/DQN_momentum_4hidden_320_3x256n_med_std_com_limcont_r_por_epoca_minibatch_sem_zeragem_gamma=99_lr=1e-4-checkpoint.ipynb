# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 4*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.99       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        #model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(modelo.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado) #pega valor que chegou
            target_f[0][acao+2*lim_cont] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7680
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 226,837
# Trainable params: 226,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    reward = 0.
    posicao = 0.
    dp = 0.

    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    
    acao = decisao - 2*lim_cont
    
    if abs(ncont+acao) <= lim_cont:
        return acao, 0 
    else:
        return 0, -20

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    penal = 0
    decisao = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l])
        modelo.state = np.reshape(np.concatenate((modelo.janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        
        acao, penal = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        reward += penal    #penalidade se quiser ficar posicionado mais que o permitido
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l])
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]) 
            
        modelo.next_state = np.reshape(np.concatenate((modelo.prox_janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        modelo.remember(acao, reward, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1104 18:13:19.750930  2340 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -13095.09 Epsilon = 1.000
# 115
# 104
# resultado da epoca 1 = -26818.51 Epsilon = 0.999
# 103
# 116
# resultado da epoca 2 = -39209.79 Epsilon = 0.998
# 90
# 129
# resultado da epoca 3 = -34690.57 Epsilon = 0.997
# 88
# 131
# resultado da epoca 4 = -42195.89 Epsilon = 0.996
# 90
# 129
# resultado da epoca 5 = -29134.44 Epsilon = 0.995
# 102
# 117
# resultado da epoca 6 = -38767.52 Epsilon = 0.994
# 94
# 125
# resultado da epoca 7 = -33779.56 Epsilon = 0.993
# 104
# 115
# resultado da epoca 8 = -29062.29 Epsilon = 0.992
# 93
# 126
# resultado da epoca 9 = -1198.82 Epsilon = 0.991
# 110
# 109
# resultado da epoca 10 = 8045.44 Epsilon = 0.990
# 111
# 108
# resultado da epoca 11 = -26852.73 Epsilon = 0.989
# 104
# 115
# resultado da epoca 12 = -35291.89 Epsilon = 0.988
# 87
# 132
# resultado da epoca 13 = -21723.05 Epsilon = 0.987
# 103
# 116
# resultado da epoca 14 = -34271.12 Epsilon = 0.986
# 99
# 120
# resultado da epoca 15 = -24021.26 Epsilon = 0.985
# 102
# 117
# resultado da epoca 16 = 234.48 Epsilon = 0.984
# 105
# 114
# resultado da epoca 17 = -21578.17 Epsilon = 0.983
# 96
# 123
# resultado da epoca 18 = -11547.17 Epsilon = 0.982
# 104
# 115
# resultado da epoca 19 = -2000.81 Epsilon = 0.981
# 107
# 112
# resultado da epoca 20 = -33772.96 Epsilon = 0.980
# 98
# 121
# resultado da epoca 21 = -18783.93 Epsilon = 0.979
# 95
# 124
# resultado da epoca 22 = -9898.18 Epsilon = 0.978
# 108
# 111
# resultado da epoca 23 = -14331.36 Epsilon = 0.977
# 108
# 111
# resultado da epoca 24 = -23335.81 Epsilon = 0.976
# 92
# 127
# resultado da epoca 25 = -33343.51 Epsilon = 0.975
# 105
# 114
# resultado da epoca 26 = -13628.93 Epsilon = 0.974
# 103
# 116
# resultado da epoca 27 = 13887.32 Epsilon = 0.973
# 114
# 105
# resultado da epoca 28 = 3626.55 Epsilon = 0.972
# 108
# 111
# resultado da epoca 29 = -25707.44 Epsilon = 0.971
# 99
# 120
# resultado da epoca 30 = -69449.67 Epsilon = 0.970
# 77
# 142
# resultado da epoca 31 = -31085.06 Epsilon = 0.969
# 88
# 131
# resultado da epoca 32 = -20984.69 Epsilon = 0.968
# 94
# 125
# resultado da epoca 33 = -10965.96 Epsilon = 0.967
# 101
# 118
# resultado da epoca 34 = -13108.42 Epsilon = 0.966
# 101
# 118
# resultado da epoca 35 = -34109.42 Epsilon = 0.965
# 90
# 129
# resultado da epoca 36 = -39746.18 Epsilon = 0.964
# 96
# 123
# resultado da epoca 37 = -45653.38 Epsilon = 0.963
# 94
# 125
# resultado da epoca 38 = -37848.03 Epsilon = 0.962
# 100
# 119
# resultado da epoca 39 = 5086.52 Epsilon = 0.961
# 111
# 108
# resultado da epoca 40 = -17438.70 Epsilon = 0.960
# 92
# 127
# resultado da epoca 41 = -13193.16 Epsilon = 0.959
# 99
# 120
# resultado da epoca 42 = -19212.46 Epsilon = 0.958
# 97
# 122
# resultado da epoca 43 = -7986.95 Epsilon = 0.957
# 108
# 111
# resultado da epoca 44 = -40840.00 Epsilon = 0.956
# 95
# 124
# resultado da epoca 45 = -37005.49 Epsilon = 0.955
# 95
# 124
# resultado da epoca 46 = -8555.99 Epsilon = 0.954
# 102
# 117
# resultado da epoca 47 = -25076.99 Epsilon = 0.953
# 102
# 117
# resultado da epoca 48 = -9038.66 Epsilon = 0.952
# 109
# 110
# resultado da epoca 49 = -38112.85 Epsilon = 0.951
# 90
# 129
# resultado da epoca 50 = -24960.73 Epsilon = 0.950
# 101
# 118
# resultado da epoca 51 = -39837.17 Epsilon = 0.950
# 96
# 123
# resultado da epoca 52 = 8866.17 Epsilon = 0.949
# 111
# 108
# resultado da epoca 53 = -15981.40 Epsilon = 0.948
# 102
# 117
# resultado da epoca 54 = -31181.87 Epsilon = 0.947
# 99
# 120
# resultado da epoca 55 = -24133.04 Epsilon = 0.946
# 109
# 110
# resultado da epoca 56 = -53070.69 Epsilon = 0.945
# 95
# 124
# resultado da epoca 57 = 5575.68 Epsilon = 0.944
# 113
# 106
# resultado da epoca 58 = -7024.47 Epsilon = 0.943
# 109
# 110
# resultado da epoca 59 = -6355.01 Epsilon = 0.942
# 101
# 118
# resultado da epoca 60 = -42750.48 Epsilon = 0.941
# 87
# 132
# resultado da epoca 61 = -16588.81 Epsilon = 0.940
# 99
# 120
# resultado da epoca 62 = -19656.57 Epsilon = 0.939
# 101
# 118
# resultado da epoca 63 = -15160.91 Epsilon = 0.938
# 102
# 117
# resultado da epoca 64 = -35052.96 Epsilon = 0.937
# 101
# 118
# resultado da epoca 65 = -27701.29 Epsilon = 0.936
# 102
# 117
# resultado da epoca 66 = -14523.50 Epsilon = 0.935
# 104
# 115
# resultado da epoca 67 = -21611.12 Epsilon = 0.934
# 100
# 119
# resultado da epoca 68 = -21816.41 Epsilon = 0.933
# 102
# 117
# resultado da epoca 69 = -18104.97 Epsilon = 0.932
# 111
# 108
# resultado da epoca 70 = -11008.63 Epsilon = 0.931
# 103
# 116
# resultado da epoca 71 = -64135.46 Epsilon = 0.930
# 84
# 135
# resultado da epoca 72 = -27145.90 Epsilon = 0.929
# 111
# 108
# resultado da epoca 73 = -9530.07 Epsilon = 0.928
# 105
# 114
# resultado da epoca 74 = -6123.21 Epsilon = 0.927
# 109
# 110
# resultado da epoca 75 = -28688.93 Epsilon = 0.926
# 96
# 123
# resultado da epoca 76 = -17012.74 Epsilon = 0.925
# 101
# 118
# resultado da epoca 77 = 2746.04 Epsilon = 0.924
# 115
# 104
# resultado da epoca 78 = -21636.57 Epsilon = 0.923
# 106
# 113
# resultado da epoca 79 = -18851.30 Epsilon = 0.922
# 98
# 121
# resultado da epoca 80 = -18129.50 Epsilon = 0.921
# 97
# 122
# resultado da epoca 81 = -21330.75 Epsilon = 0.920
# 106
# 113
# resultado da epoca 82 = 1191.15 Epsilon = 0.919
# 112
# 107
# resultado da epoca 83 = -13904.57 Epsilon = 0.918
# 105
# 114
# resultado da epoca 84 = -25155.39 Epsilon = 0.917
# 96
# 123
# resultado da epoca 85 = -37540.03 Epsilon = 0.916
# 93
# 126
# resultado da epoca 86 = -15599.95 Epsilon = 0.915
# 104
# 115
# resultado da epoca 87 = -25233.21 Epsilon = 0.914
# 96
# 123
# resultado da epoca 88 = -21408.63 Epsilon = 0.913
# 105
# 114
# resultado da epoca 89 = -33945.26 Epsilon = 0.912
# 97
# 122
# resultado da epoca 90 = -12332.98 Epsilon = 0.911
# 102
# 117
# resultado da epoca 91 = -7831.70 Epsilon = 0.910
# 106
# 113
# resultado da epoca 92 = -19571.22 Epsilon = 0.909
# 101
# 118
# resultado da epoca 93 = -21296.41 Epsilon = 0.908
# 104
# 115
# resultado da epoca 94 = -21333.96 Epsilon = 0.907
# 93
# 126
# resultado da epoca 95 = -43161.71 Epsilon = 0.906
# 99
# 120
# resultado da epoca 96 = -38159.40 Epsilon = 0.905
# 96
# 123
# resultado da epoca 97 = -32868.77 Epsilon = 0.904
# 99
# 120
# resultado da epoca 98 = -11957.90 Epsilon = 0.903
# 102
# 117
# resultado da epoca 99 = -35106.41 Epsilon = 0.902
# 88
# 131
# resultado da epoca 100 = -13656.66 Epsilon = 0.901
# 105
# 114
# resultado da epoca 101 = -12084.84 Epsilon = 0.900
# 104
# 115
# resultado da epoca 102 = -15355.14 Epsilon = 0.899
# 98
# 121
# resultado da epoca 103 = -41213.65 Epsilon = 0.898
# 98
# 121
# resultado da epoca 104 = -14393.77 Epsilon = 0.897
# 104
# 115
# resultado da epoca 105 = -25593.15 Epsilon = 0.896
# 95
# 124
# resultado da epoca 106 = -43207.04 Epsilon = 0.895
# 89
# 130
# resultado da epoca 107 = -29628.07 Epsilon = 0.894
# 94
# 125
# resultado da epoca 108 = -25177.61 Epsilon = 0.893
# 101
# 118
# resultado da epoca 109 = -4043.44 Epsilon = 0.892
# 106
# 113
# resultado da epoca 110 = -56474.74 Epsilon = 0.891
# 84
# 135
# resultado da epoca 111 = -25098.81 Epsilon = 0.890
# 93
# 126
# resultado da epoca 112 = -24638.82 Epsilon = 0.889
# 103
# 116
# resultado da epoca 113 = -27583.88 Epsilon = 0.888
# 93
# 126
# resultado da epoca 114 = -21007.18 Epsilon = 0.887
# 99
# 120
# resultado da epoca 115 = 1395.71 Epsilon = 0.886
# 109
# 110
# resultado da epoca 116 = -24883.11 Epsilon = 0.885
# 87
# 132
# resultado da epoca 117 = -24444.28 Epsilon = 0.884
# 104
# 115
# resultado da epoca 118 = 9256.24 Epsilon = 0.883
# 118
# 101
# resultado da epoca 119 = -20795.45 Epsilon = 0.882
# 102
# 117
# resultado da epoca 120 = -33543.67 Epsilon = 0.881
# 94
# 125
# resultado da epoca 121 = -15398.02 Epsilon = 0.880
# 102
# 117
# resultado da epoca 122 = -12109.93 Epsilon = 0.879
# 99
# 120
# resultado da epoca 123 = -10310.06 Epsilon = 0.878
# 102
# 117
# resultado da epoca 124 = -5980.10 Epsilon = 0.877
# 111
# 108
# resultado da epoca 125 = -30599.47 Epsilon = 0.876
# 97
# 122
# resultado da epoca 126 = -15367.61 Epsilon = 0.875
# 107
# 112
# resultado da epoca 127 = -13894.03 Epsilon = 0.874
# 97
# 122
# resultado da epoca 128 = -19404.26 Epsilon = 0.873
# 102
# 117
# resultado da epoca 129 = -36188.88 Epsilon = 0.872
# 95
# 124
# resultado da epoca 130 = -13918.97 Epsilon = 0.871
# 90
# 129
# resultado da epoca 131 = -43458.63 Epsilon = 0.870
# 97
# 122
# resultado da epoca 132 = -20704.37 Epsilon = 0.869
# 97
# 122
# resultado da epoca 133 = -45503.70 Epsilon = 0.868
# 86
# 133
# resultado da epoca 134 = -3227.69 Epsilon = 0.867
# 112
# 107
# resultado da epoca 135 = -12312.42 Epsilon = 0.866
# 106
# 113
# resultado da epoca 136 = -3736.61 Epsilon = 0.865
# 105
# 114
# resultado da epoca 137 = -3328.82 Epsilon = 0.864
# 108
# 111
# resultado da epoca 138 = -39777.85 Epsilon = 0.863
# 102
# 117
# resultado da epoca 139 = -21949.44 Epsilon = 0.862
# 102
# 117
# resultado da epoca 140 = -26060.61 Epsilon = 0.861
# 99
# 120
# resultado da epoca 141 = -17213.42 Epsilon = 0.860
# 109
# 110
# resultado da epoca 142 = -26871.42 Epsilon = 0.859
# 101
# 118
# resultado da epoca 143 = -13215.13 Epsilon = 0.858
# 100
# 119
# resultado da epoca 144 = -28196.15 Epsilon = 0.857
# 93
# 126
# resultado da epoca 145 = -23246.14 Epsilon = 0.856
# 96
# 123
# resultado da epoca 146 = -29945.93 Epsilon = 0.855
# 99
# 120
# resultado da epoca 147 = -18410.92 Epsilon = 0.854
# 104
# 115
# resultado da epoca 148 = -42996.16 Epsilon = 0.853
# 93
# 126
# resultado da epoca 149 = -49732.28 Epsilon = 0.852
# 96
# 123
# resultado da epoca 150 = -7941.36 Epsilon = 0.851
# 109
# 110
# resultado da epoca 151 = -15909.68 Epsilon = 0.851
# 104
# 115
# resultado da epoca 152 = -38438.05 Epsilon = 0.850
# 99
# 120
# resultado da epoca 153 = -11391.47 Epsilon = 0.849
# 105
# 114
# resultado da epoca 154 = -9315.79 Epsilon = 0.848
# 99
# 120
# resultado da epoca 155 = 2623.66 Epsilon = 0.847
# 110
# 109
# resultado da epoca 156 = -16734.18 Epsilon = 0.846
# 102
# 117
# resultado da epoca 157 = -1335.56 Epsilon = 0.845
# 113
# 106
# resultado da epoca 158 = 2092.33 Epsilon = 0.844
# 107
# 112
# resultado da epoca 159 = 8309.22 Epsilon = 0.843
# 111
# 108
# resultado da epoca 160 = 3699.09 Epsilon = 0.842
# 110
# 109
# resultado da epoca 161 = 8134.22 Epsilon = 0.841
# 96
# 123
# resultado da epoca 162 = -26275.23 Epsilon = 0.840
# 104
# 115
# resultado da epoca 163 = -32405.68 Epsilon = 0.839
# 92
# 127
# resultado da epoca 164 = -14401.88 Epsilon = 0.838
# 108
# 111
# resultado da epoca 165 = -1936.47 Epsilon = 0.837
# 115
# 104
# resultado da epoca 166 = -20000.48 Epsilon = 0.836
# 100
# 119
# resultado da epoca 167 = -33857.19 Epsilon = 0.835
# 92
# 127
# resultado da epoca 168 = -30099.70 Epsilon = 0.834
# 89
# 130
# resultado da epoca 169 = -18758.11 Epsilon = 0.833
# 99
# 120
# resultado da epoca 170 = -7954.07 Epsilon = 0.832
# 110
# 109
# resultado da epoca 171 = -32070.29 Epsilon = 0.831
# 86
# 133
# resultado da epoca 172 = -8209.74 Epsilon = 0.830
# 97
# 122
# resultado da epoca 173 = 4947.34 Epsilon = 0.829
# 108
# 111
# resultado da epoca 174 = -21112.29 Epsilon = 0.828
# 99
# 120
# resultado da epoca 175 = -23845.01 Epsilon = 0.827
# 99
# 120
# resultado da epoca 176 = -14796.87 Epsilon = 0.826
# 100
# 119
# resultado da epoca 177 = -28342.42 Epsilon = 0.825
# 103
# 116
# resultado da epoca 178 = -12159.40 Epsilon = 0.824
# 94
# 125
# resultado da epoca 179 = -2384.14 Epsilon = 0.823
# 114
# 105
# resultado da epoca 180 = -23154.22 Epsilon = 0.822
# 105
# 114
# resultado da epoca 181 = -22314.62 Epsilon = 0.821
# 100
# 119
# resultado da epoca 182 = -22200.92 Epsilon = 0.820
# 102
# 117
# resultado da epoca 183 = -6904.65 Epsilon = 0.819
# 111
# 108
# resultado da epoca 184 = -8673.69 Epsilon = 0.818
# 102
# 117
# resultado da epoca 185 = -58694.76 Epsilon = 0.817
# 92
# 127
# resultado da epoca 186 = -51960.71 Epsilon = 0.816
# 83
# 136
# resultado da epoca 187 = -3471.46 Epsilon = 0.815
# 107
# 112
# resultado da epoca 188 = -16407.17 Epsilon = 0.814
# 109
# 110
# resultado da epoca 189 = -9204.91 Epsilon = 0.813
# 104
# 115
# resultado da epoca 190 = -50231.09 Epsilon = 0.812
# 96
# 123
# resultado da epoca 191 = -49024.68 Epsilon = 0.811
# 88
# 131
# resultado da epoca 192 = -28237.64 Epsilon = 0.810
# 98
# 121
# resultado da epoca 193 = -18269.01 Epsilon = 0.809
# 99
# 120
# resultado da epoca 194 = -30299.71 Epsilon = 0.808
# 91
# 128
# resultado da epoca 195 = -26477.49 Epsilon = 0.807
# 87
# 132
# resultado da epoca 196 = -17206.87 Epsilon = 0.806
# 105
# 114
# resultado da epoca 197 = -14537.00 Epsilon = 0.805
# 98
# 121
# resultado da epoca 198 = -12776.40 Epsilon = 0.804
# 100
# 119
# resultado da epoca 199 = -44307.27 Epsilon = 0.803
# 98
# 121
# resultado da epoca 200 = -42780.13 Epsilon = 0.802
# 94
# 125
# resultado da epoca 201 = -22558.80 Epsilon = 0.801
# 109
# 110
# resultado da epoca 202 = -19162.45 Epsilon = 0.800
# 104
# 115
# resultado da epoca 203 = -26636.09 Epsilon = 0.799
# 99
# 120
# resultado da epoca 204 = -24939.77 Epsilon = 0.798
# 97
# 122
# resultado da epoca 205 = -4340.67 Epsilon = 0.797
# 107
# 112
# resultado da epoca 206 = -28924.44 Epsilon = 0.796
# 97
# 122
# resultado da epoca 207 = -31374.06 Epsilon = 0.795
# 100
# 119
# resultado da epoca 208 = -28469.31 Epsilon = 0.794
# 102
# 117
# resultado da epoca 209 = -55920.55 Epsilon = 0.793
# 87
# 132
# resultado da epoca 210 = -23837.77 Epsilon = 0.792
# 112
# 107
# resultado da epoca 211 = -23389.74 Epsilon = 0.791
# 101
# 118
# resultado da epoca 212 = -24944.35 Epsilon = 0.790
# 93
# 126
# resultado da epoca 213 = -27346.33 Epsilon = 0.789
# 93
# 126
# resultado da epoca 214 = -28519.02 Epsilon = 0.788
# 98
# 121
# resultado da epoca 215 = -24812.83 Epsilon = 0.787
# 101
# 118
# resultado da epoca 216 = -40269.27 Epsilon = 0.786
# 90
# 129
# resultado da epoca 217 = -47836.07 Epsilon = 0.785
# 94
# 125
# resultado da epoca 218 = -29815.93 Epsilon = 0.784
# 93
# 126
# resultado da epoca 219 = -52865.36 Epsilon = 0.783
# 97
# 122
# resultado da epoca 220 = -33903.09 Epsilon = 0.782
# 100
# 119
# resultado da epoca 221 = -34079.68 Epsilon = 0.781
# 101
# 118
# resultado da epoca 222 = -18460.61 Epsilon = 0.780
# 101
# 118
# resultado da epoca 223 = -34765.38 Epsilon = 0.779
# 89
# 130
# resultado da epoca 224 = -16351.51 Epsilon = 0.778
# 95
# 124
# resultado da epoca 225 = -16016.14 Epsilon = 0.777
# 99
# 120
# resultado da epoca 226 = -40632.32 Epsilon = 0.776
# 95
# 124
# resultado da epoca 227 = -49955.57 Epsilon = 0.775
# 95
# 124
# resultado da epoca 228 = -22948.61 Epsilon = 0.774
# 95
# 124
# resultado da epoca 229 = -18653.14 Epsilon = 0.773
# 100
# 119
# resultado da epoca 230 = -36815.03 Epsilon = 0.772
# 98
# 121
# resultado da epoca 231 = -13823.87 Epsilon = 0.771
# 109
# 110
# resultado da epoca 232 = -30921.56 Epsilon = 0.770
# 94
# 125
# resultado da epoca 233 = -19216.05 Epsilon = 0.769
# 104
# 115
# resultado da epoca 234 = -28508.00 Epsilon = 0.768
# 99
# 120
# resultado da epoca 235 = -15575.42 Epsilon = 0.767
# 101
# 118
# resultado da epoca 236 = -27483.40 Epsilon = 0.766
# 97
# 122
# resultado da epoca 237 = -49164.07 Epsilon = 0.765
# 87
# 132
# resultado da epoca 238 = -58041.43 Epsilon = 0.764
# 89
# 130
# resultado da epoca 239 = -39394.87 Epsilon = 0.763
# 91
# 128
# resultado da epoca 240 = -32369.32 Epsilon = 0.762
# 95
# 124
# resultado da epoca 241 = -39175.31 Epsilon = 0.761
# 94
# 125
# resultado da epoca 242 = -9635.78 Epsilon = 0.760
# 108
# 111
# resultado da epoca 243 = -38785.34 Epsilon = 0.759
# 97
# 122
# resultado da epoca 244 = -31475.87 Epsilon = 0.758
# 93
# 126
# resultado da epoca 245 = -18991.94 Epsilon = 0.757
# 105
# 114
# resultado da epoca 246 = -20109.71 Epsilon = 0.756
# 98
# 121
# resultado da epoca 247 = -19625.78 Epsilon = 0.755
# 96
# 123
# resultado da epoca 248 = -34586.21 Epsilon = 0.754
# 99
# 120
# resultado da epoca 249 = -48379.35 Epsilon = 0.753
# 86
# 133
# resultado da epoca 250 = -36876.29 Epsilon = 0.752
# 98
# 121
# resultado da epoca 251 = -44807.85 Epsilon = 0.752
# 94
# 125
# resultado da epoca 252 = -26576.46 Epsilon = 0.751
# 99
# 120
# resultado da epoca 253 = -30842.22 Epsilon = 0.750
# 91
# 128
# resultado da epoca 254 = 1665.18 Epsilon = 0.749
# 113
# 106
# resultado da epoca 255 = -12323.41 Epsilon = 0.748
# 104
# 115
# resultado da epoca 256 = -38695.70 Epsilon = 0.747
# 95
# 124
# resultado da epoca 257 = -32947.36 Epsilon = 0.746
# 89
# 130
# resultado da epoca 258 = -1676.10 Epsilon = 0.745
# 107
# 112
# resultado da epoca 259 = -26107.93 Epsilon = 0.744
# 105
# 114
# resultado da epoca 260 = -36190.14 Epsilon = 0.743
# 96
# 123
# resultado da epoca 261 = -26002.39 Epsilon = 0.742
# 98
# 121
# resultado da epoca 262 = -48158.20 Epsilon = 0.741
# 95
# 124
# resultado da epoca 263 = -28471.69 Epsilon = 0.740
# 103
# 116
# resultado da epoca 264 = -15711.68 Epsilon = 0.739
# 101
# 118
# resultado da epoca 265 = -69385.26 Epsilon = 0.738
# 82
# 137
# resultado da epoca 266 = -52070.84 Epsilon = 0.737
# 103
# 116
# resultado da epoca 267 = -72080.41 Epsilon = 0.736
# 90
# 129
# resultado da epoca 268 = -23098.95 Epsilon = 0.735
# 100
# 119
# resultado da epoca 269 = -39793.23 Epsilon = 0.734
# 100
# 119
# resultado da epoca 270 = -31363.44 Epsilon = 0.733
# 94
# 125
# resultado da epoca 271 = -28822.48 Epsilon = 0.732
# 101
# 118
# resultado da epoca 272 = -30136.56 Epsilon = 0.731
# 100
# 119
# resultado da epoca 273 = -26135.62 Epsilon = 0.730
# 103
# 116
# resultado da epoca 274 = -20766.54 Epsilon = 0.729
# 102
# 117
# resultado da epoca 275 = -5831.80 Epsilon = 0.728
# 106
# 113
# resultado da epoca 276 = -21923.79 Epsilon = 0.727
# 95
# 124
# resultado da epoca 277 = -15401.08 Epsilon = 0.726
# 104
# 115
# resultado da epoca 278 = -16896.93 Epsilon = 0.725
# 100
# 119
# resultado da epoca 279 = -30413.09 Epsilon = 0.724
# 103
# 116
# resultado da epoca 280 = -19418.40 Epsilon = 0.723
# 105
# 114
# resultado da epoca 281 = -31259.05 Epsilon = 0.722
# 93
# 126
# resultado da epoca 282 = -30937.51 Epsilon = 0.721
# 96
# 123
# resultado da epoca 283 = -48112.31 Epsilon = 0.720
# 95
# 124
# resultado da epoca 284 = -39962.69 Epsilon = 0.719
# 91
# 128
# resultado da epoca 285 = -36353.94 Epsilon = 0.718
# 89
# 130
# resultado da epoca 286 = -35044.46 Epsilon = 0.717
# 99
# 120
# resultado da epoca 287 = -45656.46 Epsilon = 0.716
# 90
# 129
# resultado da epoca 288 = -34223.64 Epsilon = 0.715
# 92
# 127
# resultado da epoca 289 = -42391.30 Epsilon = 0.714
# 93
# 126
# resultado da epoca 290 = -26736.35 Epsilon = 0.713
# 93
# 126
# resultado da epoca 291 = -55328.46 Epsilon = 0.712
# 98
# 121
# resultado da epoca 292 = -21149.71 Epsilon = 0.711
# 103
# 116
# resultado da epoca 293 = -44389.28 Epsilon = 0.710
# 92
# 127
# resultado da epoca 294 = -40073.90 Epsilon = 0.709
# 97
# 122
# resultado da epoca 295 = -28643.35 Epsilon = 0.708
# 101
# 118
# resultado da epoca 296 = -39110.74 Epsilon = 0.707
# 94
# 125
# resultado da epoca 297 = -11598.93 Epsilon = 0.706
# 108
# 111
# resultado da epoca 298 = -29964.71 Epsilon = 0.705
# 100
# 119
# resultado da epoca 299 = -49567.98 Epsilon = 0.704
# 93
# 126
# resultado da epoca 300 = -26110.09 Epsilon = 0.703
# 92
# 127
# resultado da epoca 301 = -22228.57 Epsilon = 0.702
# 99
# 120
# resultado da epoca 302 = -45609.01 Epsilon = 0.701
# 85
# 134
# resultado da epoca 303 = -14832.76 Epsilon = 0.700
# 109
# 110
# resultado da epoca 304 = -40585.28 Epsilon = 0.699
# 88
# 131
# resultado da epoca 305 = -25667.10 Epsilon = 0.698
# 107
# 112
# resultado da epoca 306 = -32150.27 Epsilon = 0.697
# 104
# 115
# resultado da epoca 307 = -15475.89 Epsilon = 0.696
# 106
# 113
# resultado da epoca 308 = -33948.26 Epsilon = 0.695
# 105
# 114
# resultado da epoca 309 = -12227.92 Epsilon = 0.694
# 107
# 112
# resultado da epoca 310 = -17317.74 Epsilon = 0.693
# 95
# 124
# resultado da epoca 311 = -14265.98 Epsilon = 0.692
# 102
# 117
# resultado da epoca 312 = -32720.67 Epsilon = 0.691
# 96
# 123
# resultado da epoca 313 = -42305.28 Epsilon = 0.690
# 81
# 138
# resultado da epoca 314 = -17221.64 Epsilon = 0.689
# 97
# 122
# resultado da epoca 315 = -43030.45 Epsilon = 0.688
# 84
# 135
# resultado da epoca 316 = -3620.39 Epsilon = 0.687
# 107
# 112
# resultado da epoca 317 = -42799.00 Epsilon = 0.686
# 91
# 128
# resultado da epoca 318 = -45510.51 Epsilon = 0.685
# 95
# 124
# resultado da epoca 319 = -31719.55 Epsilon = 0.684
# 96
# 123
# resultado da epoca 320 = -29946.23 Epsilon = 0.683
# 96
# 123
# resultado da epoca 321 = -43641.14 Epsilon = 0.682
# 91
# 128
# resultado da epoca 322 = -15631.24 Epsilon = 0.681
# 95
# 124
# resultado da epoca 323 = -42653.61 Epsilon = 0.680
# 100
# 119
# resultado da epoca 324 = -43792.41 Epsilon = 0.679
# 89
# 130
# resultado da epoca 325 = -11037.06 Epsilon = 0.678
# 109
# 110
# resultado da epoca 326 = -25974.98 Epsilon = 0.677
# 107
# 112
# resultado da epoca 327 = -40603.61 Epsilon = 0.676
# 96
# 123
# resultado da epoca 328 = -18087.13 Epsilon = 0.675
# 105
# 114
# resultado da epoca 329 = -6871.79 Epsilon = 0.674
# 107
# 112
# resultado da epoca 330 = -47932.10 Epsilon = 0.673
# 92
# 127
# resultado da epoca 331 = -20548.83 Epsilon = 0.672
# 101
# 118
# resultado da epoca 332 = -19240.01 Epsilon = 0.671
# 109
# 110
# resultado da epoca 333 = -19038.25 Epsilon = 0.670
# 99
# 120
# resultado da epoca 334 = -51443.78 Epsilon = 0.669
# 87
# 132
# resultado da epoca 335 = -21115.28 Epsilon = 0.668
# 96
# 123
# resultado da epoca 336 = -22451.70 Epsilon = 0.667
# 96
# 123
# resultado da epoca 337 = -5041.01 Epsilon = 0.666
# 104
# 115
# resultado da epoca 338 = -15280.58 Epsilon = 0.665
# 110
# 109
# resultado da epoca 339 = -45162.54 Epsilon = 0.664
# 91
# 128
# resultado da epoca 340 = -37711.20 Epsilon = 0.663
# 102
# 117
# resultado da epoca 341 = -1910.19 Epsilon = 0.662
# 109
# 110
# resultado da epoca 342 = -26575.30 Epsilon = 0.661
# 97
# 122
# resultado da epoca 343 = -18877.91 Epsilon = 0.660
# 98
# 121
# resultado da epoca 344 = -33226.55 Epsilon = 0.659
# 96
# 123
# resultado da epoca 345 = -23521.54 Epsilon = 0.658
# 96
# 123
# resultado da epoca 346 = -44098.88 Epsilon = 0.657
# 93
# 126
# resultado da epoca 347 = -42244.23 Epsilon = 0.656
# 84
# 135
# resultado da epoca 348 = -36348.34 Epsilon = 0.655
# 99
# 120
# resultado da epoca 349 = -42991.66 Epsilon = 0.654
# 90
# 129
# resultado da epoca 350 = -37624.04 Epsilon = 0.653
# 92
# 127
# resultado da epoca 351 = -16490.91 Epsilon = 0.653
# 100
# 119
# resultado da epoca 352 = -33005.52 Epsilon = 0.652
# 92
# 127
# resultado da epoca 353 = -25131.25 Epsilon = 0.651
# 97
# 122
# resultado da epoca 354 = -20727.33 Epsilon = 0.650
# 104
# 115
# resultado da epoca 355 = -24026.92 Epsilon = 0.649
# 97
# 122
# resultado da epoca 356 = -47783.33 Epsilon = 0.648
# 88
# 131
# resultado da epoca 357 = -44673.90 Epsilon = 0.647
# 90
# 129
# resultado da epoca 358 = 8675.22 Epsilon = 0.646
# 111
# 108
# resultado da epoca 359 = -21306.50 Epsilon = 0.645
# 88
# 131
# resultado da epoca 360 = -29365.14 Epsilon = 0.644
# 100
# 119
# resultado da epoca 361 = -26998.65 Epsilon = 0.643
# 101
# 118
# resultado da epoca 362 = -18223.74 Epsilon = 0.642
# 108
# 111
# resultado da epoca 363 = -50823.77 Epsilon = 0.641
# 89
# 130
# resultado da epoca 364 = -32333.49 Epsilon = 0.640
# 105
# 114
# resultado da epoca 365 = 2143.74 Epsilon = 0.639
# 114
# 105
# resultado da epoca 366 = -24561.18 Epsilon = 0.638
# 102
# 117
# resultado da epoca 367 = -35131.44 Epsilon = 0.637
# 100
# 119
# resultado da epoca 368 = -31932.87 Epsilon = 0.636
# 96
# 123
# resultado da epoca 369 = -19379.48 Epsilon = 0.635
# 102
# 117
# resultado da epoca 370 = -26757.63 Epsilon = 0.634
# 98
# 121
# resultado da epoca 371 = -31332.92 Epsilon = 0.633
# 103
# 116
# resultado da epoca 372 = -12847.51 Epsilon = 0.632
# 108
# 111
# resultado da epoca 373 = -10462.99 Epsilon = 0.631
# 103
# 116
# resultado da epoca 374 = -28241.66 Epsilon = 0.630
# 97
# 122
# resultado da epoca 375 = -35522.57 Epsilon = 0.629
# 88
# 131
# resultado da epoca 376 = -40996.72 Epsilon = 0.628
# 92
# 127
# resultado da epoca 377 = -22193.97 Epsilon = 0.627
# 101
# 118
# resultado da epoca 378 = -40191.73 Epsilon = 0.626
# 97
# 122
# resultado da epoca 379 = -33091.52 Epsilon = 0.625
# 97
# 122
# resultado da epoca 380 = -5686.94 Epsilon = 0.624
# 100
# 119
# resultado da epoca 381 = -13765.68 Epsilon = 0.623
# 101
# 118
# resultado da epoca 382 = -22889.88 Epsilon = 0.622
# 103
# 116
# resultado da epoca 383 = -35757.30 Epsilon = 0.621
# 97
# 122
# resultado da epoca 384 = -25143.75 Epsilon = 0.620
# 99
# 120
# resultado da epoca 385 = -789.19 Epsilon = 0.619
# 116
# 103
# resultado da epoca 386 = -22595.80 Epsilon = 0.618
# 94
# 125
# resultado da epoca 387 = -47420.45 Epsilon = 0.617
# 90
# 129
# resultado da epoca 388 = -24670.46 Epsilon = 0.616
# 106
# 113
# resultado da epoca 389 = -28173.19 Epsilon = 0.615
# 103
# 116
# resultado da epoca 390 = -33653.22 Epsilon = 0.614
# 100
# 119
# resultado da epoca 391 = -19995.30 Epsilon = 0.613
# 96
# 123
# resultado da epoca 392 = -45339.17 Epsilon = 0.612
# 86
# 133
# resultado da epoca 393 = -38772.28 Epsilon = 0.611
# 92
# 127
# resultado da epoca 394 = -25841.73 Epsilon = 0.610
# 98
# 121
# resultado da epoca 395 = -13377.00 Epsilon = 0.609
# 100
# 119
# resultado da epoca 396 = -17025.05 Epsilon = 0.608
# 98
# 121
# resultado da epoca 397 = -29470.60 Epsilon = 0.607
# 100
# 119
# resultado da epoca 398 = -23371.11 Epsilon = 0.606
# 93
# 126
# resultado da epoca 399 = -25387.42 Epsilon = 0.605
# 93
# 126
# resultado da epoca 400 = -5235.41 Epsilon = 0.604
# 110
# 109
# resultado da epoca 401 = -26958.46 Epsilon = 0.603
# 96
# 123
# resultado da epoca 402 = -55657.81 Epsilon = 0.602
# 81
# 138
# resultado da epoca 403 = -27414.23 Epsilon = 0.601
# 99
# 120
# resultado da epoca 404 = -24937.54 Epsilon = 0.600
# 102
# 117
# resultado da epoca 405 = -11107.27 Epsilon = 0.599
# 104
# 115
# resultado da epoca 406 = -37962.55 Epsilon = 0.598
# 98
# 121
# resultado da epoca 407 = -16184.37 Epsilon = 0.597
# 102
# 117
# resultado da epoca 408 = -54142.96 Epsilon = 0.596
# 87
# 132
# resultado da epoca 409 = -19086.05 Epsilon = 0.595
# 101
# 118
# resultado da epoca 410 = -11066.78 Epsilon = 0.594
# 103
# 116
# resultado da epoca 411 = -18712.61 Epsilon = 0.593
# 100
# 119
# resultado da epoca 412 = -12531.16 Epsilon = 0.592
# 108
# 111
# resultado da epoca 413 = -2602.03 Epsilon = 0.591
# 105
# 114
# resultado da epoca 414 = 5389.94 Epsilon = 0.590
# 114
# 105
# resultado da epoca 415 = -15586.68 Epsilon = 0.589
# 101
# 118
# resultado da epoca 416 = -19291.72 Epsilon = 0.588
# 95
# 124
# resultado da epoca 417 = 4851.65 Epsilon = 0.587
# 105
# 114
# resultado da epoca 418 = -21082.86 Epsilon = 0.586
# 91
# 128
# resultado da epoca 419 = -57151.44 Epsilon = 0.585
# 83
# 136
# resultado da epoca 420 = -29594.65 Epsilon = 0.584
# 85
# 134
# resultado da epoca 421 = -19197.63 Epsilon = 0.583
# 108
# 111
# resultado da epoca 422 = 5098.45 Epsilon = 0.582
# 119
# 100
# resultado da epoca 423 = -23688.52 Epsilon = 0.581
# 101
# 118
# resultado da epoca 424 = -8272.87 Epsilon = 0.580
# 105
# 114
# resultado da epoca 425 = -9424.75 Epsilon = 0.579
# 98
# 121
# resultado da epoca 426 = -26089.63 Epsilon = 0.578
# 98
# 121
# resultado da epoca 427 = -7052.29 Epsilon = 0.577
# 107
# 112
# resultado da epoca 428 = -36189.38 Epsilon = 0.576
# 99
# 120
# resultado da epoca 429 = 2307.60 Epsilon = 0.575
# 109
# 110
# resultado da epoca 430 = -21767.78 Epsilon = 0.574
# 98
# 121
# resultado da epoca 431 = -23832.43 Epsilon = 0.573
# 106
# 113
# resultado da epoca 432 = -28745.35 Epsilon = 0.572
# 98
# 121
# resultado da epoca 433 = -15481.39 Epsilon = 0.571
# 103
# 116
# resultado da epoca 434 = 773.82 Epsilon = 0.570
# 107
# 112
# resultado da epoca 435 = -17148.84 Epsilon = 0.569
# 108
# 111
# resultado da epoca 436 = -29583.90 Epsilon = 0.568
# 89
# 130
# resultado da epoca 437 = -32901.93 Epsilon = 0.567
# 91
# 128
# resultado da epoca 438 = -23899.85 Epsilon = 0.566
# 106
# 113
# resultado da epoca 439 = -16852.91 Epsilon = 0.565
# 106
# 113
# resultado da epoca 440 = -28139.81 Epsilon = 0.564
# 104
# 115
# resultado da epoca 441 = 10174.31 Epsilon = 0.563
# 113
# 106
# resultado da epoca 442 = -26929.08 Epsilon = 0.562
# 97
# 122
# resultado da epoca 443 = -7356.92 Epsilon = 0.561
# 108
# 111
# resultado da epoca 444 = 3947.53 Epsilon = 0.560
# 103
# 116
# resultado da epoca 445 = -27346.82 Epsilon = 0.559
# 94
# 125
# resultado da epoca 446 = -45739.08 Epsilon = 0.558
# 96
# 123
# resultado da epoca 447 = -1769.22 Epsilon = 0.557
# 100
# 119
# resultado da epoca 448 = -26457.84 Epsilon = 0.556
# 100
# 119
# resultado da epoca 449 = 3358.73 Epsilon = 0.555
# 108
# 111
# resultado da epoca 450 = -4455.31 Epsilon = 0.554
# 110
# 109
# resultado da epoca 451 = -23207.87 Epsilon = 0.554
# 101
# 118
# resultado da epoca 452 = -40532.91 Epsilon = 0.553
# 99
# 120
# resultado da epoca 453 = -28367.45 Epsilon = 0.552
# 102
# 117
# resultado da epoca 454 = -35815.68 Epsilon = 0.551
# 104
# 115
# resultado da epoca 455 = -29815.04 Epsilon = 0.550
# 103
# 116
# resultado da epoca 456 = -21410.97 Epsilon = 0.549
# 96
# 123
# resultado da epoca 457 = -5874.88 Epsilon = 0.548
# 110
# 109
# resultado da epoca 458 = -22833.95 Epsilon = 0.547
# 106
# 113
# resultado da epoca 459 = -46011.11 Epsilon = 0.546
# 91
# 128
# resultado da epoca 460 = -24470.99 Epsilon = 0.545
# 109
# 110
# resultado da epoca 461 = -4850.04 Epsilon = 0.544
# 100
# 119
# resultado da epoca 462 = -8371.76 Epsilon = 0.543
# 109
# 110
# resultado da epoca 463 = 13543.33 Epsilon = 0.542
# 110
# 109
# resultado da epoca 464 = -27874.42 Epsilon = 0.541
# 94
# 125
# resultado da epoca 465 = -1237.17 Epsilon = 0.540
# 101
# 118
# resultado da epoca 466 = -10389.03 Epsilon = 0.539
# 106
# 113
# resultado da epoca 467 = 9232.55 Epsilon = 0.538
# 122
# 97
# resultado da epoca 468 = -11034.31 Epsilon = 0.537
# 103
# 116
# resultado da epoca 469 = -12425.79 Epsilon = 0.536
# 103
# 116
# resultado da epoca 470 = -14040.04 Epsilon = 0.535
# 102
# 117
# resultado da epoca 471 = -20042.56 Epsilon = 0.534
# 92
# 127
# resultado da epoca 472 = -9208.54 Epsilon = 0.533
# 113
# 106
# resultado da epoca 473 = -2083.50 Epsilon = 0.532
# 107
# 112
# resultado da epoca 474 = -11087.76 Epsilon = 0.531
# 105
# 114
# resultado da epoca 475 = 9075.61 Epsilon = 0.530
# 115
# 104
# resultado da epoca 476 = 7133.88 Epsilon = 0.529
# 102
# 117
# resultado da epoca 477 = -17372.88 Epsilon = 0.528
# 98
# 121
# resultado da epoca 478 = 9994.79 Epsilon = 0.527
# 112
# 107
# resultado da epoca 479 = 4461.20 Epsilon = 0.526
# 107
# 112
# resultado da epoca 480 = -29495.58 Epsilon = 0.525
# 93
# 126
# resultado da epoca 481 = -2031.02 Epsilon = 0.524
# 116
# 103
# resultado da epoca 482 = -22757.15 Epsilon = 0.523
# 105
# 114
# resultado da epoca 483 = -7079.74 Epsilon = 0.522
# 106
# 113
# resultado da epoca 484 = -7665.04 Epsilon = 0.521
# 113
# 106
# resultado da epoca 485 = -30717.52 Epsilon = 0.520
# 105
# 114
# resultado da epoca 486 = -49204.83 Epsilon = 0.519
# 86
# 133
# resultado da epoca 487 = -27924.61 Epsilon = 0.518
# 95
# 124
# resultado da epoca 488 = 3699.28 Epsilon = 0.517
# 112
# 107
# resultado da epoca 489 = -8052.96 Epsilon = 0.516
# 103
# 116
# resultado da epoca 490 = -3626.50 Epsilon = 0.515
# 108
# 111
# resultado da epoca 491 = -13030.93 Epsilon = 0.514
# 105
# 114
# resultado da epoca 492 = -9142.01 Epsilon = 0.513
# 111
# 108
# resultado da epoca 493 = -36659.03 Epsilon = 0.512
# 94
# 125
# resultado da epoca 494 = -19710.73 Epsilon = 0.511
# 103
# 116
# resultado da epoca 495 = -15130.82 Epsilon = 0.510
# 110
# 109
# resultado da epoca 496 = -13858.04 Epsilon = 0.509
# 108
# 111
# resultado da epoca 497 = -40142.49 Epsilon = 0.508
# 90
# 129
# resultado da epoca 498 = -1068.74 Epsilon = 0.507
# 103
# 116
# resultado da epoca 499 = -15746.49 Epsilon = 0.506
# 111
# 108
# resultado da epoca 500 = -24826.95 Epsilon = 0.505
# 105
# 114
# resultado da epoca 501 = -47366.90 Epsilon = 0.504
# 100
# 119
# resultado da epoca 502 = -9930.12 Epsilon = 0.503
# 114
# 105
# resultado da epoca 503 = -27719.55 Epsilon = 0.502
# 106
# 113
# resultado da epoca 504 = 6528.16 Epsilon = 0.501
# 119
# 100
# resultado da epoca 505 = -21644.55 Epsilon = 0.500
# 105
# 114
# resultado da epoca 506 = -17979.90 Epsilon = 0.499
# 107
# 112
# resultado da epoca 507 = -35948.81 Epsilon = 0.498
# 94
# 125
# resultado da epoca 508 = -43755.69 Epsilon = 0.497
# 84
# 135
# resultado da epoca 509 = -5127.10 Epsilon = 0.496
# 106
# 113
# resultado da epoca 510 = -6801.02 Epsilon = 0.495
# 111
# 108
# resultado da epoca 511 = -31864.35 Epsilon = 0.494
# 95
# 124
# resultado da epoca 512 = -11623.13 Epsilon = 0.493
# 106
# 113
# resultado da epoca 513 = -31159.86 Epsilon = 0.492
# 91
# 128
# resultado da epoca 514 = -26510.03 Epsilon = 0.491
# 96
# 123
# resultado da epoca 515 = -30100.61 Epsilon = 0.490
# 92
# 127
# resultado da epoca 516 = -31477.82 Epsilon = 0.489
# 98
# 121
# resultado da epoca 517 = -33409.41 Epsilon = 0.488
# 94
# 125
# resultado da epoca 518 = -45772.99 Epsilon = 0.487
# 87
# 132
# resultado da epoca 519 = 7037.06 Epsilon = 0.486
# 111
# 108
# resultado da epoca 520 = -4820.63 Epsilon = 0.485
# 106
# 113
# resultado da epoca 521 = -1518.06 Epsilon = 0.484
# 111
# 108
# resultado da epoca 522 = -5664.86 Epsilon = 0.483
# 97
# 122
# resultado da epoca 523 = -18990.06 Epsilon = 0.482
# 98
# 121
# resultado da epoca 524 = -15057.02 Epsilon = 0.481
# 101
# 118
# resultado da epoca 525 = -2850.54 Epsilon = 0.480
# 102
# 117
# resultado da epoca 526 = 8315.87 Epsilon = 0.479
# 116
# 103
# resultado da epoca 527 = -17261.91 Epsilon = 0.478
# 98
# 121
# resultado da epoca 528 = -7212.36 Epsilon = 0.477
# 109
# 110
# resultado da epoca 529 = -27001.56 Epsilon = 0.476
# 95
# 124
# resultado da epoca 530 = -3702.06 Epsilon = 0.475
# 101
# 118
# resultado da epoca 531 = -14061.51 Epsilon = 0.474
# 100
# 119
# resultado da epoca 532 = -13194.04 Epsilon = 0.473
# 105
# 114
# resultado da epoca 533 = -16296.11 Epsilon = 0.472
# 100
# 119
# resultado da epoca 534 = 6371.17 Epsilon = 0.471
# 112
# 107
# resultado da epoca 535 = 12596.60 Epsilon = 0.470
# 116
# 103
# resultado da epoca 536 = -10120.92 Epsilon = 0.469
# 115
# 104
# resultado da epoca 537 = -16199.73 Epsilon = 0.468
# 101
# 118
# resultado da epoca 538 = -26983.14 Epsilon = 0.467
# 94
# 125
# resultado da epoca 539 = -16928.76 Epsilon = 0.466
# 102
# 117
# resultado da epoca 540 = -5480.36 Epsilon = 0.465
# 97
# 122
# resultado da epoca 541 = -15575.68 Epsilon = 0.464
# 109
# 110
# resultado da epoca 542 = -10612.58 Epsilon = 0.463
# 108
# 111
# resultado da epoca 543 = -17866.49 Epsilon = 0.462
# 101
# 118
# resultado da epoca 544 = -30162.98 Epsilon = 0.461
# 97
# 122
# resultado da epoca 545 = -24827.10 Epsilon = 0.460
# 102
# 117
# resultado da epoca 546 = 5254.08 Epsilon = 0.459
# 112
# 107
# resultado da epoca 547 = -13115.98 Epsilon = 0.458
# 116
# 103
# resultado da epoca 548 = -24791.59 Epsilon = 0.457
# 98
# 121
# resultado da epoca 549 = -17742.17 Epsilon = 0.456
# 105
# 114
# resultado da epoca 550 = -5458.22 Epsilon = 0.455
# 108
# 111
# resultado da epoca 551 = -7127.54 Epsilon = 0.455
# 108
# 111
# resultado da epoca 552 = -21092.45 Epsilon = 0.454
# 107
# 112
# resultado da epoca 553 = -897.73 Epsilon = 0.453
# 107
# 112
# resultado da epoca 554 = -5071.41 Epsilon = 0.452
# 104
# 115
# resultado da epoca 555 = -8283.80 Epsilon = 0.451
# 102
# 117
# resultado da epoca 556 = -31588.97 Epsilon = 0.450
# 94
# 125
# resultado da epoca 557 = -25280.44 Epsilon = 0.449
# 91
# 128
# resultado da epoca 558 = -30121.52 Epsilon = 0.448
# 100
# 119
# resultado da epoca 559 = -6041.45 Epsilon = 0.447
# 93
# 126
# resultado da epoca 560 = -3430.28 Epsilon = 0.446
# 110
# 109
# resultado da epoca 561 = -51691.72 Epsilon = 0.445
# 89
# 130
# resultado da epoca 562 = -22682.12 Epsilon = 0.444
# 99
# 120
# resultado da epoca 563 = -9506.92 Epsilon = 0.443
# 115
# 104
# resultado da epoca 564 = -10692.79 Epsilon = 0.442
# 111
# 108
# resultado da epoca 565 = -20220.99 Epsilon = 0.441
# 98
# 121
# resultado da epoca 566 = -16562.45 Epsilon = 0.440
# 103
# 116
# resultado da epoca 567 = -20420.47 Epsilon = 0.439
# 103
# 116
# resultado da epoca 568 = -28969.60 Epsilon = 0.438
# 95
# 124
# resultado da epoca 569 = -11241.00 Epsilon = 0.437
# 113
# 106
# resultado da epoca 570 = -12153.86 Epsilon = 0.436
# 107
# 112
# resultado da epoca 571 = -20142.24 Epsilon = 0.435
# 94
# 125
# resultado da epoca 572 = -5464.24 Epsilon = 0.434
# 105
# 114
# resultado da epoca 573 = 2759.89 Epsilon = 0.433
# 111
# 108
# resultado da epoca 574 = -57452.36 Epsilon = 0.432
# 88
# 131
# resultado da epoca 575 = -48522.50 Epsilon = 0.431
# 90
# 129
# resultado da epoca 576 = -1294.96 Epsilon = 0.430
# 110
# 109
# resultado da epoca 577 = -2802.58 Epsilon = 0.429
# 101
# 118
# resultado da epoca 578 = -21727.48 Epsilon = 0.428
# 98
# 121
# resultado da epoca 579 = -898.25 Epsilon = 0.427
# 106
# 113
# resultado da epoca 580 = -6674.52 Epsilon = 0.426
# 99
# 120
# resultado da epoca 581 = -16522.60 Epsilon = 0.425
# 99
# 120
# resultado da epoca 582 = 11774.70 Epsilon = 0.424
# 115
# 104
# resultado da epoca 583 = -1405.11 Epsilon = 0.423
# 105
# 114
# resultado da epoca 584 = -16981.68 Epsilon = 0.422
# 109
# 110
# resultado da epoca 585 = -6053.65 Epsilon = 0.421
# 108
# 111
# resultado da epoca 586 = -25093.39 Epsilon = 0.420
# 97
# 122
# resultado da epoca 587 = -23905.13 Epsilon = 0.419
# 100
# 119
# resultado da epoca 588 = 871.15 Epsilon = 0.418
# 106
# 113
# resultado da epoca 589 = -1723.43 Epsilon = 0.417
# 109
# 110
# resultado da epoca 590 = -21122.84 Epsilon = 0.416
# 104
# 115
# resultado da epoca 591 = -26464.79 Epsilon = 0.415
# 97
# 122
# resultado da epoca 592 = -28829.85 Epsilon = 0.414
# 101
# 118
# resultado da epoca 593 = -20771.48 Epsilon = 0.413
# 112
# 107
# resultado da epoca 594 = -21348.54 Epsilon = 0.412
# 96
# 123
# resultado da epoca 595 = -10482.35 Epsilon = 0.411
# 103
# 116
# resultado da epoca 596 = 2431.80 Epsilon = 0.410
# 112
# 107
# resultado da epoca 597 = -7796.29 Epsilon = 0.409
# 106
# 113
# resultado da epoca 598 = 3694.11 Epsilon = 0.408
# 120
# 99
# resultado da epoca 599 = -9238.74 Epsilon = 0.407
# 114
# 105
# resultado da epoca 600 = -8442.84 Epsilon = 0.406
# 104
# 115
# resultado da epoca 601 = -20423.08 Epsilon = 0.405
# 98
# 121
# resultado da epoca 602 = -15664.72 Epsilon = 0.404
# 103
# 116
# resultado da epoca 603 = -16038.93 Epsilon = 0.403
# 95
# 124
# resultado da epoca 604 = 4102.95 Epsilon = 0.402
# 113
# 106
# resultado da epoca 605 = -13658.28 Epsilon = 0.401
# 100
# 119
# resultado da epoca 606 = -20905.09 Epsilon = 0.400
# 105
# 114
# resultado da epoca 607 = 14644.43 Epsilon = 0.399
# 115
# 104
# resultado da epoca 608 = 4823.00 Epsilon = 0.398
# 113
# 106
# resultado da epoca 609 = -16897.37 Epsilon = 0.397
# 100
# 119
# resultado da epoca 610 = 1570.53 Epsilon = 0.396
# 106
# 113
# resultado da epoca 611 = -20684.63 Epsilon = 0.395
# 94
# 125
# resultado da epoca 612 = -20704.19 Epsilon = 0.394
# 106
# 113
# resultado da epoca 613 = -26979.66 Epsilon = 0.393
# 100
# 119
# resultado da epoca 614 = -13667.35 Epsilon = 0.392
# 103
# 116
# resultado da epoca 615 = -31059.58 Epsilon = 0.391
# 95
# 124
# resultado da epoca 616 = -4463.59 Epsilon = 0.390
# 108
# 111
# resultado da epoca 617 = -25446.59 Epsilon = 0.389
# 94
# 125
# resultado da epoca 618 = -6244.12 Epsilon = 0.388
# 110
# 109
# resultado da epoca 619 = -18.82 Epsilon = 0.387
# 114
# 105
# resultado da epoca 620 = -1906.09 Epsilon = 0.386
# 114
# 105
# resultado da epoca 621 = -2570.44 Epsilon = 0.385
# 106
# 113
# resultado da epoca 622 = 2764.40 Epsilon = 0.384
# 105
# 114
# resultado da epoca 623 = -6847.29 Epsilon = 0.383
# 105
# 114
# resultado da epoca 624 = 13672.61 Epsilon = 0.382
# 117
# 102
# resultado da epoca 625 = -3178.81 Epsilon = 0.381
# 108
# 111
# resultado da epoca 626 = -31538.15 Epsilon = 0.380
# 94
# 125
# resultado da epoca 627 = -12267.92 Epsilon = 0.379
# 97
# 122
# resultado da epoca 628 = -3279.45 Epsilon = 0.378
# 104
# 115
# resultado da epoca 629 = -36979.09 Epsilon = 0.377
# 90
# 129
# resultado da epoca 630 = -7596.67 Epsilon = 0.376
# 96
# 123
# resultado da epoca 631 = -1288.31 Epsilon = 0.375
# 108
# 111
# resultado da epoca 632 = -3713.02 Epsilon = 0.374
# 116
# 103
# resultado da epoca 633 = -9247.94 Epsilon = 0.373
# 105
# 114
# resultado da epoca 634 = 4615.23 Epsilon = 0.372
# 105
# 114
# resultado da epoca 635 = 3043.83 Epsilon = 0.371
# 113
# 106
# resultado da epoca 636 = 7103.69 Epsilon = 0.370
# 110
# 109
# resultado da epoca 637 = -37710.03 Epsilon = 0.369
# 96
# 123
# resultado da epoca 638 = -2245.31 Epsilon = 0.368
# 104
# 115
# resultado da epoca 639 = -3432.70 Epsilon = 0.367
# 102
# 117
# resultado da epoca 640 = -7149.54 Epsilon = 0.366
# 100
# 119
# resultado da epoca 641 = 1372.32 Epsilon = 0.365
# 111
# 108
# resultado da epoca 642 = 8293.81 Epsilon = 0.364
# 116
# 103
# resultado da epoca 643 = 2655.78 Epsilon = 0.363
# 111
# 108
# resultado da epoca 644 = 15420.68 Epsilon = 0.362
# 114
# 105
# resultado da epoca 645 = 1815.87 Epsilon = 0.361
# 108
# 111
# resultado da epoca 646 = -12011.47 Epsilon = 0.360
# 95
# 124
# resultado da epoca 647 = -31389.44 Epsilon = 0.359
# 93
# 126
# resultado da epoca 648 = -10861.78 Epsilon = 0.358
# 106
# 113
# resultado da epoca 649 = 7289.68 Epsilon = 0.357
# 115
# 104
# resultado da epoca 650 = -14756.43 Epsilon = 0.356
# 113
# 106
# resultado da epoca 651 = -12586.66 Epsilon = 0.356
# 106
# 113
# resultado da epoca 652 = -18536.51 Epsilon = 0.355
# 102
# 117
# resultado da epoca 653 = -10981.16 Epsilon = 0.354
# 97
# 122
# resultado da epoca 654 = -19346.10 Epsilon = 0.353
# 99
# 120
# resultado da epoca 655 = -17675.81 Epsilon = 0.352
# 100
# 119
# resultado da epoca 656 = 24131.22 Epsilon = 0.351
# 116
# 103
# resultado da epoca 657 = -9540.77 Epsilon = 0.350
# 94
# 125
# resultado da epoca 658 = -18798.03 Epsilon = 0.349
# 98
# 121
# resultado da epoca 659 = 11021.25 Epsilon = 0.348
# 111
# 108
# resultado da epoca 660 = 2524.97 Epsilon = 0.347
# 112
# 107
# resultado da epoca 661 = 22898.92 Epsilon = 0.346
# 124
# 95
# resultado da epoca 662 = -23260.07 Epsilon = 0.345
# 98
# 121
# resultado da epoca 663 = -2278.43 Epsilon = 0.344
# 116
# 103
# resultado da epoca 664 = -14361.84 Epsilon = 0.343
# 104
# 115
# resultado da epoca 665 = 8518.36 Epsilon = 0.342
# 113
# 106
# resultado da epoca 666 = -18315.26 Epsilon = 0.341
# 99
# 120
# resultado da epoca 667 = -22362.21 Epsilon = 0.340
# 99
# 120
# resultado da epoca 668 = -7946.02 Epsilon = 0.339
# 106
# 113
# resultado da epoca 669 = -5289.81 Epsilon = 0.338
# 108
# 111
# resultado da epoca 670 = -21070.71 Epsilon = 0.337
# 104
# 115
# resultado da epoca 671 = -12872.81 Epsilon = 0.336
# 98
# 121
# resultado da epoca 672 = 3991.50 Epsilon = 0.335
# 111
# 108
# resultado da epoca 673 = -2752.01 Epsilon = 0.334
# 110
# 109
# resultado da epoca 674 = -40683.59 Epsilon = 0.333
# 87
# 132
# resultado da epoca 675 = -28826.46 Epsilon = 0.332
# 94
# 125
# resultado da epoca 676 = -41074.58 Epsilon = 0.331
# 98
# 121
# resultado da epoca 677 = -16391.25 Epsilon = 0.330
# 99
# 120
# resultado da epoca 678 = -29205.60 Epsilon = 0.329
# 98
# 121
# resultado da epoca 679 = -15446.53 Epsilon = 0.328
# 99
# 120
# resultado da epoca 680 = -17919.76 Epsilon = 0.327
# 95
# 124
# resultado da epoca 681 = -23921.89 Epsilon = 0.326
# 95
# 124
# resultado da epoca 682 = 3562.26 Epsilon = 0.325
# 118
# 101
# resultado da epoca 683 = -18283.78 Epsilon = 0.324
# 95
# 124
# resultado da epoca 684 = -15785.27 Epsilon = 0.323
# 95
# 124
# resultado da epoca 685 = -11007.13 Epsilon = 0.322
# 105
# 114
# resultado da epoca 686 = -9986.23 Epsilon = 0.321
# 106
# 113
# resultado da epoca 687 = -13243.01 Epsilon = 0.320
# 105
# 114
# resultado da epoca 688 = -6799.33 Epsilon = 0.319
# 102
# 117
# resultado da epoca 689 = -33007.22 Epsilon = 0.318
# 94
# 125
# resultado da epoca 690 = -9689.32 Epsilon = 0.317
# 104
# 115
# resultado da epoca 691 = -12864.12 Epsilon = 0.316
# 104
# 115
# resultado da epoca 692 = -6372.29 Epsilon = 0.315
# 112
# 107
# resultado da epoca 693 = 5895.61 Epsilon = 0.314
# 105
# 114
# resultado da epoca 694 = -41824.39 Epsilon = 0.313
# 90
# 129
# resultado da epoca 695 = -5354.91 Epsilon = 0.312
# 107
# 112
# resultado da epoca 696 = -10581.34 Epsilon = 0.311
# 111
# 108
# resultado da epoca 697 = -19175.61 Epsilon = 0.310
# 99
# 120
# resultado da epoca 698 = -20230.79 Epsilon = 0.309
# 92
# 127
# resultado da epoca 699 = -2339.11 Epsilon = 0.308
# 103
# 116
# resultado da epoca 700 = -8738.42 Epsilon = 0.307
# 106
# 113
# resultado da epoca 701 = -10983.82 Epsilon = 0.306
# 107
# 112
# resultado da epoca 702 = 3478.23 Epsilon = 0.305
# 113
# 106
# resultado da epoca 703 = -4464.82 Epsilon = 0.304
# 106
# 113
# resultado da epoca 704 = 16737.64 Epsilon = 0.303
# 116
# 103
# resultado da epoca 705 = 11408.95 Epsilon = 0.302
# 103
# 116
# resultado da epoca 706 = 6079.09 Epsilon = 0.301
# 107
# 112
# resultado da epoca 707 = -25659.22 Epsilon = 0.300
# 100
# 119
# resultado da epoca 708 = -2640.83 Epsilon = 0.299
# 105
# 114
# resultado da epoca 709 = -11980.86 Epsilon = 0.298
# 108
# 111
# resultado da epoca 710 = -9449.70 Epsilon = 0.297
# 102
# 117
# resultado da epoca 711 = 11918.08 Epsilon = 0.296
# 101
# 118
# resultado da epoca 712 = -44928.48 Epsilon = 0.295
# 93
# 126
# resultado da epoca 713 = 12557.87 Epsilon = 0.294
# 114
# 105
# resultado da epoca 714 = -36538.51 Epsilon = 0.293
# 93
# 126
# resultado da epoca 715 = -15538.56 Epsilon = 0.292
# 96
# 123
# resultado da epoca 716 = -484.70 Epsilon = 0.291
# 114
# 105
# resultado da epoca 717 = -6918.63 Epsilon = 0.290
# 106
# 113
# resultado da epoca 718 = 11679.61 Epsilon = 0.289
# 113
# 106
# resultado da epoca 719 = -2923.98 Epsilon = 0.288
# 97
# 122
# resultado da epoca 720 = -4600.08 Epsilon = 0.287
# 109
# 110
# resultado da epoca 721 = 6244.34 Epsilon = 0.286
# 111
# 108
# resultado da epoca 722 = -21848.57 Epsilon = 0.285
# 104
# 115
# resultado da epoca 723 = -17078.17 Epsilon = 0.284
# 98
# 121
# resultado da epoca 724 = 13897.68 Epsilon = 0.283
# 114
# 105
# resultado da epoca 725 = -10645.63 Epsilon = 0.282
# 106
# 113
# resultado da epoca 726 = 26992.47 Epsilon = 0.281
# 122
# 97
# resultado da epoca 727 = 5158.29 Epsilon = 0.280
# 113
# 106
# resultado da epoca 728 = 359.39 Epsilon = 0.279
# 105
# 114
# resultado da epoca 729 = 257.89 Epsilon = 0.278
# 103
# 116
# resultado da epoca 730 = 7536.07 Epsilon = 0.277
# 116
# 103
# resultado da epoca 731 = 14106.51 Epsilon = 0.276
# 117
# 102
# resultado da epoca 732 = -1276.36 Epsilon = 0.275
# 109
# 110
# resultado da epoca 733 = -4685.66 Epsilon = 0.274
# 109
# 110
# resultado da epoca 734 = -17303.87 Epsilon = 0.273
# 105
# 114
# resultado da epoca 735 = 15068.17 Epsilon = 0.272
# 111
# 108
# resultado da epoca 736 = -1388.82 Epsilon = 0.271
# 105
# 114
# resultado da epoca 737 = -5782.22 Epsilon = 0.270
# 111
# 108
# resultado da epoca 738 = -24819.82 Epsilon = 0.269
# 92
# 127
# resultado da epoca 739 = 5700.55 Epsilon = 0.268
# 105
# 114
# resultado da epoca 740 = -10459.88 Epsilon = 0.267
# 115
# 104
# resultado da epoca 741 = -13079.97 Epsilon = 0.266
# 109
# 110
# resultado da epoca 742 = -10093.77 Epsilon = 0.265
# 106
# 113
# resultado da epoca 743 = -10389.76 Epsilon = 0.264
# 109
# 110
# resultado da epoca 744 = -23062.86 Epsilon = 0.263
# 106
# 113
# resultado da epoca 745 = -10886.90 Epsilon = 0.262
# 106
# 113
# resultado da epoca 746 = -15867.42 Epsilon = 0.261
# 105
# 114
# resultado da epoca 747 = 9668.49 Epsilon = 0.260
# 119
# 100
# resultado da epoca 748 = 3399.61 Epsilon = 0.259
# 107
# 112
# resultado da epoca 749 = 5767.79 Epsilon = 0.258
# 110
# 109
# resultado da epoca 750 = -8013.92 Epsilon = 0.257
# 108
# 111
# resultado da epoca 751 = -19517.31 Epsilon = 0.257
# 101
# 118
# resultado da epoca 752 = 5796.22 Epsilon = 0.256
# 116
# 103
# resultado da epoca 753 = 739.98 Epsilon = 0.255
# 108
# 111
# resultado da epoca 754 = -857.44 Epsilon = 0.254
# 106
# 113
# resultado da epoca 755 = 10020.17 Epsilon = 0.253
# 100
# 119
# resultado da epoca 756 = -29173.65 Epsilon = 0.252
# 97
# 122
# resultado da epoca 757 = -4483.02 Epsilon = 0.251
# 110
# 109
# resultado da epoca 758 = -7563.24 Epsilon = 0.250
# 102
# 117
# resultado da epoca 759 = -2240.96 Epsilon = 0.249
# 109
# 110
# resultado da epoca 760 = -13954.31 Epsilon = 0.248
# 100
# 119
# resultado da epoca 761 = -6032.79 Epsilon = 0.247
# 100
# 119
# resultado da epoca 762 = -17185.15 Epsilon = 0.246
# 101
# 118
# resultado da epoca 763 = -14519.06 Epsilon = 0.245
# 100
# 119
# resultado da epoca 764 = -18708.79 Epsilon = 0.244
# 92
# 127
# resultado da epoca 765 = -10048.93 Epsilon = 0.243
# 109
# 110
# resultado da epoca 766 = -4589.78 Epsilon = 0.242
# 103
# 116
# resultado da epoca 767 = -15146.81 Epsilon = 0.241
# 99
# 120
# resultado da epoca 768 = 6610.44 Epsilon = 0.240
# 117
# 102
# resultado da epoca 769 = 696.88 Epsilon = 0.239
# 109
# 110
# resultado da epoca 770 = -29537.24 Epsilon = 0.238
# 104
# 115
# resultado da epoca 771 = 246.54 Epsilon = 0.237
# 117
# 102
# resultado da epoca 772 = -3630.94 Epsilon = 0.236
# 109
# 110
# resultado da epoca 773 = -9583.82 Epsilon = 0.235
# 108
# 111
# resultado da epoca 774 = -5083.93 Epsilon = 0.234
# 100
# 119
# resultado da epoca 775 = -4338.07 Epsilon = 0.233
# 112
# 107
# resultado da epoca 776 = 3708.35 Epsilon = 0.232
# 100
# 119
# resultado da epoca 777 = -7066.12 Epsilon = 0.231
# 101
# 118
# resultado da epoca 778 = -9352.04 Epsilon = 0.230
# 107
# 112
# resultado da epoca 779 = -835.24 Epsilon = 0.229
# 110
# 109
# resultado da epoca 780 = -3135.89 Epsilon = 0.228
# 107
# 112
# resultado da epoca 781 = -5150.69 Epsilon = 0.227
# 104
# 115
# resultado da epoca 782 = -8350.39 Epsilon = 0.226
# 101
# 118
# resultado da epoca 783 = 8231.32 Epsilon = 0.225
# 110
# 109
# resultado da epoca 784 = -5588.57 Epsilon = 0.224
# 117
# 102
# resultado da epoca 785 = -11130.24 Epsilon = 0.223
# 110
# 109
# resultado da epoca 786 = -3793.58 Epsilon = 0.222
# 107
# 112
# resultado da epoca 787 = -14155.91 Epsilon = 0.221
# 101
# 118
# resultado da epoca 788 = -24539.81 Epsilon = 0.220
# 101
# 118
# resultado da epoca 789 = 23353.87 Epsilon = 0.219
# 128
# 91
# resultado da epoca 790 = -8882.83 Epsilon = 0.218
# 102
# 117
# resultado da epoca 791 = -17140.73 Epsilon = 0.217
# 101
# 118
# resultado da epoca 792 = 784.74 Epsilon = 0.216
# 116
# 103
# resultado da epoca 793 = -1493.28 Epsilon = 0.215
# 100
# 119
# resultado da epoca 794 = -21596.41 Epsilon = 0.214
# 95
# 124
# resultado da epoca 795 = -9171.28 Epsilon = 0.213
# 104
# 115
# resultado da epoca 796 = -9791.13 Epsilon = 0.212
# 105
# 114
# resultado da epoca 797 = 1092.38 Epsilon = 0.211
# 117
# 102
# resultado da epoca 798 = 994.92 Epsilon = 0.210
# 106
# 113
# resultado da epoca 799 = -9599.50 Epsilon = 0.209
# 102
# 117
# resultado da epoca 800 = 10284.59 Epsilon = 0.208
# 109
# 110
# resultado da epoca 801 = 25594.25 Epsilon = 0.207
# 126
# 93
# resultado da epoca 802 = -20739.49 Epsilon = 0.206
# 90
# 129
# resultado da epoca 803 = -14297.34 Epsilon = 0.205
# 104
# 115
# resultado da epoca 804 = -14303.06 Epsilon = 0.204
# 98
# 121
# resultado da epoca 805 = -28226.85 Epsilon = 0.203
# 103
# 116
# resultado da epoca 806 = 2410.81 Epsilon = 0.202
# 117
# 102
# resultado da epoca 807 = -22862.06 Epsilon = 0.201
# 92
# 127
# resultado da epoca 808 = -13887.53 Epsilon = 0.200
# 102
# 117
# resultado da epoca 809 = -23346.69 Epsilon = 0.199
# 103
# 116
# resultado da epoca 810 = 5839.42 Epsilon = 0.198
# 115
# 104
# resultado da epoca 811 = -11006.31 Epsilon = 0.197
# 106
# 113
# resultado da epoca 812 = -6231.62 Epsilon = 0.196
# 101
# 118
# resultado da epoca 813 = 17919.49 Epsilon = 0.195
# 117
# 102
# resultado da epoca 814 = 11462.10 Epsilon = 0.194
# 120
# 99
# resultado da epoca 815 = 6043.16 Epsilon = 0.193
# 104
# 115
# resultado da epoca 816 = 10577.98 Epsilon = 0.192
# 115
# 104
# resultado da epoca 817 = 1425.53 Epsilon = 0.191
# 116
# 103
# resultado da epoca 818 = -8118.42 Epsilon = 0.190
# 107
# 112
# resultado da epoca 819 = -12938.90 Epsilon = 0.189
# 102
# 117
# resultado da epoca 820 = -1066.89 Epsilon = 0.188
# 110
# 109
# resultado da epoca 821 = 4711.10 Epsilon = 0.187
# 104
# 115
# resultado da epoca 822 = -3955.12 Epsilon = 0.186
# 107
# 112
# resultado da epoca 823 = -11850.46 Epsilon = 0.185
# 107
# 112
# resultado da epoca 824 = 22670.99 Epsilon = 0.184
# 118
# 101
# resultado da epoca 825 = -22599.71 Epsilon = 0.183
# 100
# 119
# resultado da epoca 826 = 7483.93 Epsilon = 0.182
# 107
# 112
# resultado da epoca 827 = -9367.34 Epsilon = 0.181
# 103
# 116
# resultado da epoca 828 = 6784.30 Epsilon = 0.180
# 119
# 100
# resultado da epoca 829 = 10651.10 Epsilon = 0.179
# 120
# 99
# resultado da epoca 830 = 3639.59 Epsilon = 0.178
# 118
# 101
# resultado da epoca 831 = 10951.75 Epsilon = 0.177
# 111
# 108
# resultado da epoca 832 = -8025.77 Epsilon = 0.176
# 114
# 105
# resultado da epoca 833 = -4436.70 Epsilon = 0.175
# 105
# 114
# resultado da epoca 834 = -13228.33 Epsilon = 0.174
# 104
# 115
# resultado da epoca 835 = 1456.53 Epsilon = 0.173
# 110
# 109
# resultado da epoca 836 = -13411.03 Epsilon = 0.172
# 97
# 122
# resultado da epoca 837 = -7623.10 Epsilon = 0.171
# 109
# 110
# resultado da epoca 838 = -19561.94 Epsilon = 0.170
# 103
# 116
# resultado da epoca 839 = 11942.83 Epsilon = 0.169
# 114
# 105
# resultado da epoca 840 = -17502.12 Epsilon = 0.168
# 104
# 115
# resultado da epoca 841 = -29027.63 Epsilon = 0.167
# 99
# 120
# resultado da epoca 842 = 4233.66 Epsilon = 0.166
# 104
# 115
# resultado da epoca 843 = -32071.00 Epsilon = 0.165
# 84
# 135
# resultado da epoca 844 = 9928.96 Epsilon = 0.164
# 121
# 98
# resultado da epoca 845 = 2390.35 Epsilon = 0.163
# 106
# 113
# resultado da epoca 846 = -9528.32 Epsilon = 0.162
# 109
# 110
# resultado da epoca 847 = 13036.50 Epsilon = 0.161
# 111
# 108
# resultado da epoca 848 = -14978.12 Epsilon = 0.160
# 106
# 113
# resultado da epoca 849 = 5029.60 Epsilon = 0.159
# 106
# 113
# resultado da epoca 850 = 15131.64 Epsilon = 0.158
# 125
# 94
# resultado da epoca 851 = -5128.04 Epsilon = 0.158
# 105
# 114
# resultado da epoca 852 = -467.69 Epsilon = 0.157
# 106
# 113
# resultado da epoca 853 = -10706.52 Epsilon = 0.156
# 114
# 105
# resultado da epoca 854 = -2530.13 Epsilon = 0.155
# 115
# 104
# resultado da epoca 855 = 8674.49 Epsilon = 0.154
# 110
# 109
# resultado da epoca 856 = -9331.40 Epsilon = 0.153
# 100
# 119
# resultado da epoca 857 = -16700.56 Epsilon = 0.152
# 95
# 124
# resultado da epoca 858 = -1510.38 Epsilon = 0.151
# 103
# 116
# resultado da epoca 859 = 28166.45 Epsilon = 0.150
# 113
# 106
# resultado da epoca 860 = -9309.73 Epsilon = 0.149
# 110
# 109
# resultado da epoca 861 = -4112.05 Epsilon = 0.148
# 108
# 111
# resultado da epoca 862 = 17394.34 Epsilon = 0.147
# 116
# 103
# resultado da epoca 863 = -2512.31 Epsilon = 0.146
# 115
# 104
# resultado da epoca 864 = -17039.51 Epsilon = 0.145
# 98
# 121
# resultado da epoca 865 = -7956.81 Epsilon = 0.144
# 95
# 124
# resultado da epoca 866 = -1760.25 Epsilon = 0.143
# 112
# 107
# resultado da epoca 867 = 36551.33 Epsilon = 0.142
# 124
# 94
# resultado da epoca 868 = -12571.53 Epsilon = 0.141
# 113
# 106
# resultado da epoca 869 = -10744.84 Epsilon = 0.140
# 104
# 115
# resultado da epoca 870 = -10432.36 Epsilon = 0.139
# 105
# 114
# resultado da epoca 871 = -14389.78 Epsilon = 0.138
# 99
# 120
# resultado da epoca 872 = -13303.54 Epsilon = 0.137
# 98
# 120
# resultado da epoca 873 = -15454.96 Epsilon = 0.136
# 104
# 115
# resultado da epoca 874 = -36933.21 Epsilon = 0.135
# 97
# 122
# resultado da epoca 875 = 5658.46 Epsilon = 0.134
# 106
# 113
# resultado da epoca 876 = -3592.34 Epsilon = 0.133
# 110
# 109
# resultado da epoca 877 = -15541.07 Epsilon = 0.132
# 99
# 120
# resultado da epoca 878 = 1615.67 Epsilon = 0.131
# 114
# 105
# resultado da epoca 879 = 17221.29 Epsilon = 0.130
# 122
# 97
# resultado da epoca 880 = 22046.71 Epsilon = 0.129
# 120
# 99
# resultado da epoca 881 = -11214.23 Epsilon = 0.128
# 104
# 114
# resultado da epoca 882 = -15233.62 Epsilon = 0.127
# 100
# 118
# resultado da epoca 883 = 1121.65 Epsilon = 0.126
# 114
# 104
# resultado da epoca 884 = 1972.25 Epsilon = 0.125
# 99
# 118
# resultado da epoca 885 = -18809.96 Epsilon = 0.124
# 99
# 120
# resultado da epoca 886 = 8736.20 Epsilon = 0.123
# 102
# 117
# resultado da epoca 887 = 8683.10 Epsilon = 0.122
# 107
# 112
# resultado da epoca 888 = -1333.26 Epsilon = 0.121
# 110
# 109
# resultado da epoca 889 = -8063.87 Epsilon = 0.120
# 106
# 112
# resultado da epoca 890 = 2471.28 Epsilon = 0.119
# 112
# 107
# resultado da epoca 891 = 676.10 Epsilon = 0.118
# 106
# 112
# resultado da epoca 892 = -10056.15 Epsilon = 0.117
# 103
# 116
# resultado da epoca 893 = 27219.02 Epsilon = 0.116
# 122
# 97
# resultado da epoca 894 = 4874.59 Epsilon = 0.115
# 114
# 105
# resultado da epoca 895 = 11010.11 Epsilon = 0.114
# 109
# 108
# resultado da epoca 896 = -25891.93 Epsilon = 0.113
# 90
# 129
# resultado da epoca 897 = -15164.82 Epsilon = 0.112
# 95
# 124
# resultado da epoca 898 = -8615.16 Epsilon = 0.111
# 93
# 125
# resultado da epoca 899 = -11010.19 Epsilon = 0.110
# 101
# 117
# resultado da epoca 900 = 2312.52 Epsilon = 0.109
# 105
# 113
# resultado da epoca 901 = 1566.19 Epsilon = 0.108
# 101
# 117
# resultado da epoca 902 = -26855.37 Epsilon = 0.107
# 87
# 130
# resultado da epoca 903 = -21813.53 Epsilon = 0.106
# 92
# 126
# resultado da epoca 904 = -4649.51 Epsilon = 0.105
# 104
# 115
# resultado da epoca 905 = 4508.19 Epsilon = 0.104
# 103
# 116
# resultado da epoca 906 = 655.98 Epsilon = 0.103
# 106
# 113
# resultado da epoca 907 = 8572.74 Epsilon = 0.102
# 112
# 107
# resultado da epoca 908 = 12893.84 Epsilon = 0.101
# 115
# 103
# resultado da epoca 909 = -16833.72 Epsilon = 0.100
# 106
# 113
# resultado da epoca 910 = -8882.41 Epsilon = 0.099
# 97
# 120
# resultado da epoca 911 = -3391.70 Epsilon = 0.098
# 97
# 119
# resultado da epoca 912 = -6220.68 Epsilon = 0.097
# 103
# 116
# resultado da epoca 913 = -2164.81 Epsilon = 0.096
# 97
# 119
# resultado da epoca 914 = 3075.43 Epsilon = 0.095
# 101
# 117
# resultado da epoca 915 = 8040.64 Epsilon = 0.094
# 103
# 113
# resultado da epoca 916 = 2692.43 Epsilon = 0.093
# 96
# 122
# resultado da epoca 917 = -142.55 Epsilon = 0.092
# 108
# 109
# resultado da epoca 918 = -13445.48 Epsilon = 0.091
# 93
# 125
# resultado da epoca 919 = -5744.00 Epsilon = 0.090
# 95
# 121
# resultado da epoca 920 = -8240.86 Epsilon = 0.089
# 89
# 130
# resultado da epoca 921 = -4851.33 Epsilon = 0.088
# 94
# 122
# resultado da epoca 922 = -3483.52 Epsilon = 0.087
# 102
# 113
# resultado da epoca 923 = 16927.16 Epsilon = 0.086
# 105
# 110
# resultado da epoca 924 = -9961.23 Epsilon = 0.085
# 96
# 122
# resultado da epoca 925 = -8984.15 Epsilon = 0.084
# 94
# 123
# resultado da epoca 926 = -503.16 Epsilon = 0.083
# 94
# 122
# resultado da epoca 927 = -3259.88 Epsilon = 0.082
# 101
# 112
# resultado da epoca 928 = -16453.23 Epsilon = 0.081
# 89
# 122
# resultado da epoca 929 = -24917.76 Epsilon = 0.080
# 83
# 134
# resultado da epoca 930 = 6968.62 Epsilon = 0.079
# 107
# 109
# resultado da epoca 931 = 8850.44 Epsilon = 0.078
# 94
# 119
# resultado da epoca 932 = -9699.89 Epsilon = 0.077
# 88
# 127
# resultado da epoca 933 = -10529.84 Epsilon = 0.076
# 93
# 123
# resultado da epoca 934 = -6524.33 Epsilon = 0.075
# 89
# 125
# resultado da epoca 935 = 4348.91 Epsilon = 0.074
# 93
# 120
# resultado da epoca 936 = 3445.32 Epsilon = 0.073
# 93
# 120
# resultado da epoca 937 = -3139.04 Epsilon = 0.072
# 92
# 125
# resultado da epoca 938 = 3928.63 Epsilon = 0.071
# 90
# 123
# resultado da epoca 939 = 10133.40 Epsilon = 0.070
# 96
# 119
# resultado da epoca 940 = -14326.32 Epsilon = 0.069
# 86
# 133
# resultado da epoca 941 = -5835.04 Epsilon = 0.068
# 86
# 127
# resultado da epoca 942 = -16070.89 Epsilon = 0.067
# 80
# 130
# resultado da epoca 943 = 10845.74 Epsilon = 0.066
# 92
# 122
# resultado da epoca 944 = 18951.15 Epsilon = 0.065
# 94
# 120
# resultado da epoca 945 = -257.92 Epsilon = 0.064
# 89
# 122
# resultado da epoca 946 = 5011.51 Epsilon = 0.063
# 84
# 122
# resultado da epoca 947 = -7458.33 Epsilon = 0.062
# 92
# 118
# resultado da epoca 948 = -5372.45 Epsilon = 0.061
# 90
# 121
# resultado da epoca 949 = 3638.23 Epsilon = 0.060
# 85
# 127
# resultado da epoca 950 = 11522.94 Epsilon = 0.059
# 93
# 117
# resultado da epoca 951 = 6902.50 Epsilon = 0.059
# 88
# 122
# resultado da epoca 952 = -13725.39 Epsilon = 0.058
# 64
# 143
# resultado da epoca 953 = -11386.81 Epsilon = 0.057
# 77
# 133
# resultado da epoca 954 = 16924.09 Epsilon = 0.056
# 101
# 105
# resultado da epoca 955 = 5043.80 Epsilon = 0.055
# 92
# 111
# resultado da epoca 956 = -20053.45 Epsilon = 0.054
# 76
# 130
# resultado da epoca 957 = -6734.68 Epsilon = 0.053
# 88
# 118
# resultado da epoca 958 = 12855.19 Epsilon = 0.052
# 87
# 115
# resultado da epoca 959 = 8056.49 Epsilon = 0.051
# 81
# 122
# resultado da epoca 960 = -2271.33 Epsilon = 0.050
# 79
# 124
# resultado da epoca 961 = -6832.42 Epsilon = 0.049
# 84
# 121
# resultado da epoca 962 = 1327.70 Epsilon = 0.048
# 81
# 120
# resultado da epoca 963 = 8175.90 Epsilon = 0.047
# 70
# 132
# resultado da epoca 964 = 1775.23 Epsilon = 0.046
# 72
# 114
# resultado da epoca 965 = -569.38 Epsilon = 0.045
# 73
# 127
# resultado da epoca 966 = 4160.86 Epsilon = 0.044
# 71
# 128
# resultado da epoca 967 = -4948.74 Epsilon = 0.043
# 57
# 136
# resultado da epoca 968 = -15418.40 Epsilon = 0.042
# 62
# 137
# resultado da epoca 969 = -4570.85 Epsilon = 0.041
# 59
# 131
# resultado da epoca 970 = 2431.25 Epsilon = 0.040
# 65
# 130
# resultado da epoca 971 = 2200.72 Epsilon = 0.039
# 54
# 123
# resultado da epoca 972 = -4444.72 Epsilon = 0.038
# 65
# 125
# resultado da epoca 973 = 1054.79 Epsilon = 0.037
# 66
# 125
# resultado da epoca 974 = 3280.92 Epsilon = 0.036
# 60
# 127
# resultado da epoca 975 = 1508.60 Epsilon = 0.035
# 57
# 122
# resultado da epoca 976 = 5396.45 Epsilon = 0.034
# 57
# 126
# resultado da epoca 977 = 9688.76 Epsilon = 0.033
# 62
# 115
# resultado da epoca 978 = 14368.23 Epsilon = 0.032
# 68
# 114
# resultado da epoca 979 = 672.10 Epsilon = 0.031
# 51
# 116
# resultado da epoca 980 = 3505.91 Epsilon = 0.030
# 47
# 112
# resultado da epoca 981 = -11408.26 Epsilon = 0.029
# 37
# 139
# resultado da epoca 982 = 3060.16 Epsilon = 0.028
# 45
# 115
# resultado da epoca 983 = 3076.99 Epsilon = 0.027
# 52
# 107
# resultado da epoca 984 = 1376.41 Epsilon = 0.026
# 48
# 124
# resultado da epoca 985 = 8502.91 Epsilon = 0.025
# 40
# 122
# resultado da epoca 986 = -6286.21 Epsilon = 0.024
# 35
# 114
# resultado da epoca 987 = 5691.53 Epsilon = 0.023
# 38
# 125
# resultado da epoca 988 = 872.77 Epsilon = 0.022
# 34
# 110
# resultado da epoca 989 = -1441.06 Epsilon = 0.021
# 29
# 120
# resultado da epoca 990 = -5677.49 Epsilon = 0.020
# 28
# 104
# resultado da epoca 991 = 3903.86 Epsilon = 0.019
# 26
# 105
# resultado da epoca 992 = -4320.26 Epsilon = 0.018
# 13
# 118
# resultado da epoca 993 = -1014.65 Epsilon = 0.017
# 27
# 102
# resultado da epoca 994 = 4920.73 Epsilon = 0.016
# 23
# 89
# resultado da epoca 995 = -1867.04 Epsilon = 0.015
# 20
# 100
# resultado da epoca 996 = -1075.81 Epsilon = 0.014
# 15
# 90
# resultado da epoca 997 = 2736.54 Epsilon = 0.013
# 18
# 75
# resultado da epoca 998 = 1684.21 Epsilon = 0.012
# 22
# 81
# resultado da epoca 999 = -43.34 Epsilon = 0.011
# 10
# 78
# 0
# 0
# Melhor resultado diario: 8117.57
