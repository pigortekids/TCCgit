# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 4*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-6
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        #model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(modelo.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado) #pega valor que chegou
            target_f[0][acao+2*lim_cont] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7680
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 226,837
# Trainable params: 226,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    reward = 0.
    posicao = 0.
    dp = 0.
    
    if acao != 0:
        if (acao*ncont_anterior) < 0:    #realizacao (lucro ou prejuizo)
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
        else:
            reward = -custo*abs(acao)                                       #reward = -custo*acao se houve operacao
        
        if valor!=-10: 
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
        
        if abs(ncont) > 0:
            valor = (ncont_anterior*valor + acao*preco)/ncont     
        else:
            valor = -10
            
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (INSTANTNEO)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    
    acao = decisao - 2*lim_cont
    
    if abs(ncont+acao) <= lim_cont:
        return acao, 0 
    else:
        return 0, -20

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    penal = 0
    decisao = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l])
        modelo.state = np.reshape(np.concatenate((modelo.janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        
        acao, penal = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward
        reward += penal
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l])
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]) 
            
        modelo.next_state = np.reshape(np.concatenate((modelo.prox_janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        modelo.remember(acao, reward, done)  #salva step na memoria
        
    #fim do dia
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1103 13:34:14.527496  4788 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = 137619.36 Epsilon = 1.000
# 118
# 101
# resultado da epoca 1 = -259542.62 Epsilon = 0.999
# 106
# 113
# resultado da epoca 2 = 301795.34 Epsilon = 0.998
# 112
# 107
# resultado da epoca 3 = 96047.35 Epsilon = 0.997
# 110
# 109
# resultado da epoca 4 = 289.94 Epsilon = 0.996
# 101
# 118
# resultado da epoca 5 = -211490.73 Epsilon = 0.995
# 100
# 119
# resultado da epoca 6 = 210719.31 Epsilon = 0.994
# 113
# 106
# resultado da epoca 7 = -52136.10 Epsilon = 0.993
# 112
# 107
# resultado da epoca 8 = 53857.82 Epsilon = 0.992
# 116
# 103
# resultado da epoca 9 = 101712.09 Epsilon = 0.991
# 117
# 102
# resultado da epoca 10 = 26110.56 Epsilon = 0.990
# 106
# 113
# resultado da epoca 11 = -93132.59 Epsilon = 0.989
# 108
# 111
# resultado da epoca 12 = 194073.26 Epsilon = 0.988
# 109
# 110
# resultado da epoca 13 = 224192.02 Epsilon = 0.987
# 115
# 104
# resultado da epoca 14 = -54304.40 Epsilon = 0.986
# 113
# 106
# resultado da epoca 15 = 60745.56 Epsilon = 0.985
# 110
# 109
# resultado da epoca 16 = 200934.47 Epsilon = 0.984
# 110
# 109
# resultado da epoca 17 = -187475.41 Epsilon = 0.983
# 103
# 116
# resultado da epoca 18 = 211116.60 Epsilon = 0.982
# 113
# 106
# resultado da epoca 19 = 306185.16 Epsilon = 0.981
# 116
# 103
# resultado da epoca 20 = 127759.20 Epsilon = 0.980
# 108
# 111
# resultado da epoca 21 = 346662.89 Epsilon = 0.979
# 115
# 104
# resultado da epoca 22 = -278773.73 Epsilon = 0.978
# 104
# 115
# resultado da epoca 23 = 279148.47 Epsilon = 0.977
# 126
# 93
# resultado da epoca 24 = 222479.33 Epsilon = 0.976
# 112
# 107
# resultado da epoca 25 = 193583.79 Epsilon = 0.975
# 112
# 107
# resultado da epoca 26 = -42711.20 Epsilon = 0.974
# 109
# 110
# resultado da epoca 27 = -254116.65 Epsilon = 0.973
# 107
# 112
# resultado da epoca 28 = -231948.53 Epsilon = 0.972
# 115
# 104
# resultado da epoca 29 = 290179.57 Epsilon = 0.971
# 119
# 100
# resultado da epoca 30 = -102356.71 Epsilon = 0.970
# 110
# 109
# resultado da epoca 31 = -609888.24 Epsilon = 0.969
# 88
# 131
# resultado da epoca 32 = 126099.52 Epsilon = 0.968
# 111
# 108
# resultado da epoca 33 = -384559.51 Epsilon = 0.967
# 94
# 125
# resultado da epoca 34 = 196052.09 Epsilon = 0.966
# 109
# 110
# resultado da epoca 35 = 466355.52 Epsilon = 0.965
# 116
# 103
# resultado da epoca 36 = 267050.16 Epsilon = 0.964
# 109
# 110
# resultado da epoca 37 = -231530.24 Epsilon = 0.963
# 106
# 113
# resultado da epoca 38 = 347303.72 Epsilon = 0.962
# 113
# 106
# resultado da epoca 39 = -98061.89 Epsilon = 0.961
# 107
# 112
# resultado da epoca 40 = -131007.26 Epsilon = 0.960
# 97
# 122
# resultado da epoca 41 = -264373.21 Epsilon = 0.959
# 108
# 111
# resultado da epoca 42 = -334313.30 Epsilon = 0.958
# 103
# 116
# resultado da epoca 43 = -117501.14 Epsilon = 0.957
# 113
# 106
# resultado da epoca 44 = 47223.05 Epsilon = 0.956
# 99
# 120
# resultado da epoca 45 = -169866.94 Epsilon = 0.955
# 110
# 109
# resultado da epoca 46 = 124936.25 Epsilon = 0.954
# 111
# 108
# resultado da epoca 47 = 95655.81 Epsilon = 0.953
# 102
# 117
# resultado da epoca 48 = 356335.24 Epsilon = 0.952
# 114
# 105
# resultado da epoca 49 = -166771.63 Epsilon = 0.951
# 111
# 108
# resultado da epoca 50 = -103131.61 Epsilon = 0.950
# 110
# 109
# resultado da epoca 51 = 182515.76 Epsilon = 0.950
# 112
# 107
# resultado da epoca 52 = 66297.02 Epsilon = 0.949
# 111
# 108
# resultado da epoca 53 = 53313.12 Epsilon = 0.948
# 105
# 114
# resultado da epoca 54 = -389040.55 Epsilon = 0.947
# 96
# 123
# resultado da epoca 55 = 181659.05 Epsilon = 0.946
# 104
# 115
# resultado da epoca 56 = -55129.96 Epsilon = 0.945
# 106
# 113
# resultado da epoca 57 = 107819.76 Epsilon = 0.944
# 100
# 119
# resultado da epoca 58 = 270022.11 Epsilon = 0.943
# 109
# 110
# resultado da epoca 59 = -133536.90 Epsilon = 0.942
# 110
# 109
# resultado da epoca 60 = 67558.83 Epsilon = 0.941
# 113
# 106
# resultado da epoca 61 = 64063.85 Epsilon = 0.940
# 112
# 107
# resultado da epoca 62 = -334888.05 Epsilon = 0.939
# 102
# 117
# resultado da epoca 63 = -76514.08 Epsilon = 0.938
# 114
# 105
# resultado da epoca 64 = 167674.74 Epsilon = 0.937
# 114
# 105
# resultado da epoca 65 = 153905.07 Epsilon = 0.936
# 111
# 108
# resultado da epoca 66 = -594651.24 Epsilon = 0.935
# 100
# 119
# resultado da epoca 67 = -208281.79 Epsilon = 0.934
# 111
# 108
# resultado da epoca 68 = 324095.03 Epsilon = 0.933
# 114
# 105
# resultado da epoca 69 = 258407.42 Epsilon = 0.932
# 118
# 101
# resultado da epoca 70 = -315421.36 Epsilon = 0.931
# 108
# 111
# resultado da epoca 71 = 86900.37 Epsilon = 0.930
# 108
# 111
# resultado da epoca 72 = 677493.59 Epsilon = 0.929
# 109
# 110
# resultado da epoca 73 = -207673.30 Epsilon = 0.928
# 107
# 112
# resultado da epoca 74 = 36423.32 Epsilon = 0.927
# 109
# 110
# resultado da epoca 75 = 492681.68 Epsilon = 0.926
# 137
# 82
# resultado da epoca 76 = -58650.15 Epsilon = 0.925
# 111
# 108
# resultado da epoca 77 = 185363.04 Epsilon = 0.924
# 108
# 111
# resultado da epoca 78 = 278948.90 Epsilon = 0.923
# 112
# 107
# resultado da epoca 79 = 160455.63 Epsilon = 0.922
# 103
# 116
# resultado da epoca 80 = 335768.20 Epsilon = 0.921
# 114
# 105
# resultado da epoca 81 = -314500.55 Epsilon = 0.920
# 98
# 121
# resultado da epoca 82 = 227695.41 Epsilon = 0.919
# 112
# 107
# resultado da epoca 83 = -39314.85 Epsilon = 0.918
# 108
# 111
# resultado da epoca 84 = -138917.13 Epsilon = 0.917
# 102
# 117
# resultado da epoca 85 = -327004.09 Epsilon = 0.916
# 100
# 119
# resultado da epoca 86 = 256546.62 Epsilon = 0.915
# 117
# 102
# resultado da epoca 87 = 171329.94 Epsilon = 0.914
# 111
# 108
# resultado da epoca 88 = 271235.27 Epsilon = 0.913
# 110
# 109
# resultado da epoca 89 = 457279.81 Epsilon = 0.912
# 116
# 103
# resultado da epoca 90 = -82027.84 Epsilon = 0.911
# 113
# 106
# resultado da epoca 91 = 68281.81 Epsilon = 0.910
# 108
# 111
# resultado da epoca 92 = -89563.00 Epsilon = 0.909
# 100
# 119
# resultado da epoca 93 = 243702.09 Epsilon = 0.908
# 109
# 110
# resultado da epoca 94 = -63250.36 Epsilon = 0.907
# 111
# 108
# resultado da epoca 95 = 240470.21 Epsilon = 0.906
# 107
# 112
# resultado da epoca 96 = 130486.13 Epsilon = 0.905
# 114
# 105
# resultado da epoca 97 = -92830.18 Epsilon = 0.904
# 102
# 117
# resultado da epoca 98 = -37761.71 Epsilon = 0.903
# 102
# 117
# resultado da epoca 99 = -175829.54 Epsilon = 0.902
# 111
# 108
# resultado da epoca 100 = -109100.30 Epsilon = 0.901
# 99
# 120
# resultado da epoca 101 = 264837.89 Epsilon = 0.900
# 114
# 105
# resultado da epoca 102 = 253789.71 Epsilon = 0.899
# 106
# 113
# resultado da epoca 103 = -196325.98 Epsilon = 0.898
# 93
# 126
# resultado da epoca 104 = 174604.30 Epsilon = 0.897
# 119
# 100
# resultado da epoca 105 = -381748.87 Epsilon = 0.896
# 113
# 106
# resultado da epoca 106 = 37129.10 Epsilon = 0.895
# 112
# 107
# resultado da epoca 107 = 208395.89 Epsilon = 0.894
# 113
# 106
# resultado da epoca 108 = -494186.21 Epsilon = 0.893
# 97
# 122
# resultado da epoca 109 = -128753.67 Epsilon = 0.892
# 110
# 109
# resultado da epoca 110 = -331179.35 Epsilon = 0.891
# 107
# 112
# resultado da epoca 111 = 55650.97 Epsilon = 0.890
# 99
# 120
# resultado da epoca 112 = -450916.71 Epsilon = 0.889
# 94
# 125
# resultado da epoca 113 = 180122.00 Epsilon = 0.888
# 115
# 104
# resultado da epoca 114 = -53804.96 Epsilon = 0.887
# 107
# 112
# resultado da epoca 115 = -175153.20 Epsilon = 0.886
# 97
# 122
# resultado da epoca 116 = 263000.99 Epsilon = 0.885
# 99
# 120
# resultado da epoca 117 = -43617.94 Epsilon = 0.884
# 112
# 107
# resultado da epoca 118 = -68010.12 Epsilon = 0.883
# 102
# 117
# resultado da epoca 119 = -57551.41 Epsilon = 0.882
# 109
# 110
# resultado da epoca 120 = -301659.94 Epsilon = 0.881
# 93
# 126
# resultado da epoca 121 = -352727.00 Epsilon = 0.880
# 109
# 110
# resultado da epoca 122 = 33679.81 Epsilon = 0.879
# 109
# 110
# resultado da epoca 123 = -54712.82 Epsilon = 0.878
# 113
# 106
# resultado da epoca 124 = 39513.23 Epsilon = 0.877
# 108
# 111
# resultado da epoca 125 = 44768.00 Epsilon = 0.876
# 106
# 113
# resultado da epoca 126 = 71980.37 Epsilon = 0.875
# 105
# 114
# resultado da epoca 127 = -329896.86 Epsilon = 0.874
# 100
# 119
# resultado da epoca 128 = -526803.71 Epsilon = 0.873
# 100
# 119
# resultado da epoca 129 = -81804.12 Epsilon = 0.872
# 96
# 123
# resultado da epoca 130 = -202789.92 Epsilon = 0.871
# 102
# 117
# resultado da epoca 131 = 161941.24 Epsilon = 0.870
# 109
# 110
# resultado da epoca 132 = -178608.29 Epsilon = 0.869
# 106
# 113
# resultado da epoca 133 = -467091.45 Epsilon = 0.868
# 104
# 115
# resultado da epoca 134 = -284779.34 Epsilon = 0.867
# 97
# 122
# resultado da epoca 135 = 126823.29 Epsilon = 0.866
# 118
# 101
# resultado da epoca 136 = 134574.81 Epsilon = 0.865
# 107
# 112
# resultado da epoca 137 = 339668.11 Epsilon = 0.864
# 111
# 108
# resultado da epoca 138 = 437813.97 Epsilon = 0.863
# 118
# 101
# resultado da epoca 139 = 5950.63 Epsilon = 0.862
# 118
# 101
# resultado da epoca 140 = -87168.16 Epsilon = 0.861
# 110
# 109
# resultado da epoca 141 = -462612.16 Epsilon = 0.860
# 99
# 120
# resultado da epoca 142 = -7800.41 Epsilon = 0.859
# 95
# 124
# resultado da epoca 143 = 74583.98 Epsilon = 0.858
# 102
# 117
# resultado da epoca 144 = -147853.59 Epsilon = 0.857
# 112
# 107
# resultado da epoca 145 = -128546.55 Epsilon = 0.856
# 107
# 112
# resultado da epoca 146 = 284658.80 Epsilon = 0.855
# 116
# 103
# resultado da epoca 147 = 121174.47 Epsilon = 0.854
# 114
# 105
# resultado da epoca 148 = 346827.59 Epsilon = 0.853
# 119
# 100
# resultado da epoca 149 = 448415.86 Epsilon = 0.852
# 122
# 97
# resultado da epoca 150 = 80781.89 Epsilon = 0.851
# 107
# 112
# resultado da epoca 151 = -159706.80 Epsilon = 0.851
# 112
# 107
# resultado da epoca 152 = 211985.09 Epsilon = 0.850
# 112
# 107
# resultado da epoca 153 = 211898.23 Epsilon = 0.849
# 102
# 117
# resultado da epoca 154 = 622710.37 Epsilon = 0.848
# 115
# 104
# resultado da epoca 155 = -98115.55 Epsilon = 0.847
# 106
# 113
# resultado da epoca 156 = 161502.98 Epsilon = 0.846
# 105
# 114
# resultado da epoca 157 = -342822.15 Epsilon = 0.845
# 109
# 110
# resultado da epoca 158 = -734304.60 Epsilon = 0.844
# 93
# 126
# resultado da epoca 159 = -149266.08 Epsilon = 0.843
# 113
# 106
# resultado da epoca 160 = 72200.75 Epsilon = 0.842
# 107
# 112
# resultado da epoca 161 = 296768.90 Epsilon = 0.841
# 119
# 100
# resultado da epoca 162 = -259287.65 Epsilon = 0.840
# 105
# 114
# resultado da epoca 163 = -12524.58 Epsilon = 0.839
# 119
# 100
# resultado da epoca 164 = 76269.09 Epsilon = 0.838
# 110
# 109
# resultado da epoca 165 = -279275.64 Epsilon = 0.837
# 94
# 125
# resultado da epoca 166 = 268492.96 Epsilon = 0.836
# 116
# 103
# resultado da epoca 167 = -79446.06 Epsilon = 0.835
# 101
# 118
# resultado da epoca 168 = 114520.91 Epsilon = 0.834
# 112
# 107
# resultado da epoca 169 = -343534.95 Epsilon = 0.833
# 99
# 120
# resultado da epoca 170 = 158523.16 Epsilon = 0.832
# 114
# 105
# resultado da epoca 171 = 335149.80 Epsilon = 0.831
# 110
# 109
# resultado da epoca 172 = -52956.18 Epsilon = 0.830
# 96
# 123
# resultado da epoca 173 = -28646.78 Epsilon = 0.829
# 107
# 112
# resultado da epoca 174 = 43950.26 Epsilon = 0.828
# 107
# 112
# resultado da epoca 175 = 140896.97 Epsilon = 0.827
# 114
# 105
# resultado da epoca 176 = -424289.21 Epsilon = 0.826
# 103
# 116
# resultado da epoca 177 = -79991.52 Epsilon = 0.825
# 111
# 108
# resultado da epoca 178 = 316037.47 Epsilon = 0.824
# 121
# 98
# resultado da epoca 179 = -10742.75 Epsilon = 0.823
# 110
# 109
# resultado da epoca 180 = -46372.18 Epsilon = 0.822
# 112
# 107
# resultado da epoca 181 = -106600.85 Epsilon = 0.821
# 103
# 116
# resultado da epoca 182 = 163179.35 Epsilon = 0.820
# 119
# 100
# resultado da epoca 183 = 184352.77 Epsilon = 0.819
# 109
# 110
# resultado da epoca 184 = 519509.77 Epsilon = 0.818
# 108
# 111
# resultado da epoca 185 = -474167.15 Epsilon = 0.817
# 99
# 120
# resultado da epoca 186 = -204555.30 Epsilon = 0.816
# 112
# 107
# resultado da epoca 187 = 139698.65 Epsilon = 0.815
# 115
# 104
# resultado da epoca 188 = -194782.57 Epsilon = 0.814
# 98
# 121
# resultado da epoca 189 = -213510.08 Epsilon = 0.813
# 103
# 116
# resultado da epoca 190 = -275658.13 Epsilon = 0.812
# 101
# 118
# resultado da epoca 191 = 26317.60 Epsilon = 0.811
# 94
# 125
# resultado da epoca 192 = 232158.28 Epsilon = 0.810
# 108
# 111
# resultado da epoca 193 = 7641.23 Epsilon = 0.809
# 105
# 114
# resultado da epoca 194 = -400932.62 Epsilon = 0.808
# 100
# 119
# resultado da epoca 195 = 316428.73 Epsilon = 0.807
# 114
# 105
# resultado da epoca 196 = -170152.05 Epsilon = 0.806
# 112
# 107
# resultado da epoca 197 = 277071.73 Epsilon = 0.805
# 112
# 107
# resultado da epoca 198 = 258320.89 Epsilon = 0.804
# 115
# 104
# resultado da epoca 199 = -33036.41 Epsilon = 0.803
# 103
# 116
# resultado da epoca 200 = -166203.17 Epsilon = 0.802
# 111
# 108
# resultado da epoca 201 = -105655.83 Epsilon = 0.801
# 112
# 107
# resultado da epoca 202 = 70759.53 Epsilon = 0.800
# 111
# 108
# resultado da epoca 203 = 186375.27 Epsilon = 0.799
# 113
# 106
# resultado da epoca 204 = -119101.47 Epsilon = 0.798
# 108
# 111
# resultado da epoca 205 = 152928.78 Epsilon = 0.797
# 114
# 105
# resultado da epoca 206 = -337453.44 Epsilon = 0.796
# 99
# 120
# resultado da epoca 207 = -39372.81 Epsilon = 0.795
# 121
# 98
# resultado da epoca 208 = -85932.93 Epsilon = 0.794
# 105
# 114
# resultado da epoca 209 = 576936.91 Epsilon = 0.793
# 122
# 97
# resultado da epoca 210 = -231299.75 Epsilon = 0.792
# 101
# 118
# resultado da epoca 211 = -89921.08 Epsilon = 0.791
# 115
# 104
# resultado da epoca 212 = 410581.26 Epsilon = 0.790
# 127
# 92
# resultado da epoca 213 = 179022.73 Epsilon = 0.789
# 109
# 110
# resultado da epoca 214 = -193316.09 Epsilon = 0.788
# 108
# 111
# resultado da epoca 215 = -202424.88 Epsilon = 0.787
# 103
# 116
# resultado da epoca 216 = 409207.96 Epsilon = 0.786
# 114
# 105
# resultado da epoca 217 = 263555.84 Epsilon = 0.785
# 105
# 114
# resultado da epoca 218 = 127956.26 Epsilon = 0.784
# 114
# 105
# resultado da epoca 219 = 153574.41 Epsilon = 0.783
# 111
# 108
# resultado da epoca 220 = -229843.96 Epsilon = 0.782
# 113
# 106
# resultado da epoca 221 = -24638.36 Epsilon = 0.781
# 98
# 121
# resultado da epoca 222 = -79698.52 Epsilon = 0.780
# 104
# 115
# resultado da epoca 223 = 115601.68 Epsilon = 0.779
# 118
# 101
# resultado da epoca 224 = 296986.06 Epsilon = 0.778
# 111
# 108
# resultado da epoca 225 = -337750.12 Epsilon = 0.777
# 97
# 122
# resultado da epoca 226 = 5363.72 Epsilon = 0.776
# 112
# 107
# resultado da epoca 227 = 62466.72 Epsilon = 0.775
# 116
# 103
# resultado da epoca 228 = 66541.92 Epsilon = 0.774
# 98
# 121
# resultado da epoca 229 = 21853.34 Epsilon = 0.773
# 109
# 110
# resultado da epoca 230 = 287205.82 Epsilon = 0.772
# 100
# 119
# resultado da epoca 231 = -58356.18 Epsilon = 0.771
# 107
# 112
# resultado da epoca 232 = 320834.03 Epsilon = 0.770
# 110
# 109
# resultado da epoca 233 = -158153.89 Epsilon = 0.769
# 111
# 108
# resultado da epoca 234 = 9248.31 Epsilon = 0.768
# 111
# 108
# resultado da epoca 235 = -95719.20 Epsilon = 0.767
# 110
# 109
# resultado da epoca 236 = 442630.41 Epsilon = 0.766
# 127
# 92
# resultado da epoca 237 = -140166.80 Epsilon = 0.765
# 102
# 117
# resultado da epoca 238 = -282444.00 Epsilon = 0.764
# 96
# 123
# resultado da epoca 239 = 195486.01 Epsilon = 0.763
# 99
# 120
# resultado da epoca 240 = 296381.41 Epsilon = 0.762
# 115
# 104
# resultado da epoca 241 = 190243.96 Epsilon = 0.761
# 106
# 113
# resultado da epoca 242 = -346213.75 Epsilon = 0.760
# 96
# 123
# resultado da epoca 243 = 130403.19 Epsilon = 0.759
# 115
# 104
# resultado da epoca 244 = 121652.89 Epsilon = 0.758
# 107
# 112
# resultado da epoca 245 = -89849.16 Epsilon = 0.757
# 99
# 120
# resultado da epoca 246 = -251369.63 Epsilon = 0.756
# 112
# 107
# resultado da epoca 247 = -208564.93 Epsilon = 0.755
# 97
# 122
# resultado da epoca 248 = -224366.45 Epsilon = 0.754
# 98
# 121
# resultado da epoca 249 = -129984.47 Epsilon = 0.753
# 104
# 115
# resultado da epoca 250 = 406336.62 Epsilon = 0.752
# 116
# 103
# resultado da epoca 251 = 291952.74 Epsilon = 0.752
# 118
# 101
# resultado da epoca 252 = 255560.92 Epsilon = 0.751
# 122
# 97
# resultado da epoca 253 = -271843.81 Epsilon = 0.750
# 106
# 113
# resultado da epoca 254 = 436030.72 Epsilon = 0.749
# 109
# 110
# resultado da epoca 255 = 40645.58 Epsilon = 0.748
# 104
# 115
# resultado da epoca 256 = -414854.19 Epsilon = 0.747
# 100
# 119
# resultado da epoca 257 = 27094.68 Epsilon = 0.746
# 110
# 109
# resultado da epoca 258 = 168401.24 Epsilon = 0.745
# 112
# 107
# resultado da epoca 259 = -434765.26 Epsilon = 0.744
# 97
# 122
# resultado da epoca 260 = 43038.28 Epsilon = 0.743
# 113
# 106
# resultado da epoca 261 = 163196.95 Epsilon = 0.742
# 109
# 110
# resultado da epoca 262 = -87209.76 Epsilon = 0.741
# 105
# 114
# resultado da epoca 263 = 141787.96 Epsilon = 0.740
# 103
# 116
# resultado da epoca 264 = 348449.10 Epsilon = 0.739
# 108
# 111
# resultado da epoca 265 = 19345.83 Epsilon = 0.738
# 124
# 95
# resultado da epoca 266 = 395427.72 Epsilon = 0.737
# 117
# 102
# resultado da epoca 267 = -48251.70 Epsilon = 0.736
# 104
# 115
# resultado da epoca 268 = -35755.15 Epsilon = 0.735
# 109
# 110
# resultado da epoca 269 = -365836.67 Epsilon = 0.734
# 97
# 122
# resultado da epoca 270 = -145195.41 Epsilon = 0.733
# 104
# 115
# resultado da epoca 271 = 529364.71 Epsilon = 0.732
# 116
# 103
# resultado da epoca 272 = -117499.78 Epsilon = 0.731
# 107
# 112
# resultado da epoca 273 = 16376.50 Epsilon = 0.730
# 119
# 100
# resultado da epoca 274 = 35518.08 Epsilon = 0.729
# 111
# 108
# resultado da epoca 275 = 267684.83 Epsilon = 0.728
# 111
# 108
# resultado da epoca 276 = 40860.86 Epsilon = 0.727
# 109
# 110
# resultado da epoca 277 = -304628.60 Epsilon = 0.726
# 95
# 124
# resultado da epoca 278 = 20660.93 Epsilon = 0.725
# 106
# 113
# resultado da epoca 279 = -58077.65 Epsilon = 0.724
# 98
# 121
# resultado da epoca 280 = -203048.54 Epsilon = 0.723
# 111
# 108
# resultado da epoca 281 = 163969.13 Epsilon = 0.722
# 112
# 107
# resultado da epoca 282 = 123854.23 Epsilon = 0.721
# 105
# 114
# resultado da epoca 283 = 24967.14 Epsilon = 0.720
# 110
# 109
# resultado da epoca 284 = -21467.82 Epsilon = 0.719
# 102
# 117
# resultado da epoca 285 = 77774.32 Epsilon = 0.718
# 117
# 102
# resultado da epoca 286 = -104141.46 Epsilon = 0.717
# 101
# 118
# resultado da epoca 287 = -239552.50 Epsilon = 0.716
# 100
# 119
# resultado da epoca 288 = 47955.87 Epsilon = 0.715
# 104
# 115
# resultado da epoca 289 = -116209.98 Epsilon = 0.714
# 101
# 118
# resultado da epoca 290 = 195334.39 Epsilon = 0.713
# 114
# 105
# resultado da epoca 291 = -187277.91 Epsilon = 0.712
# 103
# 116
# resultado da epoca 292 = 297103.83 Epsilon = 0.711
# 109
# 110
# resultado da epoca 293 = -158317.69 Epsilon = 0.710
# 112
# 107
# resultado da epoca 294 = -310016.91 Epsilon = 0.709
# 106
# 113
# resultado da epoca 295 = -342354.25 Epsilon = 0.708
# 112
# 107
# resultado da epoca 296 = -807524.60 Epsilon = 0.707
# 77
# 142
# resultado da epoca 297 = -34914.01 Epsilon = 0.706
# 111
# 108
# resultado da epoca 298 = 315052.38 Epsilon = 0.705
# 111
# 108
# resultado da epoca 299 = 375442.68 Epsilon = 0.704
# 113
# 106
# resultado da epoca 300 = 220815.87 Epsilon = 0.703
# 113
# 106
# resultado da epoca 301 = -277838.60 Epsilon = 0.702
# 101
# 118
# resultado da epoca 302 = 128601.43 Epsilon = 0.701
# 109
# 110
# resultado da epoca 303 = 189912.90 Epsilon = 0.700
# 106
# 113
# resultado da epoca 304 = -315564.74 Epsilon = 0.699
# 107
# 112
# resultado da epoca 305 = -202581.30 Epsilon = 0.698
# 103
# 116
# resultado da epoca 306 = 411523.81 Epsilon = 0.697
# 112
# 107
# resultado da epoca 307 = -410403.47 Epsilon = 0.696
# 91
# 128
# resultado da epoca 308 = -77540.16 Epsilon = 0.695
# 114
# 105
# resultado da epoca 309 = 533760.73 Epsilon = 0.694
# 122
# 97
# resultado da epoca 310 = -334010.08 Epsilon = 0.693
# 102
# 117
# resultado da epoca 311 = 286433.75 Epsilon = 0.692
# 113
# 106
# resultado da epoca 312 = -131491.33 Epsilon = 0.691
# 98
# 121
# resultado da epoca 313 = -352814.17 Epsilon = 0.690
# 101
# 118
# resultado da epoca 314 = 446352.72 Epsilon = 0.689
# 123
# 96
# resultado da epoca 315 = -222911.64 Epsilon = 0.688
# 97
# 122
# resultado da epoca 316 = 512384.28 Epsilon = 0.687
# 110
# 109
# resultado da epoca 317 = -319253.92 Epsilon = 0.686
# 100
# 119
# resultado da epoca 318 = -125257.23 Epsilon = 0.685
# 99
# 120
# resultado da epoca 319 = 290795.10 Epsilon = 0.684
# 114
# 105
# resultado da epoca 320 = -110608.65 Epsilon = 0.683
# 110
# 109
# resultado da epoca 321 = 461905.39 Epsilon = 0.682
# 117
# 102
# resultado da epoca 322 = 209584.52 Epsilon = 0.681
# 112
# 107
# resultado da epoca 323 = -157283.65 Epsilon = 0.680
# 94
# 125
# resultado da epoca 324 = -264210.82 Epsilon = 0.679
# 103
# 116
# resultado da epoca 325 = -385040.53 Epsilon = 0.678
# 100
# 119
# resultado da epoca 326 = -99211.52 Epsilon = 0.677
# 103
# 116
# resultado da epoca 327 = 103183.10 Epsilon = 0.676
# 103
# 116
# resultado da epoca 328 = 209769.40 Epsilon = 0.675
# 115
# 104
# resultado da epoca 329 = -120281.35 Epsilon = 0.674
# 102
# 117
# resultado da epoca 330 = 151871.99 Epsilon = 0.673
# 110
# 109
# resultado da epoca 331 = 356752.38 Epsilon = 0.672
# 115
# 104
# resultado da epoca 332 = -98747.61 Epsilon = 0.671
# 101
# 118
# resultado da epoca 333 = 232383.12 Epsilon = 0.670
# 114
# 105
# resultado da epoca 334 = -200790.33 Epsilon = 0.669
# 100
# 119
# resultado da epoca 335 = -255649.93 Epsilon = 0.668
# 105
# 114
# resultado da epoca 336 = 171375.17 Epsilon = 0.667
# 104
# 115
# resultado da epoca 337 = 298065.57 Epsilon = 0.666
# 130
# 89
# resultado da epoca 338 = 477057.97 Epsilon = 0.665
# 127
# 92
# resultado da epoca 339 = 162126.22 Epsilon = 0.664
# 109
# 110
# resultado da epoca 340 = -360255.94 Epsilon = 0.663
# 107
# 112
# resultado da epoca 341 = 373330.69 Epsilon = 0.662
# 116
# 103
# resultado da epoca 342 = 341995.93 Epsilon = 0.661
# 113
# 106
# resultado da epoca 343 = -85832.34 Epsilon = 0.660
# 107
# 112
# resultado da epoca 344 = 35899.43 Epsilon = 0.659
# 110
# 109
# resultado da epoca 345 = 278165.43 Epsilon = 0.658
# 118
# 101
# resultado da epoca 346 = 598438.66 Epsilon = 0.657
# 117
# 102
# resultado da epoca 347 = -200190.82 Epsilon = 0.656
# 103
# 116
# resultado da epoca 348 = 603933.66 Epsilon = 0.655
# 120
# 99
# resultado da epoca 349 = -201845.62 Epsilon = 0.654
# 95
# 124
# resultado da epoca 350 = -156725.29 Epsilon = 0.653
# 111
# 108
# resultado da epoca 351 = 119509.70 Epsilon = 0.653
# 108
# 111
# resultado da epoca 352 = 282843.11 Epsilon = 0.652
# 108
# 111
# resultado da epoca 353 = -370097.35 Epsilon = 0.651
# 107
# 112
# resultado da epoca 354 = 468508.71 Epsilon = 0.650
# 118
# 101
