# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 4*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        #model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(modelo.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado) #pega valor que chegou
            target_f[0][acao+2*lim_cont] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7680
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 226,837
# Trainable params: 226,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    reward = 0.
    posicao = 0.
    dp = 0.

    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    
    acao = decisao - 2*lim_cont
    
    if abs(ncont+acao) <= lim_cont:
        return acao, 0 
    else:
        return 0, -20

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    penal = 0
    decisao = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l])
        modelo.state = np.reshape(np.concatenate((modelo.janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        
        acao, penal = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        reward += penal    #penalidade se quiser ficar posicionado mais que o permitido
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l])
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]) 
            
        modelo.next_state = np.reshape(np.concatenate((modelo.prox_janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        modelo.remember(acao, reward, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os v1alores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1103 19:23:07.679668  5888 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -34445.05 Epsilon = 1.000
# 96
# 123
# resultado da epoca 1 = -29628.61 Epsilon = 0.999
# 95
# 124
# resultado da epoca 2 = -13040.57 Epsilon = 0.998
# 101
# 118
# resultado da epoca 3 = -6765.38 Epsilon = 0.997
# 111
# 108
# resultado da epoca 4 = -31665.48 Epsilon = 0.996
# 98
# 121
# resultado da epoca 5 = -41415.28 Epsilon = 0.995
# 96
# 123
# resultado da epoca 6 = -15049.59 Epsilon = 0.994
# 104
# 115
# resultado da epoca 7 = -26008.20 Epsilon = 0.993
# 96
# 123
# resultado da epoca 8 = -29516.69 Epsilon = 0.992
# 111
# 108
# resultado da epoca 9 = -6174.92 Epsilon = 0.991
# 107
# 112
# resultado da epoca 10 = -20824.96 Epsilon = 0.990
# 103
# 116
# resultado da epoca 11 = -24634.69 Epsilon = 0.989
# 100
# 119
# resultado da epoca 12 = -45216.01 Epsilon = 0.988
# 94
# 125
# resultado da epoca 13 = -41976.57 Epsilon = 0.987
# 89
# 130
# resultado da epoca 14 = -20551.37 Epsilon = 0.986
# 114
# 105
# resultado da epoca 15 = 14430.23 Epsilon = 0.985
# 119
# 100
# resultado da epoca 16 = -57623.94 Epsilon = 0.984
# 88
# 131
# resultado da epoca 17 = -13902.45 Epsilon = 0.983
# 94
# 125
# resultado da epoca 18 = -20464.71 Epsilon = 0.982
# 108
# 111
# resultado da epoca 19 = -8523.97 Epsilon = 0.981
# 115
# 104
# resultado da epoca 20 = -24949.38 Epsilon = 0.980
# 103
# 116
# resultado da epoca 21 = -11295.18 Epsilon = 0.979
# 108
# 111
# resultado da epoca 22 = -44198.60 Epsilon = 0.978
# 88
# 131
# resultado da epoca 23 = -40609.55 Epsilon = 0.977
# 94
# 125
# resultado da epoca 24 = -18446.57 Epsilon = 0.976
# 91
# 128
# resultado da epoca 25 = -5080.38 Epsilon = 0.975
# 113
# 106
# resultado da epoca 26 = -10169.20 Epsilon = 0.974
# 93
# 126
# resultado da epoca 27 = 5642.61 Epsilon = 0.973
# 118
# 101
# resultado da epoca 28 = -34226.31 Epsilon = 0.972
# 90
# 129
# resultado da epoca 29 = -41767.68 Epsilon = 0.971
# 106
# 113
# resultado da epoca 30 = -8476.56 Epsilon = 0.970
# 102
# 117
# resultado da epoca 31 = -27506.38 Epsilon = 0.969
# 98
# 121
# resultado da epoca 32 = -7985.85 Epsilon = 0.968
# 112
# 107
# resultado da epoca 33 = -33017.26 Epsilon = 0.967
# 102
# 117
# resultado da epoca 34 = -31102.97 Epsilon = 0.966
# 88
# 131
# resultado da epoca 35 = -24003.36 Epsilon = 0.965
# 106
# 113
# resultado da epoca 36 = -6946.23 Epsilon = 0.964
# 106
# 113
# resultado da epoca 37 = -25275.86 Epsilon = 0.963
# 86
# 133
# resultado da epoca 38 = -40439.03 Epsilon = 0.962
# 92
# 127
# resultado da epoca 39 = -21967.63 Epsilon = 0.961
# 102
# 117
# resultado da epoca 40 = -17110.95 Epsilon = 0.960
# 98
# 121
# resultado da epoca 41 = 11570.03 Epsilon = 0.959
# 106
# 113
# resultado da epoca 42 = -18583.31 Epsilon = 0.958
# 95
# 124
# resultado da epoca 43 = -46309.68 Epsilon = 0.957
# 81
# 138
# resultado da epoca 44 = -27502.71 Epsilon = 0.956
# 96
# 123
# resultado da epoca 45 = -50186.50 Epsilon = 0.955
# 84
# 135
# resultado da epoca 46 = -32306.69 Epsilon = 0.954
# 101
# 118
# resultado da epoca 47 = 352.10 Epsilon = 0.953
# 106
# 113
# resultado da epoca 48 = 2.31 Epsilon = 0.952
# 109
# 110
# resultado da epoca 49 = -12704.57 Epsilon = 0.951
# 101
# 118
# resultado da epoca 50 = -10116.93 Epsilon = 0.950
# 99
# 120
# resultado da epoca 51 = -21412.08 Epsilon = 0.950
# 96
# 123
# resultado da epoca 52 = -28839.69 Epsilon = 0.949
# 94
# 125
# resultado da epoca 53 = -31273.88 Epsilon = 0.948
# 106
# 113
# resultado da epoca 54 = -24498.20 Epsilon = 0.947
# 99
# 120
# resultado da epoca 55 = -61864.34 Epsilon = 0.946
# 88
# 131
# resultado da epoca 56 = -24245.58 Epsilon = 0.945
# 97
# 122
# resultado da epoca 57 = -27019.34 Epsilon = 0.944
# 95
# 124
# resultado da epoca 58 = -38075.95 Epsilon = 0.943
# 89
# 130
# resultado da epoca 59 = -36248.22 Epsilon = 0.942
# 102
# 117
# resultado da epoca 60 = -22615.91 Epsilon = 0.941
# 101
# 118
# resultado da epoca 61 = -30752.24 Epsilon = 0.940
# 98
# 121
# resultado da epoca 62 = -33405.26 Epsilon = 0.939
# 93
# 126
# resultado da epoca 63 = -15122.99 Epsilon = 0.938
# 105
# 114
# resultado da epoca 64 = -22926.11 Epsilon = 0.937
# 94
# 125
# resultado da epoca 65 = -14015.51 Epsilon = 0.936
# 105
# 114
# resultado da epoca 66 = -9844.62 Epsilon = 0.935
# 99
# 120
# resultado da epoca 67 = 315.72 Epsilon = 0.934
# 107
# 112
# resultado da epoca 68 = -42208.05 Epsilon = 0.933
# 93
# 126
# resultado da epoca 69 = -48883.86 Epsilon = 0.932
# 94
# 125
# resultado da epoca 70 = -1404.00 Epsilon = 0.931
# 105
# 114
# resultado da epoca 71 = -26971.76 Epsilon = 0.930
# 94
# 125
# resultado da epoca 72 = -23440.83 Epsilon = 0.929
# 96
# 123
# resultado da epoca 73 = -14435.82 Epsilon = 0.928
# 103
# 116
# resultado da epoca 74 = -33352.70 Epsilon = 0.927
# 93
# 126
# resultado da epoca 75 = -23630.09 Epsilon = 0.926
# 98
# 121
# resultado da epoca 76 = -18260.73 Epsilon = 0.925
# 102
# 117
# resultado da epoca 77 = -50441.53 Epsilon = 0.924
# 94
# 125
# resultado da epoca 78 = -25230.21 Epsilon = 0.923
# 113
# 106
# resultado da epoca 79 = -28147.55 Epsilon = 0.922
# 98
# 121
# resultado da epoca 80 = -21297.34 Epsilon = 0.921
# 99
# 120
# resultado da epoca 81 = -22092.02 Epsilon = 0.920
# 98
# 121
# resultado da epoca 82 = -43282.44 Epsilon = 0.919
# 85
# 134
# resultado da epoca 83 = -3277.72 Epsilon = 0.918
# 108
# 111
# resultado da epoca 84 = 473.44 Epsilon = 0.917
# 113
# 106
# resultado da epoca 85 = -16103.26 Epsilon = 0.916
# 100
# 119
# resultado da epoca 86 = -13050.76 Epsilon = 0.915
# 90
# 129
# resultado da epoca 87 = -44542.73 Epsilon = 0.914
# 84
# 135
# resultado da epoca 88 = -32763.74 Epsilon = 0.913
# 91
# 128
# resultado da epoca 89 = -25267.17 Epsilon = 0.912
# 92
# 127
# resultado da epoca 90 = -3119.84 Epsilon = 0.911
# 106
# 113
# resultado da epoca 91 = -40113.22 Epsilon = 0.910
# 95
# 124
# resultado da epoca 92 = -38659.49 Epsilon = 0.909
# 92
# 127
# resultado da epoca 93 = -23293.20 Epsilon = 0.908
# 101
# 118
# resultado da epoca 94 = -62870.39 Epsilon = 0.907
# 95
# 124
# resultado da epoca 95 = -32324.26 Epsilon = 0.906
# 100
# 119
# resultado da epoca 96 = -36541.99 Epsilon = 0.905
# 84
# 135
# resultado da epoca 97 = -10664.09 Epsilon = 0.904
# 104
# 115
# resultado da epoca 98 = -49806.66 Epsilon = 0.903
# 81
# 138
# resultado da epoca 99 = -27071.53 Epsilon = 0.902
# 100
# 119
# resultado da epoca 100 = -13680.39 Epsilon = 0.901
# 109
# 110
# resultado da epoca 101 = -21632.90 Epsilon = 0.900
# 97
# 122
# resultado da epoca 102 = -60573.89 Epsilon = 0.899
# 87
# 132
# resultado da epoca 103 = -31709.55 Epsilon = 0.898
# 104
# 115
# resultado da epoca 104 = -23724.01 Epsilon = 0.897
# 105
# 114
# resultado da epoca 105 = -39435.88 Epsilon = 0.896
# 101
# 118
# resultado da epoca 106 = -24242.01 Epsilon = 0.895
# 101
# 118
# resultado da epoca 107 = -50379.21 Epsilon = 0.894
# 94
# 125
# resultado da epoca 108 = -28124.65 Epsilon = 0.893
# 93
# 126
# resultado da epoca 109 = -65313.88 Epsilon = 0.892
# 93
# 126
# resultado da epoca 110 = -4595.06 Epsilon = 0.891
# 93
# 126
# resultado da epoca 111 = -63597.12 Epsilon = 0.890
# 87
# 132
# resultado da epoca 112 = -36397.20 Epsilon = 0.889
# 97
# 122
# resultado da epoca 113 = -50843.84 Epsilon = 0.888
# 89
# 130
# resultado da epoca 114 = -38687.47 Epsilon = 0.887
# 95
# 124
# resultado da epoca 115 = -23949.63 Epsilon = 0.886
# 94
# 125
# resultado da epoca 116 = -21776.80 Epsilon = 0.885
# 107
# 112
# resultado da epoca 117 = -28094.95 Epsilon = 0.884
# 100
# 119
# resultado da epoca 118 = -17359.94 Epsilon = 0.883
# 104
# 115
# resultado da epoca 119 = -19882.12 Epsilon = 0.882
# 101
# 118
# resultado da epoca 120 = -31444.20 Epsilon = 0.881
# 94
# 125
# resultado da epoca 121 = -12690.04 Epsilon = 0.880
# 99
# 120
# resultado da epoca 122 = -38722.74 Epsilon = 0.879
# 93
# 126
# resultado da epoca 123 = -25385.71 Epsilon = 0.878
# 100
# 119
# resultado da epoca 124 = -65509.11 Epsilon = 0.877
# 82
# 137
# resultado da epoca 125 = -52468.55 Epsilon = 0.876
# 93
# 126
# resultado da epoca 126 = -40152.28 Epsilon = 0.875
# 89
# 130
# resultado da epoca 127 = -22463.09 Epsilon = 0.874
# 100
# 119
# resultado da epoca 128 = -24990.30 Epsilon = 0.873
# 102
# 117
# resultado da epoca 129 = -35573.69 Epsilon = 0.872
# 90
# 129
# resultado da epoca 130 = -22651.50 Epsilon = 0.871
# 101
# 118
# resultado da epoca 131 = -45210.27 Epsilon = 0.870
# 90
# 129
# resultado da epoca 132 = -2177.49 Epsilon = 0.869
# 107
# 112
# resultado da epoca 133 = -16948.34 Epsilon = 0.868
# 98
# 121
# resultado da epoca 134 = -17564.80 Epsilon = 0.867
# 109
# 110
# resultado da epoca 135 = -7362.12 Epsilon = 0.866
# 108
# 111
# resultado da epoca 136 = -54484.37 Epsilon = 0.865
# 88
# 131
# resultado da epoca 137 = -36326.02 Epsilon = 0.864
# 90
# 129
# resultado da epoca 138 = -47792.65 Epsilon = 0.863
# 89
# 130
# resultado da epoca 139 = -31131.11 Epsilon = 0.862
# 95
# 124
# resultado da epoca 140 = -25841.18 Epsilon = 0.861
# 99
# 120
# resultado da epoca 141 = -18452.23 Epsilon = 0.860
# 106
# 113
# resultado da epoca 142 = -41254.30 Epsilon = 0.859
# 95
# 124
# resultado da epoca 143 = -38281.60 Epsilon = 0.858
# 95
# 124
# resultado da epoca 144 = -49942.77 Epsilon = 0.857
# 94
# 125
# resultado da epoca 145 = -36247.83 Epsilon = 0.856
# 94
# 125
# resultado da epoca 146 = -45413.53 Epsilon = 0.855
# 92
# 127
# resultado da epoca 147 = -17706.63 Epsilon = 0.854
# 102
# 117
# resultado da epoca 148 = -22161.48 Epsilon = 0.853
# 102
# 117
# resultado da epoca 149 = -27985.04 Epsilon = 0.852
# 101
# 118
# resultado da epoca 150 = -47055.62 Epsilon = 0.851
# 92
# 127
# resultado da epoca 151 = -12305.99 Epsilon = 0.851
# 102
# 117
# resultado da epoca 152 = -23017.35 Epsilon = 0.850
# 98
# 121
# resultado da epoca 153 = -35535.75 Epsilon = 0.849
# 103
# 116
# resultado da epoca 154 = -37576.51 Epsilon = 0.848
# 93
# 126
# resultado da epoca 155 = -62823.25 Epsilon = 0.847
# 90
# 129
# resultado da epoca 156 = -31516.72 Epsilon = 0.846
# 98
# 121
# resultado da epoca 157 = -26618.96 Epsilon = 0.845
# 100
# 119
# resultado da epoca 158 = -37930.59 Epsilon = 0.844
# 89
# 130
# resultado da epoca 159 = -21603.15 Epsilon = 0.843
# 103
# 116
# resultado da epoca 160 = -28449.24 Epsilon = 0.842
# 91
# 128
# resultado da epoca 161 = -42086.34 Epsilon = 0.841
# 89
# 130
# resultado da epoca 162 = -26411.37 Epsilon = 0.840
# 96
# 123
# resultado da epoca 163 = 5623.76 Epsilon = 0.839
# 113
# 106
# resultado da epoca 164 = -44160.25 Epsilon = 0.838
# 93
# 126
# resultado da epoca 165 = -20808.70 Epsilon = 0.837
# 97
# 122
# resultado da epoca 166 = -9669.08 Epsilon = 0.836
# 104
# 115
# resultado da epoca 167 = -32340.06 Epsilon = 0.835
# 91
# 128
# resultado da epoca 168 = -14895.49 Epsilon = 0.834
# 113
# 106
# resultado da epoca 169 = -18176.00 Epsilon = 0.833
# 104
# 115
# resultado da epoca 170 = -27023.32 Epsilon = 0.832
# 95
# 124
# resultado da epoca 171 = -27494.35 Epsilon = 0.831
# 97
# 122
# resultado da epoca 172 = -23265.12 Epsilon = 0.830
# 115
# 104
# resultado da epoca 173 = -13393.34 Epsilon = 0.829
# 98
# 121
# resultado da epoca 174 = -36646.54 Epsilon = 0.828
# 97
# 122
# resultado da epoca 175 = -16103.90 Epsilon = 0.827
# 102
# 117
# resultado da epoca 176 = -28146.73 Epsilon = 0.826
# 91
# 128
# resultado da epoca 177 = -19179.81 Epsilon = 0.825
# 102
# 117
# resultado da epoca 178 = -18257.05 Epsilon = 0.824
# 106
# 113
# resultado da epoca 179 = -31373.77 Epsilon = 0.823
# 95
# 124
# resultado da epoca 180 = -36927.02 Epsilon = 0.822
# 99
# 120
# resultado da epoca 181 = -35535.43 Epsilon = 0.821
# 82
# 137
# resultado da epoca 182 = -44380.80 Epsilon = 0.820
# 83
# 136
# resultado da epoca 183 = -19514.82 Epsilon = 0.819
# 101
# 118
# resultado da epoca 184 = -44125.56 Epsilon = 0.818
# 89
# 130
# resultado da epoca 185 = -26601.26 Epsilon = 0.817
# 90
# 129
# resultado da epoca 186 = -9263.15 Epsilon = 0.816
# 105
# 114
# resultado da epoca 187 = -15312.58 Epsilon = 0.815
# 106
# 113
# resultado da epoca 188 = -26299.13 Epsilon = 0.814
# 107
# 112
# resultado da epoca 189 = -41160.66 Epsilon = 0.813
# 89
# 130
# resultado da epoca 190 = -54592.86 Epsilon = 0.812
# 86
# 133
# resultado da epoca 191 = -15981.81 Epsilon = 0.811
# 105
# 114
# resultado da epoca 192 = -37478.18 Epsilon = 0.810
# 93
# 126
# resultado da epoca 193 = -38498.24 Epsilon = 0.809
# 87
# 132
# resultado da epoca 194 = -52321.64 Epsilon = 0.808
# 85
# 134
# resultado da epoca 195 = -26620.29 Epsilon = 0.807
# 97
# 122
# resultado da epoca 196 = -4827.00 Epsilon = 0.806
# 106
# 113
# resultado da epoca 197 = -22946.26 Epsilon = 0.805
# 99
# 120
# resultado da epoca 198 = -19779.68 Epsilon = 0.804
# 98
# 121
# resultado da epoca 199 = -26550.54 Epsilon = 0.803
# 98
# 121
# resultado da epoca 200 = -23051.61 Epsilon = 0.802
# 99
# 120
# resultado da epoca 201 = -41355.39 Epsilon = 0.801
# 98
# 121
# resultado da epoca 202 = -14797.70 Epsilon = 0.800
# 106
# 113
# resultado da epoca 203 = -24092.83 Epsilon = 0.799
# 101
# 118
# resultado da epoca 204 = -47623.56 Epsilon = 0.798
# 88
# 131
# resultado da epoca 205 = -18930.36 Epsilon = 0.797
# 97
# 122
# resultado da epoca 206 = -1553.04 Epsilon = 0.796
# 100
# 119
# resultado da epoca 207 = -16117.50 Epsilon = 0.795
# 103
# 116
# resultado da epoca 208 = -32514.69 Epsilon = 0.794
# 100
# 119
# resultado da epoca 209 = -60398.94 Epsilon = 0.793
# 88
# 131
# resultado da epoca 210 = -14809.47 Epsilon = 0.792
# 104
# 115
# resultado da epoca 211 = -25463.69 Epsilon = 0.791
# 107
# 112
# resultado da epoca 212 = -41865.19 Epsilon = 0.790
# 80
# 139
# resultado da epoca 213 = -42431.64 Epsilon = 0.789
# 96
# 123
# resultado da epoca 214 = -15594.67 Epsilon = 0.788
# 104
# 115
# resultado da epoca 215 = -37367.88 Epsilon = 0.787
# 90
# 129
# resultado da epoca 216 = -46442.79 Epsilon = 0.786
# 95
# 124
# resultado da epoca 217 = -38788.01 Epsilon = 0.785
# 99
# 120
# resultado da epoca 218 = -14642.18 Epsilon = 0.784
# 111
# 108
# resultado da epoca 219 = -22989.33 Epsilon = 0.783
# 102
# 117
# resultado da epoca 220 = -13078.99 Epsilon = 0.782
# 106
# 113
# resultado da epoca 221 = 9769.85 Epsilon = 0.781
# 111
# 108
# resultado da epoca 222 = -25992.58 Epsilon = 0.780
# 98
# 121
# resultado da epoca 223 = -31578.04 Epsilon = 0.779
# 95
# 124
# resultado da epoca 224 = -36834.91 Epsilon = 0.778
# 102
# 117
# resultado da epoca 225 = -7341.95 Epsilon = 0.777
# 109
# 110
# resultado da epoca 226 = -26457.21 Epsilon = 0.776
# 97
# 122
# resultado da epoca 227 = -9168.79 Epsilon = 0.775
# 108
# 111
# resultado da epoca 228 = -31921.97 Epsilon = 0.774
# 92
# 127
# resultado da epoca 229 = -26517.10 Epsilon = 0.773
# 98
# 121
# resultado da epoca 230 = -21625.30 Epsilon = 0.772
# 98
# 121
# resultado da epoca 231 = -16497.29 Epsilon = 0.771
# 101
# 118
# resultado da epoca 232 = -39203.57 Epsilon = 0.770
# 97
# 122
# resultado da epoca 233 = -17166.63 Epsilon = 0.769
# 110
# 109
# resultado da epoca 234 = -13829.05 Epsilon = 0.768
# 107
# 112
# resultado da epoca 235 = -31075.59 Epsilon = 0.767
# 104
# 115
# resultado da epoca 236 = 5433.09 Epsilon = 0.766
# 110
# 109
# resultado da epoca 237 = -9621.64 Epsilon = 0.765
# 103
# 116
# resultado da epoca 238 = -29675.23 Epsilon = 0.764
# 100
# 119
# resultado da epoca 239 = -23619.99 Epsilon = 0.763
# 101
# 118
# resultado da epoca 240 = -38787.02 Epsilon = 0.762
# 95
# 124
# resultado da epoca 241 = -9154.00 Epsilon = 0.761
# 106
# 113
# resultado da epoca 242 = -39363.34 Epsilon = 0.760
# 89
# 130
# resultado da epoca 243 = -21624.88 Epsilon = 0.759
# 104
# 115
# resultado da epoca 244 = -3129.62 Epsilon = 0.758
# 113
# 106
# resultado da epoca 245 = -24332.80 Epsilon = 0.757
# 103
# 116
# resultado da epoca 246 = -25999.19 Epsilon = 0.756
# 96
# 123
# resultado da epoca 247 = -7018.56 Epsilon = 0.755
# 107
# 112
# resultado da epoca 248 = -27204.10 Epsilon = 0.754
# 97
# 122
# resultado da epoca 249 = -5329.69 Epsilon = 0.753
# 107
# 112
# resultado da epoca 250 = -29640.09 Epsilon = 0.752
# 99
# 120
# resultado da epoca 251 = -10033.17 Epsilon = 0.752
# 106
# 113
# resultado da epoca 252 = -34384.92 Epsilon = 0.751
# 100
# 119
# resultado da epoca 253 = -1755.11 Epsilon = 0.750
# 111
# 108
# resultado da epoca 254 = -3593.37 Epsilon = 0.749
# 117
# 102
# resultado da epoca 255 = -1597.36 Epsilon = 0.748
# 108
# 111
# resultado da epoca 256 = -40733.70 Epsilon = 0.747
# 101
# 118
# resultado da epoca 257 = -51715.16 Epsilon = 0.746
# 99
# 120
# resultado da epoca 258 = -14721.82 Epsilon = 0.745
# 98
# 121
# resultado da epoca 259 = -35578.60 Epsilon = 0.744
# 100
# 119
# resultado da epoca 260 = -22405.03 Epsilon = 0.743
# 107
# 112
# resultado da epoca 261 = -22904.31 Epsilon = 0.742
# 108
# 111
# resultado da epoca 262 = -29805.25 Epsilon = 0.741
# 97
# 122
# resultado da epoca 263 = -8828.07 Epsilon = 0.740
# 116
# 103
# resultado da epoca 264 = -22963.03 Epsilon = 0.739
# 100
# 119
# resultado da epoca 265 = -7498.37 Epsilon = 0.738
# 102
# 117
# resultado da epoca 266 = -9538.63 Epsilon = 0.737
# 107
# 112
# resultado da epoca 267 = -11975.89 Epsilon = 0.736
# 108
# 111
# resultado da epoca 268 = -25210.24 Epsilon = 0.735
# 100
# 119
# resultado da epoca 269 = -11999.82 Epsilon = 0.734
# 106
# 113
# resultado da epoca 270 = -53093.65 Epsilon = 0.733
# 91
# 128
# resultado da epoca 271 = -4879.94 Epsilon = 0.732
# 105
# 114
# resultado da epoca 272 = -49704.56 Epsilon = 0.731
# 85
# 134
# resultado da epoca 273 = -120.33 Epsilon = 0.730
# 114
# 105
# resultado da epoca 274 = -17952.61 Epsilon = 0.729
# 107
# 112
# resultado da epoca 275 = -14203.01 Epsilon = 0.728
# 107
# 112
# resultado da epoca 276 = -13221.84 Epsilon = 0.727
# 109
# 110
# resultado da epoca 277 = -19419.97 Epsilon = 0.726
# 103
# 116
# resultado da epoca 278 = -29457.21 Epsilon = 0.725
# 98
# 121
# resultado da epoca 279 = -37880.53 Epsilon = 0.724
# 90
# 129
# resultado da epoca 280 = -32160.26 Epsilon = 0.723
# 98
# 121
# resultado da epoca 281 = -11428.42 Epsilon = 0.722
# 111
# 108
# resultado da epoca 282 = -27314.22 Epsilon = 0.721
# 94
# 125
# resultado da epoca 283 = -34589.56 Epsilon = 0.720
# 97
# 122
# resultado da epoca 284 = -4382.64 Epsilon = 0.719
# 101
# 118
# resultado da epoca 285 = -11489.67 Epsilon = 0.718
# 103
# 116
# resultado da epoca 286 = -33517.88 Epsilon = 0.717
# 99
# 120
# resultado da epoca 287 = -37300.83 Epsilon = 0.716
# 92
# 127
# resultado da epoca 288 = -22885.53 Epsilon = 0.715
# 104
# 115
# resultado da epoca 289 = -30584.23 Epsilon = 0.714
# 104
# 115
# resultado da epoca 290 = -24300.12 Epsilon = 0.713
# 109
# 110
# resultado da epoca 291 = -14290.60 Epsilon = 0.712
# 114
# 105
# resultado da epoca 292 = -17311.05 Epsilon = 0.711
# 103
# 116
# resultado da epoca 293 = -33340.18 Epsilon = 0.710
# 96
# 123
# resultado da epoca 294 = -8682.39 Epsilon = 0.709
# 99
# 120
# resultado da epoca 295 = -33739.20 Epsilon = 0.708
# 98
# 121
# resultado da epoca 296 = -19116.99 Epsilon = 0.707
# 99
# 120
# resultado da epoca 297 = -11343.59 Epsilon = 0.706
# 109
# 110
# resultado da epoca 298 = -43976.08 Epsilon = 0.705
# 98
# 121
# resultado da epoca 299 = -13620.14 Epsilon = 0.704
# 97
# 122
# resultado da epoca 300 = -17474.09 Epsilon = 0.703
# 99
# 120
# resultado da epoca 301 = -26222.52 Epsilon = 0.702
# 102
# 117
# resultado da epoca 302 = -43149.88 Epsilon = 0.701
# 84
# 135
# resultado da epoca 303 = -3143.73 Epsilon = 0.700
# 112
# 107
# resultado da epoca 304 = -56337.61 Epsilon = 0.699
# 89
# 130
# resultado da epoca 305 = -46506.03 Epsilon = 0.698
# 98
# 121
# resultado da epoca 306 = -42703.50 Epsilon = 0.697
# 93
# 126
# resultado da epoca 307 = -5175.82 Epsilon = 0.696
# 105
# 114
# resultado da epoca 308 = -25889.38 Epsilon = 0.695
# 100
# 119
# resultado da epoca 309 = -31911.00 Epsilon = 0.694
# 101
# 118
# resultado da epoca 310 = -40371.75 Epsilon = 0.693
# 97
# 122
# resultado da epoca 311 = -13518.86 Epsilon = 0.692
# 103
# 116
# resultado da epoca 312 = 16573.67 Epsilon = 0.691
# 121
# 98
# resultado da epoca 313 = -19653.04 Epsilon = 0.690
# 99
# 120
# resultado da epoca 314 = -33760.13 Epsilon = 0.689
# 101
# 118
# resultado da epoca 315 = -10154.62 Epsilon = 0.688
# 105
# 114
# resultado da epoca 316 = -6854.61 Epsilon = 0.687
# 106
# 113
# resultado da epoca 317 = 9756.36 Epsilon = 0.686
# 115
# 104
# resultado da epoca 318 = -26223.69 Epsilon = 0.685
# 101
# 118
# resultado da epoca 319 = -12249.38 Epsilon = 0.684
# 101
# 118
# resultado da epoca 320 = -19427.30 Epsilon = 0.683
# 105
# 114
# resultado da epoca 321 = 270.89 Epsilon = 0.682
# 117
# 102
# resultado da epoca 322 = -21375.81 Epsilon = 0.681
# 106
# 113
# resultado da epoca 323 = -26547.21 Epsilon = 0.680
# 104
# 115
# resultado da epoca 324 = -25294.71 Epsilon = 0.679
# 98
# 121
# resultado da epoca 325 = -37467.12 Epsilon = 0.678
# 98
# 121
# resultado da epoca 326 = -18451.63 Epsilon = 0.677
# 102
# 117
# resultado da epoca 327 = -2655.01 Epsilon = 0.676
# 119
# 100
# resultado da epoca 328 = -34101.09 Epsilon = 0.675
# 92
# 127
# resultado da epoca 329 = 945.30 Epsilon = 0.674
# 107
# 112
# resultado da epoca 330 = -21051.53 Epsilon = 0.673
# 94
# 125
# resultado da epoca 331 = -2896.35 Epsilon = 0.672
# 115
# 104
# resultado da epoca 332 = -8528.06 Epsilon = 0.671
# 108
# 111
# resultado da epoca 333 = 12373.01 Epsilon = 0.670
# 115
# 104
# resultado da epoca 334 = -14775.08 Epsilon = 0.669
# 104
# 115
# resultado da epoca 335 = -4429.15 Epsilon = 0.668
# 104
# 115
# resultado da epoca 336 = -6930.23 Epsilon = 0.667
# 106
# 113
# resultado da epoca 337 = -13272.08 Epsilon = 0.666
# 106
# 113
# resultado da epoca 338 = -21372.12 Epsilon = 0.665
# 100
# 119
# resultado da epoca 339 = -23199.91 Epsilon = 0.664
# 104
# 115
# resultado da epoca 340 = -4406.87 Epsilon = 0.663
# 108
# 111
# resultado da epoca 341 = -29640.01 Epsilon = 0.662
# 89
# 130
# resultado da epoca 342 = -5988.82 Epsilon = 0.661
# 103
# 116
# resultado da epoca 343 = -22239.39 Epsilon = 0.660
# 109
# 110
# resultado da epoca 344 = 7255.19 Epsilon = 0.659
# 111
# 108
# resultado da epoca 345 = -31792.80 Epsilon = 0.658
# 101
# 118
# resultado da epoca 346 = -52713.96 Epsilon = 0.657
# 90
# 129
# resultado da epoca 347 = -19836.78 Epsilon = 0.656
# 99
# 120
# resultado da epoca 348 = -22626.48 Epsilon = 0.655
# 95
# 124
# resultado da epoca 349 = -30261.14 Epsilon = 0.654
# 102
# 117
# resultado da epoca 350 = -15166.88 Epsilon = 0.653
# 107
# 112
# resultado da epoca 351 = -23656.17 Epsilon = 0.653
# 104
# 115
# resultado da epoca 352 = -31903.55 Epsilon = 0.652
# 110
# 109
# resultado da epoca 353 = -24275.59 Epsilon = 0.651
# 94
# 125
# resultado da epoca 354 = -45786.75 Epsilon = 0.650
# 97
# 122
# resultado da epoca 355 = -18904.40 Epsilon = 0.649
# 111
# 108
# resultado da epoca 356 = -32589.11 Epsilon = 0.648
# 100
# 119
# resultado da epoca 357 = -31076.97 Epsilon = 0.647
# 92
# 127
# resultado da epoca 358 = -16943.19 Epsilon = 0.646
# 110
# 109
# resultado da epoca 359 = -17814.78 Epsilon = 0.645
# 98
# 121
# resultado da epoca 360 = -35374.70 Epsilon = 0.644
# 95
# 124
# resultado da epoca 361 = -35551.58 Epsilon = 0.643
# 96
# 123
# resultado da epoca 362 = -4332.77 Epsilon = 0.642
# 109
# 110
# resultado da epoca 363 = -31464.34 Epsilon = 0.641
# 100
# 119
# resultado da epoca 364 = -16297.05 Epsilon = 0.640
# 101
# 118
# resultado da epoca 365 = -43157.31 Epsilon = 0.639
# 97
# 122
# resultado da epoca 366 = -35818.37 Epsilon = 0.638
# 92
# 127
# resultado da epoca 367 = -16008.47 Epsilon = 0.637
# 107
# 112
# resultado da epoca 368 = -11443.15 Epsilon = 0.636
# 110
# 109
# resultado da epoca 369 = -14245.66 Epsilon = 0.635
# 100
# 119
# resultado da epoca 370 = -7649.60 Epsilon = 0.634
# 107
# 112
# resultado da epoca 371 = -9877.30 Epsilon = 0.633
# 102
# 117
# resultado da epoca 372 = -27905.78 Epsilon = 0.632
# 101
# 118
# resultado da epoca 373 = -13732.18 Epsilon = 0.631
# 106
# 113
# resultado da epoca 374 = -25620.94 Epsilon = 0.630
# 100
# 119
# resultado da epoca 375 = -12657.51 Epsilon = 0.629
# 105
# 114
# resultado da epoca 376 = -17724.03 Epsilon = 0.628
# 100
# 119
# resultado da epoca 377 = -2055.32 Epsilon = 0.627
# 110
# 109
# resultado da epoca 378 = -43224.96 Epsilon = 0.626
# 91
# 128
# resultado da epoca 379 = -23401.17 Epsilon = 0.625
# 102
# 117
# resultado da epoca 380 = -3107.69 Epsilon = 0.624
# 101
# 118
# resultado da epoca 381 = -28118.97 Epsilon = 0.623
# 100
# 119
# resultado da epoca 382 = -319.73 Epsilon = 0.622
# 104
# 115
# resultado da epoca 383 = -39986.15 Epsilon = 0.621
# 108
# 111
# resultado da epoca 384 = -7273.05 Epsilon = 0.620
# 111
# 108
# resultado da epoca 385 = -5654.10 Epsilon = 0.619
# 109
# 110
# resultado da epoca 386 = -25875.04 Epsilon = 0.618
# 103
# 116
# resultado da epoca 387 = -35870.68 Epsilon = 0.617
# 100
# 119
# resultado da epoca 388 = -24329.60 Epsilon = 0.616
# 102
# 117
# resultado da epoca 389 = -40120.36 Epsilon = 0.615
# 97
# 122
# resultado da epoca 390 = -27598.71 Epsilon = 0.614
# 104
# 115
# resultado da epoca 391 = -13373.68 Epsilon = 0.613
# 96
# 123
# resultado da epoca 392 = -204.63 Epsilon = 0.612
# 114
# 105
# resultado da epoca 393 = -15398.92 Epsilon = 0.611
# 106
# 113
# resultado da epoca 394 = -13135.55 Epsilon = 0.610
# 110
# 109
# resultado da epoca 395 = -39578.26 Epsilon = 0.609
# 91
# 128
# resultado da epoca 396 = -32844.53 Epsilon = 0.608
# 99
# 120
# resultado da epoca 397 = -38255.87 Epsilon = 0.607
# 90
# 129
# resultado da epoca 398 = -22501.51 Epsilon = 0.606
# 102
# 117
# resultado da epoca 399 = -17986.36 Epsilon = 0.605
# 96
# 123
# resultado da epoca 400 = -45896.23 Epsilon = 0.604
# 98
# 121
# resultado da epoca 401 = -25267.57 Epsilon = 0.603
# 95
# 124
# resultado da epoca 402 = -24401.18 Epsilon = 0.602
# 110
# 109
# resultado da epoca 403 = -46426.63 Epsilon = 0.601
# 91
# 128
# resultado da epoca 404 = -35303.28 Epsilon = 0.600
# 101
# 118
# resultado da epoca 405 = -11140.48 Epsilon = 0.599
# 107
# 112
# resultado da epoca 406 = -4435.46 Epsilon = 0.598
# 114
# 105
# resultado da epoca 407 = -21713.46 Epsilon = 0.597
# 109
# 110
# resultado da epoca 408 = -26958.70 Epsilon = 0.596
# 103
# 116
# resultado da epoca 409 = -13982.31 Epsilon = 0.595
# 110
# 109
# resultado da epoca 410 = -13797.01 Epsilon = 0.594
# 104
# 115
# resultado da epoca 411 = -30443.27 Epsilon = 0.593
# 96
# 123
# resultado da epoca 412 = -37222.92 Epsilon = 0.592
# 93
# 126
# resultado da epoca 413 = -26196.99 Epsilon = 0.591
# 92
# 127
# resultado da epoca 414 = -18073.32 Epsilon = 0.590
# 109
# 110
# resultado da epoca 415 = -25214.15 Epsilon = 0.589
# 97
# 122
# resultado da epoca 416 = -27709.33 Epsilon = 0.588
# 99
# 120
# resultado da epoca 417 = 2881.09 Epsilon = 0.587
# 115
# 104
# resultado da epoca 418 = -16556.61 Epsilon = 0.586
# 101
# 118
# resultado da epoca 419 = 5150.67 Epsilon = 0.585
# 106
# 113
# resultado da epoca 420 = -32219.27 Epsilon = 0.584
# 99
# 120
# resultado da epoca 421 = -18085.72 Epsilon = 0.583
# 103
# 116
# resultado da epoca 422 = -17898.23 Epsilon = 0.582
# 98
# 121
# resultado da epoca 423 = -33118.77 Epsilon = 0.581
# 101
# 118
# resultado da epoca 424 = -19136.21 Epsilon = 0.580
# 102
# 117
# resultado da epoca 425 = -9084.28 Epsilon = 0.579
# 104
# 115
# resultado da epoca 426 = -14240.79 Epsilon = 0.578
# 105
# 114
# resultado da epoca 427 = -7950.77 Epsilon = 0.577
# 111
# 108
# resultado da epoca 428 = -32879.83 Epsilon = 0.576
# 99
# 120
# resultado da epoca 429 = -19522.71 Epsilon = 0.575
# 97
# 122
# resultado da epoca 430 = -34906.31 Epsilon = 0.574
# 93
# 126
# resultado da epoca 431 = -7573.05 Epsilon = 0.573
# 98
# 121
# resultado da epoca 432 = -6994.07 Epsilon = 0.572
# 110
# 109
# resultado da epoca 433 = -28647.52 Epsilon = 0.571
# 93
# 126
# resultado da epoca 434 = -23087.21 Epsilon = 0.570
# 93
# 126
# resultado da epoca 435 = -23176.29 Epsilon = 0.569
# 105
# 114
# resultado da epoca 436 = -17186.19 Epsilon = 0.568
# 98
# 121
# resultado da epoca 437 = 26052.68 Epsilon = 0.567
# 127
# 92
# resultado da epoca 438 = 3408.01 Epsilon = 0.566
# 105
# 114
# resultado da epoca 439 = -296.70 Epsilon = 0.565
# 110
# 109
# resultado da epoca 440 = 18608.76 Epsilon = 0.564
# 119
# 100
# resultado da epoca 441 = -17247.47 Epsilon = 0.563
# 110
# 109
# resultado da epoca 442 = -19662.68 Epsilon = 0.562
# 109
# 110
# resultado da epoca 443 = 5060.29 Epsilon = 0.561
# 110
# 109
# resultado da epoca 444 = -26947.89 Epsilon = 0.560
# 103
# 116
# resultado da epoca 445 = -1446.67 Epsilon = 0.559
# 110
# 109
# resultado da epoca 446 = 4001.59 Epsilon = 0.558
# 115
# 104
# resultado da epoca 447 = -29056.19 Epsilon = 0.557
# 100
# 119
# resultado da epoca 448 = -18540.52 Epsilon = 0.556
# 111
# 108
# resultado da epoca 449 = -23753.64 Epsilon = 0.555
# 101
# 118
# resultado da epoca 450 = -1213.68 Epsilon = 0.554
# 110
# 109
# resultado da epoca 451 = -26005.57 Epsilon = 0.554
# 99
# 120
# resultado da epoca 452 = -15724.38 Epsilon = 0.553
# 102
# 117
# resultado da epoca 453 = -4000.04 Epsilon = 0.552
# 117
# 102
# resultado da epoca 454 = -44245.20 Epsilon = 0.551
# 91
# 128
# resultado da epoca 455 = -5828.16 Epsilon = 0.550
# 115
# 104
# resultado da epoca 456 = 9757.34 Epsilon = 0.549
# 119
# 100
# resultado da epoca 457 = -49858.16 Epsilon = 0.548
# 87
# 132
# resultado da epoca 458 = -13714.94 Epsilon = 0.547
# 106
# 113
# resultado da epoca 459 = -41150.87 Epsilon = 0.546
# 92
# 127
# resultado da epoca 460 = -16957.53 Epsilon = 0.545
# 106
# 113
# resultado da epoca 461 = -35868.53 Epsilon = 0.544
# 99
# 120
# resultado da epoca 462 = 14706.11 Epsilon = 0.543
# 112
# 107
# resultado da epoca 463 = 9612.11 Epsilon = 0.542
# 121
# 98
# resultado da epoca 464 = -36214.91 Epsilon = 0.541
# 95
# 124
# resultado da epoca 465 = -24456.86 Epsilon = 0.540
# 105
# 114
# resultado da epoca 466 = -4563.93 Epsilon = 0.539
# 109
# 110
# resultado da epoca 467 = -47733.09 Epsilon = 0.538
# 91
# 128
# resultado da epoca 468 = -35392.05 Epsilon = 0.537
# 95
# 124
# resultado da epoca 469 = -24274.83 Epsilon = 0.536
# 100
# 119
# resultado da epoca 470 = -43996.81 Epsilon = 0.535
# 95
# 124
# resultado da epoca 471 = -19859.11 Epsilon = 0.534
# 103
# 116
# resultado da epoca 472 = -23253.36 Epsilon = 0.533
# 105
# 114
# resultado da epoca 473 = -15876.67 Epsilon = 0.532
# 93
# 126
# resultado da epoca 474 = -20259.80 Epsilon = 0.531
# 104
# 115
# resultado da epoca 475 = -38987.63 Epsilon = 0.530
# 98
# 121
# resultado da epoca 476 = -5955.91 Epsilon = 0.529
# 110
# 109
# resultado da epoca 477 = -52295.79 Epsilon = 0.528
# 94
# 125
# resultado da epoca 478 = -5874.04 Epsilon = 0.527
# 101
# 118
# resultado da epoca 479 = -8879.12 Epsilon = 0.526
# 112
# 107
# resultado da epoca 480 = -27468.37 Epsilon = 0.525
# 107
# 112
# resultado da epoca 481 = -11974.62 Epsilon = 0.524
# 102
# 117
# resultado da epoca 482 = 506.44 Epsilon = 0.523
# 108
# 111
# resultado da epoca 483 = -5098.23 Epsilon = 0.522
# 103
# 116
# resultado da epoca 484 = -17531.62 Epsilon = 0.521
# 108
# 111
# resultado da epoca 485 = -14973.51 Epsilon = 0.520
# 106
# 113
# resultado da epoca 486 = -36168.70 Epsilon = 0.519
# 91
# 128
# resultado da epoca 487 = -16495.66 Epsilon = 0.518
# 101
# 118
# resultado da epoca 488 = -29996.91 Epsilon = 0.517
# 96
# 123
# resultado da epoca 489 = -42228.49 Epsilon = 0.516
# 97
# 122
# resultado da epoca 490 = 3154.12 Epsilon = 0.515
# 103
# 116
# resultado da epoca 491 = -19185.81 Epsilon = 0.514
# 99
# 120
# resultado da epoca 492 = -31859.52 Epsilon = 0.513
# 98
# 121
# resultado da epoca 493 = -21095.00 Epsilon = 0.512
# 112
# 107
# resultado da epoca 494 = -27321.64 Epsilon = 0.511
# 96
# 123
# resultado da epoca 495 = -40373.23 Epsilon = 0.510
# 97
# 122
# resultado da epoca 496 = -42435.39 Epsilon = 0.509
# 84
# 135
# resultado da epoca 497 = 7753.73 Epsilon = 0.508
# 112
# 107
# resultado da epoca 498 = -13549.98 Epsilon = 0.507
# 110
# 109
# resultado da epoca 499 = 6248.23 Epsilon = 0.506
# 112
# 107
# resultado da epoca 500 = -14984.48 Epsilon = 0.505
# 110
# 109
# resultado da epoca 501 = -38361.46 Epsilon = 0.504
# 88
# 131
# resultado da epoca 502 = -34609.80 Epsilon = 0.503
# 89
# 130
# resultado da epoca 503 = -13069.31 Epsilon = 0.502
# 98
# 121
# resultado da epoca 504 = 1311.19 Epsilon = 0.501
# 108
# 111
# resultado da epoca 505 = -29744.24 Epsilon = 0.500
# 94
# 125
# resultado da epoca 506 = -3379.20 Epsilon = 0.499
# 107
# 112
# resultado da epoca 507 = -7361.11 Epsilon = 0.498
# 107
# 112
# resultado da epoca 508 = -33577.90 Epsilon = 0.497
# 95
# 124
# resultado da epoca 509 = -30124.41 Epsilon = 0.496
# 101
# 118
# resultado da epoca 510 = -25462.70 Epsilon = 0.495
# 102
# 117
# resultado da epoca 511 = -27821.42 Epsilon = 0.494
# 97
# 122
# resultado da epoca 512 = 4205.47 Epsilon = 0.493
# 116
# 103
# resultado da epoca 513 = -29654.75 Epsilon = 0.492
# 93
# 126
# resultado da epoca 514 = -13960.30 Epsilon = 0.491
# 114
# 105
# resultado da epoca 515 = -32014.70 Epsilon = 0.490
# 102
# 117
# resultado da epoca 516 = -44727.95 Epsilon = 0.489
# 89
# 130
# resultado da epoca 517 = -24855.79 Epsilon = 0.488
# 100
# 119
# resultado da epoca 518 = -29747.26 Epsilon = 0.487
# 96
# 123
# resultado da epoca 519 = -16504.78 Epsilon = 0.486
# 101
# 118
# resultado da epoca 520 = 8023.02 Epsilon = 0.485
# 113
# 106
# resultado da epoca 521 = -281.09 Epsilon = 0.484
# 107
# 112
# resultado da epoca 522 = -35940.86 Epsilon = 0.483
# 90
# 129
# resultado da epoca 523 = 18512.18 Epsilon = 0.482
# 119
# 100
# resultado da epoca 524 = -14119.15 Epsilon = 0.481
# 105
# 114
# resultado da epoca 525 = -21687.10 Epsilon = 0.480
# 100
# 119
# resultado da epoca 526 = -15825.19 Epsilon = 0.479
# 104
# 115
# resultado da epoca 527 = -11381.20 Epsilon = 0.478
# 106
# 113
# resultado da epoca 528 = -11480.46 Epsilon = 0.477
# 116
# 103
# resultado da epoca 529 = -5330.79 Epsilon = 0.476
# 107
# 112
# resultado da epoca 530 = -615.06 Epsilon = 0.475
# 115
# 104
# resultado da epoca 531 = -8090.20 Epsilon = 0.474
# 113
# 106
# resultado da epoca 532 = -6538.02 Epsilon = 0.473
# 114
# 105
# resultado da epoca 533 = -54595.01 Epsilon = 0.472
# 88
# 131
# resultado da epoca 534 = -30097.57 Epsilon = 0.471
# 102
# 117
# resultado da epoca 535 = -5293.40 Epsilon = 0.470
# 114
# 105
# resultado da epoca 536 = 1856.65 Epsilon = 0.469
# 107
# 112
# resultado da epoca 537 = 5351.07 Epsilon = 0.468
# 112
# 107
# resultado da epoca 538 = 1510.68 Epsilon = 0.467
# 107
# 112
# resultado da epoca 539 = 16421.10 Epsilon = 0.466
# 109
# 110
# resultado da epoca 540 = -15731.88 Epsilon = 0.465
# 105
# 114
# resultado da epoca 541 = -13832.44 Epsilon = 0.464
# 104
# 115
# resultado da epoca 542 = 14630.06 Epsilon = 0.463
# 115
# 104
# resultado da epoca 543 = -12278.66 Epsilon = 0.462
# 107
# 112
# resultado da epoca 544 = -17489.35 Epsilon = 0.461
# 98
# 121
# resultado da epoca 545 = -23996.60 Epsilon = 0.460
# 100
# 119
# resultado da epoca 546 = -22590.86 Epsilon = 0.459
# 107
# 112
# resultado da epoca 547 = -35801.41 Epsilon = 0.458
# 102
# 117
# resultado da epoca 548 = -74375.13 Epsilon = 0.457
# 86
# 133
# resultado da epoca 549 = -44960.09 Epsilon = 0.456
# 91
# 128
# resultado da epoca 550 = 7225.38 Epsilon = 0.455
# 116
# 103
# resultado da epoca 551 = -21164.43 Epsilon = 0.455
# 99
# 120
# resultado da epoca 552 = 5405.83 Epsilon = 0.454
# 112
# 107
# resultado da epoca 553 = -17550.97 Epsilon = 0.453
# 104
# 115
# resultado da epoca 554 = -1872.20 Epsilon = 0.452
# 107
# 112
# resultado da epoca 555 = -792.93 Epsilon = 0.451
# 114
# 105
# resultado da epoca 556 = -30504.24 Epsilon = 0.450
# 95
# 124
# resultado da epoca 557 = -15560.59 Epsilon = 0.449
# 106
# 113
# resultado da epoca 558 = -14220.28 Epsilon = 0.448
# 112
# 107
# resultado da epoca 559 = -3482.86 Epsilon = 0.447
# 112
# 107
# resultado da epoca 560 = 6233.06 Epsilon = 0.446
# 114
# 105
# resultado da epoca 561 = -20013.47 Epsilon = 0.445
# 106
# 113
# resultado da epoca 562 = 11271.29 Epsilon = 0.444
# 117
# 102
# resultado da epoca 563 = -10400.31 Epsilon = 0.443
# 99
# 120
# resultado da epoca 564 = -4155.34 Epsilon = 0.442
# 107
# 112
# resultado da epoca 565 = 444.75 Epsilon = 0.441
# 111
# 108
# resultado da epoca 566 = 9731.92 Epsilon = 0.440
# 107
# 112
# resultado da epoca 567 = -1473.50 Epsilon = 0.439
# 114
# 105
# resultado da epoca 568 = 2042.52 Epsilon = 0.438
# 119
# 100
# resultado da epoca 569 = -9820.38 Epsilon = 0.437
# 103
# 116
# resultado da epoca 570 = -1992.47 Epsilon = 0.436
# 105
# 114
# resultado da epoca 571 = -26032.43 Epsilon = 0.435
# 95
# 124
# resultado da epoca 572 = -5934.55 Epsilon = 0.434
# 104
# 115
# resultado da epoca 573 = -31230.94 Epsilon = 0.433
# 98
# 121
# resultado da epoca 574 = -6272.76 Epsilon = 0.432
# 105
# 114
# resultado da epoca 575 = -18984.95 Epsilon = 0.431
# 100
# 119
# resultado da epoca 576 = -38635.26 Epsilon = 0.430
# 95
# 124
# resultado da epoca 577 = -20636.44 Epsilon = 0.429
# 95
# 124
# resultado da epoca 578 = -17971.22 Epsilon = 0.428
# 111
# 108
# resultado da epoca 579 = -30708.47 Epsilon = 0.427
# 95
# 124
# resultado da epoca 580 = -38904.58 Epsilon = 0.426
# 90
# 129
# resultado da epoca 581 = -2407.26 Epsilon = 0.425
# 108
# 111
# resultado da epoca 582 = -16520.62 Epsilon = 0.424
# 99
# 120
# resultado da epoca 583 = -33681.78 Epsilon = 0.423
# 101
# 118
# resultado da epoca 584 = -18666.40 Epsilon = 0.422
# 94
# 125
# resultado da epoca 585 = -34157.25 Epsilon = 0.421
# 96
# 123
# resultado da epoca 586 = -22471.49 Epsilon = 0.420
# 104
# 115
# resultado da epoca 587 = -38625.62 Epsilon = 0.419
# 105
# 114
# resultado da epoca 588 = -32307.91 Epsilon = 0.418
# 98
# 121
# resultado da epoca 589 = -2939.29 Epsilon = 0.417
# 114
# 105
# resultado da epoca 590 = -6865.88 Epsilon = 0.416
# 109
# 110
# resultado da epoca 591 = -12590.50 Epsilon = 0.415
# 103
# 116
# resultado da epoca 592 = -34237.46 Epsilon = 0.414
# 89
# 130
# resultado da epoca 593 = -21052.87 Epsilon = 0.413
# 109
# 110
# resultado da epoca 594 = -31631.19 Epsilon = 0.412
# 104
# 115
# resultado da epoca 595 = -40329.12 Epsilon = 0.411
# 88
# 131
# resultado da epoca 596 = -45069.34 Epsilon = 0.410
# 90
# 129
# resultado da epoca 597 = -18420.45 Epsilon = 0.409
# 96
# 123
# resultado da epoca 598 = -28650.38 Epsilon = 0.408
# 102
# 117
# resultado da epoca 599 = -40210.22 Epsilon = 0.407
# 97
# 122
# resultado da epoca 600 = -14268.43 Epsilon = 0.406
# 106
# 113
# resultado da epoca 601 = -23873.07 Epsilon = 0.405
# 98
# 121
# resultado da epoca 602 = -45451.90 Epsilon = 0.404
# 92
# 127
# resultado da epoca 603 = -15555.75 Epsilon = 0.403
# 104
# 115
# resultado da epoca 604 = -29441.68 Epsilon = 0.402
# 100
# 119
# resultado da epoca 605 = -11823.64 Epsilon = 0.401
# 106
# 113
# resultado da epoca 606 = -8086.38 Epsilon = 0.400
# 108
# 111
# resultado da epoca 607 = -12442.15 Epsilon = 0.399
# 104
# 115
# resultado da epoca 608 = -5045.17 Epsilon = 0.398
# 101
# 118
# resultado da epoca 609 = 3595.57 Epsilon = 0.397
# 107
# 112
# resultado da epoca 610 = -29974.95 Epsilon = 0.396
# 91
# 128
# resultado da epoca 611 = -5049.47 Epsilon = 0.395
# 104
# 115
# resultado da epoca 612 = -15796.20 Epsilon = 0.394
# 98
# 121
# resultado da epoca 613 = 4848.71 Epsilon = 0.393
# 112
# 107
# resultado da epoca 614 = -17444.94 Epsilon = 0.392
# 111
# 108
# resultado da epoca 615 = -15461.10 Epsilon = 0.391
# 101
# 118
# resultado da epoca 616 = -14159.06 Epsilon = 0.390
# 112
# 107
# resultado da epoca 617 = -24401.50 Epsilon = 0.389
# 97
# 122
# resultado da epoca 618 = -21430.66 Epsilon = 0.388
# 102
# 117
# resultado da epoca 619 = -40493.02 Epsilon = 0.387
# 87
# 132
# resultado da epoca 620 = -15825.95 Epsilon = 0.386
# 111
# 108
# resultado da epoca 621 = -29870.66 Epsilon = 0.385
# 99
# 120
# resultado da epoca 622 = -3820.55 Epsilon = 0.384
# 107
# 112
# resultado da epoca 623 = -13756.04 Epsilon = 0.383
# 101
# 118
# resultado da epoca 624 = -9775.82 Epsilon = 0.382
# 101
# 118
# resultado da epoca 625 = -15598.26 Epsilon = 0.381
# 96
# 123
# resultado da epoca 626 = -36511.86 Epsilon = 0.380
# 98
# 121
# resultado da epoca 627 = -5545.62 Epsilon = 0.379
# 100
# 119
# resultado da epoca 628 = -20244.36 Epsilon = 0.378
# 99
# 120
# resultado da epoca 629 = -19594.22 Epsilon = 0.377
# 97
# 122
# resultado da epoca 630 = -11871.72 Epsilon = 0.376
# 103
# 116
# resultado da epoca 631 = -14751.98 Epsilon = 0.375
# 103
# 116
# resultado da epoca 632 = -13856.15 Epsilon = 0.374
# 102
# 117
# resultado da epoca 633 = -11782.11 Epsilon = 0.373
# 99
# 120
# resultado da epoca 634 = -19128.55 Epsilon = 0.372
# 96
# 123
# resultado da epoca 635 = -906.82 Epsilon = 0.371
# 103
# 116
# resultado da epoca 636 = -17789.42 Epsilon = 0.370
# 104
# 115
# resultado da epoca 637 = -3328.36 Epsilon = 0.369
# 109
# 110
# resultado da epoca 638 = 6760.08 Epsilon = 0.368
# 112
# 107
# resultado da epoca 639 = -11092.11 Epsilon = 0.367
# 103
# 116
# resultado da epoca 640 = -1126.05 Epsilon = 0.366
# 107
# 112
# resultado da epoca 641 = -12363.31 Epsilon = 0.365
# 95
# 124
# resultado da epoca 642 = 3247.80 Epsilon = 0.364
# 112
# 107
# resultado da epoca 643 = -37143.71 Epsilon = 0.363
# 97
# 122
# resultado da epoca 644 = -33316.29 Epsilon = 0.362
# 91
# 128
# resultado da epoca 645 = -49574.23 Epsilon = 0.361
# 89
# 130
# resultado da epoca 646 = -16707.58 Epsilon = 0.360
# 107
# 112
# resultado da epoca 647 = -26190.57 Epsilon = 0.359
# 113
# 106
# resultado da epoca 648 = -17745.42 Epsilon = 0.358
# 100
# 119
# resultado da epoca 649 = -4314.96 Epsilon = 0.357
# 109
# 110
# resultado da epoca 650 = -32304.15 Epsilon = 0.356
# 98
# 121
# resultado da epoca 651 = -14791.91 Epsilon = 0.356
# 105
# 114
# resultado da epoca 652 = -6313.50 Epsilon = 0.355
# 103
# 116
# resultado da epoca 653 = -12943.90 Epsilon = 0.354
# 101
# 118
# resultado da epoca 654 = -10558.34 Epsilon = 0.353
# 105
# 114
# resultado da epoca 655 = -20301.04 Epsilon = 0.352
# 100
# 119
# resultado da epoca 656 = -16050.74 Epsilon = 0.351
# 101
# 118
# resultado da epoca 657 = -2999.07 Epsilon = 0.350
# 114
# 105
# resultado da epoca 658 = -10222.19 Epsilon = 0.349
# 107
# 112
# resultado da epoca 659 = -3534.14 Epsilon = 0.348
# 107
# 112
# resultado da epoca 660 = -10491.38 Epsilon = 0.347
# 105
# 114
# resultado da epoca 661 = -13562.18 Epsilon = 0.346
# 105
# 114
# resultado da epoca 662 = -9409.90 Epsilon = 0.345
# 107
# 112
# resultado da epoca 663 = -5.60 Epsilon = 0.344
# 107
# 112
# resultado da epoca 664 = -17199.07 Epsilon = 0.343
# 102
# 117
# resultado da epoca 665 = -27661.81 Epsilon = 0.342
# 101
# 118
# resultado da epoca 666 = -30860.90 Epsilon = 0.341
# 105
# 114
# resultado da epoca 667 = -5211.71 Epsilon = 0.340
# 112
# 107
# resultado da epoca 668 = -17043.17 Epsilon = 0.339
# 100
# 119
# resultado da epoca 669 = -10103.71 Epsilon = 0.338
# 109
# 110
# resultado da epoca 670 = -21783.39 Epsilon = 0.337
# 101
# 118
# resultado da epoca 671 = -16467.72 Epsilon = 0.336
# 111
# 108
# resultado da epoca 672 = 13850.42 Epsilon = 0.335
# 124
# 95
# resultado da epoca 673 = 24517.02 Epsilon = 0.334
# 121
# 98
# resultado da epoca 674 = -9310.94 Epsilon = 0.333
# 110
# 109
# resultado da epoca 675 = -5170.61 Epsilon = 0.332
# 111
# 108
# resultado da epoca 676 = -20854.18 Epsilon = 0.331
# 99
# 120
# resultado da epoca 677 = 9558.54 Epsilon = 0.330
# 118
# 101
# resultado da epoca 678 = -2275.48 Epsilon = 0.329
# 103
# 116
# resultado da epoca 679 = -2983.87 Epsilon = 0.328
# 103
# 116
# resultado da epoca 680 = 4618.97 Epsilon = 0.327
# 112
# 107
# resultado da epoca 681 = 763.09 Epsilon = 0.326
# 118
# 101
# resultado da epoca 682 = -27346.71 Epsilon = 0.325
# 105
# 114
# resultado da epoca 683 = 2987.43 Epsilon = 0.324
# 114
# 105
# resultado da epoca 684 = -8391.55 Epsilon = 0.323
# 106
# 113
# resultado da epoca 685 = 7334.67 Epsilon = 0.322
# 124
# 95
# resultado da epoca 686 = -22824.65 Epsilon = 0.321
# 108
# 111
# resultado da epoca 687 = 4492.59 Epsilon = 0.320
# 115
# 104
# resultado da epoca 688 = -23270.99 Epsilon = 0.319
# 98
# 121
# resultado da epoca 689 = -6743.85 Epsilon = 0.318
# 114
# 105
# resultado da epoca 690 = -3913.28 Epsilon = 0.317
# 113
# 106
# resultado da epoca 691 = -9590.62 Epsilon = 0.316
# 110
# 109
# resultado da epoca 692 = -30901.86 Epsilon = 0.315
# 97
# 122
# resultado da epoca 693 = -1641.63 Epsilon = 0.314
# 110
# 109
# resultado da epoca 694 = 6563.17 Epsilon = 0.313
# 116
# 103
# resultado da epoca 695 = 289.50 Epsilon = 0.312
# 116
# 103
# resultado da epoca 696 = -2678.59 Epsilon = 0.311
# 113
# 106
# resultado da epoca 697 = -27939.77 Epsilon = 0.310
# 98
# 121
# resultado da epoca 698 = -12675.29 Epsilon = 0.309
# 102
# 117
# resultado da epoca 699 = 12001.98 Epsilon = 0.308
# 115
# 104
# resultado da epoca 700 = -17605.17 Epsilon = 0.307
# 110
# 109
# resultado da epoca 701 = -285.13 Epsilon = 0.306
# 108
# 111
# resultado da epoca 702 = 16474.73 Epsilon = 0.305
# 112
# 107
# resultado da epoca 703 = 27376.84 Epsilon = 0.304
# 117
# 102
# resultado da epoca 704 = -8048.20 Epsilon = 0.303
# 110
# 109
# resultado da epoca 705 = 18555.80 Epsilon = 0.302
# 119
# 100
# resultado da epoca 706 = 28558.81 Epsilon = 0.301
# 116
# 103
# resultado da epoca 707 = 17798.18 Epsilon = 0.300
# 120
# 99
# resultado da epoca 708 = 24823.76 Epsilon = 0.299
# 115
# 104
# resultado da epoca 709 = 13864.12 Epsilon = 0.298
# 114
# 105
# resultado da epoca 710 = 8040.88 Epsilon = 0.297
# 114
# 105
# resultado da epoca 711 = 8880.10 Epsilon = 0.296
# 123
# 96
# resultado da epoca 712 = 7742.26 Epsilon = 0.295
# 113
# 106
# resultado da epoca 713 = 35580.73 Epsilon = 0.294
# 125
# 94
# resultado da epoca 714 = 3113.71 Epsilon = 0.293
# 116
# 103
# resultado da epoca 715 = 14117.50 Epsilon = 0.292
# 115
# 104
# resultado da epoca 716 = 12461.99 Epsilon = 0.291
# 110
# 109
# resultado da epoca 717 = 18829.10 Epsilon = 0.290
# 114
# 105
# resultado da epoca 718 = 14101.00 Epsilon = 0.289
# 117
# 102
# resultado da epoca 719 = 14640.16 Epsilon = 0.288
# 124
# 95
# resultado da epoca 720 = 3133.91 Epsilon = 0.287
# 120
# 99
# resultado da epoca 721 = -1536.96 Epsilon = 0.286
# 115
# 104
# resultado da epoca 722 = 29719.56 Epsilon = 0.285
# 119
# 100
# resultado da epoca 723 = -8726.78 Epsilon = 0.284
# 108
# 111
# resultado da epoca 724 = 20867.31 Epsilon = 0.283
# 119
# 100
# resultado da epoca 725 = -10991.59 Epsilon = 0.282
# 112
# 107
# resultado da epoca 726 = 22230.60 Epsilon = 0.281
# 123
# 96
# resultado da epoca 727 = -20411.58 Epsilon = 0.280
# 104
# 115
# resultado da epoca 728 = -8552.38 Epsilon = 0.279
# 104
# 115
# resultado da epoca 729 = -8331.31 Epsilon = 0.278
# 113
# 106
# resultado da epoca 730 = -19636.78 Epsilon = 0.277
# 111
# 108
# resultado da epoca 731 = 22046.36 Epsilon = 0.276
# 117
# 102
# resultado da epoca 732 = -16725.39 Epsilon = 0.275
# 96
# 123
# resultado da epoca 733 = -11256.73 Epsilon = 0.274
# 102
# 117
# resultado da epoca 734 = 3240.21 Epsilon = 0.273
# 123
# 96
# resultado da epoca 735 = -7134.86 Epsilon = 0.272
# 107
# 112
# resultado da epoca 736 = -19369.10 Epsilon = 0.271
# 97
# 122
# resultado da epoca 737 = -4355.56 Epsilon = 0.270
# 114
# 105
# resultado da epoca 738 = -33533.44 Epsilon = 0.269
# 107
# 112
# resultado da epoca 739 = -3057.30 Epsilon = 0.268
# 112
# 107
# resultado da epoca 740 = -15055.97 Epsilon = 0.267
# 102
# 117
# resultado da epoca 741 = 28906.46 Epsilon = 0.266
# 134
# 85
# resultado da epoca 742 = 3986.54 Epsilon = 0.265
# 112
# 107
# resultado da epoca 743 = 28495.20 Epsilon = 0.264
# 113
# 106
# resultado da epoca 744 = -6631.64 Epsilon = 0.263
# 110
# 109
# resultado da epoca 745 = -4301.37 Epsilon = 0.262
# 101
# 118
# resultado da epoca 746 = 8364.27 Epsilon = 0.261
# 123
# 96
# resultado da epoca 747 = 23033.97 Epsilon = 0.260
# 119
# 100
# resultado da epoca 748 = 25455.35 Epsilon = 0.259
# 121
# 98
# resultado da epoca 749 = 45855.35 Epsilon = 0.258
# 123
# 96
# resultado da epoca 750 = 35830.60 Epsilon = 0.257
# 118
# 101
# resultado da epoca 751 = 25634.00 Epsilon = 0.257
# 114
# 105
# resultado da epoca 752 = 4185.89 Epsilon = 0.256
# 121
# 98
# resultado da epoca 753 = -3732.33 Epsilon = 0.255
# 109
# 110
# resultado da epoca 754 = 3631.55 Epsilon = 0.254
# 124
# 95
# resultado da epoca 755 = 8489.81 Epsilon = 0.253
# 127
# 92
# resultado da epoca 756 = 3291.96 Epsilon = 0.252
# 123
# 96
# resultado da epoca 757 = -9897.82 Epsilon = 0.251
# 110
# 109
# resultado da epoca 758 = -19842.78 Epsilon = 0.250
# 99
# 120
# resultado da epoca 759 = 21627.03 Epsilon = 0.249
# 120
# 99
# resultado da epoca 760 = -2459.58 Epsilon = 0.248
# 116
# 103
# resultado da epoca 761 = -6113.63 Epsilon = 0.247
# 113
# 106
# resultado da epoca 762 = -5590.71 Epsilon = 0.246
# 116
# 103
# resultado da epoca 763 = 1317.85 Epsilon = 0.245
# 114
# 105
# resultado da epoca 764 = -14994.35 Epsilon = 0.244
# 110
# 109
# resultado da epoca 765 = 14578.36 Epsilon = 0.243
# 125
# 94
# resultado da epoca 766 = -9427.18 Epsilon = 0.242
# 114
# 105
# resultado da epoca 767 = 10147.42 Epsilon = 0.241
# 124
# 95
# resultado da epoca 768 = 8300.28 Epsilon = 0.240
# 123
# 96
# resultado da epoca 769 = 2438.47 Epsilon = 0.239
# 108
# 111
# resultado da epoca 770 = 7415.91 Epsilon = 0.238
# 114
# 105
# resultado da epoca 771 = 2035.52 Epsilon = 0.237
# 112
# 107
# resultado da epoca 772 = -2915.99 Epsilon = 0.236
# 116
# 103
# resultado da epoca 773 = -12777.90 Epsilon = 0.235
# 116
# 103
# resultado da epoca 774 = 30075.92 Epsilon = 0.234
# 130
# 89
# resultado da epoca 775 = 12811.38 Epsilon = 0.233
# 114
# 105
# resultado da epoca 776 = 35982.03 Epsilon = 0.232
# 118
# 101
# resultado da epoca 777 = 36246.27 Epsilon = 0.231
# 129
# 90
# resultado da epoca 778 = 12765.06 Epsilon = 0.230
# 118
# 101
# resultado da epoca 779 = 22826.94 Epsilon = 0.229
# 111
# 108
# resultado da epoca 780 = 5571.93 Epsilon = 0.228
# 114
# 105
# resultado da epoca 781 = 47475.89 Epsilon = 0.227
# 129
# 90
# resultado da epoca 782 = 14866.74 Epsilon = 0.226
# 112
# 107
# resultado da epoca 783 = 7840.88 Epsilon = 0.225
# 120
# 99
# resultado da epoca 784 = 17433.14 Epsilon = 0.224
# 118
# 101
# resultado da epoca 785 = 20052.01 Epsilon = 0.223
# 123
# 96
# resultado da epoca 786 = 15229.14 Epsilon = 0.222
# 120
# 99
# resultado da epoca 787 = 5808.03 Epsilon = 0.221
# 110
# 109
# resultado da epoca 788 = 28960.51 Epsilon = 0.220
# 123
# 96
# resultado da epoca 789 = 11462.80 Epsilon = 0.219
# 111
# 108
# resultado da epoca 790 = 12799.01 Epsilon = 0.218
# 118
# 101
# resultado da epoca 791 = 14556.99 Epsilon = 0.217
# 118
# 101
# resultado da epoca 792 = 27385.48 Epsilon = 0.216
# 117
# 102
# resultado da epoca 793 = 18237.04 Epsilon = 0.215
# 113
# 106
# resultado da epoca 794 = 1617.59 Epsilon = 0.214
# 120
# 99
# resultado da epoca 795 = -16030.19 Epsilon = 0.213
# 115
# 104
# resultado da epoca 796 = -8190.90 Epsilon = 0.212
# 113
# 106
# resultado da epoca 797 = -19226.95 Epsilon = 0.211
# 107
# 112
# resultado da epoca 798 = 16102.97 Epsilon = 0.210
# 123
# 96
# resultado da epoca 799 = 5807.37 Epsilon = 0.209
# 115
# 104
# resultado da epoca 800 = 5020.94 Epsilon = 0.208
# 110
# 109
# resultado da epoca 801 = 12203.19 Epsilon = 0.207
# 122
# 97
# resultado da epoca 802 = 44678.10 Epsilon = 0.206
# 133
# 86
# resultado da epoca 803 = 5020.61 Epsilon = 0.205
# 117
# 102
# resultado da epoca 804 = 26971.64 Epsilon = 0.204
# 127
# 92
# resultado da epoca 805 = 8508.98 Epsilon = 0.203
# 126
# 93
# resultado da epoca 806 = 1691.03 Epsilon = 0.202
# 118
# 101
# resultado da epoca 807 = -11187.87 Epsilon = 0.201
# 110
# 109
# resultado da epoca 808 = 13983.74 Epsilon = 0.200
# 114
# 105
# resultado da epoca 809 = 17401.23 Epsilon = 0.199
# 117
# 102
# resultado da epoca 810 = 6348.45 Epsilon = 0.198
# 126
# 93
# resultado da epoca 811 = 11425.21 Epsilon = 0.197
# 120
# 99
# resultado da epoca 812 = 10163.38 Epsilon = 0.196
# 122
# 97
# resultado da epoca 813 = 8054.66 Epsilon = 0.195
# 117
# 102
# resultado da epoca 814 = -11708.25 Epsilon = 0.194
# 113
# 106
# resultado da epoca 815 = -13114.02 Epsilon = 0.193
# 113
# 106
# resultado da epoca 816 = 6503.65 Epsilon = 0.192
# 110
# 109
# resultado da epoca 817 = 11550.57 Epsilon = 0.191
# 113
# 106
# resultado da epoca 818 = -749.17 Epsilon = 0.190
# 122
# 97
# resultado da epoca 819 = 22145.66 Epsilon = 0.189
# 123
# 96
# resultado da epoca 820 = -3234.03 Epsilon = 0.188
# 116
# 103
# resultado da epoca 821 = 12273.73 Epsilon = 0.187
# 114
# 105
# resultado da epoca 822 = 18466.30 Epsilon = 0.186
# 125
# 94
# resultado da epoca 823 = 19050.22 Epsilon = 0.185
# 137
# 82
# resultado da epoca 824 = 12528.32 Epsilon = 0.184
# 122
# 97
# resultado da epoca 825 = -17335.98 Epsilon = 0.183
# 106
# 113
# resultado da epoca 826 = 7200.31 Epsilon = 0.182
# 117
# 102
# resultado da epoca 827 = 28268.62 Epsilon = 0.181
# 133
# 86
# resultado da epoca 828 = 23469.74 Epsilon = 0.180
# 128
# 91
# resultado da epoca 829 = 35296.83 Epsilon = 0.179
# 127
# 92
# resultado da epoca 830 = 14651.05 Epsilon = 0.178
# 113
# 106
# resultado da epoca 831 = -32407.45 Epsilon = 0.177
# 101
# 118
# resultado da epoca 832 = 3637.42 Epsilon = 0.176
# 108
# 111
# resultado da epoca 833 = -8605.67 Epsilon = 0.175
# 107
# 112
# resultado da epoca 834 = -28352.83 Epsilon = 0.174
# 94
# 125
# resultado da epoca 835 = 19817.04 Epsilon = 0.173
# 116
# 103
# resultado da epoca 836 = 38166.52 Epsilon = 0.172
# 130
# 89
# resultado da epoca 837 = 22038.99 Epsilon = 0.171
# 121
# 98
# resultado da epoca 838 = 32176.67 Epsilon = 0.170
# 122
# 97
# resultado da epoca 839 = -6801.24 Epsilon = 0.169
# 107
# 112
# resultado da epoca 840 = 7600.05 Epsilon = 0.168
# 117
# 102
# resultado da epoca 841 = 21191.33 Epsilon = 0.167
# 117
# 102
# resultado da epoca 842 = -5451.18 Epsilon = 0.166
# 103
# 116
# resultado da epoca 843 = -26210.98 Epsilon = 0.165
# 102
# 117
# resultado da epoca 844 = 217.78 Epsilon = 0.164
# 101
# 118
# resultado da epoca 845 = -22370.77 Epsilon = 0.163
# 109
# 110
# resultado da epoca 846 = 12560.71 Epsilon = 0.162
# 113
# 106
# resultado da epoca 847 = -16190.39 Epsilon = 0.161
# 112
# 107
# resultado da epoca 848 = -20928.09 Epsilon = 0.160
# 107
# 112
# resultado da epoca 849 = -33866.03 Epsilon = 0.159
# 104
# 115
# resultado da epoca 850 = -50515.96 Epsilon = 0.158
# 91
# 128
# resultado da epoca 851 = -18735.88 Epsilon = 0.158
# 105
# 114
# resultado da epoca 852 = -17756.41 Epsilon = 0.157
# 107
# 112
# resultado da epoca 853 = 5445.56 Epsilon = 0.156
# 112
# 107
# resultado da epoca 854 = -6794.37 Epsilon = 0.155
# 114
# 105
# resultado da epoca 855 = 115.80 Epsilon = 0.154
# 117
# 102
# resultado da epoca 856 = -24323.89 Epsilon = 0.153
# 104
# 115
# resultado da epoca 857 = -1344.60 Epsilon = 0.152
# 121
# 98
# resultado da epoca 858 = 7182.52 Epsilon = 0.151
# 115
# 104
# resultado da epoca 859 = 20336.03 Epsilon = 0.150
# 123
# 96
# resultado da epoca 860 = 1192.71 Epsilon = 0.149
# 118
# 101
# resultado da epoca 861 = 17018.93 Epsilon = 0.148
# 124
# 95
# resultado da epoca 862 = 9711.86 Epsilon = 0.147
# 127
# 92
# resultado da epoca 863 = -4487.73 Epsilon = 0.146
# 115
# 104
# resultado da epoca 864 = 22014.35 Epsilon = 0.145
# 131
# 88
# resultado da epoca 865 = 15830.65 Epsilon = 0.144
# 130
# 89
# resultado da epoca 866 = -578.00 Epsilon = 0.143
# 118
# 101
# resultado da epoca 867 = -917.66 Epsilon = 0.142
# 120
# 99
# resultado da epoca 868 = 5845.94 Epsilon = 0.141
# 111
# 108
# resultado da epoca 869 = -3792.35 Epsilon = 0.140
# 118
# 101
# resultado da epoca 870 = 1027.00 Epsilon = 0.139
# 118
# 101
# resultado da epoca 871 = -1625.21 Epsilon = 0.138
# 115
# 104
# resultado da epoca 872 = 304.52 Epsilon = 0.137
# 120
# 99
# resultado da epoca 873 = 12232.17 Epsilon = 0.136
# 123
# 96
# resultado da epoca 874 = -4635.21 Epsilon = 0.135
# 116
# 103
# resultado da epoca 875 = 9845.80 Epsilon = 0.134
# 118
# 101
# resultado da epoca 876 = 20447.76 Epsilon = 0.133
# 127
# 92
# resultado da epoca 877 = 6042.37 Epsilon = 0.132
# 124
# 95
# resultado da epoca 878 = 19048.12 Epsilon = 0.131
# 134
# 85
# resultado da epoca 879 = 21401.73 Epsilon = 0.130
# 126
# 93
# resultado da epoca 880 = 11344.70 Epsilon = 0.129
# 128
# 91
# resultado da epoca 881 = 19896.71 Epsilon = 0.128
# 119
# 100
# resultado da epoca 882 = 18549.89 Epsilon = 0.127
# 123
# 96
# resultado da epoca 883 = 29640.92 Epsilon = 0.126
# 134
# 85
# resultado da epoca 884 = 38485.12 Epsilon = 0.125
# 124
# 95
# resultado da epoca 885 = 21591.44 Epsilon = 0.124
# 126
# 93
# resultado da epoca 886 = 8266.41 Epsilon = 0.123
# 118
# 101
# resultado da epoca 887 = 24287.34 Epsilon = 0.122
# 122
# 97
# resultado da epoca 888 = 18150.77 Epsilon = 0.121
# 123
# 96
# resultado da epoca 889 = 10851.34 Epsilon = 0.120
# 115
# 104
# resultado da epoca 890 = 8030.43 Epsilon = 0.119
# 121
# 98
# resultado da epoca 891 = 24847.98 Epsilon = 0.118
# 133
# 86
# resultado da epoca 892 = 13948.45 Epsilon = 0.117
# 125
# 94
# resultado da epoca 893 = -15602.04 Epsilon = 0.116
# 109
# 110
# resultado da epoca 894 = -14623.60 Epsilon = 0.115
# 101
# 118
# resultado da epoca 895 = -420.16 Epsilon = 0.114
# 120
# 99
# resultado da epoca 896 = 12810.21 Epsilon = 0.113
# 111
# 108
# resultado da epoca 897 = -10274.93 Epsilon = 0.112
# 101
# 118
# resultado da epoca 898 = -25085.43 Epsilon = 0.111
# 108
# 111
# resultado da epoca 899 = -10085.97 Epsilon = 0.110
# 108
# 111
# resultado da epoca 900 = -2382.57 Epsilon = 0.109
# 108
# 111
# resultado da epoca 901 = 3883.55 Epsilon = 0.108
# 121
# 98
# resultado da epoca 902 = 8388.63 Epsilon = 0.107
# 123
# 96
# resultado da epoca 903 = -16639.23 Epsilon = 0.106
# 104
# 115
# resultado da epoca 904 = -9145.28 Epsilon = 0.105
# 106
# 113
# resultado da epoca 905 = -20709.52 Epsilon = 0.104
# 105
# 114
# resultado da epoca 906 = -8637.66 Epsilon = 0.103
# 107
# 112
# resultado da epoca 907 = -13037.67 Epsilon = 0.102
# 112
# 107
# resultado da epoca 908 = -9293.58 Epsilon = 0.101
# 112
# 107
# resultado da epoca 909 = -3713.73 Epsilon = 0.100
# 110
# 109
# resultado da epoca 910 = -15340.61 Epsilon = 0.099
# 102
# 117
# resultado da epoca 911 = -1010.87 Epsilon = 0.098
# 110
# 109
# resultado da epoca 912 = -17253.78 Epsilon = 0.097
# 99
# 120
# resultado da epoca 913 = -14521.78 Epsilon = 0.096
# 104
# 115
# resultado da epoca 914 = -8196.69 Epsilon = 0.095
# 110
# 109
# resultado da epoca 915 = -10629.37 Epsilon = 0.094
# 105
# 114
# resultado da epoca 916 = 5660.60 Epsilon = 0.093
# 116
# 103
# resultado da epoca 917 = 7403.84 Epsilon = 0.092
# 109
# 110
# resultado da epoca 918 = 15566.71 Epsilon = 0.091
# 113
# 106
# resultado da epoca 919 = 14879.14 Epsilon = 0.090
# 119
# 100
# resultado da epoca 920 = -6142.68 Epsilon = 0.089
# 113
# 106
# resultado da epoca 921 = 366.03 Epsilon = 0.088
# 112
# 107
# resultado da epoca 922 = 1470.78 Epsilon = 0.087
# 116
# 103
# resultado da epoca 923 = 6877.05 Epsilon = 0.086
# 120
# 99
# resultado da epoca 924 = 9047.93 Epsilon = 0.085
# 122
# 97
# resultado da epoca 925 = 14028.91 Epsilon = 0.084
# 122
# 97
# resultado da epoca 926 = 10294.40 Epsilon = 0.083
# 116
# 103
# resultado da epoca 927 = 12547.11 Epsilon = 0.082
# 123
# 96
# resultado da epoca 928 = 12083.35 Epsilon = 0.081
# 121
# 98
# resultado da epoca 929 = 50.85 Epsilon = 0.080
# 116
# 103
# resultado da epoca 930 = -16575.94 Epsilon = 0.079
# 108
# 111
# resultado da epoca 931 = 4347.74 Epsilon = 0.078
# 123
# 96
# resultado da epoca 932 = 10806.30 Epsilon = 0.077
# 125
# 94
# resultado da epoca 933 = -387.63 Epsilon = 0.076
# 116
# 103
# resultado da epoca 934 = -12958.10 Epsilon = 0.075
# 108
# 111
# resultado da epoca 935 = 762.02 Epsilon = 0.074
# 111
# 108
# resultado da epoca 936 = 4543.96 Epsilon = 0.073
# 115
# 104
# resultado da epoca 937 = 785.93 Epsilon = 0.072
# 118
# 101
# resultado da epoca 938 = 1923.84 Epsilon = 0.071
# 119
# 100
# resultado da epoca 939 = 2.82 Epsilon = 0.070
# 128
# 90
# resultado da epoca 940 = 2373.20 Epsilon = 0.069
# 118
# 101
# resultado da epoca 941 = 8303.87 Epsilon = 0.068
# 122
# 97
# resultado da epoca 942 = 523.60 Epsilon = 0.067
# 122
# 97
# resultado da epoca 943 = 1530.68 Epsilon = 0.066
# 113
# 106
# resultado da epoca 944 = -11037.88 Epsilon = 0.065
# 113
# 106
# resultado da epoca 945 = -5220.92 Epsilon = 0.064
# 114
# 105
# resultado da epoca 946 = -5294.32 Epsilon = 0.063
# 110
# 109
# resultado da epoca 947 = -9704.43 Epsilon = 0.062
# 118
# 101
# resultado da epoca 948 = 48922.66 Epsilon = 0.061
# 137
# 82
# resultado da epoca 949 = 3303.34 Epsilon = 0.060
# 122
# 97
# resultado da epoca 950 = 26725.20 Epsilon = 0.059
# 128
# 91
# resultado da epoca 951 = 8887.45 Epsilon = 0.059
# 123
# 96
# resultado da epoca 952 = 21823.68 Epsilon = 0.058
# 122
# 97
# resultado da epoca 953 = 11792.15 Epsilon = 0.057
# 127
# 92
# resultado da epoca 954 = 8424.59 Epsilon = 0.056
# 122
# 97
# resultado da epoca 955 = 19424.89 Epsilon = 0.055
# 130
# 89
# resultado da epoca 956 = 4074.55 Epsilon = 0.054
# 125
# 94
# resultado da epoca 957 = 5834.39 Epsilon = 0.053
# 125
# 94
# resultado da epoca 958 = 41553.16 Epsilon = 0.052
# 137
# 82
# resultado da epoca 959 = 33468.15 Epsilon = 0.051
# 136
# 83
# resultado da epoca 960 = 45693.45 Epsilon = 0.050
# 143
# 76
# resultado da epoca 961 = 46931.50 Epsilon = 0.049
# 135
# 84
# resultado da epoca 962 = 24181.36 Epsilon = 0.048
# 126
# 93
# resultado da epoca 963 = 8132.54 Epsilon = 0.047
# 125
# 94
# resultado da epoca 964 = 16520.87 Epsilon = 0.046
# 136
# 83
# resultado da epoca 965 = 22040.17 Epsilon = 0.045
# 132
# 87
# resultado da epoca 966 = 26795.62 Epsilon = 0.044
# 135
# 84
# resultado da epoca 967 = 38767.66 Epsilon = 0.043
# 131
# 88
# resultado da epoca 968 = 40038.54 Epsilon = 0.042
# 132
# 87
# resultado da epoca 969 = 45033.31 Epsilon = 0.041
# 134
# 85
# resultado da epoca 970 = 62647.19 Epsilon = 0.040
# 147
# 72
# resultado da epoca 971 = 33661.32 Epsilon = 0.039
# 132
# 87
# resultado da epoca 972 = 29482.13 Epsilon = 0.038
# 137
# 82
# resultado da epoca 973 = 37552.10 Epsilon = 0.037
# 141
# 78
# resultado da epoca 974 = 40761.11 Epsilon = 0.036
# 137
# 82
# resultado da epoca 975 = 48922.35 Epsilon = 0.035
# 143
# 76
# resultado da epoca 976 = 54341.78 Epsilon = 0.034
# 148
# 71
# resultado da epoca 977 = 53752.23 Epsilon = 0.033
# 155
# 64
# resultado da epoca 978 = 47271.59 Epsilon = 0.032
# 152
# 67
# resultado da epoca 979 = 43532.96 Epsilon = 0.031
# 150
# 69
# resultado da epoca 980 = 69035.52 Epsilon = 0.030
# 155
# 64
# resultado da epoca 981 = 51835.09 Epsilon = 0.029
# 146
# 73
# resultado da epoca 982 = 45380.73 Epsilon = 0.028
# 147
# 72
# resultado da epoca 983 = 50485.88 Epsilon = 0.027
# 148
# 71
# resultado da epoca 984 = 52151.72 Epsilon = 0.026
# 143
# 76
# resultado da epoca 985 = 56337.51 Epsilon = 0.025
# 149
# 70
# resultado da epoca 986 = 75093.78 Epsilon = 0.024
# 163
# 56
# resultado da epoca 987 = 27405.67 Epsilon = 0.023
# 123
# 96
# resultado da epoca 988 = 54179.96 Epsilon = 0.022
# 145
# 74
# resultado da epoca 989 = 73512.42 Epsilon = 0.021
# 147
# 72
# resultado da epoca 990 = 74481.84 Epsilon = 0.020
# 156
# 63
# resultado da epoca 991 = 76358.35 Epsilon = 0.019
# 152
# 67
# resultado da epoca 992 = 99660.34 Epsilon = 0.018
# 167
# 52
# resultado da epoca 993 = 92051.75 Epsilon = 0.017
# 167
# 52
# resultado da epoca 994 = 92748.35 Epsilon = 0.016
# 165
# 54
# resultado da epoca 995 = 68018.50 Epsilon = 0.015
# 151
# 68
# resultado da epoca 996 = 89733.20 Epsilon = 0.014
# 156
# 63
# resultado da epoca 997 = 83057.52 Epsilon = 0.013
# 155
# 64
# resultado da epoca 998 = 122051.14 Epsilon = 0.012
# 162
# 57
# resultado da epoca 999 = 53926.54 Epsilon = 0.011
# 137
# 82
# 0
# 0
# Melhor resultado diario: 6723.43
