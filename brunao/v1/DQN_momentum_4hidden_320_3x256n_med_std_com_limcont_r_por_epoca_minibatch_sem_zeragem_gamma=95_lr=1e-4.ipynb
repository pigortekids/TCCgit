# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 4*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        #model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(modelo.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado) #pega valor que chegou
            target_f[0][acao+2*lim_cont] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7680
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 226,837
# Trainable params: 226,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    reward = 0.
    posicao = 0.
    dp = 0.

    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    
    acao = decisao - 2*lim_cont
    
    if abs(ncont+acao) <= lim_cont:
        return acao, 0 
    else:
        return 0, -20

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    penal = 0
    decisao = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l])
        modelo.state = np.reshape(np.concatenate((modelo.janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        
        acao, penal = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        reward += penal    #penalidade se quiser ficar posicionado mais que o permitido
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l])
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]) 
            
        modelo.next_state = np.reshape(np.concatenate((modelo.prox_janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        modelo.remember(acao, reward, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+50): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1105 09:59:10.216871  4420 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -35222.56 Epsilon = 1.000
# 108
# 111
# resultado da epoca 1 = -26391.74 Epsilon = 0.999
# 105
# 114
# resultado da epoca 2 = -42653.57 Epsilon = 0.998
# 92
# 127
# resultado da epoca 3 = -40456.93 Epsilon = 0.997
# 100
# 119
# resultado da epoca 4 = -39541.89 Epsilon = 0.996
# 93
# 126
# resultado da epoca 5 = -4515.89 Epsilon = 0.995
# 112
# 107
# resultado da epoca 6 = -37875.08 Epsilon = 0.994
# 95
# 124
# resultado da epoca 7 = -27606.49 Epsilon = 0.993
# 91
# 128
# resultado da epoca 8 = -27435.75 Epsilon = 0.992
# 98
# 121
# resultado da epoca 9 = -15972.01 Epsilon = 0.991
# 114
# 105
# resultado da epoca 10 = -25046.12 Epsilon = 0.990
# 109
# 110
# resultado da epoca 11 = -1728.28 Epsilon = 0.989
# 109
# 110
# resultado da epoca 12 = -29470.53 Epsilon = 0.988
# 93
# 126
# resultado da epoca 13 = -39512.93 Epsilon = 0.987
# 96
# 123
# resultado da epoca 14 = -23347.47 Epsilon = 0.986
# 92
# 127
# resultado da epoca 15 = -46587.33 Epsilon = 0.985
# 86
# 133
# resultado da epoca 16 = -10229.46 Epsilon = 0.984
# 107
# 112
# resultado da epoca 17 = -26833.99 Epsilon = 0.983
# 97
# 122
# resultado da epoca 18 = -32295.99 Epsilon = 0.982
# 94
# 125
# resultado da epoca 19 = -34688.95 Epsilon = 0.981
# 84
# 135
# resultado da epoca 20 = -39469.75 Epsilon = 0.980
# 91
# 128
# resultado da epoca 21 = -39230.35 Epsilon = 0.979
# 90
# 129
# resultado da epoca 22 = -49892.84 Epsilon = 0.978
# 87
# 132
# resultado da epoca 23 = -27335.53 Epsilon = 0.977
# 102
# 117
# resultado da epoca 24 = -28219.23 Epsilon = 0.976
# 102
# 117
# resultado da epoca 25 = -33337.10 Epsilon = 0.975
# 95
# 124
# resultado da epoca 26 = -29286.33 Epsilon = 0.974
# 96
# 123
# resultado da epoca 27 = -23344.75 Epsilon = 0.973
# 103
# 116
# resultado da epoca 28 = -14185.68 Epsilon = 0.972
# 106
# 113
# resultado da epoca 29 = 440.30 Epsilon = 0.971
# 105
# 114
# resultado da epoca 30 = -14185.41 Epsilon = 0.970
# 99
# 120
# resultado da epoca 31 = -23126.15 Epsilon = 0.969
# 88
# 131
# resultado da epoca 32 = -25831.76 Epsilon = 0.968
# 92
# 127
# resultado da epoca 33 = 8470.05 Epsilon = 0.967
# 107
# 112
# resultado da epoca 34 = -30323.41 Epsilon = 0.966
# 98
# 121
# resultado da epoca 35 = -13615.60 Epsilon = 0.965
# 112
# 107
# resultado da epoca 36 = -37123.60 Epsilon = 0.964
# 84
# 135
# resultado da epoca 37 = -18804.45 Epsilon = 0.963
# 99
# 120
# resultado da epoca 38 = -12178.18 Epsilon = 0.962
# 100
# 119
# resultado da epoca 39 = -26369.15 Epsilon = 0.961
# 104
# 115
# resultado da epoca 40 = -22446.33 Epsilon = 0.960
# 104
# 115
# resultado da epoca 41 = -15731.72 Epsilon = 0.959
# 101
# 118
# resultado da epoca 42 = -63812.96 Epsilon = 0.958
# 82
# 137
# resultado da epoca 43 = -17406.02 Epsilon = 0.957
# 99
# 120
# resultado da epoca 44 = -10719.28 Epsilon = 0.956
# 104
# 115
# resultado da epoca 45 = -12237.31 Epsilon = 0.955
# 103
# 116
# resultado da epoca 46 = -18869.18 Epsilon = 0.954
# 101
# 118
# resultado da epoca 47 = -26674.09 Epsilon = 0.953
# 97
# 122
# resultado da epoca 48 = -16309.37 Epsilon = 0.952
# 99
# 120
# resultado da epoca 49 = -20114.86 Epsilon = 0.951
# 106
# 113
# resultado da epoca 50 = -42422.52 Epsilon = 0.950
# 88
# 131
# resultado da epoca 51 = 5958.35 Epsilon = 0.950
# 110
# 109
# resultado da epoca 52 = -8145.83 Epsilon = 0.949
# 101
# 118
# resultado da epoca 53 = -24445.08 Epsilon = 0.948
# 98
# 121
# resultado da epoca 54 = -26304.97 Epsilon = 0.947
# 96
# 123
# resultado da epoca 55 = -10348.43 Epsilon = 0.946
# 102
# 117
# resultado da epoca 56 = 522.27 Epsilon = 0.945
# 111
# 108
# resultado da epoca 57 = -27299.55 Epsilon = 0.944
# 99
# 120
# resultado da epoca 58 = -30755.95 Epsilon = 0.943
# 99
# 120
# resultado da epoca 59 = 7998.31 Epsilon = 0.942
# 108
# 111
# resultado da epoca 60 = -30511.82 Epsilon = 0.941
# 94
# 125
# resultado da epoca 61 = -39220.91 Epsilon = 0.940
# 93
# 126
# resultado da epoca 62 = -27387.76 Epsilon = 0.939
# 96
# 123
# resultado da epoca 63 = -43904.50 Epsilon = 0.938
# 92
# 127
# resultado da epoca 64 = -54941.72 Epsilon = 0.937
# 87
# 132
# resultado da epoca 65 = 12532.49 Epsilon = 0.936
# 109
# 110
# resultado da epoca 66 = -24640.72 Epsilon = 0.935
# 109
# 110
# resultado da epoca 67 = -22297.86 Epsilon = 0.934
# 94
# 125
# resultado da epoca 68 = 3482.24 Epsilon = 0.933
# 102
# 117
# resultado da epoca 69 = -36296.36 Epsilon = 0.932
# 88
# 131
# resultado da epoca 70 = -17438.89 Epsilon = 0.931
# 99
# 120
# resultado da epoca 71 = 14325.90 Epsilon = 0.930
# 110
# 109
# resultado da epoca 72 = -4647.06 Epsilon = 0.929
# 114
# 105
# resultado da epoca 73 = -6224.30 Epsilon = 0.928
# 96
# 123
# resultado da epoca 74 = -5367.50 Epsilon = 0.927
# 113
# 106
# resultado da epoca 75 = -5162.19 Epsilon = 0.926
# 109
# 110
# resultado da epoca 76 = -33324.33 Epsilon = 0.925
# 101
# 118
# resultado da epoca 77 = -26354.23 Epsilon = 0.924
# 103
# 116
# resultado da epoca 78 = -52335.88 Epsilon = 0.923
# 91
# 128
# resultado da epoca 79 = -18279.48 Epsilon = 0.922
# 97
# 122
# resultado da epoca 80 = -35359.68 Epsilon = 0.921
# 99
# 120
# resultado da epoca 81 = -46902.39 Epsilon = 0.920
# 86
# 133
# resultado da epoca 82 = -34283.32 Epsilon = 0.919
# 96
# 123
# resultado da epoca 83 = -15016.16 Epsilon = 0.918
# 107
# 112
# resultado da epoca 84 = -18332.51 Epsilon = 0.917
# 91
# 128
# resultado da epoca 85 = -31996.49 Epsilon = 0.916
# 98
# 121
# resultado da epoca 86 = -7457.41 Epsilon = 0.915
# 104
# 115
# resultado da epoca 87 = -18432.24 Epsilon = 0.914
# 100
# 119
# resultado da epoca 88 = -25360.73 Epsilon = 0.913
# 91
# 128
# resultado da epoca 89 = -15208.47 Epsilon = 0.912
# 97
# 122
# resultado da epoca 90 = -2881.65 Epsilon = 0.911
# 107
# 112
# resultado da epoca 91 = -23414.88 Epsilon = 0.910
# 99
# 120
# resultado da epoca 92 = -39863.79 Epsilon = 0.909
# 98
# 121
# resultado da epoca 93 = -23326.22 Epsilon = 0.908
# 94
# 125
# resultado da epoca 94 = 9424.60 Epsilon = 0.907
# 102
# 117
# resultado da epoca 95 = -16631.56 Epsilon = 0.906
# 95
# 124
# resultado da epoca 96 = -20090.38 Epsilon = 0.905
# 102
# 117
# resultado da epoca 97 = -44858.67 Epsilon = 0.904
# 100
# 119
# resultado da epoca 98 = -28435.36 Epsilon = 0.903
# 96
# 123
# resultado da epoca 99 = -25461.68 Epsilon = 0.902
# 100
# 119
# resultado da epoca 100 = -29297.27 Epsilon = 0.901
# 97
# 122
# resultado da epoca 101 = -15665.77 Epsilon = 0.900
# 103
# 116
# resultado da epoca 102 = -20420.00 Epsilon = 0.899
# 103
# 116
# resultado da epoca 103 = -36417.17 Epsilon = 0.898
# 97
# 122
# resultado da epoca 104 = -25682.10 Epsilon = 0.897
# 94
# 125
# resultado da epoca 105 = -28257.41 Epsilon = 0.896
# 95
# 124
# resultado da epoca 106 = -18287.90 Epsilon = 0.895
# 97
# 122
# resultado da epoca 107 = -49188.72 Epsilon = 0.894
# 86
# 133
# resultado da epoca 108 = -19839.55 Epsilon = 0.893
# 95
# 124
# resultado da epoca 109 = -42654.01 Epsilon = 0.892
# 92
# 127
# resultado da epoca 110 = -32363.21 Epsilon = 0.891
# 91
# 128
# resultado da epoca 111 = -22377.24 Epsilon = 0.890
# 98
# 121
# resultado da epoca 112 = -31985.89 Epsilon = 0.889
# 96
# 123
# resultado da epoca 113 = -1385.58 Epsilon = 0.888
# 110
# 109
# resultado da epoca 114 = -25301.89 Epsilon = 0.887
# 100
# 119
# resultado da epoca 115 = -17742.79 Epsilon = 0.886
# 105
# 114
# resultado da epoca 116 = -17088.92 Epsilon = 0.885
# 101
# 118
# resultado da epoca 117 = -54793.28 Epsilon = 0.884
# 87
# 132
# resultado da epoca 118 = -29648.34 Epsilon = 0.883
# 99
# 120
# resultado da epoca 119 = -46861.84 Epsilon = 0.882
# 88
# 131
# resultado da epoca 120 = -34268.91 Epsilon = 0.881
# 98
# 121
# resultado da epoca 121 = -28382.47 Epsilon = 0.880
# 95
# 124
# resultado da epoca 122 = 4970.58 Epsilon = 0.879
# 112
# 107
# resultado da epoca 123 = -44619.11 Epsilon = 0.878
# 92
# 127
# resultado da epoca 124 = -15097.09 Epsilon = 0.877
# 101
# 118
# resultado da epoca 125 = -34432.20 Epsilon = 0.876
# 93
# 126
# resultado da epoca 126 = -27877.88 Epsilon = 0.875
# 101
# 118
# resultado da epoca 127 = -14580.90 Epsilon = 0.874
# 101
# 118
# resultado da epoca 128 = -33099.10 Epsilon = 0.873
# 101
# 118
# resultado da epoca 129 = -15532.58 Epsilon = 0.872
# 105
# 114
# resultado da epoca 130 = -28098.47 Epsilon = 0.871
# 93
# 126
# resultado da epoca 131 = -25676.16 Epsilon = 0.870
# 95
# 124
# resultado da epoca 132 = -16313.22 Epsilon = 0.869
# 101
# 118
# resultado da epoca 133 = -12618.51 Epsilon = 0.868
# 107
# 112
# resultado da epoca 134 = 99.47 Epsilon = 0.867
# 104
# 115
# resultado da epoca 135 = -23941.14 Epsilon = 0.866
# 98
# 121
# resultado da epoca 136 = -14987.57 Epsilon = 0.865
# 110
# 109
# resultado da epoca 137 = -25958.48 Epsilon = 0.864
# 88
# 131
# resultado da epoca 138 = -3262.09 Epsilon = 0.863
# 109
# 110
# resultado da epoca 139 = -35069.68 Epsilon = 0.862
# 94
# 125
# resultado da epoca 140 = -25405.96 Epsilon = 0.861
# 96
# 123
# resultado da epoca 141 = -26940.37 Epsilon = 0.860
# 91
# 128
# resultado da epoca 142 = -10579.72 Epsilon = 0.859
# 100
# 119
# resultado da epoca 143 = -27079.55 Epsilon = 0.858
# 98
# 121
# resultado da epoca 144 = -32973.72 Epsilon = 0.857
# 98
# 121
# resultado da epoca 145 = -18838.75 Epsilon = 0.856
# 108
# 111
# resultado da epoca 146 = -47956.31 Epsilon = 0.855
# 89
# 130
# resultado da epoca 147 = -35616.50 Epsilon = 0.854
# 92
# 127
# resultado da epoca 148 = -20508.67 Epsilon = 0.853
# 97
# 122
# resultado da epoca 149 = -23268.63 Epsilon = 0.852
# 95
# 124
# resultado da epoca 150 = -34919.47 Epsilon = 0.851
# 103
# 116
# resultado da epoca 151 = -20068.41 Epsilon = 0.851
# 96
# 123
# resultado da epoca 152 = -29976.07 Epsilon = 0.850
# 96
# 123
# resultado da epoca 153 = -18211.48 Epsilon = 0.849
# 101
# 118
# resultado da epoca 154 = -44895.65 Epsilon = 0.848
# 83
# 136
# resultado da epoca 155 = -32038.22 Epsilon = 0.847
# 109
# 110
# resultado da epoca 156 = -46066.22 Epsilon = 0.846
# 90
# 129
# resultado da epoca 157 = -38891.04 Epsilon = 0.845
# 87
# 132
# resultado da epoca 158 = -46407.48 Epsilon = 0.844
# 89
# 130
# resultado da epoca 159 = -26491.04 Epsilon = 0.843
# 92
# 127
# resultado da epoca 160 = -33604.63 Epsilon = 0.842
# 97
# 122
# resultado da epoca 161 = -21621.51 Epsilon = 0.841
# 101
# 118
# resultado da epoca 162 = -41177.82 Epsilon = 0.840
# 94
# 125
# resultado da epoca 163 = -42840.10 Epsilon = 0.839
# 96
# 123
# resultado da epoca 164 = -18292.22 Epsilon = 0.838
# 101
# 118
# resultado da epoca 165 = -5032.22 Epsilon = 0.837
# 105
# 114
# resultado da epoca 166 = -7225.85 Epsilon = 0.836
# 101
# 118
# resultado da epoca 167 = -41722.63 Epsilon = 0.835
# 93
# 126
# resultado da epoca 168 = -53442.72 Epsilon = 0.834
# 86
# 133
# resultado da epoca 169 = -23305.37 Epsilon = 0.833
# 102
# 117
# resultado da epoca 170 = -23380.64 Epsilon = 0.832
# 100
# 119
# resultado da epoca 171 = -5579.46 Epsilon = 0.831
# 109
# 110
# resultado da epoca 172 = -15121.38 Epsilon = 0.830
# 103
# 116
# resultado da epoca 173 = -15676.34 Epsilon = 0.829
# 101
# 118
# resultado da epoca 174 = -13207.96 Epsilon = 0.828
# 106
# 113
# resultado da epoca 175 = -31085.41 Epsilon = 0.827
# 90
# 129
# resultado da epoca 176 = -48568.56 Epsilon = 0.826
# 93
# 126
# resultado da epoca 177 = 2643.11 Epsilon = 0.825
# 115
# 104
# resultado da epoca 178 = -37554.62 Epsilon = 0.824
# 92
# 127
# resultado da epoca 179 = -12643.75 Epsilon = 0.823
# 100
# 119
# resultado da epoca 180 = -5296.62 Epsilon = 0.822
# 100
# 119
# resultado da epoca 181 = -46560.50 Epsilon = 0.821
# 80
# 139
# resultado da epoca 182 = -12490.43 Epsilon = 0.820
# 100
# 119
# resultado da epoca 183 = -62484.03 Epsilon = 0.819
# 90
# 129
# resultado da epoca 184 = -26589.07 Epsilon = 0.818
# 105
# 114
# resultado da epoca 185 = -2101.80 Epsilon = 0.817
# 118
# 101
# resultado da epoca 186 = -18602.01 Epsilon = 0.816
# 104
# 115
# resultado da epoca 187 = -19411.27 Epsilon = 0.815
# 94
# 125
# resultado da epoca 188 = -54877.44 Epsilon = 0.814
# 81
# 138
# resultado da epoca 189 = -33604.67 Epsilon = 0.813
# 94
# 125
# resultado da epoca 190 = -23086.72 Epsilon = 0.812
# 99
# 120
# resultado da epoca 191 = -10953.02 Epsilon = 0.811
# 106
# 113
# resultado da epoca 192 = -54825.47 Epsilon = 0.810
# 79
# 140
# resultado da epoca 193 = -15964.67 Epsilon = 0.809
# 104
# 115
# resultado da epoca 194 = -48156.22 Epsilon = 0.808
# 85
# 134
# resultado da epoca 195 = -19946.63 Epsilon = 0.807
# 100
# 119
# resultado da epoca 196 = -28084.03 Epsilon = 0.806
# 99
# 120
# resultado da epoca 197 = -8448.53 Epsilon = 0.805
# 101
# 118
# resultado da epoca 198 = -48616.86 Epsilon = 0.804
# 82
# 137
# resultado da epoca 199 = -41754.10 Epsilon = 0.803
# 96
# 123
# resultado da epoca 200 = -26618.83 Epsilon = 0.802
# 96
# 123
# resultado da epoca 201 = -28673.12 Epsilon = 0.801
# 93
# 126
# resultado da epoca 202 = -21624.89 Epsilon = 0.800
# 97
# 122
# resultado da epoca 203 = -14920.49 Epsilon = 0.799
# 95
# 124
# resultado da epoca 204 = -17547.20 Epsilon = 0.798
# 112
# 107
# resultado da epoca 205 = -33094.57 Epsilon = 0.797
# 95
# 124
# resultado da epoca 206 = -9635.52 Epsilon = 0.796
# 103
# 116
# resultado da epoca 207 = -40829.50 Epsilon = 0.795
# 94
# 125
# resultado da epoca 208 = -27365.08 Epsilon = 0.794
# 97
# 122
# resultado da epoca 209 = -41582.23 Epsilon = 0.793
# 97
# 122
# resultado da epoca 210 = -12824.78 Epsilon = 0.792
# 108
# 111
# resultado da epoca 211 = -18247.34 Epsilon = 0.791
# 94
# 125
# resultado da epoca 212 = -25864.37 Epsilon = 0.790
# 98
# 121
# resultado da epoca 213 = -22448.99 Epsilon = 0.789
# 96
# 123
# resultado da epoca 214 = -25620.90 Epsilon = 0.788
# 94
# 125
# resultado da epoca 215 = -10704.99 Epsilon = 0.787
# 108
# 111
# resultado da epoca 216 = 15229.08 Epsilon = 0.786
# 112
# 107
# resultado da epoca 217 = -28014.05 Epsilon = 0.785
# 98
# 121
# resultado da epoca 218 = -37202.65 Epsilon = 0.784
# 92
# 127
# resultado da epoca 219 = -13062.13 Epsilon = 0.783
# 110
# 109
# resultado da epoca 220 = -54515.50 Epsilon = 0.782
# 86
# 133
# resultado da epoca 221 = -25448.48 Epsilon = 0.781
# 97
# 122
# resultado da epoca 222 = -55003.69 Epsilon = 0.780
# 88
# 131
# resultado da epoca 223 = -18816.20 Epsilon = 0.779
# 102
# 117
# resultado da epoca 224 = -14980.24 Epsilon = 0.778
# 104
# 115
# resultado da epoca 225 = -14935.40 Epsilon = 0.777
# 109
# 110
# resultado da epoca 226 = -47935.32 Epsilon = 0.776
# 98
# 121
# resultado da epoca 227 = -43424.95 Epsilon = 0.775
# 104
# 115
# resultado da epoca 228 = -15997.39 Epsilon = 0.774
# 105
# 114
# resultado da epoca 229 = -38562.38 Epsilon = 0.773
# 96
# 123
# resultado da epoca 230 = -28322.21 Epsilon = 0.772
# 97
# 122
# resultado da epoca 231 = 13236.18 Epsilon = 0.771
# 111
# 108
# resultado da epoca 232 = -65011.68 Epsilon = 0.770
# 85
# 134
# resultado da epoca 233 = -43626.10 Epsilon = 0.769
# 98
# 121
# resultado da epoca 234 = -50430.11 Epsilon = 0.768
# 84
# 135
# resultado da epoca 235 = -24098.62 Epsilon = 0.767
# 97
# 122
# resultado da epoca 236 = -37736.56 Epsilon = 0.766
# 100
# 119
# resultado da epoca 237 = -19919.40 Epsilon = 0.765
# 98
# 121
# resultado da epoca 238 = -15948.33 Epsilon = 0.764
# 93
# 126
# resultado da epoca 239 = -27954.05 Epsilon = 0.763
# 94
# 125
# resultado da epoca 240 = -37983.85 Epsilon = 0.762
# 106
# 113
# resultado da epoca 241 = -25952.24 Epsilon = 0.761
# 103
# 116
# resultado da epoca 242 = -18912.73 Epsilon = 0.760
# 90
# 129
# resultado da epoca 243 = -49339.53 Epsilon = 0.759
# 93
# 126
# resultado da epoca 244 = -23248.54 Epsilon = 0.758
# 105
# 114
# resultado da epoca 245 = -16686.93 Epsilon = 0.757
# 103
# 116
# resultado da epoca 246 = -26456.64 Epsilon = 0.756
# 106
# 113
# resultado da epoca 247 = -27947.01 Epsilon = 0.755
# 98
# 121
# resultado da epoca 248 = -33164.60 Epsilon = 0.754
# 100
# 119
# resultado da epoca 249 = -49797.11 Epsilon = 0.753
# 91
# 128
# resultado da epoca 250 = -75138.96 Epsilon = 0.752
# 85
# 134
# resultado da epoca 251 = -18905.69 Epsilon = 0.752
# 102
# 117
# resultado da epoca 252 = -19061.54 Epsilon = 0.751
# 105
# 114
# resultado da epoca 253 = -18682.63 Epsilon = 0.750
# 103
# 116
# resultado da epoca 254 = -15640.95 Epsilon = 0.749
# 97
# 122
# resultado da epoca 255 = -36347.36 Epsilon = 0.748
# 95
# 124
# resultado da epoca 256 = -51886.64 Epsilon = 0.747
# 88
# 131
# resultado da epoca 257 = -46407.25 Epsilon = 0.746
# 93
# 126
# resultado da epoca 258 = -11079.34 Epsilon = 0.745
# 109
# 110
# resultado da epoca 259 = -6680.23 Epsilon = 0.744
# 111
# 108
# resultado da epoca 260 = -712.46 Epsilon = 0.743
# 108
# 111
# resultado da epoca 261 = -11248.85 Epsilon = 0.742
# 109
# 110
# resultado da epoca 262 = -28001.33 Epsilon = 0.741
# 97
# 122
# resultado da epoca 263 = -58024.84 Epsilon = 0.740
# 82
# 137
# resultado da epoca 264 = -22652.56 Epsilon = 0.739
# 91
# 128
# resultado da epoca 265 = -31617.47 Epsilon = 0.738
# 92
# 127
# resultado da epoca 266 = -27028.18 Epsilon = 0.737
# 91
# 128
# resultado da epoca 267 = -15059.70 Epsilon = 0.736
# 111
# 108
# resultado da epoca 268 = -29767.64 Epsilon = 0.735
# 101
# 118
# resultado da epoca 269 = -31938.61 Epsilon = 0.734
# 98
# 121
# resultado da epoca 270 = -19667.52 Epsilon = 0.733
# 108
# 111
# resultado da epoca 271 = -25726.89 Epsilon = 0.732
# 88
# 131
# resultado da epoca 272 = -54971.25 Epsilon = 0.731
# 87
# 132
# resultado da epoca 273 = -37853.83 Epsilon = 0.730
# 91
# 128
# resultado da epoca 274 = -45038.04 Epsilon = 0.729
# 98
# 121
# resultado da epoca 275 = -49188.64 Epsilon = 0.728
# 92
# 127
# resultado da epoca 276 = -14566.55 Epsilon = 0.727
# 107
# 112
# resultado da epoca 277 = -42659.05 Epsilon = 0.726
# 90
# 129
# resultado da epoca 278 = -39973.19 Epsilon = 0.725
# 94
# 125
# resultado da epoca 279 = -41460.63 Epsilon = 0.724
# 95
# 124
# resultado da epoca 280 = -33679.60 Epsilon = 0.723
# 91
# 128
# resultado da epoca 281 = -7488.77 Epsilon = 0.722
# 101
# 118
# resultado da epoca 282 = -7889.33 Epsilon = 0.721
# 105
# 114
# resultado da epoca 283 = -20453.57 Epsilon = 0.720
# 109
# 110
# resultado da epoca 284 = -21459.62 Epsilon = 0.719
# 94
# 125
# resultado da epoca 285 = -27094.40 Epsilon = 0.718
# 100
# 119
# resultado da epoca 286 = -27447.56 Epsilon = 0.717
# 98
# 121
# resultado da epoca 287 = -37267.37 Epsilon = 0.716
# 88
# 131
# resultado da epoca 288 = -44654.41 Epsilon = 0.715
# 92
# 127
# resultado da epoca 289 = -21803.42 Epsilon = 0.714
# 102
# 117
# resultado da epoca 290 = -11993.22 Epsilon = 0.713
# 102
# 117
# resultado da epoca 291 = -30660.12 Epsilon = 0.712
# 105
# 114
# resultado da epoca 292 = -25647.63 Epsilon = 0.711
# 87
# 132
# resultado da epoca 293 = -16766.85 Epsilon = 0.710
# 104
# 115
# resultado da epoca 294 = -41871.55 Epsilon = 0.709
# 91
# 128
# resultado da epoca 295 = -48573.55 Epsilon = 0.708
# 87
# 132
# resultado da epoca 296 = -30913.38 Epsilon = 0.707
# 99
# 120
# resultado da epoca 297 = -30514.16 Epsilon = 0.706
# 102
# 117
# resultado da epoca 298 = -40568.31 Epsilon = 0.705
# 92
# 127
# resultado da epoca 299 = -28670.66 Epsilon = 0.704
# 99
# 120
# resultado da epoca 300 = -8799.66 Epsilon = 0.703
# 111
# 108
# resultado da epoca 301 = -24308.61 Epsilon = 0.702
# 105
# 114
# resultado da epoca 302 = -64253.55 Epsilon = 0.701
# 87
# 132
# resultado da epoca 303 = -746.02 Epsilon = 0.700
# 114
# 105
# resultado da epoca 304 = -24034.43 Epsilon = 0.699
# 101
# 118
# resultado da epoca 305 = -10103.29 Epsilon = 0.698
# 102
# 117
# resultado da epoca 306 = -42109.43 Epsilon = 0.697
# 91
# 128
# resultado da epoca 307 = -1187.26 Epsilon = 0.696
# 111
# 108
# resultado da epoca 308 = -18339.55 Epsilon = 0.695
# 105
# 114
# resultado da epoca 309 = -31420.80 Epsilon = 0.694
# 90
# 129
# resultado da epoca 310 = -18550.84 Epsilon = 0.693
# 102
# 117
# resultado da epoca 311 = -17630.09 Epsilon = 0.692
# 99
# 120
# resultado da epoca 312 = -47575.94 Epsilon = 0.691
# 88
# 131
# resultado da epoca 313 = -24923.67 Epsilon = 0.690
# 92
# 127
# resultado da epoca 314 = -27271.89 Epsilon = 0.689
# 92
# 127
# resultado da epoca 315 = -7559.31 Epsilon = 0.688
# 107
# 112
# resultado da epoca 316 = -16775.21 Epsilon = 0.687
# 110
# 109
# resultado da epoca 317 = -30521.83 Epsilon = 0.686
# 109
# 110
# resultado da epoca 318 = -20036.07 Epsilon = 0.685
# 96
# 123
# resultado da epoca 319 = -19870.22 Epsilon = 0.684
# 100
# 119
# resultado da epoca 320 = -13589.97 Epsilon = 0.683
# 96
# 123
# resultado da epoca 321 = -45133.90 Epsilon = 0.682
# 97
# 122
# resultado da epoca 322 = -42196.02 Epsilon = 0.681
# 85
# 134
# resultado da epoca 323 = -1840.11 Epsilon = 0.680
# 108
# 111
# resultado da epoca 324 = -14247.62 Epsilon = 0.679
# 102
# 117
# resultado da epoca 325 = -21542.12 Epsilon = 0.678
# 104
# 115
# resultado da epoca 326 = -23743.54 Epsilon = 0.677
# 97
# 122
# resultado da epoca 327 = -2165.94 Epsilon = 0.676
# 111
# 108
# resultado da epoca 328 = -33519.69 Epsilon = 0.675
# 100
# 119
# resultado da epoca 329 = -21070.21 Epsilon = 0.674
# 102
# 117
# resultado da epoca 330 = -6116.74 Epsilon = 0.673
# 112
# 107
# resultado da epoca 331 = -33625.28 Epsilon = 0.672
# 89
# 130
# resultado da epoca 332 = -44647.04 Epsilon = 0.671
# 90
# 129
# resultado da epoca 333 = -14826.63 Epsilon = 0.670
# 106
# 113
# resultado da epoca 334 = -32408.02 Epsilon = 0.669
# 110
# 109
# resultado da epoca 335 = -9815.24 Epsilon = 0.668
# 98
# 121
# resultado da epoca 336 = -38130.27 Epsilon = 0.667
# 94
# 125
# resultado da epoca 337 = -8258.13 Epsilon = 0.666
# 101
# 118
# resultado da epoca 338 = -24640.59 Epsilon = 0.665
# 101
# 118
# resultado da epoca 339 = -19572.83 Epsilon = 0.664
# 102
# 117
# resultado da epoca 340 = -16664.33 Epsilon = 0.663
# 97
# 122
# resultado da epoca 341 = -25497.91 Epsilon = 0.662
# 97
# 122
# resultado da epoca 342 = -24189.53 Epsilon = 0.661
# 99
# 120
# resultado da epoca 343 = -30080.50 Epsilon = 0.660
# 100
# 119
# resultado da epoca 344 = -44923.32 Epsilon = 0.659
# 89
# 130
# resultado da epoca 345 = -34127.86 Epsilon = 0.658
# 91
# 128
# resultado da epoca 346 = -29469.26 Epsilon = 0.657
# 90
# 129
# resultado da epoca 347 = -19372.19 Epsilon = 0.656
# 107
# 112
# resultado da epoca 348 = -19150.24 Epsilon = 0.655
# 102
# 117
# resultado da epoca 349 = -27786.16 Epsilon = 0.654
# 100
# 119
# resultado da epoca 350 = -16055.24 Epsilon = 0.653
# 103
# 116
# resultado da epoca 351 = -6897.36 Epsilon = 0.653
# 106
# 113
# resultado da epoca 352 = -4442.24 Epsilon = 0.652
# 105
# 114
# resultado da epoca 353 = -36964.25 Epsilon = 0.651
# 95
# 124
# resultado da epoca 354 = -22017.24 Epsilon = 0.650
# 96
# 123
# resultado da epoca 355 = -3098.51 Epsilon = 0.649
# 107
# 112
# resultado da epoca 356 = -30948.97 Epsilon = 0.648
# 96
# 123
# resultado da epoca 357 = -17466.33 Epsilon = 0.647
# 97
# 122
# resultado da epoca 358 = -26115.24 Epsilon = 0.646
# 95
# 124
# resultado da epoca 359 = -32487.73 Epsilon = 0.645
# 97
# 122
# resultado da epoca 360 = -25989.20 Epsilon = 0.644
# 93
# 126
# resultado da epoca 361 = -35022.59 Epsilon = 0.643
# 99
# 120
# resultado da epoca 362 = 6826.34 Epsilon = 0.642
# 112
# 107
# resultado da epoca 363 = -5662.15 Epsilon = 0.641
# 109
# 110
# resultado da epoca 364 = -29320.35 Epsilon = 0.640
# 96
# 123
# resultado da epoca 365 = -45011.94 Epsilon = 0.639
# 92
# 127
# resultado da epoca 366 = -11024.97 Epsilon = 0.638
# 101
# 118
# resultado da epoca 367 = 6611.22 Epsilon = 0.637
# 112
# 107
# resultado da epoca 368 = 5527.46 Epsilon = 0.636
# 112
# 107
# resultado da epoca 369 = -16721.77 Epsilon = 0.635
# 99
# 120
# resultado da epoca 370 = -32318.92 Epsilon = 0.634
# 102
# 117
# resultado da epoca 371 = -6997.24 Epsilon = 0.633
# 101
# 118
# resultado da epoca 372 = -24225.79 Epsilon = 0.632
# 108
# 111
# resultado da epoca 373 = -8562.97 Epsilon = 0.631
# 108
# 111
# resultado da epoca 374 = -20580.48 Epsilon = 0.630
# 106
# 113
# resultado da epoca 375 = -371.56 Epsilon = 0.629
# 110
# 109
# resultado da epoca 376 = 6290.98 Epsilon = 0.628
# 106
# 113
# resultado da epoca 377 = -8456.36 Epsilon = 0.627
# 106
# 113
# resultado da epoca 378 = -27941.73 Epsilon = 0.626
# 105
# 114
# resultado da epoca 379 = -38256.46 Epsilon = 0.625
# 97
# 122
# resultado da epoca 380 = -33056.77 Epsilon = 0.624
# 87
# 132
# resultado da epoca 381 = -19545.88 Epsilon = 0.623
# 107
# 112
# resultado da epoca 382 = -10266.92 Epsilon = 0.622
# 107
# 112
# resultado da epoca 383 = -30719.17 Epsilon = 0.621
# 100
# 119
# resultado da epoca 384 = -13725.13 Epsilon = 0.620
# 117
# 102
# resultado da epoca 385 = -5110.99 Epsilon = 0.619
# 102
# 117
# resultado da epoca 386 = -37616.90 Epsilon = 0.618
# 98
# 121
# resultado da epoca 387 = -27989.49 Epsilon = 0.617
# 106
# 113
# resultado da epoca 388 = -39217.27 Epsilon = 0.616
# 101
# 118
# resultado da epoca 389 = -24238.93 Epsilon = 0.615
# 103
# 116
# resultado da epoca 390 = -2345.20 Epsilon = 0.614
# 102
# 117
# resultado da epoca 391 = -5735.67 Epsilon = 0.613
# 105
# 114
# resultado da epoca 392 = -10038.39 Epsilon = 0.612
# 106
# 113
# resultado da epoca 393 = -23976.67 Epsilon = 0.611
# 100
# 119
# resultado da epoca 394 = -18878.06 Epsilon = 0.610
# 98
# 121
# resultado da epoca 395 = -9280.13 Epsilon = 0.609
# 110
# 109
# resultado da epoca 396 = -15414.21 Epsilon = 0.608
# 108
# 111
# resultado da epoca 397 = 10812.81 Epsilon = 0.607
# 112
# 107
# resultado da epoca 398 = -16798.79 Epsilon = 0.606
# 111
# 108
# resultado da epoca 399 = -7851.90 Epsilon = 0.605
# 107
# 112
# resultado da epoca 400 = -7135.78 Epsilon = 0.604
# 110
# 109
# resultado da epoca 401 = -8219.52 Epsilon = 0.603
# 105
# 114
# resultado da epoca 402 = -23115.27 Epsilon = 0.602
# 95
# 124
# resultado da epoca 403 = -18854.26 Epsilon = 0.601
# 97
# 122
# resultado da epoca 404 = -18442.68 Epsilon = 0.600
# 104
# 115
# resultado da epoca 405 = -6718.01 Epsilon = 0.599
# 102
# 117
# resultado da epoca 406 = -33169.95 Epsilon = 0.598
# 102
# 117
# resultado da epoca 407 = -12735.12 Epsilon = 0.597
# 104
# 115
# resultado da epoca 408 = -27607.36 Epsilon = 0.596
# 108
# 111
# resultado da epoca 409 = -17920.88 Epsilon = 0.595
# 108
# 111
# resultado da epoca 410 = -31250.42 Epsilon = 0.594
# 103
# 116
# resultado da epoca 411 = -22783.54 Epsilon = 0.593
# 103
# 116
# resultado da epoca 412 = -12878.12 Epsilon = 0.592
# 98
# 121
# resultado da epoca 413 = 6360.43 Epsilon = 0.591
# 109
# 110
# resultado da epoca 414 = -12782.12 Epsilon = 0.590
# 107
# 112
# resultado da epoca 415 = -26880.39 Epsilon = 0.589
# 96
# 123
# resultado da epoca 416 = -12306.20 Epsilon = 0.588
# 96
# 123
# resultado da epoca 417 = -11538.97 Epsilon = 0.587
# 108
# 111
# resultado da epoca 418 = -17567.59 Epsilon = 0.586
# 103
# 116
# resultado da epoca 419 = 14934.38 Epsilon = 0.585
# 124
# 95
# resultado da epoca 420 = -28132.91 Epsilon = 0.584
# 101
# 118
# resultado da epoca 421 = -23983.93 Epsilon = 0.583
# 90
# 129
# resultado da epoca 422 = -30863.09 Epsilon = 0.582
# 104
# 115
# resultado da epoca 423 = -25799.09 Epsilon = 0.581
# 104
# 115
# resultado da epoca 424 = -14152.69 Epsilon = 0.580
# 103
# 116
# resultado da epoca 425 = -39326.01 Epsilon = 0.579
# 93
# 126
# resultado da epoca 426 = -31574.15 Epsilon = 0.578
# 95
# 124
# resultado da epoca 427 = -35878.73 Epsilon = 0.577
# 90
# 129
# resultado da epoca 428 = -46300.18 Epsilon = 0.576
# 89
# 130
# resultado da epoca 429 = -9222.97 Epsilon = 0.575
# 108
# 111
# resultado da epoca 430 = -17086.36 Epsilon = 0.574
# 98
# 121
# resultado da epoca 431 = -12163.45 Epsilon = 0.573
# 109
# 110
# resultado da epoca 432 = -2860.95 Epsilon = 0.572
# 110
# 109
# resultado da epoca 433 = -30035.20 Epsilon = 0.571
# 100
# 119
# resultado da epoca 434 = -1441.24 Epsilon = 0.570
# 117
# 102
# resultado da epoca 435 = -30015.46 Epsilon = 0.569
# 111
# 108
# resultado da epoca 436 = -42072.79 Epsilon = 0.568
# 93
# 126
# resultado da epoca 437 = -27855.74 Epsilon = 0.567
# 97
# 122
# resultado da epoca 438 = -25950.17 Epsilon = 0.566
# 95
# 124
# resultado da epoca 439 = -21728.58 Epsilon = 0.565
# 98
# 121
# resultado da epoca 440 = -17873.09 Epsilon = 0.564
# 101
# 118
# resultado da epoca 441 = -10542.49 Epsilon = 0.563
# 114
# 105
# resultado da epoca 442 = -10305.99 Epsilon = 0.562
# 108
# 111
# resultado da epoca 443 = -22887.60 Epsilon = 0.561
# 102
# 117
# resultado da epoca 444 = -17250.37 Epsilon = 0.560
# 104
# 115
# resultado da epoca 445 = -9141.97 Epsilon = 0.559
# 109
# 110
# resultado da epoca 446 = -22725.66 Epsilon = 0.558
# 100
# 119
# resultado da epoca 447 = -11874.76 Epsilon = 0.557
# 107
# 112
# resultado da epoca 448 = -7000.60 Epsilon = 0.556
# 112
# 107
# resultado da epoca 449 = 9888.42 Epsilon = 0.555
# 110
# 109
# resultado da epoca 450 = -11161.08 Epsilon = 0.554
# 104
# 115
# resultado da epoca 451 = 3302.58 Epsilon = 0.554
# 108
# 111
# resultado da epoca 452 = -5285.62 Epsilon = 0.553
# 107
# 112
# resultado da epoca 453 = -5545.62 Epsilon = 0.552
# 101
# 118
# resultado da epoca 454 = -1282.16 Epsilon = 0.551
# 108
# 111
# resultado da epoca 455 = -29964.53 Epsilon = 0.550
# 105
# 114
# resultado da epoca 456 = -23144.22 Epsilon = 0.549
# 97
# 122
# resultado da epoca 457 = -578.50 Epsilon = 0.548
# 114
# 105
# resultado da epoca 458 = -11312.17 Epsilon = 0.547
# 105
# 114
# resultado da epoca 459 = -158.77 Epsilon = 0.546
# 112
# 107
# resultado da epoca 460 = -24261.66 Epsilon = 0.545
# 98
# 121
# resultado da epoca 461 = -902.45 Epsilon = 0.544
# 107
# 112
# resultado da epoca 462 = -7188.38 Epsilon = 0.543
# 114
# 105
# resultado da epoca 463 = -20442.08 Epsilon = 0.542
# 116
# 103
# resultado da epoca 464 = -15432.90 Epsilon = 0.541
# 109
# 110
# resultado da epoca 465 = -19314.18 Epsilon = 0.540
# 103
# 116
# resultado da epoca 466 = -12118.17 Epsilon = 0.539
# 100
# 119
# resultado da epoca 467 = -16790.66 Epsilon = 0.538
# 98
# 121
# resultado da epoca 468 = -49341.68 Epsilon = 0.537
# 93
# 126
# resultado da epoca 469 = -24884.84 Epsilon = 0.536
# 104
# 115
# resultado da epoca 470 = -11366.53 Epsilon = 0.535
# 105
# 114
# resultado da epoca 471 = -33921.77 Epsilon = 0.534
# 101
# 118
# resultado da epoca 472 = 19513.43 Epsilon = 0.533
# 121
# 98
# resultado da epoca 473 = -30121.85 Epsilon = 0.532
# 97
# 122
# resultado da epoca 474 = 12964.71 Epsilon = 0.531
# 116
# 103
# resultado da epoca 475 = -16490.80 Epsilon = 0.530
# 106
# 113
# resultado da epoca 476 = 14591.58 Epsilon = 0.529
# 116
# 103
# resultado da epoca 477 = 5254.21 Epsilon = 0.528
# 116
# 103
# resultado da epoca 478 = -44173.34 Epsilon = 0.527
# 96
# 123
# resultado da epoca 479 = -60385.65 Epsilon = 0.526
# 85
# 134
# resultado da epoca 480 = -18214.86 Epsilon = 0.525
# 103
# 116
# resultado da epoca 481 = -25195.23 Epsilon = 0.524
# 92
# 127
# resultado da epoca 482 = -3132.91 Epsilon = 0.523
# 103
# 116
# resultado da epoca 483 = -11044.00 Epsilon = 0.522
# 109
# 110
# resultado da epoca 484 = -25391.86 Epsilon = 0.521
# 95
# 124
# resultado da epoca 485 = -7947.51 Epsilon = 0.520
# 105
# 114
# resultado da epoca 486 = -10060.74 Epsilon = 0.519
# 113
# 106
# resultado da epoca 487 = 13249.32 Epsilon = 0.518
# 114
# 105
# resultado da epoca 488 = -8160.74 Epsilon = 0.517
# 112
# 107
# resultado da epoca 489 = -28447.01 Epsilon = 0.516
# 100
# 119
# resultado da epoca 490 = -32848.99 Epsilon = 0.515
# 98
# 121
# resultado da epoca 491 = -27477.65 Epsilon = 0.514
# 98
# 121
# resultado da epoca 492 = -26819.95 Epsilon = 0.513
# 110
# 109
# resultado da epoca 493 = -18788.32 Epsilon = 0.512
# 106
# 113
# resultado da epoca 494 = -20481.97 Epsilon = 0.511
# 107
# 112
# resultado da epoca 495 = 14753.05 Epsilon = 0.510
# 116
# 103
# resultado da epoca 496 = 1339.70 Epsilon = 0.509
# 113
# 106
# resultado da epoca 497 = -22783.23 Epsilon = 0.508
# 102
# 117
# resultado da epoca 498 = -12471.27 Epsilon = 0.507
# 111
# 108
# resultado da epoca 499 = -7474.70 Epsilon = 0.506
# 110
# 109
# resultado da epoca 500 = 12646.21 Epsilon = 0.505
# 120
# 99
# resultado da epoca 501 = -8680.71 Epsilon = 0.504
# 97
# 122
# resultado da epoca 502 = -29992.02 Epsilon = 0.503
# 102
# 117
# resultado da epoca 503 = -8428.86 Epsilon = 0.502
# 102
# 117
# resultado da epoca 504 = -4155.56 Epsilon = 0.501
# 110
# 109
# resultado da epoca 505 = 612.25 Epsilon = 0.500
# 110
# 109
# resultado da epoca 506 = -17363.47 Epsilon = 0.499
# 105
# 114
# resultado da epoca 507 = -17269.04 Epsilon = 0.498
# 105
# 114
# resultado da epoca 508 = -2839.89 Epsilon = 0.497
# 106
# 113
# resultado da epoca 509 = 1367.89 Epsilon = 0.496
# 100
# 119
# resultado da epoca 510 = -14624.03 Epsilon = 0.495
# 100
# 119
# resultado da epoca 511 = -3744.25 Epsilon = 0.494
# 108
# 111
# resultado da epoca 512 = 889.75 Epsilon = 0.493
# 105
# 114
# resultado da epoca 513 = 23225.18 Epsilon = 0.492
# 111
# 108
# resultado da epoca 514 = -29316.32 Epsilon = 0.491
# 97
# 122
# resultado da epoca 515 = 2775.30 Epsilon = 0.490
# 109
# 110
# resultado da epoca 516 = -10177.41 Epsilon = 0.489
# 108
# 111
# resultado da epoca 517 = -18492.31 Epsilon = 0.488
# 95
# 124
# resultado da epoca 518 = -11401.04 Epsilon = 0.487
# 107
# 112
# resultado da epoca 519 = -10131.17 Epsilon = 0.486
# 102
# 117
# resultado da epoca 520 = -29339.23 Epsilon = 0.485
# 101
# 118
# resultado da epoca 521 = -16594.20 Epsilon = 0.484
# 108
# 111
# resultado da epoca 522 = -12201.91 Epsilon = 0.483
# 112
# 107
# resultado da epoca 523 = -8303.48 Epsilon = 0.482
# 105
# 114
# resultado da epoca 524 = -40836.46 Epsilon = 0.481
# 97
# 122
# resultado da epoca 525 = 9565.78 Epsilon = 0.480
# 107
# 112
# resultado da epoca 526 = 10210.07 Epsilon = 0.479
# 111
# 108
# resultado da epoca 527 = -16987.31 Epsilon = 0.478
# 104
# 115
# resultado da epoca 528 = -16144.40 Epsilon = 0.477
# 107
# 112
# resultado da epoca 529 = -30923.61 Epsilon = 0.476
# 104
# 115
# resultado da epoca 530 = -21474.60 Epsilon = 0.475
# 107
# 112
# resultado da epoca 531 = -28812.87 Epsilon = 0.474
# 94
# 125
# resultado da epoca 532 = -23201.13 Epsilon = 0.473
# 104
# 115
# resultado da epoca 533 = 14124.23 Epsilon = 0.472
# 108
# 111
# resultado da epoca 534 = 11677.88 Epsilon = 0.471
# 112
# 107
# resultado da epoca 535 = -10734.10 Epsilon = 0.470
# 108
# 111
# resultado da epoca 536 = -7198.81 Epsilon = 0.469
# 112
# 107
# resultado da epoca 537 = -7790.39 Epsilon = 0.468
# 111
# 108
# resultado da epoca 538 = 14795.43 Epsilon = 0.467
# 120
# 99
# resultado da epoca 539 = -12465.83 Epsilon = 0.466
# 106
# 113
# resultado da epoca 540 = -12489.93 Epsilon = 0.465
# 107
# 112
# resultado da epoca 541 = 13683.37 Epsilon = 0.464
# 106
# 113
# resultado da epoca 542 = -22048.85 Epsilon = 0.463
# 109
# 110
# resultado da epoca 543 = 75.97 Epsilon = 0.462
# 104
# 115
# resultado da epoca 544 = -15169.14 Epsilon = 0.461
# 106
# 113
# resultado da epoca 545 = -11667.64 Epsilon = 0.460
# 107
# 112
# resultado da epoca 546 = -24422.90 Epsilon = 0.459
# 110
# 109
# resultado da epoca 547 = -26597.30 Epsilon = 0.458
# 103
# 116
# resultado da epoca 548 = -41599.66 Epsilon = 0.457
# 91
# 128
# resultado da epoca 549 = -22305.07 Epsilon = 0.456
# 108
# 111
# resultado da epoca 550 = -29517.24 Epsilon = 0.455
# 100
# 119
# resultado da epoca 551 = -5937.08 Epsilon = 0.455
# 100
# 119
# resultado da epoca 552 = 11428.50 Epsilon = 0.454
# 113
# 106
# resultado da epoca 553 = -15844.95 Epsilon = 0.453
# 109
# 110
# resultado da epoca 554 = 22726.40 Epsilon = 0.452
# 123
# 96
# resultado da epoca 555 = 11069.84 Epsilon = 0.451
# 122
# 97
# resultado da epoca 556 = -8489.32 Epsilon = 0.450
# 110
# 109
# resultado da epoca 557 = -30658.65 Epsilon = 0.449
# 89
# 130
# resultado da epoca 558 = -10484.72 Epsilon = 0.448
# 110
# 109
# resultado da epoca 559 = -20233.88 Epsilon = 0.447
# 106
# 113
# resultado da epoca 560 = -16472.54 Epsilon = 0.446
# 104
# 115
# resultado da epoca 561 = 2704.88 Epsilon = 0.445
# 119
# 100
# resultado da epoca 562 = -14392.73 Epsilon = 0.444
# 101
# 118
# resultado da epoca 563 = -31261.61 Epsilon = 0.443
# 100
# 119
# resultado da epoca 564 = -14418.50 Epsilon = 0.442
# 106
# 113
# resultado da epoca 565 = -26351.12 Epsilon = 0.441
# 111
# 108
# resultado da epoca 566 = -27107.00 Epsilon = 0.440
# 105
# 114
# resultado da epoca 567 = -17396.56 Epsilon = 0.439
# 107
# 112
# resultado da epoca 568 = -36732.72 Epsilon = 0.438
# 92
# 127
# resultado da epoca 569 = -9173.13 Epsilon = 0.437
# 113
# 106
# resultado da epoca 570 = -9515.71 Epsilon = 0.436
# 107
# 112
# resultado da epoca 571 = -2875.17 Epsilon = 0.435
# 111
# 108
# resultado da epoca 572 = 2724.95 Epsilon = 0.434
# 115
# 104
# resultado da epoca 573 = -19124.03 Epsilon = 0.433
# 107
# 112
# resultado da epoca 574 = -5501.31 Epsilon = 0.432
# 106
# 113
# resultado da epoca 575 = -18545.96 Epsilon = 0.431
# 111
# 108
# resultado da epoca 576 = -16519.62 Epsilon = 0.430
# 106
# 113
# resultado da epoca 577 = -16648.02 Epsilon = 0.429
# 110
# 109
# resultado da epoca 578 = -3897.14 Epsilon = 0.428
# 101
# 118
# resultado da epoca 579 = 9803.55 Epsilon = 0.427
# 118
# 101
# resultado da epoca 580 = 16400.03 Epsilon = 0.426
# 122
# 97
# resultado da epoca 581 = 12479.76 Epsilon = 0.425
# 116
# 103
# resultado da epoca 582 = 2557.58 Epsilon = 0.424
# 111
# 108
# resultado da epoca 583 = 8395.62 Epsilon = 0.423
# 115
# 104
# resultado da epoca 584 = 15681.20 Epsilon = 0.422
# 122
# 97
# resultado da epoca 585 = -1690.61 Epsilon = 0.421
# 111
# 108
# resultado da epoca 586 = 25068.23 Epsilon = 0.420
# 122
# 97
# resultado da epoca 587 = 12171.41 Epsilon = 0.419
# 121
# 98
# resultado da epoca 588 = -13974.69 Epsilon = 0.418
# 100
# 119
# resultado da epoca 589 = -37393.73 Epsilon = 0.417
# 88
# 131
# resultado da epoca 590 = -30004.22 Epsilon = 0.416
# 105
# 114
# resultado da epoca 591 = -11193.33 Epsilon = 0.415
# 102
# 117
# resultado da epoca 592 = -13734.73 Epsilon = 0.414
# 108
# 111
# resultado da epoca 593 = 9383.47 Epsilon = 0.413
# 116
# 103
# resultado da epoca 594 = -20606.33 Epsilon = 0.412
# 110
# 109
# resultado da epoca 595 = 4503.48 Epsilon = 0.411
# 110
# 109
# resultado da epoca 596 = 7678.51 Epsilon = 0.410
# 121
# 98
# resultado da epoca 597 = 18452.73 Epsilon = 0.409
# 108
# 111
# resultado da epoca 598 = -13976.66 Epsilon = 0.408
# 107
# 112
# resultado da epoca 599 = -23475.93 Epsilon = 0.407
# 99
# 120
# resultado da epoca 600 = -9943.29 Epsilon = 0.406
# 110
# 109
# resultado da epoca 601 = 11760.24 Epsilon = 0.405
# 116
# 103
# resultado da epoca 602 = -17599.56 Epsilon = 0.404
# 113
# 106
# resultado da epoca 603 = 14077.70 Epsilon = 0.403
# 125
# 94
# resultado da epoca 604 = -22331.25 Epsilon = 0.402
# 112
# 107
# resultado da epoca 605 = 7162.77 Epsilon = 0.401
# 108
# 111
# resultado da epoca 606 = 16014.39 Epsilon = 0.400
# 116
# 103
# resultado da epoca 607 = -22830.99 Epsilon = 0.399
# 101
# 118
# resultado da epoca 608 = -16657.04 Epsilon = 0.398
# 107
# 112
# resultado da epoca 609 = -17985.51 Epsilon = 0.397
# 109
# 110
# resultado da epoca 610 = -12262.47 Epsilon = 0.396
# 106
# 113
# resultado da epoca 611 = -10123.49 Epsilon = 0.395
# 112
# 107
# resultado da epoca 612 = 14101.59 Epsilon = 0.394
# 118
# 101
# resultado da epoca 613 = -17287.03 Epsilon = 0.393
# 102
# 117
# resultado da epoca 614 = -1052.61 Epsilon = 0.392
# 115
# 104
# resultado da epoca 615 = -4914.41 Epsilon = 0.391
# 107
# 112
# resultado da epoca 616 = -16650.93 Epsilon = 0.390
# 100
# 119
# resultado da epoca 617 = 25963.42 Epsilon = 0.389
# 110
# 109
# resultado da epoca 618 = 20172.03 Epsilon = 0.388
# 118
# 101
# resultado da epoca 619 = 6092.28 Epsilon = 0.387
# 117
# 102
# resultado da epoca 620 = -30041.16 Epsilon = 0.386
# 88
# 131
# resultado da epoca 621 = -6788.60 Epsilon = 0.385
# 109
# 110
# resultado da epoca 622 = -22493.39 Epsilon = 0.384
# 108
# 111
# resultado da epoca 623 = -4838.96 Epsilon = 0.383
# 111
# 108
# resultado da epoca 624 = -12026.08 Epsilon = 0.382
# 105
# 114
# resultado da epoca 625 = 6542.63 Epsilon = 0.381
# 117
# 102
# resultado da epoca 626 = -9571.52 Epsilon = 0.380
# 102
# 117
# resultado da epoca 627 = -11637.94 Epsilon = 0.379
# 97
# 122
# resultado da epoca 628 = -26591.63 Epsilon = 0.378
# 102
# 117
# resultado da epoca 629 = -1675.97 Epsilon = 0.377
# 112
# 107
# resultado da epoca 630 = 7088.20 Epsilon = 0.376
# 114
# 105
# resultado da epoca 631 = -4757.22 Epsilon = 0.375
# 101
# 118
# resultado da epoca 632 = -13851.79 Epsilon = 0.374
# 105
# 114
# resultado da epoca 633 = 11051.94 Epsilon = 0.373
# 116
# 103
# resultado da epoca 634 = -19833.62 Epsilon = 0.372
# 104
# 115
# resultado da epoca 635 = -7008.75 Epsilon = 0.371
# 109
# 110
# resultado da epoca 636 = -13753.54 Epsilon = 0.370
# 110
# 109
# resultado da epoca 637 = -11801.13 Epsilon = 0.369
# 107
# 112
# resultado da epoca 638 = 8447.30 Epsilon = 0.368
# 115
# 104
# resultado da epoca 639 = -3308.70 Epsilon = 0.367
# 107
# 112
# resultado da epoca 640 = -13159.87 Epsilon = 0.366
# 102
# 117
# resultado da epoca 641 = -10030.53 Epsilon = 0.365
# 110
# 109
# resultado da epoca 642 = -8116.10 Epsilon = 0.364
# 100
# 119
# resultado da epoca 643 = -16222.66 Epsilon = 0.363
# 104
# 115
# resultado da epoca 644 = -4395.47 Epsilon = 0.362
# 102
# 117
# resultado da epoca 645 = 5091.85 Epsilon = 0.361
# 103
# 116
# resultado da epoca 646 = 4349.05 Epsilon = 0.360
# 112
# 107
# resultado da epoca 647 = -1971.27 Epsilon = 0.359
# 108
# 111
# resultado da epoca 648 = 4330.16 Epsilon = 0.358
# 110
# 109
# resultado da epoca 649 = -8017.44 Epsilon = 0.357
# 106
# 113
# resultado da epoca 650 = 4410.60 Epsilon = 0.356
# 114
# 105
# resultado da epoca 651 = -3735.01 Epsilon = 0.356
# 106
# 113
# resultado da epoca 652 = 4972.60 Epsilon = 0.355
# 106
# 113
# resultado da epoca 653 = -24910.35 Epsilon = 0.354
# 104
# 115
# resultado da epoca 654 = 156.89 Epsilon = 0.353
# 112
# 107
# resultado da epoca 655 = -35766.43 Epsilon = 0.352
# 96
# 123
# resultado da epoca 656 = 7536.53 Epsilon = 0.351
# 114
# 105
# resultado da epoca 657 = -36669.24 Epsilon = 0.350
# 97
# 122
# resultado da epoca 658 = -29204.10 Epsilon = 0.349
# 107
# 112
# resultado da epoca 659 = -6296.76 Epsilon = 0.348
# 106
# 113
# resultado da epoca 660 = -2130.94 Epsilon = 0.347
# 102
# 117
# resultado da epoca 661 = -19957.38 Epsilon = 0.346
# 93
# 126
# resultado da epoca 662 = -11861.68 Epsilon = 0.345
# 115
# 104
# resultado da epoca 663 = 8505.05 Epsilon = 0.344
# 119
# 100
# resultado da epoca 664 = -23048.58 Epsilon = 0.343
# 103
# 116
# resultado da epoca 665 = -33044.05 Epsilon = 0.342
# 97
# 122
# resultado da epoca 666 = -17554.98 Epsilon = 0.341
# 100
# 119
# resultado da epoca 667 = -594.89 Epsilon = 0.340
# 112
# 107
# resultado da epoca 668 = -17888.90 Epsilon = 0.339
# 96
# 123
# resultado da epoca 669 = 10511.87 Epsilon = 0.338
# 111
# 108
# resultado da epoca 670 = 7346.46 Epsilon = 0.337
# 113
# 106
# resultado da epoca 671 = -18112.08 Epsilon = 0.336
# 100
# 119
# resultado da epoca 672 = 26610.96 Epsilon = 0.335
# 122
# 97
# resultado da epoca 673 = -4710.00 Epsilon = 0.334
# 107
# 112
# resultado da epoca 674 = -15573.63 Epsilon = 0.333
# 101
# 118
# resultado da epoca 675 = -31423.30 Epsilon = 0.332
# 90
# 129
# resultado da epoca 676 = -23583.16 Epsilon = 0.331
# 91
# 128
# resultado da epoca 677 = -26268.80 Epsilon = 0.330
# 95
# 124
# resultado da epoca 678 = -33444.09 Epsilon = 0.329
# 102
# 117
# resultado da epoca 679 = -4161.84 Epsilon = 0.328
# 103
# 116
# resultado da epoca 680 = -14987.21 Epsilon = 0.327
# 99
# 120
# resultado da epoca 681 = 2065.94 Epsilon = 0.326
# 115
# 104
# resultado da epoca 682 = -10039.74 Epsilon = 0.325
# 102
# 117
# resultado da epoca 683 = -25147.59 Epsilon = 0.324
# 93
# 126
# resultado da epoca 684 = 26587.75 Epsilon = 0.323
# 124
# 95
# resultado da epoca 685 = -11712.24 Epsilon = 0.322
# 101
# 118
# resultado da epoca 686 = 202.99 Epsilon = 0.321
# 118
# 101
# resultado da epoca 687 = -17271.09 Epsilon = 0.320
# 103
# 116
# resultado da epoca 688 = 657.83 Epsilon = 0.319
# 118
# 101
# resultado da epoca 689 = -28637.18 Epsilon = 0.318
# 94
# 125
# resultado da epoca 690 = -12284.68 Epsilon = 0.317
# 109
# 110
# resultado da epoca 691 = -15375.52 Epsilon = 0.316
# 97
# 122
# resultado da epoca 692 = -9641.33 Epsilon = 0.315
# 101
# 118
# resultado da epoca 693 = -5113.81 Epsilon = 0.314
# 99
# 120
# resultado da epoca 694 = 3963.99 Epsilon = 0.313
# 113
# 106
# resultado da epoca 695 = 2680.24 Epsilon = 0.312
# 110
# 109
# resultado da epoca 696 = -6443.95 Epsilon = 0.311
# 107
# 112
# resultado da epoca 697 = -2696.79 Epsilon = 0.310
# 108
# 111
# resultado da epoca 698 = 6651.92 Epsilon = 0.309
# 111
# 108
# resultado da epoca 699 = -22445.50 Epsilon = 0.308
# 103
# 116
# resultado da epoca 700 = -15729.57 Epsilon = 0.307
# 104
# 115
# resultado da epoca 701 = -8269.06 Epsilon = 0.306
# 104
# 115
# resultado da epoca 702 = -20245.97 Epsilon = 0.305
# 103
# 116
# resultado da epoca 703 = -13195.27 Epsilon = 0.304
# 95
# 124
# resultado da epoca 704 = -21608.42 Epsilon = 0.303
# 94
# 125
# resultado da epoca 705 = -4378.45 Epsilon = 0.302
# 107
# 112
# resultado da epoca 706 = -5184.47 Epsilon = 0.301
# 105
# 114
# resultado da epoca 707 = -15428.68 Epsilon = 0.300
# 96
# 123
# resultado da epoca 708 = -5431.04 Epsilon = 0.299
# 102
# 117
# resultado da epoca 709 = -9615.47 Epsilon = 0.298
# 100
# 119
# resultado da epoca 710 = -32222.08 Epsilon = 0.297
# 95
# 124
# resultado da epoca 711 = -8920.68 Epsilon = 0.296
# 112
# 107
# resultado da epoca 712 = -21841.21 Epsilon = 0.295
# 98
# 121
# resultado da epoca 713 = -11552.63 Epsilon = 0.294
# 101
# 118
# resultado da epoca 714 = 17936.54 Epsilon = 0.293
# 103
# 116
# resultado da epoca 715 = -5838.29 Epsilon = 0.292
# 111
# 108
# resultado da epoca 716 = -718.41 Epsilon = 0.291
# 110
# 109
# resultado da epoca 717 = -8437.74 Epsilon = 0.290
# 99
# 120
# resultado da epoca 718 = 302.81 Epsilon = 0.289
# 103
# 116
# resultado da epoca 719 = -12236.64 Epsilon = 0.288
# 103
# 116
# resultado da epoca 720 = 2004.94 Epsilon = 0.287
# 104
# 115
# resultado da epoca 721 = -19206.54 Epsilon = 0.286
# 100
# 119
# resultado da epoca 722 = 6912.41 Epsilon = 0.285
# 112
# 107
# resultado da epoca 723 = -2421.61 Epsilon = 0.284
# 108
# 111
# resultado da epoca 724 = -4756.55 Epsilon = 0.283
# 104
# 115
# resultado da epoca 725 = -9954.34 Epsilon = 0.282
# 101
# 118
# resultado da epoca 726 = -9927.63 Epsilon = 0.281
# 110
# 109
# resultado da epoca 727 = -12567.92 Epsilon = 0.280
# 108
# 111
# resultado da epoca 728 = 8306.20 Epsilon = 0.279
# 122
# 97
# resultado da epoca 729 = -11962.43 Epsilon = 0.278
# 95
# 124
# resultado da epoca 730 = 19079.40 Epsilon = 0.277
# 109
# 110
# resultado da epoca 731 = -36604.80 Epsilon = 0.276
# 103
# 116
# resultado da epoca 732 = 10727.94 Epsilon = 0.275
# 118
# 101
# resultado da epoca 733 = 16455.35 Epsilon = 0.274
# 114
# 105
# resultado da epoca 734 = -16526.17 Epsilon = 0.273
# 107
# 112
# resultado da epoca 735 = 5149.89 Epsilon = 0.272
# 111
# 108
# resultado da epoca 736 = -16150.16 Epsilon = 0.271
# 103
# 116
# resultado da epoca 737 = -21931.32 Epsilon = 0.270
# 99
# 120
# resultado da epoca 738 = 3161.59 Epsilon = 0.269
# 105
# 114
# resultado da epoca 739 = -24508.18 Epsilon = 0.268
# 98
# 121
# resultado da epoca 740 = -24945.29 Epsilon = 0.267
# 95
# 124
# resultado da epoca 741 = 6541.07 Epsilon = 0.266
# 111
# 108
# resultado da epoca 742 = 3918.37 Epsilon = 0.265
# 113
# 106
# resultado da epoca 743 = -23319.16 Epsilon = 0.264
# 99
# 120
# resultado da epoca 744 = -22540.45 Epsilon = 0.263
# 108
# 111
# resultado da epoca 745 = -28887.25 Epsilon = 0.262
# 92
# 127
# resultado da epoca 746 = 9848.23 Epsilon = 0.261
# 112
# 107
# resultado da epoca 747 = -1667.99 Epsilon = 0.260
# 103
# 116
# resultado da epoca 748 = -8514.07 Epsilon = 0.259
# 100
# 119
# resultado da epoca 749 = -10778.86 Epsilon = 0.258
# 95
# 124
# resultado da epoca 750 = -13872.37 Epsilon = 0.257
# 97
# 122
# resultado da epoca 751 = 3564.30 Epsilon = 0.257
# 112
# 107
# resultado da epoca 752 = 8506.53 Epsilon = 0.256
# 115
# 104
# resultado da epoca 753 = -497.65 Epsilon = 0.255
# 114
# 105
# resultado da epoca 754 = -18700.41 Epsilon = 0.254
# 98
# 121
# resultado da epoca 755 = -536.13 Epsilon = 0.253
# 113
# 106
# resultado da epoca 756 = -20882.21 Epsilon = 0.252
# 96
# 123
# resultado da epoca 757 = 3386.10 Epsilon = 0.251
# 107
# 112
# resultado da epoca 758 = -6606.94 Epsilon = 0.250
# 109
# 110
# resultado da epoca 759 = -47940.64 Epsilon = 0.249
# 94
# 125
# resultado da epoca 760 = 5246.99 Epsilon = 0.248
# 108
# 111
# resultado da epoca 761 = 16445.29 Epsilon = 0.247
# 114
# 105
# resultado da epoca 762 = 12241.00 Epsilon = 0.246
# 120
# 99
# resultado da epoca 763 = -3677.01 Epsilon = 0.245
# 111
# 108
# resultado da epoca 764 = -37270.40 Epsilon = 0.244
# 86
# 133
# resultado da epoca 765 = -25703.88 Epsilon = 0.243
# 92
# 127
# resultado da epoca 766 = -2805.46 Epsilon = 0.242
# 105
# 114
# resultado da epoca 767 = -23778.71 Epsilon = 0.241
# 96
# 123
# resultado da epoca 768 = -13456.19 Epsilon = 0.240
# 97
# 122
# resultado da epoca 769 = -1591.78 Epsilon = 0.239
# 108
# 111
# resultado da epoca 770 = -42465.89 Epsilon = 0.238
# 99
# 120
# resultado da epoca 771 = -18681.38 Epsilon = 0.237
# 100
# 119
# resultado da epoca 772 = -5900.76 Epsilon = 0.236
# 103
# 116
# resultado da epoca 773 = 4621.76 Epsilon = 0.235
# 110
# 109
# resultado da epoca 774 = -2808.66 Epsilon = 0.234
# 109
# 110
# resultado da epoca 775 = -586.21 Epsilon = 0.233
# 106
# 113
# resultado da epoca 776 = 17204.81 Epsilon = 0.232
# 120
# 99
# resultado da epoca 777 = -2663.32 Epsilon = 0.231
# 104
# 115
# resultado da epoca 778 = -4698.75 Epsilon = 0.230
# 105
# 114
# resultado da epoca 779 = -7208.49 Epsilon = 0.229
# 108
# 111
# resultado da epoca 780 = 356.75 Epsilon = 0.228
# 105
# 114
# resultado da epoca 781 = 271.85 Epsilon = 0.227
# 108
# 111
# resultado da epoca 782 = -14688.73 Epsilon = 0.226
# 105
# 114
# resultado da epoca 783 = -4553.87 Epsilon = 0.225
# 101
# 118
# resultado da epoca 784 = -9937.19 Epsilon = 0.224
# 104
# 115
# resultado da epoca 785 = -16306.18 Epsilon = 0.223
# 98
# 121
# resultado da epoca 786 = -15925.07 Epsilon = 0.222
# 102
# 117
# resultado da epoca 787 = -9092.22 Epsilon = 0.221
# 100
# 119
# resultado da epoca 788 = -19546.73 Epsilon = 0.220
# 104
# 115
# resultado da epoca 789 = -2535.56 Epsilon = 0.219
# 109
# 110
# resultado da epoca 790 = -8607.46 Epsilon = 0.218
# 94
# 125
# resultado da epoca 791 = -12035.66 Epsilon = 0.217
# 95
# 124
# resultado da epoca 792 = -3125.01 Epsilon = 0.216
# 106
# 113
# resultado da epoca 793 = 2481.62 Epsilon = 0.215
# 107
# 112
# resultado da epoca 794 = -22036.66 Epsilon = 0.214
# 95
# 124
# resultado da epoca 795 = 8271.33 Epsilon = 0.213
# 115
# 104
# resultado da epoca 796 = 5203.02 Epsilon = 0.212
# 108
# 111
# resultado da epoca 797 = -22276.82 Epsilon = 0.211
# 102
# 117
# resultado da epoca 798 = -19813.45 Epsilon = 0.210
# 90
# 129
# resultado da epoca 799 = -4201.86 Epsilon = 0.209
# 105
# 114
# resultado da epoca 800 = -10650.60 Epsilon = 0.208
# 102
# 117
# resultado da epoca 801 = -16494.78 Epsilon = 0.207
# 102
# 117
# resultado da epoca 802 = -17757.46 Epsilon = 0.206
# 100
# 119
# resultado da epoca 803 = 10912.16 Epsilon = 0.205
# 110
# 109
# resultado da epoca 804 = 6060.32 Epsilon = 0.204
# 106
# 113
# resultado da epoca 805 = -38998.50 Epsilon = 0.203
# 95
# 124
# resultado da epoca 806 = -4083.71 Epsilon = 0.202
# 112
# 107
# resultado da epoca 807 = -10508.96 Epsilon = 0.201
# 108
# 111
# resultado da epoca 808 = -11512.02 Epsilon = 0.200
# 94
# 125
# resultado da epoca 809 = -10952.09 Epsilon = 0.199
# 105
# 114
# resultado da epoca 810 = 23534.70 Epsilon = 0.198
# 122
# 97
# resultado da epoca 811 = 2849.70 Epsilon = 0.197
# 117
# 102
# resultado da epoca 812 = -2169.13 Epsilon = 0.196
# 105
# 114
# resultado da epoca 813 = -20458.99 Epsilon = 0.195
# 104
# 115
# resultado da epoca 814 = 18497.93 Epsilon = 0.194
# 116
# 103
# resultado da epoca 815 = -5932.99 Epsilon = 0.193
# 106
# 113
# resultado da epoca 816 = 11785.89 Epsilon = 0.192
# 112
# 107
# resultado da epoca 817 = -226.24 Epsilon = 0.191
# 105
# 114
# resultado da epoca 818 = -580.24 Epsilon = 0.190
# 103
# 116
# resultado da epoca 819 = -3899.69 Epsilon = 0.189
# 105
# 114
# resultado da epoca 820 = 4538.79 Epsilon = 0.188
# 112
# 107
# resultado da epoca 821 = -8806.79 Epsilon = 0.187
# 99
# 120
# resultado da epoca 822 = 10631.69 Epsilon = 0.186
# 108
# 111
# resultado da epoca 823 = 1560.28 Epsilon = 0.185
# 113
# 106
# resultado da epoca 824 = -38281.40 Epsilon = 0.184
# 99
# 120
# resultado da epoca 825 = -10446.82 Epsilon = 0.183
# 101
# 118
# resultado da epoca 826 = -5903.71 Epsilon = 0.182
# 104
# 115
# resultado da epoca 827 = -9194.41 Epsilon = 0.181
# 101
# 118
# resultado da epoca 828 = -3879.62 Epsilon = 0.180
# 111
# 108
# resultado da epoca 829 = -1052.50 Epsilon = 0.179
# 111
# 108
# resultado da epoca 830 = 4642.88 Epsilon = 0.178
# 108
# 111
# resultado da epoca 831 = -10250.70 Epsilon = 0.177
# 106
# 113
# resultado da epoca 832 = 11066.20 Epsilon = 0.176
# 116
# 103
# resultado da epoca 833 = 191.64 Epsilon = 0.175
# 104
# 115
# resultado da epoca 834 = -16454.19 Epsilon = 0.174
# 99
# 120
# resultado da epoca 835 = -3705.53 Epsilon = 0.173
# 105
# 114
# resultado da epoca 836 = -7567.21 Epsilon = 0.172
# 115
# 104
# resultado da epoca 837 = 17438.34 Epsilon = 0.171
# 110
# 109
# resultado da epoca 838 = -13836.19 Epsilon = 0.170
# 105
# 114
# resultado da epoca 839 = -1859.72 Epsilon = 0.169
# 102
# 117
# resultado da epoca 840 = 7456.80 Epsilon = 0.168
# 115
# 104
# resultado da epoca 841 = -7381.33 Epsilon = 0.167
# 107
# 112
# resultado da epoca 842 = -25858.67 Epsilon = 0.166
# 93
# 126
# resultado da epoca 843 = -15454.08 Epsilon = 0.165
# 99
# 120
# resultado da epoca 844 = 7048.35 Epsilon = 0.164
# 117
# 102
# resultado da epoca 845 = -15559.63 Epsilon = 0.163
# 105
# 114
# resultado da epoca 846 = -8980.19 Epsilon = 0.162
# 106
# 113
# resultado da epoca 847 = 2501.34 Epsilon = 0.161
# 105
# 114
# resultado da epoca 848 = -22938.34 Epsilon = 0.160
# 105
# 114
# resultado da epoca 849 = 4612.51 Epsilon = 0.159
# 114
# 105
# resultado da epoca 850 = -11478.33 Epsilon = 0.158
# 110
# 108
# resultado da epoca 851 = -6564.99 Epsilon = 0.158
# 96
# 123
# resultado da epoca 852 = -8853.30 Epsilon = 0.157
# 106
# 113
# resultado da epoca 853 = 4945.97 Epsilon = 0.156
# 111
# 108
# resultado da epoca 854 = -4051.49 Epsilon = 0.155
# 105
# 114
# resultado da epoca 855 = 5711.89 Epsilon = 0.154
# 110
# 109
# resultado da epoca 856 = -18748.63 Epsilon = 0.153
# 107
# 112
# resultado da epoca 857 = 17434.17 Epsilon = 0.152
# 112
# 107
# resultado da epoca 858 = -7180.77 Epsilon = 0.151
# 98
# 120
# resultado da epoca 859 = -10441.60 Epsilon = 0.150
# 104
# 115
# resultado da epoca 860 = -33147.76 Epsilon = 0.149
# 97
# 121
# resultado da epoca 861 = -7514.19 Epsilon = 0.148
# 111
# 108
# resultado da epoca 862 = 5512.40 Epsilon = 0.147
# 109
# 110
# resultado da epoca 863 = -12807.15 Epsilon = 0.146
# 106
# 113
# resultado da epoca 864 = -16400.58 Epsilon = 0.145
# 100
# 119
# resultado da epoca 865 = -13545.35 Epsilon = 0.144
# 97
# 122
# resultado da epoca 866 = 5467.56 Epsilon = 0.143
# 113
# 106
# resultado da epoca 867 = -21607.49 Epsilon = 0.142
# 95
# 123
# resultado da epoca 868 = 3417.75 Epsilon = 0.141
# 109
# 110
# resultado da epoca 869 = -35366.34 Epsilon = 0.140
# 95
# 124
# resultado da epoca 870 = -253.33 Epsilon = 0.139
# 96
# 122
# resultado da epoca 871 = -1970.44 Epsilon = 0.138
# 99
# 120
# resultado da epoca 872 = -19403.75 Epsilon = 0.137
# 100
# 119
# resultado da epoca 873 = -17196.82 Epsilon = 0.136
# 96
# 123
# resultado da epoca 874 = -686.19 Epsilon = 0.135
# 108
# 111
# resultado da epoca 875 = -11249.00 Epsilon = 0.134
# 104
# 115
# resultado da epoca 876 = -4482.25 Epsilon = 0.133
# 102
# 117
# resultado da epoca 877 = -37900.03 Epsilon = 0.132
# 93
# 126
# resultado da epoca 878 = 9057.76 Epsilon = 0.131
# 109
# 110
# resultado da epoca 879 = -7293.09 Epsilon = 0.130
# 103
# 116
# resultado da epoca 880 = -26126.86 Epsilon = 0.129
# 87
# 132
# resultado da epoca 881 = -4568.80 Epsilon = 0.128
# 110
# 108
# resultado da epoca 882 = 760.99 Epsilon = 0.127
# 106
# 113
# resultado da epoca 883 = 7680.42 Epsilon = 0.126
# 115
# 103
# resultado da epoca 884 = -6251.99 Epsilon = 0.125
# 104
# 115
# resultado da epoca 885 = -10586.59 Epsilon = 0.124
# 99
# 120
# resultado da epoca 886 = -6425.20 Epsilon = 0.123
# 103
# 116
# resultado da epoca 887 = 11437.73 Epsilon = 0.122
# 117
# 102
# resultado da epoca 888 = 14833.47 Epsilon = 0.121
# 118
# 101
# resultado da epoca 889 = 119.20 Epsilon = 0.120
# 107
# 112
# resultado da epoca 890 = -22764.89 Epsilon = 0.119
# 94
# 125
# resultado da epoca 891 = -2520.77 Epsilon = 0.118
# 109
# 108
# resultado da epoca 892 = -27833.34 Epsilon = 0.117
# 101
# 116
# resultado da epoca 893 = -8846.63 Epsilon = 0.116
# 96
# 123
# resultado da epoca 894 = 20495.74 Epsilon = 0.115
# 116
# 103
# resultado da epoca 895 = 10220.93 Epsilon = 0.114
# 110
# 108
# resultado da epoca 896 = -9589.78 Epsilon = 0.113
# 100
# 118
# resultado da epoca 897 = -3464.23 Epsilon = 0.112
# 103
# 115
# resultado da epoca 898 = 11411.26 Epsilon = 0.111
# 108
# 110
# resultado da epoca 899 = 1786.58 Epsilon = 0.110
# 102
# 116
# resultado da epoca 900 = -7379.44 Epsilon = 0.109
# 108
# 110
# resultado da epoca 901 = -11667.81 Epsilon = 0.108
# 97
# 122
# resultado da epoca 902 = -148.42 Epsilon = 0.107
# 111
# 107
# resultado da epoca 903 = -2444.17 Epsilon = 0.106
# 109
# 110
# resultado da epoca 904 = 23782.97 Epsilon = 0.105
# 105
# 112
# resultado da epoca 905 = -7713.78 Epsilon = 0.104
# 103
# 115
# resultado da epoca 906 = 670.54 Epsilon = 0.103
# 104
# 114
# resultado da epoca 907 = -10291.60 Epsilon = 0.102
# 108
# 111
# resultado da epoca 908 = 5039.63 Epsilon = 0.101
# 110
# 109
# resultado da epoca 909 = 1529.95 Epsilon = 0.100
# 104
# 113
# resultado da epoca 910 = 10989.49 Epsilon = 0.099
# 103
# 115
# resultado da epoca 911 = -10120.53 Epsilon = 0.098
# 112
# 103
# resultado da epoca 912 = 10560.75 Epsilon = 0.097
# 113
# 103
# resultado da epoca 913 = -18163.28 Epsilon = 0.096
# 90
# 128
# resultado da epoca 914 = -3863.63 Epsilon = 0.095
# 104
# 114
# resultado da epoca 915 = -4958.12 Epsilon = 0.094
# 99
# 118
# resultado da epoca 916 = 5418.42 Epsilon = 0.093
# 104
# 113
# resultado da epoca 917 = -12567.01 Epsilon = 0.092
# 98
# 120
# resultado da epoca 918 = 1147.78 Epsilon = 0.091
# 97
# 119
# resultado da epoca 919 = 9110.87 Epsilon = 0.090
# 99
# 116
# resultado da epoca 920 = -34083.01 Epsilon = 0.089
# 77
# 139
# resultado da epoca 921 = -16646.08 Epsilon = 0.088
# 83
# 135
# resultado da epoca 922 = 6926.50 Epsilon = 0.087
# 100
# 118
# resultado da epoca 923 = 4770.51 Epsilon = 0.086
# 96
# 120
# resultado da epoca 924 = -11576.05 Epsilon = 0.085
# 89
# 128
# resultado da epoca 925 = 7709.65 Epsilon = 0.084
# 111
# 107
# resultado da epoca 926 = -33089.93 Epsilon = 0.083
# 81
# 133
# resultado da epoca 927 = 4400.41 Epsilon = 0.082
# 102
# 114
# resultado da epoca 928 = 120.56 Epsilon = 0.081
# 98
# 118
# resultado da epoca 929 = -10310.31 Epsilon = 0.080
# 106
# 111
# resultado da epoca 930 = 2424.37 Epsilon = 0.079
# 98
# 117
# resultado da epoca 931 = 8569.28 Epsilon = 0.078
# 108
# 106
# resultado da epoca 932 = 11706.41 Epsilon = 0.077
# 104
# 113
# resultado da epoca 933 = 2088.42 Epsilon = 0.076
# 90
# 124
# resultado da epoca 934 = -1804.10 Epsilon = 0.075
# 94
# 125
# resultado da epoca 935 = 8659.86 Epsilon = 0.074
# 93
# 122
# resultado da epoca 936 = 5883.31 Epsilon = 0.073
# 101
# 114
# resultado da epoca 937 = -12652.83 Epsilon = 0.072
# 95
# 123
# resultado da epoca 938 = -6286.86 Epsilon = 0.071
# 94
# 120
# resultado da epoca 939 = -9631.47 Epsilon = 0.070
# 88
# 129
# resultado da epoca 940 = -13555.89 Epsilon = 0.069
# 82
# 132
# resultado da epoca 941 = -9582.89 Epsilon = 0.068
# 81
# 130
# resultado da epoca 942 = -10927.45 Epsilon = 0.067
# 86
# 127
# resultado da epoca 943 = 109.11 Epsilon = 0.066
# 85
# 122
# resultado da epoca 944 = -14684.25 Epsilon = 0.065
# 93
# 122
# resultado da epoca 945 = -10721.73 Epsilon = 0.064
# 85
# 127
# resultado da epoca 946 = -103.76 Epsilon = 0.063
# 86
# 124
# resultado da epoca 947 = -1995.70 Epsilon = 0.062
# 81
# 129
# resultado da epoca 948 = -9603.74 Epsilon = 0.061
# 89
# 121
# resultado da epoca 949 = 5389.13 Epsilon = 0.060
# 80
# 120
# resultado da epoca 950 = -1894.53 Epsilon = 0.059
# 94
# 115
# resultado da epoca 951 = -6039.64 Epsilon = 0.059
# 79
# 130
# resultado da epoca 952 = -11451.50 Epsilon = 0.058
# 84
# 123
# resultado da epoca 953 = 11785.06 Epsilon = 0.057
# 85
# 121
# resultado da epoca 954 = -11098.16 Epsilon = 0.056
# 81
# 129
# resultado da epoca 955 = 1003.59 Epsilon = 0.055
# 79
# 128
# resultado da epoca 956 = -1408.35 Epsilon = 0.054
# 74
# 130
# resultado da epoca 957 = -13110.57 Epsilon = 0.053
# 81
# 122
# resultado da epoca 958 = -10001.64 Epsilon = 0.052
# 77
# 126
# resultado da epoca 959 = 3570.22 Epsilon = 0.051
# 79
# 125
# resultado da epoca 960 = -1423.87 Epsilon = 0.050
# 74
# 130
# resultado da epoca 961 = -679.51 Epsilon = 0.049
# 74
# 126
# resultado da epoca 962 = 4825.95 Epsilon = 0.048
# 81
# 118
# resultado da epoca 963 = -5535.95 Epsilon = 0.047
# 76
# 127
# resultado da epoca 964 = -3071.64 Epsilon = 0.046
# 59
# 142
# resultado da epoca 965 = -229.31 Epsilon = 0.045
# 77
# 126
# resultado da epoca 966 = -3879.13 Epsilon = 0.044
# 68
# 130
# resultado da epoca 967 = 1855.09 Epsilon = 0.043
# 82
# 118
# resultado da epoca 968 = -16981.38 Epsilon = 0.042
# 52
# 142
# resultado da epoca 969 = -10787.12 Epsilon = 0.041
# 56
# 130
# resultado da epoca 970 = -775.82 Epsilon = 0.040
# 67
# 127
# resultado da epoca 971 = -12529.16 Epsilon = 0.039
# 44
# 141
# resultado da epoca 972 = -7340.29 Epsilon = 0.038
# 59
# 128
# resultado da epoca 973 = -351.80 Epsilon = 0.037
# 64
# 128
# resultado da epoca 974 = -10880.81 Epsilon = 0.036
# 53
# 133
# resultado da epoca 975 = -340.24 Epsilon = 0.035
# 60
# 121
# resultado da epoca 976 = 681.31 Epsilon = 0.034
# 59
# 127
# resultado da epoca 977 = 486.86 Epsilon = 0.033
# 49
# 133
# resultado da epoca 978 = -425.53 Epsilon = 0.032
# 39
# 143
# resultado da epoca 979 = 1058.77 Epsilon = 0.031
# 43
# 132
# resultado da epoca 980 = 2188.39 Epsilon = 0.030
# 51
# 128
# resultado da epoca 981 = 16812.10 Epsilon = 0.029
# 62
# 102
# resultado da epoca 982 = 621.47 Epsilon = 0.028
# 42
# 123
# resultado da epoca 983 = 1702.99 Epsilon = 0.027
# 40
# 121
# resultado da epoca 984 = 8099.57 Epsilon = 0.026
# 45
# 122
# resultado da epoca 985 = -86.46 Epsilon = 0.025
# 34
# 118
# resultado da epoca 986 = -4787.47 Epsilon = 0.024
# 50
# 103
# resultado da epoca 987 = -6209.92 Epsilon = 0.023
# 42
# 118
# resultado da epoca 988 = -3474.34 Epsilon = 0.022
# 36
# 110
# resultado da epoca 989 = 2309.85 Epsilon = 0.021
# 34
# 111
# resultado da epoca 990 = -634.26 Epsilon = 0.020
# 27
# 121
# resultado da epoca 991 = 2655.78 Epsilon = 0.019
# 37
# 107
# resultado da epoca 992 = -2205.21 Epsilon = 0.018
# 19
# 111
# resultado da epoca 993 = -4293.74 Epsilon = 0.017
# 24
# 104
# resultado da epoca 994 = -2247.18 Epsilon = 0.016
# 21
# 106
# resultado da epoca 995 = 2234.11 Epsilon = 0.015
# 21
# 92
# resultado da epoca 996 = -2178.35 Epsilon = 0.014
# 16
# 95
# resultado da epoca 997 = -9479.09 Epsilon = 0.013
# 16
# 103
# resultado da epoca 998 = -3767.47 Epsilon = 0.012
# 19
# 77
# resultado da epoca 999 = -2743.89 Epsilon = 0.011
# 8
# 75
# resultado da epoca 1000 = -658.23 Epsilon = 0.010
# 12
# 79
# resultado da epoca 1001 = 1842.85 Epsilon = 0.010
# 12
# 84
# resultado da epoca 1002 = -161.42 Epsilon = 0.010
# 11
# 96
# resultado da epoca 1003 = 911.27 Epsilon = 0.010
# 11
# 71
# resultado da epoca 1004 = 2799.31 Epsilon = 0.010
# 17
# 68
# resultado da epoca 1005 = 2033.83 Epsilon = 0.010
# 11
# 68
# resultado da epoca 1006 = -2726.34 Epsilon = 0.010
# 11
# 84
# resultado da epoca 1007 = 1412.82 Epsilon = 0.010
# 12
# 84
# resultado da epoca 1008 = -2563.27 Epsilon = 0.010
# 13
# 71
# resultado da epoca 1009 = -2296.29 Epsilon = 0.010
# 9
# 87
# resultado da epoca 1010 = 212.93 Epsilon = 0.010
# 9
# 64
# resultado da epoca 1011 = -7252.86 Epsilon = 0.010
# 8
# 77
# resultado da epoca 1012 = 458.34 Epsilon = 0.010
# 18
# 71
# resultado da epoca 1013 = 2898.02 Epsilon = 0.010
# 14
# 76
# resultado da epoca 1014 = -558.64 Epsilon = 0.010
# 9
# 83
# resultado da epoca 1015 = 6706.75 Epsilon = 0.010
# 16
# 85
# resultado da epoca 1016 = -837.07 Epsilon = 0.010
# 12
# 78
# resultado da epoca 1017 = 2873.36 Epsilon = 0.010
# 12
# 77
# resultado da epoca 1018 = -2196.60 Epsilon = 0.010
# 11
# 69
# resultado da epoca 1019 = 576.82 Epsilon = 0.010
# 12
# 74
# resultado da epoca 1020 = -18.11 Epsilon = 0.010
# 16
# 71
# resultado da epoca 1021 = 714.75 Epsilon = 0.010
# 8
# 77
# resultado da epoca 1022 = -898.52 Epsilon = 0.010
# 9
# 76
# resultado da epoca 1023 = 2842.33 Epsilon = 0.010
# 10
# 71
# resultado da epoca 1024 = -7243.02 Epsilon = 0.010
# 9
# 84
# resultado da epoca 1025 = 889.75 Epsilon = 0.010
# 10
# 71
# resultado da epoca 1026 = 1120.39 Epsilon = 0.010
# 20
# 66
# resultado da epoca 1027 = 4204.63 Epsilon = 0.010
# 14
# 70
# resultado da epoca 1028 = 2650.67 Epsilon = 0.010
# 16
# 75
# resultado da epoca 1029 = 1357.47 Epsilon = 0.010
# 6
# 81
# resultado da epoca 1030 = 4171.15 Epsilon = 0.010
# 9
# 84
# resultado da epoca 1031 = -2170.78 Epsilon = 0.010
# 8
# 75
# resultado da epoca 1032 = 1167.08 Epsilon = 0.010
# 12
# 63
# resultado da epoca 1033 = -2483.94 Epsilon = 0.010
# 10
# 76
# resultado da epoca 1034 = 1573.85 Epsilon = 0.010
# 17
# 69
# resultado da epoca 1035 = 589.13 Epsilon = 0.010
# 6
# 75
# resultado da epoca 1036 = 434.61 Epsilon = 0.010
# 10
# 77
# resultado da epoca 1037 = 3029.08 Epsilon = 0.010
# 18
# 60
# resultado da epoca 1038 = -1076.13 Epsilon = 0.010
# 8
# 83
# resultado da epoca 1039 = -2959.24 Epsilon = 0.010
# 7
# 97
# resultado da epoca 1040 = 3853.62 Epsilon = 0.010
# 15
# 74
# resultado da epoca 1041 = -966.54 Epsilon = 0.010
# 8
# 76
# resultado da epoca 1042 = 2312.88 Epsilon = 0.010
# 15
# 68
# resultado da epoca 1043 = -785.94 Epsilon = 0.010
# 9
# 73
# resultado da epoca 1044 = -5230.32 Epsilon = 0.010
# 9
# 63
# resultado da epoca 1045 = 2851.50 Epsilon = 0.010
# 9
# 78
# resultado da epoca 1046 = 1591.18 Epsilon = 0.010
# 14
# 68
# resultado da epoca 1047 = -179.10 Epsilon = 0.010
# 9
# 76
# resultado da epoca 1048 = -870.09 Epsilon = 0.010
# 11
# 69
# resultado da epoca 1049 = 431.64 Epsilon = 0.010
# 10
# 76
# 0
# 0
# Melhor resultado diario: 7708.01
