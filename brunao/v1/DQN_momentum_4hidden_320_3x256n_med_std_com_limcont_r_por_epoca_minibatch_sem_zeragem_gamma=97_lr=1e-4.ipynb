# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 3 #ncont, valor, posicao e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 4*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(320, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        #model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(modelo.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = np.zeros((batch_size+1, self.state_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar

            target_f = self.model.predict(estado) #pega valor que chegou
            target_f[0][acao+2*lim_cont] = target #define o valor que deseja chegar
            x[i,:] = estado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit(x, y, epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 320)               7680
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               82176
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 226,837
# Trainable params: 226,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont += acao #posio atual = pos anterior + ao
    reward = 0.
    posicao = 0.
    dp = 0.

    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    
    acao = decisao - 2*lim_cont
    
    if abs(ncont+acao) <= lim_cont:
        return acao, 0 
    else:
        return 0, -20

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    penal = 0
    decisao = 0
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l])
        modelo.state = np.reshape(np.concatenate((modelo.janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        
        acao, penal = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        reward += penal    #penalidade se quiser ficar posicionado mais que o permitido
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l])
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]) 
            
        modelo.next_state = np.reshape(np.concatenate((modelo.prox_janela_precos, [ncont/lim_cont, valor, posicao/posicao_max])), (1,n_entradas)) #adiciona na variavel de estado      
        modelo.remember(acao, reward, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+5): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1105 14:32:08.187637  5468 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -24554.74 Epsilon = 1.000
# 98
# 121
# resultado da epoca 1 = -13821.15 Epsilon = 0.999
# 103
# 116
# resultado da epoca 2 = -18184.79 Epsilon = 0.998
# 101
# 118
# resultado da epoca 3 = -12834.78 Epsilon = 0.997
# 108
# 111
# resultado da epoca 4 = -28007.86 Epsilon = 0.996
# 103
# 116
# resultado da epoca 5 = -48206.08 Epsilon = 0.995
# 98
# 121
# resultado da epoca 6 = -49490.68 Epsilon = 0.994
# 80
# 139
# resultado da epoca 7 = -17409.21 Epsilon = 0.993
# 105
# 114
# resultado da epoca 8 = -29580.63 Epsilon = 0.992
# 94
# 125
# resultado da epoca 9 = -3996.21 Epsilon = 0.991
# 113
# 106
# resultado da epoca 10 = -25813.53 Epsilon = 0.990
# 94
# 125
# resultado da epoca 11 = -38062.79 Epsilon = 0.989
# 93
# 126
# resultado da epoca 12 = -7599.34 Epsilon = 0.988
# 111
# 108
# resultado da epoca 13 = -6159.35 Epsilon = 0.987
# 111
# 108
# resultado da epoca 14 = -5258.87 Epsilon = 0.986
# 108
# 111
# resultado da epoca 15 = -11843.73 Epsilon = 0.985
# 102
# 117
# resultado da epoca 16 = -651.49 Epsilon = 0.984
# 114
# 105
# resultado da epoca 17 = -14212.62 Epsilon = 0.983
# 105
# 114
# resultado da epoca 18 = -23686.89 Epsilon = 0.982
# 96
# 123
# resultado da epoca 19 = -37592.50 Epsilon = 0.981
# 100
# 119
# resultado da epoca 20 = -40085.83 Epsilon = 0.980
# 93
# 126
# resultado da epoca 21 = -41855.73 Epsilon = 0.979
# 100
# 119
# resultado da epoca 22 = -29168.63 Epsilon = 0.978
# 95
# 124
# resultado da epoca 23 = -2157.38 Epsilon = 0.977
# 109
# 110
# resultado da epoca 24 = -4608.10 Epsilon = 0.976
# 111
# 108
# resultado da epoca 25 = -26069.44 Epsilon = 0.975
# 98
# 121
# resultado da epoca 26 = -41800.62 Epsilon = 0.974
# 97
# 122
# resultado da epoca 27 = -45598.53 Epsilon = 0.973
# 86
# 133
# resultado da epoca 28 = -44165.46 Epsilon = 0.972
# 101
# 118
# resultado da epoca 29 = -18827.05 Epsilon = 0.971
# 103
# 116
# resultado da epoca 30 = -21052.37 Epsilon = 0.970
# 99
# 120
# resultado da epoca 31 = -42090.20 Epsilon = 0.969
# 91
# 128
# resultado da epoca 32 = -24338.39 Epsilon = 0.968
# 92
# 127
# resultado da epoca 33 = -34173.15 Epsilon = 0.967
# 93
# 126
# resultado da epoca 34 = -26429.69 Epsilon = 0.966
# 103
# 116
# resultado da epoca 35 = -38082.90 Epsilon = 0.965
# 96
# 123
# resultado da epoca 36 = -20656.18 Epsilon = 0.964
# 107
# 112
# resultado da epoca 37 = -15809.55 Epsilon = 0.963
# 92
# 127
# resultado da epoca 38 = -49015.42 Epsilon = 0.962
# 90
# 129
# resultado da epoca 39 = -20191.66 Epsilon = 0.961
# 100
# 119
# resultado da epoca 40 = -38201.35 Epsilon = 0.960
# 89
# 130
# resultado da epoca 41 = -30725.70 Epsilon = 0.959
# 103
# 116
# resultado da epoca 42 = 7390.01 Epsilon = 0.958
# 111
# 108
# resultado da epoca 43 = -21808.39 Epsilon = 0.957
# 106
# 113
# resultado da epoca 44 = -14781.44 Epsilon = 0.956
# 99
# 120
# resultado da epoca 45 = 3950.85 Epsilon = 0.955
# 109
# 110
# resultado da epoca 46 = -24988.94 Epsilon = 0.954
# 97
# 122
# resultado da epoca 47 = -35551.43 Epsilon = 0.953
# 97
# 122
# resultado da epoca 48 = -16159.32 Epsilon = 0.952
# 97
# 122
# resultado da epoca 49 = -2782.87 Epsilon = 0.951
# 111
# 108
# resultado da epoca 50 = -33177.46 Epsilon = 0.950
# 95
# 124
# resultado da epoca 51 = -43458.72 Epsilon = 0.950
# 85
# 134
# resultado da epoca 52 = -19488.18 Epsilon = 0.949
# 100
# 119
# resultado da epoca 53 = -53660.24 Epsilon = 0.948
# 83
# 136
# resultado da epoca 54 = -17163.89 Epsilon = 0.947
# 93
# 126
# resultado da epoca 55 = -3374.24 Epsilon = 0.946
# 107
# 112
# resultado da epoca 56 = -21084.52 Epsilon = 0.945
# 105
# 114
# resultado da epoca 57 = -36027.79 Epsilon = 0.944
# 90
# 129
# resultado da epoca 58 = -10167.84 Epsilon = 0.943
# 112
# 107
# resultado da epoca 59 = -30602.61 Epsilon = 0.942
# 96
# 123
# resultado da epoca 60 = -24406.44 Epsilon = 0.941
# 99
# 120
# resultado da epoca 61 = -34750.76 Epsilon = 0.940
# 96
# 123
# resultado da epoca 62 = -25625.16 Epsilon = 0.939
# 92
# 127
# resultado da epoca 63 = -44590.11 Epsilon = 0.938
# 92
# 127
# resultado da epoca 64 = -21033.97 Epsilon = 0.937
# 102
# 117
# resultado da epoca 65 = -20229.47 Epsilon = 0.936
# 101
# 118
# resultado da epoca 66 = -22655.80 Epsilon = 0.935
# 99
# 120
# resultado da epoca 67 = -47156.48 Epsilon = 0.934
# 95
# 124
# resultado da epoca 68 = -16188.43 Epsilon = 0.933
# 99
# 120
# resultado da epoca 69 = -47762.13 Epsilon = 0.932
# 86
# 133
# resultado da epoca 70 = -56089.76 Epsilon = 0.931
# 86
# 133
# resultado da epoca 71 = -48982.20 Epsilon = 0.930
# 95
# 124
# resultado da epoca 72 = -12025.50 Epsilon = 0.929
# 101
# 118
# resultado da epoca 73 = 9228.33 Epsilon = 0.928
# 106
# 113
# resultado da epoca 74 = -48839.74 Epsilon = 0.927
# 83
# 136
# resultado da epoca 75 = -29041.87 Epsilon = 0.926
# 99
# 120
# resultado da epoca 76 = -24480.69 Epsilon = 0.925
# 94
# 125
# resultado da epoca 77 = -14217.76 Epsilon = 0.924
# 111
# 108
# resultado da epoca 78 = -10086.32 Epsilon = 0.923
# 106
# 113
# resultado da epoca 79 = -27795.20 Epsilon = 0.922
# 96
# 123
# resultado da epoca 80 = -12729.72 Epsilon = 0.921
# 100
# 119
# resultado da epoca 81 = -6319.14 Epsilon = 0.920
# 110
# 109
# resultado da epoca 82 = -18308.43 Epsilon = 0.919
# 111
# 108
# resultado da epoca 83 = -19640.24 Epsilon = 0.918
# 97
# 122
# resultado da epoca 84 = -35944.82 Epsilon = 0.917
# 94
# 125
# resultado da epoca 85 = -22867.80 Epsilon = 0.916
# 98
# 121
# resultado da epoca 86 = -22181.17 Epsilon = 0.915
# 101
# 118
# resultado da epoca 87 = 359.49 Epsilon = 0.914
# 106
# 113
# resultado da epoca 88 = -27253.02 Epsilon = 0.913
# 97
# 122
# resultado da epoca 89 = -13928.38 Epsilon = 0.912
# 97
# 122
# resultado da epoca 90 = -53508.18 Epsilon = 0.911
# 87
# 132
# resultado da epoca 91 = -36574.28 Epsilon = 0.910
# 93
# 126
# resultado da epoca 92 = -44906.08 Epsilon = 0.909
# 86
# 133
# resultado da epoca 93 = -26787.90 Epsilon = 0.908
# 98
# 121
# resultado da epoca 94 = -16925.78 Epsilon = 0.907
# 96
# 123
# resultado da epoca 95 = -45816.74 Epsilon = 0.906
# 89
# 130
# resultado da epoca 96 = -17226.61 Epsilon = 0.905
# 108
# 111
# resultado da epoca 97 = 297.58 Epsilon = 0.904
# 117
# 102
# resultado da epoca 98 = -42482.56 Epsilon = 0.903
# 90
# 129
# resultado da epoca 99 = -48215.62 Epsilon = 0.902
# 85
# 134
# resultado da epoca 100 = -29992.82 Epsilon = 0.901
# 96
# 123
# resultado da epoca 101 = -24085.32 Epsilon = 0.900
# 89
# 130
# resultado da epoca 102 = -29764.80 Epsilon = 0.899
# 98
# 121
# resultado da epoca 103 = -25398.26 Epsilon = 0.898
# 96
# 123
# resultado da epoca 104 = -34149.66 Epsilon = 0.897
# 104
# 115
# resultado da epoca 105 = -13716.75 Epsilon = 0.896
# 107
# 112
# resultado da epoca 106 = -11271.31 Epsilon = 0.895
# 99
# 120
# resultado da epoca 107 = -22072.95 Epsilon = 0.894
# 109
# 110
# resultado da epoca 108 = -38383.16 Epsilon = 0.893
# 104
# 115
# resultado da epoca 109 = -60073.55 Epsilon = 0.892
# 81
# 138
# resultado da epoca 110 = -12320.94 Epsilon = 0.891
# 105
# 114
# resultado da epoca 111 = -14469.71 Epsilon = 0.890
# 104
# 115
# resultado da epoca 112 = -36128.86 Epsilon = 0.889
# 88
# 131
# resultado da epoca 113 = -17337.75 Epsilon = 0.888
# 95
# 124
# resultado da epoca 114 = -24685.83 Epsilon = 0.887
# 110
# 109
# resultado da epoca 115 = -13191.95 Epsilon = 0.886
# 105
# 114
# resultado da epoca 116 = -32458.59 Epsilon = 0.885
# 104
# 115
# resultado da epoca 117 = -27146.84 Epsilon = 0.884
# 98
# 121
# resultado da epoca 118 = -24224.53 Epsilon = 0.883
# 102
# 117
# resultado da epoca 119 = -10822.25 Epsilon = 0.882
# 103
# 116
# resultado da epoca 120 = -33487.73 Epsilon = 0.881
# 98
# 121
# resultado da epoca 121 = -26110.00 Epsilon = 0.880
# 101
# 118
# resultado da epoca 122 = -14017.69 Epsilon = 0.879
# 103
# 116
# resultado da epoca 123 = -31535.05 Epsilon = 0.878
# 92
# 127
# resultado da epoca 124 = -4869.92 Epsilon = 0.877
# 106
# 113
# resultado da epoca 125 = -10074.60 Epsilon = 0.876
# 109
# 110
# resultado da epoca 126 = -38003.60 Epsilon = 0.875
# 95
# 124
# resultado da epoca 127 = -45596.28 Epsilon = 0.874
# 89
# 130
# resultado da epoca 128 = -45536.54 Epsilon = 0.873
# 92
# 127
# resultado da epoca 129 = -26904.63 Epsilon = 0.872
# 95
# 124
# resultado da epoca 130 = -11383.10 Epsilon = 0.871
# 96
# 123
# resultado da epoca 131 = -4617.96 Epsilon = 0.870
# 105
# 114
# resultado da epoca 132 = -15753.14 Epsilon = 0.869
# 103
# 116
# resultado da epoca 133 = -9884.72 Epsilon = 0.868
# 110
# 109
# resultado da epoca 134 = -17155.67 Epsilon = 0.867
# 101
# 118
# resultado da epoca 135 = -17143.83 Epsilon = 0.866
# 101
# 118
# resultado da epoca 136 = -26724.07 Epsilon = 0.865
# 104
# 115
# resultado da epoca 137 = -35023.15 Epsilon = 0.864
# 97
# 122
# resultado da epoca 138 = -29992.67 Epsilon = 0.863
# 93
# 126
# resultado da epoca 139 = -29722.64 Epsilon = 0.862
# 94
# 125
# resultado da epoca 140 = -26318.66 Epsilon = 0.861
# 97
# 122
# resultado da epoca 141 = -48789.60 Epsilon = 0.860
# 93
# 126
# resultado da epoca 142 = -5874.27 Epsilon = 0.859
# 108
# 111
# resultado da epoca 143 = -14181.19 Epsilon = 0.858
# 98
# 121
# resultado da epoca 144 = -36718.79 Epsilon = 0.857
# 96
# 123
# resultado da epoca 145 = -47860.46 Epsilon = 0.856
# 88
# 131
# resultado da epoca 146 = -23338.85 Epsilon = 0.855
# 103
# 116
# resultado da epoca 147 = -56217.65 Epsilon = 0.854
# 93
# 126
# resultado da epoca 148 = -27158.93 Epsilon = 0.853
# 95
# 124
# resultado da epoca 149 = -20128.86 Epsilon = 0.852
# 96
# 123
# resultado da epoca 150 = -32955.21 Epsilon = 0.851
# 93
# 126
# resultado da epoca 151 = -12729.06 Epsilon = 0.851
# 98
# 121
# resultado da epoca 152 = -34753.64 Epsilon = 0.850
# 91
# 128
# resultado da epoca 153 = -30869.95 Epsilon = 0.849
# 97
# 122
# resultado da epoca 154 = -10983.06 Epsilon = 0.848
# 98
# 121
# resultado da epoca 155 = -33066.91 Epsilon = 0.847
# 99
# 120
# resultado da epoca 156 = -30811.18 Epsilon = 0.846
# 90
# 129
# resultado da epoca 157 = -15666.89 Epsilon = 0.845
# 98
# 121
# resultado da epoca 158 = -62651.75 Epsilon = 0.844
# 84
# 135
# resultado da epoca 159 = -39233.32 Epsilon = 0.843
# 100
# 119
# resultado da epoca 160 = -34312.29 Epsilon = 0.842
# 91
# 128
# resultado da epoca 161 = -21217.42 Epsilon = 0.841
# 91
# 128
# resultado da epoca 162 = -16981.01 Epsilon = 0.840
# 103
# 116
# resultado da epoca 163 = -37603.34 Epsilon = 0.839
# 93
# 126
# resultado da epoca 164 = -15528.42 Epsilon = 0.838
# 111
# 108
# resultado da epoca 165 = -34770.44 Epsilon = 0.837
# 93
# 126
# resultado da epoca 166 = -38904.03 Epsilon = 0.836
# 91
# 128
# resultado da epoca 167 = -22749.95 Epsilon = 0.835
# 102
# 117
# resultado da epoca 168 = -41806.61 Epsilon = 0.834
# 91
# 128
# resultado da epoca 169 = -46002.19 Epsilon = 0.833
# 94
# 125
# resultado da epoca 170 = -26105.99 Epsilon = 0.832
# 105
# 114
# resultado da epoca 171 = -18112.64 Epsilon = 0.831
# 101
# 118
# resultado da epoca 172 = -40032.47 Epsilon = 0.830
# 92
# 127
# resultado da epoca 173 = 113.53 Epsilon = 0.829
# 112
# 107
# resultado da epoca 174 = -24600.14 Epsilon = 0.828
# 99
# 120
# resultado da epoca 175 = -25254.81 Epsilon = 0.827
# 92
# 127
# resultado da epoca 176 = -26668.93 Epsilon = 0.826
# 108
# 111
# resultado da epoca 177 = -31518.27 Epsilon = 0.825
# 96
# 123
# resultado da epoca 178 = -20522.09 Epsilon = 0.824
# 101
# 118
# resultado da epoca 179 = -43783.33 Epsilon = 0.823
# 89
# 130
# resultado da epoca 180 = -48609.40 Epsilon = 0.822
# 96
# 123
# resultado da epoca 181 = -30561.82 Epsilon = 0.821
# 90
# 129
# resultado da epoca 182 = -23313.54 Epsilon = 0.820
# 105
# 114
# resultado da epoca 183 = -16355.64 Epsilon = 0.819
# 105
# 114
# resultado da epoca 184 = -38175.49 Epsilon = 0.818
# 94
# 125
# resultado da epoca 185 = 657.85 Epsilon = 0.817
# 109
# 110
# resultado da epoca 186 = -17761.09 Epsilon = 0.816
# 99
# 120
# resultado da epoca 187 = -71090.64 Epsilon = 0.815
# 85
# 134
# resultado da epoca 188 = -29537.77 Epsilon = 0.814
# 102
# 117
# resultado da epoca 189 = -29354.88 Epsilon = 0.813
# 100
# 119
# resultado da epoca 190 = -23215.15 Epsilon = 0.812
# 98
# 121
# resultado da epoca 191 = -31639.14 Epsilon = 0.811
# 90
# 129
# resultado da epoca 192 = -61708.03 Epsilon = 0.810
# 85
# 134
# resultado da epoca 193 = -2420.52 Epsilon = 0.809
# 104
# 115
# resultado da epoca 194 = -18638.76 Epsilon = 0.808
# 107
# 112
# resultado da epoca 195 = -29506.70 Epsilon = 0.807
# 95
# 124
# resultado da epoca 196 = -37217.71 Epsilon = 0.806
# 93
# 126
# resultado da epoca 197 = -27630.31 Epsilon = 0.805
# 106
# 113
# resultado da epoca 198 = -25045.30 Epsilon = 0.804
# 95
# 124
# resultado da epoca 199 = -56721.80 Epsilon = 0.803
# 89
# 130
# resultado da epoca 200 = -45176.35 Epsilon = 0.802
# 89
# 130
# resultado da epoca 201 = 13354.87 Epsilon = 0.801
# 108
# 111
# resultado da epoca 202 = -18464.47 Epsilon = 0.800
# 98
# 121
# resultado da epoca 203 = -72490.14 Epsilon = 0.799
# 89
# 130
# resultado da epoca 204 = -59955.46 Epsilon = 0.798
# 90
# 129
# resultado da epoca 205 = -47685.94 Epsilon = 0.797
# 92
# 127
# resultado da epoca 206 = -42098.32 Epsilon = 0.796
# 99
# 120
# resultado da epoca 207 = -17120.92 Epsilon = 0.795
# 101
# 118
# resultado da epoca 208 = -27236.80 Epsilon = 0.794
# 100
# 119
# resultado da epoca 209 = -12572.80 Epsilon = 0.793
# 110
# 109
# resultado da epoca 210 = -16440.90 Epsilon = 0.792
# 105
# 114
# resultado da epoca 211 = -25600.27 Epsilon = 0.791
# 96
# 123
# resultado da epoca 212 = -21157.97 Epsilon = 0.790
# 99
# 120
# resultado da epoca 213 = -21525.01 Epsilon = 0.789
# 102
# 117
# resultado da epoca 214 = -34910.29 Epsilon = 0.788
# 96
# 123
# resultado da epoca 215 = -22756.12 Epsilon = 0.787
# 92
# 127
# resultado da epoca 216 = -32924.83 Epsilon = 0.786
# 97
# 122
# resultado da epoca 217 = -15050.79 Epsilon = 0.785
# 105
# 114
# resultado da epoca 218 = -25169.86 Epsilon = 0.784
# 93
# 126
# resultado da epoca 219 = -37000.59 Epsilon = 0.783
# 98
# 121
# resultado da epoca 220 = -14350.06 Epsilon = 0.782
# 104
# 115
# resultado da epoca 221 = -17223.17 Epsilon = 0.781
# 108
# 111
# resultado da epoca 222 = -26423.38 Epsilon = 0.780
# 103
# 116
# resultado da epoca 223 = -14185.03 Epsilon = 0.779
# 101
# 118
# resultado da epoca 224 = -29055.36 Epsilon = 0.778
# 103
# 116
# resultado da epoca 225 = -20340.40 Epsilon = 0.777
# 95
# 124
# resultado da epoca 226 = -22869.83 Epsilon = 0.776
# 99
# 120
# resultado da epoca 227 = -19506.00 Epsilon = 0.775
# 98
# 121
# resultado da epoca 228 = -52199.71 Epsilon = 0.774
# 88
# 131
# resultado da epoca 229 = -20523.48 Epsilon = 0.773
# 110
# 109
# resultado da epoca 230 = -36008.39 Epsilon = 0.772
# 87
# 132
# resultado da epoca 231 = -40158.79 Epsilon = 0.771
# 91
# 128
# resultado da epoca 232 = -5987.24 Epsilon = 0.770
# 104
# 115
# resultado da epoca 233 = -18369.14 Epsilon = 0.769
# 105
# 114
# resultado da epoca 234 = -37026.11 Epsilon = 0.768
# 96
# 123
# resultado da epoca 235 = -41054.43 Epsilon = 0.767
# 94
# 125
# resultado da epoca 236 = -25279.78 Epsilon = 0.766
# 98
# 121
# resultado da epoca 237 = -42875.85 Epsilon = 0.765
# 87
# 132
# resultado da epoca 238 = -34832.16 Epsilon = 0.764
# 95
# 124
# resultado da epoca 239 = -34341.27 Epsilon = 0.763
# 100
# 119
# resultado da epoca 240 = -30988.20 Epsilon = 0.762
# 95
# 124
# resultado da epoca 241 = -41705.23 Epsilon = 0.761
# 105
# 114
# resultado da epoca 242 = -14297.80 Epsilon = 0.760
# 104
# 115
# resultado da epoca 243 = -29270.55 Epsilon = 0.759
# 101
# 118
# resultado da epoca 244 = -21397.20 Epsilon = 0.758
# 87
# 132
# resultado da epoca 245 = -50660.91 Epsilon = 0.757
# 86
# 133
# resultado da epoca 246 = -20778.99 Epsilon = 0.756
# 102
# 117
# resultado da epoca 247 = -613.57 Epsilon = 0.755
# 107
# 112
# resultado da epoca 248 = -11602.53 Epsilon = 0.754
# 97
# 122
# resultado da epoca 249 = -42920.81 Epsilon = 0.753
# 80
# 139
# resultado da epoca 250 = -21235.40 Epsilon = 0.752
# 100
# 119
# resultado da epoca 251 = -23599.87 Epsilon = 0.752
# 107
# 112
# resultado da epoca 252 = -31182.81 Epsilon = 0.751
# 93
# 126
# resultado da epoca 253 = -4706.39 Epsilon = 0.750
# 106
# 113
# resultado da epoca 254 = -29160.99 Epsilon = 0.749
# 96
# 123
# resultado da epoca 255 = 32177.56 Epsilon = 0.748
# 126
# 93
# resultado da epoca 256 = -4261.01 Epsilon = 0.747
# 110
# 109
# resultado da epoca 257 = -25639.54 Epsilon = 0.746
# 108
# 111
# resultado da epoca 258 = -15189.83 Epsilon = 0.745
# 106
# 113
# resultado da epoca 259 = -14725.24 Epsilon = 0.744
# 104
# 115
# resultado da epoca 260 = -16033.23 Epsilon = 0.743
# 106
# 113
# resultado da epoca 261 = -55343.57 Epsilon = 0.742
# 93
# 126
# resultado da epoca 262 = -25127.15 Epsilon = 0.741
# 100
# 119
# resultado da epoca 263 = -27313.87 Epsilon = 0.740
# 102
# 117
# resultado da epoca 264 = -10659.88 Epsilon = 0.739
# 108
# 111
# resultado da epoca 265 = -23368.34 Epsilon = 0.738
# 95
# 124
# resultado da epoca 266 = -21857.56 Epsilon = 0.737
# 109
# 110
# resultado da epoca 267 = 330.20 Epsilon = 0.736
# 106
# 113
# resultado da epoca 268 = -23595.73 Epsilon = 0.735
# 94
# 125
# resultado da epoca 269 = -21280.71 Epsilon = 0.734
# 97
# 122
# resultado da epoca 270 = -33000.58 Epsilon = 0.733
# 92
# 127
# resultado da epoca 271 = -30785.09 Epsilon = 0.732
# 95
# 124
# resultado da epoca 272 = -14377.55 Epsilon = 0.731
# 98
# 121
# resultado da epoca 273 = -28712.78 Epsilon = 0.730
# 102
# 117
# resultado da epoca 274 = -26344.86 Epsilon = 0.729
# 95
# 124
# resultado da epoca 275 = -31551.07 Epsilon = 0.728
# 93
# 126
# resultado da epoca 276 = -4763.52 Epsilon = 0.727
# 103
# 116
# resultado da epoca 277 = -34952.23 Epsilon = 0.726
# 86
# 133
# resultado da epoca 278 = 3012.37 Epsilon = 0.725
# 104
# 115
# resultado da epoca 279 = -30013.33 Epsilon = 0.724
# 92
# 127
# resultado da epoca 280 = -2255.44 Epsilon = 0.723
# 118
# 101
# resultado da epoca 281 = -18324.86 Epsilon = 0.722
# 102
# 117
# resultado da epoca 282 = -8602.81 Epsilon = 0.721
# 115
# 104
# resultado da epoca 283 = -21755.83 Epsilon = 0.720
# 96
# 123
# resultado da epoca 284 = -24509.12 Epsilon = 0.719
# 100
# 119
# resultado da epoca 285 = -18780.78 Epsilon = 0.718
# 98
# 121
# resultado da epoca 286 = -23946.80 Epsilon = 0.717
# 93
# 126
# resultado da epoca 287 = -17376.15 Epsilon = 0.716
# 108
# 111
# resultado da epoca 288 = -40980.73 Epsilon = 0.715
# 95
# 124
# resultado da epoca 289 = -18736.58 Epsilon = 0.714
# 104
# 115
# resultado da epoca 290 = -49006.81 Epsilon = 0.713
# 96
# 123
# resultado da epoca 291 = -29619.47 Epsilon = 0.712
# 96
# 123
# resultado da epoca 292 = -24037.04 Epsilon = 0.711
# 105
# 114
# resultado da epoca 293 = -16810.60 Epsilon = 0.710
# 108
# 111
# resultado da epoca 294 = -38450.29 Epsilon = 0.709
# 92
# 127
# resultado da epoca 295 = -17796.65 Epsilon = 0.708
# 104
# 115
# resultado da epoca 296 = -21527.92 Epsilon = 0.707
# 105
# 114
# resultado da epoca 297 = -19987.11 Epsilon = 0.706
# 100
# 119
# resultado da epoca 298 = -12088.46 Epsilon = 0.705
# 110
# 109
# resultado da epoca 299 = -9138.86 Epsilon = 0.704
# 109
# 110
# resultado da epoca 300 = -25136.72 Epsilon = 0.703
# 103
# 116
# resultado da epoca 301 = -3603.30 Epsilon = 0.702
# 107
# 112
# resultado da epoca 302 = -18780.27 Epsilon = 0.701
# 94
# 125
# resultado da epoca 303 = 4804.26 Epsilon = 0.700
# 113
# 106
# resultado da epoca 304 = -31268.57 Epsilon = 0.699
# 106
# 113
# resultado da epoca 305 = -14224.56 Epsilon = 0.698
# 105
# 114
# resultado da epoca 306 = -12448.83 Epsilon = 0.697
# 100
# 119
# resultado da epoca 307 = -39652.38 Epsilon = 0.696
# 93
# 126
# resultado da epoca 308 = -17813.51 Epsilon = 0.695
# 94
# 125
# resultado da epoca 309 = -23276.02 Epsilon = 0.694
# 92
# 127
# resultado da epoca 310 = -35962.09 Epsilon = 0.693
# 101
# 118
# resultado da epoca 311 = -11631.67 Epsilon = 0.692
# 113
# 106
# resultado da epoca 312 = -34550.12 Epsilon = 0.691
# 91
# 128
# resultado da epoca 313 = 7545.35 Epsilon = 0.690
# 112
# 107
# resultado da epoca 314 = -22284.52 Epsilon = 0.689
# 104
# 115
# resultado da epoca 315 = -30025.53 Epsilon = 0.688
# 101
# 118
# resultado da epoca 316 = 1194.54 Epsilon = 0.687
# 113
# 106
# resultado da epoca 317 = -717.07 Epsilon = 0.686
# 109
# 110
# resultado da epoca 318 = -27217.67 Epsilon = 0.685
# 103
# 116
# resultado da epoca 319 = -15534.03 Epsilon = 0.684
# 106
# 113
# resultado da epoca 320 = -35257.87 Epsilon = 0.683
# 102
# 117
# resultado da epoca 321 = -3651.41 Epsilon = 0.682
# 100
# 119
# resultado da epoca 322 = -15127.19 Epsilon = 0.681
# 104
# 115
# resultado da epoca 323 = -47228.56 Epsilon = 0.680
# 91
# 128
# resultado da epoca 324 = -7569.82 Epsilon = 0.679
# 97
# 122
# resultado da epoca 325 = -32228.95 Epsilon = 0.678
# 98
# 121
# resultado da epoca 326 = -19352.45 Epsilon = 0.677
# 103
# 116
# resultado da epoca 327 = -31171.33 Epsilon = 0.676
# 97
# 122
# resultado da epoca 328 = -40673.01 Epsilon = 0.675
# 97
# 122
# resultado da epoca 329 = 15797.35 Epsilon = 0.674
# 106
# 113
# resultado da epoca 330 = -8419.34 Epsilon = 0.673
# 108
# 111
# resultado da epoca 331 = 554.92 Epsilon = 0.672
# 104
# 115
# resultado da epoca 332 = 882.03 Epsilon = 0.671
# 105
# 114
# resultado da epoca 333 = -5301.69 Epsilon = 0.670
# 114
# 105
# resultado da epoca 334 = -6728.51 Epsilon = 0.669
# 110
# 109
# resultado da epoca 335 = 1953.62 Epsilon = 0.668
# 116
# 103
# resultado da epoca 336 = 12006.63 Epsilon = 0.667
# 113
# 106
# resultado da epoca 337 = -18184.98 Epsilon = 0.666
# 109
# 110
# resultado da epoca 338 = 11406.19 Epsilon = 0.665
# 108
# 111
# resultado da epoca 339 = -12807.40 Epsilon = 0.664
# 102
# 117
# resultado da epoca 340 = -38483.62 Epsilon = 0.663
# 97
# 122
# resultado da epoca 341 = -28254.65 Epsilon = 0.662
# 92
# 127
# resultado da epoca 342 = -14128.26 Epsilon = 0.661
# 96
# 123
# resultado da epoca 343 = -46835.52 Epsilon = 0.660
# 89
# 130
# resultado da epoca 344 = -35434.38 Epsilon = 0.659
# 99
# 120
# resultado da epoca 345 = -23261.80 Epsilon = 0.658
# 97
# 122
# resultado da epoca 346 = -29802.05 Epsilon = 0.657
# 99
# 120
# resultado da epoca 347 = -7584.96 Epsilon = 0.656
# 107
# 112
# resultado da epoca 348 = -35686.86 Epsilon = 0.655
# 96
# 123
# resultado da epoca 349 = -2757.10 Epsilon = 0.654
# 107
# 112
# resultado da epoca 350 = -30704.25 Epsilon = 0.653
# 104
# 115
# resultado da epoca 351 = -29441.84 Epsilon = 0.653
# 102
# 117
# resultado da epoca 352 = -51659.26 Epsilon = 0.652
# 97
# 122
# resultado da epoca 353 = -34524.34 Epsilon = 0.651
# 94
# 125
# resultado da epoca 354 = -13690.97 Epsilon = 0.650
# 98
# 121
# resultado da epoca 355 = -40070.08 Epsilon = 0.649
# 89
# 130
# resultado da epoca 356 = 9163.70 Epsilon = 0.648
# 100
# 119
# resultado da epoca 357 = -7986.57 Epsilon = 0.647
# 107
# 112
# resultado da epoca 358 = -26898.80 Epsilon = 0.646
# 95
# 124
# resultado da epoca 359 = -10608.71 Epsilon = 0.645
# 110
# 109
# resultado da epoca 360 = -19638.43 Epsilon = 0.644
# 111
# 108
# resultado da epoca 361 = 10174.56 Epsilon = 0.643
# 116
# 103
# resultado da epoca 362 = -32219.91 Epsilon = 0.642
# 99
# 120
# resultado da epoca 363 = -34253.95 Epsilon = 0.641
# 101
# 118
# resultado da epoca 364 = -18980.96 Epsilon = 0.640
# 103
# 116
# resultado da epoca 365 = -44634.50 Epsilon = 0.639
# 97
# 122
# resultado da epoca 366 = -15255.11 Epsilon = 0.638
# 105
# 114
# resultado da epoca 367 = -26476.41 Epsilon = 0.637
# 105
# 114
# resultado da epoca 368 = -18470.37 Epsilon = 0.636
# 99
# 120
# resultado da epoca 369 = -10297.93 Epsilon = 0.635
# 103
# 116
# resultado da epoca 370 = -35191.72 Epsilon = 0.634
# 103
# 116
# resultado da epoca 371 = -47932.86 Epsilon = 0.633
# 93
# 126
# resultado da epoca 372 = -33850.64 Epsilon = 0.632
# 103
# 116
# resultado da epoca 373 = -13048.76 Epsilon = 0.631
# 108
# 111
# resultado da epoca 374 = -30397.84 Epsilon = 0.630
# 103
# 116
# resultado da epoca 375 = -20207.34 Epsilon = 0.629
# 110
# 109
# resultado da epoca 376 = -17750.51 Epsilon = 0.628
# 106
# 113
# resultado da epoca 377 = -32368.98 Epsilon = 0.627
# 93
# 126
# resultado da epoca 378 = -19079.16 Epsilon = 0.626
# 100
# 119
# resultado da epoca 379 = -21672.69 Epsilon = 0.625
# 105
# 114
# resultado da epoca 380 = -21910.78 Epsilon = 0.624
# 99
# 120
# resultado da epoca 381 = -4629.64 Epsilon = 0.623
# 99
# 120
# resultado da epoca 382 = -20765.36 Epsilon = 0.622
# 102
# 117
# resultado da epoca 383 = -28702.98 Epsilon = 0.621
# 109
# 110
# resultado da epoca 384 = -17799.86 Epsilon = 0.620
# 110
# 109
# resultado da epoca 385 = -23192.00 Epsilon = 0.619
# 106
# 113
# resultado da epoca 386 = -7298.89 Epsilon = 0.618
# 110
# 109
# resultado da epoca 387 = -26296.94 Epsilon = 0.617
# 100
# 119
# resultado da epoca 388 = -19972.88 Epsilon = 0.616
# 100
# 119
# resultado da epoca 389 = -7352.77 Epsilon = 0.615
# 106
# 113
# resultado da epoca 390 = -23137.83 Epsilon = 0.614
# 98
# 121
# resultado da epoca 391 = -21440.37 Epsilon = 0.613
# 105
# 114
# resultado da epoca 392 = -416.72 Epsilon = 0.612
# 111
# 108
# resultado da epoca 393 = 13164.42 Epsilon = 0.611
# 116
# 103
# resultado da epoca 394 = -1990.35 Epsilon = 0.610
# 111
# 108
# resultado da epoca 395 = -8402.29 Epsilon = 0.609
# 104
# 115
# resultado da epoca 396 = -14310.15 Epsilon = 0.608
# 97
# 122
# resultado da epoca 397 = -8785.49 Epsilon = 0.607
# 105
# 114
# resultado da epoca 398 = -3897.08 Epsilon = 0.606
# 122
# 97
# resultado da epoca 399 = -42069.32 Epsilon = 0.605
# 98
# 121
# resultado da epoca 400 = -14630.84 Epsilon = 0.604
# 106
# 113
# resultado da epoca 401 = -33044.75 Epsilon = 0.603
# 101
# 118
# resultado da epoca 402 = -35642.30 Epsilon = 0.602
# 104
# 115
# resultado da epoca 403 = -28497.99 Epsilon = 0.601
# 97
# 122
# resultado da epoca 404 = -18055.41 Epsilon = 0.600
# 109
# 110
# resultado da epoca 405 = -21996.17 Epsilon = 0.599
# 100
# 119
# resultado da epoca 406 = -11167.49 Epsilon = 0.598
# 103
# 116
# resultado da epoca 407 = -34895.15 Epsilon = 0.597
# 97
# 122
# resultado da epoca 408 = -16387.00 Epsilon = 0.596
# 103
# 116
# resultado da epoca 409 = 4128.55 Epsilon = 0.595
# 109
# 110
# resultado da epoca 410 = -11407.84 Epsilon = 0.594
# 102
# 117
# resultado da epoca 411 = -26569.89 Epsilon = 0.593
# 104
# 115
# resultado da epoca 412 = -19217.66 Epsilon = 0.592
# 94
# 125
# resultado da epoca 413 = -3379.57 Epsilon = 0.591
# 105
# 114
# resultado da epoca 414 = -25761.37 Epsilon = 0.590
# 104
# 115
# resultado da epoca 415 = -26092.56 Epsilon = 0.589
# 98
# 121
# resultado da epoca 416 = -2859.91 Epsilon = 0.588
# 106
# 113
# resultado da epoca 417 = -23659.71 Epsilon = 0.587
# 101
# 118
# resultado da epoca 418 = -56179.28 Epsilon = 0.586
# 98
# 121
# resultado da epoca 419 = -25954.41 Epsilon = 0.585
# 98
# 121
# resultado da epoca 420 = 5741.69 Epsilon = 0.584
# 109
# 110
# resultado da epoca 421 = -15177.30 Epsilon = 0.583
# 109
# 110
# resultado da epoca 422 = -8348.11 Epsilon = 0.582
# 108
# 111
# resultado da epoca 423 = -55962.77 Epsilon = 0.581
# 94
# 125
# resultado da epoca 424 = 9046.89 Epsilon = 0.580
# 110
# 109
# resultado da epoca 425 = -11891.76 Epsilon = 0.579
# 109
# 110
# resultado da epoca 426 = 5901.13 Epsilon = 0.578
# 113
# 106
# resultado da epoca 427 = 9026.27 Epsilon = 0.577
# 114
# 105
# resultado da epoca 428 = -15518.16 Epsilon = 0.576
# 103
# 116
# resultado da epoca 429 = -21527.39 Epsilon = 0.575
# 98
# 121
# resultado da epoca 430 = -12248.50 Epsilon = 0.574
# 110
# 109
# resultado da epoca 431 = -1628.33 Epsilon = 0.573
# 106
# 113
# resultado da epoca 432 = -10375.85 Epsilon = 0.572
# 101
# 118
# resultado da epoca 433 = -43110.02 Epsilon = 0.571
# 97
# 122
# resultado da epoca 434 = -20641.78 Epsilon = 0.570
# 100
# 119
# resultado da epoca 435 = -17886.09 Epsilon = 0.569
# 113
# 106
# resultado da epoca 436 = -3025.07 Epsilon = 0.568
# 110
# 109
# resultado da epoca 437 = 1513.51 Epsilon = 0.567
# 107
# 112
# resultado da epoca 438 = 7908.54 Epsilon = 0.566
# 109
# 110
# resultado da epoca 439 = 11840.48 Epsilon = 0.565
# 108
# 111
# resultado da epoca 440 = -4070.95 Epsilon = 0.564
# 117
# 102
# resultado da epoca 441 = -14359.61 Epsilon = 0.563
# 97
# 122
# resultado da epoca 442 = -61248.24 Epsilon = 0.562
# 94
# 125
# resultado da epoca 443 = -11446.14 Epsilon = 0.561
# 102
# 117
# resultado da epoca 444 = 6980.62 Epsilon = 0.560
# 112
# 107
# resultado da epoca 445 = -30348.57 Epsilon = 0.559
# 104
# 115
# resultado da epoca 446 = -23358.10 Epsilon = 0.558
# 103
# 116
# resultado da epoca 447 = -20075.59 Epsilon = 0.557
# 103
# 116
# resultado da epoca 448 = -25704.43 Epsilon = 0.556
# 113
# 106
# resultado da epoca 449 = -10603.62 Epsilon = 0.555
# 104
# 115
# resultado da epoca 450 = -25626.08 Epsilon = 0.554
# 110
# 109
# resultado da epoca 451 = -25846.47 Epsilon = 0.554
# 101
# 118
# resultado da epoca 452 = 5948.10 Epsilon = 0.553
# 119
# 100
# resultado da epoca 453 = -1448.81 Epsilon = 0.552
# 105
# 114
# resultado da epoca 454 = 519.39 Epsilon = 0.551
# 116
# 103
# resultado da epoca 455 = -25801.49 Epsilon = 0.550
# 102
# 117
# resultado da epoca 456 = -140.61 Epsilon = 0.549
# 116
# 103
# resultado da epoca 457 = -24246.71 Epsilon = 0.548
# 102
# 117
# resultado da epoca 458 = -3364.02 Epsilon = 0.547
# 105
# 114
# resultado da epoca 459 = -4439.95 Epsilon = 0.546
# 109
# 110
# resultado da epoca 460 = -14431.07 Epsilon = 0.545
# 107
# 112
# resultado da epoca 461 = -14310.83 Epsilon = 0.544
# 116
# 103
# resultado da epoca 462 = -3198.70 Epsilon = 0.543
# 110
# 109
# resultado da epoca 463 = -3549.06 Epsilon = 0.542
# 110
# 109
# resultado da epoca 464 = -20789.64 Epsilon = 0.541
# 107
# 112
# resultado da epoca 465 = -10394.90 Epsilon = 0.540
# 111
# 108
# resultado da epoca 466 = 2805.79 Epsilon = 0.539
# 113
# 106
# resultado da epoca 467 = -19505.93 Epsilon = 0.538
# 115
# 104
# resultado da epoca 468 = 3626.77 Epsilon = 0.537
# 115
# 104
# resultado da epoca 469 = -13653.60 Epsilon = 0.536
# 97
# 122
# resultado da epoca 470 = -5238.34 Epsilon = 0.535
# 118
# 101
# resultado da epoca 471 = -8917.96 Epsilon = 0.534
# 106
# 113
# resultado da epoca 472 = -12513.03 Epsilon = 0.533
# 110
# 109
# resultado da epoca 473 = -33918.06 Epsilon = 0.532
# 97
# 122
# resultado da epoca 474 = -1575.63 Epsilon = 0.531
# 104
# 115
# resultado da epoca 475 = 11050.18 Epsilon = 0.530
# 109
# 110
# resultado da epoca 476 = -8937.72 Epsilon = 0.529
# 108
# 111
# resultado da epoca 477 = 3642.24 Epsilon = 0.528
# 115
# 104
# resultado da epoca 478 = -29862.70 Epsilon = 0.527
# 100
# 119
# resultado da epoca 479 = 218.17 Epsilon = 0.526
# 106
# 113
# resultado da epoca 480 = -20714.17 Epsilon = 0.525
# 100
# 119
# resultado da epoca 481 = -20771.30 Epsilon = 0.524
# 101
# 118
# resultado da epoca 482 = -15469.53 Epsilon = 0.523
# 102
# 117
# resultado da epoca 483 = -10972.64 Epsilon = 0.522
# 102
# 117
# resultado da epoca 484 = -29684.12 Epsilon = 0.521
# 102
# 117
# resultado da epoca 485 = -12065.31 Epsilon = 0.520
# 98
# 121
# resultado da epoca 486 = -36132.64 Epsilon = 0.519
# 106
# 113
# resultado da epoca 487 = -28567.25 Epsilon = 0.518
# 105
# 114
# resultado da epoca 488 = 4590.79 Epsilon = 0.517
# 112
# 107
# resultado da epoca 489 = -24335.72 Epsilon = 0.516
# 105
# 114
# resultado da epoca 490 = -11653.94 Epsilon = 0.515
# 98
# 121
# resultado da epoca 491 = -155.19 Epsilon = 0.514
# 106
# 113
# resultado da epoca 492 = -24071.60 Epsilon = 0.513
# 102
# 117
# resultado da epoca 493 = -19898.52 Epsilon = 0.512
# 108
# 111
# resultado da epoca 494 = 8256.73 Epsilon = 0.511
# 101
# 118
# resultado da epoca 495 = 7554.71 Epsilon = 0.510
# 116
# 103
# resultado da epoca 496 = -65.46 Epsilon = 0.509
# 109
# 110
# resultado da epoca 497 = -16528.32 Epsilon = 0.508
# 112
# 107
# resultado da epoca 498 = -5410.80 Epsilon = 0.507
# 106
# 113
# resultado da epoca 499 = -44860.47 Epsilon = 0.506
# 89
# 130
# resultado da epoca 500 = -23062.83 Epsilon = 0.505
# 94
# 125
# resultado da epoca 501 = -33113.58 Epsilon = 0.504
# 94
# 125
# resultado da epoca 502 = -11454.32 Epsilon = 0.503
# 102
# 117
# resultado da epoca 503 = -29316.73 Epsilon = 0.502
# 97
# 122
# resultado da epoca 504 = -7230.41 Epsilon = 0.501
# 109
# 110
# resultado da epoca 505 = -13024.25 Epsilon = 0.500
# 104
# 115
# resultado da epoca 506 = -19474.96 Epsilon = 0.499
# 96
# 123
# resultado da epoca 507 = -4858.64 Epsilon = 0.498
# 110
# 109
# resultado da epoca 508 = -7490.29 Epsilon = 0.497
# 109
# 110
# resultado da epoca 509 = -29161.22 Epsilon = 0.496
# 95
# 124
# resultado da epoca 510 = -3879.36 Epsilon = 0.495
# 98
# 121
# resultado da epoca 511 = -13623.30 Epsilon = 0.494
# 95
# 124
# resultado da epoca 512 = -46653.13 Epsilon = 0.493
# 94
# 125
# resultado da epoca 513 = -19149.05 Epsilon = 0.492
# 99
# 120
# resultado da epoca 514 = -37835.55 Epsilon = 0.491
# 101
# 118
# resultado da epoca 515 = -17607.06 Epsilon = 0.490
# 99
# 120
# resultado da epoca 516 = -39049.13 Epsilon = 0.489
# 93
# 126
# resultado da epoca 517 = -11508.60 Epsilon = 0.488
# 108
# 111
# resultado da epoca 518 = 17642.66 Epsilon = 0.487
# 114
# 105
# resultado da epoca 519 = -28497.91 Epsilon = 0.486
# 98
# 121
# resultado da epoca 520 = -13321.15 Epsilon = 0.485
# 104
# 115
# resultado da epoca 521 = -10789.14 Epsilon = 0.484
# 106
# 113
# resultado da epoca 522 = -23617.97 Epsilon = 0.483
# 92
# 127
# resultado da epoca 523 = -21495.98 Epsilon = 0.482
# 98
# 121
# resultado da epoca 524 = -11776.31 Epsilon = 0.481
# 102
# 117
# resultado da epoca 525 = 10377.60 Epsilon = 0.480
# 110
# 109
# resultado da epoca 526 = 3569.24 Epsilon = 0.479
# 113
# 106
# resultado da epoca 527 = 1870.61 Epsilon = 0.478
# 112
# 107
# resultado da epoca 528 = -41307.18 Epsilon = 0.477
# 95
# 124
# resultado da epoca 529 = -16152.02 Epsilon = 0.476
# 102
# 117
# resultado da epoca 530 = -11689.43 Epsilon = 0.475
# 105
# 114
# resultado da epoca 531 = -47507.08 Epsilon = 0.474
# 99
# 120
# resultado da epoca 532 = 445.82 Epsilon = 0.473
# 121
# 98
# resultado da epoca 533 = -26844.85 Epsilon = 0.472
# 102
# 117
# resultado da epoca 534 = -24985.29 Epsilon = 0.471
# 101
# 118
# resultado da epoca 535 = -7197.10 Epsilon = 0.470
# 104
# 115
# resultado da epoca 536 = -5161.05 Epsilon = 0.469
# 108
# 111
# resultado da epoca 537 = -26354.47 Epsilon = 0.468
# 99
# 120
# resultado da epoca 538 = -13214.89 Epsilon = 0.467
# 110
# 109
# resultado da epoca 539 = -27603.52 Epsilon = 0.466
# 97
# 122
# resultado da epoca 540 = -25438.75 Epsilon = 0.465
# 100
# 119
# resultado da epoca 541 = -22106.77 Epsilon = 0.464
# 97
# 122
# resultado da epoca 542 = -33841.00 Epsilon = 0.463
# 98
# 121
# resultado da epoca 543 = -16501.84 Epsilon = 0.462
# 110
# 109
# resultado da epoca 544 = -10807.64 Epsilon = 0.461
# 100
# 119
# resultado da epoca 545 = -17439.82 Epsilon = 0.460
# 106
# 113
# resultado da epoca 546 = -16965.38 Epsilon = 0.459
# 103
# 116
# resultado da epoca 547 = -11871.62 Epsilon = 0.458
# 109
# 110
# resultado da epoca 548 = 921.43 Epsilon = 0.457
# 108
# 111
# resultado da epoca 549 = -1994.98 Epsilon = 0.456
# 103
# 116
# resultado da epoca 550 = 29302.30 Epsilon = 0.455
# 114
# 105
# resultado da epoca 551 = -31019.68 Epsilon = 0.455
# 96
# 123
# resultado da epoca 552 = -9815.98 Epsilon = 0.454
# 112
# 107
# resultado da epoca 553 = -27980.44 Epsilon = 0.453
# 106
# 113
# resultado da epoca 554 = -7783.88 Epsilon = 0.452
# 117
# 102
# resultado da epoca 555 = -4882.33 Epsilon = 0.451
# 104
# 115
# resultado da epoca 556 = -41071.76 Epsilon = 0.450
# 83
# 136
# resultado da epoca 557 = -38754.80 Epsilon = 0.449
# 91
# 128
# resultado da epoca 558 = -24610.11 Epsilon = 0.448
# 97
# 122
# resultado da epoca 559 = -20157.64 Epsilon = 0.447
# 100
# 119
# resultado da epoca 560 = -29471.42 Epsilon = 0.446
# 99
# 120
# resultado da epoca 561 = -16261.92 Epsilon = 0.445
# 106
# 113
# resultado da epoca 562 = -12921.18 Epsilon = 0.444
# 104
# 115
# resultado da epoca 563 = 2075.64 Epsilon = 0.443
# 109
# 110
# resultado da epoca 564 = -18708.22 Epsilon = 0.442
# 100
# 119
# resultado da epoca 565 = 1232.05 Epsilon = 0.441
# 104
# 115
# resultado da epoca 566 = 12777.30 Epsilon = 0.440
# 108
# 111
# resultado da epoca 567 = 7657.28 Epsilon = 0.439
# 121
# 98
# resultado da epoca 568 = -21257.76 Epsilon = 0.438
# 105
# 114
# resultado da epoca 569 = -17592.91 Epsilon = 0.437
# 106
# 113
# resultado da epoca 570 = -26816.61 Epsilon = 0.436
# 99
# 120
# resultado da epoca 571 = 15356.24 Epsilon = 0.435
# 117
# 102
# resultado da epoca 572 = 9635.33 Epsilon = 0.434
# 104
# 115
# resultado da epoca 573 = -17411.88 Epsilon = 0.433
# 104
# 115
# resultado da epoca 574 = 8930.85 Epsilon = 0.432
# 112
# 107
# resultado da epoca 575 = 22235.89 Epsilon = 0.431
# 116
# 103
# resultado da epoca 576 = 20214.54 Epsilon = 0.430
# 126
# 93
# resultado da epoca 577 = -5850.36 Epsilon = 0.429
# 112
# 107
# resultado da epoca 578 = 30645.73 Epsilon = 0.428
# 123
# 96
# resultado da epoca 579 = -317.16 Epsilon = 0.427
# 110
# 109
# resultado da epoca 580 = 6805.58 Epsilon = 0.426
# 108
# 111
# resultado da epoca 581 = -13672.65 Epsilon = 0.425
# 111
# 108
# resultado da epoca 582 = -37533.57 Epsilon = 0.424
# 100
# 119
# resultado da epoca 583 = 20351.70 Epsilon = 0.423
# 107
# 112
# resultado da epoca 584 = -17170.20 Epsilon = 0.422
# 100
# 119
# resultado da epoca 585 = -14558.09 Epsilon = 0.421
# 102
# 117
# resultado da epoca 586 = -6421.16 Epsilon = 0.420
# 104
# 115
# resultado da epoca 587 = -20306.12 Epsilon = 0.419
# 101
# 118
# resultado da epoca 588 = -29819.00 Epsilon = 0.418
# 101
# 118
# resultado da epoca 589 = -2599.54 Epsilon = 0.417
# 108
# 111
# resultado da epoca 590 = -41945.28 Epsilon = 0.416
# 102
# 117
# resultado da epoca 591 = -24369.28 Epsilon = 0.415
# 102
# 117
# resultado da epoca 592 = -16456.22 Epsilon = 0.414
# 96
# 123
# resultado da epoca 593 = -2903.05 Epsilon = 0.413
# 113
# 106
# resultado da epoca 594 = -26690.35 Epsilon = 0.412
# 96
# 123
# resultado da epoca 595 = -16745.32 Epsilon = 0.411
# 113
# 106
# resultado da epoca 596 = 9559.00 Epsilon = 0.410
# 124
# 95
# resultado da epoca 597 = -8663.65 Epsilon = 0.409
# 109
# 110
# resultado da epoca 598 = -10668.78 Epsilon = 0.408
# 109
# 110
# resultado da epoca 599 = -20392.64 Epsilon = 0.407
# 107
# 112
# resultado da epoca 600 = 338.56 Epsilon = 0.406
# 108
# 111
# resultado da epoca 601 = 4764.52 Epsilon = 0.405
# 108
# 111
# resultado da epoca 602 = 8219.54 Epsilon = 0.404
# 109
# 110
# resultado da epoca 603 = 4500.27 Epsilon = 0.403
# 116
# 103
# resultado da epoca 604 = -757.91 Epsilon = 0.402
# 108
# 111
# resultado da epoca 605 = -10055.12 Epsilon = 0.401
# 115
# 104
# resultado da epoca 606 = -5221.38 Epsilon = 0.400
# 112
# 107
# resultado da epoca 607 = -1284.13 Epsilon = 0.399
# 113
# 106
# resultado da epoca 608 = -4575.75 Epsilon = 0.398
# 106
# 113
# resultado da epoca 609 = -2.49 Epsilon = 0.397
# 113
# 106
# resultado da epoca 610 = 7638.63 Epsilon = 0.396
# 112
# 107
# resultado da epoca 611 = -20830.79 Epsilon = 0.395
# 101
# 118
# resultado da epoca 612 = 3938.33 Epsilon = 0.394
# 114
# 105
# resultado da epoca 613 = -2952.89 Epsilon = 0.393
# 110
# 109
# resultado da epoca 614 = 2578.57 Epsilon = 0.392
# 112
# 107
# resultado da epoca 615 = -21031.39 Epsilon = 0.391
# 91
# 128
# resultado da epoca 616 = -2651.82 Epsilon = 0.390
# 111
# 108
# resultado da epoca 617 = -26788.36 Epsilon = 0.389
# 102
# 117
# resultado da epoca 618 = -11827.84 Epsilon = 0.388
# 106
# 113
# resultado da epoca 619 = -36044.34 Epsilon = 0.387
# 91
# 128
# resultado da epoca 620 = -23936.52 Epsilon = 0.386
# 97
# 122
# resultado da epoca 621 = -2462.32 Epsilon = 0.385
# 108
# 111
# resultado da epoca 622 = 3421.92 Epsilon = 0.384
# 116
# 103
# resultado da epoca 623 = -19419.63 Epsilon = 0.383
# 103
# 116
# resultado da epoca 624 = -4426.95 Epsilon = 0.382
# 110
# 109
# resultado da epoca 625 = -2742.06 Epsilon = 0.381
# 118
# 101
# resultado da epoca 626 = -16877.63 Epsilon = 0.380
# 108
# 111
# resultado da epoca 627 = -18521.70 Epsilon = 0.379
# 101
# 118
# resultado da epoca 628 = -7586.52 Epsilon = 0.378
# 117
# 102
# resultado da epoca 629 = -2687.75 Epsilon = 0.377
# 111
# 108
# resultado da epoca 630 = 8404.13 Epsilon = 0.376
# 110
# 109
# resultado da epoca 631 = -32457.45 Epsilon = 0.375
# 101
# 118
# resultado da epoca 632 = -9639.88 Epsilon = 0.374
# 104
# 115
# resultado da epoca 633 = -1693.78 Epsilon = 0.373
# 111
# 108
# resultado da epoca 634 = -30562.43 Epsilon = 0.372
# 98
# 121
# resultado da epoca 635 = -9534.17 Epsilon = 0.371
# 113
# 106
# resultado da epoca 636 = 14108.58 Epsilon = 0.370
# 117
# 102
# resultado da epoca 637 = -23686.66 Epsilon = 0.369
# 102
# 117
# resultado da epoca 638 = 12050.74 Epsilon = 0.368
# 118
# 101
# resultado da epoca 639 = -5004.33 Epsilon = 0.367
# 108
# 111
# resultado da epoca 640 = 5601.07 Epsilon = 0.366
# 115
# 104
# resultado da epoca 641 = -20414.71 Epsilon = 0.365
# 105
# 114
# resultado da epoca 642 = 322.02 Epsilon = 0.364
# 110
# 109
# resultado da epoca 643 = 17106.93 Epsilon = 0.363
# 113
# 106
# resultado da epoca 644 = -13702.96 Epsilon = 0.362
# 101
# 118
# resultado da epoca 645 = -21463.49 Epsilon = 0.361
# 93
# 126
# resultado da epoca 646 = -5149.45 Epsilon = 0.360
# 104
# 115
# resultado da epoca 647 = 58.71 Epsilon = 0.359
# 118
# 101
# resultado da epoca 648 = -13833.69 Epsilon = 0.358
# 104
# 115
# resultado da epoca 649 = -21459.62 Epsilon = 0.357
# 102
# 117
# resultado da epoca 650 = -16954.44 Epsilon = 0.356
# 115
# 104
# resultado da epoca 651 = -4693.33 Epsilon = 0.356
# 113
# 106
# resultado da epoca 652 = 7033.72 Epsilon = 0.355
# 106
# 113
# resultado da epoca 653 = -3306.19 Epsilon = 0.354
# 113
# 106
# resultado da epoca 654 = -15418.50 Epsilon = 0.353
# 106
# 113
# resultado da epoca 655 = -34.49 Epsilon = 0.352
# 115
# 104
# resultado da epoca 656 = -31758.98 Epsilon = 0.351
# 93
# 126
# resultado da epoca 657 = -5164.39 Epsilon = 0.350
# 114
# 105
# resultado da epoca 658 = -5751.19 Epsilon = 0.349
# 112
# 107
# resultado da epoca 659 = -14029.61 Epsilon = 0.348
# 103
# 116
# resultado da epoca 660 = -12369.49 Epsilon = 0.347
# 107
# 112
# resultado da epoca 661 = -21419.24 Epsilon = 0.346
# 100
# 119
# resultado da epoca 662 = -7038.92 Epsilon = 0.345
# 118
# 101
# resultado da epoca 663 = -3987.76 Epsilon = 0.344
# 111
# 108
# resultado da epoca 664 = -13858.10 Epsilon = 0.343
# 109
# 110
# resultado da epoca 665 = -16100.11 Epsilon = 0.342
# 113
# 106
# resultado da epoca 666 = -30571.82 Epsilon = 0.341
# 99
# 120
# resultado da epoca 667 = 701.50 Epsilon = 0.340
# 119
# 100
# resultado da epoca 668 = 16374.56 Epsilon = 0.339
# 123
# 96
# resultado da epoca 669 = 35203.97 Epsilon = 0.338
# 123
# 96
# resultado da epoca 670 = 29698.54 Epsilon = 0.337
# 124
# 95
# resultado da epoca 671 = -3008.96 Epsilon = 0.336
# 107
# 112
# resultado da epoca 672 = 9025.89 Epsilon = 0.335
# 114
# 105
# resultado da epoca 673 = 13507.80 Epsilon = 0.334
# 121
# 98
# resultado da epoca 674 = 14182.37 Epsilon = 0.333
# 119
# 100
# resultado da epoca 675 = 6049.77 Epsilon = 0.332
# 123
# 96
# resultado da epoca 676 = 9184.40 Epsilon = 0.331
# 118
# 101
# resultado da epoca 677 = -15362.61 Epsilon = 0.330
# 106
# 113
# resultado da epoca 678 = -21975.57 Epsilon = 0.329
# 103
# 116
# resultado da epoca 679 = -397.85 Epsilon = 0.328
# 108
# 111
# resultado da epoca 680 = -32793.96 Epsilon = 0.327
# 98
# 121
# resultado da epoca 681 = 5369.68 Epsilon = 0.326
# 112
# 107
# resultado da epoca 682 = 4582.62 Epsilon = 0.325
# 109
# 110
# resultado da epoca 683 = -17094.53 Epsilon = 0.324
# 99
# 120
# resultado da epoca 684 = -2452.74 Epsilon = 0.323
# 114
# 105
# resultado da epoca 685 = -25069.84 Epsilon = 0.322
# 106
# 113
# resultado da epoca 686 = -20292.33 Epsilon = 0.321
# 105
# 114
# resultado da epoca 687 = -20484.41 Epsilon = 0.320
# 110
# 109
# resultado da epoca 688 = -4784.60 Epsilon = 0.319
# 104
# 115
# resultado da epoca 689 = -29344.56 Epsilon = 0.318
# 105
# 114
# resultado da epoca 690 = -7437.27 Epsilon = 0.317
# 109
# 110
# resultado da epoca 691 = -14959.06 Epsilon = 0.316
# 103
# 116
# resultado da epoca 692 = -8918.02 Epsilon = 0.315
# 120
# 99
# resultado da epoca 693 = -30869.91 Epsilon = 0.314
# 101
# 118
# resultado da epoca 694 = -29409.25 Epsilon = 0.313
# 99
# 120
# resultado da epoca 695 = -14858.15 Epsilon = 0.312
# 110
# 109
# resultado da epoca 696 = -14184.41 Epsilon = 0.311
# 111
# 108
# resultado da epoca 697 = -6466.85 Epsilon = 0.310
# 115
# 104
# resultado da epoca 698 = -13806.23 Epsilon = 0.309
# 108
# 111
# resultado da epoca 699 = -7214.85 Epsilon = 0.308
# 109
# 110
# resultado da epoca 700 = -24556.14 Epsilon = 0.307
# 100
# 119
# resultado da epoca 701 = -23948.22 Epsilon = 0.306
# 103
# 116
# resultado da epoca 702 = -2758.95 Epsilon = 0.305
# 105
# 114
# resultado da epoca 703 = -38603.76 Epsilon = 0.304
# 98
# 121
# resultado da epoca 704 = -9400.65 Epsilon = 0.303
# 101
# 118
# resultado da epoca 705 = -19649.91 Epsilon = 0.302
# 102
# 117
# resultado da epoca 706 = -4888.35 Epsilon = 0.301
# 118
# 101
# resultado da epoca 707 = -28695.38 Epsilon = 0.300
# 103
# 116
# resultado da epoca 708 = -7353.74 Epsilon = 0.299
# 109
# 110
# resultado da epoca 709 = -25134.35 Epsilon = 0.298
# 105
# 114
# resultado da epoca 710 = -44124.66 Epsilon = 0.297
# 97
# 122
# resultado da epoca 711 = -17649.50 Epsilon = 0.296
# 100
# 119
# resultado da epoca 712 = -5045.99 Epsilon = 0.295
# 111
# 108
# resultado da epoca 713 = -9357.76 Epsilon = 0.294
# 107
# 112
# resultado da epoca 714 = -17170.75 Epsilon = 0.293
# 99
# 120
# resultado da epoca 715 = -3151.60 Epsilon = 0.292
# 112
# 107
# resultado da epoca 716 = 13036.04 Epsilon = 0.291
# 113
# 106
# resultado da epoca 717 = -9331.08 Epsilon = 0.290
# 105
# 114
# resultado da epoca 718 = -6251.19 Epsilon = 0.289
# 112
# 107
# resultado da epoca 719 = -13380.64 Epsilon = 0.288
# 112
# 107
# resultado da epoca 720 = -12274.46 Epsilon = 0.287
# 101
# 118
# resultado da epoca 721 = 12900.54 Epsilon = 0.286
# 113
# 106
# resultado da epoca 722 = -945.55 Epsilon = 0.285
# 110
# 109
# resultado da epoca 723 = -8597.86 Epsilon = 0.284
# 100
# 119
# resultado da epoca 724 = 112.65 Epsilon = 0.283
# 108
# 111
# resultado da epoca 725 = -5054.02 Epsilon = 0.282
# 107
# 112
# resultado da epoca 726 = -3957.87 Epsilon = 0.281
# 103
# 116
# resultado da epoca 727 = 24745.11 Epsilon = 0.280
# 125
# 94
# resultado da epoca 728 = -5802.34 Epsilon = 0.279
# 98
# 121
# resultado da epoca 729 = -12680.51 Epsilon = 0.278
# 100
# 119
# resultado da epoca 730 = 1461.93 Epsilon = 0.277
# 108
# 111
# resultado da epoca 731 = -2979.55 Epsilon = 0.276
# 104
# 115
# resultado da epoca 732 = 10683.70 Epsilon = 0.275
# 115
# 104
# resultado da epoca 733 = -28975.19 Epsilon = 0.274
# 99
# 120
# resultado da epoca 734 = -29048.19 Epsilon = 0.273
# 107
# 112
# resultado da epoca 735 = -26275.92 Epsilon = 0.272
# 103
# 116
# resultado da epoca 736 = -31729.58 Epsilon = 0.271
# 94
# 125
# resultado da epoca 737 = -9133.81 Epsilon = 0.270
# 114
# 105
# resultado da epoca 738 = 13323.69 Epsilon = 0.269
# 106
# 113
# resultado da epoca 739 = 640.19 Epsilon = 0.268
# 115
# 104
# resultado da epoca 740 = -13612.84 Epsilon = 0.267
# 104
# 115
# resultado da epoca 741 = -5870.35 Epsilon = 0.266
# 105
# 114
# resultado da epoca 742 = -19362.30 Epsilon = 0.265
# 111
# 108
# resultado da epoca 743 = 15132.84 Epsilon = 0.264
# 110
# 109
# resultado da epoca 744 = 10658.77 Epsilon = 0.263
# 112
# 107
# resultado da epoca 745 = -14740.07 Epsilon = 0.262
# 110
# 109
# resultado da epoca 746 = -17025.34 Epsilon = 0.261
# 98
# 121
# resultado da epoca 747 = -15313.10 Epsilon = 0.260
# 101
# 118
# resultado da epoca 748 = -17723.56 Epsilon = 0.259
# 107
# 112
# resultado da epoca 749 = -6557.99 Epsilon = 0.258
# 109
# 110
# resultado da epoca 750 = 15701.99 Epsilon = 0.257
# 108
# 111
# resultado da epoca 751 = 15833.85 Epsilon = 0.257
# 112
# 107
# resultado da epoca 752 = -2804.18 Epsilon = 0.256
# 109
# 110
# resultado da epoca 753 = 14378.79 Epsilon = 0.255
# 111
# 108
# resultado da epoca 754 = 3630.74 Epsilon = 0.254
# 104
# 115
# resultado da epoca 755 = -14107.01 Epsilon = 0.253
# 111
# 108
# resultado da epoca 756 = -568.23 Epsilon = 0.252
# 122
# 97
# resultado da epoca 757 = -18890.80 Epsilon = 0.251
# 102
# 117
# resultado da epoca 758 = -15799.39 Epsilon = 0.250
# 103
# 116
# resultado da epoca 759 = -6162.02 Epsilon = 0.249
# 118
# 101
# resultado da epoca 760 = -17477.48 Epsilon = 0.248
# 103
# 116
# resultado da epoca 761 = 14043.11 Epsilon = 0.247
# 124
# 95
# resultado da epoca 762 = -12253.08 Epsilon = 0.246
# 114
# 105
# resultado da epoca 763 = 19664.86 Epsilon = 0.245
# 124
# 95
# resultado da epoca 764 = -9576.93 Epsilon = 0.244
# 102
# 117
# resultado da epoca 765 = 27816.89 Epsilon = 0.243
# 120
# 99
# resultado da epoca 766 = -21188.79 Epsilon = 0.242
# 110
# 109
# resultado da epoca 767 = -2738.77 Epsilon = 0.241
# 103
# 116
# resultado da epoca 768 = -14014.92 Epsilon = 0.240
# 103
# 116
# resultado da epoca 769 = -6206.96 Epsilon = 0.239
# 123
# 96
# resultado da epoca 770 = -9446.69 Epsilon = 0.238
# 109
# 110
# resultado da epoca 771 = 11577.87 Epsilon = 0.237
# 121
# 98
# resultado da epoca 772 = -15272.38 Epsilon = 0.236
# 102
# 117
# resultado da epoca 773 = 11028.54 Epsilon = 0.235
# 121
# 98
# resultado da epoca 774 = 6015.51 Epsilon = 0.234
# 117
# 102
# resultado da epoca 775 = 5246.99 Epsilon = 0.233
# 118
# 101
# resultado da epoca 776 = -22044.55 Epsilon = 0.232
# 95
# 124
# resultado da epoca 777 = 6614.56 Epsilon = 0.231
# 113
# 106
# resultado da epoca 778 = 2467.92 Epsilon = 0.230
# 112
# 107
# resultado da epoca 779 = -44264.56 Epsilon = 0.229
# 91
# 128
# resultado da epoca 780 = 2438.76 Epsilon = 0.228
# 117
# 102
# resultado da epoca 781 = -14033.13 Epsilon = 0.227
# 110
# 109
# resultado da epoca 782 = 7294.84 Epsilon = 0.226
# 114
# 105
# resultado da epoca 783 = 2829.97 Epsilon = 0.225
# 111
# 108
# resultado da epoca 784 = 9582.69 Epsilon = 0.224
# 117
# 102
# resultado da epoca 785 = -13517.53 Epsilon = 0.223
# 114
# 105
# resultado da epoca 786 = 14624.41 Epsilon = 0.222
# 120
# 99
# resultado da epoca 787 = 14820.62 Epsilon = 0.221
# 114
# 105
# resultado da epoca 788 = 23054.07 Epsilon = 0.220
# 117
# 102
# resultado da epoca 789 = 10903.93 Epsilon = 0.219
# 110
# 109
# resultado da epoca 790 = 27356.42 Epsilon = 0.218
# 123
# 96
# resultado da epoca 791 = 7727.17 Epsilon = 0.217
# 120
# 99
# resultado da epoca 792 = -9788.72 Epsilon = 0.216
# 107
# 112
# resultado da epoca 793 = -5575.28 Epsilon = 0.215
# 112
# 107
# resultado da epoca 794 = 3345.62 Epsilon = 0.214
# 116
# 103
# resultado da epoca 795 = 6348.72 Epsilon = 0.213
# 122
# 97
# resultado da epoca 796 = 11937.15 Epsilon = 0.212
# 116
# 103
# resultado da epoca 797 = -5069.32 Epsilon = 0.211
# 111
# 108
# resultado da epoca 798 = -10448.35 Epsilon = 0.210
# 96
# 123
# resultado da epoca 799 = 4428.17 Epsilon = 0.209
# 105
# 114
# resultado da epoca 800 = 3674.45 Epsilon = 0.208
# 112
# 107
# resultado da epoca 801 = -12788.60 Epsilon = 0.207
# 103
# 116
# resultado da epoca 802 = -2595.37 Epsilon = 0.206
# 99
# 120
# resultado da epoca 803 = -2446.36 Epsilon = 0.205
# 105
# 114
# resultado da epoca 804 = 2783.92 Epsilon = 0.204
# 108
# 111
# resultado da epoca 805 = 952.48 Epsilon = 0.203
# 117
# 102
# resultado da epoca 806 = 13135.81 Epsilon = 0.202
# 113
# 106
# resultado da epoca 807 = -18282.78 Epsilon = 0.201
# 107
# 112
# resultado da epoca 808 = 7320.31 Epsilon = 0.200
# 106
# 113
# resultado da epoca 809 = 2423.20 Epsilon = 0.199
# 108
# 111
# resultado da epoca 810 = 19608.03 Epsilon = 0.198
# 112
# 107
# resultado da epoca 811 = -9626.00 Epsilon = 0.197
# 110
# 109
# resultado da epoca 812 = 13121.62 Epsilon = 0.196
# 113
# 106
# resultado da epoca 813 = -10236.18 Epsilon = 0.195
# 102
# 117
# resultado da epoca 814 = -16640.92 Epsilon = 0.194
# 100
# 119
# resultado da epoca 815 = -27590.78 Epsilon = 0.193
# 99
# 120
# resultado da epoca 816 = -24231.32 Epsilon = 0.192
# 107
# 112
# resultado da epoca 817 = -19423.44 Epsilon = 0.191
# 104
# 115
# resultado da epoca 818 = -25571.53 Epsilon = 0.190
# 97
# 122
# resultado da epoca 819 = 619.84 Epsilon = 0.189
# 113
# 106
# resultado da epoca 820 = -32575.59 Epsilon = 0.188
# 93
# 126
# resultado da epoca 821 = -26093.09 Epsilon = 0.187
# 102
# 117
# resultado da epoca 822 = -9677.60 Epsilon = 0.186
# 110
# 109
# resultado da epoca 823 = -10108.02 Epsilon = 0.185
# 110
# 109
# resultado da epoca 824 = 13394.02 Epsilon = 0.184
# 121
# 98
# resultado da epoca 825 = 3478.28 Epsilon = 0.183
# 120
# 99
# resultado da epoca 826 = -3080.41 Epsilon = 0.182
# 120
# 99
# resultado da epoca 827 = -29334.71 Epsilon = 0.181
# 108
# 111
# resultado da epoca 828 = 18730.86 Epsilon = 0.180
# 127
# 92
# resultado da epoca 829 = -2749.18 Epsilon = 0.179
# 125
# 94
# resultado da epoca 830 = -24043.57 Epsilon = 0.178
# 107
# 112
# resultado da epoca 831 = -10661.95 Epsilon = 0.177
# 111
# 108
# resultado da epoca 832 = 9302.92 Epsilon = 0.176
# 122
# 97
# resultado da epoca 833 = -18387.75 Epsilon = 0.175
# 111
# 108
# resultado da epoca 834 = -1135.73 Epsilon = 0.174
# 118
# 101
# resultado da epoca 835 = -33044.10 Epsilon = 0.173
# 110
# 109
# resultado da epoca 836 = 9337.95 Epsilon = 0.172
# 120
# 99
# resultado da epoca 837 = -3667.69 Epsilon = 0.171
# 110
# 109
# resultado da epoca 838 = -6052.89 Epsilon = 0.170
# 121
# 98
# resultado da epoca 839 = 2358.47 Epsilon = 0.169
# 116
# 103
# resultado da epoca 840 = -15669.24 Epsilon = 0.168
# 117
# 102
# resultado da epoca 841 = 4350.87 Epsilon = 0.167
# 120
# 99
# resultado da epoca 842 = 4170.36 Epsilon = 0.166
# 124
# 95
# resultado da epoca 843 = 7436.05 Epsilon = 0.165
# 122
# 97
# resultado da epoca 844 = 404.63 Epsilon = 0.164
# 115
# 104
# resultado da epoca 845 = 11892.23 Epsilon = 0.163
# 119
# 100
# resultado da epoca 846 = -4854.06 Epsilon = 0.162
# 111
# 108
# resultado da epoca 847 = -10423.75 Epsilon = 0.161
# 122
# 97
# resultado da epoca 848 = 2477.48 Epsilon = 0.160
# 108
# 111
# resultado da epoca 849 = 6684.55 Epsilon = 0.159
# 122
# 97
# resultado da epoca 850 = -17317.06 Epsilon = 0.158
# 118
# 101
# resultado da epoca 851 = 1187.09 Epsilon = 0.158
# 114
# 105
# resultado da epoca 852 = 23859.89 Epsilon = 0.157
# 120
# 99
# resultado da epoca 853 = 1171.19 Epsilon = 0.156
# 120
# 99
# resultado da epoca 854 = -18322.48 Epsilon = 0.155
# 107
# 112
# resultado da epoca 855 = -23886.07 Epsilon = 0.154
# 109
# 110
# resultado da epoca 856 = 18837.34 Epsilon = 0.153
# 123
# 96
# resultado da epoca 857 = 14365.59 Epsilon = 0.152
# 129
# 90
# resultado da epoca 858 = 16667.94 Epsilon = 0.151
# 126
# 93
# resultado da epoca 859 = -4492.46 Epsilon = 0.150
# 109
# 110
# resultado da epoca 860 = 1678.99 Epsilon = 0.149
# 108
# 111
# resultado da epoca 861 = 17189.71 Epsilon = 0.148
# 121
# 98
# resultado da epoca 862 = 7849.01 Epsilon = 0.147
# 120
# 99
# resultado da epoca 863 = 17299.92 Epsilon = 0.146
# 115
# 104
# resultado da epoca 864 = 3541.02 Epsilon = 0.145
# 120
# 99
# resultado da epoca 865 = 14626.11 Epsilon = 0.144
# 128
# 91
# resultado da epoca 866 = 13294.44 Epsilon = 0.143
# 123
# 96
# resultado da epoca 867 = 3193.74 Epsilon = 0.142
# 113
# 106
# resultado da epoca 868 = -338.19 Epsilon = 0.141
# 116
# 103
# resultado da epoca 869 = 10519.45 Epsilon = 0.140
# 136
# 83
# resultado da epoca 870 = 7938.69 Epsilon = 0.139
# 119
# 100
# resultado da epoca 871 = 10537.37 Epsilon = 0.138
# 130
# 89
# resultado da epoca 872 = 16754.33 Epsilon = 0.137
# 128
# 91
# resultado da epoca 873 = -18405.85 Epsilon = 0.136
# 110
# 109
# resultado da epoca 874 = 24121.83 Epsilon = 0.135
# 122
# 97
# resultado da epoca 875 = -13973.21 Epsilon = 0.134
# 118
# 101
# resultado da epoca 876 = 21548.11 Epsilon = 0.133
# 128
# 91
# resultado da epoca 877 = 7306.70 Epsilon = 0.132
# 122
# 97
# resultado da epoca 878 = -942.26 Epsilon = 0.131
# 114
# 105
# resultado da epoca 879 = 8754.45 Epsilon = 0.130
# 116
# 103
# resultado da epoca 880 = 13612.48 Epsilon = 0.129
# 124
# 95
# resultado da epoca 881 = 18196.64 Epsilon = 0.128
# 126
# 93
# resultado da epoca 882 = 30512.71 Epsilon = 0.127
# 128
# 91
# resultado da epoca 883 = 17819.00 Epsilon = 0.126
# 123
# 96
# resultado da epoca 884 = 26459.45 Epsilon = 0.125
# 130
# 89
# resultado da epoca 885 = 34065.85 Epsilon = 0.124
# 135
# 84
# resultado da epoca 886 = 23683.46 Epsilon = 0.123
# 129
# 90
# resultado da epoca 887 = 17865.38 Epsilon = 0.122
# 123
# 96
# resultado da epoca 888 = 12607.23 Epsilon = 0.121
# 127
# 92
# resultado da epoca 889 = 12229.67 Epsilon = 0.120
# 118
# 101
# resultado da epoca 890 = 15506.27 Epsilon = 0.119
# 127
# 92
# resultado da epoca 891 = 20424.24 Epsilon = 0.118
# 132
# 87
# resultado da epoca 892 = 32779.34 Epsilon = 0.117
# 133
# 86
# resultado da epoca 893 = 7637.03 Epsilon = 0.116
# 121
# 98
# resultado da epoca 894 = 22940.80 Epsilon = 0.115
# 130
# 89
# resultado da epoca 895 = 13939.65 Epsilon = 0.114
# 121
# 98
# resultado da epoca 896 = 8713.78 Epsilon = 0.113
# 118
# 101
# resultado da epoca 897 = 25076.16 Epsilon = 0.112
# 123
# 96
# resultado da epoca 898 = -5037.52 Epsilon = 0.111
# 119
# 100
# resultado da epoca 899 = 5048.56 Epsilon = 0.110
# 127
# 92
# resultado da epoca 900 = 47708.19 Epsilon = 0.109
# 138
# 81
# resultado da epoca 901 = 36376.14 Epsilon = 0.108
# 138
# 81
# resultado da epoca 902 = -2598.25 Epsilon = 0.107
# 112
# 107
# resultado da epoca 903 = 11555.87 Epsilon = 0.106
# 126
# 93
# resultado da epoca 904 = 16165.16 Epsilon = 0.105
# 124
# 95
# resultado da epoca 905 = 46983.51 Epsilon = 0.104
# 137
# 82
# resultado da epoca 906 = 26316.54 Epsilon = 0.103
# 128
# 91
# resultado da epoca 907 = 22707.32 Epsilon = 0.102
# 133
# 86
# resultado da epoca 908 = 25948.49 Epsilon = 0.101
# 135
# 84
# resultado da epoca 909 = 32678.35 Epsilon = 0.100
# 126
# 93
# resultado da epoca 910 = 35563.88 Epsilon = 0.099
# 138
# 81
# resultado da epoca 911 = 17850.93 Epsilon = 0.098
# 122
# 97
# resultado da epoca 912 = 7498.68 Epsilon = 0.097
# 129
# 90
# resultado da epoca 913 = 45705.37 Epsilon = 0.096
# 139
# 80
# resultado da epoca 914 = 28322.32 Epsilon = 0.095
# 130
# 89
# resultado da epoca 915 = 22420.57 Epsilon = 0.094
# 124
# 95
# resultado da epoca 916 = 26091.18 Epsilon = 0.093
# 132
# 87
# resultado da epoca 917 = 53071.96 Epsilon = 0.092
# 139
# 80
# resultado da epoca 918 = 42264.88 Epsilon = 0.091
# 134
# 85
# resultado da epoca 919 = 35637.49 Epsilon = 0.090
# 137
# 82
# resultado da epoca 920 = 20379.11 Epsilon = 0.089
# 132
# 87
# resultado da epoca 921 = 29132.13 Epsilon = 0.088
# 135
# 84
# resultado da epoca 922 = 21522.09 Epsilon = 0.087
# 134
# 85
# resultado da epoca 923 = 2021.68 Epsilon = 0.086
# 122
# 97
# resultado da epoca 924 = 26867.55 Epsilon = 0.085
# 123
# 96
# resultado da epoca 925 = 44276.95 Epsilon = 0.084
# 139
# 80
# resultado da epoca 926 = 28002.75 Epsilon = 0.083
# 133
# 86
# resultado da epoca 927 = 49069.63 Epsilon = 0.082
# 135
# 84
# resultado da epoca 928 = 43261.29 Epsilon = 0.081
# 136
# 83
# resultado da epoca 929 = 13008.73 Epsilon = 0.080
# 124
# 95
# resultado da epoca 930 = 45860.41 Epsilon = 0.079
# 135
# 84
# resultado da epoca 931 = 31172.88 Epsilon = 0.078
# 133
# 86
# resultado da epoca 932 = 33699.23 Epsilon = 0.077
# 135
# 84
# resultado da epoca 933 = 42124.16 Epsilon = 0.076
# 140
# 79
# resultado da epoca 934 = 49992.86 Epsilon = 0.075
# 131
# 88
# resultado da epoca 935 = 39236.04 Epsilon = 0.074
# 136
# 83
# resultado da epoca 936 = 43002.34 Epsilon = 0.073
# 141
# 78
# resultado da epoca 937 = 31303.15 Epsilon = 0.072
# 137
# 82
# resultado da epoca 938 = 33803.57 Epsilon = 0.071
# 136
# 83
# resultado da epoca 939 = 31620.91 Epsilon = 0.070
# 137
# 82
# resultado da epoca 940 = 44562.47 Epsilon = 0.069
# 132
# 87
# resultado da epoca 941 = 34127.09 Epsilon = 0.068
# 135
# 84
# resultado da epoca 942 = 15087.66 Epsilon = 0.067
# 124
# 95
# resultado da epoca 943 = 31159.28 Epsilon = 0.066
# 130
# 89
# resultado da epoca 944 = 35355.12 Epsilon = 0.065
# 139
# 80
# resultado da epoca 945 = 32849.10 Epsilon = 0.064
# 130
# 89
# resultado da epoca 946 = 28902.40 Epsilon = 0.063
# 141
# 78
# resultado da epoca 947 = 43754.33 Epsilon = 0.062
# 146
# 66
# resultado da epoca 948 = 37255.35 Epsilon = 0.061
# 152
# 67
# resultado da epoca 949 = 32204.28 Epsilon = 0.060
# 132
# 87
# resultado da epoca 950 = 41159.85 Epsilon = 0.059
# 135
# 84
# resultado da epoca 951 = 24433.92 Epsilon = 0.059
# 134
# 85
# resultado da epoca 952 = 49782.29 Epsilon = 0.058
# 137
# 82
# resultado da epoca 953 = 55492.01 Epsilon = 0.057
# 141
# 78
# resultado da epoca 954 = 59821.67 Epsilon = 0.056
# 140
# 79
# resultado da epoca 955 = -8858.62 Epsilon = 0.055
# 79
# 126
# resultado da epoca 956 = -6728.25 Epsilon = 0.054
# 74
# 133
# resultado da epoca 957 = -11626.26 Epsilon = 0.053
# 61
# 148
# resultado da epoca 958 = -6079.19 Epsilon = 0.052
# 71
# 136
# resultado da epoca 959 = -7121.16 Epsilon = 0.051
# 63
# 135
# resultado da epoca 960 = -10557.52 Epsilon = 0.050
# 66
# 139
# resultado da epoca 961 = -7773.31 Epsilon = 0.049
# 68
# 137
# resultado da epoca 962 = -16283.82 Epsilon = 0.048
# 72
# 127
# resultado da epoca 963 = 5263.37 Epsilon = 0.047
# 75
# 118
# resultado da epoca 964 = -14543.50 Epsilon = 0.046
# 61
# 136
# resultado da epoca 965 = -2427.98 Epsilon = 0.045
# 50
# 144
# resultado da epoca 966 = 5383.60 Epsilon = 0.044
# 72
# 130
# resultado da epoca 967 = -5504.69 Epsilon = 0.043
# 67
# 126
# resultado da epoca 968 = 6037.12 Epsilon = 0.042
# 73
# 118
# resultado da epoca 969 = -631.88 Epsilon = 0.041
# 71
# 129
# resultado da epoca 970 = -3626.48 Epsilon = 0.040
# 62
# 125
# resultado da epoca 971 = 4515.41 Epsilon = 0.039
# 72
# 117
# resultado da epoca 972 = 931.52 Epsilon = 0.038
# 60
# 128
# resultado da epoca 973 = -789.22 Epsilon = 0.037
# 61
# 125
# resultado da epoca 974 = -4400.51 Epsilon = 0.036
# 56
# 137
# resultado da epoca 975 = 5863.29 Epsilon = 0.035
# 62
# 127
# resultado da epoca 976 = -3416.19 Epsilon = 0.034
# 45
# 141
# resultado da epoca 977 = 3238.55 Epsilon = 0.033
# 56
# 112
# resultado da epoca 978 = -15046.28 Epsilon = 0.032
# 49
# 129
# resultado da epoca 979 = 3391.55 Epsilon = 0.031
# 48
# 111
# resultado da epoca 980 = -2558.13 Epsilon = 0.030
# 44
# 111
# resultado da epoca 981 = -4009.80 Epsilon = 0.029
# 44
# 120
# resultado da epoca 982 = -5650.18 Epsilon = 0.028
# 36
# 132
# resultado da epoca 983 = -1215.22 Epsilon = 0.027
# 41
# 116
# resultado da epoca 984 = 7145.86 Epsilon = 0.026
# 47
# 119
# resultado da epoca 985 = 940.91 Epsilon = 0.025
# 41
# 110
# resultado da epoca 986 = -4208.38 Epsilon = 0.024
# 26
# 119
# resultado da epoca 987 = -621.22 Epsilon = 0.023
# 34
# 119
# resultado da epoca 988 = 1656.03 Epsilon = 0.022
# 39
# 115
# resultado da epoca 989 = 3781.47 Epsilon = 0.021
# 39
# 114
# resultado da epoca 990 = -4786.27 Epsilon = 0.020
# 22
# 119
# resultado da epoca 991 = 3196.59 Epsilon = 0.019
# 30
# 106
# resultado da epoca 992 = 1538.36 Epsilon = 0.018
# 31
# 109
# resultado da epoca 993 = -472.83 Epsilon = 0.017
# 28
# 94
# resultado da epoca 994 = 4046.53 Epsilon = 0.016
# 22
# 95
# resultado da epoca 995 = 5773.50 Epsilon = 0.015
# 28
# 97
# resultado da epoca 996 = -2424.50 Epsilon = 0.014
# 17
# 93
# resultado da epoca 997 = -1048.37 Epsilon = 0.013
# 17
# 95
# resultado da epoca 998 = 3941.77 Epsilon = 0.012
# 26
# 68
# resultado da epoca 999 = -1934.77 Epsilon = 0.011
# 11
# 84
# resultado da epoca 1000 = 2010.95 Epsilon = 0.010
# 7
# 60
# resultado da epoca 1001 = 5023.78 Epsilon = 0.010
# 18
# 65
# resultado da epoca 1002 = -1406.33 Epsilon = 0.010
# 7
# 74
# resultado da epoca 1003 = 1905.12 Epsilon = 0.010
# 13
# 72
# resultado da epoca 1004 = 1519.59 Epsilon = 0.010
# 11
# 60
# 0
# 0
# Melhor resultado diario: 6699.60
