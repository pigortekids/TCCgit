# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
n_mercado = n_variaveis*janela #inputs
n_estados = 2 #ncont e valor
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0

for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Model
from keras.layers import Dense, Input, concatenate
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, mkt_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.mkt_size = mkt_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        #inputs
        x1 = Input(shape=(self.state_size,))
        x2 = Input(shape=(self.mkt_size,))
        
        #state hidden layers
        a1 = Dense(320)(x1)
        a2 = Dense(256)(a1)
        
        #mkt hidden layers
        b1 = Dense(320)(x2)
        b2 = Dense(256)(b1)
        
        #concatenacao
        x12 = concatenate([a2, b2], axis=-1)
        
        #camada de suporte
        a12 = Dense(128)(x12)
        
        #camada de saida
        y = Dense(self.action_size, activation='linear')(a12)
        
        model = Model(inputs=[x1, x2], outputs=y)
        
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(self.mkt_size)
        self.prox_janela_precos = np.zeros(self.mkt_size)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict([self.state, self.janela_precos]) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x1 = np.zeros((batch_size+1, self.state_size))
        x2 = np.zeros((batch_size+1, self.mkt_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, mercado, prox_estado, prox_mercado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict([prox_estado, prox_mercado])[0])) #pega valor que quer chegar

            target_f = self.model.predict([estado, mercado]) #pega valor que chegou
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x1[i,:] = estado
            x2[i,:] = mercado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit([x1, x2], y, epochs=1, verbose=0) #treina modelo
            
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.janela_precos, self.next_state, self.prox_janela_precos, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_estados, n_mercado, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          960         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 320)          6720        input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          82176       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          82176       dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           dense_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          65664       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 11)           1419        dense_5[0][0]
# ==================================================================================================
# Total params: 239,115
# Trainable params: 239,115
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.reshape(np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l]), (1,modelo.mkt_size))
        modelo.state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        
        acao = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l]),(1,modelo.mkt_size))
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]),(1,modelo.mkt_size))
        
        modelo.next_state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    lucro += posicao

    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+5): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos2.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1106 17:49:44.535006  7500 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -23786.80 Epsilon = 1.000
# 96
# 123
# resultado da epoca 1 = -50560.48 Epsilon = 0.999
# 91
# 128
# resultado da epoca 2 = -46119.58 Epsilon = 0.998
# 95
# 124
# resultado da epoca 3 = -35500.52 Epsilon = 0.997
# 89
# 130
# resultado da epoca 4 = -31474.90 Epsilon = 0.996
# 99
# 120
# resultado da epoca 5 = -37115.62 Epsilon = 0.995
# 89
# 130
# resultado da epoca 6 = -33196.88 Epsilon = 0.994
# 98
# 121
# resultado da epoca 7 = -46835.08 Epsilon = 0.993
# 86
# 133
# resultado da epoca 8 = -38810.80 Epsilon = 0.992
# 87
# 132
# resultado da epoca 9 = -44375.28 Epsilon = 0.991
# 89
# 130
# resultado da epoca 10 = -48873.46 Epsilon = 0.990
# 89
# 130
# resultado da epoca 11 = 5061.22 Epsilon = 0.989
# 107
# 112
# resultado da epoca 12 = -42002.22 Epsilon = 0.988
# 97
# 122
# resultado da epoca 13 = -86194.16 Epsilon = 0.987
# 77
# 142
# resultado da epoca 14 = -57639.92 Epsilon = 0.986
# 78
# 141
# resultado da epoca 15 = -45561.06 Epsilon = 0.985
# 81
# 138
# resultado da epoca 16 = -57822.66 Epsilon = 0.984
# 89
# 130
# resultado da epoca 17 = -22825.44 Epsilon = 0.983
# 106
# 113
# resultado da epoca 18 = -42884.82 Epsilon = 0.982
# 94
# 125
# resultado da epoca 19 = -44250.48 Epsilon = 0.981
# 86
# 133
# resultado da epoca 20 = -7206.72 Epsilon = 0.980
# 109
# 110
# resultado da epoca 21 = -30852.40 Epsilon = 0.979
# 95
# 124
# resultado da epoca 22 = -40489.40 Epsilon = 0.978
# 91
# 128
# resultado da epoca 23 = -52009.78 Epsilon = 0.977
# 88
# 131
# resultado da epoca 24 = -32213.04 Epsilon = 0.976
# 93
# 126
# resultado da epoca 25 = -15066.38 Epsilon = 0.975
# 105
# 114
# resultado da epoca 26 = -71655.92 Epsilon = 0.974
# 80
# 139
# resultado da epoca 27 = -40064.68 Epsilon = 0.973
# 87
# 132
# resultado da epoca 28 = -61730.54 Epsilon = 0.972
# 85
# 134
# resultado da epoca 29 = -48737.60 Epsilon = 0.971
# 87
# 132
# resultado da epoca 30 = -48664.66 Epsilon = 0.970
# 91
# 128
# resultado da epoca 31 = -44967.08 Epsilon = 0.969
# 91
# 128
# resultado da epoca 32 = -11808.90 Epsilon = 0.968
# 105
# 114
# resultado da epoca 33 = -60877.76 Epsilon = 0.967
# 88
# 131
# resultado da epoca 34 = -42130.64 Epsilon = 0.966
# 92
# 127
# resultado da epoca 35 = -52131.06 Epsilon = 0.965
# 87
# 132
# resultado da epoca 36 = -54120.56 Epsilon = 0.964
# 87
# 132
# resultado da epoca 37 = -59549.44 Epsilon = 0.963
# 78
# 141
# resultado da epoca 38 = -42010.64 Epsilon = 0.962
# 104
# 115
# resultado da epoca 39 = -36043.54 Epsilon = 0.961
# 89
# 130
# resultado da epoca 40 = -34492.00 Epsilon = 0.960
# 92
# 127
# resultado da epoca 41 = -33234.82 Epsilon = 0.959
# 97
# 122
# resultado da epoca 42 = -60492.40 Epsilon = 0.958
# 79
# 140
# resultado da epoca 43 = -37245.52 Epsilon = 0.957
# 92
# 127
# resultado da epoca 44 = -61206.92 Epsilon = 0.956
# 85
# 134
# resultado da epoca 45 = -42260.62 Epsilon = 0.955
# 92
# 127
# resultado da epoca 46 = -39435.48 Epsilon = 0.954
# 86
# 133
# resultado da epoca 47 = -41868.34 Epsilon = 0.953
# 96
# 123
# resultado da epoca 48 = -49519.60 Epsilon = 0.952
# 89
# 130
# resultado da epoca 49 = -37485.56 Epsilon = 0.951
# 98
# 121
# resultado da epoca 50 = -28588.74 Epsilon = 0.950
# 97
# 122
# resultado da epoca 51 = -8028.54 Epsilon = 0.950
# 101
# 118
# resultado da epoca 52 = -62937.98 Epsilon = 0.949
# 80
# 139
# resultado da epoca 53 = -49156.14 Epsilon = 0.948
# 90
# 129
# resultado da epoca 54 = -31110.18 Epsilon = 0.947
# 93
# 126
# resultado da epoca 55 = -37277.98 Epsilon = 0.946
# 97
# 122
# resultado da epoca 56 = -35655.74 Epsilon = 0.945
# 99
# 120
# resultado da epoca 57 = -37376.02 Epsilon = 0.944
# 100
# 119
# resultado da epoca 58 = -42600.32 Epsilon = 0.943
# 90
# 129
# resultado da epoca 59 = -19139.94 Epsilon = 0.942
# 102
# 117
# resultado da epoca 60 = -50089.42 Epsilon = 0.941
# 91
# 128
# resultado da epoca 61 = -30552.66 Epsilon = 0.940
# 98
# 121
# resultado da epoca 62 = -30058.24 Epsilon = 0.939
# 100
# 119
# resultado da epoca 63 = -26813.04 Epsilon = 0.938
# 97
# 122
# resultado da epoca 64 = -32308.70 Epsilon = 0.937
# 103
# 116
# resultado da epoca 65 = -56060.02 Epsilon = 0.936
# 80
# 139
# resultado da epoca 66 = -45142.28 Epsilon = 0.935
# 91
# 128
# resultado da epoca 67 = -35028.04 Epsilon = 0.934
# 90
# 129
# resultado da epoca 68 = -30891.54 Epsilon = 0.933
# 93
# 126
# resultado da epoca 69 = -42556.26 Epsilon = 0.932
# 87
# 132
# resultado da epoca 70 = -41126.40 Epsilon = 0.931
# 94
# 125
# resultado da epoca 71 = -38408.12 Epsilon = 0.930
# 94
# 125
# resultado da epoca 72 = -22867.28 Epsilon = 0.929
# 99
# 120
# resultado da epoca 73 = -66731.60 Epsilon = 0.928
# 82
# 137
# resultado da epoca 74 = -49481.66 Epsilon = 0.927
# 87
# 132
# resultado da epoca 75 = -39879.36 Epsilon = 0.926
# 93
# 126
# resultado da epoca 76 = -26519.04 Epsilon = 0.925
# 103
# 116
# resultado da epoca 77 = -28108.66 Epsilon = 0.924
# 107
# 112
# resultado da epoca 78 = -51534.08 Epsilon = 0.923
# 103
# 116
# resultado da epoca 79 = -31960.72 Epsilon = 0.922
# 101
# 118
# resultado da epoca 80 = -46778.60 Epsilon = 0.921
# 88
# 131
# resultado da epoca 81 = -22104.34 Epsilon = 0.920
# 91
# 128
# resultado da epoca 82 = -24378.20 Epsilon = 0.919
# 103
# 116
# resultado da epoca 83 = -39369.26 Epsilon = 0.918
# 83
# 136
# resultado da epoca 84 = -16235.70 Epsilon = 0.917
# 98
# 121
# resultado da epoca 85 = -31425.64 Epsilon = 0.916
# 94
# 125
# resultado da epoca 86 = -42157.00 Epsilon = 0.915
# 90
# 129
# resultado da epoca 87 = -25049.02 Epsilon = 0.914
# 105
# 114
# resultado da epoca 88 = -51579.28 Epsilon = 0.913
# 94
# 125
# resultado da epoca 89 = -36692.82 Epsilon = 0.912
# 93
# 126
# resultado da epoca 90 = -23179.78 Epsilon = 0.911
# 97
# 122
# resultado da epoca 91 = -29359.74 Epsilon = 0.910
# 100
# 119
# resultado da epoca 92 = -68626.86 Epsilon = 0.909
# 78
# 141
# resultado da epoca 93 = -18214.54 Epsilon = 0.908
# 106
# 113
# resultado da epoca 94 = -41410.74 Epsilon = 0.907
# 95
# 124
# resultado da epoca 95 = -54231.14 Epsilon = 0.906
# 85
# 134
# resultado da epoca 96 = -46815.32 Epsilon = 0.905
# 85
# 134
# resultado da epoca 97 = -34234.28 Epsilon = 0.904
# 87
# 132
# resultado da epoca 98 = -52027.28 Epsilon = 0.903
# 92
# 127
# resultado da epoca 99 = -50681.68 Epsilon = 0.902
# 93
# 126
# resultado da epoca 100 = -49634.28 Epsilon = 0.901
# 85
# 134
# resultado da epoca 101 = -32125.60 Epsilon = 0.900
# 99
# 120
# resultado da epoca 102 = -41723.46 Epsilon = 0.899
# 87
# 132
# resultado da epoca 103 = -35601.66 Epsilon = 0.898
# 88
# 131
# resultado da epoca 104 = -41371.20 Epsilon = 0.897
# 99
# 120
# resultado da epoca 105 = -57156.02 Epsilon = 0.896
# 86
# 133
# resultado da epoca 106 = -66320.82 Epsilon = 0.895
# 81
# 138
# resultado da epoca 107 = -23247.02 Epsilon = 0.894
# 101
# 118
# resultado da epoca 108 = -28718.92 Epsilon = 0.893
# 99
# 120
# resultado da epoca 109 = -30546.58 Epsilon = 0.892
# 99
# 120
# resultado da epoca 110 = -49974.76 Epsilon = 0.891
# 88
# 131
# resultado da epoca 111 = -47818.56 Epsilon = 0.890
# 93
# 126
# resultado da epoca 112 = -34010.36 Epsilon = 0.889
# 99
# 120
# resultado da epoca 113 = -32159.36 Epsilon = 0.888
# 96
# 123
# resultado da epoca 114 = -53743.80 Epsilon = 0.887
# 85
# 134
# resultado da epoca 115 = -35312.96 Epsilon = 0.886
# 88
# 131
# resultado da epoca 116 = -25850.08 Epsilon = 0.885
# 97
# 122
# resultado da epoca 117 = -30515.28 Epsilon = 0.884
# 93
# 126
# resultado da epoca 118 = -51255.00 Epsilon = 0.883
# 90
# 129
# resultado da epoca 119 = -52180.30 Epsilon = 0.882
# 79
# 140
# resultado da epoca 120 = -26438.96 Epsilon = 0.881
# 107
# 112
# resultado da epoca 121 = -38997.58 Epsilon = 0.880
# 91
# 128
# resultado da epoca 122 = -35150.24 Epsilon = 0.879
# 97
# 122
# resultado da epoca 123 = -29008.02 Epsilon = 0.878
# 97
# 122
# resultado da epoca 124 = -27425.92 Epsilon = 0.877
# 102
# 117
# resultado da epoca 125 = -58551.04 Epsilon = 0.876
# 87
# 132
# resultado da epoca 126 = -14822.48 Epsilon = 0.875
# 100
# 119
# resultado da epoca 127 = -39780.52 Epsilon = 0.874
# 100
# 119
# resultado da epoca 128 = -40671.62 Epsilon = 0.873
# 91
# 128
# resultado da epoca 129 = -36183.60 Epsilon = 0.872
# 101
# 118
# resultado da epoca 130 = -33828.12 Epsilon = 0.871
# 95
# 124
# resultado da epoca 131 = -25223.28 Epsilon = 0.870
# 107
# 112
# resultado da epoca 132 = -44212.00 Epsilon = 0.869
# 92
# 127
# resultado da epoca 133 = -74820.52 Epsilon = 0.868
# 88
# 131
# resultado da epoca 134 = -31809.64 Epsilon = 0.867
# 98
# 121
# resultado da epoca 135 = -27389.90 Epsilon = 0.866
# 93
# 126
# resultado da epoca 136 = -27048.72 Epsilon = 0.865
# 93
# 126
# resultado da epoca 137 = -76304.08 Epsilon = 0.864
# 80
# 139
# resultado da epoca 138 = -36207.96 Epsilon = 0.863
# 98
# 121
# resultado da epoca 139 = -55516.16 Epsilon = 0.862
# 85
# 134
# resultado da epoca 140 = -26521.00 Epsilon = 0.861
# 102
# 117
# resultado da epoca 141 = -45120.92 Epsilon = 0.860
# 84
# 135
# resultado da epoca 142 = -23507.06 Epsilon = 0.859
# 94
# 125
# resultado da epoca 143 = -33285.00 Epsilon = 0.858
# 88
# 131
# resultado da epoca 144 = -19169.24 Epsilon = 0.857
# 94
# 125
# resultado da epoca 145 = -34553.28 Epsilon = 0.856
# 89
# 130
# resultado da epoca 146 = -43387.56 Epsilon = 0.855
# 91
# 128
# resultado da epoca 147 = -57457.04 Epsilon = 0.854
# 83
# 136
# resultado da epoca 148 = -27645.18 Epsilon = 0.853
# 100
# 119
# resultado da epoca 149 = -83257.76 Epsilon = 0.852
# 73
# 146
# resultado da epoca 150 = -28912.34 Epsilon = 0.851
# 98
# 121
# resultado da epoca 151 = -57769.52 Epsilon = 0.851
# 88
# 131
# resultado da epoca 152 = -15885.44 Epsilon = 0.850
# 103
# 116
# resultado da epoca 153 = -11217.70 Epsilon = 0.849
# 112
# 107
# resultado da epoca 154 = -67213.84 Epsilon = 0.848
# 86
# 133
# resultado da epoca 155 = -22816.36 Epsilon = 0.847
# 100
# 119
# resultado da epoca 156 = -40913.84 Epsilon = 0.846
# 96
# 123
# resultado da epoca 157 = -56136.40 Epsilon = 0.845
# 89
# 130
# resultado da epoca 158 = -39573.06 Epsilon = 0.844
# 99
# 120
# resultado da epoca 159 = -47782.02 Epsilon = 0.843
# 88
# 131
# resultado da epoca 160 = -38378.76 Epsilon = 0.842
# 92
# 127
# resultado da epoca 161 = -42942.26 Epsilon = 0.841
# 86
# 133
# resultado da epoca 162 = -69180.70 Epsilon = 0.840
# 91
# 128
# resultado da epoca 163 = -36419.98 Epsilon = 0.839
# 96
# 123
# resultado da epoca 164 = -44138.32 Epsilon = 0.838
# 87
# 132
# resultado da epoca 165 = -74614.56 Epsilon = 0.837
# 86
# 133
# resultado da epoca 166 = -41525.46 Epsilon = 0.836
# 83
# 136
# resultado da epoca 167 = -60002.78 Epsilon = 0.835
# 89
# 130
# resultado da epoca 168 = -51295.46 Epsilon = 0.834
# 98
# 121
# resultado da epoca 169 = -50365.92 Epsilon = 0.833
# 89
# 130
# resultado da epoca 170 = -48529.88 Epsilon = 0.832
# 94
# 125
# resultado da epoca 171 = -17257.26 Epsilon = 0.831
# 99
# 120
# resultado da epoca 172 = -54185.54 Epsilon = 0.830
# 89
# 130
# resultado da epoca 173 = -70980.50 Epsilon = 0.829
# 86
# 133
# resultado da epoca 174 = -77597.90 Epsilon = 0.828
# 81
# 138
# resultado da epoca 175 = -36333.90 Epsilon = 0.827
# 96
# 123
# resultado da epoca 176 = -54630.58 Epsilon = 0.826
# 96
# 123
# resultado da epoca 177 = -39191.10 Epsilon = 0.825
# 88
# 131
# resultado da epoca 178 = -55001.02 Epsilon = 0.824
# 90
# 129
# resultado da epoca 179 = -65763.66 Epsilon = 0.823
# 88
# 131
# resultado da epoca 180 = -73540.04 Epsilon = 0.822
# 84
# 135
# resultado da epoca 181 = -68214.68 Epsilon = 0.821
# 85
# 134
# resultado da epoca 182 = -22308.42 Epsilon = 0.820
# 100
# 119
# resultado da epoca 183 = -56661.40 Epsilon = 0.819
# 95
# 124
# resultado da epoca 184 = -51162.20 Epsilon = 0.818
# 96
# 123
# resultado da epoca 185 = -67825.72 Epsilon = 0.817
# 84
# 135
# resultado da epoca 186 = -34180.44 Epsilon = 0.816
# 97
# 122
# resultado da epoca 187 = -62056.66 Epsilon = 0.815
# 85
# 134
# resultado da epoca 188 = -40706.60 Epsilon = 0.814
# 86
# 133
# resultado da epoca 189 = -31152.08 Epsilon = 0.813
# 83
# 136
# resultado da epoca 190 = -70302.72 Epsilon = 0.812
# 86
# 133
# resultado da epoca 191 = -21319.86 Epsilon = 0.811
# 88
# 131
# resultado da epoca 192 = -10371.76 Epsilon = 0.810
# 106
# 113
# resultado da epoca 193 = -39532.66 Epsilon = 0.809
# 89
# 130
# resultado da epoca 194 = -36795.34 Epsilon = 0.808
# 88
# 131
# resultado da epoca 195 = -29464.14 Epsilon = 0.807
# 104
# 115
# resultado da epoca 196 = -37567.64 Epsilon = 0.806
# 94
# 125
# resultado da epoca 197 = -60604.96 Epsilon = 0.805
# 81
# 138
# resultado da epoca 198 = -56437.12 Epsilon = 0.804
# 87
# 132
# resultado da epoca 199 = -35571.44 Epsilon = 0.803
# 109
# 110
# resultado da epoca 200 = -55561.08 Epsilon = 0.802
# 80
# 139
# resultado da epoca 201 = -8827.78 Epsilon = 0.801
# 107
# 112
# resultado da epoca 202 = -65816.86 Epsilon = 0.800
# 86
# 133
# resultado da epoca 203 = -42195.44 Epsilon = 0.799
# 99
# 120
# resultado da epoca 204 = -17243.14 Epsilon = 0.798
# 100
# 119
# resultado da epoca 205 = -39843.48 Epsilon = 0.797
# 96
# 123
# resultado da epoca 206 = -58740.56 Epsilon = 0.796
# 92
# 127
# resultado da epoca 207 = -57895.04 Epsilon = 0.795
# 82
# 137
# resultado da epoca 208 = -54809.92 Epsilon = 0.794
# 90
# 129
# resultado da epoca 209 = -68592.40 Epsilon = 0.793
# 94
# 125
# resultado da epoca 210 = -32642.78 Epsilon = 0.792
# 91
# 128
# resultado da epoca 211 = -48889.34 Epsilon = 0.791
# 90
# 129
# resultado da epoca 212 = -26306.22 Epsilon = 0.790
# 93
# 126
# resultado da epoca 213 = -52657.06 Epsilon = 0.789
# 88
# 131
# resultado da epoca 214 = -47065.10 Epsilon = 0.788
# 96
# 123
# resultado da epoca 215 = -38756.16 Epsilon = 0.787
# 92
# 127
# resultado da epoca 216 = -41844.10 Epsilon = 0.786
# 91
# 128
# resultado da epoca 217 = -63530.64 Epsilon = 0.785
# 87
# 132
# resultado da epoca 218 = -39736.80 Epsilon = 0.784
# 90
# 129
# resultado da epoca 219 = -45108.52 Epsilon = 0.783
# 91
# 128
# resultado da epoca 220 = -42064.34 Epsilon = 0.782
# 97
# 122
# resultado da epoca 221 = -40718.12 Epsilon = 0.781
# 91
# 128
# resultado da epoca 222 = -51841.74 Epsilon = 0.780
# 90
# 129
# resultado da epoca 223 = -70691.28 Epsilon = 0.779
# 78
# 141
# resultado da epoca 224 = -47934.90 Epsilon = 0.778
# 89
# 130
# resultado da epoca 225 = -13168.96 Epsilon = 0.777
# 99
# 120
# resultado da epoca 226 = -29613.82 Epsilon = 0.776
# 102
# 117
# resultado da epoca 227 = -7028.20 Epsilon = 0.775
# 108
# 111
# resultado da epoca 228 = -61292.52 Epsilon = 0.774
# 80
# 139
# resultado da epoca 229 = -51429.98 Epsilon = 0.773
# 87
# 132
# resultado da epoca 230 = -32751.60 Epsilon = 0.772
# 96
# 123
# resultado da epoca 231 = -49809.06 Epsilon = 0.771
# 85
# 134
# resultado da epoca 232 = -34777.74 Epsilon = 0.770
# 94
# 125
# resultado da epoca 233 = -28264.58 Epsilon = 0.769
# 100
# 119
# resultado da epoca 234 = -79264.74 Epsilon = 0.768
# 88
# 131
# resultado da epoca 235 = -65978.28 Epsilon = 0.767
# 91
# 128
# resultado da epoca 236 = -54035.16 Epsilon = 0.766
# 88
# 131
# resultado da epoca 237 = -48484.18 Epsilon = 0.765
# 93
# 126
# resultado da epoca 238 = -26144.20 Epsilon = 0.764
# 102
# 117
# resultado da epoca 239 = -38257.80 Epsilon = 0.763
# 96
# 123
# resultado da epoca 240 = -36923.78 Epsilon = 0.762
# 94
# 125
# resultado da epoca 241 = -57438.94 Epsilon = 0.761
# 84
# 135
# resultado da epoca 242 = -31201.90 Epsilon = 0.760
# 95
# 124
# resultado da epoca 243 = -28365.36 Epsilon = 0.759
# 95
# 124
# resultado da epoca 244 = -47704.86 Epsilon = 0.758
# 96
# 123
# resultado da epoca 245 = -48265.06 Epsilon = 0.757
# 97
# 122
# resultado da epoca 246 = -48395.12 Epsilon = 0.756
# 92
# 127
# resultado da epoca 247 = -36006.82 Epsilon = 0.755
# 88
# 131
# resultado da epoca 248 = -28132.46 Epsilon = 0.754
# 96
# 123
# resultado da epoca 249 = -44585.84 Epsilon = 0.753
# 81
# 138
# resultado da epoca 250 = -37201.54 Epsilon = 0.752
# 100
# 119
# resultado da epoca 251 = -47021.72 Epsilon = 0.752
# 88
# 131
# resultado da epoca 252 = -57608.58 Epsilon = 0.751
# 89
# 130
# resultado da epoca 253 = -41966.36 Epsilon = 0.750
# 94
# 125
# resultado da epoca 254 = -35567.54 Epsilon = 0.749
# 92
# 127
# resultado da epoca 255 = -34814.32 Epsilon = 0.748
# 89
# 130
# resultado da epoca 256 = -45499.12 Epsilon = 0.747
# 99
# 120
# resultado da epoca 257 = -27688.24 Epsilon = 0.746
# 96
# 123
# resultado da epoca 258 = -55426.52 Epsilon = 0.745
# 98
# 121
# resultado da epoca 259 = -38232.86 Epsilon = 0.744
# 89
# 130
# resultado da epoca 260 = -48902.40 Epsilon = 0.743
# 96
# 123
# resultado da epoca 261 = -38702.04 Epsilon = 0.742
# 87
# 132
# resultado da epoca 262 = -46104.76 Epsilon = 0.741
# 88
# 131
# resultado da epoca 263 = -33150.56 Epsilon = 0.740
# 91
# 128
# resultado da epoca 264 = -67165.60 Epsilon = 0.739
# 87
# 132
# resultado da epoca 265 = -48913.16 Epsilon = 0.738
# 96
# 123
# resultado da epoca 266 = -51293.42 Epsilon = 0.737
# 101
# 118
# resultado da epoca 267 = -63212.50 Epsilon = 0.736
# 96
# 123
# resultado da epoca 268 = -31773.56 Epsilon = 0.735
# 95
# 124
# resultado da epoca 269 = -41612.00 Epsilon = 0.734
# 94
# 125
# resultado da epoca 270 = -62868.24 Epsilon = 0.733
# 85
# 134
# resultado da epoca 271 = -23418.56 Epsilon = 0.732
# 101
# 118
# resultado da epoca 272 = -53254.80 Epsilon = 0.731
# 95
# 124
# resultado da epoca 273 = -51614.48 Epsilon = 0.730
# 79
# 140
# resultado da epoca 274 = -27109.36 Epsilon = 0.729
# 101
# 118
# resultado da epoca 275 = -37593.76 Epsilon = 0.728
# 98
# 121
# resultado da epoca 276 = -35249.40 Epsilon = 0.727
# 102
# 117
# resultado da epoca 277 = -41926.14 Epsilon = 0.726
# 94
# 125
# resultado da epoca 278 = -50849.74 Epsilon = 0.725
# 90
# 129
# resultado da epoca 279 = -54164.30 Epsilon = 0.724
# 81
# 138
# resultado da epoca 280 = -35667.52 Epsilon = 0.723
# 105
# 114
# resultado da epoca 281 = -54406.00 Epsilon = 0.722
# 78
# 141
# resultado da epoca 282 = -23989.12 Epsilon = 0.721
# 97
# 122
# resultado da epoca 283 = -31283.54 Epsilon = 0.720
# 91
# 128
# resultado da epoca 284 = -73138.66 Epsilon = 0.719
# 91
# 128
# resultado da epoca 285 = -51161.24 Epsilon = 0.718
# 92
# 127
# resultado da epoca 286 = -41917.66 Epsilon = 0.717
# 91
# 128
# resultado da epoca 287 = -46003.48 Epsilon = 0.716
# 87
# 132
# resultado da epoca 288 = -37299.88 Epsilon = 0.715
# 102
# 117
# resultado da epoca 289 = -31755.88 Epsilon = 0.714
# 97
# 122
# resultado da epoca 290 = -68422.52 Epsilon = 0.713
# 84
# 135
# resultado da epoca 291 = -29654.16 Epsilon = 0.712
# 97
# 122
# resultado da epoca 292 = -78828.66 Epsilon = 0.711
# 88
# 131
# resultado da epoca 293 = -59720.82 Epsilon = 0.710
# 85
# 134
# resultado da epoca 294 = -9852.20 Epsilon = 0.709
# 105
# 114
# resultado da epoca 295 = -55446.66 Epsilon = 0.708
# 92
# 127
# resultado da epoca 296 = -21987.44 Epsilon = 0.707
# 102
# 117
# resultado da epoca 297 = -58028.82 Epsilon = 0.706
# 92
# 127
# resultado da epoca 298 = -43196.52 Epsilon = 0.705
# 93
# 126
# resultado da epoca 299 = -59248.20 Epsilon = 0.704
# 84
# 135
# resultado da epoca 300 = -30030.58 Epsilon = 0.703
# 102
# 117
# resultado da epoca 301 = -58202.98 Epsilon = 0.702
# 94
# 125
# resultado da epoca 302 = -78076.10 Epsilon = 0.701
# 84
# 135
# resultado da epoca 303 = -64578.14 Epsilon = 0.700
# 81
# 138
# resultado da epoca 304 = -56705.62 Epsilon = 0.699
# 87
# 132
# resultado da epoca 305 = -57881.66 Epsilon = 0.698
# 87
# 132
# resultado da epoca 306 = -44453.60 Epsilon = 0.697
# 91
# 128
# resultado da epoca 307 = -70272.08 Epsilon = 0.696
# 78
# 141
# resultado da epoca 308 = -34942.00 Epsilon = 0.695
# 96
# 123
# resultado da epoca 309 = -33257.00 Epsilon = 0.694
# 88
# 131
# resultado da epoca 310 = -53372.04 Epsilon = 0.693
# 78
# 141
# resultado da epoca 311 = -53118.08 Epsilon = 0.692
# 86
# 133
# resultado da epoca 312 = -40951.90 Epsilon = 0.691
# 93
# 126
# resultado da epoca 313 = -45069.84 Epsilon = 0.690
# 88
# 131
# resultado da epoca 314 = -49234.48 Epsilon = 0.689
# 93
# 126
# resultado da epoca 315 = -25908.18 Epsilon = 0.688
# 97
# 122
# resultado da epoca 316 = -42995.30 Epsilon = 0.687
# 93
# 126
# resultado da epoca 317 = -25789.32 Epsilon = 0.686
# 89
# 130
# resultado da epoca 318 = -38829.36 Epsilon = 0.685
# 92
# 127
# resultado da epoca 319 = -50683.34 Epsilon = 0.684
# 87
# 132
# resultado da epoca 320 = -26903.42 Epsilon = 0.683
# 98
# 121
# resultado da epoca 321 = -45123.94 Epsilon = 0.682
# 95
# 124
# resultado da epoca 322 = -67586.80 Epsilon = 0.681
# 81
# 138
# resultado da epoca 323 = -29160.10 Epsilon = 0.680
# 89
# 130
# resultado da epoca 324 = -61398.96 Epsilon = 0.679
# 88
# 131
# resultado da epoca 325 = -71973.54 Epsilon = 0.678
# 80
# 139
# resultado da epoca 326 = -18238.94 Epsilon = 0.677
# 98
# 121
# resultado da epoca 327 = -46428.92 Epsilon = 0.676
# 82
# 137
# resultado da epoca 328 = -30578.02 Epsilon = 0.675
# 91
# 128
# resultado da epoca 329 = -27502.30 Epsilon = 0.674
# 103
# 116
# resultado da epoca 330 = -43909.14 Epsilon = 0.673
# 96
# 123
# resultado da epoca 331 = -51720.22 Epsilon = 0.672
# 88
# 131
# resultado da epoca 332 = -50510.52 Epsilon = 0.671
# 85
# 134
# resultado da epoca 333 = -9456.00 Epsilon = 0.670
# 99
# 120
# resultado da epoca 334 = -54108.28 Epsilon = 0.669
# 84
# 135
# resultado da epoca 335 = -3271.54 Epsilon = 0.668
# 106
# 113
# resultado da epoca 336 = -49152.28 Epsilon = 0.667
# 94
# 125
# resultado da epoca 337 = -78972.92 Epsilon = 0.666
# 80
# 139
# resultado da epoca 338 = -56129.36 Epsilon = 0.665
# 83
# 136
# resultado da epoca 339 = -43964.68 Epsilon = 0.664
# 90
# 129
# resultado da epoca 340 = -50365.20 Epsilon = 0.663
# 92
# 127
# resultado da epoca 341 = -40384.74 Epsilon = 0.662
# 92
# 127
# resultado da epoca 342 = -40484.54 Epsilon = 0.661
# 92
# 127
# resultado da epoca 343 = -23933.50 Epsilon = 0.660
# 98
# 121
# resultado da epoca 344 = -52799.78 Epsilon = 0.659
# 79
# 140
# resultado da epoca 345 = -23769.92 Epsilon = 0.658
# 107
# 112
# resultado da epoca 346 = -33274.54 Epsilon = 0.657
# 91
# 128
# resultado da epoca 347 = -61766.00 Epsilon = 0.656
# 84
# 135
# resultado da epoca 348 = -87143.84 Epsilon = 0.655
# 71
# 148
# resultado da epoca 349 = -33628.12 Epsilon = 0.654
# 96
# 123
# resultado da epoca 350 = -42387.50 Epsilon = 0.653
# 89
# 130
# resultado da epoca 351 = -46737.78 Epsilon = 0.653
# 95
# 124
# resultado da epoca 352 = -53550.10 Epsilon = 0.652
# 83
# 136
# resultado da epoca 353 = -35076.52 Epsilon = 0.651
# 89
# 130
# resultado da epoca 354 = -37107.22 Epsilon = 0.650
# 86
# 133
# resultado da epoca 355 = -40814.98 Epsilon = 0.649
# 93
# 126
# resultado da epoca 356 = -49206.58 Epsilon = 0.648
# 92
# 127
# resultado da epoca 357 = -40633.58 Epsilon = 0.647
# 90
# 129
# resultado da epoca 358 = -35157.10 Epsilon = 0.646
# 91
# 128
# resultado da epoca 359 = -62469.78 Epsilon = 0.645
# 93
# 126
# resultado da epoca 360 = -45044.08 Epsilon = 0.644
# 93
# 126
# resultado da epoca 361 = -38441.92 Epsilon = 0.643
# 98
# 121
# resultado da epoca 362 = -27724.06 Epsilon = 0.642
# 90
# 129
# resultado da epoca 363 = -39983.68 Epsilon = 0.641
# 92
# 127
# resultado da epoca 364 = -42095.78 Epsilon = 0.640
# 90
# 129
# resultado da epoca 365 = -24561.04 Epsilon = 0.639
# 98
# 121
# resultado da epoca 366 = -28790.30 Epsilon = 0.638
# 94
# 125
# resultado da epoca 367 = -31332.78 Epsilon = 0.637
# 90
# 129
# resultado da epoca 368 = -44458.50 Epsilon = 0.636
# 89
# 130
# resultado da epoca 369 = -68702.46 Epsilon = 0.635
# 91
# 128
# resultado da epoca 370 = -57717.90 Epsilon = 0.634
# 92
# 127
# resultado da epoca 371 = -51531.34 Epsilon = 0.633
# 86
# 133
# resultado da epoca 372 = -40003.92 Epsilon = 0.632
# 94
# 125
# resultado da epoca 373 = -44077.38 Epsilon = 0.631
# 91
# 128
# resultado da epoca 374 = -59483.16 Epsilon = 0.630
# 83
# 136
# resultado da epoca 375 = -47034.64 Epsilon = 0.629
# 86
# 133
# resultado da epoca 376 = -44461.36 Epsilon = 0.628
# 93
# 126
# resultado da epoca 377 = -67829.76 Epsilon = 0.627
# 83
# 136
# resultado da epoca 378 = -62060.18 Epsilon = 0.626
# 90
# 129
# resultado da epoca 379 = -47866.48 Epsilon = 0.625
# 86
# 133
# resultado da epoca 380 = -53620.24 Epsilon = 0.624
# 89
# 130
# resultado da epoca 381 = -50981.22 Epsilon = 0.623
# 89
# 130
# resultado da epoca 382 = -39704.72 Epsilon = 0.622
# 91
# 128
# resultado da epoca 383 = -73550.66 Epsilon = 0.621
# 75
# 144
# resultado da epoca 384 = -58805.16 Epsilon = 0.620
# 87
# 132
# resultado da epoca 385 = -32949.34 Epsilon = 0.619
# 102
# 117
# resultado da epoca 386 = -31445.40 Epsilon = 0.618
# 94
# 125
# resultado da epoca 387 = -56149.28 Epsilon = 0.617
# 80
# 139
# resultado da epoca 388 = -37272.16 Epsilon = 0.616
# 92
# 127
# resultado da epoca 389 = -38936.34 Epsilon = 0.615
# 97
# 122
# resultado da epoca 390 = -25444.32 Epsilon = 0.614
# 103
# 116
# resultado da epoca 391 = -46827.92 Epsilon = 0.613
# 89
# 130
# resultado da epoca 392 = -87102.86 Epsilon = 0.612
# 78
# 141
# resultado da epoca 393 = -33783.36 Epsilon = 0.611
# 96
# 123
# resultado da epoca 394 = -55317.90 Epsilon = 0.610
# 95
# 124
# resultado da epoca 395 = -57152.72 Epsilon = 0.609
# 105
# 114
# resultado da epoca 396 = -49721.78 Epsilon = 0.608
# 86
# 133
# resultado da epoca 397 = -50125.92 Epsilon = 0.607
# 85
# 134
# resultado da epoca 398 = -46046.38 Epsilon = 0.606
# 93
# 126
# resultado da epoca 399 = -32025.76 Epsilon = 0.605
# 99
# 120
# resultado da epoca 400 = -52264.78 Epsilon = 0.604
# 95
# 124
# resultado da epoca 401 = -48550.04 Epsilon = 0.603
# 96
# 123
# resultado da epoca 402 = -45781.88 Epsilon = 0.602
# 90
# 129
# resultado da epoca 403 = -73360.24 Epsilon = 0.601
# 82
# 137
# resultado da epoca 404 = -78406.18 Epsilon = 0.600
# 89
# 130
# resultado da epoca 405 = -59243.44 Epsilon = 0.599
# 88
# 131
# resultado da epoca 406 = -55934.48 Epsilon = 0.598
# 90
# 129
# resultado da epoca 407 = -21051.38 Epsilon = 0.597
# 97
# 122
# resultado da epoca 408 = -37288.20 Epsilon = 0.596
# 89
# 130
# resultado da epoca 409 = -68314.40 Epsilon = 0.595
# 89
# 130
# resultado da epoca 410 = -65066.68 Epsilon = 0.594
# 92
# 127
# resultado da epoca 411 = -19935.80 Epsilon = 0.593
# 107
# 112
# resultado da epoca 412 = -49628.78 Epsilon = 0.592
# 96
# 123
# resultado da epoca 413 = -59901.58 Epsilon = 0.591
# 82
# 137
# resultado da epoca 414 = -70438.12 Epsilon = 0.590
# 97
# 122
# resultado da epoca 415 = -23538.16 Epsilon = 0.589
# 103
# 116
# resultado da epoca 416 = -62973.52 Epsilon = 0.588
# 83
# 136
# resultado da epoca 417 = -40676.46 Epsilon = 0.587
# 94
# 125
# resultado da epoca 418 = -24852.06 Epsilon = 0.586
# 94
# 125
# resultado da epoca 419 = -63675.50 Epsilon = 0.585
# 92
# 127
# resultado da epoca 420 = -4684.88 Epsilon = 0.584
# 111
# 108
# resultado da epoca 421 = -52525.34 Epsilon = 0.583
# 101
# 118
# resultado da epoca 422 = -31733.60 Epsilon = 0.582
# 98
# 121
# resultado da epoca 423 = -16121.32 Epsilon = 0.581
# 107
# 112
# resultado da epoca 424 = -60571.12 Epsilon = 0.580
# 98
# 121
# resultado da epoca 425 = -52287.84 Epsilon = 0.579
# 84
# 135
# resultado da epoca 426 = -80099.84 Epsilon = 0.578
# 91
# 128
# resultado da epoca 427 = -35949.64 Epsilon = 0.577
# 95
# 124
# resultado da epoca 428 = -40661.28 Epsilon = 0.576
# 96
# 123
# resultado da epoca 429 = -41485.70 Epsilon = 0.575
# 89
# 130
# resultado da epoca 430 = -36230.44 Epsilon = 0.574
# 97
# 122
# resultado da epoca 431 = -59405.74 Epsilon = 0.573
# 85
# 134
# resultado da epoca 432 = -43688.80 Epsilon = 0.572
# 95
# 124
# resultado da epoca 433 = -38379.38 Epsilon = 0.571
# 95
# 124
# resultado da epoca 434 = -57606.60 Epsilon = 0.570
# 85
# 134
# resultado da epoca 435 = -6099.30 Epsilon = 0.569
# 109
# 110
# resultado da epoca 436 = -44678.58 Epsilon = 0.568
# 91
# 128
# resultado da epoca 437 = -7501.68 Epsilon = 0.567
# 104
# 115
# resultado da epoca 438 = -84296.80 Epsilon = 0.566
# 79
# 140
# resultado da epoca 439 = -42437.86 Epsilon = 0.565
# 94
# 125
# resultado da epoca 440 = -41465.48 Epsilon = 0.564
# 90
# 129
# resultado da epoca 441 = -55934.18 Epsilon = 0.563
# 90
# 129
# resultado da epoca 442 = -47054.60 Epsilon = 0.562
# 96
# 123
# resultado da epoca 443 = -29820.06 Epsilon = 0.561
# 96
# 123
# resultado da epoca 444 = -35531.42 Epsilon = 0.560
# 97
# 122
# resultado da epoca 445 = -29805.26 Epsilon = 0.559
# 94
# 125
# resultado da epoca 446 = -53327.12 Epsilon = 0.558
# 95
# 124
# resultado da epoca 447 = -40538.00 Epsilon = 0.557
# 97
# 122
# resultado da epoca 448 = -37314.22 Epsilon = 0.556
# 99
# 120
# resultado da epoca 449 = -63837.38 Epsilon = 0.555
# 92
# 127
# resultado da epoca 450 = -52615.16 Epsilon = 0.554
# 97
# 122
# resultado da epoca 451 = -36793.88 Epsilon = 0.554
# 92
# 127
# resultado da epoca 452 = -44340.60 Epsilon = 0.553
# 95
# 124
# resultado da epoca 453 = -60727.28 Epsilon = 0.552
# 90
# 129
# resultado da epoca 454 = -37653.24 Epsilon = 0.551
# 99
# 120
# resultado da epoca 455 = -5225.88 Epsilon = 0.550
# 108
# 111
# resultado da epoca 456 = -38973.64 Epsilon = 0.549
# 98
# 121
# resultado da epoca 457 = -43232.70 Epsilon = 0.548
# 95
# 124
# resultado da epoca 458 = -72485.06 Epsilon = 0.547
# 78
# 141
# resultado da epoca 459 = -54247.50 Epsilon = 0.546
# 88
# 131
# resultado da epoca 460 = -58689.00 Epsilon = 0.545
# 92
# 127
# resultado da epoca 461 = -41854.14 Epsilon = 0.544
# 94
# 125
# resultado da epoca 462 = -50887.50 Epsilon = 0.543
# 98
# 121
# resultado da epoca 463 = -41354.36 Epsilon = 0.542
# 101
# 118
# resultado da epoca 464 = -29102.30 Epsilon = 0.541
# 103
# 116
# resultado da epoca 465 = -40434.80 Epsilon = 0.540
# 89
# 130
# resultado da epoca 466 = -34197.72 Epsilon = 0.539
# 100
# 119
# resultado da epoca 467 = -74103.32 Epsilon = 0.538
# 82
# 137
# resultado da epoca 468 = -61307.28 Epsilon = 0.537
# 89
# 130
# resultado da epoca 469 = -52129.58 Epsilon = 0.536
# 84
# 135
# resultado da epoca 470 = -29814.66 Epsilon = 0.535
# 92
# 127
# resultado da epoca 471 = -31492.48 Epsilon = 0.534
# 105
# 114
# resultado da epoca 472 = -34113.46 Epsilon = 0.533
# 95
# 124
# resultado da epoca 473 = -41729.00 Epsilon = 0.532
# 92
# 127
# resultado da epoca 474 = -36414.54 Epsilon = 0.531
# 106
# 113
# resultado da epoca 475 = -47656.88 Epsilon = 0.530
# 87
# 132
# resultado da epoca 476 = -22799.74 Epsilon = 0.529
# 106
# 113
# resultado da epoca 477 = -61282.80 Epsilon = 0.528
# 87
# 132
# resultado da epoca 478 = -16910.78 Epsilon = 0.527
# 103
# 116
# resultado da epoca 479 = -55421.90 Epsilon = 0.526
# 99
# 120
# resultado da epoca 480 = -41845.06 Epsilon = 0.525
# 100
# 119
# resultado da epoca 481 = -35842.50 Epsilon = 0.524
# 98
# 121
# resultado da epoca 482 = -58569.42 Epsilon = 0.523
# 88
# 131
# resultado da epoca 483 = -45364.66 Epsilon = 0.522
# 96
# 123
# resultado da epoca 484 = -43455.08 Epsilon = 0.521
# 89
# 130
# resultado da epoca 485 = -35236.44 Epsilon = 0.520
# 97
# 122
# resultado da epoca 486 = -37905.70 Epsilon = 0.519
# 101
# 118
# resultado da epoca 487 = -26030.74 Epsilon = 0.518
# 103
# 116
# resultado da epoca 488 = -14684.36 Epsilon = 0.517
# 107
# 112
# resultado da epoca 489 = -48253.32 Epsilon = 0.516
# 98
# 121
# resultado da epoca 490 = -62863.76 Epsilon = 0.515
# 90
# 129
# resultado da epoca 491 = -35040.80 Epsilon = 0.514
# 98
# 121
# resultado da epoca 492 = -44205.10 Epsilon = 0.513
# 97
# 122
# resultado da epoca 493 = -39612.74 Epsilon = 0.512
# 100
# 119
# resultado da epoca 494 = -32238.32 Epsilon = 0.511
# 99
# 120
# resultado da epoca 495 = -34977.68 Epsilon = 0.510
# 95
# 124
# resultado da epoca 496 = -48389.70 Epsilon = 0.509
# 94
# 125
# resultado da epoca 497 = -49684.44 Epsilon = 0.508
# 95
# 124
# resultado da epoca 498 = -52217.96 Epsilon = 0.507
# 92
# 127
# resultado da epoca 499 = -30388.66 Epsilon = 0.506
# 96
# 123
# resultado da epoca 500 = -42079.08 Epsilon = 0.505
# 95
# 124
# resultado da epoca 501 = -34005.48 Epsilon = 0.504
# 104
# 115
# resultado da epoca 502 = -62697.48 Epsilon = 0.503
# 93
# 126
# resultado da epoca 503 = -33004.54 Epsilon = 0.502
# 91
# 128
# resultado da epoca 504 = -26787.82 Epsilon = 0.501
# 92
# 127
# resultado da epoca 505 = -50934.84 Epsilon = 0.500
# 104
# 115
# resultado da epoca 506 = -37181.58 Epsilon = 0.499
# 101
# 118
# resultado da epoca 507 = -64632.10 Epsilon = 0.498
# 81
# 138
# resultado da epoca 508 = -40004.52 Epsilon = 0.497
# 100
# 119
# resultado da epoca 509 = -52690.80 Epsilon = 0.496
# 94
# 125
# resultado da epoca 510 = -41917.42 Epsilon = 0.495
# 103
# 116
# resultado da epoca 511 = -47598.64 Epsilon = 0.494
# 91
# 128
# resultado da epoca 512 = -42562.18 Epsilon = 0.493
# 96
# 123
# resultado da epoca 513 = -45916.20 Epsilon = 0.492
# 93
# 126
# resultado da epoca 514 = -28804.80 Epsilon = 0.491
# 100
# 119
# resultado da epoca 515 = -37007.42 Epsilon = 0.490
# 98
# 121
# resultado da epoca 516 = -38325.02 Epsilon = 0.489
# 93
# 126
# resultado da epoca 517 = -18839.78 Epsilon = 0.488
# 103
# 116
# resultado da epoca 518 = -10032.20 Epsilon = 0.487
# 108
# 111
# resultado da epoca 519 = -35884.06 Epsilon = 0.486
# 96
# 123
# resultado da epoca 520 = -40224.26 Epsilon = 0.485
# 95
# 124
# resultado da epoca 521 = -41921.76 Epsilon = 0.484
# 90
# 129
# resultado da epoca 522 = -40890.08 Epsilon = 0.483
# 92
# 127
# resultado da epoca 523 = -65115.74 Epsilon = 0.482
# 93
# 126
# resultado da epoca 524 = -31435.26 Epsilon = 0.481
# 96
# 123
# resultado da epoca 525 = -24253.08 Epsilon = 0.480
# 105
# 114
# resultado da epoca 526 = -56055.94 Epsilon = 0.479
# 87
# 132
# resultado da epoca 527 = -51417.48 Epsilon = 0.478
# 96
# 123
# resultado da epoca 528 = -36168.86 Epsilon = 0.477
# 96
# 123
# resultado da epoca 529 = -36256.20 Epsilon = 0.476
# 93
# 126
# resultado da epoca 530 = -56248.34 Epsilon = 0.475
# 91
# 128
# resultado da epoca 531 = -64103.80 Epsilon = 0.474
# 90
# 129
# resultado da epoca 532 = -49966.10 Epsilon = 0.473
# 92
# 127
# resultado da epoca 533 = -52734.20 Epsilon = 0.472
# 96
# 123
# resultado da epoca 534 = -41259.58 Epsilon = 0.471
# 94
# 125
# resultado da epoca 535 = -16897.28 Epsilon = 0.470
# 104
# 115
# resultado da epoca 536 = -54022.54 Epsilon = 0.469
# 95
# 124
# resultado da epoca 537 = -36439.52 Epsilon = 0.468
# 99
# 120
# resultado da epoca 538 = -33864.62 Epsilon = 0.467
# 96
# 123
# resultado da epoca 539 = -28968.16 Epsilon = 0.466
# 103
# 116
# resultado da epoca 540 = -45474.24 Epsilon = 0.465
# 98
# 121
# resultado da epoca 541 = -25726.80 Epsilon = 0.464
# 98
# 121
# resultado da epoca 542 = -50418.44 Epsilon = 0.463
# 97
# 122
# resultado da epoca 543 = -29288.32 Epsilon = 0.462
# 107
# 112
# resultado da epoca 544 = -43103.54 Epsilon = 0.461
# 87
# 132
# resultado da epoca 545 = -28616.20 Epsilon = 0.460
# 95
# 124
# resultado da epoca 546 = -26125.60 Epsilon = 0.459
# 110
# 109
# resultado da epoca 547 = -36461.00 Epsilon = 0.458
# 91
# 128
# resultado da epoca 548 = -57966.30 Epsilon = 0.457
# 94
# 125
# resultado da epoca 549 = -65008.38 Epsilon = 0.456
# 91
# 128
# resultado da epoca 550 = -44678.16 Epsilon = 0.455
# 104
# 115
# resultado da epoca 551 = -47085.68 Epsilon = 0.455
# 99
# 120
# resultado da epoca 552 = -45523.58 Epsilon = 0.454
# 95
# 124
# resultado da epoca 553 = -46008.34 Epsilon = 0.453
# 95
# 124
# resultado da epoca 554 = -57191.06 Epsilon = 0.452
# 88
# 131
# resultado da epoca 555 = -42740.92 Epsilon = 0.451
# 95
# 124
# resultado da epoca 556 = -58272.10 Epsilon = 0.450
# 95
# 124
# resultado da epoca 557 = -28527.46 Epsilon = 0.449
# 97
# 122
# resultado da epoca 558 = -41519.16 Epsilon = 0.448
# 98
# 121
# resultado da epoca 559 = -52916.84 Epsilon = 0.447
# 94
# 125
# resultado da epoca 560 = -50372.48 Epsilon = 0.446
# 100
# 119
# resultado da epoca 561 = -29832.04 Epsilon = 0.445
# 99
# 120
# resultado da epoca 562 = -13646.16 Epsilon = 0.444
# 99
# 120
# resultado da epoca 563 = -48674.64 Epsilon = 0.443
# 95
# 124
# resultado da epoca 564 = -47335.38 Epsilon = 0.442
# 98
# 121
# resultado da epoca 565 = -11605.44 Epsilon = 0.441
# 104
# 115
# resultado da epoca 566 = -51137.64 Epsilon = 0.440
# 98
# 121
# resultado da epoca 567 = -77759.16 Epsilon = 0.439
# 86
# 133
# resultado da epoca 568 = -20747.94 Epsilon = 0.438
# 99
# 120
# resultado da epoca 569 = -26313.28 Epsilon = 0.437
# 104
# 115
# resultado da epoca 570 = -6969.12 Epsilon = 0.436
# 99
# 120
# resultado da epoca 571 = -39231.60 Epsilon = 0.435
# 94
# 125
# resultado da epoca 572 = -10644.98 Epsilon = 0.434
# 96
# 123
# resultado da epoca 573 = -48933.66 Epsilon = 0.433
# 94
# 125
# resultado da epoca 574 = -48717.90 Epsilon = 0.432
# 90
# 129
# resultado da epoca 575 = -19884.26 Epsilon = 0.431
# 101
# 118
# resultado da epoca 576 = -47872.38 Epsilon = 0.430
# 90
# 129
# resultado da epoca 577 = -38510.24 Epsilon = 0.429
# 101
# 118
# resultado da epoca 578 = -41262.26 Epsilon = 0.428
# 100
# 119
# resultado da epoca 579 = -25064.38 Epsilon = 0.427
# 96
# 123
# resultado da epoca 580 = -51094.64 Epsilon = 0.426
# 94
# 125
# resultado da epoca 581 = -58448.68 Epsilon = 0.425
# 93
# 126
# resultado da epoca 582 = -17633.90 Epsilon = 0.424
# 101
# 118
# resultado da epoca 583 = -25675.32 Epsilon = 0.423
# 97
# 122
# resultado da epoca 584 = -53753.88 Epsilon = 0.422
# 89
# 130
# resultado da epoca 585 = -48132.00 Epsilon = 0.421
# 97
# 122
# resultado da epoca 586 = -39854.04 Epsilon = 0.420
# 98
# 121
# resultado da epoca 587 = -79010.72 Epsilon = 0.419
# 92
# 127
# resultado da epoca 588 = -60425.82 Epsilon = 0.418
# 92
# 127
# resultado da epoca 589 = -55070.22 Epsilon = 0.417
# 94
# 125
# resultado da epoca 590 = -96157.88 Epsilon = 0.416
# 83
# 136
# resultado da epoca 591 = -35951.68 Epsilon = 0.415
# 101
# 118
# resultado da epoca 592 = -51624.30 Epsilon = 0.414
# 93
# 126
# resultado da epoca 593 = 2210.60 Epsilon = 0.413
# 105
# 114
# resultado da epoca 594 = -23355.14 Epsilon = 0.412
# 97
# 122
# resultado da epoca 595 = -66143.16 Epsilon = 0.411
# 89
# 130
# resultado da epoca 596 = -54754.58 Epsilon = 0.410
# 95
# 124
# resultado da epoca 597 = -39154.64 Epsilon = 0.409
# 96
# 123
# resultado da epoca 598 = -40741.70 Epsilon = 0.408
# 102
# 117
# resultado da epoca 599 = -14383.00 Epsilon = 0.407
# 102
# 117
# resultado da epoca 600 = -23581.72 Epsilon = 0.406
# 101
# 118
# resultado da epoca 601 = -42619.96 Epsilon = 0.405
# 88
# 131
# resultado da epoca 602 = -51659.76 Epsilon = 0.404
# 90
# 129
# resultado da epoca 603 = -36995.30 Epsilon = 0.403
# 94
# 125
# resultado da epoca 604 = -58650.06 Epsilon = 0.402
# 96
# 123
# resultado da epoca 605 = -57031.22 Epsilon = 0.401
# 89
# 130
# resultado da epoca 606 = -42173.62 Epsilon = 0.400
# 88
# 131
# resultado da epoca 607 = -47678.34 Epsilon = 0.399
# 90
# 129
# resultado da epoca 608 = -36688.46 Epsilon = 0.398
# 101
# 118
# resultado da epoca 609 = -46931.26 Epsilon = 0.397
# 94
# 125
# resultado da epoca 610 = -49171.80 Epsilon = 0.396
# 88
# 131
# resultado da epoca 611 = -60157.68 Epsilon = 0.395
# 93
# 126
# resultado da epoca 612 = -65213.40 Epsilon = 0.394
# 91
# 128
# resultado da epoca 613 = -17022.56 Epsilon = 0.393
# 104
# 115
# resultado da epoca 614 = -34025.38 Epsilon = 0.392
# 91
# 128
# resultado da epoca 615 = -40332.64 Epsilon = 0.391
# 102
# 117
# resultado da epoca 616 = -39321.38 Epsilon = 0.390
# 98
# 121
# resultado da epoca 617 = -28818.16 Epsilon = 0.389
# 101
# 118
# resultado da epoca 618 = -52556.54 Epsilon = 0.388
# 94
# 125
# resultado da epoca 619 = -26451.90 Epsilon = 0.387
# 101
# 118
# resultado da epoca 620 = -34722.02 Epsilon = 0.386
# 97
# 122
# resultado da epoca 621 = -43618.70 Epsilon = 0.385
# 93
# 126
# resultado da epoca 622 = -30127.56 Epsilon = 0.384
# 95
# 124
# resultado da epoca 623 = -41517.90 Epsilon = 0.383
# 93
# 126
# resultado da epoca 624 = -16108.68 Epsilon = 0.382
# 109
# 110
# resultado da epoca 625 = -45299.58 Epsilon = 0.381
# 93
# 126
# resultado da epoca 626 = -58115.98 Epsilon = 0.380
# 92
# 127
# resultado da epoca 627 = -46890.04 Epsilon = 0.379
# 84
# 135
# resultado da epoca 628 = -40781.44 Epsilon = 0.378
# 90
# 129
# resultado da epoca 629 = -36674.70 Epsilon = 0.377
# 97
# 122
# resultado da epoca 630 = -39182.26 Epsilon = 0.376
# 90
# 129
# resultado da epoca 631 = -40759.58 Epsilon = 0.375
# 97
# 122
# resultado da epoca 632 = -36554.32 Epsilon = 0.374
# 90
# 129
# resultado da epoca 633 = -42646.42 Epsilon = 0.373
# 85
# 134
# resultado da epoca 634 = -37148.58 Epsilon = 0.372
# 99
# 120
# resultado da epoca 635 = -26485.56 Epsilon = 0.371
# 95
# 124
# resultado da epoca 636 = -46206.92 Epsilon = 0.370
# 96
# 123
# resultado da epoca 637 = -26576.68 Epsilon = 0.369
# 95
# 124
# resultado da epoca 638 = -61573.92 Epsilon = 0.368
# 97
# 122
# resultado da epoca 639 = -48730.22 Epsilon = 0.367
# 95
# 124
# resultado da epoca 640 = -44461.72 Epsilon = 0.366
# 96
# 123
# resultado da epoca 641 = -49376.12 Epsilon = 0.365
# 90
# 129
# resultado da epoca 642 = -24750.46 Epsilon = 0.364
# 101
# 118
# resultado da epoca 643 = -35108.44 Epsilon = 0.363
# 99
# 120
# resultado da epoca 644 = -61565.40 Epsilon = 0.362
# 92
# 127
# resultado da epoca 645 = -4708.40 Epsilon = 0.361
# 104
# 115
# resultado da epoca 646 = -12685.62 Epsilon = 0.360
# 107
# 112
# resultado da epoca 647 = -34887.18 Epsilon = 0.359
# 88
# 131
# resultado da epoca 648 = -41723.72 Epsilon = 0.358
# 90
# 129
# resultado da epoca 649 = -23236.08 Epsilon = 0.357
# 93
# 126
# resultado da epoca 650 = -61792.16 Epsilon = 0.356
# 94
# 125
# resultado da epoca 651 = -67394.26 Epsilon = 0.356
# 87
# 132
# resultado da epoca 652 = -29556.20 Epsilon = 0.355
# 92
# 127
# resultado da epoca 653 = -24064.08 Epsilon = 0.354
# 99
# 120
# resultado da epoca 654 = -34501.14 Epsilon = 0.353
# 95
# 124
# resultado da epoca 655 = -60198.06 Epsilon = 0.352
# 85
# 134
# resultado da epoca 656 = -42181.92 Epsilon = 0.351
# 95
# 124
# resultado da epoca 657 = -38613.66 Epsilon = 0.350
# 100
# 119
# resultado da epoca 658 = -43476.82 Epsilon = 0.349
# 94
# 125
# resultado da epoca 659 = -37038.02 Epsilon = 0.348
# 97
# 122
# resultado da epoca 660 = -46331.58 Epsilon = 0.347
# 95
# 124
# resultado da epoca 661 = -25275.46 Epsilon = 0.346
# 100
# 119
# resultado da epoca 662 = -26872.56 Epsilon = 0.345
# 98
# 121
# resultado da epoca 663 = -49227.30 Epsilon = 0.344
# 95
# 124
# resultado da epoca 664 = -33365.52 Epsilon = 0.343
# 93
# 126
# resultado da epoca 665 = -26282.58 Epsilon = 0.342
# 98
# 121
# resultado da epoca 666 = -42637.86 Epsilon = 0.341
# 93
# 126
# resultado da epoca 667 = -14790.56 Epsilon = 0.340
# 99
# 120
# resultado da epoca 668 = -26836.82 Epsilon = 0.339
# 98
# 121
# resultado da epoca 669 = -35728.22 Epsilon = 0.338
# 95
# 124
# resultado da epoca 670 = -24639.94 Epsilon = 0.337
# 107
# 112
# resultado da epoca 671 = -24160.72 Epsilon = 0.336
# 101
# 118
# resultado da epoca 672 = -13317.06 Epsilon = 0.335
# 102
# 117
# resultado da epoca 673 = -32242.96 Epsilon = 0.334
# 104
# 115
# resultado da epoca 674 = -45793.72 Epsilon = 0.333
# 92
# 127
# resultado da epoca 675 = -42149.78 Epsilon = 0.332
# 104
# 115
# resultado da epoca 676 = -18645.44 Epsilon = 0.331
# 103
# 116
# resultado da epoca 677 = -38264.18 Epsilon = 0.330
# 90
# 129
# resultado da epoca 678 = -8362.18 Epsilon = 0.329
# 99
# 120
# resultado da epoca 679 = -17149.48 Epsilon = 0.328
# 98
# 121
# resultado da epoca 680 = -36161.02 Epsilon = 0.327
# 97
# 122
# resultado da epoca 681 = -58799.64 Epsilon = 0.326
# 86
# 133
# resultado da epoca 682 = -6477.64 Epsilon = 0.325
# 111
# 108
# resultado da epoca 683 = -34631.56 Epsilon = 0.324
# 98
# 121
# resultado da epoca 684 = -36578.46 Epsilon = 0.323
# 102
# 117
# resultado da epoca 685 = -22414.68 Epsilon = 0.322
# 104
# 115
# resultado da epoca 686 = -60252.74 Epsilon = 0.321
# 90
# 129
# resultado da epoca 687 = -18564.82 Epsilon = 0.320
# 100
# 119
# resultado da epoca 688 = -42997.50 Epsilon = 0.319
# 92
# 127
# resultado da epoca 689 = -32243.84 Epsilon = 0.318
# 100
# 119
# resultado da epoca 690 = -21791.62 Epsilon = 0.317
# 111
# 108
# resultado da epoca 691 = -34278.66 Epsilon = 0.316
# 98
# 121
# resultado da epoca 692 = -46147.34 Epsilon = 0.315
# 98
# 121
# resultado da epoca 693 = -1014.18 Epsilon = 0.314
# 103
# 116
# resultado da epoca 694 = -21675.18 Epsilon = 0.313
# 99
# 120
# resultado da epoca 695 = -24392.08 Epsilon = 0.312
# 100
# 119
# resultado da epoca 696 = -41493.72 Epsilon = 0.311
# 102
# 117
# resultado da epoca 697 = -36113.66 Epsilon = 0.310
# 97
# 122
# resultado da epoca 698 = -37076.08 Epsilon = 0.309
# 97
# 122
# resultado da epoca 699 = -41896.72 Epsilon = 0.308
# 98
# 121
# resultado da epoca 700 = -5127.96 Epsilon = 0.307
# 107
# 112
# resultado da epoca 701 = -16625.44 Epsilon = 0.306
# 103
# 116
# resultado da epoca 702 = -43974.70 Epsilon = 0.305
# 101
# 118
# resultado da epoca 703 = -44345.26 Epsilon = 0.304
# 92
# 127
# resultado da epoca 704 = -29833.26 Epsilon = 0.303
# 111
# 108
# resultado da epoca 705 = -23432.18 Epsilon = 0.302
# 102
# 117
# resultado da epoca 706 = -29729.70 Epsilon = 0.301
# 88
# 131
# resultado da epoca 707 = -39320.00 Epsilon = 0.300
# 98
# 121
# resultado da epoca 708 = -40327.24 Epsilon = 0.299
# 99
# 120
# resultado da epoca 709 = -24980.32 Epsilon = 0.298
# 107
# 112
# resultado da epoca 710 = -53406.64 Epsilon = 0.297
# 85
# 134
# resultado da epoca 711 = -41225.40 Epsilon = 0.296
# 98
# 121
# resultado da epoca 712 = -52112.20 Epsilon = 0.295
# 94
# 125
# resultado da epoca 713 = -44833.20 Epsilon = 0.294
# 97
# 122
# resultado da epoca 714 = -56423.48 Epsilon = 0.293
# 89
# 130
# resultado da epoca 715 = -32214.34 Epsilon = 0.292
# 99
# 120
# resultado da epoca 716 = -21297.84 Epsilon = 0.291
# 103
# 116
# resultado da epoca 717 = -52812.54 Epsilon = 0.290
# 91
# 128
# resultado da epoca 718 = -37407.12 Epsilon = 0.289
# 100
# 119
# resultado da epoca 719 = -37337.44 Epsilon = 0.288
# 101
# 118
# resultado da epoca 720 = -30203.76 Epsilon = 0.287
# 103
# 116
# resultado da epoca 721 = -40613.70 Epsilon = 0.286
# 96
# 123
# resultado da epoca 722 = -5305.96 Epsilon = 0.285
# 104
# 115
# resultado da epoca 723 = -34500.74 Epsilon = 0.284
# 98
# 121
# resultado da epoca 724 = -30237.94 Epsilon = 0.283
# 99
# 120
# resultado da epoca 725 = -44493.92 Epsilon = 0.282
# 94
# 125
# resultado da epoca 726 = -17214.44 Epsilon = 0.281
# 107
# 112
# resultado da epoca 727 = -40239.76 Epsilon = 0.280
# 90
# 129
# resultado da epoca 728 = 2709.40 Epsilon = 0.279
# 111
# 108
# resultado da epoca 729 = -37136.82 Epsilon = 0.278
# 99
# 120
# resultado da epoca 730 = -22321.76 Epsilon = 0.277
# 96
# 123
# resultado da epoca 731 = -47723.38 Epsilon = 0.276
# 104
# 115
# resultado da epoca 732 = -30967.48 Epsilon = 0.275
# 92
# 127
# resultado da epoca 733 = -34681.96 Epsilon = 0.274
# 100
# 119
# resultado da epoca 734 = -28186.14 Epsilon = 0.273
# 96
# 123
# resultado da epoca 735 = -25820.74 Epsilon = 0.272
# 98
# 121
# resultado da epoca 736 = -40920.28 Epsilon = 0.271
# 96
# 123
# resultado da epoca 737 = -31105.58 Epsilon = 0.270
# 96
# 123
# resultado da epoca 738 = -10873.32 Epsilon = 0.269
# 104
# 115
# resultado da epoca 739 = -41598.18 Epsilon = 0.268
# 92
# 127
# resultado da epoca 740 = -23541.72 Epsilon = 0.267
# 97
# 122
# resultado da epoca 741 = -19860.06 Epsilon = 0.266
# 101
# 118
# resultado da epoca 742 = -20713.16 Epsilon = 0.265
# 99
# 120
# resultado da epoca 743 = -39519.18 Epsilon = 0.264
# 97
# 122
# resultado da epoca 744 = -50566.86 Epsilon = 0.263
# 97
# 122
# resultado da epoca 745 = -34034.80 Epsilon = 0.262
# 98
# 121
# resultado da epoca 746 = -25929.08 Epsilon = 0.261
# 93
# 126
# resultado da epoca 747 = -17236.42 Epsilon = 0.260
# 104
# 115
# resultado da epoca 748 = -40035.18 Epsilon = 0.259
# 97
# 122
# resultado da epoca 749 = -34350.92 Epsilon = 0.258
# 99
# 120
# resultado da epoca 750 = -25545.04 Epsilon = 0.257
# 98
# 121
# resultado da epoca 751 = -11478.20 Epsilon = 0.257
# 104
# 115
# resultado da epoca 752 = 24349.20 Epsilon = 0.256
# 108
# 111
# resultado da epoca 753 = -44866.46 Epsilon = 0.255
# 93
# 126
# resultado da epoca 754 = 1661.12 Epsilon = 0.254
# 109
# 110
# resultado da epoca 755 = -31338.16 Epsilon = 0.253
# 94
# 125
# resultado da epoca 756 = -42287.42 Epsilon = 0.252
# 97
# 122
# resultado da epoca 757 = -55330.42 Epsilon = 0.251
# 90
# 129
# resultado da epoca 758 = -39349.70 Epsilon = 0.250
# 95
# 124
# resultado da epoca 759 = -32280.30 Epsilon = 0.249
# 101
# 118
# resultado da epoca 760 = -21747.28 Epsilon = 0.248
# 96
# 123
# resultado da epoca 761 = -58494.56 Epsilon = 0.247
# 88
# 131
# resultado da epoca 762 = -21483.34 Epsilon = 0.246
# 106
# 113
# resultado da epoca 763 = -34821.20 Epsilon = 0.245
# 97
# 122
# resultado da epoca 764 = -22072.12 Epsilon = 0.244
# 104
# 115
# resultado da epoca 765 = -5968.20 Epsilon = 0.243
# 108
# 111
# resultado da epoca 766 = -40955.20 Epsilon = 0.242
# 96
# 123
# resultado da epoca 767 = -17896.54 Epsilon = 0.241
# 100
# 119
# resultado da epoca 768 = -8205.86 Epsilon = 0.240
# 111
# 108
# resultado da epoca 769 = -21343.80 Epsilon = 0.239
# 99
# 120
# resultado da epoca 770 = -9117.98 Epsilon = 0.238
# 100
# 119
# resultado da epoca 771 = -23454.40 Epsilon = 0.237
# 101
# 118
# resultado da epoca 772 = -2102.86 Epsilon = 0.236
# 107
# 112
# resultado da epoca 773 = -15223.46 Epsilon = 0.235
# 101
# 118
# resultado da epoca 774 = -17301.08 Epsilon = 0.234
# 108
# 111
# resultado da epoca 775 = -38995.12 Epsilon = 0.233
# 102
# 117
# resultado da epoca 776 = -24259.56 Epsilon = 0.232
# 100
# 119
# resultado da epoca 777 = -39114.36 Epsilon = 0.231
# 96
# 123
# resultado da epoca 778 = -27529.78 Epsilon = 0.230
# 97
# 122
# resultado da epoca 779 = -49058.40 Epsilon = 0.229
# 91
# 128
# resultado da epoca 780 = -38131.80 Epsilon = 0.228
# 99
# 120
# resultado da epoca 781 = -28988.98 Epsilon = 0.227
# 96
# 123
# resultado da epoca 782 = -23417.98 Epsilon = 0.226
# 100
# 119
# resultado da epoca 783 = -21893.48 Epsilon = 0.225
# 103
# 116
# resultado da epoca 784 = -2779.88 Epsilon = 0.224
# 104
# 115
# resultado da epoca 785 = -46960.26 Epsilon = 0.223
# 92
# 127
# resultado da epoca 786 = -21436.68 Epsilon = 0.222
# 99
# 120
# resultado da epoca 787 = -41090.70 Epsilon = 0.221
# 99
# 120
# resultado da epoca 788 = -41207.56 Epsilon = 0.220
# 92
# 127
# resultado da epoca 789 = -31642.32 Epsilon = 0.219
# 96
# 123
# resultado da epoca 790 = -20101.18 Epsilon = 0.218
# 104
# 115
# resultado da epoca 791 = -24732.86 Epsilon = 0.217
# 99
# 120
# resultado da epoca 792 = -34622.16 Epsilon = 0.216
# 103
# 116
# resultado da epoca 793 = -21589.22 Epsilon = 0.215
# 101
# 118
# resultado da epoca 794 = -7806.14 Epsilon = 0.214
# 107
# 112
# resultado da epoca 795 = -12651.24 Epsilon = 0.213
# 98
# 121
# resultado da epoca 796 = -10515.20 Epsilon = 0.212
# 105
# 114
# resultado da epoca 797 = -26952.18 Epsilon = 0.211
# 99
# 120
# resultado da epoca 798 = -34207.88 Epsilon = 0.210
# 90
# 129
# resultado da epoca 799 = -18180.22 Epsilon = 0.209
# 99
# 120
# resultado da epoca 800 = -15578.56 Epsilon = 0.208
# 104
# 115
# resultado da epoca 801 = -21696.90 Epsilon = 0.207
# 101
# 118
# resultado da epoca 802 = -32241.64 Epsilon = 0.206
# 93
# 126
# resultado da epoca 803 = -52066.68 Epsilon = 0.205
# 100
# 119
# resultado da epoca 804 = -23014.46 Epsilon = 0.204
# 103
# 116
# resultado da epoca 805 = -34072.76 Epsilon = 0.203
# 97
# 122
# resultado da epoca 806 = -52475.92 Epsilon = 0.202
# 96
# 123
# resultado da epoca 807 = -23243.40 Epsilon = 0.201
# 102
# 117
# resultado da epoca 808 = -13514.16 Epsilon = 0.200
# 102
# 117
# resultado da epoca 809 = -25975.10 Epsilon = 0.199
# 103
# 116
# resultado da epoca 810 = -31320.70 Epsilon = 0.198
# 94
# 125
# resultado da epoca 811 = -15296.26 Epsilon = 0.197
# 100
# 119
# resultado da epoca 812 = -6497.86 Epsilon = 0.196
# 102
# 117
# resultado da epoca 813 = -22804.74 Epsilon = 0.195
# 96
# 123
# resultado da epoca 814 = -11774.44 Epsilon = 0.194
# 98
# 121
# resultado da epoca 815 = -16948.44 Epsilon = 0.193
# 100
# 119
# resultado da epoca 816 = -18562.00 Epsilon = 0.192
# 103
# 116
# resultado da epoca 817 = -24970.58 Epsilon = 0.191
# 97
# 122
# resultado da epoca 818 = -9425.46 Epsilon = 0.190
# 108
# 111
# resultado da epoca 819 = -52306.64 Epsilon = 0.189
# 99
# 120
# resultado da epoca 820 = -27581.64 Epsilon = 0.188
# 101
# 118
# resultado da epoca 821 = -37000.54 Epsilon = 0.187
# 99
# 120
# resultado da epoca 822 = -38116.54 Epsilon = 0.186
# 99
# 120
# resultado da epoca 823 = -19417.00 Epsilon = 0.185
# 97
# 122
# resultado da epoca 824 = -18273.14 Epsilon = 0.184
# 98
# 121
# resultado da epoca 825 = -33259.44 Epsilon = 0.183
# 96
# 123
# resultado da epoca 826 = -19124.56 Epsilon = 0.182
# 106
# 113
# resultado da epoca 827 = -20930.78 Epsilon = 0.181
# 105
# 114
# resultado da epoca 828 = -26223.90 Epsilon = 0.180
# 102
# 117
# resultado da epoca 829 = -26046.02 Epsilon = 0.179
# 102
# 117
# resultado da epoca 830 = -6388.74 Epsilon = 0.178
# 101
# 118
# resultado da epoca 831 = -48738.24 Epsilon = 0.177
# 88
# 131
# resultado da epoca 832 = -21164.88 Epsilon = 0.176
# 102
# 117
# resultado da epoca 833 = -16042.48 Epsilon = 0.175
# 106
# 113
# resultado da epoca 834 = -27551.92 Epsilon = 0.174
# 96
# 123
# resultado da epoca 835 = -30238.22 Epsilon = 0.173
# 96
# 123
# resultado da epoca 836 = -23396.32 Epsilon = 0.172
# 96
# 123
# resultado da epoca 837 = -20530.40 Epsilon = 0.171
# 97
# 122
# resultado da epoca 838 = -22404.64 Epsilon = 0.170
# 102
# 117
# resultado da epoca 839 = -12001.48 Epsilon = 0.169
# 101
# 118
# resultado da epoca 840 = -35428.60 Epsilon = 0.168
# 97
# 122
# resultado da epoca 841 = -24972.02 Epsilon = 0.167
# 94
# 125
# resultado da epoca 842 = -18731.84 Epsilon = 0.166
# 101
# 118
# resultado da epoca 843 = -44508.86 Epsilon = 0.165
# 93
# 126
# resultado da epoca 844 = -11975.40 Epsilon = 0.164
# 99
# 120
# resultado da epoca 845 = -15470.98 Epsilon = 0.163
# 98
# 121
# resultado da epoca 846 = -27991.42 Epsilon = 0.162
# 95
# 124
# resultado da epoca 847 = -21970.56 Epsilon = 0.161
# 106
# 113
# resultado da epoca 848 = -27947.54 Epsilon = 0.160
# 94
# 125
# resultado da epoca 849 = -28289.00 Epsilon = 0.159
# 105
# 114
# resultado da epoca 850 = -25205.38 Epsilon = 0.158
# 91
# 128
# resultado da epoca 851 = -16207.80 Epsilon = 0.158
# 97
# 122
# resultado da epoca 852 = -14473.98 Epsilon = 0.157
# 103
# 116
# resultado da epoca 853 = -19255.96 Epsilon = 0.156
# 100
# 119
# resultado da epoca 854 = 4950.86 Epsilon = 0.155
# 101
# 118
# resultado da epoca 855 = -12759.24 Epsilon = 0.154
# 106
# 113
# resultado da epoca 856 = -28172.70 Epsilon = 0.153
# 98
# 121
# resultado da epoca 857 = -11080.56 Epsilon = 0.152
# 95
# 124
# resultado da epoca 858 = -28433.88 Epsilon = 0.151
# 94
# 125
# resultado da epoca 859 = -19112.22 Epsilon = 0.150
# 102
# 117
# resultado da epoca 860 = 4129.24 Epsilon = 0.149
# 111
# 108
# resultado da epoca 861 = -42588.58 Epsilon = 0.148
# 105
# 114
# resultado da epoca 862 = -17150.64 Epsilon = 0.147
# 98
# 121
# resultado da epoca 863 = -7197.12 Epsilon = 0.146
# 104
# 115
# resultado da epoca 864 = -20449.54 Epsilon = 0.145
# 105
# 114
# resultado da epoca 865 = -353.66 Epsilon = 0.144
# 112
# 107
# resultado da epoca 866 = -23339.24 Epsilon = 0.143
# 97
# 122
# resultado da epoca 867 = -16972.20 Epsilon = 0.142
# 107
# 112
# resultado da epoca 868 = -14729.40 Epsilon = 0.141
# 99
# 120
# resultado da epoca 869 = -18211.78 Epsilon = 0.140
# 106
# 113
# resultado da epoca 870 = -20202.34 Epsilon = 0.139
# 103
# 116
# resultado da epoca 871 = -15528.02 Epsilon = 0.138
# 104
# 115
# resultado da epoca 872 = -21789.78 Epsilon = 0.137
# 100
# 119
# resultado da epoca 873 = -32534.68 Epsilon = 0.136
# 96
# 123
# resultado da epoca 874 = -23109.12 Epsilon = 0.135
# 97
# 122
# resultado da epoca 875 = -18470.16 Epsilon = 0.134
# 96
# 123
# resultado da epoca 876 = -16761.02 Epsilon = 0.133
# 100
# 119
# resultado da epoca 877 = -17916.12 Epsilon = 0.132
# 98
# 121
# resultado da epoca 878 = -15157.76 Epsilon = 0.131
# 102
# 117
# resultado da epoca 879 = -23118.74 Epsilon = 0.130
# 100
# 119
# resultado da epoca 880 = -28068.36 Epsilon = 0.129
# 99
# 120
# resultado da epoca 881 = -29722.60 Epsilon = 0.128
# 96
# 123
# resultado da epoca 882 = -4798.78 Epsilon = 0.127
# 103
# 116
# resultado da epoca 883 = -24223.28 Epsilon = 0.126
# 102
# 117
# resultado da epoca 884 = -21085.96 Epsilon = 0.125
# 104
# 115
# resultado da epoca 885 = -2882.44 Epsilon = 0.124
# 108
# 111
# resultado da epoca 886 = -17107.46 Epsilon = 0.123
# 99
# 120
# resultado da epoca 887 = -23671.02 Epsilon = 0.122
# 97
# 122
# resultado da epoca 888 = -10473.12 Epsilon = 0.121
# 99
# 120
# resultado da epoca 889 = 7589.60 Epsilon = 0.120
# 109
# 110
# resultado da epoca 890 = -7591.24 Epsilon = 0.119
# 101
# 118
# resultado da epoca 891 = -21263.46 Epsilon = 0.118
# 99
# 120
# resultado da epoca 892 = -25903.62 Epsilon = 0.117
# 102
# 117
# resultado da epoca 893 = -2563.00 Epsilon = 0.116
# 103
# 116
# resultado da epoca 894 = -11180.80 Epsilon = 0.115
# 101
# 118
# resultado da epoca 895 = -9152.22 Epsilon = 0.114
# 107
# 112
# resultado da epoca 896 = -21850.82 Epsilon = 0.113
# 96
# 123
# resultado da epoca 897 = -25623.94 Epsilon = 0.112
# 96
# 123
# resultado da epoca 898 = -9674.48 Epsilon = 0.111
# 107
# 112
# resultado da epoca 899 = -11915.30 Epsilon = 0.110
# 101
# 118
# resultado da epoca 900 = -24459.94 Epsilon = 0.109
# 103
# 116
# resultado da epoca 901 = -16067.84 Epsilon = 0.108
# 98
# 121
# resultado da epoca 902 = -8630.56 Epsilon = 0.107
# 96
# 123
# resultado da epoca 903 = -18422.98 Epsilon = 0.106
# 100
# 119
# resultado da epoca 904 = -18211.38 Epsilon = 0.105
# 100
# 119
# resultado da epoca 905 = -11671.56 Epsilon = 0.104
# 104
# 115
# resultado da epoca 906 = -771.54 Epsilon = 0.103
# 104
# 115
# resultado da epoca 907 = -6895.36 Epsilon = 0.102
# 105
# 114
# resultado da epoca 908 = -15524.08 Epsilon = 0.101
# 100
# 119
# resultado da epoca 909 = -4700.08 Epsilon = 0.100
# 107
# 112
# resultado da epoca 910 = -11405.38 Epsilon = 0.099
# 99
# 120
# resultado da epoca 911 = -11795.62 Epsilon = 0.098
# 97
# 122
# resultado da epoca 912 = -26675.94 Epsilon = 0.097
# 92
# 127
# resultado da epoca 913 = -19857.18 Epsilon = 0.096
# 103
# 116
# resultado da epoca 914 = -9398.36 Epsilon = 0.095
# 100
# 119
# resultado da epoca 915 = -25574.04 Epsilon = 0.094
# 104
# 115
# resultado da epoca 916 = -1086.44 Epsilon = 0.093
# 105
# 114
# resultado da epoca 917 = -11274.68 Epsilon = 0.092
# 103
# 116
# resultado da epoca 918 = -12082.04 Epsilon = 0.091
# 107
# 112
# resultado da epoca 919 = -12623.58 Epsilon = 0.090
# 96
# 123
# resultado da epoca 920 = -22346.46 Epsilon = 0.089
# 102
# 117
# resultado da epoca 921 = 2156.20 Epsilon = 0.088
# 107
# 112
# resultado da epoca 922 = -18997.18 Epsilon = 0.087
# 100
# 119
# resultado da epoca 923 = -9755.00 Epsilon = 0.086
# 100
# 119
# resultado da epoca 924 = -14400.46 Epsilon = 0.085
# 97
# 122
# resultado da epoca 925 = -9605.18 Epsilon = 0.084
# 100
# 119
# resultado da epoca 926 = -2101.72 Epsilon = 0.083
# 100
# 119
# resultado da epoca 927 = -14345.42 Epsilon = 0.082
# 106
# 113
# resultado da epoca 928 = -16891.46 Epsilon = 0.081
# 101
# 118
# resultado da epoca 929 = -20464.90 Epsilon = 0.080
# 101
# 118
# resultado da epoca 930 = -30187.34 Epsilon = 0.079
# 102
# 117
# resultado da epoca 931 = -10396.44 Epsilon = 0.078
# 100
# 119
# resultado da epoca 932 = -15303.90 Epsilon = 0.077
# 103
# 116
# resultado da epoca 933 = -14816.92 Epsilon = 0.076
# 103
# 116
# resultado da epoca 934 = -10008.14 Epsilon = 0.075
# 102
# 117
# resultado da epoca 935 = -20255.70 Epsilon = 0.074
# 97
# 122
# resultado da epoca 936 = -6021.94 Epsilon = 0.073
# 105
# 114
# resultado da epoca 937 = -20215.00 Epsilon = 0.072
# 96
# 123
# resultado da epoca 938 = -18402.28 Epsilon = 0.071
# 101
# 118
# resultado da epoca 939 = -16984.66 Epsilon = 0.070
# 100
# 119
# resultado da epoca 940 = -19557.70 Epsilon = 0.069
# 101
# 118
# resultado da epoca 941 = -8543.08 Epsilon = 0.068
# 101
# 118
# resultado da epoca 942 = -14570.54 Epsilon = 0.067
# 98
# 121
# resultado da epoca 943 = -17894.60 Epsilon = 0.066
# 97
# 122
# resultado da epoca 944 = -6758.86 Epsilon = 0.065
# 101
# 118
# resultado da epoca 945 = -11140.60 Epsilon = 0.064
# 99
# 120
# resultado da epoca 946 = -15021.74 Epsilon = 0.063
# 99
# 120
# resultado da epoca 947 = -14359.52 Epsilon = 0.062
# 106
# 113
# resultado da epoca 948 = -6730.24 Epsilon = 0.061
# 102
# 117
# resultado da epoca 949 = -6155.40 Epsilon = 0.060
# 108
# 111
# resultado da epoca 950 = 2248.68 Epsilon = 0.059
# 100
# 119
# resultado da epoca 951 = -5776.74 Epsilon = 0.059
# 99
# 120
# resultado da epoca 952 = 1330.10 Epsilon = 0.058
# 99
# 120
# resultado da epoca 953 = -8636.24 Epsilon = 0.057
# 100
# 119
# resultado da epoca 954 = -19240.86 Epsilon = 0.056
# 101
# 118
# resultado da epoca 955 = -21268.82 Epsilon = 0.055
# 94
# 125
# resultado da epoca 956 = -13500.56 Epsilon = 0.054
# 96
# 123
# resultado da epoca 957 = -12421.30 Epsilon = 0.053
# 101
# 118
# resultado da epoca 958 = -17379.96 Epsilon = 0.052
# 93
# 126
# resultado da epoca 959 = -13086.56 Epsilon = 0.051
# 96
# 123
# resultado da epoca 960 = -14700.92 Epsilon = 0.050
# 103
# 116
# resultado da epoca 961 = -21474.70 Epsilon = 0.049
# 98
# 121
# resultado da epoca 962 = -643.70 Epsilon = 0.048
# 97
# 122
# resultado da epoca 963 = -14301.66 Epsilon = 0.047
# 98
# 121
# resultado da epoca 964 = 3512.00 Epsilon = 0.046
# 99
# 120
# resultado da epoca 965 = 9119.10 Epsilon = 0.045
# 105
# 114
# resultado da epoca 966 = -18040.20 Epsilon = 0.044
# 97
# 122
# resultado da epoca 967 = -9990.64 Epsilon = 0.043
# 99
# 120
# resultado da epoca 968 = -4924.82 Epsilon = 0.042
# 102
# 117
# resultado da epoca 969 = -7661.78 Epsilon = 0.041
# 101
# 118
# resultado da epoca 970 = -10789.80 Epsilon = 0.040
# 101
# 118
# resultado da epoca 971 = -10681.52 Epsilon = 0.039
# 98
# 121
# resultado da epoca 972 = -17505.52 Epsilon = 0.038
# 97
# 122
# resultado da epoca 973 = -10182.22 Epsilon = 0.037
# 99
# 120
# resultado da epoca 974 = -7339.78 Epsilon = 0.036
# 98
# 121
# resultado da epoca 975 = -3003.78 Epsilon = 0.035
# 101
# 118
# resultado da epoca 976 = -4918.88 Epsilon = 0.034
# 100
# 119
# resultado da epoca 977 = -10658.54 Epsilon = 0.033
# 98
# 121
# resultado da epoca 978 = -12327.34 Epsilon = 0.032
# 101
# 118
# resultado da epoca 979 = -15027.46 Epsilon = 0.031
# 95
# 124
# resultado da epoca 980 = -2862.80 Epsilon = 0.030
# 101
# 118
# resultado da epoca 981 = -5812.98 Epsilon = 0.029
# 96
# 123
# resultado da epoca 982 = -8517.06 Epsilon = 0.028
# 100
# 119
# resultado da epoca 983 = 978.20 Epsilon = 0.027
# 98
# 121
# resultado da epoca 984 = -5701.56 Epsilon = 0.026
# 96
# 123
# resultado da epoca 985 = -17056.64 Epsilon = 0.025
# 98
# 121
# resultado da epoca 986 = -5292.30 Epsilon = 0.024
# 100
# 119
# resultado da epoca 987 = -9842.26 Epsilon = 0.023
# 100
# 119
# resultado da epoca 988 = -9638.00 Epsilon = 0.022
# 99
# 120
# resultado da epoca 989 = -14441.58 Epsilon = 0.021
# 94
# 125
# resultado da epoca 990 = -5702.82 Epsilon = 0.020
# 97
# 122
# resultado da epoca 991 = -6704.98 Epsilon = 0.019
# 97
# 122
# resultado da epoca 992 = -8878.44 Epsilon = 0.018
# 96
# 123
# resultado da epoca 993 = -7653.90 Epsilon = 0.017
# 94
# 125
# resultado da epoca 994 = -4685.26 Epsilon = 0.016
# 97
# 122
# resultado da epoca 995 = -3000.02 Epsilon = 0.015
# 95
# 124
# resultado da epoca 996 = -1443.00 Epsilon = 0.014
# 100
# 119
# resultado da epoca 997 = -5332.64 Epsilon = 0.013
# 99
# 120
# resultado da epoca 998 = -4364.32 Epsilon = 0.012
# 96
# 123
# resultado da epoca 999 = -6923.34 Epsilon = 0.011
# 97
# 122
# resultado da epoca 1000 = -932.76 Epsilon = 0.010
# 95
# 124
# resultado da epoca 1001 = -8859.94 Epsilon = 0.010
# 97
# 122
# resultado da epoca 1002 = -3265.72 Epsilon = 0.010
# 96
# 123
# resultado da epoca 1003 = -9531.14 Epsilon = 0.010
# 98
# 121
# resultado da epoca 1004 = -4400.92 Epsilon = 0.010
# 98
# 121
# 0
# 0
# Melhor resultado diario: 7872.98
