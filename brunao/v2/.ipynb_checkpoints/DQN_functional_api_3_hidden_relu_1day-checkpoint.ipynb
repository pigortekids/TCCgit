# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
n_mercado = n_variaveis*janela #inputs
n_estados = 2 #ncont e valor
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 1

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0

for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Model
from keras.layers import Dense, Input, concatenate
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, mkt_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.mkt_size = mkt_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        #inputs
        x1 = Input(shape=(self.state_size,))
        x2 = Input(shape=(self.mkt_size,))
        
        #state hidden layers
        a1 = Dense(320)(x1)
        a2 = Dense(256)(a1)
        a3 = Dense(256)(a2)
        
        #mkt hidden layers
        b1 = Dense(320)(x2)
        b2 = Dense(256)(b1)
        b3 = Dense(256)(b2)
        
        #concatenacao
        x12 = concatenate([a3, b3], axis=-1)
        
        #camada de saida
        y = Dense(self.action_size, activation='linear')(x12)
        
        model = Model(inputs=[x1, x2], outputs=y)
        
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(self.mkt_size)
        self.prox_janela_precos = np.zeros(self.mkt_size)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict([self.state, self.janela_precos]) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x1 = np.zeros((batch_size, self.state_size))
        x2 = np.zeros((batch_size, self.mkt_size))
        y = np.zeros((batch_size, self.action_size))
        i = 0
        for acao, reward, estado, mercado, prox_estado, prox_mercado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict([prox_estado, prox_mercado])[0])) #pega valor que quer chegar

            target_f = self.model.predict([estado, mercado]) #pega valor que chegou
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x1[i,:] = estado
            x2[i,:] = mercado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit([x1, x2], y, epochs=1, verbose=0) #treina modelo
            
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.janela_precos, self.next_state, self.prox_janela_precos, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_estados, n_mercado, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 320)          960         input_7[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 320)          6720        input_8[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 256)          82176       dense_22[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 256)          82176       dense_25[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 256)          65792       dense_23[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 256)          65792       dense_26[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512)          0           dense_24[0][0]
#                                                                  dense_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 11)           5643        concatenate_4[0][0]
# ==================================================================================================
# Total params: 309,259
# Trainable params: 309,259
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.reshape(np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l]), (1,modelo.mkt_size))
        modelo.state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        
        acao = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l]),(1,modelo.mkt_size))
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]),(1,modelo.mkt_size))
        
        modelo.next_state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        modelo.remember(acao, posicao/posicao_max, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    lucro += posicao

    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 0, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+5): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos2.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# resultado da epoca 0 = 403.44 Epsilon = 1.000
# 1
# 0
# resultado da epoca 1 = 363.60 Epsilon = 0.999
# 1
# 0
# resultado da epoca 2 = -462.46 Epsilon = 0.998
# 0
# 1
# resultado da epoca 3 = -683.98 Epsilon = 0.997
# 0
# 1
# resultado da epoca 4 = 683.60 Epsilon = 0.996
# 1
# 0
# resultado da epoca 5 = -1163.22 Epsilon = 0.995
# 0
# 1
# resultado da epoca 6 = -444.14 Epsilon = 0.994
# 0
# 1
# resultado da epoca 7 = -2054.42 Epsilon = 0.993
# 0
# 1
# resultado da epoca 8 = 735.10 Epsilon = 0.992
# 1
# 0
# resultado da epoca 9 = -409.42 Epsilon = 0.991
# 0
# 1
# resultado da epoca 10 = 1721.92 Epsilon = 0.990
# 1
# 0
# resultado da epoca 11 = -83.04 Epsilon = 0.989
# 0
# 1
# resultado da epoca 12 = 42.08 Epsilon = 0.988
# 1
# 0
# resultado da epoca 13 = 1291.78 Epsilon = 0.987
# 1
# 0
# resultado da epoca 14 = -884.28 Epsilon = 0.986
# 0
# 1
# resultado da epoca 15 = 103.90 Epsilon = 0.985
# 1
# 0
# resultado da epoca 16 = -1647.92 Epsilon = 0.984
# 0
# 1
# resultado da epoca 17 = -122.30 Epsilon = 0.983
# 0
# 1
# resultado da epoca 18 = -253.52 Epsilon = 0.982
# 0
# 1
# resultado da epoca 19 = -978.68 Epsilon = 0.981
# 0
# 1
# resultado da epoca 20 = 446.48 Epsilon = 0.980
# 1
# 0
# resultado da epoca 21 = 592.10 Epsilon = 0.979
# 1
# 0
# resultado da epoca 22 = -855.50 Epsilon = 0.978
# 0
# 1
# resultado da epoca 23 = -921.70 Epsilon = 0.977
# 0
# 1
# resultado da epoca 24 = -935.32 Epsilon = 0.976
# 0
# 1
# resultado da epoca 25 = -673.82 Epsilon = 0.975
# 0
# 1
# resultado da epoca 26 = 310.42 Epsilon = 0.974
# 1
# 0
# resultado da epoca 27 = 24.34 Epsilon = 0.973
# 1
# 0
# resultado da epoca 28 = -204.26 Epsilon = 0.972
# 0
# 1
# resultado da epoca 29 = 240.56 Epsilon = 0.971
# 1
# 0
# resultado da epoca 30 = -1067.76 Epsilon = 0.970
# 0
# 1
# resultado da epoca 31 = -89.42 Epsilon = 0.969
# 0
# 1
# resultado da epoca 32 = -615.18 Epsilon = 0.968
# 0
# 1
# resultado da epoca 33 = -1303.52 Epsilon = 0.967
# 0
# 1
# resultado da epoca 34 = 478.14 Epsilon = 0.966
# 1
# 0
# resultado da epoca 35 = -520.64 Epsilon = 0.965
# 0
# 1
# resultado da epoca 36 = -1508.36 Epsilon = 0.964
# 0
# 1
# resultado da epoca 37 = 1750.12 Epsilon = 0.963
# 1
# 0
# resultado da epoca 38 = 1239.06 Epsilon = 0.962
# 1
# 0
# resultado da epoca 39 = -988.82 Epsilon = 0.961
# 0
# 1
# resultado da epoca 40 = 876.80 Epsilon = 0.960
# 1
# 0
# resultado da epoca 41 = -715.80 Epsilon = 0.959
# 0
# 1
# resultado da epoca 42 = -2118.52 Epsilon = 0.958
# 0
# 1
# resultado da epoca 43 = -72.00 Epsilon = 0.957
# 0
# 1
# resultado da epoca 44 = -363.66 Epsilon = 0.956
# 0
# 1
# resultado da epoca 45 = -336.24 Epsilon = 0.955
# 0
# 1
# resultado da epoca 46 = 1245.12 Epsilon = 0.954
# 1
# 0
# resultado da epoca 47 = -525.48 Epsilon = 0.953
# 0
# 1
# resultado da epoca 48 = -804.58 Epsilon = 0.952
# 0
# 1
# resultado da epoca 49 = -774.26 Epsilon = 0.951
# 0
# 1
# resultado da epoca 50 = 1256.18 Epsilon = 0.950
# 1
# 0
# resultado da epoca 51 = -183.52 Epsilon = 0.950
# 0
# 1
# resultado da epoca 52 = -77.46 Epsilon = 0.949
# 0
# 1
# resultado da epoca 53 = -1504.28 Epsilon = 0.948
# 0
# 1
# resultado da epoca 54 = -561.54 Epsilon = 0.947
# 0
# 1
# resultado da epoca 55 = -29.12 Epsilon = 0.946
# 0
# 1
# resultado da epoca 56 = -668.52 Epsilon = 0.945
# 0
# 1
# resultado da epoca 57 = -779.88 Epsilon = 0.944
# 0
# 1
# resultado da epoca 58 = 791.20 Epsilon = 0.943
# 1
# 0
# resultado da epoca 59 = 982.54 Epsilon = 0.942
# 1
# 0
# resultado da epoca 60 = 550.12 Epsilon = 0.941
# 1
# 0
# resultado da epoca 61 = 68.60 Epsilon = 0.940
# 1
# 0
# resultado da epoca 62 = -1599.28 Epsilon = 0.939
# 0
# 1
# resultado da epoca 63 = 467.22 Epsilon = 0.938
# 1
# 0
# resultado da epoca 64 = -158.82 Epsilon = 0.937
# 0
# 1
# resultado da epoca 65 = -356.08 Epsilon = 0.936
# 0
# 1
# resultado da epoca 66 = -575.04 Epsilon = 0.935
# 0
# 1
# resultado da epoca 67 = 1451.18 Epsilon = 0.934
# 1
# 0
# resultado da epoca 68 = -73.08 Epsilon = 0.933
# 0
# 1
# resultado da epoca 69 = -646.70 Epsilon = 0.932
# 0
# 1
# resultado da epoca 70 = -954.28 Epsilon = 0.931
# 0
# 1
# resultado da epoca 71 = -570.48 Epsilon = 0.930
# 0
# 1
# resultado da epoca 72 = -881.10 Epsilon = 0.929
# 0
# 1
# resultado da epoca 73 = -1283.66 Epsilon = 0.928
# 0
# 1
# resultado da epoca 74 = -1773.82 Epsilon = 0.927
# 0
# 1
# resultado da epoca 75 = 4.36 Epsilon = 0.926
# 1
# 0
# resultado da epoca 76 = 271.02 Epsilon = 0.925
# 1
# 0
# resultado da epoca 77 = -989.58 Epsilon = 0.924
# 0
# 1
# resultado da epoca 78 = -1399.42 Epsilon = 0.923
# 0
# 1
# resultado da epoca 79 = -776.10 Epsilon = 0.922
# 0
# 1
# resultado da epoca 80 = 1464.36 Epsilon = 0.921
# 1
# 0
# resultado da epoca 81 = 394.96 Epsilon = 0.920
# 1
# 0
# resultado da epoca 82 = -67.46 Epsilon = 0.919
# 0
# 1
# resultado da epoca 83 = 169.36 Epsilon = 0.918
# 1
# 0
# resultado da epoca 84 = -1134.58 Epsilon = 0.917
# 0
# 1
# resultado da epoca 85 = 823.46 Epsilon = 0.916
# 1
# 0
# resultado da epoca 86 = -352.78 Epsilon = 0.915
# 0
# 1
# resultado da epoca 87 = -633.20 Epsilon = 0.914
# 0
# 1
# resultado da epoca 88 = 353.16 Epsilon = 0.913
# 1
# 0
# resultado da epoca 89 = -285.18 Epsilon = 0.912
# 0
# 1
# resultado da epoca 90 = -1598.82 Epsilon = 0.911
# 0
# 1
# resultado da epoca 91 = -873.52 Epsilon = 0.910
# 0
# 1
# resultado da epoca 92 = -653.36 Epsilon = 0.909
# 0
# 1
# resultado da epoca 93 = -436.54 Epsilon = 0.908
# 0
# 1
# resultado da epoca 94 = -2051.84 Epsilon = 0.907
# 0
# 1
# resultado da epoca 95 = 48.76 Epsilon = 0.906
# 1
# 0
# resultado da epoca 96 = 251.48 Epsilon = 0.905
# 1
# 0
# resultado da epoca 97 = -989.26 Epsilon = 0.904
# 0
# 1
# resultado da epoca 98 = -183.06 Epsilon = 0.903
# 0
# 1
# resultado da epoca 99 = -1256.68 Epsilon = 0.902
# 0
# 1
# resultado da epoca 100 = -117.14 Epsilon = 0.901
# 0
# 1
# resultado da epoca 101 = -1385.50 Epsilon = 0.900
# 0
# 1
# resultado da epoca 102 = -806.24 Epsilon = 0.899
# 0
# 1
# resultado da epoca 103 = -2067.76 Epsilon = 0.898
# 0
# 1
# resultado da epoca 104 = -14.28 Epsilon = 0.897
# 0
# 1
# resultado da epoca 105 = -73.84 Epsilon = 0.896
# 0
# 1
# resultado da epoca 106 = -969.28 Epsilon = 0.895
# 0
# 1
# resultado da epoca 107 = -1076.38 Epsilon = 0.894
# 0
# 1
# resultado da epoca 108 = -992.76 Epsilon = 0.893
# 0
# 1
# resultado da epoca 109 = -504.58 Epsilon = 0.892
# 0
# 1
# resultado da epoca 110 = -1231.10 Epsilon = 0.891
# 0
# 1
# resultado da epoca 111 = 932.84 Epsilon = 0.890
# 1
# 0
# resultado da epoca 112 = 781.64 Epsilon = 0.889
# 1
# 0
# resultado da epoca 113 = -452.76 Epsilon = 0.888
# 0
# 1
# resultado da epoca 114 = 564.22 Epsilon = 0.887
# 1
# 0
# resultado da epoca 115 = 33.46 Epsilon = 0.886
# 1
# 0
# resultado da epoca 116 = 1137.40 Epsilon = 0.885
# 1
# 0
# resultado da epoca 117 = -1345.48 Epsilon = 0.884
# 0
# 1
# resultado da epoca 118 = 371.64 Epsilon = 0.883
# 1
# 0
# resultado da epoca 119 = -847.76 Epsilon = 0.882
# 0
# 1
# resultado da epoca 120 = -1446.24 Epsilon = 0.881
# 0
# 1
# resultado da epoca 121 = -1123.68 Epsilon = 0.880
# 0
# 1
# resultado da epoca 122 = -360.48 Epsilon = 0.879
# 0
# 1
# resultado da epoca 123 = -568.82 Epsilon = 0.878
# 0
# 1
# resultado da epoca 124 = -631.10 Epsilon = 0.877
# 0
# 1
# resultado da epoca 125 = -766.22 Epsilon = 0.876
# 0
# 1
# resultado da epoca 126 = -143.98 Epsilon = 0.875
# 0
# 1
# resultado da epoca 127 = 1850.26 Epsilon = 0.874
# 1
# 0
# resultado da epoca 128 = -1432.46 Epsilon = 0.873
# 0
# 1
# resultado da epoca 129 = 369.96 Epsilon = 0.872
# 1
# 0
# resultado da epoca 130 = 498.00 Epsilon = 0.871
# 1
# 0
# resultado da epoca 131 = -1255.48 Epsilon = 0.870
# 0
# 1
# resultado da epoca 132 = -23.98 Epsilon = 0.869
# 0
# 1
# resultado da epoca 133 = 824.06 Epsilon = 0.868
# 1
# 0
# resultado da epoca 134 = -15.04 Epsilon = 0.867
# 0
# 1
# resultado da epoca 135 = -160.18 Epsilon = 0.866
# 0
# 1
# resultado da epoca 136 = -337.14 Epsilon = 0.865
# 0
# 1
# resultado da epoca 137 = -269.74 Epsilon = 0.864
# 0
# 1
# resultado da epoca 138 = -1454.56 Epsilon = 0.863
# 0
# 1
# resultado da epoca 139 = -340.80 Epsilon = 0.862
# 0
# 1
# resultado da epoca 140 = 617.40 Epsilon = 0.861
# 1
# 0
# resultado da epoca 141 = 2528.90 Epsilon = 0.860
# 1
# 0
# resultado da epoca 142 = 1199.98 Epsilon = 0.859
# 1
# 0
# resultado da epoca 143 = -764.88 Epsilon = 0.858
# 0
# 1
# resultado da epoca 144 = 379.80 Epsilon = 0.857
# 1
# 0
# resultado da epoca 145 = 98.44 Epsilon = 0.856
# 1
# 0
# resultado da epoca 146 = 861.18 Epsilon = 0.855
# 1
# 0
# resultado da epoca 147 = 1112.54 Epsilon = 0.854
# 1
# 0
# resultado da epoca 148 = 1388.90 Epsilon = 0.853
# 1
# 0
# resultado da epoca 149 = -9.58 Epsilon = 0.852
# 0
# 1
# resultado da epoca 150 = 992.68 Epsilon = 0.851
# 1
# 0
# resultado da epoca 151 = -189.26 Epsilon = 0.851
# 0
# 1
# resultado da epoca 152 = -148.82 Epsilon = 0.850
# 0
# 1
# resultado da epoca 153 = 694.82 Epsilon = 0.849
# 1
# 0
# resultado da epoca 154 = 395.26 Epsilon = 0.848
# 1
# 0
# resultado da epoca 155 = -2115.34 Epsilon = 0.847
# 0
# 1
# resultado da epoca 156 = -397.00 Epsilon = 0.846
# 0
# 1
# resultado da epoca 157 = 474.34 Epsilon = 0.845
# 1
# 0
# resultado da epoca 158 = -121.70 Epsilon = 0.844
# 0
# 1
# resultado da epoca 159 = 66.94 Epsilon = 0.843
# 1
# 0
# resultado da epoca 160 = -145.62 Epsilon = 0.842
# 0
# 1
# resultado da epoca 161 = 413.00 Epsilon = 0.841
# 1
# 0
# resultado da epoca 162 = 1009.52 Epsilon = 0.840
# 1
# 0
# resultado da epoca 163 = -1184.12 Epsilon = 0.839
# 0
# 1
# resultado da epoca 164 = 714.98 Epsilon = 0.838
# 1
# 0
# resultado da epoca 165 = 257.38 Epsilon = 0.837
# 1
# 0
# resultado da epoca 166 = 1453.90 Epsilon = 0.836
# 1
# 0
# resultado da epoca 167 = -1043.98 Epsilon = 0.835
# 0
# 1
# resultado da epoca 168 = -1567.60 Epsilon = 0.834
# 0
# 1
# resultado da epoca 169 = 1493.60 Epsilon = 0.833
# 1
# 0
# resultado da epoca 170 = -930.04 Epsilon = 0.832
# 0
# 1
# resultado da epoca 171 = 645.86 Epsilon = 0.831
# 1
# 0
# resultado da epoca 172 = 150.12 Epsilon = 0.830
# 1
# 0
# resultado da epoca 173 = 234.38 Epsilon = 0.829
# 1
# 0
# resultado da epoca 174 = -871.24 Epsilon = 0.828
# 0
# 1
# resultado da epoca 175 = 383.46 Epsilon = 0.827
# 1
# 0
# resultado da epoca 176 = -1547.30 Epsilon = 0.826
# 0
# 1
# resultado da epoca 177 = -1053.96 Epsilon = 0.825
# 0
# 1
# resultado da epoca 178 = 167.08 Epsilon = 0.824
# 1
# 0
# resultado da epoca 179 = 213.62 Epsilon = 0.823
# 1
# 0
# resultado da epoca 180 = 1416.34 Epsilon = 0.822
# 1
# 0
# resultado da epoca 181 = -1087.76 Epsilon = 0.821
# 0
# 1
# resultado da epoca 182 = 734.38 Epsilon = 0.820
# 1
# 0
# resultado da epoca 183 = -133.22 Epsilon = 0.819
# 0
# 1
# resultado da epoca 184 = 451.04 Epsilon = 0.818
# 1
# 0
# resultado da epoca 185 = 538.46 Epsilon = 0.817
# 1
# 0
# resultado da epoca 186 = -1997.44 Epsilon = 0.816
# 0
# 1
# resultado da epoca 187 = 678.62 Epsilon = 0.815
# 1
# 0
# resultado da epoca 188 = -250.80 Epsilon = 0.814
# 0
# 1
# resultado da epoca 189 = 1351.04 Epsilon = 0.813
# 1
# 0
# resultado da epoca 190 = -1852.76 Epsilon = 0.812
# 0
# 1
# resultado da epoca 191 = 897.84 Epsilon = 0.811
# 1
# 0
# resultado da epoca 192 = 2143.44 Epsilon = 0.810
# 1
# 0
# resultado da epoca 193 = 1917.38 Epsilon = 0.809
# 1
# 0
# resultado da epoca 194 = -846.84 Epsilon = 0.808
# 0
# 1
# resultado da epoca 195 = -548.36 Epsilon = 0.807
# 0
# 1
# resultado da epoca 196 = -565.62 Epsilon = 0.806
# 0
# 1
# resultado da epoca 197 = 885.72 Epsilon = 0.805
# 1
# 0
# resultado da epoca 198 = 944.52 Epsilon = 0.804
# 1
# 0
# resultado da epoca 199 = -277.92 Epsilon = 0.803
# 0
# 1
# resultado da epoca 200 = 41.02 Epsilon = 0.802
# 1
# 0
# resultado da epoca 201 = -733.38 Epsilon = 0.801
# 0
# 1
# resultado da epoca 202 = 467.70 Epsilon = 0.800
# 1
# 0
# resultado da epoca 203 = -1913.52 Epsilon = 0.799
# 0
# 1
# resultado da epoca 204 = 1313.78 Epsilon = 0.798
# 1
# 0
# resultado da epoca 205 = 165.42 Epsilon = 0.797
# 1
# 0
# resultado da epoca 206 = 652.26 Epsilon = 0.796
# 1
# 0
# resultado da epoca 207 = -65.18 Epsilon = 0.795
# 0
# 1
# resultado da epoca 208 = -239.42 Epsilon = 0.794
# 0
# 1
# resultado da epoca 209 = -552.14 Epsilon = 0.793
# 0
# 1
# resultado da epoca 210 = -2375.18 Epsilon = 0.792
# 0
# 1
# resultado da epoca 211 = 1254.22 Epsilon = 0.791
# 1
# 0
# resultado da epoca 212 = 451.50 Epsilon = 0.790
# 1
# 0
# resultado da epoca 213 = 1207.24 Epsilon = 0.789
# 1
# 0
# resultado da epoca 214 = -944.88 Epsilon = 0.788
# 0
# 1
# resultado da epoca 215 = -30.48 Epsilon = 0.787
# 0
# 1
# resultado da epoca 216 = 498.74 Epsilon = 0.786
# 1
# 0
# resultado da epoca 217 = -323.36 Epsilon = 0.785
# 0
# 1
# resultado da epoca 218 = 390.26 Epsilon = 0.784
# 1
# 0
# resultado da epoca 219 = -157.60 Epsilon = 0.783
# 0
# 1
# resultado da epoca 220 = 188.30 Epsilon = 0.782
# 1
# 0
# resultado da epoca 221 = 463.76 Epsilon = 0.781
# 1
# 0
# resultado da epoca 222 = -415.76 Epsilon = 0.780
# 0
# 1
# resultado da epoca 223 = -1359.58 Epsilon = 0.779
# 0
# 1
# resultado da epoca 224 = 1723.16 Epsilon = 0.778
# 1
# 0
# resultado da epoca 225 = -347.46 Epsilon = 0.777
# 0
# 1
# resultado da epoca 226 = -504.88 Epsilon = 0.776
# 0
# 1
# resultado da epoca 227 = -930.02 Epsilon = 0.775
# 0
# 1
# resultado da epoca 228 = 310.88 Epsilon = 0.774
# 1
# 0
# resultado da epoca 229 = -1870.62 Epsilon = 0.773
# 0
# 1
# resultado da epoca 230 = -244.72 Epsilon = 0.772
# 0
# 1
# resultado da epoca 231 = -2085.78 Epsilon = 0.771
# 0
# 1
# resultado da epoca 232 = -389.72 Epsilon = 0.770
# 0
# 1
# resultado da epoca 233 = 498.62 Epsilon = 0.769
# 1
# 0
# resultado da epoca 234 = -1140.76 Epsilon = 0.768
# 0
# 1
# resultado da epoca 235 = 2167.10 Epsilon = 0.767
# 1
# 0
# resultado da epoca 236 = 31.04 Epsilon = 0.766
# 1
# 0
# resultado da epoca 237 = 325.88 Epsilon = 0.765
# 1
# 0
# resultado da epoca 238 = -307.76 Epsilon = 0.764
# 0
# 1
# resultado da epoca 239 = -1042.46 Epsilon = 0.763
# 0
# 1
# resultado da epoca 240 = -718.04 Epsilon = 0.762
# 0
# 1
# resultado da epoca 241 = -895.02 Epsilon = 0.761
# 0
# 1
# resultado da epoca 242 = 603.76 Epsilon = 0.760
# 1
# 0
# resultado da epoca 243 = -303.06 Epsilon = 0.759
# 0
# 1
# resultado da epoca 244 = -88.52 Epsilon = 0.758
# 0
# 1
# resultado da epoca 245 = -1467.30 Epsilon = 0.757
# 0
# 1
# resultado da epoca 246 = 539.36 Epsilon = 0.756
# 1
# 0
# resultado da epoca 247 = -1478.98 Epsilon = 0.755
# 0
# 1
# resultado da epoca 248 = -297.46 Epsilon = 0.754
# 0
# 1
# resultado da epoca 249 = -108.52 Epsilon = 0.753
# 0
# 1
# resultado da epoca 250 = -1325.62 Epsilon = 0.752
# 0
# 1
# resultado da epoca 251 = 234.06 Epsilon = 0.752
# 1
# 0
# resultado da epoca 252 = -103.06 Epsilon = 0.751
# 0
# 1
# resultado da epoca 253 = 232.54 Epsilon = 0.750
# 1
# 0
# resultado da epoca 254 = -1651.24 Epsilon = 0.749
# 0
# 1
# resultado da epoca 255 = 249.38 Epsilon = 0.748
# 1
# 0
# resultado da epoca 256 = 206.78 Epsilon = 0.747
# 1
# 0
# resultado da epoca 257 = 1534.20 Epsilon = 0.746
# 1
# 0
# resultado da epoca 258 = -1887.00 Epsilon = 0.745
# 0
# 1
# resultado da epoca 259 = -1237.00 Epsilon = 0.744
# 0
# 1
# resultado da epoca 260 = 1109.22 Epsilon = 0.743
# 1
# 0
# resultado da epoca 261 = -550.02 Epsilon = 0.742
# 0
# 1
# resultado da epoca 262 = -691.70 Epsilon = 0.741
# 0
# 1
# resultado da epoca 263 = -491.68 Epsilon = 0.740
# 0
# 1
# resultado da epoca 264 = 439.82 Epsilon = 0.739
# 1
# 0
# resultado da epoca 265 = -646.86 Epsilon = 0.738
# 0
# 1
# resultado da epoca 266 = -129.88 Epsilon = 0.737
# 0
# 1
# resultado da epoca 267 = 249.36 Epsilon = 0.736
# 1
# 0
# resultado da epoca 268 = -0.32 Epsilon = 0.735
# 0
# 1
# resultado da epoca 269 = -690.02 Epsilon = 0.734
# 0
# 1
# resultado da epoca 270 = -598.84 Epsilon = 0.733
# 0
# 1
# resultado da epoca 271 = 763.44 Epsilon = 0.732
# 1
# 0
# resultado da epoca 272 = -1393.80 Epsilon = 0.731
# 0
# 1
# resultado da epoca 273 = -19.74 Epsilon = 0.730
# 0
# 1
# resultado da epoca 274 = -355.18 Epsilon = 0.729
# 0
# 1
# resultado da epoca 275 = -156.70 Epsilon = 0.728
# 0
# 1
# resultado da epoca 276 = -491.24 Epsilon = 0.727
# 0
# 1
# resultado da epoca 277 = -927.14 Epsilon = 0.726
# 0
# 1
# resultado da epoca 278 = -3280.02 Epsilon = 0.725
# 0
# 1
# resultado da epoca 279 = -929.88 Epsilon = 0.724
# 0
# 1
# resultado da epoca 280 = -576.26 Epsilon = 0.723
# 0
# 1
# resultado da epoca 281 = 416.04 Epsilon = 0.722
# 1
# 0
# resultado da epoca 282 = 899.36 Epsilon = 0.721
# 1
# 0
# resultado da epoca 283 = -1980.18 Epsilon = 0.720
# 0
# 1
# resultado da epoca 284 = -1719.88 Epsilon = 0.719
# 0
# 1
# resultado da epoca 285 = 447.38 Epsilon = 0.718
# 1
# 0
# resultado da epoca 286 = 160.42 Epsilon = 0.717
# 1
# 0
# resultado da epoca 287 = 432.86 Epsilon = 0.716
# 1
# 0
# resultado da epoca 288 = 141.34 Epsilon = 0.715
# 1
# 0
# resultado da epoca 289 = -612.46 Epsilon = 0.714
# 0
# 1
# resultado da epoca 290 = -2309.42 Epsilon = 0.713
# 0
# 1
# resultado da epoca 291 = 468.60 Epsilon = 0.712
# 1
# 0
# resultado da epoca 292 = -693.50 Epsilon = 0.711
# 0
# 1
# resultado da epoca 293 = 399.66 Epsilon = 0.710
# 1
# 0
# resultado da epoca 294 = 430.12 Epsilon = 0.709
# 1
# 0
# resultado da epoca 295 = -1713.66 Epsilon = 0.708
# 0
# 1
# resultado da epoca 296 = 864.66 Epsilon = 0.707
# 1
# 0
# resultado da epoca 297 = 820.28 Epsilon = 0.706
# 1
# 0
# resultado da epoca 298 = 379.82 Epsilon = 0.705
# 1
# 0
# resultado da epoca 299 = 1021.02 Epsilon = 0.704
# 1
# 0
# resultado da epoca 300 = -1591.54 Epsilon = 0.703
# 0
# 1
# resultado da epoca 301 = -1438.50 Epsilon = 0.702
# 0
# 1
# resultado da epoca 302 = -695.18 Epsilon = 0.701
# 0
# 1
# resultado da epoca 303 = -1031.40 Epsilon = 0.700
# 0
# 1
# resultado da epoca 304 = -1964.58 Epsilon = 0.699
# 0
# 1
# resultado da epoca 305 = 597.84 Epsilon = 0.698
# 1
# 0
# resultado da epoca 306 = -1360.20 Epsilon = 0.697
# 0
# 1
# resultado da epoca 307 = 150.12 Epsilon = 0.696
# 1
# 0
# resultado da epoca 308 = -2549.12 Epsilon = 0.695
# 0
# 1
# resultado da epoca 309 = 734.22 Epsilon = 0.694
# 1
# 0
# resultado da epoca 310 = -529.58 Epsilon = 0.693
# 0
# 1
# resultado da epoca 311 = -756.68 Epsilon = 0.692
# 0
# 1
# resultado da epoca 312 = 689.82 Epsilon = 0.691
# 1
# 0
# resultado da epoca 313 = -1189.42 Epsilon = 0.690
# 0
# 1
# resultado da epoca 314 = 963.76 Epsilon = 0.689
# 1
# 0
# resultado da epoca 315 = 538.16 Epsilon = 0.688
# 1
# 0
# resultado da epoca 316 = -150.04 Epsilon = 0.687
# 0
# 1
# resultado da epoca 317 = -123.52 Epsilon = 0.686
# 0
# 1
# resultado da epoca 318 = 1001.04 Epsilon = 0.685
# 1
# 0
# resultado da epoca 319 = -2481.10 Epsilon = 0.684
# 0
# 1
# resultado da epoca 320 = -331.70 Epsilon = 0.683
# 0
# 1
# resultado da epoca 321 = 198.16 Epsilon = 0.682
# 1
# 0
# resultado da epoca 322 = -567.16 Epsilon = 0.681
# 0
# 1
# resultado da epoca 323 = -940.78 Epsilon = 0.680
# 0
# 1
# resultado da epoca 324 = -559.28 Epsilon = 0.679
# 0
# 1
# resultado da epoca 325 = 1605.88 Epsilon = 0.678
# 1
# 0
# resultado da epoca 326 = 454.96 Epsilon = 0.677
# 1
# 0
# resultado da epoca 327 = 932.56 Epsilon = 0.676
# 1
# 0
# resultado da epoca 328 = 450.12 Epsilon = 0.675
# 1
# 0
# resultado da epoca 329 = -681.40 Epsilon = 0.674
# 0
# 1
# resultado da epoca 330 = -295.96 Epsilon = 0.673
# 0
# 1
# resultado da epoca 331 = -537.00 Epsilon = 0.672
# 0
# 1
# resultado da epoca 332 = -305.96 Epsilon = 0.671
# 0
# 1
# resultado da epoca 333 = 1936.48 Epsilon = 0.670
# 1
# 0
# resultado da epoca 334 = -262.76 Epsilon = 0.669
# 0
# 1
# resultado da epoca 335 = -255.02 Epsilon = 0.668
# 0
# 1
# resultado da epoca 336 = 421.64 Epsilon = 0.667
# 1
# 0
# resultado da epoca 337 = 152.84 Epsilon = 0.666
# 1
# 0
# resultado da epoca 338 = 600.42 Epsilon = 0.665
# 1
# 0
# resultado da epoca 339 = 53.62 Epsilon = 0.664
# 1
# 0
# resultado da epoca 340 = 717.70 Epsilon = 0.663
# 1
# 0
# resultado da epoca 341 = 10.58 Epsilon = 0.662
# 1
# 0
# resultado da epoca 342 = -882.62 Epsilon = 0.661
# 0
# 1
# resultado da epoca 343 = -1110.64 Epsilon = 0.660
# 0
# 1
# resultado da epoca 344 = -710.80 Epsilon = 0.659
# 0
# 1
# resultado da epoca 345 = -852.92 Epsilon = 0.658
# 0
# 1
# resultado da epoca 346 = -240.02 Epsilon = 0.657
# 0
# 1
# resultado da epoca 347 = -109.12 Epsilon = 0.656
# 0
# 1
# resultado da epoca 348 = -754.72 Epsilon = 0.655
# 0
# 1
# resultado da epoca 349 = 822.08 Epsilon = 0.654
# 1
# 0
# resultado da epoca 350 = -1029.88 Epsilon = 0.653
# 0
# 1
# resultado da epoca 351 = 689.08 Epsilon = 0.653
# 1
# 0
# resultado da epoca 352 = -1236.70 Epsilon = 0.652
# 0
# 1
# resultado da epoca 353 = 695.74 Epsilon = 0.651
# 1
# 0
# resultado da epoca 354 = 78.46 Epsilon = 0.650
# 1
# 0
# resultado da epoca 355 = -885.64 Epsilon = 0.649
# 0
# 1
# resultado da epoca 356 = -974.44 Epsilon = 0.648
# 0
# 1
# resultado da epoca 357 = -1214.42 Epsilon = 0.647
# 0
# 1
# resultado da epoca 358 = 54.98 Epsilon = 0.646
# 1
# 0
# resultado da epoca 359 = 1049.06 Epsilon = 0.645
# 1
# 0
# resultado da epoca 360 = -2029.60 Epsilon = 0.644
# 0
# 1
# resultado da epoca 361 = 324.24 Epsilon = 0.643
# 1
# 0
# resultado da epoca 362 = -1154.58 Epsilon = 0.642
# 0
# 1
# resultado da epoca 363 = -420.04 Epsilon = 0.641
# 0
# 1
# resultado da epoca 364 = -2166.26 Epsilon = 0.640
# 0
# 1
# resultado da epoca 365 = 725.76 Epsilon = 0.639
# 1
# 0
# resultado da epoca 366 = 42.10 Epsilon = 0.638
# 1
# 0
# resultado da epoca 367 = -102.00 Epsilon = 0.637
# 0
# 1
# resultado da epoca 368 = 779.66 Epsilon = 0.636
# 1
# 0
# resultado da epoca 369 = 650.58 Epsilon = 0.635
# 1
# 0
# resultado da epoca 370 = 519.50 Epsilon = 0.634
# 1
# 0
# resultado da epoca 371 = -75.78 Epsilon = 0.633
# 0
# 1
# resultado da epoca 372 = 1168.90 Epsilon = 0.632
# 1
# 0
# resultado da epoca 373 = 1279.82 Epsilon = 0.631
# 1
# 0
# resultado da epoca 374 = -310.16 Epsilon = 0.630
# 0
# 1
# resultado da epoca 375 = -25.80 Epsilon = 0.629
# 0
# 1
# resultado da epoca 376 = -476.38 Epsilon = 0.628
# 0
# 1
# resultado da epoca 377 = 780.88 Epsilon = 0.627
# 1
# 0
# resultado da epoca 378 = -179.88 Epsilon = 0.626
# 0
# 1
# resultado da epoca 379 = -686.12 Epsilon = 0.625
# 0
# 1
# resultado da epoca 380 = -367.16 Epsilon = 0.624
# 0
# 1
# resultado da epoca 381 = -1069.88 Epsilon = 0.623
# 0
# 1
# resultado da epoca 382 = -547.00 Epsilon = 0.622
# 0
# 1
# resultado da epoca 383 = -76.70 Epsilon = 0.621
# 0
# 1
# resultado da epoca 384 = -245.18 Epsilon = 0.620
# 0
# 1
# resultado da epoca 385 = 227.70 Epsilon = 0.619
# 1
# 0
# resultado da epoca 386 = -1112.76 Epsilon = 0.618
# 0
# 1
# resultado da epoca 387 = -1007.76 Epsilon = 0.617
# 0
# 1
# resultado da epoca 388 = -301.24 Epsilon = 0.616
# 0
# 1
# resultado da epoca 389 = -549.28 Epsilon = 0.615
# 0
# 1
# resultado da epoca 390 = 675.26 Epsilon = 0.614
# 1
# 0
# resultado da epoca 391 = -1389.88 Epsilon = 0.613
# 0
# 1
# resultado da epoca 392 = -768.22 Epsilon = 0.612
# 0
# 1
# resultado da epoca 393 = -447.16 Epsilon = 0.611
# 0
# 1
# resultado da epoca 394 = -675.02 Epsilon = 0.610
# 0
# 1
# resultado da epoca 395 = -795.62 Epsilon = 0.609
# 0
# 1
# resultado da epoca 396 = -1402.92 Epsilon = 0.608
# 0
# 1
# resultado da epoca 397 = 351.64 Epsilon = 0.607
# 1
# 0
# resultado da epoca 398 = 756.78 Epsilon = 0.606
# 1
# 0
# resultado da epoca 399 = -817.92 Epsilon = 0.605
# 0
# 1
# resultado da epoca 400 = -956.40 Epsilon = 0.604
# 0
# 1
# resultado da epoca 401 = -73.68 Epsilon = 0.603
# 0
# 1
# resultado da epoca 402 = 933.44 Epsilon = 0.602
# 1
# 0
# resultado da epoca 403 = -305.96 Epsilon = 0.601
# 0
# 1
# resultado da epoca 404 = 910.88 Epsilon = 0.600
# 1
# 0
# resultado da epoca 405 = -1408.36 Epsilon = 0.599
# 0
# 1
# resultado da epoca 406 = -2319.88 Epsilon = 0.598
# 0
# 1
# resultado da epoca 407 = 1703.00 Epsilon = 0.597
# 1
# 0
# resultado da epoca 408 = -980.66 Epsilon = 0.596
# 0
# 1
# resultado da epoca 409 = -2030.34 Epsilon = 0.595
# 0
# 1
# resultado da epoca 410 = 161.80 Epsilon = 0.594
# 1
# 0
# resultado da epoca 411 = 173.30 Epsilon = 0.593
# 1
# 0
# resultado da epoca 412 = 1471.48 Epsilon = 0.592
# 1
# 0
# resultado da epoca 413 = -93.82 Epsilon = 0.591
# 0
# 1
# resultado da epoca 414 = 1485.12 Epsilon = 0.590
# 1
# 0
# resultado da epoca 415 = -239.72 Epsilon = 0.589
# 0
# 1
# resultado da epoca 416 = -60.34 Epsilon = 0.588
# 0
# 1
# resultado da epoca 417 = -438.06 Epsilon = 0.587
# 0
# 1
# resultado da epoca 418 = -1355.18 Epsilon = 0.586
# 0
# 1
# resultado da epoca 419 = -364.44 Epsilon = 0.585
# 0
# 1
# resultado da epoca 420 = 156.62 Epsilon = 0.584
# 1
# 0
# resultado da epoca 421 = 84.82 Epsilon = 0.583
# 1
# 0
# resultado da epoca 422 = 29.36 Epsilon = 0.582
# 1
# 0
# resultado da epoca 423 = -1300.48 Epsilon = 0.581
# 0
# 1
# resultado da epoca 424 = -349.86 Epsilon = 0.580
# 0
# 1
# resultado da epoca 425 = 179.80 Epsilon = 0.579
# 1
# 0
# resultado da epoca 426 = 912.68 Epsilon = 0.578
# 1
# 0
# resultado da epoca 427 = 991.80 Epsilon = 0.577
# 1
# 0
# resultado da epoca 428 = -1471.70 Epsilon = 0.576
# 0
# 1
# resultado da epoca 429 = -1494.44 Epsilon = 0.575
# 0
# 1
# resultado da epoca 430 = -2429.28 Epsilon = 0.574
# 0
# 1
# resultado da epoca 431 = -500.34 Epsilon = 0.573
# 0
# 1
# resultado da epoca 432 = -819.28 Epsilon = 0.572
# 0
# 1
# resultado da epoca 433 = -483.52 Epsilon = 0.571
# 0
# 1
# resultado da epoca 434 = -1031.70 Epsilon = 0.570
# 0
# 1
# resultado da epoca 435 = -740.64 Epsilon = 0.569
# 0
# 1
# resultado da epoca 436 = -207.16 Epsilon = 0.568
# 0
# 1
# resultado da epoca 437 = -1577.00 Epsilon = 0.567
# 0
# 1
# resultado da epoca 438 = 1256.48 Epsilon = 0.566
# 1
# 0
# resultado da epoca 439 = 317.08 Epsilon = 0.565
# 1
# 0
# resultado da epoca 440 = -764.58 Epsilon = 0.564
# 0
# 1
# resultado da epoca 441 = -511.56 Epsilon = 0.563
# 0
# 1
# resultado da epoca 442 = 1137.70 Epsilon = 0.562
# 1
# 0
# resultado da epoca 443 = -412.32 Epsilon = 0.561
# 0
# 1
# resultado da epoca 444 = 782.54 Epsilon = 0.560
# 1
# 0
# resultado da epoca 445 = 279.66 Epsilon = 0.559
# 1
# 0
# resultado da epoca 446 = 24.68 Epsilon = 0.558
# 1
# 0
# resultado da epoca 447 = 75.42 Epsilon = 0.557
# 1
# 0
# resultado da epoca 448 = -1708.66 Epsilon = 0.556
# 0
# 1
# resultado da epoca 449 = -253.68 Epsilon = 0.555
# 0
# 1
# resultado da epoca 450 = -1153.22 Epsilon = 0.554
# 0
# 1
# resultado da epoca 451 = -67.62 Epsilon = 0.554
# 0
# 1
# resultado da epoca 452 = 1279.04 Epsilon = 0.553
# 1
# 0
# resultado da epoca 453 = -1764.74 Epsilon = 0.552
# 0
# 1
# resultado da epoca 454 = -1088.08 Epsilon = 0.551
# 0
# 1
# resultado da epoca 455 = -1693.84 Epsilon = 0.550
# 0
# 1
# resultado da epoca 456 = 358.14 Epsilon = 0.549
# 1
# 0
# resultado da epoca 457 = -4.88 Epsilon = 0.548
# 0
# 1
# resultado da epoca 458 = 459.66 Epsilon = 0.547
# 1
# 0
# resultado da epoca 459 = 2042.08 Epsilon = 0.546
# 1
# 0
# resultado da epoca 460 = 285.26 Epsilon = 0.545
# 1
# 0
# resultado da epoca 461 = -898.68 Epsilon = 0.544
# 0
# 1
# resultado da epoca 462 = 547.24 Epsilon = 0.543
# 1
# 0
# resultado da epoca 463 = 44.66 Epsilon = 0.542
# 1
# 0
# resultado da epoca 464 = -3056.26 Epsilon = 0.541
# 0
# 1
# resultado da epoca 465 = -931.10 Epsilon = 0.540
# 0
# 1
# resultado da epoca 466 = -1887.46 Epsilon = 0.539
# 0
# 1
# resultado da epoca 467 = -1324.74 Epsilon = 0.538
# 0
# 1
# resultado da epoca 468 = 1611.48 Epsilon = 0.537
# 1
# 0
# resultado da epoca 469 = 67.26 Epsilon = 0.536
# 1
# 0
# resultado da epoca 470 = -1247.28 Epsilon = 0.535
# 0
# 1
# resultado da epoca 471 = -865.64 Epsilon = 0.534
# 0
# 1
# resultado da epoca 472 = 610.72 Epsilon = 0.533
# 1
# 0
# resultado da epoca 473 = -349.72 Epsilon = 0.532
# 0
# 1
# resultado da epoca 474 = 906.48 Epsilon = 0.531
# 1
# 0
# resultado da epoca 475 = -1235.04 Epsilon = 0.530
# 0
# 1
# resultado da epoca 476 = -584.58 Epsilon = 0.529
# 0
# 1
# resultado da epoca 477 = -2110.48 Epsilon = 0.528
# 0
# 1
# resultado da epoca 478 = -285.04 Epsilon = 0.527
# 0
# 1
# resultado da epoca 479 = -294.12 Epsilon = 0.526
# 0
# 1
# resultado da epoca 480 = -1402.92 Epsilon = 0.525
# 0
# 1
# resultado da epoca 481 = 473.46 Epsilon = 0.524
# 1
# 0
# resultado da epoca 482 = -443.06 Epsilon = 0.523
# 0
# 1
# resultado da epoca 483 = 230.72 Epsilon = 0.522
# 1
# 0
# resultado da epoca 484 = -535.50 Epsilon = 0.521
# 0
# 1
# resultado da epoca 485 = -1593.06 Epsilon = 0.520
# 0
# 1
# resultado da epoca 486 = -1856.26 Epsilon = 0.519
# 0
# 1
# resultado da epoca 487 = 749.52 Epsilon = 0.518
# 1
# 0
# resultado da epoca 488 = -832.92 Epsilon = 0.517
# 0
# 1
# resultado da epoca 489 = -2286.84 Epsilon = 0.516
# 0
# 1
# resultado da epoca 490 = -1154.58 Epsilon = 0.515
# 0
# 1
# resultado da epoca 491 = -323.52 Epsilon = 0.514
# 0
# 1
# resultado da epoca 492 = -769.74 Epsilon = 0.513
# 0
# 1
# resultado da epoca 493 = -713.06 Epsilon = 0.512
# 0
# 1
# resultado da epoca 494 = 726.32 Epsilon = 0.511
# 1
# 0
# resultado da epoca 495 = -873.98 Epsilon = 0.510
# 0
# 1
# resultado da epoca 496 = -2031.72 Epsilon = 0.509
# 0
# 1
# resultado da epoca 497 = 496.92 Epsilon = 0.508
# 1
# 0
# resultado da epoca 498 = -674.44 Epsilon = 0.507
# 0
# 1
# resultado da epoca 499 = 482.54 Epsilon = 0.506
# 1
# 0
# resultado da epoca 500 = -584.74 Epsilon = 0.505
# 0
# 1
# resultado da epoca 501 = 1063.90 Epsilon = 0.504
# 1
# 0
# resultado da epoca 502 = -63.22 Epsilon = 0.503
# 0
# 1
# resultado da epoca 503 = -730.80 Epsilon = 0.502
# 0
# 1
# resultado da epoca 504 = -1799.58 Epsilon = 0.501
# 0
# 1
# resultado da epoca 505 = -1095.66 Epsilon = 0.500
# 0
# 1
# resultado da epoca 506 = -32.00 Epsilon = 0.499
# 0
# 1
# resultado da epoca 507 = -2148.52 Epsilon = 0.498
# 0
# 1
# resultado da epoca 508 = 178.60 Epsilon = 0.497
# 1
# 0
# resultado da epoca 509 = 987.08 Epsilon = 0.496
# 1
# 0
# resultado da epoca 510 = -63.98 Epsilon = 0.495
# 0
# 1
# resultado da epoca 511 = 587.54 Epsilon = 0.494
# 1
# 0
# resultado da epoca 512 = -366.24 Epsilon = 0.493
# 0
# 1
# resultado da epoca 513 = 45.58 Epsilon = 0.492
# 1
# 0
# resultado da epoca 514 = 107.84 Epsilon = 0.491
# 1
# 0
# resultado da epoca 515 = -1153.82 Epsilon = 0.490
# 0
# 1
# resultado da epoca 516 = -1542.00 Epsilon = 0.489
# 0
# 1
# resultado da epoca 517 = -388.52 Epsilon = 0.488
# 0
# 1
# resultado da epoca 518 = -682.92 Epsilon = 0.487
# 0
# 1
# resultado da epoca 519 = 388.76 Epsilon = 0.486
# 1
# 0
# resultado da epoca 520 = -244.00 Epsilon = 0.485
# 0
# 1
# resultado da epoca 521 = -243.52 Epsilon = 0.484
# 0
# 1
# resultado da epoca 522 = 107.38 Epsilon = 0.483
# 1
# 0
# resultado da epoca 523 = -396.10 Epsilon = 0.482
# 0
# 1
# resultado da epoca 524 = 396.18 Epsilon = 0.481
# 1
# 0
# resultado da epoca 525 = -1215.80 Epsilon = 0.480
# 0
# 1
# resultado da epoca 526 = -200.80 Epsilon = 0.479
# 0
# 1
# resultado da epoca 527 = -1398.68 Epsilon = 0.478
# 0
# 1
# resultado da epoca 528 = 91.94 Epsilon = 0.477
# 1
# 0
# resultado da epoca 529 = 1639.96 Epsilon = 0.476
# 1
# 0
# resultado da epoca 530 = -176.86 Epsilon = 0.475
# 0
# 1
# resultado da epoca 531 = 633.60 Epsilon = 0.474
# 1
# 0
# resultado da epoca 532 = -1510.94 Epsilon = 0.473
# 0
# 1
# resultado da epoca 533 = 835.42 Epsilon = 0.472
# 1
# 0
# resultado da epoca 534 = -160.50 Epsilon = 0.471
# 0
# 1
# resultado da epoca 535 = -730.78 Epsilon = 0.470
# 0
# 1
# resultado da epoca 536 = -577.30 Epsilon = 0.469
# 0
# 1
# resultado da epoca 537 = 762.08 Epsilon = 0.468
# 1
# 0
# resultado da epoca 538 = -1045.48 Epsilon = 0.467
# 0
# 1
# resultado da epoca 539 = 346.18 Epsilon = 0.466
# 1
# 0
# resultado da epoca 540 = 1659.96 Epsilon = 0.465
# 1
# 0
# resultado da epoca 541 = -700.94 Epsilon = 0.464
# 0
# 1
# resultado da epoca 542 = 1463.60 Epsilon = 0.463
# 1
# 0
# resultado da epoca 543 = 1036.96 Epsilon = 0.462
# 1
# 0
# resultado da epoca 544 = -490.20 Epsilon = 0.461
# 0
# 1
# resultado da epoca 545 = 43.90 Epsilon = 0.460
# 1
# 0
# resultado da epoca 546 = -774.88 Epsilon = 0.459
# 0
# 1
# resultado da epoca 547 = -1506.10 Epsilon = 0.458
# 0
# 1
# resultado da epoca 548 = 24.04 Epsilon = 0.457
# 1
# 0
# resultado da epoca 549 = -478.38 Epsilon = 0.456
# 0
# 1
# resultado da epoca 550 = 283.30 Epsilon = 0.455
# 1
# 0
# resultado da epoca 551 = 550.26 Epsilon = 0.455
# 1
# 0
# resultado da epoca 552 = 396.32 Epsilon = 0.454
# 1
# 0
# resultado da epoca 553 = 333.00 Epsilon = 0.453
# 1
# 0
# resultado da epoca 554 = -70.64 Epsilon = 0.452
# 0
# 1
# resultado da epoca 555 = -1107.76 Epsilon = 0.451
# 0
# 1
# resultado da epoca 556 = -817.64 Epsilon = 0.450
# 0
# 1
# resultado da epoca 557 = -773.98 Epsilon = 0.449
# 0
# 1
# resultado da epoca 558 = -311.26 Epsilon = 0.448
# 0
# 1
# resultado da epoca 559 = -1037.92 Epsilon = 0.447
# 0
# 1
# resultado da epoca 560 = 597.54 Epsilon = 0.446
# 1
# 0
# resultado da epoca 561 = -1433.22 Epsilon = 0.445
# 0
# 1
# resultado da epoca 562 = -1037.16 Epsilon = 0.444
# 0
# 1
# resultado da epoca 563 = 55.56 Epsilon = 0.443
# 1
# 0
# resultado da epoca 564 = 840.12 Epsilon = 0.442
# 1
# 0
# resultado da epoca 565 = -939.14 Epsilon = 0.441
# 0
# 1
# resultado da epoca 566 = 1470.12 Epsilon = 0.440
# 1
# 0
# resultado da epoca 567 = 267.54 Epsilon = 0.439
# 1
# 0
# resultado da epoca 568 = -1002.16 Epsilon = 0.438
# 0
# 1
# resultado da epoca 569 = -445.18 Epsilon = 0.437
# 0
# 1
# resultado da epoca 570 = 496.18 Epsilon = 0.436
# 1
# 0
# resultado da epoca 571 = -563.68 Epsilon = 0.435
# 0
# 1
# resultado da epoca 572 = -338.98 Epsilon = 0.434
# 0
# 1
# resultado da epoca 573 = -431.56 Epsilon = 0.433
# 0
# 1
# resultado da epoca 574 = 454.96 Epsilon = 0.432
# 1
# 0
# resultado da epoca 575 = 283.14 Epsilon = 0.431
# 1
# 0
# resultado da epoca 576 = 1435.42 Epsilon = 0.430
# 1
# 0
# resultado da epoca 577 = -831.54 Epsilon = 0.429
# 0
# 1
# resultado da epoca 578 = 1747.84 Epsilon = 0.428
# 1
# 0
# resultado da epoca 579 = 906.02 Epsilon = 0.427
# 1
# 0
# resultado da epoca 580 = -745.18 Epsilon = 0.426
# 0
# 1
# resultado da epoca 581 = -626.54 Epsilon = 0.425
# 0
# 1
# resultado da epoca 582 = -1127.92 Epsilon = 0.424
# 0
# 1
# resultado da epoca 583 = 409.80 Epsilon = 0.423
# 1
# 0
# resultado da epoca 584 = 913.14 Epsilon = 0.422
# 1
# 0
# resultado da epoca 585 = -567.46 Epsilon = 0.421
# 0
# 1
# resultado da epoca 586 = 79.20 Epsilon = 0.420
# 1
# 0
# resultado da epoca 587 = -982.14 Epsilon = 0.419
# 0
# 1
# resultado da epoca 588 = -62.00 Epsilon = 0.418
# 0
# 1
# resultado da epoca 589 = 651.92 Epsilon = 0.417
# 1
# 0
# resultado da epoca 590 = 233.60 Epsilon = 0.416
# 1
# 0
# resultado da epoca 591 = -1278.22 Epsilon = 0.415
# 0
# 1
# resultado da epoca 592 = -224.30 Epsilon = 0.414
# 0
# 1
# resultado da epoca 593 = 103.00 Epsilon = 0.413
# 1
# 0
# resultado da epoca 594 = -687.64 Epsilon = 0.412
# 0
# 1
# resultado da epoca 595 = 1072.84 Epsilon = 0.411
# 1
# 0
# resultado da epoca 596 = 653.28 Epsilon = 0.410
# 1
# 0
# resultado da epoca 597 = 419.50 Epsilon = 0.409
# 1
# 0
# resultado da epoca 598 = 838.90 Epsilon = 0.408
# 1
# 0
# resultado da epoca 599 = 1295.56 Epsilon = 0.407
# 1
# 0
# resultado da epoca 600 = 855.40 Epsilon = 0.406
# 1
# 0
# resultado da epoca 601 = 877.22 Epsilon = 0.405
# 1
# 0
# resultado da epoca 602 = -1986.84 Epsilon = 0.404
# 0
# 1
# resultado da epoca 603 = 751.92 Epsilon = 0.403
# 1
# 0
# resultado da epoca 604 = -584.28 Epsilon = 0.402
# 0
# 1
# resultado da epoca 605 = -139.74 Epsilon = 0.401
# 0
# 1
# resultado da epoca 606 = 1073.14 Epsilon = 0.400
# 1
# 0
# resultado da epoca 607 = -230.94 Epsilon = 0.399
# 0
# 1
# resultado da epoca 608 = 411.02 Epsilon = 0.398
# 1
# 0
# resultado da epoca 609 = -427.92 Epsilon = 0.397
# 0
# 1
# resultado da epoca 610 = -848.82 Epsilon = 0.396
# 0
# 1
# resultado da epoca 611 = 382.70 Epsilon = 0.395
# 1
# 0
# resultado da epoca 612 = 1076.62 Epsilon = 0.394
# 1
# 0
# resultado da epoca 613 = 1149.06 Epsilon = 0.393
# 1
# 0
# resultado da epoca 614 = -147.02 Epsilon = 0.392
# 0
# 1
# resultado da epoca 615 = -953.08 Epsilon = 0.391
# 0
# 1
# resultado da epoca 616 = 1511.76 Epsilon = 0.390
# 1
# 0
# resultado da epoca 617 = 898.28 Epsilon = 0.389
# 1
# 0
# resultado da epoca 618 = -1004.74 Epsilon = 0.388
# 0
# 1
# resultado da epoca 619 = 603.14 Epsilon = 0.387
# 1
# 0
# resultado da epoca 620 = 204.96 Epsilon = 0.386
# 1
# 0
# resultado da epoca 621 = 300.72 Epsilon = 0.385
# 1
# 0
# resultado da epoca 622 = 805.26 Epsilon = 0.384
# 1
# 0
# resultado da epoca 623 = -566.56 Epsilon = 0.383
# 0
# 1
# resultado da epoca 624 = -683.98 Epsilon = 0.382
# 0
# 1
# resultado da epoca 625 = -442.16 Epsilon = 0.381
# 0
# 1
# resultado da epoca 626 = 438.74 Epsilon = 0.380
# 1
# 0
# resultado da epoca 627 = -648.52 Epsilon = 0.379
# 0
# 1
# resultado da epoca 628 = -488.84 Epsilon = 0.378
# 0
# 1
# resultado da epoca 629 = -1022.16 Epsilon = 0.377
# 0
# 1
# resultado da epoca 630 = 102.82 Epsilon = 0.376
# 1
# 0
# resultado da epoca 631 = -650.20 Epsilon = 0.375
# 0
# 1
# resultado da epoca 632 = -439.88 Epsilon = 0.374
# 0
# 1
# resultado da epoca 633 = 583.30 Epsilon = 0.373
# 1
# 0
# resultado da epoca 634 = -487.78 Epsilon = 0.372
# 0
# 1
# resultado da epoca 635 = -152.34 Epsilon = 0.371
# 0
# 1
# resultado da epoca 636 = -327.48 Epsilon = 0.370
# 0
# 1
# resultado da epoca 637 = -1146.10 Epsilon = 0.369
# 0
# 1
# resultado da epoca 638 = 1168.28 Epsilon = 0.368
# 1
# 0
# resultado da epoca 639 = -94.90 Epsilon = 0.367
# 0
# 1
# resultado da epoca 640 = -421.72 Epsilon = 0.366
# 0
# 1
# resultado da epoca 641 = 472.68 Epsilon = 0.365
# 1
# 0
# resultado da epoca 642 = -699.44 Epsilon = 0.364
# 0
# 1
# resultado da epoca 643 = 823.88 Epsilon = 0.363
# 1
# 0
# resultado da epoca 644 = 789.06 Epsilon = 0.362
# 1
# 0
# resultado da epoca 645 = 619.94 Epsilon = 0.361
# 1
# 0
# resultado da epoca 646 = 986.64 Epsilon = 0.360
# 1
# 0
# resultado da epoca 647 = 312.22 Epsilon = 0.359
# 1
# 0
# resultado da epoca 648 = 591.92 Epsilon = 0.358
# 1
# 0
# resultado da epoca 649 = 1229.50 Epsilon = 0.357
# 1
# 0
# resultado da epoca 650 = -939.14 Epsilon = 0.356
# 0
# 1
# resultado da epoca 651 = -258.54 Epsilon = 0.356
# 0
# 1
# resultado da epoca 652 = -513.08 Epsilon = 0.355
# 0
# 1
# resultado da epoca 653 = -270.06 Epsilon = 0.354
# 0
# 1
# resultado da epoca 654 = -160.80 Epsilon = 0.353
# 0
# 1
# resultado da epoca 655 = -867.02 Epsilon = 0.352
# 0
# 1
# resultado da epoca 656 = 490.56 Epsilon = 0.351
# 1
# 0
# resultado da epoca 657 = 640.10 Epsilon = 0.350
# 1
# 0
# resultado da epoca 658 = -1392.48 Epsilon = 0.349
# 0
# 1
# resultado da epoca 659 = -351.72 Epsilon = 0.348
# 0
# 1
# resultado da epoca 660 = 361.14 Epsilon = 0.347
# 1
# 0
# resultado da epoca 661 = -250.48 Epsilon = 0.346
# 0
# 1
# resultado da epoca 662 = 197.06 Epsilon = 0.345
# 1
# 0
# resultado da epoca 663 = 1026.48 Epsilon = 0.344
# 1
# 0
# resultado da epoca 664 = -935.66 Epsilon = 0.343
# 0
# 1
# resultado da epoca 665 = -740.66 Epsilon = 0.342
# 0
# 1
# resultado da epoca 666 = -25.04 Epsilon = 0.341
# 0
# 1
# resultado da epoca 667 = 141.78 Epsilon = 0.340
# 1
# 0
# resultado da epoca 668 = 493.14 Epsilon = 0.339
# 1
# 0
# resultado da epoca 669 = 300.56 Epsilon = 0.338
# 1
# 0
# resultado da epoca 670 = -823.24 Epsilon = 0.337
# 0
# 1
# resultado da epoca 671 = -821.12 Epsilon = 0.336
# 0
# 1
# resultado da epoca 672 = -235.50 Epsilon = 0.335
# 0
# 1
# resultado da epoca 673 = -1393.08 Epsilon = 0.334
# 0
# 1
# resultado da epoca 674 = -359.74 Epsilon = 0.333
# 0
# 1
# resultado da epoca 675 = -1272.48 Epsilon = 0.332
# 0
# 1
# resultado da epoca 676 = 1007.08 Epsilon = 0.331
# 1
# 0
# resultado da epoca 677 = 738.90 Epsilon = 0.330
# 1
# 0
# resultado da epoca 678 = -1197.02 Epsilon = 0.329
# 0
# 1
# resultado da epoca 679 = 642.98 Epsilon = 0.328
# 1
# 0
# resultado da epoca 680 = 249.66 Epsilon = 0.327
# 1
# 0
# resultado da epoca 681 = -565.34 Epsilon = 0.326
# 0
# 1
# resultado da epoca 682 = 970.12 Epsilon = 0.325
# 1
# 0
# resultado da epoca 683 = 113.90 Epsilon = 0.324
# 1
# 0
# resultado da epoca 684 = 435.70 Epsilon = 0.323
# 1
# 0
# resultado da epoca 685 = -92.34 Epsilon = 0.322
# 0
# 1
# resultado da epoca 686 = 358.28 Epsilon = 0.321
# 1
# 0
# resultado da epoca 687 = -42.18 Epsilon = 0.320
# 0
# 1
# resultado da epoca 688 = -407.34 Epsilon = 0.319
# 0
# 1
# resultado da epoca 689 = -1037.32 Epsilon = 0.318
# 0
# 1
# resultado da epoca 690 = -470.66 Epsilon = 0.317
# 0
# 1
# resultado da epoca 691 = -274.00 Epsilon = 0.316
# 0
# 1
# resultado da epoca 692 = -1303.68 Epsilon = 0.315
# 0
# 1
# resultado da epoca 693 = 118.44 Epsilon = 0.314
# 1
# 0
# resultado da epoca 694 = 18.44 Epsilon = 0.313
# 1
# 0
# resultado da epoca 695 = -124.00 Epsilon = 0.312
# 0
# 1
# resultado da epoca 696 = 480.70 Epsilon = 0.311
# 1
# 0
# resultado da epoca 697 = 200.10 Epsilon = 0.310
# 1
# 0
# resultado da epoca 698 = 656.46 Epsilon = 0.309
# 1
# 0
# resultado da epoca 699 = -452.62 Epsilon = 0.308
# 0
# 1
# resultado da epoca 700 = 405.26 Epsilon = 0.307
# 1
# 0
# resultado da epoca 701 = 2.38 Epsilon = 0.306
# 1
# 0
# resultado da epoca 702 = 492.22 Epsilon = 0.305
# 1
# 0
# resultado da epoca 703 = 235.40 Epsilon = 0.304
# 1
# 0
# resultado da epoca 704 = 140.72 Epsilon = 0.303
# 1
# 0
# resultado da epoca 705 = 189.96 Epsilon = 0.302
# 1
# 0
# resultado da epoca 706 = 456.92 Epsilon = 0.301
# 1
# 0
# resultado da epoca 707 = -121.72 Epsilon = 0.300
# 0
# 1
# resultado da epoca 708 = 236.46 Epsilon = 0.299
# 1
# 0
# resultado da epoca 709 = -758.68 Epsilon = 0.298
# 0
# 1
# resultado da epoca 710 = -920.04 Epsilon = 0.297
# 0
# 1
# resultado da epoca 711 = 570.70 Epsilon = 0.296
# 1
# 0
# resultado da epoca 712 = -869.14 Epsilon = 0.295
# 0
# 1
# resultado da epoca 713 = -198.38 Epsilon = 0.294
# 0
# 1
# resultado da epoca 714 = 707.82 Epsilon = 0.293
# 1
# 0
# resultado da epoca 715 = -719.14 Epsilon = 0.292
# 0
# 1
# resultado da epoca 716 = -10.36 Epsilon = 0.291
# 0
# 1
# resultado da epoca 717 = -591.58 Epsilon = 0.290
# 0
# 1
# resultado da epoca 718 = -245.50 Epsilon = 0.289
# 0
# 1
# resultado da epoca 719 = 501.76 Epsilon = 0.288
# 1
# 0
# resultado da epoca 720 = -1595.06 Epsilon = 0.287
# 0
# 1
# resultado da epoca 721 = 136.76 Epsilon = 0.286
# 1
# 0
# resultado da epoca 722 = -1550.66 Epsilon = 0.285
# 0
# 1
# resultado da epoca 723 = 272.20 Epsilon = 0.284
# 1
# 0
# resultado da epoca 724 = -276.86 Epsilon = 0.283
# 0
# 1
# resultado da epoca 725 = -609.90 Epsilon = 0.282
# 0
# 1
# resultado da epoca 726 = -931.58 Epsilon = 0.281
# 0
# 1
# resultado da epoca 727 = -1248.84 Epsilon = 0.280
# 0
# 1
# resultado da epoca 728 = 329.48 Epsilon = 0.279
# 1
# 0
# resultado da epoca 729 = -247.32 Epsilon = 0.278
# 0
# 1
# resultado da epoca 730 = -1654.44 Epsilon = 0.277
# 0
# 1
# resultado da epoca 731 = -146.74 Epsilon = 0.276
# 0
# 1
# resultado da epoca 732 = 560.10 Epsilon = 0.275
# 1
# 0
# resultado da epoca 733 = -224.14 Epsilon = 0.274
# 0
# 1
# resultado da epoca 734 = 511.46 Epsilon = 0.273
# 1
# 0
# resultado da epoca 735 = -134.90 Epsilon = 0.272
# 0
# 1
# resultado da epoca 736 = -44.90 Epsilon = 0.271
# 0
# 1
# resultado da epoca 737 = -779.76 Epsilon = 0.270
# 0
# 1
# resultado da epoca 738 = 186.62 Epsilon = 0.269
# 1
# 0
# resultado da epoca 739 = -398.26 Epsilon = 0.268
# 0
# 1
# resultado da epoca 740 = -1357.02 Epsilon = 0.267
# 0
# 1
# resultado da epoca 741 = 507.52 Epsilon = 0.266
# 1
# 0
# resultado da epoca 742 = 414.32 Epsilon = 0.265
# 1
# 0
# resultado da epoca 743 = 1448.90 Epsilon = 0.264
# 1
# 0
# resultado da epoca 744 = -945.96 Epsilon = 0.263
# 0
# 1
# resultado da epoca 745 = -581.72 Epsilon = 0.262
# 0
# 1
# resultado da epoca 746 = 12.68 Epsilon = 0.261
# 1
# 0
# resultado da epoca 747 = -953.70 Epsilon = 0.260
# 0
# 1
# resultado da epoca 748 = 766.16 Epsilon = 0.259
# 1
# 0
# resultado da epoca 749 = -179.90 Epsilon = 0.258
# 0
# 1
# resultado da epoca 750 = -305.80 Epsilon = 0.257
# 0
# 1
# resultado da epoca 751 = -901.12 Epsilon = 0.257
# 0
# 1
# resultado da epoca 752 = -396.86 Epsilon = 0.256
# 0
# 1
# resultado da epoca 753 = 832.36 Epsilon = 0.255
# 1
# 0
# resultado da epoca 754 = -218.38 Epsilon = 0.254
# 0
# 1
# resultado da epoca 755 = -784.44 Epsilon = 0.253
# 0
# 1
# resultado da epoca 756 = 115.70 Epsilon = 0.252
# 1
# 0
# resultado da epoca 757 = -129.62 Epsilon = 0.251
# 0
# 1
# resultado da epoca 758 = 623.12 Epsilon = 0.250
# 1
# 0
# resultado da epoca 759 = 429.64 Epsilon = 0.249
# 1
# 0
# resultado da epoca 760 = 1368.90 Epsilon = 0.248
# 1
# 0
# resultado da epoca 761 = 832.82 Epsilon = 0.247
# 1
# 0
# resultado da epoca 762 = 1631.92 Epsilon = 0.246
# 1
# 0
# resultado da epoca 763 = 1915.40 Epsilon = 0.245
# 1
# 0
# resultado da epoca 764 = 898.30 Epsilon = 0.244
# 1
# 0
# resultado da epoca 765 = -673.84 Epsilon = 0.243
# 0
# 1
# resultado da epoca 766 = 513.60 Epsilon = 0.242
# 1
# 0
# resultado da epoca 767 = -780.96 Epsilon = 0.241
# 0
# 1
# resultado da epoca 768 = 99.96 Epsilon = 0.240
# 1
# 0
# resultado da epoca 769 = 609.94 Epsilon = 0.239
# 1
# 0
# resultado da epoca 770 = 548.28 Epsilon = 0.238
# 1
# 0
# resultado da epoca 771 = -384.60 Epsilon = 0.237
# 0
# 1
# resultado da epoca 772 = 11.92 Epsilon = 0.236
# 1
# 0
# resultado da epoca 773 = -263.24 Epsilon = 0.235
# 0
# 1
# resultado da epoca 774 = 1916.78 Epsilon = 0.234
# 1
# 0
# resultado da epoca 775 = -240.06 Epsilon = 0.233
# 0
# 1
# resultado da epoca 776 = 1150.56 Epsilon = 0.232
# 1
# 0
# resultado da epoca 777 = -686.12 Epsilon = 0.231
# 0
# 1
# resultado da epoca 778 = 433.12 Epsilon = 0.230
# 1
# 0
# resultado da epoca 779 = 980.86 Epsilon = 0.229
# 1
# 0
# resultado da epoca 780 = 2228.44 Epsilon = 0.228
# 1
# 0
# resultado da epoca 781 = 1428.12 Epsilon = 0.227
# 1
# 0
# resultado da epoca 782 = -1117.48 Epsilon = 0.226
# 0
# 1
# resultado da epoca 783 = 570.70 Epsilon = 0.225
# 1
# 0
# resultado da epoca 784 = -58.86 Epsilon = 0.224
# 0
# 1
# resultado da epoca 785 = 898.28 Epsilon = 0.223
# 1
# 0
# resultado da epoca 786 = -352.62 Epsilon = 0.222
# 0
# 1
# resultado da epoca 787 = 172.98 Epsilon = 0.221
# 1
# 0
# resultado da epoca 788 = 1092.36 Epsilon = 0.220
# 1
# 0
# resultado da epoca 789 = 1070.84 Epsilon = 0.219
# 1
# 0
# resultado da epoca 790 = 801.92 Epsilon = 0.218
# 1
# 0
# resultado da epoca 791 = 977.38 Epsilon = 0.217
# 1
# 0
# resultado da epoca 792 = 708.44 Epsilon = 0.216
# 1
# 0
# resultado da epoca 793 = 130.38 Epsilon = 0.215
# 1
# 0
# resultado da epoca 794 = -1170.96 Epsilon = 0.214
# 0
# 1
# resultado da epoca 795 = 316.48 Epsilon = 0.213
# 1
# 0
# resultado da epoca 796 = 1391.30 Epsilon = 0.212
# 1
# 0
# resultado da epoca 797 = 827.68 Epsilon = 0.211
# 1
# 0
# resultado da epoca 798 = 1174.50 Epsilon = 0.210
# 1
# 0
# resultado da epoca 799 = 486.60 Epsilon = 0.209
# 1
# 0
# resultado da epoca 800 = -92.16 Epsilon = 0.208
# 0
# 1
# resultado da epoca 801 = 123.88 Epsilon = 0.207
# 1
# 0
# resultado da epoca 802 = 1256.00 Epsilon = 0.206
# 1
# 0
# resultado da epoca 803 = 1130.24 Epsilon = 0.205
# 1
# 0
# resultado da epoca 804 = 252.06 Epsilon = 0.204
# 1
# 0
# resultado da epoca 805 = 18.12 Epsilon = 0.203
# 1
# 0
# resultado da epoca 806 = 992.66 Epsilon = 0.202
# 1
# 0
# resultado da epoca 807 = 543.42 Epsilon = 0.201
# 1
# 0
# resultado da epoca 808 = 463.72 Epsilon = 0.200
# 1
# 0
# resultado da epoca 809 = 332.98 Epsilon = 0.199
# 1
# 0
# resultado da epoca 810 = 626.00 Epsilon = 0.198
# 1
# 0
# resultado da epoca 811 = 606.60 Epsilon = 0.197
# 1
# 0
# resultado da epoca 812 = 686.92 Epsilon = 0.196
# 1
# 0
# resultado da epoca 813 = 1590.54 Epsilon = 0.195
# 1
# 0
# resultado da epoca 814 = 106.46 Epsilon = 0.194
# 1
# 0
# resultado da epoca 815 = -329.76 Epsilon = 0.193
# 0
# 1
# resultado da epoca 816 = 449.94 Epsilon = 0.192
# 1
# 0
# resultado da epoca 817 = 575.84 Epsilon = 0.191
# 1
# 0
# resultado da epoca 818 = 114.32 Epsilon = 0.190
# 1
# 0
# resultado da epoca 819 = 113.86 Epsilon = 0.189
# 1
# 0
# resultado da epoca 820 = -170.22 Epsilon = 0.188
# 0
# 1
# resultado da epoca 821 = 1076.46 Epsilon = 0.187
# 1
# 0
# resultado da epoca 822 = 498.72 Epsilon = 0.186
# 1
# 0
# resultado da epoca 823 = 1050.70 Epsilon = 0.185
# 1
# 0
# resultado da epoca 824 = -202.64 Epsilon = 0.184
# 0
# 1
# resultado da epoca 825 = -78.70 Epsilon = 0.183
# 0
# 1
# resultado da epoca 826 = 836.92 Epsilon = 0.182
# 1
# 0
# resultado da epoca 827 = 1381.16 Epsilon = 0.181
# 1
# 0
# resultado da epoca 828 = 350.40 Epsilon = 0.180
# 1
# 0
# resultado da epoca 829 = -25.66 Epsilon = 0.179
# 0
# 1
# resultado da epoca 830 = 320.86 Epsilon = 0.178
# 1
# 0
# resultado da epoca 831 = -70.04 Epsilon = 0.177
# 0
# 1
# resultado da epoca 832 = 1181.92 Epsilon = 0.176
# 1
# 0
# resultado da epoca 833 = 1156.76 Epsilon = 0.175
# 1
# 0
# resultado da epoca 834 = 1234.80 Epsilon = 0.174
# 1
# 0
# resultado da epoca 835 = 839.94 Epsilon = 0.173
# 1
# 0
# resultado da epoca 836 = 28.72 Epsilon = 0.172
# 1
# 0
# resultado da epoca 837 = 559.64 Epsilon = 0.171
# 1
# 0
# resultado da epoca 838 = 835.70 Epsilon = 0.170
# 1
# 0
# resultado da epoca 839 = 1079.94 Epsilon = 0.169
# 1
# 0
# resultado da epoca 840 = 64.48 Epsilon = 0.168
# 1
# 0
# resultado da epoca 841 = 975.54 Epsilon = 0.167
# 1
# 0
# resultado da epoca 842 = 286.46 Epsilon = 0.166
# 1
# 0
# resultado da epoca 843 = -540.36 Epsilon = 0.165
# 0
# 1
# resultado da epoca 844 = 19.34 Epsilon = 0.164
# 1
# 0
# resultado da epoca 845 = 999.04 Epsilon = 0.163
# 1
# 0
# resultado da epoca 846 = -45.82 Epsilon = 0.162
# 0
# 1
# resultado da epoca 847 = 604.94 Epsilon = 0.161
# 1
# 0
# resultado da epoca 848 = 439.02 Epsilon = 0.160
# 1
# 0
# resultado da epoca 849 = 417.98 Epsilon = 0.159
# 1
# 0
# resultado da epoca 850 = -48.70 Epsilon = 0.158
# 0
# 1
# resultado da epoca 851 = 275.70 Epsilon = 0.158
# 1
# 0
# resultado da epoca 852 = 623.28 Epsilon = 0.157
# 1
# 0
# resultado da epoca 853 = 220.86 Epsilon = 0.156
# 1
# 0
# resultado da epoca 854 = 764.92 Epsilon = 0.155
# 1
# 0
# resultado da epoca 855 = 819.18 Epsilon = 0.154
# 1
# 0
# resultado da epoca 856 = 710.70 Epsilon = 0.153
# 1
# 0
# resultado da epoca 857 = 312.20 Epsilon = 0.152
# 1
# 0
# resultado da epoca 858 = 352.96 Epsilon = 0.151
# 1
# 0
# resultado da epoca 859 = 1078.42 Epsilon = 0.150
# 1
# 0
# resultado da epoca 860 = 855.84 Epsilon = 0.149
# 1
# 0
# resultado da epoca 861 = 1156.30 Epsilon = 0.148
# 1
# 0
# resultado da epoca 862 = 239.04 Epsilon = 0.147
# 1
# 0
# resultado da epoca 863 = 7.06 Epsilon = 0.146
# 1
# 0
# resultado da epoca 864 = -633.38 Epsilon = 0.145
# 0
# 1
# resultado da epoca 865 = 94.02 Epsilon = 0.144
# 1
# 0
# resultado da epoca 866 = 635.70 Epsilon = 0.143
# 1
# 0
# resultado da epoca 867 = 706.46 Epsilon = 0.142
# 1
# 0
# resultado da epoca 868 = 777.82 Epsilon = 0.141
# 1
# 0
# resultado da epoca 869 = 919.78 Epsilon = 0.140
# 1
# 0
# resultado da epoca 870 = 644.94 Epsilon = 0.139
# 1
# 0
# resultado da epoca 871 = 461.92 Epsilon = 0.138
# 1
# 0
# resultado da epoca 872 = 933.72 Epsilon = 0.137
# 1
# 0
# resultado da epoca 873 = 1635.54 Epsilon = 0.136
# 1
# 0
# resultado da epoca 874 = 714.64 Epsilon = 0.135
# 1
# 0
# resultado da epoca 875 = 471.60 Epsilon = 0.134
# 1
# 0
# resultado da epoca 876 = 90.54 Epsilon = 0.133
# 1
# 0
# resultado da epoca 877 = 1237.82 Epsilon = 0.132
# 1
# 0
# resultado da epoca 878 = 1092.98 Epsilon = 0.131
# 1
# 0
# resultado da epoca 879 = 1756.00 Epsilon = 0.130
# 1
# 0
# resultado da epoca 880 = 81.92 Epsilon = 0.129
# 1
# 0
# resultado da epoca 881 = 1456.90 Epsilon = 0.128
# 1
# 0
# resultado da epoca 882 = 2206.00 Epsilon = 0.127
# 1
# 0
# resultado da epoca 883 = 836.76 Epsilon = 0.126
# 1
# 0
# resultado da epoca 884 = 888.72 Epsilon = 0.125
# 1
# 0
# resultado da epoca 885 = 413.10 Epsilon = 0.124
# 1
# 0
# resultado da epoca 886 = 898.72 Epsilon = 0.123
# 1
# 0
# resultado da epoca 887 = 299.48 Epsilon = 0.122
# 1
# 0
# resultado da epoca 888 = 386.46 Epsilon = 0.121
# 1
# 0
# resultado da epoca 889 = 1013.72 Epsilon = 0.120
# 1
# 0
# resultado da epoca 890 = 1018.56 Epsilon = 0.119
# 1
# 0
# resultado da epoca 891 = 832.82 Epsilon = 0.118
# 1
# 0
# resultado da epoca 892 = 88.72 Epsilon = 0.117
# 1
# 0
# resultado da epoca 893 = 1359.78 Epsilon = 0.116
# 1
# 0
# resultado da epoca 894 = 223.88 Epsilon = 0.115
# 1
# 0
# resultado da epoca 895 = 1366.60 Epsilon = 0.114
# 1
# 0
# resultado da epoca 896 = 950.24 Epsilon = 0.113
# 1
# 0
# resultado da epoca 897 = 542.52 Epsilon = 0.112
# 1
# 0
# resultado da epoca 898 = 1716.46 Epsilon = 0.111
# 1
# 0
# resultado da epoca 899 = 982.06 Epsilon = 0.110
# 1
# 0
# resultado da epoca 900 = 281.30 Epsilon = 0.109
# 1
# 0
# resultado da epoca 901 = 916.00 Epsilon = 0.108
# 1
# 0
# resultado da epoca 902 = 566.00 Epsilon = 0.107
# 1
# 0
# resultado da epoca 903 = 1214.18 Epsilon = 0.106
# 1
# 0
# resultado da epoca 904 = 1511.00 Epsilon = 0.105
# 1
# 0
# resultado da epoca 905 = 311.90 Epsilon = 0.104
# 1
# 0
# resultado da epoca 906 = 146.74 Epsilon = 0.103
# 1
# 0
# resultado da epoca 907 = 148.72 Epsilon = 0.102
# 1
# 0
# resultado da epoca 908 = 989.78 Epsilon = 0.101
# 1
# 0
# resultado da epoca 909 = 1452.96 Epsilon = 0.100
# 1
# 0
# resultado da epoca 910 = 540.08 Epsilon = 0.099
# 1
# 0
# resultado da epoca 911 = 1195.84 Epsilon = 0.098
# 1
# 0
# resultado da epoca 912 = 855.40 Epsilon = 0.097
# 1
# 0
# resultado da epoca 913 = 276.90 Epsilon = 0.096
# 1
# 0
# resultado da epoca 914 = 961.60 Epsilon = 0.095
# 1
# 0
# resultado da epoca 915 = 1291.30 Epsilon = 0.094
# 1
# 0
# resultado da epoca 916 = 750.54 Epsilon = 0.093
# 1
# 0
# resultado da epoca 917 = 684.18 Epsilon = 0.092
# 1
# 0
# resultado da epoca 918 = 1119.02 Epsilon = 0.091
# 1
# 0
# resultado da epoca 919 = 1233.88 Epsilon = 0.090
# 1
# 0
# resultado da epoca 920 = 1155.68 Epsilon = 0.089
# 1
# 0
# resultado da epoca 921 = 878.26 Epsilon = 0.088
# 1
# 0
# resultado da epoca 922 = 935.84 Epsilon = 0.087
# 1
# 0
# resultado da epoca 923 = 1546.30 Epsilon = 0.086
# 1
# 0
# resultado da epoca 924 = 894.94 Epsilon = 0.085
# 1
# 0
# resultado da epoca 925 = 69.78 Epsilon = 0.084
# 1
# 0
# resultado da epoca 926 = 807.20 Epsilon = 0.083
# 1
# 0
# resultado da epoca 927 = 1599.78 Epsilon = 0.082
# 1
# 0
# resultado da epoca 928 = 1524.94 Epsilon = 0.081
# 1
# 0
# resultado da epoca 929 = 1422.20 Epsilon = 0.080
# 1
# 0
# resultado da epoca 930 = 1459.78 Epsilon = 0.079
# 1
# 0
# resultado da epoca 931 = 671.60 Epsilon = 0.078
# 1
# 0
# resultado da epoca 932 = 551.30 Epsilon = 0.077
# 1
# 0
# resultado da epoca 933 = 1112.20 Epsilon = 0.076
# 1
# 0
# resultado da epoca 934 = 1300.54 Epsilon = 0.075
# 1
# 0
# resultado da epoca 935 = 1137.66 Epsilon = 0.074
# 1
# 0
# resultado da epoca 936 = 1139.94 Epsilon = 0.073
# 1
# 0
# resultado da epoca 937 = 109.02 Epsilon = 0.072
# 1
# 0
# resultado da epoca 938 = 1030.54 Epsilon = 0.071
# 1
# 0
# resultado da epoca 939 = 865.08 Epsilon = 0.070
# 1
# 0
# resultado da epoca 940 = 676.44 Epsilon = 0.069
# 1
# 0
# resultado da epoca 941 = 781.30 Epsilon = 0.068
# 1
# 0
# resultado da epoca 942 = 897.20 Epsilon = 0.067
# 1
# 0
# resultado da epoca 943 = 1198.26 Epsilon = 0.066
# 1
# 0
# resultado da epoca 944 = 1154.78 Epsilon = 0.065
# 1
# 0
# resultado da epoca 945 = 739.78 Epsilon = 0.064
# 1
# 0
# resultado da epoca 946 = 1120.84 Epsilon = 0.063
# 1
# 0
# resultado da epoca 947 = 1405.68 Epsilon = 0.062
# 1
# 0
# resultado da epoca 948 = 837.36 Epsilon = 0.061
# 1
# 0
# resultado da epoca 949 = 842.66 Epsilon = 0.060
# 1
# 0
# resultado da epoca 950 = 1032.36 Epsilon = 0.059
# 1
# 0
# resultado da epoca 951 = 835.54 Epsilon = 0.059
# 1
# 0
# resultado da epoca 952 = 1155.68 Epsilon = 0.058
# 1
# 0
# resultado da epoca 953 = 906.90 Epsilon = 0.057
# 1
# 0
# resultado da epoca 954 = 1137.50 Epsilon = 0.056
# 1
# 0
# resultado da epoca 955 = 1151.76 Epsilon = 0.055
# 1
# 0
# resultado da epoca 956 = 734.78 Epsilon = 0.054
# 1
# 0
# resultado da epoca 957 = 944.32 Epsilon = 0.053
# 1
# 0
# resultado da epoca 958 = 1200.68 Epsilon = 0.052
# 1
# 0
# resultado da epoca 959 = 1017.50 Epsilon = 0.051
# 1
# 0
# resultado da epoca 960 = 930.08 Epsilon = 0.050
# 1
# 0
# resultado da epoca 961 = 1153.72 Epsilon = 0.049
# 1
# 0
# resultado da epoca 962 = 938.72 Epsilon = 0.048
# 1
# 0
# resultado da epoca 963 = 1137.66 Epsilon = 0.047
# 1
# 0
# resultado da epoca 964 = 1319.62 Epsilon = 0.046
# 1
# 0
# resultado da epoca 965 = 983.56 Epsilon = 0.045
# 1
# 0
# resultado da epoca 966 = 1162.20 Epsilon = 0.044
# 1
# 0
# resultado da epoca 967 = 1086.74 Epsilon = 0.043
# 1
# 0
# resultado da epoca 968 = 1117.20 Epsilon = 0.042
# 1
# 0
# resultado da epoca 969 = 1131.44 Epsilon = 0.041
# 1
# 0
# resultado da epoca 970 = 693.86 Epsilon = 0.040
# 1
# 0
# resultado da epoca 971 = 1389.32 Epsilon = 0.039
# 1
# 0
# resultado da epoca 972 = 1420.98 Epsilon = 0.038
# 1
# 0
# resultado da epoca 973 = 1301.74 Epsilon = 0.037
# 1
# 0
# resultado da epoca 974 = 1087.50 Epsilon = 0.036
# 1
# 0
# resultado da epoca 975 = 853.56 Epsilon = 0.035
# 1
# 0
# resultado da epoca 976 = 1143.86 Epsilon = 0.034
# 1
# 0
# resultado da epoca 977 = 1301.74 Epsilon = 0.033
# 1
# 0
# resultado da epoca 978 = 1389.62 Epsilon = 0.032
# 1
# 0
# resultado da epoca 979 = 748.86 Epsilon = 0.031
# 1
# 0
# resultado da epoca 980 = 1460.68 Epsilon = 0.030
# 1
# 0
# resultado da epoca 981 = 880.84 Epsilon = 0.029
# 1
# 0
# resultado da epoca 982 = 1615.08 Epsilon = 0.028
# 1
# 0
# resultado da epoca 983 = 1190.08 Epsilon = 0.027
# 1
# 0
# resultado da epoca 984 = 1068.56 Epsilon = 0.026
# 1
# 0
# resultado da epoca 985 = 1093.42 Epsilon = 0.025
# 1
# 0
# resultado da epoca 986 = 1053.72 Epsilon = 0.024
# 1
# 0
# resultado da epoca 987 = 1164.78 Epsilon = 0.023
# 1
# 0
# resultado da epoca 988 = 1430.38 Epsilon = 0.022
# 1
# 0
# resultado da epoca 989 = 1430.38 Epsilon = 0.021
# 1
# 0
# resultado da epoca 990 = 1414.32 Epsilon = 0.020
# 1
# 0
# resultado da epoca 991 = 1780.08 Epsilon = 0.019
# 1
# 0
# resultado da epoca 992 = 1724.02 Epsilon = 0.018
# 1
# 0
# resultado da epoca 993 = 1654.02 Epsilon = 0.017
# 1
# 0
# resultado da epoca 994 = 1416.90 Epsilon = 0.016
# 1
# 0
# resultado da epoca 995 = 1404.78 Epsilon = 0.015
# 1
# 0
# resultado da epoca 996 = 1424.32 Epsilon = 0.014
# 1
# 0
# resultado da epoca 997 = 1304.02 Epsilon = 0.013
# 1
# 0
# resultado da epoca 998 = 1304.02 Epsilon = 0.012
# 1
# 0
# resultado da epoca 999 = 1097.66 Epsilon = 0.011
# 1
# 0
# resultado da epoca 1000 = 1321.90 Epsilon = 0.010
# 1
# 0
# resultado da epoca 1001 = 1239.78 Epsilon = 0.010
# 1
# 0
# resultado da epoca 1002 = 1028.26 Epsilon = 0.010
# 1
# 0
# resultado da epoca 1003 = 1243.26 Epsilon = 0.010
# 1
# 0
# resultado da epoca 1004 = 1028.26 Epsilon = 0.010
# 1
# 0
# 0
# 0
# Melhor resultado diario: 9025.64
