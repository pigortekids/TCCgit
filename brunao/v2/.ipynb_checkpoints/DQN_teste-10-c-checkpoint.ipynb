# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma']#, 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 5

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
inputs_nao_norm = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# C:\Users\core\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\core\Anaconda3\lib\site-packages\pandas\core\indexing.py:562: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 5
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.98     # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        model.add(Dense(512, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(64, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(32, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(x*3, activation='relu')) #camada escondida
        #model.add(Dense(x*2, activation='relu')) #camada escondida
        #model.add(Dense(x, activation='relu')) #camada escondida
        #model.add(Dense(64, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size) if dias>5 else self.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3072
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 11)                363
# =================================================================
# Total params: 177,995
# Trainable params: 177,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(preco, ncont, acao, valor, custo=0):   

    if acao == 0: #zerado
        if ncont>0:  #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        elif ncont<0: #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        else:         
            reward = 0
        valor = -100
    elif acao>0:  #comprado
        if ncont>0:
            if acao>ncont: #aumento da posicao
                reward = -custo*(acao-ncont)
                valor = (valor*ncont+(acao-ncont)*preco)/(acao)  #calculo preco medio
            elif acao<ncont:  #diminuicao da posicao
                reward = (ncont-acao)*(preco-valor) -custo*(ncont-acao)
                valor = valor #preco medio se mantem
            else:
                reward = 0
        elif ncont<0:   #trocando a mao
            reward = abs(ncont)*(valor-preco) -custo*(acao+abs(ncont))
            valor = preco
        else:          #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
    else:       #vendido
        if ncont>0:#trocando a mao
            reward = ncont*(preco-valor) -custo*(ncont+abs(acao))
            valor = preco
        elif ncont<0:
            if abs(acao)<abs(ncont): #diminuicao da posicao
                reward = (abs(ncont)-abs(acao))*(valor-preco) -custo*(abs(ncont)-abs(acao))
                valor = valor #preco medio se mantem
            elif abs(acao)>abs(ncont): #aumento da posicao
                reward = -custo*(abs(acao)-abs(ncont))
                valor = (valor*abs(ncont)+(abs(acao)-abs(ncont))*preco)/(abs(acao))  #calculo preco medio
            else: #preco medio se mantem
                reward = 0
        else:  #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
                
    #reward = ncont*acao*preco
    ncont = acao
    posicao = ncont*(preco-valor) -custo*abs(ncont) if ncont!=0 else 0.
    return ncont, reward, valor, posicao

def obter_acao():
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -100 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    indice = 0
    lucro = 0.
    posicao = 0. #cria variavel de posicao 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont/lim_cont, indice/step_max, precos['preco'][step], valor, precos['preco_pon'][step]], (1,modelo.state_size))
        
        acao = obter_acao()
        ncont, reward, valor, posicao = teste(precos['preco'][step], ncont, acao, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor*pstd+pmean if valor!=-100 else 0
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; reward={2} valor={3} preco={4}".format(acao, ncont, reward, valor, precos['preco'][step]))   

        if step == (steps[dia+1] - 1): #se ultimo step do dia
            done = True     
        
        modelo.next_state = np.reshape([ncont/lim_cont, (indice+1)/step_max, precos['preco'][step+1], valor, precos['preco_pon'][step+1]], (1,modelo.state_size))
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        indice += 1
        
    #fim do dia
    lucro +=posicao
    
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 0, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        
        minibatch = random.sample(modelo.memory, batch_size) if dias>5 else modelo.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    melhor_reward = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1112 18:35:27.795638  8852 deprecation_wrapper.py:119] From C:\Users\core\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1112 18:35:29.551842  8852 deprecation_wrapper.py:119] From C:\Users\core\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1112 18:35:29.662387  8852 deprecation_wrapper.py:119] From C:\Users\core\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -14.30 Epsilon = 1.000
# resultado da epoca 1 = -3.62 Epsilon = 0.999
# resultado da epoca 2 = -1.99 Epsilon = 0.998
# resultado da epoca 3 = -9.46 Epsilon = 0.997
# resultado da epoca 4 = -5.42 Epsilon = 0.996
# resultado da epoca 5 = 2.02 Epsilon = 0.995
# resultado da epoca 6 = 5.45 Epsilon = 0.994
# resultado da epoca 7 = -8.45 Epsilon = 0.993
# resultado da epoca 8 = 21.48 Epsilon = 0.992
# resultado da epoca 9 = 19.27 Epsilon = 0.991
# resultado da epoca 10 = 4.25 Epsilon = 0.990
# resultado da epoca 11 = -4.44 Epsilon = 0.989
# resultado da epoca 12 = 6.91 Epsilon = 0.988
# resultado da epoca 13 = -4.73 Epsilon = 0.987
# resultado da epoca 14 = 17.86 Epsilon = 0.986
# resultado da epoca 15 = 0.93 Epsilon = 0.985
# resultado da epoca 16 = -5.42 Epsilon = 0.984
# resultado da epoca 17 = 3.56 Epsilon = 0.983
# resultado da epoca 18 = -3.16 Epsilon = 0.982
# resultado da epoca 19 = 2.05 Epsilon = 0.981
# resultado da epoca 20 = -24.99 Epsilon = 0.980
# resultado da epoca 21 = -7.28 Epsilon = 0.979
# resultado da epoca 22 = -12.23 Epsilon = 0.978
# resultado da epoca 23 = -6.91 Epsilon = 0.977
# resultado da epoca 24 = 11.88 Epsilon = 0.976
# resultado da epoca 25 = -2.71 Epsilon = 0.975
# resultado da epoca 26 = -18.53 Epsilon = 0.974
# resultado da epoca 27 = 3.46 Epsilon = 0.973
# resultado da epoca 28 = 7.60 Epsilon = 0.972
# resultado da epoca 29 = -17.33 Epsilon = 0.971
# resultado da epoca 30 = -5.10 Epsilon = 0.970
# resultado da epoca 31 = -1.22 Epsilon = 0.969
# resultado da epoca 32 = -4.68 Epsilon = 0.968
# resultado da epoca 33 = -12.92 Epsilon = 0.967
# resultado da epoca 34 = -8.11 Epsilon = 0.966
# resultado da epoca 35 = -11.70 Epsilon = 0.965
# resultado da epoca 36 = 10.31 Epsilon = 0.964
# resultado da epoca 37 = 5.18 Epsilon = 0.963
# resultado da epoca 38 = 7.07 Epsilon = 0.962
# resultado da epoca 39 = 4.86 Epsilon = 0.961
# resultado da epoca 40 = 13.11 Epsilon = 0.960
# resultado da epoca 41 = -10.79 Epsilon = 0.959
# resultado da epoca 42 = -15.02 Epsilon = 0.958
# resultado da epoca 43 = 9.14 Epsilon = 0.957
# resultado da epoca 44 = 7.18 Epsilon = 0.956
# resultado da epoca 45 = -13.13 Epsilon = 0.955
# resultado da epoca 46 = 17.86 Epsilon = 0.954
# resultado da epoca 47 = -11.38 Epsilon = 0.953
# resultado da epoca 48 = -0.64 Epsilon = 0.952
# resultado da epoca 49 = -1.33 Epsilon = 0.951
# resultado da epoca 50 = -8.93 Epsilon = 0.950
# resultado da epoca 51 = -13.96 Epsilon = 0.950
# resultado da epoca 52 = -5.85 Epsilon = 0.949
# resultado da epoca 53 = 7.76 Epsilon = 0.948
# resultado da epoca 54 = -6.06 Epsilon = 0.947
# resultado da epoca 55 = 2.84 Epsilon = 0.946
# resultado da epoca 56 = 13.98 Epsilon = 0.945
# resultado da epoca 57 = -1.97 Epsilon = 0.944
# resultado da epoca 58 = -1.97 Epsilon = 0.943
# resultado da epoca 59 = 16.22 Epsilon = 0.942
# resultado da epoca 60 = -9.76 Epsilon = 0.941
# resultado da epoca 61 = 4.04 Epsilon = 0.940
# resultado da epoca 62 = -2.68 Epsilon = 0.939
# resultado da epoca 63 = 26.40 Epsilon = 0.938
# resultado da epoca 64 = 7.28 Epsilon = 0.937
# resultado da epoca 65 = 21.35 Epsilon = 0.936
# resultado da epoca 66 = 5.05 Epsilon = 0.935
# resultado da epoca 67 = 18.16 Epsilon = 0.934
# resultado da epoca 68 = 4.71 Epsilon = 0.933
# resultado da epoca 69 = 2.66 Epsilon = 0.932
# resultado da epoca 70 = 0.35 Epsilon = 0.931
# resultado da epoca 71 = -4.49 Epsilon = 0.930
# resultado da epoca 72 = 0.00 Epsilon = 0.929
# resultado da epoca 73 = -10.21 Epsilon = 0.928
# resultado da epoca 74 = 1.06 Epsilon = 0.927
# resultado da epoca 75 = 17.01 Epsilon = 0.926
# resultado da epoca 76 = 14.97 Epsilon = 0.925
# resultado da epoca 77 = -11.01 Epsilon = 0.924
# resultado da epoca 78 = 10.15 Epsilon = 0.923
# resultado da epoca 79 = -2.45 Epsilon = 0.922
# resultado da epoca 80 = 11.06 Epsilon = 0.921
# resultado da epoca 81 = -2.42 Epsilon = 0.920
# resultado da epoca 82 = -7.58 Epsilon = 0.919
# resultado da epoca 83 = 9.01 Epsilon = 0.918
# resultado da epoca 84 = 2.87 Epsilon = 0.917
# resultado da epoca 85 = -14.67 Epsilon = 0.916
# resultado da epoca 86 = -8.64 Epsilon = 0.915
# resultado da epoca 87 = -17.12 Epsilon = 0.914
# resultado da epoca 88 = 3.80 Epsilon = 0.913
# resultado da epoca 89 = -15.50 Epsilon = 0.912
# resultado da epoca 90 = 6.73 Epsilon = 0.911
# resultado da epoca 91 = -9.25 Epsilon = 0.910
# resultado da epoca 92 = -1.97 Epsilon = 0.909
# resultado da epoca 93 = -9.44 Epsilon = 0.908
# resultado da epoca 94 = 3.43 Epsilon = 0.907
# resultado da epoca 95 = 5.87 Epsilon = 0.906
# resultado da epoca 96 = -6.75 Epsilon = 0.905
# resultado da epoca 97 = 5.10 Epsilon = 0.904
# resultado da epoca 98 = -17.84 Epsilon = 0.903
# resultado da epoca 99 = 5.05 Epsilon = 0.902
# resultado da epoca 100 = -12.55 Epsilon = 0.901
# resultado da epoca 101 = -13.82 Epsilon = 0.900
# resultado da epoca 102 = 19.91 Epsilon = 0.899
# resultado da epoca 103 = -10.47 Epsilon = 0.898
# resultado da epoca 104 = 2.53 Epsilon = 0.897
# resultado da epoca 105 = -19.03 Epsilon = 0.896
# resultado da epoca 106 = 5.02 Epsilon = 0.895
# resultado da epoca 107 = 3.38 Epsilon = 0.894
# resultado da epoca 108 = -15.23 Epsilon = 0.893
# resultado da epoca 109 = 23.58 Epsilon = 0.892
# resultado da epoca 110 = 7.74 Epsilon = 0.891
# resultado da epoca 111 = 6.14 Epsilon = 0.890
# resultado da epoca 112 = 12.52 Epsilon = 0.889
# resultado da epoca 113 = 7.34 Epsilon = 0.888
# resultado da epoca 114 = -19.33 Epsilon = 0.887
# resultado da epoca 115 = 2.71 Epsilon = 0.886
# resultado da epoca 116 = -13.13 Epsilon = 0.885
# resultado da epoca 117 = 4.71 Epsilon = 0.884
# resultado da epoca 118 = -2.13 Epsilon = 0.883
# resultado da epoca 119 = 3.96 Epsilon = 0.882
# resultado da epoca 120 = -5.42 Epsilon = 0.881
# resultado da epoca 121 = -16.59 Epsilon = 0.880
# resultado da epoca 122 = 10.58 Epsilon = 0.879
# resultado da epoca 123 = -0.85 Epsilon = 0.878
# resultado da epoca 124 = 11.72 Epsilon = 0.877
# resultado da epoca 125 = -3.77 Epsilon = 0.876
# resultado da epoca 126 = -5.48 Epsilon = 0.875
# resultado da epoca 127 = -7.74 Epsilon = 0.874
# resultado da epoca 128 = -16.48 Epsilon = 0.873
# resultado da epoca 129 = 0.29 Epsilon = 0.872
# resultado da epoca 130 = -10.79 Epsilon = 0.871
# resultado da epoca 131 = 2.98 Epsilon = 0.870
# resultado da epoca 132 = 16.06 Epsilon = 0.869
# resultado da epoca 133 = 6.70 Epsilon = 0.868
# resultado da epoca 134 = 7.52 Epsilon = 0.867
# resultado da epoca 135 = -1.41 Epsilon = 0.866
# resultado da epoca 136 = -8.40 Epsilon = 0.865
# resultado da epoca 137 = 17.76 Epsilon = 0.864
# resultado da epoca 138 = 6.51 Epsilon = 0.863
# resultado da epoca 139 = -3.80 Epsilon = 0.862
# resultado da epoca 140 = 8.45 Epsilon = 0.861
# resultado da epoca 141 = 6.59 Epsilon = 0.860
# resultado da epoca 142 = -15.98 Epsilon = 0.859
# resultado da epoca 143 = -8.32 Epsilon = 0.858
# resultado da epoca 144 = 17.01 Epsilon = 0.857
# resultado da epoca 145 = -16.24 Epsilon = 0.856
# resultado da epoca 146 = -11.40 Epsilon = 0.855
# resultado da epoca 147 = -18.95 Epsilon = 0.854
# resultado da epoca 148 = 3.22 Epsilon = 0.853
# resultado da epoca 149 = -2.10 Epsilon = 0.852
# resultado da epoca 150 = 14.33 Epsilon = 0.851
# resultado da epoca 151 = -23.15 Epsilon = 0.851
# resultado da epoca 152 = -14.41 Epsilon = 0.850
# resultado da epoca 153 = -12.41 Epsilon = 0.849
# resultado da epoca 154 = 3.83 Epsilon = 0.848
# resultado da epoca 155 = -8.21 Epsilon = 0.847
# resultado da epoca 156 = 0.85 Epsilon = 0.846
# resultado da epoca 157 = 6.59 Epsilon = 0.845
# resultado da epoca 158 = 7.74 Epsilon = 0.844
# resultado da epoca 159 = -2.37 Epsilon = 0.843
# resultado da epoca 160 = -1.01 Epsilon = 0.842
# resultado da epoca 161 = -0.45 Epsilon = 0.841
# resultado da epoca 162 = -25.41 Epsilon = 0.840
# resultado da epoca 163 = -28.90 Epsilon = 0.839
# resultado da epoca 164 = 2.29 Epsilon = 0.838
# resultado da epoca 165 = 3.88 Epsilon = 0.837
# resultado da epoca 166 = 15.74 Epsilon = 0.836
# resultado da epoca 167 = -4.78 Epsilon = 0.835
# resultado da epoca 168 = -13.32 Epsilon = 0.834
# resultado da epoca 169 = 11.16 Epsilon = 0.833
# resultado da epoca 170 = 0.93 Epsilon = 0.832
# resultado da epoca 171 = 4.07 Epsilon = 0.831
# resultado da epoca 172 = -8.88 Epsilon = 0.830
# resultado da epoca 173 = 7.92 Epsilon = 0.829
# resultado da epoca 174 = 10.31 Epsilon = 0.828
# resultado da epoca 175 = -8.35 Epsilon = 0.827
# resultado da epoca 176 = -17.92 Epsilon = 0.826
# resultado da epoca 177 = -0.64 Epsilon = 0.825
# resultado da epoca 178 = -13.85 Epsilon = 0.824
# resultado da epoca 179 = 10.55 Epsilon = 0.823
# resultado da epoca 180 = 0.69 Epsilon = 0.822
# resultado da epoca 181 = -16.48 Epsilon = 0.821
# resultado da epoca 182 = -11.80 Epsilon = 0.820
# resultado da epoca 183 = -9.68 Epsilon = 0.819
# resultado da epoca 184 = 8.21 Epsilon = 0.818
# resultado da epoca 185 = 15.95 Epsilon = 0.817
# resultado da epoca 186 = 6.35 Epsilon = 0.816
# resultado da epoca 187 = 8.45 Epsilon = 0.815
# resultado da epoca 188 = -20.31 Epsilon = 0.814
# resultado da epoca 189 = 11.30 Epsilon = 0.813
# resultado da epoca 190 = 2.63 Epsilon = 0.812
# resultado da epoca 191 = 10.74 Epsilon = 0.811
# resultado da epoca 192 = 19.99 Epsilon = 0.810
# resultado da epoca 193 = -16.96 Epsilon = 0.809
# resultado da epoca 194 = -5.77 Epsilon = 0.808
# resultado da epoca 195 = 1.28 Epsilon = 0.807
# resultado da epoca 196 = -9.89 Epsilon = 0.806
# resultado da epoca 197 = -3.03 Epsilon = 0.805
# resultado da epoca 198 = -2.66 Epsilon = 0.804
# resultado da epoca 199 = 4.15 Epsilon = 0.803
# resultado da epoca 200 = -10.00 Epsilon = 0.802
# resultado da epoca 201 = -0.45 Epsilon = 0.801
# resultado da epoca 202 = -14.14 Epsilon = 0.800
# resultado da epoca 203 = 4.65 Epsilon = 0.799
# resultado da epoca 204 = 4.12 Epsilon = 0.798
# resultado da epoca 205 = -9.65 Epsilon = 0.797
# resultado da epoca 206 = 7.92 Epsilon = 0.796
# resultado da epoca 207 = -0.45 Epsilon = 0.795
# resultado da epoca 208 = -7.07 Epsilon = 0.794
# resultado da epoca 209 = 5.53 Epsilon = 0.793
# resultado da epoca 210 = -4.52 Epsilon = 0.792
# resultado da epoca 211 = -6.49 Epsilon = 0.791
# resultado da epoca 212 = 7.50 Epsilon = 0.790
# resultado da epoca 213 = 12.60 Epsilon = 0.789
# resultado da epoca 214 = -12.65 Epsilon = 0.788
# resultado da epoca 215 = 1.44 Epsilon = 0.787
# resultado da epoca 216 = -0.64 Epsilon = 0.786
# resultado da epoca 217 = 1.20 Epsilon = 0.785
# resultado da epoca 218 = -0.03 Epsilon = 0.784
# resultado da epoca 219 = 1.44 Epsilon = 0.783
# resultado da epoca 220 = -1.52 Epsilon = 0.782
# resultado da epoca 221 = 4.63 Epsilon = 0.781
# resultado da epoca 222 = 9.33 Epsilon = 0.780
# resultado da epoca 223 = 5.13 Epsilon = 0.779
# resultado da epoca 224 = 7.79 Epsilon = 0.778
# resultado da epoca 225 = 20.20 Epsilon = 0.777
# resultado da epoca 226 = 5.10 Epsilon = 0.776
# resultado da epoca 227 = -15.23 Epsilon = 0.775
# resultado da epoca 228 = 1.17 Epsilon = 0.774
# resultado da epoca 229 = -4.84 Epsilon = 0.773
# resultado da epoca 230 = 2.47 Epsilon = 0.772
# resultado da epoca 231 = -11.62 Epsilon = 0.771
# resultado da epoca 232 = -7.04 Epsilon = 0.770
# resultado da epoca 233 = -5.18 Epsilon = 0.769
# resultado da epoca 234 = 14.81 Epsilon = 0.768
# resultado da epoca 235 = 27.83 Epsilon = 0.767
# resultado da epoca 236 = 22.36 Epsilon = 0.766
# resultado da epoca 237 = 8.48 Epsilon = 0.765
# resultado da epoca 238 = -10.50 Epsilon = 0.764
# resultado da epoca 239 = -5.48 Epsilon = 0.763
# resultado da epoca 240 = 7.97 Epsilon = 0.762
# resultado da epoca 241 = 23.42 Epsilon = 0.761
# resultado da epoca 242 = 9.97 Epsilon = 0.760
# resultado da epoca 243 = -14.17 Epsilon = 0.759
# resultado da epoca 244 = -15.10 Epsilon = 0.758
# resultado da epoca 245 = -4.31 Epsilon = 0.757
# resultado da epoca 246 = 11.27 Epsilon = 0.756
# resultado da epoca 247 = 22.60 Epsilon = 0.755
# resultado da epoca 248 = -3.56 Epsilon = 0.754
# resultado da epoca 249 = 3.46 Epsilon = 0.753
# resultado da epoca 250 = -2.05 Epsilon = 0.752
# resultado da epoca 251 = 17.92 Epsilon = 0.752
# resultado da epoca 252 = 2.92 Epsilon = 0.751
# resultado da epoca 253 = -0.00 Epsilon = 0.750
# resultado da epoca 254 = 4.73 Epsilon = 0.749
# resultado da epoca 255 = -2.66 Epsilon = 0.748
# resultado da epoca 256 = 4.01 Epsilon = 0.747
# resultado da epoca 257 = 1.75 Epsilon = 0.746
# resultado da epoca 258 = 18.98 Epsilon = 0.745
# resultado da epoca 259 = -4.94 Epsilon = 0.744
# resultado da epoca 260 = -6.35 Epsilon = 0.743
# resultado da epoca 261 = -14.65 Epsilon = 0.742
# resultado da epoca 262 = 1.22 Epsilon = 0.741
# resultado da epoca 263 = 5.98 Epsilon = 0.740
# resultado da epoca 264 = 10.47 Epsilon = 0.739
# resultado da epoca 265 = 0.51 Epsilon = 0.738
# resultado da epoca 266 = 3.40 Epsilon = 0.737
# resultado da epoca 267 = -2.42 Epsilon = 0.736
# resultado da epoca 268 = 14.59 Epsilon = 0.735
# resultado da epoca 269 = -2.23 Epsilon = 0.734
# resultado da epoca 270 = -0.43 Epsilon = 0.733
# resultado da epoca 271 = 0.48 Epsilon = 0.732
# resultado da epoca 272 = -14.65 Epsilon = 0.731
# resultado da epoca 273 = -7.97 Epsilon = 0.730
# resultado da epoca 274 = 0.66 Epsilon = 0.729
# resultado da epoca 275 = -10.95 Epsilon = 0.728
# resultado da epoca 276 = 5.95 Epsilon = 0.727
# resultado da epoca 277 = 9.12 Epsilon = 0.726
# resultado da epoca 278 = -0.37 Epsilon = 0.725
# resultado da epoca 279 = 3.08 Epsilon = 0.724
# resultado da epoca 280 = 6.51 Epsilon = 0.723
# resultado da epoca 281 = 17.76 Epsilon = 0.722
# resultado da epoca 282 = 11.54 Epsilon = 0.721
# resultado da epoca 283 = -1.46 Epsilon = 0.720
# resultado da epoca 284 = 13.96 Epsilon = 0.719
# resultado da epoca 285 = 18.77 Epsilon = 0.718
# resultado da epoca 286 = -5.32 Epsilon = 0.717
# resultado da epoca 287 = 2.74 Epsilon = 0.716
# resultado da epoca 288 = 6.81 Epsilon = 0.715
# resultado da epoca 289 = 18.08 Epsilon = 0.714
# resultado da epoca 290 = 6.22 Epsilon = 0.713
# resultado da epoca 291 = 6.33 Epsilon = 0.712
# resultado da epoca 292 = -3.56 Epsilon = 0.711
# resultado da epoca 293 = 12.87 Epsilon = 0.710
# resultado da epoca 294 = 0.61 Epsilon = 0.709
# resultado da epoca 295 = 4.07 Epsilon = 0.708
# resultado da epoca 296 = 6.22 Epsilon = 0.707
# resultado da epoca 297 = 5.95 Epsilon = 0.706
# resultado da epoca 298 = -3.99 Epsilon = 0.705
# resultado da epoca 299 = 16.53 Epsilon = 0.704
# resultado da epoca 300 = 15.71 Epsilon = 0.703
# resultado da epoca 301 = 4.89 Epsilon = 0.702
# resultado da epoca 302 = 21.05 Epsilon = 0.701
# resultado da epoca 303 = -9.65 Epsilon = 0.700
# resultado da epoca 304 = 5.16 Epsilon = 0.699
# resultado da epoca 305 = -0.27 Epsilon = 0.698
# resultado da epoca 306 = 12.12 Epsilon = 0.697
# resultado da epoca 307 = -23.07 Epsilon = 0.696
# resultado da epoca 308 = -10.87 Epsilon = 0.695
# resultado da epoca 309 = 9.60 Epsilon = 0.694
# resultado da epoca 310 = 15.28 Epsilon = 0.693
# resultado da epoca 311 = 0.61 Epsilon = 0.692
# resultado da epoca 312 = 32.01 Epsilon = 0.691
# resultado da epoca 313 = -13.69 Epsilon = 0.690
# resultado da epoca 314 = 2.61 Epsilon = 0.689
# resultado da epoca 315 = 14.89 Epsilon = 0.688
# resultado da epoca 316 = -1.12 Epsilon = 0.687
# resultado da epoca 317 = -6.59 Epsilon = 0.686
# resultado da epoca 318 = 19.41 Epsilon = 0.685
# resultado da epoca 319 = -18.61 Epsilon = 0.684
# resultado da epoca 320 = 1.22 Epsilon = 0.683
# resultado da epoca 321 = -7.39 Epsilon = 0.682
# resultado da epoca 322 = 15.18 Epsilon = 0.681
# resultado da epoca 323 = -29.05 Epsilon = 0.680
# resultado da epoca 324 = 7.20 Epsilon = 0.679
# resultado da epoca 325 = 2.39 Epsilon = 0.678
# resultado da epoca 326 = 4.17 Epsilon = 0.677
# resultado da epoca 327 = 5.93 Epsilon = 0.676
# resultado da epoca 328 = 20.95 Epsilon = 0.675
# resultado da epoca 329 = 18.82 Epsilon = 0.674
# resultado da epoca 330 = 13.77 Epsilon = 0.673
# resultado da epoca 331 = -3.30 Epsilon = 0.672
# resultado da epoca 332 = -10.53 Epsilon = 0.671
# resultado da epoca 333 = 12.52 Epsilon = 0.670
# resultado da epoca 334 = -12.52 Epsilon = 0.669
# resultado da epoca 335 = 14.41 Epsilon = 0.668
# resultado da epoca 336 = -9.22 Epsilon = 0.667
# resultado da epoca 337 = 6.03 Epsilon = 0.666
# resultado da epoca 338 = 17.04 Epsilon = 0.665
# resultado da epoca 339 = 1.57 Epsilon = 0.664
# resultado da epoca 340 = 2.02 Epsilon = 0.663
# resultado da epoca 341 = 20.34 Epsilon = 0.662
# resultado da epoca 342 = 9.70 Epsilon = 0.661
# resultado da epoca 343 = -6.06 Epsilon = 0.660
# resultado da epoca 344 = 12.15 Epsilon = 0.659
# resultado da epoca 345 = -4.86 Epsilon = 0.658
# resultado da epoca 346 = -13.69 Epsilon = 0.657
# resultado da epoca 347 = -7.42 Epsilon = 0.656
# resultado da epoca 348 = 7.60 Epsilon = 0.655
# resultado da epoca 349 = 5.56 Epsilon = 0.654
# resultado da epoca 350 = 16.03 Epsilon = 0.653
# resultado da epoca 351 = -1.49 Epsilon = 0.653
# resultado da epoca 352 = -2.05 Epsilon = 0.652
# resultado da epoca 353 = 5.56 Epsilon = 0.651
# resultado da epoca 354 = -13.05 Epsilon = 0.650
# resultado da epoca 355 = 1.70 Epsilon = 0.649
# resultado da epoca 356 = -4.76 Epsilon = 0.648
# resultado da epoca 357 = -8.61 Epsilon = 0.647
# resultado da epoca 358 = 5.82 Epsilon = 0.646
# resultado da epoca 359 = 0.51 Epsilon = 0.645
# resultado da epoca 360 = 6.41 Epsilon = 0.644
# resultado da epoca 361 = 9.78 Epsilon = 0.643
# resultado da epoca 362 = 0.56 Epsilon = 0.642
# resultado da epoca 363 = -11.62 Epsilon = 0.641
# resultado da epoca 364 = -22.44 Epsilon = 0.640
# resultado da epoca 365 = -15.82 Epsilon = 0.639
# resultado da epoca 366 = -9.62 Epsilon = 0.638
# resultado da epoca 367 = -13.64 Epsilon = 0.637
# resultado da epoca 368 = -11.11 Epsilon = 0.636
# resultado da epoca 369 = -7.23 Epsilon = 0.635
# resultado da epoca 370 = 13.56 Epsilon = 0.634
# resultado da epoca 371 = 0.77 Epsilon = 0.633
# resultado da epoca 372 = 0.35 Epsilon = 0.632
# resultado da epoca 373 = -23.34 Epsilon = 0.631
# resultado da epoca 374 = -5.72 Epsilon = 0.630
# resultado da epoca 375 = -7.95 Epsilon = 0.629
# resultado da epoca 376 = -5.85 Epsilon = 0.628
# resultado da epoca 377 = 2.13 Epsilon = 0.627
# resultado da epoca 378 = -8.21 Epsilon = 0.626
# resultado da epoca 379 = -19.96 Epsilon = 0.625
# resultado da epoca 380 = -4.09 Epsilon = 0.624
# resultado da epoca 381 = 4.76 Epsilon = 0.623
# resultado da epoca 382 = 4.65 Epsilon = 0.622
# resultado da epoca 383 = 1.52 Epsilon = 0.621
# resultado da epoca 384 = -10.10 Epsilon = 0.620
# resultado da epoca 385 = -4.81 Epsilon = 0.619
# resultado da epoca 386 = -7.97 Epsilon = 0.618
# resultado da epoca 387 = -13.24 Epsilon = 0.617
# resultado da epoca 388 = 17.33 Epsilon = 0.616
# resultado da epoca 389 = 13.72 Epsilon = 0.615
# resultado da epoca 390 = -7.50 Epsilon = 0.614
# resultado da epoca 391 = -7.15 Epsilon = 0.613
# resultado da epoca 392 = -1.22 Epsilon = 0.612
# resultado da epoca 393 = -3.67 Epsilon = 0.611
# resultado da epoca 394 = 13.08 Epsilon = 0.610
# resultado da epoca 395 = 19.14 Epsilon = 0.609
# resultado da epoca 396 = 7.36 Epsilon = 0.608
# resultado da epoca 397 = 1.75 Epsilon = 0.607
# resultado da epoca 398 = 4.41 Epsilon = 0.606
# resultado da epoca 399 = 0.85 Epsilon = 0.605
# resultado da epoca 400 = 7.87 Epsilon = 0.604
# resultado da epoca 401 = 11.43 Epsilon = 0.603
# resultado da epoca 402 = 23.55 Epsilon = 0.602
# resultado da epoca 403 = 13.61 Epsilon = 0.601
# resultado da epoca 404 = 2.53 Epsilon = 0.600
# resultado da epoca 405 = 25.04 Epsilon = 0.599
# resultado da epoca 406 = 15.13 Epsilon = 0.598
# resultado da epoca 407 = 24.48 Epsilon = 0.597
# resultado da epoca 408 = 13.64 Epsilon = 0.596
# resultado da epoca 409 = -3.22 Epsilon = 0.595
# resultado da epoca 410 = 10.18 Epsilon = 0.594
# resultado da epoca 411 = -8.45 Epsilon = 0.593
# resultado da epoca 412 = -3.99 Epsilon = 0.592
# resultado da epoca 413 = 0.43 Epsilon = 0.591
# resultado da epoca 414 = -0.24 Epsilon = 0.590
# resultado da epoca 415 = -10.39 Epsilon = 0.589
# resultado da epoca 416 = -5.69 Epsilon = 0.588
# resultado da epoca 417 = 0.43 Epsilon = 0.587
# resultado da epoca 418 = 12.65 Epsilon = 0.586
# resultado da epoca 419 = -4.44 Epsilon = 0.585
# resultado da epoca 420 = -14.51 Epsilon = 0.584
# resultado da epoca 421 = -7.04 Epsilon = 0.583
# resultado da epoca 422 = 20.10 Epsilon = 0.582
# resultado da epoca 423 = -14.70 Epsilon = 0.581
# resultado da epoca 424 = -3.51 Epsilon = 0.580
# resultado da epoca 425 = 2.21 Epsilon = 0.579
# resultado da epoca 426 = -1.33 Epsilon = 0.578
# resultado da epoca 427 = -11.64 Epsilon = 0.577
# resultado da epoca 428 = 24.43 Epsilon = 0.576
# resultado da epoca 429 = -5.29 Epsilon = 0.575
# resultado da epoca 430 = -4.57 Epsilon = 0.574
# resultado da epoca 431 = 35.12 Epsilon = 0.573
# resultado da epoca 432 = 27.49 Epsilon = 0.572
# resultado da epoca 433 = -2.02 Epsilon = 0.571
# resultado da epoca 434 = 22.81 Epsilon = 0.570
# resultado da epoca 435 = 2.95 Epsilon = 0.569
# resultado da epoca 436 = 4.31 Epsilon = 0.568
# resultado da epoca 437 = -0.77 Epsilon = 0.567
# resultado da epoca 438 = 9.01 Epsilon = 0.566
# resultado da epoca 439 = 7.58 Epsilon = 0.565
# resultado da epoca 440 = -4.01 Epsilon = 0.564
# resultado da epoca 441 = 16.93 Epsilon = 0.563
# resultado da epoca 442 = 4.92 Epsilon = 0.562
# resultado da epoca 443 = 13.98 Epsilon = 0.561
# resultado da epoca 444 = 2.13 Epsilon = 0.560
# resultado da epoca 445 = 14.91 Epsilon = 0.559
# resultado da epoca 446 = -9.54 Epsilon = 0.558
# resultado da epoca 447 = 13.34 Epsilon = 0.557
# resultado da epoca 448 = 15.21 Epsilon = 0.556
# resultado da epoca 449 = -2.71 Epsilon = 0.555
# resultado da epoca 450 = 14.27 Epsilon = 0.554
# resultado da epoca 451 = -5.05 Epsilon = 0.554
# resultado da epoca 452 = -2.13 Epsilon = 0.553
# resultado da epoca 453 = -12.07 Epsilon = 0.552
# resultado da epoca 454 = 19.43 Epsilon = 0.551
# resultado da epoca 455 = 8.03 Epsilon = 0.550
# resultado da epoca 456 = 14.09 Epsilon = 0.549
# resultado da epoca 457 = 10.39 Epsilon = 0.548
# resultado da epoca 458 = 18.45 Epsilon = 0.547
# resultado da epoca 459 = 6.73 Epsilon = 0.546
# resultado da epoca 460 = 4.01 Epsilon = 0.545
# resultado da epoca 461 = 16.35 Epsilon = 0.544
# resultado da epoca 462 = 6.83 Epsilon = 0.543
# resultado da epoca 463 = 16.59 Epsilon = 0.542
# resultado da epoca 464 = 13.50 Epsilon = 0.541
# resultado da epoca 465 = 3.96 Epsilon = 0.540
# resultado da epoca 466 = 19.06 Epsilon = 0.539
# resultado da epoca 467 = 15.79 Epsilon = 0.538
# resultado da epoca 468 = 8.53 Epsilon = 0.537
# resultado da epoca 469 = -7.97 Epsilon = 0.536
# resultado da epoca 470 = -0.27 Epsilon = 0.535
# resultado da epoca 471 = 4.49 Epsilon = 0.534
# resultado da epoca 472 = 5.13 Epsilon = 0.533
# resultado da epoca 473 = 13.56 Epsilon = 0.532
# resultado da epoca 474 = 29.59 Epsilon = 0.531
# resultado da epoca 475 = 13.74 Epsilon = 0.530
# resultado da epoca 476 = 8.48 Epsilon = 0.529
# resultado da epoca 477 = 12.76 Epsilon = 0.528
# resultado da epoca 478 = -0.16 Epsilon = 0.527
# resultado da epoca 479 = -29.91 Epsilon = 0.526
# resultado da epoca 480 = -11.01 Epsilon = 0.525
# resultado da epoca 481 = 8.27 Epsilon = 0.524
# resultado da epoca 482 = -5.32 Epsilon = 0.523
# resultado da epoca 483 = -6.01 Epsilon = 0.522
# resultado da epoca 484 = -12.33 Epsilon = 0.521
# resultado da epoca 485 = 13.93 Epsilon = 0.520
# resultado da epoca 486 = 6.62 Epsilon = 0.519
# resultado da epoca 487 = 3.40 Epsilon = 0.518
# resultado da epoca 488 = -8.11 Epsilon = 0.517
# resultado da epoca 489 = 6.62 Epsilon = 0.516
# resultado da epoca 490 = 5.42 Epsilon = 0.515
# resultado da epoca 491 = 5.56 Epsilon = 0.514
# resultado da epoca 492 = -3.30 Epsilon = 0.513
# resultado da epoca 493 = 7.15 Epsilon = 0.512
# resultado da epoca 494 = -0.37 Epsilon = 0.511
# resultado da epoca 495 = 5.61 Epsilon = 0.510
# resultado da epoca 496 = 15.13 Epsilon = 0.509
# resultado da epoca 497 = -5.24 Epsilon = 0.508
# resultado da epoca 498 = 0.88 Epsilon = 0.507
# resultado da epoca 499 = 3.22 Epsilon = 0.506
# resultado da epoca 500 = 15.98 Epsilon = 0.505
# resultado da epoca 501 = -12.07 Epsilon = 0.504
# resultado da epoca 502 = -4.65 Epsilon = 0.503
# resultado da epoca 503 = 10.85 Epsilon = 0.502
# resultado da epoca 504 = 21.13 Epsilon = 0.501
# resultado da epoca 505 = -8.56 Epsilon = 0.500
# resultado da epoca 506 = -2.92 Epsilon = 0.499
# resultado da epoca 507 = 2.71 Epsilon = 0.498
# resultado da epoca 508 = 7.92 Epsilon = 0.497
# resultado da epoca 509 = -5.50 Epsilon = 0.496
# resultado da epoca 510 = 15.68 Epsilon = 0.495
# resultado da epoca 511 = 6.09 Epsilon = 0.494
# resultado da epoca 512 = 0.11 Epsilon = 0.493
# resultado da epoca 513 = 26.02 Epsilon = 0.492
# resultado da epoca 514 = 0.98 Epsilon = 0.491
# resultado da epoca 515 = 11.75 Epsilon = 0.490
# resultado da epoca 516 = 10.10 Epsilon = 0.489
# resultado da epoca 517 = -4.84 Epsilon = 0.488
# resultado da epoca 518 = 4.49 Epsilon = 0.487
# resultado da epoca 519 = 5.08 Epsilon = 0.486
# resultado da epoca 520 = -6.62 Epsilon = 0.485
# resultado da epoca 521 = -23.13 Epsilon = 0.484
# resultado da epoca 522 = 7.04 Epsilon = 0.483
# resultado da epoca 523 = -12.71 Epsilon = 0.482
# resultado da epoca 524 = 5.05 Epsilon = 0.481
# resultado da epoca 525 = 12.39 Epsilon = 0.480
# resultado da epoca 526 = -1.22 Epsilon = 0.479
# resultado da epoca 527 = -12.60 Epsilon = 0.478
# resultado da epoca 528 = -13.66 Epsilon = 0.477
# resultado da epoca 529 = 8.96 Epsilon = 0.476
# resultado da epoca 530 = -6.51 Epsilon = 0.475
# resultado da epoca 531 = 1.25 Epsilon = 0.474
# resultado da epoca 532 = -11.91 Epsilon = 0.473
# resultado da epoca 533 = -16.16 Epsilon = 0.472
# resultado da epoca 534 = -4.63 Epsilon = 0.471
# resultado da epoca 535 = 6.19 Epsilon = 0.470
# resultado da epoca 536 = -10.15 Epsilon = 0.469
# resultado da epoca 537 = 0.88 Epsilon = 0.468
# resultado da epoca 538 = -3.69 Epsilon = 0.467
# resultado da epoca 539 = 4.01 Epsilon = 0.466
# resultado da epoca 540 = -18.95 Epsilon = 0.465
# resultado da epoca 541 = 11.27 Epsilon = 0.464
# resultado da epoca 542 = 3.80 Epsilon = 0.463
# resultado da epoca 543 = -16.61 Epsilon = 0.462
# resultado da epoca 544 = 27.78 Epsilon = 0.461
# resultado da epoca 545 = -1.62 Epsilon = 0.460
# resultado da epoca 546 = 27.65 Epsilon = 0.459
# resultado da epoca 547 = 14.38 Epsilon = 0.458
# resultado da epoca 548 = -10.23 Epsilon = 0.457
# resultado da epoca 549 = 4.36 Epsilon = 0.456
# resultado da epoca 550 = 26.58 Epsilon = 0.455
# resultado da epoca 551 = -29.11 Epsilon = 0.455
# resultado da epoca 552 = -6.27 Epsilon = 0.454
# resultado da epoca 553 = 4.78 Epsilon = 0.453
# resultado da epoca 554 = -5.08 Epsilon = 0.452
# resultado da epoca 555 = -6.43 Epsilon = 0.451
# resultado da epoca 556 = 22.17 Epsilon = 0.450
# resultado da epoca 557 = 11.59 Epsilon = 0.449
# resultado da epoca 558 = 10.34 Epsilon = 0.448
# resultado da epoca 559 = 3.62 Epsilon = 0.447
# resultado da epoca 560 = 30.68 Epsilon = 0.446
# resultado da epoca 561 = -6.35 Epsilon = 0.445
# resultado da epoca 562 = 11.88 Epsilon = 0.444
# resultado da epoca 563 = -6.03 Epsilon = 0.443
# resultado da epoca 564 = 35.73 Epsilon = 0.442
# resultado da epoca 565 = -18.02 Epsilon = 0.441
# resultado da epoca 566 = 5.45 Epsilon = 0.440
# resultado da epoca 567 = -6.22 Epsilon = 0.439
# resultado da epoca 568 = 17.33 Epsilon = 0.438
# resultado da epoca 569 = -13.53 Epsilon = 0.437
# resultado da epoca 570 = 12.02 Epsilon = 0.436
# resultado da epoca 571 = 31.00 Epsilon = 0.435
# resultado da epoca 572 = 10.77 Epsilon = 0.434
# resultado da epoca 573 = 5.00 Epsilon = 0.433
# resultado da epoca 574 = 12.31 Epsilon = 0.432
# resultado da epoca 575 = 20.12 Epsilon = 0.431
# resultado da epoca 576 = 10.42 Epsilon = 0.430
# resultado da epoca 577 = 0.19 Epsilon = 0.429
# resultado da epoca 578 = 9.01 Epsilon = 0.428
# resultado da epoca 579 = -1.94 Epsilon = 0.427
# resultado da epoca 580 = 23.55 Epsilon = 0.426
# resultado da epoca 581 = 4.55 Epsilon = 0.425
# resultado da epoca 582 = -6.75 Epsilon = 0.424
# resultado da epoca 583 = 24.35 Epsilon = 0.423
# resultado da epoca 584 = 5.50 Epsilon = 0.422
# resultado da epoca 585 = 12.04 Epsilon = 0.421
# resultado da epoca 586 = 25.76 Epsilon = 0.420
# resultado da epoca 587 = -20.76 Epsilon = 0.419
# resultado da epoca 588 = 15.92 Epsilon = 0.418
# resultado da epoca 589 = 3.62 Epsilon = 0.417
# resultado da epoca 590 = 15.42 Epsilon = 0.416
# resultado da epoca 591 = 15.63 Epsilon = 0.415
# resultado da epoca 592 = 1.65 Epsilon = 0.414
# resultado da epoca 593 = 7.74 Epsilon = 0.413
# resultado da epoca 594 = 29.35 Epsilon = 0.412
# resultado da epoca 595 = -1.78 Epsilon = 0.411
# resultado da epoca 596 = -7.52 Epsilon = 0.410
# resultado da epoca 597 = 6.51 Epsilon = 0.409
# resultado da epoca 598 = 6.14 Epsilon = 0.408
# resultado da epoca 599 = 21.24 Epsilon = 0.407
# resultado da epoca 600 = 17.60 Epsilon = 0.406
# resultado da epoca 601 = -2.37 Epsilon = 0.405
# resultado da epoca 602 = 15.28 Epsilon = 0.404
# resultado da epoca 603 = 2.61 Epsilon = 0.403
# resultado da epoca 604 = 0.35 Epsilon = 0.402
# resultado da epoca 605 = 26.56 Epsilon = 0.401
# resultado da epoca 606 = 20.07 Epsilon = 0.400
# resultado da epoca 607 = 14.99 Epsilon = 0.399
# resultado da epoca 608 = 18.90 Epsilon = 0.398
# resultado da epoca 609 = 14.41 Epsilon = 0.397
# resultado da epoca 610 = 14.86 Epsilon = 0.396
# resultado da epoca 611 = 12.57 Epsilon = 0.395
# resultado da epoca 612 = 4.86 Epsilon = 0.394
# resultado da epoca 613 = -11.11 Epsilon = 0.393
# resultado da epoca 614 = 16.48 Epsilon = 0.392
# resultado da epoca 615 = -0.24 Epsilon = 0.391
# resultado da epoca 616 = 8.88 Epsilon = 0.390
# resultado da epoca 617 = 42.77 Epsilon = 0.389
# resultado da epoca 618 = -0.32 Epsilon = 0.388
# resultado da epoca 619 = 1.73 Epsilon = 0.387
# resultado da epoca 620 = 0.77 Epsilon = 0.386
# resultado da epoca 621 = 0.66 Epsilon = 0.385
# resultado da epoca 622 = 24.43 Epsilon = 0.384
# resultado da epoca 623 = 7.50 Epsilon = 0.383
# resultado da epoca 624 = 33.81 Epsilon = 0.382
# resultado da epoca 625 = 16.45 Epsilon = 0.381
# resultado da epoca 626 = 4.76 Epsilon = 0.380
# resultado da epoca 627 = 14.65 Epsilon = 0.379
# resultado da epoca 628 = 18.45 Epsilon = 0.378
# resultado da epoca 629 = -0.37 Epsilon = 0.377
# resultado da epoca 630 = -11.22 Epsilon = 0.376
# resultado da epoca 631 = 13.40 Epsilon = 0.375
# resultado da epoca 632 = 12.33 Epsilon = 0.374
# resultado da epoca 633 = 9.17 Epsilon = 0.373
# resultado da epoca 634 = 15.44 Epsilon = 0.372
# resultado da epoca 635 = 7.82 Epsilon = 0.371
# resultado da epoca 636 = 16.16 Epsilon = 0.370
# resultado da epoca 637 = 29.11 Epsilon = 0.369
# resultado da epoca 638 = 0.21 Epsilon = 0.368
# resultado da epoca 639 = 10.77 Epsilon = 0.367
# resultado da epoca 640 = 1.38 Epsilon = 0.366
# resultado da epoca 641 = 9.09 Epsilon = 0.365
# resultado da epoca 642 = 26.50 Epsilon = 0.364
# resultado da epoca 643 = -2.68 Epsilon = 0.363
# resultado da epoca 644 = -3.06 Epsilon = 0.362
# resultado da epoca 645 = 0.03 Epsilon = 0.361
# resultado da epoca 646 = 4.57 Epsilon = 0.360
# resultado da epoca 647 = 16.93 Epsilon = 0.359
# resultado da epoca 648 = 6.14 Epsilon = 0.358
# resultado da epoca 649 = -3.08 Epsilon = 0.357
# resultado da epoca 650 = 15.21 Epsilon = 0.356
# resultado da epoca 651 = 21.61 Epsilon = 0.356
# resultado da epoca 652 = 1.09 Epsilon = 0.355
# resultado da epoca 653 = 4.25 Epsilon = 0.354
# resultado da epoca 654 = 13.53 Epsilon = 0.353
# resultado da epoca 655 = 5.66 Epsilon = 0.352
# resultado da epoca 656 = 15.79 Epsilon = 0.351
# resultado da epoca 657 = 17.01 Epsilon = 0.350
# resultado da epoca 658 = 3.38 Epsilon = 0.349
# resultado da epoca 659 = -4.65 Epsilon = 0.348
# resultado da epoca 660 = 10.05 Epsilon = 0.347
# resultado da epoca 661 = 19.62 Epsilon = 0.346
# resultado da epoca 662 = -6.30 Epsilon = 0.345
# resultado da epoca 663 = 3.99 Epsilon = 0.344
# resultado da epoca 664 = 3.46 Epsilon = 0.343
# resultado da epoca 665 = 10.29 Epsilon = 0.342
# resultado da epoca 666 = 8.37 Epsilon = 0.341
# resultado da epoca 667 = 14.65 Epsilon = 0.340
# resultado da epoca 668 = 4.78 Epsilon = 0.339
# resultado da epoca 669 = 21.24 Epsilon = 0.338
# resultado da epoca 670 = 14.17 Epsilon = 0.337
# resultado da epoca 671 = 0.72 Epsilon = 0.336
# resultado da epoca 672 = 20.15 Epsilon = 0.335
# resultado da epoca 673 = -3.06 Epsilon = 0.334
# resultado da epoca 674 = -9.06 Epsilon = 0.333
# resultado da epoca 675 = 7.55 Epsilon = 0.332
# resultado da epoca 676 = 27.22 Epsilon = 0.331
# resultado da epoca 677 = 6.43 Epsilon = 0.330
# resultado da epoca 678 = 2.47 Epsilon = 0.329
# resultado da epoca 679 = -1.04 Epsilon = 0.328
# resultado da epoca 680 = 18.95 Epsilon = 0.327
# resultado da epoca 681 = 40.54 Epsilon = 0.326
# resultado da epoca 682 = 25.86 Epsilon = 0.325
# resultado da epoca 683 = 10.87 Epsilon = 0.324
# resultado da epoca 684 = 24.38 Epsilon = 0.323
# resultado da epoca 685 = 23.26 Epsilon = 0.322
# resultado da epoca 686 = 25.73 Epsilon = 0.321
# resultado da epoca 687 = 36.47 Epsilon = 0.320
# resultado da epoca 688 = 20.60 Epsilon = 0.319
# resultado da epoca 689 = 13.40 Epsilon = 0.318
# resultado da epoca 690 = 12.73 Epsilon = 0.317
# resultado da epoca 691 = 14.97 Epsilon = 0.316
# resultado da epoca 692 = 2.90 Epsilon = 0.315
# resultado da epoca 693 = 2.61 Epsilon = 0.314
# resultado da epoca 694 = 3.96 Epsilon = 0.313
# resultado da epoca 695 = 13.48 Epsilon = 0.312
# resultado da epoca 696 = 4.15 Epsilon = 0.311
# resultado da epoca 697 = 13.61 Epsilon = 0.310
# resultado da epoca 698 = 11.08 Epsilon = 0.309
# resultado da epoca 699 = 26.29 Epsilon = 0.308
# resultado da epoca 700 = -6.73 Epsilon = 0.307
# resultado da epoca 701 = -3.48 Epsilon = 0.306
# resultado da epoca 702 = -2.42 Epsilon = 0.305
# resultado da epoca 703 = 18.24 Epsilon = 0.304
# resultado da epoca 704 = 8.11 Epsilon = 0.303
# resultado da epoca 705 = 11.67 Epsilon = 0.302
# Melhor resultado diario: 29.72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-71b69c397d4d> in <module>
#      15             modelo.limpa_memoria_epoca()
#      16             sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
# ---> 17             train_teste() #roda o modelo com toda a memoria da epoca
#      18             sr.append(sum_rewards)
#      19             print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
#
# <ipython-input-5-4cf38477d6f8> in train_teste(batch_size)
#     175                 target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
#     176
# --> 177             target_f = modelo.model.predict(estado)
#     178             target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
#     179             x.append(estado[0])
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo))

# %%
np.amax(inputs['preco'])

# %%
plt.plot(range(0,len(inputs)), inputs['preco'])

# %%
plt.plot(range(0,len(inputs_nao_norm)), inputs_nao_norm['preco'])

# %%
7.6871599336160745*pstd*10
