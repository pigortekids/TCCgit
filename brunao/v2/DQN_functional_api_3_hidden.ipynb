# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
n_mercado = n_variaveis*janela #inputs
n_estados = 2 #ncont e valor
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0

for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Model
from keras.layers import Dense, Input, concatenate
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, mkt_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.mkt_size = mkt_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        #inputs
        x1 = Input(shape=(self.state_size,))
        x2 = Input(shape=(self.mkt_size,))
        
        #state hidden layers
        a1 = Dense(320)(x1)
        a2 = Dense(256)(a1)
        a3 = Dense(256)(a2)
        
        #mkt hidden layers
        b1 = Dense(320)(x2)
        b2 = Dense(256)(b1)
        b3 = Dense(256)(b2)
        
        #concatenacao
        x12 = concatenate([a3, b3], axis=-1)
        
        #camada de saida
        y = Dense(self.action_size, activation='linear')(x12)
        
        model = Model(inputs=[x1, x2], outputs=y)
        
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(self.mkt_size)
        self.prox_janela_precos = np.zeros(self.mkt_size)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict([self.state, self.janela_precos]) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x1 = np.zeros((batch_size+1, self.state_size))
        x2 = np.zeros((batch_size+1, self.mkt_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, mercado, prox_estado, prox_mercado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict([prox_estado, prox_mercado])[0])) #pega valor que quer chegar

            target_f = self.model.predict([estado, mercado]) #pega valor que chegou
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x1[i,:] = estado
            x2[i,:] = mercado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit([x1, x2], y, epochs=1, verbose=0) #treina modelo
            
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.janela_precos, self.next_state, self.prox_janela_precos, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_estados, n_mercado, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          960         input_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 320)          6720        input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          82176       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          82176       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          65792       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          65792       dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           dense_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 11)           5643        concatenate_1[0][0]
# ==================================================================================================
# Total params: 309,259
# Trainable params: 309,259
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.reshape(np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l]), (1,modelo.mkt_size))
        modelo.state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        
        acao = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l]),(1,modelo.mkt_size))
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]),(1,modelo.mkt_size))
        
        modelo.next_state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    lucro += posicao

    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+5): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos2.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1106 22:42:27.413546  4920 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -36030.26 Epsilon = 1.000
# 80
# 139
# resultado da epoca 1 = -37028.30 Epsilon = 0.999
# 92
# 127
# resultado da epoca 2 = -16526.32 Epsilon = 0.998
# 99
# 120
# resultado da epoca 3 = -61147.56 Epsilon = 0.997
# 93
# 126
# resultado da epoca 4 = -68259.32 Epsilon = 0.996
# 79
# 140
# resultado da epoca 5 = -41459.90 Epsilon = 0.995
# 91
# 128
# resultado da epoca 6 = -86949.74 Epsilon = 0.994
# 78
# 141
# resultado da epoca 7 = -34479.68 Epsilon = 0.993
# 96
# 123
# resultado da epoca 8 = -40952.26 Epsilon = 0.992
# 94
# 125
# resultado da epoca 9 = -30400.06 Epsilon = 0.991
# 97
# 122
# resultado da epoca 10 = -58655.52 Epsilon = 0.990
# 90
# 129
# resultado da epoca 11 = -29289.98 Epsilon = 0.989
# 104
# 115
# resultado da epoca 12 = -46487.06 Epsilon = 0.988
# 94
# 125
# resultado da epoca 13 = -36619.00 Epsilon = 0.987
# 89
# 130
# resultado da epoca 14 = -39216.66 Epsilon = 0.986
# 90
# 129
# resultado da epoca 15 = -40787.44 Epsilon = 0.985
# 94
# 125
# resultado da epoca 16 = -74210.10 Epsilon = 0.984
# 84
# 135
# resultado da epoca 17 = -33709.14 Epsilon = 0.983
# 88
# 131
# resultado da epoca 18 = -28005.70 Epsilon = 0.982
# 101
# 118
# resultado da epoca 19 = -33803.20 Epsilon = 0.981
# 96
# 123
# resultado da epoca 20 = -53294.40 Epsilon = 0.980
# 92
# 127
# resultado da epoca 21 = -56530.48 Epsilon = 0.979
# 81
# 138
# resultado da epoca 22 = -36602.62 Epsilon = 0.978
# 84
# 135
# resultado da epoca 23 = -34957.30 Epsilon = 0.977
# 89
# 130
# resultado da epoca 24 = -59051.94 Epsilon = 0.976
# 96
# 123
# resultado da epoca 25 = -43599.72 Epsilon = 0.975
# 94
# 125
# resultado da epoca 26 = -42830.86 Epsilon = 0.974
# 91
# 128
# resultado da epoca 27 = -79555.68 Epsilon = 0.973
# 75
# 144
# resultado da epoca 28 = -53867.20 Epsilon = 0.972
# 87
# 132
# resultado da epoca 29 = -41743.84 Epsilon = 0.971
# 92
# 127
# resultado da epoca 30 = -54670.60 Epsilon = 0.970
# 85
# 134
# resultado da epoca 31 = -41969.96 Epsilon = 0.969
# 95
# 124
# resultado da epoca 32 = -22524.82 Epsilon = 0.968
# 102
# 117
# resultado da epoca 33 = -29182.72 Epsilon = 0.967
# 95
# 124
# resultado da epoca 34 = -32811.06 Epsilon = 0.966
# 94
# 125
# resultado da epoca 35 = -50542.38 Epsilon = 0.965
# 91
# 128
# resultado da epoca 36 = -54551.88 Epsilon = 0.964
# 85
# 134
# resultado da epoca 37 = -33590.76 Epsilon = 0.963
# 90
# 129
# resultado da epoca 38 = -45752.76 Epsilon = 0.962
# 85
# 134
# resultado da epoca 39 = -41822.78 Epsilon = 0.961
# 87
# 132
# resultado da epoca 40 = -47449.00 Epsilon = 0.960
# 87
# 132
# resultado da epoca 41 = -72698.06 Epsilon = 0.959
# 78
# 141
# resultado da epoca 42 = -64187.96 Epsilon = 0.958
# 83
# 136
# resultado da epoca 43 = -19226.62 Epsilon = 0.957
# 103
# 116
# resultado da epoca 44 = -47681.52 Epsilon = 0.956
# 83
# 136
# resultado da epoca 45 = -51619.66 Epsilon = 0.955
# 83
# 136
# resultado da epoca 46 = -48139.54 Epsilon = 0.954
# 93
# 126
# resultado da epoca 47 = -50323.14 Epsilon = 0.953
# 92
# 127
# resultado da epoca 48 = -33939.14 Epsilon = 0.952
# 93
# 126
# resultado da epoca 49 = -38607.62 Epsilon = 0.951
# 97
# 122
# resultado da epoca 50 = -37663.68 Epsilon = 0.950
# 94
# 125
# resultado da epoca 51 = -53742.30 Epsilon = 0.950
# 86
# 133
# resultado da epoca 52 = -39049.00 Epsilon = 0.949
# 99
# 120
# resultado da epoca 53 = -45681.64 Epsilon = 0.948
# 97
# 122
# resultado da epoca 54 = -30735.40 Epsilon = 0.947
# 97
# 122
# resultado da epoca 55 = -55380.86 Epsilon = 0.946
# 90
# 129
# resultado da epoca 56 = -33807.18 Epsilon = 0.945
# 100
# 119
# resultado da epoca 57 = -60845.12 Epsilon = 0.944
# 89
# 130
# resultado da epoca 58 = -38077.12 Epsilon = 0.943
# 94
# 125
# resultado da epoca 59 = -44076.96 Epsilon = 0.942
# 94
# 125
# resultado da epoca 60 = -29517.12 Epsilon = 0.941
# 103
# 116
# resultado da epoca 61 = -16397.60 Epsilon = 0.940
# 110
# 109
# resultado da epoca 62 = -72652.64 Epsilon = 0.939
# 83
# 136
# resultado da epoca 63 = -34864.80 Epsilon = 0.938
# 93
# 126
# resultado da epoca 64 = -49546.62 Epsilon = 0.937
# 85
# 134
# resultado da epoca 65 = -30132.70 Epsilon = 0.936
# 95
# 124
# resultado da epoca 66 = -47700.48 Epsilon = 0.935
# 86
# 133
# resultado da epoca 67 = -12756.40 Epsilon = 0.934
# 109
# 110
# resultado da epoca 68 = -45212.64 Epsilon = 0.933
# 98
# 121
# resultado da epoca 69 = -45084.72 Epsilon = 0.932
# 99
# 120
# resultado da epoca 70 = -68720.36 Epsilon = 0.931
# 76
# 143
# resultado da epoca 71 = -70481.66 Epsilon = 0.930
# 73
# 146
# resultado da epoca 72 = -47945.28 Epsilon = 0.929
# 89
# 130
# resultado da epoca 73 = -31073.04 Epsilon = 0.928
# 88
# 131
# resultado da epoca 74 = -53459.36 Epsilon = 0.927
# 89
# 130
# resultado da epoca 75 = -39433.90 Epsilon = 0.926
# 89
# 130
# resultado da epoca 76 = -54638.18 Epsilon = 0.925
# 87
# 132
# resultado da epoca 77 = -67269.84 Epsilon = 0.924
# 85
# 134
# resultado da epoca 78 = -14604.24 Epsilon = 0.923
# 105
# 114
# resultado da epoca 79 = -27715.02 Epsilon = 0.922
# 93
# 126
# resultado da epoca 80 = -32156.54 Epsilon = 0.921
# 94
# 125
# resultado da epoca 81 = -26035.32 Epsilon = 0.920
# 99
# 120
# resultado da epoca 82 = -45472.06 Epsilon = 0.919
# 95
# 124
# resultado da epoca 83 = -51080.66 Epsilon = 0.918
# 87
# 132
# resultado da epoca 84 = -39202.10 Epsilon = 0.917
# 93
# 126
# resultado da epoca 85 = -53402.00 Epsilon = 0.916
# 92
# 127
# resultado da epoca 86 = -39150.84 Epsilon = 0.915
# 95
# 124
# resultado da epoca 87 = -47244.94 Epsilon = 0.914
# 90
# 129
# resultado da epoca 88 = -57349.56 Epsilon = 0.913
# 94
# 125
# resultado da epoca 89 = -34128.16 Epsilon = 0.912
# 92
# 127
# resultado da epoca 90 = -41763.00 Epsilon = 0.911
# 100
# 119
# resultado da epoca 91 = -33251.20 Epsilon = 0.910
# 101
# 118
# resultado da epoca 92 = -43477.50 Epsilon = 0.909
# 94
# 125
# resultado da epoca 93 = -39377.02 Epsilon = 0.908
# 91
# 128
# resultado da epoca 94 = -47725.12 Epsilon = 0.907
# 86
# 133
# resultado da epoca 95 = -44762.86 Epsilon = 0.906
# 87
# 132
# resultado da epoca 96 = -36688.58 Epsilon = 0.905
# 93
# 126
# resultado da epoca 97 = -55986.72 Epsilon = 0.904
# 80
# 139
# resultado da epoca 98 = -25719.96 Epsilon = 0.903
# 98
# 121
# resultado da epoca 99 = -48873.98 Epsilon = 0.902
# 79
# 140
# resultado da epoca 100 = -64398.58 Epsilon = 0.901
# 77
# 142
# resultado da epoca 101 = -38443.40 Epsilon = 0.900
# 87
# 132
# resultado da epoca 102 = -19426.86 Epsilon = 0.899
# 97
# 122
# resultado da epoca 103 = -71259.70 Epsilon = 0.898
# 79
# 140
# resultado da epoca 104 = -44777.80 Epsilon = 0.897
# 90
# 129
# resultado da epoca 105 = -31230.28 Epsilon = 0.896
# 97
# 122
# resultado da epoca 106 = -42016.84 Epsilon = 0.895
# 82
# 137
# resultado da epoca 107 = -46404.24 Epsilon = 0.894
# 95
# 124
# resultado da epoca 108 = -66511.84 Epsilon = 0.893
# 88
# 131
# resultado da epoca 109 = -20854.42 Epsilon = 0.892
# 98
# 121
# resultado da epoca 110 = -26673.86 Epsilon = 0.891
# 100
# 119
# resultado da epoca 111 = -38081.32 Epsilon = 0.890
# 90
# 129
# resultado da epoca 112 = -48914.70 Epsilon = 0.889
# 90
# 129
# resultado da epoca 113 = -8864.52 Epsilon = 0.888
# 107
# 112
# resultado da epoca 114 = -21905.90 Epsilon = 0.887
# 103
# 116
# resultado da epoca 115 = -71845.04 Epsilon = 0.886
# 80
# 139
# resultado da epoca 116 = -44116.48 Epsilon = 0.885
# 85
# 134
# resultado da epoca 117 = -9372.04 Epsilon = 0.884
# 116
# 103
# resultado da epoca 118 = -25624.18 Epsilon = 0.883
# 94
# 125
# resultado da epoca 119 = -54630.10 Epsilon = 0.882
# 84
# 135
# resultado da epoca 120 = -31959.82 Epsilon = 0.881
# 87
# 132
# resultado da epoca 121 = -51078.04 Epsilon = 0.880
# 97
# 122
# resultado da epoca 122 = -36342.32 Epsilon = 0.879
# 99
# 120
# resultado da epoca 123 = -27107.02 Epsilon = 0.878
# 92
# 127
# resultado da epoca 124 = -44198.88 Epsilon = 0.877
# 89
# 130
# resultado da epoca 125 = -44573.54 Epsilon = 0.876
# 88
# 131
# resultado da epoca 126 = -41321.26 Epsilon = 0.875
# 93
# 126
# resultado da epoca 127 = -53004.26 Epsilon = 0.874
# 89
# 130
# resultado da epoca 128 = -35120.00 Epsilon = 0.873
# 90
# 129
# resultado da epoca 129 = -24155.26 Epsilon = 0.872
# 109
# 110
# resultado da epoca 130 = -48011.78 Epsilon = 0.871
# 86
# 133
# resultado da epoca 131 = -34156.82 Epsilon = 0.870
# 91
# 128
# resultado da epoca 132 = -38813.70 Epsilon = 0.869
# 86
# 133
# resultado da epoca 133 = -48881.82 Epsilon = 0.868
# 91
# 128
# resultado da epoca 134 = -58730.00 Epsilon = 0.867
# 83
# 136
# resultado da epoca 135 = -56231.82 Epsilon = 0.866
# 82
# 137
# resultado da epoca 136 = -60250.14 Epsilon = 0.865
# 82
# 137
# resultado da epoca 137 = -52527.06 Epsilon = 0.864
# 86
# 133
# resultado da epoca 138 = -8143.76 Epsilon = 0.863
# 102
# 117
# resultado da epoca 139 = -57073.06 Epsilon = 0.862
# 79
# 140
# resultado da epoca 140 = -49128.50 Epsilon = 0.861
# 92
# 127
# resultado da epoca 141 = -45142.52 Epsilon = 0.860
# 89
# 130
# resultado da epoca 142 = -39577.10 Epsilon = 0.859
# 97
# 122
# resultado da epoca 143 = -34566.42 Epsilon = 0.858
# 92
# 127
# resultado da epoca 144 = -39646.48 Epsilon = 0.857
# 96
# 123
# resultado da epoca 145 = -23090.80 Epsilon = 0.856
# 100
# 119
# resultado da epoca 146 = -28169.32 Epsilon = 0.855
# 109
# 110
# resultado da epoca 147 = -40516.62 Epsilon = 0.854
# 92
# 127
# resultado da epoca 148 = -69726.16 Epsilon = 0.853
# 87
# 132
# resultado da epoca 149 = -46584.60 Epsilon = 0.852
# 90
# 129
# resultado da epoca 150 = -40956.14 Epsilon = 0.851
# 88
# 131
# resultado da epoca 151 = -27844.22 Epsilon = 0.851
# 98
# 121
# resultado da epoca 152 = -15675.02 Epsilon = 0.850
# 99
# 120
# resultado da epoca 153 = -39876.92 Epsilon = 0.849
# 95
# 124
# resultado da epoca 154 = -69107.64 Epsilon = 0.848
# 86
# 133
# resultado da epoca 155 = -25206.20 Epsilon = 0.847
# 93
# 126
# resultado da epoca 156 = -46410.42 Epsilon = 0.846
# 95
# 124
# resultado da epoca 157 = -29874.16 Epsilon = 0.845
# 95
# 124
# resultado da epoca 158 = -37530.76 Epsilon = 0.844
# 86
# 133
# resultado da epoca 159 = -48168.98 Epsilon = 0.843
# 98
# 121
# resultado da epoca 160 = -66968.38 Epsilon = 0.842
# 85
# 134
# resultado da epoca 161 = -30125.14 Epsilon = 0.841
# 93
# 126
# resultado da epoca 162 = -48292.20 Epsilon = 0.840
# 88
# 131
# resultado da epoca 163 = -39289.88 Epsilon = 0.839
# 105
# 114
# resultado da epoca 164 = -39719.28 Epsilon = 0.838
# 93
# 126
# resultado da epoca 165 = -46451.60 Epsilon = 0.837
# 88
# 131
# resultado da epoca 166 = -46489.24 Epsilon = 0.836
# 92
# 127
# resultado da epoca 167 = -31817.30 Epsilon = 0.835
# 96
# 123
# resultado da epoca 168 = -49644.88 Epsilon = 0.834
# 95
# 124
# resultado da epoca 169 = -78060.28 Epsilon = 0.833
# 77
# 142
# resultado da epoca 170 = -33259.90 Epsilon = 0.832
# 98
# 121
# resultado da epoca 171 = -51563.40 Epsilon = 0.831
# 87
# 132
# resultado da epoca 172 = -28568.48 Epsilon = 0.830
# 91
# 128
# resultado da epoca 173 = -76628.00 Epsilon = 0.829
# 82
# 137
# resultado da epoca 174 = -35737.82 Epsilon = 0.828
# 94
# 125
# resultado da epoca 175 = -23029.58 Epsilon = 0.827
# 101
# 118
# resultado da epoca 176 = -32273.90 Epsilon = 0.826
# 85
# 134
# resultado da epoca 177 = -44912.48 Epsilon = 0.825
# 94
# 125
# resultado da epoca 178 = -41644.86 Epsilon = 0.824
# 97
# 122
# resultado da epoca 179 = -40069.32 Epsilon = 0.823
# 89
# 130
# resultado da epoca 180 = -57971.34 Epsilon = 0.822
# 90
# 129
# resultado da epoca 181 = -42396.34 Epsilon = 0.821
# 99
# 120
# resultado da epoca 182 = -40128.88 Epsilon = 0.820
# 89
# 130
# resultado da epoca 183 = -45489.54 Epsilon = 0.819
# 95
# 124
# resultado da epoca 184 = -46117.24 Epsilon = 0.818
# 93
# 126
# resultado da epoca 185 = -65199.56 Epsilon = 0.817
# 88
# 131
# resultado da epoca 186 = -936.40 Epsilon = 0.816
# 111
# 108
# resultado da epoca 187 = -38656.78 Epsilon = 0.815
# 96
# 123
# resultado da epoca 188 = -32057.16 Epsilon = 0.814
# 90
# 129
# resultado da epoca 189 = -13623.90 Epsilon = 0.813
# 105
# 114
# resultado da epoca 190 = -69314.68 Epsilon = 0.812
# 83
# 136
# resultado da epoca 191 = -29898.88 Epsilon = 0.811
# 94
# 125
# resultado da epoca 192 = -31196.66 Epsilon = 0.810
# 103
# 116
# resultado da epoca 193 = -34515.82 Epsilon = 0.809
# 100
# 119
# resultado da epoca 194 = -30225.40 Epsilon = 0.808
# 103
# 116
# resultado da epoca 195 = -43931.50 Epsilon = 0.807
# 90
# 129
# resultado da epoca 196 = -24051.90 Epsilon = 0.806
# 103
# 116
# resultado da epoca 197 = -39072.94 Epsilon = 0.805
# 88
# 131
# resultado da epoca 198 = -26060.98 Epsilon = 0.804
# 95
# 124
# resultado da epoca 199 = -21939.74 Epsilon = 0.803
# 96
# 123
# resultado da epoca 200 = -34790.32 Epsilon = 0.802
# 92
# 127
# resultado da epoca 201 = -57004.72 Epsilon = 0.801
# 86
# 133
# resultado da epoca 202 = -53142.58 Epsilon = 0.800
# 88
# 131
# resultado da epoca 203 = -66459.08 Epsilon = 0.799
# 91
# 128
# resultado da epoca 204 = -11450.80 Epsilon = 0.798
# 104
# 115
# resultado da epoca 205 = -14747.90 Epsilon = 0.797
# 95
# 124
# resultado da epoca 206 = -26120.90 Epsilon = 0.796
# 96
# 123
# resultado da epoca 207 = -38100.46 Epsilon = 0.795
# 97
# 122
# resultado da epoca 208 = -49775.56 Epsilon = 0.794
# 81
# 138
# resultado da epoca 209 = -31035.88 Epsilon = 0.793
# 106
# 113
# resultado da epoca 210 = -75441.80 Epsilon = 0.792
# 78
# 141
# resultado da epoca 211 = -8144.02 Epsilon = 0.791
# 104
# 115
# resultado da epoca 212 = -56558.38 Epsilon = 0.790
# 92
# 127
# resultado da epoca 213 = -29251.40 Epsilon = 0.789
# 93
# 126
# resultado da epoca 214 = -57889.26 Epsilon = 0.788
# 76
# 143
# resultado da epoca 215 = -28787.00 Epsilon = 0.787
# 105
# 114
# resultado da epoca 216 = -37030.42 Epsilon = 0.786
# 95
# 124
# resultado da epoca 217 = -49761.82 Epsilon = 0.785
# 88
# 131
# resultado da epoca 218 = -7187.68 Epsilon = 0.784
# 105
# 114
# resultado da epoca 219 = -21657.02 Epsilon = 0.783
# 110
# 109
# resultado da epoca 220 = -43338.04 Epsilon = 0.782
# 88
# 131
# resultado da epoca 221 = -43191.74 Epsilon = 0.781
# 95
# 124
# resultado da epoca 222 = -49084.88 Epsilon = 0.780
# 90
# 129
# resultado da epoca 223 = 58.90 Epsilon = 0.779
# 107
# 112
# resultado da epoca 224 = -57879.02 Epsilon = 0.778
# 72
# 147
# resultado da epoca 225 = -21767.74 Epsilon = 0.777
# 100
# 119
# resultado da epoca 226 = -5513.28 Epsilon = 0.776
# 111
# 108
# resultado da epoca 227 = -49191.50 Epsilon = 0.775
# 87
# 132
# resultado da epoca 228 = -36604.72 Epsilon = 0.774
# 92
# 127
# resultado da epoca 229 = -29170.44 Epsilon = 0.773
# 97
# 122
# resultado da epoca 230 = -28700.30 Epsilon = 0.772
# 98
# 121
# resultado da epoca 231 = -18598.02 Epsilon = 0.771
# 101
# 118
# resultado da epoca 232 = -45725.96 Epsilon = 0.770
# 91
# 128
# resultado da epoca 233 = -22053.94 Epsilon = 0.769
# 100
# 119
# resultado da epoca 234 = -44024.92 Epsilon = 0.768
# 91
# 128
# resultado da epoca 235 = -45290.54 Epsilon = 0.767
# 94
# 125
# resultado da epoca 236 = -38728.60 Epsilon = 0.766
# 88
# 131
# resultado da epoca 237 = -48456.92 Epsilon = 0.765
# 89
# 130
# resultado da epoca 238 = -46837.90 Epsilon = 0.764
# 97
# 122
# resultado da epoca 239 = 4355.30 Epsilon = 0.763
# 102
# 117
# resultado da epoca 240 = -63534.28 Epsilon = 0.762
# 83
# 136
# resultado da epoca 241 = -64322.00 Epsilon = 0.761
# 91
# 128
# resultado da epoca 242 = -56737.74 Epsilon = 0.760
# 89
# 130
# resultado da epoca 243 = -38053.78 Epsilon = 0.759
# 82
# 137
# resultado da epoca 244 = -31474.40 Epsilon = 0.758
# 93
# 126
# resultado da epoca 245 = -34896.68 Epsilon = 0.757
# 97
# 122
# resultado da epoca 246 = -70957.36 Epsilon = 0.756
# 82
# 137
# resultado da epoca 247 = -7503.82 Epsilon = 0.755
# 104
# 115
# resultado da epoca 248 = -33327.42 Epsilon = 0.754
# 97
# 122
# resultado da epoca 249 = -20223.46 Epsilon = 0.753
# 97
# 122
# resultado da epoca 250 = -46809.20 Epsilon = 0.752
# 93
# 126
# resultado da epoca 251 = -50790.80 Epsilon = 0.752
# 92
# 127
# resultado da epoca 252 = -43934.00 Epsilon = 0.751
# 100
# 119
# resultado da epoca 253 = -41101.86 Epsilon = 0.750
# 92
# 127
# resultado da epoca 254 = -68865.88 Epsilon = 0.749
# 84
# 135
# resultado da epoca 255 = -61908.84 Epsilon = 0.748
# 79
# 140
# resultado da epoca 256 = -65978.32 Epsilon = 0.747
# 87
# 132
# resultado da epoca 257 = -38820.00 Epsilon = 0.746
# 89
# 130
# resultado da epoca 258 = -58667.02 Epsilon = 0.745
# 91
# 128
# resultado da epoca 259 = -53202.88 Epsilon = 0.744
# 91
# 128
# resultado da epoca 260 = -47198.06 Epsilon = 0.743
# 91
# 128
# resultado da epoca 261 = -52994.72 Epsilon = 0.742
# 85
# 134
# resultado da epoca 262 = -27524.76 Epsilon = 0.741
# 96
# 123
# resultado da epoca 263 = -48799.70 Epsilon = 0.740
# 102
# 117
# resultado da epoca 264 = -62985.56 Epsilon = 0.739
# 85
# 134
# resultado da epoca 265 = -35233.90 Epsilon = 0.738
# 90
# 129
# resultado da epoca 266 = -50892.22 Epsilon = 0.737
# 82
# 137
# resultado da epoca 267 = -83241.52 Epsilon = 0.736
# 84
# 135
# resultado da epoca 268 = -55420.92 Epsilon = 0.735
# 92
# 127
# resultado da epoca 269 = -43229.08 Epsilon = 0.734
# 96
# 123
# resultado da epoca 270 = -55946.70 Epsilon = 0.733
# 91
# 128
# resultado da epoca 271 = -29407.02 Epsilon = 0.732
# 99
# 120
# resultado da epoca 272 = -77606.34 Epsilon = 0.731
# 77
# 142
# resultado da epoca 273 = -38080.68 Epsilon = 0.730
# 99
# 120
# resultado da epoca 274 = -53026.58 Epsilon = 0.729
# 91
# 128
# resultado da epoca 275 = -43009.18 Epsilon = 0.728
# 86
# 133
# resultado da epoca 276 = -51357.98 Epsilon = 0.727
# 86
# 133
# resultado da epoca 277 = -48918.30 Epsilon = 0.726
# 82
# 137
# resultado da epoca 278 = -30112.68 Epsilon = 0.725
# 102
# 117
# resultado da epoca 279 = -25045.30 Epsilon = 0.724
# 95
# 124
# resultado da epoca 280 = -63578.44 Epsilon = 0.723
# 92
# 127
# resultado da epoca 281 = -46078.40 Epsilon = 0.722
# 94
# 125
# resultado da epoca 282 = -38773.64 Epsilon = 0.721
# 99
# 120
# resultado da epoca 283 = -68250.36 Epsilon = 0.720
# 89
# 130
# resultado da epoca 284 = -54773.60 Epsilon = 0.719
# 81
# 138
# resultado da epoca 285 = -24961.62 Epsilon = 0.718
# 99
# 120
# resultado da epoca 286 = -72108.70 Epsilon = 0.717
# 86
# 133
# resultado da epoca 287 = -82712.84 Epsilon = 0.716
# 79
# 140
# resultado da epoca 288 = -2410.36 Epsilon = 0.715
# 112
# 107
# resultado da epoca 289 = -48408.28 Epsilon = 0.714
# 85
# 134
# resultado da epoca 290 = -33038.78 Epsilon = 0.713
# 99
# 120
# resultado da epoca 291 = -59325.62 Epsilon = 0.712
# 92
# 127
# resultado da epoca 292 = -29674.36 Epsilon = 0.711
# 96
# 123
# resultado da epoca 293 = -46245.46 Epsilon = 0.710
# 95
# 124
# resultado da epoca 294 = -58302.50 Epsilon = 0.709
# 85
# 134
# resultado da epoca 295 = -52062.14 Epsilon = 0.708
# 88
# 131
# resultado da epoca 296 = -34106.22 Epsilon = 0.707
# 94
# 125
# resultado da epoca 297 = -50224.88 Epsilon = 0.706
# 87
# 132
# resultado da epoca 298 = -80590.14 Epsilon = 0.705
# 87
# 132
# resultado da epoca 299 = -60942.50 Epsilon = 0.704
# 90
# 129
# resultado da epoca 300 = -55588.54 Epsilon = 0.703
# 95
# 124
# resultado da epoca 301 = -52246.94 Epsilon = 0.702
# 89
# 130
# resultado da epoca 302 = -60019.38 Epsilon = 0.701
# 88
# 131
# resultado da epoca 303 = -20061.18 Epsilon = 0.700
# 102
# 117
# resultado da epoca 304 = -69833.68 Epsilon = 0.699
# 87
# 132
# resultado da epoca 305 = -45620.14 Epsilon = 0.698
# 92
# 127
# resultado da epoca 306 = -19309.92 Epsilon = 0.697
# 97
# 122
# resultado da epoca 307 = -20475.08 Epsilon = 0.696
# 102
# 117
# resultado da epoca 308 = -39724.98 Epsilon = 0.695
# 99
# 120
# resultado da epoca 309 = -53344.66 Epsilon = 0.694
# 90
# 129
# resultado da epoca 310 = -38100.88 Epsilon = 0.693
# 98
# 121
# resultado da epoca 311 = -58351.04 Epsilon = 0.692
# 87
# 132
# resultado da epoca 312 = -33702.44 Epsilon = 0.691
# 98
# 121
# resultado da epoca 313 = -50591.14 Epsilon = 0.690
# 87
# 132
# resultado da epoca 314 = -54529.14 Epsilon = 0.689
# 99
# 120
# resultado da epoca 315 = -35865.76 Epsilon = 0.688
# 93
# 126
# resultado da epoca 316 = -20244.10 Epsilon = 0.687
# 99
# 120
# resultado da epoca 317 = -77034.28 Epsilon = 0.686
# 93
# 126
# resultado da epoca 318 = -60302.72 Epsilon = 0.685
# 88
# 131
# resultado da epoca 319 = -33710.80 Epsilon = 0.684
# 95
# 124
# resultado da epoca 320 = -25833.92 Epsilon = 0.683
# 95
# 124
# resultado da epoca 321 = -57657.88 Epsilon = 0.682
# 80
# 139
# resultado da epoca 322 = -75963.22 Epsilon = 0.681
# 81
# 138
# resultado da epoca 323 = -45132.24 Epsilon = 0.680
# 95
# 124
# resultado da epoca 324 = -46500.84 Epsilon = 0.679
# 91
# 128
# resultado da epoca 325 = -58162.58 Epsilon = 0.678
# 89
# 130
# resultado da epoca 326 = -54579.26 Epsilon = 0.677
# 92
# 127
# resultado da epoca 327 = -51633.40 Epsilon = 0.676
# 94
# 125
# resultado da epoca 328 = -48499.84 Epsilon = 0.675
# 96
# 123
# resultado da epoca 329 = -43886.42 Epsilon = 0.674
# 97
# 122
# resultado da epoca 330 = -40077.42 Epsilon = 0.673
# 93
# 126
# resultado da epoca 331 = -31801.02 Epsilon = 0.672
# 94
# 125
# resultado da epoca 332 = -53908.14 Epsilon = 0.671
# 85
# 134
# resultado da epoca 333 = -65191.12 Epsilon = 0.670
# 88
# 131
# resultado da epoca 334 = -30096.02 Epsilon = 0.669
# 97
# 122
# resultado da epoca 335 = -74562.42 Epsilon = 0.668
# 78
# 141
# resultado da epoca 336 = -46797.66 Epsilon = 0.667
# 93
# 126
# resultado da epoca 337 = -17162.40 Epsilon = 0.666
# 105
# 114
# resultado da epoca 338 = -60215.68 Epsilon = 0.665
# 95
# 124
# resultado da epoca 339 = -42489.86 Epsilon = 0.664
# 101
# 118
# resultado da epoca 340 = -37443.32 Epsilon = 0.663
# 99
# 120
# resultado da epoca 341 = -35439.68 Epsilon = 0.662
# 92
# 127
# resultado da epoca 342 = -47775.00 Epsilon = 0.661
# 81
# 138
# resultado da epoca 343 = -37090.28 Epsilon = 0.660
# 98
# 121
# resultado da epoca 344 = -55780.28 Epsilon = 0.659
# 94
# 125
# resultado da epoca 345 = -50511.48 Epsilon = 0.658
# 87
# 132
# resultado da epoca 346 = -51473.92 Epsilon = 0.657
# 94
# 125
# resultado da epoca 347 = -38333.14 Epsilon = 0.656
# 97
# 122
# resultado da epoca 348 = -32021.50 Epsilon = 0.655
# 95
# 124
# resultado da epoca 349 = -51832.24 Epsilon = 0.654
# 93
# 126
# resultado da epoca 350 = -44981.38 Epsilon = 0.653
# 100
# 119
# resultado da epoca 351 = -49718.54 Epsilon = 0.653
# 96
# 123
# resultado da epoca 352 = -49591.76 Epsilon = 0.652
# 89
# 130
# resultado da epoca 353 = -27368.64 Epsilon = 0.651
# 103
# 116
# resultado da epoca 354 = -33214.02 Epsilon = 0.650
# 94
# 125
# resultado da epoca 355 = -69356.88 Epsilon = 0.649
# 86
# 133
# resultado da epoca 356 = -35035.72 Epsilon = 0.648
# 99
# 120
# resultado da epoca 357 = -58957.78 Epsilon = 0.647
# 86
# 133
# resultado da epoca 358 = -54679.56 Epsilon = 0.646
# 87
# 132
# resultado da epoca 359 = -20454.18 Epsilon = 0.645
# 97
# 122
# resultado da epoca 360 = -51724.76 Epsilon = 0.644
# 96
# 123
# resultado da epoca 361 = -17059.18 Epsilon = 0.643
# 98
# 121
# resultado da epoca 362 = -78214.42 Epsilon = 0.642
# 85
# 134
# resultado da epoca 363 = -51145.46 Epsilon = 0.641
# 92
# 127
# resultado da epoca 364 = -46777.86 Epsilon = 0.640
# 88
# 131
# resultado da epoca 365 = -48083.04 Epsilon = 0.639
# 86
# 133
# resultado da epoca 366 = -30433.96 Epsilon = 0.638
# 97
# 122
# resultado da epoca 367 = -50098.58 Epsilon = 0.637
# 98
# 121
# resultado da epoca 368 = -39374.70 Epsilon = 0.636
# 92
# 127
# resultado da epoca 369 = -45669.30 Epsilon = 0.635
# 101
# 118
# resultado da epoca 370 = -56546.40 Epsilon = 0.634
# 98
# 121
# resultado da epoca 371 = -41176.92 Epsilon = 0.633
# 95
# 124
# resultado da epoca 372 = -37820.68 Epsilon = 0.632
# 97
# 122
# resultado da epoca 373 = -30886.86 Epsilon = 0.631
# 98
# 121
# resultado da epoca 374 = -76074.44 Epsilon = 0.630
# 93
# 126
# resultado da epoca 375 = -67363.22 Epsilon = 0.629
# 86
# 133
# resultado da epoca 376 = -54263.50 Epsilon = 0.628
# 88
# 131
# resultado da epoca 377 = -60336.82 Epsilon = 0.627
# 91
# 128
# resultado da epoca 378 = -37879.88 Epsilon = 0.626
# 95
# 124
# resultado da epoca 379 = -41144.42 Epsilon = 0.625
# 99
# 120
# resultado da epoca 380 = -41197.90 Epsilon = 0.624
# 93
# 126
# resultado da epoca 381 = -47154.14 Epsilon = 0.623
# 95
# 124
# resultado da epoca 382 = -68449.92 Epsilon = 0.622
# 83
# 136
# resultado da epoca 383 = -37421.18 Epsilon = 0.621
# 97
# 122
# resultado da epoca 384 = -62774.82 Epsilon = 0.620
# 82
# 137
# resultado da epoca 385 = -46182.42 Epsilon = 0.619
# 95
# 124
# resultado da epoca 386 = -30360.16 Epsilon = 0.618
# 91
# 128
# resultado da epoca 387 = -35386.20 Epsilon = 0.617
# 103
# 116
# resultado da epoca 388 = -68059.80 Epsilon = 0.616
# 92
# 127
# resultado da epoca 389 = -47823.98 Epsilon = 0.615
# 102
# 117
# resultado da epoca 390 = -17648.84 Epsilon = 0.614
# 105
# 114
# resultado da epoca 391 = -67155.88 Epsilon = 0.613
# 86
# 133
# resultado da epoca 392 = -33554.64 Epsilon = 0.612
# 94
# 125
# resultado da epoca 393 = -51845.16 Epsilon = 0.611
# 85
# 134
# resultado da epoca 394 = -45124.12 Epsilon = 0.610
# 93
# 126
# resultado da epoca 395 = -69010.76 Epsilon = 0.609
# 91
# 128
# resultado da epoca 396 = -57266.72 Epsilon = 0.608
# 86
# 133
# resultado da epoca 397 = -30324.86 Epsilon = 0.607
# 95
# 124
# resultado da epoca 398 = -48533.96 Epsilon = 0.606
# 87
# 132
# resultado da epoca 399 = -58736.02 Epsilon = 0.605
# 87
# 132
# resultado da epoca 400 = -61301.46 Epsilon = 0.604
# 88
# 131
# resultado da epoca 401 = -75660.76 Epsilon = 0.603
# 84
# 135
# resultado da epoca 402 = -36034.08 Epsilon = 0.602
# 96
# 123
# resultado da epoca 403 = -55666.86 Epsilon = 0.601
# 102
# 117
# resultado da epoca 404 = -50355.24 Epsilon = 0.600
# 88
# 131
# resultado da epoca 405 = -61429.64 Epsilon = 0.599
# 95
# 124
# resultado da epoca 406 = -63552.68 Epsilon = 0.598
# 84
# 135
# resultado da epoca 407 = -42892.26 Epsilon = 0.597
# 97
# 122
# resultado da epoca 408 = -72084.74 Epsilon = 0.596
# 85
# 134
# resultado da epoca 409 = -67017.00 Epsilon = 0.595
# 87
# 132
# resultado da epoca 410 = -60222.32 Epsilon = 0.594
# 86
# 133
# resultado da epoca 411 = -28775.16 Epsilon = 0.593
# 103
# 116
# resultado da epoca 412 = -49701.02 Epsilon = 0.592
# 96
# 123
# resultado da epoca 413 = -77429.22 Epsilon = 0.591
# 77
# 142
# resultado da epoca 414 = -43891.36 Epsilon = 0.590
# 95
# 124
# resultado da epoca 415 = -34352.30 Epsilon = 0.589
# 91
# 128
# resultado da epoca 416 = -58216.24 Epsilon = 0.588
# 90
# 129
# resultado da epoca 417 = -36991.08 Epsilon = 0.587
# 89
# 130
# resultado da epoca 418 = -46910.72 Epsilon = 0.586
# 93
# 126
# resultado da epoca 419 = -70777.70 Epsilon = 0.585
# 81
# 138
# resultado da epoca 420 = -63192.86 Epsilon = 0.584
# 83
# 136
# resultado da epoca 421 = -65292.32 Epsilon = 0.583
# 94
# 125
# resultado da epoca 422 = -68786.18 Epsilon = 0.582
# 86
# 133
# resultado da epoca 423 = -9969.32 Epsilon = 0.581
# 99
# 120
# resultado da epoca 424 = -50788.26 Epsilon = 0.580
# 88
# 131
# resultado da epoca 425 = -39317.66 Epsilon = 0.579
# 87
# 132
# resultado da epoca 426 = -53728.80 Epsilon = 0.578
# 89
# 130
# resultado da epoca 427 = -54374.78 Epsilon = 0.577
# 98
# 121
# resultado da epoca 428 = -56230.84 Epsilon = 0.576
# 80
# 139
# resultado da epoca 429 = -49678.48 Epsilon = 0.575
# 99
# 120
# resultado da epoca 430 = -74835.58 Epsilon = 0.574
# 84
# 135
# resultado da epoca 431 = -55566.68 Epsilon = 0.573
# 86
# 133
# resultado da epoca 432 = -35744.36 Epsilon = 0.572
# 92
# 127
# resultado da epoca 433 = -65367.92 Epsilon = 0.571
# 81
# 138
# resultado da epoca 434 = -33605.14 Epsilon = 0.570
# 96
# 123
# resultado da epoca 435 = -42730.76 Epsilon = 0.569
# 106
# 113
# resultado da epoca 436 = -25384.70 Epsilon = 0.568
# 103
# 116
# resultado da epoca 437 = -49589.76 Epsilon = 0.567
# 98
# 121
# resultado da epoca 438 = -46771.08 Epsilon = 0.566
# 93
# 126
# resultado da epoca 439 = -46183.94 Epsilon = 0.565
# 94
# 125
# resultado da epoca 440 = -16613.54 Epsilon = 0.564
# 107
# 112
# resultado da epoca 441 = -34035.30 Epsilon = 0.563
# 101
# 118
# resultado da epoca 442 = -79341.20 Epsilon = 0.562
# 86
# 133
# resultado da epoca 443 = -49258.38 Epsilon = 0.561
# 100
# 119
# resultado da epoca 444 = -68753.50 Epsilon = 0.560
# 88
# 131
# resultado da epoca 445 = -26750.14 Epsilon = 0.559
# 95
# 124
# resultado da epoca 446 = -87421.04 Epsilon = 0.558
# 73
# 146
# resultado da epoca 447 = -70281.94 Epsilon = 0.557
# 86
# 133
# resultado da epoca 448 = -25946.34 Epsilon = 0.556
# 87
# 132
# resultado da epoca 449 = -57961.40 Epsilon = 0.555
# 93
# 126
# resultado da epoca 450 = -67570.80 Epsilon = 0.554
# 94
# 125
# resultado da epoca 451 = -31688.72 Epsilon = 0.554
# 96
# 123
# resultado da epoca 452 = -59388.12 Epsilon = 0.553
# 93
# 126
# resultado da epoca 453 = -49148.76 Epsilon = 0.552
# 90
# 129
# resultado da epoca 454 = -27344.92 Epsilon = 0.551
# 99
# 120
# resultado da epoca 455 = 3701.30 Epsilon = 0.550
# 105
# 114
# resultado da epoca 456 = -19206.86 Epsilon = 0.549
# 103
# 116
# resultado da epoca 457 = -42431.84 Epsilon = 0.548
# 93
# 126
# resultado da epoca 458 = -56809.18 Epsilon = 0.547
# 87
# 132
# resultado da epoca 459 = -36292.14 Epsilon = 0.546
# 93
# 126
# resultado da epoca 460 = -63845.66 Epsilon = 0.545
# 87
# 132
# resultado da epoca 461 = -27769.54 Epsilon = 0.544
# 94
# 125
# resultado da epoca 462 = -22494.18 Epsilon = 0.543
# 100
# 119
# resultado da epoca 463 = -50867.52 Epsilon = 0.542
# 93
# 126
# resultado da epoca 464 = -35001.10 Epsilon = 0.541
# 94
# 125
# resultado da epoca 465 = -50281.92 Epsilon = 0.540
# 102
# 117
# resultado da epoca 466 = -34644.90 Epsilon = 0.539
# 103
# 116
# resultado da epoca 467 = -38302.64 Epsilon = 0.538
# 91
# 128
# resultado da epoca 468 = -51239.96 Epsilon = 0.537
# 86
# 133
# resultado da epoca 469 = -63837.28 Epsilon = 0.536
# 93
# 126
# resultado da epoca 470 = -28944.22 Epsilon = 0.535
# 90
# 129
# resultado da epoca 471 = -68377.66 Epsilon = 0.534
# 95
# 124
# resultado da epoca 472 = -23242.28 Epsilon = 0.533
# 97
# 122
# resultado da epoca 473 = -59468.72 Epsilon = 0.532
# 92
# 127
# resultado da epoca 474 = -42639.30 Epsilon = 0.531
# 92
# 127
# resultado da epoca 475 = -9852.68 Epsilon = 0.530
# 102
# 117
# resultado da epoca 476 = -46889.18 Epsilon = 0.529
# 99
# 120
# resultado da epoca 477 = -30308.86 Epsilon = 0.528
# 101
# 118
# resultado da epoca 478 = -77671.32 Epsilon = 0.527
# 76
# 143
# resultado da epoca 479 = -16772.60 Epsilon = 0.526
# 107
# 112
# resultado da epoca 480 = -46655.52 Epsilon = 0.525
# 87
# 132
# resultado da epoca 481 = -72517.32 Epsilon = 0.524
# 89
# 130
# resultado da epoca 482 = -54181.42 Epsilon = 0.523
# 93
# 126
# resultado da epoca 483 = -44049.46 Epsilon = 0.522
# 86
# 133
# resultado da epoca 484 = -53125.62 Epsilon = 0.521
# 99
# 120
# resultado da epoca 485 = -25686.04 Epsilon = 0.520
# 93
# 126
# resultado da epoca 486 = -50365.74 Epsilon = 0.519
# 89
# 130
# resultado da epoca 487 = -44735.92 Epsilon = 0.518
# 91
# 128
# resultado da epoca 488 = -44905.34 Epsilon = 0.517
# 92
# 127
# resultado da epoca 489 = -23251.88 Epsilon = 0.516
# 99
# 120
# resultado da epoca 490 = -35826.84 Epsilon = 0.515
# 94
# 125
# resultado da epoca 491 = -59839.08 Epsilon = 0.514
# 93
# 126
# resultado da epoca 492 = -57678.78 Epsilon = 0.513
# 90
# 129
# resultado da epoca 493 = -60566.04 Epsilon = 0.512
# 87
# 132
# resultado da epoca 494 = -42530.32 Epsilon = 0.511
# 89
# 130
# resultado da epoca 495 = -42626.06 Epsilon = 0.510
# 99
# 120
# resultado da epoca 496 = -30809.92 Epsilon = 0.509
# 103
# 116
# resultado da epoca 497 = -75506.14 Epsilon = 0.508
# 94
# 125
# resultado da epoca 498 = -9340.24 Epsilon = 0.507
# 102
# 117
# resultado da epoca 499 = -45768.62 Epsilon = 0.506
# 95
# 124
# resultado da epoca 500 = -29820.72 Epsilon = 0.505
# 96
# 123
# resultado da epoca 501 = -51152.08 Epsilon = 0.504
# 92
# 127
# resultado da epoca 502 = -49849.20 Epsilon = 0.503
# 95
# 124
# resultado da epoca 503 = -78127.98 Epsilon = 0.502
# 83
# 136
# resultado da epoca 504 = -18434.14 Epsilon = 0.501
# 102
# 117
# resultado da epoca 505 = -50179.82 Epsilon = 0.500
# 92
# 127
# resultado da epoca 506 = -48663.10 Epsilon = 0.499
# 97
# 122
# resultado da epoca 507 = -73823.40 Epsilon = 0.498
# 88
# 131
# resultado da epoca 508 = -35572.32 Epsilon = 0.497
# 95
# 124
# resultado da epoca 509 = -79179.26 Epsilon = 0.496
# 86
# 133
# resultado da epoca 510 = -28977.50 Epsilon = 0.495
# 107
# 112
# resultado da epoca 511 = -46646.10 Epsilon = 0.494
# 95
# 124
# resultado da epoca 512 = -60158.42 Epsilon = 0.493
# 87
# 132
# resultado da epoca 513 = -19945.08 Epsilon = 0.492
# 98
# 121
# resultado da epoca 514 = -50940.06 Epsilon = 0.491
# 97
# 122
# resultado da epoca 515 = -20682.16 Epsilon = 0.490
# 100
# 119
# resultado da epoca 516 = -51853.02 Epsilon = 0.489
# 91
# 128
# resultado da epoca 517 = -35120.22 Epsilon = 0.488
# 98
# 121
# resultado da epoca 518 = -53038.10 Epsilon = 0.487
# 92
# 127
# resultado da epoca 519 = -46818.88 Epsilon = 0.486
# 106
# 113
# resultado da epoca 520 = -37918.36 Epsilon = 0.485
# 102
# 117
# resultado da epoca 521 = -22228.42 Epsilon = 0.484
# 101
# 118
# resultado da epoca 522 = -35496.62 Epsilon = 0.483
# 92
# 127
# resultado da epoca 523 = -43907.80 Epsilon = 0.482
# 92
# 127
# resultado da epoca 524 = -24096.50 Epsilon = 0.481
# 110
# 109
# resultado da epoca 525 = -67558.34 Epsilon = 0.480
# 89
# 130
# resultado da epoca 526 = -16697.06 Epsilon = 0.479
# 101
# 118
# resultado da epoca 527 = -39145.16 Epsilon = 0.478
# 97
# 122
# resultado da epoca 528 = -11098.10 Epsilon = 0.477
# 107
# 112
# resultado da epoca 529 = -34709.06 Epsilon = 0.476
# 99
# 120
# resultado da epoca 530 = -62725.30 Epsilon = 0.475
# 93
# 126
# resultado da epoca 531 = -53588.78 Epsilon = 0.474
# 92
# 127
# resultado da epoca 532 = -38089.18 Epsilon = 0.473
# 86
# 133
# resultado da epoca 533 = -51059.20 Epsilon = 0.472
# 100
# 119
# resultado da epoca 534 = -19643.30 Epsilon = 0.471
# 97
# 122
# resultado da epoca 535 = -28157.90 Epsilon = 0.470
# 104
# 115
# resultado da epoca 536 = -42295.68 Epsilon = 0.469
# 93
# 126
# resultado da epoca 537 = -44323.80 Epsilon = 0.468
# 95
# 124
# resultado da epoca 538 = -28923.32 Epsilon = 0.467
# 102
# 117
# resultado da epoca 539 = -64150.42 Epsilon = 0.466
# 91
# 128
# resultado da epoca 540 = -38581.60 Epsilon = 0.465
# 93
# 126
# resultado da epoca 541 = -2481.60 Epsilon = 0.464
# 103
# 116
# resultado da epoca 542 = -56609.50 Epsilon = 0.463
# 94
# 125
# resultado da epoca 543 = -73176.18 Epsilon = 0.462
# 80
# 139
# resultado da epoca 544 = -17209.24 Epsilon = 0.461
# 106
# 113
# resultado da epoca 545 = -35066.40 Epsilon = 0.460
# 104
# 115
# resultado da epoca 546 = -54867.70 Epsilon = 0.459
# 93
# 126
# resultado da epoca 547 = -20486.96 Epsilon = 0.458
# 107
# 112
# resultado da epoca 548 = -49878.30 Epsilon = 0.457
# 94
# 125
# resultado da epoca 549 = -17986.48 Epsilon = 0.456
# 108
# 111
# resultado da epoca 550 = -20421.52 Epsilon = 0.455
# 95
# 124
# resultado da epoca 551 = -39125.22 Epsilon = 0.455
# 96
# 123
# resultado da epoca 552 = -47419.52 Epsilon = 0.454
# 92
# 127
# resultado da epoca 553 = -21246.06 Epsilon = 0.453
# 99
# 120
# resultado da epoca 554 = -68677.56 Epsilon = 0.452
# 90
# 129
# resultado da epoca 555 = -28345.24 Epsilon = 0.451
# 103
# 116
# resultado da epoca 556 = -37736.90 Epsilon = 0.450
# 97
# 122
# resultado da epoca 557 = -22135.90 Epsilon = 0.449
# 105
# 114
# resultado da epoca 558 = -42503.54 Epsilon = 0.448
# 96
# 123
# resultado da epoca 559 = -34309.42 Epsilon = 0.447
# 94
# 125
# resultado da epoca 560 = -34369.96 Epsilon = 0.446
# 92
# 127
# resultado da epoca 561 = -33922.14 Epsilon = 0.445
# 95
# 124
# resultado da epoca 562 = -65069.88 Epsilon = 0.444
# 89
# 130
# resultado da epoca 563 = -37517.74 Epsilon = 0.443
# 98
# 121
# resultado da epoca 564 = -35403.42 Epsilon = 0.442
# 103
# 116
# resultado da epoca 565 = -36265.10 Epsilon = 0.441
# 99
# 120
# resultado da epoca 566 = -78191.78 Epsilon = 0.440
# 87
# 132
# resultado da epoca 567 = -30153.66 Epsilon = 0.439
# 94
# 125
# resultado da epoca 568 = -80754.38 Epsilon = 0.438
# 80
# 139
# resultado da epoca 569 = -51015.42 Epsilon = 0.437
# 91
# 128
# resultado da epoca 570 = -66176.28 Epsilon = 0.436
# 94
# 125
# resultado da epoca 571 = -53254.98 Epsilon = 0.435
# 89
# 130
# resultado da epoca 572 = -47997.78 Epsilon = 0.434
# 91
# 128
# resultado da epoca 573 = -11300.74 Epsilon = 0.433
# 101
# 118
# resultado da epoca 574 = -40514.66 Epsilon = 0.432
# 98
# 121
# resultado da epoca 575 = -49220.36 Epsilon = 0.431
# 87
# 132
# resultado da epoca 576 = -28777.74 Epsilon = 0.430
# 94
# 125
# resultado da epoca 577 = -34193.52 Epsilon = 0.429
# 96
# 123
# resultado da epoca 578 = -32373.34 Epsilon = 0.428
# 101
# 118
# resultado da epoca 579 = -17726.84 Epsilon = 0.427
# 111
# 108
# resultado da epoca 580 = -86431.02 Epsilon = 0.426
# 80
# 139
# resultado da epoca 581 = -25446.70 Epsilon = 0.425
# 98
# 121
# resultado da epoca 582 = -53019.52 Epsilon = 0.424
# 102
# 117
# resultado da epoca 583 = -40052.88 Epsilon = 0.423
# 101
# 118
# resultado da epoca 584 = -55548.76 Epsilon = 0.422
# 82
# 137
# resultado da epoca 585 = -47177.60 Epsilon = 0.421
# 95
# 124
# resultado da epoca 586 = -52078.10 Epsilon = 0.420
# 92
# 127
# resultado da epoca 587 = -53376.86 Epsilon = 0.419
# 94
# 125
# resultado da epoca 588 = -40135.74 Epsilon = 0.418
# 94
# 125
# resultado da epoca 589 = -59015.28 Epsilon = 0.417
# 94
# 125
# resultado da epoca 590 = -69755.54 Epsilon = 0.416
# 82
# 137
# resultado da epoca 591 = -40900.78 Epsilon = 0.415
# 90
# 129
# resultado da epoca 592 = -10898.36 Epsilon = 0.414
# 111
# 108
# resultado da epoca 593 = -29043.12 Epsilon = 0.413
# 99
# 120
# resultado da epoca 594 = -23963.02 Epsilon = 0.412
# 98
# 121
# resultado da epoca 595 = -44212.12 Epsilon = 0.411
# 92
# 127
# resultado da epoca 596 = -73222.62 Epsilon = 0.410
# 83
# 136
# resultado da epoca 597 = -60965.14 Epsilon = 0.409
# 100
# 119
# resultado da epoca 598 = -80451.80 Epsilon = 0.408
# 82
# 137
# resultado da epoca 599 = -62024.52 Epsilon = 0.407
# 87
# 132
# resultado da epoca 600 = -26018.90 Epsilon = 0.406
# 100
# 119
# resultado da epoca 601 = -31705.24 Epsilon = 0.405
# 105
# 114
# resultado da epoca 602 = -39579.96 Epsilon = 0.404
# 90
# 129
# resultado da epoca 603 = -41332.64 Epsilon = 0.403
# 102
# 117
# resultado da epoca 604 = -44321.28 Epsilon = 0.402
# 96
# 123
# resultado da epoca 605 = -15797.16 Epsilon = 0.401
# 98
# 121
# resultado da epoca 606 = -36960.48 Epsilon = 0.400
# 97
# 122
# resultado da epoca 607 = -66404.54 Epsilon = 0.399
# 93
# 126
# resultado da epoca 608 = -66212.44 Epsilon = 0.398
# 92
# 127
# resultado da epoca 609 = -50156.66 Epsilon = 0.397
# 84
# 135
# resultado da epoca 610 = -26611.78 Epsilon = 0.396
# 101
# 118
# resultado da epoca 611 = -41590.10 Epsilon = 0.395
# 89
# 130
# resultado da epoca 612 = -44552.58 Epsilon = 0.394
# 92
# 127
# resultado da epoca 613 = -31304.14 Epsilon = 0.393
# 101
# 118
# resultado da epoca 614 = -65043.98 Epsilon = 0.392
# 84
# 135
# resultado da epoca 615 = -24176.78 Epsilon = 0.391
# 104
# 115
# resultado da epoca 616 = -15536.70 Epsilon = 0.390
# 107
# 112
# resultado da epoca 617 = -39797.58 Epsilon = 0.389
# 96
# 123
# resultado da epoca 618 = -52587.50 Epsilon = 0.388
# 94
# 125
# resultado da epoca 619 = -46961.42 Epsilon = 0.387
# 89
# 130
# resultado da epoca 620 = -56303.98 Epsilon = 0.386
# 101
# 118
# resultado da epoca 621 = -45612.90 Epsilon = 0.385
# 98
# 121
# resultado da epoca 622 = -32472.02 Epsilon = 0.384
# 99
# 120
# resultado da epoca 623 = -32807.50 Epsilon = 0.383
# 101
# 118
# resultado da epoca 624 = -18757.36 Epsilon = 0.382
# 103
# 116
# resultado da epoca 625 = -58273.48 Epsilon = 0.381
# 96
# 123
# resultado da epoca 626 = -37549.76 Epsilon = 0.380
# 102
# 117
# resultado da epoca 627 = -17480.50 Epsilon = 0.379
# 99
# 120
# resultado da epoca 628 = -7177.28 Epsilon = 0.378
# 106
# 113
# resultado da epoca 629 = -32917.52 Epsilon = 0.377
# 105
# 114
# resultado da epoca 630 = -40216.42 Epsilon = 0.376
# 88
# 131
# resultado da epoca 631 = -21043.80 Epsilon = 0.375
# 103
# 116
# resultado da epoca 632 = -63464.04 Epsilon = 0.374
# 88
# 131
# resultado da epoca 633 = -42560.90 Epsilon = 0.373
# 94
# 125
# resultado da epoca 634 = -18230.88 Epsilon = 0.372
# 101
# 118
# resultado da epoca 635 = -30962.22 Epsilon = 0.371
# 96
# 123
# resultado da epoca 636 = -57629.64 Epsilon = 0.370
# 97
# 122
# resultado da epoca 637 = -24163.32 Epsilon = 0.369
# 100
# 119
# resultado da epoca 638 = -25546.06 Epsilon = 0.368
# 98
# 121
# resultado da epoca 639 = -35004.60 Epsilon = 0.367
# 102
# 117
# resultado da epoca 640 = -43198.22 Epsilon = 0.366
# 101
# 118
# resultado da epoca 641 = -28701.52 Epsilon = 0.365
# 97
# 122
# resultado da epoca 642 = -23100.38 Epsilon = 0.364
# 100
# 119
# resultado da epoca 643 = -35648.08 Epsilon = 0.363
# 89
# 130
# resultado da epoca 644 = -47160.20 Epsilon = 0.362
# 92
# 127
# resultado da epoca 645 = -14350.06 Epsilon = 0.361
# 112
# 107
# resultado da epoca 646 = -59536.62 Epsilon = 0.360
# 96
# 123
# resultado da epoca 647 = -51995.00 Epsilon = 0.359
# 88
# 131
# resultado da epoca 648 = -15117.68 Epsilon = 0.358
# 106
# 113
# resultado da epoca 649 = -45909.08 Epsilon = 0.357
# 89
# 130
# resultado da epoca 650 = -26644.74 Epsilon = 0.356
# 98
# 121
# resultado da epoca 651 = -6279.18 Epsilon = 0.356
# 102
# 117
# resultado da epoca 652 = -25816.34 Epsilon = 0.355
# 102
# 117
# resultado da epoca 653 = -29036.12 Epsilon = 0.354
# 100
# 119
# resultado da epoca 654 = -42753.66 Epsilon = 0.353
# 93
# 126
# resultado da epoca 655 = -20736.04 Epsilon = 0.352
# 97
# 122
# resultado da epoca 656 = -26344.26 Epsilon = 0.351
# 97
# 122
# resultado da epoca 657 = -17858.76 Epsilon = 0.350
# 104
# 115
# resultado da epoca 658 = -35084.74 Epsilon = 0.349
# 95
# 124
# resultado da epoca 659 = -46160.94 Epsilon = 0.348
# 98
# 121
# resultado da epoca 660 = -40086.82 Epsilon = 0.347
# 100
# 119
# resultado da epoca 661 = -48797.24 Epsilon = 0.346
# 92
# 127
# resultado da epoca 662 = -19843.06 Epsilon = 0.345
# 103
# 116
# resultado da epoca 663 = -41915.98 Epsilon = 0.344
# 94
# 125
# resultado da epoca 664 = -35557.48 Epsilon = 0.343
# 96
# 123
# resultado da epoca 665 = -30879.96 Epsilon = 0.342
# 100
# 119
# resultado da epoca 666 = -35168.60 Epsilon = 0.341
# 94
# 125
# resultado da epoca 667 = -35698.86 Epsilon = 0.340
# 97
# 122
# resultado da epoca 668 = -18924.44 Epsilon = 0.339
# 95
# 124
# resultado da epoca 669 = -45177.52 Epsilon = 0.338
# 96
# 123
# resultado da epoca 670 = -47442.56 Epsilon = 0.337
# 105
# 114
# resultado da epoca 671 = -30930.94 Epsilon = 0.336
# 105
# 114
# resultado da epoca 672 = -39450.08 Epsilon = 0.335
# 95
# 124
# resultado da epoca 673 = -50038.46 Epsilon = 0.334
# 103
# 116
# resultado da epoca 674 = -14950.88 Epsilon = 0.333
# 98
# 121
# resultado da epoca 675 = -30187.00 Epsilon = 0.332
# 93
# 126
# resultado da epoca 676 = -56976.70 Epsilon = 0.331
# 85
# 134
# resultado da epoca 677 = -10248.32 Epsilon = 0.330
# 101
# 118
# resultado da epoca 678 = -23027.56 Epsilon = 0.329
# 92
# 127
# resultado da epoca 679 = -32291.70 Epsilon = 0.328
# 99
# 120
# resultado da epoca 680 = -34662.82 Epsilon = 0.327
# 99
# 120
# resultado da epoca 681 = -15137.50 Epsilon = 0.326
# 104
# 115
# resultado da epoca 682 = -37277.18 Epsilon = 0.325
# 90
# 129
# resultado da epoca 683 = -11686.08 Epsilon = 0.324
# 101
# 118
# resultado da epoca 684 = -29834.02 Epsilon = 0.323
# 102
# 117
# resultado da epoca 685 = -25630.04 Epsilon = 0.322
# 101
# 118
# resultado da epoca 686 = -46221.00 Epsilon = 0.321
# 98
# 121
# resultado da epoca 687 = -23476.14 Epsilon = 0.320
# 97
# 122
# resultado da epoca 688 = -22076.78 Epsilon = 0.319
# 103
# 116
# resultado da epoca 689 = -54836.32 Epsilon = 0.318
# 85
# 134
# resultado da epoca 690 = -20405.82 Epsilon = 0.317
# 95
# 124
# resultado da epoca 691 = -38963.40 Epsilon = 0.316
# 91
# 128
# resultado da epoca 692 = -21270.28 Epsilon = 0.315
# 104
# 115
# resultado da epoca 693 = -29846.42 Epsilon = 0.314
# 107
# 112
# resultado da epoca 694 = 2697.42 Epsilon = 0.313
# 110
# 109
# resultado da epoca 695 = -29654.96 Epsilon = 0.312
# 100
# 119
# resultado da epoca 696 = -39821.20 Epsilon = 0.311
# 90
# 129
# resultado da epoca 697 = -42159.02 Epsilon = 0.310
# 86
# 133
# resultado da epoca 698 = -31741.42 Epsilon = 0.309
# 94
# 125
# resultado da epoca 699 = -38515.66 Epsilon = 0.308
# 97
# 122
# resultado da epoca 700 = -44865.48 Epsilon = 0.307
# 92
# 127
# resultado da epoca 701 = -18489.02 Epsilon = 0.306
# 102
# 117
# resultado da epoca 702 = -37221.72 Epsilon = 0.305
# 102
# 117
# resultado da epoca 703 = -35138.56 Epsilon = 0.304
# 105
# 114
# resultado da epoca 704 = -36014.24 Epsilon = 0.303
# 89
# 130
# resultado da epoca 705 = -37592.02 Epsilon = 0.302
# 101
# 118
# resultado da epoca 706 = -28690.68 Epsilon = 0.301
# 94
# 125
# resultado da epoca 707 = -1766.98 Epsilon = 0.300
# 105
# 114
# resultado da epoca 708 = -42335.24 Epsilon = 0.299
# 96
# 123
# resultado da epoca 709 = -32431.64 Epsilon = 0.298
# 100
# 119
# resultado da epoca 710 = -37598.90 Epsilon = 0.297
# 96
# 123
# resultado da epoca 711 = -45173.84 Epsilon = 0.296
# 95
# 124
# resultado da epoca 712 = -44102.48 Epsilon = 0.295
# 95
# 124
# resultado da epoca 713 = -21191.04 Epsilon = 0.294
# 105
# 114
# resultado da epoca 714 = -21867.76 Epsilon = 0.293
# 94
# 125
# resultado da epoca 715 = -26057.34 Epsilon = 0.292
# 106
# 113
# resultado da epoca 716 = -31441.94 Epsilon = 0.291
# 98
# 121
# resultado da epoca 717 = -40052.74 Epsilon = 0.290
# 93
# 126
# resultado da epoca 718 = -44287.74 Epsilon = 0.289
# 95
# 124
# resultado da epoca 719 = -33471.74 Epsilon = 0.288
# 101
# 118
# resultado da epoca 720 = -13828.28 Epsilon = 0.287
# 96
# 123
# resultado da epoca 721 = -43668.26 Epsilon = 0.286
# 98
# 121
# resultado da epoca 722 = -31666.88 Epsilon = 0.285
# 96
# 123
# resultado da epoca 723 = -27505.50 Epsilon = 0.284
# 90
# 129
# resultado da epoca 724 = -30044.70 Epsilon = 0.283
# 105
# 114
# resultado da epoca 725 = -27901.20 Epsilon = 0.282
# 94
# 125
# resultado da epoca 726 = -22634.84 Epsilon = 0.281
# 94
# 125
# resultado da epoca 727 = -15056.32 Epsilon = 0.280
# 106
# 113
# resultado da epoca 728 = -21226.54 Epsilon = 0.279
# 100
# 119
# resultado da epoca 729 = -12128.18 Epsilon = 0.278
# 102
# 117
# resultado da epoca 730 = -39043.36 Epsilon = 0.277
# 95
# 124
# resultado da epoca 731 = -2350.00 Epsilon = 0.276
# 112
# 107
# resultado da epoca 732 = -37636.00 Epsilon = 0.275
# 93
# 126
# resultado da epoca 733 = -15642.18 Epsilon = 0.274
# 103
# 116
# resultado da epoca 734 = -65579.76 Epsilon = 0.273
# 94
# 125
# resultado da epoca 735 = -18249.80 Epsilon = 0.272
# 101
# 118
# resultado da epoca 736 = -41506.58 Epsilon = 0.271
# 97
# 122
# resultado da epoca 737 = -44148.04 Epsilon = 0.270
# 97
# 122
# resultado da epoca 738 = -41076.60 Epsilon = 0.269
# 107
# 112
# resultado da epoca 739 = -52617.36 Epsilon = 0.268
# 85
# 134
# resultado da epoca 740 = -44917.80 Epsilon = 0.267
# 98
# 121
# resultado da epoca 741 = -19793.70 Epsilon = 0.266
# 102
# 117
# resultado da epoca 742 = -29799.44 Epsilon = 0.265
# 99
# 120
# resultado da epoca 743 = -10234.36 Epsilon = 0.264
# 106
# 113
# resultado da epoca 744 = -30801.54 Epsilon = 0.263
# 99
# 120
# resultado da epoca 745 = -7067.48 Epsilon = 0.262
# 105
# 114
# resultado da epoca 746 = -23493.34 Epsilon = 0.261
# 103
# 116
# resultado da epoca 747 = -22995.50 Epsilon = 0.260
# 90
# 129
# resultado da epoca 748 = -52772.42 Epsilon = 0.259
# 95
# 124
# resultado da epoca 749 = -13327.98 Epsilon = 0.258
# 104
# 115
# resultado da epoca 750 = -18803.68 Epsilon = 0.257
# 105
# 114
# resultado da epoca 751 = -28665.26 Epsilon = 0.257
# 98
# 121
# resultado da epoca 752 = 1800.34 Epsilon = 0.256
# 111
# 108
# resultado da epoca 753 = -15482.52 Epsilon = 0.255
# 100
# 119
# resultado da epoca 754 = -41981.48 Epsilon = 0.254
# 95
# 124
# resultado da epoca 755 = -15792.44 Epsilon = 0.253
# 107
# 112
# resultado da epoca 756 = -40017.04 Epsilon = 0.252
# 97
# 122
# resultado da epoca 757 = -25641.12 Epsilon = 0.251
# 104
# 115
# resultado da epoca 758 = -34005.42 Epsilon = 0.250
# 104
# 115
# resultado da epoca 759 = -21415.14 Epsilon = 0.249
# 98
# 121
# resultado da epoca 760 = -14908.14 Epsilon = 0.248
# 108
# 111
# resultado da epoca 761 = -37360.50 Epsilon = 0.247
# 102
# 117
# resultado da epoca 762 = -17313.66 Epsilon = 0.246
# 98
# 121
# resultado da epoca 763 = -43418.98 Epsilon = 0.245
# 93
# 126
# resultado da epoca 764 = -32964.42 Epsilon = 0.244
# 98
# 121
# resultado da epoca 765 = -35524.26 Epsilon = 0.243
# 93
# 126
# resultado da epoca 766 = -37890.70 Epsilon = 0.242
# 101
# 118
# resultado da epoca 767 = -29051.88 Epsilon = 0.241
# 93
# 126
# resultado da epoca 768 = -9855.72 Epsilon = 0.240
# 101
# 118
# resultado da epoca 769 = -15356.48 Epsilon = 0.239
# 105
# 114
# resultado da epoca 770 = -20722.48 Epsilon = 0.238
# 102
# 117
# resultado da epoca 771 = -21415.70 Epsilon = 0.237
# 105
# 114
# resultado da epoca 772 = -25751.08 Epsilon = 0.236
# 96
# 123
# resultado da epoca 773 = -25996.56 Epsilon = 0.235
# 98
# 121
# resultado da epoca 774 = -24915.62 Epsilon = 0.234
# 102
# 117
# resultado da epoca 775 = -15642.80 Epsilon = 0.233
# 103
# 116
# resultado da epoca 776 = -23907.54 Epsilon = 0.232
# 99
# 120
# resultado da epoca 777 = -43115.30 Epsilon = 0.231
# 97
# 122
# resultado da epoca 778 = -49483.58 Epsilon = 0.230
# 91
# 128
# resultado da epoca 779 = 3905.40 Epsilon = 0.229
# 105
# 114
# resultado da epoca 780 = -36492.14 Epsilon = 0.228
# 100
# 119
# resultado da epoca 781 = -10561.90 Epsilon = 0.227
# 96
# 123
# resultado da epoca 782 = -26088.00 Epsilon = 0.226
# 101
# 118
# resultado da epoca 783 = -20406.36 Epsilon = 0.225
# 105
# 114
# resultado da epoca 784 = -21442.50 Epsilon = 0.224
# 99
# 120
# resultado da epoca 785 = -27411.94 Epsilon = 0.223
# 100
# 119
# resultado da epoca 786 = -36040.24 Epsilon = 0.222
# 97
# 122
# resultado da epoca 787 = -22228.56 Epsilon = 0.221
# 110
# 109
# resultado da epoca 788 = -29561.24 Epsilon = 0.220
# 100
# 119
# resultado da epoca 789 = -25616.56 Epsilon = 0.219
# 99
# 120
# resultado da epoca 790 = -11469.38 Epsilon = 0.218
# 107
# 112
# resultado da epoca 791 = -32535.64 Epsilon = 0.217
# 94
# 125
# resultado da epoca 792 = -10866.88 Epsilon = 0.216
# 98
# 121
# resultado da epoca 793 = -32320.18 Epsilon = 0.215
# 97
# 122
# resultado da epoca 794 = -9056.64 Epsilon = 0.214
# 101
# 118
# resultado da epoca 795 = -30601.14 Epsilon = 0.213
# 104
# 115
# resultado da epoca 796 = -8012.70 Epsilon = 0.212
# 105
# 114
# resultado da epoca 797 = -11886.86 Epsilon = 0.211
# 100
# 119
# resultado da epoca 798 = -28374.32 Epsilon = 0.210
# 103
# 116
# resultado da epoca 799 = -13603.14 Epsilon = 0.209
# 102
# 117
# resultado da epoca 800 = -16119.34 Epsilon = 0.208
# 95
# 124
# resultado da epoca 801 = -15039.44 Epsilon = 0.207
# 101
# 118
# resultado da epoca 802 = -62110.36 Epsilon = 0.206
# 94
# 125
# resultado da epoca 803 = -21521.86 Epsilon = 0.205
# 102
# 117
# resultado da epoca 804 = -15717.42 Epsilon = 0.204
# 99
# 120
# resultado da epoca 805 = -9276.34 Epsilon = 0.203
# 100
# 119
# resultado da epoca 806 = -29949.58 Epsilon = 0.202
# 109
# 110
# resultado da epoca 807 = -31097.02 Epsilon = 0.201
# 96
# 123
# resultado da epoca 808 = -21150.84 Epsilon = 0.200
# 102
# 117
# resultado da epoca 809 = -24158.00 Epsilon = 0.199
# 101
# 118
# resultado da epoca 810 = -4631.20 Epsilon = 0.198
# 105
# 114
# resultado da epoca 811 = -24691.26 Epsilon = 0.197
# 98
# 121
# resultado da epoca 812 = -34351.66 Epsilon = 0.196
# 101
# 118
# resultado da epoca 813 = -39392.22 Epsilon = 0.195
# 96
# 123
# resultado da epoca 814 = -7313.02 Epsilon = 0.194
# 99
# 120
# resultado da epoca 815 = -29161.96 Epsilon = 0.193
# 102
# 117
# resultado da epoca 816 = -13305.66 Epsilon = 0.192
# 104
# 115
# resultado da epoca 817 = -13684.96 Epsilon = 0.191
# 103
# 116
# resultado da epoca 818 = -13897.58 Epsilon = 0.190
# 108
# 111
# resultado da epoca 819 = -22693.66 Epsilon = 0.189
# 100
# 119
# resultado da epoca 820 = -25999.40 Epsilon = 0.188
# 107
# 112
# resultado da epoca 821 = -24061.48 Epsilon = 0.187
# 95
# 124
# resultado da epoca 822 = -12550.98 Epsilon = 0.186
# 106
# 113
# resultado da epoca 823 = 3341.08 Epsilon = 0.185
# 110
# 109
# resultado da epoca 824 = -13271.16 Epsilon = 0.184
# 95
# 124
# resultado da epoca 825 = -17930.60 Epsilon = 0.183
# 104
# 115
# resultado da epoca 826 = -25883.06 Epsilon = 0.182
# 104
# 115
# resultado da epoca 827 = -10461.88 Epsilon = 0.181
# 97
# 122
# resultado da epoca 828 = -21970.48 Epsilon = 0.180
# 94
# 125
# resultado da epoca 829 = -20700.68 Epsilon = 0.179
# 101
# 118
# resultado da epoca 830 = -11052.78 Epsilon = 0.178
# 101
# 118
# resultado da epoca 831 = -32430.16 Epsilon = 0.177
# 93
# 126
# resultado da epoca 832 = -27385.44 Epsilon = 0.176
# 108
# 111
# resultado da epoca 833 = -9374.50 Epsilon = 0.175
# 105
# 114
# resultado da epoca 834 = -47056.38 Epsilon = 0.174
# 98
# 121
# resultado da epoca 835 = -8157.00 Epsilon = 0.173
# 106
# 113
# resultado da epoca 836 = -44436.76 Epsilon = 0.172
# 98
# 121
# resultado da epoca 837 = -14493.36 Epsilon = 0.171
# 99
# 120
# resultado da epoca 838 = -27589.68 Epsilon = 0.170
# 100
# 119
# resultado da epoca 839 = -21121.20 Epsilon = 0.169
# 106
# 113
# resultado da epoca 840 = -20376.46 Epsilon = 0.168
# 100
# 119
# resultado da epoca 841 = -13054.56 Epsilon = 0.167
# 109
# 110
# resultado da epoca 842 = -36053.64 Epsilon = 0.166
# 97
# 122
# resultado da epoca 843 = -36573.68 Epsilon = 0.165
# 100
# 119
# resultado da epoca 844 = -22358.62 Epsilon = 0.164
# 105
# 114
# resultado da epoca 845 = -5638.76 Epsilon = 0.163
# 109
# 110
# resultado da epoca 846 = -19672.50 Epsilon = 0.162
# 97
# 122
# resultado da epoca 847 = -20178.00 Epsilon = 0.161
# 108
# 111
# resultado da epoca 848 = -26895.30 Epsilon = 0.160
# 105
# 114
# resultado da epoca 849 = -9125.54 Epsilon = 0.159
# 103
# 116
# resultado da epoca 850 = -33640.56 Epsilon = 0.158
# 102
# 117
# resultado da epoca 851 = -10229.24 Epsilon = 0.158
# 108
# 111
# resultado da epoca 852 = -26242.76 Epsilon = 0.157
# 97
# 122
# resultado da epoca 853 = -8858.92 Epsilon = 0.156
# 109
# 110
# resultado da epoca 854 = -45431.38 Epsilon = 0.155
# 94
# 125
# resultado da epoca 855 = -25317.52 Epsilon = 0.154
# 97
# 122
# resultado da epoca 856 = -7921.06 Epsilon = 0.153
# 105
# 114
# resultado da epoca 857 = -18561.26 Epsilon = 0.152
# 98
# 121
# resultado da epoca 858 = -14986.80 Epsilon = 0.151
# 100
# 119
# resultado da epoca 859 = -37537.78 Epsilon = 0.150
# 95
# 124
# resultado da epoca 860 = -5443.90 Epsilon = 0.149
# 102
# 117
# resultado da epoca 861 = -27755.16 Epsilon = 0.148
# 100
# 119
# resultado da epoca 862 = -15293.52 Epsilon = 0.147
# 96
# 123
# resultado da epoca 863 = -15007.62 Epsilon = 0.146
# 101
# 118
# resultado da epoca 864 = -22154.80 Epsilon = 0.145
# 101
# 118
# resultado da epoca 865 = -5277.46 Epsilon = 0.144
# 105
# 114
# resultado da epoca 866 = -35759.54 Epsilon = 0.143
# 99
# 120
# resultado da epoca 867 = -27757.22 Epsilon = 0.142
# 104
# 115
# resultado da epoca 868 = -15929.40 Epsilon = 0.141
# 102
# 117
# resultado da epoca 869 = 1806.98 Epsilon = 0.140
# 103
# 116
# resultado da epoca 870 = -13632.02 Epsilon = 0.139
# 98
# 121
# resultado da epoca 871 = -15489.36 Epsilon = 0.138
# 107
# 112
# resultado da epoca 872 = -32655.34 Epsilon = 0.137
# 105
# 114
# resultado da epoca 873 = -9235.16 Epsilon = 0.136
# 101
# 118
# resultado da epoca 874 = -10369.94 Epsilon = 0.135
# 104
# 115
# resultado da epoca 875 = -22917.10 Epsilon = 0.134
# 99
# 120
# resultado da epoca 876 = -27712.12 Epsilon = 0.133
# 97
# 122
# resultado da epoca 877 = -16958.92 Epsilon = 0.132
# 101
# 118
# resultado da epoca 878 = -21014.16 Epsilon = 0.131
# 97
# 122
# resultado da epoca 879 = -2842.50 Epsilon = 0.130
# 109
# 110
# resultado da epoca 880 = -6881.08 Epsilon = 0.129
# 100
# 119
# resultado da epoca 881 = -24682.82 Epsilon = 0.128
# 97
# 122
# resultado da epoca 882 = -895.50 Epsilon = 0.127
# 101
# 118
# resultado da epoca 883 = -10735.56 Epsilon = 0.126
# 102
# 117
# resultado da epoca 884 = -8779.18 Epsilon = 0.125
# 98
# 121
# resultado da epoca 885 = -22566.90 Epsilon = 0.124
# 102
# 117
# resultado da epoca 886 = -4806.50 Epsilon = 0.123
# 103
# 116
# resultado da epoca 887 = -29230.82 Epsilon = 0.122
# 97
# 122
# resultado da epoca 888 = -25707.48 Epsilon = 0.121
# 98
# 121
# resultado da epoca 889 = -23742.72 Epsilon = 0.120
# 91
# 128
# resultado da epoca 890 = -29053.78 Epsilon = 0.119
# 103
# 116
# resultado da epoca 891 = -18118.68 Epsilon = 0.118
# 98
# 121
# resultado da epoca 892 = -13816.26 Epsilon = 0.117
# 106
# 113
# resultado da epoca 893 = 2325.44 Epsilon = 0.116
# 106
# 113
# resultado da epoca 894 = -5034.06 Epsilon = 0.115
# 108
# 111
# resultado da epoca 895 = -15514.10 Epsilon = 0.114
# 104
# 115
# resultado da epoca 896 = -7568.68 Epsilon = 0.113
# 100
# 119
# resultado da epoca 897 = -14352.56 Epsilon = 0.112
# 101
# 118
# resultado da epoca 898 = -11198.52 Epsilon = 0.111
# 99
# 120
# resultado da epoca 899 = -14105.58 Epsilon = 0.110
# 105
# 114
# resultado da epoca 900 = -35432.40 Epsilon = 0.109
# 101
# 118
# resultado da epoca 901 = -25331.30 Epsilon = 0.108
# 92
# 127
# resultado da epoca 902 = -26019.06 Epsilon = 0.107
# 100
# 119
# resultado da epoca 903 = -29257.96 Epsilon = 0.106
# 100
# 119
# resultado da epoca 904 = -27538.08 Epsilon = 0.105
# 99
# 120
# resultado da epoca 905 = -23805.26 Epsilon = 0.104
# 98
# 121
# resultado da epoca 906 = -19257.14 Epsilon = 0.103
# 101
# 118
# resultado da epoca 907 = -10316.26 Epsilon = 0.102
# 100
# 119
# resultado da epoca 908 = -21845.18 Epsilon = 0.101
# 96
# 123
# resultado da epoca 909 = -16256.40 Epsilon = 0.100
# 100
# 119
# resultado da epoca 910 = -23335.96 Epsilon = 0.099
# 102
# 117
# resultado da epoca 911 = -8744.50 Epsilon = 0.098
# 104
# 115
# resultado da epoca 912 = -19018.10 Epsilon = 0.097
# 103
# 116
# resultado da epoca 913 = -130.78 Epsilon = 0.096
# 103
# 116
# resultado da epoca 914 = -17433.00 Epsilon = 0.095
# 97
# 122
# resultado da epoca 915 = -18055.88 Epsilon = 0.094
# 96
# 123
# resultado da epoca 916 = -6235.34 Epsilon = 0.093
# 100
# 119
# resultado da epoca 917 = -20407.40 Epsilon = 0.092
# 98
# 121
# resultado da epoca 918 = -27324.20 Epsilon = 0.091
# 104
# 115
# resultado da epoca 919 = -19328.14 Epsilon = 0.090
# 100
# 119
# resultado da epoca 920 = -7673.56 Epsilon = 0.089
# 102
# 117
# resultado da epoca 921 = -23128.50 Epsilon = 0.088
# 105
# 114
# resultado da epoca 922 = -21776.22 Epsilon = 0.087
# 96
# 123
# resultado da epoca 923 = -23084.64 Epsilon = 0.086
# 95
# 124
# resultado da epoca 924 = -7024.28 Epsilon = 0.085
# 102
# 117
# resultado da epoca 925 = -17429.54 Epsilon = 0.084
# 98
# 121
# resultado da epoca 926 = 2468.74 Epsilon = 0.083
# 108
# 111
# resultado da epoca 927 = -16397.96 Epsilon = 0.082
# 97
# 122
# resultado da epoca 928 = -28234.12 Epsilon = 0.081
# 101
# 118
# resultado da epoca 929 = -14446.50 Epsilon = 0.080
# 97
# 122
# resultado da epoca 930 = -6672.16 Epsilon = 0.079
# 104
# 115
# resultado da epoca 931 = -6564.56 Epsilon = 0.078
# 106
# 113
# resultado da epoca 932 = 4278.56 Epsilon = 0.077
# 111
# 108
# resultado da epoca 933 = -13559.64 Epsilon = 0.076
# 102
# 117
# resultado da epoca 934 = -6822.50 Epsilon = 0.075
# 97
# 122
# resultado da epoca 935 = -13400.88 Epsilon = 0.074
# 99
# 120
# resultado da epoca 936 = -11071.50 Epsilon = 0.073
# 105
# 114
# resultado da epoca 937 = -7062.80 Epsilon = 0.072
# 100
# 119
# resultado da epoca 938 = -33245.68 Epsilon = 0.071
# 93
# 126
# resultado da epoca 939 = -14943.04 Epsilon = 0.070
# 95
# 124
# resultado da epoca 940 = -13048.34 Epsilon = 0.069
# 95
# 124
# resultado da epoca 941 = -17080.74 Epsilon = 0.068
# 101
# 118
# resultado da epoca 942 = -7200.74 Epsilon = 0.067
# 95
# 124
# resultado da epoca 943 = -22523.94 Epsilon = 0.066
# 97
# 122
# resultado da epoca 944 = -24712.40 Epsilon = 0.065
# 94
# 125
# resultado da epoca 945 = -9445.64 Epsilon = 0.064
# 104
# 115
# resultado da epoca 946 = 6771.44 Epsilon = 0.063
# 107
# 112
# resultado da epoca 947 = -704.36 Epsilon = 0.062
# 100
# 119
# resultado da epoca 948 = -13587.74 Epsilon = 0.061
# 102
# 117
# resultado da epoca 949 = -17654.98 Epsilon = 0.060
# 103
# 116
# resultado da epoca 950 = -9139.04 Epsilon = 0.059
# 97
# 122
# resultado da epoca 951 = -2669.96 Epsilon = 0.059
# 105
# 114
# resultado da epoca 952 = -27602.64 Epsilon = 0.058
# 97
# 122
# resultado da epoca 953 = -21255.00 Epsilon = 0.057
# 101
# 118
# resultado da epoca 954 = -9132.06 Epsilon = 0.056
# 100
# 119
# resultado da epoca 955 = -11547.08 Epsilon = 0.055
# 99
# 120
# resultado da epoca 956 = -5186.70 Epsilon = 0.054
# 101
# 118
# resultado da epoca 957 = -6934.94 Epsilon = 0.053
# 100
# 119
# resultado da epoca 958 = -18130.52 Epsilon = 0.052
# 98
# 121
# resultado da epoca 959 = -17363.62 Epsilon = 0.051
# 99
# 120
# resultado da epoca 960 = -6191.82 Epsilon = 0.050
# 100
# 119
# resultado da epoca 961 = -12689.10 Epsilon = 0.049
# 98
# 121
# resultado da epoca 962 = -9947.38 Epsilon = 0.048
# 103
# 116
# resultado da epoca 963 = -8150.06 Epsilon = 0.047
# 95
# 124
# resultado da epoca 964 = -10702.98 Epsilon = 0.046
# 97
# 122
# resultado da epoca 965 = 2111.12 Epsilon = 0.045
# 104
# 115
# resultado da epoca 966 = -8887.06 Epsilon = 0.044
# 96
# 123
# resultado da epoca 967 = -13285.10 Epsilon = 0.043
# 98
# 121
# resultado da epoca 968 = -11185.12 Epsilon = 0.042
# 97
# 122
# resultado da epoca 969 = -7406.00 Epsilon = 0.041
# 101
# 118
# resultado da epoca 970 = 5776.16 Epsilon = 0.040
# 103
# 116
# resultado da epoca 971 = 591.94 Epsilon = 0.039
# 97
# 122
# resultado da epoca 972 = -22571.40 Epsilon = 0.038
# 97
# 122
# resultado da epoca 973 = -7894.74 Epsilon = 0.037
# 104
# 115
# resultado da epoca 974 = -7595.16 Epsilon = 0.036
# 101
# 118
# resultado da epoca 975 = -9784.48 Epsilon = 0.035
# 100
# 119
# resultado da epoca 976 = -12671.46 Epsilon = 0.034
# 97
# 122
# resultado da epoca 977 = -13983.50 Epsilon = 0.033
# 99
# 120
# resultado da epoca 978 = -6101.08 Epsilon = 0.032
# 98
# 121
# resultado da epoca 979 = -5195.28 Epsilon = 0.031
# 94
# 125
# resultado da epoca 980 = -2636.28 Epsilon = 0.030
# 100
# 119
# resultado da epoca 981 = -7731.02 Epsilon = 0.029
# 96
# 123
# resultado da epoca 982 = -9469.68 Epsilon = 0.028
# 105
# 114
# resultado da epoca 983 = -5977.64 Epsilon = 0.027
# 96
# 123
# resultado da epoca 984 = -18085.94 Epsilon = 0.026
# 97
# 122
# resultado da epoca 985 = -2779.14 Epsilon = 0.025
# 96
# 123
# resultado da epoca 986 = -10211.34 Epsilon = 0.024
# 100
# 119
# resultado da epoca 987 = -9658.40 Epsilon = 0.023
# 98
# 121
# resultado da epoca 988 = -6792.80 Epsilon = 0.022
# 97
# 122
# resultado da epoca 989 = -2116.56 Epsilon = 0.021
# 97
# 122
# resultado da epoca 990 = -7849.66 Epsilon = 0.020
# 96
# 123
# resultado da epoca 991 = -441.90 Epsilon = 0.019
# 99
# 120
# resultado da epoca 992 = -8405.08 Epsilon = 0.018
# 100
# 119
# resultado da epoca 993 = 1547.88 Epsilon = 0.017
# 97
# 122
# resultado da epoca 994 = -7789.54 Epsilon = 0.016
# 95
# 124
# resultado da epoca 995 = -11474.22 Epsilon = 0.015
# 98
# 121
# resultado da epoca 996 = -11219.96 Epsilon = 0.014
# 97
# 122
# resultado da epoca 997 = -10718.68 Epsilon = 0.013
# 98
# 121
# resultado da epoca 998 = -8805.60 Epsilon = 0.012
# 96
# 123
# resultado da epoca 999 = -6994.96 Epsilon = 0.011
# 95
# 124
# resultado da epoca 1000 = -8309.48 Epsilon = 0.010
# 93
# 126
# resultado da epoca 1001 = -9730.58 Epsilon = 0.010
# 94
# 125
# resultado da epoca 1002 = -3170.34 Epsilon = 0.010
# 96
# 123
# resultado da epoca 1003 = -701.94 Epsilon = 0.010
# 96
# 123
# resultado da epoca 1004 = -5257.26 Epsilon = 0.010
# 98
# 121
# 0
# 0
# Melhor resultado diario: 9025.64
