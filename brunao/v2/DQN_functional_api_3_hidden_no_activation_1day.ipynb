# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
n_mercado = n_variaveis*janela #inputs
n_estados = 2 #ncont e valor
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 1

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0

for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Model
from keras.layers import Dense, Input, concatenate
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, mkt_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.mkt_size = mkt_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        #inputs
        x1 = Input(shape=(self.state_size,))
        x2 = Input(shape=(self.mkt_size,))
        
        #state hidden layers
        a1 = Dense(320)(x1)
        a2 = Dense(256)(a1)
        a3 = Dense(256)(a2)
        
        #mkt hidden layers
        b1 = Dense(320)(x2)
        b2 = Dense(256)(b1)
        b3 = Dense(256)(b2)
        
        #concatenacao
        x12 = concatenate([a3, b3], axis=-1)
        
        #camada de saida
        y = Dense(self.action_size, activation='linear')(x12)
        
        model = Model(inputs=[x1, x2], outputs=y)
        
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        
        model.compile(loss='mean_squared_error', optimizer=optimizers.Adam(lr=self.learning_rate))
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(self.mkt_size)
        self.prox_janela_precos = np.zeros(self.mkt_size)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict([self.state, self.janela_precos]) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x1 = np.zeros((batch_size, self.state_size))
        x2 = np.zeros((batch_size, self.mkt_size))
        y = np.zeros((batch_size, self.action_size))
        i = 0
        for acao, reward, estado, mercado, prox_estado, prox_mercado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict([prox_estado, prox_mercado])[0])) #pega valor que quer chegar

            target_f = self.model.predict([estado, mercado]) #pega valor que chegou
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x1[i,:] = estado
            x2[i,:] = mercado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit([x1, x2], y, epochs=1, verbose=0) #treina modelo
            
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.janela_precos, self.next_state, self.prox_janela_precos, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_estados, n_mercado, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 20)           0
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 320)          960         input_9[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 320)          6720        input_10[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 256)          82176       dense_29[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 256)          82176       dense_32[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 256)          65792       dense_30[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 256)          65792       dense_33[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 512)          0           dense_31[0][0]
#                                                                  dense_34[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 11)           5643        concatenate_5[0][0]
# ==================================================================================================
# Total params: 309,259
# Trainable params: 309,259
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.reshape(np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l]), (1,modelo.mkt_size))
        modelo.state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        
        acao = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l]),(1,modelo.mkt_size))
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]),(1,modelo.mkt_size))
        
        modelo.next_state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        modelo.remember(acao, posicao/posicao_max, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    lucro += posicao

    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 0, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos2.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+5): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos2.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
                
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos2.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# resultado da epoca 0 = 817.10 Epsilon = 1.000
# 1
# 0
# resultado da epoca 1 = 291.02 Epsilon = 0.999
# 1
# 0
# resultado da epoca 2 = -1109.58 Epsilon = 0.998
# 0
# 1
# resultado da epoca 3 = 741.18 Epsilon = 0.997
# 1
# 0
# resultado da epoca 4 = 561.94 Epsilon = 0.996
# 1
# 0
# resultado da epoca 5 = -287.00 Epsilon = 0.995
# 0
# 1
# resultado da epoca 6 = -190.34 Epsilon = 0.994
# 0
# 1
# resultado da epoca 7 = 1749.50 Epsilon = 0.993
# 1
# 0
# resultado da epoca 8 = -43.98 Epsilon = 0.992
# 0
# 1
# resultado da epoca 9 = 1239.20 Epsilon = 0.991
# 1
# 0
# resultado da epoca 10 = 776.18 Epsilon = 0.990
# 1
# 0
# resultado da epoca 11 = -1744.28 Epsilon = 0.989
# 0
# 1
# resultado da epoca 12 = -256.26 Epsilon = 0.988
# 0
# 1
# resultado da epoca 13 = 421.48 Epsilon = 0.987
# 1
# 0
# resultado da epoca 14 = -669.12 Epsilon = 0.986
# 0
# 1
# resultado da epoca 15 = 851.78 Epsilon = 0.985
# 1
# 0
# resultado da epoca 16 = -700.34 Epsilon = 0.984
# 0
# 1
# resultado da epoca 17 = 851.92 Epsilon = 0.983
# 1
# 0
# resultado da epoca 18 = 432.54 Epsilon = 0.982
# 1
# 0
# resultado da epoca 19 = 327.84 Epsilon = 0.981
# 1
# 0
# resultado da epoca 20 = 794.20 Epsilon = 0.980
# 1
# 0
# resultado da epoca 21 = -377.76 Epsilon = 0.979
# 0
# 1
# resultado da epoca 22 = 506.34 Epsilon = 0.978
# 1
# 0
# resultado da epoca 23 = -934.88 Epsilon = 0.977
# 0
# 1
# resultado da epoca 24 = 1112.40 Epsilon = 0.976
# 1
# 0
# resultado da epoca 25 = 413.00 Epsilon = 0.975
# 1
# 0
# resultado da epoca 26 = 1104.82 Epsilon = 0.974
# 1
# 0
# resultado da epoca 27 = 670.56 Epsilon = 0.973
# 1
# 0
# resultado da epoca 28 = 269.96 Epsilon = 0.972
# 1
# 0
# resultado da epoca 29 = -470.96 Epsilon = 0.971
# 0
# 1
# resultado da epoca 30 = -595.20 Epsilon = 0.970
# 0
# 1
# resultado da epoca 31 = -495.34 Epsilon = 0.969
# 0
# 1
# resultado da epoca 32 = 767.54 Epsilon = 0.968
# 1
# 0
# resultado da epoca 33 = 284.52 Epsilon = 0.967
# 1
# 0
# resultado da epoca 34 = -923.52 Epsilon = 0.966
# 0
# 1
# resultado da epoca 35 = 1767.54 Epsilon = 0.965
# 1
# 0
# resultado da epoca 36 = 81.18 Epsilon = 0.964
# 1
# 0
# resultado da epoca 37 = 983.14 Epsilon = 0.963
# 1
# 0
# resultado da epoca 38 = -751.26 Epsilon = 0.962
# 0
# 1
# resultado da epoca 39 = -939.44 Epsilon = 0.961
# 0
# 1
# resultado da epoca 40 = -836.70 Epsilon = 0.960
# 0
# 1
# resultado da epoca 41 = 534.82 Epsilon = 0.959
# 1
# 0
# resultado da epoca 42 = -1863.82 Epsilon = 0.958
# 0
# 1
# resultado da epoca 43 = -359.12 Epsilon = 0.957
# 0
# 1
# resultado da epoca 44 = 99.96 Epsilon = 0.956
# 1
# 0
# resultado da epoca 45 = -1092.44 Epsilon = 0.955
# 0
# 1
# resultado da epoca 46 = -447.76 Epsilon = 0.954
# 0
# 1
# resultado da epoca 47 = 85.58 Epsilon = 0.953
# 1
# 0
# resultado da epoca 48 = 1343.00 Epsilon = 0.952
# 1
# 0
# resultado da epoca 49 = -1588.36 Epsilon = 0.951
# 0
# 1
# resultado da epoca 50 = -647.32 Epsilon = 0.950
# 0
# 1
# resultado da epoca 51 = -1792.02 Epsilon = 0.950
# 0
# 1
# resultado da epoca 52 = 1038.14 Epsilon = 0.949
# 1
# 0
# resultado da epoca 53 = -1000.04 Epsilon = 0.948
# 0
# 1
# resultado da epoca 54 = -497.46 Epsilon = 0.947
# 0
# 1
# resultado da epoca 55 = -486.26 Epsilon = 0.946
# 0
# 1
# resultado da epoca 56 = -1568.84 Epsilon = 0.945
# 0
# 1
# resultado da epoca 57 = 309.08 Epsilon = 0.944
# 1
# 0
# resultado da epoca 58 = 1098.60 Epsilon = 0.943
# 1
# 0
# resultado da epoca 59 = -2333.38 Epsilon = 0.942
# 0
# 1
# resultado da epoca 60 = -391.10 Epsilon = 0.941
# 0
# 1
# resultado da epoca 61 = 611.34 Epsilon = 0.940
# 1
# 0
# resultado da epoca 62 = 201.78 Epsilon = 0.939
# 1
# 0
# resultado da epoca 63 = -934.12 Epsilon = 0.938
# 0
# 1
# resultado da epoca 64 = 59.04 Epsilon = 0.937
# 1
# 0
# resultado da epoca 65 = -439.28 Epsilon = 0.936
# 0
# 1
# resultado da epoca 66 = 482.86 Epsilon = 0.935
# 1
# 0
# resultado da epoca 67 = 1118.30 Epsilon = 0.934
# 1
# 0
# resultado da epoca 68 = -1043.66 Epsilon = 0.933
# 0
# 1
# resultado da epoca 69 = -444.90 Epsilon = 0.932
# 0
# 1
# resultado da epoca 70 = -763.68 Epsilon = 0.931
# 0
# 1
# resultado da epoca 71 = -316.86 Epsilon = 0.930
# 0
# 1
# resultado da epoca 72 = -366.42 Epsilon = 0.929
# 0
# 1
# resultado da epoca 73 = 1723.60 Epsilon = 0.928
# 1
# 0
# resultado da epoca 74 = -228.22 Epsilon = 0.927
# 0
# 1
# resultado da epoca 75 = -1403.38 Epsilon = 0.926
# 0
# 1
# resultado da epoca 76 = 58.14 Epsilon = 0.925
# 1
# 0
# resultado da epoca 77 = 194.96 Epsilon = 0.924
# 1
# 0
# resultado da epoca 78 = -188.38 Epsilon = 0.923
# 0
# 1
# resultado da epoca 79 = 2193.74 Epsilon = 0.922
# 1
# 0
# resultado da epoca 80 = -4.58 Epsilon = 0.921
# 0
# 1
# resultado da epoca 81 = -890.64 Epsilon = 0.920
# 0
# 1
# resultado da epoca 82 = 1665.42 Epsilon = 0.919
# 1
# 0
# resultado da epoca 83 = 2318.44 Epsilon = 0.918
# 1
# 0
# resultado da epoca 84 = 49.06 Epsilon = 0.917
# 1
# 0
# resultado da epoca 85 = -494.88 Epsilon = 0.916
# 0
# 1
# resultado da epoca 86 = -63.82 Epsilon = 0.915
# 0
# 1
# resultado da epoca 87 = 686.78 Epsilon = 0.914
# 1
# 0
# resultado da epoca 88 = -1379.28 Epsilon = 0.913
# 0
# 1
# resultado da epoca 89 = -884.14 Epsilon = 0.912
# 0
# 1
# resultado da epoca 90 = -98.08 Epsilon = 0.911
# 0
# 1
# resultado da epoca 91 = -42.32 Epsilon = 0.910
# 0
# 1
# resultado da epoca 92 = -1024.44 Epsilon = 0.909
# 0
# 1
# resultado da epoca 93 = 1495.28 Epsilon = 0.908
# 1
# 0
# resultado da epoca 94 = 69.36 Epsilon = 0.907
# 1
# 0
# resultado da epoca 95 = -765.80 Epsilon = 0.906
# 0
# 1
# resultado da epoca 96 = -1578.98 Epsilon = 0.905
# 0
# 1
# resultado da epoca 97 = 1147.68 Epsilon = 0.904
# 1
# 0
# resultado da epoca 98 = 1337.40 Epsilon = 0.903
# 1
# 0
# resultado da epoca 99 = 1225.88 Epsilon = 0.902
# 1
# 0
# resultado da epoca 100 = -272.46 Epsilon = 0.901
# 0
# 1
# resultado da epoca 101 = -2797.92 Epsilon = 0.900
# 0
# 1
# resultado da epoca 102 = 261.62 Epsilon = 0.899
# 1
# 0
# resultado da epoca 103 = -660.94 Epsilon = 0.898
# 0
# 1
# resultado da epoca 104 = 340.12 Epsilon = 0.897
# 1
# 0
# resultado da epoca 105 = -639.88 Epsilon = 0.896
# 0
# 1
# resultado da epoca 106 = -363.98 Epsilon = 0.895
# 0
# 1
# resultado da epoca 107 = -1938.66 Epsilon = 0.894
# 0
# 1
# resultado da epoca 108 = -1518.22 Epsilon = 0.893
# 0
# 1
# resultado da epoca 109 = 2186.92 Epsilon = 0.892
# 1
# 0
# resultado da epoca 110 = 253.14 Epsilon = 0.891
# 1
# 0
# resultado da epoca 111 = 599.82 Epsilon = 0.890
# 1
# 0
# resultado da epoca 112 = 556.32 Epsilon = 0.889
# 1
# 0
# resultado da epoca 113 = -29.12 Epsilon = 0.888
# 0
# 1
# resultado da epoca 114 = -610.48 Epsilon = 0.887
# 0
# 1
# resultado da epoca 115 = 407.40 Epsilon = 0.886
# 1
# 0
# resultado da epoca 116 = 149.52 Epsilon = 0.885
# 1
# 0
# resultado da epoca 117 = 145.10 Epsilon = 0.884
# 1
# 0
# resultado da epoca 118 = -1897.46 Epsilon = 0.883
# 0
# 1
# resultado da epoca 119 = -913.08 Epsilon = 0.882
# 0
# 1
# resultado da epoca 120 = 596.18 Epsilon = 0.881
# 1
# 0
# resultado da epoca 121 = 1119.06 Epsilon = 0.880
# 1
# 0
# resultado da epoca 122 = -260.50 Epsilon = 0.879
# 0
# 1
# resultado da epoca 123 = 934.96 Epsilon = 0.878
# 1
# 0
# resultado da epoca 124 = 529.52 Epsilon = 0.877
# 1
# 0
# resultado da epoca 125 = -312.92 Epsilon = 0.876
# 0
# 1
# resultado da epoca 126 = -1433.68 Epsilon = 0.875
# 0
# 1
# resultado da epoca 127 = -487.16 Epsilon = 0.874
# 0
# 1
# resultado da epoca 128 = -2132.92 Epsilon = 0.873
# 0
# 1
# resultado da epoca 129 = 816.78 Epsilon = 0.872
# 1
# 0
# resultado da epoca 130 = -913.98 Epsilon = 0.871
# 0
# 1
# resultado da epoca 131 = 476.32 Epsilon = 0.870
# 1
# 0
# resultado da epoca 132 = -774.88 Epsilon = 0.869
# 0
# 1
# resultado da epoca 133 = -1288.96 Epsilon = 0.868
# 0
# 1
# resultado da epoca 134 = -645.50 Epsilon = 0.867
# 0
# 1
# resultado da epoca 135 = -127.78 Epsilon = 0.866
# 0
# 1
# resultado da epoca 136 = 663.44 Epsilon = 0.865
# 1
# 0
# resultado da epoca 137 = -382.46 Epsilon = 0.864
# 0
# 1
# resultado da epoca 138 = 24.50 Epsilon = 0.863
# 1
# 0
# resultado da epoca 139 = 335.86 Epsilon = 0.862
# 1
# 0
# resultado da epoca 140 = 180.72 Epsilon = 0.861
# 1
# 0
# resultado da epoca 141 = -327.62 Epsilon = 0.860
# 0
# 1
# resultado da epoca 142 = -667.00 Epsilon = 0.859
# 0
# 1
# resultado da epoca 143 = 441.78 Epsilon = 0.858
# 1
# 0
# resultado da epoca 144 = -946.08 Epsilon = 0.857
# 0
# 1
# resultado da epoca 145 = -1555.04 Epsilon = 0.856
# 0
# 1
# resultado da epoca 146 = 736.46 Epsilon = 0.855
# 1
# 0
# resultado da epoca 147 = 486.62 Epsilon = 0.854
# 1
# 0
# resultado da epoca 148 = -343.82 Epsilon = 0.853
# 0
# 1
# resultado da epoca 149 = 623.14 Epsilon = 0.852
# 1
# 0
# resultado da epoca 150 = -12.92 Epsilon = 0.851
# 0
# 1
# resultado da epoca 151 = -832.92 Epsilon = 0.851
# 0
# 1
# resultado da epoca 152 = -473.98 Epsilon = 0.850
# 0
# 1
# resultado da epoca 153 = 822.84 Epsilon = 0.849
# 1
# 0
# resultado da epoca 154 = 203.14 Epsilon = 0.848
# 1
# 0
# resultado da epoca 155 = -409.28 Epsilon = 0.847
# 0
# 1
# resultado da epoca 156 = -315.20 Epsilon = 0.846
# 0
# 1
# resultado da epoca 157 = -1023.66 Epsilon = 0.845
# 0
# 1
# resultado da epoca 158 = -1916.10 Epsilon = 0.844
# 0
# 1
# resultado da epoca 159 = 158.74 Epsilon = 0.843
# 1
# 0
# resultado da epoca 160 = 149.20 Epsilon = 0.842
# 1
# 0
# resultado da epoca 161 = -1183.54 Epsilon = 0.841
# 0
# 1
# resultado da epoca 162 = 437.98 Epsilon = 0.840
# 1
# 0
# resultado da epoca 163 = -2050.18 Epsilon = 0.839
# 0
# 1
# resultado da epoca 164 = -1243.38 Epsilon = 0.838
# 0
# 1
# resultado da epoca 165 = -111.86 Epsilon = 0.837
# 0
# 1
# resultado da epoca 166 = 2212.84 Epsilon = 0.836
# 1
# 0
# resultado da epoca 167 = -543.22 Epsilon = 0.835
# 0
# 1
# resultado da epoca 168 = 651.32 Epsilon = 0.834
# 1
# 0
# resultado da epoca 169 = 2497.84 Epsilon = 0.833
# 1
# 0
# resultado da epoca 170 = -153.98 Epsilon = 0.832
# 0
# 1
# resultado da epoca 171 = -566.26 Epsilon = 0.831
# 0
# 1
# resultado da epoca 172 = -374.14 Epsilon = 0.830
# 0
# 1
# resultado da epoca 173 = 106.14 Epsilon = 0.829
# 1
# 0
# resultado da epoca 174 = -178.08 Epsilon = 0.828
# 0
# 1
# resultado da epoca 175 = -305.06 Epsilon = 0.827
# 0
# 1
# resultado da epoca 176 = -361.86 Epsilon = 0.826
# 0
# 1
# resultado da epoca 177 = 1385.72 Epsilon = 0.825
# 1
# 0
# resultado da epoca 178 = -581.70 Epsilon = 0.824
# 0
# 1
# resultado da epoca 179 = 485.42 Epsilon = 0.823
# 1
# 0
# resultado da epoca 180 = 1801.34 Epsilon = 0.822
# 1
# 0
# resultado da epoca 181 = -374.58 Epsilon = 0.821
# 0
# 1
# resultado da epoca 182 = -90.20 Epsilon = 0.820
# 0
# 1
# resultado da epoca 183 = -222.16 Epsilon = 0.819
# 0
# 1
# resultado da epoca 184 = 1121.34 Epsilon = 0.818
# 1
# 0
# resultado da epoca 185 = 1055.56 Epsilon = 0.817
# 1
# 0
# resultado da epoca 186 = -551.86 Epsilon = 0.816
# 0
# 1
# resultado da epoca 187 = -222.32 Epsilon = 0.815
# 0
# 1
# resultado da epoca 188 = -532.76 Epsilon = 0.814
# 0
# 1
# resultado da epoca 189 = -1500.50 Epsilon = 0.813
# 0
# 1
# resultado da epoca 190 = -154.74 Epsilon = 0.812
# 0
# 1
# resultado da epoca 191 = -808.52 Epsilon = 0.811
# 0
# 1
# resultado da epoca 192 = -83.82 Epsilon = 0.810
# 0
# 1
# resultado da epoca 193 = 229.66 Epsilon = 0.809
# 1
# 0
# resultado da epoca 194 = 1124.80 Epsilon = 0.808
# 1
# 0
# resultado da epoca 195 = -1058.84 Epsilon = 0.807
# 0
# 1
# resultado da epoca 196 = -293.52 Epsilon = 0.806
# 0
# 1
# resultado da epoca 197 = 1032.22 Epsilon = 0.805
# 1
# 0
# resultado da epoca 198 = -1375.66 Epsilon = 0.804
# 0
# 1
# resultado da epoca 199 = 655.56 Epsilon = 0.803
# 1
# 0
# resultado da epoca 200 = -68.68 Epsilon = 0.802
# 0
# 1
# resultado da epoca 201 = -1088.54 Epsilon = 0.801
# 0
# 1
# resultado da epoca 202 = 163.74 Epsilon = 0.800
# 1
# 0
# resultado da epoca 203 = 200.70 Epsilon = 0.799
# 1
# 0
# resultado da epoca 204 = -730.80 Epsilon = 0.798
# 0
# 1
# resultado da epoca 205 = 231.92 Epsilon = 0.797
# 1
# 0
# resultado da epoca 206 = 485.12 Epsilon = 0.796
# 1
# 0
# resultado da epoca 207 = -66.70 Epsilon = 0.795
# 0
# 1
# resultado da epoca 208 = -69.44 Epsilon = 0.794
# 0
# 1
# resultado da epoca 209 = -124.28 Epsilon = 0.793
# 0
# 1
# resultado da epoca 210 = -1324.76 Epsilon = 0.792
# 0
# 1
# resultado da epoca 211 = 353.60 Epsilon = 0.791
# 1
# 0
# resultado da epoca 212 = 1668.14 Epsilon = 0.790
# 1
# 0
# resultado da epoca 213 = -301.40 Epsilon = 0.789
# 0
# 1
# resultado da epoca 214 = 575.26 Epsilon = 0.788
# 1
# 0
# resultado da epoca 215 = 399.34 Epsilon = 0.787
# 1
# 0
# resultado da epoca 216 = -642.00 Epsilon = 0.786
# 0
# 1
# resultado da epoca 217 = 376.02 Epsilon = 0.785
# 1
# 0
# resultado da epoca 218 = 861.60 Epsilon = 0.784
# 1
# 0
# resultado da epoca 219 = -157.02 Epsilon = 0.783
# 0
# 1
# resultado da epoca 220 = -700.66 Epsilon = 0.782
# 0
# 1
# resultado da epoca 221 = 1240.26 Epsilon = 0.781
# 1
# 0
# resultado da epoca 222 = 822.82 Epsilon = 0.780
# 1
# 0
# resultado da epoca 223 = -358.40 Epsilon = 0.779
# 0
# 1
# resultado da epoca 224 = -15.34 Epsilon = 0.778
# 0
# 1
# resultado da epoca 225 = 798.74 Epsilon = 0.777
# 1
# 0
# resultado da epoca 226 = -1074.76 Epsilon = 0.776
# 0
# 1
# resultado da epoca 227 = -439.74 Epsilon = 0.775
# 0
# 1
# resultado da epoca 228 = 1513.30 Epsilon = 0.774
# 1
# 0
# resultado da epoca 229 = -467.02 Epsilon = 0.773
# 0
# 1
# resultado da epoca 230 = 542.98 Epsilon = 0.772
# 1
# 0
# resultado da epoca 231 = -146.42 Epsilon = 0.771
# 0
# 1
# resultado da epoca 232 = -459.14 Epsilon = 0.770
# 0
# 1
# resultado da epoca 233 = 740.10 Epsilon = 0.769
# 1
# 0
# resultado da epoca 234 = 454.50 Epsilon = 0.768
# 1
# 0
# resultado da epoca 235 = 5.40 Epsilon = 0.767
# 1
# 0
# resultado da epoca 236 = -1703.38 Epsilon = 0.766
# 0
# 1
# resultado da epoca 237 = 229.34 Epsilon = 0.765
# 1
# 0
# resultado da epoca 238 = -790.82 Epsilon = 0.764
# 0
# 1
# resultado da epoca 239 = -443.68 Epsilon = 0.763
# 0
# 1
# resultado da epoca 240 = 52.06 Epsilon = 0.762
# 1
# 0
# resultado da epoca 241 = -931.72 Epsilon = 0.761
# 0
# 1
# resultado da epoca 242 = 432.82 Epsilon = 0.760
# 1
# 0
# resultado da epoca 243 = 1959.50 Epsilon = 0.759
# 1
# 0
# resultado da epoca 244 = 210.40 Epsilon = 0.758
# 1
# 0
# resultado da epoca 245 = -1156.72 Epsilon = 0.757
# 0
# 1
# resultado da epoca 246 = 782.98 Epsilon = 0.756
# 1
# 0
# resultado da epoca 247 = 299.64 Epsilon = 0.755
# 1
# 0
# resultado da epoca 248 = 873.72 Epsilon = 0.754
# 1
# 0
# resultado da epoca 249 = 1179.34 Epsilon = 0.753
# 1
# 0
# resultado da epoca 250 = 629.50 Epsilon = 0.752
# 1
# 0
# resultado da epoca 251 = 377.68 Epsilon = 0.752
# 1
# 0
# resultado da epoca 252 = 67.68 Epsilon = 0.751
# 1
# 0
# resultado da epoca 253 = 488.00 Epsilon = 0.750
# 1
# 0
# resultado da epoca 254 = 180.40 Epsilon = 0.749
# 1
# 0
# resultado da epoca 255 = 473.74 Epsilon = 0.748
# 1
# 0
# resultado da epoca 256 = -101.42 Epsilon = 0.747
# 0
# 1
# resultado da epoca 257 = 384.96 Epsilon = 0.746
# 1
# 0
# resultado da epoca 258 = -1544.72 Epsilon = 0.745
# 0
# 1
# resultado da epoca 259 = -1533.98 Epsilon = 0.744
# 0
# 1
# resultado da epoca 260 = -1295.50 Epsilon = 0.743
# 0
# 1
# resultado da epoca 261 = 738.74 Epsilon = 0.742
# 1
# 0
# resultado da epoca 262 = 1427.24 Epsilon = 0.741
# 1
# 0
# resultado da epoca 263 = -862.16 Epsilon = 0.740
# 0
# 1
# resultado da epoca 264 = -577.02 Epsilon = 0.739
# 0
# 1
# resultado da epoca 265 = -578.84 Epsilon = 0.738
# 0
# 1
# resultado da epoca 266 = -123.68 Epsilon = 0.737
# 0
# 1
# resultado da epoca 267 = -1468.36 Epsilon = 0.736
# 0
# 1
# resultado da epoca 268 = -832.00 Epsilon = 0.735
# 0
# 1
# resultado da epoca 269 = 893.74 Epsilon = 0.734
# 1
# 0
# resultado da epoca 270 = -250.04 Epsilon = 0.733
# 0
# 1
# resultado da epoca 271 = -273.68 Epsilon = 0.732
# 0
# 1
# resultado da epoca 272 = -427.46 Epsilon = 0.731
# 0
# 1
# resultado da epoca 273 = 818.60 Epsilon = 0.730
# 1
# 0
# resultado da epoca 274 = 285.42 Epsilon = 0.729
# 1
# 0
# resultado da epoca 275 = -2080.66 Epsilon = 0.728
# 0
# 1
# resultado da epoca 276 = -220.80 Epsilon = 0.727
# 0
# 1
# resultado da epoca 277 = 1191.48 Epsilon = 0.726
# 1
# 0
# resultado da epoca 278 = -537.16 Epsilon = 0.725
# 0
# 1
# resultado da epoca 279 = -414.12 Epsilon = 0.724
# 0
# 1
# resultado da epoca 280 = 434.18 Epsilon = 0.723
# 1
# 0
# resultado da epoca 281 = -149.44 Epsilon = 0.722
# 0
# 1
# resultado da epoca 282 = 1162.82 Epsilon = 0.721
# 1
# 0
# resultado da epoca 283 = -628.10 Epsilon = 0.720
# 0
# 1
# resultado da epoca 284 = -707.16 Epsilon = 0.719
# 0
# 1
# resultado da epoca 285 = -685.66 Epsilon = 0.718
# 0
# 1
# resultado da epoca 286 = -489.76 Epsilon = 0.717
# 0
# 1
# resultado da epoca 287 = 536.62 Epsilon = 0.716
# 1
# 0
# resultado da epoca 288 = 228.28 Epsilon = 0.715
# 1
# 0
# resultado da epoca 289 = -1833.54 Epsilon = 0.714
# 0
# 1
# resultado da epoca 290 = -451.72 Epsilon = 0.713
# 0
# 1
# resultado da epoca 291 = -14.60 Epsilon = 0.712
# 0
# 1
# resultado da epoca 292 = -1024.60 Epsilon = 0.711
# 0
# 1
# resultado da epoca 293 = 1480.54 Epsilon = 0.710
# 1
# 0
# resultado da epoca 294 = 453.28 Epsilon = 0.709
# 1
# 0
# resultado da epoca 295 = -1823.84 Epsilon = 0.708
# 0
# 1
# resultado da epoca 296 = 113.26 Epsilon = 0.707
# 1
# 0
# resultado da epoca 297 = -794.60 Epsilon = 0.706
# 0
# 1
# resultado da epoca 298 = -495.36 Epsilon = 0.705
# 0
# 1
# resultado da epoca 299 = -287.48 Epsilon = 0.704
# 0
# 1
# resultado da epoca 300 = 452.06 Epsilon = 0.703
# 1
# 0
# resultado da epoca 301 = -1438.38 Epsilon = 0.702
# 0
# 1
# resultado da epoca 302 = 967.06 Epsilon = 0.701
# 1
# 0
# resultado da epoca 303 = 915.40 Epsilon = 0.700
# 1
# 0
# resultado da epoca 304 = 197.82 Epsilon = 0.699
# 1
# 0
# resultado da epoca 305 = 1144.64 Epsilon = 0.698
# 1
# 0
# resultado da epoca 306 = -225.80 Epsilon = 0.697
# 0
# 1
# resultado da epoca 307 = 202.24 Epsilon = 0.696
# 1
# 0
# resultado da epoca 308 = -7.48 Epsilon = 0.695
# 0
# 1
# resultado da epoca 309 = -385.66 Epsilon = 0.694
# 0
# 1
# resultado da epoca 310 = -401.10 Epsilon = 0.693
# 0
# 1
# resultado da epoca 311 = -1203.70 Epsilon = 0.692
# 0
# 1
# resultado da epoca 312 = -1792.02 Epsilon = 0.691
# 0
# 1
# resultado da epoca 313 = -476.70 Epsilon = 0.690
# 0
# 1
# resultado da epoca 314 = 44.80 Epsilon = 0.689
# 1
# 0
# resultado da epoca 315 = 547.08 Epsilon = 0.688
# 1
# 0
# resultado da epoca 316 = 1335.10 Epsilon = 0.687
# 1
# 0
# resultado da epoca 317 = 192.68 Epsilon = 0.686
# 1
# 0
# resultado da epoca 318 = -392.92 Epsilon = 0.685
# 0
# 1
# resultado da epoca 319 = -648.24 Epsilon = 0.684
# 0
# 1
# resultado da epoca 320 = -1234.90 Epsilon = 0.683
# 0
# 1
# resultado da epoca 321 = -968.54 Epsilon = 0.682
# 0
# 1
# resultado da epoca 322 = 663.28 Epsilon = 0.681
# 1
# 0
# resultado da epoca 323 = 57.06 Epsilon = 0.680
# 1
# 0
# resultado da epoca 324 = 882.38 Epsilon = 0.679
# 1
# 0
# resultado da epoca 325 = -740.96 Epsilon = 0.678
# 0
# 1
# resultado da epoca 326 = -125.66 Epsilon = 0.677
# 0
# 1
# resultado da epoca 327 = -37.32 Epsilon = 0.676
# 0
# 1
# resultado da epoca 328 = -474.28 Epsilon = 0.675
# 0
# 1
# resultado da epoca 329 = -196.26 Epsilon = 0.674
# 0
# 1
# resultado da epoca 330 = -349.74 Epsilon = 0.673
# 0
# 1
# resultado da epoca 331 = 379.66 Epsilon = 0.672
# 1
# 0
# resultado da epoca 332 = -820.04 Epsilon = 0.671
# 0
# 1
# resultado da epoca 333 = -917.92 Epsilon = 0.670
# 0
# 1
# resultado da epoca 334 = -348.06 Epsilon = 0.669
# 0
# 1
# resultado da epoca 335 = 824.66 Epsilon = 0.668
# 1
# 0
# resultado da epoca 336 = 11.94 Epsilon = 0.667
# 1
# 0
# resultado da epoca 337 = 744.06 Epsilon = 0.666
# 1
# 0
# resultado da epoca 338 = -755.18 Epsilon = 0.665
# 0
# 1
# resultado da epoca 339 = -559.74 Epsilon = 0.664
# 0
# 1
# resultado da epoca 340 = 154.06 Epsilon = 0.663
# 1
# 0
# resultado da epoca 341 = -423.82 Epsilon = 0.662
# 0
# 1
# resultado da epoca 342 = -1149.28 Epsilon = 0.661
# 0
# 1
# resultado da epoca 343 = -381.10 Epsilon = 0.660
# 0
# 1
# resultado da epoca 344 = 94.66 Epsilon = 0.659
# 1
# 0
# resultado da epoca 345 = 1063.90 Epsilon = 0.658
# 1
# 0
# resultado da epoca 346 = -850.02 Epsilon = 0.657
# 0
# 1
# resultado da epoca 347 = 1738.60 Epsilon = 0.656
# 1
# 0
# resultado da epoca 348 = -135.64 Epsilon = 0.655
# 0
# 1
# resultado da epoca 349 = -1002.30 Epsilon = 0.654
# 0
# 1
# resultado da epoca 350 = 749.50 Epsilon = 0.653
# 1
# 0
# resultado da epoca 351 = -743.36 Epsilon = 0.653
# 0
# 1
# resultado da epoca 352 = 304.20 Epsilon = 0.652
# 1
# 0
# resultado da epoca 353 = -740.50 Epsilon = 0.651
# 0
# 1
# resultado da epoca 354 = -1333.98 Epsilon = 0.650
# 0
# 1
# resultado da epoca 355 = -732.78 Epsilon = 0.649
# 0
# 1
# resultado da epoca 356 = 1298.72 Epsilon = 0.648
# 1
# 0
# resultado da epoca 357 = -1451.10 Epsilon = 0.647
# 0
# 1
# resultado da epoca 358 = -716.28 Epsilon = 0.646
# 0
# 1
# resultado da epoca 359 = -31.72 Epsilon = 0.645
# 0
# 1
# resultado da epoca 360 = -167.62 Epsilon = 0.644
# 0
# 1
# resultado da epoca 361 = -520.36 Epsilon = 0.643
# 0
# 1
# resultado da epoca 362 = -138.08 Epsilon = 0.642
# 0
# 1
# resultado da epoca 363 = 26.46 Epsilon = 0.641
# 1
# 0
# resultado da epoca 364 = 315.10 Epsilon = 0.640
# 1
# 0
# resultado da epoca 365 = 112.66 Epsilon = 0.639
# 1
# 0
# resultado da epoca 366 = -997.34 Epsilon = 0.638
# 0
# 1
# resultado da epoca 367 = -120.06 Epsilon = 0.637
# 0
# 1
# resultado da epoca 368 = -704.30 Epsilon = 0.636
# 0
# 1
# resultado da epoca 369 = -3.24 Epsilon = 0.635
# 0
# 1
# resultado da epoca 370 = 301.16 Epsilon = 0.634
# 1
# 0
# resultado da epoca 371 = -717.02 Epsilon = 0.633
# 0
# 1
# resultado da epoca 372 = 484.96 Epsilon = 0.632
# 1
# 0
# resultado da epoca 373 = -983.82 Epsilon = 0.631
# 0
# 1
# resultado da epoca 374 = 262.38 Epsilon = 0.630
# 1
# 0
# resultado da epoca 375 = -288.08 Epsilon = 0.629
# 0
# 1
# resultado da epoca 376 = -204.74 Epsilon = 0.628
# 0
# 1
# resultado da epoca 377 = 547.98 Epsilon = 0.627
# 1
# 0
# resultado da epoca 378 = -98.54 Epsilon = 0.626
# 0
# 1
# resultado da epoca 379 = 153.74 Epsilon = 0.625
# 1
# 0
# resultado da epoca 380 = 163.90 Epsilon = 0.624
# 1
# 0
# resultado da epoca 381 = -755.20 Epsilon = 0.623
# 0
# 1
# resultado da epoca 382 = -203.98 Epsilon = 0.622
# 0
# 1
# resultado da epoca 383 = -226.56 Epsilon = 0.621
# 0
# 1
# resultado da epoca 384 = -2313.98 Epsilon = 0.620
# 0
# 1
# resultado da epoca 385 = -416.42 Epsilon = 0.619
# 0
# 1
# resultado da epoca 386 = -561.42 Epsilon = 0.618
# 0
# 1
# resultado da epoca 387 = 458.90 Epsilon = 0.617
# 1
# 0
# resultado da epoca 388 = 1050.72 Epsilon = 0.616
# 1
# 0
# resultado da epoca 389 = 393.60 Epsilon = 0.615
# 1
# 0
# resultado da epoca 390 = -2154.28 Epsilon = 0.614
# 0
# 1
# resultado da epoca 391 = -1247.64 Epsilon = 0.613
# 0
# 1
# resultado da epoca 392 = 1680.54 Epsilon = 0.612
# 1
# 0
# resultado da epoca 393 = 164.18 Epsilon = 0.611
# 1
# 0
# resultado da epoca 394 = -340.36 Epsilon = 0.610
# 0
# 1
# resultado da epoca 395 = -27.78 Epsilon = 0.609
# 0
# 1
# resultado da epoca 396 = 1500.40 Epsilon = 0.608
# 1
# 0
# resultado da epoca 397 = -542.48 Epsilon = 0.607
# 0
# 1
# resultado da epoca 398 = 763.58 Epsilon = 0.606
# 1
# 0
# resultado da epoca 399 = -647.16 Epsilon = 0.605
# 0
# 1
# resultado da epoca 400 = -681.42 Epsilon = 0.604
# 0
# 1
# resultado da epoca 401 = -1335.34 Epsilon = 0.603
# 0
# 1
# resultado da epoca 402 = -642.00 Epsilon = 0.602
# 0
# 1
# resultado da epoca 403 = 465.42 Epsilon = 0.601
# 1
# 0
# resultado da epoca 404 = 239.96 Epsilon = 0.600
# 1
# 0
# resultado da epoca 405 = -627.62 Epsilon = 0.599
# 0
# 1
# resultado da epoca 406 = -42.16 Epsilon = 0.598
# 0
# 1
# resultado da epoca 407 = -917.16 Epsilon = 0.597
# 0
# 1
# resultado da epoca 408 = -1296.86 Epsilon = 0.596
# 0
# 1
# resultado da epoca 409 = 992.38 Epsilon = 0.595
# 1
# 0
# resultado da epoca 410 = -938.98 Epsilon = 0.594
# 0
# 1
# resultado da epoca 411 = 1437.38 Epsilon = 0.593
# 1
# 0
# resultado da epoca 412 = -1199.60 Epsilon = 0.592
# 0
# 1
# resultado da epoca 413 = -81.56 Epsilon = 0.591
# 0
# 1
# resultado da epoca 414 = -495.34 Epsilon = 0.590
# 0
# 1
# resultado da epoca 415 = -11.86 Epsilon = 0.589
# 0
# 1
# resultado da epoca 416 = -1130.50 Epsilon = 0.588
# 0
# 1
# resultado da epoca 417 = 430.10 Epsilon = 0.587
# 1
# 0
# resultado da epoca 418 = 631.92 Epsilon = 0.586
# 1
# 0
# resultado da epoca 419 = -1518.98 Epsilon = 0.585
# 0
# 1
# resultado da epoca 420 = -928.40 Epsilon = 0.584
# 0
# 1
# resultado da epoca 421 = 1130.10 Epsilon = 0.583
# 1
# 0
# resultado da epoca 422 = -783.54 Epsilon = 0.582
# 0
# 1
# resultado da epoca 423 = -1566.58 Epsilon = 0.581
# 0
# 1
# resultado da epoca 424 = -790.82 Epsilon = 0.580
# 0
# 1
# resultado da epoca 425 = 1590.10 Epsilon = 0.579
# 1
# 0
# resultado da epoca 426 = 992.38 Epsilon = 0.578
# 1
# 0
# resultado da epoca 427 = 455.24 Epsilon = 0.577
# 1
# 0
# resultado da epoca 428 = 656.76 Epsilon = 0.576
# 1
# 0
# resultado da epoca 429 = 932.06 Epsilon = 0.575
# 1
# 0
# resultado da epoca 430 = -954.14 Epsilon = 0.574
# 0
# 1
# resultado da epoca 431 = -456.88 Epsilon = 0.573
# 0
# 1
# resultado da epoca 432 = 1380.10 Epsilon = 0.572
# 1
# 0
# resultado da epoca 433 = -1549.44 Epsilon = 0.571
# 0
# 1
# resultado da epoca 434 = 32.52 Epsilon = 0.570
# 1
# 0
# resultado da epoca 435 = 406.30 Epsilon = 0.569
# 1
# 0
# resultado da epoca 436 = 1430.26 Epsilon = 0.568
# 1
# 0
# resultado da epoca 437 = 990.08 Epsilon = 0.567
# 1
# 0
# resultado da epoca 438 = 868.44 Epsilon = 0.566
# 1
# 0
# resultado da epoca 439 = 1110.10 Epsilon = 0.565
# 1
# 0
# resultado da epoca 440 = 679.50 Epsilon = 0.564
# 1
# 0
# resultado da epoca 441 = -448.38 Epsilon = 0.563
# 0
# 1
# resultado da epoca 442 = -737.48 Epsilon = 0.562
# 0
# 1
# resultado da epoca 443 = -101.42 Epsilon = 0.561
# 0
# 1
# resultado da epoca 444 = 2139.80 Epsilon = 0.560
# 1
# 0
# resultado da epoca 445 = 1245.56 Epsilon = 0.559
# 1
# 0
# resultado da epoca 446 = 496.46 Epsilon = 0.558
# 1
# 0
# resultado da epoca 447 = 1446.00 Epsilon = 0.557
# 1
# 0
# resultado da epoca 448 = 25.24 Epsilon = 0.556
# 1
# 0
# resultado da epoca 449 = 1267.52 Epsilon = 0.555
# 1
# 0
# resultado da epoca 450 = 504.20 Epsilon = 0.554
# 1
# 0
# resultado da epoca 451 = 1924.50 Epsilon = 0.554
# 1
# 0
# resultado da epoca 452 = 72.68 Epsilon = 0.553
# 1
# 0
# resultado da epoca 453 = -227.34 Epsilon = 0.552
# 0
# 1
# resultado da epoca 454 = 84.48 Epsilon = 0.551
# 1
# 0
# resultado da epoca 455 = -830.52 Epsilon = 0.550
# 0
# 1
# resultado da epoca 456 = 1558.42 Epsilon = 0.549
# 1
# 0
# resultado da epoca 457 = -488.24 Epsilon = 0.548
# 0
# 1
# resultado da epoca 458 = -295.96 Epsilon = 0.547
# 0
# 1
# resultado da epoca 459 = -157.02 Epsilon = 0.546
# 0
# 1
# resultado da epoca 460 = 156.92 Epsilon = 0.545
# 1
# 0
# resultado da epoca 461 = 185.86 Epsilon = 0.544
# 1
# 0
# resultado da epoca 462 = 528.12 Epsilon = 0.543
# 1
# 0
# resultado da epoca 463 = 248.88 Epsilon = 0.542
# 1
# 0
# resultado da epoca 464 = 441.02 Epsilon = 0.541
# 1
# 0
# resultado da epoca 465 = -385.96 Epsilon = 0.540
# 0
# 1
# resultado da epoca 466 = 926.62 Epsilon = 0.539
# 1
# 0
# resultado da epoca 467 = 461.16 Epsilon = 0.538
# 1
# 0
# resultado da epoca 468 = 738.28 Epsilon = 0.537
# 1
# 0
# resultado da epoca 469 = 326.16 Epsilon = 0.536
# 1
# 0
# resultado da epoca 470 = -219.28 Epsilon = 0.535
# 0
# 1
# resultado da epoca 471 = -1291.72 Epsilon = 0.534
# 0
# 1
# resultado da epoca 472 = -70.80 Epsilon = 0.533
# 0
# 1
# resultado da epoca 473 = -732.48 Epsilon = 0.532
# 0
# 1
# resultado da epoca 474 = -55.66 Epsilon = 0.531
# 0
# 1
# resultado da epoca 475 = -149.74 Epsilon = 0.530
# 0
# 1
# resultado da epoca 476 = 444.80 Epsilon = 0.529
# 1
# 0
# resultado da epoca 477 = 2453.58 Epsilon = 0.528
# 1
# 0
# resultado da epoca 478 = -705.96 Epsilon = 0.527
# 0
# 1
# resultado da epoca 479 = -818.68 Epsilon = 0.526
# 0
# 1
# resultado da epoca 480 = 179.20 Epsilon = 0.525
# 1
# 0
# resultado da epoca 481 = 1270.26 Epsilon = 0.524
# 1
# 0
# resultado da epoca 482 = -1218.08 Epsilon = 0.523
# 0
# 1
# resultado da epoca 483 = 278.12 Epsilon = 0.522
# 1
# 0
# resultado da epoca 484 = 4.50 Epsilon = 0.521
# 1
# 0
# resultado da epoca 485 = 1708.74 Epsilon = 0.520
# 1
# 0
# resultado da epoca 486 = 106.92 Epsilon = 0.519
# 1
# 0
# resultado da epoca 487 = 498.74 Epsilon = 0.518
# 1
# 0
# resultado da epoca 488 = 764.64 Epsilon = 0.517
# 1
# 0
# resultado da epoca 489 = -397.92 Epsilon = 0.516
# 0
# 1
# resultado da epoca 490 = -822.32 Epsilon = 0.515
# 0
# 1
# resultado da epoca 491 = 363.74 Epsilon = 0.514
# 1
# 0
# resultado da epoca 492 = -733.38 Epsilon = 0.513
# 0
# 1
# resultado da epoca 493 = 477.38 Epsilon = 0.512
# 1
# 0
# resultado da epoca 494 = -272.32 Epsilon = 0.511
# 0
# 1
# resultado da epoca 495 = -1000.66 Epsilon = 0.510
# 0
# 1
# resultado da epoca 496 = 1052.52 Epsilon = 0.509
# 1
# 0
# resultado da epoca 497 = 709.18 Epsilon = 0.508
# 1
# 0
# resultado da epoca 498 = 111.76 Epsilon = 0.507
# 1
# 0
# resultado da epoca 499 = -775.64 Epsilon = 0.506
# 0
# 1
# resultado da epoca 500 = 1426.92 Epsilon = 0.505
# 1
# 0
# resultado da epoca 501 = -248.70 Epsilon = 0.504
# 0
# 1
# resultado da epoca 502 = 321.30 Epsilon = 0.503
# 1
# 0
# resultado da epoca 503 = -1225.82 Epsilon = 0.502
# 0
# 1
# resultado da epoca 504 = -1436.86 Epsilon = 0.501
# 0
# 1
# resultado da epoca 505 = -474.74 Epsilon = 0.500
# 0
# 1
# resultado da epoca 506 = -967.32 Epsilon = 0.499
# 0
# 1
# resultado da epoca 507 = -788.10 Epsilon = 0.498
# 0
# 1
# resultado da epoca 508 = 22.98 Epsilon = 0.497
# 1
# 0
# resultado da epoca 509 = 1058.90 Epsilon = 0.496
# 1
# 0
# resultado da epoca 510 = -18.54 Epsilon = 0.495
# 0
# 1
# resultado da epoca 511 = 292.98 Epsilon = 0.494
# 1
# 0
# resultado da epoca 512 = -1141.10 Epsilon = 0.493
# 0
# 1
# resultado da epoca 513 = 343.58 Epsilon = 0.492
# 1
# 0
# resultado da epoca 514 = -32.92 Epsilon = 0.491
# 0
# 1
# resultado da epoca 515 = -419.12 Epsilon = 0.490
# 0
# 1
# resultado da epoca 516 = 319.96 Epsilon = 0.489
# 1
# 0
# resultado da epoca 517 = 573.88 Epsilon = 0.488
# 1
# 0
# resultado da epoca 518 = 1419.34 Epsilon = 0.487
# 1
# 0
# resultado da epoca 519 = -872.16 Epsilon = 0.486
# 0
# 1
# resultado da epoca 520 = 112.22 Epsilon = 0.485
# 1
# 0
# resultado da epoca 521 = 365.24 Epsilon = 0.484
# 1
# 0
# resultado da epoca 522 = 127.06 Epsilon = 0.483
# 1
# 0
# resultado da epoca 523 = 14.80 Epsilon = 0.482
# 1
# 0
# resultado da epoca 524 = -59.62 Epsilon = 0.481
# 0
# 1
# resultado da epoca 525 = -884.14 Epsilon = 0.480
# 0
# 1
# resultado da epoca 526 = 1253.12 Epsilon = 0.479
# 1
# 0
# resultado da epoca 527 = -882.48 Epsilon = 0.478
# 0
# 1
# resultado da epoca 528 = 62.22 Epsilon = 0.477
# 1
# 0
# resultado da epoca 529 = 115.40 Epsilon = 0.476
# 1
# 0
# resultado da epoca 530 = -173.38 Epsilon = 0.475
# 0
# 1
# resultado da epoca 531 = -380.80 Epsilon = 0.474
# 0
# 1
# resultado da epoca 532 = -411.42 Epsilon = 0.473
# 0
# 1
# resultado da epoca 533 = 286.76 Epsilon = 0.472
# 1
# 0
# resultado da epoca 534 = -1150.36 Epsilon = 0.471
# 0
# 1
# resultado da epoca 535 = -1125.82 Epsilon = 0.470
# 0
# 1
# resultado da epoca 536 = -1532.94 Epsilon = 0.469
# 0
# 1
# resultado da epoca 537 = -661.58 Epsilon = 0.468
# 0
# 1
# resultado da epoca 538 = 964.20 Epsilon = 0.467
# 1
# 0
# resultado da epoca 539 = 274.94 Epsilon = 0.466
# 1
# 0
# resultado da epoca 540 = -981.42 Epsilon = 0.465
# 0
# 1
# resultado da epoca 541 = -1025.50 Epsilon = 0.464
# 0
# 1
# resultado da epoca 542 = -144.90 Epsilon = 0.463
# 0
# 1
# resultado da epoca 543 = -1219.90 Epsilon = 0.462
# 0
# 1
# resultado da epoca 544 = -1161.88 Epsilon = 0.461
# 0
# 1
# resultado da epoca 545 = -13.70 Epsilon = 0.460
# 0
# 1
# resultado da epoca 546 = 647.68 Epsilon = 0.459
# 1
# 0
# resultado da epoca 547 = -512.32 Epsilon = 0.458
# 0
# 1
# resultado da epoca 548 = -31.86 Epsilon = 0.457
# 0
# 1
# resultado da epoca 549 = 1046.46 Epsilon = 0.456
# 1
# 0
# resultado da epoca 550 = -2623.36 Epsilon = 0.455
# 0
# 1
# resultado da epoca 551 = 1444.04 Epsilon = 0.455
# 1
# 0
# resultado da epoca 552 = 624.36 Epsilon = 0.454
# 1
# 0
# resultado da epoca 553 = -1334.74 Epsilon = 0.453
# 0
# 1
# resultado da epoca 554 = -1049.90 Epsilon = 0.452
# 0
# 1
# resultado da epoca 555 = 602.10 Epsilon = 0.451
# 1
# 0
# resultado da epoca 556 = 1142.54 Epsilon = 0.450
# 1
# 0
# resultado da epoca 557 = 972.38 Epsilon = 0.449
# 1
# 0
# resultado da epoca 558 = 881.48 Epsilon = 0.448
# 1
# 0
# resultado da epoca 559 = 1086.18 Epsilon = 0.447
# 1
# 0
# resultado da epoca 560 = -8.22 Epsilon = 0.446
# 0
# 1
# resultado da epoca 561 = -475.48 Epsilon = 0.445
# 0
# 1
# resultado da epoca 562 = -997.76 Epsilon = 0.444
# 0
# 1
# resultado da epoca 563 = -37.32 Epsilon = 0.443
# 0
# 1
# resultado da epoca 564 = -478.38 Epsilon = 0.442
# 0
# 1
# resultado da epoca 565 = 136.18 Epsilon = 0.441
# 1
# 0
# resultado da epoca 566 = -240.96 Epsilon = 0.440
# 0
# 1
# resultado da epoca 567 = -1492.62 Epsilon = 0.439
# 0
# 1
# resultado da epoca 568 = -798.98 Epsilon = 0.438
# 0
# 1
# resultado da epoca 569 = -576.10 Epsilon = 0.437
# 0
# 1
# resultado da epoca 570 = -1667.16 Epsilon = 0.436
# 0
# 1
# resultado da epoca 571 = -1077.00 Epsilon = 0.435
# 0
# 1
# resultado da epoca 572 = -1290.64 Epsilon = 0.434
# 0
# 1
# resultado da epoca 573 = -442.16 Epsilon = 0.433
# 0
# 1
# resultado da epoca 574 = -876.08 Epsilon = 0.432
# 0
# 1
# resultado da epoca 575 = -998.22 Epsilon = 0.431
# 0
# 1
# resultado da epoca 576 = -691.68 Epsilon = 0.430
# 0
# 1
# resultado da epoca 577 = -1130.04 Epsilon = 0.429
# 0
# 1
# resultado da epoca 578 = 866.62 Epsilon = 0.428
# 1
# 0
# resultado da epoca 579 = -1642.62 Epsilon = 0.427
# 0
# 1
# resultado da epoca 580 = -1204.42 Epsilon = 0.426
# 0
# 1
# resultado da epoca 581 = -338.96 Epsilon = 0.425
# 0
# 1
# resultado da epoca 582 = 105.42 Epsilon = 0.424
# 1
# 0
# resultado da epoca 583 = -195.48 Epsilon = 0.423
# 0
# 1
# resultado da epoca 584 = 720.88 Epsilon = 0.422
# 1
# 0
# resultado da epoca 585 = -702.92 Epsilon = 0.421
# 0
# 1
# resultado da epoca 586 = -672.00 Epsilon = 0.420
# 0
# 1
# resultado da epoca 587 = -927.92 Epsilon = 0.419
# 0
# 1
# resultado da epoca 588 = 343.14 Epsilon = 0.418
# 1
# 0
# resultado da epoca 589 = -1009.74 Epsilon = 0.417
# 0
# 1
# resultado da epoca 590 = -423.98 Epsilon = 0.416
# 0
# 1
# resultado da epoca 591 = 118.28 Epsilon = 0.415
# 1
# 0
# resultado da epoca 592 = 513.14 Epsilon = 0.414
# 1
# 0
# resultado da epoca 593 = -133.82 Epsilon = 0.413
# 0
# 1
# resultado da epoca 594 = -199.90 Epsilon = 0.412
# 0
# 1
# resultado da epoca 595 = -949.74 Epsilon = 0.411
# 0
# 1
# resultado da epoca 596 = -220.04 Epsilon = 0.410
# 0
# 1
# resultado da epoca 597 = 1211.16 Epsilon = 0.409
# 1
# 0
# resultado da epoca 598 = 277.70 Epsilon = 0.408
# 1
# 0
# resultado da epoca 599 = 1059.50 Epsilon = 0.407
# 1
# 0
# resultado da epoca 600 = -500.96 Epsilon = 0.406
# 0
# 1
# resultado da epoca 601 = 454.50 Epsilon = 0.405
# 1
# 0
# resultado da epoca 602 = 784.96 Epsilon = 0.404
# 1
# 0
# resultado da epoca 603 = 371.18 Epsilon = 0.403
# 1
# 0
# resultado da epoca 604 = 1029.50 Epsilon = 0.402
# 1
# 0
# resultado da epoca 605 = 824.80 Epsilon = 0.401
# 1
# 0
# resultado da epoca 606 = 982.08 Epsilon = 0.400
# 1
# 0
# resultado da epoca 607 = 829.36 Epsilon = 0.399
# 1
# 0
# resultado da epoca 608 = -1182.30 Epsilon = 0.398
# 0
# 1
# resultado da epoca 609 = 83.60 Epsilon = 0.397
# 1
# 0
# resultado da epoca 610 = 940.12 Epsilon = 0.396
# 1
# 0
# resultado da epoca 611 = 358.00 Epsilon = 0.395
# 1
# 0
# resultado da epoca 612 = -149.12 Epsilon = 0.394
# 0
# 1
# resultado da epoca 613 = 79.06 Epsilon = 0.393
# 1
# 0
# resultado da epoca 614 = -879.28 Epsilon = 0.392
# 0
# 1
# resultado da epoca 615 = -118.38 Epsilon = 0.391
# 0
# 1
# resultado da epoca 616 = 1170.72 Epsilon = 0.390
# 1
# 0
# resultado da epoca 617 = 731.18 Epsilon = 0.389
# 1
# 0
# resultado da epoca 618 = -344.74 Epsilon = 0.388
# 0
# 1
# resultado da epoca 619 = 510.12 Epsilon = 0.387
# 1
# 0
# resultado da epoca 620 = 1293.30 Epsilon = 0.386
# 1
# 0
# resultado da epoca 621 = 593.58 Epsilon = 0.385
# 1
# 0
# resultado da epoca 622 = 128.14 Epsilon = 0.384
# 1
# 0
# resultado da epoca 623 = -286.26 Epsilon = 0.383
# 0
# 1
# resultado da epoca 624 = -581.86 Epsilon = 0.382
# 0
# 1
# resultado da epoca 625 = -682.78 Epsilon = 0.381
# 0
# 1
# resultado da epoca 626 = -628.22 Epsilon = 0.380
# 0
# 1
# resultado da epoca 627 = 975.86 Epsilon = 0.379
# 1
# 0
# resultado da epoca 628 = -818.52 Epsilon = 0.378
# 0
# 1
# resultado da epoca 629 = -315.48 Epsilon = 0.377
# 0
# 1
# resultado da epoca 630 = -407.16 Epsilon = 0.376
# 0
# 1
# resultado da epoca 631 = -127.28 Epsilon = 0.375
# 0
# 1
# resultado da epoca 632 = -343.06 Epsilon = 0.374
# 0
# 1
# resultado da epoca 633 = 1573.16 Epsilon = 0.373
# 1
# 0
# resultado da epoca 634 = -1733.66 Epsilon = 0.372
# 0
# 1
# resultado da epoca 635 = -704.26 Epsilon = 0.371
# 0
# 1
# resultado da epoca 636 = -1514.72 Epsilon = 0.370
# 0
# 1
# resultado da epoca 637 = -761.54 Epsilon = 0.369
# 0
# 1
# resultado da epoca 638 = 7.54 Epsilon = 0.368
# 1
# 0
# resultado da epoca 639 = -994.86 Epsilon = 0.367
# 0
# 1
# resultado da epoca 640 = -571.08 Epsilon = 0.366
# 0
# 1
# resultado da epoca 641 = -187.90 Epsilon = 0.365
# 0
# 1
# resultado da epoca 642 = -470.78 Epsilon = 0.364
# 0
# 1
# resultado da epoca 643 = 551.80 Epsilon = 0.363
# 1
# 0
# resultado da epoca 644 = -487.44 Epsilon = 0.362
# 0
# 1
# resultado da epoca 645 = -723.36 Epsilon = 0.361
# 0
# 1
# resultado da epoca 646 = 608.94 Epsilon = 0.360
# 1
# 0
# resultado da epoca 647 = 628.00 Epsilon = 0.359
# 1
# 0
# resultado da epoca 648 = -192.14 Epsilon = 0.358
# 0
# 1
# resultado da epoca 649 = -913.96 Epsilon = 0.357
# 0
# 1
# resultado da epoca 650 = -1078.82 Epsilon = 0.356
# 0
# 1
# resultado da epoca 651 = -1843.50 Epsilon = 0.356
# 0
# 1
# resultado da epoca 652 = 872.10 Epsilon = 0.355
# 1
# 0
# resultado da epoca 653 = 519.52 Epsilon = 0.354
# 1
# 0
# resultado da epoca 654 = -201.54 Epsilon = 0.353
# 0
# 1
# resultado da epoca 655 = -1039.10 Epsilon = 0.352
# 0
# 1
# resultado da epoca 656 = -1134.58 Epsilon = 0.351
# 0
# 1
# resultado da epoca 657 = 1404.96 Epsilon = 0.350
# 1
# 0
# resultado da epoca 658 = 307.26 Epsilon = 0.349
# 1
# 0
# resultado da epoca 659 = -150.04 Epsilon = 0.348
# 0
# 1
# resultado da epoca 660 = 852.24 Epsilon = 0.347
# 1
# 0
# resultado da epoca 661 = -179.28 Epsilon = 0.346
# 0
# 1
# resultado da epoca 662 = 357.54 Epsilon = 0.345
# 1
# 0
# resultado da epoca 663 = 279.36 Epsilon = 0.344
# 1
# 0
# resultado da epoca 664 = 2132.68 Epsilon = 0.343
# 1
# 0
# resultado da epoca 665 = 1700.86 Epsilon = 0.342
# 1
# 0
# resultado da epoca 666 = 4.50 Epsilon = 0.341
# 1
# 0
# resultado da epoca 667 = 2466.62 Epsilon = 0.340
# 1
# 0
# resultado da epoca 668 = 1048.30 Epsilon = 0.339
# 1
# 0
# resultado da epoca 669 = 1907.70 Epsilon = 0.338
# 1
# 0
# resultado da epoca 670 = 1151.18 Epsilon = 0.337
# 1
# 0
# resultado da epoca 671 = 108.14 Epsilon = 0.336
# 1
# 0
# resultado da epoca 672 = -7.92 Epsilon = 0.335
# 0
# 1
# resultado da epoca 673 = -174.44 Epsilon = 0.334
# 0
# 1
# resultado da epoca 674 = 1626.02 Epsilon = 0.333
# 1
# 0
# resultado da epoca 675 = -1139.88 Epsilon = 0.332
# 0
# 1
# resultado da epoca 676 = -586.70 Epsilon = 0.331
# 0
# 1
# resultado da epoca 677 = -366.24 Epsilon = 0.330
# 0
# 1
# resultado da epoca 678 = 625.12 Epsilon = 0.329
# 1
# 0
# resultado da epoca 679 = 751.48 Epsilon = 0.328
# 1
# 0
# resultado da epoca 680 = 1256.18 Epsilon = 0.327
# 1
# 0
# resultado da epoca 681 = 1231.04 Epsilon = 0.326
# 1
# 0
# resultado da epoca 682 = 1741.64 Epsilon = 0.325
# 1
# 0
# resultado da epoca 683 = -1571.98 Epsilon = 0.324
# 0
# 1
# resultado da epoca 684 = 670.88 Epsilon = 0.323
# 1
# 0
# resultado da epoca 685 = 45.14 Epsilon = 0.322
# 1
# 0
# resultado da epoca 686 = 8.16 Epsilon = 0.321
# 1
# 0
# resultado da epoca 687 = 603.46 Epsilon = 0.320
# 1
# 0
# resultado da epoca 688 = -2023.82 Epsilon = 0.319
# 0
# 1
# resultado da epoca 689 = 76.18 Epsilon = 0.318
# 1
# 0
# resultado da epoca 690 = -995.48 Epsilon = 0.317
# 0
# 1
# resultado da epoca 691 = -113.38 Epsilon = 0.316
# 0
# 1
# resultado da epoca 692 = -974.28 Epsilon = 0.315
# 0
# 1
# resultado da epoca 693 = -612.46 Epsilon = 0.314
# 0
# 1
# resultado da epoca 694 = -225.02 Epsilon = 0.313
# 0
# 1
# resultado da epoca 695 = -446.84 Epsilon = 0.312
# 0
# 1
# resultado da epoca 696 = 56.78 Epsilon = 0.311
# 1
# 0
# resultado da epoca 697 = 589.98 Epsilon = 0.310
# 1
# 0
# resultado da epoca 698 = -625.92 Epsilon = 0.309
# 0
# 1
# resultado da epoca 699 = 307.54 Epsilon = 0.308
# 1
# 0
# resultado da epoca 700 = 45.86 Epsilon = 0.307
# 1
# 0
# resultado da epoca 701 = -485.64 Epsilon = 0.306
# 0
# 1
# resultado da epoca 702 = -60.34 Epsilon = 0.305
# 0
# 1
# resultado da epoca 703 = -554.88 Epsilon = 0.304
# 0
# 1
# resultado da epoca 704 = -120.34 Epsilon = 0.303
# 0
# 1
# resultado da epoca 705 = 412.54 Epsilon = 0.302
# 1
# 0
# resultado da epoca 706 = -455.04 Epsilon = 0.301
# 0
# 1
# resultado da epoca 707 = -1102.32 Epsilon = 0.300
# 0
# 1
# resultado da epoca 708 = -3082.60 Epsilon = 0.299
# 0
# 1
# resultado da epoca 709 = -865.48 Epsilon = 0.298
# 0
# 1
# resultado da epoca 710 = -1933.06 Epsilon = 0.297
# 0
# 1
# resultado da epoca 711 = -954.12 Epsilon = 0.296
# 0
# 1
# resultado da epoca 712 = -1111.10 Epsilon = 0.295
# 0
# 1
# resultado da epoca 713 = -1270.94 Epsilon = 0.294
# 0
# 1
# resultado da epoca 714 = -1261.86 Epsilon = 0.293
# 0
# 1
# resultado da epoca 715 = -778.98 Epsilon = 0.292
# 0
# 1
# resultado da epoca 716 = -806.56 Epsilon = 0.291
# 0
# 1
# resultado da epoca 717 = 31.32 Epsilon = 0.290
# 1
# 0
# resultado da epoca 718 = -1873.68 Epsilon = 0.289
# 0
# 1
# resultado da epoca 719 = -1127.48 Epsilon = 0.288
# 0
# 1
# resultado da epoca 720 = -560.36 Epsilon = 0.287
# 0
# 1
# resultado da epoca 721 = -1276.24 Epsilon = 0.286
# 0
# 1
# resultado da epoca 722 = -1010.96 Epsilon = 0.285
# 0
# 1
# resultado da epoca 723 = 448.00 Epsilon = 0.284
# 1
# 0
# resultado da epoca 724 = -1612.76 Epsilon = 0.283
# 0
# 1
# resultado da epoca 725 = 726.32 Epsilon = 0.282
# 1
# 0
# resultado da epoca 726 = -63.22 Epsilon = 0.281
# 0
# 1
# resultado da epoca 727 = -229.44 Epsilon = 0.280
# 0
# 1
# resultado da epoca 728 = 732.40 Epsilon = 0.279
# 1
# 0
# resultado da epoca 729 = 93.44 Epsilon = 0.278
# 1
# 0
# resultado da epoca 730 = 664.20 Epsilon = 0.277
# 1
# 0
# resultado da epoca 731 = -516.10 Epsilon = 0.276
# 0
# 1
# resultado da epoca 732 = 1693.90 Epsilon = 0.275
# 1
# 0
# resultado da epoca 733 = 525.26 Epsilon = 0.274
# 1
# 0
# resultado da epoca 734 = 1244.36 Epsilon = 0.273
# 1
# 0
# resultado da epoca 735 = 1703.76 Epsilon = 0.272
# 1
# 0
# resultado da epoca 736 = 188.90 Epsilon = 0.271
# 1
# 0
# resultado da epoca 737 = 1570.72 Epsilon = 0.270
# 1
# 0
# resultado da epoca 738 = 262.22 Epsilon = 0.269
# 1
# 0
# resultado da epoca 739 = 606.78 Epsilon = 0.268
# 1
# 0
# resultado da epoca 740 = -408.38 Epsilon = 0.267
# 0
# 1
# resultado da epoca 741 = 540.26 Epsilon = 0.266
# 1
# 0
# resultado da epoca 742 = 1088.44 Epsilon = 0.265
# 1
# 0
# resultado da epoca 743 = 794.20 Epsilon = 0.264
# 1
# 0
# resultado da epoca 744 = 769.36 Epsilon = 0.263
# 1
# 0
# resultado da epoca 745 = 1685.26 Epsilon = 0.262
# 1
# 0
# resultado da epoca 746 = -373.98 Epsilon = 0.261
# 0
# 1
# resultado da epoca 747 = 372.54 Epsilon = 0.260
# 1
# 0
# resultado da epoca 748 = 183.30 Epsilon = 0.259
# 1
# 0
# resultado da epoca 749 = 587.52 Epsilon = 0.258
# 1
# 0
# resultado da epoca 750 = -74.28 Epsilon = 0.257
# 0
# 1
# resultado da epoca 751 = 281.62 Epsilon = 0.257
# 1
# 0
# resultado da epoca 752 = 729.96 Epsilon = 0.256
# 1
# 0
# resultado da epoca 753 = 1529.50 Epsilon = 0.255
# 1
# 0
# resultado da epoca 754 = 655.86 Epsilon = 0.254
# 1
# 0
# resultado da epoca 755 = 309.34 Epsilon = 0.253
# 1
# 0
# resultado da epoca 756 = 426.62 Epsilon = 0.252
# 1
# 0
# resultado da epoca 757 = 595.56 Epsilon = 0.251
# 1
# 0
# resultado da epoca 758 = 543.72 Epsilon = 0.250
# 1
# 0
# resultado da epoca 759 = 676.16 Epsilon = 0.249
# 1
# 0
# resultado da epoca 760 = 335.72 Epsilon = 0.248
# 1
# 0
# resultado da epoca 761 = 413.58 Epsilon = 0.247
# 1
# 0
# resultado da epoca 762 = 502.68 Epsilon = 0.246
# 1
# 0
# resultado da epoca 763 = -212.46 Epsilon = 0.245
# 0
# 1
# resultado da epoca 764 = -41.86 Epsilon = 0.244
# 0
# 1
# resultado da epoca 765 = -432.00 Epsilon = 0.243
# 0
# 1
# resultado da epoca 766 = 667.24 Epsilon = 0.242
# 1
# 0
# resultado da epoca 767 = 110.72 Epsilon = 0.241
# 1
# 0
# resultado da epoca 768 = -1126.56 Epsilon = 0.240
# 0
# 1
# resultado da epoca 769 = -885.18 Epsilon = 0.239
# 0
# 1
# resultado da epoca 770 = 1043.44 Epsilon = 0.238
# 1
# 0
# resultado da epoca 771 = 952.08 Epsilon = 0.237
# 1
# 0
# resultado da epoca 772 = -313.68 Epsilon = 0.236
# 0
# 1
# resultado da epoca 773 = -183.22 Epsilon = 0.235
# 0
# 1
# resultado da epoca 774 = -834.56 Epsilon = 0.234
# 0
# 1
# resultado da epoca 775 = -1116.68 Epsilon = 0.233
# 0
# 1
# resultado da epoca 776 = -746.08 Epsilon = 0.232
# 0
# 1
# resultado da epoca 777 = -1245.48 Epsilon = 0.231
# 0
# 1
# resultado da epoca 778 = -606.98 Epsilon = 0.230
# 0
# 1
# resultado da epoca 779 = -551.08 Epsilon = 0.229
# 0
# 1
# resultado da epoca 780 = -1168.06 Epsilon = 0.228
# 0
# 1
# resultado da epoca 781 = -1013.82 Epsilon = 0.227
# 0
# 1
# resultado da epoca 782 = -562.30 Epsilon = 0.226
# 0
# 1
# resultado da epoca 783 = -717.30 Epsilon = 0.225
# 0
# 1
# resultado da epoca 784 = -384.44 Epsilon = 0.224
# 0
# 1
# resultado da epoca 785 = -808.68 Epsilon = 0.223
# 0
# 1
# resultado da epoca 786 = 30.72 Epsilon = 0.222
# 1
# 0
# resultado da epoca 787 = 241.78 Epsilon = 0.221
# 1
# 0
# resultado da epoca 788 = -251.70 Epsilon = 0.220
# 0
# 1
# resultado da epoca 789 = 19.52 Epsilon = 0.219
# 1
# 0
# resultado da epoca 790 = 34.98 Epsilon = 0.218
# 1
# 0
# resultado da epoca 791 = 342.70 Epsilon = 0.217
# 1
# 0
# resultado da epoca 792 = 113.46 Epsilon = 0.216
# 1
# 0
# resultado da epoca 793 = -188.06 Epsilon = 0.215
# 0
# 1
# resultado da epoca 794 = -643.82 Epsilon = 0.214
# 0
# 1
# resultado da epoca 795 = 239.36 Epsilon = 0.213
# 1
# 0
# resultado da epoca 796 = -734.58 Epsilon = 0.212
# 0
# 1
# resultado da epoca 797 = -929.74 Epsilon = 0.211
# 0
# 1
# resultado da epoca 798 = 179.22 Epsilon = 0.210
# 1
# 0
# resultado da epoca 799 = -668.96 Epsilon = 0.209
# 0
# 1
# resultado da epoca 800 = -957.60 Epsilon = 0.208
# 0
# 1
# resultado da epoca 801 = 388.16 Epsilon = 0.207
# 1
# 0
# resultado da epoca 802 = 100.58 Epsilon = 0.206
# 1
# 0
# resultado da epoca 803 = -1036.10 Epsilon = 0.205
# 0
# 1
# resultado da epoca 804 = 1353.30 Epsilon = 0.204
# 1
# 0
# resultado da epoca 805 = -35.94 Epsilon = 0.203
# 0
# 1
# resultado da epoca 806 = -68.06 Epsilon = 0.202
# 0
# 1
# resultado da epoca 807 = -1456.10 Epsilon = 0.201
# 0
# 1
# resultado da epoca 808 = -873.96 Epsilon = 0.200
# 0
# 1
# resultado da epoca 809 = -733.98 Epsilon = 0.199
# 0
# 1
# resultado da epoca 810 = 79.52 Epsilon = 0.198
# 1
# 0
# resultado da epoca 811 = -126.54 Epsilon = 0.197
# 0
# 1
# resultado da epoca 812 = -918.38 Epsilon = 0.196
# 0
# 1
# resultado da epoca 813 = 1019.50 Epsilon = 0.195
# 1
# 0
# resultado da epoca 814 = 265.56 Epsilon = 0.194
# 1
# 0
# resultado da epoca 815 = -480.80 Epsilon = 0.193
# 0
# 1
# resultado da epoca 816 = -340.96 Epsilon = 0.192
# 0
# 1
# resultado da epoca 817 = -715.80 Epsilon = 0.191
# 0
# 1
# resultado da epoca 818 = -491.56 Epsilon = 0.190
# 0
# 1
# resultado da epoca 819 = -649.14 Epsilon = 0.189
# 0
# 1
# resultado da epoca 820 = -234.60 Epsilon = 0.188
# 0
# 1
# resultado da epoca 821 = -283.24 Epsilon = 0.187
# 0
# 1
# resultado da epoca 822 = -1311.56 Epsilon = 0.186
# 0
# 1
# resultado da epoca 823 = -910.04 Epsilon = 0.185
# 0
# 1
# resultado da epoca 824 = -1444.74 Epsilon = 0.184
# 0
# 1
# resultado da epoca 825 = -725.80 Epsilon = 0.183
# 0
# 1
# resultado da epoca 826 = -48.22 Epsilon = 0.182
# 0
# 1
# resultado da epoca 827 = -1031.40 Epsilon = 0.181
# 0
# 1
# resultado da epoca 828 = 164.22 Epsilon = 0.180
# 1
# 0
# resultado da epoca 829 = -725.18 Epsilon = 0.179
# 0
# 1
# resultado da epoca 830 = -881.08 Epsilon = 0.178
# 0
# 1
# resultado da epoca 831 = -1891.24 Epsilon = 0.177
# 0
# 1
# resultado da epoca 832 = -461.54 Epsilon = 0.176
# 0
# 1
# resultado da epoca 833 = -963.36 Epsilon = 0.175
# 0
# 1
# resultado da epoca 834 = -952.46 Epsilon = 0.174
# 0
# 1
# resultado da epoca 835 = -1224.12 Epsilon = 0.173
# 0
# 1
# resultado da epoca 836 = -1020.34 Epsilon = 0.172
# 0
# 1
# resultado da epoca 837 = -1722.92 Epsilon = 0.171
# 0
# 1
# resultado da epoca 838 = -1397.14 Epsilon = 0.170
# 0
# 1
# resultado da epoca 839 = -271.68 Epsilon = 0.169
# 0
# 1
# resultado da epoca 840 = -1236.08 Epsilon = 0.168
# 0
# 1
# resultado da epoca 841 = -1119.56 Epsilon = 0.167
# 0
# 1
# resultado da epoca 842 = 338.62 Epsilon = 0.166
# 1
# 0
# resultado da epoca 843 = -412.44 Epsilon = 0.165
# 0
# 1
# resultado da epoca 844 = -239.54 Epsilon = 0.164
# 0
# 1
# resultado da epoca 845 = -1476.38 Epsilon = 0.163
# 0
# 1
# resultado da epoca 846 = -1068.20 Epsilon = 0.162
# 0
# 1
# resultado da epoca 847 = -512.72 Epsilon = 0.161
# 0
# 1
# resultado da epoca 848 = -821.52 Epsilon = 0.160
# 0
# 1
# resultado da epoca 849 = -271.06 Epsilon = 0.159
# 0
# 1
# resultado da epoca 850 = -698.66 Epsilon = 0.158
# 0
# 1
# resultado da epoca 851 = -537.44 Epsilon = 0.158
# 0
# 1
# resultado da epoca 852 = -258.96 Epsilon = 0.157
# 0
# 1
# resultado da epoca 853 = 921.06 Epsilon = 0.156
# 1
# 0
# resultado da epoca 854 = 643.62 Epsilon = 0.155
# 1
# 0
# resultado da epoca 855 = 375.14 Epsilon = 0.154
# 1
# 0
# resultado da epoca 856 = 625.60 Epsilon = 0.153
# 1
# 0
# resultado da epoca 857 = 64.84 Epsilon = 0.152
# 1
# 0
# resultado da epoca 858 = -1059.10 Epsilon = 0.151
# 0
# 1
# resultado da epoca 859 = 508.46 Epsilon = 0.150
# 1
# 0
# resultado da epoca 860 = -33.50 Epsilon = 0.149
# 0
# 1
# resultado da epoca 861 = -208.22 Epsilon = 0.148
# 0
# 1
# resultado da epoca 862 = -1007.00 Epsilon = 0.147
# 0
# 1
# resultado da epoca 863 = -335.96 Epsilon = 0.146
# 0
# 1
# resultado da epoca 864 = -1013.98 Epsilon = 0.145
# 0
# 1
# resultado da epoca 865 = -461.10 Epsilon = 0.144
# 0
# 1
# resultado da epoca 866 = -295.50 Epsilon = 0.143
# 0
# 1
# resultado da epoca 867 = -973.52 Epsilon = 0.142
# 0
# 1
# resultado da epoca 868 = -6.70 Epsilon = 0.141
# 0
# 1
# resultado da epoca 869 = -217.16 Epsilon = 0.140
# 0
# 1
# resultado da epoca 870 = -217.62 Epsilon = 0.139
# 0
# 1
# resultado da epoca 871 = 337.38 Epsilon = 0.138
# 1
# 0
# resultado da epoca 872 = 453.74 Epsilon = 0.137
# 1
# 0
# resultado da epoca 873 = -860.64 Epsilon = 0.136
# 0
# 1
# resultado da epoca 874 = -448.06 Epsilon = 0.135
# 0
# 1
# resultado da epoca 875 = -199.28 Epsilon = 0.134
# 0
# 1
# resultado da epoca 876 = -346.86 Epsilon = 0.133
# 0
# 1
# resultado da epoca 877 = -560.64 Epsilon = 0.132
# 0
# 1
# resultado da epoca 878 = 463.90 Epsilon = 0.131
# 1
# 0
# resultado da epoca 879 = -1796.54 Epsilon = 0.130
# 0
# 1
# resultado da epoca 880 = 215.28 Epsilon = 0.129
# 1
# 0
# resultado da epoca 881 = 815.88 Epsilon = 0.128
# 1
# 0
# resultado da epoca 882 = 633.60 Epsilon = 0.127
# 1
# 0
# resultado da epoca 883 = 539.36 Epsilon = 0.126
# 1
# 0
# resultado da epoca 884 = 650.42 Epsilon = 0.125
# 1
# 0
# resultado da epoca 885 = -400.32 Epsilon = 0.124
# 0
# 1
# resultado da epoca 886 = -875.94 Epsilon = 0.123
# 0
# 1
# resultado da epoca 887 = -1766.84 Epsilon = 0.122
# 0
# 1
# resultado da epoca 888 = -1496.84 Epsilon = 0.121
# 0
# 1
# resultado da epoca 889 = -1882.74 Epsilon = 0.120
# 0
# 1
# resultado da epoca 890 = -1061.98 Epsilon = 0.119
# 0
# 1
# resultado da epoca 891 = -307.00 Epsilon = 0.118
# 0
# 1
# resultado da epoca 892 = -1439.12 Epsilon = 0.117
# 0
# 1
# resultado da epoca 893 = -968.82 Epsilon = 0.116
# 0
# 1
# resultado da epoca 894 = -402.46 Epsilon = 0.115
# 0
# 1
# resultado da epoca 895 = -960.64 Epsilon = 0.114
# 0
# 1
# resultado da epoca 896 = -926.10 Epsilon = 0.113
# 0
# 1
# resultado da epoca 897 = -800.96 Epsilon = 0.112
# 0
# 1
# resultado da epoca 898 = -283.08 Epsilon = 0.111
# 0
# 1
# resultado da epoca 899 = -1088.38 Epsilon = 0.110
# 0
# 1
# resultado da epoca 900 = -2192.76 Epsilon = 0.109
# 0
# 1
# resultado da epoca 901 = -1075.50 Epsilon = 0.108
# 0
# 1
# resultado da epoca 902 = -751.26 Epsilon = 0.107
# 0
# 1
# resultado da epoca 903 = -1179.88 Epsilon = 0.106
# 0
# 1
# resultado da epoca 904 = -44.42 Epsilon = 0.105
# 0
# 1
# resultado da epoca 905 = -1551.38 Epsilon = 0.104
# 0
# 1
# resultado da epoca 906 = -657.30 Epsilon = 0.103
# 0
# 1
# resultado da epoca 907 = -61.54 Epsilon = 0.102
# 0
# 1
# resultado da epoca 908 = 489.06 Epsilon = 0.101
# 1
# 0
# resultado da epoca 909 = -292.30 Epsilon = 0.100
# 0
# 1
# resultado da epoca 910 = -714.74 Epsilon = 0.099
# 0
# 1
# resultado da epoca 911 = -434.28 Epsilon = 0.098
# 0
# 1
# resultado da epoca 912 = -33.52 Epsilon = 0.097
# 0
# 1
# resultado da epoca 913 = 429.36 Epsilon = 0.096
# 1
# 0
# resultado da epoca 914 = 543.00 Epsilon = 0.095
# 1
# 0
# resultado da epoca 915 = 865.72 Epsilon = 0.094
# 1
# 0
# resultado da epoca 916 = 1291.48 Epsilon = 0.093
# 1
# 0
# resultado da epoca 917 = 83.76 Epsilon = 0.092
# 1
# 0
# resultado da epoca 918 = 1286.20 Epsilon = 0.091
# 1
# 0
# resultado da epoca 919 = 888.00 Epsilon = 0.090
# 1
# 0
# resultado da epoca 920 = 592.10 Epsilon = 0.089
# 1
# 0
# resultado da epoca 921 = 1670.88 Epsilon = 0.088
# 1
# 0
# resultado da epoca 922 = 295.88 Epsilon = 0.087
# 1
# 0
# resultado da epoca 923 = -248.22 Epsilon = 0.086
# 0
# 1
# resultado da epoca 924 = -979.14 Epsilon = 0.085
# 0
# 1
# resultado da epoca 925 = 543.90 Epsilon = 0.084
# 1
# 0
# resultado da epoca 926 = -1048.52 Epsilon = 0.083
# 0
# 1
# resultado da epoca 927 = -58.22 Epsilon = 0.082
# 0
# 1
# resultado da epoca 928 = -422.92 Epsilon = 0.081
# 0
# 1
# resultado da epoca 929 = -1107.62 Epsilon = 0.080
# 0
# 1
# resultado da epoca 930 = -628.38 Epsilon = 0.079
# 0
# 1
# resultado da epoca 931 = -207.92 Epsilon = 0.078
# 0
# 1
# resultado da epoca 932 = -1011.54 Epsilon = 0.077
# 0
# 1
# resultado da epoca 933 = -1235.34 Epsilon = 0.076
# 0
# 1
# resultado da epoca 934 = -1642.00 Epsilon = 0.075
# 0
# 1
# resultado da epoca 935 = -1310.80 Epsilon = 0.074
# 0
# 1
# resultado da epoca 936 = -1367.62 Epsilon = 0.073
# 0
# 1
# resultado da epoca 937 = -1951.56 Epsilon = 0.072
# 0
# 1
# resultado da epoca 938 = -1010.80 Epsilon = 0.071
# 0
# 1
# resultado da epoca 939 = -408.68 Epsilon = 0.070
# 0
# 1
# resultado da epoca 940 = -651.10 Epsilon = 0.069
# 0
# 1
# resultado da epoca 941 = -1439.42 Epsilon = 0.068
# 0
# 1
# resultado da epoca 942 = -1698.66 Epsilon = 0.067
# 0
# 1
# resultado da epoca 943 = -1297.30 Epsilon = 0.066
# 0
# 1
# resultado da epoca 944 = -738.82 Epsilon = 0.065
# 0
# 1
# resultado da epoca 945 = -1274.72 Epsilon = 0.064
# 0
# 1
# resultado da epoca 946 = -1603.96 Epsilon = 0.063
# 0
# 1
# resultado da epoca 947 = -1612.90 Epsilon = 0.062
# 0
# 1
# resultado da epoca 948 = -1318.80 Epsilon = 0.061
# 0
# 1
# resultado da epoca 949 = -1583.20 Epsilon = 0.060
# 0
# 1
# resultado da epoca 950 = -1875.78 Epsilon = 0.059
# 0
# 1
# resultado da epoca 951 = -1061.38 Epsilon = 0.059
# 0
# 1
# resultado da epoca 952 = -1710.78 Epsilon = 0.058
# 0
# 1
# resultado da epoca 953 = -1871.82 Epsilon = 0.057
# 0
# 1
# resultado da epoca 954 = -883.64 Epsilon = 0.056
# 0
# 1
# resultado da epoca 955 = -1706.96 Epsilon = 0.055
# 0
# 1
# resultado da epoca 956 = -1479.40 Epsilon = 0.054
# 0
# 1
# resultado da epoca 957 = -1486.38 Epsilon = 0.053
# 0
# 1
# resultado da epoca 958 = -1439.86 Epsilon = 0.052
# 0
# 1
# resultado da epoca 959 = -1625.32 Epsilon = 0.051
# 0
# 1
# resultado da epoca 960 = -796.22 Epsilon = 0.050
# 0
# 1
# resultado da epoca 961 = 14.52 Epsilon = 0.049
# 1
# 0
# resultado da epoca 962 = -248.66 Epsilon = 0.048
# 0
# 1
# resultado da epoca 963 = -1427.76 Epsilon = 0.047
# 0
# 1
# resultado da epoca 964 = -491.70 Epsilon = 0.046
# 0
# 1
# resultado da epoca 965 = -43.96 Epsilon = 0.045
# 0
# 1
# resultado da epoca 966 = -901.24 Epsilon = 0.044
# 0
# 1
# resultado da epoca 967 = -1669.56 Epsilon = 0.043
# 0
# 1
# resultado da epoca 968 = -1413.80 Epsilon = 0.042
# 0
# 1
# resultado da epoca 969 = -513.52 Epsilon = 0.041
# 0
# 1
# resultado da epoca 970 = 98.60 Epsilon = 0.040
# 1
# 0
# resultado da epoca 971 = -701.70 Epsilon = 0.039
# 0
# 1
# resultado da epoca 972 = -114.58 Epsilon = 0.038
# 0
# 1
# resultado da epoca 973 = -20.34 Epsilon = 0.037
# 0
# 1
# resultado da epoca 974 = -102.76 Epsilon = 0.036
# 0
# 1
# resultado da epoca 975 = 500.72 Epsilon = 0.035
# 1
# 0
# resultado da epoca 976 = 252.54 Epsilon = 0.034
# 1
# 0
# resultado da epoca 977 = -59.42 Epsilon = 0.033
# 0
# 1
# resultado da epoca 978 = -1093.82 Epsilon = 0.032
# 0
# 1
# resultado da epoca 979 = 179.96 Epsilon = 0.031
# 1
# 0
# resultado da epoca 980 = 793.44 Epsilon = 0.030
# 1
# 0
# resultado da epoca 981 = 539.34 Epsilon = 0.029
# 1
# 0
# resultado da epoca 982 = 674.20 Epsilon = 0.028
# 1
# 0
# resultado da epoca 983 = 129.50 Epsilon = 0.027
# 1
# 0
# resultado da epoca 984 = -457.32 Epsilon = 0.026
# 0
# 1
# resultado da epoca 985 = -1100.96 Epsilon = 0.025
# 0
# 1
# resultado da epoca 986 = -1646.72 Epsilon = 0.024
# 0
# 1
# resultado da epoca 987 = -1315.66 Epsilon = 0.023
# 0
# 1
# resultado da epoca 988 = -1704.60 Epsilon = 0.022
# 0
# 1
# resultado da epoca 989 = -762.78 Epsilon = 0.021
# 0
# 1
# resultado da epoca 990 = -588.38 Epsilon = 0.020
# 0
# 1
# resultado da epoca 991 = -879.14 Epsilon = 0.019
# 0
# 1
# resultado da epoca 992 = -847.78 Epsilon = 0.018
# 0
# 1
# resultado da epoca 993 = -1211.56 Epsilon = 0.017
# 0
# 1
# resultado da epoca 994 = -746.40 Epsilon = 0.016
# 0
# 1
# resultado da epoca 995 = -1558.38 Epsilon = 0.015
# 0
# 1
# resultado da epoca 996 = 163.74 Epsilon = 0.014
# 1
# 0
# resultado da epoca 997 = -805.04 Epsilon = 0.013
# 0
# 1
# resultado da epoca 998 = -739.28 Epsilon = 0.012
# 0
# 1
# resultado da epoca 999 = -625.64 Epsilon = 0.011
# 0
# 1
# resultado da epoca 1000 = -890.18 Epsilon = 0.010
# 0
# 1
# resultado da epoca 1001 = -967.30 Epsilon = 0.010
# 0
# 1
# resultado da epoca 1002 = -598.06 Epsilon = 0.010
# 0
# 1
# resultado da epoca 1003 = -950.94 Epsilon = 0.010
# 0
# 1
# resultado da epoca 1004 = -1364.58 Epsilon = 0.010
# 0
# 1
# 0
# 0
# Melhor resultado diario: 2609.96
