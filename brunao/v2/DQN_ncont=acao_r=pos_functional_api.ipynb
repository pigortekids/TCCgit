# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
n_mercado = n_variaveis*janela #inputs
n_estados = 2 #ncont e valor
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 220

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0

for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Model
from keras.layers import Dense, Input, concatenate
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, mkt_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = state_size
        self.mkt_size = mkt_size
        self.n_neuronios = n_neuronios
        self.action_size = action_size
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.97       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        #inputs
        x1 = Input(shape=(self.state_size,))
        x2 = Input(shape=(self.mkt_size,))
        
        #state hidden layers
        a1 = Dense(320)(x1)
        a2 = Dense(256)(a1)
        
        #mkt hidden layers
        b1 = Dense(320)(x2)
        b2 = Dense(256)(b1)
        
        #concatenacao
        x12 = concatenate([a2, b2], axis=-1)
        
        #camada de processamento ????
        
        #camada de saida
        y = Dense(self.action_size, activation='linear')(x12)
        
        model = Model(inputs=[x1, x2], outputs=y)
        
        sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(loss='mean_squared_error', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(self.mkt_size)
        self.prox_janela_precos = np.zeros(self.mkt_size)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict([self.state, self.janela_precos]) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x1 = np.zeros((batch_size+1, self.state_size))
        x2 = np.zeros((batch_size+1, self.mkt_size))
        y = np.zeros((batch_size+1, self.action_size))
        i = 0
        for acao, reward, estado, mercado, prox_estado, prox_mercado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict([prox_estado, prox_mercado])[0])) #pega valor que quer chegar

            target_f = self.model.predict([estado, mercado]) #pega valor que chegou
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x1[i,:] = estado
            x2[i,:] = mercado
            y[i,:] = target_f
            i = i + 1
            
        self.model.fit([x1, x2], y, epochs=1, verbose=0) #treina modelo
            
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.janela_precos, self.next_state, self.prox_janela_precos, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_estados, n_mercado, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 20)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 320)          960         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 320)          6720        input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          82176       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          82176       dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           dense_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 11)           5643        concatenate_1[0][0]
# ==================================================================================================
# Total params: 177,675
# Trainable params: 177,675
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia - 1], steps[dia] ):  #roda os dados
        
        ultimos_precos = precos[ step : step + 1 ] #pega os valores de agora
        modelo.janela_precos = np.reshape(np.delete(np.insert(modelo.janela_precos,shp,np.concatenate(ultimos_precos.values).tolist()),[0,l]), (1,modelo.mkt_size))
        modelo.state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        
        acao = obter_acao(ncont)        
        ncont, valor, posicao, reward = atuacao(precos['preco'][step], ncont, acao, custo, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; valor={2}; preco={3}; posicao={4}; lucro={5}; reward={6}".format(acao, ncont, v, p, posicao, lucro, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            prox_precos = np.zeros(n_variaveis)
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,prox_precos),[0,l]),(1,modelo.mkt_size))
        else:
            prox_precos = precos[ step + 1 : step + 2 ] #pega os proximos valores
            modelo.prox_janela_precos = np.reshape(np.delete(np.insert(modelo.prox_janela_precos,shp,np.concatenate(prox_precos.values).tolist()),[0,l]),(1,modelo.mkt_size))
        
        modelo.next_state = np.reshape([ncont/lim_cont, valor], (1,modelo.state_size)) #adiciona na variavel de estado      
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia
    lucro += posicao

    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 1, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    sum_rewards_total = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas+5): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            modelo.treina_modelo() #roda o modelo com toda a memoria da epoca
            sum_rewards_total += sum_rewards
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            print(dias_pos)
            print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        print(dias_pos)
        print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1106 06:35:56.012628  7924 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# resultado da epoca 0 = -53051.82 Epsilon = 1.000
# 89
# 130
# resultado da epoca 1 = -57802.72 Epsilon = 0.999
# 87
# 132
# resultado da epoca 2 = -61353.30 Epsilon = 0.998
# 84
# 135
# resultado da epoca 3 = -41311.62 Epsilon = 0.997
# 94
# 125
# resultado da epoca 4 = -32716.18 Epsilon = 0.996
# 96
# 123
# resultado da epoca 5 = -25894.60 Epsilon = 0.995
# 91
# 128
# resultado da epoca 6 = -67535.20 Epsilon = 0.994
# 85
# 134
# resultado da epoca 7 = -46950.62 Epsilon = 0.993
# 86
# 133
# resultado da epoca 8 = -59766.40 Epsilon = 0.992
# 87
# 132
# resultado da epoca 9 = -57550.26 Epsilon = 0.991
# 83
# 136
# resultado da epoca 10 = -20727.20 Epsilon = 0.990
# 99
# 120
# resultado da epoca 11 = -61422.66 Epsilon = 0.989
# 82
# 137
# resultado da epoca 12 = -53974.78 Epsilon = 0.988
# 88
# 131
# resultado da epoca 13 = -40530.26 Epsilon = 0.987
# 98
# 121
# resultado da epoca 14 = -43147.72 Epsilon = 0.986
# 96
# 123
# resultado da epoca 15 = -37197.26 Epsilon = 0.985
# 103
# 116
# resultado da epoca 16 = -46504.44 Epsilon = 0.984
# 98
# 121
# resultado da epoca 17 = -37785.74 Epsilon = 0.983
# 99
# 120
# resultado da epoca 18 = -30908.74 Epsilon = 0.982
# 90
# 129
# resultado da epoca 19 = -14849.88 Epsilon = 0.981
# 101
# 118
# resultado da epoca 20 = -80910.88 Epsilon = 0.980
# 66
# 153
# resultado da epoca 21 = -28706.90 Epsilon = 0.979
# 105
# 114
# resultado da epoca 22 = -46075.10 Epsilon = 0.978
# 92
# 127
# resultado da epoca 23 = -32610.04 Epsilon = 0.977
# 93
# 126
# resultado da epoca 24 = -43674.06 Epsilon = 0.976
# 97
# 122
# resultado da epoca 25 = -29996.96 Epsilon = 0.975
# 97
# 122
# resultado da epoca 26 = -29167.98 Epsilon = 0.974
# 94
# 125
# resultado da epoca 27 = -20390.34 Epsilon = 0.973
# 101
# 118
# resultado da epoca 28 = -44764.00 Epsilon = 0.972
# 88
# 131
# resultado da epoca 29 = -32442.50 Epsilon = 0.971
# 93
# 126
# resultado da epoca 30 = -71387.22 Epsilon = 0.970
# 81
# 138
# resultado da epoca 31 = -62243.58 Epsilon = 0.969
# 80
# 139
# resultado da epoca 32 = -39709.74 Epsilon = 0.968
# 90
# 129
# resultado da epoca 33 = -56902.44 Epsilon = 0.967
# 80
# 139
# resultado da epoca 34 = -44113.30 Epsilon = 0.966
# 90
# 129
# resultado da epoca 35 = -61476.88 Epsilon = 0.965
# 84
# 135
# resultado da epoca 36 = -47163.48 Epsilon = 0.964
# 92
# 127
# resultado da epoca 37 = -54383.08 Epsilon = 0.963
# 92
# 127
# resultado da epoca 38 = -61051.18 Epsilon = 0.962
# 86
# 133
# resultado da epoca 39 = -22291.16 Epsilon = 0.961
# 98
# 121
# resultado da epoca 40 = -34914.72 Epsilon = 0.960
# 96
# 123
# resultado da epoca 41 = -49927.24 Epsilon = 0.959
# 94
# 125
# resultado da epoca 42 = -35754.64 Epsilon = 0.958
# 96
# 123
# resultado da epoca 43 = -19282.94 Epsilon = 0.957
# 100
# 119
# resultado da epoca 44 = -55724.30 Epsilon = 0.956
# 82
# 137
# resultado da epoca 45 = -80899.20 Epsilon = 0.955
# 76
# 143
# resultado da epoca 46 = -36759.20 Epsilon = 0.954
# 95
# 124
# resultado da epoca 47 = -52982.18 Epsilon = 0.953
# 87
# 132
# resultado da epoca 48 = -25799.68 Epsilon = 0.952
# 100
# 119
# resultado da epoca 49 = -45838.94 Epsilon = 0.951
# 94
# 125
# resultado da epoca 50 = -41288.38 Epsilon = 0.950
# 93
# 126
# resultado da epoca 51 = -47743.12 Epsilon = 0.950
# 80
# 139
# resultado da epoca 52 = -26404.04 Epsilon = 0.949
# 99
# 120
# resultado da epoca 53 = -25620.22 Epsilon = 0.948
# 105
# 114
# resultado da epoca 54 = -25923.88 Epsilon = 0.947
# 98
# 121
# resultado da epoca 55 = -51179.68 Epsilon = 0.946
# 96
# 123
# resultado da epoca 56 = -56168.82 Epsilon = 0.945
# 82
# 137
# resultado da epoca 57 = -28274.30 Epsilon = 0.944
# 100
# 119
# resultado da epoca 58 = -25272.10 Epsilon = 0.943
# 91
# 128
# resultado da epoca 59 = -52801.02 Epsilon = 0.942
# 90
# 129
# resultado da epoca 60 = -40664.58 Epsilon = 0.941
# 98
# 121
# resultado da epoca 61 = -52409.56 Epsilon = 0.940
# 85
# 134
# resultado da epoca 62 = -87759.90 Epsilon = 0.939
# 79
# 140
# resultado da epoca 63 = -50907.54 Epsilon = 0.938
# 88
# 131
# resultado da epoca 64 = -63617.20 Epsilon = 0.937
# 85
# 134
# resultado da epoca 65 = -51547.72 Epsilon = 0.936
# 99
# 120
# resultado da epoca 66 = -61007.52 Epsilon = 0.935
# 86
# 133
# resultado da epoca 67 = -23134.88 Epsilon = 0.934
# 103
# 116
# resultado da epoca 68 = -34591.62 Epsilon = 0.933
# 103
# 116
# resultado da epoca 69 = -13478.64 Epsilon = 0.932
# 94
# 125
# resultado da epoca 70 = -76632.52 Epsilon = 0.931
# 77
# 142
# resultado da epoca 71 = -21860.50 Epsilon = 0.930
# 101
# 118
# resultado da epoca 72 = -27239.52 Epsilon = 0.929
# 100
# 119
# resultado da epoca 73 = -43914.32 Epsilon = 0.928
# 93
# 126
# resultado da epoca 74 = -42243.10 Epsilon = 0.927
# 94
# 125
# resultado da epoca 75 = -71409.62 Epsilon = 0.926
# 83
# 136
# resultado da epoca 76 = -41016.26 Epsilon = 0.925
# 93
# 126
# resultado da epoca 77 = -42757.80 Epsilon = 0.924
# 84
# 135
# resultado da epoca 78 = -29994.16 Epsilon = 0.923
# 93
# 126
# resultado da epoca 79 = -40886.90 Epsilon = 0.922
# 91
# 128
# resultado da epoca 80 = -45906.02 Epsilon = 0.921
# 99
# 120
# resultado da epoca 81 = -40080.58 Epsilon = 0.920
# 93
# 126
# resultado da epoca 82 = -50925.54 Epsilon = 0.919
# 94
# 125
# resultado da epoca 83 = -27702.46 Epsilon = 0.918
# 103
# 116
# resultado da epoca 84 = -32548.86 Epsilon = 0.917
# 103
# 116
# resultado da epoca 85 = -34642.10 Epsilon = 0.916
# 95
# 124
# resultado da epoca 86 = -35903.38 Epsilon = 0.915
# 95
# 124
# resultado da epoca 87 = -52158.02 Epsilon = 0.914
# 84
# 135
# resultado da epoca 88 = -47449.52 Epsilon = 0.913
# 95
# 124
# resultado da epoca 89 = -49380.66 Epsilon = 0.912
# 83
# 136
# resultado da epoca 90 = -26869.80 Epsilon = 0.911
# 96
# 123
# resultado da epoca 91 = -32296.44 Epsilon = 0.910
# 96
# 123
# resultado da epoca 92 = -46560.44 Epsilon = 0.909
# 95
# 124
# resultado da epoca 93 = -20165.24 Epsilon = 0.908
# 96
# 123
# resultado da epoca 94 = -26136.38 Epsilon = 0.907
# 93
# 126
# resultado da epoca 95 = -69704.98 Epsilon = 0.906
# 75
# 144
# resultado da epoca 96 = -63002.76 Epsilon = 0.905
# 76
# 143
# resultado da epoca 97 = -52900.18 Epsilon = 0.904
# 86
# 133
# resultado da epoca 98 = -41918.16 Epsilon = 0.903
# 94
# 125
# resultado da epoca 99 = -44477.06 Epsilon = 0.902
# 93
# 126
# resultado da epoca 100 = -31228.76 Epsilon = 0.901
# 94
# 125
# resultado da epoca 101 = -30246.40 Epsilon = 0.900
# 99
# 120
# resultado da epoca 102 = -24957.02 Epsilon = 0.899
# 91
# 128
# resultado da epoca 103 = -36225.06 Epsilon = 0.898
# 102
# 117
# resultado da epoca 104 = -19997.86 Epsilon = 0.897
# 102
# 117
# resultado da epoca 105 = -42102.62 Epsilon = 0.896
# 96
# 123
# resultado da epoca 106 = -22015.02 Epsilon = 0.895
# 97
# 122
# resultado da epoca 107 = -66558.10 Epsilon = 0.894
# 80
# 139
# resultado da epoca 108 = -38589.76 Epsilon = 0.893
# 94
# 125
# resultado da epoca 109 = -38723.46 Epsilon = 0.892
# 79
# 140
# resultado da epoca 110 = -43101.00 Epsilon = 0.891
# 91
# 128
# resultado da epoca 111 = -29305.62 Epsilon = 0.890
# 103
# 116
# resultado da epoca 112 = -49291.92 Epsilon = 0.889
# 90
# 129
# resultado da epoca 113 = -247.68 Epsilon = 0.888
# 104
# 115
# resultado da epoca 114 = -39027.74 Epsilon = 0.887
# 97
# 122
# resultado da epoca 115 = -25544.88 Epsilon = 0.886
# 100
# 119
# resultado da epoca 116 = -51552.34 Epsilon = 0.885
# 88
# 131
# resultado da epoca 117 = -36405.80 Epsilon = 0.884
# 95
# 124
# resultado da epoca 118 = -51022.74 Epsilon = 0.883
# 88
# 131
# resultado da epoca 119 = -23034.28 Epsilon = 0.882
# 103
# 116
# resultado da epoca 120 = -29697.14 Epsilon = 0.881
# 100
# 119
# resultado da epoca 121 = -33430.92 Epsilon = 0.880
# 92
# 127
# resultado da epoca 122 = -37360.96 Epsilon = 0.879
# 102
# 117
# resultado da epoca 123 = -49795.10 Epsilon = 0.878
# 83
# 136
# resultado da epoca 124 = -10335.76 Epsilon = 0.877
# 111
# 108
# resultado da epoca 125 = -22373.36 Epsilon = 0.876
# 101
# 118
# resultado da epoca 126 = -56912.74 Epsilon = 0.875
# 93
# 126
# resultado da epoca 127 = -52068.26 Epsilon = 0.874
# 85
# 134
# resultado da epoca 128 = -48324.46 Epsilon = 0.873
# 82
# 137
# resultado da epoca 129 = -43528.90 Epsilon = 0.872
# 95
# 124
# resultado da epoca 130 = -40274.68 Epsilon = 0.871
# 84
# 135
# resultado da epoca 131 = -24199.34 Epsilon = 0.870
# 99
# 120
# resultado da epoca 132 = -22227.12 Epsilon = 0.869
# 99
# 120
# resultado da epoca 133 = -16754.80 Epsilon = 0.868
# 101
# 118
# resultado da epoca 134 = -12585.54 Epsilon = 0.867
# 105
# 114
# resultado da epoca 135 = -50511.50 Epsilon = 0.866
# 85
# 134
# resultado da epoca 136 = -47599.76 Epsilon = 0.865
# 83
# 136
# resultado da epoca 137 = -37901.70 Epsilon = 0.864
# 95
# 124
# resultado da epoca 138 = -43819.96 Epsilon = 0.863
# 95
# 124
# resultado da epoca 139 = -32403.12 Epsilon = 0.862
# 98
# 121
# resultado da epoca 140 = -67901.54 Epsilon = 0.861
# 82
# 137
# resultado da epoca 141 = -29345.14 Epsilon = 0.860
# 95
# 124
# resultado da epoca 142 = -52554.72 Epsilon = 0.859
# 85
# 134
# resultado da epoca 143 = -48166.14 Epsilon = 0.858
# 92
# 127
# resultado da epoca 144 = -40078.66 Epsilon = 0.857
# 91
# 128
# resultado da epoca 145 = -35325.26 Epsilon = 0.856
# 86
# 133
# resultado da epoca 146 = -64831.28 Epsilon = 0.855
# 78
# 141
# resultado da epoca 147 = -42982.32 Epsilon = 0.854
# 91
# 128
# resultado da epoca 148 = -46530.92 Epsilon = 0.853
# 92
# 127
# resultado da epoca 149 = -37789.32 Epsilon = 0.852
# 92
# 127
# resultado da epoca 150 = -31117.46 Epsilon = 0.851
# 91
# 128
# resultado da epoca 151 = -72414.24 Epsilon = 0.851
# 84
# 135
# resultado da epoca 152 = -38788.74 Epsilon = 0.850
# 91
# 128
# resultado da epoca 153 = -39510.44 Epsilon = 0.849
# 99
# 120
# resultado da epoca 154 = -35779.14 Epsilon = 0.848
# 105
# 114
# resultado da epoca 155 = -31716.48 Epsilon = 0.847
# 98
# 121
# resultado da epoca 156 = -57751.12 Epsilon = 0.846
# 74
# 145
# resultado da epoca 157 = -62560.78 Epsilon = 0.845
# 89
# 130
# resultado da epoca 158 = -60211.86 Epsilon = 0.844
# 84
# 135
# resultado da epoca 159 = -65780.14 Epsilon = 0.843
# 86
# 133
# resultado da epoca 160 = -44611.98 Epsilon = 0.842
# 86
# 133
# resultado da epoca 161 = -57926.00 Epsilon = 0.841
# 85
# 134
# resultado da epoca 162 = -39395.42 Epsilon = 0.840
# 90
# 129
# resultado da epoca 163 = -44780.62 Epsilon = 0.839
# 96
# 123
# resultado da epoca 164 = -40378.12 Epsilon = 0.838
# 87
# 132
# resultado da epoca 165 = -37268.06 Epsilon = 0.837
# 97
# 122
# resultado da epoca 166 = -34552.56 Epsilon = 0.836
# 92
# 127
# resultado da epoca 167 = -58299.74 Epsilon = 0.835
# 90
# 129
# resultado da epoca 168 = -58091.54 Epsilon = 0.834
# 84
# 135
# resultado da epoca 169 = -33283.02 Epsilon = 0.833
# 95
# 124
# resultado da epoca 170 = -6478.58 Epsilon = 0.832
# 106
# 113
# resultado da epoca 171 = -31248.54 Epsilon = 0.831
# 92
# 127
# resultado da epoca 172 = -24940.62 Epsilon = 0.830
# 106
# 113
# resultado da epoca 173 = -36451.12 Epsilon = 0.829
# 93
# 126
# resultado da epoca 174 = -50617.94 Epsilon = 0.828
# 89
# 130
# resultado da epoca 175 = -53009.84 Epsilon = 0.827
# 93
# 126
# resultado da epoca 176 = -26632.56 Epsilon = 0.826
# 95
# 124
# resultado da epoca 177 = -9222.36 Epsilon = 0.825
# 110
# 109
# resultado da epoca 178 = -30966.66 Epsilon = 0.824
# 99
# 120
# resultado da epoca 179 = -54108.58 Epsilon = 0.823
# 80
# 139
# resultado da epoca 180 = -54190.66 Epsilon = 0.822
# 92
# 127
# resultado da epoca 181 = -60971.12 Epsilon = 0.821
# 87
# 132
# resultado da epoca 182 = -62792.54 Epsilon = 0.820
# 84
# 135
# resultado da epoca 183 = -61608.12 Epsilon = 0.819
# 82
# 137
# resultado da epoca 184 = -46455.74 Epsilon = 0.818
# 91
# 128
# resultado da epoca 185 = -58201.04 Epsilon = 0.817
# 88
# 131
# resultado da epoca 186 = -35328.38 Epsilon = 0.816
# 96
# 123
# resultado da epoca 187 = -37817.46 Epsilon = 0.815
# 95
# 124
# resultado da epoca 188 = -37472.86 Epsilon = 0.814
# 82
# 137
# resultado da epoca 189 = -25427.70 Epsilon = 0.813
# 93
# 126
# resultado da epoca 190 = -7203.92 Epsilon = 0.812
# 100
# 119
# resultado da epoca 191 = -57950.64 Epsilon = 0.811
# 86
# 133
# resultado da epoca 192 = -42188.44 Epsilon = 0.810
# 91
# 128
# resultado da epoca 193 = -35559.94 Epsilon = 0.809
# 97
# 122
# resultado da epoca 194 = -39845.48 Epsilon = 0.808
# 96
# 123
# resultado da epoca 195 = -24535.14 Epsilon = 0.807
# 103
# 116
# resultado da epoca 196 = -41193.80 Epsilon = 0.806
# 90
# 129
# resultado da epoca 197 = -39412.60 Epsilon = 0.805
# 91
# 128
# resultado da epoca 198 = -60813.14 Epsilon = 0.804
# 84
# 135
# resultado da epoca 199 = -47224.32 Epsilon = 0.803
# 97
# 122
# resultado da epoca 200 = -30793.64 Epsilon = 0.802
# 101
# 118
# resultado da epoca 201 = -49397.46 Epsilon = 0.801
# 87
# 132
# resultado da epoca 202 = -57210.68 Epsilon = 0.800
# 91
# 128
# resultado da epoca 203 = -49034.14 Epsilon = 0.799
# 87
# 132
# resultado da epoca 204 = -24189.88 Epsilon = 0.798
# 103
# 116
# resultado da epoca 205 = -63795.66 Epsilon = 0.797
# 82
# 137
# resultado da epoca 206 = 5874.08 Epsilon = 0.796
# 104
# 115
# resultado da epoca 207 = -33795.04 Epsilon = 0.795
# 98
# 121
# resultado da epoca 208 = -53506.84 Epsilon = 0.794
# 94
# 125
# resultado da epoca 209 = -38878.12 Epsilon = 0.793
# 91
# 128
# resultado da epoca 210 = -52698.40 Epsilon = 0.792
# 91
# 128
# resultado da epoca 211 = -44462.18 Epsilon = 0.791
# 97
# 122
# resultado da epoca 212 = -33345.06 Epsilon = 0.790
# 91
# 128
# resultado da epoca 213 = -65052.54 Epsilon = 0.789
# 89
# 130
# resultado da epoca 214 = -45185.54 Epsilon = 0.788
# 97
# 122
# resultado da epoca 215 = -28069.84 Epsilon = 0.787
# 109
# 110
# resultado da epoca 216 = -66247.66 Epsilon = 0.786
# 78
# 141
# resultado da epoca 217 = -61441.64 Epsilon = 0.785
# 82
# 137
# resultado da epoca 218 = -55978.46 Epsilon = 0.784
# 92
# 127
# resultado da epoca 219 = -34568.40 Epsilon = 0.783
# 95
# 124
# resultado da epoca 220 = -57271.40 Epsilon = 0.782
# 80
# 139
# resultado da epoca 221 = -45070.68 Epsilon = 0.781
# 90
# 129
# resultado da epoca 222 = -31252.56 Epsilon = 0.780
# 89
# 130
# resultado da epoca 223 = -32555.08 Epsilon = 0.779
# 99
# 120
# resultado da epoca 224 = -34524.38 Epsilon = 0.778
# 88
# 131
# resultado da epoca 225 = -59370.28 Epsilon = 0.777
# 84
# 135
# resultado da epoca 226 = -43524.62 Epsilon = 0.776
# 98
# 121
# resultado da epoca 227 = -34270.96 Epsilon = 0.775
# 90
# 129
# resultado da epoca 228 = -85035.88 Epsilon = 0.774
# 79
# 140
# resultado da epoca 229 = -16733.34 Epsilon = 0.773
# 104
# 115
# resultado da epoca 230 = -32975.52 Epsilon = 0.772
# 97
# 122
# resultado da epoca 231 = -67912.78 Epsilon = 0.771
# 84
# 135
# resultado da epoca 232 = -54187.18 Epsilon = 0.770
# 98
# 121
# resultado da epoca 233 = -42607.52 Epsilon = 0.769
# 95
# 124
# resultado da epoca 234 = -36351.50 Epsilon = 0.768
# 99
# 120
# resultado da epoca 235 = -64591.82 Epsilon = 0.767
# 84
# 135
# resultado da epoca 236 = -48360.02 Epsilon = 0.766
# 85
# 134
# resultado da epoca 237 = -55810.32 Epsilon = 0.765
# 85
# 134
# resultado da epoca 238 = -41272.72 Epsilon = 0.764
# 89
# 130
# resultado da epoca 239 = -40679.92 Epsilon = 0.763
# 95
# 124
# resultado da epoca 240 = -49356.48 Epsilon = 0.762
# 90
# 129
# resultado da epoca 241 = -58776.72 Epsilon = 0.761
# 88
# 131
# resultado da epoca 242 = -56554.00 Epsilon = 0.760
# 85
# 134
# resultado da epoca 243 = -49048.64 Epsilon = 0.759
# 84
# 135
# resultado da epoca 244 = -29938.40 Epsilon = 0.758
# 102
# 117
# resultado da epoca 245 = -31737.48 Epsilon = 0.757
# 93
# 126
# resultado da epoca 246 = -43910.82 Epsilon = 0.756
# 89
# 130
# resultado da epoca 247 = -38566.00 Epsilon = 0.755
# 99
# 120
# resultado da epoca 248 = -58924.82 Epsilon = 0.754
# 87
# 132
# resultado da epoca 249 = -36337.10 Epsilon = 0.753
# 95
# 124
# resultado da epoca 250 = -33975.72 Epsilon = 0.752
# 94
# 125
# resultado da epoca 251 = -33063.22 Epsilon = 0.752
# 94
# 125
# resultado da epoca 252 = -74271.86 Epsilon = 0.751
# 80
# 139
# resultado da epoca 253 = -60907.82 Epsilon = 0.750
# 92
# 127
# resultado da epoca 254 = -53519.78 Epsilon = 0.749
# 95
# 124
# resultado da epoca 255 = -65133.90 Epsilon = 0.748
# 83
# 136
# resultado da epoca 256 = -36175.66 Epsilon = 0.747
# 92
# 127
# resultado da epoca 257 = -20625.02 Epsilon = 0.746
# 103
# 116
# resultado da epoca 258 = -39824.04 Epsilon = 0.745
# 87
# 132
# resultado da epoca 259 = -81776.14 Epsilon = 0.744
# 80
# 139
# resultado da epoca 260 = -71801.82 Epsilon = 0.743
# 81
# 138
# resultado da epoca 261 = -39046.82 Epsilon = 0.742
# 94
# 125
# resultado da epoca 262 = -23913.92 Epsilon = 0.741
# 94
# 125
# resultado da epoca 263 = -25385.18 Epsilon = 0.740
# 96
# 123
# resultado da epoca 264 = -55372.06 Epsilon = 0.739
# 96
# 123
# resultado da epoca 265 = -20599.54 Epsilon = 0.738
# 91
# 128
# resultado da epoca 266 = -82893.12 Epsilon = 0.737
# 78
# 141
# resultado da epoca 267 = -58540.30 Epsilon = 0.736
# 87
# 132
# resultado da epoca 268 = -53484.38 Epsilon = 0.735
# 94
# 125
# resultado da epoca 269 = -44049.70 Epsilon = 0.734
# 89
# 130
# resultado da epoca 270 = -61602.04 Epsilon = 0.733
# 85
# 134
# resultado da epoca 271 = -45433.64 Epsilon = 0.732
# 89
# 130
# resultado da epoca 272 = -55450.94 Epsilon = 0.731
# 84
# 135
# resultado da epoca 273 = -54681.56 Epsilon = 0.730
# 83
# 136
# resultado da epoca 274 = -39983.34 Epsilon = 0.729
# 90
# 129
# resultado da epoca 275 = -64265.90 Epsilon = 0.728
# 74
# 145
# resultado da epoca 276 = -45134.66 Epsilon = 0.727
# 83
# 136
# resultado da epoca 277 = -36040.90 Epsilon = 0.726
# 89
# 130
# resultado da epoca 278 = -62504.06 Epsilon = 0.725
# 89
# 130
# resultado da epoca 279 = -43896.30 Epsilon = 0.724
# 88
# 131
# resultado da epoca 280 = -34511.54 Epsilon = 0.723
# 96
# 123
# resultado da epoca 281 = -47853.22 Epsilon = 0.722
# 93
# 126
# resultado da epoca 282 = -27011.18 Epsilon = 0.721
# 93
# 126
# resultado da epoca 283 = -31965.16 Epsilon = 0.720
# 93
# 126
# resultado da epoca 284 = -47934.28 Epsilon = 0.719
# 90
# 129
# resultado da epoca 285 = -14457.86 Epsilon = 0.718
# 112
# 107
# resultado da epoca 286 = -10024.52 Epsilon = 0.717
# 93
# 126
# resultado da epoca 287 = -43102.70 Epsilon = 0.716
# 94
# 125
# resultado da epoca 288 = -30992.90 Epsilon = 0.715
# 99
# 120
# resultado da epoca 289 = -44988.48 Epsilon = 0.714
# 93
# 126
# resultado da epoca 290 = -60732.86 Epsilon = 0.713
# 89
# 130
# resultado da epoca 291 = -40388.64 Epsilon = 0.712
# 83
# 136
# resultado da epoca 292 = -45704.46 Epsilon = 0.711
# 88
# 131
# resultado da epoca 293 = -26803.58 Epsilon = 0.710
# 102
# 117
# resultado da epoca 294 = -53635.76 Epsilon = 0.709
# 87
# 132
# resultado da epoca 295 = -53642.42 Epsilon = 0.708
# 85
# 134
# resultado da epoca 296 = -33760.42 Epsilon = 0.707
# 99
# 120
# resultado da epoca 297 = -50029.74 Epsilon = 0.706
# 88
# 131
# resultado da epoca 298 = -69689.36 Epsilon = 0.705
# 89
# 130
# resultado da epoca 299 = -48870.20 Epsilon = 0.704
# 91
# 128
# resultado da epoca 300 = -30416.72 Epsilon = 0.703
# 96
# 123
# resultado da epoca 301 = -37873.00 Epsilon = 0.702
# 100
# 119
# resultado da epoca 302 = -54288.98 Epsilon = 0.701
# 90
# 129
# resultado da epoca 303 = -35942.60 Epsilon = 0.700
# 97
# 122
# resultado da epoca 304 = -68183.36 Epsilon = 0.699
# 84
# 135
# resultado da epoca 305 = -64507.04 Epsilon = 0.698
# 85
# 134
# resultado da epoca 306 = -45934.22 Epsilon = 0.697
# 98
# 121
# resultado da epoca 307 = -27512.22 Epsilon = 0.696
# 101
# 118
# resultado da epoca 308 = -29069.62 Epsilon = 0.695
# 95
# 124
# resultado da epoca 309 = -26802.46 Epsilon = 0.694
# 99
# 120
# resultado da epoca 310 = -49785.14 Epsilon = 0.693
# 85
# 134
# resultado da epoca 311 = -22809.42 Epsilon = 0.692
# 89
# 130
# resultado da epoca 312 = -35767.18 Epsilon = 0.691
# 88
# 131
# resultado da epoca 313 = -8576.54 Epsilon = 0.690
# 109
# 110
# resultado da epoca 314 = -47231.00 Epsilon = 0.689
# 92
# 127
# resultado da epoca 315 = -34336.58 Epsilon = 0.688
# 101
# 118
# resultado da epoca 316 = -40752.12 Epsilon = 0.687
# 89
# 130
# resultado da epoca 317 = -11143.46 Epsilon = 0.686
# 106
# 113
# resultado da epoca 318 = -30500.66 Epsilon = 0.685
# 102
# 117
# resultado da epoca 319 = -39209.72 Epsilon = 0.684
# 95
# 124
# resultado da epoca 320 = -28534.90 Epsilon = 0.683
# 99
# 120
# resultado da epoca 321 = -39301.82 Epsilon = 0.682
# 93
# 126
# resultado da epoca 322 = -41801.34 Epsilon = 0.681
# 93
# 126
# resultado da epoca 323 = -61955.92 Epsilon = 0.680
# 85
# 134
# resultado da epoca 324 = -34166.70 Epsilon = 0.679
# 98
# 121
# resultado da epoca 325 = -53614.08 Epsilon = 0.678
# 86
# 133
# resultado da epoca 326 = -31911.78 Epsilon = 0.677
# 100
# 119
# resultado da epoca 327 = -59850.98 Epsilon = 0.676
# 83
# 136
# resultado da epoca 328 = -34714.86 Epsilon = 0.675
# 88
# 131
# resultado da epoca 329 = -29600.54 Epsilon = 0.674
# 97
# 122
# resultado da epoca 330 = -13250.74 Epsilon = 0.673
# 90
# 129
# resultado da epoca 331 = -48059.18 Epsilon = 0.672
# 91
# 128
# resultado da epoca 332 = -24012.04 Epsilon = 0.671
# 98
# 121
# resultado da epoca 333 = -49645.62 Epsilon = 0.670
# 85
# 134
# resultado da epoca 334 = -40333.16 Epsilon = 0.669
# 87
# 132
# resultado da epoca 335 = -48292.46 Epsilon = 0.668
# 91
# 128
# resultado da epoca 336 = -69569.64 Epsilon = 0.667
# 82
# 137
# resultado da epoca 337 = -16320.60 Epsilon = 0.666
# 110
# 109
# resultado da epoca 338 = -45432.52 Epsilon = 0.665
# 95
# 124
# resultado da epoca 339 = -42528.32 Epsilon = 0.664
# 91
# 128
# resultado da epoca 340 = -28107.84 Epsilon = 0.663
# 95
# 124
# resultado da epoca 341 = -53429.86 Epsilon = 0.662
# 84
# 135
# resultado da epoca 342 = -22727.34 Epsilon = 0.661
# 109
# 110
# resultado da epoca 343 = -38489.22 Epsilon = 0.660
# 90
# 129
# resultado da epoca 344 = -52011.88 Epsilon = 0.659
# 87
# 132
# resultado da epoca 345 = -55183.10 Epsilon = 0.658
# 92
# 127
# resultado da epoca 346 = -31696.10 Epsilon = 0.657
# 94
# 125
# resultado da epoca 347 = -34238.18 Epsilon = 0.656
# 97
# 122
# resultado da epoca 348 = -29689.88 Epsilon = 0.655
# 98
# 121
# resultado da epoca 349 = -28061.02 Epsilon = 0.654
# 97
# 122
# resultado da epoca 350 = -22131.28 Epsilon = 0.653
# 96
# 123
# resultado da epoca 351 = -55955.74 Epsilon = 0.653
# 82
# 137
# resultado da epoca 352 = -78348.08 Epsilon = 0.652
# 73
# 146
# resultado da epoca 353 = -37755.36 Epsilon = 0.651
# 95
# 124
# resultado da epoca 354 = -53975.84 Epsilon = 0.650
# 92
# 127
# resultado da epoca 355 = -79067.30 Epsilon = 0.649
# 74
# 145
# resultado da epoca 356 = -62164.42 Epsilon = 0.648
# 81
# 138
# resultado da epoca 357 = -45292.56 Epsilon = 0.647
# 91
# 128
# resultado da epoca 358 = -31964.18 Epsilon = 0.646
# 94
# 125
# resultado da epoca 359 = -83797.36 Epsilon = 0.645
# 78
# 141
# resultado da epoca 360 = -51917.76 Epsilon = 0.644
# 92
# 127
# resultado da epoca 361 = -48545.76 Epsilon = 0.643
# 92
# 127
# resultado da epoca 362 = -42483.18 Epsilon = 0.642
# 91
# 128
# resultado da epoca 363 = -61219.44 Epsilon = 0.641
# 87
# 132
# resultado da epoca 364 = -39277.26 Epsilon = 0.640
# 103
# 116
# resultado da epoca 365 = -40653.38 Epsilon = 0.639
# 85
# 134
# resultado da epoca 366 = -36667.78 Epsilon = 0.638
# 89
# 130
# resultado da epoca 367 = -32268.96 Epsilon = 0.637
# 107
# 112
# resultado da epoca 368 = -28114.64 Epsilon = 0.636
# 99
# 120
# resultado da epoca 369 = -43406.60 Epsilon = 0.635
# 102
# 117
# resultado da epoca 370 = -58639.04 Epsilon = 0.634
# 85
# 134
# resultado da epoca 371 = -9233.68 Epsilon = 0.633
# 109
# 110
# resultado da epoca 372 = -25946.32 Epsilon = 0.632
# 105
# 114
# resultado da epoca 373 = -36203.22 Epsilon = 0.631
# 86
# 133
# resultado da epoca 374 = -54109.72 Epsilon = 0.630
# 88
# 131
# resultado da epoca 375 = -37787.56 Epsilon = 0.629
# 93
# 126
# resultado da epoca 376 = -33785.34 Epsilon = 0.628
# 91
# 128
# resultado da epoca 377 = -61491.42 Epsilon = 0.627
# 86
# 133
# resultado da epoca 378 = -50198.18 Epsilon = 0.626
# 80
# 139
# resultado da epoca 379 = -53554.74 Epsilon = 0.625
# 80
# 139
# resultado da epoca 380 = -57611.60 Epsilon = 0.624
# 90
# 129
# resultado da epoca 381 = -37929.16 Epsilon = 0.623
# 95
# 124
# resultado da epoca 382 = -44884.36 Epsilon = 0.622
# 85
# 134
# resultado da epoca 383 = -49059.44 Epsilon = 0.621
# 91
# 128
# resultado da epoca 384 = -30947.54 Epsilon = 0.620
# 104
# 115
# resultado da epoca 385 = -44317.60 Epsilon = 0.619
# 89
# 130
# resultado da epoca 386 = -28830.14 Epsilon = 0.618
# 96
# 123
# resultado da epoca 387 = -54965.00 Epsilon = 0.617
# 103
# 116
# resultado da epoca 388 = -44729.18 Epsilon = 0.616
# 84
# 135
# resultado da epoca 389 = -38239.38 Epsilon = 0.615
# 90
# 129
# resultado da epoca 390 = -28809.48 Epsilon = 0.614
# 108
# 111
# resultado da epoca 391 = 2357.54 Epsilon = 0.613
# 113
# 106
# resultado da epoca 392 = -32817.90 Epsilon = 0.612
# 96
# 123
# resultado da epoca 393 = -40365.26 Epsilon = 0.611
# 95
# 124
# resultado da epoca 394 = -51020.88 Epsilon = 0.610
# 97
# 122
# resultado da epoca 395 = -35398.62 Epsilon = 0.609
# 96
# 123
# resultado da epoca 396 = -32303.92 Epsilon = 0.608
# 96
# 123
# resultado da epoca 397 = -42337.98 Epsilon = 0.607
# 106
# 113
# resultado da epoca 398 = -16620.66 Epsilon = 0.606
# 93
# 126
# resultado da epoca 399 = -51277.36 Epsilon = 0.605
# 94
# 125
# resultado da epoca 400 = -16487.26 Epsilon = 0.604
# 108
# 111
# resultado da epoca 401 = -48864.98 Epsilon = 0.603
# 83
# 136
# resultado da epoca 402 = -35026.74 Epsilon = 0.602
# 101
# 118
# resultado da epoca 403 = -43436.68 Epsilon = 0.601
# 87
# 132
# resultado da epoca 404 = -21541.36 Epsilon = 0.600
# 94
# 125
# resultado da epoca 405 = -42177.76 Epsilon = 0.599
# 82
# 137
# resultado da epoca 406 = -39966.38 Epsilon = 0.598
# 102
# 117
# resultado da epoca 407 = -24914.16 Epsilon = 0.597
# 100
# 119
# resultado da epoca 408 = -15367.92 Epsilon = 0.596
# 104
# 115
# resultado da epoca 409 = -61002.02 Epsilon = 0.595
# 88
# 131
# resultado da epoca 410 = -54131.38 Epsilon = 0.594
# 87
# 132
# resultado da epoca 411 = -41496.14 Epsilon = 0.593
# 88
# 131
# resultado da epoca 412 = -40176.14 Epsilon = 0.592
# 88
# 131
# resultado da epoca 413 = -22610.06 Epsilon = 0.591
# 107
# 112
# resultado da epoca 414 = -59017.58 Epsilon = 0.590
# 92
# 127
# resultado da epoca 415 = -78797.48 Epsilon = 0.589
# 86
# 133
# resultado da epoca 416 = -21419.40 Epsilon = 0.588
# 104
# 115
# resultado da epoca 417 = -57898.76 Epsilon = 0.587
# 89
# 130
# resultado da epoca 418 = -46922.20 Epsilon = 0.586
# 100
# 119
# resultado da epoca 419 = -64315.10 Epsilon = 0.585
# 85
# 134
# resultado da epoca 420 = -45551.76 Epsilon = 0.584
# 91
# 128
# resultado da epoca 421 = -27436.72 Epsilon = 0.583
# 99
# 120
# resultado da epoca 422 = -50094.80 Epsilon = 0.582
# 89
# 130
# resultado da epoca 423 = -55778.20 Epsilon = 0.581
# 98
# 121
# resultado da epoca 424 = -72328.36 Epsilon = 0.580
# 80
# 139
# resultado da epoca 425 = -36555.20 Epsilon = 0.579
# 98
# 121
# resultado da epoca 426 = -46431.62 Epsilon = 0.578
# 93
# 126
# resultado da epoca 427 = -39375.28 Epsilon = 0.577
# 95
# 124
# resultado da epoca 428 = -8984.64 Epsilon = 0.576
# 103
# 116
# resultado da epoca 429 = -18810.04 Epsilon = 0.575
# 102
# 117
# resultado da epoca 430 = -58708.34 Epsilon = 0.574
# 88
# 131
# resultado da epoca 431 = -50180.64 Epsilon = 0.573
# 96
# 123
# resultado da epoca 432 = -19083.66 Epsilon = 0.572
# 104
# 115
# resultado da epoca 433 = -39315.50 Epsilon = 0.571
# 87
# 132
# resultado da epoca 434 = -35091.30 Epsilon = 0.570
# 97
# 122
# resultado da epoca 435 = -42536.00 Epsilon = 0.569
# 100
# 119
# resultado da epoca 436 = -18539.94 Epsilon = 0.568
# 108
# 111
# resultado da epoca 437 = -30378.42 Epsilon = 0.567
# 95
# 124
# resultado da epoca 438 = -18335.38 Epsilon = 0.566
# 99
# 120
# resultado da epoca 439 = 4392.80 Epsilon = 0.565
# 108
# 111
# resultado da epoca 440 = -37407.04 Epsilon = 0.564
# 97
# 122
# resultado da epoca 441 = -42563.02 Epsilon = 0.563
# 94
# 125
# resultado da epoca 442 = -31302.98 Epsilon = 0.562
# 102
# 117
# resultado da epoca 443 = -47258.58 Epsilon = 0.561
# 88
# 131
# resultado da epoca 444 = -7793.92 Epsilon = 0.560
# 101
# 118
# resultado da epoca 445 = -30033.40 Epsilon = 0.559
# 104
# 115
# resultado da epoca 446 = -38449.52 Epsilon = 0.558
# 93
# 126
# resultado da epoca 447 = -46430.98 Epsilon = 0.557
# 87
# 132
# resultado da epoca 448 = -27656.10 Epsilon = 0.556
# 95
# 124
# resultado da epoca 449 = -59708.22 Epsilon = 0.555
# 79
# 140
# resultado da epoca 450 = -69152.64 Epsilon = 0.554
# 84
# 135
# resultado da epoca 451 = -15160.28 Epsilon = 0.554
# 108
# 111
# resultado da epoca 452 = -17753.16 Epsilon = 0.553
# 106
# 113
# resultado da epoca 453 = -61307.90 Epsilon = 0.552
# 79
# 140
# resultado da epoca 454 = -30567.78 Epsilon = 0.551
# 98
# 121
# resultado da epoca 455 = -58006.80 Epsilon = 0.550
# 76
# 143
# resultado da epoca 456 = -55467.18 Epsilon = 0.549
# 93
# 126
# resultado da epoca 457 = 6119.90 Epsilon = 0.548
# 107
# 112
# resultado da epoca 458 = -29003.08 Epsilon = 0.547
# 100
# 119
# resultado da epoca 459 = -37979.18 Epsilon = 0.546
# 95
# 124
# resultado da epoca 460 = -23116.02 Epsilon = 0.545
# 93
# 126
# resultado da epoca 461 = -72173.82 Epsilon = 0.544
# 95
# 124
# resultado da epoca 462 = -61044.46 Epsilon = 0.543
# 84
# 135
# resultado da epoca 463 = -86680.62 Epsilon = 0.542
# 77
# 142
# resultado da epoca 464 = -49056.12 Epsilon = 0.541
# 83
# 136
# resultado da epoca 465 = -4685.76 Epsilon = 0.540
# 107
# 112
# resultado da epoca 466 = -51759.82 Epsilon = 0.539
# 93
# 126
# resultado da epoca 467 = -46866.14 Epsilon = 0.538
# 90
# 129
# resultado da epoca 468 = -16206.92 Epsilon = 0.537
# 109
# 110
# resultado da epoca 469 = -71707.04 Epsilon = 0.536
# 85
# 134
# resultado da epoca 470 = -53807.70 Epsilon = 0.535
# 97
# 122
# resultado da epoca 471 = -35026.02 Epsilon = 0.534
# 100
# 119
# resultado da epoca 472 = -16001.32 Epsilon = 0.533
# 99
# 120
# resultado da epoca 473 = -62788.06 Epsilon = 0.532
# 95
# 124
# resultado da epoca 474 = -37533.06 Epsilon = 0.531
# 106
# 113
# resultado da epoca 475 = -61679.02 Epsilon = 0.530
# 104
# 115
# resultado da epoca 476 = -41905.16 Epsilon = 0.529
# 100
# 119
# resultado da epoca 477 = -25433.10 Epsilon = 0.528
# 100
# 119
# resultado da epoca 478 = 15339.50 Epsilon = 0.527
# 111
# 108
# resultado da epoca 479 = -27624.22 Epsilon = 0.526
# 105
# 114
# resultado da epoca 480 = -52044.68 Epsilon = 0.525
# 81
# 138
# resultado da epoca 481 = -31141.52 Epsilon = 0.524
# 98
# 121
# resultado da epoca 482 = -74942.56 Epsilon = 0.523
# 78
# 141
# resultado da epoca 483 = -56585.52 Epsilon = 0.522
# 88
# 131
# resultado da epoca 484 = -68929.82 Epsilon = 0.521
# 85
# 134
# resultado da epoca 485 = -22355.72 Epsilon = 0.520
# 111
# 108
# resultado da epoca 486 = -46259.72 Epsilon = 0.519
# 93
# 126
# resultado da epoca 487 = -27676.02 Epsilon = 0.518
# 99
# 120
# resultado da epoca 488 = -53743.26 Epsilon = 0.517
# 90
# 129
# resultado da epoca 489 = -47371.66 Epsilon = 0.516
# 93
# 126
# resultado da epoca 490 = -38508.38 Epsilon = 0.515
# 96
# 123
# resultado da epoca 491 = -53917.08 Epsilon = 0.514
# 95
# 124
# resultado da epoca 492 = -62156.60 Epsilon = 0.513
# 92
# 127
# resultado da epoca 493 = -29669.48 Epsilon = 0.512
# 100
# 119
# resultado da epoca 494 = -55762.22 Epsilon = 0.511
# 100
# 119
# resultado da epoca 495 = -42819.20 Epsilon = 0.510
# 90
# 129
# resultado da epoca 496 = -33730.34 Epsilon = 0.509
# 98
# 121
# resultado da epoca 497 = -48185.50 Epsilon = 0.508
# 96
# 123
# resultado da epoca 498 = -14704.46 Epsilon = 0.507
# 103
# 116
# resultado da epoca 499 = -32977.68 Epsilon = 0.506
# 99
# 120
# resultado da epoca 500 = -54920.46 Epsilon = 0.505
# 95
# 124
# resultado da epoca 501 = -27808.10 Epsilon = 0.504
# 101
# 118
# resultado da epoca 502 = -38937.38 Epsilon = 0.503
# 95
# 124
# resultado da epoca 503 = -29759.16 Epsilon = 0.502
# 100
# 119
# resultado da epoca 504 = -80572.50 Epsilon = 0.501
# 82
# 137
# resultado da epoca 505 = -44030.14 Epsilon = 0.500
# 98
# 121
# resultado da epoca 506 = -58812.14 Epsilon = 0.499
# 85
# 134
# resultado da epoca 507 = -55256.48 Epsilon = 0.498
# 92
# 127
# resultado da epoca 508 = -51477.08 Epsilon = 0.497
# 91
# 128
# resultado da epoca 509 = -31730.80 Epsilon = 0.496
# 99
# 120
# resultado da epoca 510 = -41689.58 Epsilon = 0.495
# 93
# 126
# resultado da epoca 511 = -10510.04 Epsilon = 0.494
# 105
# 114
# resultado da epoca 512 = -27284.22 Epsilon = 0.493
# 96
# 123
# resultado da epoca 513 = -28615.68 Epsilon = 0.492
# 90
# 129
# resultado da epoca 514 = -32536.88 Epsilon = 0.491
# 97
# 122
# resultado da epoca 515 = -47610.44 Epsilon = 0.490
# 98
# 121
# resultado da epoca 516 = -51573.94 Epsilon = 0.489
# 89
# 130
# resultado da epoca 517 = -36168.62 Epsilon = 0.488
# 89
# 130
# resultado da epoca 518 = -48158.80 Epsilon = 0.487
# 101
# 118
# resultado da epoca 519 = -48403.06 Epsilon = 0.486
# 91
# 128
# resultado da epoca 520 = -57230.58 Epsilon = 0.485
# 99
# 120
# resultado da epoca 521 = -26478.00 Epsilon = 0.484
# 101
# 118
# resultado da epoca 522 = -29437.58 Epsilon = 0.483
# 102
# 117
# resultado da epoca 523 = -47945.14 Epsilon = 0.482
# 91
# 128
# resultado da epoca 524 = -79398.28 Epsilon = 0.481
# 85
# 134
# resultado da epoca 525 = -68727.76 Epsilon = 0.480
# 84
# 135
# resultado da epoca 526 = -18152.46 Epsilon = 0.479
# 101
# 118
# resultado da epoca 527 = -45879.48 Epsilon = 0.478
# 97
# 122
# resultado da epoca 528 = -66237.44 Epsilon = 0.477
# 93
# 126
# resultado da epoca 529 = -53945.52 Epsilon = 0.476
# 94
# 125
# resultado da epoca 530 = -41018.72 Epsilon = 0.475
# 92
# 127
# resultado da epoca 531 = -30740.48 Epsilon = 0.474
# 95
# 124
# resultado da epoca 532 = -36030.80 Epsilon = 0.473
# 100
# 119
# resultado da epoca 533 = -23482.74 Epsilon = 0.472
# 105
# 114
# resultado da epoca 534 = -44734.54 Epsilon = 0.471
# 92
# 127
# resultado da epoca 535 = -38103.52 Epsilon = 0.470
# 94
# 125
# resultado da epoca 536 = -41198.18 Epsilon = 0.469
# 101
# 118
# resultado da epoca 537 = -39103.18 Epsilon = 0.468
# 92
# 127
# resultado da epoca 538 = -20051.76 Epsilon = 0.467
# 107
# 112
# resultado da epoca 539 = -73336.74 Epsilon = 0.466
# 89
# 130
# resultado da epoca 540 = -28795.02 Epsilon = 0.465
# 89
# 130
# resultado da epoca 541 = -14271.14 Epsilon = 0.464
# 90
# 129
# resultado da epoca 542 = -56847.62 Epsilon = 0.463
# 91
# 128
# resultado da epoca 543 = -19115.78 Epsilon = 0.462
# 98
# 121
# resultado da epoca 544 = -52747.40 Epsilon = 0.461
# 94
# 125
# resultado da epoca 545 = -27520.34 Epsilon = 0.460
# 96
# 123
# resultado da epoca 546 = -50243.80 Epsilon = 0.459
# 96
# 123
# resultado da epoca 547 = -58047.44 Epsilon = 0.458
# 98
# 121
# resultado da epoca 548 = -57591.56 Epsilon = 0.457
# 88
# 131
# resultado da epoca 549 = -36063.40 Epsilon = 0.456
# 97
# 122
# resultado da epoca 550 = -46234.24 Epsilon = 0.455
# 97
# 122
# resultado da epoca 551 = -22244.50 Epsilon = 0.455
# 104
# 115
# resultado da epoca 552 = -17998.66 Epsilon = 0.454
# 104
# 115
# resultado da epoca 553 = -21933.86 Epsilon = 0.453
# 106
# 113
# resultado da epoca 554 = -70672.86 Epsilon = 0.452
# 84
# 135
# resultado da epoca 555 = -11276.52 Epsilon = 0.451
# 96
# 123
# resultado da epoca 556 = -51477.94 Epsilon = 0.450
# 101
# 118
# resultado da epoca 557 = -58511.86 Epsilon = 0.449
# 84
# 135
# resultado da epoca 558 = -44888.92 Epsilon = 0.448
# 101
# 118
# resultado da epoca 559 = -51479.80 Epsilon = 0.447
# 94
# 125
# resultado da epoca 560 = 466.22 Epsilon = 0.446
# 114
# 105
# resultado da epoca 561 = -10846.56 Epsilon = 0.445
# 102
# 117
# resultado da epoca 562 = -49516.74 Epsilon = 0.444
# 91
# 128
# resultado da epoca 563 = -29185.40 Epsilon = 0.443
# 104
# 115
# resultado da epoca 564 = -31506.38 Epsilon = 0.442
# 103
# 116
# resultado da epoca 565 = -83232.78 Epsilon = 0.441
# 85
# 134
# resultado da epoca 566 = -33298.20 Epsilon = 0.440
# 101
# 118
# resultado da epoca 567 = -70754.54 Epsilon = 0.439
# 84
# 135
# resultado da epoca 568 = -13784.38 Epsilon = 0.438
# 100
# 119
# resultado da epoca 569 = -72109.42 Epsilon = 0.437
# 88
# 131
# resultado da epoca 570 = 4868.86 Epsilon = 0.436
# 108
# 111
# resultado da epoca 571 = -34477.32 Epsilon = 0.435
# 108
# 111
# resultado da epoca 572 = -6988.34 Epsilon = 0.434
# 107
# 112
# resultado da epoca 573 = -32161.64 Epsilon = 0.433
# 108
# 111
# resultado da epoca 574 = -44017.88 Epsilon = 0.432
# 90
# 129
# resultado da epoca 575 = -34548.70 Epsilon = 0.431
# 99
# 120
# resultado da epoca 576 = -14882.34 Epsilon = 0.430
# 103
# 116
# resultado da epoca 577 = -63316.72 Epsilon = 0.429
# 88
# 131
# resultado da epoca 578 = -53115.80 Epsilon = 0.428
# 96
# 123
# resultado da epoca 579 = -42998.00 Epsilon = 0.427
# 94
# 125
# resultado da epoca 580 = -49973.32 Epsilon = 0.426
# 94
# 125
# resultado da epoca 581 = -11584.36 Epsilon = 0.425
# 101
# 118
# resultado da epoca 582 = -20320.60 Epsilon = 0.424
# 94
# 125
# resultado da epoca 583 = -54725.86 Epsilon = 0.423
# 95
# 124
# resultado da epoca 584 = -58322.16 Epsilon = 0.422
# 95
# 124
# resultado da epoca 585 = -27739.36 Epsilon = 0.421
# 106
# 113
# resultado da epoca 586 = -14254.26 Epsilon = 0.420
# 103
# 116
# resultado da epoca 587 = -32008.76 Epsilon = 0.419
# 100
# 119
# resultado da epoca 588 = -37544.70 Epsilon = 0.418
# 91
# 128
# resultado da epoca 589 = -53029.56 Epsilon = 0.417
# 98
# 121
# resultado da epoca 590 = -36463.86 Epsilon = 0.416
# 102
# 117
# resultado da epoca 591 = -49134.22 Epsilon = 0.415
# 93
# 126
# resultado da epoca 592 = -48901.76 Epsilon = 0.414
# 97
# 122
# resultado da epoca 593 = -32610.48 Epsilon = 0.413
# 100
# 119
# resultado da epoca 594 = -20561.10 Epsilon = 0.412
# 103
# 116
# resultado da epoca 595 = -43568.88 Epsilon = 0.411
# 82
# 137
# resultado da epoca 596 = -34953.50 Epsilon = 0.410
# 93
# 126
# resultado da epoca 597 = -47711.06 Epsilon = 0.409
# 93
# 126
# resultado da epoca 598 = -51700.24 Epsilon = 0.408
# 91
# 128
# resultado da epoca 599 = -47175.08 Epsilon = 0.407
# 97
# 122
# resultado da epoca 600 = -36182.28 Epsilon = 0.406
# 93
# 126
# resultado da epoca 601 = -29813.80 Epsilon = 0.405
# 95
# 124
# resultado da epoca 602 = -47330.86 Epsilon = 0.404
# 94
# 125
# resultado da epoca 603 = -46017.48 Epsilon = 0.403
# 93
# 126
# resultado da epoca 604 = -41622.00 Epsilon = 0.402
# 91
# 128
# resultado da epoca 605 = -60118.40 Epsilon = 0.401
# 90
# 129
# resultado da epoca 606 = -55597.74 Epsilon = 0.400
# 86
# 133
# resultado da epoca 607 = -46899.46 Epsilon = 0.399
# 94
# 125
# resultado da epoca 608 = -18681.82 Epsilon = 0.398
# 95
# 124
# resultado da epoca 609 = -38423.20 Epsilon = 0.397
# 93
# 126
# resultado da epoca 610 = -11750.52 Epsilon = 0.396
# 102
# 117
# resultado da epoca 611 = -28944.52 Epsilon = 0.395
# 109
# 110
# resultado da epoca 612 = -47690.38 Epsilon = 0.394
# 93
# 126
# resultado da epoca 613 = -48133.54 Epsilon = 0.393
# 92
# 127
# resultado da epoca 614 = -26845.58 Epsilon = 0.392
# 95
# 124
# resultado da epoca 615 = -32134.74 Epsilon = 0.391
# 97
# 122
# resultado da epoca 616 = -36901.08 Epsilon = 0.390
# 99
# 120
# resultado da epoca 617 = -39195.18 Epsilon = 0.389
# 97
# 122
# resultado da epoca 618 = -19330.04 Epsilon = 0.388
# 105
# 114
# resultado da epoca 619 = -17902.76 Epsilon = 0.387
# 106
# 113
# resultado da epoca 620 = -40123.36 Epsilon = 0.386
# 91
# 128
# resultado da epoca 621 = -46479.20 Epsilon = 0.385
# 99
# 120
# resultado da epoca 622 = -12700.04 Epsilon = 0.384
# 107
# 112
# resultado da epoca 623 = -32246.44 Epsilon = 0.383
# 96
# 123
# resultado da epoca 624 = -19585.46 Epsilon = 0.382
# 99
# 120
# resultado da epoca 625 = -35044.44 Epsilon = 0.381
# 95
# 124
# resultado da epoca 626 = -28574.82 Epsilon = 0.380
# 98
# 121
# resultado da epoca 627 = -25512.32 Epsilon = 0.379
# 95
# 124
# resultado da epoca 628 = -51929.42 Epsilon = 0.378
# 93
# 126
# resultado da epoca 629 = -67036.64 Epsilon = 0.377
# 90
# 129
# resultado da epoca 630 = -43023.32 Epsilon = 0.376
# 92
# 127
# resultado da epoca 631 = -38039.96 Epsilon = 0.375
# 94
# 125
# resultado da epoca 632 = -34305.54 Epsilon = 0.374
# 104
# 115
# resultado da epoca 633 = -57596.56 Epsilon = 0.373
# 85
# 134
# resultado da epoca 634 = -51831.88 Epsilon = 0.372
# 94
# 125
# resultado da epoca 635 = -45251.14 Epsilon = 0.371
# 88
# 131
# resultado da epoca 636 = -36294.32 Epsilon = 0.370
# 92
# 127
# resultado da epoca 637 = -26942.94 Epsilon = 0.369
# 93
# 126
# resultado da epoca 638 = -20269.00 Epsilon = 0.368
# 96
# 123
# resultado da epoca 639 = -33577.76 Epsilon = 0.367
# 98
# 121
# resultado da epoca 640 = -41984.46 Epsilon = 0.366
# 99
# 120
# resultado da epoca 641 = -47533.44 Epsilon = 0.365
# 93
# 126
# resultado da epoca 642 = -14869.88 Epsilon = 0.364
# 107
# 112
# resultado da epoca 643 = -25943.06 Epsilon = 0.363
# 100
# 119
# resultado da epoca 644 = -39473.24 Epsilon = 0.362
# 96
# 123
# resultado da epoca 645 = -66684.88 Epsilon = 0.361
# 87
# 132
# resultado da epoca 646 = -54616.80 Epsilon = 0.360
# 92
# 127
# resultado da epoca 647 = -41361.84 Epsilon = 0.359
# 95
# 124
# resultado da epoca 648 = -50278.30 Epsilon = 0.358
# 91
# 128
# resultado da epoca 649 = -28627.76 Epsilon = 0.357
# 106
# 113
# resultado da epoca 650 = -29616.40 Epsilon = 0.356
# 102
# 117
# resultado da epoca 651 = -44003.16 Epsilon = 0.356
# 92
# 127
# resultado da epoca 652 = -39930.86 Epsilon = 0.355
# 91
# 128
# resultado da epoca 653 = -14014.86 Epsilon = 0.354
# 100
# 119
# resultado da epoca 654 = 4169.26 Epsilon = 0.353
# 105
# 114
# resultado da epoca 655 = -25658.70 Epsilon = 0.352
# 110
# 109
# resultado da epoca 656 = -34086.18 Epsilon = 0.351
# 96
# 123
# resultado da epoca 657 = -27928.12 Epsilon = 0.350
# 95
# 124
# resultado da epoca 658 = -10383.78 Epsilon = 0.349
# 102
# 117
# resultado da epoca 659 = -46601.04 Epsilon = 0.348
# 97
# 122
# resultado da epoca 660 = -23609.34 Epsilon = 0.347
# 98
# 121
# resultado da epoca 661 = -11570.14 Epsilon = 0.346
# 104
# 115
# resultado da epoca 662 = -35043.48 Epsilon = 0.345
# 100
# 119
# resultado da epoca 663 = -39870.66 Epsilon = 0.344
# 91
# 128
# resultado da epoca 664 = -44869.92 Epsilon = 0.343
# 98
# 121
# resultado da epoca 665 = -46631.40 Epsilon = 0.342
# 101
# 118
# resultado da epoca 666 = -14006.34 Epsilon = 0.341
# 103
# 116
# resultado da epoca 667 = -47359.02 Epsilon = 0.340
# 98
# 121
# resultado da epoca 668 = -32826.48 Epsilon = 0.339
# 96
# 123
# resultado da epoca 669 = -26521.40 Epsilon = 0.338
# 104
# 115
# resultado da epoca 670 = -20655.06 Epsilon = 0.337
# 107
# 112
# resultado da epoca 671 = -43708.02 Epsilon = 0.336
# 96
# 123
# resultado da epoca 672 = -10893.30 Epsilon = 0.335
# 92
# 127
# resultado da epoca 673 = -56262.44 Epsilon = 0.334
# 88
# 131
# resultado da epoca 674 = -31139.08 Epsilon = 0.333
# 94
# 125
# resultado da epoca 675 = -38869.34 Epsilon = 0.332
# 95
# 124
# resultado da epoca 676 = -30236.34 Epsilon = 0.331
# 97
# 122
# resultado da epoca 677 = -32305.34 Epsilon = 0.330
# 93
# 126
# resultado da epoca 678 = -26981.40 Epsilon = 0.329
# 94
# 125
# resultado da epoca 679 = -49798.00 Epsilon = 0.328
# 92
# 127
# resultado da epoca 680 = -50845.54 Epsilon = 0.327
# 91
# 128
# resultado da epoca 681 = -30850.18 Epsilon = 0.326
# 101
# 118
# resultado da epoca 682 = -45037.10 Epsilon = 0.325
# 103
# 116
# resultado da epoca 683 = -44649.98 Epsilon = 0.324
# 99
# 120
# resultado da epoca 684 = -26044.24 Epsilon = 0.323
# 98
# 121
# resultado da epoca 685 = -55930.02 Epsilon = 0.322
# 90
# 129
# resultado da epoca 686 = -34231.60 Epsilon = 0.321
# 96
# 123
# resultado da epoca 687 = -41482.24 Epsilon = 0.320
# 97
# 122
# resultado da epoca 688 = -33122.52 Epsilon = 0.319
# 104
# 115
# resultado da epoca 689 = -32460.46 Epsilon = 0.318
# 99
# 120
# resultado da epoca 690 = -40328.76 Epsilon = 0.317
# 101
# 118
# resultado da epoca 691 = -24938.06 Epsilon = 0.316
# 94
# 125
# resultado da epoca 692 = -17495.22 Epsilon = 0.315
# 103
# 116
# resultado da epoca 693 = -1853.08 Epsilon = 0.314
# 113
# 106
# resultado da epoca 694 = -26934.34 Epsilon = 0.313
# 100
# 119
# resultado da epoca 695 = -11865.12 Epsilon = 0.312
# 101
# 118
# resultado da epoca 696 = -32871.88 Epsilon = 0.311
# 99
# 120
# resultado da epoca 697 = -44208.82 Epsilon = 0.310
# 90
# 129
# resultado da epoca 698 = -56614.32 Epsilon = 0.309
# 98
# 121
# resultado da epoca 699 = -49760.68 Epsilon = 0.308
# 92
# 127
# resultado da epoca 700 = -59636.80 Epsilon = 0.307
# 88
# 131
# resultado da epoca 701 = -29031.32 Epsilon = 0.306
# 107
# 112
# resultado da epoca 702 = -22299.18 Epsilon = 0.305
# 106
# 113
# resultado da epoca 703 = -46761.38 Epsilon = 0.304
# 94
# 125
# resultado da epoca 704 = -44756.36 Epsilon = 0.303
# 94
# 125
# resultado da epoca 705 = -27353.64 Epsilon = 0.302
# 98
# 121
# resultado da epoca 706 = -51120.98 Epsilon = 0.301
# 95
# 124
# resultado da epoca 707 = -16539.10 Epsilon = 0.300
# 105
# 114
# resultado da epoca 708 = -34658.76 Epsilon = 0.299
# 95
# 124
# resultado da epoca 709 = -50192.26 Epsilon = 0.298
# 97
# 122
# resultado da epoca 710 = -34010.44 Epsilon = 0.297
# 93
# 126
# resultado da epoca 711 = -30616.40 Epsilon = 0.296
# 98
# 121
# resultado da epoca 712 = -23240.88 Epsilon = 0.295
# 103
# 116
# resultado da epoca 713 = -39234.28 Epsilon = 0.294
# 96
# 123
# resultado da epoca 714 = -50278.58 Epsilon = 0.293
# 92
# 127
# resultado da epoca 715 = -41856.66 Epsilon = 0.292
# 97
# 122
# resultado da epoca 716 = -49496.12 Epsilon = 0.291
# 95
# 124
# resultado da epoca 717 = -31488.22 Epsilon = 0.290
# 94
# 125
# resultado da epoca 718 = -39169.38 Epsilon = 0.289
# 101
# 118
# resultado da epoca 719 = -53540.20 Epsilon = 0.288
# 108
# 111
# resultado da epoca 720 = -23761.68 Epsilon = 0.287
# 93
# 126
# resultado da epoca 721 = -27285.92 Epsilon = 0.286
# 100
# 119
# resultado da epoca 722 = -40754.18 Epsilon = 0.285
# 96
# 123
# resultado da epoca 723 = -43584.28 Epsilon = 0.284
# 93
# 126
# resultado da epoca 724 = -22987.42 Epsilon = 0.283
# 97
# 122
# resultado da epoca 725 = -35398.32 Epsilon = 0.282
# 100
# 119
# resultado da epoca 726 = -40554.44 Epsilon = 0.281
# 100
# 119
# resultado da epoca 727 = -43414.10 Epsilon = 0.280
# 87
# 132
# resultado da epoca 728 = -39613.10 Epsilon = 0.279
# 98
# 121
# resultado da epoca 729 = -10777.30 Epsilon = 0.278
# 102
# 117
# resultado da epoca 730 = -58261.16 Epsilon = 0.277
# 92
# 127
# resultado da epoca 731 = -22587.90 Epsilon = 0.276
# 99
# 120
# resultado da epoca 732 = -23702.46 Epsilon = 0.275
# 106
# 113
# resultado da epoca 733 = -29139.38 Epsilon = 0.274
# 102
# 117
# resultado da epoca 734 = -12764.62 Epsilon = 0.273
# 105
# 114
# resultado da epoca 735 = -17641.52 Epsilon = 0.272
# 102
# 117
# resultado da epoca 736 = -10963.82 Epsilon = 0.271
# 95
# 124
# resultado da epoca 737 = -2137.08 Epsilon = 0.270
# 103
# 116
# resultado da epoca 738 = -24419.46 Epsilon = 0.269
# 99
# 120
# resultado da epoca 739 = -26973.80 Epsilon = 0.268
# 93
# 126
# resultado da epoca 740 = -37556.16 Epsilon = 0.267
# 105
# 114
# resultado da epoca 741 = -36055.30 Epsilon = 0.266
# 98
# 121
# resultado da epoca 742 = -29761.82 Epsilon = 0.265
# 107
# 112
# resultado da epoca 743 = -48108.50 Epsilon = 0.264
# 98
# 121
# resultado da epoca 744 = -16912.12 Epsilon = 0.263
# 107
# 112
# resultado da epoca 745 = -33550.16 Epsilon = 0.262
# 93
# 126
# resultado da epoca 746 = -41826.48 Epsilon = 0.261
# 99
# 120
# resultado da epoca 747 = -45451.56 Epsilon = 0.260
# 93
# 126
# resultado da epoca 748 = -36852.64 Epsilon = 0.259
# 101
# 118
# resultado da epoca 749 = -27553.26 Epsilon = 0.258
# 98
# 121
# resultado da epoca 750 = -18036.34 Epsilon = 0.257
# 102
# 117
# resultado da epoca 751 = -32362.04 Epsilon = 0.257
# 103
# 116
# resultado da epoca 752 = -14537.34 Epsilon = 0.256
# 98
# 121
# resultado da epoca 753 = -30478.76 Epsilon = 0.255
# 98
# 121
# resultado da epoca 754 = -1428.34 Epsilon = 0.254
# 105
# 114
# resultado da epoca 755 = -17301.94 Epsilon = 0.253
# 107
# 112
# resultado da epoca 756 = -35061.06 Epsilon = 0.252
# 94
# 125
# resultado da epoca 757 = -55819.36 Epsilon = 0.251
# 94
# 125
# resultado da epoca 758 = -26474.26 Epsilon = 0.250
# 98
# 121
# resultado da epoca 759 = -32394.28 Epsilon = 0.249
# 99
# 120
# resultado da epoca 760 = -17254.28 Epsilon = 0.248
# 107
# 112
# resultado da epoca 761 = -25040.06 Epsilon = 0.247
# 95
# 124
# resultado da epoca 762 = -24113.88 Epsilon = 0.246
# 105
# 114
# resultado da epoca 763 = -36198.08 Epsilon = 0.245
# 92
# 127
# resultado da epoca 764 = -44053.82 Epsilon = 0.244
# 93
# 126
# resultado da epoca 765 = -22041.84 Epsilon = 0.243
# 99
# 120
# resultado da epoca 766 = -45320.62 Epsilon = 0.242
# 98
# 121
# resultado da epoca 767 = -23803.62 Epsilon = 0.241
# 98
# 121
# resultado da epoca 768 = -23839.82 Epsilon = 0.240
# 100
# 119
# resultado da epoca 769 = -49528.30 Epsilon = 0.239
# 94
# 125
# resultado da epoca 770 = -36555.54 Epsilon = 0.238
# 99
# 120
# resultado da epoca 771 = -13736.82 Epsilon = 0.237
# 102
# 117
# resultado da epoca 772 = -12014.86 Epsilon = 0.236
# 110
# 109
# resultado da epoca 773 = -6971.76 Epsilon = 0.235
# 99
# 120
# resultado da epoca 774 = -43178.38 Epsilon = 0.234
# 98
# 121
# resultado da epoca 775 = -15856.68 Epsilon = 0.233
# 107
# 112
# resultado da epoca 776 = -30700.06 Epsilon = 0.232
# 100
# 119
# resultado da epoca 777 = -15248.98 Epsilon = 0.231
# 102
# 117
# resultado da epoca 778 = -36479.72 Epsilon = 0.230
# 96
# 123
# resultado da epoca 779 = -37733.66 Epsilon = 0.229
# 97
# 122
# resultado da epoca 780 = -25711.40 Epsilon = 0.228
# 100
# 119
# resultado da epoca 781 = -29311.22 Epsilon = 0.227
# 102
# 117
# resultado da epoca 782 = -31610.64 Epsilon = 0.226
# 93
# 126
# resultado da epoca 783 = -42651.30 Epsilon = 0.225
# 95
# 124
# resultado da epoca 784 = -36194.12 Epsilon = 0.224
# 93
# 126
# resultado da epoca 785 = -37283.70 Epsilon = 0.223
# 98
# 121
# resultado da epoca 786 = -40349.48 Epsilon = 0.222
# 94
# 125
# resultado da epoca 787 = -9747.52 Epsilon = 0.221
# 104
# 115
# resultado da epoca 788 = -14071.78 Epsilon = 0.220
# 97
# 122
# resultado da epoca 789 = -19158.50 Epsilon = 0.219
# 93
# 126
# resultado da epoca 790 = -19265.64 Epsilon = 0.218
# 97
# 122
# resultado da epoca 791 = -28411.48 Epsilon = 0.217
# 100
# 119
# resultado da epoca 792 = -23491.48 Epsilon = 0.216
# 95
# 124
# resultado da epoca 793 = -35193.40 Epsilon = 0.215
# 94
# 125
# resultado da epoca 794 = -23408.30 Epsilon = 0.214
# 101
# 118
# resultado da epoca 795 = -25932.78 Epsilon = 0.213
# 105
# 114
# resultado da epoca 796 = -19424.60 Epsilon = 0.212
# 98
# 121
# resultado da epoca 797 = -22500.92 Epsilon = 0.211
# 105
# 114
# resultado da epoca 798 = -25898.30 Epsilon = 0.210
# 95
# 124
# resultado da epoca 799 = -32564.60 Epsilon = 0.209
# 96
# 123
# resultado da epoca 800 = -37840.94 Epsilon = 0.208
# 95
# 124
# resultado da epoca 801 = -35858.50 Epsilon = 0.207
# 96
# 123
# resultado da epoca 802 = -37354.40 Epsilon = 0.206
# 93
# 126
# resultado da epoca 803 = -32507.84 Epsilon = 0.205
# 103
# 116
# resultado da epoca 804 = -30847.98 Epsilon = 0.204
# 86
# 133
# resultado da epoca 805 = -34849.34 Epsilon = 0.203
# 95
# 124
# resultado da epoca 806 = 8973.70 Epsilon = 0.202
# 103
# 116
# resultado da epoca 807 = -15797.70 Epsilon = 0.201
# 100
# 119
# resultado da epoca 808 = -22028.52 Epsilon = 0.200
# 97
# 122
# resultado da epoca 809 = -25911.90 Epsilon = 0.199
# 97
# 122
# resultado da epoca 810 = -27300.70 Epsilon = 0.198
# 95
# 124
# resultado da epoca 811 = -32693.58 Epsilon = 0.197
# 105
# 114
# resultado da epoca 812 = -10032.52 Epsilon = 0.196
# 100
# 119
# resultado da epoca 813 = -37320.16 Epsilon = 0.195
# 100
# 119
# resultado da epoca 814 = -24191.72 Epsilon = 0.194
# 103
# 116
# resultado da epoca 815 = -36752.62 Epsilon = 0.193
# 91
# 128
# resultado da epoca 816 = -33188.52 Epsilon = 0.192
# 98
# 121
# resultado da epoca 817 = -23348.86 Epsilon = 0.191
# 107
# 112
# resultado da epoca 818 = -20642.56 Epsilon = 0.190
# 98
# 121
# resultado da epoca 819 = -21210.58 Epsilon = 0.189
# 98
# 121
# resultado da epoca 820 = -10306.82 Epsilon = 0.188
# 103
# 116
# resultado da epoca 821 = -32363.88 Epsilon = 0.187
# 103
# 116
# resultado da epoca 822 = -31998.28 Epsilon = 0.186
# 102
# 117
# resultado da epoca 823 = -37724.30 Epsilon = 0.185
# 100
# 119
# resultado da epoca 824 = -29444.62 Epsilon = 0.184
# 93
# 126
# resultado da epoca 825 = -26354.68 Epsilon = 0.183
# 100
# 119
# resultado da epoca 826 = -13818.86 Epsilon = 0.182
# 103
# 116
# resultado da epoca 827 = -46504.84 Epsilon = 0.181
# 94
# 125
# resultado da epoca 828 = -27885.00 Epsilon = 0.180
# 98
# 121
# resultado da epoca 829 = -17112.90 Epsilon = 0.179
# 103
# 116
# resultado da epoca 830 = -14742.02 Epsilon = 0.178
# 102
# 117
# resultado da epoca 831 = -25065.66 Epsilon = 0.177
# 101
# 118
# resultado da epoca 832 = -39060.46 Epsilon = 0.176
# 96
# 123
# resultado da epoca 833 = -18832.98 Epsilon = 0.175
# 99
# 120
# resultado da epoca 834 = -37770.72 Epsilon = 0.174
# 88
# 131
# resultado da epoca 835 = -34499.76 Epsilon = 0.173
# 102
# 117
# resultado da epoca 836 = -27114.18 Epsilon = 0.172
# 102
# 117
# resultado da epoca 837 = -22615.06 Epsilon = 0.171
# 102
# 117
# resultado da epoca 838 = -42135.92 Epsilon = 0.170
# 95
# 124
# resultado da epoca 839 = -37137.02 Epsilon = 0.169
# 93
# 126
# resultado da epoca 840 = -1040.08 Epsilon = 0.168
# 108
# 111
# resultado da epoca 841 = -25654.64 Epsilon = 0.167
# 99
# 120
# resultado da epoca 842 = -952.38 Epsilon = 0.166
# 107
# 112
# resultado da epoca 843 = -24658.62 Epsilon = 0.165
# 110
# 109
# resultado da epoca 844 = -13214.14 Epsilon = 0.164
# 99
# 120
# resultado da epoca 845 = -14281.02 Epsilon = 0.163
# 104
# 115
# resultado da epoca 846 = -26263.30 Epsilon = 0.162
# 100
# 119
# resultado da epoca 847 = -34202.84 Epsilon = 0.161
# 96
# 123
# resultado da epoca 848 = -16980.94 Epsilon = 0.160
# 99
# 120
# resultado da epoca 849 = -15733.20 Epsilon = 0.159
# 107
# 112
# resultado da epoca 850 = -21745.56 Epsilon = 0.158
# 101
# 118
# resultado da epoca 851 = -25940.74 Epsilon = 0.158
# 95
# 124
# resultado da epoca 852 = -29713.90 Epsilon = 0.157
# 90
# 129
# resultado da epoca 853 = -29257.82 Epsilon = 0.156
# 99
# 120
# resultado da epoca 854 = -16486.80 Epsilon = 0.155
# 95
# 124
# resultado da epoca 855 = -22434.62 Epsilon = 0.154
# 106
# 113
# resultado da epoca 856 = -15083.76 Epsilon = 0.153
# 97
# 122
# resultado da epoca 857 = -31802.16 Epsilon = 0.152
# 101
# 118
# resultado da epoca 858 = -1960.66 Epsilon = 0.151
# 101
# 118
# resultado da epoca 859 = -15131.18 Epsilon = 0.150
# 102
# 117
# resultado da epoca 860 = -13557.56 Epsilon = 0.149
# 95
# 124
# resultado da epoca 861 = -10599.06 Epsilon = 0.148
# 98
# 121
# resultado da epoca 862 = -34967.02 Epsilon = 0.147
# 96
# 123
# resultado da epoca 863 = -24556.84 Epsilon = 0.146
# 94
# 125
# resultado da epoca 864 = -18974.90 Epsilon = 0.145
# 102
# 117
# resultado da epoca 865 = -7595.24 Epsilon = 0.144
# 102
# 117
# resultado da epoca 866 = -13026.32 Epsilon = 0.143
# 100
# 119
# resultado da epoca 867 = -30697.10 Epsilon = 0.142
# 94
# 125
# resultado da epoca 868 = -26457.68 Epsilon = 0.141
# 101
# 118
# resultado da epoca 869 = -11219.72 Epsilon = 0.140
# 105
# 114
# resultado da epoca 870 = -24552.30 Epsilon = 0.139
# 106
# 113
# resultado da epoca 871 = -12415.22 Epsilon = 0.138
# 100
# 119
# resultado da epoca 872 = -17657.90 Epsilon = 0.137
# 97
# 122
# resultado da epoca 873 = -21653.02 Epsilon = 0.136
# 104
# 115
# resultado da epoca 874 = -687.96 Epsilon = 0.135
# 109
# 110
# resultado da epoca 875 = -14116.28 Epsilon = 0.134
# 98
# 121
# resultado da epoca 876 = -30271.18 Epsilon = 0.133
# 101
# 118
# resultado da epoca 877 = -16644.66 Epsilon = 0.132
# 95
# 124
# resultado da epoca 878 = -3472.36 Epsilon = 0.131
# 103
# 116
# resultado da epoca 879 = -26182.98 Epsilon = 0.130
# 102
# 117
# resultado da epoca 880 = -11834.44 Epsilon = 0.129
# 101
# 118
# resultado da epoca 881 = -16336.44 Epsilon = 0.128
# 100
# 119
# resultado da epoca 882 = -17316.14 Epsilon = 0.127
# 100
# 119
# resultado da epoca 883 = -25063.80 Epsilon = 0.126
# 95
# 124
# resultado da epoca 884 = -29144.72 Epsilon = 0.125
# 97
# 122
# resultado da epoca 885 = -16117.88 Epsilon = 0.124
# 106
# 113
# resultado da epoca 886 = -27214.26 Epsilon = 0.123
# 97
# 122
# resultado da epoca 887 = -23647.46 Epsilon = 0.122
# 100
# 119
# resultado da epoca 888 = 515.78 Epsilon = 0.121
# 103
# 116
# resultado da epoca 889 = -18565.00 Epsilon = 0.120
# 98
# 121
# resultado da epoca 890 = -5574.08 Epsilon = 0.119
# 104
# 115
# resultado da epoca 891 = -20299.30 Epsilon = 0.118
# 100
# 119
# resultado da epoca 892 = -9459.50 Epsilon = 0.117
# 102
# 117
# resultado da epoca 893 = -26263.66 Epsilon = 0.116
# 96
# 123
# resultado da epoca 894 = -9780.68 Epsilon = 0.115
# 109
# 110
# resultado da epoca 895 = -7704.08 Epsilon = 0.114
# 103
# 116
# resultado da epoca 896 = -13804.56 Epsilon = 0.113
# 99
# 120
# resultado da epoca 897 = -24557.76 Epsilon = 0.112
# 100
# 119
# resultado da epoca 898 = -15876.12 Epsilon = 0.111
# 101
# 118
# resultado da epoca 899 = -2294.40 Epsilon = 0.110
# 107
# 112
# resultado da epoca 900 = -11441.40 Epsilon = 0.109
# 106
# 113
# resultado da epoca 901 = -21443.60 Epsilon = 0.108
# 97
# 122
# resultado da epoca 902 = -8638.28 Epsilon = 0.107
# 109
# 110
# resultado da epoca 903 = -2540.78 Epsilon = 0.106
# 106
# 113
# resultado da epoca 904 = -6915.88 Epsilon = 0.105
# 109
# 110
# resultado da epoca 905 = -25793.82 Epsilon = 0.104
# 97
# 122
# resultado da epoca 906 = -13079.16 Epsilon = 0.103
# 102
# 117
# resultado da epoca 907 = -4704.82 Epsilon = 0.102
# 101
# 118
# resultado da epoca 908 = -17756.46 Epsilon = 0.101
# 101
# 118
# resultado da epoca 909 = -12919.36 Epsilon = 0.100
# 103
# 116
# resultado da epoca 910 = 2152.02 Epsilon = 0.099
# 107
# 112
# resultado da epoca 911 = -1979.52 Epsilon = 0.098
# 97
# 122
# resultado da epoca 912 = -11020.12 Epsilon = 0.097
# 94
# 125
# resultado da epoca 913 = -20492.82 Epsilon = 0.096
# 101
# 118
# resultado da epoca 914 = -23524.12 Epsilon = 0.095
# 101
# 118
# resultado da epoca 915 = -9995.86 Epsilon = 0.094
# 103
# 116
# resultado da epoca 916 = -16495.66 Epsilon = 0.093
# 99
# 120
# resultado da epoca 917 = -19401.10 Epsilon = 0.092
# 95
# 124
# resultado da epoca 918 = -23373.46 Epsilon = 0.091
# 92
# 127
# resultado da epoca 919 = -2243.92 Epsilon = 0.090
# 107
# 112
# resultado da epoca 920 = 2070.54 Epsilon = 0.089
# 98
# 121
# resultado da epoca 921 = -9777.12 Epsilon = 0.088
# 98
# 121
# resultado da epoca 922 = -17165.66 Epsilon = 0.087
# 99
# 120
# resultado da epoca 923 = -8679.50 Epsilon = 0.086
# 103
# 116
# resultado da epoca 924 = -7840.88 Epsilon = 0.085
# 101
# 118
# resultado da epoca 925 = -14033.90 Epsilon = 0.084
# 102
# 117
# resultado da epoca 926 = -7173.38 Epsilon = 0.083
# 96
# 123
# resultado da epoca 927 = -20459.22 Epsilon = 0.082
# 95
# 124
# resultado da epoca 928 = -11570.96 Epsilon = 0.081
# 93
# 126
# resultado da epoca 929 = -12918.38 Epsilon = 0.080
# 103
# 116
# resultado da epoca 930 = -22048.82 Epsilon = 0.079
# 104
# 115
# resultado da epoca 931 = -24445.68 Epsilon = 0.078
# 95
# 124
# resultado da epoca 932 = -18287.66 Epsilon = 0.077
# 100
# 119
# resultado da epoca 933 = -13699.04 Epsilon = 0.076
# 96
# 123
# resultado da epoca 934 = -10121.64 Epsilon = 0.075
# 100
# 119
# resultado da epoca 935 = -6044.72 Epsilon = 0.074
# 102
# 117
# resultado da epoca 936 = -27903.94 Epsilon = 0.073
# 94
# 125
# resultado da epoca 937 = -5721.40 Epsilon = 0.072
# 103
# 116
# resultado da epoca 938 = -7663.22 Epsilon = 0.071
# 106
# 113
# resultado da epoca 939 = -18522.84 Epsilon = 0.070
# 98
# 121
# resultado da epoca 940 = -16053.62 Epsilon = 0.069
# 100
# 119
# resultado da epoca 941 = -14542.18 Epsilon = 0.068
# 100
# 119
# resultado da epoca 942 = -21142.74 Epsilon = 0.067
# 96
# 123
# resultado da epoca 943 = -3778.06 Epsilon = 0.066
# 104
# 115
# resultado da epoca 944 = -3542.36 Epsilon = 0.065
# 103
# 116
# resultado da epoca 945 = -12189.48 Epsilon = 0.064
# 101
# 118
# resultado da epoca 946 = -16519.62 Epsilon = 0.063
# 101
# 118
# resultado da epoca 947 = -16892.30 Epsilon = 0.062
# 103
# 116
# resultado da epoca 948 = -10129.02 Epsilon = 0.061
# 99
# 120
# resultado da epoca 949 = -17419.70 Epsilon = 0.060
# 102
# 117
# resultado da epoca 950 = -11520.02 Epsilon = 0.059
# 102
# 117
# resultado da epoca 951 = -2150.40 Epsilon = 0.059
# 102
# 117
# resultado da epoca 952 = -5561.78 Epsilon = 0.058
# 103
# 116
# resultado da epoca 953 = -11854.62 Epsilon = 0.057
# 100
# 119
# resultado da epoca 954 = -10719.24 Epsilon = 0.056
# 102
# 117
# resultado da epoca 955 = -19500.12 Epsilon = 0.055
# 100
# 119
# resultado da epoca 956 = -17370.18 Epsilon = 0.054
# 97
# 122
# resultado da epoca 957 = -16231.04 Epsilon = 0.053
# 97
# 122
# resultado da epoca 958 = -14976.88 Epsilon = 0.052
# 96
# 123
# resultado da epoca 959 = -13272.66 Epsilon = 0.051
# 103
# 116
# resultado da epoca 960 = 139.64 Epsilon = 0.050
# 101
# 118
# resultado da epoca 961 = -17437.28 Epsilon = 0.049
# 101
# 118
# resultado da epoca 962 = -7811.66 Epsilon = 0.048
# 100
# 119
# resultado da epoca 963 = -13566.36 Epsilon = 0.047
# 98
# 121
# resultado da epoca 964 = -13862.04 Epsilon = 0.046
# 96
# 123
# resultado da epoca 965 = -21167.96 Epsilon = 0.045
# 97
# 122
# resultado da epoca 966 = -6365.88 Epsilon = 0.044
# 104
# 115
# resultado da epoca 967 = -6657.70 Epsilon = 0.043
# 98
# 121
# resultado da epoca 968 = -5183.36 Epsilon = 0.042
# 104
# 115
# resultado da epoca 969 = -8615.30 Epsilon = 0.041
# 100
# 119
# resultado da epoca 970 = -8367.20 Epsilon = 0.040
# 99
# 120
# resultado da epoca 971 = -15691.68 Epsilon = 0.039
# 96
# 123
# resultado da epoca 972 = -3777.62 Epsilon = 0.038
# 102
# 117
# resultado da epoca 973 = -10462.88 Epsilon = 0.037
# 98
# 121
# resultado da epoca 974 = -9008.70 Epsilon = 0.036
# 96
# 123
# resultado da epoca 975 = -8156.42 Epsilon = 0.035
# 98
# 121
# resultado da epoca 976 = -1181.00 Epsilon = 0.034
# 100
# 119
# resultado da epoca 977 = -6951.86 Epsilon = 0.033
# 93
# 126
# resultado da epoca 978 = -5034.14 Epsilon = 0.032
# 101
# 118
# resultado da epoca 979 = -5908.00 Epsilon = 0.031
# 101
# 118
# resultado da epoca 980 = -3273.90 Epsilon = 0.030
# 97
# 122
# resultado da epoca 981 = -14176.38 Epsilon = 0.029
# 101
# 118
# resultado da epoca 982 = -850.38 Epsilon = 0.028
# 104
# 115
# resultado da epoca 983 = -16860.24 Epsilon = 0.027
# 95
# 124
# resultado da epoca 984 = -14995.44 Epsilon = 0.026
# 96
# 123
# resultado da epoca 985 = -13979.20 Epsilon = 0.025
# 101
# 118
# resultado da epoca 986 = -895.40 Epsilon = 0.024
# 99
# 120
# resultado da epoca 987 = -7398.00 Epsilon = 0.023
# 97
# 122
# resultado da epoca 988 = -16719.00 Epsilon = 0.022
# 98
# 121
# resultado da epoca 989 = -13237.40 Epsilon = 0.021
# 95
# 124
# resultado da epoca 990 = -2359.38 Epsilon = 0.020
# 96
# 123
# resultado da epoca 991 = -8928.88 Epsilon = 0.019
# 95
# 124
# resultado da epoca 992 = -660.56 Epsilon = 0.018
# 99
# 120
# resultado da epoca 993 = -3261.18 Epsilon = 0.017
# 103
# 116
# resultado da epoca 994 = -7778.64 Epsilon = 0.016
# 97
# 122
# resultado da epoca 995 = -5777.70 Epsilon = 0.015
# 96
# 123
# resultado da epoca 996 = -7471.14 Epsilon = 0.014
# 94
# 125
# resultado da epoca 997 = -4348.42 Epsilon = 0.013
# 94
# 125
# resultado da epoca 998 = -9022.66 Epsilon = 0.012
# 97
# 122
# resultado da epoca 999 = -10567.72 Epsilon = 0.011
# 95
# 124
# resultado da epoca 1000 = -4657.96 Epsilon = 0.010
# 97
# 122
# resultado da epoca 1001 = -4461.18 Epsilon = 0.010
# 97
# 122
# resultado da epoca 1002 = -5641.38 Epsilon = 0.010
# 95
# 124
# resultado da epoca 1003 = -3332.20 Epsilon = 0.010
# 99
# 120
# resultado da epoca 1004 = -5488.40 Epsilon = 0.010
# 101
# 118
# 0
# 0
# Melhor resultado diario: 7668.60
