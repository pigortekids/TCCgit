# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma']#, 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 50

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
inputs_nao_norm = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1
print(inputs)
#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    print(i, imean, istd)
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
#         preco    hr_int  preco_pon  qnt_soma
# 0      3907.5  32700000    3907.50       1.0
# 1      3900.0  33000000    3901.26   20309.0
# 2      3898.0  33300000    3901.42   17614.0
# 3      3898.0  33600000    3895.37   14283.0
# 4      3899.5  33900000    3897.78    6638.0
# 5      3906.0  34200000    3902.52   13485.0
# 6      3908.0  34500000    3907.20   12677.0
# 7      3913.0  34800000    3910.72   17927.0
# 8      3906.0  35100000    3909.27   18032.0
# 9      3902.0  35400000    3904.82   17600.0
# 10     3900.5  35700000    3900.53    9326.0
# 11     3894.0  36000000    3896.53   18013.0
# 12     3897.5  36300000    3897.41   14159.0
# 13     3900.0  36600000    3897.87    5793.0
# 14     3906.0  36900000    3902.17   15901.0
# 15     3907.5  37200000    3905.68   12928.0
# 16     3908.0  37500000    3908.40    7904.0
# 17     3911.0  37800000    3909.38    7750.0
# 18     3911.0  38100000    3912.43   10917.0
# 19     3908.5  38400000    3910.42    8978.0
# 20     3916.5  38700000    3913.49   12775.0
# 21     3914.0  39000000    3915.66    7874.0
# 22     3912.0  39300000    3913.06    6877.0
# 23     3910.5  39600000    3910.59    6747.0
# 24     3917.5  39900000    3914.81   12360.0
# 25     3914.0  40200000    3915.96    8289.0
# 26     3918.5  40500000    3916.91    6028.0
# 27     3918.0  40800000    3917.95    4025.0
# 28     3918.5  41100000    3917.52    4618.0
# 29     3917.5  41400000    3917.21    2747.0
# ...       ...       ...        ...       ...
# 30074  4076.5  55500000    4076.10    9242.0
# 30075  4076.5  55800000    4076.64    4228.0
# 30076  4076.0  56100000    4075.85    3009.0
# 30077  4078.5  56400000    4077.82    9162.0
# 30078  4078.0  56700000    4078.75    5166.0
# 30079  4080.0  57000000    4078.75    4928.0
# 30080  4083.0  57300000    4081.52    9979.0
# 30081  4078.0  57600000    4080.32   17157.0
# 30082  4077.5  57900000    4078.53    5130.0
# 30083  4077.5  58200000    4077.40    3576.0
# 30084  4075.0  58500000    4075.73    7682.0
# 30085  4077.0  58800000    4076.49    3760.0
# 30086  4075.5  59100000    4076.04    2943.0
# 30087  4080.5  59400000    4078.23    7689.0
# 30088  4079.5  59700000    4080.42    9414.0
# 30089  4081.5  60000000    4079.69    8811.0
# 30090  4082.5  60300000    4081.89    8741.0
# 30091  4083.5  60600000    4083.25    6228.0
# 30092  4084.0  60900000    4083.63    3415.0
# 30093  4085.5  61200000    4084.95    5914.0
# 30094  4081.0  61500000    4083.09    7944.0
# 30095  4079.5  61800000    4080.75    5461.0
# 30096  4078.0  62100000    4079.08    4891.0
# 30097  4079.0  62400000    4078.74    2705.0
# 30098  4077.5  62700000    4078.02    2231.0
# 30099  4074.0  63000000    4074.69    9221.0
# 30100  4071.5  63300000    4071.88    5389.0
# 30101  4071.0  63600000    4070.23    5930.0
# 30102  4069.0  63900000    4071.37    5387.0
# 30103  4068.5  64200000    4069.33    4407.0
#
# [30104 rows x 4 columns]
# 0 3950.350311262026 151.02816834876631
# 1 0.49990567817392934 0.2914648644319737
# 2 3950.337021316743 151.06081783999053
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# 3 10616.129409545369 7734.606896444387

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 5
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.98     # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        model.add(Dense(512, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(64, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(32, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(x*3, activation='relu')) #camada escondida
        #model.add(Dense(x*2, activation='relu')) #camada escondida
        #model.add(Dense(x, activation='relu')) #camada escondida
        #model.add(Dense(64, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size) if dias>5 else self.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3072
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 11)                363
# =================================================================
# Total params: 177,995
# Trainable params: 177,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(preco, ncont, acao, valor, custo=0):   

    if acao == 0: #zerado
        if ncont>0:  #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        elif ncont<0: #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        else:         
            reward = 0
        valor = -100
    elif acao>0:  #comprado
        if ncont>0:
            if acao>ncont: #aumento da posicao
                reward = -custo*(acao-ncont)
                valor = (valor*ncont+(acao-ncont)*preco)/(acao)  #calculo preco medio
            elif acao<ncont:  #diminuicao da posicao
                reward = (ncont-acao)*(preco-valor) -custo*(ncont-acao)
                valor = valor #preco medio se mantem
            else:
                reward = 0
        elif ncont<0:   #trocando a mao
            reward = abs(ncont)*(valor-preco) -custo*(acao+abs(ncont))
            valor = preco
        else:          #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
    else:       #vendido
        if ncont>0:#trocando a mao
            reward = ncont*(preco-valor) -custo*(ncont+abs(acao))
            valor = preco
        elif ncont<0:
            if abs(acao)<abs(ncont): #diminuicao da posicao
                reward = (abs(ncont)-abs(acao))*(valor-preco) -custo*(abs(ncont)-abs(acao))
                valor = valor #preco medio se mantem
            elif abs(acao)>abs(ncont): #aumento da posicao
                reward = -custo*(abs(acao)-abs(ncont))
                valor = (valor*abs(ncont)+(abs(acao)-abs(ncont))*preco)/(abs(acao))  #calculo preco medio
            else: #preco medio se mantem
                reward = 0
        else:  #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
                
    #reward = ncont*acao*preco
    ncont = acao
    posicao = ncont*(preco-valor) -custo*abs(ncont) if ncont!=0 else 0.
    return ncont, reward, valor, posicao

def obter_acao():
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -100 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    indice = 0
    lucro = 0.
    posicao = 0. #cria variavel de posicao 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont, indice, precos['preco'][step], valor, precos['preco_pon'][step]], (1,modelo.state_size))
        
        acao = obter_acao()
        ncont, reward, valor, posicao = teste(precos['preco'][step], ncont, acao, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor*pstd+pmean if valor!=-100 else 0
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; reward={2} valor={3} preco={4}".format(acao, ncont, reward, valor, precos['preco'][step]))   

        if step == (steps[dia+1] - 1): #se ultimo step do dia
            done = True     
        
        modelo.next_state = np.reshape([ncont, indice+1, precos['preco'][step+1], valor, precos['preco_pon'][step+1]], (1,modelo.state_size))
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        indice += 1
        
    #fim do dia
    lucro +=posicao
    
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 0, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        
        minibatch = random.sample(modelo.memory, batch_size) if dias>5 else modelo.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    melhor_reward = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1113 19:30:58.975508   500 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1113 19:30:59.256524   500 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1113 19:30:59.288526   500 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -5.63 Epsilon = 1.000
# resultado da epoca 1 = -0.24 Epsilon = 0.999
# resultado da epoca 2 = 2.50 Epsilon = 0.998
# resultado da epoca 3 = 6.57 Epsilon = 0.997
# resultado da epoca 4 = 4.03 Epsilon = 0.996
# resultado da epoca 5 = -7.03 Epsilon = 0.995
# resultado da epoca 6 = 5.88 Epsilon = 0.994
# resultado da epoca 7 = 0.27 Epsilon = 0.993
# resultado da epoca 8 = 7.04 Epsilon = 0.992
# resultado da epoca 9 = -3.83 Epsilon = 0.991
# resultado da epoca 10 = 3.76 Epsilon = 0.990
# resultado da epoca 11 = 4.11 Epsilon = 0.989
# resultado da epoca 12 = 6.48 Epsilon = 0.988
# resultado da epoca 13 = 8.28 Epsilon = 0.987
# resultado da epoca 14 = 1.09 Epsilon = 0.986
# resultado da epoca 15 = -10.64 Epsilon = 0.985
# resultado da epoca 16 = 9.40 Epsilon = 0.984
# resultado da epoca 17 = -0.69 Epsilon = 0.983
# resultado da epoca 18 = 1.76 Epsilon = 0.982
# resultado da epoca 19 = 8.32 Epsilon = 0.981
# resultado da epoca 20 = 4.14 Epsilon = 0.980
# resultado da epoca 21 = -9.05 Epsilon = 0.979
# resultado da epoca 22 = 4.41 Epsilon = 0.978
# resultado da epoca 23 = -1.38 Epsilon = 0.977
# resultado da epoca 24 = -1.45 Epsilon = 0.976
# resultado da epoca 25 = -3.15 Epsilon = 0.975
# resultado da epoca 26 = 7.51 Epsilon = 0.974
# resultado da epoca 27 = 1.18 Epsilon = 0.973
# resultado da epoca 28 = 2.49 Epsilon = 0.972
# resultado da epoca 29 = 8.15 Epsilon = 0.971
# resultado da epoca 30 = 0.30 Epsilon = 0.970
# resultado da epoca 31 = 1.99 Epsilon = 0.969
# resultado da epoca 32 = -2.03 Epsilon = 0.968
# resultado da epoca 33 = -0.78 Epsilon = 0.967
# resultado da epoca 34 = -3.40 Epsilon = 0.966
# resultado da epoca 35 = -2.51 Epsilon = 0.965
# resultado da epoca 36 = -2.24 Epsilon = 0.964
# resultado da epoca 37 = 4.23 Epsilon = 0.963
# resultado da epoca 38 = 6.87 Epsilon = 0.962
# resultado da epoca 39 = 0.33 Epsilon = 0.961
# resultado da epoca 40 = 7.22 Epsilon = 0.960
# resultado da epoca 41 = 3.96 Epsilon = 0.959
# resultado da epoca 42 = 3.78 Epsilon = 0.958
# resultado da epoca 43 = 4.79 Epsilon = 0.957
# resultado da epoca 44 = -2.15 Epsilon = 0.956
# resultado da epoca 45 = -1.59 Epsilon = 0.955
# resultado da epoca 46 = -0.87 Epsilon = 0.954
# resultado da epoca 47 = 8.73 Epsilon = 0.953
# resultado da epoca 48 = 7.15 Epsilon = 0.952
# resultado da epoca 49 = -1.27 Epsilon = 0.951
# resultado da epoca 50 = 6.01 Epsilon = 0.950
# resultado da epoca 51 = -2.70 Epsilon = 0.950
# resultado da epoca 52 = -5.55 Epsilon = 0.949
# resultado da epoca 53 = -1.13 Epsilon = 0.948
# resultado da epoca 54 = 2.32 Epsilon = 0.947
# resultado da epoca 55 = -0.85 Epsilon = 0.946
# resultado da epoca 56 = 0.95 Epsilon = 0.945
# resultado da epoca 57 = 2.06 Epsilon = 0.944
# resultado da epoca 58 = 9.02 Epsilon = 0.943
# resultado da epoca 59 = -3.14 Epsilon = 0.942
# resultado da epoca 60 = 9.22 Epsilon = 0.941
# resultado da epoca 61 = -6.08 Epsilon = 0.940
# resultado da epoca 62 = 3.11 Epsilon = 0.939
# resultado da epoca 63 = -5.60 Epsilon = 0.938
# resultado da epoca 64 = 3.68 Epsilon = 0.937
# resultado da epoca 65 = 6.94 Epsilon = 0.936
# resultado da epoca 66 = -12.66 Epsilon = 0.935
# resultado da epoca 67 = 4.83 Epsilon = 0.934
# resultado da epoca 68 = 0.36 Epsilon = 0.933
# resultado da epoca 69 = -3.94 Epsilon = 0.932
# resultado da epoca 70 = 2.54 Epsilon = 0.931
# resultado da epoca 71 = -8.58 Epsilon = 0.930
# resultado da epoca 72 = 0.53 Epsilon = 0.929
# resultado da epoca 73 = 4.10 Epsilon = 0.928
# resultado da epoca 74 = -5.12 Epsilon = 0.927
# resultado da epoca 75 = -4.46 Epsilon = 0.926
# resultado da epoca 76 = -3.04 Epsilon = 0.925
# resultado da epoca 77 = 4.82 Epsilon = 0.924
# resultado da epoca 78 = 4.43 Epsilon = 0.923
# resultado da epoca 79 = -1.97 Epsilon = 0.922
# resultado da epoca 80 = -2.74 Epsilon = 0.921
# resultado da epoca 81 = -3.19 Epsilon = 0.920
# resultado da epoca 82 = -1.45 Epsilon = 0.919
# resultado da epoca 83 = 4.75 Epsilon = 0.918
# resultado da epoca 84 = 3.47 Epsilon = 0.917
# resultado da epoca 85 = -5.39 Epsilon = 0.916
# resultado da epoca 86 = 1.75 Epsilon = 0.915
# resultado da epoca 87 = -6.32 Epsilon = 0.914
# resultado da epoca 88 = 1.93 Epsilon = 0.913
# resultado da epoca 89 = 0.73 Epsilon = 0.912
# resultado da epoca 90 = -2.84 Epsilon = 0.911
# resultado da epoca 91 = -5.94 Epsilon = 0.910
# resultado da epoca 92 = -0.27 Epsilon = 0.909
# resultado da epoca 93 = -7.48 Epsilon = 0.908
# resultado da epoca 94 = 3.44 Epsilon = 0.907
# resultado da epoca 95 = -4.69 Epsilon = 0.906
# resultado da epoca 96 = -1.89 Epsilon = 0.905
# resultado da epoca 97 = -3.00 Epsilon = 0.904
# resultado da epoca 98 = 1.22 Epsilon = 0.903
# resultado da epoca 99 = 3.61 Epsilon = 0.902
# resultado da epoca 100 = 8.55 Epsilon = 0.901
# resultado da epoca 101 = -5.18 Epsilon = 0.900
# resultado da epoca 102 = -7.68 Epsilon = 0.899
# resultado da epoca 103 = -2.38 Epsilon = 0.898
# resultado da epoca 104 = -8.77 Epsilon = 0.897
# resultado da epoca 105 = -2.59 Epsilon = 0.896
# resultado da epoca 106 = -13.60 Epsilon = 0.895
# resultado da epoca 107 = -4.07 Epsilon = 0.894
# resultado da epoca 108 = -3.75 Epsilon = 0.893
# resultado da epoca 109 = 2.78 Epsilon = 0.892
# resultado da epoca 110 = 3.85 Epsilon = 0.891
# resultado da epoca 111 = 5.87 Epsilon = 0.890
# resultado da epoca 112 = -2.33 Epsilon = 0.889
# resultado da epoca 113 = -3.47 Epsilon = 0.888
# resultado da epoca 114 = -1.96 Epsilon = 0.887
# resultado da epoca 115 = 7.58 Epsilon = 0.886
# resultado da epoca 116 = 0.31 Epsilon = 0.885
# resultado da epoca 117 = -9.72 Epsilon = 0.884
# resultado da epoca 118 = -9.62 Epsilon = 0.883
# resultado da epoca 119 = -14.72 Epsilon = 0.882
# resultado da epoca 120 = -7.65 Epsilon = 0.881
# resultado da epoca 121 = -3.75 Epsilon = 0.880
# resultado da epoca 122 = 5.04 Epsilon = 0.879
# resultado da epoca 123 = -5.33 Epsilon = 0.878
# resultado da epoca 124 = 1.16 Epsilon = 0.877
# resultado da epoca 125 = 4.51 Epsilon = 0.876
# resultado da epoca 126 = -4.06 Epsilon = 0.875
# resultado da epoca 127 = 5.35 Epsilon = 0.874
# resultado da epoca 128 = -1.98 Epsilon = 0.873
# resultado da epoca 129 = 0.55 Epsilon = 0.872
# resultado da epoca 130 = -2.01 Epsilon = 0.871
# resultado da epoca 131 = -1.97 Epsilon = 0.870
# resultado da epoca 132 = -1.16 Epsilon = 0.869
# resultado da epoca 133 = 6.08 Epsilon = 0.868
# resultado da epoca 134 = 4.18 Epsilon = 0.867
# resultado da epoca 135 = -5.21 Epsilon = 0.866
# resultado da epoca 136 = -10.84 Epsilon = 0.865
# resultado da epoca 137 = -4.96 Epsilon = 0.864
# resultado da epoca 138 = -0.34 Epsilon = 0.863
# resultado da epoca 139 = -6.66 Epsilon = 0.862
# resultado da epoca 140 = 6.67 Epsilon = 0.861
# resultado da epoca 141 = 3.65 Epsilon = 0.860
# resultado da epoca 142 = -6.86 Epsilon = 0.859
# resultado da epoca 143 = 1.27 Epsilon = 0.858
# resultado da epoca 144 = -4.19 Epsilon = 0.857
# resultado da epoca 145 = -0.24 Epsilon = 0.856
# resultado da epoca 146 = -0.06 Epsilon = 0.855
# resultado da epoca 147 = 4.50 Epsilon = 0.854
# resultado da epoca 148 = -2.21 Epsilon = 0.853
# resultado da epoca 149 = 8.31 Epsilon = 0.852
# resultado da epoca 150 = -2.70 Epsilon = 0.851
# resultado da epoca 151 = 10.34 Epsilon = 0.851
# resultado da epoca 152 = -2.53 Epsilon = 0.850
# resultado da epoca 153 = 7.05 Epsilon = 0.849
# resultado da epoca 154 = -3.23 Epsilon = 0.848
# resultado da epoca 155 = 0.61 Epsilon = 0.847
# resultado da epoca 156 = 2.22 Epsilon = 0.846
# resultado da epoca 157 = -8.80 Epsilon = 0.845
# resultado da epoca 158 = -3.14 Epsilon = 0.844
# resultado da epoca 159 = -2.52 Epsilon = 0.843
# resultado da epoca 160 = 2.57 Epsilon = 0.842
# resultado da epoca 161 = 0.82 Epsilon = 0.841
# resultado da epoca 162 = 2.32 Epsilon = 0.840
# resultado da epoca 163 = 4.06 Epsilon = 0.839
# resultado da epoca 164 = 4.11 Epsilon = 0.838
# resultado da epoca 165 = -0.98 Epsilon = 0.837
# resultado da epoca 166 = -1.34 Epsilon = 0.836
# resultado da epoca 167 = 4.28 Epsilon = 0.835
# resultado da epoca 168 = -0.01 Epsilon = 0.834
# resultado da epoca 169 = 3.98 Epsilon = 0.833
# resultado da epoca 170 = -5.27 Epsilon = 0.832
# resultado da epoca 171 = 6.10 Epsilon = 0.831
# resultado da epoca 172 = -3.71 Epsilon = 0.830
# resultado da epoca 173 = 4.55 Epsilon = 0.829
# resultado da epoca 174 = 10.05 Epsilon = 0.828
# resultado da epoca 175 = -0.56 Epsilon = 0.827
# resultado da epoca 176 = 9.40 Epsilon = 0.826
# resultado da epoca 177 = 1.03 Epsilon = 0.825
# resultado da epoca 178 = 4.71 Epsilon = 0.824
# resultado da epoca 179 = -4.59 Epsilon = 0.823
# resultado da epoca 180 = -2.23 Epsilon = 0.822
# resultado da epoca 181 = -3.67 Epsilon = 0.821
# resultado da epoca 182 = 0.27 Epsilon = 0.820
# resultado da epoca 183 = -4.47 Epsilon = 0.819
# resultado da epoca 184 = 7.18 Epsilon = 0.818
# resultado da epoca 185 = -2.87 Epsilon = 0.817
# resultado da epoca 186 = 0.32 Epsilon = 0.816
# resultado da epoca 187 = 3.94 Epsilon = 0.815
# resultado da epoca 188 = 1.51 Epsilon = 0.814
# resultado da epoca 189 = 0.48 Epsilon = 0.813
# resultado da epoca 190 = -6.26 Epsilon = 0.812
# resultado da epoca 191 = -5.78 Epsilon = 0.811
# resultado da epoca 192 = -1.63 Epsilon = 0.810
# resultado da epoca 193 = -1.28 Epsilon = 0.809
# resultado da epoca 194 = -1.66 Epsilon = 0.808
# resultado da epoca 195 = -5.07 Epsilon = 0.807
# resultado da epoca 196 = -4.46 Epsilon = 0.806
# resultado da epoca 197 = -1.04 Epsilon = 0.805
# resultado da epoca 198 = 5.86 Epsilon = 0.804
# resultado da epoca 199 = -0.94 Epsilon = 0.803
# resultado da epoca 200 = 3.89 Epsilon = 0.802
# resultado da epoca 201 = 5.05 Epsilon = 0.801
# resultado da epoca 202 = 1.44 Epsilon = 0.800
# resultado da epoca 203 = 2.41 Epsilon = 0.799
# resultado da epoca 204 = 5.29 Epsilon = 0.798
# resultado da epoca 205 = 9.77 Epsilon = 0.797
# resultado da epoca 206 = 0.29 Epsilon = 0.796
# resultado da epoca 207 = -0.48 Epsilon = 0.795
# resultado da epoca 208 = 9.84 Epsilon = 0.794
# resultado da epoca 209 = 0.46 Epsilon = 0.793
# resultado da epoca 210 = -0.79 Epsilon = 0.792
# resultado da epoca 211 = -6.77 Epsilon = 0.791
# resultado da epoca 212 = 3.04 Epsilon = 0.790
# resultado da epoca 213 = 9.95 Epsilon = 0.789
# resultado da epoca 214 = 7.68 Epsilon = 0.788
# resultado da epoca 215 = 2.61 Epsilon = 0.787
# resultado da epoca 216 = -4.97 Epsilon = 0.786
# resultado da epoca 217 = 3.95 Epsilon = 0.785
# resultado da epoca 218 = -2.73 Epsilon = 0.784
# resultado da epoca 219 = -2.03 Epsilon = 0.783
# resultado da epoca 220 = 2.35 Epsilon = 0.782
# resultado da epoca 221 = 1.88 Epsilon = 0.781
# resultado da epoca 222 = -5.11 Epsilon = 0.780
# resultado da epoca 223 = 7.16 Epsilon = 0.779
# resultado da epoca 224 = -1.60 Epsilon = 0.778
# resultado da epoca 225 = 2.48 Epsilon = 0.777
# resultado da epoca 226 = -4.02 Epsilon = 0.776
# resultado da epoca 227 = 6.21 Epsilon = 0.775
# resultado da epoca 228 = -10.40 Epsilon = 0.774
# resultado da epoca 229 = 1.33 Epsilon = 0.773
# resultado da epoca 230 = 5.22 Epsilon = 0.772
# resultado da epoca 231 = -10.84 Epsilon = 0.771
# resultado da epoca 232 = 1.68 Epsilon = 0.770
# resultado da epoca 233 = -5.98 Epsilon = 0.769
# resultado da epoca 234 = 0.51 Epsilon = 0.768
# resultado da epoca 235 = 0.52 Epsilon = 0.767
# resultado da epoca 236 = 2.64 Epsilon = 0.766
# resultado da epoca 237 = 3.17 Epsilon = 0.765
# resultado da epoca 238 = 2.56 Epsilon = 0.764
# resultado da epoca 239 = -6.54 Epsilon = 0.763
# resultado da epoca 240 = 9.92 Epsilon = 0.762
# resultado da epoca 241 = -1.05 Epsilon = 0.761
# resultado da epoca 242 = 6.85 Epsilon = 0.760
# resultado da epoca 243 = -0.59 Epsilon = 0.759
# resultado da epoca 244 = 4.74 Epsilon = 0.758
# resultado da epoca 245 = -3.93 Epsilon = 0.757
# resultado da epoca 246 = 4.19 Epsilon = 0.756
# resultado da epoca 247 = 0.15 Epsilon = 0.755
# resultado da epoca 248 = -7.16 Epsilon = 0.754
# resultado da epoca 249 = 2.97 Epsilon = 0.753
# resultado da epoca 250 = -1.86 Epsilon = 0.752
# resultado da epoca 251 = -5.06 Epsilon = 0.752
# resultado da epoca 252 = -4.25 Epsilon = 0.751
# resultado da epoca 253 = 1.07 Epsilon = 0.750
# resultado da epoca 254 = -2.27 Epsilon = 0.749
# resultado da epoca 255 = -2.62 Epsilon = 0.748
# resultado da epoca 256 = 6.60 Epsilon = 0.747
# resultado da epoca 257 = 6.59 Epsilon = 0.746
# resultado da epoca 258 = -1.99 Epsilon = 0.745
# resultado da epoca 259 = -0.67 Epsilon = 0.744
# resultado da epoca 260 = -4.53 Epsilon = 0.743
# resultado da epoca 261 = -5.15 Epsilon = 0.742
# resultado da epoca 262 = 1.97 Epsilon = 0.741
# resultado da epoca 263 = 0.33 Epsilon = 0.740
# resultado da epoca 264 = -5.22 Epsilon = 0.739
# resultado da epoca 265 = 3.50 Epsilon = 0.738
# resultado da epoca 266 = 3.48 Epsilon = 0.737
# resultado da epoca 267 = 6.44 Epsilon = 0.736
# resultado da epoca 268 = -2.64 Epsilon = 0.735
# resultado da epoca 269 = 1.35 Epsilon = 0.734
# resultado da epoca 270 = 6.83 Epsilon = 0.733
# resultado da epoca 271 = 3.77 Epsilon = 0.732
# resultado da epoca 272 = 2.58 Epsilon = 0.731
# resultado da epoca 273 = -0.24 Epsilon = 0.730
# resultado da epoca 274 = -2.07 Epsilon = 0.729
# resultado da epoca 275 = 3.70 Epsilon = 0.728
# resultado da epoca 276 = -5.20 Epsilon = 0.727
# resultado da epoca 277 = 0.84 Epsilon = 0.726
# resultado da epoca 278 = -1.19 Epsilon = 0.725
# resultado da epoca 279 = -8.13 Epsilon = 0.724
# resultado da epoca 280 = -3.21 Epsilon = 0.723
# resultado da epoca 281 = 1.64 Epsilon = 0.722
# resultado da epoca 282 = -1.92 Epsilon = 0.721
# resultado da epoca 283 = 3.37 Epsilon = 0.720
# resultado da epoca 284 = -7.26 Epsilon = 0.719
# resultado da epoca 285 = 4.43 Epsilon = 0.718
# resultado da epoca 286 = 3.55 Epsilon = 0.717
# resultado da epoca 287 = 2.16 Epsilon = 0.716
# resultado da epoca 288 = 0.57 Epsilon = 0.715
# resultado da epoca 289 = -0.01 Epsilon = 0.714
# resultado da epoca 290 = 4.03 Epsilon = 0.713
# resultado da epoca 291 = 3.89 Epsilon = 0.712
# resultado da epoca 292 = -0.84 Epsilon = 0.711
# resultado da epoca 293 = -1.09 Epsilon = 0.710
# resultado da epoca 294 = 5.29 Epsilon = 0.709
# resultado da epoca 295 = 3.94 Epsilon = 0.708
# resultado da epoca 296 = -4.88 Epsilon = 0.707
# resultado da epoca 297 = -6.08 Epsilon = 0.706
# resultado da epoca 298 = -3.22 Epsilon = 0.705
# resultado da epoca 299 = -8.85 Epsilon = 0.704
# resultado da epoca 300 = 2.00 Epsilon = 0.703
# resultado da epoca 301 = 8.10 Epsilon = 0.702
# resultado da epoca 302 = 1.01 Epsilon = 0.701
# resultado da epoca 303 = 3.27 Epsilon = 0.700
# resultado da epoca 304 = 3.62 Epsilon = 0.699
# resultado da epoca 305 = 0.77 Epsilon = 0.698
# resultado da epoca 306 = -4.97 Epsilon = 0.697
# resultado da epoca 307 = -10.59 Epsilon = 0.696
# resultado da epoca 308 = -1.08 Epsilon = 0.695
# resultado da epoca 309 = 5.99 Epsilon = 0.694
# resultado da epoca 310 = -2.34 Epsilon = 0.693
# resultado da epoca 311 = -2.80 Epsilon = 0.692
# resultado da epoca 312 = 10.63 Epsilon = 0.691
# resultado da epoca 313 = -3.04 Epsilon = 0.690
# resultado da epoca 314 = -4.58 Epsilon = 0.689
# resultado da epoca 315 = 5.86 Epsilon = 0.688
# resultado da epoca 316 = 0.94 Epsilon = 0.687
# resultado da epoca 317 = -2.75 Epsilon = 0.686
# resultado da epoca 318 = -2.82 Epsilon = 0.685
# resultado da epoca 319 = 4.79 Epsilon = 0.684
# resultado da epoca 320 = 0.43 Epsilon = 0.683
# resultado da epoca 321 = -1.10 Epsilon = 0.682
# resultado da epoca 322 = 3.09 Epsilon = 0.681
# resultado da epoca 323 = 10.94 Epsilon = 0.680
# resultado da epoca 324 = 5.22 Epsilon = 0.679
# resultado da epoca 325 = 0.75 Epsilon = 0.678
# resultado da epoca 326 = 3.17 Epsilon = 0.677
# resultado da epoca 327 = 2.26 Epsilon = 0.676
# resultado da epoca 328 = 2.93 Epsilon = 0.675
# resultado da epoca 329 = -4.50 Epsilon = 0.674
# resultado da epoca 330 = 0.10 Epsilon = 0.673
# resultado da epoca 331 = 5.21 Epsilon = 0.672
# resultado da epoca 332 = 4.65 Epsilon = 0.671
# resultado da epoca 333 = -5.28 Epsilon = 0.670
# resultado da epoca 334 = -1.70 Epsilon = 0.669
# resultado da epoca 335 = 3.52 Epsilon = 0.668
# resultado da epoca 336 = -0.04 Epsilon = 0.667
# resultado da epoca 337 = -2.28 Epsilon = 0.666
# resultado da epoca 338 = -2.23 Epsilon = 0.665
# resultado da epoca 339 = -7.54 Epsilon = 0.664
# resultado da epoca 340 = 5.12 Epsilon = 0.663
# resultado da epoca 341 = 0.96 Epsilon = 0.662
# resultado da epoca 342 = 6.83 Epsilon = 0.661
# resultado da epoca 343 = 3.93 Epsilon = 0.660
# resultado da epoca 344 = -0.61 Epsilon = 0.659
# resultado da epoca 345 = -11.47 Epsilon = 0.658
# resultado da epoca 346 = -2.48 Epsilon = 0.657
# resultado da epoca 347 = -0.66 Epsilon = 0.656
# resultado da epoca 348 = 1.00 Epsilon = 0.655
# resultado da epoca 349 = -3.14 Epsilon = 0.654
# resultado da epoca 350 = 0.33 Epsilon = 0.653
# resultado da epoca 351 = -1.41 Epsilon = 0.653
# resultado da epoca 352 = 2.83 Epsilon = 0.652
# resultado da epoca 353 = -3.03 Epsilon = 0.651
# resultado da epoca 354 = 5.44 Epsilon = 0.650
# resultado da epoca 355 = -2.08 Epsilon = 0.649
# resultado da epoca 356 = 1.69 Epsilon = 0.648
# resultado da epoca 357 = 2.90 Epsilon = 0.647
# resultado da epoca 358 = -1.21 Epsilon = 0.646
# resultado da epoca 359 = 5.23 Epsilon = 0.645
# resultado da epoca 360 = 9.80 Epsilon = 0.644
# resultado da epoca 361 = 6.59 Epsilon = 0.643
# resultado da epoca 362 = -5.22 Epsilon = 0.642
# resultado da epoca 363 = 2.96 Epsilon = 0.641
# resultado da epoca 364 = -3.42 Epsilon = 0.640
# resultado da epoca 365 = 4.95 Epsilon = 0.639
# resultado da epoca 366 = 2.16 Epsilon = 0.638
# resultado da epoca 367 = -3.15 Epsilon = 0.637
# resultado da epoca 368 = -3.47 Epsilon = 0.636
# resultado da epoca 369 = -0.76 Epsilon = 0.635
# resultado da epoca 370 = 2.04 Epsilon = 0.634
# resultado da epoca 371 = -4.32 Epsilon = 0.633
# resultado da epoca 372 = -0.41 Epsilon = 0.632
# resultado da epoca 373 = 1.49 Epsilon = 0.631
# resultado da epoca 374 = -1.09 Epsilon = 0.630
# resultado da epoca 375 = -5.24 Epsilon = 0.629
# resultado da epoca 376 = 0.66 Epsilon = 0.628
# resultado da epoca 377 = 1.98 Epsilon = 0.627
# resultado da epoca 378 = -4.45 Epsilon = 0.626
# resultado da epoca 379 = 5.70 Epsilon = 0.625
# resultado da epoca 380 = -5.28 Epsilon = 0.624
# resultado da epoca 381 = 0.69 Epsilon = 0.623
# resultado da epoca 382 = -4.52 Epsilon = 0.622
# resultado da epoca 383 = -0.71 Epsilon = 0.621
# resultado da epoca 384 = -6.30 Epsilon = 0.620
# resultado da epoca 385 = -3.58 Epsilon = 0.619
# resultado da epoca 386 = -1.72 Epsilon = 0.618
# resultado da epoca 387 = -1.33 Epsilon = 0.617
# resultado da epoca 388 = 9.75 Epsilon = 0.616
# resultado da epoca 389 = -3.22 Epsilon = 0.615
# resultado da epoca 390 = -8.64 Epsilon = 0.614
# resultado da epoca 391 = 4.64 Epsilon = 0.613
# resultado da epoca 392 = -6.64 Epsilon = 0.612
# resultado da epoca 393 = 3.93 Epsilon = 0.611
# resultado da epoca 394 = -2.43 Epsilon = 0.610
# resultado da epoca 395 = -2.10 Epsilon = 0.609
# resultado da epoca 396 = -1.19 Epsilon = 0.608
# resultado da epoca 397 = 7.84 Epsilon = 0.607
# resultado da epoca 398 = -2.17 Epsilon = 0.606
# resultado da epoca 399 = 3.23 Epsilon = 0.605
# resultado da epoca 400 = -4.55 Epsilon = 0.604
# resultado da epoca 401 = -1.76 Epsilon = 0.603
# resultado da epoca 402 = 0.88 Epsilon = 0.602
# resultado da epoca 403 = -2.36 Epsilon = 0.601
# resultado da epoca 404 = -3.08 Epsilon = 0.600
# resultado da epoca 405 = 4.78 Epsilon = 0.599
# resultado da epoca 406 = 7.46 Epsilon = 0.598
# resultado da epoca 407 = 1.97 Epsilon = 0.597
# resultado da epoca 408 = 3.95 Epsilon = 0.596
# resultado da epoca 409 = -0.37 Epsilon = 0.595
# resultado da epoca 410 = 0.15 Epsilon = 0.594
# resultado da epoca 411 = 8.95 Epsilon = 0.593
# resultado da epoca 412 = 6.32 Epsilon = 0.592
# resultado da epoca 413 = -6.71 Epsilon = 0.591
# resultado da epoca 414 = 5.46 Epsilon = 0.590
# resultado da epoca 415 = 3.64 Epsilon = 0.589
# resultado da epoca 416 = 0.09 Epsilon = 0.588
# resultado da epoca 417 = -3.68 Epsilon = 0.587
# resultado da epoca 418 = -4.71 Epsilon = 0.586
# resultado da epoca 419 = -0.64 Epsilon = 0.585
# resultado da epoca 420 = 2.83 Epsilon = 0.584
# resultado da epoca 421 = -5.02 Epsilon = 0.583
# resultado da epoca 422 = -2.78 Epsilon = 0.582
# resultado da epoca 423 = -7.14 Epsilon = 0.581
# resultado da epoca 424 = -0.49 Epsilon = 0.580
# resultado da epoca 425 = -4.79 Epsilon = 0.579
# resultado da epoca 426 = -1.29 Epsilon = 0.578
# resultado da epoca 427 = 1.57 Epsilon = 0.577
# resultado da epoca 428 = 3.44 Epsilon = 0.576
# resultado da epoca 429 = 3.57 Epsilon = 0.575
# resultado da epoca 430 = 2.22 Epsilon = 0.574
# resultado da epoca 431 = -5.68 Epsilon = 0.573
# resultado da epoca 432 = 4.73 Epsilon = 0.572
# resultado da epoca 433 = -3.23 Epsilon = 0.571
# resultado da epoca 434 = -0.44 Epsilon = 0.570
# resultado da epoca 435 = -2.33 Epsilon = 0.569
# resultado da epoca 436 = -2.36 Epsilon = 0.568
# resultado da epoca 437 = 4.53 Epsilon = 0.567
# resultado da epoca 438 = 2.00 Epsilon = 0.566
# resultado da epoca 439 = -0.62 Epsilon = 0.565
# resultado da epoca 440 = 4.67 Epsilon = 0.564
# resultado da epoca 441 = -2.16 Epsilon = 0.563
# resultado da epoca 442 = -7.94 Epsilon = 0.562
# resultado da epoca 443 = -0.22 Epsilon = 0.561
# resultado da epoca 444 = -0.85 Epsilon = 0.560
# resultado da epoca 445 = 3.91 Epsilon = 0.559
# resultado da epoca 446 = -1.24 Epsilon = 0.558
# resultado da epoca 447 = -1.57 Epsilon = 0.557
# resultado da epoca 448 = -0.38 Epsilon = 0.556
# resultado da epoca 449 = -0.60 Epsilon = 0.555
# resultado da epoca 450 = -0.45 Epsilon = 0.554
# resultado da epoca 451 = -1.64 Epsilon = 0.554
# resultado da epoca 452 = -0.43 Epsilon = 0.553
# resultado da epoca 453 = 4.72 Epsilon = 0.552
# resultado da epoca 454 = 2.13 Epsilon = 0.551
# resultado da epoca 455 = 6.54 Epsilon = 0.550
# resultado da epoca 456 = 0.71 Epsilon = 0.549
# resultado da epoca 457 = 0.67 Epsilon = 0.548
# resultado da epoca 458 = 6.26 Epsilon = 0.547
# resultado da epoca 459 = 1.23 Epsilon = 0.546
# resultado da epoca 460 = -4.75 Epsilon = 0.545
# resultado da epoca 461 = -2.31 Epsilon = 0.544
# resultado da epoca 462 = 5.74 Epsilon = 0.543
# resultado da epoca 463 = 1.52 Epsilon = 0.542
# resultado da epoca 464 = 9.70 Epsilon = 0.541
# resultado da epoca 465 = 0.41 Epsilon = 0.540
# resultado da epoca 466 = 4.05 Epsilon = 0.539
# resultado da epoca 467 = -6.76 Epsilon = 0.538
# resultado da epoca 468 = 2.99 Epsilon = 0.537
# resultado da epoca 469 = -5.63 Epsilon = 0.536
# resultado da epoca 470 = -2.08 Epsilon = 0.535
# resultado da epoca 471 = 1.31 Epsilon = 0.534
# resultado da epoca 472 = -0.23 Epsilon = 0.533
# resultado da epoca 473 = -1.89 Epsilon = 0.532
# resultado da epoca 474 = 3.97 Epsilon = 0.531
# resultado da epoca 475 = 0.12 Epsilon = 0.530
# resultado da epoca 476 = -1.90 Epsilon = 0.529
# resultado da epoca 477 = 1.96 Epsilon = 0.528
# resultado da epoca 478 = -4.02 Epsilon = 0.527
# resultado da epoca 479 = -9.06 Epsilon = 0.526
# resultado da epoca 480 = 3.57 Epsilon = 0.525
# resultado da epoca 481 = -0.12 Epsilon = 0.524
# resultado da epoca 482 = 0.39 Epsilon = 0.523
# resultado da epoca 483 = 1.55 Epsilon = 0.522
# resultado da epoca 484 = -1.04 Epsilon = 0.521
# resultado da epoca 485 = -3.52 Epsilon = 0.520
# resultado da epoca 486 = 5.00 Epsilon = 0.519
# resultado da epoca 487 = 4.16 Epsilon = 0.518
# resultado da epoca 488 = -5.12 Epsilon = 0.517
# resultado da epoca 489 = 5.08 Epsilon = 0.516
# resultado da epoca 490 = -2.23 Epsilon = 0.515
# resultado da epoca 491 = -0.35 Epsilon = 0.514
# resultado da epoca 492 = -2.95 Epsilon = 0.513
# resultado da epoca 493 = -3.39 Epsilon = 0.512
# resultado da epoca 494 = 1.95 Epsilon = 0.511
# resultado da epoca 495 = 0.77 Epsilon = 0.510
# resultado da epoca 496 = 5.82 Epsilon = 0.509
# resultado da epoca 497 = -1.35 Epsilon = 0.508
# resultado da epoca 498 = 0.25 Epsilon = 0.507
# resultado da epoca 499 = -2.05 Epsilon = 0.506
# resultado da epoca 500 = 3.87 Epsilon = 0.505
# resultado da epoca 501 = 4.25 Epsilon = 0.504
# resultado da epoca 502 = -1.45 Epsilon = 0.503
# resultado da epoca 503 = 0.28 Epsilon = 0.502
# resultado da epoca 504 = -3.17 Epsilon = 0.501
# resultado da epoca 505 = -1.98 Epsilon = 0.500
# resultado da epoca 506 = 4.35 Epsilon = 0.499
# resultado da epoca 507 = 1.78 Epsilon = 0.498
# resultado da epoca 508 = -5.38 Epsilon = 0.497
# resultado da epoca 509 = 4.28 Epsilon = 0.496
# resultado da epoca 510 = 5.34 Epsilon = 0.495
# resultado da epoca 511 = -0.43 Epsilon = 0.494
# resultado da epoca 512 = 1.57 Epsilon = 0.493
# resultado da epoca 513 = -3.31 Epsilon = 0.492
# resultado da epoca 514 = 1.73 Epsilon = 0.491
# resultado da epoca 515 = -3.86 Epsilon = 0.490
# resultado da epoca 516 = 6.61 Epsilon = 0.489
# resultado da epoca 517 = 5.90 Epsilon = 0.488
# resultado da epoca 518 = -3.36 Epsilon = 0.487
# resultado da epoca 519 = -3.85 Epsilon = 0.486
# resultado da epoca 520 = 1.24 Epsilon = 0.485
# resultado da epoca 521 = 1.61 Epsilon = 0.484
# resultado da epoca 522 = 2.36 Epsilon = 0.483
# resultado da epoca 523 = 4.55 Epsilon = 0.482
# resultado da epoca 524 = -5.62 Epsilon = 0.481
# resultado da epoca 525 = -1.25 Epsilon = 0.480
# resultado da epoca 526 = -5.43 Epsilon = 0.479
# resultado da epoca 527 = 0.07 Epsilon = 0.478
# resultado da epoca 528 = -6.88 Epsilon = 0.477
# resultado da epoca 529 = -5.59 Epsilon = 0.476
# resultado da epoca 530 = -3.81 Epsilon = 0.475
# resultado da epoca 531 = -1.91 Epsilon = 0.474
# resultado da epoca 532 = 5.09 Epsilon = 0.473
# resultado da epoca 533 = -4.78 Epsilon = 0.472
# resultado da epoca 534 = 2.55 Epsilon = 0.471
# resultado da epoca 535 = 9.39 Epsilon = 0.470
# resultado da epoca 536 = 1.70 Epsilon = 0.469
# resultado da epoca 537 = -0.47 Epsilon = 0.468
# resultado da epoca 538 = 0.06 Epsilon = 0.467
# resultado da epoca 539 = 4.10 Epsilon = 0.466
# resultado da epoca 540 = -1.46 Epsilon = 0.465
# resultado da epoca 541 = -0.53 Epsilon = 0.464
# resultado da epoca 542 = 0.66 Epsilon = 0.463
# resultado da epoca 543 = -1.47 Epsilon = 0.462
# resultado da epoca 544 = 1.46 Epsilon = 0.461
# resultado da epoca 545 = -4.06 Epsilon = 0.460
# resultado da epoca 546 = 3.28 Epsilon = 0.459
# resultado da epoca 547 = 3.00 Epsilon = 0.458
# resultado da epoca 548 = -5.16 Epsilon = 0.457
# resultado da epoca 549 = -0.14 Epsilon = 0.456
# resultado da epoca 550 = -1.25 Epsilon = 0.455
# resultado da epoca 551 = -1.43 Epsilon = 0.455
# resultado da epoca 552 = -2.93 Epsilon = 0.454
# resultado da epoca 553 = 6.48 Epsilon = 0.453
# resultado da epoca 554 = 5.51 Epsilon = 0.452
# resultado da epoca 555 = 2.28 Epsilon = 0.451
# resultado da epoca 556 = 2.76 Epsilon = 0.450
# resultado da epoca 557 = 8.05 Epsilon = 0.449
# resultado da epoca 558 = -5.78 Epsilon = 0.448
# resultado da epoca 559 = -4.39 Epsilon = 0.447
# resultado da epoca 560 = -0.07 Epsilon = 0.446
# resultado da epoca 561 = -1.39 Epsilon = 0.445
# resultado da epoca 562 = 4.77 Epsilon = 0.444
# resultado da epoca 563 = 2.16 Epsilon = 0.443
# resultado da epoca 564 = -1.46 Epsilon = 0.442
# resultado da epoca 565 = 4.46 Epsilon = 0.441
# resultado da epoca 566 = 1.22 Epsilon = 0.440
# resultado da epoca 567 = -1.95 Epsilon = 0.439
# resultado da epoca 568 = -1.46 Epsilon = 0.438
# resultado da epoca 569 = 3.95 Epsilon = 0.437
# resultado da epoca 570 = 4.84 Epsilon = 0.436
# resultado da epoca 571 = 6.32 Epsilon = 0.435
# resultado da epoca 572 = -1.82 Epsilon = 0.434
# resultado da epoca 573 = -3.06 Epsilon = 0.433
# resultado da epoca 574 = 6.42 Epsilon = 0.432
# resultado da epoca 575 = 5.66 Epsilon = 0.431
# resultado da epoca 576 = 2.28 Epsilon = 0.430
# resultado da epoca 577 = -1.39 Epsilon = 0.429
# resultado da epoca 578 = 1.01 Epsilon = 0.428
# resultado da epoca 579 = 7.43 Epsilon = 0.427
# resultado da epoca 580 = -0.08 Epsilon = 0.426
# resultado da epoca 581 = 0.81 Epsilon = 0.425
# resultado da epoca 582 = 0.95 Epsilon = 0.424
# resultado da epoca 583 = -1.82 Epsilon = 0.423
# resultado da epoca 584 = 0.97 Epsilon = 0.422
# resultado da epoca 585 = -7.79 Epsilon = 0.421
# resultado da epoca 586 = 7.59 Epsilon = 0.420
# resultado da epoca 587 = -0.20 Epsilon = 0.419
# resultado da epoca 588 = -0.28 Epsilon = 0.418
# resultado da epoca 589 = -1.98 Epsilon = 0.417
# resultado da epoca 590 = 3.91 Epsilon = 0.416
# resultado da epoca 591 = 5.15 Epsilon = 0.415
# resultado da epoca 592 = -4.76 Epsilon = 0.414
# resultado da epoca 593 = 4.62 Epsilon = 0.413
# resultado da epoca 594 = -2.53 Epsilon = 0.412
# resultado da epoca 595 = 1.27 Epsilon = 0.411
# resultado da epoca 596 = -6.72 Epsilon = 0.410
# resultado da epoca 597 = -3.47 Epsilon = 0.409
# resultado da epoca 598 = -1.78 Epsilon = 0.408
# resultado da epoca 599 = -4.39 Epsilon = 0.407
# resultado da epoca 600 = -6.77 Epsilon = 0.406
# resultado da epoca 601 = -3.42 Epsilon = 0.405
# resultado da epoca 602 = 0.85 Epsilon = 0.404
# resultado da epoca 603 = 2.33 Epsilon = 0.403
# resultado da epoca 604 = 4.35 Epsilon = 0.402
# resultado da epoca 605 = 4.40 Epsilon = 0.401
# resultado da epoca 606 = -0.58 Epsilon = 0.400
# resultado da epoca 607 = 0.15 Epsilon = 0.399
# resultado da epoca 608 = -0.75 Epsilon = 0.398
# resultado da epoca 609 = 3.68 Epsilon = 0.397
# resultado da epoca 610 = -4.06 Epsilon = 0.396
# resultado da epoca 611 = 0.32 Epsilon = 0.395
# resultado da epoca 612 = -2.54 Epsilon = 0.394
# resultado da epoca 613 = -1.61 Epsilon = 0.393
# resultado da epoca 614 = 1.18 Epsilon = 0.392
# resultado da epoca 615 = -8.21 Epsilon = 0.391
# resultado da epoca 616 = -3.27 Epsilon = 0.390
# resultado da epoca 617 = 3.38 Epsilon = 0.389
# resultado da epoca 618 = 1.93 Epsilon = 0.388
# resultado da epoca 619 = 5.68 Epsilon = 0.387
# resultado da epoca 620 = 4.76 Epsilon = 0.386
# resultado da epoca 621 = 0.07 Epsilon = 0.385
# resultado da epoca 622 = -2.14 Epsilon = 0.384
# resultado da epoca 623 = -4.53 Epsilon = 0.383
# resultado da epoca 624 = -0.94 Epsilon = 0.382
# resultado da epoca 625 = -6.31 Epsilon = 0.381
# resultado da epoca 626 = 1.53 Epsilon = 0.380
# resultado da epoca 627 = 1.16 Epsilon = 0.379
# resultado da epoca 628 = 1.78 Epsilon = 0.378
# resultado da epoca 629 = -1.59 Epsilon = 0.377
# resultado da epoca 630 = 4.39 Epsilon = 0.376
# resultado da epoca 631 = 0.98 Epsilon = 0.375
# resultado da epoca 632 = -3.97 Epsilon = 0.374
# resultado da epoca 633 = 0.74 Epsilon = 0.373
# resultado da epoca 634 = 2.44 Epsilon = 0.372
# resultado da epoca 635 = -3.19 Epsilon = 0.371
# resultado da epoca 636 = -1.66 Epsilon = 0.370
# resultado da epoca 637 = 0.60 Epsilon = 0.369
# resultado da epoca 638 = -2.88 Epsilon = 0.368
# resultado da epoca 639 = 5.76 Epsilon = 0.367
# resultado da epoca 640 = -1.00 Epsilon = 0.366
# resultado da epoca 641 = -3.95 Epsilon = 0.365
# resultado da epoca 642 = 0.69 Epsilon = 0.364
# resultado da epoca 643 = -4.37 Epsilon = 0.363
# resultado da epoca 644 = -3.02 Epsilon = 0.362
# resultado da epoca 645 = -1.10 Epsilon = 0.361
# resultado da epoca 646 = 6.67 Epsilon = 0.360
# resultado da epoca 647 = -0.52 Epsilon = 0.359
# resultado da epoca 648 = -1.30 Epsilon = 0.358
# resultado da epoca 649 = -0.99 Epsilon = 0.357
# resultado da epoca 650 = -0.03 Epsilon = 0.356
# resultado da epoca 651 = 3.98 Epsilon = 0.356
# resultado da epoca 652 = -6.47 Epsilon = 0.355
# resultado da epoca 653 = 3.59 Epsilon = 0.354
# resultado da epoca 654 = -6.75 Epsilon = 0.353
# resultado da epoca 655 = -1.68 Epsilon = 0.352
# resultado da epoca 656 = 3.31 Epsilon = 0.351
# resultado da epoca 657 = 2.82 Epsilon = 0.350
# resultado da epoca 658 = 5.39 Epsilon = 0.349
# resultado da epoca 659 = 1.40 Epsilon = 0.348
# resultado da epoca 660 = 3.34 Epsilon = 0.347
# resultado da epoca 661 = -4.64 Epsilon = 0.346
# resultado da epoca 662 = 3.07 Epsilon = 0.345
# resultado da epoca 663 = 2.12 Epsilon = 0.344
# resultado da epoca 664 = 1.95 Epsilon = 0.343
# resultado da epoca 665 = 0.55 Epsilon = 0.342
# resultado da epoca 666 = -2.91 Epsilon = 0.341
# resultado da epoca 667 = -5.90 Epsilon = 0.340
# resultado da epoca 668 = 2.35 Epsilon = 0.339
# resultado da epoca 669 = 1.53 Epsilon = 0.338
# resultado da epoca 670 = 1.96 Epsilon = 0.337
# resultado da epoca 671 = -5.76 Epsilon = 0.336
# resultado da epoca 672 = -0.68 Epsilon = 0.335
# resultado da epoca 673 = -6.73 Epsilon = 0.334
# resultado da epoca 674 = -2.16 Epsilon = 0.333
# resultado da epoca 675 = 3.55 Epsilon = 0.332
# resultado da epoca 676 = 0.33 Epsilon = 0.331
# resultado da epoca 677 = -1.62 Epsilon = 0.330
# resultado da epoca 678 = 4.82 Epsilon = 0.329
# resultado da epoca 679 = 0.58 Epsilon = 0.328
# resultado da epoca 680 = -1.91 Epsilon = 0.327
# resultado da epoca 681 = 1.97 Epsilon = 0.326
# resultado da epoca 682 = -3.19 Epsilon = 0.325
# resultado da epoca 683 = 2.74 Epsilon = 0.324
# resultado da epoca 684 = 1.59 Epsilon = 0.323
# resultado da epoca 685 = 1.43 Epsilon = 0.322
# resultado da epoca 686 = -0.95 Epsilon = 0.321
# resultado da epoca 687 = -1.04 Epsilon = 0.320
# resultado da epoca 688 = 3.39 Epsilon = 0.319
# resultado da epoca 689 = 1.58 Epsilon = 0.318
# resultado da epoca 690 = 0.39 Epsilon = 0.317
# resultado da epoca 691 = -4.51 Epsilon = 0.316
# resultado da epoca 692 = 0.45 Epsilon = 0.315
# resultado da epoca 693 = -5.31 Epsilon = 0.314
# resultado da epoca 694 = -1.26 Epsilon = 0.313
# resultado da epoca 695 = -1.90 Epsilon = 0.312
# resultado da epoca 696 = -1.20 Epsilon = 0.311
# resultado da epoca 697 = -2.21 Epsilon = 0.310
# resultado da epoca 698 = -1.35 Epsilon = 0.309
# resultado da epoca 699 = -3.61 Epsilon = 0.308
# resultado da epoca 700 = -6.06 Epsilon = 0.307
# resultado da epoca 701 = 2.08 Epsilon = 0.306
# resultado da epoca 702 = 1.78 Epsilon = 0.305
# resultado da epoca 703 = -2.26 Epsilon = 0.304
# resultado da epoca 704 = 2.76 Epsilon = 0.303
# resultado da epoca 705 = 1.72 Epsilon = 0.302
# resultado da epoca 706 = -2.19 Epsilon = 0.301
# resultado da epoca 707 = -3.68 Epsilon = 0.300
# resultado da epoca 708 = 0.33 Epsilon = 0.299
# resultado da epoca 709 = -1.52 Epsilon = 0.298
# resultado da epoca 710 = 3.75 Epsilon = 0.297
# resultado da epoca 711 = -3.16 Epsilon = 0.296
# resultado da epoca 712 = 0.22 Epsilon = 0.295
# resultado da epoca 713 = -2.41 Epsilon = 0.294
# resultado da epoca 714 = 0.82 Epsilon = 0.293
# resultado da epoca 715 = -3.44 Epsilon = 0.292
# resultado da epoca 716 = -3.73 Epsilon = 0.291
# resultado da epoca 717 = 1.43 Epsilon = 0.290
# resultado da epoca 718 = 0.88 Epsilon = 0.289
# resultado da epoca 719 = 4.54 Epsilon = 0.288
# resultado da epoca 720 = 0.85 Epsilon = 0.287
# resultado da epoca 721 = 1.85 Epsilon = 0.286
# resultado da epoca 722 = 2.81 Epsilon = 0.285
# resultado da epoca 723 = -1.48 Epsilon = 0.284
# resultado da epoca 724 = -3.13 Epsilon = 0.283
# resultado da epoca 725 = 4.58 Epsilon = 0.282
# resultado da epoca 726 = 0.61 Epsilon = 0.281
# resultado da epoca 727 = -1.19 Epsilon = 0.280
# resultado da epoca 728 = 2.74 Epsilon = 0.279
# resultado da epoca 729 = 0.37 Epsilon = 0.278
# resultado da epoca 730 = 0.03 Epsilon = 0.277
# resultado da epoca 731 = -5.52 Epsilon = 0.276
# resultado da epoca 732 = 2.52 Epsilon = 0.275
# resultado da epoca 733 = 3.73 Epsilon = 0.274
# resultado da epoca 734 = -1.76 Epsilon = 0.273
# resultado da epoca 735 = -0.74 Epsilon = 0.272
# resultado da epoca 736 = -4.91 Epsilon = 0.271
# resultado da epoca 737 = -1.42 Epsilon = 0.270
# resultado da epoca 738 = 6.31 Epsilon = 0.269
# resultado da epoca 739 = 2.75 Epsilon = 0.268
# resultado da epoca 740 = 3.95 Epsilon = 0.267
# resultado da epoca 741 = 1.96 Epsilon = 0.266
# resultado da epoca 742 = -5.42 Epsilon = 0.265
# resultado da epoca 743 = 2.98 Epsilon = 0.264
# resultado da epoca 744 = 1.23 Epsilon = 0.263
# resultado da epoca 745 = 0.92 Epsilon = 0.262
# resultado da epoca 746 = -3.99 Epsilon = 0.261
# resultado da epoca 747 = 2.31 Epsilon = 0.260
# resultado da epoca 748 = 7.50 Epsilon = 0.259
# resultado da epoca 749 = -0.79 Epsilon = 0.258
# resultado da epoca 750 = 4.26 Epsilon = 0.257
# resultado da epoca 751 = -0.76 Epsilon = 0.257
# resultado da epoca 752 = 1.02 Epsilon = 0.256
# resultado da epoca 753 = -0.32 Epsilon = 0.255
# resultado da epoca 754 = 3.54 Epsilon = 0.254
# resultado da epoca 755 = -0.95 Epsilon = 0.253
# resultado da epoca 756 = -3.58 Epsilon = 0.252
# resultado da epoca 757 = 1.85 Epsilon = 0.251
# resultado da epoca 758 = -2.53 Epsilon = 0.250
# resultado da epoca 759 = 2.30 Epsilon = 0.249
# resultado da epoca 760 = 2.71 Epsilon = 0.248
# resultado da epoca 761 = 2.77 Epsilon = 0.247
# resultado da epoca 762 = -2.99 Epsilon = 0.246
# resultado da epoca 763 = 0.91 Epsilon = 0.245
# resultado da epoca 764 = -0.71 Epsilon = 0.244
# resultado da epoca 765 = 1.90 Epsilon = 0.243
# resultado da epoca 766 = 3.55 Epsilon = 0.242
# resultado da epoca 767 = 1.37 Epsilon = 0.241
# resultado da epoca 768 = -1.10 Epsilon = 0.240
# resultado da epoca 769 = -2.18 Epsilon = 0.239
# resultado da epoca 770 = 0.79 Epsilon = 0.238
# resultado da epoca 771 = 2.30 Epsilon = 0.237
# resultado da epoca 772 = 0.29 Epsilon = 0.236
# resultado da epoca 773 = 1.04 Epsilon = 0.235
# resultado da epoca 774 = -0.43 Epsilon = 0.234
# resultado da epoca 775 = 2.23 Epsilon = 0.233
# resultado da epoca 776 = -3.66 Epsilon = 0.232
# resultado da epoca 777 = -0.21 Epsilon = 0.231
# resultado da epoca 778 = -5.97 Epsilon = 0.230
# resultado da epoca 779 = -0.24 Epsilon = 0.229
# resultado da epoca 780 = 4.97 Epsilon = 0.228
# resultado da epoca 781 = 3.03 Epsilon = 0.227
# resultado da epoca 782 = 5.33 Epsilon = 0.226
# resultado da epoca 783 = -4.97 Epsilon = 0.225
# resultado da epoca 784 = 0.05 Epsilon = 0.224
# resultado da epoca 785 = -2.03 Epsilon = 0.223
# resultado da epoca 786 = 1.53 Epsilon = 0.222
# resultado da epoca 787 = -3.52 Epsilon = 0.221
# resultado da epoca 788 = 0.50 Epsilon = 0.220
# resultado da epoca 789 = 3.31 Epsilon = 0.219
# resultado da epoca 790 = 1.25 Epsilon = 0.218
# resultado da epoca 791 = -1.35 Epsilon = 0.217
# resultado da epoca 792 = -1.10 Epsilon = 0.216
# resultado da epoca 793 = -1.44 Epsilon = 0.215
# resultado da epoca 794 = -1.75 Epsilon = 0.214
# resultado da epoca 795 = 1.75 Epsilon = 0.213
# resultado da epoca 796 = -2.18 Epsilon = 0.212
# resultado da epoca 797 = -0.26 Epsilon = 0.211
# resultado da epoca 798 = 2.45 Epsilon = 0.210
# resultado da epoca 799 = 1.29 Epsilon = 0.209
# resultado da epoca 800 = 1.42 Epsilon = 0.208
# resultado da epoca 801 = -1.79 Epsilon = 0.207
# resultado da epoca 802 = -0.18 Epsilon = 0.206
# resultado da epoca 803 = 1.97 Epsilon = 0.205
# resultado da epoca 804 = -3.99 Epsilon = 0.204
# resultado da epoca 805 = -1.90 Epsilon = 0.203
# resultado da epoca 806 = 3.64 Epsilon = 0.202
# resultado da epoca 807 = 0.69 Epsilon = 0.201
# resultado da epoca 808 = -3.60 Epsilon = 0.200
# resultado da epoca 809 = -0.45 Epsilon = 0.199
# resultado da epoca 810 = -0.07 Epsilon = 0.198
# resultado da epoca 811 = -2.10 Epsilon = 0.197
# resultado da epoca 812 = 1.42 Epsilon = 0.196
# resultado da epoca 813 = 0.10 Epsilon = 0.195
# resultado da epoca 814 = -0.81 Epsilon = 0.194
# resultado da epoca 815 = -2.29 Epsilon = 0.193
# resultado da epoca 816 = -1.72 Epsilon = 0.192
# resultado da epoca 817 = -2.08 Epsilon = 0.191
# resultado da epoca 818 = -2.02 Epsilon = 0.190
# resultado da epoca 819 = 1.30 Epsilon = 0.189
# resultado da epoca 820 = 0.81 Epsilon = 0.188
# resultado da epoca 821 = 1.28 Epsilon = 0.187
# resultado da epoca 822 = 3.50 Epsilon = 0.186
# resultado da epoca 823 = 0.23 Epsilon = 0.185
# resultado da epoca 824 = -3.79 Epsilon = 0.184
# resultado da epoca 825 = -3.56 Epsilon = 0.183
# resultado da epoca 826 = -2.30 Epsilon = 0.182
# resultado da epoca 827 = 2.62 Epsilon = 0.181
# resultado da epoca 828 = -3.40 Epsilon = 0.180
# resultado da epoca 829 = 0.83 Epsilon = 0.179
# resultado da epoca 830 = -0.78 Epsilon = 0.178
# resultado da epoca 831 = -1.92 Epsilon = 0.177
# resultado da epoca 832 = -0.24 Epsilon = 0.176
# resultado da epoca 833 = -0.87 Epsilon = 0.175
# resultado da epoca 834 = -1.05 Epsilon = 0.174
# resultado da epoca 835 = 2.03 Epsilon = 0.173
# resultado da epoca 836 = -2.59 Epsilon = 0.172
# resultado da epoca 837 = -1.91 Epsilon = 0.171
# resultado da epoca 838 = 0.46 Epsilon = 0.170
# resultado da epoca 839 = 0.45 Epsilon = 0.169
# resultado da epoca 840 = 0.45 Epsilon = 0.168
# resultado da epoca 841 = -0.95 Epsilon = 0.167
# resultado da epoca 842 = -1.72 Epsilon = 0.166
# resultado da epoca 843 = 5.11 Epsilon = 0.165
# resultado da epoca 844 = 2.07 Epsilon = 0.164
# resultado da epoca 845 = -1.35 Epsilon = 0.163
# resultado da epoca 846 = -0.56 Epsilon = 0.162
# resultado da epoca 847 = 0.24 Epsilon = 0.161
# resultado da epoca 848 = -1.05 Epsilon = 0.160
# resultado da epoca 849 = 0.19 Epsilon = 0.159
# resultado da epoca 850 = -1.90 Epsilon = 0.158
# resultado da epoca 851 = 4.64 Epsilon = 0.158
# resultado da epoca 852 = 0.23 Epsilon = 0.157
# resultado da epoca 853 = 0.10 Epsilon = 0.156
# resultado da epoca 854 = -1.93 Epsilon = 0.155
# resultado da epoca 855 = 1.45 Epsilon = 0.154
# resultado da epoca 856 = -2.05 Epsilon = 0.153
# resultado da epoca 857 = 1.50 Epsilon = 0.152
# resultado da epoca 858 = 0.73 Epsilon = 0.151
# resultado da epoca 859 = -0.04 Epsilon = 0.150
# resultado da epoca 860 = -1.15 Epsilon = 0.149
# resultado da epoca 861 = -3.11 Epsilon = 0.148
# resultado da epoca 862 = 0.51 Epsilon = 0.147
# resultado da epoca 863 = -1.28 Epsilon = 0.146
# resultado da epoca 864 = -1.60 Epsilon = 0.145
# resultado da epoca 865 = 4.14 Epsilon = 0.144
# resultado da epoca 866 = -3.50 Epsilon = 0.143
# resultado da epoca 867 = -2.10 Epsilon = 0.142
# resultado da epoca 868 = -0.01 Epsilon = 0.141
# resultado da epoca 869 = 0.27 Epsilon = 0.140
# resultado da epoca 870 = -1.19 Epsilon = 0.139
# resultado da epoca 871 = 1.16 Epsilon = 0.138
# resultado da epoca 872 = -0.63 Epsilon = 0.137
# resultado da epoca 873 = -0.79 Epsilon = 0.136
# resultado da epoca 874 = -1.56 Epsilon = 0.135
# resultado da epoca 875 = 1.85 Epsilon = 0.134
# resultado da epoca 876 = 0.12 Epsilon = 0.133
# resultado da epoca 877 = 1.02 Epsilon = 0.132
# resultado da epoca 878 = 0.66 Epsilon = 0.131
# resultado da epoca 879 = 5.07 Epsilon = 0.130
# resultado da epoca 880 = 0.30 Epsilon = 0.129
# resultado da epoca 881 = -0.15 Epsilon = 0.128
# resultado da epoca 882 = -2.56 Epsilon = 0.127
# resultado da epoca 883 = 1.72 Epsilon = 0.126
# resultado da epoca 884 = 0.96 Epsilon = 0.125
# resultado da epoca 885 = -2.23 Epsilon = 0.124
# resultado da epoca 886 = -2.41 Epsilon = 0.123
# resultado da epoca 887 = 0.68 Epsilon = 0.122
# resultado da epoca 888 = -1.16 Epsilon = 0.121
# resultado da epoca 889 = 4.43 Epsilon = 0.120
# resultado da epoca 890 = -0.89 Epsilon = 0.119
# resultado da epoca 891 = -1.85 Epsilon = 0.118
# resultado da epoca 892 = -0.01 Epsilon = 0.117
# resultado da epoca 893 = -1.89 Epsilon = 0.116
# resultado da epoca 894 = -1.19 Epsilon = 0.115
# resultado da epoca 895 = -0.35 Epsilon = 0.114
# resultado da epoca 896 = 1.06 Epsilon = 0.113
# resultado da epoca 897 = -0.41 Epsilon = 0.112
# resultado da epoca 898 = -1.07 Epsilon = 0.111
# resultado da epoca 899 = 2.00 Epsilon = 0.110
# resultado da epoca 900 = 0.51 Epsilon = 0.109
# resultado da epoca 901 = 0.16 Epsilon = 0.108
# resultado da epoca 902 = -1.55 Epsilon = 0.107
# resultado da epoca 903 = -1.61 Epsilon = 0.106
# resultado da epoca 904 = 2.46 Epsilon = 0.105
# resultado da epoca 905 = -0.06 Epsilon = 0.104
# resultado da epoca 906 = 0.15 Epsilon = 0.103
# resultado da epoca 907 = 2.03 Epsilon = 0.102
# resultado da epoca 908 = 1.04 Epsilon = 0.101
# resultado da epoca 909 = -2.12 Epsilon = 0.100
# resultado da epoca 910 = 1.06 Epsilon = 0.099
# resultado da epoca 911 = 0.06 Epsilon = 0.098
# resultado da epoca 912 = 2.58 Epsilon = 0.097
# resultado da epoca 913 = -0.42 Epsilon = 0.096
# resultado da epoca 914 = 0.14 Epsilon = 0.095
# resultado da epoca 915 = 1.39 Epsilon = 0.094
# resultado da epoca 916 = 0.79 Epsilon = 0.093
# resultado da epoca 917 = 1.23 Epsilon = 0.092
# resultado da epoca 918 = 0.77 Epsilon = 0.091
# resultado da epoca 919 = 1.01 Epsilon = 0.090
# resultado da epoca 920 = 0.60 Epsilon = 0.089
# resultado da epoca 921 = 0.24 Epsilon = 0.088
# resultado da epoca 922 = -1.04 Epsilon = 0.087
# resultado da epoca 923 = -0.66 Epsilon = 0.086
# resultado da epoca 924 = 2.23 Epsilon = 0.085
# resultado da epoca 925 = 1.55 Epsilon = 0.084
# resultado da epoca 926 = 1.84 Epsilon = 0.083
# resultado da epoca 927 = 0.81 Epsilon = 0.082
# resultado da epoca 928 = 1.65 Epsilon = 0.081
# resultado da epoca 929 = 4.54 Epsilon = 0.080
# resultado da epoca 930 = 1.49 Epsilon = 0.079
# resultado da epoca 931 = 0.56 Epsilon = 0.078
# resultado da epoca 932 = -1.69 Epsilon = 0.077
# resultado da epoca 933 = -0.04 Epsilon = 0.076
# resultado da epoca 934 = 0.63 Epsilon = 0.075
# resultado da epoca 935 = 1.15 Epsilon = 0.074
# resultado da epoca 936 = 1.65 Epsilon = 0.073
# resultado da epoca 937 = -0.35 Epsilon = 0.072
# resultado da epoca 938 = 0.41 Epsilon = 0.071
# resultado da epoca 939 = -0.05 Epsilon = 0.070
# resultado da epoca 940 = 1.07 Epsilon = 0.069
# resultado da epoca 941 = -0.31 Epsilon = 0.068
# resultado da epoca 942 = -2.73 Epsilon = 0.067
# resultado da epoca 943 = 1.81 Epsilon = 0.066
# resultado da epoca 944 = -1.52 Epsilon = 0.065
# resultado da epoca 945 = -1.12 Epsilon = 0.064
# resultado da epoca 946 = 1.38 Epsilon = 0.063
# resultado da epoca 947 = 1.00 Epsilon = 0.062
# resultado da epoca 948 = -2.17 Epsilon = 0.061
# resultado da epoca 949 = -0.11 Epsilon = 0.060
# resultado da epoca 950 = 1.49 Epsilon = 0.059
# resultado da epoca 951 = -1.17 Epsilon = 0.059
# resultado da epoca 952 = -0.22 Epsilon = 0.058
# resultado da epoca 953 = -1.16 Epsilon = 0.057
# resultado da epoca 954 = -0.90 Epsilon = 0.056
# resultado da epoca 955 = -0.41 Epsilon = 0.055
# resultado da epoca 956 = 0.47 Epsilon = 0.054
# resultado da epoca 957 = 1.68 Epsilon = 0.053
# resultado da epoca 958 = 2.07 Epsilon = 0.052
# resultado da epoca 959 = -2.21 Epsilon = 0.051
# resultado da epoca 960 = 0.16 Epsilon = 0.050
# resultado da epoca 961 = -2.78 Epsilon = 0.049
# resultado da epoca 962 = 0.34 Epsilon = 0.048
# resultado da epoca 963 = 1.05 Epsilon = 0.047
# resultado da epoca 964 = 0.89 Epsilon = 0.046
# resultado da epoca 965 = 0.61 Epsilon = 0.045
# resultado da epoca 966 = -0.37 Epsilon = 0.044
# resultado da epoca 967 = 1.09 Epsilon = 0.043
# resultado da epoca 968 = 0.31 Epsilon = 0.042
# resultado da epoca 969 = -0.76 Epsilon = 0.041
# resultado da epoca 970 = 0.21 Epsilon = 0.040
# resultado da epoca 971 = 0.36 Epsilon = 0.039
# resultado da epoca 972 = 0.39 Epsilon = 0.038
# resultado da epoca 973 = -0.35 Epsilon = 0.037
# resultado da epoca 974 = 0.26 Epsilon = 0.036
# resultado da epoca 975 = 0.43 Epsilon = 0.035
# resultado da epoca 976 = -0.39 Epsilon = 0.034
# resultado da epoca 977 = -1.60 Epsilon = 0.033
# resultado da epoca 978 = 1.13 Epsilon = 0.032
# resultado da epoca 979 = 0.24 Epsilon = 0.031
# resultado da epoca 980 = -1.89 Epsilon = 0.030
# resultado da epoca 981 = 0.32 Epsilon = 0.029
# resultado da epoca 982 = 0.98 Epsilon = 0.028
# resultado da epoca 983 = 0.23 Epsilon = 0.027
# resultado da epoca 984 = 0.19 Epsilon = 0.026
# resultado da epoca 985 = -0.18 Epsilon = 0.025
# resultado da epoca 986 = 0.07 Epsilon = 0.024
# resultado da epoca 987 = -0.52 Epsilon = 0.023
# resultado da epoca 988 = 0.07 Epsilon = 0.022
# resultado da epoca 989 = -0.83 Epsilon = 0.021
# resultado da epoca 990 = -0.34 Epsilon = 0.020
# resultado da epoca 991 = -0.49 Epsilon = 0.019
# resultado da epoca 992 = -0.43 Epsilon = 0.018
# resultado da epoca 993 = 0.45 Epsilon = 0.017
# resultado da epoca 994 = -0.11 Epsilon = 0.016
# resultado da epoca 995 = 0.52 Epsilon = 0.015
# resultado da epoca 996 = 0.89 Epsilon = 0.014
# resultado da epoca 997 = 0.12 Epsilon = 0.013
# resultado da epoca 998 = -0.59 Epsilon = 0.012
# resultado da epoca 999 = -0.66 Epsilon = 0.011
# Melhor resultado diario: 4.01

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo))
# Out:
# 0.0

# %%
np.amax(inputs['preco'])
# Out:
# 1.7324562139544168

# %%
plt.plot(range(0,len(inputs)), inputs['preco'])

# %%
plt.plot(range(0,len(inputs_nao_norm)), inputs_nao_norm['preco'])

# %%
pstd
# Out:
# 151.02816834876631

# %%
pmean
# Out:
# 3950.350311262026

# %%
(4200-pmean)/pstd
# Out:
# 1.6530008373104477

# %%
np.std(inputs_nao_norm['preco'])
# Out:
# 130.87810760032863
