# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma']#, 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 500 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 250

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
inputs_nao_norm = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1
print(inputs)
#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
       
    inputs.loc[:, inputs.columns[i]] = inputs.loc[:, inputs.columns[i]] - imean 

valor0 = np.amin(inputs['preco']) - 500
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         preco    hr_int  preco_pon  qnt_soma
# 0      3907.5  32700000    3907.50       1.0
# 1      3900.0  33000000    3901.26   20309.0
# 2      3898.0  33300000    3901.42   17614.0
# 3      3898.0  33600000    3895.37   14283.0
# 4      3899.5  33900000    3897.78    6638.0
# 5      3906.0  34200000    3902.52   13485.0
# 6      3908.0  34500000    3907.20   12677.0
# 7      3913.0  34800000    3910.72   17927.0
# 8      3906.0  35100000    3909.27   18032.0
# 9      3902.0  35400000    3904.82   17600.0
# 10     3900.5  35700000    3900.53    9326.0
# 11     3894.0  36000000    3896.53   18013.0
# 12     3897.5  36300000    3897.41   14159.0
# 13     3900.0  36600000    3897.87    5793.0
# 14     3906.0  36900000    3902.17   15901.0
# 15     3907.5  37200000    3905.68   12928.0
# 16     3908.0  37500000    3908.40    7904.0
# 17     3911.0  37800000    3909.38    7750.0
# 18     3911.0  38100000    3912.43   10917.0
# 19     3908.5  38400000    3910.42    8978.0
# 20     3916.5  38700000    3913.49   12775.0
# 21     3914.0  39000000    3915.66    7874.0
# 22     3912.0  39300000    3913.06    6877.0
# 23     3910.5  39600000    3910.59    6747.0
# 24     3917.5  39900000    3914.81   12360.0
# 25     3914.0  40200000    3915.96    8289.0
# 26     3918.5  40500000    3916.91    6028.0
# 27     3918.0  40800000    3917.95    4025.0
# 28     3918.5  41100000    3917.52    4618.0
# 29     3917.5  41400000    3917.21    2747.0
# ...       ...       ...        ...       ...
# 30074  4076.5  55500000    4076.10    9242.0
# 30075  4076.5  55800000    4076.64    4228.0
# 30076  4076.0  56100000    4075.85    3009.0
# 30077  4078.5  56400000    4077.82    9162.0
# 30078  4078.0  56700000    4078.75    5166.0
# 30079  4080.0  57000000    4078.75    4928.0
# 30080  4083.0  57300000    4081.52    9979.0
# 30081  4078.0  57600000    4080.32   17157.0
# 30082  4077.5  57900000    4078.53    5130.0
# 30083  4077.5  58200000    4077.40    3576.0
# 30084  4075.0  58500000    4075.73    7682.0
# 30085  4077.0  58800000    4076.49    3760.0
# 30086  4075.5  59100000    4076.04    2943.0
# 30087  4080.5  59400000    4078.23    7689.0
# 30088  4079.5  59700000    4080.42    9414.0
# 30089  4081.5  60000000    4079.69    8811.0
# 30090  4082.5  60300000    4081.89    8741.0
# 30091  4083.5  60600000    4083.25    6228.0
# 30092  4084.0  60900000    4083.63    3415.0
# 30093  4085.5  61200000    4084.95    5914.0
# 30094  4081.0  61500000    4083.09    7944.0
# 30095  4079.5  61800000    4080.75    5461.0
# 30096  4078.0  62100000    4079.08    4891.0
# 30097  4079.0  62400000    4078.74    2705.0
# 30098  4077.5  62700000    4078.02    2231.0
# 30099  4074.0  63000000    4074.69    9221.0
# 30100  4071.5  63300000    4071.88    5389.0
# 30101  4071.0  63600000    4070.23    5930.0
# 30102  4069.0  63900000    4071.37    5387.0
# 30103  4068.5  64200000    4069.33    4407.0
#
# [30104 rows x 4 columns]
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 5
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.98     # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(512, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(196, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)        
        model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(64, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(32, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        
        #model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(x*3, activation='relu')) #camada escondida
        #model.add(Dense(x*2, activation='relu')) #camada escondida
        #model.add(Dense(x, activation='relu')) #camada escondida
        #model.add(Dense(64, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size) if dias>5 else self.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3072
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 196)               50372
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               25216
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 11)                363
# =================================================================
# Total params: 286,479
# Trainable params: 286,479
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(preco, ncont, acao, valor, custo=0):   

    if acao == 0: #zerado
        if ncont>0:  #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        elif ncont<0: #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        else:         
            reward = 0
        valor = valor0
    elif acao>0:  #comprado
        if ncont>0:
            if acao>ncont: #aumento da posicao
                reward = -custo*(acao-ncont)
                valor = (valor*ncont+(acao-ncont)*preco)/(acao)  #calculo preco medio
            elif acao<ncont:  #diminuicao da posicao
                reward = (ncont-acao)*(preco-valor) -custo*(ncont-acao)
                valor = valor #preco medio se mantem
            else:
                reward = 0
        elif ncont<0:   #trocando a mao
            reward = abs(ncont)*(valor-preco) -custo*(acao+abs(ncont))
            valor = preco
        else:          #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
    else:       #vendido
        if ncont>0:#trocando a mao
            reward = ncont*(preco-valor) -custo*(ncont+abs(acao))
            valor = preco
        elif ncont<0:
            if abs(acao)<abs(ncont): #diminuicao da posicao
                reward = (abs(ncont)-abs(acao))*(valor-preco) -custo*(abs(ncont)-abs(acao))
                valor = valor #preco medio se mantem
            elif abs(acao)>abs(ncont): #aumento da posicao
                reward = -custo*(abs(acao)-abs(ncont))
                valor = (valor*abs(ncont)+(abs(acao)-abs(ncont))*preco)/(abs(acao))  #calculo preco medio
            else: #preco medio se mantem
                reward = 0
        else:  #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
                
    #reward = ncont*acao*preco
    ncont = acao
    posicao = ncont*(preco-valor) -custo*abs(ncont) if ncont!=0 else 0.
    return ncont, reward, valor, posicao

def obter_acao():
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = valor0 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    indice = 0
    lucro = 0.
    posicao = 0. #cria variavel de posicao 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont, indice, precos['preco'][step], valor, precos['preco_pon'][step]], (1,modelo.state_size))
        
        acao = obter_acao()
        ncont, reward, valor, posicao = teste(precos['preco'][step], ncont, acao, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor*pstd+pmean if valor!=-100 else 0
        #p=precos['preco'][step]+pmean
        #print("acao={0}; ncont={1}; reward={2} valor={3} preco={4}".format(acao, ncont, reward, valor, precos['preco'][step]))   

        if step == (steps[dia+1] - 1): #se ultimo step do dia
            done = True     
        
        modelo.next_state = np.reshape([ncont, indice+1, precos['preco'][step+1], valor, precos['preco_pon'][step+1]], (1,modelo.state_size))
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        indice += 1
        
    #fim do dia
    lucro +=posicao
    
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo, dia_inicial, n_dias):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( dia_inicial, dia_inicial+n_dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        
        minibatch = modelo.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    melhor_reward = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo, 0, dias) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1116 01:25:20.396186  7440 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1116 01:25:40.182318  7440 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1116 01:25:40.222320  7440 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = 1774.00 Epsilon = 1.000
# resultado da epoca 1 = -1633.00 Epsilon = 0.998
# resultado da epoca 2 = -55.50 Epsilon = 0.996
# resultado da epoca 3 = -879.00 Epsilon = 0.994
# resultado da epoca 4 = 823.50 Epsilon = 0.992
# resultado da epoca 5 = -1937.50 Epsilon = 0.990
# resultado da epoca 6 = -94.50 Epsilon = 0.988
# resultado da epoca 7 = -1710.00 Epsilon = 0.986
# resultado da epoca 8 = 3553.50 Epsilon = 0.984
# resultado da epoca 9 = 237.00 Epsilon = 0.982
# resultado da epoca 10 = 470.50 Epsilon = 0.980
# resultado da epoca 11 = -2296.00 Epsilon = 0.978
# resultado da epoca 12 = 218.00 Epsilon = 0.976
# resultado da epoca 13 = -3123.50 Epsilon = 0.974
# resultado da epoca 14 = 2068.50 Epsilon = 0.972
# resultado da epoca 15 = 621.50 Epsilon = 0.970
# resultado da epoca 16 = -672.00 Epsilon = 0.968
# resultado da epoca 17 = -989.50 Epsilon = 0.966
# resultado da epoca 18 = -46.50 Epsilon = 0.964
# resultado da epoca 19 = 2657.00 Epsilon = 0.962
# resultado da epoca 20 = -1097.50 Epsilon = 0.960
# resultado da epoca 21 = 35.50 Epsilon = 0.958
# resultado da epoca 22 = -91.00 Epsilon = 0.956
# resultado da epoca 23 = 2076.00 Epsilon = 0.954
# resultado da epoca 24 = 1690.50 Epsilon = 0.952
# resultado da epoca 25 = -426.00 Epsilon = 0.951
# resultado da epoca 26 = 202.50 Epsilon = 0.949
# resultado da epoca 27 = -1528.50 Epsilon = 0.947
# resultado da epoca 28 = -275.50 Epsilon = 0.945
# resultado da epoca 29 = 1347.00 Epsilon = 0.943
# resultado da epoca 30 = -1319.00 Epsilon = 0.941
# resultado da epoca 31 = 2682.50 Epsilon = 0.939
# resultado da epoca 32 = -2234.50 Epsilon = 0.937
# resultado da epoca 33 = -970.50 Epsilon = 0.935
# resultado da epoca 34 = -1013.00 Epsilon = 0.933
# resultado da epoca 35 = -75.00 Epsilon = 0.931
# resultado da epoca 36 = 1616.50 Epsilon = 0.929
# resultado da epoca 37 = -149.00 Epsilon = 0.927
# resultado da epoca 38 = -2113.00 Epsilon = 0.925
# resultado da epoca 39 = 641.50 Epsilon = 0.923
# resultado da epoca 40 = 1181.00 Epsilon = 0.921
# resultado da epoca 41 = 953.50 Epsilon = 0.919
# resultado da epoca 42 = -2491.00 Epsilon = 0.917
# resultado da epoca 43 = -204.00 Epsilon = 0.915
# resultado da epoca 44 = -543.00 Epsilon = 0.913
# resultado da epoca 45 = 1946.50 Epsilon = 0.911
# resultado da epoca 46 = -1354.00 Epsilon = 0.909
# resultado da epoca 47 = -421.50 Epsilon = 0.907
# resultado da epoca 48 = 1881.00 Epsilon = 0.905
# resultado da epoca 49 = -3606.50 Epsilon = 0.903
# resultado da epoca 50 = 948.50 Epsilon = 0.901
# resultado da epoca 51 = -738.50 Epsilon = 0.899
# resultado da epoca 52 = 1185.00 Epsilon = 0.897
# resultado da epoca 53 = 255.50 Epsilon = 0.895
# resultado da epoca 54 = 504.50 Epsilon = 0.893
# resultado da epoca 55 = -2195.50 Epsilon = 0.891
# resultado da epoca 56 = 318.50 Epsilon = 0.889
# resultado da epoca 57 = 1096.00 Epsilon = 0.887
# resultado da epoca 58 = -1548.50 Epsilon = 0.885
# resultado da epoca 59 = 1617.00 Epsilon = 0.883
# resultado da epoca 60 = -1.00 Epsilon = 0.881
# resultado da epoca 61 = 1697.50 Epsilon = 0.879
# resultado da epoca 62 = -386.50 Epsilon = 0.877
# resultado da epoca 63 = 223.00 Epsilon = 0.875
# resultado da epoca 64 = -1221.00 Epsilon = 0.873
# resultado da epoca 65 = 886.00 Epsilon = 0.871
# resultado da epoca 66 = 3975.50 Epsilon = 0.869
# resultado da epoca 67 = -1117.50 Epsilon = 0.867
# resultado da epoca 68 = -1556.00 Epsilon = 0.865
# resultado da epoca 69 = -260.00 Epsilon = 0.863
# resultado da epoca 70 = 1401.50 Epsilon = 0.861
# resultado da epoca 71 = 1287.00 Epsilon = 0.859
# resultado da epoca 72 = -2210.50 Epsilon = 0.857
# resultado da epoca 73 = 2879.50 Epsilon = 0.855
# resultado da epoca 74 = 2305.50 Epsilon = 0.853
# resultado da epoca 75 = 1433.50 Epsilon = 0.852
# resultado da epoca 76 = 2780.50 Epsilon = 0.850
# resultado da epoca 77 = 223.00 Epsilon = 0.848
# resultado da epoca 78 = 957.00 Epsilon = 0.846
# resultado da epoca 79 = 275.00 Epsilon = 0.844
# resultado da epoca 80 = -2603.50 Epsilon = 0.842
# resultado da epoca 81 = -3098.00 Epsilon = 0.840
# resultado da epoca 82 = -1397.00 Epsilon = 0.838
# resultado da epoca 83 = -1909.00 Epsilon = 0.836
# resultado da epoca 84 = -180.50 Epsilon = 0.834
# resultado da epoca 85 = -1888.00 Epsilon = 0.832
# resultado da epoca 86 = -446.50 Epsilon = 0.830
# resultado da epoca 87 = -1214.50 Epsilon = 0.828
# resultado da epoca 88 = -211.50 Epsilon = 0.826
# resultado da epoca 89 = -2908.00 Epsilon = 0.824
# resultado da epoca 90 = 2860.00 Epsilon = 0.822
# resultado da epoca 91 = 589.50 Epsilon = 0.820
# resultado da epoca 92 = -2106.50 Epsilon = 0.818
# resultado da epoca 93 = -327.50 Epsilon = 0.816
# resultado da epoca 94 = 2936.50 Epsilon = 0.814
# resultado da epoca 95 = -849.50 Epsilon = 0.812
# resultado da epoca 96 = -2986.50 Epsilon = 0.810
# resultado da epoca 97 = 355.00 Epsilon = 0.808
# resultado da epoca 98 = -4805.00 Epsilon = 0.806
# resultado da epoca 99 = -646.50 Epsilon = 0.804
# resultado da epoca 100 = -1482.00 Epsilon = 0.802
# resultado da epoca 101 = 1345.50 Epsilon = 0.800
# resultado da epoca 102 = 2118.50 Epsilon = 0.798
# resultado da epoca 103 = -949.50 Epsilon = 0.796
# resultado da epoca 104 = -2234.00 Epsilon = 0.794
# resultado da epoca 105 = 1950.00 Epsilon = 0.792
# resultado da epoca 106 = -62.50 Epsilon = 0.790
# resultado da epoca 107 = -226.50 Epsilon = 0.788
# resultado da epoca 108 = 3447.00 Epsilon = 0.786
# resultado da epoca 109 = 126.50 Epsilon = 0.784
# resultado da epoca 110 = -1822.50 Epsilon = 0.782
# resultado da epoca 111 = -922.00 Epsilon = 0.780
# resultado da epoca 112 = -2995.00 Epsilon = 0.778
# resultado da epoca 113 = 1374.00 Epsilon = 0.776
# resultado da epoca 114 = 2149.00 Epsilon = 0.774
# resultado da epoca 115 = 227.00 Epsilon = 0.772
# resultado da epoca 116 = 678.50 Epsilon = 0.770
# resultado da epoca 117 = -736.00 Epsilon = 0.768
# resultado da epoca 118 = 1425.00 Epsilon = 0.766
# resultado da epoca 119 = 4856.00 Epsilon = 0.764
# resultado da epoca 120 = 3718.50 Epsilon = 0.762
# resultado da epoca 121 = -2043.00 Epsilon = 0.760
# resultado da epoca 122 = 532.50 Epsilon = 0.758
# resultado da epoca 123 = -971.50 Epsilon = 0.756
# resultado da epoca 124 = 871.50 Epsilon = 0.754
# resultado da epoca 125 = -2237.50 Epsilon = 0.753
# resultado da epoca 126 = -346.50 Epsilon = 0.751
# resultado da epoca 127 = -3047.50 Epsilon = 0.749
# resultado da epoca 128 = 178.00 Epsilon = 0.747
# resultado da epoca 129 = -1435.00 Epsilon = 0.745
# resultado da epoca 130 = -1408.00 Epsilon = 0.743
# resultado da epoca 131 = 748.50 Epsilon = 0.741
# resultado da epoca 132 = 375.50 Epsilon = 0.739
# resultado da epoca 133 = -1842.50 Epsilon = 0.737
# resultado da epoca 134 = -506.50 Epsilon = 0.735
# resultado da epoca 135 = -611.00 Epsilon = 0.733
# resultado da epoca 136 = 655.00 Epsilon = 0.731
# resultado da epoca 137 = -2404.50 Epsilon = 0.729
# resultado da epoca 138 = 804.50 Epsilon = 0.727
# resultado da epoca 139 = -542.50 Epsilon = 0.725
# resultado da epoca 140 = 32.50 Epsilon = 0.723
# resultado da epoca 141 = -752.00 Epsilon = 0.721
# resultado da epoca 142 = 796.50 Epsilon = 0.719
# resultado da epoca 143 = -1741.00 Epsilon = 0.717
# resultado da epoca 144 = -2181.00 Epsilon = 0.715
# resultado da epoca 145 = -1267.50 Epsilon = 0.713
# resultado da epoca 146 = -2851.00 Epsilon = 0.711
# resultado da epoca 147 = 1579.50 Epsilon = 0.709
# resultado da epoca 148 = -405.50 Epsilon = 0.707
# resultado da epoca 149 = -592.50 Epsilon = 0.705
# resultado da epoca 150 = -3122.00 Epsilon = 0.703
# resultado da epoca 151 = -2360.50 Epsilon = 0.701
# resultado da epoca 152 = 194.00 Epsilon = 0.699
# resultado da epoca 153 = 1093.50 Epsilon = 0.697
# resultado da epoca 154 = 978.50 Epsilon = 0.695
# resultado da epoca 155 = -2679.50 Epsilon = 0.693
# resultado da epoca 156 = -2185.50 Epsilon = 0.691
# resultado da epoca 157 = -1139.00 Epsilon = 0.689
# resultado da epoca 158 = -2766.00 Epsilon = 0.687
# resultado da epoca 159 = 930.00 Epsilon = 0.685
# resultado da epoca 160 = 389.00 Epsilon = 0.683
# resultado da epoca 161 = 2125.50 Epsilon = 0.681
# resultado da epoca 162 = 232.00 Epsilon = 0.679
# resultado da epoca 163 = -1528.50 Epsilon = 0.677
# resultado da epoca 164 = -964.50 Epsilon = 0.675
# resultado da epoca 165 = 2250.50 Epsilon = 0.673
# resultado da epoca 166 = -78.50 Epsilon = 0.671
# resultado da epoca 167 = -462.50 Epsilon = 0.669
# resultado da epoca 168 = 361.00 Epsilon = 0.667
# resultado da epoca 169 = 1795.50 Epsilon = 0.665
# resultado da epoca 170 = -168.00 Epsilon = 0.663
# resultado da epoca 171 = -2066.00 Epsilon = 0.661
# resultado da epoca 172 = 2221.00 Epsilon = 0.659
# resultado da epoca 173 = -2220.00 Epsilon = 0.657
# resultado da epoca 174 = 2053.00 Epsilon = 0.655
# resultado da epoca 175 = -633.50 Epsilon = 0.654
# resultado da epoca 176 = -2109.00 Epsilon = 0.652
# resultado da epoca 177 = -460.00 Epsilon = 0.650
# resultado da epoca 178 = -1554.50 Epsilon = 0.648
# resultado da epoca 179 = 140.00 Epsilon = 0.646
# resultado da epoca 180 = 176.00 Epsilon = 0.644
# resultado da epoca 181 = -774.00 Epsilon = 0.642
# resultado da epoca 182 = 1483.50 Epsilon = 0.640
# resultado da epoca 183 = 1684.00 Epsilon = 0.638
# resultado da epoca 184 = -615.00 Epsilon = 0.636
# resultado da epoca 185 = -1589.50 Epsilon = 0.634
# resultado da epoca 186 = 2680.50 Epsilon = 0.632
# resultado da epoca 187 = 1582.50 Epsilon = 0.630
# resultado da epoca 188 = -1008.00 Epsilon = 0.628
# resultado da epoca 189 = -1525.00 Epsilon = 0.626
# resultado da epoca 190 = 1882.50 Epsilon = 0.624
# resultado da epoca 191 = -678.00 Epsilon = 0.622
# resultado da epoca 192 = -871.50 Epsilon = 0.620
# resultado da epoca 193 = -1053.50 Epsilon = 0.618
# resultado da epoca 194 = 2092.50 Epsilon = 0.616
# resultado da epoca 195 = -1569.00 Epsilon = 0.614
# resultado da epoca 196 = 2190.00 Epsilon = 0.612
# resultado da epoca 197 = 1809.00 Epsilon = 0.610
# resultado da epoca 198 = 1282.50 Epsilon = 0.608
# resultado da epoca 199 = 3731.00 Epsilon = 0.606
# resultado da epoca 200 = -1228.00 Epsilon = 0.604
# resultado da epoca 201 = 1779.00 Epsilon = 0.602
# resultado da epoca 202 = 1714.50 Epsilon = 0.600
# resultado da epoca 203 = 1673.50 Epsilon = 0.598
# resultado da epoca 204 = 3131.00 Epsilon = 0.596
# resultado da epoca 205 = 2886.50 Epsilon = 0.594
# resultado da epoca 206 = -334.00 Epsilon = 0.592
# resultado da epoca 207 = 1811.00 Epsilon = 0.590
# resultado da epoca 208 = -89.50 Epsilon = 0.588
# resultado da epoca 209 = -1087.50 Epsilon = 0.586
# resultado da epoca 210 = 1772.00 Epsilon = 0.584
# resultado da epoca 211 = -970.50 Epsilon = 0.582
# resultado da epoca 212 = 1455.00 Epsilon = 0.580
# resultado da epoca 213 = -387.50 Epsilon = 0.578
# resultado da epoca 214 = 668.00 Epsilon = 0.576
# resultado da epoca 215 = 1828.50 Epsilon = 0.574
# resultado da epoca 216 = 2571.50 Epsilon = 0.572
# resultado da epoca 217 = 2527.50 Epsilon = 0.570
# resultado da epoca 218 = -1252.00 Epsilon = 0.568
# resultado da epoca 219 = -1505.50 Epsilon = 0.566
# resultado da epoca 220 = 2601.00 Epsilon = 0.564
# resultado da epoca 221 = 4320.50 Epsilon = 0.562
# resultado da epoca 222 = 1062.50 Epsilon = 0.560
# resultado da epoca 223 = 3052.00 Epsilon = 0.558
# resultado da epoca 224 = 664.50 Epsilon = 0.556
# resultado da epoca 225 = 2790.50 Epsilon = 0.555
# resultado da epoca 226 = 1872.50 Epsilon = 0.553
# resultado da epoca 227 = 3903.00 Epsilon = 0.551
# resultado da epoca 228 = 4778.00 Epsilon = 0.549
# resultado da epoca 229 = 3549.50 Epsilon = 0.547
# resultado da epoca 230 = 1727.50 Epsilon = 0.545
# resultado da epoca 231 = 3523.00 Epsilon = 0.543
# resultado da epoca 232 = 2431.00 Epsilon = 0.541
# resultado da epoca 233 = 1889.50 Epsilon = 0.539
# resultado da epoca 234 = 5231.00 Epsilon = 0.537
# resultado da epoca 235 = 1432.00 Epsilon = 0.535
# resultado da epoca 236 = 5218.50 Epsilon = 0.533
# resultado da epoca 237 = 407.50 Epsilon = 0.531
# resultado da epoca 238 = 1235.50 Epsilon = 0.529
# resultado da epoca 239 = 3377.50 Epsilon = 0.527
# resultado da epoca 240 = 5003.00 Epsilon = 0.525
# resultado da epoca 241 = 3284.50 Epsilon = 0.523
# resultado da epoca 242 = 223.50 Epsilon = 0.521
# resultado da epoca 243 = 1826.50 Epsilon = 0.519
# resultado da epoca 244 = -1184.00 Epsilon = 0.517
# resultado da epoca 245 = 1686.00 Epsilon = 0.515
# resultado da epoca 246 = -1361.00 Epsilon = 0.513
# resultado da epoca 247 = 1822.50 Epsilon = 0.511
# resultado da epoca 248 = 4146.00 Epsilon = 0.509
# resultado da epoca 249 = 3363.00 Epsilon = 0.507
# resultado da epoca 250 = 1454.50 Epsilon = 0.505
# resultado da epoca 251 = 148.50 Epsilon = 0.503
# resultado da epoca 252 = 3868.50 Epsilon = 0.501
# resultado da epoca 253 = 2019.50 Epsilon = 0.499
# resultado da epoca 254 = 1352.50 Epsilon = 0.497
# resultado da epoca 255 = 4558.50 Epsilon = 0.495
# resultado da epoca 256 = 3321.50 Epsilon = 0.493
# resultado da epoca 257 = 2095.50 Epsilon = 0.491
# resultado da epoca 258 = 961.50 Epsilon = 0.489
# resultado da epoca 259 = 3080.50 Epsilon = 0.487
# resultado da epoca 260 = 464.00 Epsilon = 0.485
# resultado da epoca 261 = 4263.00 Epsilon = 0.483
# resultado da epoca 262 = 3230.50 Epsilon = 0.481
# resultado da epoca 263 = 2081.00 Epsilon = 0.479
# resultado da epoca 264 = 781.50 Epsilon = 0.477
# resultado da epoca 265 = 3400.00 Epsilon = 0.475
# resultado da epoca 266 = 1978.00 Epsilon = 0.473
# resultado da epoca 267 = 3663.50 Epsilon = 0.471
# resultado da epoca 268 = 2662.50 Epsilon = 0.469
# resultado da epoca 269 = 3667.50 Epsilon = 0.467
# resultado da epoca 270 = 2584.50 Epsilon = 0.465
# resultado da epoca 271 = 1393.50 Epsilon = 0.463
# resultado da epoca 272 = 3380.50 Epsilon = 0.461
# resultado da epoca 273 = 3643.00 Epsilon = 0.459
# resultado da epoca 274 = 2686.50 Epsilon = 0.457
# resultado da epoca 275 = 58.00 Epsilon = 0.456
# resultado da epoca 276 = 989.50 Epsilon = 0.454
# resultado da epoca 277 = 1816.00 Epsilon = 0.452
# resultado da epoca 278 = 1616.00 Epsilon = 0.450
# resultado da epoca 279 = 2081.50 Epsilon = 0.448
# resultado da epoca 280 = 3180.50 Epsilon = 0.446
# resultado da epoca 281 = 2984.50 Epsilon = 0.444
# resultado da epoca 282 = 2965.50 Epsilon = 0.442
# resultado da epoca 283 = 2265.50 Epsilon = 0.440
# resultado da epoca 284 = 1295.50 Epsilon = 0.438
# resultado da epoca 285 = 1456.50 Epsilon = 0.436
# resultado da epoca 286 = 4857.00 Epsilon = 0.434
# resultado da epoca 287 = 2785.00 Epsilon = 0.432
# resultado da epoca 288 = 3814.50 Epsilon = 0.430
# resultado da epoca 289 = 1036.50 Epsilon = 0.428
# resultado da epoca 290 = 411.00 Epsilon = 0.426
# resultado da epoca 291 = 2506.00 Epsilon = 0.424
# resultado da epoca 292 = 3785.50 Epsilon = 0.422
# resultado da epoca 293 = 553.00 Epsilon = 0.420
# resultado da epoca 294 = 4737.00 Epsilon = 0.418
# resultado da epoca 295 = 999.00 Epsilon = 0.416
# resultado da epoca 296 = 2992.00 Epsilon = 0.414
# resultado da epoca 297 = -97.50 Epsilon = 0.412
# resultado da epoca 298 = 666.50 Epsilon = 0.410
# resultado da epoca 299 = 2892.50 Epsilon = 0.408
# resultado da epoca 300 = 4651.00 Epsilon = 0.406
# resultado da epoca 301 = 5089.00 Epsilon = 0.404
# resultado da epoca 302 = 3513.50 Epsilon = 0.402
# resultado da epoca 303 = 4808.00 Epsilon = 0.400
# resultado da epoca 304 = 3751.00 Epsilon = 0.398
# resultado da epoca 305 = 1873.00 Epsilon = 0.396
# resultado da epoca 306 = 3938.50 Epsilon = 0.394
# resultado da epoca 307 = -12.00 Epsilon = 0.392
# resultado da epoca 308 = 2168.50 Epsilon = 0.390
# resultado da epoca 309 = 3225.00 Epsilon = 0.388
# resultado da epoca 310 = 675.50 Epsilon = 0.386
# resultado da epoca 311 = 770.00 Epsilon = 0.384
# resultado da epoca 312 = 1921.50 Epsilon = 0.382
# resultado da epoca 313 = 662.50 Epsilon = 0.380
# resultado da epoca 314 = 392.50 Epsilon = 0.378
# resultado da epoca 315 = 1853.00 Epsilon = 0.376
# resultado da epoca 316 = 3137.50 Epsilon = 0.374
# resultado da epoca 317 = 1423.00 Epsilon = 0.372
# resultado da epoca 318 = 1646.00 Epsilon = 0.370
# resultado da epoca 319 = 3404.00 Epsilon = 0.368
# resultado da epoca 320 = 5788.00 Epsilon = 0.366
# resultado da epoca 321 = 2396.50 Epsilon = 0.364
# resultado da epoca 322 = 2705.50 Epsilon = 0.362
# resultado da epoca 323 = 3767.50 Epsilon = 0.360
# resultado da epoca 324 = 2934.00 Epsilon = 0.358
# resultado da epoca 325 = 434.00 Epsilon = 0.357
# resultado da epoca 326 = -946.00 Epsilon = 0.355
# resultado da epoca 327 = 2001.00 Epsilon = 0.353
# resultado da epoca 328 = 1539.00 Epsilon = 0.351
# resultado da epoca 329 = -555.00 Epsilon = 0.349
# resultado da epoca 330 = -444.50 Epsilon = 0.347
# resultado da epoca 331 = 2563.00 Epsilon = 0.345
# resultado da epoca 332 = 4146.50 Epsilon = 0.343
# resultado da epoca 333 = -127.50 Epsilon = 0.341
# resultado da epoca 334 = -155.00 Epsilon = 0.339
# resultado da epoca 335 = 4748.50 Epsilon = 0.337
# resultado da epoca 336 = 3013.50 Epsilon = 0.335
# resultado da epoca 337 = 3188.00 Epsilon = 0.333
# resultado da epoca 338 = 3549.50 Epsilon = 0.331
# resultado da epoca 339 = 6047.50 Epsilon = 0.329
# resultado da epoca 340 = 6906.00 Epsilon = 0.327
# resultado da epoca 341 = 2044.50 Epsilon = 0.325
# resultado da epoca 342 = 2516.00 Epsilon = 0.323
# resultado da epoca 343 = 2447.50 Epsilon = 0.321
# resultado da epoca 344 = 5107.00 Epsilon = 0.319
# resultado da epoca 345 = 2290.00 Epsilon = 0.317
# resultado da epoca 346 = 2272.50 Epsilon = 0.315
# resultado da epoca 347 = 3307.50 Epsilon = 0.313
# resultado da epoca 348 = 1190.50 Epsilon = 0.311
# resultado da epoca 349 = 1856.00 Epsilon = 0.309
# resultado da epoca 350 = 3259.00 Epsilon = 0.307
# resultado da epoca 351 = 3250.00 Epsilon = 0.305
# resultado da epoca 352 = 2851.50 Epsilon = 0.303
# resultado da epoca 353 = -411.50 Epsilon = 0.301
# resultado da epoca 354 = 1990.50 Epsilon = 0.299
# resultado da epoca 355 = 5160.00 Epsilon = 0.297
# resultado da epoca 356 = 4657.00 Epsilon = 0.295
# resultado da epoca 357 = 6213.50 Epsilon = 0.293
# resultado da epoca 358 = -21.00 Epsilon = 0.291
# resultado da epoca 359 = 3526.00 Epsilon = 0.289
# resultado da epoca 360 = 2528.50 Epsilon = 0.287
# resultado da epoca 361 = 1795.50 Epsilon = 0.285
# resultado da epoca 362 = 4558.50 Epsilon = 0.283
# resultado da epoca 363 = 2209.00 Epsilon = 0.281
# resultado da epoca 364 = 639.50 Epsilon = 0.279
# resultado da epoca 365 = 965.50 Epsilon = 0.277
# resultado da epoca 366 = -61.50 Epsilon = 0.275
# resultado da epoca 367 = 2801.50 Epsilon = 0.273
# resultado da epoca 368 = 61.50 Epsilon = 0.271
# resultado da epoca 369 = 1042.50 Epsilon = 0.269
# resultado da epoca 370 = -957.50 Epsilon = 0.267
# resultado da epoca 371 = -2413.50 Epsilon = 0.265
# resultado da epoca 372 = -357.00 Epsilon = 0.263
# resultado da epoca 373 = -4361.00 Epsilon = 0.261
# resultado da epoca 374 = 3183.50 Epsilon = 0.259
# resultado da epoca 375 = -132.50 Epsilon = 0.258
# resultado da epoca 376 = 6.50 Epsilon = 0.256
# resultado da epoca 377 = -2168.50 Epsilon = 0.254
# resultado da epoca 378 = 558.00 Epsilon = 0.252
# resultado da epoca 379 = -1356.50 Epsilon = 0.250
# resultado da epoca 380 = 2583.00 Epsilon = 0.248
# resultado da epoca 381 = 3620.50 Epsilon = 0.246
# resultado da epoca 382 = 2394.00 Epsilon = 0.244
# resultado da epoca 383 = 2829.00 Epsilon = 0.242
# resultado da epoca 384 = -1864.50 Epsilon = 0.240
# resultado da epoca 385 = -2137.50 Epsilon = 0.238
# resultado da epoca 386 = 4364.50 Epsilon = 0.236
# resultado da epoca 387 = 4595.50 Epsilon = 0.234
# resultado da epoca 388 = 3612.00 Epsilon = 0.232
# resultado da epoca 389 = 1190.50 Epsilon = 0.230
# resultado da epoca 390 = 5229.50 Epsilon = 0.228
# resultado da epoca 391 = 6875.00 Epsilon = 0.226
# resultado da epoca 392 = 962.00 Epsilon = 0.224
# resultado da epoca 393 = 1219.50 Epsilon = 0.222
# resultado da epoca 394 = 2334.50 Epsilon = 0.220
# resultado da epoca 395 = 4824.50 Epsilon = 0.218
# resultado da epoca 396 = 4358.00 Epsilon = 0.216
# resultado da epoca 397 = 2169.50 Epsilon = 0.214
# resultado da epoca 398 = 1820.50 Epsilon = 0.212
# resultado da epoca 399 = 1488.00 Epsilon = 0.210
# resultado da epoca 400 = 4229.50 Epsilon = 0.208
# resultado da epoca 401 = 965.50 Epsilon = 0.206
# resultado da epoca 402 = 1299.00 Epsilon = 0.204
# resultado da epoca 403 = 560.50 Epsilon = 0.202
# resultado da epoca 404 = 4310.50 Epsilon = 0.200
# resultado da epoca 405 = 905.50 Epsilon = 0.198
# resultado da epoca 406 = 3397.50 Epsilon = 0.196
# resultado da epoca 407 = 2670.00 Epsilon = 0.194
# resultado da epoca 408 = 3803.00 Epsilon = 0.192
# resultado da epoca 409 = 3610.50 Epsilon = 0.190
# resultado da epoca 410 = 1491.50 Epsilon = 0.188
# resultado da epoca 411 = 612.50 Epsilon = 0.186
# resultado da epoca 412 = 1399.00 Epsilon = 0.184
# resultado da epoca 413 = 355.50 Epsilon = 0.182
# resultado da epoca 414 = 2454.50 Epsilon = 0.180
# resultado da epoca 415 = 2322.00 Epsilon = 0.178
# resultado da epoca 416 = 1583.50 Epsilon = 0.176
# resultado da epoca 417 = 893.50 Epsilon = 0.174
# resultado da epoca 418 = -278.50 Epsilon = 0.172
# resultado da epoca 419 = -145.50 Epsilon = 0.170
# resultado da epoca 420 = -524.00 Epsilon = 0.168
# resultado da epoca 421 = -707.50 Epsilon = 0.166
# resultado da epoca 422 = 190.00 Epsilon = 0.164
# resultado da epoca 423 = 4809.00 Epsilon = 0.162
# resultado da epoca 424 = 3460.50 Epsilon = 0.160
# resultado da epoca 425 = -159.00 Epsilon = 0.159
# resultado da epoca 426 = 3703.00 Epsilon = 0.157
# resultado da epoca 427 = 2081.50 Epsilon = 0.155
# resultado da epoca 428 = 4646.00 Epsilon = 0.153
# resultado da epoca 429 = 1604.50 Epsilon = 0.151
# resultado da epoca 430 = 2058.00 Epsilon = 0.149
# resultado da epoca 431 = 2736.50 Epsilon = 0.147
# resultado da epoca 432 = -613.50 Epsilon = 0.145
# resultado da epoca 433 = 2468.00 Epsilon = 0.143
# resultado da epoca 434 = 5792.00 Epsilon = 0.141
# resultado da epoca 435 = 1995.00 Epsilon = 0.139
# resultado da epoca 436 = 2508.50 Epsilon = 0.137
# resultado da epoca 437 = -1665.00 Epsilon = 0.135
# resultado da epoca 438 = 3242.50 Epsilon = 0.133
# resultado da epoca 439 = 3363.50 Epsilon = 0.131
# resultado da epoca 440 = 3928.50 Epsilon = 0.129
# resultado da epoca 441 = 3927.50 Epsilon = 0.127
# resultado da epoca 442 = 1913.50 Epsilon = 0.125
# resultado da epoca 443 = 3879.00 Epsilon = 0.123
# resultado da epoca 444 = 5997.50 Epsilon = 0.121
# resultado da epoca 445 = 3622.00 Epsilon = 0.119
# resultado da epoca 446 = 4323.00 Epsilon = 0.117
# resultado da epoca 447 = 1464.50 Epsilon = 0.115
# resultado da epoca 448 = 6859.50 Epsilon = 0.113
# resultado da epoca 449 = 3575.00 Epsilon = 0.111
# resultado da epoca 450 = 5992.00 Epsilon = 0.109
# resultado da epoca 451 = 166.50 Epsilon = 0.107
# resultado da epoca 452 = 3877.50 Epsilon = 0.105
# resultado da epoca 453 = 904.50 Epsilon = 0.103
# resultado da epoca 454 = 4572.50 Epsilon = 0.101
# resultado da epoca 455 = 6106.00 Epsilon = 0.099
# resultado da epoca 456 = 7308.50 Epsilon = 0.097
# resultado da epoca 457 = 4507.50 Epsilon = 0.095
# resultado da epoca 458 = 961.00 Epsilon = 0.093
# resultado da epoca 459 = 7179.00 Epsilon = 0.091
# resultado da epoca 460 = 4784.50 Epsilon = 0.089
# resultado da epoca 461 = 5228.50 Epsilon = 0.087
# resultado da epoca 462 = 6660.50 Epsilon = 0.085
# resultado da epoca 463 = 5108.00 Epsilon = 0.083
# resultado da epoca 464 = 5636.00 Epsilon = 0.081
# resultado da epoca 465 = 5456.50 Epsilon = 0.079
# resultado da epoca 466 = 7787.50 Epsilon = 0.077
# resultado da epoca 467 = 5828.00 Epsilon = 0.075
# resultado da epoca 468 = 8606.50 Epsilon = 0.073
# resultado da epoca 469 = 6834.00 Epsilon = 0.071
# resultado da epoca 470 = 6691.00 Epsilon = 0.069
# resultado da epoca 471 = 6733.00 Epsilon = 0.067
# resultado da epoca 472 = 6077.50 Epsilon = 0.065
# resultado da epoca 473 = 4647.50 Epsilon = 0.063
# resultado da epoca 474 = 5522.00 Epsilon = 0.061
# resultado da epoca 475 = 8211.00 Epsilon = 0.060
# resultado da epoca 476 = 6583.00 Epsilon = 0.058
# resultado da epoca 477 = 7431.00 Epsilon = 0.056
# resultado da epoca 478 = 5927.00 Epsilon = 0.054
# resultado da epoca 479 = 5180.50 Epsilon = 0.052
# resultado da epoca 480 = 4593.00 Epsilon = 0.050
# resultado da epoca 481 = 5009.00 Epsilon = 0.048
# resultado da epoca 482 = 3950.00 Epsilon = 0.046
# resultado da epoca 483 = 1490.00 Epsilon = 0.044
# resultado da epoca 484 = 6294.50 Epsilon = 0.042
# resultado da epoca 485 = 5536.00 Epsilon = 0.040
# resultado da epoca 486 = 3776.00 Epsilon = 0.038
# resultado da epoca 487 = 7076.50 Epsilon = 0.036
# resultado da epoca 488 = 4687.50 Epsilon = 0.034
# resultado da epoca 489 = 8330.50 Epsilon = 0.032
# resultado da epoca 490 = 8385.00 Epsilon = 0.030
# resultado da epoca 491 = 8861.50 Epsilon = 0.028
# resultado da epoca 492 = 7658.00 Epsilon = 0.026
# resultado da epoca 493 = 10083.00 Epsilon = 0.024
# resultado da epoca 494 = 9383.00 Epsilon = 0.022
# resultado da epoca 495 = 7073.00 Epsilon = 0.020
# resultado da epoca 496 = 8202.00 Epsilon = 0.018
# resultado da epoca 497 = 9664.00 Epsilon = 0.016
# resultado da epoca 498 = 7387.00 Epsilon = 0.014
# resultado da epoca 499 = 8810.50 Epsilon = 0.012
# Melhor resultado diario: 813.50

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo, 0, dias))
# Out:
# 9848.0

# %%
modelo.epsilon = 0
rodar_dias(inputs, custo, dias, 20)
# Out:
# -905.4999999999999

# %%
plt.plot(range(0,len(inputs)), inputs['preco'])

# %%
plt.plot(range(0,len(inputs_nao_norm)), inputs_nao_norm['preco'])

# %%
np.amin(inputs['preco'])
# Out:
# -275.7738953247049

# %%
pmean
# Out:
# 3859.773895324705

# %%
(4200-pmean)/pstd
# Out:
# 2.784507614194732

# %%
np.std(inputs_nao_norm['preco'])
# Out:
# 130.87810760032863
