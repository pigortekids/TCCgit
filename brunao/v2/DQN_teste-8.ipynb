# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma']#, 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 1

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
inputs_nao_norm = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 5
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.98     # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        model.add(Dense(512, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(64, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(32, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(x*3, activation='relu')) #camada escondida
        #model.add(Dense(x*2, activation='relu')) #camada escondida
        #model.add(Dense(x, activation='relu')) #camada escondida
        #model.add(Dense(64, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size) if dias>5 else self.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3072
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 11)                363
# =================================================================
# Total params: 177,995
# Trainable params: 177,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(preco, ncont, acao, valor, custo=0):   

    if acao == 0: #zerado
        if ncont>0:  #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        elif ncont<0: #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        else:         
            reward = 0
        valor = -100
    elif acao>0:  #comprado
        if ncont>0:
            if acao>ncont: #aumento da posicao
                reward = -custo*(acao-ncont)
                valor = (valor*ncont+(acao-ncont)*preco)/(acao)  #calculo preco medio
            elif acao<ncont:  #diminuicao da posicao
                reward = (ncont-acao)*(preco-valor) -custo*(ncont-acao)
                valor = valor #preco medio se mantem
            else:
                reward = 0
        elif ncont<0:   #trocando a mao
            reward = abs(ncont)*(valor-preco) -custo*(acao+abs(ncont))
            valor = preco
        else:          #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
    else:       #vendido
        if ncont>0:#trocando a mao
            reward = ncont*(preco-valor) -custo*(ncont+abs(acao))
            valor = preco
        elif ncont<0:
            if abs(acao)<abs(ncont): #diminuicao da posicao
                reward = (abs(ncont)-abs(acao))*(valor-preco) -custo*(abs(ncont)-abs(acao))
                valor = valor #preco medio se mantem
            elif abs(acao)>abs(ncont): #aumento da posicao
                reward = -custo*(abs(acao)-abs(ncont))
                valor = (valor*abs(ncont)+(abs(acao)-abs(ncont))*preco)/(abs(acao))  #calculo preco medio
            else: #preco medio se mantem
                reward = 0
        else:  #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
                
    #reward = ncont*acao*preco
    ncont = acao
    posicao = ncont*(preco-valor) -custo*abs(ncont) if ncont!=0 else 0.
    return ncont, reward, valor, posicao

def obter_acao():
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -100 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    indice = 0
    lucro = 0.
    posicao = 0. #cria variavel de posicao 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont, step, precos['preco'][step], valor, precos['preco_pon'][step]], (1,modelo.state_size))
        
        acao = obter_acao()
        ncont, reward, valor, posicao = teste(precos['preco'][step], ncont, acao, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor*pstd+pmean if valor!=-100 else 0
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; reward={2} valor={3} preco={4}".format(acao, ncont, reward, valor, precos['preco'][step]))   

        if step == (steps[dia+1] - 1): #se ultimo step do dia
            done = True     
        
        modelo.next_state = np.reshape([ncont, step+1, precos['preco'][step+1], valor, precos['preco_pon'][step+1]], (1,modelo.state_size))
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        indice += 1
        
    #fim do dia
    lucro +=posicao
    
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 0, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        
        minibatch = random.sample(modelo.memory, batch_size) if dias>5 else modelo.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    melhor_reward = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1111 23:00:06.436059 10176 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1111 23:00:06.804080 10176 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1111 23:00:06.834082 10176 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -3.32 Epsilon = 1.000
# resultado da epoca 1 = 11.07 Epsilon = 0.999
# resultado da epoca 2 = -13.28 Epsilon = 0.998
# resultado da epoca 3 = -1.97 Epsilon = 0.997
# resultado da epoca 4 = -17.10 Epsilon = 0.996
# resultado da epoca 5 = -4.24 Epsilon = 0.995
# resultado da epoca 6 = -3.32 Epsilon = 0.994
# resultado da epoca 7 = -29.89 Epsilon = 0.993
# resultado da epoca 8 = 3.63 Epsilon = 0.992
# resultado da epoca 9 = -1.17 Epsilon = 0.991
# resultado da epoca 10 = 15.50 Epsilon = 0.990
# resultado da epoca 11 = -10.15 Epsilon = 0.989
# resultado da epoca 12 = -3.26 Epsilon = 0.988
# resultado da epoca 13 = -11.99 Epsilon = 0.987
# resultado da epoca 14 = 15.13 Epsilon = 0.986
# resultado da epoca 15 = -14.88 Epsilon = 0.985
# resultado da epoca 16 = -25.03 Epsilon = 0.984
# resultado da epoca 17 = -4.49 Epsilon = 0.983
# resultado da epoca 18 = -6.09 Epsilon = 0.982
# resultado da epoca 19 = -3.75 Epsilon = 0.981
# resultado da epoca 20 = 3.81 Epsilon = 0.980
# resultado da epoca 21 = -4.37 Epsilon = 0.979
# resultado da epoca 22 = -8.79 Epsilon = 0.978
# resultado da epoca 23 = -7.50 Epsilon = 0.977
# resultado da epoca 24 = 11.87 Epsilon = 0.976
# resultado da epoca 25 = 4.55 Epsilon = 0.975
# resultado da epoca 26 = -17.10 Epsilon = 0.974
# resultado da epoca 27 = 3.07 Epsilon = 0.973
# resultado da epoca 28 = -26.81 Epsilon = 0.972
# resultado da epoca 29 = -15.80 Epsilon = 0.971
# resultado da epoca 30 = -2.15 Epsilon = 0.970
# resultado da epoca 31 = 11.25 Epsilon = 0.969
# resultado da epoca 32 = 6.83 Epsilon = 0.968
# resultado da epoca 33 = -19.80 Epsilon = 0.967
# resultado da epoca 34 = -3.38 Epsilon = 0.966
# resultado da epoca 35 = 9.66 Epsilon = 0.965
# resultado da epoca 36 = 9.10 Epsilon = 0.964
# resultado da epoca 37 = 10.64 Epsilon = 0.963
# resultado da epoca 38 = 1.66 Epsilon = 0.962
# resultado da epoca 39 = 9.59 Epsilon = 0.961
# resultado da epoca 40 = -12.48 Epsilon = 0.960
# resultado da epoca 41 = 7.50 Epsilon = 0.959
# resultado da epoca 42 = -8.67 Epsilon = 0.958
# resultado da epoca 43 = -12.73 Epsilon = 0.957
# resultado da epoca 44 = -3.01 Epsilon = 0.956
# resultado da epoca 45 = 17.16 Epsilon = 0.955
# resultado da epoca 46 = 3.94 Epsilon = 0.954
# resultado da epoca 47 = 3.94 Epsilon = 0.953
# resultado da epoca 48 = 15.99 Epsilon = 0.952
# resultado da epoca 49 = -7.99 Epsilon = 0.951
# resultado da epoca 50 = 9.10 Epsilon = 0.950
# resultado da epoca 51 = 4.55 Epsilon = 0.950
# resultado da epoca 52 = -17.90 Epsilon = 0.949
# resultado da epoca 53 = -7.20 Epsilon = 0.948
# resultado da epoca 54 = 2.58 Epsilon = 0.947
# resultado da epoca 55 = -17.71 Epsilon = 0.946
# resultado da epoca 56 = -6.89 Epsilon = 0.945
# resultado da epoca 57 = -17.65 Epsilon = 0.944
# resultado da epoca 58 = 15.93 Epsilon = 0.943
# resultado da epoca 59 = -29.89 Epsilon = 0.942
# resultado da epoca 60 = -8.67 Epsilon = 0.941
# resultado da epoca 61 = 4.30 Epsilon = 0.940
# resultado da epoca 62 = -18.76 Epsilon = 0.939
# resultado da epoca 63 = 6.03 Epsilon = 0.938
# resultado da epoca 64 = -3.44 Epsilon = 0.937
# resultado da epoca 65 = 9.10 Epsilon = 0.936
# resultado da epoca 66 = -5.10 Epsilon = 0.935
# resultado da epoca 67 = -18.39 Epsilon = 0.934
# resultado da epoca 68 = -4.18 Epsilon = 0.933
# resultado da epoca 69 = -9.47 Epsilon = 0.932
# resultado da epoca 70 = -18.88 Epsilon = 0.931
# resultado da epoca 71 = 12.30 Epsilon = 0.930
# resultado da epoca 72 = -23.43 Epsilon = 0.929
# resultado da epoca 73 = -16.73 Epsilon = 0.928
# resultado da epoca 74 = -26.07 Epsilon = 0.927
# resultado da epoca 75 = 17.34 Epsilon = 0.926
# resultado da epoca 76 = -16.97 Epsilon = 0.925
# resultado da epoca 77 = 20.23 Epsilon = 0.924
# resultado da epoca 78 = -7.32 Epsilon = 0.923
# resultado da epoca 79 = -7.44 Epsilon = 0.922
# resultado da epoca 80 = 3.44 Epsilon = 0.921
# resultado da epoca 81 = -0.06 Epsilon = 0.920
# resultado da epoca 82 = 8.61 Epsilon = 0.919
# resultado da epoca 83 = -5.97 Epsilon = 0.918
# resultado da epoca 84 = -0.18 Epsilon = 0.917
# resultado da epoca 85 = -13.16 Epsilon = 0.916
# resultado da epoca 86 = -22.51 Epsilon = 0.915
# resultado da epoca 87 = 7.44 Epsilon = 0.914
# resultado da epoca 88 = 7.63 Epsilon = 0.913
# resultado da epoca 89 = -2.58 Epsilon = 0.912
# resultado da epoca 90 = 8.18 Epsilon = 0.911
# resultado da epoca 91 = -16.67 Epsilon = 0.910
# resultado da epoca 92 = -7.99 Epsilon = 0.909
# resultado da epoca 93 = -8.30 Epsilon = 0.908
# resultado da epoca 94 = 24.60 Epsilon = 0.907
# resultado da epoca 95 = -11.50 Epsilon = 0.906
# resultado da epoca 96 = -14.33 Epsilon = 0.905
# resultado da epoca 97 = -2.64 Epsilon = 0.904
# resultado da epoca 98 = 29.03 Epsilon = 0.903
# resultado da epoca 99 = 13.16 Epsilon = 0.902
# resultado da epoca 100 = 10.64 Epsilon = 0.901
# resultado da epoca 101 = 1.97 Epsilon = 0.900
# resultado da epoca 102 = -13.96 Epsilon = 0.899
# resultado da epoca 103 = 13.16 Epsilon = 0.898
# resultado da epoca 104 = -2.40 Epsilon = 0.897
# resultado da epoca 105 = 20.79 Epsilon = 0.896
# resultado da epoca 106 = 5.23 Epsilon = 0.895
# resultado da epoca 107 = -18.70 Epsilon = 0.894
# resultado da epoca 108 = 0.61 Epsilon = 0.893
# resultado da epoca 109 = -9.41 Epsilon = 0.892
# resultado da epoca 110 = -26.20 Epsilon = 0.891
# resultado da epoca 111 = 10.45 Epsilon = 0.890
# resultado da epoca 112 = 21.09 Epsilon = 0.889
# resultado da epoca 113 = 2.09 Epsilon = 0.888
# resultado da epoca 114 = -4.80 Epsilon = 0.887
# resultado da epoca 115 = 15.50 Epsilon = 0.886
# resultado da epoca 116 = -3.87 Epsilon = 0.885
# resultado da epoca 117 = -1.41 Epsilon = 0.884
# resultado da epoca 118 = -7.87 Epsilon = 0.883
# resultado da epoca 119 = -1.35 Epsilon = 0.882
# resultado da epoca 120 = -5.97 Epsilon = 0.881
# resultado da epoca 121 = 12.30 Epsilon = 0.880
# resultado da epoca 122 = 10.52 Epsilon = 0.879
# resultado da epoca 123 = 0.55 Epsilon = 0.878
# resultado da epoca 124 = -4.74 Epsilon = 0.877
# resultado da epoca 125 = 14.27 Epsilon = 0.876
# resultado da epoca 126 = -10.52 Epsilon = 0.875
# resultado da epoca 127 = -19.37 Epsilon = 0.874
# resultado da epoca 128 = 2.83 Epsilon = 0.873
# resultado da epoca 129 = -7.56 Epsilon = 0.872
# resultado da epoca 130 = -11.56 Epsilon = 0.871
# resultado da epoca 131 = -0.31 Epsilon = 0.870
# resultado da epoca 132 = -7.56 Epsilon = 0.869
# resultado da epoca 133 = -2.58 Epsilon = 0.868
# resultado da epoca 134 = -14.14 Epsilon = 0.867
# resultado da epoca 135 = -8.98 Epsilon = 0.866
# resultado da epoca 136 = -4.67 Epsilon = 0.865
# resultado da epoca 137 = 1.05 Epsilon = 0.864
# resultado da epoca 138 = -8.06 Epsilon = 0.863
# resultado da epoca 139 = -4.30 Epsilon = 0.862
# resultado da epoca 140 = -16.60 Epsilon = 0.861
# resultado da epoca 141 = -18.08 Epsilon = 0.860
# resultado da epoca 142 = -12.42 Epsilon = 0.859
# resultado da epoca 143 = -0.25 Epsilon = 0.858
# resultado da epoca 144 = -10.33 Epsilon = 0.857
# resultado da epoca 145 = -0.55 Epsilon = 0.856
# resultado da epoca 146 = 33.45 Epsilon = 0.855
# resultado da epoca 147 = 6.83 Epsilon = 0.854
# resultado da epoca 148 = 2.40 Epsilon = 0.853
# resultado da epoca 149 = 5.90 Epsilon = 0.852
# resultado da epoca 150 = 27.92 Epsilon = 0.851
# resultado da epoca 151 = 8.73 Epsilon = 0.851
# resultado da epoca 152 = -19.19 Epsilon = 0.850
# resultado da epoca 153 = 0.98 Epsilon = 0.849
# resultado da epoca 154 = 2.40 Epsilon = 0.848
# resultado da epoca 155 = -11.13 Epsilon = 0.847
# resultado da epoca 156 = 0.80 Epsilon = 0.846
# resultado da epoca 157 = -1.11 Epsilon = 0.845
# resultado da epoca 158 = 12.98 Epsilon = 0.844
# resultado da epoca 159 = -15.80 Epsilon = 0.843
# resultado da epoca 160 = 16.54 Epsilon = 0.842
# resultado da epoca 161 = -3.44 Epsilon = 0.841
# resultado da epoca 162 = 2.64 Epsilon = 0.840
# resultado da epoca 163 = 7.75 Epsilon = 0.839
# resultado da epoca 164 = -21.65 Epsilon = 0.838
# resultado da epoca 165 = -1.05 Epsilon = 0.837
# resultado da epoca 166 = -15.93 Epsilon = 0.836
# resultado da epoca 167 = -16.36 Epsilon = 0.835
# resultado da epoca 168 = 0.98 Epsilon = 0.834
# resultado da epoca 169 = -2.95 Epsilon = 0.833
# resultado da epoca 170 = 0.43 Epsilon = 0.832
# resultado da epoca 171 = 14.70 Epsilon = 0.831
# resultado da epoca 172 = -14.94 Epsilon = 0.830
# resultado da epoca 173 = 6.21 Epsilon = 0.829
# resultado da epoca 174 = 11.50 Epsilon = 0.828
# resultado da epoca 175 = -3.01 Epsilon = 0.827
# resultado da epoca 176 = 6.95 Epsilon = 0.826
# resultado da epoca 177 = 10.89 Epsilon = 0.825
# resultado da epoca 178 = 0.37 Epsilon = 0.824
# resultado da epoca 179 = -0.06 Epsilon = 0.823
# resultado da epoca 180 = -0.86 Epsilon = 0.822
# resultado da epoca 181 = 1.97 Epsilon = 0.821
# resultado da epoca 182 = 4.37 Epsilon = 0.820
# resultado da epoca 183 = 4.43 Epsilon = 0.819
# resultado da epoca 184 = 29.76 Epsilon = 0.818
# resultado da epoca 185 = 4.00 Epsilon = 0.817
# resultado da epoca 186 = -3.44 Epsilon = 0.816
# resultado da epoca 187 = -24.35 Epsilon = 0.815
# resultado da epoca 188 = 8.67 Epsilon = 0.814
# resultado da epoca 189 = 0.31 Epsilon = 0.813
# resultado da epoca 190 = -5.84 Epsilon = 0.812
# resultado da epoca 191 = 14.02 Epsilon = 0.811
# resultado da epoca 192 = -5.17 Epsilon = 0.810
# resultado da epoca 193 = 0.92 Epsilon = 0.809
# resultado da epoca 194 = 16.30 Epsilon = 0.808
# resultado da epoca 195 = -11.56 Epsilon = 0.807
# resultado da epoca 196 = 7.93 Epsilon = 0.806
# resultado da epoca 197 = 7.50 Epsilon = 0.805
# resultado da epoca 198 = 20.48 Epsilon = 0.804
# resultado da epoca 199 = -10.09 Epsilon = 0.803
# resultado da epoca 200 = -14.39 Epsilon = 0.802
# resultado da epoca 201 = -7.69 Epsilon = 0.801
# resultado da epoca 202 = -7.99 Epsilon = 0.800
# resultado da epoca 203 = 13.78 Epsilon = 0.799
# resultado da epoca 204 = 15.13 Epsilon = 0.798
# resultado da epoca 205 = -18.57 Epsilon = 0.797
# resultado da epoca 206 = 9.72 Epsilon = 0.796
# resultado da epoca 207 = -2.28 Epsilon = 0.795
# resultado da epoca 208 = 14.45 Epsilon = 0.794
# resultado da epoca 209 = -3.32 Epsilon = 0.793
# resultado da epoca 210 = -7.81 Epsilon = 0.792
# resultado da epoca 211 = 9.59 Epsilon = 0.791
# resultado da epoca 212 = 1.60 Epsilon = 0.790
# resultado da epoca 213 = -4.49 Epsilon = 0.789
# resultado da epoca 214 = 12.55 Epsilon = 0.788
# resultado da epoca 215 = -2.83 Epsilon = 0.787
# resultado da epoca 216 = 3.69 Epsilon = 0.786
# resultado da epoca 217 = -2.71 Epsilon = 0.785
# resultado da epoca 218 = -8.18 Epsilon = 0.784
# resultado da epoca 219 = 10.02 Epsilon = 0.783
# resultado da epoca 220 = -16.17 Epsilon = 0.782
# resultado da epoca 221 = -4.06 Epsilon = 0.781
# resultado da epoca 222 = -2.40 Epsilon = 0.780
# resultado da epoca 223 = -3.26 Epsilon = 0.779
# resultado da epoca 224 = 3.57 Epsilon = 0.778
# resultado da epoca 225 = 4.12 Epsilon = 0.777
# resultado da epoca 226 = -10.21 Epsilon = 0.776
# resultado da epoca 227 = 3.57 Epsilon = 0.775
# resultado da epoca 228 = -5.97 Epsilon = 0.774
# resultado da epoca 229 = 4.06 Epsilon = 0.773
# resultado da epoca 230 = -13.90 Epsilon = 0.772
# resultado da epoca 231 = 11.13 Epsilon = 0.771
# resultado da epoca 232 = -13.84 Epsilon = 0.770
# resultado da epoca 233 = 6.83 Epsilon = 0.769
# resultado da epoca 234 = -9.10 Epsilon = 0.768
# resultado da epoca 235 = -13.65 Epsilon = 0.767
# resultado da epoca 236 = 15.07 Epsilon = 0.766
# resultado da epoca 237 = -11.07 Epsilon = 0.765
# resultado da epoca 238 = -5.35 Epsilon = 0.764
# resultado da epoca 239 = 10.58 Epsilon = 0.763
# resultado da epoca 240 = -7.38 Epsilon = 0.762
# resultado da epoca 241 = -11.07 Epsilon = 0.761
# resultado da epoca 242 = -4.74 Epsilon = 0.760
# resultado da epoca 243 = 11.44 Epsilon = 0.759
# resultado da epoca 244 = -0.12 Epsilon = 0.758
# resultado da epoca 245 = -12.85 Epsilon = 0.757
# resultado da epoca 246 = -9.04 Epsilon = 0.756
# resultado da epoca 247 = 6.40 Epsilon = 0.755
# resultado da epoca 248 = -4.61 Epsilon = 0.754
# resultado da epoca 249 = 1.91 Epsilon = 0.753
# resultado da epoca 250 = -0.12 Epsilon = 0.752
# resultado da epoca 251 = -0.49 Epsilon = 0.752
# resultado da epoca 252 = 15.87 Epsilon = 0.751
# resultado da epoca 253 = 7.75 Epsilon = 0.750
# resultado da epoca 254 = -0.18 Epsilon = 0.749
# resultado da epoca 255 = -11.25 Epsilon = 0.748
# resultado da epoca 256 = 4.30 Epsilon = 0.747
# resultado da epoca 257 = 19.37 Epsilon = 0.746
# resultado da epoca 258 = 22.94 Epsilon = 0.745
# resultado da epoca 259 = 27.80 Epsilon = 0.744
# resultado da epoca 260 = 13.84 Epsilon = 0.743
# resultado da epoca 261 = -10.27 Epsilon = 0.742
# resultado da epoca 262 = -4.43 Epsilon = 0.741
# resultado da epoca 263 = 22.14 Epsilon = 0.740
# resultado da epoca 264 = 2.83 Epsilon = 0.739
# resultado da epoca 265 = -7.75 Epsilon = 0.738
# resultado da epoca 266 = 4.12 Epsilon = 0.737
# resultado da epoca 267 = -7.69 Epsilon = 0.736
# resultado da epoca 268 = -6.70 Epsilon = 0.735
# resultado da epoca 269 = -7.32 Epsilon = 0.734
# resultado da epoca 270 = -7.20 Epsilon = 0.733
# resultado da epoca 271 = -2.15 Epsilon = 0.732
# resultado da epoca 272 = 2.21 Epsilon = 0.731
# resultado da epoca 273 = 7.87 Epsilon = 0.730
# resultado da epoca 274 = -2.15 Epsilon = 0.729
# resultado da epoca 275 = 16.48 Epsilon = 0.728
# resultado da epoca 276 = 11.93 Epsilon = 0.727
# resultado da epoca 277 = 1.11 Epsilon = 0.726
# resultado da epoca 278 = 6.83 Epsilon = 0.725
# resultado da epoca 279 = 7.01 Epsilon = 0.724
# resultado da epoca 280 = 1.97 Epsilon = 0.723
# resultado da epoca 281 = 2.95 Epsilon = 0.722
# resultado da epoca 282 = 1.41 Epsilon = 0.721
# resultado da epoca 283 = -13.71 Epsilon = 0.720
# resultado da epoca 284 = 3.51 Epsilon = 0.719
# resultado da epoca 285 = 11.32 Epsilon = 0.718
# resultado da epoca 286 = -10.95 Epsilon = 0.717
# resultado da epoca 287 = -21.34 Epsilon = 0.716
# resultado da epoca 288 = -17.90 Epsilon = 0.715
# resultado da epoca 289 = -9.66 Epsilon = 0.714
# resultado da epoca 290 = -0.18 Epsilon = 0.713
# resultado da epoca 291 = -7.01 Epsilon = 0.712
# resultado da epoca 292 = 5.35 Epsilon = 0.711
# resultado da epoca 293 = 3.44 Epsilon = 0.710
# resultado da epoca 294 = -6.33 Epsilon = 0.709
# resultado da epoca 295 = 8.61 Epsilon = 0.708
# resultado da epoca 296 = 5.53 Epsilon = 0.707
# resultado da epoca 297 = -6.15 Epsilon = 0.706
# resultado da epoca 298 = 27.55 Epsilon = 0.705
# resultado da epoca 299 = -9.84 Epsilon = 0.704
# resultado da epoca 300 = 31.30 Epsilon = 0.703
# resultado da epoca 301 = 9.47 Epsilon = 0.702
# resultado da epoca 302 = 9.96 Epsilon = 0.701
# resultado da epoca 303 = 3.63 Epsilon = 0.700
# resultado da epoca 304 = -2.64 Epsilon = 0.699
# resultado da epoca 305 = 9.78 Epsilon = 0.698
# resultado da epoca 306 = -0.80 Epsilon = 0.697
# resultado da epoca 307 = -11.19 Epsilon = 0.696
# resultado da epoca 308 = -15.50 Epsilon = 0.695
# resultado da epoca 309 = 13.28 Epsilon = 0.694
# resultado da epoca 310 = 6.83 Epsilon = 0.693
# resultado da epoca 311 = -9.90 Epsilon = 0.692
# resultado da epoca 312 = 5.35 Epsilon = 0.691
# resultado da epoca 313 = 17.96 Epsilon = 0.690
# resultado da epoca 314 = -8.36 Epsilon = 0.689
# resultado da epoca 315 = -2.83 Epsilon = 0.688
# resultado da epoca 316 = -12.18 Epsilon = 0.687
# resultado da epoca 317 = 7.99 Epsilon = 0.686
# resultado da epoca 318 = 5.84 Epsilon = 0.685
# resultado da epoca 319 = 7.44 Epsilon = 0.684
# resultado da epoca 320 = -1.05 Epsilon = 0.683
# resultado da epoca 321 = -3.38 Epsilon = 0.682
# resultado da epoca 322 = 12.73 Epsilon = 0.681
# resultado da epoca 323 = -3.01 Epsilon = 0.680
# resultado da epoca 324 = 1.72 Epsilon = 0.679
# resultado da epoca 325 = -17.59 Epsilon = 0.678
# resultado da epoca 326 = 0.68 Epsilon = 0.677
# resultado da epoca 327 = -25.71 Epsilon = 0.676
# resultado da epoca 328 = -6.89 Epsilon = 0.675
# resultado da epoca 329 = 7.69 Epsilon = 0.674
# resultado da epoca 330 = -5.17 Epsilon = 0.673
# resultado da epoca 331 = 7.56 Epsilon = 0.672
# resultado da epoca 332 = -17.77 Epsilon = 0.671
# resultado da epoca 333 = 5.04 Epsilon = 0.670
# resultado da epoca 334 = -7.93 Epsilon = 0.669
# resultado da epoca 335 = -13.84 Epsilon = 0.668
# resultado da epoca 336 = 8.73 Epsilon = 0.667
# resultado da epoca 337 = -2.83 Epsilon = 0.666
# resultado da epoca 338 = 10.15 Epsilon = 0.665
# resultado da epoca 339 = 4.00 Epsilon = 0.664
# resultado da epoca 340 = -10.70 Epsilon = 0.663
# resultado da epoca 341 = 14.39 Epsilon = 0.662
# resultado da epoca 342 = -1.91 Epsilon = 0.661
# resultado da epoca 343 = -7.75 Epsilon = 0.660
# resultado da epoca 344 = -7.69 Epsilon = 0.659
# resultado da epoca 345 = 8.24 Epsilon = 0.658
# resultado da epoca 346 = 2.58 Epsilon = 0.657
# resultado da epoca 347 = 4.67 Epsilon = 0.656
# resultado da epoca 348 = -18.94 Epsilon = 0.655
# resultado da epoca 349 = -2.40 Epsilon = 0.654
# resultado da epoca 350 = 13.53 Epsilon = 0.653
# resultado da epoca 351 = -22.26 Epsilon = 0.653
# resultado da epoca 352 = 28.72 Epsilon = 0.652
# resultado da epoca 353 = -12.36 Epsilon = 0.651
# resultado da epoca 354 = 11.13 Epsilon = 0.650
# resultado da epoca 355 = 4.86 Epsilon = 0.649
# resultado da epoca 356 = 22.08 Epsilon = 0.648
# resultado da epoca 357 = -13.65 Epsilon = 0.647
# resultado da epoca 358 = -21.83 Epsilon = 0.646
# resultado da epoca 359 = -4.67 Epsilon = 0.645
# resultado da epoca 360 = 18.76 Epsilon = 0.644
# resultado da epoca 361 = 6.83 Epsilon = 0.643
# resultado da epoca 362 = -7.93 Epsilon = 0.642
# resultado da epoca 363 = 1.84 Epsilon = 0.641
# resultado da epoca 364 = -5.29 Epsilon = 0.640
# resultado da epoca 365 = -8.61 Epsilon = 0.639
# resultado da epoca 366 = -0.86 Epsilon = 0.638
# resultado da epoca 367 = 6.15 Epsilon = 0.637
# resultado da epoca 368 = -9.78 Epsilon = 0.636
# resultado da epoca 369 = -11.81 Epsilon = 0.635
# resultado da epoca 370 = -16.48 Epsilon = 0.634
# resultado da epoca 371 = 7.44 Epsilon = 0.633
# resultado da epoca 372 = -16.42 Epsilon = 0.632
# resultado da epoca 373 = -10.70 Epsilon = 0.631
# resultado da epoca 374 = -4.86 Epsilon = 0.630
# resultado da epoca 375 = -5.84 Epsilon = 0.629
# resultado da epoca 376 = -8.79 Epsilon = 0.628
# resultado da epoca 377 = -11.75 Epsilon = 0.627
# resultado da epoca 378 = -1.54 Epsilon = 0.626
# resultado da epoca 379 = -4.24 Epsilon = 0.625
# resultado da epoca 380 = 7.63 Epsilon = 0.624
# resultado da epoca 381 = 4.12 Epsilon = 0.623
# resultado da epoca 382 = -11.13 Epsilon = 0.622
# resultado da epoca 383 = 7.99 Epsilon = 0.621
# resultado da epoca 384 = 17.71 Epsilon = 0.620
# resultado da epoca 385 = 7.20 Epsilon = 0.619
# resultado da epoca 386 = -2.28 Epsilon = 0.618
# resultado da epoca 387 = 13.90 Epsilon = 0.617
# resultado da epoca 388 = -15.68 Epsilon = 0.616
# resultado da epoca 389 = -15.13 Epsilon = 0.615
# resultado da epoca 390 = 1.17 Epsilon = 0.614
# resultado da epoca 391 = 11.81 Epsilon = 0.613
# resultado da epoca 392 = 8.49 Epsilon = 0.612
# resultado da epoca 393 = -4.74 Epsilon = 0.611
# resultado da epoca 394 = -4.30 Epsilon = 0.610
# resultado da epoca 395 = 4.18 Epsilon = 0.609
# resultado da epoca 396 = 2.83 Epsilon = 0.608
# resultado da epoca 397 = 24.48 Epsilon = 0.607
# resultado da epoca 398 = -16.67 Epsilon = 0.606
# resultado da epoca 399 = -16.11 Epsilon = 0.605
# resultado da epoca 400 = -9.53 Epsilon = 0.604
# resultado da epoca 401 = 3.69 Epsilon = 0.603
# resultado da epoca 402 = -17.03 Epsilon = 0.602
# resultado da epoca 403 = -9.29 Epsilon = 0.601
# resultado da epoca 404 = -24.41 Epsilon = 0.600
# resultado da epoca 405 = -4.74 Epsilon = 0.599
# resultado da epoca 406 = -8.67 Epsilon = 0.598
# resultado da epoca 407 = -15.99 Epsilon = 0.597
# resultado da epoca 408 = 11.44 Epsilon = 0.596
# resultado da epoca 409 = 1.48 Epsilon = 0.595
# resultado da epoca 410 = 17.96 Epsilon = 0.594
# resultado da epoca 411 = -2.52 Epsilon = 0.593
# resultado da epoca 412 = 10.76 Epsilon = 0.592
# resultado da epoca 413 = 5.72 Epsilon = 0.591
# resultado da epoca 414 = 5.17 Epsilon = 0.590
# resultado da epoca 415 = -22.57 Epsilon = 0.589
# resultado da epoca 416 = 11.75 Epsilon = 0.588
# resultado da epoca 417 = -2.15 Epsilon = 0.587
# resultado da epoca 418 = 7.56 Epsilon = 0.586
# resultado da epoca 419 = -3.81 Epsilon = 0.585
# resultado da epoca 420 = -5.23 Epsilon = 0.584
# resultado da epoca 421 = 3.51 Epsilon = 0.583
# resultado da epoca 422 = 11.07 Epsilon = 0.582
# resultado da epoca 423 = -4.24 Epsilon = 0.581
# resultado da epoca 424 = 11.07 Epsilon = 0.580
# resultado da epoca 425 = -0.55 Epsilon = 0.579
# resultado da epoca 426 = 4.49 Epsilon = 0.578
# resultado da epoca 427 = 9.41 Epsilon = 0.577
# resultado da epoca 428 = -18.02 Epsilon = 0.576
# resultado da epoca 429 = -0.80 Epsilon = 0.575
# resultado da epoca 430 = -7.99 Epsilon = 0.574
# resultado da epoca 431 = -2.71 Epsilon = 0.573
# resultado da epoca 432 = 9.84 Epsilon = 0.572
# resultado da epoca 433 = -1.72 Epsilon = 0.571
# resultado da epoca 434 = 0.98 Epsilon = 0.570
# resultado da epoca 435 = 4.67 Epsilon = 0.569
# resultado da epoca 436 = 3.14 Epsilon = 0.568
# resultado da epoca 437 = -17.16 Epsilon = 0.567
# resultado da epoca 438 = 9.22 Epsilon = 0.566
# resultado da epoca 439 = -0.43 Epsilon = 0.565
# resultado da epoca 440 = 7.87 Epsilon = 0.564
# resultado da epoca 441 = -6.76 Epsilon = 0.563
# resultado da epoca 442 = 1.72 Epsilon = 0.562
# resultado da epoca 443 = -11.44 Epsilon = 0.561
# resultado da epoca 444 = 21.83 Epsilon = 0.560
# resultado da epoca 445 = 5.17 Epsilon = 0.559
# resultado da epoca 446 = 11.50 Epsilon = 0.558
# resultado da epoca 447 = -6.27 Epsilon = 0.557
# resultado da epoca 448 = -17.96 Epsilon = 0.556
# resultado da epoca 449 = 16.85 Epsilon = 0.555
# resultado da epoca 450 = -8.24 Epsilon = 0.554
# resultado da epoca 451 = -4.00 Epsilon = 0.554
# resultado da epoca 452 = -0.92 Epsilon = 0.553
# resultado da epoca 453 = 9.04 Epsilon = 0.552
# resultado da epoca 454 = -0.31 Epsilon = 0.551
# resultado da epoca 455 = -12.36 Epsilon = 0.550
# resultado da epoca 456 = -0.31 Epsilon = 0.549
# resultado da epoca 457 = -14.39 Epsilon = 0.548
# resultado da epoca 458 = 11.62 Epsilon = 0.547
# resultado da epoca 459 = -26.87 Epsilon = 0.546
# resultado da epoca 460 = -4.30 Epsilon = 0.545
# resultado da epoca 461 = 1.72 Epsilon = 0.544
# resultado da epoca 462 = -17.59 Epsilon = 0.543
# resultado da epoca 463 = -21.77 Epsilon = 0.542
# resultado da epoca 464 = 4.98 Epsilon = 0.541
# resultado da epoca 465 = 8.92 Epsilon = 0.540
# resultado da epoca 466 = 14.02 Epsilon = 0.539
# resultado da epoca 467 = 23.43 Epsilon = 0.538
# resultado da epoca 468 = -1.91 Epsilon = 0.537
# resultado da epoca 469 = -14.45 Epsilon = 0.536
# resultado da epoca 470 = -15.50 Epsilon = 0.535
# resultado da epoca 471 = -10.70 Epsilon = 0.534
# resultado da epoca 472 = -12.24 Epsilon = 0.533
# resultado da epoca 473 = -6.58 Epsilon = 0.532
# resultado da epoca 474 = -10.64 Epsilon = 0.531
# resultado da epoca 475 = -8.06 Epsilon = 0.530
# resultado da epoca 476 = 14.82 Epsilon = 0.529
# resultado da epoca 477 = -0.80 Epsilon = 0.528
# resultado da epoca 478 = 4.12 Epsilon = 0.527
# resultado da epoca 479 = 12.91 Epsilon = 0.526
# resultado da epoca 480 = -1.60 Epsilon = 0.525
# resultado da epoca 481 = -0.68 Epsilon = 0.524
# resultado da epoca 482 = -3.63 Epsilon = 0.523
# resultado da epoca 483 = -3.51 Epsilon = 0.522
# resultado da epoca 484 = -10.64 Epsilon = 0.521
# resultado da epoca 485 = 16.85 Epsilon = 0.520
# resultado da epoca 486 = -28.90 Epsilon = 0.519
# resultado da epoca 487 = 2.83 Epsilon = 0.518
# resultado da epoca 488 = 16.42 Epsilon = 0.517
# resultado da epoca 489 = -0.12 Epsilon = 0.516
# resultado da epoca 490 = 0.06 Epsilon = 0.515
# resultado da epoca 491 = -1.72 Epsilon = 0.514
# resultado da epoca 492 = -6.89 Epsilon = 0.513
# resultado da epoca 493 = 1.23 Epsilon = 0.512
# resultado da epoca 494 = -1.54 Epsilon = 0.511
# resultado da epoca 495 = 0.55 Epsilon = 0.510
# resultado da epoca 496 = -7.75 Epsilon = 0.509
# resultado da epoca 497 = 1.29 Epsilon = 0.508
# resultado da epoca 498 = -13.53 Epsilon = 0.507
# resultado da epoca 499 = 11.32 Epsilon = 0.506
# resultado da epoca 500 = -9.29 Epsilon = 0.505
# resultado da epoca 501 = -8.24 Epsilon = 0.504
# resultado da epoca 502 = -6.58 Epsilon = 0.503
# resultado da epoca 503 = 13.90 Epsilon = 0.502
# resultado da epoca 504 = 2.77 Epsilon = 0.501
# resultado da epoca 505 = 14.45 Epsilon = 0.500
# resultado da epoca 506 = 8.86 Epsilon = 0.499
# resultado da epoca 507 = -3.69 Epsilon = 0.498
# resultado da epoca 508 = -9.29 Epsilon = 0.497
# resultado da epoca 509 = 7.63 Epsilon = 0.496
# resultado da epoca 510 = 1.41 Epsilon = 0.495
# resultado da epoca 511 = 11.01 Epsilon = 0.494
# resultado da epoca 512 = -19.74 Epsilon = 0.493
# resultado da epoca 513 = -0.74 Epsilon = 0.492
# resultado da epoca 514 = 7.26 Epsilon = 0.491
# resultado da epoca 515 = 7.01 Epsilon = 0.490
# resultado da epoca 516 = 23.12 Epsilon = 0.489
# resultado da epoca 517 = -7.01 Epsilon = 0.488
# resultado da epoca 518 = 2.46 Epsilon = 0.487
# resultado da epoca 519 = -11.19 Epsilon = 0.486
# resultado da epoca 520 = -20.97 Epsilon = 0.485
# resultado da epoca 521 = 9.53 Epsilon = 0.484
# resultado da epoca 522 = -5.29 Epsilon = 0.483
# resultado da epoca 523 = 33.15 Epsilon = 0.482
# resultado da epoca 524 = 10.76 Epsilon = 0.481
# resultado da epoca 525 = 15.80 Epsilon = 0.480
# resultado da epoca 526 = -5.23 Epsilon = 0.479
# resultado da epoca 527 = -10.33 Epsilon = 0.478
# resultado da epoca 528 = 20.54 Epsilon = 0.477
# resultado da epoca 529 = -3.14 Epsilon = 0.476
# resultado da epoca 530 = 6.03 Epsilon = 0.475
# resultado da epoca 531 = -4.74 Epsilon = 0.474
# resultado da epoca 532 = -12.11 Epsilon = 0.473
# resultado da epoca 533 = 5.66 Epsilon = 0.472
# resultado da epoca 534 = -3.14 Epsilon = 0.471
# resultado da epoca 535 = -5.04 Epsilon = 0.470
# resultado da epoca 536 = -4.00 Epsilon = 0.469
# resultado da epoca 537 = -3.44 Epsilon = 0.468
# resultado da epoca 538 = -10.02 Epsilon = 0.467
# resultado da epoca 539 = 9.53 Epsilon = 0.466
# resultado da epoca 540 = 23.55 Epsilon = 0.465
# resultado da epoca 541 = 12.73 Epsilon = 0.464
# resultado da epoca 542 = -2.89 Epsilon = 0.463
# resultado da epoca 543 = -1.54 Epsilon = 0.462
# resultado da epoca 544 = 6.21 Epsilon = 0.461
# resultado da epoca 545 = -7.26 Epsilon = 0.460
# resultado da epoca 546 = 24.84 Epsilon = 0.459
# resultado da epoca 547 = 13.34 Epsilon = 0.458
# resultado da epoca 548 = 4.18 Epsilon = 0.457
# resultado da epoca 549 = 10.39 Epsilon = 0.456
# resultado da epoca 550 = -13.22 Epsilon = 0.455
# resultado da epoca 551 = 4.18 Epsilon = 0.455
# resultado da epoca 552 = -9.22 Epsilon = 0.454
# resultado da epoca 553 = -4.37 Epsilon = 0.453
# resultado da epoca 554 = -12.91 Epsilon = 0.452
# resultado da epoca 555 = 6.33 Epsilon = 0.451
# resultado da epoca 556 = 15.87 Epsilon = 0.450
# resultado da epoca 557 = -3.07 Epsilon = 0.449
# resultado da epoca 558 = 0.68 Epsilon = 0.448
# resultado da epoca 559 = 4.12 Epsilon = 0.447
# resultado da epoca 560 = 21.83 Epsilon = 0.446
# resultado da epoca 561 = 16.85 Epsilon = 0.445
# resultado da epoca 562 = 0.37 Epsilon = 0.444
# resultado da epoca 563 = -1.05 Epsilon = 0.443
# resultado da epoca 564 = 0.74 Epsilon = 0.442
# resultado da epoca 565 = -16.42 Epsilon = 0.441
# resultado da epoca 566 = -0.86 Epsilon = 0.440
# resultado da epoca 567 = -4.67 Epsilon = 0.439
# resultado da epoca 568 = 26.57 Epsilon = 0.438
# resultado da epoca 569 = -1.78 Epsilon = 0.437
# resultado da epoca 570 = 10.76 Epsilon = 0.436
# resultado da epoca 571 = 14.88 Epsilon = 0.435
# resultado da epoca 572 = -3.32 Epsilon = 0.434
# resultado da epoca 573 = 13.84 Epsilon = 0.433
# resultado da epoca 574 = -1.78 Epsilon = 0.432
# resultado da epoca 575 = -0.18 Epsilon = 0.431
# resultado da epoca 576 = 2.34 Epsilon = 0.430
# resultado da epoca 577 = 3.94 Epsilon = 0.429
# resultado da epoca 578 = 14.88 Epsilon = 0.428
# resultado da epoca 579 = 10.09 Epsilon = 0.427
# resultado da epoca 580 = 2.52 Epsilon = 0.426
# resultado da epoca 581 = 8.98 Epsilon = 0.425
# resultado da epoca 582 = 21.09 Epsilon = 0.424
# resultado da epoca 583 = 10.33 Epsilon = 0.423
# resultado da epoca 584 = -3.51 Epsilon = 0.422
# resultado da epoca 585 = 19.00 Epsilon = 0.421
# resultado da epoca 586 = 16.54 Epsilon = 0.420
# resultado da epoca 587 = 5.41 Epsilon = 0.419
# resultado da epoca 588 = 11.68 Epsilon = 0.418
# resultado da epoca 589 = -9.66 Epsilon = 0.417
# resultado da epoca 590 = -7.69 Epsilon = 0.416
# resultado da epoca 591 = -5.10 Epsilon = 0.415
# resultado da epoca 592 = 8.98 Epsilon = 0.414
# resultado da epoca 593 = 0.74 Epsilon = 0.413
# resultado da epoca 594 = -8.92 Epsilon = 0.412
# resultado da epoca 595 = 17.71 Epsilon = 0.411
# resultado da epoca 596 = 6.27 Epsilon = 0.410
# resultado da epoca 597 = 0.18 Epsilon = 0.409
# resultado da epoca 598 = -8.06 Epsilon = 0.408
# resultado da epoca 599 = 4.92 Epsilon = 0.407
# resultado da epoca 600 = 8.98 Epsilon = 0.406
# resultado da epoca 601 = 14.45 Epsilon = 0.405
# resultado da epoca 602 = 10.76 Epsilon = 0.404
# resultado da epoca 603 = 4.37 Epsilon = 0.403
# resultado da epoca 604 = 6.46 Epsilon = 0.402
# resultado da epoca 605 = -0.18 Epsilon = 0.401
# resultado da epoca 606 = 18.08 Epsilon = 0.400
# resultado da epoca 607 = -11.56 Epsilon = 0.399
# resultado da epoca 608 = 11.32 Epsilon = 0.398
# resultado da epoca 609 = 6.70 Epsilon = 0.397
# resultado da epoca 610 = 7.07 Epsilon = 0.396
# resultado da epoca 611 = 9.47 Epsilon = 0.395
# resultado da epoca 612 = 6.58 Epsilon = 0.394
# resultado da epoca 613 = -3.26 Epsilon = 0.393
# resultado da epoca 614 = 21.46 Epsilon = 0.392
# resultado da epoca 615 = 14.21 Epsilon = 0.391
# resultado da epoca 616 = -10.15 Epsilon = 0.390
# resultado da epoca 617 = -1.60 Epsilon = 0.389
# resultado da epoca 618 = -13.22 Epsilon = 0.388
# resultado da epoca 619 = 2.34 Epsilon = 0.387
# resultado da epoca 620 = 6.46 Epsilon = 0.386
# resultado da epoca 621 = -12.48 Epsilon = 0.385
# resultado da epoca 622 = 23.92 Epsilon = 0.384
# resultado da epoca 623 = 7.07 Epsilon = 0.383
# resultado da epoca 624 = 9.29 Epsilon = 0.382
# resultado da epoca 625 = 11.01 Epsilon = 0.381
# resultado da epoca 626 = -0.80 Epsilon = 0.380
# resultado da epoca 627 = -3.14 Epsilon = 0.379
# resultado da epoca 628 = 12.55 Epsilon = 0.378
# resultado da epoca 629 = 6.70 Epsilon = 0.377
# resultado da epoca 630 = 28.10 Epsilon = 0.376
# resultado da epoca 631 = 13.22 Epsilon = 0.375
# resultado da epoca 632 = 10.95 Epsilon = 0.374
# resultado da epoca 633 = 15.87 Epsilon = 0.373
# resultado da epoca 634 = 20.11 Epsilon = 0.372
# resultado da epoca 635 = 19.25 Epsilon = 0.371
# resultado da epoca 636 = -1.97 Epsilon = 0.370
# resultado da epoca 637 = 11.38 Epsilon = 0.369
# resultado da epoca 638 = 20.54 Epsilon = 0.368
# resultado da epoca 639 = 10.39 Epsilon = 0.367
# resultado da epoca 640 = -0.80 Epsilon = 0.366
# resultado da epoca 641 = 0.80 Epsilon = 0.365
# resultado da epoca 642 = 12.18 Epsilon = 0.364
# resultado da epoca 643 = 8.86 Epsilon = 0.363
# resultado da epoca 644 = 28.23 Epsilon = 0.362
# resultado da epoca 645 = 9.66 Epsilon = 0.361
# resultado da epoca 646 = 15.01 Epsilon = 0.360
# resultado da epoca 647 = -1.54 Epsilon = 0.359
# resultado da epoca 648 = 19.49 Epsilon = 0.358
# resultado da epoca 649 = 16.42 Epsilon = 0.357
# resultado da epoca 650 = -7.38 Epsilon = 0.356
# resultado da epoca 651 = 11.81 Epsilon = 0.356
# resultado da epoca 652 = 12.55 Epsilon = 0.355
# resultado da epoca 653 = 9.59 Epsilon = 0.354
# resultado da epoca 654 = 28.41 Epsilon = 0.353
# resultado da epoca 655 = 5.53 Epsilon = 0.352
# resultado da epoca 656 = 21.28 Epsilon = 0.351
# resultado da epoca 657 = 0.00 Epsilon = 0.350
# resultado da epoca 658 = 13.53 Epsilon = 0.349
# resultado da epoca 659 = 17.34 Epsilon = 0.348
# resultado da epoca 660 = 19.13 Epsilon = 0.347
# resultado da epoca 661 = 11.19 Epsilon = 0.346
# resultado da epoca 662 = 17.59 Epsilon = 0.345
# resultado da epoca 663 = -4.49 Epsilon = 0.344
# resultado da epoca 664 = 23.12 Epsilon = 0.343
# resultado da epoca 665 = 10.33 Epsilon = 0.342
# resultado da epoca 666 = 45.69 Epsilon = 0.341
# resultado da epoca 667 = 8.30 Epsilon = 0.340
# resultado da epoca 668 = 20.66 Epsilon = 0.339
# resultado da epoca 669 = -13.34 Epsilon = 0.338
# resultado da epoca 670 = 16.60 Epsilon = 0.337
# resultado da epoca 671 = 2.09 Epsilon = 0.336
# resultado da epoca 672 = 5.72 Epsilon = 0.335
# resultado da epoca 673 = 12.24 Epsilon = 0.334
# resultado da epoca 674 = 10.15 Epsilon = 0.333
# resultado da epoca 675 = 10.95 Epsilon = 0.332
# resultado da epoca 676 = 8.43 Epsilon = 0.331
# resultado da epoca 677 = 13.47 Epsilon = 0.330
# resultado da epoca 678 = 17.71 Epsilon = 0.329
# resultado da epoca 679 = 25.71 Epsilon = 0.328
# resultado da epoca 680 = 18.26 Epsilon = 0.327
# resultado da epoca 681 = 27.86 Epsilon = 0.326
# resultado da epoca 682 = 18.02 Epsilon = 0.325
# resultado da epoca 683 = 17.28 Epsilon = 0.324
# resultado da epoca 684 = 4.55 Epsilon = 0.323
# resultado da epoca 685 = 2.52 Epsilon = 0.322
# resultado da epoca 686 = -0.86 Epsilon = 0.321
# resultado da epoca 687 = 5.04 Epsilon = 0.320
# resultado da epoca 688 = 4.49 Epsilon = 0.319
# resultado da epoca 689 = 5.60 Epsilon = 0.318
# resultado da epoca 690 = 24.05 Epsilon = 0.317
# resultado da epoca 691 = 37.88 Epsilon = 0.316
# resultado da epoca 692 = 14.39 Epsilon = 0.315
# resultado da epoca 693 = 22.39 Epsilon = 0.314
# resultado da epoca 694 = 3.26 Epsilon = 0.313
# resultado da epoca 695 = 0.00 Epsilon = 0.312
# resultado da epoca 696 = 29.89 Epsilon = 0.311
# resultado da epoca 697 = 28.23 Epsilon = 0.310
# resultado da epoca 698 = 9.41 Epsilon = 0.309
# resultado da epoca 699 = 6.76 Epsilon = 0.308
# resultado da epoca 700 = 2.77 Epsilon = 0.307
# resultado da epoca 701 = 0.00 Epsilon = 0.306
# resultado da epoca 702 = 27.92 Epsilon = 0.305
# resultado da epoca 703 = 31.79 Epsilon = 0.304
# resultado da epoca 704 = 18.76 Epsilon = 0.303
# resultado da epoca 705 = 13.71 Epsilon = 0.302
# resultado da epoca 706 = 23.61 Epsilon = 0.301
# resultado da epoca 707 = 15.68 Epsilon = 0.300
# resultado da epoca 708 = 0.18 Epsilon = 0.299
# resultado da epoca 709 = 21.52 Epsilon = 0.298
# resultado da epoca 710 = -0.92 Epsilon = 0.297
# resultado da epoca 711 = 12.79 Epsilon = 0.296
# resultado da epoca 712 = 1.29 Epsilon = 0.295
# resultado da epoca 713 = 6.03 Epsilon = 0.294
# resultado da epoca 714 = 10.21 Epsilon = 0.293
# resultado da epoca 715 = 7.13 Epsilon = 0.292
# resultado da epoca 716 = 7.32 Epsilon = 0.291
# resultado da epoca 717 = -9.96 Epsilon = 0.290
# resultado da epoca 718 = 15.07 Epsilon = 0.289
# resultado da epoca 719 = 16.05 Epsilon = 0.288
# resultado da epoca 720 = 25.03 Epsilon = 0.287
# resultado da epoca 721 = 16.11 Epsilon = 0.286
# resultado da epoca 722 = 8.18 Epsilon = 0.285
# resultado da epoca 723 = 21.83 Epsilon = 0.284
# resultado da epoca 724 = 33.33 Epsilon = 0.283
# resultado da epoca 725 = -0.92 Epsilon = 0.282
# resultado da epoca 726 = 6.70 Epsilon = 0.281
# resultado da epoca 727 = 29.03 Epsilon = 0.280
# resultado da epoca 728 = 30.63 Epsilon = 0.279
# resultado da epoca 729 = 16.67 Epsilon = 0.278
# resultado da epoca 730 = 26.20 Epsilon = 0.277
# resultado da epoca 731 = 4.61 Epsilon = 0.276
# resultado da epoca 732 = 3.87 Epsilon = 0.275
# resultado da epoca 733 = 9.84 Epsilon = 0.274
# resultado da epoca 734 = 9.04 Epsilon = 0.273
# resultado da epoca 735 = -5.17 Epsilon = 0.272
# resultado da epoca 736 = 3.26 Epsilon = 0.271
# resultado da epoca 737 = 32.22 Epsilon = 0.270
# resultado da epoca 738 = 21.83 Epsilon = 0.269
# resultado da epoca 739 = 1.48 Epsilon = 0.268
# resultado da epoca 740 = 23.31 Epsilon = 0.267
# resultado da epoca 741 = 2.58 Epsilon = 0.266
# resultado da epoca 742 = 7.93 Epsilon = 0.265
# resultado da epoca 743 = 20.79 Epsilon = 0.264
# resultado da epoca 744 = -14.14 Epsilon = 0.263
# resultado da epoca 745 = 9.59 Epsilon = 0.262
# resultado da epoca 746 = 35.79 Epsilon = 0.261
# resultado da epoca 747 = 30.63 Epsilon = 0.260
# resultado da epoca 748 = 12.48 Epsilon = 0.259
# resultado da epoca 749 = 13.59 Epsilon = 0.258
# resultado da epoca 750 = 19.68 Epsilon = 0.257
# resultado da epoca 751 = 34.75 Epsilon = 0.257
# resultado da epoca 752 = 13.59 Epsilon = 0.256
# resultado da epoca 753 = -17.71 Epsilon = 0.255
# resultado da epoca 754 = 22.57 Epsilon = 0.254
# resultado da epoca 755 = 24.66 Epsilon = 0.253
# resultado da epoca 756 = 10.45 Epsilon = 0.252
# resultado da epoca 757 = 15.50 Epsilon = 0.251
# resultado da epoca 758 = 39.60 Epsilon = 0.250
# resultado da epoca 759 = 11.32 Epsilon = 0.249
# resultado da epoca 760 = 15.99 Epsilon = 0.248
# resultado da epoca 761 = -6.40 Epsilon = 0.247
# resultado da epoca 762 = 19.13 Epsilon = 0.246
# resultado da epoca 763 = 25.95 Epsilon = 0.245
# resultado da epoca 764 = 19.93 Epsilon = 0.244
# resultado da epoca 765 = 19.56 Epsilon = 0.243
# resultado da epoca 766 = 26.32 Epsilon = 0.242
# resultado da epoca 767 = 19.31 Epsilon = 0.241
# resultado da epoca 768 = 32.41 Epsilon = 0.240
# resultado da epoca 769 = 15.62 Epsilon = 0.239
# resultado da epoca 770 = 33.95 Epsilon = 0.238
# resultado da epoca 771 = 24.17 Epsilon = 0.237
# resultado da epoca 772 = 27.24 Epsilon = 0.236
# resultado da epoca 773 = 22.02 Epsilon = 0.235
# resultado da epoca 774 = 27.55 Epsilon = 0.234
# resultado da epoca 775 = 9.59 Epsilon = 0.233
# resultado da epoca 776 = 17.22 Epsilon = 0.232
# resultado da epoca 777 = 24.41 Epsilon = 0.231
# resultado da epoca 778 = 13.78 Epsilon = 0.230
# resultado da epoca 779 = 12.79 Epsilon = 0.229
# resultado da epoca 780 = 13.65 Epsilon = 0.228
# resultado da epoca 781 = 27.18 Epsilon = 0.227
# resultado da epoca 782 = 14.27 Epsilon = 0.226
# resultado da epoca 783 = 28.35 Epsilon = 0.225
# resultado da epoca 784 = 5.41 Epsilon = 0.224
# resultado da epoca 785 = 9.10 Epsilon = 0.223
# resultado da epoca 786 = 13.71 Epsilon = 0.222
# resultado da epoca 787 = 11.81 Epsilon = 0.221
# resultado da epoca 788 = 10.45 Epsilon = 0.220
# resultado da epoca 789 = 19.13 Epsilon = 0.219
# resultado da epoca 790 = 17.59 Epsilon = 0.218
# resultado da epoca 791 = 11.38 Epsilon = 0.217
# resultado da epoca 792 = 14.02 Epsilon = 0.216
# resultado da epoca 793 = 1.66 Epsilon = 0.215
# resultado da epoca 794 = 28.29 Epsilon = 0.214
# resultado da epoca 795 = -11.13 Epsilon = 0.213
# resultado da epoca 796 = 12.11 Epsilon = 0.212
# resultado da epoca 797 = 15.37 Epsilon = 0.211
# resultado da epoca 798 = 16.97 Epsilon = 0.210
# resultado da epoca 799 = 16.05 Epsilon = 0.209
# resultado da epoca 800 = 12.73 Epsilon = 0.208
# resultado da epoca 801 = 20.11 Epsilon = 0.207
# resultado da epoca 802 = -17.03 Epsilon = 0.206
# resultado da epoca 803 = -10.58 Epsilon = 0.205
# resultado da epoca 804 = 17.16 Epsilon = 0.204
# resultado da epoca 805 = 15.25 Epsilon = 0.203
# resultado da epoca 806 = 32.96 Epsilon = 0.202
# resultado da epoca 807 = 20.54 Epsilon = 0.201
# resultado da epoca 808 = -3.26 Epsilon = 0.200
# resultado da epoca 809 = 14.51 Epsilon = 0.199
# resultado da epoca 810 = 23.00 Epsilon = 0.198
# resultado da epoca 811 = 4.98 Epsilon = 0.197
# resultado da epoca 812 = 9.35 Epsilon = 0.196
# resultado da epoca 813 = -4.06 Epsilon = 0.195
# resultado da epoca 814 = 23.49 Epsilon = 0.194
# resultado da epoca 815 = 7.75 Epsilon = 0.193
# resultado da epoca 816 = 2.40 Epsilon = 0.192
# resultado da epoca 817 = -7.56 Epsilon = 0.191
# resultado da epoca 818 = 4.12 Epsilon = 0.190
# resultado da epoca 819 = 21.89 Epsilon = 0.189
# resultado da epoca 820 = 12.36 Epsilon = 0.188
# resultado da epoca 821 = 19.68 Epsilon = 0.187
# resultado da epoca 822 = 29.58 Epsilon = 0.186
# resultado da epoca 823 = 23.49 Epsilon = 0.185
# resultado da epoca 824 = 15.19 Epsilon = 0.184
# resultado da epoca 825 = 17.22 Epsilon = 0.183
# resultado da epoca 826 = 12.18 Epsilon = 0.182
# resultado da epoca 827 = 13.41 Epsilon = 0.181
# resultado da epoca 828 = 15.19 Epsilon = 0.180
# resultado da epoca 829 = 17.10 Epsilon = 0.179
# resultado da epoca 830 = 28.97 Epsilon = 0.178
# resultado da epoca 831 = 29.95 Epsilon = 0.177
# resultado da epoca 832 = -2.34 Epsilon = 0.176
# resultado da epoca 833 = 17.10 Epsilon = 0.175
# resultado da epoca 834 = 22.57 Epsilon = 0.174
# resultado da epoca 835 = 14.51 Epsilon = 0.173
# resultado da epoca 836 = 8.55 Epsilon = 0.172
# resultado da epoca 837 = 17.96 Epsilon = 0.171
# resultado da epoca 838 = 17.59 Epsilon = 0.170
# resultado da epoca 839 = 2.95 Epsilon = 0.169
# resultado da epoca 840 = 13.41 Epsilon = 0.168
# resultado da epoca 841 = 18.57 Epsilon = 0.167
# resultado da epoca 842 = 4.92 Epsilon = 0.166
# resultado da epoca 843 = 14.64 Epsilon = 0.165
# resultado da epoca 844 = 17.03 Epsilon = 0.164
# resultado da epoca 845 = 12.18 Epsilon = 0.163
# resultado da epoca 846 = 33.02 Epsilon = 0.162
# resultado da epoca 847 = 8.30 Epsilon = 0.161
# resultado da epoca 848 = 20.36 Epsilon = 0.160
# resultado da epoca 849 = 3.51 Epsilon = 0.159
# resultado da epoca 850 = 18.94 Epsilon = 0.158
# resultado da epoca 851 = 13.22 Epsilon = 0.158
# resultado da epoca 852 = 33.45 Epsilon = 0.157
# resultado da epoca 853 = 28.47 Epsilon = 0.156
# resultado da epoca 854 = 6.58 Epsilon = 0.155
# resultado da epoca 855 = 24.91 Epsilon = 0.154
# resultado da epoca 856 = 8.55 Epsilon = 0.153
# resultado da epoca 857 = 7.87 Epsilon = 0.152
# resultado da epoca 858 = -9.22 Epsilon = 0.151
# resultado da epoca 859 = 5.84 Epsilon = 0.150
# resultado da epoca 860 = 14.08 Epsilon = 0.149
# resultado da epoca 861 = 13.34 Epsilon = 0.148
# resultado da epoca 862 = 5.60 Epsilon = 0.147
# resultado da epoca 863 = 22.02 Epsilon = 0.146
# resultado da epoca 864 = 31.79 Epsilon = 0.145
# resultado da epoca 865 = 18.63 Epsilon = 0.144
# resultado da epoca 866 = 6.64 Epsilon = 0.143
# resultado da epoca 867 = 25.09 Epsilon = 0.142
# resultado da epoca 868 = -2.77 Epsilon = 0.141
# resultado da epoca 869 = 15.13 Epsilon = 0.140
# resultado da epoca 870 = 8.24 Epsilon = 0.139
# resultado da epoca 871 = 13.71 Epsilon = 0.138
# resultado da epoca 872 = 15.56 Epsilon = 0.137
# resultado da epoca 873 = 15.25 Epsilon = 0.136
# resultado da epoca 874 = 15.31 Epsilon = 0.135
# resultado da epoca 875 = 9.41 Epsilon = 0.134
# resultado da epoca 876 = 12.36 Epsilon = 0.133
# resultado da epoca 877 = 17.59 Epsilon = 0.132
# resultado da epoca 878 = 9.04 Epsilon = 0.131
# resultado da epoca 879 = 4.74 Epsilon = 0.130
# resultado da epoca 880 = 16.48 Epsilon = 0.129
# resultado da epoca 881 = 21.52 Epsilon = 0.128
# resultado da epoca 882 = 23.06 Epsilon = 0.127
# resultado da epoca 883 = 14.94 Epsilon = 0.126
# resultado da epoca 884 = 20.11 Epsilon = 0.125
# resultado da epoca 885 = 20.23 Epsilon = 0.124
# resultado da epoca 886 = -3.38 Epsilon = 0.123
# resultado da epoca 887 = 9.29 Epsilon = 0.122
# resultado da epoca 888 = 11.93 Epsilon = 0.121
# resultado da epoca 889 = 31.43 Epsilon = 0.120
# resultado da epoca 890 = 22.69 Epsilon = 0.119
# resultado da epoca 891 = -1.17 Epsilon = 0.118
# resultado da epoca 892 = 6.83 Epsilon = 0.117
# resultado da epoca 893 = 1.97 Epsilon = 0.116
# resultado da epoca 894 = 2.77 Epsilon = 0.115
# resultado da epoca 895 = 2.58 Epsilon = 0.114
# resultado da epoca 896 = 29.64 Epsilon = 0.113
# resultado da epoca 897 = 25.71 Epsilon = 0.112
# resultado da epoca 898 = 7.44 Epsilon = 0.111
# resultado da epoca 899 = 19.49 Epsilon = 0.110
# resultado da epoca 900 = 6.52 Epsilon = 0.109
# resultado da epoca 901 = 20.85 Epsilon = 0.108
# resultado da epoca 902 = 6.89 Epsilon = 0.107
# resultado da epoca 903 = 7.87 Epsilon = 0.106
# resultado da epoca 904 = 11.50 Epsilon = 0.105
# resultado da epoca 905 = 0.12 Epsilon = 0.104
# resultado da epoca 906 = 19.99 Epsilon = 0.103
# resultado da epoca 907 = 2.95 Epsilon = 0.102
# resultado da epoca 908 = 7.50 Epsilon = 0.101
# resultado da epoca 909 = 14.14 Epsilon = 0.100
# resultado da epoca 910 = 0.43 Epsilon = 0.099
# resultado da epoca 911 = 6.09 Epsilon = 0.098
# resultado da epoca 912 = 27.43 Epsilon = 0.097
# resultado da epoca 913 = 3.81 Epsilon = 0.096
# resultado da epoca 914 = 9.29 Epsilon = 0.095
# resultado da epoca 915 = 7.93 Epsilon = 0.094
# resultado da epoca 916 = 12.55 Epsilon = 0.093
# resultado da epoca 917 = 28.41 Epsilon = 0.092
# resultado da epoca 918 = 15.56 Epsilon = 0.091
# resultado da epoca 919 = 17.28 Epsilon = 0.090
# resultado da epoca 920 = 22.14 Epsilon = 0.089
# resultado da epoca 921 = 22.57 Epsilon = 0.088
# resultado da epoca 922 = 2.09 Epsilon = 0.087
# resultado da epoca 923 = 3.20 Epsilon = 0.086
# resultado da epoca 924 = 12.42 Epsilon = 0.085
# resultado da epoca 925 = 20.66 Epsilon = 0.084
# resultado da epoca 926 = 13.28 Epsilon = 0.083
# resultado da epoca 927 = 25.77 Epsilon = 0.082
# resultado da epoca 928 = 16.30 Epsilon = 0.081
# resultado da epoca 929 = 7.69 Epsilon = 0.080
# resultado da epoca 930 = 14.14 Epsilon = 0.079
# resultado da epoca 931 = -8.61 Epsilon = 0.078
# resultado da epoca 932 = 3.01 Epsilon = 0.077
# resultado da epoca 933 = 12.79 Epsilon = 0.076
# resultado da epoca 934 = 14.45 Epsilon = 0.075
# resultado da epoca 935 = 6.52 Epsilon = 0.074
# resultado da epoca 936 = 27.74 Epsilon = 0.073
# resultado da epoca 937 = -2.89 Epsilon = 0.072
# resultado da epoca 938 = 7.07 Epsilon = 0.071
# resultado da epoca 939 = 25.28 Epsilon = 0.070
# resultado da epoca 940 = 25.40 Epsilon = 0.069
# resultado da epoca 941 = 13.65 Epsilon = 0.068
# resultado da epoca 942 = 10.39 Epsilon = 0.067
# resultado da epoca 943 = 16.11 Epsilon = 0.066
# resultado da epoca 944 = 17.28 Epsilon = 0.065
# resultado da epoca 945 = 9.29 Epsilon = 0.064
# resultado da epoca 946 = 12.79 Epsilon = 0.063
# resultado da epoca 947 = 16.97 Epsilon = 0.062
# resultado da epoca 948 = 11.62 Epsilon = 0.061
# resultado da epoca 949 = 7.99 Epsilon = 0.060
# resultado da epoca 950 = 21.65 Epsilon = 0.059
# resultado da epoca 951 = 17.10 Epsilon = 0.059
# resultado da epoca 952 = 8.73 Epsilon = 0.058
# resultado da epoca 953 = 20.11 Epsilon = 0.057
# resultado da epoca 954 = 13.84 Epsilon = 0.056
# resultado da epoca 955 = 17.47 Epsilon = 0.055
# resultado da epoca 956 = 15.44 Epsilon = 0.054
# resultado da epoca 957 = 0.25 Epsilon = 0.053
# resultado da epoca 958 = 18.76 Epsilon = 0.052
# resultado da epoca 959 = 11.56 Epsilon = 0.051
# resultado da epoca 960 = 20.42 Epsilon = 0.050
# resultado da epoca 961 = 12.11 Epsilon = 0.049
# resultado da epoca 962 = 18.82 Epsilon = 0.048
# resultado da epoca 963 = 23.74 Epsilon = 0.047
# resultado da epoca 964 = 10.45 Epsilon = 0.046
# resultado da epoca 965 = 7.50 Epsilon = 0.045
# resultado da epoca 966 = 15.74 Epsilon = 0.044
# resultado da epoca 967 = 21.71 Epsilon = 0.043
# resultado da epoca 968 = 13.65 Epsilon = 0.042
# resultado da epoca 969 = 20.48 Epsilon = 0.041
# resultado da epoca 970 = 18.26 Epsilon = 0.040
# resultado da epoca 971 = 22.69 Epsilon = 0.039
# resultado da epoca 972 = 15.01 Epsilon = 0.038
# resultado da epoca 973 = 20.72 Epsilon = 0.037
# resultado da epoca 974 = 9.04 Epsilon = 0.036
# resultado da epoca 975 = 12.55 Epsilon = 0.035
# resultado da epoca 976 = 19.56 Epsilon = 0.034
# resultado da epoca 977 = 17.40 Epsilon = 0.033
# resultado da epoca 978 = 16.91 Epsilon = 0.032
# resultado da epoca 979 = 19.80 Epsilon = 0.031
# resultado da epoca 980 = 16.48 Epsilon = 0.030
# resultado da epoca 981 = 15.93 Epsilon = 0.029
# resultado da epoca 982 = 21.77 Epsilon = 0.028
# resultado da epoca 983 = 17.53 Epsilon = 0.027
# resultado da epoca 984 = 15.74 Epsilon = 0.026
# resultado da epoca 985 = 17.59 Epsilon = 0.025
# resultado da epoca 986 = 19.80 Epsilon = 0.024
# resultado da epoca 987 = 11.99 Epsilon = 0.023
# resultado da epoca 988 = 18.45 Epsilon = 0.022
# resultado da epoca 989 = 20.72 Epsilon = 0.021
# resultado da epoca 990 = 18.45 Epsilon = 0.020
# resultado da epoca 991 = 16.79 Epsilon = 0.019
# resultado da epoca 992 = 16.79 Epsilon = 0.018
# resultado da epoca 993 = 18.45 Epsilon = 0.017
# resultado da epoca 994 = 22.32 Epsilon = 0.016
# resultado da epoca 995 = 18.20 Epsilon = 0.015
# resultado da epoca 996 = 16.73 Epsilon = 0.014
# resultado da epoca 997 = 18.08 Epsilon = 0.013
# resultado da epoca 998 = 16.73 Epsilon = 0.012
# resultado da epoca 999 = 18.94 Epsilon = 0.011
# Melhor resultado diario: 45.69

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo))
# Out:
# 18.44918384067858

# %%
np.amax(inputs['preco'])
# Out:
# 36.16442351423735

# %%
plt.plot(range(0,len(inputs)), inputs['preco'])

# %%
plt.plot(range(0,len(inputs_nao_norm)), inputs_nao_norm['preco'])
