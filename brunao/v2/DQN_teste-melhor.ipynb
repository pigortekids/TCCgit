# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int', 'preco_pon', 'qnt_soma']#, 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 5
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 250

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
inputs_nao_norm = arquivo[index_arquivo]
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1
print(inputs)
#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
       
    inputs.loc[:, inputs.columns[i]] = inputs.loc[:, inputs.columns[i]] - imean 

valor0 = np.amin(inputs['preco']) - 500
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         preco    hr_int  preco_pon  qnt_soma
# 0      3907.5  32700000    3907.50       1.0
# 1      3900.0  33000000    3901.26   20309.0
# 2      3898.0  33300000    3901.42   17614.0
# 3      3898.0  33600000    3895.37   14283.0
# 4      3899.5  33900000    3897.78    6638.0
# 5      3906.0  34200000    3902.52   13485.0
# 6      3908.0  34500000    3907.20   12677.0
# 7      3913.0  34800000    3910.72   17927.0
# 8      3906.0  35100000    3909.27   18032.0
# 9      3902.0  35400000    3904.82   17600.0
# 10     3900.5  35700000    3900.53    9326.0
# 11     3894.0  36000000    3896.53   18013.0
# 12     3897.5  36300000    3897.41   14159.0
# 13     3900.0  36600000    3897.87    5793.0
# 14     3906.0  36900000    3902.17   15901.0
# 15     3907.5  37200000    3905.68   12928.0
# 16     3908.0  37500000    3908.40    7904.0
# 17     3911.0  37800000    3909.38    7750.0
# 18     3911.0  38100000    3912.43   10917.0
# 19     3908.5  38400000    3910.42    8978.0
# 20     3916.5  38700000    3913.49   12775.0
# 21     3914.0  39000000    3915.66    7874.0
# 22     3912.0  39300000    3913.06    6877.0
# 23     3910.5  39600000    3910.59    6747.0
# 24     3917.5  39900000    3914.81   12360.0
# 25     3914.0  40200000    3915.96    8289.0
# 26     3918.5  40500000    3916.91    6028.0
# 27     3918.0  40800000    3917.95    4025.0
# 28     3918.5  41100000    3917.52    4618.0
# 29     3917.5  41400000    3917.21    2747.0
# ...       ...       ...        ...       ...
# 30074  4076.5  55500000    4076.10    9242.0
# 30075  4076.5  55800000    4076.64    4228.0
# 30076  4076.0  56100000    4075.85    3009.0
# 30077  4078.5  56400000    4077.82    9162.0
# 30078  4078.0  56700000    4078.75    5166.0
# 30079  4080.0  57000000    4078.75    4928.0
# 30080  4083.0  57300000    4081.52    9979.0
# 30081  4078.0  57600000    4080.32   17157.0
# 30082  4077.5  57900000    4078.53    5130.0
# 30083  4077.5  58200000    4077.40    3576.0
# 30084  4075.0  58500000    4075.73    7682.0
# 30085  4077.0  58800000    4076.49    3760.0
# 30086  4075.5  59100000    4076.04    2943.0
# 30087  4080.5  59400000    4078.23    7689.0
# 30088  4079.5  59700000    4080.42    9414.0
# 30089  4081.5  60000000    4079.69    8811.0
# 30090  4082.5  60300000    4081.89    8741.0
# 30091  4083.5  60600000    4083.25    6228.0
# 30092  4084.0  60900000    4083.63    3415.0
# 30093  4085.5  61200000    4084.95    5914.0
# 30094  4081.0  61500000    4083.09    7944.0
# 30095  4079.5  61800000    4080.75    5461.0
# 30096  4078.0  62100000    4079.08    4891.0
# 30097  4079.0  62400000    4078.74    2705.0
# 30098  4077.5  62700000    4078.02    2231.0
# 30099  4074.0  63000000    4074.69    9221.0
# 30100  4071.5  63300000    4071.88    5389.0
# 30101  4071.0  63600000    4070.23    5930.0
# 30102  4069.0  63900000    4071.37    5387.0
# 30103  4068.5  64200000    4069.33    4407.0
#
# [30104 rows x 4 columns]
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 5
        self.action_size = action_size
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.98     # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(512, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(196, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)        
        model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(64, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(32, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        
        #model.add(Dense(128, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(x*3, activation='relu')) #camada escondida
        #model.add(Dense(x*2, activation='relu')) #camada escondida
        #model.add(Dense(x, activation='relu')) #camada escondida
        #model.add(Dense(64, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size) if dias>5 else self.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3072
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 196)               50372
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               25216
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 11)                363
# =================================================================
# Total params: 286,479
# Trainable params: 286,479
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(preco, ncont, acao, valor, custo=0):   

    if acao == 0: #zerado
        if ncont>0:  #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        elif ncont<0: #zerando
            reward = ncont*(preco-valor) -custo*abs(ncont)
        else:         
            reward = 0
        valor = valor0
    elif acao>0:  #comprado
        if ncont>0:
            if acao>ncont: #aumento da posicao
                reward = -custo*(acao-ncont)
                valor = (valor*ncont+(acao-ncont)*preco)/(acao)  #calculo preco medio
            elif acao<ncont:  #diminuicao da posicao
                reward = (ncont-acao)*(preco-valor) -custo*(ncont-acao)
                valor = valor #preco medio se mantem
            else:
                reward = 0
        elif ncont<0:   #trocando a mao
            reward = abs(ncont)*(valor-preco) -custo*(acao+abs(ncont))
            valor = preco
        else:          #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
    else:       #vendido
        if ncont>0:#trocando a mao
            reward = ncont*(preco-valor) -custo*(ncont+abs(acao))
            valor = preco
        elif ncont<0:
            if abs(acao)<abs(ncont): #diminuicao da posicao
                reward = (abs(ncont)-abs(acao))*(valor-preco) -custo*(abs(ncont)-abs(acao))
                valor = valor #preco medio se mantem
            elif abs(acao)>abs(ncont): #aumento da posicao
                reward = -custo*(abs(acao)-abs(ncont))
                valor = (valor*abs(ncont)+(abs(acao)-abs(ncont))*preco)/(abs(acao))  #calculo preco medio
            else: #preco medio se mantem
                reward = 0
        else:  #saiu do zero
            reward = -custo*abs(acao)
            valor = preco
                
    #reward = ncont*acao*preco
    ncont = acao
    posicao = ncont*(preco-valor) -custo*abs(ncont) if ncont!=0 else 0.
    return ncont, reward, valor, posicao

def obter_acao():
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = valor0 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    indice = 0
    lucro = 0.
    posicao = 0. #cria variavel de posicao 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 1e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont, indice, precos['preco'][step], valor, precos['preco_pon'][step]], (1,modelo.state_size))
        
        acao = obter_acao()
        ncont, reward, valor, posicao = teste(precos['preco'][step], ncont, acao, valor)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor*pstd+pmean if valor!=-100 else 0
        #p=precos['preco'][step]+pmean
        #print("acao={0}; ncont={1}; reward={2} valor={3} preco={4}".format(acao, ncont, reward, valor, precos['preco'][step]))   

        if step == (steps[dia+1] - 1): #se ultimo step do dia
            done = True     
        
        modelo.next_state = np.reshape([ncont, indice+1, precos['preco'][step+1], valor, precos['preco_pon'][step+1]], (1,modelo.state_size))
        modelo.remember(acao, posicao, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        indice += 1
        
    #fim do dia
    lucro +=posicao
    
    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo, dia_inicial, n_dias):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( dia_inicial, dia_inicial+n_dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        
        minibatch = modelo.memory
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    melhor_reward = 0
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo, 0, dias) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = epsilon_min
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1117 16:54:03.612360  9080 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1117 16:54:22.488440  9080 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1117 16:54:22.528442  9080 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -654.50 Epsilon = 1.000
# resultado da epoca 1 = -1829.50 Epsilon = 0.999
# resultado da epoca 2 = -12.50 Epsilon = 0.998
# resultado da epoca 3 = 216.50 Epsilon = 0.997
# resultado da epoca 4 = -1105.50 Epsilon = 0.996
# resultado da epoca 5 = -839.00 Epsilon = 0.995
# resultado da epoca 6 = -888.00 Epsilon = 0.994
# resultado da epoca 7 = 4321.50 Epsilon = 0.993
# resultado da epoca 8 = 1287.50 Epsilon = 0.992
# resultado da epoca 9 = 1525.50 Epsilon = 0.991
# resultado da epoca 10 = 2062.00 Epsilon = 0.990
# resultado da epoca 11 = 924.50 Epsilon = 0.989
# resultado da epoca 12 = 3656.50 Epsilon = 0.988
# resultado da epoca 13 = 744.00 Epsilon = 0.987
# resultado da epoca 14 = 1548.00 Epsilon = 0.986
# resultado da epoca 15 = -262.00 Epsilon = 0.985
# resultado da epoca 16 = -1121.50 Epsilon = 0.984
# resultado da epoca 17 = 90.00 Epsilon = 0.983
# resultado da epoca 18 = 2438.50 Epsilon = 0.982
# resultado da epoca 19 = 977.00 Epsilon = 0.981
# resultado da epoca 20 = -2324.00 Epsilon = 0.980
# resultado da epoca 21 = 4208.00 Epsilon = 0.979
# resultado da epoca 22 = 725.50 Epsilon = 0.978
# resultado da epoca 23 = -1868.00 Epsilon = 0.977
# resultado da epoca 24 = -4242.00 Epsilon = 0.976
# resultado da epoca 25 = 676.00 Epsilon = 0.975
# resultado da epoca 26 = -1398.00 Epsilon = 0.974
# resultado da epoca 27 = -1047.50 Epsilon = 0.973
# resultado da epoca 28 = -334.00 Epsilon = 0.972
# resultado da epoca 29 = 1164.00 Epsilon = 0.971
# resultado da epoca 30 = -186.00 Epsilon = 0.970
# resultado da epoca 31 = -1335.00 Epsilon = 0.969
# resultado da epoca 32 = 603.50 Epsilon = 0.968
# resultado da epoca 33 = 2655.50 Epsilon = 0.967
# resultado da epoca 34 = 1272.00 Epsilon = 0.966
# resultado da epoca 35 = 3095.50 Epsilon = 0.965
# resultado da epoca 36 = -978.00 Epsilon = 0.964
# resultado da epoca 37 = -815.50 Epsilon = 0.963
# resultado da epoca 38 = -1463.00 Epsilon = 0.962
# resultado da epoca 39 = -1211.00 Epsilon = 0.961
# resultado da epoca 40 = -2358.50 Epsilon = 0.960
# resultado da epoca 41 = -1812.00 Epsilon = 0.959
# resultado da epoca 42 = -3990.00 Epsilon = 0.958
# resultado da epoca 43 = -2896.00 Epsilon = 0.957
# resultado da epoca 44 = -615.00 Epsilon = 0.956
# resultado da epoca 45 = 2120.00 Epsilon = 0.955
# resultado da epoca 46 = -877.50 Epsilon = 0.954
# resultado da epoca 47 = 2285.50 Epsilon = 0.953
# resultado da epoca 48 = -1252.00 Epsilon = 0.952
# resultado da epoca 49 = 1636.50 Epsilon = 0.951
# resultado da epoca 50 = 1334.50 Epsilon = 0.950
# resultado da epoca 51 = 1546.50 Epsilon = 0.950
# resultado da epoca 52 = 1828.00 Epsilon = 0.949
# resultado da epoca 53 = -478.50 Epsilon = 0.948
# resultado da epoca 54 = 652.50 Epsilon = 0.947
# resultado da epoca 55 = -696.00 Epsilon = 0.946
# resultado da epoca 56 = 1144.50 Epsilon = 0.945
# resultado da epoca 57 = -3382.00 Epsilon = 0.944
# resultado da epoca 58 = 1269.50 Epsilon = 0.943
# resultado da epoca 59 = 118.00 Epsilon = 0.942
# resultado da epoca 60 = 363.00 Epsilon = 0.941
# resultado da epoca 61 = -1326.50 Epsilon = 0.940
# resultado da epoca 62 = -146.50 Epsilon = 0.939
# resultado da epoca 63 = -1069.50 Epsilon = 0.938
# resultado da epoca 64 = -2276.50 Epsilon = 0.937
# resultado da epoca 65 = -2288.00 Epsilon = 0.936
# resultado da epoca 66 = -20.50 Epsilon = 0.935
# resultado da epoca 67 = 1056.00 Epsilon = 0.934
# resultado da epoca 68 = 51.50 Epsilon = 0.933
# resultado da epoca 69 = -138.50 Epsilon = 0.932
# resultado da epoca 70 = -776.00 Epsilon = 0.931
# resultado da epoca 71 = 224.00 Epsilon = 0.930
# resultado da epoca 72 = -2431.50 Epsilon = 0.929
# resultado da epoca 73 = 1175.50 Epsilon = 0.928
# resultado da epoca 74 = -1683.50 Epsilon = 0.927
# resultado da epoca 75 = 1429.50 Epsilon = 0.926
# resultado da epoca 76 = 870.00 Epsilon = 0.925
# resultado da epoca 77 = -1593.50 Epsilon = 0.924
# resultado da epoca 78 = -99.00 Epsilon = 0.923
# resultado da epoca 79 = 1848.00 Epsilon = 0.922
# resultado da epoca 80 = -826.00 Epsilon = 0.921
# resultado da epoca 81 = 117.50 Epsilon = 0.920
# resultado da epoca 82 = 26.00 Epsilon = 0.919
# resultado da epoca 83 = 2543.00 Epsilon = 0.918
# resultado da epoca 84 = 104.50 Epsilon = 0.917
# resultado da epoca 85 = -1042.00 Epsilon = 0.916
# resultado da epoca 86 = -1236.50 Epsilon = 0.915
# resultado da epoca 87 = -1632.50 Epsilon = 0.914
# resultado da epoca 88 = 3020.50 Epsilon = 0.913
# resultado da epoca 89 = -1762.50 Epsilon = 0.912
# resultado da epoca 90 = 563.50 Epsilon = 0.911
# resultado da epoca 91 = 1496.50 Epsilon = 0.910
# resultado da epoca 92 = 1286.00 Epsilon = 0.909
# resultado da epoca 93 = 734.50 Epsilon = 0.908
# resultado da epoca 94 = 580.50 Epsilon = 0.907
# resultado da epoca 95 = 4047.00 Epsilon = 0.906
# resultado da epoca 96 = -1666.50 Epsilon = 0.905
# resultado da epoca 97 = -300.00 Epsilon = 0.904
# resultado da epoca 98 = 1796.50 Epsilon = 0.903
# resultado da epoca 99 = -257.00 Epsilon = 0.902
# resultado da epoca 100 = -578.00 Epsilon = 0.901
# resultado da epoca 101 = 603.00 Epsilon = 0.900
# resultado da epoca 102 = 841.00 Epsilon = 0.899
# resultado da epoca 103 = -2462.00 Epsilon = 0.898
# resultado da epoca 104 = -1346.00 Epsilon = 0.897
# resultado da epoca 105 = 1965.00 Epsilon = 0.896
# resultado da epoca 106 = 4012.50 Epsilon = 0.895
# resultado da epoca 107 = 623.50 Epsilon = 0.894
# resultado da epoca 108 = 110.50 Epsilon = 0.893
# resultado da epoca 109 = 1179.50 Epsilon = 0.892
# resultado da epoca 110 = 478.00 Epsilon = 0.891
# resultado da epoca 111 = -206.50 Epsilon = 0.890
# resultado da epoca 112 = -425.50 Epsilon = 0.889
# resultado da epoca 113 = -1336.50 Epsilon = 0.888
# resultado da epoca 114 = -1371.50 Epsilon = 0.887
# resultado da epoca 115 = -2764.50 Epsilon = 0.886
# resultado da epoca 116 = 1410.50 Epsilon = 0.885
# resultado da epoca 117 = 214.50 Epsilon = 0.884
# resultado da epoca 118 = -1788.50 Epsilon = 0.883
# resultado da epoca 119 = 1852.50 Epsilon = 0.882
# resultado da epoca 120 = 2418.00 Epsilon = 0.881
# resultado da epoca 121 = 962.50 Epsilon = 0.880
# resultado da epoca 122 = 828.50 Epsilon = 0.879
# resultado da epoca 123 = 1126.00 Epsilon = 0.878
# resultado da epoca 124 = 741.50 Epsilon = 0.877
# resultado da epoca 125 = -1785.50 Epsilon = 0.876
# resultado da epoca 126 = 1124.00 Epsilon = 0.875
# resultado da epoca 127 = 2172.00 Epsilon = 0.874
# resultado da epoca 128 = -1909.00 Epsilon = 0.873
# resultado da epoca 129 = 1602.50 Epsilon = 0.872
# resultado da epoca 130 = 1168.00 Epsilon = 0.871
# resultado da epoca 131 = -596.50 Epsilon = 0.870
# resultado da epoca 132 = 1153.50 Epsilon = 0.869
# resultado da epoca 133 = 1442.50 Epsilon = 0.868
# resultado da epoca 134 = 2182.50 Epsilon = 0.867
# resultado da epoca 135 = -1173.50 Epsilon = 0.866
# resultado da epoca 136 = 1624.50 Epsilon = 0.865
# resultado da epoca 137 = 2990.50 Epsilon = 0.864
# resultado da epoca 138 = -1324.50 Epsilon = 0.863
# resultado da epoca 139 = -647.00 Epsilon = 0.862
# resultado da epoca 140 = 409.00 Epsilon = 0.861
# resultado da epoca 141 = -245.00 Epsilon = 0.860
# resultado da epoca 142 = 1825.50 Epsilon = 0.859
# resultado da epoca 143 = -1825.00 Epsilon = 0.858
# resultado da epoca 144 = 2631.50 Epsilon = 0.857
# resultado da epoca 145 = -216.50 Epsilon = 0.856
# resultado da epoca 146 = -312.00 Epsilon = 0.855
# resultado da epoca 147 = 710.00 Epsilon = 0.854
# resultado da epoca 148 = 625.50 Epsilon = 0.853
# resultado da epoca 149 = -1049.50 Epsilon = 0.852
# resultado da epoca 150 = 123.00 Epsilon = 0.851
# resultado da epoca 151 = 3092.50 Epsilon = 0.851
# resultado da epoca 152 = 861.50 Epsilon = 0.850
# resultado da epoca 153 = -3272.00 Epsilon = 0.849
# resultado da epoca 154 = 1559.00 Epsilon = 0.848
# resultado da epoca 155 = -4940.50 Epsilon = 0.847
# resultado da epoca 156 = -1755.50 Epsilon = 0.846
# resultado da epoca 157 = -178.00 Epsilon = 0.845
# resultado da epoca 158 = -4656.00 Epsilon = 0.844
# resultado da epoca 159 = 451.00 Epsilon = 0.843
# resultado da epoca 160 = -1210.50 Epsilon = 0.842
# resultado da epoca 161 = -339.50 Epsilon = 0.841
# resultado da epoca 162 = -3449.50 Epsilon = 0.840
# resultado da epoca 163 = 4826.50 Epsilon = 0.839
# resultado da epoca 164 = 2974.50 Epsilon = 0.838
# resultado da epoca 165 = 64.00 Epsilon = 0.837
# resultado da epoca 166 = -1318.00 Epsilon = 0.836
# resultado da epoca 167 = -1838.50 Epsilon = 0.835
# resultado da epoca 168 = 1100.50 Epsilon = 0.834
# resultado da epoca 169 = 1032.50 Epsilon = 0.833
# resultado da epoca 170 = -2738.00 Epsilon = 0.832
# resultado da epoca 171 = -2460.50 Epsilon = 0.831
# resultado da epoca 172 = 1411.00 Epsilon = 0.830
# resultado da epoca 173 = 157.50 Epsilon = 0.829
# resultado da epoca 174 = 434.50 Epsilon = 0.828
# resultado da epoca 175 = 266.00 Epsilon = 0.827
# resultado da epoca 176 = 2553.00 Epsilon = 0.826
# resultado da epoca 177 = 2191.00 Epsilon = 0.825
# resultado da epoca 178 = 1295.50 Epsilon = 0.824
# resultado da epoca 179 = -2003.00 Epsilon = 0.823
# resultado da epoca 180 = -1836.50 Epsilon = 0.822
# resultado da epoca 181 = -1109.50 Epsilon = 0.821
# resultado da epoca 182 = 2114.50 Epsilon = 0.820
# resultado da epoca 183 = -2768.50 Epsilon = 0.819
# resultado da epoca 184 = -194.00 Epsilon = 0.818
# resultado da epoca 185 = -634.00 Epsilon = 0.817
# resultado da epoca 186 = -952.00 Epsilon = 0.816
# resultado da epoca 187 = 2762.00 Epsilon = 0.815
# resultado da epoca 188 = 1946.00 Epsilon = 0.814
# resultado da epoca 189 = 2130.00 Epsilon = 0.813
# resultado da epoca 190 = 1760.00 Epsilon = 0.812
# resultado da epoca 191 = 207.00 Epsilon = 0.811
# resultado da epoca 192 = -3142.00 Epsilon = 0.810
# resultado da epoca 193 = 2873.00 Epsilon = 0.809
# resultado da epoca 194 = -346.50 Epsilon = 0.808
# resultado da epoca 195 = 2232.50 Epsilon = 0.807
# resultado da epoca 196 = -1939.50 Epsilon = 0.806
# resultado da epoca 197 = 1160.00 Epsilon = 0.805
# resultado da epoca 198 = 1562.00 Epsilon = 0.804
# resultado da epoca 199 = 1344.50 Epsilon = 0.803
# resultado da epoca 200 = 1355.50 Epsilon = 0.802
# resultado da epoca 201 = -3232.00 Epsilon = 0.801
# resultado da epoca 202 = 316.00 Epsilon = 0.800
# resultado da epoca 203 = 958.50 Epsilon = 0.799
# resultado da epoca 204 = -914.50 Epsilon = 0.798
# resultado da epoca 205 = 3067.00 Epsilon = 0.797
# resultado da epoca 206 = -2383.50 Epsilon = 0.796
# resultado da epoca 207 = -17.00 Epsilon = 0.795
# resultado da epoca 208 = 390.00 Epsilon = 0.794
# resultado da epoca 209 = 433.00 Epsilon = 0.793
# resultado da epoca 210 = 522.00 Epsilon = 0.792
# resultado da epoca 211 = 848.00 Epsilon = 0.791
# resultado da epoca 212 = 525.50 Epsilon = 0.790
# resultado da epoca 213 = 1975.00 Epsilon = 0.789
# resultado da epoca 214 = -66.00 Epsilon = 0.788
# resultado da epoca 215 = -230.00 Epsilon = 0.787
# resultado da epoca 216 = -1586.00 Epsilon = 0.786
# resultado da epoca 217 = 9.00 Epsilon = 0.785
# resultado da epoca 218 = -174.00 Epsilon = 0.784
# resultado da epoca 219 = -3053.50 Epsilon = 0.783
# resultado da epoca 220 = -2491.50 Epsilon = 0.782
# resultado da epoca 221 = -1023.00 Epsilon = 0.781
# resultado da epoca 222 = 4453.50 Epsilon = 0.780
# resultado da epoca 223 = -1998.50 Epsilon = 0.779
# resultado da epoca 224 = -3007.00 Epsilon = 0.778
# resultado da epoca 225 = 990.00 Epsilon = 0.777
# resultado da epoca 226 = 3166.00 Epsilon = 0.776
# resultado da epoca 227 = -801.00 Epsilon = 0.775
# resultado da epoca 228 = 1885.50 Epsilon = 0.774
# resultado da epoca 229 = -609.50 Epsilon = 0.773
# resultado da epoca 230 = 358.50 Epsilon = 0.772
# resultado da epoca 231 = 112.50 Epsilon = 0.771
# resultado da epoca 232 = -631.50 Epsilon = 0.770
# resultado da epoca 233 = 1034.00 Epsilon = 0.769
# resultado da epoca 234 = 580.00 Epsilon = 0.768
# resultado da epoca 235 = 4934.00 Epsilon = 0.767
# resultado da epoca 236 = 59.50 Epsilon = 0.766
# resultado da epoca 237 = -3009.50 Epsilon = 0.765
# resultado da epoca 238 = -1541.50 Epsilon = 0.764
# resultado da epoca 239 = 91.50 Epsilon = 0.763
# resultado da epoca 240 = 1881.50 Epsilon = 0.762
# resultado da epoca 241 = -962.50 Epsilon = 0.761
# resultado da epoca 242 = -1897.50 Epsilon = 0.760
# resultado da epoca 243 = 680.50 Epsilon = 0.759
# resultado da epoca 244 = 923.50 Epsilon = 0.758
# resultado da epoca 245 = 2142.00 Epsilon = 0.757
# resultado da epoca 246 = 914.50 Epsilon = 0.756
# resultado da epoca 247 = -562.50 Epsilon = 0.755
# resultado da epoca 248 = 4709.50 Epsilon = 0.754
# resultado da epoca 249 = 1277.50 Epsilon = 0.753
# resultado da epoca 250 = 113.50 Epsilon = 0.752
# resultado da epoca 251 = -1252.00 Epsilon = 0.752
# resultado da epoca 252 = -1608.50 Epsilon = 0.751
# resultado da epoca 253 = 1572.00 Epsilon = 0.750
# resultado da epoca 254 = 1224.00 Epsilon = 0.749
# resultado da epoca 255 = -140.00 Epsilon = 0.748
# resultado da epoca 256 = 2866.50 Epsilon = 0.747
# resultado da epoca 257 = -3041.00 Epsilon = 0.746
# resultado da epoca 258 = 2970.00 Epsilon = 0.745
# resultado da epoca 259 = -182.50 Epsilon = 0.744
# resultado da epoca 260 = 843.00 Epsilon = 0.743
# resultado da epoca 261 = 1011.50 Epsilon = 0.742
# resultado da epoca 262 = 1806.50 Epsilon = 0.741
# resultado da epoca 263 = 626.00 Epsilon = 0.740
# resultado da epoca 264 = -1429.00 Epsilon = 0.739
# resultado da epoca 265 = -3784.50 Epsilon = 0.738
# resultado da epoca 266 = 2731.00 Epsilon = 0.737
# resultado da epoca 267 = 1716.50 Epsilon = 0.736
# resultado da epoca 268 = 995.50 Epsilon = 0.735
# resultado da epoca 269 = 944.00 Epsilon = 0.734
# resultado da epoca 270 = 4171.00 Epsilon = 0.733
# resultado da epoca 271 = -643.50 Epsilon = 0.732
# resultado da epoca 272 = 2006.50 Epsilon = 0.731
# resultado da epoca 273 = -826.00 Epsilon = 0.730
# resultado da epoca 274 = 5504.00 Epsilon = 0.729
# resultado da epoca 275 = -1023.00 Epsilon = 0.728
# resultado da epoca 276 = 1666.50 Epsilon = 0.727
# resultado da epoca 277 = 2830.50 Epsilon = 0.726
# resultado da epoca 278 = 3372.50 Epsilon = 0.725
# resultado da epoca 279 = 4883.00 Epsilon = 0.724
# resultado da epoca 280 = 32.00 Epsilon = 0.723
# resultado da epoca 281 = -1031.00 Epsilon = 0.722
# resultado da epoca 282 = 691.00 Epsilon = 0.721
# resultado da epoca 283 = 1285.00 Epsilon = 0.720
# resultado da epoca 284 = 924.50 Epsilon = 0.719
# resultado da epoca 285 = 102.00 Epsilon = 0.718
# resultado da epoca 286 = 3226.50 Epsilon = 0.717
# resultado da epoca 287 = 520.00 Epsilon = 0.716
# resultado da epoca 288 = 2591.50 Epsilon = 0.715
# resultado da epoca 289 = 3259.50 Epsilon = 0.714
# resultado da epoca 290 = -708.50 Epsilon = 0.713
# resultado da epoca 291 = 1193.50 Epsilon = 0.712
# resultado da epoca 292 = 869.00 Epsilon = 0.711
# resultado da epoca 293 = 477.00 Epsilon = 0.710
# resultado da epoca 294 = -2003.00 Epsilon = 0.709
# resultado da epoca 295 = 3827.00 Epsilon = 0.708
# resultado da epoca 296 = 133.00 Epsilon = 0.707
# resultado da epoca 297 = 2089.50 Epsilon = 0.706
# resultado da epoca 298 = 4784.50 Epsilon = 0.705
# resultado da epoca 299 = -594.50 Epsilon = 0.704
# resultado da epoca 300 = 89.50 Epsilon = 0.703
# resultado da epoca 301 = 2216.00 Epsilon = 0.702
# resultado da epoca 302 = 24.00 Epsilon = 0.701
# resultado da epoca 303 = 1800.00 Epsilon = 0.700
# resultado da epoca 304 = 2155.50 Epsilon = 0.699
# resultado da epoca 305 = 860.00 Epsilon = 0.698
# resultado da epoca 306 = 2628.50 Epsilon = 0.697
# resultado da epoca 307 = 1527.00 Epsilon = 0.696
# resultado da epoca 308 = 3024.50 Epsilon = 0.695
# resultado da epoca 309 = 1670.50 Epsilon = 0.694
# resultado da epoca 310 = 1650.50 Epsilon = 0.693
# resultado da epoca 311 = 486.00 Epsilon = 0.692
# resultado da epoca 312 = -1488.00 Epsilon = 0.691
# resultado da epoca 313 = 105.50 Epsilon = 0.690
# resultado da epoca 314 = -1270.50 Epsilon = 0.689
# resultado da epoca 315 = 1538.50 Epsilon = 0.688
# resultado da epoca 316 = -684.00 Epsilon = 0.687
# resultado da epoca 317 = 1695.50 Epsilon = 0.686
# resultado da epoca 318 = 1006.50 Epsilon = 0.685
# resultado da epoca 319 = 2205.50 Epsilon = 0.684
# resultado da epoca 320 = -453.50 Epsilon = 0.683
# resultado da epoca 321 = -43.00 Epsilon = 0.682
# resultado da epoca 322 = -2157.00 Epsilon = 0.681
# resultado da epoca 323 = 854.50 Epsilon = 0.680
# resultado da epoca 324 = 2253.50 Epsilon = 0.679
# resultado da epoca 325 = 1017.50 Epsilon = 0.678
# resultado da epoca 326 = 486.00 Epsilon = 0.677
# resultado da epoca 327 = -348.00 Epsilon = 0.676
# resultado da epoca 328 = -581.00 Epsilon = 0.675
# resultado da epoca 329 = 2576.00 Epsilon = 0.674
# resultado da epoca 330 = -2010.50 Epsilon = 0.673
# resultado da epoca 331 = 1271.00 Epsilon = 0.672
# resultado da epoca 332 = 2961.50 Epsilon = 0.671
# resultado da epoca 333 = 2522.50 Epsilon = 0.670
# resultado da epoca 334 = 1789.50 Epsilon = 0.669
# resultado da epoca 335 = 871.00 Epsilon = 0.668
# resultado da epoca 336 = 2357.50 Epsilon = 0.667
# resultado da epoca 337 = 4749.50 Epsilon = 0.666
# resultado da epoca 338 = 2828.00 Epsilon = 0.665
# resultado da epoca 339 = 2200.50 Epsilon = 0.664
# resultado da epoca 340 = 3329.00 Epsilon = 0.663
# resultado da epoca 341 = 434.00 Epsilon = 0.662
# resultado da epoca 342 = 425.00 Epsilon = 0.661
# resultado da epoca 343 = 2101.50 Epsilon = 0.660
# resultado da epoca 344 = 4101.00 Epsilon = 0.659
# resultado da epoca 345 = 3851.00 Epsilon = 0.658
# resultado da epoca 346 = 2575.00 Epsilon = 0.657
# resultado da epoca 347 = 1214.00 Epsilon = 0.656
# resultado da epoca 348 = 3380.00 Epsilon = 0.655
# resultado da epoca 349 = 2724.00 Epsilon = 0.654
# resultado da epoca 350 = 387.50 Epsilon = 0.653
# resultado da epoca 351 = 1937.00 Epsilon = 0.653
# resultado da epoca 352 = 2786.00 Epsilon = 0.652
# resultado da epoca 353 = 1289.50 Epsilon = 0.651
# resultado da epoca 354 = 1233.50 Epsilon = 0.650
# resultado da epoca 355 = 4736.50 Epsilon = 0.649
# resultado da epoca 356 = -1715.50 Epsilon = 0.648
# resultado da epoca 357 = 2843.50 Epsilon = 0.647
# resultado da epoca 358 = -131.50 Epsilon = 0.646
# resultado da epoca 359 = 2161.50 Epsilon = 0.645
# resultado da epoca 360 = 3637.50 Epsilon = 0.644
# resultado da epoca 361 = 1056.00 Epsilon = 0.643
# resultado da epoca 362 = -3183.50 Epsilon = 0.642
# resultado da epoca 363 = 2410.00 Epsilon = 0.641
# resultado da epoca 364 = 3001.50 Epsilon = 0.640
# resultado da epoca 365 = 3170.50 Epsilon = 0.639
# resultado da epoca 366 = 62.00 Epsilon = 0.638
# resultado da epoca 367 = 1486.00 Epsilon = 0.637
# resultado da epoca 368 = 5145.50 Epsilon = 0.636
# resultado da epoca 369 = 1461.50 Epsilon = 0.635
# resultado da epoca 370 = -1160.50 Epsilon = 0.634
# resultado da epoca 371 = 2399.00 Epsilon = 0.633
# resultado da epoca 372 = 2251.00 Epsilon = 0.632
# resultado da epoca 373 = 5382.50 Epsilon = 0.631
# resultado da epoca 374 = 3828.00 Epsilon = 0.630
# resultado da epoca 375 = 3488.00 Epsilon = 0.629
# resultado da epoca 376 = -2111.50 Epsilon = 0.628
# resultado da epoca 377 = 977.50 Epsilon = 0.627
# resultado da epoca 378 = 2756.00 Epsilon = 0.626
# resultado da epoca 379 = 5087.00 Epsilon = 0.625
# resultado da epoca 380 = 540.50 Epsilon = 0.624
# resultado da epoca 381 = 2080.50 Epsilon = 0.623
# resultado da epoca 382 = 2873.00 Epsilon = 0.622
# resultado da epoca 383 = 706.00 Epsilon = 0.621
# resultado da epoca 384 = 3883.50 Epsilon = 0.620
# resultado da epoca 385 = 2345.00 Epsilon = 0.619
# resultado da epoca 386 = 3984.50 Epsilon = 0.618
# resultado da epoca 387 = -2047.00 Epsilon = 0.617
# resultado da epoca 388 = 3929.50 Epsilon = 0.616
# resultado da epoca 389 = -3835.50 Epsilon = 0.615
# resultado da epoca 390 = 1383.00 Epsilon = 0.614
# resultado da epoca 391 = 2350.50 Epsilon = 0.613
# resultado da epoca 392 = 5722.00 Epsilon = 0.612
# resultado da epoca 393 = 2822.00 Epsilon = 0.611
# resultado da epoca 394 = 1834.00 Epsilon = 0.610
# resultado da epoca 395 = 2772.50 Epsilon = 0.609
# resultado da epoca 396 = -1288.50 Epsilon = 0.608
# resultado da epoca 397 = 1594.50 Epsilon = 0.607
# resultado da epoca 398 = 5129.50 Epsilon = 0.606
# resultado da epoca 399 = 3029.50 Epsilon = 0.605
# resultado da epoca 400 = 2657.50 Epsilon = 0.604
# resultado da epoca 401 = 1616.50 Epsilon = 0.603
# resultado da epoca 402 = 765.50 Epsilon = 0.602
# resultado da epoca 403 = 398.50 Epsilon = 0.601
# resultado da epoca 404 = -1926.50 Epsilon = 0.600
# resultado da epoca 405 = 600.00 Epsilon = 0.599
# resultado da epoca 406 = 4298.50 Epsilon = 0.598
# resultado da epoca 407 = 976.50 Epsilon = 0.597
# resultado da epoca 408 = 754.50 Epsilon = 0.596
# resultado da epoca 409 = 4257.00 Epsilon = 0.595
# resultado da epoca 410 = 489.50 Epsilon = 0.594
# resultado da epoca 411 = 442.00 Epsilon = 0.593
# resultado da epoca 412 = -127.00 Epsilon = 0.592
# resultado da epoca 413 = 3923.00 Epsilon = 0.591
# resultado da epoca 414 = -946.50 Epsilon = 0.590
# resultado da epoca 415 = -969.00 Epsilon = 0.589
# resultado da epoca 416 = 1662.00 Epsilon = 0.588
# resultado da epoca 417 = 774.00 Epsilon = 0.587
# resultado da epoca 418 = -257.00 Epsilon = 0.586
# resultado da epoca 419 = 2005.50 Epsilon = 0.585
# resultado da epoca 420 = -228.00 Epsilon = 0.584
# resultado da epoca 421 = -525.00 Epsilon = 0.583
# resultado da epoca 422 = 951.00 Epsilon = 0.582
# resultado da epoca 423 = -3139.00 Epsilon = 0.581
# resultado da epoca 424 = 4057.00 Epsilon = 0.580
# resultado da epoca 425 = 716.00 Epsilon = 0.579
# resultado da epoca 426 = 414.50 Epsilon = 0.578
# resultado da epoca 427 = 4159.50 Epsilon = 0.577
# resultado da epoca 428 = 2701.50 Epsilon = 0.576
# resultado da epoca 429 = 2920.50 Epsilon = 0.575
# resultado da epoca 430 = 3063.50 Epsilon = 0.574
# resultado da epoca 431 = 1645.50 Epsilon = 0.573
# resultado da epoca 432 = -755.00 Epsilon = 0.572
# resultado da epoca 433 = 4181.00 Epsilon = 0.571
# resultado da epoca 434 = 1416.50 Epsilon = 0.570
# resultado da epoca 435 = 5232.50 Epsilon = 0.569
# resultado da epoca 436 = 5442.00 Epsilon = 0.568
# resultado da epoca 437 = 2250.50 Epsilon = 0.567
# resultado da epoca 438 = 3733.50 Epsilon = 0.566
# resultado da epoca 439 = 6170.50 Epsilon = 0.565
# resultado da epoca 440 = 4113.00 Epsilon = 0.564
# resultado da epoca 441 = 7006.00 Epsilon = 0.563
# resultado da epoca 442 = 6080.50 Epsilon = 0.562
# resultado da epoca 443 = 2911.50 Epsilon = 0.561
# resultado da epoca 444 = 2600.00 Epsilon = 0.560
# resultado da epoca 445 = 5231.50 Epsilon = 0.559
# resultado da epoca 446 = 2395.00 Epsilon = 0.558
# resultado da epoca 447 = 1258.50 Epsilon = 0.557
# resultado da epoca 448 = 3611.50 Epsilon = 0.556
# resultado da epoca 449 = 158.00 Epsilon = 0.555
# resultado da epoca 450 = 3770.50 Epsilon = 0.554
# resultado da epoca 451 = 355.50 Epsilon = 0.554
# resultado da epoca 452 = 1191.00 Epsilon = 0.553
# resultado da epoca 453 = 1192.00 Epsilon = 0.552
# resultado da epoca 454 = 2251.50 Epsilon = 0.551
# resultado da epoca 455 = -1142.00 Epsilon = 0.550
# resultado da epoca 456 = 1507.50 Epsilon = 0.549
# resultado da epoca 457 = 2116.00 Epsilon = 0.548
# resultado da epoca 458 = 1198.00 Epsilon = 0.547
# resultado da epoca 459 = 3848.00 Epsilon = 0.546
# resultado da epoca 460 = 5895.50 Epsilon = 0.545
# resultado da epoca 461 = 4684.00 Epsilon = 0.544
# resultado da epoca 462 = 2466.00 Epsilon = 0.543
# resultado da epoca 463 = 1937.50 Epsilon = 0.542
# resultado da epoca 464 = 5165.50 Epsilon = 0.541
# resultado da epoca 465 = 3651.00 Epsilon = 0.540
# resultado da epoca 466 = 3433.00 Epsilon = 0.539
# resultado da epoca 467 = 4137.00 Epsilon = 0.538
# resultado da epoca 468 = 3983.00 Epsilon = 0.537
# resultado da epoca 469 = -718.50 Epsilon = 0.536
# resultado da epoca 470 = 4302.00 Epsilon = 0.535
# resultado da epoca 471 = 2232.50 Epsilon = 0.534
# resultado da epoca 472 = 2271.00 Epsilon = 0.533
# resultado da epoca 473 = 3566.50 Epsilon = 0.532
# resultado da epoca 474 = 693.50 Epsilon = 0.531
# resultado da epoca 475 = 420.50 Epsilon = 0.530
# resultado da epoca 476 = 961.00 Epsilon = 0.529
# resultado da epoca 477 = -952.50 Epsilon = 0.528
# resultado da epoca 478 = 1373.00 Epsilon = 0.527
# resultado da epoca 479 = -65.50 Epsilon = 0.526
# resultado da epoca 480 = 1773.00 Epsilon = 0.525
# resultado da epoca 481 = 3150.50 Epsilon = 0.524
# resultado da epoca 482 = 2924.50 Epsilon = 0.523
# resultado da epoca 483 = 1194.50 Epsilon = 0.522
# resultado da epoca 484 = 1797.50 Epsilon = 0.521
# resultado da epoca 485 = 4413.50 Epsilon = 0.520
# resultado da epoca 486 = -2279.00 Epsilon = 0.519
# resultado da epoca 487 = 1552.50 Epsilon = 0.518
# resultado da epoca 488 = -1451.50 Epsilon = 0.517
# resultado da epoca 489 = 3120.50 Epsilon = 0.516
# resultado da epoca 490 = 1434.50 Epsilon = 0.515
# resultado da epoca 491 = 1983.50 Epsilon = 0.514
# resultado da epoca 492 = 2602.50 Epsilon = 0.513
# resultado da epoca 493 = 1354.50 Epsilon = 0.512
# resultado da epoca 494 = 3290.50 Epsilon = 0.511
# resultado da epoca 495 = 5157.00 Epsilon = 0.510
# resultado da epoca 496 = 1784.50 Epsilon = 0.509
# resultado da epoca 497 = 4281.50 Epsilon = 0.508
# resultado da epoca 498 = 1770.00 Epsilon = 0.507
# resultado da epoca 499 = 3142.50 Epsilon = 0.506
# resultado da epoca 500 = -1203.00 Epsilon = 0.505
# resultado da epoca 501 = 1324.00 Epsilon = 0.504
# resultado da epoca 502 = -507.50 Epsilon = 0.503
# resultado da epoca 503 = 2148.00 Epsilon = 0.502
# resultado da epoca 504 = 5571.00 Epsilon = 0.501
# resultado da epoca 505 = 4538.00 Epsilon = 0.500
# resultado da epoca 506 = 1244.00 Epsilon = 0.499
# resultado da epoca 507 = 1594.50 Epsilon = 0.498
# resultado da epoca 508 = 621.50 Epsilon = 0.497
# resultado da epoca 509 = 2060.00 Epsilon = 0.496
# resultado da epoca 510 = 4046.00 Epsilon = 0.495
# resultado da epoca 511 = 5480.50 Epsilon = 0.494
# resultado da epoca 512 = 1932.00 Epsilon = 0.493
# resultado da epoca 513 = -453.50 Epsilon = 0.492
# resultado da epoca 514 = 829.00 Epsilon = 0.491
# resultado da epoca 515 = 5564.50 Epsilon = 0.490
# resultado da epoca 516 = 3265.50 Epsilon = 0.489
# resultado da epoca 517 = 1578.00 Epsilon = 0.488
# resultado da epoca 518 = 1906.00 Epsilon = 0.487
# resultado da epoca 519 = 1686.50 Epsilon = 0.486
# resultado da epoca 520 = 4190.00 Epsilon = 0.485
# resultado da epoca 521 = 1476.50 Epsilon = 0.484
# resultado da epoca 522 = 5574.50 Epsilon = 0.483
# resultado da epoca 523 = 682.00 Epsilon = 0.482
# resultado da epoca 524 = -911.50 Epsilon = 0.481
# resultado da epoca 525 = 3556.00 Epsilon = 0.480
# resultado da epoca 526 = -26.50 Epsilon = 0.479
# resultado da epoca 527 = 2657.00 Epsilon = 0.478
# resultado da epoca 528 = 5147.50 Epsilon = 0.477
# resultado da epoca 529 = 2428.50 Epsilon = 0.476
# resultado da epoca 530 = 3930.00 Epsilon = 0.475
# resultado da epoca 531 = 4878.00 Epsilon = 0.474
# resultado da epoca 532 = 5425.00 Epsilon = 0.473
# resultado da epoca 533 = 2786.50 Epsilon = 0.472
# resultado da epoca 534 = 4618.00 Epsilon = 0.471
# resultado da epoca 535 = 6247.00 Epsilon = 0.470
# resultado da epoca 536 = 6730.50 Epsilon = 0.469
# resultado da epoca 537 = 3071.50 Epsilon = 0.468
# resultado da epoca 538 = 2282.00 Epsilon = 0.467
# resultado da epoca 539 = 4029.50 Epsilon = 0.466
# resultado da epoca 540 = 3335.00 Epsilon = 0.465
# resultado da epoca 541 = 3173.00 Epsilon = 0.464
# resultado da epoca 542 = 3782.00 Epsilon = 0.463
# resultado da epoca 543 = 2101.50 Epsilon = 0.462
# resultado da epoca 544 = -17.00 Epsilon = 0.461
# resultado da epoca 545 = 7913.00 Epsilon = 0.460
# resultado da epoca 546 = 5077.50 Epsilon = 0.459
# resultado da epoca 547 = 3195.50 Epsilon = 0.458
# resultado da epoca 548 = 2571.50 Epsilon = 0.457
# resultado da epoca 549 = 3532.50 Epsilon = 0.456
# resultado da epoca 550 = 5776.00 Epsilon = 0.455
# resultado da epoca 551 = 5728.00 Epsilon = 0.455
# resultado da epoca 552 = 3926.50 Epsilon = 0.454
# resultado da epoca 553 = 2388.50 Epsilon = 0.453
# resultado da epoca 554 = 4877.50 Epsilon = 0.452
# resultado da epoca 555 = 7233.00 Epsilon = 0.451
# resultado da epoca 556 = 4628.50 Epsilon = 0.450
# resultado da epoca 557 = 4532.00 Epsilon = 0.449
# resultado da epoca 558 = 3080.00 Epsilon = 0.448
# resultado da epoca 559 = 4130.00 Epsilon = 0.447
# resultado da epoca 560 = 1416.50 Epsilon = 0.446
# resultado da epoca 561 = 3467.50 Epsilon = 0.445
# resultado da epoca 562 = 3452.00 Epsilon = 0.444
# resultado da epoca 563 = 2404.00 Epsilon = 0.443
# resultado da epoca 564 = 3063.00 Epsilon = 0.442
# resultado da epoca 565 = 4033.00 Epsilon = 0.441
# resultado da epoca 566 = 5209.00 Epsilon = 0.440
# resultado da epoca 567 = 2204.50 Epsilon = 0.439
# resultado da epoca 568 = 3672.50 Epsilon = 0.438
# resultado da epoca 569 = 2367.50 Epsilon = 0.437
# resultado da epoca 570 = 4474.50 Epsilon = 0.436
# resultado da epoca 571 = 4054.00 Epsilon = 0.435
# resultado da epoca 572 = 4937.00 Epsilon = 0.434
# resultado da epoca 573 = -115.00 Epsilon = 0.433
# resultado da epoca 574 = 3620.00 Epsilon = 0.432
# resultado da epoca 575 = 6383.00 Epsilon = 0.431
# resultado da epoca 576 = 3730.50 Epsilon = 0.430
# resultado da epoca 577 = 3156.50 Epsilon = 0.429
# resultado da epoca 578 = 1994.50 Epsilon = 0.428
# resultado da epoca 579 = 5971.00 Epsilon = 0.427
# resultado da epoca 580 = 6103.50 Epsilon = 0.426
# resultado da epoca 581 = 4445.00 Epsilon = 0.425
# resultado da epoca 582 = 4554.00 Epsilon = 0.424
# resultado da epoca 583 = 6821.00 Epsilon = 0.423
# resultado da epoca 584 = 3484.00 Epsilon = 0.422
# resultado da epoca 585 = 4202.50 Epsilon = 0.421
# resultado da epoca 586 = 7275.50 Epsilon = 0.420
# resultado da epoca 587 = 5413.50 Epsilon = 0.419
# resultado da epoca 588 = 4130.00 Epsilon = 0.418
# resultado da epoca 589 = 3956.00 Epsilon = 0.417
# resultado da epoca 590 = 7456.00 Epsilon = 0.416
# resultado da epoca 591 = 8609.00 Epsilon = 0.415
# resultado da epoca 592 = 4737.50 Epsilon = 0.414
# resultado da epoca 593 = 4900.00 Epsilon = 0.413
# resultado da epoca 594 = 4904.50 Epsilon = 0.412
# resultado da epoca 595 = 2053.00 Epsilon = 0.411
# resultado da epoca 596 = 4534.50 Epsilon = 0.410
# resultado da epoca 597 = 4446.50 Epsilon = 0.409
# resultado da epoca 598 = 4815.50 Epsilon = 0.408
# resultado da epoca 599 = 5212.50 Epsilon = 0.407
# resultado da epoca 600 = 4155.00 Epsilon = 0.406
# resultado da epoca 601 = 5540.00 Epsilon = 0.405
# resultado da epoca 602 = 5297.00 Epsilon = 0.404
# resultado da epoca 603 = 3930.00 Epsilon = 0.403
# resultado da epoca 604 = 6022.00 Epsilon = 0.402
# resultado da epoca 605 = 6882.50 Epsilon = 0.401
# resultado da epoca 606 = 3631.00 Epsilon = 0.400
# resultado da epoca 607 = 7450.50 Epsilon = 0.399
# resultado da epoca 608 = 5778.00 Epsilon = 0.398
# resultado da epoca 609 = 3148.00 Epsilon = 0.397
# resultado da epoca 610 = 3202.50 Epsilon = 0.396
# resultado da epoca 611 = 4898.50 Epsilon = 0.395
# resultado da epoca 612 = 7415.50 Epsilon = 0.394
# resultado da epoca 613 = 5100.50 Epsilon = 0.393
# resultado da epoca 614 = 4842.50 Epsilon = 0.392
# resultado da epoca 615 = 7927.50 Epsilon = 0.391
# resultado da epoca 616 = 2115.50 Epsilon = 0.390
# resultado da epoca 617 = 2684.50 Epsilon = 0.389
# resultado da epoca 618 = 3117.00 Epsilon = 0.388
# resultado da epoca 619 = 1531.50 Epsilon = 0.387
# resultado da epoca 620 = 8213.00 Epsilon = 0.386
# resultado da epoca 621 = 4607.00 Epsilon = 0.385
# resultado da epoca 622 = 3035.00 Epsilon = 0.384
# resultado da epoca 623 = 4146.50 Epsilon = 0.383
# resultado da epoca 624 = 4604.00 Epsilon = 0.382
# resultado da epoca 625 = 4586.00 Epsilon = 0.381
# resultado da epoca 626 = 5075.00 Epsilon = 0.380
# resultado da epoca 627 = 6202.50 Epsilon = 0.379
# resultado da epoca 628 = 1487.00 Epsilon = 0.378
# resultado da epoca 629 = 2620.50 Epsilon = 0.377
# resultado da epoca 630 = 8491.00 Epsilon = 0.376
# resultado da epoca 631 = 5170.50 Epsilon = 0.375
# resultado da epoca 632 = 4148.00 Epsilon = 0.374
# resultado da epoca 633 = 2468.00 Epsilon = 0.373
# resultado da epoca 634 = 6333.50 Epsilon = 0.372
# resultado da epoca 635 = 2287.00 Epsilon = 0.371
# resultado da epoca 636 = 6870.00 Epsilon = 0.370
# resultado da epoca 637 = 5205.50 Epsilon = 0.369
# resultado da epoca 638 = 3720.50 Epsilon = 0.368
# resultado da epoca 639 = 6582.00 Epsilon = 0.367
# resultado da epoca 640 = 3856.50 Epsilon = 0.366
# resultado da epoca 641 = 5018.00 Epsilon = 0.365
# resultado da epoca 642 = 4552.50 Epsilon = 0.364
# resultado da epoca 643 = 7348.50 Epsilon = 0.363
# resultado da epoca 644 = 3330.00 Epsilon = 0.362
# resultado da epoca 645 = 4971.00 Epsilon = 0.361
# resultado da epoca 646 = 3669.50 Epsilon = 0.360
# resultado da epoca 647 = 3992.50 Epsilon = 0.359
# resultado da epoca 648 = 5872.00 Epsilon = 0.358
# resultado da epoca 649 = 3727.00 Epsilon = 0.357
# resultado da epoca 650 = 1606.00 Epsilon = 0.356
# resultado da epoca 651 = 152.00 Epsilon = 0.356
# resultado da epoca 652 = 3088.50 Epsilon = 0.355
# resultado da epoca 653 = 915.00 Epsilon = 0.354
# resultado da epoca 654 = 2312.00 Epsilon = 0.353
# resultado da epoca 655 = 5474.50 Epsilon = 0.352
# resultado da epoca 656 = 2515.50 Epsilon = 0.351
# resultado da epoca 657 = 4028.50 Epsilon = 0.350
# resultado da epoca 658 = 3625.00 Epsilon = 0.349
# resultado da epoca 659 = 3629.00 Epsilon = 0.348
# resultado da epoca 660 = 3860.00 Epsilon = 0.347
# resultado da epoca 661 = 312.50 Epsilon = 0.346
# resultado da epoca 662 = 6066.50 Epsilon = 0.345
# resultado da epoca 663 = 6337.50 Epsilon = 0.344
# resultado da epoca 664 = 7812.00 Epsilon = 0.343
# resultado da epoca 665 = 5978.50 Epsilon = 0.342
# resultado da epoca 666 = 5276.00 Epsilon = 0.341
# resultado da epoca 667 = 7019.00 Epsilon = 0.340
# resultado da epoca 668 = 2839.50 Epsilon = 0.339
# resultado da epoca 669 = 7171.00 Epsilon = 0.338
# resultado da epoca 670 = 6018.00 Epsilon = 0.337
# resultado da epoca 671 = 4789.00 Epsilon = 0.336
# resultado da epoca 672 = 2424.50 Epsilon = 0.335
# resultado da epoca 673 = 2622.00 Epsilon = 0.334
# resultado da epoca 674 = 1332.00 Epsilon = 0.333
# resultado da epoca 675 = 2557.50 Epsilon = 0.332
# resultado da epoca 676 = 8285.00 Epsilon = 0.331
# resultado da epoca 677 = 1219.50 Epsilon = 0.330
# resultado da epoca 678 = 2142.50 Epsilon = 0.329
# resultado da epoca 679 = 3223.50 Epsilon = 0.328
# resultado da epoca 680 = 5463.50 Epsilon = 0.327
# resultado da epoca 681 = 6201.00 Epsilon = 0.326
# resultado da epoca 682 = 4201.50 Epsilon = 0.325
# resultado da epoca 683 = 4017.50 Epsilon = 0.324
# resultado da epoca 684 = 6324.50 Epsilon = 0.323
# resultado da epoca 685 = 3461.00 Epsilon = 0.322
# resultado da epoca 686 = 8545.00 Epsilon = 0.321
# resultado da epoca 687 = 4987.50 Epsilon = 0.320
# resultado da epoca 688 = 5740.50 Epsilon = 0.319
# resultado da epoca 689 = 1188.00 Epsilon = 0.318
# resultado da epoca 690 = 3185.00 Epsilon = 0.317
# resultado da epoca 691 = 9204.00 Epsilon = 0.316
# resultado da epoca 692 = 625.50 Epsilon = 0.315
# resultado da epoca 693 = 5134.50 Epsilon = 0.314
# resultado da epoca 694 = 5376.00 Epsilon = 0.313
# resultado da epoca 695 = 6988.50 Epsilon = 0.312
# resultado da epoca 696 = 5511.50 Epsilon = 0.311
# resultado da epoca 697 = 6196.00 Epsilon = 0.310
# resultado da epoca 698 = 1193.00 Epsilon = 0.309
# resultado da epoca 699 = 5393.50 Epsilon = 0.308
# resultado da epoca 700 = 4312.50 Epsilon = 0.307
# resultado da epoca 701 = 3661.50 Epsilon = 0.306
# resultado da epoca 702 = 4774.00 Epsilon = 0.305
# resultado da epoca 703 = 6030.00 Epsilon = 0.304
# resultado da epoca 704 = 3699.00 Epsilon = 0.303
# resultado da epoca 705 = 5180.50 Epsilon = 0.302
# resultado da epoca 706 = -429.00 Epsilon = 0.301
# resultado da epoca 707 = 2246.00 Epsilon = 0.300
# resultado da epoca 708 = 2981.50 Epsilon = 0.299
# resultado da epoca 709 = 1107.00 Epsilon = 0.298
# resultado da epoca 710 = -2045.00 Epsilon = 0.297
# resultado da epoca 711 = 1027.00 Epsilon = 0.296
# resultado da epoca 712 = 1527.00 Epsilon = 0.295
# resultado da epoca 713 = -737.50 Epsilon = 0.294
# resultado da epoca 714 = 3201.00 Epsilon = 0.293
# resultado da epoca 715 = 735.00 Epsilon = 0.292
# resultado da epoca 716 = 1744.50 Epsilon = 0.291
# resultado da epoca 717 = 2210.00 Epsilon = 0.290
# resultado da epoca 718 = 5298.50 Epsilon = 0.289
# resultado da epoca 719 = 4121.50 Epsilon = 0.288
# resultado da epoca 720 = 2309.50 Epsilon = 0.287
# resultado da epoca 721 = 2332.00 Epsilon = 0.286
# resultado da epoca 722 = 4748.00 Epsilon = 0.285
# resultado da epoca 723 = 5367.00 Epsilon = 0.284
# resultado da epoca 724 = 4169.00 Epsilon = 0.283
# resultado da epoca 725 = 4056.00 Epsilon = 0.282
# resultado da epoca 726 = 5055.00 Epsilon = 0.281
# resultado da epoca 727 = 3391.50 Epsilon = 0.280
# resultado da epoca 728 = 2662.00 Epsilon = 0.279
# resultado da epoca 729 = 6667.50 Epsilon = 0.278
# resultado da epoca 730 = 4141.50 Epsilon = 0.277
# resultado da epoca 731 = 2546.50 Epsilon = 0.276
# resultado da epoca 732 = 2637.00 Epsilon = 0.275
# resultado da epoca 733 = 5082.00 Epsilon = 0.274
# resultado da epoca 734 = 5492.00 Epsilon = 0.273
# resultado da epoca 735 = 3336.50 Epsilon = 0.272
# resultado da epoca 736 = 3063.00 Epsilon = 0.271
# resultado da epoca 737 = 6439.00 Epsilon = 0.270
# resultado da epoca 738 = 4922.50 Epsilon = 0.269
# resultado da epoca 739 = 5392.50 Epsilon = 0.268
# resultado da epoca 740 = -912.00 Epsilon = 0.267
# resultado da epoca 741 = 3361.00 Epsilon = 0.266
# resultado da epoca 742 = 4520.50 Epsilon = 0.265
# resultado da epoca 743 = 4199.00 Epsilon = 0.264
# resultado da epoca 744 = 4350.50 Epsilon = 0.263
# resultado da epoca 745 = 6507.50 Epsilon = 0.262
# resultado da epoca 746 = 3688.50 Epsilon = 0.261
# resultado da epoca 747 = 8469.00 Epsilon = 0.260
# resultado da epoca 748 = 6121.50 Epsilon = 0.259
# resultado da epoca 749 = 4551.50 Epsilon = 0.258
# resultado da epoca 750 = 4994.50 Epsilon = 0.257
# resultado da epoca 751 = 1526.50 Epsilon = 0.257
# resultado da epoca 752 = 1155.00 Epsilon = 0.256
# resultado da epoca 753 = 4211.50 Epsilon = 0.255
# resultado da epoca 754 = 6703.00 Epsilon = 0.254
# resultado da epoca 755 = 4700.50 Epsilon = 0.253
# resultado da epoca 756 = 4507.50 Epsilon = 0.252
# resultado da epoca 757 = 6191.50 Epsilon = 0.251
# resultado da epoca 758 = 4930.50 Epsilon = 0.250
# resultado da epoca 759 = 6292.00 Epsilon = 0.249
# resultado da epoca 760 = 4728.00 Epsilon = 0.248
# resultado da epoca 761 = 4800.00 Epsilon = 0.247
# resultado da epoca 762 = 5473.50 Epsilon = 0.246
# resultado da epoca 763 = 7150.50 Epsilon = 0.245
# resultado da epoca 764 = 3410.00 Epsilon = 0.244
# resultado da epoca 765 = 6794.00 Epsilon = 0.243
# resultado da epoca 766 = 6837.00 Epsilon = 0.242
# resultado da epoca 767 = 4198.50 Epsilon = 0.241
# resultado da epoca 768 = 11905.50 Epsilon = 0.240
# resultado da epoca 769 = 6227.00 Epsilon = 0.239
# resultado da epoca 770 = 6863.50 Epsilon = 0.238
# resultado da epoca 771 = 4620.50 Epsilon = 0.237
# resultado da epoca 772 = 4818.00 Epsilon = 0.236
# resultado da epoca 773 = 6107.50 Epsilon = 0.235
# resultado da epoca 774 = 5925.00 Epsilon = 0.234
# resultado da epoca 775 = 6305.00 Epsilon = 0.233
# resultado da epoca 776 = 5017.50 Epsilon = 0.232
# resultado da epoca 777 = 7237.50 Epsilon = 0.231
# resultado da epoca 778 = 5045.50 Epsilon = 0.230
# resultado da epoca 779 = 4658.50 Epsilon = 0.229
# resultado da epoca 780 = 7522.00 Epsilon = 0.228
# resultado da epoca 781 = 1831.00 Epsilon = 0.227
# resultado da epoca 782 = 6764.50 Epsilon = 0.226
# resultado da epoca 783 = 7778.00 Epsilon = 0.225
# resultado da epoca 784 = 8585.00 Epsilon = 0.224
# resultado da epoca 785 = 6752.00 Epsilon = 0.223
# resultado da epoca 786 = 5395.50 Epsilon = 0.222
# resultado da epoca 787 = 6053.00 Epsilon = 0.221
# resultado da epoca 788 = 5498.00 Epsilon = 0.220
# resultado da epoca 789 = 5410.50 Epsilon = 0.219
# resultado da epoca 790 = 3728.00 Epsilon = 0.218
# resultado da epoca 791 = 7881.50 Epsilon = 0.217
# resultado da epoca 792 = 5530.50 Epsilon = 0.216
# resultado da epoca 793 = 4020.00 Epsilon = 0.215
# resultado da epoca 794 = 1429.00 Epsilon = 0.214
# resultado da epoca 795 = 5305.50 Epsilon = 0.213
# resultado da epoca 796 = 6925.00 Epsilon = 0.212
# resultado da epoca 797 = 2110.50 Epsilon = 0.211
# resultado da epoca 798 = 5922.00 Epsilon = 0.210
# resultado da epoca 799 = 8121.50 Epsilon = 0.209
# resultado da epoca 800 = 10515.00 Epsilon = 0.208
# resultado da epoca 801 = 6775.00 Epsilon = 0.207
# resultado da epoca 802 = 5716.00 Epsilon = 0.206
# resultado da epoca 803 = 7293.50 Epsilon = 0.205
# resultado da epoca 804 = 5686.50 Epsilon = 0.204
# resultado da epoca 805 = 6725.50 Epsilon = 0.203
# resultado da epoca 806 = 4506.00 Epsilon = 0.202
# resultado da epoca 807 = 6386.00 Epsilon = 0.201
# resultado da epoca 808 = 5975.50 Epsilon = 0.200
# resultado da epoca 809 = 6056.50 Epsilon = 0.199
# resultado da epoca 810 = 2600.00 Epsilon = 0.198
# resultado da epoca 811 = 6718.50 Epsilon = 0.197
# resultado da epoca 812 = 3299.00 Epsilon = 0.196
# resultado da epoca 813 = 3017.50 Epsilon = 0.195
# resultado da epoca 814 = 4383.00 Epsilon = 0.194
# resultado da epoca 815 = 4699.00 Epsilon = 0.193
# resultado da epoca 816 = 5325.00 Epsilon = 0.192
# resultado da epoca 817 = 2613.00 Epsilon = 0.191
# resultado da epoca 818 = 6441.00 Epsilon = 0.190
# resultado da epoca 819 = 4209.50 Epsilon = 0.189
# resultado da epoca 820 = 6054.50 Epsilon = 0.188
# resultado da epoca 821 = 8922.50 Epsilon = 0.187
# resultado da epoca 822 = 5991.50 Epsilon = 0.186
# resultado da epoca 823 = 7943.00 Epsilon = 0.185
# resultado da epoca 824 = 7930.00 Epsilon = 0.184
# resultado da epoca 825 = 4592.00 Epsilon = 0.183
# resultado da epoca 826 = 2975.50 Epsilon = 0.182
# resultado da epoca 827 = 6967.50 Epsilon = 0.181
# resultado da epoca 828 = 7777.50 Epsilon = 0.180
# resultado da epoca 829 = 7489.00 Epsilon = 0.179
# resultado da epoca 830 = 6078.50 Epsilon = 0.178
# resultado da epoca 831 = 5723.50 Epsilon = 0.177
# resultado da epoca 832 = 3460.00 Epsilon = 0.176
# resultado da epoca 833 = 8199.00 Epsilon = 0.175
# resultado da epoca 834 = 3508.00 Epsilon = 0.174
# resultado da epoca 835 = 7603.00 Epsilon = 0.173
# resultado da epoca 836 = 2301.50 Epsilon = 0.172
# resultado da epoca 837 = 6373.00 Epsilon = 0.171
# resultado da epoca 838 = 6919.50 Epsilon = 0.170
# resultado da epoca 839 = 8355.00 Epsilon = 0.169
# resultado da epoca 840 = 5852.50 Epsilon = 0.168
# resultado da epoca 841 = 5598.00 Epsilon = 0.167
# resultado da epoca 842 = 6185.00 Epsilon = 0.166
# resultado da epoca 843 = 7571.50 Epsilon = 0.165
# resultado da epoca 844 = 7956.50 Epsilon = 0.164
# resultado da epoca 845 = 5831.50 Epsilon = 0.163
# resultado da epoca 846 = 9557.50 Epsilon = 0.162
# resultado da epoca 847 = 8931.50 Epsilon = 0.161
# resultado da epoca 848 = 6239.00 Epsilon = 0.160
# resultado da epoca 849 = 9039.00 Epsilon = 0.159
# resultado da epoca 850 = 5029.00 Epsilon = 0.158
# resultado da epoca 851 = 6033.00 Epsilon = 0.158
# resultado da epoca 852 = 4160.00 Epsilon = 0.157
# resultado da epoca 853 = 9186.00 Epsilon = 0.156
# resultado da epoca 854 = 5778.50 Epsilon = 0.155
# resultado da epoca 855 = 9107.00 Epsilon = 0.154
# resultado da epoca 856 = 4854.00 Epsilon = 0.153
# resultado da epoca 857 = 9519.00 Epsilon = 0.152
# resultado da epoca 858 = 8155.50 Epsilon = 0.151
# resultado da epoca 859 = 6245.00 Epsilon = 0.150
# resultado da epoca 860 = 7187.00 Epsilon = 0.149
# resultado da epoca 861 = 7194.50 Epsilon = 0.148
# resultado da epoca 862 = 4133.50 Epsilon = 0.147
# resultado da epoca 863 = 8478.50 Epsilon = 0.146
# resultado da epoca 864 = 8235.00 Epsilon = 0.145
# resultado da epoca 865 = 7882.00 Epsilon = 0.144
# resultado da epoca 866 = 5526.50 Epsilon = 0.143
# resultado da epoca 867 = 3773.50 Epsilon = 0.142
# resultado da epoca 868 = 6094.00 Epsilon = 0.141
# resultado da epoca 869 = 4205.50 Epsilon = 0.140
# resultado da epoca 870 = 7737.50 Epsilon = 0.139
# resultado da epoca 871 = 7388.00 Epsilon = 0.138
# resultado da epoca 872 = 6848.00 Epsilon = 0.137
# resultado da epoca 873 = 7046.50 Epsilon = 0.136
# resultado da epoca 874 = 6476.50 Epsilon = 0.135
# resultado da epoca 875 = 6119.00 Epsilon = 0.134
# resultado da epoca 876 = 6776.00 Epsilon = 0.133
# resultado da epoca 877 = 6404.00 Epsilon = 0.132
# resultado da epoca 878 = 4804.00 Epsilon = 0.131
# resultado da epoca 879 = 9542.50 Epsilon = 0.130
# resultado da epoca 880 = 8464.50 Epsilon = 0.129
# resultado da epoca 881 = 9361.50 Epsilon = 0.128
# resultado da epoca 882 = 6273.00 Epsilon = 0.127
# resultado da epoca 883 = 11106.50 Epsilon = 0.126
# resultado da epoca 884 = 8086.00 Epsilon = 0.125
# resultado da epoca 885 = 8872.50 Epsilon = 0.124
# resultado da epoca 886 = 12196.00 Epsilon = 0.123
# resultado da epoca 887 = 9113.50 Epsilon = 0.122
# resultado da epoca 888 = 8785.50 Epsilon = 0.121
# resultado da epoca 889 = 7312.00 Epsilon = 0.120
# resultado da epoca 890 = 9291.50 Epsilon = 0.119
# resultado da epoca 891 = 8987.50 Epsilon = 0.118
# resultado da epoca 892 = 9070.50 Epsilon = 0.117
# resultado da epoca 893 = 7052.00 Epsilon = 0.116
# resultado da epoca 894 = 8249.00 Epsilon = 0.115
# resultado da epoca 895 = 5373.50 Epsilon = 0.114
# resultado da epoca 896 = 8499.00 Epsilon = 0.113
# resultado da epoca 897 = 5941.00 Epsilon = 0.112
# resultado da epoca 898 = 6037.50 Epsilon = 0.111
# resultado da epoca 899 = 6467.50 Epsilon = 0.110
# resultado da epoca 900 = 7387.50 Epsilon = 0.109
# resultado da epoca 901 = 9360.50 Epsilon = 0.108
# resultado da epoca 902 = 8394.00 Epsilon = 0.107
# resultado da epoca 903 = 7061.00 Epsilon = 0.106
# resultado da epoca 904 = 6061.00 Epsilon = 0.105
# resultado da epoca 905 = 8136.50 Epsilon = 0.104
# resultado da epoca 906 = 6178.50 Epsilon = 0.103
# resultado da epoca 907 = 7171.00 Epsilon = 0.102
# resultado da epoca 908 = 7972.00 Epsilon = 0.101
# resultado da epoca 909 = 8409.50 Epsilon = 0.100
# resultado da epoca 910 = 7679.00 Epsilon = 0.099
# resultado da epoca 911 = 6750.50 Epsilon = 0.098
# resultado da epoca 912 = 6171.50 Epsilon = 0.097
# resultado da epoca 913 = 5955.50 Epsilon = 0.096
# resultado da epoca 914 = 7261.50 Epsilon = 0.095
# resultado da epoca 915 = 9536.00 Epsilon = 0.094
# resultado da epoca 916 = 6523.00 Epsilon = 0.093
# resultado da epoca 917 = 7464.50 Epsilon = 0.092
# resultado da epoca 918 = 6609.50 Epsilon = 0.091
# resultado da epoca 919 = 7460.50 Epsilon = 0.090
# resultado da epoca 920 = 7472.00 Epsilon = 0.089
# resultado da epoca 921 = 6595.00 Epsilon = 0.088
# resultado da epoca 922 = 10778.00 Epsilon = 0.087
# resultado da epoca 923 = 8766.50 Epsilon = 0.086
# resultado da epoca 924 = 6741.00 Epsilon = 0.085
# resultado da epoca 925 = 8213.00 Epsilon = 0.084
# resultado da epoca 926 = 9652.50 Epsilon = 0.083
# resultado da epoca 927 = 11743.50 Epsilon = 0.082
# resultado da epoca 928 = 8410.00 Epsilon = 0.081
# resultado da epoca 929 = 5846.50 Epsilon = 0.080
# resultado da epoca 930 = 7011.50 Epsilon = 0.079
# resultado da epoca 931 = 9681.50 Epsilon = 0.078
# resultado da epoca 932 = 10272.50 Epsilon = 0.077
# resultado da epoca 933 = 10327.00 Epsilon = 0.076
# resultado da epoca 934 = 7570.50 Epsilon = 0.075
# resultado da epoca 935 = 8863.50 Epsilon = 0.074
# resultado da epoca 936 = 8303.50 Epsilon = 0.073
# resultado da epoca 937 = 9432.50 Epsilon = 0.072
# resultado da epoca 938 = 9020.00 Epsilon = 0.071
# resultado da epoca 939 = 5838.50 Epsilon = 0.070
# resultado da epoca 940 = 9642.00 Epsilon = 0.069
# resultado da epoca 941 = 9868.50 Epsilon = 0.068
# resultado da epoca 942 = 10858.00 Epsilon = 0.067
# resultado da epoca 943 = 10854.50 Epsilon = 0.066
# resultado da epoca 944 = 8667.50 Epsilon = 0.065
# resultado da epoca 945 = 7291.00 Epsilon = 0.064
# resultado da epoca 946 = 7216.50 Epsilon = 0.063
# resultado da epoca 947 = 6469.00 Epsilon = 0.062
# resultado da epoca 948 = 6886.00 Epsilon = 0.061
# resultado da epoca 949 = 8669.50 Epsilon = 0.060
# resultado da epoca 950 = 10087.00 Epsilon = 0.059
# resultado da epoca 951 = 11467.00 Epsilon = 0.059
# resultado da epoca 952 = 7881.50 Epsilon = 0.058
# resultado da epoca 953 = 6833.50 Epsilon = 0.057
# resultado da epoca 954 = 8930.00 Epsilon = 0.056
# resultado da epoca 955 = 7739.00 Epsilon = 0.055
# resultado da epoca 956 = 7812.00 Epsilon = 0.054
# resultado da epoca 957 = 7988.50 Epsilon = 0.053
# resultado da epoca 958 = 12222.00 Epsilon = 0.052
# resultado da epoca 959 = 13099.50 Epsilon = 0.051
# resultado da epoca 960 = 11033.50 Epsilon = 0.050
# resultado da epoca 961 = 12874.50 Epsilon = 0.049
# resultado da epoca 962 = 11707.00 Epsilon = 0.048
# resultado da epoca 963 = 9574.00 Epsilon = 0.047
# resultado da epoca 964 = 11546.50 Epsilon = 0.046
# resultado da epoca 965 = 8769.50 Epsilon = 0.045
# resultado da epoca 966 = 8797.50 Epsilon = 0.044
# resultado da epoca 967 = 8115.50 Epsilon = 0.043
# resultado da epoca 968 = 8846.00 Epsilon = 0.042
# resultado da epoca 969 = 9266.50 Epsilon = 0.041
# resultado da epoca 970 = 9751.00 Epsilon = 0.040
# resultado da epoca 971 = 9610.50 Epsilon = 0.039
# resultado da epoca 972 = 9405.00 Epsilon = 0.038
# resultado da epoca 973 = 9567.50 Epsilon = 0.037
# resultado da epoca 974 = 10636.00 Epsilon = 0.036
# resultado da epoca 975 = 10576.00 Epsilon = 0.035
# resultado da epoca 976 = 10033.00 Epsilon = 0.034
# resultado da epoca 977 = 10613.00 Epsilon = 0.033
# resultado da epoca 978 = 9408.50 Epsilon = 0.032
# resultado da epoca 979 = 9636.00 Epsilon = 0.031
# resultado da epoca 980 = 9497.50 Epsilon = 0.030
# resultado da epoca 981 = 8128.00 Epsilon = 0.029
# resultado da epoca 982 = 10750.50 Epsilon = 0.028
# resultado da epoca 983 = 9283.50 Epsilon = 0.027
# resultado da epoca 984 = 10581.50 Epsilon = 0.026
# resultado da epoca 985 = 8027.00 Epsilon = 0.025
# resultado da epoca 986 = 11291.00 Epsilon = 0.024
# resultado da epoca 987 = 9087.50 Epsilon = 0.023
# resultado da epoca 988 = 10062.00 Epsilon = 0.022
# resultado da epoca 989 = 8893.50 Epsilon = 0.021
# resultado da epoca 990 = 9926.00 Epsilon = 0.020
# resultado da epoca 991 = 7835.00 Epsilon = 0.019
# resultado da epoca 992 = 7094.50 Epsilon = 0.018
# resultado da epoca 993 = 8318.50 Epsilon = 0.017
# resultado da epoca 994 = 8769.00 Epsilon = 0.016
# resultado da epoca 995 = 10943.50 Epsilon = 0.015
# resultado da epoca 996 = 11677.00 Epsilon = 0.014
# resultado da epoca 997 = 9181.00 Epsilon = 0.013
# resultado da epoca 998 = 12888.00 Epsilon = 0.012
# resultado da epoca 999 = 9478.50 Epsilon = 0.011
# Melhor resultado diario: 824.00

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo, 0, dias))
# Out:
# 11760.0

# %%
modelo.epsilon = 0
rodar_dias(inputs, custo, dias, 10)
# Out:
# 235.0

# %%
plt.plot(range(0,len(inputs)), inputs['preco'])

# %%
plt.plot(range(0,len(inputs_nao_norm)), inputs_nao_norm['preco'])

# %%
np.amin(inputs['preco'])
# Out:
# -275.7738953247049

# %%
pmean
# Out:
# 3859.773895324705

# %%
(4200-pmean)/pstd
# Out:
# 2.784507614194732

# %%
np.std(inputs_nao_norm['preco'])
# Out:
# 130.87810760032863
