# %%
#################################### IMPORTS ###################################################
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import datetime
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
##################### INICIALIZACAO DE VARIAVEIS ################################################
index_arquivo = ['preco', 'hr_int']#, 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'] #index do arquivo
steps = [] # 9h04 -> 17h50 a cada 5 segundos 
epocas = 1000 #quantidade de vezes que vai rodar todos os dias
janela = 10 #janela de valores
n_variaveis = len(index_arquivo) #'preco', 'hr_int', 'preco_pon', 'qnt_soma', 'max', 'min', 'IND', 'ISP'
l = n_variaveis-1
tam_janela = n_variaveis*janela
n_entradas = n_variaveis * janela + 2 #ncont, valor e inputs
n_neuronios = 216 #numero de neuronios da camada escondida
lim_cont = 1
n_saidas = 2*lim_cont+1   #numero de saidas da rede (compra, vende, segura)
custo = 1.06/2 #custo da operao
melhor_reward = 0

versao_arquivo = 2

carregar_pesos = False
carregar_epoca_epsilon = False
epoca_init = 0
if carregar_epoca_epsilon:
    file = open("./epoca_epsilon.txt", "r")
    valores = file.read().split(',')
    epoca_init = int(valores[0])
    epsilon = float(valores[1])
    file.close()
else:
    epsilon = 1. #valor de epsilon
epsilon_min = 0.01 #valor minimo de epsilon
epsilon_decay = (epsilon - epsilon_min) / (epocas - epoca_init) #o valor que vai retirado do epsilon por epoca

rewards = [0] #variavel para guardar rewards
plotx = [0] #variavel para guardar valores a serem plotados do eixo x

# %%
####################### LEITURA DOS DADOS #######################################################
dias = 1

caminho_arquivo = ('./consolidado.csv')
arquivo = pd.read_csv(caminho_arquivo) #le arquivo
inputs = arquivo[index_arquivo]
print(inputs['preco'][0:2])
if versao_arquivo == 1: #se quiser usar apenas os dias com IND e ISP
    inputs = inputs[inputs['IND'] != 0]
    arquivo = arquivo[arquivo['IND'] != 0]

dt = arquivo['dt'].values #cria coluna apenas dos dias

steps = []
ultimo_dia = 0
dias_para_rodar = [] #variavel para colocar os dias a serem rodados
j = 0
hr = []
h = 0
n_steps = 106 #especifico pra 5min
for i in range( 0, len(dt) ):    
    if (dt[i] != ultimo_dia):
        steps.append(i) #numero de linhas entre dias
        ultimo_dia = dt[i]
        dias_para_rodar.append(j) #numero do dia
        j += 1
        h = 0
    hr.append(h)
    h += 1
step_max = np.amax(hr)
batch = step_max + 1

#normalizacao dos dados
hr = hr/step_max
inputs['hr_int'] = hr
pmean = np.mean( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor minimo do preco  #step = 106
pstd = np.std( inputs.loc[:dias*batch, inputs.columns[0]] ) #define valor maximo do preco
for i in range( inputs.shape[1] ): #roda normalizo para todas as colunas
    imean = np.mean( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor maximo
    istd = np.std( inputs.loc[:dias*batch, inputs.columns[i]] ) #pega valor minimo
    
    inputs.loc[:, inputs.columns[i]] = ( inputs.loc[:, inputs.columns[i]] - imean ) / istd #normaliza prs
    
mini_batch_size = int(dias*batch*0.1)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0    3907.5
# 1    3900.0
# Name: preco, dtype: float64
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
########################################   BIBLIOTECAS ####################################
import random
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import backend as K            #importa backend para clear_session()


##################### MODELO DQN ####################################################
class DQNAgent:
    ########################### INICIALIZA ###########################################
    def __init__(self, state_size, action_size, epsilon, janela, n_neuronios, n_variaveis):
        self.state_size = 2
        self.action_size = 3
        self.janela = janela
        self.n_variaveis = n_variaveis
        self.limpa_memoria_dia()
        self.limpa_memoria_epoca()
        self.gamma = 0.99       # discount rate
        self.epsilon = epsilon  # exploration rate
        self.learning_rate = 1e-4
        self.model = self.cria_modelo()
        self.model.summary()
        self.state = []
        self.next_state = []
        self.janela_precos = []
        self.prox_janela_precos = []

################################# REDE NEURAL ###########################################
    def cria_modelo(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        """
        model.add(Dense(self.n_neuronios, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.n_neuronios, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='softmax')) #camada de saida
        model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        """
        
        model.add(Dense(256, input_dim=self.state_size, activation='relu')) #camada de entrada (escondida)
        #model.add(Dense(256, activation='relu')) #camada escondida
        #model.add(Dense(256, activation='relu')) #camada escondida
        model.add(Dense(128, activation='relu')) #camada escondida
        model.add(Dense(self.action_size, activation='linear')) #camada de saida
        model.compile(loss='mse', optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)) #compilador
        #sgd = optimizers.SGD(lr=self.learning_rate, decay=1e-6, momentum=0.9, nesterov=True)
        #model.compile(loss='mse', optimizer=sgd)
        return model

    def limpa_memoria_dia(self):
        self.janela_precos = np.zeros(n_variaveis*janela)
        self.prox_janela_precos = np.zeros(n_variaveis*janela)
        self.state = []
        self.next_state = []
    
    def limpa_memoria_epoca(self):
        self.memory = []
        
    def toma_acao(self):
        if np.random.rand() <= self.epsilon: #se o numero aleatorio for menor que o epsilon
            return random.randrange(self.action_size) #retorna acao aleatoria     
        act_values = self.model.predict(self.state) #calcula qual a melhor acao
        return np.argmax(act_values[0])  # returns action
    
    def treina_modelo(self, batch_size=mini_batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(prox_estado)[0])) #pega valor que quer chegar
            
            target_f = self.model.predict(estado) 
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
            
        self.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo
        
    def tira_ultima_janela(self):
        if self.janela_precos.shape[0] > self.janela * self.n_variaveis:
            self.janela_precos = self.janela_precos[self.n_variaveis:] #tira os ultimos precos
    
    def remember(self, acao, reward, done):
        self.memory.append((acao, reward, self.state, self.next_state, done))
    
    def carrega_pesos(self, name):
        self.model.load_weights(name) #carrega pesos

    def salva_pesos(self, name):
        self.model.save_weights(name) #salva pesos
                
########################  DECLARA MODELO ################################
modelo = DQNAgent(n_entradas, n_saidas, epsilon, janela, n_neuronios, n_variaveis)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               768
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 34,051
# Trainable params: 34,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
########################### FUNCOES ###############################################################

def atuacao( preco, ncont, acao, custo, valor ):  #preo atual, n de contratos posicionados,
                                                #acaoo atual, custo, valor da posio
    preco_cheio = 0.
    valor_cheio = 0.
    ncont_anterior = ncont #salva posio anterior
    ncont = acao #posicao atual = acao
    reward = 0.
    posicao = 0.
    dp = 0.

    
    #variaveis para tratamento do sinal de ncont, ncont_anterior e da acao
    acao = ncont - ncont_anterior  #ajuda a manter as condições anteriores
    var1 = ncont*ncont_anterior
    var2 = ncont*acao

    if acao != 0:
        #realizacao de lucros e custos
        if ((var2>0) and (var1>=0)):
            #aumento da posicao
            reward = -custo*abs(acao)    #reward = -custo*acao se houve operacao (aumento da posicao)
            #aumento da posicao = preco medio:
            valor = (ncont_anterior*valor + acao*preco)/ncont  
            
        else:
            valor_cheio = valor * pstd + pmean  #valores nao normalizados
            preco_cheio = preco * pstd + pmean
            if (var1)>= 0:
                #diminuicao da posicao
                reward = acao*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve diminuicao da posicao
                #valor medio nao muda na diminuicao, somente se ncont==0:
                if ncont==0: valor=-10
                    
            else:
                #troca de posicao
                reward = (-ncont_anterior)*(valor_cheio - preco_cheio)*10 - custo*abs(acao)  #reward se houve troca da posicao
                #preco medio da posicao = preco da troca de posicao
                valor = preco
    
    #definindo o lucro potencial da carteira(posicao)
    if valor!=-10:
        valor_cheio = valor * pstd + pmean  #valor posicionado atual      
        dp = (preco * pstd + pmean) - valor_cheio #variacao do preco atual e do preco de compra/venda
        posicao = ncont * dp * 10 - custo*abs(ncont)           #posicao = lucro (POTENCIAL)
        
    return ncont, valor, posicao, reward

def teste(ncont, acao, step):   
    return acao, ncont*acao*step

def obter_acao(ncont):
    decisao = modelo.toma_acao() #calcula a saida da rede neural
    return (decisao - lim_cont)

def rodar_1dia(precos, custo, dia):
    global melhor_reward
    ncont = 0 #cria variavel de quantidade de contratos
    ncont_anterior = 0 #cria variavel para quantidade de contratos anterior
    valor = -10 #cria variavel para preo medio
    reward = 0. #cria variavel para recompensa
    lucro = 0.
    posicao = 0 #cria variavel de posio 
    erro = []
    modelo.limpa_memoria_dia() #limpa o vetor de memoria
    done = False
    posicao_max = 10e4
    shp = modelo.janela_precos.shape
    
    for step in range( steps[dia], steps[dia+1] ):  #roda os dados
        
        modelo.state = np.reshape([ncont, step], (1,2))
        
        acao = obter_acao(ncont)
        ncont, reward = teste(ncont, acao, step)
        
        #pos acao
        lucro += reward    #LUCRO ACUMULADO
        
        #v=valor if valor==-10 else valor*pstd+pmean
        #p=precos['preco'][step]*pstd+pmean
        #print("acao={0}; ncont={1}; reward={2}".format(acao, modelo.state, reward))   

        if step == (steps[dia] - 1): #se ultimo step do dia
            done = True     
            
        modelo.next_state = np.reshape([ncont, step+1], (1,2))
        modelo.remember(acao, reward, done)  #salva step na memoria - reward = lucro instantaneo que a ação gerou
        
    #fim do dia

    #print("ncont zerados={0}; posicao={1}".format(ncont, posicao))
    if lucro > melhor_reward:
        melhor_reward = lucro
    return lucro #retorna o valor do reward

dias_pos = 0
dias_neg = 0

def rodar_dias(precos, custo):   
    global dias_pos
    global dias_neg
    sum_rewards = 0 #cria variavel de somatoria de recompensas
    
    for dia in range( 0, dias ): #loop de dias
        reward = rodar_1dia(precos, custo, dia)
        sum_rewards += reward #roda 1 dia e adiciona o total na variavel de somatoria
        
        if reward>0: 
            dias_pos += 1
        elif reward<0:
            dias_neg += 1
    return sum_rewards

indic = 0

def train_teste(batch_size=10):
        global indic
        minibatch = random.sample(modelo.memory, batch_size)
        
        x = []
        y = []
        for acao, reward, estado, prox_estado, done in minibatch:        
            target = reward
            if not done:
                target = (reward + modelo.gamma * np.amax(modelo.model.predict(prox_estado)[0])) #pega valor que quer chegar
            

            target_f = modelo.model.predict(estado)
            target_f[0][acao+lim_cont] = target #define o valor que deseja chegar
            x.append(estado[0])
            y.append(target_f[0])
        
        modelo.model.fit(np.asarray(x), np.asarray(y), epochs=1, verbose=0) #treina modelo

# %%
import time
##################################  MAIN  #########################################
if __name__ == "__main__":
    global dias_pos
    global dias_neg
    modelo.epsilon = 1.
    sr=[]
    try:
        if carregar_pesos:
            modelo.carrega_pesos('./pesos.h5')
            
        epoca_parou = epoca_init
        for epoca in range(epoca_init, epocas): #rodar uma quantidade de epocas
            modelo.limpa_memoria_epoca()
            sum_rewards = rodar_dias(inputs, custo) #adiciona o resultado da epoca na somatoria
            train_teste() #roda o modelo com toda a memoria da epoca
            sr.append(sum_rewards)
            print("resultado da epoca {0} = {1:0.2f} Epsilon = {2:0.3f}".format(epoca, sum_rewards, modelo.epsilon))
            #print(dias_pos)
            #print(dias_neg)
            epoca_parou += 1
            if ((epoca % 200) == 0):
                modelo.salva_pesos('./pesos_5.h5')
            dias_pos = 0
            dias_neg = 0            
            if modelo.epsilon <= epsilon_min:
                modelo.epsilon = 0
            else:
                modelo.epsilon -= epsilon_decay
    finally:
        #print(dias_pos)
        #print(dias_neg)
        modelo.salva_pesos('./pesos_5.h5')
        if carregar_epoca_epsilon:
            file = open("./epoca_epsilon.txt", "w")
            file.writelines("{0},{1}".format(epoca_parou, modelo.epsilon))
            file.close()
            print("parou na epoca {0} com epsilon {1}".format(epoca_parou, modelo.epsilon))
            
        print("Melhor resultado diario: {0:0.2f}".format(melhor_reward))
        plt.plot(range(0, len(sr)), sr, range(0, len(sr)), np.zeros(len(sr))) #plota os valores de reward por epoca
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1110 14:50:57.374732  5324 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1110 14:50:57.557743  5324 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1110 14:50:57.576744  5324 deprecation_wrapper.py:119] From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# resultado da epoca 0 = -115.00 Epsilon = 1.000
# resultado da epoca 1 = 151.00 Epsilon = 0.999
# resultado da epoca 2 = -219.00 Epsilon = 0.998
# resultado da epoca 3 = 294.00 Epsilon = 0.997
# resultado da epoca 4 = 77.00 Epsilon = 0.996
# resultado da epoca 5 = 311.00 Epsilon = 0.995
# resultado da epoca 6 = 286.00 Epsilon = 0.994
# resultado da epoca 7 = -120.00 Epsilon = 0.993
# resultado da epoca 8 = 403.00 Epsilon = 0.992
# resultado da epoca 9 = 451.00 Epsilon = 0.991
# resultado da epoca 10 = -117.00 Epsilon = 0.990
# resultado da epoca 11 = -198.00 Epsilon = 0.989
# resultado da epoca 12 = 34.00 Epsilon = 0.988
# resultado da epoca 13 = -732.00 Epsilon = 0.987
# resultado da epoca 14 = -70.00 Epsilon = 0.986
# resultado da epoca 15 = -269.00 Epsilon = 0.985
# resultado da epoca 16 = 67.00 Epsilon = 0.984
# resultado da epoca 17 = 73.00 Epsilon = 0.983
# resultado da epoca 18 = 136.00 Epsilon = 0.982
# resultado da epoca 19 = 172.00 Epsilon = 0.981
# resultado da epoca 20 = 478.00 Epsilon = 0.980
# resultado da epoca 21 = 341.00 Epsilon = 0.979
# resultado da epoca 22 = 202.00 Epsilon = 0.978
# resultado da epoca 23 = -448.00 Epsilon = 0.977
# resultado da epoca 24 = 316.00 Epsilon = 0.976
# resultado da epoca 25 = -13.00 Epsilon = 0.975
# resultado da epoca 26 = -303.00 Epsilon = 0.974
# resultado da epoca 27 = 171.00 Epsilon = 0.973
# resultado da epoca 28 = 418.00 Epsilon = 0.972
# resultado da epoca 29 = -217.00 Epsilon = 0.971
# resultado da epoca 30 = -40.00 Epsilon = 0.970
# resultado da epoca 31 = -185.00 Epsilon = 0.969
# resultado da epoca 32 = 419.00 Epsilon = 0.968
# resultado da epoca 33 = -473.00 Epsilon = 0.967
# resultado da epoca 34 = -153.00 Epsilon = 0.966
# resultado da epoca 35 = -822.00 Epsilon = 0.965
# resultado da epoca 36 = -228.00 Epsilon = 0.964
# resultado da epoca 37 = 956.00 Epsilon = 0.963
# resultado da epoca 38 = 1.00 Epsilon = 0.962
# resultado da epoca 39 = 430.00 Epsilon = 0.961
# resultado da epoca 40 = 160.00 Epsilon = 0.960
# resultado da epoca 41 = -129.00 Epsilon = 0.959
# resultado da epoca 42 = -646.00 Epsilon = 0.958
# resultado da epoca 43 = 183.00 Epsilon = 0.957
# resultado da epoca 44 = -541.00 Epsilon = 0.956
# resultado da epoca 45 = 297.00 Epsilon = 0.955
# resultado da epoca 46 = -368.00 Epsilon = 0.954
# resultado da epoca 47 = 433.00 Epsilon = 0.953
# resultado da epoca 48 = -270.00 Epsilon = 0.952
# resultado da epoca 49 = 143.00 Epsilon = 0.951
# resultado da epoca 50 = -336.00 Epsilon = 0.950
# resultado da epoca 51 = -134.00 Epsilon = 0.950
# resultado da epoca 52 = -232.00 Epsilon = 0.949
# resultado da epoca 53 = 88.00 Epsilon = 0.948
# resultado da epoca 54 = -383.00 Epsilon = 0.947
# resultado da epoca 55 = -142.00 Epsilon = 0.946
# resultado da epoca 56 = -729.00 Epsilon = 0.945
# resultado da epoca 57 = 435.00 Epsilon = 0.944
# resultado da epoca 58 = -87.00 Epsilon = 0.943
# resultado da epoca 59 = -292.00 Epsilon = 0.942
# resultado da epoca 60 = 122.00 Epsilon = 0.941
# resultado da epoca 61 = -37.00 Epsilon = 0.940
# resultado da epoca 62 = -93.00 Epsilon = 0.939
# resultado da epoca 63 = 485.00 Epsilon = 0.938
# resultado da epoca 64 = -124.00 Epsilon = 0.937
# resultado da epoca 65 = -860.00 Epsilon = 0.936
# resultado da epoca 66 = 163.00 Epsilon = 0.935
# resultado da epoca 67 = 72.00 Epsilon = 0.934
# resultado da epoca 68 = 721.00 Epsilon = 0.933
# resultado da epoca 69 = 197.00 Epsilon = 0.932
# resultado da epoca 70 = -16.00 Epsilon = 0.931
# resultado da epoca 71 = 135.00 Epsilon = 0.930
# resultado da epoca 72 = -530.00 Epsilon = 0.929
# resultado da epoca 73 = -1204.00 Epsilon = 0.928
# resultado da epoca 74 = -794.00 Epsilon = 0.927
# resultado da epoca 75 = -615.00 Epsilon = 0.926
# resultado da epoca 76 = 846.00 Epsilon = 0.925
# resultado da epoca 77 = -194.00 Epsilon = 0.924
# resultado da epoca 78 = 346.00 Epsilon = 0.923
# resultado da epoca 79 = -440.00 Epsilon = 0.922
# resultado da epoca 80 = 167.00 Epsilon = 0.921
# resultado da epoca 81 = -118.00 Epsilon = 0.920
# resultado da epoca 82 = 80.00 Epsilon = 0.919
# resultado da epoca 83 = -437.00 Epsilon = 0.918
# resultado da epoca 84 = 564.00 Epsilon = 0.917
# resultado da epoca 85 = -62.00 Epsilon = 0.916
# resultado da epoca 86 = 96.00 Epsilon = 0.915
# resultado da epoca 87 = -35.00 Epsilon = 0.914
# resultado da epoca 88 = 395.00 Epsilon = 0.913
# resultado da epoca 89 = -64.00 Epsilon = 0.912
# resultado da epoca 90 = -909.00 Epsilon = 0.911
# resultado da epoca 91 = -499.00 Epsilon = 0.910
# resultado da epoca 92 = 83.00 Epsilon = 0.909
# resultado da epoca 93 = 476.00 Epsilon = 0.908
# resultado da epoca 94 = 51.00 Epsilon = 0.907
# resultado da epoca 95 = 219.00 Epsilon = 0.906
# resultado da epoca 96 = -782.00 Epsilon = 0.905
# resultado da epoca 97 = -238.00 Epsilon = 0.904
# resultado da epoca 98 = -294.00 Epsilon = 0.903
# resultado da epoca 99 = 302.00 Epsilon = 0.902
# resultado da epoca 100 = 387.00 Epsilon = 0.901
# resultado da epoca 101 = 944.00 Epsilon = 0.900
# resultado da epoca 102 = -324.00 Epsilon = 0.899
# resultado da epoca 103 = 251.00 Epsilon = 0.898
# resultado da epoca 104 = -206.00 Epsilon = 0.897
# resultado da epoca 105 = 198.00 Epsilon = 0.896
# resultado da epoca 106 = -578.00 Epsilon = 0.895
# resultado da epoca 107 = -189.00 Epsilon = 0.894
# resultado da epoca 108 = 18.00 Epsilon = 0.893
# resultado da epoca 109 = -332.00 Epsilon = 0.892
# resultado da epoca 110 = 200.00 Epsilon = 0.891
# resultado da epoca 111 = -57.00 Epsilon = 0.890
# resultado da epoca 112 = -525.00 Epsilon = 0.889
# resultado da epoca 113 = 6.00 Epsilon = 0.888
# resultado da epoca 114 = -314.00 Epsilon = 0.887
# resultado da epoca 115 = -192.00 Epsilon = 0.886
# resultado da epoca 116 = -583.00 Epsilon = 0.885
# resultado da epoca 117 = -185.00 Epsilon = 0.884
# resultado da epoca 118 = 165.00 Epsilon = 0.883
# resultado da epoca 119 = -120.00 Epsilon = 0.882
# resultado da epoca 120 = -694.00 Epsilon = 0.881
# resultado da epoca 121 = 100.00 Epsilon = 0.880
# resultado da epoca 122 = 31.00 Epsilon = 0.879
# resultado da epoca 123 = 241.00 Epsilon = 0.878
# resultado da epoca 124 = -118.00 Epsilon = 0.877
# resultado da epoca 125 = 110.00 Epsilon = 0.876
# resultado da epoca 126 = -311.00 Epsilon = 0.875
# resultado da epoca 127 = 22.00 Epsilon = 0.874
# resultado da epoca 128 = -106.00 Epsilon = 0.873
# resultado da epoca 129 = -223.00 Epsilon = 0.872
# resultado da epoca 130 = -303.00 Epsilon = 0.871
# resultado da epoca 131 = -135.00 Epsilon = 0.870
# resultado da epoca 132 = -667.00 Epsilon = 0.869
# resultado da epoca 133 = 195.00 Epsilon = 0.868
# resultado da epoca 134 = 348.00 Epsilon = 0.867
# resultado da epoca 135 = 370.00 Epsilon = 0.866
# resultado da epoca 136 = -165.00 Epsilon = 0.865
# resultado da epoca 137 = -368.00 Epsilon = 0.864
# resultado da epoca 138 = 457.00 Epsilon = 0.863
# resultado da epoca 139 = -238.00 Epsilon = 0.862
# resultado da epoca 140 = 54.00 Epsilon = 0.861
# resultado da epoca 141 = -30.00 Epsilon = 0.860
# resultado da epoca 142 = -75.00 Epsilon = 0.859
# resultado da epoca 143 = 182.00 Epsilon = 0.858
# resultado da epoca 144 = 496.00 Epsilon = 0.857
# resultado da epoca 145 = 914.00 Epsilon = 0.856
# resultado da epoca 146 = -227.00 Epsilon = 0.855
# resultado da epoca 147 = -14.00 Epsilon = 0.854
# resultado da epoca 148 = 33.00 Epsilon = 0.853
# resultado da epoca 149 = -207.00 Epsilon = 0.852
# resultado da epoca 150 = 267.00 Epsilon = 0.851
# resultado da epoca 151 = 867.00 Epsilon = 0.851
# resultado da epoca 152 = -16.00 Epsilon = 0.850
# resultado da epoca 153 = -234.00 Epsilon = 0.849
# resultado da epoca 154 = -236.00 Epsilon = 0.848
# resultado da epoca 155 = -57.00 Epsilon = 0.847
# resultado da epoca 156 = -111.00 Epsilon = 0.846
# resultado da epoca 157 = 78.00 Epsilon = 0.845
# resultado da epoca 158 = -310.00 Epsilon = 0.844
# resultado da epoca 159 = 248.00 Epsilon = 0.843
# resultado da epoca 160 = 380.00 Epsilon = 0.842
# resultado da epoca 161 = 525.00 Epsilon = 0.841
# resultado da epoca 162 = -907.00 Epsilon = 0.840
# resultado da epoca 163 = -140.00 Epsilon = 0.839
# resultado da epoca 164 = 51.00 Epsilon = 0.838
# resultado da epoca 165 = -111.00 Epsilon = 0.837
# resultado da epoca 166 = -432.00 Epsilon = 0.836
# resultado da epoca 167 = -29.00 Epsilon = 0.835
# resultado da epoca 168 = -183.00 Epsilon = 0.834
# resultado da epoca 169 = 298.00 Epsilon = 0.833
# resultado da epoca 170 = -185.00 Epsilon = 0.832
# resultado da epoca 171 = -215.00 Epsilon = 0.831
# resultado da epoca 172 = 612.00 Epsilon = 0.830
# resultado da epoca 173 = 278.00 Epsilon = 0.829
# resultado da epoca 174 = 70.00 Epsilon = 0.828
# resultado da epoca 175 = 139.00 Epsilon = 0.827
# resultado da epoca 176 = -298.00 Epsilon = 0.826
# resultado da epoca 177 = -409.00 Epsilon = 0.825
# resultado da epoca 178 = 998.00 Epsilon = 0.824
# resultado da epoca 179 = -434.00 Epsilon = 0.823
# resultado da epoca 180 = 171.00 Epsilon = 0.822
# resultado da epoca 181 = -30.00 Epsilon = 0.821
# resultado da epoca 182 = 256.00 Epsilon = 0.820
# resultado da epoca 183 = 226.00 Epsilon = 0.819
# resultado da epoca 184 = -588.00 Epsilon = 0.818
# resultado da epoca 185 = 216.00 Epsilon = 0.817
# resultado da epoca 186 = 491.00 Epsilon = 0.816
# resultado da epoca 187 = 110.00 Epsilon = 0.815
# resultado da epoca 188 = 412.00 Epsilon = 0.814
# resultado da epoca 189 = 370.00 Epsilon = 0.813
# resultado da epoca 190 = -363.00 Epsilon = 0.812
# resultado da epoca 191 = -642.00 Epsilon = 0.811
# resultado da epoca 192 = -560.00 Epsilon = 0.810
# resultado da epoca 193 = 300.00 Epsilon = 0.809
# resultado da epoca 194 = -325.00 Epsilon = 0.808
# resultado da epoca 195 = -330.00 Epsilon = 0.807
# resultado da epoca 196 = 122.00 Epsilon = 0.806
# resultado da epoca 197 = -660.00 Epsilon = 0.805
# resultado da epoca 198 = 30.00 Epsilon = 0.804
# resultado da epoca 199 = 182.00 Epsilon = 0.803
# resultado da epoca 200 = -273.00 Epsilon = 0.802
# resultado da epoca 201 = -658.00 Epsilon = 0.801
# resultado da epoca 202 = 396.00 Epsilon = 0.800
# resultado da epoca 203 = 51.00 Epsilon = 0.799
# resultado da epoca 204 = -62.00 Epsilon = 0.798
# resultado da epoca 205 = -142.00 Epsilon = 0.797
# resultado da epoca 206 = 334.00 Epsilon = 0.796
# resultado da epoca 207 = -531.00 Epsilon = 0.795
# resultado da epoca 208 = -228.00 Epsilon = 0.794
# resultado da epoca 209 = -234.00 Epsilon = 0.793
# resultado da epoca 210 = 142.00 Epsilon = 0.792
# resultado da epoca 211 = -637.00 Epsilon = 0.791
# resultado da epoca 212 = -297.00 Epsilon = 0.790
# resultado da epoca 213 = 133.00 Epsilon = 0.789
# resultado da epoca 214 = 387.00 Epsilon = 0.788
# resultado da epoca 215 = 1124.00 Epsilon = 0.787
# resultado da epoca 216 = -272.00 Epsilon = 0.786
# resultado da epoca 217 = -785.00 Epsilon = 0.785
# resultado da epoca 218 = -277.00 Epsilon = 0.784
# resultado da epoca 219 = -359.00 Epsilon = 0.783
# resultado da epoca 220 = -597.00 Epsilon = 0.782
# resultado da epoca 221 = 24.00 Epsilon = 0.781
# resultado da epoca 222 = -160.00 Epsilon = 0.780
# resultado da epoca 223 = 333.00 Epsilon = 0.779
# resultado da epoca 224 = -99.00 Epsilon = 0.778
# resultado da epoca 225 = -5.00 Epsilon = 0.777
# resultado da epoca 226 = 61.00 Epsilon = 0.776
# resultado da epoca 227 = -68.00 Epsilon = 0.775
# resultado da epoca 228 = -42.00 Epsilon = 0.774
# resultado da epoca 229 = 55.00 Epsilon = 0.773
# resultado da epoca 230 = 348.00 Epsilon = 0.772
# resultado da epoca 231 = 139.00 Epsilon = 0.771
# resultado da epoca 232 = -184.00 Epsilon = 0.770
# resultado da epoca 233 = -178.00 Epsilon = 0.769
# resultado da epoca 234 = -70.00 Epsilon = 0.768
# resultado da epoca 235 = 66.00 Epsilon = 0.767
# resultado da epoca 236 = -72.00 Epsilon = 0.766
# resultado da epoca 237 = 168.00 Epsilon = 0.765
# resultado da epoca 238 = 149.00 Epsilon = 0.764
# resultado da epoca 239 = 244.00 Epsilon = 0.763
# resultado da epoca 240 = 595.00 Epsilon = 0.762
# resultado da epoca 241 = -70.00 Epsilon = 0.761
# resultado da epoca 242 = 448.00 Epsilon = 0.760
# resultado da epoca 243 = -193.00 Epsilon = 0.759
# resultado da epoca 244 = 28.00 Epsilon = 0.758
# resultado da epoca 245 = -15.00 Epsilon = 0.757
# resultado da epoca 246 = -368.00 Epsilon = 0.756
# resultado da epoca 247 = 456.00 Epsilon = 0.755
# resultado da epoca 248 = -244.00 Epsilon = 0.754
# resultado da epoca 249 = -136.00 Epsilon = 0.753
# resultado da epoca 250 = -58.00 Epsilon = 0.752
# resultado da epoca 251 = 117.00 Epsilon = 0.752
# resultado da epoca 252 = -368.00 Epsilon = 0.751
# resultado da epoca 253 = 142.00 Epsilon = 0.750
# resultado da epoca 254 = 58.00 Epsilon = 0.749
# resultado da epoca 255 = 49.00 Epsilon = 0.748
# resultado da epoca 256 = 148.00 Epsilon = 0.747
# resultado da epoca 257 = 176.00 Epsilon = 0.746
# resultado da epoca 258 = 419.00 Epsilon = 0.745
# resultado da epoca 259 = 250.00 Epsilon = 0.744
# resultado da epoca 260 = -98.00 Epsilon = 0.743
# resultado da epoca 261 = -76.00 Epsilon = 0.742
# resultado da epoca 262 = 230.00 Epsilon = 0.741
# resultado da epoca 263 = 174.00 Epsilon = 0.740
# resultado da epoca 264 = 312.00 Epsilon = 0.739
# resultado da epoca 265 = -791.00 Epsilon = 0.738
# resultado da epoca 266 = 404.00 Epsilon = 0.737
# resultado da epoca 267 = -73.00 Epsilon = 0.736
# resultado da epoca 268 = -241.00 Epsilon = 0.735
# resultado da epoca 269 = -314.00 Epsilon = 0.734
# resultado da epoca 270 = 113.00 Epsilon = 0.733
# resultado da epoca 271 = -637.00 Epsilon = 0.732
# resultado da epoca 272 = 144.00 Epsilon = 0.731
# resultado da epoca 273 = -109.00 Epsilon = 0.730
# resultado da epoca 274 = 10.00 Epsilon = 0.729
# resultado da epoca 275 = -766.00 Epsilon = 0.728
# resultado da epoca 276 = 436.00 Epsilon = 0.727
# resultado da epoca 277 = 75.00 Epsilon = 0.726
# resultado da epoca 278 = 257.00 Epsilon = 0.725
# resultado da epoca 279 = 222.00 Epsilon = 0.724
# resultado da epoca 280 = 363.00 Epsilon = 0.723
# resultado da epoca 281 = -528.00 Epsilon = 0.722
# resultado da epoca 282 = 161.00 Epsilon = 0.721
# resultado da epoca 283 = -71.00 Epsilon = 0.720
# resultado da epoca 284 = 239.00 Epsilon = 0.719
# resultado da epoca 285 = -196.00 Epsilon = 0.718
# resultado da epoca 286 = -457.00 Epsilon = 0.717
# resultado da epoca 287 = 400.00 Epsilon = 0.716
# resultado da epoca 288 = -308.00 Epsilon = 0.715
# resultado da epoca 289 = 881.00 Epsilon = 0.714
# resultado da epoca 290 = -15.00 Epsilon = 0.713
# resultado da epoca 291 = -456.00 Epsilon = 0.712
# resultado da epoca 292 = 233.00 Epsilon = 0.711
# resultado da epoca 293 = 560.00 Epsilon = 0.710
# resultado da epoca 294 = -141.00 Epsilon = 0.709
# resultado da epoca 295 = -48.00 Epsilon = 0.708
# resultado da epoca 296 = 367.00 Epsilon = 0.707
# resultado da epoca 297 = -361.00 Epsilon = 0.706
# resultado da epoca 298 = -63.00 Epsilon = 0.705
# resultado da epoca 299 = -66.00 Epsilon = 0.704
# resultado da epoca 300 = 72.00 Epsilon = 0.703
# resultado da epoca 301 = 104.00 Epsilon = 0.702
# resultado da epoca 302 = 144.00 Epsilon = 0.701
# resultado da epoca 303 = 215.00 Epsilon = 0.700
# resultado da epoca 304 = -312.00 Epsilon = 0.699
# resultado da epoca 305 = 286.00 Epsilon = 0.698
# resultado da epoca 306 = -176.00 Epsilon = 0.697
# resultado da epoca 307 = -492.00 Epsilon = 0.696
# resultado da epoca 308 = -335.00 Epsilon = 0.695
# resultado da epoca 309 = 206.00 Epsilon = 0.694
# resultado da epoca 310 = -119.00 Epsilon = 0.693
# resultado da epoca 311 = 132.00 Epsilon = 0.692
# resultado da epoca 312 = -205.00 Epsilon = 0.691
# resultado da epoca 313 = -104.00 Epsilon = 0.690
# resultado da epoca 314 = 309.00 Epsilon = 0.689
# resultado da epoca 315 = -104.00 Epsilon = 0.688
# resultado da epoca 316 = -77.00 Epsilon = 0.687
# resultado da epoca 317 = -114.00 Epsilon = 0.686
# resultado da epoca 318 = 35.00 Epsilon = 0.685
# resultado da epoca 319 = -10.00 Epsilon = 0.684
# resultado da epoca 320 = -425.00 Epsilon = 0.683
# resultado da epoca 321 = 81.00 Epsilon = 0.682
# resultado da epoca 322 = -235.00 Epsilon = 0.681
# resultado da epoca 323 = -490.00 Epsilon = 0.680
# resultado da epoca 324 = -396.00 Epsilon = 0.679
# resultado da epoca 325 = -132.00 Epsilon = 0.678
# resultado da epoca 326 = -280.00 Epsilon = 0.677
# resultado da epoca 327 = 261.00 Epsilon = 0.676
# resultado da epoca 328 = 115.00 Epsilon = 0.675
# resultado da epoca 329 = -20.00 Epsilon = 0.674
# resultado da epoca 330 = 104.00 Epsilon = 0.673
# resultado da epoca 331 = -383.00 Epsilon = 0.672
# resultado da epoca 332 = 741.00 Epsilon = 0.671
# resultado da epoca 333 = 391.00 Epsilon = 0.670
# resultado da epoca 334 = 1164.00 Epsilon = 0.669
# resultado da epoca 335 = 859.00 Epsilon = 0.668
# resultado da epoca 336 = 289.00 Epsilon = 0.667
# resultado da epoca 337 = 146.00 Epsilon = 0.666
# resultado da epoca 338 = 755.00 Epsilon = 0.665
# resultado da epoca 339 = 675.00 Epsilon = 0.664
# resultado da epoca 340 = 102.00 Epsilon = 0.663
# resultado da epoca 341 = 371.00 Epsilon = 0.662
# resultado da epoca 342 = 894.00 Epsilon = 0.661
# resultado da epoca 343 = 82.00 Epsilon = 0.660
# resultado da epoca 344 = 593.00 Epsilon = 0.659
# resultado da epoca 345 = 1474.00 Epsilon = 0.658
# resultado da epoca 346 = 68.00 Epsilon = 0.657
# resultado da epoca 347 = 929.00 Epsilon = 0.656
# resultado da epoca 348 = 422.00 Epsilon = 0.655
# resultado da epoca 349 = 231.00 Epsilon = 0.654
# resultado da epoca 350 = 248.00 Epsilon = 0.653
# resultado da epoca 351 = -633.00 Epsilon = 0.653
# resultado da epoca 352 = 592.00 Epsilon = 0.652
# resultado da epoca 353 = 1068.00 Epsilon = 0.651
# resultado da epoca 354 = 160.00 Epsilon = 0.650
# resultado da epoca 355 = 2087.00 Epsilon = 0.649
# resultado da epoca 356 = 1158.00 Epsilon = 0.648
# resultado da epoca 357 = 1568.00 Epsilon = 0.647
# resultado da epoca 358 = 1552.00 Epsilon = 0.646
# resultado da epoca 359 = 879.00 Epsilon = 0.645
# resultado da epoca 360 = 1577.00 Epsilon = 0.644
# resultado da epoca 361 = 860.00 Epsilon = 0.643
# resultado da epoca 362 = -24.00 Epsilon = 0.642
# resultado da epoca 363 = 1317.00 Epsilon = 0.641
# resultado da epoca 364 = 1034.00 Epsilon = 0.640
# resultado da epoca 365 = 735.00 Epsilon = 0.639
# resultado da epoca 366 = 356.00 Epsilon = 0.638
# resultado da epoca 367 = 401.00 Epsilon = 0.637
# resultado da epoca 368 = 1205.00 Epsilon = 0.636
# resultado da epoca 369 = 1592.00 Epsilon = 0.635
# resultado da epoca 370 = 51.00 Epsilon = 0.634
# resultado da epoca 371 = 1764.00 Epsilon = 0.633
# resultado da epoca 372 = 635.00 Epsilon = 0.632
# resultado da epoca 373 = 1041.00 Epsilon = 0.631
# resultado da epoca 374 = 729.00 Epsilon = 0.630
# resultado da epoca 375 = 277.00 Epsilon = 0.629
# resultado da epoca 376 = 860.00 Epsilon = 0.628
# resultado da epoca 377 = 648.00 Epsilon = 0.627
# resultado da epoca 378 = 1389.00 Epsilon = 0.626
# resultado da epoca 379 = 1843.00 Epsilon = 0.625
# resultado da epoca 380 = 1180.00 Epsilon = 0.624
# resultado da epoca 381 = 1117.00 Epsilon = 0.623
# resultado da epoca 382 = 1883.00 Epsilon = 0.622
# resultado da epoca 383 = 740.00 Epsilon = 0.621
# resultado da epoca 384 = 1864.00 Epsilon = 0.620
# resultado da epoca 385 = 890.00 Epsilon = 0.619
# resultado da epoca 386 = 434.00 Epsilon = 0.618
# resultado da epoca 387 = 638.00 Epsilon = 0.617
# resultado da epoca 388 = 491.00 Epsilon = 0.616
# resultado da epoca 389 = 1232.00 Epsilon = 0.615
# resultado da epoca 390 = 925.00 Epsilon = 0.614
# resultado da epoca 391 = 666.00 Epsilon = 0.613
# resultado da epoca 392 = -215.00 Epsilon = 0.612
# resultado da epoca 393 = 725.00 Epsilon = 0.611
# resultado da epoca 394 = 736.00 Epsilon = 0.610
# resultado da epoca 395 = 573.00 Epsilon = 0.609
# resultado da epoca 396 = 785.00 Epsilon = 0.608
# resultado da epoca 397 = 305.00 Epsilon = 0.607
# resultado da epoca 398 = 770.00 Epsilon = 0.606
# resultado da epoca 399 = 1660.00 Epsilon = 0.605
# resultado da epoca 400 = 357.00 Epsilon = 0.604
# resultado da epoca 401 = 1128.00 Epsilon = 0.603
# resultado da epoca 402 = 563.00 Epsilon = 0.602
# resultado da epoca 403 = 1149.00 Epsilon = 0.601
# resultado da epoca 404 = 673.00 Epsilon = 0.600
# resultado da epoca 405 = 775.00 Epsilon = 0.599
# resultado da epoca 406 = 193.00 Epsilon = 0.598
# resultado da epoca 407 = 1053.00 Epsilon = 0.597
# resultado da epoca 408 = 29.00 Epsilon = 0.596
# resultado da epoca 409 = 1435.00 Epsilon = 0.595
# resultado da epoca 410 = 597.00 Epsilon = 0.594
# resultado da epoca 411 = 662.00 Epsilon = 0.593
# resultado da epoca 412 = 1052.00 Epsilon = 0.592
# resultado da epoca 413 = 823.00 Epsilon = 0.591
# resultado da epoca 414 = 1153.00 Epsilon = 0.590
# resultado da epoca 415 = 704.00 Epsilon = 0.589
# resultado da epoca 416 = 744.00 Epsilon = 0.588
# resultado da epoca 417 = 1489.00 Epsilon = 0.587
# resultado da epoca 418 = 1312.00 Epsilon = 0.586
# resultado da epoca 419 = 1932.00 Epsilon = 0.585
# resultado da epoca 420 = 1086.00 Epsilon = 0.584
# resultado da epoca 421 = 693.00 Epsilon = 0.583
# resultado da epoca 422 = 1674.00 Epsilon = 0.582
# resultado da epoca 423 = -289.00 Epsilon = 0.581
# resultado da epoca 424 = 1273.00 Epsilon = 0.580
# resultado da epoca 425 = 377.00 Epsilon = 0.579
# resultado da epoca 426 = 2317.00 Epsilon = 0.578
# resultado da epoca 427 = 179.00 Epsilon = 0.577
# resultado da epoca 428 = 963.00 Epsilon = 0.576
# resultado da epoca 429 = 1779.00 Epsilon = 0.575
# resultado da epoca 430 = 2029.00 Epsilon = 0.574
# resultado da epoca 431 = 1929.00 Epsilon = 0.573
# resultado da epoca 432 = 1179.00 Epsilon = 0.572
# resultado da epoca 433 = 723.00 Epsilon = 0.571
# resultado da epoca 434 = 1188.00 Epsilon = 0.570
# resultado da epoca 435 = 1132.00 Epsilon = 0.569
# resultado da epoca 436 = 642.00 Epsilon = 0.568
# resultado da epoca 437 = 1874.00 Epsilon = 0.567
# resultado da epoca 438 = 1107.00 Epsilon = 0.566
# resultado da epoca 439 = 1650.00 Epsilon = 0.565
# resultado da epoca 440 = 1197.00 Epsilon = 0.564
# resultado da epoca 441 = 2326.00 Epsilon = 0.563
# resultado da epoca 442 = 1674.00 Epsilon = 0.562
# resultado da epoca 443 = 1122.00 Epsilon = 0.561
# resultado da epoca 444 = 885.00 Epsilon = 0.560
# resultado da epoca 445 = 1638.00 Epsilon = 0.559
# resultado da epoca 446 = 1657.00 Epsilon = 0.558
# resultado da epoca 447 = 1166.00 Epsilon = 0.557
# resultado da epoca 448 = -122.00 Epsilon = 0.556
# resultado da epoca 449 = 1054.00 Epsilon = 0.555
# resultado da epoca 450 = 1111.00 Epsilon = 0.554
# resultado da epoca 451 = 1363.00 Epsilon = 0.554
# resultado da epoca 452 = 589.00 Epsilon = 0.553
# resultado da epoca 453 = 1442.00 Epsilon = 0.552
# resultado da epoca 454 = 1174.00 Epsilon = 0.551
# resultado da epoca 455 = 1451.00 Epsilon = 0.550
# resultado da epoca 456 = 1626.00 Epsilon = 0.549
# resultado da epoca 457 = 141.00 Epsilon = 0.548
# resultado da epoca 458 = 1152.00 Epsilon = 0.547
# resultado da epoca 459 = 2362.00 Epsilon = 0.546
# resultado da epoca 460 = 1723.00 Epsilon = 0.545
# resultado da epoca 461 = 1771.00 Epsilon = 0.544
# resultado da epoca 462 = 1809.00 Epsilon = 0.543
# resultado da epoca 463 = 1251.00 Epsilon = 0.542
# resultado da epoca 464 = 246.00 Epsilon = 0.541
# resultado da epoca 465 = 1412.00 Epsilon = 0.540
# resultado da epoca 466 = 884.00 Epsilon = 0.539
# resultado da epoca 467 = 724.00 Epsilon = 0.538
# resultado da epoca 468 = 564.00 Epsilon = 0.537
# resultado da epoca 469 = 1222.00 Epsilon = 0.536
# resultado da epoca 470 = 1433.00 Epsilon = 0.535
# resultado da epoca 471 = 681.00 Epsilon = 0.534
# resultado da epoca 472 = 29.00 Epsilon = 0.533
# resultado da epoca 473 = 636.00 Epsilon = 0.532
# resultado da epoca 474 = 917.00 Epsilon = 0.531
# resultado da epoca 475 = 2541.00 Epsilon = 0.530
# resultado da epoca 476 = 887.00 Epsilon = 0.529
# resultado da epoca 477 = 1691.00 Epsilon = 0.528
# resultado da epoca 478 = 740.00 Epsilon = 0.527
# resultado da epoca 479 = 60.00 Epsilon = 0.526
# resultado da epoca 480 = 1458.00 Epsilon = 0.525
# resultado da epoca 481 = 1090.00 Epsilon = 0.524
# resultado da epoca 482 = 414.00 Epsilon = 0.523
# resultado da epoca 483 = 1487.00 Epsilon = 0.522
# resultado da epoca 484 = 685.00 Epsilon = 0.521
# resultado da epoca 485 = 1410.00 Epsilon = 0.520
# resultado da epoca 486 = 729.00 Epsilon = 0.519
# resultado da epoca 487 = 822.00 Epsilon = 0.518
# resultado da epoca 488 = 1341.00 Epsilon = 0.517
# resultado da epoca 489 = 113.00 Epsilon = 0.516
# resultado da epoca 490 = 1747.00 Epsilon = 0.515
# resultado da epoca 491 = 2397.00 Epsilon = 0.514
# resultado da epoca 492 = 2188.00 Epsilon = 0.513
# resultado da epoca 493 = 1477.00 Epsilon = 0.512
# resultado da epoca 494 = 235.00 Epsilon = 0.511
# resultado da epoca 495 = 1087.00 Epsilon = 0.510
# resultado da epoca 496 = 465.00 Epsilon = 0.509
# resultado da epoca 497 = 703.00 Epsilon = 0.508
# resultado da epoca 498 = 1975.00 Epsilon = 0.507
# resultado da epoca 499 = 1226.00 Epsilon = 0.506
# resultado da epoca 500 = 1335.00 Epsilon = 0.505
# resultado da epoca 501 = 1802.00 Epsilon = 0.504
# resultado da epoca 502 = 1314.00 Epsilon = 0.503
# resultado da epoca 503 = 902.00 Epsilon = 0.502
# resultado da epoca 504 = 1327.00 Epsilon = 0.501
# resultado da epoca 505 = 1198.00 Epsilon = 0.500
# resultado da epoca 506 = 1430.00 Epsilon = 0.499
# resultado da epoca 507 = 743.00 Epsilon = 0.498
# resultado da epoca 508 = 993.00 Epsilon = 0.497
# resultado da epoca 509 = 893.00 Epsilon = 0.496
# resultado da epoca 510 = 1342.00 Epsilon = 0.495
# resultado da epoca 511 = 836.00 Epsilon = 0.494
# resultado da epoca 512 = 2296.00 Epsilon = 0.493
# resultado da epoca 513 = 1687.00 Epsilon = 0.492
# resultado da epoca 514 = 1035.00 Epsilon = 0.491
# resultado da epoca 515 = 1108.00 Epsilon = 0.490
# resultado da epoca 516 = 1857.00 Epsilon = 0.489
# resultado da epoca 517 = 844.00 Epsilon = 0.488
# resultado da epoca 518 = 1232.00 Epsilon = 0.487
# resultado da epoca 519 = 1375.00 Epsilon = 0.486
# resultado da epoca 520 = 859.00 Epsilon = 0.485
# resultado da epoca 521 = 1600.00 Epsilon = 0.484
# resultado da epoca 522 = 1319.00 Epsilon = 0.483
# resultado da epoca 523 = 2102.00 Epsilon = 0.482
# resultado da epoca 524 = 474.00 Epsilon = 0.481
# resultado da epoca 525 = 1743.00 Epsilon = 0.480
# resultado da epoca 526 = 1715.00 Epsilon = 0.479
# resultado da epoca 527 = 1756.00 Epsilon = 0.478
# resultado da epoca 528 = 860.00 Epsilon = 0.477
# resultado da epoca 529 = 1247.00 Epsilon = 0.476
# resultado da epoca 530 = 2127.00 Epsilon = 0.475
# resultado da epoca 531 = 2088.00 Epsilon = 0.474
# resultado da epoca 532 = 1452.00 Epsilon = 0.473
# resultado da epoca 533 = 402.00 Epsilon = 0.472
# resultado da epoca 534 = 2051.00 Epsilon = 0.471
# resultado da epoca 535 = 2126.00 Epsilon = 0.470
# resultado da epoca 536 = 2078.00 Epsilon = 0.469
# resultado da epoca 537 = 1574.00 Epsilon = 0.468
# resultado da epoca 538 = 1605.00 Epsilon = 0.467
# resultado da epoca 539 = 1385.00 Epsilon = 0.466
# resultado da epoca 540 = 2193.00 Epsilon = 0.465
# resultado da epoca 541 = 2020.00 Epsilon = 0.464
# resultado da epoca 542 = 1638.00 Epsilon = 0.463
# resultado da epoca 543 = 2035.00 Epsilon = 0.462
# resultado da epoca 544 = 1318.00 Epsilon = 0.461
# resultado da epoca 545 = 3043.00 Epsilon = 0.460
# resultado da epoca 546 = 1621.00 Epsilon = 0.459
# resultado da epoca 547 = 1346.00 Epsilon = 0.458
# resultado da epoca 548 = 266.00 Epsilon = 0.457
# resultado da epoca 549 = 2002.00 Epsilon = 0.456
# resultado da epoca 550 = 1968.00 Epsilon = 0.455
# resultado da epoca 551 = 2288.00 Epsilon = 0.455
# resultado da epoca 552 = 1722.00 Epsilon = 0.454
# resultado da epoca 553 = 1879.00 Epsilon = 0.453
# resultado da epoca 554 = 964.00 Epsilon = 0.452
# resultado da epoca 555 = 840.00 Epsilon = 0.451
# resultado da epoca 556 = 1238.00 Epsilon = 0.450
# resultado da epoca 557 = 1572.00 Epsilon = 0.449
# resultado da epoca 558 = 1683.00 Epsilon = 0.448
# resultado da epoca 559 = 1636.00 Epsilon = 0.447
# resultado da epoca 560 = 907.00 Epsilon = 0.446
# resultado da epoca 561 = 767.00 Epsilon = 0.445
# resultado da epoca 562 = 1514.00 Epsilon = 0.444
# resultado da epoca 563 = 1492.00 Epsilon = 0.443
# resultado da epoca 564 = 712.00 Epsilon = 0.442
# resultado da epoca 565 = 8.00 Epsilon = 0.441
# resultado da epoca 566 = 1576.00 Epsilon = 0.440
# resultado da epoca 567 = 1707.00 Epsilon = 0.439
# resultado da epoca 568 = 2520.00 Epsilon = 0.438
# resultado da epoca 569 = 2344.00 Epsilon = 0.437
# resultado da epoca 570 = 2173.00 Epsilon = 0.436
# resultado da epoca 571 = 2017.00 Epsilon = 0.435
# resultado da epoca 572 = 1614.00 Epsilon = 0.434
# resultado da epoca 573 = 1699.00 Epsilon = 0.433
# resultado da epoca 574 = 2964.00 Epsilon = 0.432
# resultado da epoca 575 = 1254.00 Epsilon = 0.431
# resultado da epoca 576 = 2177.00 Epsilon = 0.430
# resultado da epoca 577 = 1505.00 Epsilon = 0.429
# resultado da epoca 578 = 682.00 Epsilon = 0.428
# resultado da epoca 579 = 2681.00 Epsilon = 0.427
# resultado da epoca 580 = 676.00 Epsilon = 0.426
# resultado da epoca 581 = 1875.00 Epsilon = 0.425
# resultado da epoca 582 = 2091.00 Epsilon = 0.424
# resultado da epoca 583 = 1007.00 Epsilon = 0.423
# resultado da epoca 584 = 1138.00 Epsilon = 0.422
# resultado da epoca 585 = 2029.00 Epsilon = 0.421
# resultado da epoca 586 = 470.00 Epsilon = 0.420
# resultado da epoca 587 = 1614.00 Epsilon = 0.419
# resultado da epoca 588 = 1320.00 Epsilon = 0.418
# resultado da epoca 589 = 2253.00 Epsilon = 0.417
# resultado da epoca 590 = 1941.00 Epsilon = 0.416
# resultado da epoca 591 = 1342.00 Epsilon = 0.415
# resultado da epoca 592 = 1450.00 Epsilon = 0.414
# resultado da epoca 593 = 2513.00 Epsilon = 0.413
# resultado da epoca 594 = 1041.00 Epsilon = 0.412
# resultado da epoca 595 = 2677.00 Epsilon = 0.411
# resultado da epoca 596 = 2355.00 Epsilon = 0.410
# resultado da epoca 597 = 1784.00 Epsilon = 0.409
# resultado da epoca 598 = 2584.00 Epsilon = 0.408
# resultado da epoca 599 = 892.00 Epsilon = 0.407
# resultado da epoca 600 = 1586.00 Epsilon = 0.406
# resultado da epoca 601 = 706.00 Epsilon = 0.405
# resultado da epoca 602 = 2995.00 Epsilon = 0.404
# resultado da epoca 603 = 1954.00 Epsilon = 0.403
# resultado da epoca 604 = 1821.00 Epsilon = 0.402
# resultado da epoca 605 = 2591.00 Epsilon = 0.401
# resultado da epoca 606 = 2499.00 Epsilon = 0.400
# resultado da epoca 607 = 2159.00 Epsilon = 0.399
# resultado da epoca 608 = 2339.00 Epsilon = 0.398
# resultado da epoca 609 = 2119.00 Epsilon = 0.397
# resultado da epoca 610 = 666.00 Epsilon = 0.396
# resultado da epoca 611 = 1445.00 Epsilon = 0.395
# resultado da epoca 612 = 1669.00 Epsilon = 0.394
# resultado da epoca 613 = 1891.00 Epsilon = 0.393
# resultado da epoca 614 = 1550.00 Epsilon = 0.392
# resultado da epoca 615 = 3337.00 Epsilon = 0.391
# resultado da epoca 616 = 1043.00 Epsilon = 0.390
# resultado da epoca 617 = 1989.00 Epsilon = 0.389
# resultado da epoca 618 = 947.00 Epsilon = 0.388
# resultado da epoca 619 = 1141.00 Epsilon = 0.387
# resultado da epoca 620 = 2174.00 Epsilon = 0.386
# resultado da epoca 621 = 3137.00 Epsilon = 0.385
# resultado da epoca 622 = 1829.00 Epsilon = 0.384
# resultado da epoca 623 = 2288.00 Epsilon = 0.383
# resultado da epoca 624 = 2623.00 Epsilon = 0.382
# resultado da epoca 625 = 2883.00 Epsilon = 0.381
# resultado da epoca 626 = 3326.00 Epsilon = 0.380
# resultado da epoca 627 = 2224.00 Epsilon = 0.379
# resultado da epoca 628 = 2053.00 Epsilon = 0.378
# resultado da epoca 629 = 1702.00 Epsilon = 0.377
# resultado da epoca 630 = 1942.00 Epsilon = 0.376
# resultado da epoca 631 = 1200.00 Epsilon = 0.375
# resultado da epoca 632 = 1036.00 Epsilon = 0.374
# resultado da epoca 633 = 2584.00 Epsilon = 0.373
# resultado da epoca 634 = 1769.00 Epsilon = 0.372
# resultado da epoca 635 = 1732.00 Epsilon = 0.371
# resultado da epoca 636 = 3406.00 Epsilon = 0.370
# resultado da epoca 637 = 2416.00 Epsilon = 0.369
# resultado da epoca 638 = 2256.00 Epsilon = 0.368
# resultado da epoca 639 = 1042.00 Epsilon = 0.367
# resultado da epoca 640 = 1786.00 Epsilon = 0.366
# resultado da epoca 641 = 2091.00 Epsilon = 0.365
# resultado da epoca 642 = 2049.00 Epsilon = 0.364
# resultado da epoca 643 = 2354.00 Epsilon = 0.363
# resultado da epoca 644 = 2287.00 Epsilon = 0.362
# resultado da epoca 645 = 2023.00 Epsilon = 0.361
# resultado da epoca 646 = 2597.00 Epsilon = 0.360
# resultado da epoca 647 = 1702.00 Epsilon = 0.359
# resultado da epoca 648 = 2245.00 Epsilon = 0.358
# resultado da epoca 649 = 1492.00 Epsilon = 0.357
# resultado da epoca 650 = 1369.00 Epsilon = 0.356
# resultado da epoca 651 = 2841.00 Epsilon = 0.356
# resultado da epoca 652 = 2314.00 Epsilon = 0.355
# resultado da epoca 653 = 2262.00 Epsilon = 0.354
# resultado da epoca 654 = 1804.00 Epsilon = 0.353
# resultado da epoca 655 = 2588.00 Epsilon = 0.352
# resultado da epoca 656 = 3159.00 Epsilon = 0.351
# resultado da epoca 657 = 1805.00 Epsilon = 0.350
# resultado da epoca 658 = 2148.00 Epsilon = 0.349
# resultado da epoca 659 = 1784.00 Epsilon = 0.348
# resultado da epoca 660 = 2865.00 Epsilon = 0.347
# resultado da epoca 661 = 2538.00 Epsilon = 0.346
# resultado da epoca 662 = 1030.00 Epsilon = 0.345
# resultado da epoca 663 = 726.00 Epsilon = 0.344
# resultado da epoca 664 = 2572.00 Epsilon = 0.343
# resultado da epoca 665 = 3813.00 Epsilon = 0.342
# resultado da epoca 666 = 3153.00 Epsilon = 0.341
# resultado da epoca 667 = 2955.00 Epsilon = 0.340
# resultado da epoca 668 = 3454.00 Epsilon = 0.339
# resultado da epoca 669 = 2998.00 Epsilon = 0.338
# resultado da epoca 670 = 1876.00 Epsilon = 0.337
# resultado da epoca 671 = 3509.00 Epsilon = 0.336
# resultado da epoca 672 = 3183.00 Epsilon = 0.335
# resultado da epoca 673 = 2966.00 Epsilon = 0.334
# resultado da epoca 674 = 2837.00 Epsilon = 0.333
# resultado da epoca 675 = 2261.00 Epsilon = 0.332
# resultado da epoca 676 = 1314.00 Epsilon = 0.331
# resultado da epoca 677 = 1798.00 Epsilon = 0.330
# resultado da epoca 678 = 1623.00 Epsilon = 0.329
# resultado da epoca 679 = 2483.00 Epsilon = 0.328
# resultado da epoca 680 = 3058.00 Epsilon = 0.327
# resultado da epoca 681 = 3056.00 Epsilon = 0.326
# resultado da epoca 682 = 1977.00 Epsilon = 0.325
# resultado da epoca 683 = 2803.00 Epsilon = 0.324
# resultado da epoca 684 = 2173.00 Epsilon = 0.323
# resultado da epoca 685 = 2207.00 Epsilon = 0.322
# resultado da epoca 686 = 2075.00 Epsilon = 0.321
# resultado da epoca 687 = 3297.00 Epsilon = 0.320
# resultado da epoca 688 = 2526.00 Epsilon = 0.319
# resultado da epoca 689 = 2501.00 Epsilon = 0.318
# resultado da epoca 690 = 2889.00 Epsilon = 0.317
# resultado da epoca 691 = 3124.00 Epsilon = 0.316
# resultado da epoca 692 = 3525.00 Epsilon = 0.315
# resultado da epoca 693 = 2197.00 Epsilon = 0.314
# resultado da epoca 694 = 3312.00 Epsilon = 0.313
# resultado da epoca 695 = 739.00 Epsilon = 0.312
# resultado da epoca 696 = 2498.00 Epsilon = 0.311
# resultado da epoca 697 = 1644.00 Epsilon = 0.310
# resultado da epoca 698 = 2040.00 Epsilon = 0.309
# resultado da epoca 699 = 1719.00 Epsilon = 0.308
# resultado da epoca 700 = 2132.00 Epsilon = 0.307
# resultado da epoca 701 = 3273.00 Epsilon = 0.306
# resultado da epoca 702 = 3737.00 Epsilon = 0.305
# resultado da epoca 703 = 2324.00 Epsilon = 0.304
# resultado da epoca 704 = 2054.00 Epsilon = 0.303
# resultado da epoca 705 = 3060.00 Epsilon = 0.302
# resultado da epoca 706 = 2809.00 Epsilon = 0.301
# resultado da epoca 707 = 2601.00 Epsilon = 0.300
# resultado da epoca 708 = 2280.00 Epsilon = 0.299
# resultado da epoca 709 = 2046.00 Epsilon = 0.298
# resultado da epoca 710 = 2637.00 Epsilon = 0.297
# resultado da epoca 711 = 3922.00 Epsilon = 0.296
# resultado da epoca 712 = 2736.00 Epsilon = 0.295
# resultado da epoca 713 = 2684.00 Epsilon = 0.294
# resultado da epoca 714 = 2902.00 Epsilon = 0.293
# resultado da epoca 715 = 2188.00 Epsilon = 0.292
# resultado da epoca 716 = 3546.00 Epsilon = 0.291
# resultado da epoca 717 = 3316.00 Epsilon = 0.290
# resultado da epoca 718 = 2641.00 Epsilon = 0.289
# resultado da epoca 719 = 3174.00 Epsilon = 0.288
# resultado da epoca 720 = 3900.00 Epsilon = 0.287
# resultado da epoca 721 = 3370.00 Epsilon = 0.286
# resultado da epoca 722 = 3090.00 Epsilon = 0.285
# resultado da epoca 723 = 3187.00 Epsilon = 0.284
# resultado da epoca 724 = 2790.00 Epsilon = 0.283
# resultado da epoca 725 = 2361.00 Epsilon = 0.282
# resultado da epoca 726 = 3477.00 Epsilon = 0.281
# resultado da epoca 727 = 3552.00 Epsilon = 0.280
# resultado da epoca 728 = 3400.00 Epsilon = 0.279
# resultado da epoca 729 = 2291.00 Epsilon = 0.278
# resultado da epoca 730 = 4519.00 Epsilon = 0.277
# resultado da epoca 731 = 2218.00 Epsilon = 0.276
# resultado da epoca 732 = 1979.00 Epsilon = 0.275
# resultado da epoca 733 = 3882.00 Epsilon = 0.274
# resultado da epoca 734 = 3021.00 Epsilon = 0.273
# resultado da epoca 735 = 2239.00 Epsilon = 0.272
# resultado da epoca 736 = 3448.00 Epsilon = 0.271
# resultado da epoca 737 = 2730.00 Epsilon = 0.270
# resultado da epoca 738 = 4136.00 Epsilon = 0.269
# resultado da epoca 739 = 2918.00 Epsilon = 0.268
# resultado da epoca 740 = 2335.00 Epsilon = 0.267
# resultado da epoca 741 = 2782.00 Epsilon = 0.266
# resultado da epoca 742 = 3368.00 Epsilon = 0.265
# resultado da epoca 743 = 3307.00 Epsilon = 0.264
# resultado da epoca 744 = 2788.00 Epsilon = 0.263
# resultado da epoca 745 = 2359.00 Epsilon = 0.262
# resultado da epoca 746 = 2898.00 Epsilon = 0.261
# resultado da epoca 747 = 2323.00 Epsilon = 0.260
# resultado da epoca 748 = 2765.00 Epsilon = 0.259
# resultado da epoca 749 = 3717.00 Epsilon = 0.258
# resultado da epoca 750 = 3746.00 Epsilon = 0.257
# resultado da epoca 751 = 2359.00 Epsilon = 0.257
# resultado da epoca 752 = 2572.00 Epsilon = 0.256
# resultado da epoca 753 = 3089.00 Epsilon = 0.255
# resultado da epoca 754 = 1439.00 Epsilon = 0.254
# resultado da epoca 755 = 2910.00 Epsilon = 0.253
# resultado da epoca 756 = 2160.00 Epsilon = 0.252
# resultado da epoca 757 = 3200.00 Epsilon = 0.251
# resultado da epoca 758 = 3119.00 Epsilon = 0.250
# resultado da epoca 759 = 3196.00 Epsilon = 0.249
# resultado da epoca 760 = 4167.00 Epsilon = 0.248
# resultado da epoca 761 = 1968.00 Epsilon = 0.247
# resultado da epoca 762 = 4053.00 Epsilon = 0.246
# resultado da epoca 763 = 3659.00 Epsilon = 0.245
# resultado da epoca 764 = 3036.00 Epsilon = 0.244
# resultado da epoca 765 = 3037.00 Epsilon = 0.243
# resultado da epoca 766 = 3621.00 Epsilon = 0.242
# resultado da epoca 767 = 2417.00 Epsilon = 0.241
# resultado da epoca 768 = 2476.00 Epsilon = 0.240
# resultado da epoca 769 = 4066.00 Epsilon = 0.239
# resultado da epoca 770 = 2597.00 Epsilon = 0.238
# resultado da epoca 771 = 3000.00 Epsilon = 0.237
# resultado da epoca 772 = 3968.00 Epsilon = 0.236
# resultado da epoca 773 = 2757.00 Epsilon = 0.235
# resultado da epoca 774 = 3917.00 Epsilon = 0.234
# resultado da epoca 775 = 3983.00 Epsilon = 0.233
# resultado da epoca 776 = 2933.00 Epsilon = 0.232
# resultado da epoca 777 = 3629.00 Epsilon = 0.231
# resultado da epoca 778 = 2830.00 Epsilon = 0.230
# resultado da epoca 779 = 3389.00 Epsilon = 0.229
# resultado da epoca 780 = 3520.00 Epsilon = 0.228
# resultado da epoca 781 = 3546.00 Epsilon = 0.227
# resultado da epoca 782 = 3671.00 Epsilon = 0.226
# resultado da epoca 783 = 3983.00 Epsilon = 0.225
# resultado da epoca 784 = 3617.00 Epsilon = 0.224
# resultado da epoca 785 = 3141.00 Epsilon = 0.223
# resultado da epoca 786 = 3008.00 Epsilon = 0.222
# resultado da epoca 787 = 3070.00 Epsilon = 0.221
# resultado da epoca 788 = 3772.00 Epsilon = 0.220
# resultado da epoca 789 = 3512.00 Epsilon = 0.219
# resultado da epoca 790 = 4188.00 Epsilon = 0.218
# resultado da epoca 791 = 3908.00 Epsilon = 0.217
# resultado da epoca 792 = 3822.00 Epsilon = 0.216
# resultado da epoca 793 = 3949.00 Epsilon = 0.215
# resultado da epoca 794 = 3748.00 Epsilon = 0.214
# resultado da epoca 795 = 3968.00 Epsilon = 0.213
# resultado da epoca 796 = 3827.00 Epsilon = 0.212
# resultado da epoca 797 = 3555.00 Epsilon = 0.211
# resultado da epoca 798 = 3991.00 Epsilon = 0.210
# resultado da epoca 799 = 3532.00 Epsilon = 0.209
# resultado da epoca 800 = 3105.00 Epsilon = 0.208
# resultado da epoca 801 = 3227.00 Epsilon = 0.207
# resultado da epoca 802 = 3843.00 Epsilon = 0.206
# resultado da epoca 803 = 4044.00 Epsilon = 0.205
# resultado da epoca 804 = 3271.00 Epsilon = 0.204
# resultado da epoca 805 = 4857.00 Epsilon = 0.203
# resultado da epoca 806 = 3393.00 Epsilon = 0.202
# resultado da epoca 807 = 3730.00 Epsilon = 0.201
# resultado da epoca 808 = 3773.00 Epsilon = 0.200
# resultado da epoca 809 = 3183.00 Epsilon = 0.199
# resultado da epoca 810 = 3426.00 Epsilon = 0.198
# resultado da epoca 811 = 3527.00 Epsilon = 0.197
# resultado da epoca 812 = 3411.00 Epsilon = 0.196
# resultado da epoca 813 = 4224.00 Epsilon = 0.195
# resultado da epoca 814 = 4217.00 Epsilon = 0.194
# resultado da epoca 815 = 3697.00 Epsilon = 0.193
# resultado da epoca 816 = 4223.00 Epsilon = 0.192
# resultado da epoca 817 = 4730.00 Epsilon = 0.191
# resultado da epoca 818 = 3427.00 Epsilon = 0.190
# resultado da epoca 819 = 3468.00 Epsilon = 0.189
# resultado da epoca 820 = 4112.00 Epsilon = 0.188
# resultado da epoca 821 = 4009.00 Epsilon = 0.187
# resultado da epoca 822 = 3219.00 Epsilon = 0.186
# resultado da epoca 823 = 3579.00 Epsilon = 0.185
# resultado da epoca 824 = 4813.00 Epsilon = 0.184
# resultado da epoca 825 = 2497.00 Epsilon = 0.183
# resultado da epoca 826 = 4603.00 Epsilon = 0.182
# resultado da epoca 827 = 4500.00 Epsilon = 0.181
# resultado da epoca 828 = 3394.00 Epsilon = 0.180
# resultado da epoca 829 = 3463.00 Epsilon = 0.179
# resultado da epoca 830 = 2644.00 Epsilon = 0.178
# resultado da epoca 831 = 4537.00 Epsilon = 0.177
# resultado da epoca 832 = 4211.00 Epsilon = 0.176
# resultado da epoca 833 = 3822.00 Epsilon = 0.175
# resultado da epoca 834 = 4583.00 Epsilon = 0.174
# resultado da epoca 835 = 4868.00 Epsilon = 0.173
# resultado da epoca 836 = 4010.00 Epsilon = 0.172
# resultado da epoca 837 = 4715.00 Epsilon = 0.171
# resultado da epoca 838 = 2905.00 Epsilon = 0.170
# resultado da epoca 839 = 2899.00 Epsilon = 0.169
# resultado da epoca 840 = 3505.00 Epsilon = 0.168
# resultado da epoca 841 = 3848.00 Epsilon = 0.167
# resultado da epoca 842 = 3017.00 Epsilon = 0.166
# resultado da epoca 843 = 4551.00 Epsilon = 0.165
# resultado da epoca 844 = 2068.00 Epsilon = 0.164
# resultado da epoca 845 = 4693.00 Epsilon = 0.163
# resultado da epoca 846 = 4180.00 Epsilon = 0.162
# resultado da epoca 847 = 3789.00 Epsilon = 0.161
# resultado da epoca 848 = 4488.00 Epsilon = 0.160
# resultado da epoca 849 = 4540.00 Epsilon = 0.159
# resultado da epoca 850 = 3883.00 Epsilon = 0.158
# resultado da epoca 851 = 5070.00 Epsilon = 0.158
# resultado da epoca 852 = 3656.00 Epsilon = 0.157
# resultado da epoca 853 = 3476.00 Epsilon = 0.156
# resultado da epoca 854 = 4429.00 Epsilon = 0.155
# resultado da epoca 855 = 3959.00 Epsilon = 0.154
# resultado da epoca 856 = 3984.00 Epsilon = 0.153
# resultado da epoca 857 = 3980.00 Epsilon = 0.152
# resultado da epoca 858 = 3960.00 Epsilon = 0.151
# resultado da epoca 859 = 3599.00 Epsilon = 0.150
# resultado da epoca 860 = 4019.00 Epsilon = 0.149
# resultado da epoca 861 = 3798.00 Epsilon = 0.148
# resultado da epoca 862 = 4303.00 Epsilon = 0.147
# resultado da epoca 863 = 3771.00 Epsilon = 0.146
# resultado da epoca 864 = 4546.00 Epsilon = 0.145
# resultado da epoca 865 = 3783.00 Epsilon = 0.144
# resultado da epoca 866 = 4443.00 Epsilon = 0.143
# resultado da epoca 867 = 3463.00 Epsilon = 0.142
# resultado da epoca 868 = 4713.00 Epsilon = 0.141
# resultado da epoca 869 = 3840.00 Epsilon = 0.140
# resultado da epoca 870 = 4316.00 Epsilon = 0.139
# resultado da epoca 871 = 3927.00 Epsilon = 0.138
# resultado da epoca 872 = 3508.00 Epsilon = 0.137
# resultado da epoca 873 = 4475.00 Epsilon = 0.136
# resultado da epoca 874 = 3830.00 Epsilon = 0.135
# resultado da epoca 875 = 3635.00 Epsilon = 0.134
# resultado da epoca 876 = 4291.00 Epsilon = 0.133
# resultado da epoca 877 = 3386.00 Epsilon = 0.132
# resultado da epoca 878 = 4197.00 Epsilon = 0.131
# resultado da epoca 879 = 5029.00 Epsilon = 0.130
# resultado da epoca 880 = 4497.00 Epsilon = 0.129
# resultado da epoca 881 = 4255.00 Epsilon = 0.128
# resultado da epoca 882 = 4106.00 Epsilon = 0.127
# resultado da epoca 883 = 3387.00 Epsilon = 0.126
# resultado da epoca 884 = 4564.00 Epsilon = 0.125
# resultado da epoca 885 = 4023.00 Epsilon = 0.124
# resultado da epoca 886 = 4229.00 Epsilon = 0.123
# resultado da epoca 887 = 4813.00 Epsilon = 0.122
# resultado da epoca 888 = 3670.00 Epsilon = 0.121
# resultado da epoca 889 = 3759.00 Epsilon = 0.120
# resultado da epoca 890 = 4385.00 Epsilon = 0.119
# resultado da epoca 891 = 4284.00 Epsilon = 0.118
# resultado da epoca 892 = 3906.00 Epsilon = 0.117
# resultado da epoca 893 = 4657.00 Epsilon = 0.116
# resultado da epoca 894 = 4714.00 Epsilon = 0.115
# resultado da epoca 895 = 3867.00 Epsilon = 0.114
# resultado da epoca 896 = 4128.00 Epsilon = 0.113
# resultado da epoca 897 = 4275.00 Epsilon = 0.112
# resultado da epoca 898 = 4315.00 Epsilon = 0.111
# resultado da epoca 899 = 4393.00 Epsilon = 0.110
# resultado da epoca 900 = 5176.00 Epsilon = 0.109
# resultado da epoca 901 = 4395.00 Epsilon = 0.108
# resultado da epoca 902 = 4615.00 Epsilon = 0.107
# resultado da epoca 903 = 4829.00 Epsilon = 0.106
# resultado da epoca 904 = 4671.00 Epsilon = 0.105
# resultado da epoca 905 = 3185.00 Epsilon = 0.104
# resultado da epoca 906 = 4712.00 Epsilon = 0.103
# resultado da epoca 907 = 4458.00 Epsilon = 0.102
# resultado da epoca 908 = 4499.00 Epsilon = 0.101
# resultado da epoca 909 = 4592.00 Epsilon = 0.100
# resultado da epoca 910 = 4296.00 Epsilon = 0.099
# resultado da epoca 911 = 5050.00 Epsilon = 0.098
# resultado da epoca 912 = 5270.00 Epsilon = 0.097
# resultado da epoca 913 = 4452.00 Epsilon = 0.096
# resultado da epoca 914 = 4554.00 Epsilon = 0.095
# resultado da epoca 915 = 4360.00 Epsilon = 0.094
# resultado da epoca 916 = 3654.00 Epsilon = 0.093
# resultado da epoca 917 = 4937.00 Epsilon = 0.092
# resultado da epoca 918 = 5198.00 Epsilon = 0.091
# resultado da epoca 919 = 4509.00 Epsilon = 0.090
# resultado da epoca 920 = 5097.00 Epsilon = 0.089
# resultado da epoca 921 = 4826.00 Epsilon = 0.088
# resultado da epoca 922 = 4415.00 Epsilon = 0.087
# resultado da epoca 923 = 5069.00 Epsilon = 0.086
# resultado da epoca 924 = 4685.00 Epsilon = 0.085
# resultado da epoca 925 = 4763.00 Epsilon = 0.084
# resultado da epoca 926 = 4783.00 Epsilon = 0.083
# resultado da epoca 927 = 4589.00 Epsilon = 0.082
# resultado da epoca 928 = 3971.00 Epsilon = 0.081
# resultado da epoca 929 = 5247.00 Epsilon = 0.080
# resultado da epoca 930 = 4007.00 Epsilon = 0.079
# resultado da epoca 931 = 4785.00 Epsilon = 0.078
# resultado da epoca 932 = 4993.00 Epsilon = 0.077
# resultado da epoca 933 = 4655.00 Epsilon = 0.076
# resultado da epoca 934 = 4713.00 Epsilon = 0.075
# resultado da epoca 935 = 3621.00 Epsilon = 0.074
# resultado da epoca 936 = 4957.00 Epsilon = 0.073
# resultado da epoca 937 = 5058.00 Epsilon = 0.072
# resultado da epoca 938 = 4979.00 Epsilon = 0.071
# resultado da epoca 939 = 4547.00 Epsilon = 0.070
# resultado da epoca 940 = 4282.00 Epsilon = 0.069
# resultado da epoca 941 = 4489.00 Epsilon = 0.068
# resultado da epoca 942 = 4591.00 Epsilon = 0.067
# resultado da epoca 943 = 4916.00 Epsilon = 0.066
# resultado da epoca 944 = 5424.00 Epsilon = 0.065
# resultado da epoca 945 = 4640.00 Epsilon = 0.064
# resultado da epoca 946 = 5082.00 Epsilon = 0.063
# resultado da epoca 947 = 5014.00 Epsilon = 0.062
# resultado da epoca 948 = 5171.00 Epsilon = 0.061
# resultado da epoca 949 = 5022.00 Epsilon = 0.060
# resultado da epoca 950 = 4425.00 Epsilon = 0.059
# resultado da epoca 951 = 4997.00 Epsilon = 0.059
# resultado da epoca 952 = 4370.00 Epsilon = 0.058
# resultado da epoca 953 = 5062.00 Epsilon = 0.057
# resultado da epoca 954 = 4981.00 Epsilon = 0.056
# resultado da epoca 955 = 4624.00 Epsilon = 0.055
# resultado da epoca 956 = 5154.00 Epsilon = 0.054
# resultado da epoca 957 = 4624.00 Epsilon = 0.053
# resultado da epoca 958 = 5117.00 Epsilon = 0.052
# resultado da epoca 959 = 4500.00 Epsilon = 0.051
# resultado da epoca 960 = 5160.00 Epsilon = 0.050
# resultado da epoca 961 = 4879.00 Epsilon = 0.049
# resultado da epoca 962 = 5220.00 Epsilon = 0.048
# resultado da epoca 963 = 5245.00 Epsilon = 0.047
# resultado da epoca 964 = 4496.00 Epsilon = 0.046
# resultado da epoca 965 = 4794.00 Epsilon = 0.045
# resultado da epoca 966 = 5468.00 Epsilon = 0.044
# resultado da epoca 967 = 5435.00 Epsilon = 0.043
# resultado da epoca 968 = 5017.00 Epsilon = 0.042
# resultado da epoca 969 = 4603.00 Epsilon = 0.041
# resultado da epoca 970 = 5565.00 Epsilon = 0.040
# resultado da epoca 971 = 5020.00 Epsilon = 0.039
# resultado da epoca 972 = 5276.00 Epsilon = 0.038
# resultado da epoca 973 = 5416.00 Epsilon = 0.037
# resultado da epoca 974 = 5095.00 Epsilon = 0.036
# resultado da epoca 975 = 4767.00 Epsilon = 0.035
# resultado da epoca 976 = 5381.00 Epsilon = 0.034
# resultado da epoca 977 = 5185.00 Epsilon = 0.033
# resultado da epoca 978 = 5033.00 Epsilon = 0.032
# resultado da epoca 979 = 4913.00 Epsilon = 0.031
# resultado da epoca 980 = 4988.00 Epsilon = 0.030
# resultado da epoca 981 = 5061.00 Epsilon = 0.029
# resultado da epoca 982 = 5263.00 Epsilon = 0.028
# resultado da epoca 983 = 4426.00 Epsilon = 0.027
# resultado da epoca 984 = 5487.00 Epsilon = 0.026
# resultado da epoca 985 = 5565.00 Epsilon = 0.025
# resultado da epoca 986 = 5203.00 Epsilon = 0.024
# resultado da epoca 987 = 5454.00 Epsilon = 0.023
# resultado da epoca 988 = 5014.00 Epsilon = 0.022
# resultado da epoca 989 = 5439.00 Epsilon = 0.021
# resultado da epoca 990 = 5406.00 Epsilon = 0.020
# resultado da epoca 991 = 5368.00 Epsilon = 0.019
# resultado da epoca 992 = 5565.00 Epsilon = 0.018
# resultado da epoca 993 = 5237.00 Epsilon = 0.017
# resultado da epoca 994 = 5350.00 Epsilon = 0.016
# resultado da epoca 995 = 5565.00 Epsilon = 0.015
# resultado da epoca 996 = 4974.00 Epsilon = 0.014
# resultado da epoca 997 = 5470.00 Epsilon = 0.013
# resultado da epoca 998 = 5278.00 Epsilon = 0.012
# resultado da epoca 999 = 5565.00 Epsilon = 0.011
# Melhor resultado diario: 5565.00

# %%
modelo.epsilon = 0
print(rodar_dias(inputs, custo))
# Out:
# 5565.0
